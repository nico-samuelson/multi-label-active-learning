# %%
import pandas as pd

# --- Configuration ---
csv_file_path = './val_data.csv'  # <--- IMPORTANT: Replace with the actual path to your CSV file

# List of your label columns
label_columns = [
    'fuel', 'machine', 'others', 'part', 'price', 'service'
]
# --- End Configuration ---

try:
    # Load the dataset from the CSV file
    df = pd.read_csv(csv_file_path)

    # Verify that all specified label columns exist in the DataFrame
    missing_cols = [col for col in label_columns if col not in df.columns]
    if missing_cols:
        print(f"Error: The following label columns were not found in the CSV: {missing_cols}")
        print(f"Available columns are: {list(df.columns)}")
    else:
        # Select only the label columns (optional, but good practice if there are many other columns)
        # labels_df = df[label_columns] # You can use either df or labels_df below

        # Group by all label columns and count the size of each group
        # This effectively counts rows where the combination of values in label_columns is identical.
        combination_counts = df.groupby(label_columns).size()

        # Convert the result (which is a pandas Series with a MultiIndex)
        # into a DataFrame for easier viewing. The count is named 'Count'.
        combination_counts_df = combination_counts.reset_index(name='Count')

        # Sort the results by count in descending order (most frequent combinations first)
        combination_counts_df = combination_counts_df.sort_values('Count', ascending=False)

        combination_counts_df.to_csv('label_combination_counts_2.csv', index=False)

        # --- Display the results ---
        print(f"Found {len(combination_counts_df)} unique label combinations.")
        print("\nLabel Combination Occurrences (Top 20 shown if more exist):")
        # Use pd.option_context to temporarily display more rows if needed
        with pd.option_context('display.max_rows', 100):
              print(combination_counts_df)

        # Optional: Save the results to a new CSV file
        # output_csv_path = 'label_combination_counts.csv'
        # combination_counts_df.to_csv(output_csv_path, index=False)
        # print(f"\nResults saved to {output_csv_path}")


except FileNotFoundError:
    print(f"Error: The file '{csv_file_path}' was not found.")
    print("Please make sure the file path is correct and the file exists.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Found 37 unique label combinations.
#
# Label Combination Occurrences (Top 20 shown if more exist):
#         fuel   machine    others      part     price   service  Count
# 18   neutral   neutral  positive   neutral   neutral   neutral     34
# 9    neutral   neutral   neutral  negative   neutral   neutral     21
# 15   neutral   neutral   neutral  positive   neutral   neutral     17
# 4    neutral  negative   neutral   neutral   neutral   neutral     15
# 11   neutral   neutral   neutral   neutral   neutral  negative     14
# 12   neutral   neutral   neutral   neutral   neutral  positive     13
# 30  positive   neutral   neutral   neutral   neutral   neutral     11
# 21   neutral  positive   neutral   neutral   neutral   neutral     10
# 6    neutral   neutral  negative   neutral   neutral   neutral     10
# 13   neutral   neutral   neutral   neutral  positive   neutral      9
# 0   negative   neutral   neutral   neutral   neutral   neutral      9
# 10   neutral   neutral   neutral   neutral  negative   neutral      9
# 33  positive  positive   neutral   neutral   neutral   neutral      5
# 23   neutral  positive   neutral  positive   neutral   neutral      5
# 20   neutral   neutral  positive  positive   neutral   neutral      4
# 26   neutral  positive  positive   neutral   neutral   neutral      3
# 16   neutral   neutral   neutral  positive  positive   neutral      3
# 34  positive  positive   neutral  positive   neutral   neutral      2
# 32  positive   neutral  positive   neutral   neutral   neutral      2
# 31  positive   neutral   neutral  positive   neutral   neutral      2
# 19   neutral   neutral  positive   neutral  positive   neutral      2
# 35  positive  positive  positive   neutral   neutral   neutral      1
# 2   negative   neutral  positive   neutral   neutral   neutral      1
# 29   neutral  positive  positive  positive  positive   neutral      1
# 28   neutral  positive  positive  positive   neutral  positive      1
# 27   neutral  positive  positive   neutral   neutral  positive      1
# 24   neutral  positive   neutral  positive   neutral  positive      1
# 25   neutral  positive   neutral  positive  positive  positive      1
# 8    neutral   neutral   neutral  negative  negative   neutral      1
# 22   neutral  positive   neutral   neutral  positive   neutral      1
# 3    neutral  negative   neutral  negative   neutral   neutral      1
# 1   negative   neutral   neutral  positive   neutral   neutral      1
# 17   neutral   neutral  positive   neutral  negative   neutral      1
# 5    neutral   neutral  negative   neutral  negative   neutral      1
# 14   neutral   neutral   neutral  positive  negative   neutral      1
# 7    neutral   neutral  negative  positive   neutral   neutral      1
# 36  positive  positive  positive  positive   neutral   neutral      1
