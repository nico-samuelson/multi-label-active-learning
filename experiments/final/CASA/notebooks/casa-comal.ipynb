# %%
import os
import time
import math
import torch
import random
import warnings
import numpy as np
import pandas as pd
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
from torch.multiprocessing import Manager
from torch.utils.data import DataLoader, Dataset
from torch.utils.data.sampler import SubsetRandomSampler
from sklearn.model_selection import train_test_split
from accelerate import Accelerator, notebook_launcher
from transformers import BertTokenizer, BertModel, BertConfig
from sklearn.metrics import precision_recall_fscore_support, f1_score, classification_report

# %% [markdown]
# # SETUP

# %%
warnings.filterwarnings('ignore')

# %%
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic=True
    torch.backends.cudnn.benchmark=False

set_seed(42)

# %% [markdown]
# # GLOBAL VARIABLES

# %%
manager = Manager()

# Shared resources
aspect_accuracies = manager.list()
aspect_f1_micros = manager.list()
aspect_f1_macros = manager.list()
sentiment_accuracies = manager.list()
sentiment_f1_micros = manager.list()
sentiment_f1_macros = manager.list()
accuracies = manager.list()
f1_micros = manager.list()
f1_macros = manager.list()

new_sample_data = manager.list()
new_sample_labels = manager.list()

# Non shared resources
filename = 'casa-comal'
epochs = 10
batch_size = 16
sequence_length = 48

aspect_list = ['fuel', 'machine', 'others', 'part', 'price', 'service']
aspect_mapping = {'fuel': 0, 'machine': 1, 'others': 2, 'part': 3, 'price': 4, 'service': 5 }
label_mapping = {"negative": 0, "neutral": 1, 'positive': 2}
ignored_keys = ['labels', 'ori_text', 'ori_label', 'ori_indices', 'aspect', 'sampler_loss_weight', 'all_labeled_mask']

# %% [markdown]
# # LOAD AND PREPROCESS DATA

# %%
train_data = pd.read_csv('/kaggle/input/casa-dataset/train_preprocess.csv', encoding='latin-1')
val_data = pd.read_csv('/kaggle/input/casa-dataset/valid_preprocess.csv', encoding='latin-1')
test_data = pd.read_csv('/kaggle/input/casa-dataset/test_preprocess.csv', encoding='latin-1')

data = pd.concat([train_data, val_data, test_data], ignore_index=True)

data.head()
# Out:
#                                             sentence      fuel   machine  \
# 0  Saya memakai Honda Jazz GK5 tahun 2014 ( perta...   neutral   neutral
# 1  Avanza kenapa jadi boros bensin begini dah ah....  negative   neutral
# 2  saran ku dan pengalaman ku , mending beli mobi...  positive  positive
# 3  Dari segi harga juga pajero lebih mahal 30 jut...   neutral   neutral
# 4                     Kalo menurut gw enak pajero si   neutral   neutral
#
#      others     part     price  service
# 0  positive  neutral   neutral  neutral
# 1   neutral  neutral   neutral  neutral
# 2   neutral  neutral   neutral  neutral
# 3   neutral  neutral  positive  neutral
# 4  positive  neutral   neutral  neutral

# %%
train_data, val_data = train_test_split(data, test_size=0.2, random_state=42, shuffle=False)

# %%
train_labels = train_data.columns[1:]
val_labels = val_data.columns[1:]

# Extract features and labels for training and validation
X_train = train_data['sentence'].values
y_train = train_data[train_labels].values
X_val = val_data['sentence'].values
y_val = val_data[val_labels].values

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
# Out:
# (864,) (864, 6)
# (216,) (216, 6)

# %% [markdown]
# # BULDING DATASET

# %%
tokenizer = BertTokenizer.from_pretrained('indobenchmark/indobert-base-p1')
review_token = '[REVIEW]'
aspect_token = '[ASPECT]'
special_tokens_dict = {'additional_special_tokens': [review_token, aspect_token]}
num_added_tokens = tokenizer.add_special_tokens(special_tokens_dict)
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/229k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.53k [00:00<?, ?B/s]

# %%
class AspectDetectionDataset(Dataset):
    def __init__(self, data, labels, tokenizer, label2id, aspect_list, max_length=48):
        # Initialize dataset with data, tokenizer, and label mappings
        self.data = data
        self.tokenizer = tokenizer
        self.label2id = label2id
        self.maxlength = sequence_length  # Maximum token length for input sequences
        self.all_labels_num = len(aspect_list)  # Total number of labels
        self.aspect_list = aspect_list
        self.pair_wise_sampled = None  # Tracks sampling status of label pairs
        self.gt_labels = labels  # Ground truth labels in one-hot format
        self.all_labeled_mask = None  # Indicates whether all labels of a sample have been queried
        self.max_length = max_length
        self.init()  # Initializes sampling and label mask states

    def init(self):
        # Initialize sampled pairs and mask for all data
        self.pair_wise_sampled = torch.ones(len(self.data), self.all_labels_num)
        self.all_labeled_mask = torch.zeros(len(self.data))  # Initially, no data is fully labeled

    def get_label_Cardinality(self):
        # Compute label cardinality, representing average positive labels per sample in the labeled pool
        labed_cnt = torch.sum(self.all_labeled_mask)  # Total number of samples fully labeled
        original_labels = torch.tensor([[self.label2id[label] for label in labels] for labels in self.gt_labels], dtype=torch.float32)
        encoded_labels = torch.tensor([[1 if label == 1 else 0 for label in labels] for labels in original_labels], dtype=torch.float32)
        all_labed_pos_label_cnt = torch.sum(self.all_labeled_mask.unsqueeze(-1) * encoded_labels)
        return all_labed_pos_label_cnt / labed_cnt  # Average number of positive labels per fully labeled sample

    def update_data(self, query_example_indices, query_label_indices=None, init_time=False):
        # Update dataset with new labeled data points and labels after each query cycle
        if query_label_indices is not None:
            ones = torch.ones(self.all_labels_num)
            for example_idx, label_idx in zip(query_example_indices, query_label_indices):
                # Access individual data and update based on queried label
                one_data = self.__getitem__(example_idx)
                one_label = one_data[1][label_idx]
                if one_label == 0:
                    # Set pair-wise sampled state for newly queried labels
                    self.pair_wise_sampled[example_idx][label_idx] = 1
                else:
                    self.pair_wise_sampled[example_idx][label_idx] = 1
                
                # Update all_labeled_mask if all labels for a sample are queried
                if torch.sum(ones - self.pair_wise_sampled[example_idx]) == 0:
                    self.all_labeled_mask[example_idx] = 1
        else:
            # Mark all labels as queried for each example if only examples are specified
            for example_idx in query_example_indices:
                ones = torch.ones(self.all_labels_num)
                self.pair_wise_sampled[example_idx] = ones
                self.all_labeled_mask[example_idx] = 1

    def get_labeled_set(self):
        # Return list of indices for samples that have been fully labeled
        labeled_set = []
        for idx, mask in enumerate(self.all_labeled_mask):
            if mask != 0:
                labeled_set.append(idx)
        return labeled_set

    def __len__(self):
        # Return the number of samples in the dataset
        return len(self.data)

    def __getitem__(self, idx):
        text = self.data[idx] 
        original_labels = torch.tensor([self.label2id[label] for label in self.gt_labels[idx]], dtype=torch.float32)
        encoded_labels = torch.tensor([1 if label == 1 else 0 for label in original_labels], dtype=torch.float32)

        # Tokenize the raw text and apply padding/truncation to reach maxlength
        encoding = self.tokenizer(
            text,
            padding='max_length',
            truncation=True,
            max_length=self.max_length,
            return_tensors="pt"
        )

        input_ids = encoding['input_ids'].squeeze(0)  # Remove batch dimension
        input_type_ids = encoding.get('token_type_ids', torch.zeros_like(input_ids))
        input_mask = encoding['attention_mask'].squeeze(0)
        text_inputs = [input_ids, input_type_ids, input_mask]
        sampler_loss_weight = self.pair_wise_sampled[idx]  # Weight for active learning sample 

        inputs_list = [text_inputs, encoded_labels, idx, sampler_loss_weight, self.all_labeled_mask[idx], text, original_labels]
        return inputs_list

# %%
class SentimentAnalysisDataset(Dataset):
    def __init__(self, data, labels, aspects, indices, tokenizer, label2id, max_length):
        # Initialize dataset with data, tokenizer, and label mappings
        self.data = data
        self.tokenizer = tokenizer
        self.label2id = label2id
        self.maxlength = sequence_length  # Maximum token length for input sequences
        self.all_labels_num = 2
        self.pair_wise_sampled = None  # Tracks sampling status of label pairs
        self.gt_labels = labels  # Ground truth labels in one-hot format
        self.all_labeled_mask = None  # Indicates whether all labels of a sample have been queried
        self.aspects = aspects
        self.indices = indices
        self.max_length = max_length
        self.init()  # Initializes sampling and label mask states

    def init(self):
        # Initialize sampled pairs and mask for all data
        self.pair_wise_sampled = torch.ones(len(self.data), self.all_labels_num)
        self.all_labeled_mask = torch.zeros(len(self.data))  # Initially, no data is fully labeled

    def get_label_Cardinality(self):
        # Compute label cardinality, representing average positive labels per sample in the labeled pool
        labed_cnt = torch.sum(self.all_labeled_mask)  # Total number of samples fully labeled
        all_labed_pos_label_cnt = torch.sum(self.all_labeled_mask.unsqueeze(-1) * self.gt_labels)
        return all_labed_pos_label_cnt / labed_cnt  # Average number of positive labels per fully labeled sample

    def update_data(self, query_example_indices, query_label_indices=None, init_time=False):
        # Update dataset with new labeled data points and labels after each query cycle
        if query_label_indices is not None:
            ones = torch.ones(self.all_labels_num)
            for example_idx, label_idx in zip(query_example_indices, query_label_indices):
                # Access individual data and update based on queried label
                one_data = self.__getitem__(example_idx)
                one_label = one_data[1][label_idx]
                if one_label == 0:
                    # Set pair-wise sampled state for newly queried labels
                    self.pair_wise_sampled[example_idx][label_idx] = 1
                else:
                    self.pair_wise_sampled[example_idx][label_idx] = 1
                
                # Update all_labeled_mask if all labels for a sample are queried
                if torch.sum(ones - self.pair_wise_sampled[example_idx]) == 0:
                    self.all_labeled_mask[example_idx] = 1
        else:
            # Mark all labels as queried for each example if only examples are specified
            for example_idx in query_example_indices:
                ones = torch.ones(self.all_labels_num)
                self.pair_wise_sampled[example_idx] = ones
                self.all_labeled_mask[example_idx] = 1

    def get_labeled_set(self):
        # Return list of indices for samples that have been fully labeled
        labeled_set = []
        for idx, mask in enumerate(self.all_labeled_mask):
            if mask != 0:
                labeled_set.append(idx)
        return labeled_set

    def __len__(self):
        # Return the number of samples in the dataset
        return len(self.data)

    def __getitem__(self, idx):
        text = aspect_token + ' ' + self.aspects[idx] + ' ' + review_token + ' ' + self.data[idx] 

        # Tokenize the raw text and apply padding/truncation to reach maxlength
        encoding = self.tokenizer(
            text,
            padding='max_length',
            truncation=True,
            max_length=self.max_length,
            return_tensors="pt"
        )

        if isinstance(self.gt_labels[idx], str):
            self.gt_labels[idx] = self.label2id[self.gt_labels[idx]]
        elif torch.is_tensor(self.gt_labels[idx]):
            self.gt_labels[idx] = int(self.gt_labels[idx].item())

        encoded_label = 1 if self.gt_labels[idx] == 2 else self.gt_labels[idx]
        one_hot_label = F.one_hot(torch.tensor(encoded_label, dtype=torch.long), num_classes=2).float()

        input_ids = encoding['input_ids'].squeeze(0)  # Remove batch dimension
        input_type_ids = encoding.get('token_type_ids', torch.zeros_like(input_ids))
        input_mask = encoding['attention_mask'].squeeze(0)
        text_inputs = [input_ids, input_type_ids, input_mask]
        sampler_loss_weight = self.pair_wise_sampled[idx]  # Weight for active learning sample 
        original_label = torch.tensor(self.gt_labels[idx], dtype=torch.long)
        aspect = self.aspects[idx]

        inputs_list = [text_inputs, one_hot_label, idx, sampler_loss_weight, self.all_labeled_mask[idx], text, original_label, aspect, self.indices[idx]]
        return inputs_list

# %%
def build_aspect_dataset(X_train, y_train, X_val, y_val, sequence_length, num_workers=4):
    train_dataset = AspectDetectionDataset(X_train, y_train, tokenizer, label_mapping, aspect_list, max_length=sequence_length)
    val_dataset = AspectDetectionDataset(X_val, y_val, tokenizer, label_mapping, aspect_list, max_length=sequence_length)
    
    train_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=batch_size, shuffle=True, pin_memory=True, num_workers=num_workers,
    )
    val_loader = torch.utils.data.DataLoader(
        val_dataset, batch_size=batch_size, shuffle=False, pin_memory=True, num_workers=num_workers, 
    )

    return train_loader, val_loader, train_dataset, val_dataset

# %%
def build_sentiment_dataset(device, train_dataset, val_dataset, aspect_detection_model, tokenizer, max_length=sequence_length):
    train_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=batch_size, shuffle=False, pin_memory=True, num_workers=4, 
    )
    val_loader = torch.utils.data.DataLoader(
        val_dataset, batch_size=batch_size, shuffle=False, pin_memory=True, num_workers=4, 
    )

    aspect_detection_model.to(device)
    aspect_detection_model.eval()

    train_data = []
    train_labels = []
    train_aspects = []
    train_indices = []

    val_data = []
    val_labels = []
    val_aspects = []
    val_indices = []

    # Transform train set
    with torch.no_grad():
        for batch in train_loader:
            input_ids, input_type_ids, input_mask = [x.to(device) for x in batch[0]]
            inputs_list = [input_ids, input_type_ids, input_mask, None]
            
            outputs = aspect_detection_model(inputs_list)
            preds = torch.sigmoid(outputs[0]).round()

            for i in range(len(preds)):
                for j in range(len(preds[i])):
                    if int(preds[i][j]) != 1:
                        train_aspects.append(aspect_list[j])
                        train_data.append(batch[5][i])
                        train_labels.append(batch[6][i][j])
                        train_indices.append(batch[2][i])
            
        # Transform validation set
        for batch in val_loader:
            input_ids, input_type_ids, input_mask = [x.to(device) for x in batch[0]]
            inputs_list = [input_ids, input_type_ids, input_mask, None]
            
            outputs = aspect_detection_model(inputs_list)
            preds = torch.sigmoid(outputs[0]).round()

            for i in range(len(preds)):
                for j in range(len(preds[i])):
                    if int(preds[i][j]) != 1:
                        val_aspects.append(aspect_list[j])
                        val_data.append(batch[5][i])
                        val_labels.append(batch[6][i][j])
                        val_indices.append(batch[2][i])

    train_dataset = SentimentAnalysisDataset(train_data, train_labels, train_aspects, train_indices, tokenizer, label_mapping, max_length=max_length)
    val_dataset = SentimentAnalysisDataset(val_data, val_labels, val_aspects, val_indices, tokenizer, label_mapping, max_length=max_length)

    train_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=batch_size, shuffle=True, pin_memory=True, num_workers=4, 
    )
    val_loader = torch.utils.data.DataLoader(
        val_dataset, batch_size=batch_size, shuffle=False, pin_memory=True, num_workers=4, 
    )

    return train_loader, val_loader, train_dataset, val_dataset

# %% [markdown]
# # DEFINE THE MODEL

# %%
class IndoBERT_Backbone(nn.Module):
    def __init__(self, label_num):
        super(IndoBERT_Backbone, self).__init__()
        self.label_num = label_num
        self.encoder = IndoBERT_Encoder(label_num)
        model_config = BertConfig.from_pretrained("indobenchmark/indobert-base-p1")
        self.clf = nn.Linear(model_config.hidden_size, label_num)
        nn.init.xavier_uniform_(self.clf.weight)

    def forward(self, inputs):
        encoder_out = self.encoder(inputs)
        out = self.clf(encoder_out)
        return out, encoder_out

class IndoBERT_Encoder(nn.Module):
    def __init__(self, label_num):
        super(IndoBERT_Encoder, self).__init__()
        self.label_num = label_num
        self.encoder = BertModel.from_pretrained(
            'indobenchmark/indobert-base-p1',
            num_labels=self.label_num,
        )
        
        self.encoder_init()

    def encoder_init(self):
        all_layers = ['embeddings', 'layer.0', 'layer.1', 'layer.2', 'layer.3', 'layer.4', 'layer.5', 'layer.6',
                      'layer.7', 'layer.8', 'layer.9', 'layer.10', 'layer.11', 'pooler']
        unfreeze_layers = all_layers[7:]
        for name, param in self.encoder.named_parameters():
            param.requires_grad = False
            for ele in unfreeze_layers:
                if ele in name:
                    param.requires_grad = True
                    break

    def forward(self, inputs):
        # Ensure each component in inputs is a tensor
        input_ids = torch.tensor(inputs[0]) if not isinstance(inputs[0], torch.Tensor) else inputs[0]
        token_type_ids = torch.tensor(inputs[1]) if not isinstance(inputs[1], torch.Tensor) else inputs[1]
        attention_mask = torch.tensor(inputs[2]) if not isinstance(inputs[2], torch.Tensor) else inputs[2]
        
        input_ids = input_ids.view(-1, input_ids.size(-1))  # Ensuring batch_size, sequence_length
        token_type_ids = token_type_ids.view(input_ids.size(0), -1)  # Reshaping to [batch_size, sequence_length]
        attention_mask = attention_mask.view(-1, attention_mask.size(-1))
        
        outputs = self.encoder(
            input_ids=input_ids,
            token_type_ids=token_type_ids,
            attention_mask=attention_mask,
        )
        cls_output = outputs.pooler_output
        return cls_output

# %%
class MLP_VAE(nn.Module):
    def __init__(self, hidden_size, device, label_num):
        super(MLP_VAE, self).__init__()
        self.device = device
        self.label_num = label_num
        self.cl_neg_mode = 1
        self.proto_size = 256
        self.hidden_size = hidden_size
        
        # Initial fully connected layer to project input to higher-dimensional space for each label
        self.fc0 = nn.Linear(self.hidden_size, self.label_num * 512)
        self.fc1 = nn.Linear(512, self.proto_size)  # Dimensionality reduction for prototypes

        # Adjust the number of label representations based on contrastive learning mode
        if self.cl_neg_mode == 0:
            cl_label_num = self.label_num  # Standard label number
        elif self.cl_neg_mode == 1:
            cl_label_num = self.label_num + 1  # Add one for negative prototype handling
            self.ins_neg_cnt = torch.zeros(1).to(device)
        elif self.cl_neg_mode == 2:
            cl_label_num = self.label_num * 2  # Double for positive and negative prototypes
            self.ins_neg_cnt = torch.zeros(self.label_num).to(device)
        self.cl_label_num = cl_label_num

        # Register buffer for label prototypes, aligned with CoMAL's prototype-based sampling
        self.register_buffer("prototypes", torch.zeros(self.cl_label_num, self.proto_size))
        self.ins_pos_cnt = torch.zeros(self.label_num).to(device)  # Track count of positive instances

        # Decoder and final aggregation layers
        self.fc3 = nn.Linear(self.proto_size, 512)
        self.agg = nn.Linear(self.label_num * 512, self.hidden_size)
        self.clf = nn.Linear(self.hidden_size, self.label_num)  # Classification layer

    def get_protos(self):
        return self.prototypes  # Return the prototypes for external use

    def reparameterize(self, mu, logvar):
        # VAE reparameterization trick for latent space sampling
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def reset_proto(self):
        # Reset prototype and count buffers
        self.ins_pos_cnt *= 0
        self.ins_neg_cnt *= 0
        self.prototypes *= 0

    def forward(self, x, labels=None, weights=None, reset_proto=False):
        # Project input into sub-representations per label
        sub_rep_ori = self.fc0(x)
        sr_shape = sub_rep_ori.shape
        sub_rep_ori = sub_rep_ori.view(sr_shape[0], self.label_num, -1)  # Split per label

        # Further reduction to prototype size and decoding step
        sub_rep = self.fc1(sub_rep_ori)
        dec_sub_rep = self.fc3(sub_rep)

        dist_1 = None
        sub_rep_norm = F.normalize(sub_rep.data, dim=-1)  # Normalize for distance calculations

        if labels is not None and weights is not None:
            # Generate masks for positive and negative samples
            pos_mask = labels * weights
            neg_mask = (1 - labels) * weights
            pos_mask = pos_mask.unsqueeze(-1)
            neg_mask = neg_mask.unsqueeze(-1)

            # Update prototypes based on positive and negative samples
            feat = torch.sum(sub_rep_norm * pos_mask, dim=0)
            self.prototypes[:self.label_num] = self.prototypes[:self.label_num] * self.ins_pos_cnt.unsqueeze(-1) + feat

            # Handle different contrastive learning modes
            if self.cl_neg_mode == 2:
                feat_neg = torch.sum(sub_rep_norm * neg_mask, dim=0)
                self.prototypes[self.label_num:] = self.prototypes[self.label_num:] * self.ins_neg_cnt.unsqueeze(-1) + feat_neg
                self.ins_neg_cnt += torch.sum(neg_mask.squeeze(-1), dim=0)
            elif self.cl_neg_mode == 1:
                feat_neg = torch.sum(sub_rep_norm * neg_mask, dim=0)
                feat_neg = torch.sum(feat_neg, dim=0)
                self.prototypes[-1] = self.prototypes[-1] * self.ins_neg_cnt + feat_neg
                self.ins_neg_cnt += torch.sum(neg_mask)
            
            # Update positive instance counts and normalize prototypes
            self.ins_pos_cnt += torch.sum(pos_mask.squeeze(-1), dim=0)
            self.prototypes = F.normalize(self.prototypes, p=2, dim=-1)

        # Calculate distances between sub-representations and prototypes
        dist_1 = sub_rep_norm @ self.prototypes.T  

        # Decode and classify reconstructed input
        concat_sub_rep = dec_sub_rep.contiguous().view(dec_sub_rep.shape[0], -1)
        recon_x = self.agg(concat_sub_rep)
        recon_x_clf = self.clf(recon_x)

        if reset_proto:
            self.reset_proto()

        return recon_x, sub_rep, recon_x_clf, dist_1  # Return reconstruction, sub-representation, classification, and distances

# %%
def get_cl_labels(labels, label_num, weight, cl_neg_mode=1):
    cl_labels = torch.zeros_like(labels, dtype=torch.long)
    cl_labels.fill_(label_num)
    example_idx, label_idx = torch.where(labels>=0.5)
    cl_labels[example_idx, label_idx] = label_idx #.float()
    cl_labels = cl_labels * weight + label_num * (1 - weight)
    if cl_neg_mode == 2:
        example_idx, label_idx = torch.where(labels < 0.5)
        cl_neg_labels = label_idx + label_num
        cl_labels[example_idx, label_idx] = cl_neg_labels.float()
        cl_labels = cl_labels * weight + 2 * label_num * (1 - weight)
    cl_labels = cl_labels.to(torch.int)
    return cl_labels

def get_cl_mask(cl_labels, label_num, batch_size, cl_neg_mode=1):
    mask = torch.eq(cl_labels[:batch_size], cl_labels.T).float()
    if cl_neg_mode == 0:
        neg_idx, _ = torch.where(cl_labels[:batch_size] >= label_num)
        neg_mask = torch.ones_like(mask)
        neg_mask[neg_idx] = 0
        neg_mask[:, neg_idx] = 0
        mask *= neg_mask
    elif cl_neg_mode == 1:
        neg_idx, _ = torch.where(cl_labels[:batch_size] > label_num)
        neg_mask = torch.ones_like(mask)
        neg_mask[neg_idx] = 0
        neg_mask[:, neg_idx] = 0
        mask *= neg_mask
    elif cl_neg_mode == 2:
        neg_idx, _ = torch.where(cl_labels[:batch_size] >= label_num * 2)
        neg_mask = torch.ones_like(mask)
        neg_mask[neg_idx] = 0
        neg_mask[:, neg_idx] = 0
        mask *= neg_mask
    else:
        neg_mask = torch.ones_like(mask)
    return mask, neg_mask

# %% [markdown]
# # DEFINE LOSSES

# %%
class SupConLoss(nn.Module):
    """Following Supervised Contrastive Learning:
        https://arxiv.org/pdf/2004.11362.pdf."""

    def __init__(self, temperature=0.07, base_temperature=0.07):
        super().__init__()
        self.temperature = temperature
        self.base_temperature = base_temperature

    def forward(self, features, mask, neg_mask=None, batch_size=-1, device=None, other_features=None):
        if mask is not None:
            # SupCon loss (Partial Label Mode)
            mask = mask.float().detach()
            # compute logits
            if other_features is None:
                anchor_dot_contrast = torch.div(
                    torch.matmul(features[:batch_size], features.T),
                    self.temperature)
            else:
                anchor_dot_contrast = torch.div(
                    torch.matmul(features[:batch_size], other_features.T),
                    self.temperature)

            # for numerical stability
            logits_max, _ = torch.max(anchor_dot_contrast, dim=1, keepdim=True)
            logits = anchor_dot_contrast - logits_max.detach()

            # mask-out self-contrast cases
            if neg_mask is None:
                logits_mask = torch.ones_like(mask)
            else:
                logits_mask = torch.scatter(
                    neg_mask,
                    1,
                    torch.arange(batch_size).view(-1, 1).to(device),
                    0
                )
            mask = mask * logits_mask

            # compute log_prob
            exp_logits = torch.exp(logits) * logits_mask
            log_prob = logits - torch.log(exp_logits.sum(1, keepdim=True) + 1e-12)
            # compute mean of log-likelihood over positive
            mean_log_prob_pos = (mask * log_prob).sum(1) / (mask.sum(1) + 1e-12)
            # loss
            loss = - (self.temperature / self.base_temperature) * mean_log_prob_pos
            loss = loss.mean()
        else:
            q = features[:batch_size]
            k = features[batch_size:batch_size * 2]
            queue = features[batch_size * 2:]
            l_pos = torch.einsum('nc,nc->n', [q, k]).unsqueeze(-1)
            # negative logits: NxK
            l_neg = torch.einsum('nc,kc->nk', [q, queue])
            # logits: Nx(1+K)
            logits = torch.cat([l_pos, l_neg], dim=1)

            # apply temperature
            logits /= self.temperature

            # labels: positive key indicators
            labels = torch.zeros(logits.shape[0], dtype=torch.long).cuda()
            loss = F.cross_entropy(logits, labels)

        return loss

# %% [markdown]
# # MODEL TRAINING AND TESTING

# %%
total_data = len(X_train) + len(X_val)
initial_train_size = int(0.05 * total_data)
checkpoints = [
    int(0.5 * total_data), 
    int(0.6 * total_data), 
    int(0.7 * total_data),
    len(X_train)
]
min_increment = 25

# %%
def compute_metrics(p, label, classes):
    preds = torch.tensor(p.predictions) # Sigmoid and threshold for multi-label
    labels = torch.tensor(p.label_ids)

    hamming_accuracy = (preds == labels).float().mean().item()

    # Standard multi-label precision, recall, and F1 metrics
    precision, recall, f1_micro, _ = precision_recall_fscore_support(labels, preds, average='micro', zero_division=0)
    _, _, f1_macro, _ = precision_recall_fscore_support(labels, preds, average='macro', zero_division=0)

    report = classification_report(
        labels, 
        preds, 
        labels=label,
        target_names=classes,
        zero_division=0
    ) 

    return {
        'accuracy': hamming_accuracy,
        'precision': precision,
        'recall': recall,
        'f1_micro': f1_micro,
        'f1_macro': f1_macro,
        'report': report
    }

# %%
def compute_metrics_overall(p, classes):
    preds = torch.tensor(p.predictions)
    labels = torch.tensor(p.label_ids)

    # Ensure it's in the correct shape
    if preds.shape != labels.shape:
        raise ValueError("Shape mismatch: predictions and labels must have the same shape.")

    # Hamming accuracy: proportion of correctly predicted labels over total labels
    hamming_accuracy = (preds == labels).float().mean().item()

    # Compute per-label (column-wise) precision, recall, F1
    precision_list, recall_list, f1_micro_list, f1_macro_list = [], [], [], []
    
    for i in range(labels.shape[1]):  # Loop through each column (multi-output)
        prec, rec, f1_micro, _ = precision_recall_fscore_support(
            labels[:, i], preds[:, i], average='micro', zero_division=0
        )
        _, _, f1_macro, _ = precision_recall_fscore_support(
            labels[:, i], preds[:, i], average='macro', zero_division=0
        )

        precision_list.append(prec)
        recall_list.append(rec)
        f1_micro_list.append(f1_micro)
        f1_macro_list.append(f1_macro)

    # Compute average metrics across all outputs
    precision = sum(precision_list) / len(precision_list)
    recall = sum(recall_list) / len(recall_list)
    f1_micro = sum(f1_micro_list) / len(f1_micro_list)
    f1_macro = sum(f1_macro_list) / len(f1_macro_list)

    # Generate classification report per output
    reports = [classification_report(labels[:, i], preds[:, i], target_names=classes, zero_division=0) for i in range(labels.shape[1])]

    return {
        'accuracy': hamming_accuracy,
        'precision': precision,
        'recall': recall,
        'f1_micro': f1_micro,
        'f1_macro': f1_macro,
        'reports': reports  # Returns list of reports, one for each output label
    }

# %%
def concat_test_result(outputs):
    outputs[0] = np.concatenate(outputs[0], axis=0)
    outputs[1] = np.concatenate(outputs[1], axis=0)
    outputs[2] = np.concatenate(outputs[2], axis=0)
    outputs[3] = np.concatenate(outputs[3], axis=0)
    outputs[4] = np.concatenate(outputs[4], axis=0)
    return outputs

def neaten_test_result(outputs, logits, labels, test_type):
    labels = labels.data.cpu().numpy()
    prob, pred = torch.topk(logits, 6 if test_type == 'aspect' else 2)
    prob = torch.sigmoid(prob).data.cpu().numpy()
    pred = pred.data.cpu().numpy()
    logits = torch.sigmoid(logits).data.cpu().numpy()
    pred_labels = np.zeros(logits.shape)
    pred_labels[logits >= 0.5] = 1
    outputs[0].append(labels)
    outputs[1].append(pred)
    outputs[2].append(prob)
    outputs[3].append(logits)
    outputs[4].append(pred_labels)
    
    return outputs

# %%
def train_total_sep2(aspect_datasets, dataloaders, trials, aspect_metrics, sentiment_metrics, metrics, current_train_size, label_num=-1, seed=42, total_patience=3):
    set_seed(seed)
    accelerator = Accelerator(mixed_precision='fp16')
    device = accelerator.device
    accelerator.print(accelerator.distributed_type)
    
    tasks = ['aspect', 'sentiment']
    sentiment_val_loader = None

    nearest_cp = current_train_size
    if nearest_cp not in checkpoints:
        for cp in checkpoints:
            if cp > current_train_size:
                nearest_cp = cp
                break
    percentage = math.ceil(nearest_cp / total_data * 100)

    for task in tasks:
        accelerator.print("--------------------------------------------------")
        if task == 'sentiment':
            accelerator.print("SENTIMENT ANALYSIS")
        else:
            accelerator.print("ASPECT DETECTION")
            
        accelerator.wait_for_everyone()
        best_score = {
            'accuracy': 0,
            'f1_micro': 0,
            'f1_macro': 0
        }  # Track best score for first phase
        best_score2 = {
            'accuracy': 0,
            'f1_micro': 0,
            'f1_macro': 0
        }  # Track best score for second phase
        second_phase = False  # Control flag for switching between training phases
        total_patience_cnt = 0
        models = {}

        # Initialize backbone model for task learning
        label_num = 6 if task == 'aspect' else 2
        models['backbone'] = IndoBERT_Backbone(label_num)
        optim_backbone = torch.optim.AdamW(models['backbone'].parameters(), lr=2e-5, weight_decay=0.01)

        # Initialize VAE module if specified (aligns with CoMAL's contrastive and auxiliary module)
        models['vae_module'] = MLP_VAE(768, device, label_num=label_num)
        optim_module = torch.optim.AdamW(models['vae_module'].parameters(), lr=2e-5, weight_decay=0.01)

        if task == 'sentiment':
            best_aspect_model = IndoBERT_Backbone(6)
            best_aspect_model.load_state_dict(torch.load(f"{filename}-aspect-p1-backbone-{trials+1}-{percentage}.pth"))
            train_loader, val_loader, _, _ = build_sentiment_dataset(
                device, aspect_datasets['train'], aspect_datasets['val'], best_aspect_model, tokenizer, max_length=sequence_length
            )
            sentiment_val_loader = val_loader
            
        else:
            train_loader = dataloaders['labeled']
            val_loader = dataloaders['test']

        accelerator.wait_for_everyone()
        models['backbone'], models['vae_module'], train_loader, val_loader = accelerator.prepare(
            models['backbone'], models['vae_module'], train_loader, val_loader
        )

        # Loop over epochs
        for epoch in range(1, epochs+1):
            if second_phase:
                models['backbone'].eval()  # Backbone frozen in second phase
            else:
                models['backbone'].train()
            models['vae_module'].train()

            # Iterate over labeled data for training
            total_loss = 0
            for data in train_loader:
                # Zero the gradients for all optimizers
                optim_backbone.zero_grad()
                optim_module.zero_grad()

                # Prepare inputs and labels for training
                labels, idx, loss_weight = [x.to(device) for x in data[1:4]]
                input_ids, input_type_ids, input_mask = [x.to(device) for x in data[0]]
                inputs_list = [input_ids, input_type_ids, input_mask, None]

                loss = 0

                # Forward pass through backbone model
                clf_out, encoder_cls = models['backbone'](inputs_list)

                # VAE training logic (aligns with CoMAL's multi-label decoupling and contrastive learning)
                loss2 = 0
                module_cls = encoder_cls.detach()  # Detach to prevent gradient flow to backbone

                # Forward pass through VAE module
                recon_x, latent_rep, recon_x_clf, _ = models['vae_module'](module_cls, labels=labels, weights=loss_weight)

                # Compute contrastive loss if enabled (aligns with CoMAL's use of contrastive learning)
                cl_labels = get_cl_labels(labels, label_num, loss_weight).view(-1)
                cl_labels_total = cl_labels.unsqueeze(-1)
                proj_total = latent_rep.view(-1, latent_rep.shape[-1])
                proj_total = F.normalize(proj_total, dim=-1)  # Normalize latent representation
                batch_size = clf_out.shape[0] * label_num
                mask, neg_mask = get_cl_mask(cl_labels_total, label_num, batch_size)

                criterion_cl = SupConLoss()  # Supervised contrastive loss function
                cl_loss = criterion_cl(proj_total, mask, neg_mask, batch_size, device)
                loss2 += cl_loss  # Add contrastive loss

                # Compute reconstruction and classification loss
                criterion_mse = nn.MSELoss()
                recon_mse_loss = criterion_mse(recon_x, module_cls)
                criterion_bce = nn.BCEWithLogitsLoss(weight=loss_weight, reduction='mean')
                recon_bce_loss = criterion_bce(recon_x_clf, labels.float())
                
                loss2 += recon_mse_loss + recon_bce_loss
                
                # Compute classification loss for the backbone (first phase)
                if not second_phase:
                    criterion = nn.BCEWithLogitsLoss(weight=loss_weight, reduction='mean')
                    clf_loss = criterion(clf_out, labels.float())
                    loss += clf_loss  # Add classification loss to total loss

                # Add VAE loss to total loss
                loss += loss2
                # Backpropagation step
                accelerator.backward(loss)
                
                total_loss += loss

                # Update weights based on current phase
                if second_phase:
                    optim_module.step()
                else:
                    optim_module.step()
                    optim_backbone.step()

            # Scheduler step for learning rate adjustment
            if second_phase:
                accelerator.print('in second')
            
            result = {}
            outputs_clf = [[], [], [], [], []]
            outputs_dual = [[], [], [], [], []]
            match task:
                case 'aspect':
                    with torch.no_grad():
                        for data in val_loader:
                            input_ids, input_type_ids, input_mask = [x.to(device, non_blocking=True) for x in data[0]]
                            labels = data[1].to(device)
                            out = [input_ids, input_type_ids, input_mask, None]
                
                            clf_out, encoder_cls = models['backbone'](out)
                            outputs_clf = neaten_test_result(outputs_clf, clf_out, labels, task)

                            if 'vae_module' in models.keys():
                                _, _, recon_x_clf, _ = models['vae_module'](encoder_cls, reset_proto=True)
                                outputs_dual = neaten_test_result(outputs_dual, recon_x_clf, labels, task)

                    if second_phase:
                        outputs_dual = concat_test_result(outputs_dual)
                        preds = torch.tensor(outputs_dual[4], device=device)
                        labels = torch.tensor(outputs_dual[0], device=device)
                    else:
                        outputs_clf = concat_test_result(outputs_clf)
                        preds = torch.tensor(outputs_clf[4], device=device)
                        labels = torch.tensor(outputs_clf[0], device=device)

                    preds = accelerator.gather_for_metrics(preds)
                    labels = accelerator.gather_for_metrics(labels)
                        
                    result = compute_metrics(
                        type('EvalOutput', (object,), {'predictions': preds.cpu().numpy(), 'label_ids': labels.cpu().numpy()}),
                        None,
                        ['fuel', 'machine', 'others', 'part', 'price', 'service']
                    )
                case 'sentiment':
                    sentiment_val_outputs = []
                    with torch.no_grad():
                        for data in val_loader:
                            input_ids, input_type_ids, input_mask = [x.to(device, non_blocking=True) for x in data[0]]
                            labels = data[1].to(device)
                            out = [input_ids, input_type_ids, input_mask, None]
                        
                            clf_out, encoder_cls = models['backbone'](out)
                            clf_out = torch.sigmoid(clf_out)
                        
                            if 'vae_module' in models.keys():
                                _, _, recon_x_clf, _ = models['vae_module'](encoder_cls, reset_proto=True)
                                recon_x_clf = torch.sigmoid(recon_x_clf)

                            for i in range(len(clf_out)):
                                val_output = {
                                    'label': data[1][i],
                                    'aspect': data[7][i],
                                    'ori_indices': data[2][i],
                                    'pred': np.argmax(clf_out[i].cpu().numpy() if not second_phase else recon_x_clf[i].cpu().numpy()),
                                }
                                sentiment_val_outputs.append(val_output)

                    sentiment_val_outputs = accelerator.gather_for_metrics(sentiment_val_outputs)
                    unique_val_outputs = {(x['ori_indices'].item(), x['aspect']): x for x in sentiment_val_outputs}
                    sentiment_val_outputs = list(unique_val_outputs.values())

                    result = compute_metrics(
                        type('EvalOutput', (object,), {'predictions': [item['pred'] for item in sentiment_val_outputs], 'label_ids': [np.argmax(item['label'].cpu().numpy()) for item in sentiment_val_outputs]}),
                        [0, 1],
                        ['negative', 'positive']
                    )

            if second_phase:
                if result["f1_micro"] >= best_score2['f1_micro']:
                    total_patience_cnt = 0
                    best_score2 = result
                    
                    accelerator.wait_for_everyone()
                    unwrapped_vae = accelerator.unwrap_model(models['vae_module'])
                    if accelerator.is_local_main_process:
                        accelerator.save(unwrapped_vae.state_dict(), f"{filename}-{task}-p2-vae-{trials+1}-{percentage}.pth")
                else:
                    total_patience_cnt += 1
                    if total_patience_cnt >= total_patience:
                        break
            else:
                if result["f1_micro"] >= best_score['f1_micro']:
                    best_score = result
                    total_patience_cnt = 0

                    accelerator.wait_for_everyone()
                    unwrapped_backbone = accelerator.unwrap_model(models['backbone'])
                    unwrapped_vae = accelerator.unwrap_model(models['vae_module'])

                    if accelerator.is_local_main_process:
                        accelerator.save(unwrapped_backbone.state_dict(), f"{filename}-{task}-p1-backbone-{trials+1}-{percentage}.pth")
                        accelerator.save(unwrapped_vae.state_dict(), f"{filename}-{task}-p1-vae-{trials+1}-{percentage}.pth")
                else:
                    total_patience_cnt += 1
                    if total_patience_cnt >= total_patience:
                        total_patience_cnt = 0
                        second_phase = True
                
            accelerator.print(f"EPOCH {epoch} | LOSS: {total_loss / len(dataloaders['labeled'])} | ACCURACY: {round(result['accuracy'], 4)} | F1 MACRO: {round(result['f1_macro'], 4)} | F1 MICRO: {round(result['f1_micro'], 4)}")

        if accelerator.is_local_main_process:
            if task == 'aspect':
                aspect_metrics[0].append(best_score['accuracy'])
                aspect_metrics[1].append(best_score['f1_micro'])
                aspect_metrics[2].append(best_score['f1_macro'])
            elif task == 'sentiment':
                sentiment_metrics[0].append(best_score['accuracy'])
                sentiment_metrics[1].append(best_score['f1_micro'])
                sentiment_metrics[2].append(best_score['f1_macro'])
        
        accelerator.print(f"{task}: ACCURACY {round(best_score['accuracy'], 4)} | F1 MACRO {round(best_score['f1_macro'], 4)} | F1 MICRO {round(best_score['f1_micro'], 4)}")
        accelerator.print(best_score['report'])

    # Compute overall metrics
    aspect_labels = []
    aspect_indices = []
    aspect_preds = []

    aspect_outputs = {}
    sentiment_outputs = []

    accelerator.wait_for_everyone()

    best_aspect_model = IndoBERT_Backbone(6)
    best_sentiment_model = IndoBERT_Backbone(2)

    best_aspect_model.load_state_dict(torch.load(f"{filename}-aspect-p1-backbone-{trials+1}-{percentage}.pth"))
    best_sentiment_model.load_state_dict(torch.load(f"{filename}-sentiment-p1-backbone-{trials+1}-{percentage}.pth"))

    best_aspect_model, best_sentiment_model, val_loader = accelerator.prepare(best_aspect_model, best_sentiment_model, dataloaders['test'])

    with torch.no_grad():
        for batch in val_loader:
            input_ids, input_type_ids, input_mask = [x.to(device) for x in batch[0]]
            inputs_list = [input_ids, input_type_ids, input_mask, None]
            clf_out, encoder_cls = best_aspect_model(inputs_list)
            preds = torch.sigmoid(clf_out).round()

            aspect_indices.append(accelerator.gather(batch[2]))
            aspect_labels.append(accelerator.gather(batch[6]))
            aspect_preds.append(accelerator.gather(preds))

        aspect_indices = torch.cat(aspect_indices).cpu().numpy()
        aspect_labels = torch.cat(aspect_labels).cpu().numpy()
        aspect_preds = torch.cat(aspect_preds).cpu().numpy()

        accelerator.wait_for_everyone()
        aspect_outputs = [
            {'ori_indices': aspect_indices[i], 
             'ori_labels': aspect_labels[i], 
             'pred': aspect_preds[i]}
            for i in range(len(aspect_preds))
        ]
        aspect_outputs = {x['ori_indices'].item(): x for x in aspect_outputs}
    
        for batch in sentiment_val_loader:
            input_ids, input_type_ids, input_mask = [x.to(device) for x in batch[0]]
            inputs_list = [input_ids, input_type_ids, input_mask, None]
            clf_out, encoder_cls = best_sentiment_model(inputs_list)
            preds = torch.sigmoid(clf_out).round()
    
            for i in range(len(preds)):
                output = {
                    'aspect': batch[7][i],
                    'ori_indices': batch[8][i],
                    'pred': np.argmax(preds[i].cpu().numpy()),
                }
                sentiment_outputs.append(output)

        sentiment_outputs = accelerator.gather_for_metrics(sentiment_outputs)
        sentiment_outputs = {(x['ori_indices'].item(), x['aspect']): x for x in sentiment_outputs}

    # Replcae non neutral aspect to its predicted sentiment
    accelerator.wait_for_everyone()
    if accelerator.is_main_process:
        i = -1
        for (ori_index, aspect), value in sentiment_outputs.items():
            aspect = aspect_mapping[aspect]
            aspect_outputs[ori_index]['pred'][aspect] = 2 if value['pred'] == 1.0 else value['pred']

        result = compute_metrics_overall(
            type('EvalOutput', (object,), {'predictions': [output['pred'] for output in aspect_outputs.values()], 'label_ids': [output['ori_labels'] for output in aspect_outputs.values()]}),
            ['negative', 'neutral', 'positive'],
        )

        accelerator.print("--------------------------------------------------")
        accelerator.print(f"Iteration {current_train_size}: Accuracy: {round(result['accuracy'], 4)}, F1 Micro: {round(result['f1_micro'], 4)}, F1 Macro: {round(result['f1_macro'], 4)}")
        accelerator.print("--------------------------------------------------")
        
        for i in range(len(train_labels)):
            accelerator.print(f"Aspect {aspect_list[i]} report:")
            accelerator.print(result['reports'][i])
            
        metrics[0].append(current_train_size)
        metrics[1].append(result['accuracy'])
        metrics[2].append(result['f1_micro'])
        metrics[3].append(result['f1_macro'])

# %% [markdown]
# # QUERY STRATEGY

# %%
def query_samples(filename, dataset, labeled_set, unlabeled_indices, num_labels, trials, sampling_dur, new_sample_data, new_sample_labels,
                  label_cardinality=None, labeled_subset=None, save_path=None, cl_neg_mode=1, n_samples=min_increment):
    accelerator = Accelerator(mixed_precision='fp16')
    device = accelerator.device

    models = {}
    tasks = ['aspect', 'sentiment']
    
    current_train_size = len(dataset.get_labeled_set())

    nearest_cp = current_train_size
    if nearest_cp not in checkpoints:
        for cp in checkpoints:
            if cp > current_train_size:
                nearest_cp = cp
                break
    percentage = math.ceil(nearest_cp / total_data * 100)

    for task in tasks:
        backbone = IndoBERT_Backbone(6 if task == 'aspect' else 2)
        vae = MLP_VAE(768, device, 6 if task == 'aspect' else 2)
        backbone.load_state_dict(torch.load(f"{filename}-{task}-p1-backbone-{trials+1}-{percentage}.pth"))
        models[f'{task}_backbone'] = backbone
        
        if os.path.exists(f'/kaggle/working/{filename}-{task}-p2-vae-{trials+1}.pt'):
            vae.load_state_dict(torch.load(f"{filename}-{task}-p2-vae-{trials+1}-{percentage}.pth"))
        else:
            vae.load_state_dict(torch.load(f"{filename}-{task}-p1-vae-{trials+1}-{percentage}.pth"))
        models[f'{task}_vae_module'] = vae

    
    # Set all models to evaluation mode to freeze parameters during sampling
    for model_name in models.keys():
        models[model_name].to(device)
        models[model_name].eval()

    # Initialize lists to store outputs used for sampling calculations
    aspect_outputs = {}
    sentiment_outputs = {}
    
    labeled_distances = []
    labeled_ground_truths = []
    
    labeled_aspects = []
    labeled_labels = []
    labeled_indices = []
    labeled_texts = []

    unlabeled_aspects = []
    unlabeled_labels = []
    unlabeled_ori_indices = []
    unlabeled_texts = []

    # DataLoader for labeled data subset, sampled randomly
    labeled_dataloader = DataLoader(
        dataset,
        batch_size=batch_size,
        num_workers=4,
        shuffle=False,
        pin_memory=True,
        sampler=SubsetRandomSampler(list(set(labeled_set)))
    )

    start_time = time.time()

    # Process labeled data to extract features and distances for sampling criteria
    for batch in labeled_dataloader:
        text_inputs = batch[0]
        gt_label = batch[1]
        idx = batch[2]
        input_ids, token_type_ids, attention_mask = [x.to(device, non_blocking=True) for x in text_inputs]
        labeled_ground_truths.extend(gt_label)

        with torch.no_grad():
            # Use backbone model to get encoded representations
            predictions, encoded_cls = models['aspect_backbone']([input_ids, token_type_ids, attention_mask, None])

            for i in range(len(predictions)):
                indices = idx[i].item()
                for j in range(len(predictions[i])):
                    if int(predictions[i][j].round()) != 1:
                        labeled_aspects.append(aspect_list[j])
                        labeled_labels.append(gt_label[i][j])
                        labeled_texts.append(batch[5][i])
                        labeled_indices.append(indices)
                    
            _, sub_representation, _, vae_distance = models['aspect_vae_module'](encoded_cls)
            vae_distance = vae_distance.cpu().data
            labeled_distances.extend(vae_distance)

    # Stack outputs for further processing
    labeled_ground_truths = torch.stack(labeled_ground_truths)
    labeled_distances = torch.stack(labeled_distances)

    accelerator.wait_for_everyone()
    if accelerator.is_main_process:
        # Compute self-prototype distances based on CoMAL's contrastive learning mode
        if cl_neg_mode == 1:
            labeled_prototype_distances = labeled_distances[:, :, :-1]  # Exclude last distance for prototype calculation
            labeled_prototype_distances = labeled_prototype_distances * torch.eye(num_labels)  # Keep only diagonal elements
            labeled_prototype_distances = torch.sum(labeled_prototype_distances, dim=-1)  # Sum along prototype axis
            positive_distances = labeled_prototype_distances * labeled_ground_truths  # Mask with ground truth labels
    
        # Calculate max, min, and mean positive distances for uncertainty measurement
        max_positive_distances = torch.max(positive_distances, dim=0)[0]
        min_positive_distances = torch.min(positive_distances + (1 - labeled_ground_truths) * 2, dim=0)[0]
        mean_positive_distances = (max_positive_distances + min_positive_distances) / 2
    
        # DataLoader for unlabeled data to compute sampling scores
        unlabeled_dataloader = DataLoader(
            dataset,
            batch_size=batch_size,
            num_workers=4,
            shuffle=False,
            pin_memory=True,
            sampler=SubsetRandomSampler(list(set(unlabeled_indices)))
        )
    
        # Process unlabeled data to get sampling scores
        for batch in unlabeled_dataloader:
            text_inputs = batch[0]
            labels = batch[1]
            idx = batch[2]
            loss_weight = batch[3]
            input_ids, token_type_ids, attention_mask = [x.to(device) for x in text_inputs]
    
            with torch.no_grad():
                # Get predictions and encoded representations
                predictions, encoded_cls = models['aspect_backbone']([input_ids, token_type_ids, attention_mask, None])
                predictions = predictions.cpu().data
                
                for i in range(len(predictions)):
                    indices = idx[i].item()
                    
                    if indices not in aspect_outputs.keys():
                        aspect_outputs[indices] = {}
                        
                    aspect_outputs[indices]['backbone_predictions'] = predictions[i]
                    aspect_outputs[indices]['loss_weight'] = loss_weight[i]
                    
                    # Collect non neutral aspect for sentiment analysis
                    for j in range(len(predictions[i])):
                        if int(torch.sigmoid(predictions[i][j]).round()) != 1:
                            unlabeled_aspects.append(aspect_list[j])
                            unlabeled_labels.append(labels[i][j])
                            unlabeled_texts.append(batch[5][i])
                            unlabeled_ori_indices.append(indices)
    
                # Get latent representations, reconstructions, and distances
                _, _, _, vae_distance = models['aspect_vae_module'](encoded_cls)

                for i in range(len(vae_distance)):
                    aspect_outputs[idx[i].item()]['backbone_distances'] = vae_distance[i].cpu().data

        # Convert lists to tensors for further computation
        sample_indices = torch.stack([torch.tensor(key, dtype=torch.long) for key in aspect_outputs.keys()])
        sample_weights = torch.stack([aspect_outputs[key]['loss_weight'] for key in aspect_outputs.keys()])
        distance_matrix = torch.stack([aspect_outputs[key]['backbone_distances'] for key in aspect_outputs.keys()])
    
        # Convert predictions to probability and adjust masks for scoring
        backbone_predictions = torch.stack([aspect_outputs[key]['backbone_predictions'] for key, val in aspect_outputs.items()])
        probability_predictions = torch.zeros_like(backbone_predictions) + backbone_predictions
        probability_predictions = torch.sigmoid(probability_predictions)
        unlabeled_mask = torch.ones_like(sample_weights) - sample_weights
    
        # Calculate uncertainty metrics and part scores for sampling
        sample_weights = sample_weights.view(-1)
    
        # Mask predictions based on positive distances
        positive_distance_mask = ((probability_predictions >= 0.5) * unlabeled_mask).float()
        positive_prototype_distances = distance_matrix[:, :, :-1]
        positive_prototype_distances = positive_prototype_distances * torch.eye(num_labels)
        positive_prototype_distances = torch.sum(positive_prototype_distances, dim=-1)
    
        # Compute scores based on uncertainty and diversity metrics
        prediction_mask = (positive_prototype_distances > mean_positive_distances).float()
        distance_count = torch.sum(prediction_mask, dim=-1)
        cardinality_difference = torch.abs(distance_count - label_cardinality)
        score_weight = positive_distance_mask * (positive_prototype_distances + 1) / 2
        score_weight = 1 / torch.sum(score_weight + 1e-10, dim=-1)
        adjusted_score = torch.pow(score_weight, 0.5) * torch.pow(cardinality_difference, 1 - 0.5)
        final_scores = adjusted_score.unsqueeze(-1)
        average_scores = torch.mean(final_scores, dim=-1).cpu().numpy()

        z = 0
        for key in aspect_outputs.keys():
            aspect_outputs[key]['score'] = average_scores[z]
            z += 1

    # -------- SENTIMENT ANALYSIS ---------
    accelerator.wait_for_everyone()
    labeled_sentiment_dataset = SentimentAnalysisDataset(labeled_texts, labeled_labels, labeled_aspects, labeled_indices, tokenizer, label_mapping, max_length=sequence_length)
    unlabeled_sentiment_dataset = SentimentAnalysisDataset(unlabeled_texts, unlabeled_labels, unlabeled_aspects, unlabeled_ori_indices, tokenizer, label_mapping, max_length=sequence_length)
    
    labeled_loader = torch.utils.data.DataLoader(
        labeled_sentiment_dataset, batch_size=batch_size, shuffle=False, pin_memory=True, num_workers=4,
    )
    unlabeled_loader = torch.utils.data.DataLoader(
        unlabeled_sentiment_dataset, batch_size=batch_size, shuffle=False, pin_memory=True, num_workers=4,
    )

    labeled_ground_truths = []
    labeled_distances = []
    for batch in labeled_loader:
        text_inputs = batch[0]
        gt_label = batch[1]
        input_ids, token_type_ids, attention_mask = [x.to(device, non_blocking=True) for x in text_inputs]
        labeled_ground_truths.extend(gt_label)

        with torch.no_grad():
            # Use backbone model to get encoded representations
            predictions, encoded_cls = models['sentiment_backbone']([input_ids, token_type_ids, attention_mask, None])
                    
            _, sub_representation, _, vae_distance = models['sentiment_vae_module'](encoded_cls)
            labeled_distances.extend(vae_distance.cpu().data)

    # Stack outputs for further processing
    labeled_ground_truths = torch.stack(labeled_ground_truths)
    labeled_distances = torch.stack(labeled_distances)

    accelerator.wait_for_everyone()
    if accelerator.is_main_process:
        # Compute self-prototype distances based on CoMAL's contrastive learning mode
        labeled_prototype_distances = labeled_distances[:, :, :-1]  # Exclude last distance for prototype calculation
        labeled_prototype_distances = labeled_prototype_distances * torch.eye(2)  # Keep only diagonal elements
        labeled_prototype_distances = torch.sum(labeled_prototype_distances, dim=-1)  # Sum along prototype axis
        positive_distances = labeled_prototype_distances * labeled_ground_truths  # Mask with ground truth labels
    
        # Calculate max, min, and mean positive distances for uncertainty measurement
        max_positive_distances = torch.max(positive_distances, dim=0)[0]
        min_positive_distances = torch.min(positive_distances + (1 - labeled_ground_truths) * 2, dim=0)[0]
        mean_positive_distances = (max_positive_distances + min_positive_distances) / 2
    
        # Process unlabeled data to get sampling scores
        for batch in unlabeled_loader:
            text_inputs = batch[0]
            idx = batch[8]
            loss_weight = batch[3]
            input_ids, token_type_ids, attention_mask = [x.to(device) for x in text_inputs]
    
            with torch.no_grad():
                # Get predictions and encoded representations
                predictions, encoded_cls = models['sentiment_backbone']([input_ids, token_type_ids, attention_mask, None])
                predictions = predictions.cpu().data
                    
                for i in range(len(predictions)):
                    indices = idx[i].item()
                    if indices not in sentiment_outputs.keys():
                        sentiment_outputs[indices] = {}
                        sentiment_outputs[idx[i].item()]['backbone_predictions'] = [predictions[i]]
                        sentiment_outputs[idx[i].item()]['loss_weight'] = [loss_weight[i]]
                    else:
                        sentiment_outputs[idx[i].item()]['backbone_predictions'].append(predictions[i])
                        sentiment_outputs[idx[i].item()]['loss_weight'].append(loss_weight[i])
    
                # Get latent representations, reconstructions, and distances
                _, _, _, vae_distance = models['sentiment_vae_module'](encoded_cls)

                for i in range(len(vae_distance)):
                    if 'backbone_distances' not in sentiment_outputs[indices].keys():
                        sentiment_outputs[idx[i].item()]['backbone_distances'] = [vae_distance[i].cpu().data]
                    else:
                        sentiment_outputs[idx[i].item()]['backbone_distances'].append(vae_distance[i].cpu().data)

        # print(len(unlabeled_sentiment_dataset), length, len(sentiment_outputs))
        sample_indices = torch.stack([torch.tensor(key, dtype=torch.long) for key in sentiment_outputs.keys()])

        sample_weights = torch.stack([
            torch.mean(torch.stack(sentiment_outputs[key]['loss_weight']), dim=0).round() 
            for key in sentiment_outputs
        ])
        distance_matrix = torch.stack([
            torch.mean(torch.stack(sentiment_outputs[key]['backbone_distances']), dim=0)
            for key in sentiment_outputs
        ])
        backbone_predictions = torch.stack([
            torch.mean(torch.stack(sentiment_outputs[key]['backbone_predictions']), dim=0) 
            for key in sentiment_outputs
        ])
        
        # Convert predictions to probability and adjust masks for scoring
        probability_predictions = torch.zeros_like(backbone_predictions) + backbone_predictions
        probability_predictions = torch.sigmoid(probability_predictions)
        unlabeled_mask = torch.ones_like(sample_weights) - sample_weights
    
        # Calculate uncertainty metrics and part scores for sampling
        sample_weights = sample_weights.view(-1)
    
        # Mask predictions based on positive distances
        positive_distance_mask = ((probability_predictions >= 0.5) * unlabeled_mask).float()
        positive_prototype_distances = distance_matrix[:, :, :-1]
        positive_prototype_distances = positive_prototype_distances * torch.eye(2)
        positive_prototype_distances = torch.sum(positive_prototype_distances, dim=-1)
    
        # Compute scores based on uncertainty and diversity metrics
        prediction_mask = (positive_prototype_distances > mean_positive_distances).float()
        distance_count = torch.sum(prediction_mask, dim=-1)
        cardinality_difference = torch.abs(distance_count - label_cardinality)
        score_weight = positive_distance_mask * (positive_prototype_distances + 1) / 2
        score_weight = 1 / torch.sum(score_weight + 1e-10, dim=-1)
        adjusted_score = torch.pow(score_weight, 0.5) * torch.pow(cardinality_difference, 1 - 0.5)
        final_scores = adjusted_score.unsqueeze(-1)
        average_sentiment_scores = torch.mean(final_scores, dim=-1).cpu().numpy()

        print(len(average_sentiment_scores), len(sentiment_outputs))

        z = 0
        for key in sentiment_outputs.keys():
            aspect_outputs[key]['score'] = (average_sentiment_scores[z] + aspect_outputs[key]['score']) / 2
            z += 1

        ranked_indices = np.argsort(average_scores)
        ranked_indices = ranked_indices[::-1]
        sample_indices = torch.stack([torch.tensor(key, dtype=torch.long) for key in aspect_outputs.keys()])
        
        # Select top samples for annotation
        threshold = np.percentile(average_scores, 90)
        items_greater_than_threshold = average_scores[average_scores >= threshold]
        num_of_candidates = min(math.ceil(0.1 * len(average_scores)), len(items_greater_than_threshold))
    
        nearest_cp = 0
        for cp in checkpoints:
            if cp > current_train_size:
                nearest_cp = cp
                break
    
        if num_of_candidates <= n_samples and n_samples < nearest_cp - current_train_size:
            selected_indices = ranked_indices[:n_samples]
        elif num_of_candidates > n_samples and num_of_candidates < nearest_cp - current_train_size:
            selected_indices = ranked_indices[:max(n_samples, num_of_candidates)]
        else:
            selected_indices = ranked_indices[:nearest_cp - current_train_size]
            
            temp = dataset.get_labeled_set()
            temp.extend([sample_indices[int(x)] for x in selected_indices])
            
            # Save acquired data up to checkpoint
            acquired_data = pd.DataFrame({
                'processed_text': [X_train[i] for i in temp],
                'fuel': [y_train[i][0] for i in temp],
                'machine': [y_train[i][1] for i in temp],
                'others': [y_train[i][2] for i in temp],
                'part': [y_train[i][3] for i in temp],
                'price': [y_train[i][4] for i in temp],
                'service': [y_train[i][5] for i in temp],
            })
    
            acquired_data.to_csv(f'{filename}-{trials+1}-data-{nearest_cp}.csv', index=False)

        for x in selected_indices:
            new_sample_data.append(sample_indices[int(x)])
        new_sample_labels = None
        
        end_time = time.time()
        duration = end_time - start_time
    
        print("Nearest checkpoint:", nearest_cp)
        print("Threshold:", threshold)
        print("Samples above threshold:", num_of_candidates)
        print("Acquired samples:", len(selected_indices))
        print(f"Sampling duration: {duration} seconds")  # Print or return the runtime if needed
    
        sampling_dur.append(duration)

def pred_part_stat(pred, threshold=0.0):
    part_1 = torch.where(pred >= threshold)[0]
    part_0 = torch.where(pred < threshold)[0]
    return part_0, part_1

# %% [markdown]
# # PLOT RESULT

# %%
import matplotlib.pyplot as plt

def plot_result(data_used, accuracies, f1_micros, f1_macros):
    fig, axs = plt.subplots(1, 3, figsize=(21, 5))
    data_used = [round(data / total_data * 100, 1) for data in data_used]

    # Plot for Accuracy
    axs[0].plot(data_used, accuracies, label="Accuracy", color="blue")
    axs[0].set_xlabel("Percentage of data used")
    axs[0].set_title("Accuracy")
    axs[0].set_xticks(data_used)

    # Plot for F1 Micro
    axs[1].plot(data_used, f1_micros, label="F1 Micro", color="orange")
    axs[1].set_xlabel("Percentage of data used")
    axs[1].set_title("F1 Micro")
    axs[1].set_xticks(data_used)

    # Plot for F1 Macro
    axs[2].plot(data_used, f1_macros, label="F1 Macro", color="green")
    axs[2].set_xlabel("Percentage of data used")
    axs[2].set_title("F1 Macro")
    axs[2].set_xticks(data_used)

    # Adjust layout and show the plots
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # MAIN LOOP

# %%
def active_learning(seed, i):
    aspect_accuracies = manager.list()
    aspect_f1_micros = manager.list()
    aspect_f1_macros = manager.list()
    sentiment_accuracies = manager.list()
    sentiment_f1_micros = manager.list()
    sentiment_f1_macros = manager.list()
    accuracies = manager.list()
    f1_micros = manager.list()
    f1_macros = manager.list()
    data_used = manager.list()
    sampling_dur = manager.list()
    new_sample_data = manager.list()
    new_sample_labels = manager.list()
    
    current_train_size = initial_train_size
    start_time = time.time()
    set_seed(seeds[i])

    print("===============================================")
    print("TRIAL {}".format(i+1))
    print("Random seed:", seeds[i])
    
    # Load label information and dataset
    label_num = 6
    _, _, aspect_train_dataset, aspect_val_dataset = build_aspect_dataset(X_train, y_train, X_val, y_val, sequence_length)
    
    # Shuffle and initialize labeled and unlabeled sets
    indices = list(range(len(aspect_train_dataset)))
    random.shuffle(indices)
    labeled_set = indices[:initial_train_size]  # Random initial labeled set
    unlabeled_set = [x for x in indices if x not in labeled_set]  # Define the unlabeled set
    
    # Update dataset with initial labeled set
    aspect_train_dataset.update_data(labeled_set, init_time=True)
    
    # Prepare data loaders for labeled and test sets
    labeled_loader = DataLoader(
        aspect_train_dataset,
        batch_size=batch_size,
        num_workers=4,
        pin_memory=True,
        sampler=SubsetRandomSampler(list(set(labeled_set)))
    )
    test_loader = DataLoader(
        aspect_val_dataset,
        batch_size=batch_size,
        num_workers=4,
        pin_memory=True
    )

    models = {}

    while current_train_size < checkpoints[len(checkpoints) - 1]:
        dataloaders = {
            'labeled': labeled_loader,
            'test': test_loader
        }
        aspect_datasets = {
            'train': aspect_train_dataset,
            'val': aspect_val_dataset
        }
    
        # Train model
        train_args = (
            aspect_datasets,
            dataloaders, 
            i, 
            (aspect_accuracies, aspect_f1_micros, aspect_f1_macros), 
            (sentiment_accuracies, sentiment_f1_micros, sentiment_f1_macros),
            (data_used, accuracies, f1_micros, f1_macros), 
            current_train_size, 
            label_num,
            seed
        )
        notebook_launcher(train_total_sep2, train_args, num_processes=2)
        
        query_set = list(set(unlabeled_set))
        random.shuffle(query_set)
    
        # Query samples for next cycle, using appropriate selection strategy
        new_sample_data = manager.list()
        new_sample_labels = manager.list()
        sampling_args = (
            filename,
            aspect_train_dataset, 
            labeled_set,
            query_set, 
            label_num,
            i,
            sampling_dur,
            new_sample_data,
            new_sample_labels,
            aspect_train_dataset.get_label_Cardinality()
        )
        notebook_launcher(query_samples, sampling_args, num_processes=2)
        new_sample_data = list(new_sample_data)
        new_sample_labels = list(new_sample_labels)

        # print(len(new_sample_data))
        aspect_train_dataset.update_data(new_sample_data, None)
        labeled_set = aspect_train_dataset.get_labeled_set()
        unlabeled_set = [x for x in indices if x not in labeled_set]
    
        # Refresh data loader with new labeled set
        labeled_loader = DataLoader(
            aspect_train_dataset,
            batch_size=batch_size,
            num_workers=4,
            pin_memory=True,
            sampler=SubsetRandomSampler(list(set(labeled_set)))
        )
        
        # Update current train size
        current_train_size = len(labeled_set)
        print("New train size:", current_train_size)
    
    # DataLoader dictionary to be used for training and testing
    dataloaders = {
        'labeled': labeled_loader,
        'test': test_loader
    }
    
    # Train last iteration
    train_args = (
        aspect_datasets,
        dataloaders, 
        i, 
        (aspect_accuracies, aspect_f1_micros, aspect_f1_macros), 
        (sentiment_accuracies, sentiment_f1_micros, sentiment_f1_macros),
        (data_used, accuracies, f1_micros, f1_macros), 
        current_train_size, 
        label_num,
        seed
    )
    notebook_launcher(train_total_sep2, train_args, num_processes=2)
    data_used, accuracies, f1_micros, f1_macros, sampling_dur = list(data_used), list(accuracies), list(f1_micros), list(f1_macros), list(sampling_dur)
    aspect_accuracies, aspect_f1_micros, aspect_f1_macros = list(aspect_accuracies), list(aspect_f1_micros), list(aspect_f1_macros)
    sentiment_accuracies, sentiment_f1_micros, sentiment_f1_macros = list(sentiment_accuracies), list(sentiment_f1_micros), list(sentiment_f1_macros)
        
    # Log results
    end_time = time.time()
    duration = end_time - start_time

    print(f"Total sampling time: {np.array(sampling_dur).sum().round(2)} seconds")
    print(f"Total runtime: {duration} seconds")

    plot_result(data_used, accuracies, f1_micros, f1_macros)
    
    results = pd.DataFrame({
        'Data Used': data_used,
        'Aspect Accuracy': aspect_accuracies,
        'Aspect F1 Micro': aspect_f1_micros,
        'Aspect F1 Macro': aspect_f1_macros,
        'Sentiment Accuracy': sentiment_accuracies,
        'Sentiment F1 Micro': sentiment_f1_micros,
        'Sentiment F1 Macro': sentiment_f1_macros,
        'Accuracy': accuracies,
        'F1 Micro': f1_micros,
        'F1 Macro': f1_macros,
    })
    sampling_dur.insert(0, 0)
    
    results['Sampling Duration'] = sampling_dur
    
    results.to_csv(f'{filename}-{i+1}-results.csv', index=False)

# %%
seeds = [50, 81, 14, 3, 94]

# %% [markdown]
# ## RUN 1

# %%
active_learning(seeds[0], 0)
# Out:
# ===============================================
# TRIAL 1
# Random seed: 50
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.4285407066345215 | ACCURACY: 0.7329 | F1 MACRO: 0.8333 | F1 MICRO: 0.8411
# EPOCH 2 | LOSS: 3.2759060859680176 | ACCURACY: 0.7723 | F1 MACRO: 0.86 | F1 MICRO: 0.8681
# EPOCH 3 | LOSS: 3.174009323120117 | ACCURACY: 0.7924 | F1 MACRO: 0.8822 | F1 MICRO: 0.8837
# EPOCH 4 | LOSS: 3.0779800415039062 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# EPOCH 5 | LOSS: 3.0897669792175293 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# EPOCH 6 | LOSS: 2.987666606903076 | ACCURACY: 0.7902 | F1 MACRO: 0.8812 | F1 MICRO: 0.8826
# in second
# EPOCH 7 | LOSS: 2.796860456466675 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# in second
# EPOCH 8 | LOSS: 2.6878042221069336 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# in second
# EPOCH 9 | LOSS: 2.478614330291748 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# in second
# EPOCH 10 | LOSS: 2.386249303817749 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# aspect: ACCURACY 0.7924 | F1 MACRO 0.8822 | F1 MICRO 0.8837
#               precision    recall  f1-score   support
#
#         fuel       0.83      1.00      0.91       187
#      machine       0.78      1.00      0.88       175
#       others       0.71      1.00      0.83       158
#         part       0.72      0.99      0.84       158
#        price       0.86      1.00      0.92       192
#      service       0.85      1.00      0.92       191
#
#    micro avg       0.79      1.00      0.88      1061
#    macro avg       0.79      1.00      0.88      1061
# weighted avg       0.80      1.00      0.89      1061
#  samples avg       0.79      1.00      0.88      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 1.5277245044708252 | ACCURACY: 0.6667 | F1 MACRO: 0.4 | F1 MICRO: 0.6667
# EPOCH 2 | LOSS: 1.3809763193130493 | ACCURACY: 0.6667 | F1 MACRO: 0.4 | F1 MICRO: 0.6667
# EPOCH 3 | LOSS: 1.252987265586853 | ACCURACY: 0.6667 | F1 MACRO: 0.4 | F1 MICRO: 0.6667
# EPOCH 4 | LOSS: 1.17083740234375 | ACCURACY: 0.6667 | F1 MACRO: 0.4 | F1 MICRO: 0.6667
# EPOCH 5 | LOSS: 1.1955150365829468 | ACCURACY: 0.6667 | F1 MACRO: 0.4 | F1 MICRO: 0.6667
# EPOCH 6 | LOSS: 1.1505563259124756 | ACCURACY: 0.6667 | F1 MACRO: 0.4 | F1 MICRO: 0.6667
# EPOCH 7 | LOSS: 1.1758167743682861 | ACCURACY: 0.6667 | F1 MACRO: 0.4 | F1 MICRO: 0.6667
# EPOCH 8 | LOSS: 1.0909439325332642 | ACCURACY: 0.6667 | F1 MACRO: 0.4 | F1 MICRO: 0.6667
# EPOCH 9 | LOSS: 1.068453073501587 | ACCURACY: 0.6667 | F1 MACRO: 0.4 | F1 MICRO: 0.6667
# EPOCH 10 | LOSS: 1.0418633222579956 | ACCURACY: 0.6667 | F1 MACRO: 0.4 | F1 MICRO: 0.6667
# sentiment: ACCURACY 0.6667 | F1 MACRO 0.4 | F1 MICRO 0.6667
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00         1
#     positive       0.67      1.00      0.80         2
#
#     accuracy                           0.67         3
#    macro avg       0.33      0.50      0.40         3
# weighted avg       0.44      0.67      0.53         3
#
# --------------------------------------------------
# Iteration 54: Accuracy: 0.7894, F1 Micro: 0.7894, F1 Macro: 0.2962
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        11
#      neutral       0.84      1.00      0.91       181
#     positive       0.00      0.00      0.00        24
#
#     accuracy                           0.84       216
#    macro avg       0.28      0.33      0.30       216
# weighted avg       0.70      0.84      0.76       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        16
#      neutral       0.77      1.00      0.87       167
#     positive       0.00      0.00      0.00        33
#
#     accuracy                           0.77       216
#    macro avg       0.26      0.33      0.29       216
# weighted avg       0.60      0.77      0.67       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        12
#      neutral       0.70      1.00      0.83       152
#     positive       0.00      0.00      0.00        52
#
#     accuracy                           0.70       216
#    macro avg       0.23      0.33      0.28       216
# weighted avg       0.50      0.70      0.58       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        23
#      neutral       0.71      0.99      0.83       152
#     positive       0.33      0.02      0.05        41
#
#     accuracy                           0.70       216
#    macro avg       0.35      0.34      0.29       216
# weighted avg       0.56      0.70      0.59       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        13
#      neutral       0.86      1.00      0.93       186
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.86       216
#    macro avg       0.29      0.33      0.31       216
# weighted avg       0.74      0.86      0.80       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        14
#      neutral       0.86      1.00      0.92       185
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.86       216
#    macro avg       0.29      0.33      0.31       216
# weighted avg       0.73      0.86      0.79       216
#
# Launching training on 2 GPUs.
# 16 16
# Nearest checkpoint: 540
# Threshold: 88888.890625
# Samples above threshold: 81
# Acquired samples: 81
# Sampling duration: 5.7793402671813965 seconds
# New train size: 135
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.7288568019866943 | ACCURACY: 0.7924 | F1 MACRO: 0.8816 | F1 MICRO: 0.8833
# EPOCH 2 | LOSS: 3.4614202976226807 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# EPOCH 3 | LOSS: 3.149143934249878 | ACCURACY: 0.8058 | F1 MACRO: 0.8893 | F1 MICRO: 0.8905
# EPOCH 4 | LOSS: 3.0808331966400146 | ACCURACY: 0.8185 | F1 MACRO: 0.894 | F1 MICRO: 0.8955
# EPOCH 5 | LOSS: 2.9215757846832275 | ACCURACY: 0.8393 | F1 MACRO: 0.9061 | F1 MICRO: 0.907
# EPOCH 6 | LOSS: 2.7765262126922607 | ACCURACY: 0.8452 | F1 MACRO: 0.9072 | F1 MICRO: 0.9088
# EPOCH 7 | LOSS: 2.876804828643799 | ACCURACY: 0.8571 | F1 MACRO: 0.9143 | F1 MICRO: 0.9156
# EPOCH 8 | LOSS: 2.717442035675049 | ACCURACY: 0.8839 | F1 MACRO: 0.9291 | F1 MICRO: 0.9304
# EPOCH 9 | LOSS: 2.793822765350342 | ACCURACY: 0.8943 | F1 MACRO: 0.9344 | F1 MICRO: 0.9358
# EPOCH 10 | LOSS: 2.6402482986450195 | ACCURACY: 0.9062 | F1 MACRO: 0.9404 | F1 MICRO: 0.9423
# aspect: ACCURACY 0.9062 | F1 MACRO 0.9404 | F1 MICRO 0.9423
#               precision    recall  f1-score   support
#
#         fuel       0.95      1.00      0.98       187
#      machine       0.89      0.95      0.92       175
#       others       0.83      0.91      0.87       158
#         part       0.92      0.97      0.94       158
#        price       0.96      0.97      0.97       192
#      service       0.93      0.99      0.96       191
#
#    micro avg       0.92      0.97      0.94      1061
#    macro avg       0.92      0.97      0.94      1061
# weighted avg       0.92      0.97      0.94      1061
#  samples avg       0.92      0.97      0.94      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 16.843358993530273 | ACCURACY: 0.7692 | F1 MACRO: 0.6351 | F1 MICRO: 0.7692
# EPOCH 2 | LOSS: 15.956573486328125 | ACCURACY: 0.9005 | F1 MACRO: 0.8812 | F1 MICRO: 0.9005
# EPOCH 3 | LOSS: 12.810531616210938 | ACCURACY: 0.905 | F1 MACRO: 0.8937 | F1 MICRO: 0.905
# EPOCH 4 | LOSS: 11.847843170166016 | ACCURACY: 0.905 | F1 MACRO: 0.8898 | F1 MICRO: 0.905
# EPOCH 5 | LOSS: 10.820937156677246 | ACCURACY: 0.9095 | F1 MACRO: 0.897 | F1 MICRO: 0.9095
# EPOCH 6 | LOSS: 10.769107818603516 | ACCURACY: 0.9005 | F1 MACRO: 0.879 | F1 MICRO: 0.9005
# EPOCH 7 | LOSS: 10.374418258666992 | ACCURACY: 0.905 | F1 MACRO: 0.8898 | F1 MICRO: 0.905
# EPOCH 8 | LOSS: 10.41982650756836 | ACCURACY: 0.9095 | F1 MACRO: 0.8955 | F1 MICRO: 0.9095
# EPOCH 9 | LOSS: 9.612488746643066 | ACCURACY: 0.9231 | F1 MACRO: 0.9093 | F1 MICRO: 0.9231
# EPOCH 10 | LOSS: 9.757686614990234 | ACCURACY: 0.914 | F1 MACRO: 0.8978 | F1 MICRO: 0.914
# sentiment: ACCURACY 0.9231 | F1 MACRO 0.9093 | F1 MICRO 0.9231
#               precision    recall  f1-score   support
#
#     negative       0.89      0.86      0.87        69
#     positive       0.94      0.95      0.94       152
#
#     accuracy                           0.92       221
#    macro avg       0.91      0.90      0.91       221
# weighted avg       0.92      0.92      0.92       221
#
# --------------------------------------------------
# Iteration 135: Accuracy: 0.9074, F1 Micro: 0.9074, F1 Macro: 0.8143
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.90      0.82      0.86        11
#      neutral       0.96      0.99      0.98       181
#     positive       0.95      0.75      0.84        24
#
#     accuracy                           0.96       216
#    macro avg       0.94      0.85      0.89       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.56      0.72        16
#      neutral       0.91      0.95      0.93       167
#     positive       0.66      0.64      0.65        33
#
#     accuracy                           0.88       216
#    macro avg       0.85      0.72      0.77       216
# weighted avg       0.88      0.88      0.87       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.88      0.58      0.70        12
#      neutral       0.84      0.95      0.90       152
#     positive       0.81      0.56      0.66        52
#
#     accuracy                           0.84       216
#    macro avg       0.84      0.70      0.75       216
# weighted avg       0.84      0.84      0.83       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.81      0.74      0.77        23
#      neutral       0.91      0.96      0.94       152
#     positive       0.83      0.71      0.76        41
#
#     accuracy                           0.89       216
#    macro avg       0.85      0.80      0.82       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.69      0.72        13
#      neutral       0.97      0.97      0.97       186
#     positive       0.67      0.71      0.69        17
#
#     accuracy                           0.93       216
#    macro avg       0.79      0.79      0.79       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.95      1.00      0.97       185
#     positive       1.00      0.53      0.69        17
#
#     accuracy                           0.95       216
#    macro avg       0.98      0.80      0.86       216
# weighted avg       0.96      0.95      0.95       216
#
# Launching training on 2 GPUs.
# 603 603
# Nearest checkpoint: 540
# Threshold: 88680.3125
# Samples above threshold: 73
# Acquired samples: 73
# Sampling duration: 9.97421646118164 seconds
# New train size: 208
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.636146068572998 | ACCURACY: 0.7909 | F1 MACRO: 0.8816 | F1 MICRO: 0.8831
# EPOCH 2 | LOSS: 3.1863081455230713 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# EPOCH 3 | LOSS: 2.9296395778656006 | ACCURACY: 0.817 | F1 MACRO: 0.8946 | F1 MICRO: 0.8959
# EPOCH 4 | LOSS: 2.6803157329559326 | ACCURACY: 0.8438 | F1 MACRO: 0.9074 | F1 MICRO: 0.9089
# EPOCH 5 | LOSS: 2.7161850929260254 | ACCURACY: 0.8757 | F1 MACRO: 0.9244 | F1 MICRO: 0.926
# EPOCH 6 | LOSS: 2.6551716327667236 | ACCURACY: 0.9018 | F1 MACRO: 0.9384 | F1 MICRO: 0.9404
# EPOCH 7 | LOSS: 2.613969564437866 | ACCURACY: 0.9263 | F1 MACRO: 0.9524 | F1 MICRO: 0.9544
# EPOCH 8 | LOSS: 2.5285022258758545 | ACCURACY: 0.9278 | F1 MACRO: 0.9538 | F1 MICRO: 0.9553
# EPOCH 9 | LOSS: 2.3932998180389404 | ACCURACY: 0.9293 | F1 MACRO: 0.9545 | F1 MICRO: 0.9563
# EPOCH 10 | LOSS: 2.374269723892212 | ACCURACY: 0.9353 | F1 MACRO: 0.9581 | F1 MICRO: 0.9599
# aspect: ACCURACY 0.9353 | F1 MACRO 0.9581 | F1 MICRO 0.9599
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.93      0.98      0.96       175
#       others       0.87      0.94      0.90       158
#         part       0.93      0.97      0.95       158
#        price       0.96      0.98      0.97       192
#      service       0.95      1.00      0.98       191
#
#    micro avg       0.94      0.98      0.96      1061
#    macro avg       0.94      0.98      0.96      1061
# weighted avg       0.94      0.98      0.96      1061
#  samples avg       0.94      0.98      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 13.370230674743652 | ACCURACY: 0.8723 | F1 MACRO: 0.842 | F1 MICRO: 0.8723
# EPOCH 2 | LOSS: 11.921360969543457 | ACCURACY: 0.8979 | F1 MACRO: 0.8799 | F1 MICRO: 0.8979
# EPOCH 3 | LOSS: 9.660285949707031 | ACCURACY: 0.9106 | F1 MACRO: 0.8961 | F1 MICRO: 0.9106
# EPOCH 4 | LOSS: 8.698318481445312 | ACCURACY: 0.9362 | F1 MACRO: 0.9296 | F1 MICRO: 0.9362
# EPOCH 5 | LOSS: 8.966975212097168 | ACCURACY: 0.8979 | F1 MACRO: 0.8789 | F1 MICRO: 0.8979
# EPOCH 6 | LOSS: 8.361875534057617 | ACCURACY: 0.9234 | F1 MACRO: 0.9084 | F1 MICRO: 0.9234
# EPOCH 7 | LOSS: 8.302090644836426 | ACCURACY: 0.9149 | F1 MACRO: 0.9014 | F1 MICRO: 0.9149
# in second
# EPOCH 8 | LOSS: 7.55288553237915 | ACCURACY: 0.9191 | F1 MACRO: 0.9066 | F1 MICRO: 0.9191
# in second
# EPOCH 9 | LOSS: 7.250434398651123 | ACCURACY: 0.9234 | F1 MACRO: 0.9125 | F1 MICRO: 0.9234
# in second
# EPOCH 10 | LOSS: 7.154712200164795 | ACCURACY: 0.9277 | F1 MACRO: 0.9171 | F1 MICRO: 0.9277
# sentiment: ACCURACY 0.9362 | F1 MACRO 0.9296 | F1 MICRO 0.9362
#               precision    recall  f1-score   support
#
#     negative       0.85      0.97      0.91        76
#     positive       0.99      0.92      0.95       159
#
#     accuracy                           0.94       235
#    macro avg       0.92      0.95      0.93       235
# weighted avg       0.94      0.94      0.94       235
#
# --------------------------------------------------
# Iteration 208: Accuracy: 0.9306, F1 Micro: 0.9306, F1 Macro: 0.8614
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.91      0.91        11
#      neutral       0.98      1.00      0.99       181
#     positive       1.00      0.83      0.91        24
#
#     accuracy                           0.98       216
#    macro avg       0.96      0.91      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.88      0.88      0.88        16
#      neutral       0.96      0.99      0.97       167
#     positive       0.89      0.76      0.82        33
#
#     accuracy                           0.94       216
#    macro avg       0.91      0.87      0.89       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.67      0.73        12
#      neutral       0.87      0.94      0.90       152
#     positive       0.78      0.62      0.69        52
#
#     accuracy                           0.85       216
#    macro avg       0.82      0.74      0.77       216
# weighted avg       0.84      0.85      0.84       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.79      0.96      0.86        23
#      neutral       0.94      0.97      0.95       152
#     positive       0.90      0.68      0.78        41
#
#     accuracy                           0.91       216
#    macro avg       0.88      0.87      0.86       216
# weighted avg       0.91      0.91      0.91       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.82      0.69      0.75        13
#      neutral       0.97      0.98      0.98       186
#     positive       0.78      0.82      0.80        17
#
#     accuracy                           0.95       216
#    macro avg       0.86      0.83      0.84       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.79      0.88        14
#      neutral       0.95      1.00      0.97       185
#     positive       1.00      0.59      0.74        17
#
#     accuracy                           0.95       216
#    macro avg       0.98      0.79      0.86       216
# weighted avg       0.96      0.95      0.95       216
#
# Launching training on 2 GPUs.
# 600 600
# Nearest checkpoint: 540
# Threshold: 88343.015625
# Samples above threshold: 66
# Acquired samples: 66
# Sampling duration: 12.038693904876709 seconds
# New train size: 274
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.308885097503662 | ACCURACY: 0.7924 | F1 MACRO: 0.8823 | F1 MICRO: 0.8838
# EPOCH 2 | LOSS: 2.898439884185791 | ACCURACY: 0.8118 | F1 MACRO: 0.8924 | F1 MICRO: 0.8935
# EPOCH 3 | LOSS: 2.569701910018921 | ACCURACY: 0.8408 | F1 MACRO: 0.9067 | F1 MICRO: 0.9076
# EPOCH 4 | LOSS: 2.482120990753174 | ACCURACY: 0.8646 | F1 MACRO: 0.9193 | F1 MICRO: 0.9201
# EPOCH 5 | LOSS: 2.4536948204040527 | ACCURACY: 0.9152 | F1 MACRO: 0.9467 | F1 MICRO: 0.9481
# EPOCH 6 | LOSS: 2.3367888927459717 | ACCURACY: 0.9241 | F1 MACRO: 0.9514 | F1 MICRO: 0.9531
# EPOCH 7 | LOSS: 2.3443336486816406 | ACCURACY: 0.9375 | F1 MACRO: 0.9592 | F1 MICRO: 0.9611
# EPOCH 8 | LOSS: 2.142317056655884 | ACCURACY: 0.942 | F1 MACRO: 0.9622 | F1 MICRO: 0.9638
# EPOCH 9 | LOSS: 2.098593235015869 | ACCURACY: 0.939 | F1 MACRO: 0.9601 | F1 MICRO: 0.962
# EPOCH 10 | LOSS: 1.959830403327942 | ACCURACY: 0.936 | F1 MACRO: 0.9583 | F1 MICRO: 0.9601
# aspect: ACCURACY 0.942 | F1 MACRO 0.9622 | F1 MICRO 0.9638
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.94      0.98      0.96       175
#       others       0.86      0.95      0.90       158
#         part       0.95      0.96      0.96       158
#        price       0.98      0.97      0.98       192
#      service       0.97      1.00      0.99       191
#
#    micro avg       0.95      0.98      0.96      1061
#    macro avg       0.95      0.98      0.96      1061
# weighted avg       0.95      0.98      0.96      1061
#  samples avg       0.95      0.98      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 9.50338077545166 | ACCURACY: 0.9072 | F1 MACRO: 0.8894 | F1 MICRO: 0.9072
# EPOCH 2 | LOSS: 8.082317352294922 | ACCURACY: 0.9114 | F1 MACRO: 0.9039 | F1 MICRO: 0.9114
# EPOCH 3 | LOSS: 6.865443229675293 | ACCURACY: 0.9451 | F1 MACRO: 0.9385 | F1 MICRO: 0.9451
# EPOCH 4 | LOSS: 6.4601006507873535 | ACCURACY: 0.9409 | F1 MACRO: 0.9322 | F1 MICRO: 0.9409
# EPOCH 5 | LOSS: 6.072137832641602 | ACCURACY: 0.9409 | F1 MACRO: 0.9322 | F1 MICRO: 0.9409
# EPOCH 6 | LOSS: 5.909445762634277 | ACCURACY: 0.9325 | F1 MACRO: 0.9236 | F1 MICRO: 0.9325
# in second
# EPOCH 7 | LOSS: 5.354918479919434 | ACCURACY: 0.9283 | F1 MACRO: 0.919 | F1 MICRO: 0.9283
# in second
# EPOCH 8 | LOSS: 5.2114081382751465 | ACCURACY: 0.9409 | F1 MACRO: 0.934 | F1 MICRO: 0.9409
# in second
# EPOCH 9 | LOSS: 5.239434719085693 | ACCURACY: 0.9409 | F1 MACRO: 0.934 | F1 MICRO: 0.9409
# in second
# EPOCH 10 | LOSS: 5.0125908851623535 | ACCURACY: 0.9409 | F1 MACRO: 0.934 | F1 MICRO: 0.9409
# sentiment: ACCURACY 0.9451 | F1 MACRO 0.9385 | F1 MICRO 0.9451
#               precision    recall  f1-score   support
#
#     negative       0.89      0.95      0.92        77
#     positive       0.97      0.94      0.96       160
#
#     accuracy                           0.95       237
#    macro avg       0.93      0.95      0.94       237
# weighted avg       0.95      0.95      0.95       237
#
# --------------------------------------------------
# Iteration 274: Accuracy: 0.9313, F1 Micro: 0.9313, F1 Macro: 0.8747
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.98      1.00      0.99       181
#     positive       1.00      0.92      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       0.99      0.94      0.97       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.75      0.80        16
#      neutral       0.94      0.98      0.96       167
#     positive       0.85      0.70      0.77        33
#
#     accuracy                           0.92       216
#    macro avg       0.88      0.81      0.84       216
# weighted avg       0.92      0.92      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.89      0.67      0.76        12
#      neutral       0.86      0.93      0.90       152
#     positive       0.76      0.62      0.68        52
#
#     accuracy                           0.84       216
#    macro avg       0.84      0.74      0.78       216
# weighted avg       0.84      0.84      0.84       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.88      0.91      0.89        23
#      neutral       0.93      0.97      0.95       152
#     positive       0.88      0.68      0.77        41
#
#     accuracy                           0.91       216
#    macro avg       0.89      0.86      0.87       216
# weighted avg       0.91      0.91      0.91       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.77      0.80        13
#      neutral       0.98      0.97      0.98       186
#     positive       0.74      0.82      0.78        17
#
#     accuracy                           0.95       216
#    macro avg       0.85      0.86      0.85       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.97      1.00      0.99       185
#     positive       1.00      0.76      0.87        17
#
#     accuracy                           0.98       216
#    macro avg       0.99      0.90      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Launching training on 2 GPUs.
# 543 543
# Nearest checkpoint: 540
# Threshold: 88409.8515625
# Samples above threshold: 59
# Acquired samples: 59
# Sampling duration: 13.918855667114258 seconds
# New train size: 333
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.3376166820526123 | ACCURACY: 0.7902 | F1 MACRO: 0.8812 | F1 MICRO: 0.8827
# EPOCH 2 | LOSS: 2.880296230316162 | ACCURACY: 0.8251 | F1 MACRO: 0.899 | F1 MICRO: 0.8998
# EPOCH 3 | LOSS: 2.5893301963806152 | ACCURACY: 0.8601 | F1 MACRO: 0.9176 | F1 MICRO: 0.9183
# EPOCH 4 | LOSS: 2.5723326206207275 | ACCURACY: 0.901 | F1 MACRO: 0.9389 | F1 MICRO: 0.94
# EPOCH 5 | LOSS: 2.5023648738861084 | ACCURACY: 0.9375 | F1 MACRO: 0.9593 | F1 MICRO: 0.9611
# EPOCH 6 | LOSS: 2.388209342956543 | ACCURACY: 0.9412 | F1 MACRO: 0.9626 | F1 MICRO: 0.9636
# EPOCH 7 | LOSS: 2.282780408859253 | ACCURACY: 0.9397 | F1 MACRO: 0.9602 | F1 MICRO: 0.9623
# EPOCH 8 | LOSS: 2.1163833141326904 | ACCURACY: 0.9435 | F1 MACRO: 0.9636 | F1 MICRO: 0.9649
# EPOCH 9 | LOSS: 1.97446608543396 | ACCURACY: 0.9487 | F1 MACRO: 0.9666 | F1 MICRO: 0.968
# EPOCH 10 | LOSS: 1.9106485843658447 | ACCURACY: 0.9449 | F1 MACRO: 0.964 | F1 MICRO: 0.9656
# aspect: ACCURACY 0.9487 | F1 MACRO 0.9666 | F1 MICRO 0.968
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.94      0.99      0.97       175
#       others       0.87      0.97      0.92       158
#         part       0.95      0.96      0.96       158
#        price       0.97      0.98      0.98       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.95      0.98      0.97      1061
#    macro avg       0.95      0.98      0.97      1061
# weighted avg       0.95      0.98      0.97      1061
#  samples avg       0.95      0.99      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 8.83586311340332 | ACCURACY: 0.9212 | F1 MACRO: 0.9097 | F1 MICRO: 0.9212
# EPOCH 2 | LOSS: 7.163419723510742 | ACCURACY: 0.9336 | F1 MACRO: 0.9265 | F1 MICRO: 0.9336
# EPOCH 3 | LOSS: 5.905720233917236 | ACCURACY: 0.9419 | F1 MACRO: 0.9357 | F1 MICRO: 0.9419
# EPOCH 4 | LOSS: 5.521512985229492 | ACCURACY: 0.9087 | F1 MACRO: 0.8935 | F1 MICRO: 0.9087
# EPOCH 5 | LOSS: 5.388246059417725 | ACCURACY: 0.9212 | F1 MACRO: 0.9143 | F1 MICRO: 0.9212
# EPOCH 6 | LOSS: 5.0425944328308105 | ACCURACY: 0.9419 | F1 MACRO: 0.9357 | F1 MICRO: 0.9419
# EPOCH 7 | LOSS: 4.910262107849121 | ACCURACY: 0.9295 | F1 MACRO: 0.9197 | F1 MICRO: 0.9295
# EPOCH 8 | LOSS: 4.795413494110107 | ACCURACY: 0.9461 | F1 MACRO: 0.9404 | F1 MICRO: 0.9461
# EPOCH 9 | LOSS: 4.616619110107422 | ACCURACY: 0.9253 | F1 MACRO: 0.9147 | F1 MICRO: 0.9253
# EPOCH 10 | LOSS: 4.628293037414551 | ACCURACY: 0.9253 | F1 MACRO: 0.9182 | F1 MICRO: 0.9253
# sentiment: ACCURACY 0.9461 | F1 MACRO 0.9404 | F1 MICRO 0.9461
#               precision    recall  f1-score   support
#
#     negative       0.88      0.97      0.92        79
#     positive       0.99      0.93      0.96       162
#
#     accuracy                           0.95       241
#    macro avg       0.93      0.95      0.94       241
# weighted avg       0.95      0.95      0.95       241
#
# --------------------------------------------------
# Iteration 333: Accuracy: 0.9437, F1 Micro: 0.9437, F1 Macro: 0.8892
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.82      0.90        11
#      neutral       0.98      1.00      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.98       216
#    macro avg       0.98      0.91      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.81      0.84        16
#      neutral       0.95      0.99      0.97       167
#     positive       0.92      0.73      0.81        33
#
#     accuracy                           0.94       216
#    macro avg       0.91      0.84      0.87       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.89      0.67      0.76        12
#      neutral       0.87      0.97      0.92       152
#     positive       0.89      0.65      0.76        52
#
#     accuracy                           0.88       216
#    macro avg       0.88      0.76      0.81       216
# weighted avg       0.88      0.88      0.87       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.88      1.00      0.94        23
#      neutral       0.95      0.96      0.96       152
#     positive       0.86      0.78      0.82        41
#
#     accuracy                           0.93       216
#    macro avg       0.90      0.91      0.91       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.77      0.77      0.77        13
#      neutral       0.98      0.98      0.98       186
#     positive       0.76      0.76      0.76        17
#
#     accuracy                           0.95       216
#    macro avg       0.84      0.84      0.84       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.98      1.00      0.99       185
#     positive       1.00      0.88      0.94        17
#
#     accuracy                           0.99       216
#    macro avg       0.99      0.94      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 501 501
# Nearest checkpoint: 540
# Threshold: 88672.78125
# Samples above threshold: 54
# Acquired samples: 54
# Sampling duration: 14.215009689331055 seconds
# New train size: 387
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.2753562927246094 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# EPOCH 2 | LOSS: 2.7478346824645996 | ACCURACY: 0.84 | F1 MACRO: 0.9067 | F1 MICRO: 0.9074
# EPOCH 3 | LOSS: 2.566535472869873 | ACCURACY: 0.8824 | F1 MACRO: 0.9283 | F1 MICRO: 0.9293
# EPOCH 4 | LOSS: 2.512237548828125 | ACCURACY: 0.9278 | F1 MACRO: 0.9537 | F1 MICRO: 0.9553
# EPOCH 5 | LOSS: 2.3613390922546387 | ACCURACY: 0.9375 | F1 MACRO: 0.9601 | F1 MICRO: 0.9614
# EPOCH 6 | LOSS: 2.1861555576324463 | ACCURACY: 0.9382 | F1 MACRO: 0.9598 | F1 MICRO: 0.9615
# EPOCH 7 | LOSS: 2.0806686878204346 | ACCURACY: 0.9449 | F1 MACRO: 0.9639 | F1 MICRO: 0.9656
# EPOCH 8 | LOSS: 1.9837244749069214 | ACCURACY: 0.9509 | F1 MACRO: 0.9684 | F1 MICRO: 0.9694
# EPOCH 9 | LOSS: 1.8949047327041626 | ACCURACY: 0.9524 | F1 MACRO: 0.9685 | F1 MICRO: 0.9702
# EPOCH 10 | LOSS: 1.837201476097107 | ACCURACY: 0.9427 | F1 MACRO: 0.9619 | F1 MICRO: 0.9642
# aspect: ACCURACY 0.9524 | F1 MACRO 0.9685 | F1 MICRO 0.9702
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.95      0.99      0.97       175
#       others       0.92      0.91      0.91       158
#         part       0.95      0.99      0.97       158
#        price       0.97      0.98      0.98       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.96      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 7.4784440994262695 | ACCURACY: 0.9053 | F1 MACRO: 0.8918 | F1 MICRO: 0.9053
# EPOCH 2 | LOSS: 6.428194999694824 | ACCURACY: 0.9424 | F1 MACRO: 0.936 | F1 MICRO: 0.9424
# EPOCH 3 | LOSS: 5.052524566650391 | ACCURACY: 0.9342 | F1 MACRO: 0.9272 | F1 MICRO: 0.9342
# EPOCH 4 | LOSS: 4.513914585113525 | ACCURACY: 0.9342 | F1 MACRO: 0.9259 | F1 MICRO: 0.9342
# EPOCH 5 | LOSS: 4.498386859893799 | ACCURACY: 0.9383 | F1 MACRO: 0.9299 | F1 MICRO: 0.9383
# in second
# EPOCH 6 | LOSS: 4.058449745178223 | ACCURACY: 0.9342 | F1 MACRO: 0.9255 | F1 MICRO: 0.9342
# in second
# EPOCH 7 | LOSS: 3.998440980911255 | ACCURACY: 0.9342 | F1 MACRO: 0.9259 | F1 MICRO: 0.9342
# in second
# EPOCH 8 | LOSS: 3.8868534564971924 | ACCURACY: 0.9342 | F1 MACRO: 0.9259 | F1 MICRO: 0.9342
# in second
# EPOCH 9 | LOSS: 3.9172496795654297 | ACCURACY: 0.9342 | F1 MACRO: 0.9264 | F1 MICRO: 0.9342
# in second
# EPOCH 10 | LOSS: 3.7180023193359375 | ACCURACY: 0.93 | F1 MACRO: 0.9215 | F1 MICRO: 0.93
# sentiment: ACCURACY 0.9424 | F1 MACRO 0.936 | F1 MICRO 0.9424
#               precision    recall  f1-score   support
#
#     negative       0.86      0.97      0.92        78
#     positive       0.99      0.93      0.96       165
#
#     accuracy                           0.94       243
#    macro avg       0.93      0.95      0.94       243
# weighted avg       0.95      0.94      0.94       243
#
# --------------------------------------------------
# Iteration 387: Accuracy: 0.9414, F1 Micro: 0.9414, F1 Macro: 0.8813
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.92      1.00      0.96        11
#      neutral       0.99      1.00      0.99       181
#     positive       1.00      0.88      0.93        24
#
#     accuracy                           0.99       216
#    macro avg       0.97      0.96      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.75      0.83        16
#      neutral       0.94      0.99      0.97       167
#     positive       0.92      0.73      0.81        33
#
#     accuracy                           0.94       216
#    macro avg       0.93      0.82      0.87       216
# weighted avg       0.93      0.94      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.64      0.75      0.69        12
#      neutral       0.91      0.93      0.92       152
#     positive       0.81      0.73      0.77        52
#
#     accuracy                           0.87       216
#    macro avg       0.79      0.80      0.79       216
# weighted avg       0.87      0.87      0.87       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.88      0.96      0.92        23
#      neutral       0.93      0.99      0.96       152
#     positive       0.97      0.68      0.80        41
#
#     accuracy                           0.93       216
#    macro avg       0.93      0.88      0.89       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.69      0.72        13
#      neutral       0.97      0.98      0.98       186
#     positive       0.76      0.76      0.76        17
#
#     accuracy                           0.94       216
#    macro avg       0.83      0.81      0.82       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.98      1.00      0.99       185
#     positive       1.00      0.82      0.90        17
#
#     accuracy                           0.98       216
#    macro avg       0.99      0.92      0.95       216
# weighted avg       0.98      0.98      0.98       216
#
# Launching training on 2 GPUs.
# 457 457
# Nearest checkpoint: 540
# Threshold: 88459.8828125
# Samples above threshold: 48
# Acquired samples: 48
# Sampling duration: 15.294305801391602 seconds
# New train size: 435
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.1598596572875977 | ACCURACY: 0.7909 | F1 MACRO: 0.8816 | F1 MICRO: 0.8831
# EPOCH 2 | LOSS: 2.579899311065674 | ACCURACY: 0.846 | F1 MACRO: 0.9093 | F1 MICRO: 0.91
# EPOCH 3 | LOSS: 2.4938647747039795 | ACCURACY: 0.9003 | F1 MACRO: 0.9386 | F1 MICRO: 0.9398
# EPOCH 4 | LOSS: 2.420449733734131 | ACCURACY: 0.936 | F1 MACRO: 0.9583 | F1 MICRO: 0.9602
# EPOCH 5 | LOSS: 2.209627151489258 | ACCURACY: 0.942 | F1 MACRO: 0.9627 | F1 MICRO: 0.9641
# EPOCH 6 | LOSS: 2.0279414653778076 | ACCURACY: 0.9449 | F1 MACRO: 0.964 | F1 MICRO: 0.9656
# EPOCH 7 | LOSS: 1.9644238948822021 | ACCURACY: 0.9442 | F1 MACRO: 0.9633 | F1 MICRO: 0.9649
# EPOCH 8 | LOSS: 1.8842055797576904 | ACCURACY: 0.9435 | F1 MACRO: 0.9627 | F1 MICRO: 0.9646
# EPOCH 9 | LOSS: 1.8150436878204346 | ACCURACY: 0.9501 | F1 MACRO: 0.9672 | F1 MICRO: 0.9688
# EPOCH 10 | LOSS: 1.7371234893798828 | ACCURACY: 0.9494 | F1 MACRO: 0.967 | F1 MICRO: 0.9684
# aspect: ACCURACY 0.9501 | F1 MACRO 0.9672 | F1 MICRO 0.9688
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.94      0.99      0.96       175
#       others       0.90      0.94      0.92       158
#         part       0.96      0.97      0.96       158
#        price       0.98      0.98      0.98       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.96      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.6207804679870605 | ACCURACY: 0.9098 | F1 MACRO: 0.8934 | F1 MICRO: 0.9098
# EPOCH 2 | LOSS: 6.043164253234863 | ACCURACY: 0.902 | F1 MACRO: 0.8858 | F1 MICRO: 0.902
# EPOCH 3 | LOSS: 4.753228187561035 | ACCURACY: 0.9294 | F1 MACRO: 0.9219 | F1 MICRO: 0.9294
# EPOCH 4 | LOSS: 4.527629852294922 | ACCURACY: 0.9216 | F1 MACRO: 0.9089 | F1 MICRO: 0.9216
# EPOCH 5 | LOSS: 4.207904815673828 | ACCURACY: 0.9255 | F1 MACRO: 0.9154 | F1 MICRO: 0.9255
# EPOCH 6 | LOSS: 3.968001365661621 | ACCURACY: 0.9255 | F1 MACRO: 0.9164 | F1 MICRO: 0.9255
# in second
# EPOCH 7 | LOSS: 3.8814053535461426 | ACCURACY: 0.9255 | F1 MACRO: 0.9178 | F1 MICRO: 0.9255
# in second
# EPOCH 8 | LOSS: 3.7168631553649902 | ACCURACY: 0.9255 | F1 MACRO: 0.9178 | F1 MICRO: 0.9255
# in second
# EPOCH 9 | LOSS: 3.6289265155792236 | ACCURACY: 0.9294 | F1 MACRO: 0.9215 | F1 MICRO: 0.9294
# in second
# EPOCH 10 | LOSS: 3.6384546756744385 | ACCURACY: 0.9333 | F1 MACRO: 0.9252 | F1 MICRO: 0.9333
# sentiment: ACCURACY 0.9294 | F1 MACRO 0.9219 | F1 MICRO 0.9294
#               precision    recall  f1-score   support
#
#     negative       0.83      0.98      0.90        81
#     positive       0.99      0.91      0.95       174
#
#     accuracy                           0.93       255
#    macro avg       0.91      0.94      0.92       255
# weighted avg       0.94      0.93      0.93       255
#
# --------------------------------------------------
# Iteration 435: Accuracy: 0.9421, F1 Micro: 0.9421, F1 Macro: 0.8847
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      1.00      0.99       181
#     positive       1.00      0.92      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.97      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.75      0.80        16
#      neutral       0.93      0.99      0.96       167
#     positive       0.92      0.67      0.77        33
#
#     accuracy                           0.93       216
#    macro avg       0.90      0.80      0.84       216
# weighted avg       0.92      0.93      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.69      0.75      0.72        12
#      neutral       0.90      0.93      0.91       152
#     positive       0.80      0.71      0.76        52
#
#     accuracy                           0.87       216
#    macro avg       0.80      0.80      0.80       216
# weighted avg       0.86      0.87      0.86       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.74      1.00      0.85        23
#      neutral       0.97      0.97      0.97       152
#     positive       0.94      0.76      0.84        41
#
#     accuracy                           0.94       216
#    macro avg       0.89      0.91      0.89       216
# weighted avg       0.94      0.94      0.93       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.77      0.77      0.77        13
#      neutral       0.98      0.97      0.98       186
#     positive       0.72      0.76      0.74        17
#
#     accuracy                           0.94       216
#    macro avg       0.82      0.84      0.83       216
# weighted avg       0.95      0.94      0.94       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.93      1.00      0.97        14
#      neutral       0.99      1.00      1.00       185
#     positive       1.00      0.88      0.94        17
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.96      0.97       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 411 411
# Nearest checkpoint: 540
# Threshold: 88473.640625
# Samples above threshold: 43
# Acquired samples: 43
# Sampling duration: 17.422232389450073 seconds
# New train size: 478
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.1587746143341064 | ACCURACY: 0.7917 | F1 MACRO: 0.882 | F1 MICRO: 0.8834
# EPOCH 2 | LOSS: 2.5745956897735596 | ACCURACY: 0.8475 | F1 MACRO: 0.9098 | F1 MICRO: 0.911
# EPOCH 3 | LOSS: 2.5046794414520264 | ACCURACY: 0.9129 | F1 MACRO: 0.9455 | F1 MICRO: 0.9471
# EPOCH 4 | LOSS: 2.432772636413574 | ACCURACY: 0.933 | F1 MACRO: 0.9565 | F1 MICRO: 0.9585
# EPOCH 5 | LOSS: 2.188880443572998 | ACCURACY: 0.9405 | F1 MACRO: 0.9603 | F1 MICRO: 0.9628
# EPOCH 6 | LOSS: 2.0526275634765625 | ACCURACY: 0.9501 | F1 MACRO: 0.9672 | F1 MICRO: 0.9688
# EPOCH 7 | LOSS: 1.9521845579147339 | ACCURACY: 0.9427 | F1 MACRO: 0.9615 | F1 MICRO: 0.964
# EPOCH 8 | LOSS: 1.8477598428726196 | ACCURACY: 0.9524 | F1 MACRO: 0.9686 | F1 MICRO: 0.9701
# EPOCH 9 | LOSS: 1.7703160047531128 | ACCURACY: 0.9427 | F1 MACRO: 0.9619 | F1 MICRO: 0.9639
# EPOCH 10 | LOSS: 1.7178680896759033 | ACCURACY: 0.9435 | F1 MACRO: 0.9621 | F1 MICRO: 0.9644
# aspect: ACCURACY 0.9524 | F1 MACRO 0.9686 | F1 MICRO 0.9701
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.95      1.00      0.97       175
#       others       0.91      0.94      0.93       158
#         part       0.96      0.95      0.96       158
#        price       0.97      0.97      0.97       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.96      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.452291011810303 | ACCURACY: 0.8054 | F1 MACRO: 0.7217 | F1 MICRO: 0.8054
# EPOCH 2 | LOSS: 5.057940483093262 | ACCURACY: 0.9105 | F1 MACRO: 0.8945 | F1 MICRO: 0.9105
# EPOCH 3 | LOSS: 4.440404415130615 | ACCURACY: 0.9339 | F1 MACRO: 0.9231 | F1 MICRO: 0.9339
# EPOCH 4 | LOSS: 4.175090312957764 | ACCURACY: 0.9339 | F1 MACRO: 0.9251 | F1 MICRO: 0.9339
# EPOCH 5 | LOSS: 4.045102119445801 | ACCURACY: 0.9261 | F1 MACRO: 0.9172 | F1 MICRO: 0.9261
# EPOCH 6 | LOSS: 3.811305522918701 | ACCURACY: 0.9261 | F1 MACRO: 0.9141 | F1 MICRO: 0.9261
# EPOCH 7 | LOSS: 3.8901076316833496 | ACCURACY: 0.9261 | F1 MACRO: 0.9167 | F1 MICRO: 0.9261
# in second
# EPOCH 8 | LOSS: 3.471184015274048 | ACCURACY: 0.9222 | F1 MACRO: 0.9136 | F1 MICRO: 0.9222
# in second
# EPOCH 9 | LOSS: 3.358182907104492 | ACCURACY: 0.9261 | F1 MACRO: 0.9181 | F1 MICRO: 0.9261
# in second
# EPOCH 10 | LOSS: 3.379434585571289 | ACCURACY: 0.9261 | F1 MACRO: 0.9181 | F1 MICRO: 0.9261
# sentiment: ACCURACY 0.9339 | F1 MACRO 0.9251 | F1 MICRO 0.9339
#               precision    recall  f1-score   support
#
#     negative       0.86      0.94      0.90        81
#     positive       0.97      0.93      0.95       176
#
#     accuracy                           0.93       257
#    macro avg       0.92      0.94      0.93       257
# weighted avg       0.94      0.93      0.93       257
#
# --------------------------------------------------
# Iteration 478: Accuracy: 0.9452, F1 Micro: 0.9452, F1 Macro: 0.8958
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      1.00      0.99       181
#     positive       1.00      0.92      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.97      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.81      0.87        16
#      neutral       0.95      0.98      0.96       167
#     positive       0.86      0.76      0.81        33
#
#     accuracy                           0.94       216
#    macro avg       0.91      0.85      0.88       216
# weighted avg       0.93      0.94      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.75      0.75        12
#      neutral       0.90      0.93      0.92       152
#     positive       0.83      0.75      0.79        52
#
#     accuracy                           0.88       216
#    macro avg       0.83      0.81      0.82       216
# weighted avg       0.88      0.88      0.88       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.85      1.00      0.92        23
#      neutral       0.96      0.97      0.97       152
#     positive       0.91      0.78      0.84        41
#
#     accuracy                           0.94       216
#    macro avg       0.91      0.92      0.91       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.71      0.77      0.74        13
#      neutral       0.98      0.97      0.97       186
#     positive       0.72      0.76      0.74        17
#
#     accuracy                           0.94       216
#    macro avg       0.80      0.83      0.82       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.98      1.00      0.99       185
#     positive       1.00      0.88      0.94        17
#
#     accuracy                           0.99       216
#    macro avg       0.99      0.94      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 377 377
# Nearest checkpoint: 540
# Threshold: 88395.734375
# Samples above threshold: 39
# Acquired samples: 39
# Sampling duration: 17.222615480422974 seconds
# New train size: 517
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.215693473815918 | ACCURACY: 0.8013 | F1 MACRO: 0.8869 | F1 MICRO: 0.8882
# EPOCH 2 | LOSS: 2.5975759029388428 | ACCURACY: 0.8586 | F1 MACRO: 0.9154 | F1 MICRO: 0.9163
# EPOCH 3 | LOSS: 2.535025119781494 | ACCURACY: 0.9137 | F1 MACRO: 0.9426 | F1 MICRO: 0.9458
# EPOCH 4 | LOSS: 2.335212469100952 | ACCURACY: 0.9435 | F1 MACRO: 0.9633 | F1 MICRO: 0.9648
# EPOCH 5 | LOSS: 2.123502731323242 | ACCURACY: 0.942 | F1 MACRO: 0.962 | F1 MICRO: 0.9638
# EPOCH 6 | LOSS: 2.0369107723236084 | ACCURACY: 0.9472 | F1 MACRO: 0.9649 | F1 MICRO: 0.9669
# EPOCH 7 | LOSS: 1.9267295598983765 | ACCURACY: 0.9501 | F1 MACRO: 0.9676 | F1 MICRO: 0.9689
# EPOCH 8 | LOSS: 1.8285915851593018 | ACCURACY: 0.9539 | F1 MACRO: 0.9699 | F1 MICRO: 0.9711
# ...
#    macro avg       0.96      0.98      0.97      1061
# weighted avg       0.97      0.99      0.98      1061
#  samples avg       0.97      0.99      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.6291723251342773 | ACCURACY: 0.9073 | F1 MACRO: 0.8921 | F1 MICRO: 0.9073
# EPOCH 2 | LOSS: 2.776884078979492 | ACCURACY: 0.9395 | F1 MACRO: 0.9315 | F1 MICRO: 0.9395
# EPOCH 3 | LOSS: 2.4730141162872314 | ACCURACY: 0.9476 | F1 MACRO: 0.942 | F1 MICRO: 0.9476
# EPOCH 4 | LOSS: 2.307631015777588 | ACCURACY: 0.9476 | F1 MACRO: 0.9413 | F1 MICRO: 0.9476
# EPOCH 5 | LOSS: 2.1755125522613525 | ACCURACY: 0.9476 | F1 MACRO: 0.9423 | F1 MICRO: 0.9476
# EPOCH 6 | LOSS: 2.1064229011535645 | ACCURACY: 0.9476 | F1 MACRO: 0.9406 | F1 MICRO: 0.9476
# EPOCH 7 | LOSS: 2.052462339401245 | ACCURACY: 0.9395 | F1 MACRO: 0.9334 | F1 MICRO: 0.9395
# EPOCH 8 | LOSS: 1.9821984767913818 | ACCURACY: 0.9315 | F1 MACRO: 0.9246 | F1 MICRO: 0.9315
# EPOCH 9 | LOSS: 1.9785348176956177 | ACCURACY: 0.9274 | F1 MACRO: 0.9133 | F1 MICRO: 0.9274
# in second
# EPOCH 10 | LOSS: 1.9025710821151733 | ACCURACY: 0.9476 | F1 MACRO: 0.9413 | F1 MICRO: 0.9476
# sentiment: ACCURACY 0.9476 | F1 MACRO 0.9406 | F1 MICRO 0.9476
#               precision    recall  f1-score   support
#
#     negative       0.93      0.91      0.92        82
#     positive       0.96      0.96      0.96       166
#
#     accuracy                           0.95       248
#    macro avg       0.94      0.94      0.94       248
# weighted avg       0.95      0.95      0.95       248
#
# --------------------------------------------------
# Iteration 831: Accuracy: 0.9506, F1 Micro: 0.9506, F1 Macro: 0.8991
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.82      0.90        11
#      neutral       0.99      1.00      0.99       181
#     positive       0.92      0.92      0.92        24
#
#     accuracy                           0.98       216
#    macro avg       0.97      0.91      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.75      0.83        16
#      neutral       0.94      0.99      0.97       167
#     positive       0.92      0.73      0.81        33
#
#     accuracy                           0.94       216
#    macro avg       0.93      0.82      0.87       216
# weighted avg       0.93      0.94      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.90      0.75      0.82        12
#      neutral       0.91      0.96      0.94       152
#     positive       0.87      0.77      0.82        52
#
#     accuracy                           0.90       216
#    macro avg       0.89      0.83      0.86       216
# weighted avg       0.90      0.90      0.90       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.84      0.91      0.87        23
#      neutral       0.96      0.99      0.97       152
#     positive       0.91      0.76      0.83        41
#
#     accuracy                           0.94       216
#    macro avg       0.90      0.89      0.89       216
# weighted avg       0.93      0.94      0.93       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.85      0.85        13
#      neutral       0.98      0.98      0.98       186
#     positive       0.76      0.76      0.76        17
#
#     accuracy                           0.95       216
#    macro avg       0.86      0.86      0.86       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       1.00      1.00      1.00       185
#     positive       0.94      1.00      0.97        17
#
#     accuracy                           1.00       216
#    macro avg       0.98      0.98      0.98       216
# weighted avg       1.00      1.00      1.00       216
#
# Launching training on 2 GPUs.
# 33 33
# Nearest checkpoint: 864
# Threshold: 88282.625
# Samples above threshold: 4
# Acquired samples: 25
# Sampling duration: 22.326682329177856 seconds
# New train size: 856
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.8853085041046143 | ACCURACY: 0.8385 | F1 MACRO: 0.9057 | F1 MICRO: 0.9067
# EPOCH 2 | LOSS: 2.4331436157226562 | ACCURACY: 0.9345 | F1 MACRO: 0.9579 | F1 MICRO: 0.9593
# EPOCH 3 | LOSS: 2.2335445880889893 | ACCURACY: 0.9501 | F1 MACRO: 0.9677 | F1 MICRO: 0.9689
# EPOCH 4 | LOSS: 1.9915452003479004 | ACCURACY: 0.9531 | F1 MACRO: 0.9692 | F1 MICRO: 0.9706
# EPOCH 5 | LOSS: 1.8732749223709106 | ACCURACY: 0.9494 | F1 MACRO: 0.9664 | F1 MICRO: 0.9681
# EPOCH 6 | LOSS: 1.773660659790039 | ACCURACY: 0.9546 | F1 MACRO: 0.9694 | F1 MICRO: 0.9714
# EPOCH 7 | LOSS: 1.7014669179916382 | ACCURACY: 0.9494 | F1 MACRO: 0.966 | F1 MICRO: 0.9682
# EPOCH 8 | LOSS: 1.6564955711364746 | ACCURACY: 0.9539 | F1 MACRO: 0.9679 | F1 MICRO: 0.9707
# EPOCH 9 | LOSS: 1.5947102308273315 | ACCURACY: 0.9554 | F1 MACRO: 0.9694 | F1 MICRO: 0.9717
# EPOCH 10 | LOSS: 1.5764542818069458 | ACCURACY: 0.9576 | F1 MACRO: 0.9707 | F1 MICRO: 0.9731
# aspect: ACCURACY 0.9576 | F1 MACRO 0.9707 | F1 MICRO 0.9731
#               precision    recall  f1-score   support
#
#         fuel       0.98      0.99      0.99       187
#      machine       0.95      0.98      0.97       175
#       others       0.95      0.87      0.91       158
#         part       0.97      0.96      0.97       158
#        price       0.99      1.00      0.99       192
#      service       0.99      1.00      1.00       191
#
#    micro avg       0.97      0.97      0.97      1061
#    macro avg       0.97      0.97      0.97      1061
# weighted avg       0.97      0.97      0.97      1061
#  samples avg       0.97      0.97      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.6711227893829346 | ACCURACY: 0.9058 | F1 MACRO: 0.8909 | F1 MICRO: 0.9058
# EPOCH 2 | LOSS: 2.979734420776367 | ACCURACY: 0.9167 | F1 MACRO: 0.9079 | F1 MICRO: 0.9167
# EPOCH 3 | LOSS: 2.450840711593628 | ACCURACY: 0.942 | F1 MACRO: 0.9329 | F1 MICRO: 0.942
# EPOCH 4 | LOSS: 2.2706046104431152 | ACCURACY: 0.9529 | F1 MACRO: 0.9463 | F1 MICRO: 0.9529
# EPOCH 5 | LOSS: 2.208200454711914 | ACCURACY: 0.913 | F1 MACRO: 0.8944 | F1 MICRO: 0.913
# EPOCH 6 | LOSS: 2.127781629562378 | ACCURACY: 0.9239 | F1 MACRO: 0.9105 | F1 MICRO: 0.9239
# EPOCH 7 | LOSS: 2.0856282711029053 | ACCURACY: 0.9457 | F1 MACRO: 0.9372 | F1 MICRO: 0.9457
# in second
# EPOCH 8 | LOSS: 1.953835368156433 | ACCURACY: 0.9348 | F1 MACRO: 0.9254 | F1 MICRO: 0.9348
# in second
# EPOCH 9 | LOSS: 1.9241942167282104 | ACCURACY: 0.9312 | F1 MACRO: 0.9219 | F1 MICRO: 0.9312
# in second
# EPOCH 10 | LOSS: 1.891944169998169 | ACCURACY: 0.9312 | F1 MACRO: 0.9219 | F1 MICRO: 0.9312
# sentiment: ACCURACY 0.9529 | F1 MACRO 0.9463 | F1 MICRO 0.9529
#               precision    recall  f1-score   support
#
#     negative       0.89      0.97      0.93        86
#     positive       0.98      0.95      0.97       190
#
#     accuracy                           0.95       276
#    macro avg       0.94      0.96      0.95       276
# weighted avg       0.96      0.95      0.95       276
#
# --------------------------------------------------
# Iteration 856: Accuracy: 0.9483, F1 Micro: 0.9483, F1 Macro: 0.9094
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.96      0.96      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.98      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.81      0.84        16
#      neutral       0.95      0.98      0.96       167
#     positive       0.86      0.76      0.81        33
#
#     accuracy                           0.93       216
#    macro avg       0.89      0.85      0.87       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.71      0.83      0.77        12
#      neutral       0.94      0.88      0.90       152
#     positive       0.68      0.79      0.73        52
#
#     accuracy                           0.85       216
#    macro avg       0.78      0.83      0.80       216
# weighted avg       0.86      0.85      0.86       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.79      1.00      0.88        23
#      neutral       0.97      0.98      0.98       152
#     positive       0.94      0.78      0.85        41
#
#     accuracy                           0.94       216
#    macro avg       0.90      0.92      0.90       216
# weighted avg       0.95      0.94      0.94       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.92      0.86        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.93      0.76      0.84        17
#
#     accuracy                           0.97       216
#    macro avg       0.91      0.89      0.90       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        14
#      neutral       1.00      1.00      1.00       185
#     positive       1.00      1.00      1.00        17
#
#     accuracy                           1.00       216
#    macro avg       1.00      1.00      1.00       216
# weighted avg       1.00      1.00      1.00       216
#
# Launching training on 2 GPUs.
# 8 8
# Nearest checkpoint: 864
# Threshold: 88294.6796875
# Samples above threshold: 1
# Acquired samples: 8
# Sampling duration: 22.99829864501953 seconds
# New train size: 864
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.93326735496521 | ACCURACY: 0.8289 | F1 MACRO: 0.901 | F1 MICRO: 0.9021
# EPOCH 2 | LOSS: 2.4251656532287598 | ACCURACY: 0.9382 | F1 MACRO: 0.9599 | F1 MICRO: 0.9617
# EPOCH 3 | LOSS: 2.192793846130371 | ACCURACY: 0.9539 | F1 MACRO: 0.9699 | F1 MICRO: 0.9713
# EPOCH 4 | LOSS: 1.9771536588668823 | ACCURACY: 0.9598 | F1 MACRO: 0.9735 | F1 MICRO: 0.9748
# EPOCH 5 | LOSS: 1.8499311208724976 | ACCURACY: 0.9598 | F1 MACRO: 0.9736 | F1 MICRO: 0.9748
# EPOCH 6 | LOSS: 1.7582319974899292 | ACCURACY: 0.9576 | F1 MACRO: 0.9717 | F1 MICRO: 0.9733
# EPOCH 7 | LOSS: 1.688629150390625 | ACCURACY: 0.9546 | F1 MACRO: 0.9694 | F1 MICRO: 0.9714
# in second
# EPOCH 8 | LOSS: 1.6046810150146484 | ACCURACY: 0.9479 | F1 MACRO: 0.9671 | F1 MICRO: 0.9679
# in second
# EPOCH 9 | LOSS: 1.5500402450561523 | ACCURACY: 0.9546 | F1 MACRO: 0.9711 | F1 MICRO: 0.9719
# in second
# EPOCH 10 | LOSS: 1.5192784070968628 | ACCURACY: 0.9583 | F1 MACRO: 0.9732 | F1 MICRO: 0.9741
# aspect: ACCURACY 0.9598 | F1 MACRO 0.9735 | F1 MICRO 0.9748
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.94      0.99      0.96       175
#       others       0.92      0.94      0.93       158
#         part       0.97      0.99      0.98       158
#        price       0.98      0.99      0.98       192
#      service       0.99      1.00      0.99       191
#
#    micro avg       0.96      0.99      0.97      1061
#    macro avg       0.96      0.98      0.97      1061
# weighted avg       0.96      0.99      0.97      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.594268798828125 | ACCURACY: 0.9113 | F1 MACRO: 0.901 | F1 MICRO: 0.9113
# EPOCH 2 | LOSS: 2.9001216888427734 | ACCURACY: 0.9194 | F1 MACRO: 0.9119 | F1 MICRO: 0.9194
# EPOCH 3 | LOSS: 2.4478061199188232 | ACCURACY: 0.9395 | F1 MACRO: 0.9334 | F1 MICRO: 0.9395
# EPOCH 4 | LOSS: 2.2388293743133545 | ACCURACY: 0.9476 | F1 MACRO: 0.9406 | F1 MICRO: 0.9476
# EPOCH 5 | LOSS: 2.100783109664917 | ACCURACY: 0.9516 | F1 MACRO: 0.9453 | F1 MICRO: 0.9516
# EPOCH 6 | LOSS: 2.097388505935669 | ACCURACY: 0.9194 | F1 MACRO: 0.9119 | F1 MICRO: 0.9194
# EPOCH 7 | LOSS: 1.9641485214233398 | ACCURACY: 0.9395 | F1 MACRO: 0.9334 | F1 MICRO: 0.9395
# EPOCH 8 | LOSS: 1.9301226139068604 | ACCURACY: 0.9234 | F1 MACRO: 0.9095 | F1 MICRO: 0.9234
# in second
# EPOCH 9 | LOSS: 1.830468773841858 | ACCURACY: 0.9435 | F1 MACRO: 0.9358 | F1 MICRO: 0.9435
# in second
# EPOCH 10 | LOSS: 1.8051741123199463 | ACCURACY: 0.9435 | F1 MACRO: 0.9358 | F1 MICRO: 0.9435
# sentiment: ACCURACY 0.9516 | F1 MACRO 0.9453 | F1 MICRO 0.9516
#               precision    recall  f1-score   support
#
#     negative       0.92      0.94      0.93        81
#     positive       0.97      0.96      0.96       167
#
#     accuracy                           0.95       248
#    macro avg       0.94      0.95      0.95       248
# weighted avg       0.95      0.95      0.95       248
#
# --------------------------------------------------
# Iteration 864: Accuracy: 0.9529, F1 Micro: 0.9529, F1 Macro: 0.9088
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      1.00      0.99       181
#     positive       1.00      0.92      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.97      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.75      0.83        16
#      neutral       0.94      0.99      0.96       167
#     positive       0.89      0.73      0.80        33
#
#     accuracy                           0.93       216
#    macro avg       0.92      0.82      0.86       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.90      0.75      0.82        12
#      neutral       0.92      0.95      0.93       152
#     positive       0.84      0.79      0.81        52
#
#     accuracy                           0.90       216
#    macro avg       0.88      0.83      0.85       216
# weighted avg       0.90      0.90      0.90       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.82      1.00      0.90        23
#      neutral       0.96      0.99      0.97       152
#     positive       0.97      0.76      0.85        41
#
#     accuracy                           0.94       216
#    macro avg       0.92      0.91      0.91       216
# weighted avg       0.95      0.94      0.94       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.85      0.85        13
#      neutral       0.98      0.99      0.99       186
#     positive       0.93      0.76      0.84        17
#
#     accuracy                           0.97       216
#    macro avg       0.92      0.87      0.89       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.99      1.00      0.99       185
#     positive       0.94      0.94      0.94        17
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.93      0.95       216
# weighted avg       0.99      0.99      0.99       216
#
# Total sampling time: 406.65 seconds
# Total runtime: 3370.1621499061584 seconds

# %% [markdown]
# ## RUN 2

# %%
active_learning(seeds[1], 1)
# Out:
# ===============================================
# TRIAL 2
# Random seed: 81
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.5976929664611816 | ACCURACY: 0.7634 | F1 MACRO: 0.8524 | F1 MICRO: 0.8603
# EPOCH 2 | LOSS: 3.2051076889038086 | ACCURACY: 0.7314 | F1 MACRO: 0.7859 | F1 MICRO: 0.8372
# EPOCH 3 | LOSS: 3.1839632987976074 | ACCURACY: 0.7269 | F1 MACRO: 0.7834 | F1 MICRO: 0.8348
# EPOCH 4 | LOSS: 3.163743734359741 | ACCURACY: 0.7515 | F1 MACRO: 0.8361 | F1 MICRO: 0.854
# in second
# EPOCH 5 | LOSS: 2.8541488647460938 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# in second
# EPOCH 6 | LOSS: 2.6820874214172363 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# in second
# EPOCH 7 | LOSS: 2.605513095855713 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# in second
# EPOCH 8 | LOSS: 2.602536916732788 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# in second
# EPOCH 9 | LOSS: 2.466979503631592 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# in second
# EPOCH 10 | LOSS: 2.4038352966308594 | ACCURACY: 0.7909 | F1 MACRO: 0.8816 | F1 MICRO: 0.8831
# aspect: ACCURACY 0.7634 | F1 MACRO 0.8524 | F1 MICRO 0.8603
#               precision    recall  f1-score   support
#
#         fuel       0.84      0.96      0.89       187
#      machine       0.79      1.00      0.88       175
#       others       0.70      0.68      0.69       158
#         part       0.76      0.89      0.82       158
#        price       0.86      1.00      0.92       192
#      service       0.85      0.97      0.90       191
#
#    micro avg       0.81      0.92      0.86      1061
#    macro avg       0.80      0.92      0.85      1061
# weighted avg       0.80      0.92      0.86      1061
#  samples avg       0.81      0.92      0.86      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 18.40941619873047 | ACCURACY: 0.9304 | F1 MACRO: 0.482 | F1 MICRO: 0.9304
# EPOCH 2 | LOSS: 14.951237678527832 | ACCURACY: 0.9304 | F1 MACRO: 0.482 | F1 MICRO: 0.9304
# EPOCH 3 | LOSS: 14.035446166992188 | ACCURACY: 0.9304 | F1 MACRO: 0.482 | F1 MICRO: 0.9304
# EPOCH 4 | LOSS: 13.811029434204102 | ACCURACY: 0.9304 | F1 MACRO: 0.482 | F1 MICRO: 0.9304
# EPOCH 5 | LOSS: 13.885565757751465 | ACCURACY: 0.9391 | F1 MACRO: 0.5953 | F1 MICRO: 0.9391
# EPOCH 6 | LOSS: 12.672772407531738 | ACCURACY: 0.9304 | F1 MACRO: 0.6483 | F1 MICRO: 0.9304
# EPOCH 7 | LOSS: 12.17520523071289 | ACCURACY: 0.913 | F1 MACRO: 0.4773 | F1 MICRO: 0.913
# EPOCH 8 | LOSS: 11.68865966796875 | ACCURACY: 0.8783 | F1 MACRO: 0.6482 | F1 MICRO: 0.8783
# in second
# EPOCH 9 | LOSS: 11.087661743164062 | ACCURACY: 0.9304 | F1 MACRO: 0.482 | F1 MICRO: 0.9304
# in second
# EPOCH 10 | LOSS: 10.67453670501709 | ACCURACY: 0.9304 | F1 MACRO: 0.482 | F1 MICRO: 0.9304
# sentiment: ACCURACY 0.9391 | F1 MACRO 0.5953 | F1 MICRO 0.9391
#               precision    recall  f1-score   support
#
#     negative       1.00      0.12      0.22         8
#     positive       0.94      1.00      0.97       107
#
#     accuracy                           0.94       115
#    macro avg       0.97      0.56      0.60       115
# weighted avg       0.94      0.94      0.92       115
#
# --------------------------------------------------
# Iteration 54: Accuracy: 0.76, F1 Micro: 0.76, F1 Macro: 0.3362
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        11
#      neutral       0.84      0.96      0.90       181
#     positive       0.22      0.08      0.12        24
#
#     accuracy                           0.81       216
#    macro avg       0.35      0.35      0.34       216
# weighted avg       0.73      0.81      0.77       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        16
#      neutral       0.78      1.00      0.87       167
#     positive       0.00      0.00      0.00        33
#
#     accuracy                           0.77       216
#    macro avg       0.26      0.33      0.29       216
# weighted avg       0.60      0.77      0.68       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        12
#      neutral       0.68      0.67      0.68       152
#     positive       0.22      0.27      0.24        52
#
#     accuracy                           0.54       216
#    macro avg       0.30      0.31      0.31       216
# weighted avg       0.53      0.54      0.53       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.04      0.08        23
#      neutral       0.77      0.92      0.84       152
#     positive       0.53      0.44      0.48        41
#
#     accuracy                           0.74       216
#    macro avg       0.77      0.47      0.47       216
# weighted avg       0.75      0.74      0.69       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        13
#      neutral       0.86      1.00      0.93       186
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.86       216
#    macro avg       0.29      0.33      0.31       216
# weighted avg       0.74      0.86      0.80       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        14
#      neutral       0.85      0.98      0.91       185
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.84       216
#    macro avg       0.28      0.33      0.30       216
# weighted avg       0.73      0.84      0.78       216
#
# Launching training on 2 GPUs.
# 345 345
# Nearest checkpoint: 540
# Threshold: 88540.9921875
# Samples above threshold: 81
# Acquired samples: 81
# Sampling duration: 6.30552339553833 seconds
# New train size: 135
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.818103313446045 | ACCURACY: 0.7366 | F1 MACRO: 0.8044 | F1 MICRO: 0.842
# EPOCH 2 | LOSS: 3.4540112018585205 | ACCURACY: 0.7894 | F1 MACRO: 0.8796 | F1 MICRO: 0.8815
# EPOCH 3 | LOSS: 3.1120445728302 | ACCURACY: 0.7976 | F1 MACRO: 0.8835 | F1 MICRO: 0.8854
# EPOCH 4 | LOSS: 3.013359546661377 | ACCURACY: 0.779 | F1 MACRO: 0.8458 | F1 MICRO: 0.8666
# EPOCH 5 | LOSS: 2.8024446964263916 | ACCURACY: 0.8214 | F1 MACRO: 0.8919 | F1 MICRO: 0.8955
# EPOCH 6 | LOSS: 2.684115171432495 | ACCURACY: 0.8408 | F1 MACRO: 0.9036 | F1 MICRO: 0.9061
# EPOCH 7 | LOSS: 2.5977718830108643 | ACCURACY: 0.8452 | F1 MACRO: 0.9005 | F1 MICRO: 0.9062
# EPOCH 8 | LOSS: 2.6041994094848633 | ACCURACY: 0.8586 | F1 MACRO: 0.9108 | F1 MICRO: 0.9144
# EPOCH 9 | LOSS: 2.5477585792541504 | ACCURACY: 0.869 | F1 MACRO: 0.9172 | F1 MICRO: 0.9205
# EPOCH 10 | LOSS: 2.557084798812866 | ACCURACY: 0.8847 | F1 MACRO: 0.9259 | F1 MICRO: 0.9291
# aspect: ACCURACY 0.8847 | F1 MACRO 0.9259 | F1 MICRO 0.9291
#               precision    recall  f1-score   support
#
#         fuel       0.88      1.00      0.94       187
#      machine       0.91      0.96      0.93       175
#       others       0.86      0.84      0.85       158
#         part       0.87      0.94      0.90       158
#        price       0.96      0.98      0.97       192
#      service       0.93      1.00      0.96       191
#
#    micro avg       0.90      0.96      0.93      1061
#    macro avg       0.90      0.95      0.93      1061
# weighted avg       0.90      0.96      0.93      1061
#  samples avg       0.91      0.96      0.93      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 17.727487564086914 | ACCURACY: 0.8235 | F1 MACRO: 0.7595 | F1 MICRO: 0.8235
# EPOCH 2 | LOSS: 14.523781776428223 | ACCURACY: 0.8778 | F1 MACRO: 0.8479 | F1 MICRO: 0.8778
# EPOCH 3 | LOSS: 13.109131813049316 | ACCURACY: 0.8643 | F1 MACRO: 0.8319 | F1 MICRO: 0.8643
# EPOCH 4 | LOSS: 12.36688232421875 | ACCURACY: 0.8824 | F1 MACRO: 0.8543 | F1 MICRO: 0.8824
# EPOCH 5 | LOSS: 11.29793930053711 | ACCURACY: 0.8824 | F1 MACRO: 0.8528 | F1 MICRO: 0.8824
# EPOCH 6 | LOSS: 11.065682411193848 | ACCURACY: 0.8824 | F1 MACRO: 0.8641 | F1 MICRO: 0.8824
# EPOCH 7 | LOSS: 10.668816566467285 | ACCURACY: 0.8733 | F1 MACRO: 0.8431 | F1 MICRO: 0.8733
# EPOCH 8 | LOSS: 10.434109687805176 | ACCURACY: 0.8914 | F1 MACRO: 0.8668 | F1 MICRO: 0.8914
# EPOCH 9 | LOSS: 9.667438507080078 | ACCURACY: 0.8869 | F1 MACRO: 0.8619 | F1 MICRO: 0.8869
# EPOCH 10 | LOSS: 9.882495880126953 | ACCURACY: 0.8643 | F1 MACRO: 0.8394 | F1 MICRO: 0.8643
# sentiment: ACCURACY 0.8914 | F1 MACRO 0.8668 | F1 MICRO 0.8914
#               precision    recall  f1-score   support
#
#     negative       0.77      0.85      0.81        60
#     positive       0.94      0.91      0.92       161
#
#     accuracy                           0.89       221
#    macro avg       0.86      0.88      0.87       221
# weighted avg       0.90      0.89      0.89       221
#
# --------------------------------------------------
# Iteration 135: Accuracy: 0.8827, F1 Micro: 0.8827, F1 Macro: 0.7427
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.45      0.62        11
#      neutral       0.90      1.00      0.95       181
#     positive       1.00      0.38      0.55        24
#
#     accuracy                           0.90       216
#    macro avg       0.97      0.61      0.71       216
# weighted avg       0.91      0.90      0.88       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.50      0.62        16
#      neutral       0.91      0.95      0.93       167
#     positive       0.62      0.61      0.62        33
#
#     accuracy                           0.86       216
#    macro avg       0.78      0.68      0.72       216
# weighted avg       0.86      0.86      0.86       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.50      0.75      0.60        12
#      neutral       0.89      0.82      0.86       152
#     positive       0.66      0.73      0.69        52
#
#     accuracy                           0.80       216
#    macro avg       0.68      0.77      0.72       216
# weighted avg       0.81      0.80      0.80       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.88      0.61      0.72        23
#      neutral       0.89      0.97      0.93       152
#     positive       0.85      0.68      0.76        41
#
#     accuracy                           0.88       216
#    macro avg       0.87      0.76      0.80       216
# weighted avg       0.88      0.88      0.87       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.90      0.69      0.78        13
#      neutral       0.96      0.98      0.97       186
#     positive       0.69      0.65      0.67        17
#
#     accuracy                           0.94       216
#    macro avg       0.85      0.77      0.81       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.50      0.67        14
#      neutral       0.92      1.00      0.96       185
#     positive       0.86      0.35      0.50        17
#
#     accuracy                           0.92       216
#    macro avg       0.92      0.62      0.71       216
# weighted avg       0.92      0.92      0.90       216
#
# Launching training on 2 GPUs.
# 617 617
# Nearest checkpoint: 540
# Threshold: 87911.2890625
# Samples above threshold: 73
# Acquired samples: 73
# Sampling duration: 9.294573783874512 seconds
# New train size: 208
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.6874215602874756 | ACCURACY: 0.7664 | F1 MACRO: 0.858 | F1 MICRO: 0.8656
# EPOCH 2 | LOSS: 3.262702226638794 | ACCURACY: 0.7954 | F1 MACRO: 0.8835 | F1 MICRO: 0.8851
# EPOCH 3 | LOSS: 2.9711456298828125 | ACCURACY: 0.808 | F1 MACRO: 0.8874 | F1 MICRO: 0.8897
# EPOCH 4 | LOSS: 2.670907974243164 | ACCURACY: 0.8423 | F1 MACRO: 0.9062 | F1 MICRO: 0.9081
# EPOCH 5 | LOSS: 2.5933401584625244 | ACCURACY: 0.8519 | F1 MACRO: 0.9102 | F1 MICRO: 0.912
# EPOCH 6 | LOSS: 2.5710835456848145 | ACCURACY: 0.8765 | F1 MACRO: 0.9232 | F1 MICRO: 0.9252
# EPOCH 7 | LOSS: 2.4888484477996826 | ACCURACY: 0.901 | F1 MACRO: 0.9377 | F1 MICRO: 0.9394
# EPOCH 8 | LOSS: 2.374866485595703 | ACCURACY: 0.9137 | F1 MACRO: 0.945 | F1 MICRO: 0.9466
# EPOCH 9 | LOSS: 2.4530181884765625 | ACCURACY: 0.91 | F1 MACRO: 0.9414 | F1 MICRO: 0.9439
# EPOCH 10 | LOSS: 2.4056591987609863 | ACCURACY: 0.9219 | F1 MACRO: 0.9491 | F1 MICRO: 0.9514
# aspect: ACCURACY 0.9219 | F1 MACRO 0.9491 | F1 MICRO 0.9514
#               precision    recall  f1-score   support
#
#         fuel       0.95      1.00      0.97       187
#      machine       0.93      0.96      0.94       175
#       others       0.88      0.92      0.90       158
#         part       0.93      0.93      0.93       158
#        price       0.97      0.98      0.98       192
#      service       0.95      1.00      0.97       191
#
#    micro avg       0.94      0.97      0.95      1061
#    macro avg       0.93      0.97      0.95      1061
# weighted avg       0.94      0.97      0.95      1061
#  samples avg       0.94      0.97      0.95      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 13.64260196685791 | ACCURACY: 0.8694 | F1 MACRO: 0.8325 | F1 MICRO: 0.8694
# EPOCH 2 | LOSS: 11.219250679016113 | ACCURACY: 0.9224 | F1 MACRO: 0.9084 | F1 MICRO: 0.9224
# EPOCH 3 | LOSS: 9.793525695800781 | ACCURACY: 0.9184 | F1 MACRO: 0.9017 | F1 MICRO: 0.9184
# EPOCH 4 | LOSS: 9.003247261047363 | ACCURACY: 0.898 | F1 MACRO: 0.8812 | F1 MICRO: 0.898
# EPOCH 5 | LOSS: 8.833327293395996 | ACCURACY: 0.902 | F1 MACRO: 0.8871 | F1 MICRO: 0.902
# in second
# EPOCH 6 | LOSS: 7.713102340698242 | ACCURACY: 0.9143 | F1 MACRO: 0.8987 | F1 MICRO: 0.9143
# in second
# EPOCH 7 | LOSS: 7.637383460998535 | ACCURACY: 0.9224 | F1 MACRO: 0.9097 | F1 MICRO: 0.9224
# in second
# EPOCH 8 | LOSS: 7.550515651702881 | ACCURACY: 0.9184 | F1 MACRO: 0.9046 | F1 MICRO: 0.9184
# in second
# EPOCH 9 | LOSS: 7.3737969398498535 | ACCURACY: 0.9224 | F1 MACRO: 0.9097 | F1 MICRO: 0.9224
# in second
# EPOCH 10 | LOSS: 7.413262844085693 | ACCURACY: 0.9224 | F1 MACRO: 0.9097 | F1 MICRO: 0.9224
# sentiment: ACCURACY 0.9224 | F1 MACRO 0.9084 | F1 MICRO 0.9224
#               precision    recall  f1-score   support
#
#     negative       0.83      0.92      0.87        71
#     positive       0.96      0.93      0.94       174
#
#     accuracy                           0.92       245
#    macro avg       0.90      0.92      0.91       245
# weighted avg       0.93      0.92      0.92       245
#
# --------------------------------------------------
# Iteration 208: Accuracy: 0.9167, F1 Micro: 0.9167, F1 Macro: 0.8319
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.73      0.84        11
#      neutral       0.96      1.00      0.98       181
#     positive       1.00      0.83      0.91        24
#
#     accuracy                           0.97       216
#    macro avg       0.99      0.85      0.91       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.76      0.81      0.79        16
#      neutral       0.93      0.95      0.94       167
#     positive       0.79      0.67      0.72        33
#
#     accuracy                           0.90       216
#    macro avg       0.83      0.81      0.82       216
# weighted avg       0.90      0.90      0.90       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.67      0.67      0.67        12
#      neutral       0.88      0.94      0.91       152
#     positive       0.83      0.65      0.73        52
#
#     accuracy                           0.86       216
#    macro avg       0.79      0.75      0.77       216
# weighted avg       0.85      0.86      0.85       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.74      0.79        23
#      neutral       0.94      0.93      0.94       152
#     positive       0.76      0.83      0.79        41
#
#     accuracy                           0.89       216
#    macro avg       0.85      0.83      0.84       216
# weighted avg       0.90      0.89      0.89       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.73      0.85      0.79        13
#      neutral       0.98      0.96      0.97       186
#     positive       0.61      0.65      0.63        17
#
#     accuracy                           0.93       216
#    macro avg       0.77      0.82      0.79       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.64      0.78        14
#      neutral       0.95      1.00      0.97       185
#     positive       1.00      0.71      0.83        17
#
#     accuracy                           0.95       216
#    macro avg       0.98      0.78      0.86       216
# weighted avg       0.96      0.95      0.95       216
#
# Launching training on 2 GPUs.
# 591 591
# Nearest checkpoint: 540
# Threshold: 87568.6484375
# Samples above threshold: 66
# Acquired samples: 66
# Sampling duration: 12.15831208229065 seconds
# New train size: 274
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.3852169513702393 | ACCURACY: 0.7894 | F1 MACRO: 0.8807 | F1 MICRO: 0.8822
# EPOCH 2 | LOSS: 2.9055917263031006 | ACCURACY: 0.8051 | F1 MACRO: 0.8865 | F1 MICRO: 0.8887
# EPOCH 3 | LOSS: 2.6319692134857178 | ACCURACY: 0.8333 | F1 MACRO: 0.9017 | F1 MICRO: 0.9034
# EPOCH 4 | LOSS: 2.377441167831421 | ACCURACY: 0.8676 | F1 MACRO: 0.9198 | F1 MICRO: 0.9211
# EPOCH 5 | LOSS: 2.317870855331421 | ACCURACY: 0.8906 | F1 MACRO: 0.931 | F1 MICRO: 0.9331
# EPOCH 6 | LOSS: 2.2991700172424316 | ACCURACY: 0.9174 | F1 MACRO: 0.9462 | F1 MICRO: 0.9485
# EPOCH 7 | LOSS: 2.255957841873169 | ACCURACY: 0.9256 | F1 MACRO: 0.9509 | F1 MICRO: 0.9536
# EPOCH 8 | LOSS: 2.1975152492523193 | ACCURACY: 0.9256 | F1 MACRO: 0.9513 | F1 MICRO: 0.9536
# EPOCH 9 | LOSS: 2.1199562549591064 | ACCURACY: 0.9368 | F1 MACRO: 0.9586 | F1 MICRO: 0.9605
# EPOCH 10 | LOSS: 2.0625698566436768 | ACCURACY: 0.9412 | F1 MACRO: 0.9612 | F1 MICRO: 0.9632
# aspect: ACCURACY 0.9412 | F1 MACRO 0.9612 | F1 MICRO 0.9632
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.94      0.98      0.96       175
#       others       0.90      0.93      0.91       158
#         part       0.94      0.94      0.94       158
#        price       0.98      0.98      0.98       192
#      service       0.96      1.00      0.98       191
#
#    micro avg       0.95      0.98      0.96      1061
#    macro avg       0.95      0.97      0.96      1061
# weighted avg       0.95      0.98      0.96      1061
#  samples avg       0.95      0.97      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 10.356579780578613 | ACCURACY: 0.9094 | F1 MACRO: 0.8899 | F1 MICRO: 0.9094
# EPOCH 2 | LOSS: 8.062739372253418 | ACCURACY: 0.9173 | F1 MACRO: 0.9063 | F1 MICRO: 0.9173
# EPOCH 3 | LOSS: 7.182474136352539 | ACCURACY: 0.9134 | F1 MACRO: 0.9027 | F1 MICRO: 0.9134
# EPOCH 4 | LOSS: 6.617185592651367 | ACCURACY: 0.937 | F1 MACRO: 0.927 | F1 MICRO: 0.937
# EPOCH 5 | LOSS: 6.417006492614746 | ACCURACY: 0.9331 | F1 MACRO: 0.9211 | F1 MICRO: 0.9331
# EPOCH 6 | LOSS: 5.928160190582275 | ACCURACY: 0.9252 | F1 MACRO: 0.9136 | F1 MICRO: 0.9252
# EPOCH 7 | LOSS: 6.001823902130127 | ACCURACY: 0.937 | F1 MACRO: 0.9265 | F1 MICRO: 0.937
# EPOCH 8 | LOSS: 5.934784412384033 | ACCURACY: 0.937 | F1 MACRO: 0.9275 | F1 MICRO: 0.937
# EPOCH 9 | LOSS: 5.853818893432617 | ACCURACY: 0.937 | F1 MACRO: 0.9231 | F1 MICRO: 0.937
# EPOCH 10 | LOSS: 5.661635398864746 | ACCURACY: 0.9331 | F1 MACRO: 0.9199 | F1 MICRO: 0.9331
# sentiment: ACCURACY 0.937 | F1 MACRO 0.9231 | F1 MICRO 0.937
#               precision    recall  f1-score   support
#
#     negative       0.93      0.86      0.89        76
#     positive       0.94      0.97      0.96       178
#
#     accuracy                           0.94       254
#    macro avg       0.93      0.91      0.92       254
# weighted avg       0.94      0.94      0.94       254
#
# --------------------------------------------------
# Iteration 274: Accuracy: 0.9329, F1 Micro: 0.9329, F1 Macro: 0.8725
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.98      1.00      0.99       181
#     positive       1.00      0.92      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       0.99      0.94      0.97       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.75      0.83        16
#      neutral       0.95      0.95      0.95       167
#     positive       0.69      0.76      0.72        33
#
#     accuracy                           0.91       216
#    macro avg       0.86      0.82      0.83       216
# weighted avg       0.91      0.91      0.91       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.75      0.86        12
#      neutral       0.90      0.93      0.92       152
#     positive       0.78      0.73      0.75        52
#
#     accuracy                           0.88       216
#    macro avg       0.89      0.80      0.84       216
# weighted avg       0.87      0.88      0.87       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.89      0.74      0.81        23
#      neutral       0.94      0.96      0.95       152
#     positive       0.83      0.83      0.83        41
#
#     accuracy                           0.91       216
#    macro avg       0.89      0.84      0.86       216
# weighted avg       0.91      0.91      0.91       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.85      0.85        13
#      neutral       0.98      0.98      0.98       186
#     positive       0.72      0.76      0.74        17
#
#     accuracy                           0.95       216
#    macro avg       0.85      0.86      0.86       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.57      0.73        14
#      neutral       0.96      1.00      0.98       185
#     positive       0.94      0.88      0.91        17
#
#     accuracy                           0.96       216
#    macro avg       0.97      0.82      0.87       216
# weighted avg       0.96      0.96      0.96       216
#
# Launching training on 2 GPUs.
# 551 551
# Nearest checkpoint: 540
# Threshold: 87649.7578125
# Samples above threshold: 59
# Acquired samples: 59
# Sampling duration: 11.540935039520264 seconds
# New train size: 333
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.5494515895843506 | ACCURACY: 0.7902 | F1 MACRO: 0.8811 | F1 MICRO: 0.8826
# EPOCH 2 | LOSS: 2.979344367980957 | ACCURACY: 0.7656 | F1 MACRO: 0.8363 | F1 MICRO: 0.8597
# EPOCH 3 | LOSS: 2.615811824798584 | ACCURACY: 0.8519 | F1 MACRO: 0.9111 | F1 MICRO: 0.9125
# EPOCH 4 | LOSS: 2.4788639545440674 | ACCURACY: 0.8914 | F1 MACRO: 0.9316 | F1 MICRO: 0.9337
# EPOCH 5 | LOSS: 2.382143974304199 | ACCURACY: 0.9137 | F1 MACRO: 0.9407 | F1 MICRO: 0.9454
# EPOCH 6 | LOSS: 2.303203582763672 | ACCURACY: 0.9226 | F1 MACRO: 0.9481 | F1 MICRO: 0.9512
# EPOCH 7 | LOSS: 2.201533317565918 | ACCURACY: 0.9308 | F1 MACRO: 0.9546 | F1 MICRO: 0.9568
# EPOCH 8 | LOSS: 2.1364641189575195 | ACCURACY: 0.9412 | F1 MACRO: 0.9605 | F1 MICRO: 0.963
# EPOCH 9 | LOSS: 2.116433620452881 | ACCURACY: 0.939 | F1 MACRO: 0.9591 | F1 MICRO: 0.9615
# EPOCH 10 | LOSS: 1.9735828638076782 | ACCURACY: 0.939 | F1 MACRO: 0.9579 | F1 MICRO: 0.9614
# aspect: ACCURACY 0.9412 | F1 MACRO 0.9605 | F1 MICRO 0.963
#               precision    recall  f1-score   support
#
#         fuel       0.97      1.00      0.99       187
#      machine       0.94      0.98      0.96       175
#       others       0.94      0.86      0.90       158
#         part       0.94      0.97      0.96       158
#        price       0.98      0.97      0.98       192
#      service       0.97      1.00      0.98       191
#
#    micro avg       0.96      0.97      0.96      1061
#    macro avg       0.96      0.97      0.96      1061
# weighted avg       0.96      0.97      0.96      1061
#  samples avg       0.96      0.97      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 9.00838565826416 | ACCURACY: 0.8817 | F1 MACRO: 0.8514 | F1 MICRO: 0.8817
# EPOCH 2 | LOSS: 7.469325542449951 | ACCURACY: 0.8961 | F1 MACRO: 0.8821 | F1 MICRO: 0.8961
# EPOCH 3 | LOSS: 6.532886981964111 | ACCURACY: 0.9032 | F1 MACRO: 0.8896 | F1 MICRO: 0.9032
# EPOCH 4 | LOSS: 6.042072772979736 | ACCURACY: 0.9068 | F1 MACRO: 0.8907 | F1 MICRO: 0.9068
# EPOCH 5 | LOSS: 5.806571006774902 | ACCURACY: 0.8961 | F1 MACRO: 0.8814 | F1 MICRO: 0.8961
# EPOCH 6 | LOSS: 5.671355724334717 | ACCURACY: 0.9068 | F1 MACRO: 0.8914 | F1 MICRO: 0.9068
# EPOCH 7 | LOSS: 5.612890720367432 | ACCURACY: 0.8853 | F1 MACRO: 0.871 | F1 MICRO: 0.8853
# EPOCH 8 | LOSS: 5.41259765625 | ACCURACY: 0.914 | F1 MACRO: 0.8978 | F1 MICRO: 0.914
# EPOCH 9 | LOSS: 5.242084503173828 | ACCURACY: 0.8853 | F1 MACRO: 0.8703 | F1 MICRO: 0.8853
# EPOCH 10 | LOSS: 5.166199684143066 | ACCURACY: 0.9032 | F1 MACRO: 0.889 | F1 MICRO: 0.9032
# sentiment: ACCURACY 0.914 | F1 MACRO 0.8978 | F1 MICRO 0.914
#               precision    recall  f1-score   support
#
#     negative       0.81      0.91      0.86        79
#     positive       0.96      0.92      0.94       200
#
#     accuracy                           0.91       279
#    macro avg       0.89      0.91      0.90       279
# weighted avg       0.92      0.91      0.92       279
#
# --------------------------------------------------
# Iteration 333: Accuracy: 0.9244, F1 Micro: 0.9244, F1 Macro: 0.8668
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.91      0.91        11
#      neutral       0.98      1.00      0.99       181
#     positive       1.00      0.88      0.93        24
#
#     accuracy                           0.98       216
#    macro avg       0.96      0.93      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.81      0.87        16
#      neutral       0.94      0.97      0.96       167
#     positive       0.77      0.70      0.73        33
#
#     accuracy                           0.92       216
#    macro avg       0.88      0.83      0.85       216
# weighted avg       0.91      0.92      0.91       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.65      0.92      0.76        12
#      neutral       0.92      0.81      0.86       152
#     positive       0.62      0.79      0.69        52
#
#     accuracy                           0.81       216
#    macro avg       0.73      0.84      0.77       216
# weighted avg       0.84      0.81      0.82       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.84      0.91      0.87        23
#      neutral       0.95      0.96      0.95       152
#     positive       0.86      0.78      0.82        41
#
#     accuracy                           0.92       216
#    macro avg       0.88      0.88      0.88       216
# weighted avg       0.92      0.92      0.92       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.71      0.77      0.74        13
#      neutral       0.98      0.97      0.98       186
#     positive       0.74      0.82      0.78        17
#
#     accuracy                           0.94       216
#    macro avg       0.81      0.85      0.83       216
# weighted avg       0.95      0.94      0.95       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.71      0.83        14
#      neutral       0.97      1.00      0.98       185
#     positive       1.00      0.88      0.94        17
#
#     accuracy                           0.97       216
#    macro avg       0.99      0.87      0.92       216
# weighted avg       0.97      0.97      0.97       216
#
# Launching training on 2 GPUs.
# 508 508
# Nearest checkpoint: 540
# Threshold: 87422.203125
# Samples above threshold: 54
# Acquired samples: 54
# Sampling duration: 12.751513004302979 seconds
# New train size: 387
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.4208409786224365 | ACCURACY: 0.7909 | F1 MACRO: 0.8816 | F1 MICRO: 0.8831
# EPOCH 2 | LOSS: 2.8832995891571045 | ACCURACY: 0.8125 | F1 MACRO: 0.8877 | F1 MICRO: 0.8912
# EPOCH 3 | LOSS: 2.5238687992095947 | ACCURACY: 0.8601 | F1 MACRO: 0.9112 | F1 MICRO: 0.9154
# EPOCH 4 | LOSS: 2.41853928565979 | ACCURACY: 0.8891 | F1 MACRO: 0.9216 | F1 MICRO: 0.9299
# EPOCH 5 | LOSS: 2.2942399978637695 | ACCURACY: 0.9375 | F1 MACRO: 0.9596 | F1 MICRO: 0.961
# EPOCH 6 | LOSS: 2.2468700408935547 | ACCURACY: 0.9449 | F1 MACRO: 0.9641 | F1 MICRO: 0.9656
# EPOCH 7 | LOSS: 2.165210247039795 | ACCURACY: 0.9435 | F1 MACRO: 0.962 | F1 MICRO: 0.9644
# EPOCH 8 | LOSS: 2.019663095474243 | ACCURACY: 0.9457 | F1 MACRO: 0.9644 | F1 MICRO: 0.966
# EPOCH 9 | LOSS: 1.9306714534759521 | ACCURACY: 0.942 | F1 MACRO: 0.9595 | F1 MICRO: 0.9631
# EPOCH 10 | LOSS: 1.8702607154846191 | ACCURACY: 0.936 | F1 MACRO: 0.9572 | F1 MICRO: 0.9597
# aspect: ACCURACY 0.9457 | F1 MACRO 0.9644 | F1 MICRO 0.966
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.95      0.97      0.96       175
#       others       0.91      0.94      0.92       158
#         part       0.93      0.97      0.95       158
#        price       0.98      0.97      0.98       192
#      service       0.97      1.00      0.98       191
#
#    micro avg       0.95      0.98      0.97      1061
#    macro avg       0.95      0.98      0.96      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.95      0.98      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 7.144194602966309 | ACCURACY: 0.913 | F1 MACRO: 0.8988 | F1 MICRO: 0.913
# EPOCH 2 | LOSS: 5.763615608215332 | ACCURACY: 0.9289 | F1 MACRO: 0.9183 | F1 MICRO: 0.9289
# EPOCH 3 | LOSS: 5.1738128662109375 | ACCURACY: 0.9289 | F1 MACRO: 0.9203 | F1 MICRO: 0.9289
# EPOCH 4 | LOSS: 4.7109808921813965 | ACCURACY: 0.9249 | F1 MACRO: 0.9161 | F1 MICRO: 0.9249
# EPOCH 5 | LOSS: 4.618810176849365 | ACCURACY: 0.9249 | F1 MACRO: 0.9161 | F1 MICRO: 0.9249
# EPOCH 6 | LOSS: 4.333994388580322 | ACCURACY: 0.913 | F1 MACRO: 0.9047 | F1 MICRO: 0.913
# in second
# EPOCH 7 | LOSS: 4.035943031311035 | ACCURACY: 0.9209 | F1 MACRO: 0.9129 | F1 MICRO: 0.9209
# in second
# EPOCH 8 | LOSS: 3.9718234539031982 | ACCURACY: 0.9209 | F1 MACRO: 0.9129 | F1 MICRO: 0.9209
# in second
# EPOCH 9 | LOSS: 3.9713377952575684 | ACCURACY: 0.9289 | F1 MACRO: 0.9212 | F1 MICRO: 0.9289
# in second
# EPOCH 10 | LOSS: 3.9220378398895264 | ACCURACY: 0.9249 | F1 MACRO: 0.917 | F1 MICRO: 0.9249
# sentiment: ACCURACY 0.9289 | F1 MACRO 0.9203 | F1 MICRO 0.9289
#               precision    recall  f1-score   support
#
#     negative       0.84      0.95      0.89        80
#     positive       0.98      0.92      0.95       173
#
#     accuracy                           0.93       253
#    macro avg       0.91      0.93      0.92       253
# weighted avg       0.93      0.93      0.93       253
#
# --------------------------------------------------
# Iteration 387: Accuracy: 0.9414, F1 Micro: 0.9414, F1 Macro: 0.8859
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.98      1.00      0.99       181
#     positive       1.00      0.92      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       0.99      0.94      0.97       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.82      0.88      0.85        16
#      neutral       0.95      0.96      0.96       167
#     positive       0.83      0.76      0.79        33
#
#     accuracy                           0.93       216
#    macro avg       0.87      0.87      0.87       216
# weighted avg       0.92      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.75      0.75        12
#      neutral       0.91      0.95      0.93       152
#     positive       0.84      0.73      0.78        52
#
#     accuracy                           0.88       216
#    macro avg       0.83      0.81      0.82       216
# weighted avg       0.88      0.88      0.88       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.79      0.83      0.81        23
#      neutral       0.94      0.98      0.96       152
#     positive       0.91      0.76      0.83        41
#
#     accuracy                           0.92       216
#    macro avg       0.88      0.85      0.87       216
# weighted avg       0.92      0.92      0.92       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.92      0.83        13
#      neutral       0.99      0.97      0.98       186
#     positive       0.76      0.76      0.76        17
#
#     accuracy                           0.95       216
#    macro avg       0.83      0.89      0.86       216
# weighted avg       0.96      0.95      0.95       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.97      1.00      0.99       185
#     positive       1.00      0.76      0.87        17
#
#     accuracy                           0.98       216
#    macro avg       0.99      0.90      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Launching training on 2 GPUs.
# 450 450
# Nearest checkpoint: 540
# Threshold: 87431.53125
# Samples above threshold: 48
# Acquired samples: 48
# Sampling duration: 13.414404153823853 seconds
# New train size: 435
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.271211862564087 | ACCURACY: 0.8013 | F1 MACRO: 0.8867 | F1 MICRO: 0.8881
# EPOCH 2 | LOSS: 2.640735149383545 | ACCURACY: 0.8318 | F1 MACRO: 0.9002 | F1 MICRO: 0.9021
# EPOCH 3 | LOSS: 2.399845600128174 | ACCURACY: 0.878 | F1 MACRO: 0.9194 | F1 MICRO: 0.9246
# EPOCH 4 | LOSS: 2.3366291522979736 | ACCURACY: 0.9338 | F1 MACRO: 0.9565 | F1 MICRO: 0.9588
# EPOCH 5 | LOSS: 2.218377113342285 | ACCURACY: 0.9442 | F1 MACRO: 0.9636 | F1 MICRO: 0.9652
# EPOCH 6 | LOSS: 2.1010754108428955 | ACCURACY: 0.9382 | F1 MACRO: 0.9587 | F1 MICRO: 0.9613
# EPOCH 7 | LOSS: 1.9889287948608398 | ACCURACY: 0.9449 | F1 MACRO: 0.9629 | F1 MICRO: 0.9653
# EPOCH 8 | LOSS: 1.8927026987075806 | ACCURACY: 0.9464 | F1 MACRO: 0.9644 | F1 MICRO: 0.9663
# EPOCH 9 | LOSS: 1.830155611038208 | ACCURACY: 0.9501 | F1 MACRO: 0.967 | F1 MICRO: 0.9688
# EPOCH 10 | LOSS: 1.7938694953918457 | ACCURACY: 0.9487 | F1 MACRO: 0.9659 | F1 MICRO: 0.9679
# aspect: ACCURACY 0.9501 | F1 MACRO 0.967 | F1 MICRO 0.9688
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.94      0.98      0.96       175
#       others       0.90      0.94      0.92       158
#         part       0.95      0.96      0.96       158
#        price       0.98      0.99      0.98       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.96      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.96      0.98      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.618873119354248 | ACCURACY: 0.9231 | F1 MACRO: 0.915 | F1 MICRO: 0.9231
# EPOCH 2 | LOSS: 5.1112589836120605 | ACCURACY: 0.9385 | F1 MACRO: 0.9313 | F1 MICRO: 0.9385
# EPOCH 3 | LOSS: 4.633932113647461 | ACCURACY: 0.9346 | F1 MACRO: 0.9272 | F1 MICRO: 0.9346
# EPOCH 4 | LOSS: 4.345383644104004 | ACCURACY: 0.9231 | F1 MACRO: 0.9155 | F1 MICRO: 0.9231
# EPOCH 5 | LOSS: 4.007572174072266 | ACCURACY: 0.9346 | F1 MACRO: 0.925 | F1 MICRO: 0.9346
# in second
# EPOCH 6 | LOSS: 3.6433374881744385 | ACCURACY: 0.9385 | F1 MACRO: 0.9309 | F1 MICRO: 0.9385
# in second
# EPOCH 7 | LOSS: 3.6169445514678955 | ACCURACY: 0.9346 | F1 MACRO: 0.9268 | F1 MICRO: 0.9346
# in second
# EPOCH 8 | LOSS: 3.5726699829101562 | ACCURACY: 0.9462 | F1 MACRO: 0.9392 | F1 MICRO: 0.9462
# in second
# EPOCH 9 | LOSS: 3.543886423110962 | ACCURACY: 0.9462 | F1 MACRO: 0.9392 | F1 MICRO: 0.9462
# in second
# EPOCH 10 | LOSS: 3.476907730102539 | ACCURACY: 0.9462 | F1 MACRO: 0.9392 | F1 MICRO: 0.9462
# sentiment: ACCURACY 0.9385 | F1 MACRO 0.9313 | F1 MICRO 0.9385
#               precision    recall  f1-score   support
#
#     negative       0.86      0.96      0.91        83
#     positive       0.98      0.93      0.95       177
#
#     accuracy                           0.94       260
#    macro avg       0.92      0.95      0.93       260
# weighted avg       0.94      0.94      0.94       260
#
# --------------------------------------------------
# Iteration 435: Accuracy: 0.9452, F1 Micro: 0.9452, F1 Macro: 0.902
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      1.00      0.99       181
#     positive       1.00      0.92      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.97      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.81      0.87        16
#      neutral       0.94      0.98      0.96       167
#     positive       0.86      0.73      0.79        33
#
#     accuracy                           0.93       216
#    macro avg       0.91      0.84      0.87       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.62      0.83      0.71        12
#      neutral       0.92      0.93      0.92       152
#     positive       0.80      0.71      0.76        52
#
#     accuracy                           0.87       216
#    macro avg       0.78      0.82      0.80       216
# weighted avg       0.87      0.87      0.87       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.81      0.96      0.88        23
#      neutral       0.95      0.96      0.96       152
#     positive       0.86      0.76      0.81        41
#
#     accuracy                           0.92       216
#    macro avg       0.88      0.89      0.88       216
# weighted avg       0.92      0.92      0.92       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.92      0.92        13
#      neutral       0.99      0.98      0.99       186
#     positive       0.78      0.82      0.80        17
#
#     accuracy                           0.97       216
#    macro avg       0.90      0.91      0.90       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.99      1.00      0.99       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.96      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 409 409
# Nearest checkpoint: 540
# Threshold: 87493.84375
# Samples above threshold: 43
# Acquired samples: 43
# Sampling duration: 14.128847599029541 seconds
# New train size: 478
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.2399535179138184 | ACCURACY: 0.7909 | F1 MACRO: 0.8816 | F1 MICRO: 0.8831
# EPOCH 2 | LOSS: 2.661626100540161 | ACCURACY: 0.8326 | F1 MACRO: 0.9018 | F1 MICRO: 0.903
# EPOCH 3 | LOSS: 2.3895087242126465 | ACCURACY: 0.8884 | F1 MACRO: 0.9289 | F1 MICRO: 0.9316
# EPOCH 4 | LOSS: 2.290792465209961 | ACCURACY: 0.9234 | F1 MACRO: 0.9498 | F1 MICRO: 0.952
# EPOCH 5 | LOSS: 2.122997999191284 | ACCURACY: 0.9382 | F1 MACRO: 0.9591 | F1 MICRO: 0.9613
# EPOCH 6 | LOSS: 2.0545897483825684 | ACCURACY: 0.9449 | F1 MACRO: 0.9639 | F1 MICRO: 0.9655
# EPOCH 7 | LOSS: 1.9631602764129639 | ACCURACY: 0.942 | F1 MACRO: 0.9613 | F1 MICRO: 0.9634
# EPOCH 8 | LOSS: 1.8761404752731323 | ACCURACY: 0.9464 | F1 MACRO: 0.9636 | F1 MICRO: 0.9661
# EPOCH 9 | LOSS: 1.825993537902832 | ACCURACY: 0.9442 | F1 MACRO: 0.9622 | F1 MICRO: 0.9648
# EPOCH 10 | LOSS: 1.7614887952804565 | ACCURACY: 0.9457 | F1 MACRO: 0.9633 | F1 MICRO: 0.9657
# aspect: ACCURACY 0.9464 | F1 MACRO 0.9636 | F1 MICRO 0.9661
#               precision    recall  f1-score   support
#
#         fuel       0.98      0.99      0.99       187
#      machine       0.95      0.98      0.96       175
#       others       0.94      0.87      0.90       158
#         part       0.93      0.97      0.95       158
#        price       0.98      0.98      0.98       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.96      0.97      0.97      1061
#    macro avg       0.96      0.97      0.96      1061
# weighted avg       0.96      0.97      0.97      1061
#  samples avg       0.96      0.97      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.313939571380615 | ACCURACY: 0.9167 | F1 MACRO: 0.9055 | F1 MICRO: 0.9167
# EPOCH 2 | LOSS: 5.052484512329102 | ACCURACY: 0.9348 | F1 MACRO: 0.924 | F1 MICRO: 0.9348
# EPOCH 3 | LOSS: 4.530797958374023 | ACCURACY: 0.9203 | F1 MACRO: 0.9046 | F1 MICRO: 0.9203
# EPOCH 4 | LOSS: 4.26685094833374 | ACCURACY: 0.9239 | F1 MACRO: 0.9092 | F1 MICRO: 0.9239
# EPOCH 5 | LOSS: 3.9884696006774902 | ACCURACY: 0.913 | F1 MACRO: 0.8952 | F1 MICRO: 0.913
# in second
# EPOCH 6 | LOSS: 3.574984312057495 | ACCURACY: 0.9348 | F1 MACRO: 0.9235 | F1 MICRO: 0.9348
# in second
# EPOCH 7 | LOSS: 3.479978322982788 | ACCURACY: 0.9275 | F1 MACRO: 0.9161 | F1 MICRO: 0.9275
# in second
# EPOCH 8 | LOSS: 3.516930103302002 | ACCURACY: 0.9239 | F1 MACRO: 0.9121 | F1 MICRO: 0.9239
# in second
# sentiment: ACCURACY 0.9348 | F1 MACRO 0.924 | F1 MICRO 0.9348
#               precision    recall  f1-score   support
#
#     negative       0.85      0.95      0.90        81
#     positive       0.98      0.93      0.95       195
#
#     accuracy                           0.93       276
#    macro avg       0.91      0.94      0.92       276
# weighted avg       0.94      0.93      0.94       276
#
# --------------------------------------------------
# Iteration 478: Accuracy: 0.9375, F1 Micro: 0.9375, F1 Macro: 0.8864
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.99      1.00      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.94      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.88      0.90        16
#      neutral       0.96      0.96      0.96       167
#     positive       0.79      0.79      0.79        33
#
#     accuracy                           0.93       216
#    macro avg       0.89      0.88      0.88       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.61      0.92      0.73        12
#      neutral       0.95      0.84      0.89       152
#     positive       0.70      0.85      0.77        52
#
#     accuracy                           0.85       216
#    macro avg       0.75      0.87      0.80       216
# weighted avg       0.87      0.85      0.85       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.87      0.85        23
#      neutral       0.94      0.98      0.96       152
#     positive       0.91      0.76      0.83        41
#
#     accuracy                           0.93       216
#    macro avg       0.90      0.87      0.88       216
# weighted avg       0.93      0.93      0.92       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.77      0.80        13
#      neutral       0.97      0.98      0.98       186
#     positive       0.75      0.71      0.73        17
#
#     accuracy                           0.95       216
#    macro avg       0.85      0.82      0.84       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.98      1.00      0.99       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       0.99      0.93      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 374 374
# Nearest checkpoint: 540
# Threshold: 87623.1953125
# Samples above threshold: 39
# Acquired samples: 39
# Sampling duration: 14.791813373565674 seconds
# New train size: 517
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.319915294647217 | ACCURACY: 0.7946 | F1 MACRO: 0.8795 | F1 MICRO: 0.8826
# EPOCH 2 | LOSS: 2.6063668727874756 | ACCURACY: 0.8356 | F1 MACRO: 0.9005 | F1 MICRO: 0.9031
# EPOCH 3 | LOSS: 2.395963430404663 | ACCURACY: 0.907 | F1 MACRO: 0.9393 | F1 MICRO: 0.9422
# EPOCH 4 | LOSS: 2.3130595684051514 | ACCURACY: 0.933 | F1 MACRO: 0.9566 | F1 MICRO: 0.9583
# EPOCH 5 | LOSS: 2.129304885864258 | ACCURACY: 0.942 | F1 MACRO: 0.9628 | F1 MICRO: 0.9639
# EPOCH 6 | LOSS: 2.05548095703125 | ACCURACY: 0.9487 | F1 MACRO: 0.9656 | F1 MICRO: 0.9678
# EPOCH 7 | LOSS: 1.937248706817627 | ACCURACY: 0.939 | F1 MACRO: 0.9595 | F1 MICRO: 0.9618
# EPOCH 8 | LOSS: 1.8521087169647217 | ACCURACY: 0.9427 | F1 MACRO: 0.9606 | F1 MICRO: 0.9638
# EPOCH 9 | LOSS: 1.8035989999771118 | ACCURACY: 0.9487 | F1 MACRO: 0.9646 | F1 MICRO: 0.9675
# in second
# EPOCH 10 | LOSS: 1.7401679754257202 | ACCURACY: 0.8921 | F1 MACRO: 0.9345 | F1 MICRO: 0.9352
# ...
#    macro avg       0.97      0.98      0.98      1061
# weighted avg       0.97      0.98      0.98      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.7405247688293457 | ACCURACY: 0.9071 | F1 MACRO: 0.898 | F1 MICRO: 0.9071
# EPOCH 2 | LOSS: 2.826260566711426 | ACCURACY: 0.9257 | F1 MACRO: 0.9178 | F1 MICRO: 0.9257
# EPOCH 3 | LOSS: 2.551950216293335 | ACCURACY: 0.9331 | F1 MACRO: 0.9257 | F1 MICRO: 0.9331
# EPOCH 4 | LOSS: 2.31601619720459 | ACCURACY: 0.9294 | F1 MACRO: 0.9213 | F1 MICRO: 0.9294
# EPOCH 5 | LOSS: 2.200176477432251 | ACCURACY: 0.9405 | F1 MACRO: 0.9328 | F1 MICRO: 0.9405
# EPOCH 6 | LOSS: 2.1161105632781982 | ACCURACY: 0.9368 | F1 MACRO: 0.928 | F1 MICRO: 0.9368
# EPOCH 7 | LOSS: 2.100522756576538 | ACCURACY: 0.9405 | F1 MACRO: 0.9336 | F1 MICRO: 0.9405
# EPOCH 8 | LOSS: 2.035637617111206 | ACCURACY: 0.9368 | F1 MACRO: 0.928 | F1 MICRO: 0.9368
# EPOCH 9 | LOSS: 1.9986510276794434 | ACCURACY: 0.9405 | F1 MACRO: 0.932 | F1 MICRO: 0.9405
# EPOCH 10 | LOSS: 1.9863462448120117 | ACCURACY: 0.9368 | F1 MACRO: 0.9292 | F1 MICRO: 0.9368
# sentiment: ACCURACY 0.9405 | F1 MACRO 0.932 | F1 MICRO 0.9405
#               precision    recall  f1-score   support
#
#     negative       0.90      0.92      0.91        86
#     positive       0.96      0.95      0.96       183
#
#     accuracy                           0.94       269
#    macro avg       0.93      0.93      0.93       269
# weighted avg       0.94      0.94      0.94       269
#
# --------------------------------------------------
# Iteration 831: Accuracy: 0.9529, F1 Micro: 0.9529, F1 Macro: 0.9073
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.82      0.90        11
#      neutral       0.99      1.00      0.99       181
#     positive       0.92      0.92      0.92        24
#
#     accuracy                           0.98       216
#    macro avg       0.97      0.91      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.75      0.83        16
#      neutral       0.95      0.98      0.96       167
#     positive       0.80      0.73      0.76        33
#
#     accuracy                           0.93       216
#    macro avg       0.89      0.82      0.85       216
# weighted avg       0.92      0.93      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.77      0.83      0.80        12
#      neutral       0.97      0.91      0.94       152
#     positive       0.75      0.87      0.80        52
#
#     accuracy                           0.89       216
#    macro avg       0.83      0.87      0.85       216
# weighted avg       0.90      0.89      0.90       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.81      0.96      0.88        23
#      neutral       0.96      0.98      0.97       152
#     positive       0.94      0.78      0.85        41
#
#     accuracy                           0.94       216
#    macro avg       0.91      0.91      0.90       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.92      0.89        13
#      neutral       0.99      1.00      0.99       186
#     positive       0.93      0.76      0.84        17
#
#     accuracy                           0.98       216
#    macro avg       0.93      0.90      0.91       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        14
#      neutral       1.00      1.00      1.00       185
#     positive       1.00      1.00      1.00        17
#
#     accuracy                           1.00       216
#    macro avg       1.00      1.00      1.00       216
# weighted avg       1.00      1.00      1.00       216
#
# Launching training on 2 GPUs.
# 33 33
# Nearest checkpoint: 864
# Threshold: 88203.078125
# Samples above threshold: 4
# Acquired samples: 25
# Sampling duration: 19.575546503067017 seconds
# New train size: 856
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.9041969776153564 | ACCURACY: 0.8244 | F1 MACRO: 0.8945 | F1 MICRO: 0.8976
# EPOCH 2 | LOSS: 2.3383305072784424 | ACCURACY: 0.9263 | F1 MACRO: 0.952 | F1 MICRO: 0.9542
# EPOCH 3 | LOSS: 2.15971040725708 | ACCURACY: 0.9531 | F1 MACRO: 0.969 | F1 MICRO: 0.9707
# EPOCH 4 | LOSS: 1.983439564704895 | ACCURACY: 0.9524 | F1 MACRO: 0.9682 | F1 MICRO: 0.97
# EPOCH 5 | LOSS: 1.8643782138824463 | ACCURACY: 0.9554 | F1 MACRO: 0.9695 | F1 MICRO: 0.9718
# EPOCH 6 | LOSS: 1.7660719156265259 | ACCURACY: 0.9509 | F1 MACRO: 0.9676 | F1 MICRO: 0.9691
# EPOCH 7 | LOSS: 1.7113778591156006 | ACCURACY: 0.9576 | F1 MACRO: 0.9719 | F1 MICRO: 0.9734
# EPOCH 8 | LOSS: 1.6440391540527344 | ACCURACY: 0.9546 | F1 MACRO: 0.9691 | F1 MICRO: 0.9713
# EPOCH 9 | LOSS: 1.6080176830291748 | ACCURACY: 0.9554 | F1 MACRO: 0.9705 | F1 MICRO: 0.9719
# EPOCH 10 | LOSS: 1.5666272640228271 | ACCURACY: 0.9576 | F1 MACRO: 0.9715 | F1 MICRO: 0.9732
# aspect: ACCURACY 0.9576 | F1 MACRO 0.9719 | F1 MICRO 0.9734
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.93      0.99      0.96       175
#       others       0.92      0.93      0.92       158
#         part       0.97      0.97      0.97       158
#        price       0.99      0.99      0.99       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.96      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.708294153213501 | ACCURACY: 0.9137 | F1 MACRO: 0.9024 | F1 MICRO: 0.9137
# EPOCH 2 | LOSS: 2.8391900062561035 | ACCURACY: 0.9333 | F1 MACRO: 0.9268 | F1 MICRO: 0.9333
# EPOCH 3 | LOSS: 2.4249861240386963 | ACCURACY: 0.9294 | F1 MACRO: 0.9223 | F1 MICRO: 0.9294
# EPOCH 4 | LOSS: 2.340153217315674 | ACCURACY: 0.9412 | F1 MACRO: 0.9344 | F1 MICRO: 0.9412
# EPOCH 5 | LOSS: 2.145230293273926 | ACCURACY: 0.9451 | F1 MACRO: 0.9382 | F1 MICRO: 0.9451
# EPOCH 6 | LOSS: 2.0797057151794434 | ACCURACY: 0.9451 | F1 MACRO: 0.9382 | F1 MICRO: 0.9451
# EPOCH 7 | LOSS: 2.0548412799835205 | ACCURACY: 0.9294 | F1 MACRO: 0.9227 | F1 MICRO: 0.9294
# EPOCH 8 | LOSS: 2.0236399173736572 | ACCURACY: 0.9373 | F1 MACRO: 0.931 | F1 MICRO: 0.9373
# EPOCH 9 | LOSS: 2.0602283477783203 | ACCURACY: 0.9255 | F1 MACRO: 0.9186 | F1 MICRO: 0.9255
# in second
# EPOCH 10 | LOSS: 1.9048079252243042 | ACCURACY: 0.9176 | F1 MACRO: 0.9105 | F1 MICRO: 0.9176
# sentiment: ACCURACY 0.9451 | F1 MACRO 0.9382 | F1 MICRO 0.9451
#               precision    recall  f1-score   support
#
#     negative       0.90      0.94      0.92        83
#     positive       0.97      0.95      0.96       172
#
#     accuracy                           0.95       255
#    macro avg       0.93      0.94      0.94       255
# weighted avg       0.95      0.95      0.95       255
#
# --------------------------------------------------
# Iteration 856: Accuracy: 0.9529, F1 Micro: 0.9529, F1 Macro: 0.9033
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.92      1.00      0.96        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.95      0.88      0.91        24
#
#     accuracy                           0.98       216
#    macro avg       0.95      0.96      0.95       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.81      0.84        16
#      neutral       0.94      0.99      0.96       167
#     positive       0.88      0.70      0.78        33
#
#     accuracy                           0.93       216
#    macro avg       0.90      0.83      0.86       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.69      0.75      0.72        12
#      neutral       0.92      0.95      0.93       152
#     positive       0.85      0.75      0.80        52
#
#     accuracy                           0.89       216
#    macro avg       0.82      0.82      0.82       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.81      0.96      0.88        23
#      neutral       0.98      0.98      0.98       152
#     positive       0.92      0.83      0.87        41
#
#     accuracy                           0.95       216
#    macro avg       0.90      0.92      0.91       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.85      0.85        13
#      neutral       0.98      1.00      0.99       186
#     positive       0.92      0.71      0.80        17
#
#     accuracy                           0.97       216
#    macro avg       0.92      0.85      0.88       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        14
#      neutral       1.00      1.00      1.00       185
#     positive       1.00      1.00      1.00        17
#
#     accuracy                           1.00       216
#    macro avg       1.00      1.00      1.00       216
# weighted avg       1.00      1.00      1.00       216
#
# Launching training on 2 GPUs.
# 8 8
# Nearest checkpoint: 864
# Threshold: 88261.59375
# Samples above threshold: 1
# Acquired samples: 8
# Sampling duration: 20.07633662223816 seconds
# New train size: 864
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.944631576538086 | ACCURACY: 0.8207 | F1 MACRO: 0.896 | F1 MICRO: 0.8975
# EPOCH 2 | LOSS: 2.3285555839538574 | ACCURACY: 0.9345 | F1 MACRO: 0.9576 | F1 MICRO: 0.9594
# EPOCH 3 | LOSS: 2.1578097343444824 | ACCURACY: 0.9531 | F1 MACRO: 0.9694 | F1 MICRO: 0.9709
# EPOCH 4 | LOSS: 1.9996709823608398 | ACCURACY: 0.9591 | F1 MACRO: 0.9737 | F1 MICRO: 0.9745
# EPOCH 5 | LOSS: 1.8579329252243042 | ACCURACY: 0.9621 | F1 MACRO: 0.9749 | F1 MICRO: 0.9761
# EPOCH 6 | LOSS: 1.738457441329956 | ACCURACY: 0.9554 | F1 MACRO: 0.9699 | F1 MICRO: 0.9718
# EPOCH 7 | LOSS: 1.6792716979980469 | ACCURACY: 0.9524 | F1 MACRO: 0.9674 | F1 MICRO: 0.97
# EPOCH 8 | LOSS: 1.6421780586242676 | ACCURACY: 0.9554 | F1 MACRO: 0.9702 | F1 MICRO: 0.9719
# in second
# EPOCH 9 | LOSS: 1.5650575160980225 | ACCURACY: 0.9546 | F1 MACRO: 0.9706 | F1 MICRO: 0.9718
# in second
# EPOCH 10 | LOSS: 1.5186561346054077 | ACCURACY: 0.9613 | F1 MACRO: 0.9747 | F1 MICRO: 0.9758
# aspect: ACCURACY 0.9621 | F1 MACRO 0.9749 | F1 MICRO 0.9761
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.95      0.98      0.96       175
#       others       0.94      0.96      0.95       158
#         part       0.98      0.96      0.97       158
#        price       0.98      0.99      0.99       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.97      0.98      0.98      1061
#    macro avg       0.97      0.98      0.97      1061
# weighted avg       0.97      0.98      0.98      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.554063558578491 | ACCURACY: 0.9436 | F1 MACRO: 0.9345 | F1 MICRO: 0.9436
# EPOCH 2 | LOSS: 2.7125394344329834 | ACCURACY: 0.9436 | F1 MACRO: 0.9345 | F1 MICRO: 0.9436
# EPOCH 3 | LOSS: 2.4155609607696533 | ACCURACY: 0.9549 | F1 MACRO: 0.9481 | F1 MICRO: 0.9549
# EPOCH 4 | LOSS: 2.316171169281006 | ACCURACY: 0.9361 | F1 MACRO: 0.9272 | F1 MICRO: 0.9361
# EPOCH 5 | LOSS: 2.1790571212768555 | ACCURACY: 0.9323 | F1 MACRO: 0.9231 | F1 MICRO: 0.9323
# EPOCH 6 | LOSS: 2.0553224086761475 | ACCURACY: 0.9286 | F1 MACRO: 0.9176 | F1 MICRO: 0.9286
# in second
# EPOCH 7 | LOSS: 1.9105297327041626 | ACCURACY: 0.9511 | F1 MACRO: 0.9443 | F1 MICRO: 0.9511
# in second
# EPOCH 8 | LOSS: 1.8712353706359863 | ACCURACY: 0.9398 | F1 MACRO: 0.9321 | F1 MICRO: 0.9398
# in second
# EPOCH 9 | LOSS: 1.84971022605896 | ACCURACY: 0.9436 | F1 MACRO: 0.9361 | F1 MICRO: 0.9436
# in second
# EPOCH 10 | LOSS: 1.869681715965271 | ACCURACY: 0.9511 | F1 MACRO: 0.9443 | F1 MICRO: 0.9511
# sentiment: ACCURACY 0.9549 | F1 MACRO 0.9481 | F1 MICRO 0.9549
#               precision    recall  f1-score   support
#
#     negative       0.90      0.96      0.93        82
#     positive       0.98      0.95      0.97       184
#
#     accuracy                           0.95       266
#    macro avg       0.94      0.96      0.95       266
# weighted avg       0.96      0.95      0.96       266
#
# --------------------------------------------------
# Iteration 864: Accuracy: 0.9514, F1 Micro: 0.9514, F1 Macro: 0.9067
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      1.00      0.99       181
#     positive       1.00      0.92      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.97      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.81      0.84        16
#      neutral       0.95      0.97      0.96       167
#     positive       0.84      0.79      0.81        33
#
#     accuracy                           0.93       216
#    macro avg       0.89      0.86      0.87       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.75      0.75        12
#      neutral       0.93      0.93      0.93       152
#     positive       0.82      0.81      0.82        52
#
#     accuracy                           0.89       216
#    macro avg       0.83      0.83      0.83       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.77      1.00      0.87        23
#      neutral       0.98      0.96      0.97       152
#     positive       0.89      0.80      0.85        41
#
#     accuracy                           0.94       216
#    macro avg       0.88      0.92      0.89       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.85      0.85        13
#      neutral       0.98      0.99      0.99       186
#     positive       0.87      0.76      0.81        17
#
#     accuracy                           0.97       216
#    macro avg       0.90      0.87      0.88       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.99      1.00      0.99       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.96      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Total sampling time: 362.63 seconds
# Total runtime: 2851.3469684123993 seconds

# %% [markdown]
# ## RUN 3

# %%
active_learning(seeds[2], 2)
# Out:
# ===============================================
# TRIAL 3
# Random seed: 14
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.5870654582977295 | ACCURACY: 0.7448 | F1 MACRO: 0.8463 | F1 MICRO: 0.8498
# EPOCH 2 | LOSS: 3.536916494369507 | ACCURACY: 0.7812 | F1 MACRO: 0.8738 | F1 MICRO: 0.8763
# EPOCH 3 | LOSS: 3.41666316986084 | ACCURACY: 0.7857 | F1 MACRO: 0.8774 | F1 MICRO: 0.8795
# EPOCH 4 | LOSS: 3.3116543292999268 | ACCURACY: 0.7879 | F1 MACRO: 0.8792 | F1 MICRO: 0.881
# EPOCH 5 | LOSS: 3.2140653133392334 | ACCURACY: 0.7894 | F1 MACRO: 0.8788 | F1 MICRO: 0.881
# EPOCH 6 | LOSS: 3.2702386379241943 | ACCURACY: 0.7902 | F1 MACRO: 0.878 | F1 MICRO: 0.8806
# EPOCH 7 | LOSS: 3.0499675273895264 | ACCURACY: 0.7887 | F1 MACRO: 0.8742 | F1 MICRO: 0.8783
# EPOCH 8 | LOSS: 3.18894100189209 | ACCURACY: 0.7783 | F1 MACRO: 0.8648 | F1 MICRO: 0.8711
# in second
# EPOCH 9 | LOSS: 3.1297123432159424 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# in second
# EPOCH 10 | LOSS: 3.0261359214782715 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# aspect: ACCURACY 0.7894 | F1 MACRO 0.8788 | F1 MICRO 0.881
#               precision    recall  f1-score   support
#
#         fuel       0.83      1.00      0.91       187
#      machine       0.78      1.00      0.88       175
#       others       0.71      0.93      0.80       158
#         part       0.73      0.99      0.84       158
#        price       0.86      1.00      0.92       192
#      service       0.85      1.00      0.92       191
#
#    micro avg       0.80      0.99      0.88      1061
#    macro avg       0.79      0.99      0.88      1061
# weighted avg       0.80      0.99      0.88      1061
#  samples avg       0.80      0.99      0.88      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.530926704406738 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# EPOCH 2 | LOSS: 5.93828010559082 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# EPOCH 3 | LOSS: 5.120326995849609 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# EPOCH 4 | LOSS: 4.854779243469238 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# EPOCH 5 | LOSS: 4.772058963775635 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# EPOCH 6 | LOSS: 4.72989559173584 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# EPOCH 7 | LOSS: 4.586083889007568 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# EPOCH 8 | LOSS: 4.799030303955078 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# EPOCH 9 | LOSS: 4.7115044593811035 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# EPOCH 10 | LOSS: 5.037998676300049 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# sentiment: ACCURACY 0.95 | F1 MACRO 0.4872 | F1 MICRO 0.95
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00         1
#     positive       0.95      1.00      0.97        19
#
#     accuracy                           0.95        20
#    macro avg       0.47      0.50      0.49        20
# weighted avg       0.90      0.95      0.93        20
#
# --------------------------------------------------
# Iteration 54: Accuracy: 0.7917, F1 Micro: 0.7917, F1 Macro: 0.3167
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        11
#      neutral       0.84      1.00      0.91       181
#     positive       0.00      0.00      0.00        24
#
#     accuracy                           0.84       216
#    macro avg       0.28      0.33      0.30       216
# weighted avg       0.70      0.84      0.76       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        16
#      neutral       0.77      1.00      0.87       167
#     positive       0.00      0.00      0.00        33
#
#     accuracy                           0.77       216
#    macro avg       0.26      0.33      0.29       216
# weighted avg       0.60      0.77      0.67       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        12
#      neutral       0.71      0.95      0.81       152
#     positive       0.31      0.08      0.12        52
#
#     accuracy                           0.69       216
#    macro avg       0.34      0.34      0.31       216
# weighted avg       0.57      0.69      0.60       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        23
#      neutral       0.73      1.00      0.84       152
#     positive       1.00      0.17      0.29        41
#
#     accuracy                           0.74       216
#    macro avg       0.58      0.39      0.38       216
# weighted avg       0.70      0.74      0.65       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        13
#      neutral       0.86      1.00      0.93       186
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.86       216
#    macro avg       0.29      0.33      0.31       216
# weighted avg       0.74      0.86      0.80       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        14
#      neutral       0.86      1.00      0.92       185
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.86       216
#    macro avg       0.29      0.33      0.31       216
# weighted avg       0.73      0.86      0.79       216
#
# Launching training on 2 GPUs.
# 91 91
# Nearest checkpoint: 540
# Threshold: 87312.4140625
# Samples above threshold: 81
# Acquired samples: 81
# Sampling duration: 6.201587915420532 seconds
# New train size: 135
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 4.004424571990967 | ACCURACY: 0.7693 | F1 MACRO: 0.8608 | F1 MICRO: 0.8671
# EPOCH 2 | LOSS: 3.5355608463287354 | ACCURACY: 0.7946 | F1 MACRO: 0.883 | F1 MICRO: 0.8846
# EPOCH 3 | LOSS: 3.4778714179992676 | ACCURACY: 0.7969 | F1 MACRO: 0.8799 | F1 MICRO: 0.8834
# EPOCH 4 | LOSS: 3.1904847621917725 | ACCURACY: 0.7902 | F1 MACRO: 0.8702 | F1 MICRO: 0.8766
# EPOCH 5 | LOSS: 2.978048324584961 | ACCURACY: 0.8155 | F1 MACRO: 0.8891 | F1 MICRO: 0.892
# EPOCH 6 | LOSS: 2.892927885055542 | ACCURACY: 0.8251 | F1 MACRO: 0.8916 | F1 MICRO: 0.8963
# EPOCH 7 | LOSS: 2.9106874465942383 | ACCURACY: 0.8415 | F1 MACRO: 0.9018 | F1 MICRO: 0.9057
# EPOCH 8 | LOSS: 2.830986499786377 | ACCURACY: 0.8616 | F1 MACRO: 0.9121 | F1 MICRO: 0.9165
# EPOCH 9 | LOSS: 2.746617555618286 | ACCURACY: 0.878 | F1 MACRO: 0.9222 | F1 MICRO: 0.9257
# EPOCH 10 | LOSS: 2.7063376903533936 | ACCURACY: 0.8802 | F1 MACRO: 0.9225 | F1 MICRO: 0.9269
# aspect: ACCURACY 0.8802 | F1 MACRO 0.9225 | F1 MICRO 0.9269
#               precision    recall  f1-score   support
#
#         fuel       0.94      1.00      0.97       187
#      machine       0.83      1.00      0.90       175
#       others       0.87      0.81      0.84       158
#         part       0.83      0.94      0.88       158
#        price       0.95      1.00      0.97       192
#      service       0.94      0.99      0.97       191
#
#    micro avg       0.89      0.96      0.93      1061
#    macro avg       0.89      0.96      0.92      1061
# weighted avg       0.90      0.96      0.93      1061
#  samples avg       0.90      0.96      0.92      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 16.72056770324707 | ACCURACY: 0.7665 | F1 MACRO: 0.4904 | F1 MICRO: 0.7665
# EPOCH 2 | LOSS: 14.581924438476562 | ACCURACY: 0.9086 | F1 MACRO: 0.8852 | F1 MICRO: 0.9086
# EPOCH 3 | LOSS: 12.500737190246582 | ACCURACY: 0.9137 | F1 MACRO: 0.8804 | F1 MICRO: 0.9137
# EPOCH 4 | LOSS: 11.585431098937988 | ACCURACY: 0.9289 | F1 MACRO: 0.9086 | F1 MICRO: 0.9289
# EPOCH 5 | LOSS: 11.083793640136719 | ACCURACY: 0.934 | F1 MACRO: 0.9135 | F1 MICRO: 0.934
# EPOCH 6 | LOSS: 10.730295181274414 | ACCURACY: 0.9289 | F1 MACRO: 0.9086 | F1 MICRO: 0.9289
# EPOCH 7 | LOSS: 9.891963005065918 | ACCURACY: 0.9239 | F1 MACRO: 0.9026 | F1 MICRO: 0.9239
# EPOCH 8 | LOSS: 9.449169158935547 | ACCURACY: 0.9289 | F1 MACRO: 0.9074 | F1 MICRO: 0.9289
# in second
# EPOCH 9 | LOSS: 8.837825775146484 | ACCURACY: 0.934 | F1 MACRO: 0.9135 | F1 MICRO: 0.934
# in second
# EPOCH 10 | LOSS: 8.696743965148926 | ACCURACY: 0.9391 | F1 MACRO: 0.9206 | F1 MICRO: 0.9391
# sentiment: ACCURACY 0.934 | F1 MACRO 0.9135 | F1 MICRO 0.934
#               precision    recall  f1-score   support
#
#     negative       0.85      0.90      0.87        49
#     positive       0.97      0.95      0.96       148
#
#     accuracy                           0.93       197
#    macro avg       0.91      0.92      0.91       197
# weighted avg       0.94      0.93      0.93       197
#
# --------------------------------------------------
# Iteration 135: Accuracy: 0.8812, F1 Micro: 0.8812, F1 Macro: 0.7342
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.91      0.91        11
#      neutral       0.95      0.99      0.97       181
#     positive       1.00      0.62      0.77        24
#
#     accuracy                           0.95       216
#    macro avg       0.95      0.84      0.88       216
# weighted avg       0.95      0.95      0.94       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        16
#      neutral       0.81      1.00      0.89       167
#     positive       0.89      0.24      0.38        33
#
#     accuracy                           0.81       216
#    macro avg       0.57      0.41      0.42       216
# weighted avg       0.76      0.81      0.75       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.71      0.42      0.53        12
#      neutral       0.89      0.81      0.85       152
#     positive       0.62      0.85      0.72        52
#
#     accuracy                           0.80       216
#    macro avg       0.74      0.69      0.70       216
# weighted avg       0.82      0.80      0.80       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.81      0.57      0.67        23
#      neutral       0.83      0.96      0.89       152
#     positive       0.84      0.51      0.64        41
#
#     accuracy                           0.83       216
#    macro avg       0.83      0.68      0.73       216
# weighted avg       0.83      0.83      0.82       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.54      0.70        13
#      neutral       0.95      1.00      0.98       186
#     positive       0.86      0.71      0.77        17
#
#     accuracy                           0.95       216
#    macro avg       0.94      0.75      0.82       216
# weighted avg       0.95      0.95      0.94       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.71      0.80        14
#      neutral       0.95      0.99      0.97       185
#     positive       1.00      0.65      0.79        17
#
#     accuracy                           0.95       216
#    macro avg       0.95      0.79      0.85       216
# weighted avg       0.95      0.95      0.95       216
#
# Launching training on 2 GPUs.
# 574 574
# Nearest checkpoint: 540
# Threshold: 87206.296875
# Samples above threshold: 73
# Acquired samples: 73
# Sampling duration: 9.227976560592651 seconds
# New train size: 208
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.7084004878997803 | ACCURACY: 0.7917 | F1 MACRO: 0.8817 | F1 MICRO: 0.8832
# EPOCH 2 | LOSS: 3.3938605785369873 | ACCURACY: 0.8028 | F1 MACRO: 0.8858 | F1 MICRO: 0.8879
# EPOCH 3 | LOSS: 3.0198256969451904 | ACCURACY: 0.8065 | F1 MACRO: 0.8884 | F1 MICRO: 0.8896
# EPOCH 4 | LOSS: 2.84250545501709 | ACCURACY: 0.8408 | F1 MACRO: 0.9035 | F1 MICRO: 0.9057
# EPOCH 5 | LOSS: 2.7825562953948975 | ACCURACY: 0.8594 | F1 MACRO: 0.9149 | F1 MICRO: 0.9168
# EPOCH 6 | LOSS: 2.695394515991211 | ACCURACY: 0.8929 | F1 MACRO: 0.9326 | F1 MICRO: 0.9349
# EPOCH 7 | LOSS: 2.6902196407318115 | ACCURACY: 0.8996 | F1 MACRO: 0.9342 | F1 MICRO: 0.9376
# EPOCH 8 | LOSS: 2.669940233230591 | ACCURACY: 0.9107 | F1 MACRO: 0.9423 | F1 MICRO: 0.9449
# EPOCH 9 | LOSS: 2.502408027648926 | ACCURACY: 0.9182 | F1 MACRO: 0.9472 | F1 MICRO: 0.9496
# EPOCH 10 | LOSS: 2.4031434059143066 | ACCURACY: 0.9226 | F1 MACRO: 0.9503 | F1 MICRO: 0.9522
# aspect: ACCURACY 0.9226 | F1 MACRO 0.9503 | F1 MICRO 0.9522
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.87      0.99      0.93       175
#       others       0.89      0.93      0.91       158
#         part       0.94      0.93      0.93       158
#        price       0.96      0.99      0.98       192
#      service       0.94      1.00      0.97       191
#
#    micro avg       0.93      0.98      0.95      1061
#    macro avg       0.93      0.97      0.95      1061
# weighted avg       0.93      0.98      0.95      1061
#  samples avg       0.93      0.98      0.95      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 13.401007652282715 | ACCURACY: 0.8841 | F1 MACRO: 0.858 | F1 MICRO: 0.8841
# EPOCH 2 | LOSS: 11.347734451293945 | ACCURACY: 0.9442 | F1 MACRO: 0.9316 | F1 MICRO: 0.9442
# EPOCH 3 | LOSS: 9.259416580200195 | ACCURACY: 0.9313 | F1 MACRO: 0.9183 | F1 MICRO: 0.9313
# EPOCH 4 | LOSS: 8.689702033996582 | ACCURACY: 0.9442 | F1 MACRO: 0.9328 | F1 MICRO: 0.9442
# EPOCH 5 | LOSS: 8.115523338317871 | ACCURACY: 0.9356 | F1 MACRO: 0.9188 | F1 MICRO: 0.9356
# EPOCH 6 | LOSS: 7.901813983917236 | ACCURACY: 0.9313 | F1 MACRO: 0.9112 | F1 MICRO: 0.9313
# EPOCH 7 | LOSS: 7.583729267120361 | ACCURACY: 0.9227 | F1 MACRO: 0.9001 | F1 MICRO: 0.9227
# in second
# EPOCH 8 | LOSS: 7.224335670471191 | ACCURACY: 0.9399 | F1 MACRO: 0.9239 | F1 MICRO: 0.9399
# in second
# EPOCH 9 | LOSS: 6.935152053833008 | ACCURACY: 0.9442 | F1 MACRO: 0.9296 | F1 MICRO: 0.9442
# in second
# EPOCH 10 | LOSS: 6.895196437835693 | ACCURACY: 0.9442 | F1 MACRO: 0.9296 | F1 MICRO: 0.9442
# sentiment: ACCURACY 0.9442 | F1 MACRO 0.9328 | F1 MICRO 0.9442
#               precision    recall  f1-score   support
#
#     negative       0.86      0.95      0.91        65
#     positive       0.98      0.94      0.96       168
#
#     accuracy                           0.94       233
#    macro avg       0.92      0.95      0.93       233
# weighted avg       0.95      0.94      0.95       233
#
# --------------------------------------------------
# Iteration 208: Accuracy: 0.9205, F1 Micro: 0.9205, F1 Macro: 0.8344
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.98      1.00      0.99       181
#     positive       1.00      0.92      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       0.99      0.94      0.97       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.89      0.50      0.64        16
#      neutral       0.87      0.99      0.93       167
#     positive       0.83      0.45      0.59        33
#
#     accuracy                           0.87       216
#    macro avg       0.87      0.65      0.72       216
# weighted avg       0.87      0.87      0.85       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.42      0.56        12
#      neutral       0.90      0.90      0.90       152
#     positive       0.74      0.81      0.77        52
#
#     accuracy                           0.85       216
#    macro avg       0.82      0.71      0.74       216
# weighted avg       0.85      0.85      0.85       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.78      0.91      0.84        23
#      neutral       0.94      0.94      0.94       152
#     positive       0.86      0.78      0.82        41
#
#     accuracy                           0.91       216
#    macro avg       0.86      0.88      0.87       216
# weighted avg       0.91      0.91      0.91       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.89      0.62      0.73        13
#      neutral       0.96      0.99      0.97       186
#     positive       0.80      0.71      0.75        17
#
#     accuracy                           0.94       216
#    macro avg       0.88      0.77      0.82       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.79      0.88        14
#      neutral       0.96      1.00      0.98       185
#     positive       1.00      0.71      0.83        17
#
#     accuracy                           0.96       216
#    macro avg       0.99      0.83      0.90       216
# weighted avg       0.96      0.96      0.96       216
#
# Launching training on 2 GPUs.
# 579 579
# Nearest checkpoint: 540
# Threshold: 87568.6484375
# Samples above threshold: 66
# Acquired samples: 66
# Sampling duration: 10.85128927230835 seconds
# New train size: 274
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.375866174697876 | ACCURACY: 0.7909 | F1 MACRO: 0.8816 | F1 MICRO: 0.8831
# EPOCH 2 | LOSS: 2.9880099296569824 | ACCURACY: 0.8043 | F1 MACRO: 0.8845 | F1 MICRO: 0.8874
# EPOCH 3 | LOSS: 2.65682053565979 | ACCURACY: 0.8259 | F1 MACRO: 0.8985 | F1 MICRO: 0.9001
# EPOCH 4 | LOSS: 2.4955685138702393 | ACCURACY: 0.8765 | F1 MACRO: 0.9245 | F1 MICRO: 0.9262
# EPOCH 5 | LOSS: 2.4244701862335205 | ACCURACY: 0.9107 | F1 MACRO: 0.944 | F1 MICRO: 0.9456
# EPOCH 6 | LOSS: 2.275178909301758 | ACCURACY: 0.9189 | F1 MACRO: 0.9474 | F1 MICRO: 0.9499
# EPOCH 7 | LOSS: 2.2292098999023438 | ACCURACY: 0.9263 | F1 MACRO: 0.9522 | F1 MICRO: 0.9546
# EPOCH 8 | LOSS: 2.112541913986206 | ACCURACY: 0.9449 | F1 MACRO: 0.9642 | F1 MICRO: 0.9658
# EPOCH 9 | LOSS: 2.025613784790039 | ACCURACY: 0.9405 | F1 MACRO: 0.9605 | F1 MICRO: 0.9628
# EPOCH 10 | LOSS: 1.9571291208267212 | ACCURACY: 0.9382 | F1 MACRO: 0.9592 | F1 MICRO: 0.9614
# aspect: ACCURACY 0.9449 | F1 MACRO 0.9642 | F1 MICRO 0.9658
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.91      0.99      0.95       175
#       others       0.91      0.94      0.93       158
#         part       0.93      0.97      0.95       158
#        price       0.96      1.00      0.98       192
#      service       0.97      1.00      0.99       191
#
#    micro avg       0.95      0.98      0.97      1061
#    macro avg       0.95      0.98      0.96      1061
# weighted avg       0.95      0.98      0.97      1061
#  samples avg       0.95      0.99      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 10.22999095916748 | ACCURACY: 0.8975 | F1 MACRO: 0.881 | F1 MICRO: 0.8975
# EPOCH 2 | LOSS: 7.971127986907959 | ACCURACY: 0.9631 | F1 MACRO: 0.9575 | F1 MICRO: 0.9631
# EPOCH 3 | LOSS: 6.77061128616333 | ACCURACY: 0.9631 | F1 MACRO: 0.9575 | F1 MICRO: 0.9631
# EPOCH 4 | LOSS: 6.2958784103393555 | ACCURACY: 0.918 | F1 MACRO: 0.899 | F1 MICRO: 0.918
# EPOCH 5 | LOSS: 5.975954055786133 | ACCURACY: 0.9426 | F1 MACRO: 0.9345 | F1 MICRO: 0.9426
# EPOCH 6 | LOSS: 5.760956287384033 | ACCURACY: 0.9262 | F1 MACRO: 0.9158 | F1 MICRO: 0.9262
# in second
# EPOCH 7 | LOSS: 5.248309135437012 | ACCURACY: 0.9467 | F1 MACRO: 0.939 | F1 MICRO: 0.9467
# in second
# EPOCH 8 | LOSS: 5.11226749420166 | ACCURACY: 0.9467 | F1 MACRO: 0.939 | F1 MICRO: 0.9467
# in second
# EPOCH 9 | LOSS: 5.067726135253906 | ACCURACY: 0.9508 | F1 MACRO: 0.9435 | F1 MICRO: 0.9508
# in second
# EPOCH 10 | LOSS: 4.966322422027588 | ACCURACY: 0.9426 | F1 MACRO: 0.9331 | F1 MICRO: 0.9426
# sentiment: ACCURACY 0.9631 | F1 MACRO 0.9575 | F1 MICRO 0.9631
#               precision    recall  f1-score   support
#
#     negative       0.91      0.97      0.94        75
#     positive       0.99      0.96      0.97       169
#
#     accuracy                           0.96       244
#    macro avg       0.95      0.97      0.96       244
# weighted avg       0.96      0.96      0.96       244
#
# --------------------------------------------------
# Iteration 274: Accuracy: 0.9414, F1 Micro: 0.9414, F1 Macro: 0.8831
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.92      1.00      0.96        11
#      neutral       0.99      1.00      0.99       181
#     positive       1.00      0.88      0.93        24
#
#     accuracy                           0.99       216
#    macro avg       0.97      0.96      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.69      0.76        16
#      neutral       0.92      0.99      0.95       167
#     positive       0.91      0.61      0.73        33
#
#     accuracy                           0.91       216
#    macro avg       0.89      0.76      0.81       216
# weighted avg       0.91      0.91      0.90       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.67      0.73        12
#      neutral       0.92      0.93      0.92       152
#     positive       0.79      0.79      0.79        52
#
#     accuracy                           0.88       216
#    macro avg       0.83      0.79      0.81       216
# weighted avg       0.88      0.88      0.88       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.87      0.85        23
#      neutral       0.94      0.97      0.95       152
#     positive       0.89      0.78      0.83        41
#
#     accuracy                           0.92       216
#    macro avg       0.89      0.87      0.88       216
# weighted avg       0.92      0.92      0.92       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.82      0.69      0.75        13
#      neutral       0.97      0.99      0.98       186
#     positive       0.93      0.76      0.84        17
#
#     accuracy                           0.96       216
#    macro avg       0.91      0.82      0.86       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.99      1.00      0.99       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.96      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 547 547
# Nearest checkpoint: 540
# Threshold: 88099.6953125
# Samples above threshold: 59
# Acquired samples: 59
# Sampling duration: 11.811522245407104 seconds
# New train size: 333
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.5196192264556885 | ACCURACY: 0.7909 | F1 MACRO: 0.8803 | F1 MICRO: 0.8823
# EPOCH 2 | LOSS: 3.025219678878784 | ACCURACY: 0.7999 | F1 MACRO: 0.8855 | F1 MICRO: 0.8868
# EPOCH 3 | LOSS: 2.683371067047119 | ACCURACY: 0.8646 | F1 MACRO: 0.9175 | F1 MICRO: 0.9197
# EPOCH 4 | LOSS: 2.584280490875244 | ACCURACY: 0.901 | F1 MACRO: 0.9386 | F1 MICRO: 0.9401
# EPOCH 5 | LOSS: 2.5606374740600586 | ACCURACY: 0.9345 | F1 MACRO: 0.9577 | F1 MICRO: 0.9593
# EPOCH 6 | LOSS: 2.401275873184204 | ACCURACY: 0.9397 | F1 MACRO: 0.961 | F1 MICRO: 0.9625
# EPOCH 7 | LOSS: 2.2573959827423096 | ACCURACY: 0.9487 | F1 MACRO: 0.9664 | F1 MICRO: 0.968
# EPOCH 8 | LOSS: 2.140428066253662 | ACCURACY: 0.9509 | F1 MACRO: 0.9676 | F1 MICRO: 0.9692
# EPOCH 9 | LOSS: 2.013296127319336 | ACCURACY: 0.9531 | F1 MACRO: 0.969 | F1 MICRO: 0.9706
# EPOCH 10 | LOSS: 1.962381362915039 | ACCURACY: 0.9531 | F1 MACRO: 0.9694 | F1 MICRO: 0.9707
# aspect: ACCURACY 0.9531 | F1 MACRO 0.9694 | F1 MICRO 0.9707
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.93      0.99      0.96       175
#       others       0.94      0.96      0.95       158
#         part       0.95      0.95      0.95       158
#        price       0.97      0.99      0.98       192
#      service       0.98      0.99      0.99       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.96      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 8.911905288696289 | ACCURACY: 0.8653 | F1 MACRO: 0.8281 | F1 MICRO: 0.8653
# EPOCH 2 | LOSS: 7.046684741973877 | ACCURACY: 0.9224 | F1 MACRO: 0.9127 | F1 MICRO: 0.9224
# EPOCH 3 | LOSS: 6.032115459442139 | ACCURACY: 0.9429 | F1 MACRO: 0.9337 | F1 MICRO: 0.9429
# EPOCH 4 | LOSS: 5.523568153381348 | ACCURACY: 0.9388 | F1 MACRO: 0.9297 | F1 MICRO: 0.9388
# EPOCH 5 | LOSS: 5.294276714324951 | ACCURACY: 0.9347 | F1 MACRO: 0.9253 | F1 MICRO: 0.9347
# EPOCH 6 | LOSS: 4.99269962310791 | ACCURACY: 0.9347 | F1 MACRO: 0.9267 | F1 MICRO: 0.9347
# in second
# EPOCH 7 | LOSS: 4.725368976593018 | ACCURACY: 0.9388 | F1 MACRO: 0.9302 | F1 MICRO: 0.9388
# in second
# EPOCH 8 | LOSS: 4.541701793670654 | ACCURACY: 0.9429 | F1 MACRO: 0.935 | F1 MICRO: 0.9429
# in second
# EPOCH 9 | LOSS: 4.4679789543151855 | ACCURACY: 0.9388 | F1 MACRO: 0.9306 | F1 MICRO: 0.9388
# in second
# EPOCH 10 | LOSS: 4.4337592124938965 | ACCURACY: 0.9388 | F1 MACRO: 0.9306 | F1 MICRO: 0.9388
# sentiment: ACCURACY 0.9429 | F1 MACRO 0.9337 | F1 MICRO 0.9429
#               precision    recall  f1-score   support
#
#     negative       0.92      0.90      0.91        78
#     positive       0.95      0.96      0.96       167
#
#     accuracy                           0.94       245
#    macro avg       0.94      0.93      0.93       245
# weighted avg       0.94      0.94      0.94       245
#
# --------------------------------------------------
# Iteration 333: Accuracy: 0.9498, F1 Micro: 0.9498, F1 Macro: 0.8971
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.92      1.00      0.96        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.95      0.88      0.91        24
#
#     accuracy                           0.98       216
#    macro avg       0.95      0.96      0.95       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.69      0.76        16
#      neutral       0.93      0.99      0.96       167
#     positive       0.88      0.64      0.74        33
#
#     accuracy                           0.92       216
#    macro avg       0.88      0.77      0.82       216
# weighted avg       0.91      0.92      0.91       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.89      0.67      0.76        12
#      neutral       0.92      0.96      0.94       152
#     positive       0.86      0.81      0.83        52
#
#     accuracy                           0.91       216
#    macro avg       0.89      0.81      0.85       216
# weighted avg       0.91      0.91      0.91       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.84      0.91      0.87        23
#      neutral       0.95      0.97      0.96       152
#     positive       0.92      0.80      0.86        41
#
#     accuracy                           0.94       216
#    macro avg       0.90      0.90      0.90       216
# weighted avg       0.94      0.94      0.93       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.90      0.69      0.78        13
#      neutral       0.97      0.99      0.98       186
#     positive       0.93      0.82      0.87        17
#
#     accuracy                           0.96       216
#    macro avg       0.93      0.84      0.88       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.99      1.00      1.00       185
#     positive       1.00      1.00      1.00        17
#
#     accuracy                           1.00       216
#    macro avg       1.00      0.98      0.99       216
# weighted avg       1.00      1.00      1.00       216
#
# Launching training on 2 GPUs.
# 508 508
# Nearest checkpoint: 540
# Threshold: 88021.296875
# Samples above threshold: 54
# Acquired samples: 54
# Sampling duration: 12.907731056213379 seconds
# New train size: 387
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.414809226989746 | ACCURACY: 0.7969 | F1 MACRO: 0.883 | F1 MICRO: 0.885
# EPOCH 2 | LOSS: 2.886430025100708 | ACCURACY: 0.8318 | F1 MACRO: 0.9007 | F1 MICRO: 0.9023
# EPOCH 3 | LOSS: 2.5833749771118164 | ACCURACY: 0.8951 | F1 MACRO: 0.9358 | F1 MICRO: 0.937
# EPOCH 4 | LOSS: 2.5700292587280273 | ACCURACY: 0.9263 | F1 MACRO: 0.9512 | F1 MICRO: 0.9539
# EPOCH 5 | LOSS: 2.3552043437957764 | ACCURACY: 0.9323 | F1 MACRO: 0.954 | F1 MICRO: 0.9575
# EPOCH 6 | LOSS: 2.206418752670288 | ACCURACY: 0.9435 | F1 MACRO: 0.9618 | F1 MICRO: 0.9646
# EPOCH 7 | LOSS: 2.070810317993164 | ACCURACY: 0.9494 | F1 MACRO: 0.9667 | F1 MICRO: 0.9683
# EPOCH 8 | LOSS: 1.999684453010559 | ACCURACY: 0.9501 | F1 MACRO: 0.967 | F1 MICRO: 0.9687
# EPOCH 9 | LOSS: 1.9339417219161987 | ACCURACY: 0.9606 | F1 MACRO: 0.9742 | F1 MICRO: 0.9753
# EPOCH 10 | LOSS: 1.8572094440460205 | ACCURACY: 0.9539 | F1 MACRO: 0.9696 | F1 MICRO: 0.971
# aspect: ACCURACY 0.9606 | F1 MACRO 0.9742 | F1 MICRO 0.9753
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.94      0.99      0.96       175
#       others       0.94      0.96      0.95       158
#         part       0.94      0.97      0.96       158
#        price       0.97      0.99      0.98       192
#      service       0.99      1.00      1.00       191
#
#    micro avg       0.96      0.99      0.98      1061
#    macro avg       0.96      0.99      0.97      1061
# weighted avg       0.96      0.99      0.98      1061
#  samples avg       0.96      0.99      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 7.387162685394287 | ACCURACY: 0.932 | F1 MACRO: 0.9231 | F1 MICRO: 0.932
# EPOCH 2 | LOSS: 5.679591655731201 | ACCURACY: 0.944 | F1 MACRO: 0.9357 | F1 MICRO: 0.944
# EPOCH 3 | LOSS: 5.008164405822754 | ACCURACY: 0.924 | F1 MACRO: 0.916 | F1 MICRO: 0.924
# EPOCH 4 | LOSS: 4.630442142486572 | ACCURACY: 0.932 | F1 MACRO: 0.9226 | F1 MICRO: 0.932
# EPOCH 5 | LOSS: 4.607155799865723 | ACCURACY: 0.928 | F1 MACRO: 0.9161 | F1 MICRO: 0.928
# in second
# EPOCH 6 | LOSS: 4.0345001220703125 | ACCURACY: 0.92 | F1 MACRO: 0.9093 | F1 MICRO: 0.92
# in second
# EPOCH 7 | LOSS: 3.933962821960449 | ACCURACY: 0.92 | F1 MACRO: 0.9093 | F1 MICRO: 0.92
# in second
# EPOCH 8 | LOSS: 3.9325344562530518 | ACCURACY: 0.92 | F1 MACRO: 0.9093 | F1 MICRO: 0.92
# in second
# EPOCH 9 | LOSS: 3.8736510276794434 | ACCURACY: 0.92 | F1 MACRO: 0.9093 | F1 MICRO: 0.92
# in second
# EPOCH 10 | LOSS: 3.7906761169433594 | ACCURACY: 0.92 | F1 MACRO: 0.9093 | F1 MICRO: 0.92
# sentiment: ACCURACY 0.944 | F1 MACRO 0.9357 | F1 MICRO 0.944
#               precision    recall  f1-score   support
#
#     negative       0.92      0.90      0.91        81
#     positive       0.95      0.96      0.96       169
#
#     accuracy                           0.94       250
#    macro avg       0.94      0.93      0.94       250
# weighted avg       0.94      0.94      0.94       250
#
# --------------------------------------------------
# Iteration 387: Accuracy: 0.9506, F1 Micro: 0.9506, F1 Macro: 0.8961
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.82      0.90        11
#      neutral       0.99      1.00      0.99       181
#     positive       0.92      0.92      0.92        24
#
#     accuracy                           0.98       216
#    macro avg       0.97      0.91      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.69      0.79        16
#      neutral       0.93      0.98      0.96       167
#     positive       0.82      0.70      0.75        33
#
#     accuracy                           0.92       216
#    macro avg       0.89      0.79      0.83       216
# weighted avg       0.91      0.92      0.91       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.82      0.75      0.78        12
#      neutral       0.94      0.96      0.95       152
#     positive       0.86      0.81      0.83        52
#
#     accuracy                           0.91       216
#    macro avg       0.87      0.84      0.85       216
# weighted avg       0.91      0.91      0.91       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.84      0.91      0.87        23
#      neutral       0.95      0.98      0.96       152
#     positive       0.91      0.76      0.83        41
#
#     accuracy                           0.93       216
#    macro avg       0.90      0.88      0.89       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.77      0.77      0.77        13
#      neutral       0.98      0.99      0.99       186
#     positive       0.93      0.76      0.84        17
#
#     accuracy                           0.96       216
#    macro avg       0.89      0.84      0.86       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        14
#      neutral       1.00      1.00      1.00       185
#     positive       1.00      1.00      1.00        17
#
#     accuracy                           1.00       216
#    macro avg       1.00      1.00      1.00       216
# weighted avg       1.00      1.00      1.00       216
#
# Launching training on 2 GPUs.
# 458 458
# Nearest checkpoint: 540
# Threshold: 87971.6796875
# Samples above threshold: 48
# Acquired samples: 48
# Sampling duration: 13.650367498397827 seconds
# New train size: 435
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.2528066635131836 | ACCURACY: 0.7961 | F1 MACRO: 0.8836 | F1 MICRO: 0.8853
# EPOCH 2 | LOSS: 2.677865505218506 | ACCURACY: 0.8475 | F1 MACRO: 0.9086 | F1 MICRO: 0.9103
# EPOCH 3 | LOSS: 2.4244394302368164 | ACCURACY: 0.901 | F1 MACRO: 0.937 | F1 MICRO: 0.9393
# EPOCH 4 | LOSS: 2.4173381328582764 | ACCURACY: 0.933 | F1 MACRO: 0.9568 | F1 MICRO: 0.9585
# EPOCH 5 | LOSS: 2.2502355575561523 | ACCURACY: 0.9405 | F1 MACRO: 0.9606 | F1 MICRO: 0.9627
# EPOCH 6 | LOSS: 2.0778298377990723 | ACCURACY: 0.9494 | F1 MACRO: 0.9668 | F1 MICRO: 0.9685
# EPOCH 7 | LOSS: 1.9512046575546265 | ACCURACY: 0.9487 | F1 MACRO: 0.9653 | F1 MICRO: 0.9677
# EPOCH 8 | LOSS: 1.9032129049301147 | ACCURACY: 0.9539 | F1 MACRO: 0.9695 | F1 MICRO: 0.9711
# EPOCH 9 | LOSS: 1.8154746294021606 | ACCURACY: 0.9583 | F1 MACRO: 0.9728 | F1 MICRO: 0.974
# EPOCH 10 | LOSS: 1.770957589149475 | ACCURACY: 0.9591 | F1 MACRO: 0.9732 | F1 MICRO: 0.9744
# aspect: ACCURACY 0.9591 | F1 MACRO 0.9732 | F1 MICRO 0.9744
#               precision    recall  f1-score   support
#
#         fuel       0.97      1.00      0.98       187
#      machine       0.94      0.99      0.97       175
#       others       0.93      0.97      0.95       158
#         part       0.94      0.97      0.95       158
#        price       0.98      0.99      0.98       192
#      service       1.00      1.00      1.00       191
#
#    micro avg       0.96      0.99      0.97      1061
#    macro avg       0.96      0.99      0.97      1061
# weighted avg       0.96      0.99      0.97      1061
#  samples avg       0.96      0.99      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.861530303955078 | ACCURACY: 0.8623 | F1 MACRO: 0.8429 | F1 MICRO: 0.8623
# EPOCH 2 | LOSS: 5.511658668518066 | ACCURACY: 0.9312 | F1 MACRO: 0.9201 | F1 MICRO: 0.9312
# EPOCH 3 | LOSS: 4.59161376953125 | ACCURACY: 0.9312 | F1 MACRO: 0.9236 | F1 MICRO: 0.9312
# EPOCH 4 | LOSS: 4.282373905181885 | ACCURACY: 0.9271 | F1 MACRO: 0.9138 | F1 MICRO: 0.9271
# EPOCH 5 | LOSS: 4.023313522338867 | ACCURACY: 0.9312 | F1 MACRO: 0.9217 | F1 MICRO: 0.9312
# EPOCH 6 | LOSS: 3.967538833618164 | ACCURACY: 0.9352 | F1 MACRO: 0.9278 | F1 MICRO: 0.9352
# EPOCH 7 | LOSS: 3.9367356300354004 | ACCURACY: 0.9271 | F1 MACRO: 0.9197 | F1 MICRO: 0.9271
# EPOCH 8 | LOSS: 3.7733993530273438 | ACCURACY: 0.9109 | F1 MACRO: 0.899 | F1 MICRO: 0.9109
# EPOCH 9 | LOSS: 3.7012927532196045 | ACCURACY: 0.9312 | F1 MACRO: 0.9201 | F1 MICRO: 0.9312
# in second
# EPOCH 10 | LOSS: 3.4910154342651367 | ACCURACY: 0.9393 | F1 MACRO: 0.9317 | F1 MICRO: 0.9393
# sentiment: ACCURACY 0.9352 | F1 MACRO 0.9278 | F1 MICRO 0.9352
#               precision    recall  f1-score   support
#
#     negative       0.86      0.95      0.90        80
#     positive       0.97      0.93      0.95       167
#
#     accuracy                           0.94       247
#    macro avg       0.92      0.94      0.93       247
# weighted avg       0.94      0.94      0.94       247
#
# --------------------------------------------------
# Iteration 435: Accuracy: 0.9483, F1 Micro: 0.9483, F1 Macro: 0.8899
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.91      0.91        11
#      neutral       0.99      1.00      0.99       181
#     positive       0.95      0.88      0.91        24
#
#     accuracy                           0.98       216
#    macro avg       0.95      0.93      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.75      0.83        16
#      neutral       0.93      0.99      0.96       167
#     positive       0.88      0.70      0.78        33
#
#     accuracy                           0.93       216
#    macro avg       0.91      0.81      0.86       216
# weighted avg       0.92      0.93      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.69      0.75      0.72        12
#      neutral       0.93      0.95      0.94       152
#     positive       0.85      0.77      0.81        52
#
#     accuracy                           0.90       216
#    macro avg       0.82      0.82      0.82       216
# weighted avg       0.90      0.90      0.90       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.84      0.91      0.87        23
#      neutral       0.96      0.98      0.97       152
#     positive       0.91      0.78      0.84        41
#
#     accuracy                           0.94       216
#    macro avg       0.90      0.89      0.89       216
# weighted avg       0.94      0.94      0.93       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.77      0.77      0.77        13
#      neutral       0.97      0.99      0.98       186
#     positive       0.92      0.71      0.80        17
#
#     accuracy                           0.96       216
#    macro avg       0.89      0.82      0.85       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.99      1.00      0.99       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.96      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 416 416
# Nearest checkpoint: 540
# Threshold: 88148.2578125
# Samples above threshold: 43
# Acquired samples: 43
# Sampling duration: 14.45425033569336 seconds
# New train size: 478
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.226423740386963 | ACCURACY: 0.8036 | F1 MACRO: 0.8873 | F1 MICRO: 0.8889
# EPOCH 2 | LOSS: 2.6523287296295166 | ACCURACY: 0.8475 | F1 MACRO: 0.9105 | F1 MICRO: 0.9112
# EPOCH 3 | LOSS: 2.448594093322754 | ACCURACY: 0.9085 | F1 MACRO: 0.9427 | F1 MICRO: 0.9442
# EPOCH 4 | LOSS: 2.3277201652526855 | ACCURACY: 0.9301 | F1 MACRO: 0.955 | F1 MICRO: 0.9567
# EPOCH 5 | LOSS: 2.1376397609710693 | ACCURACY: 0.9472 | F1 MACRO: 0.9658 | F1 MICRO: 0.9673
# EPOCH 6 | LOSS: 2.021270513534546 | ACCURACY: 0.9435 | F1 MACRO: 0.9621 | F1 MICRO: 0.9645
# EPOCH 7 | LOSS: 1.893345594406128 | ACCURACY: 0.9501 | F1 MACRO: 0.967 | F1 MICRO: 0.9688
# EPOCH 8 | LOSS: 1.8581490516662598 | ACCURACY: 0.9524 | F1 MACRO: 0.9686 | F1 MICRO: 0.9703
# EPOCH 9 | LOSS: 1.7720487117767334 | ACCURACY: 0.9442 | F1 MACRO: 0.9623 | F1 MICRO: 0.9649
# EPOCH 10 | LOSS: 1.7238901853561401 | ACCURACY: 0.9487 | F1 MACRO: 0.9657 | F1 MICRO: 0.9676
# aspect: ACCURACY 0.9524 | F1 MACRO 0.9686 | F1 MICRO 0.9703
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.93      0.99      0.96       175
#       others       0.90      0.95      0.92       158
#         part       0.94      0.97      0.96       158
#        price       0.98      0.99      0.99       192
#      service       0.99      1.00      0.99       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.95      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.261505603790283 | ACCURACY: 0.8831 | F1 MACRO: 0.8619 | F1 MICRO: 0.8831
# EPOCH 2 | LOSS: 4.986752986907959 | ACCURACY: 0.9073 | F1 MACRO: 0.886 | F1 MICRO: 0.9073
# EPOCH 3 | LOSS: 4.2755889892578125 | ACCURACY: 0.9315 | F1 MACRO: 0.9246 | F1 MICRO: 0.9315
# EPOCH 4 | LOSS: 3.946113348007202 | ACCURACY: 0.9395 | F1 MACRO: 0.9319 | F1 MICRO: 0.9395
# EPOCH 5 | LOSS: 3.687407970428467 | ACCURACY: 0.9355 | F1 MACRO: 0.9271 | F1 MICRO: 0.9355
# EPOCH 6 | LOSS: 3.6491148471832275 | ACCURACY: 0.9435 | F1 MACRO: 0.935 | F1 MICRO: 0.9435
# EPOCH 7 | LOSS: 3.554351806640625 | ACCURACY: 0.9355 | F1 MACRO: 0.9276 | F1 MICRO: 0.9355
# EPOCH 8 | LOSS: 3.498244285583496 | ACCURACY: 0.9274 | F1 MACRO: 0.9185 | F1 MICRO: 0.9274
# EPOCH 9 | LOSS: 3.39104962348938 | ACCURACY: 0.9194 | F1 MACRO: 0.9065 | F1 MICRO: 0.9194
# in second
# EPOCH 10 | LOSS: 3.156546115875244 | ACCURACY: 0.9556 | F1 MACRO: 0.9491 | F1 MICRO: 0.9556
# sentiment: ACCURACY 0.9435 | F1 MACRO 0.935 | F1 MICRO 0.9435
#               precision    recall  f1-score   support
#
#     negative       0.92      0.90      0.91        80
#     positive       0.95      0.96      0.96       168
#
#     accuracy                           0.94       248
#    macro avg       0.94      0.93      0.93       248
# weighted avg       0.94      0.94      0.94       248
#
# --------------------------------------------------
# Iteration 478: Accuracy: 0.9498, F1 Micro: 0.9498, F1 Macro: 0.8993
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.82      0.90        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.88      0.92      0.90        24
#
#     accuracy                           0.98       216
#    macro avg       0.96      0.91      0.93       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.69      0.79        16
#      neutral       0.92      0.99      0.96       167
#     positive       0.88      0.64      0.74        33
#
#     accuracy                           0.92       216
#    macro avg       0.90      0.77      0.83       216
# weighted avg       0.91      0.92      0.91       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.89      0.67      0.76        12
#      neutral       0.93      0.93      0.93       152
#     positive       0.78      0.83      0.80        52
#
#     accuracy                           0.89       216
#    macro avg       0.87      0.81      0.83       216
# weighted avg       0.90      0.89      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.95      0.83      0.88        23
#      neutral       0.95      0.99      0.97       152
#     positive       0.92      0.83      0.87        41
#
#     accuracy                           0.94       216
#    macro avg       0.94      0.88      0.91       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.77      0.83        13
#      neutral       0.97      0.99      0.98       186
#     positive       0.93      0.82      0.87        17
#
#     accuracy                           0.97       216
#    macro avg       0.94      0.86      0.90       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        14
#      neutral       1.00      1.00      1.00       185
#     positive       1.00      1.00      1.00        17
#
#     accuracy                           1.00       216
#    macro avg       1.00      1.00      1.00       216
# weighted avg       1.00      1.00      1.00       216
#
# Launching training on 2 GPUs.
# 364 364
# Nearest checkpoint: 540
# Threshold: 88237.8203125
# Samples above threshold: 39
# Acquired samples: 39
# Sampling duration: 17.48730754852295 seconds
# New train size: 517
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.260756731033325 | ACCURACY: 0.8073 | F1 MACRO: 0.8897 | F1 MICRO: 0.8909
# EPOCH 2 | LOSS: 2.617499828338623 | ACCURACY: 0.8616 | F1 MACRO: 0.9176 | F1 MICRO: 0.9188
# EPOCH 3 | LOSS: 2.5099246501922607 | ACCURACY: 0.9241 | F1 MACRO: 0.9513 | F1 MICRO: 0.9531
# EPOCH 4 | LOSS: 2.3270881175994873 | ACCURACY: 0.9435 | F1 MACRO: 0.9634 | F1 MICRO: 0.9649
# EPOCH 5 | LOSS: 2.169011354446411 | ACCURACY: 0.9479 | F1 MACRO: 0.9659 | F1 MICRO: 0.9675
# EPOCH 6 | LOSS: 1.9839954376220703 | ACCURACY: 0.9554 | F1 MACRO: 0.9707 | F1 MICRO: 0.972
# EPOCH 7 | LOSS: 1.899808645248413 | ACCURACY: 0.9524 | F1 MACRO: 0.9679 | F1 MICRO: 0.97
# EPOCH 8 | LOSS: 1.8417112827301025 | ACCURACY: 0.9516 | F1 MACRO: 0.9682 | F1 MICRO: 0.9696
# EPOCH 9 | LOSS: 1.7864906787872314 | ACCURACY: 0.9516 | F1 MACRO: 0.9677 | F1 MICRO: 0.9696
# in second
# ...
# weighted avg       0.97      0.98      0.98      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.851773738861084 | ACCURACY: 0.8778 | F1 MACRO: 0.8605 | F1 MICRO: 0.8778
# EPOCH 2 | LOSS: 3.199032783508301 | ACCURACY: 0.9444 | F1 MACRO: 0.9373 | F1 MICRO: 0.9444
# EPOCH 3 | LOSS: 2.563380002975464 | ACCURACY: 0.9148 | F1 MACRO: 0.9028 | F1 MICRO: 0.9148
# EPOCH 4 | LOSS: 2.41792893409729 | ACCURACY: 0.937 | F1 MACRO: 0.9281 | F1 MICRO: 0.937
# EPOCH 5 | LOSS: 2.3209848403930664 | ACCURACY: 0.937 | F1 MACRO: 0.929 | F1 MICRO: 0.937
# in second
# EPOCH 6 | LOSS: 2.011319875717163 | ACCURACY: 0.9333 | F1 MACRO: 0.9254 | F1 MICRO: 0.9333
# in second
# EPOCH 7 | LOSS: 1.952799677848816 | ACCURACY: 0.9296 | F1 MACRO: 0.9215 | F1 MICRO: 0.9296
# in second
# EPOCH 8 | LOSS: 1.9391887187957764 | ACCURACY: 0.9333 | F1 MACRO: 0.9254 | F1 MICRO: 0.9333
# in second
# EPOCH 9 | LOSS: 1.9094523191452026 | ACCURACY: 0.9296 | F1 MACRO: 0.9215 | F1 MICRO: 0.9296
# in second
# EPOCH 10 | LOSS: 1.8963490724563599 | ACCURACY: 0.9296 | F1 MACRO: 0.9215 | F1 MICRO: 0.9296
# sentiment: ACCURACY 0.9444 | F1 MACRO 0.9373 | F1 MICRO 0.9444
#               precision    recall  f1-score   support
#
#     negative       0.87      0.96      0.92        85
#     positive       0.98      0.94      0.96       185
#
#     accuracy                           0.94       270
#    macro avg       0.93      0.95      0.94       270
# weighted avg       0.95      0.94      0.95       270
#
# --------------------------------------------------
# Iteration 831: Accuracy: 0.9537, F1 Micro: 0.9537, F1 Macro: 0.9148
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.96      0.96      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.98      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.81      0.84        16
#      neutral       0.95      0.98      0.96       167
#     positive       0.86      0.76      0.81        33
#
#     accuracy                           0.93       216
#    macro avg       0.89      0.85      0.87       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.79      0.92      0.85        12
#      neutral       0.94      0.92      0.93       152
#     positive       0.79      0.81      0.80        52
#
#     accuracy                           0.89       216
#    macro avg       0.84      0.88      0.86       216
# weighted avg       0.90      0.89      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.81      0.96      0.88        23
#      neutral       0.98      0.97      0.97       152
#     positive       0.90      0.85      0.88        41
#
#     accuracy                           0.94       216
#    macro avg       0.90      0.93      0.91       216
# weighted avg       0.95      0.94      0.94       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.79      0.85      0.81        13
#      neutral       0.98      0.99      0.99       186
#     positive       0.92      0.71      0.80        17
#
#     accuracy                           0.96       216
#    macro avg       0.90      0.85      0.87       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        14
#      neutral       1.00      1.00      1.00       185
#     positive       1.00      1.00      1.00        17
#
#     accuracy                           1.00       216
#    macro avg       1.00      1.00      1.00       216
# weighted avg       1.00      1.00      1.00       216
#
# Launching training on 2 GPUs.
# 33 33
# Nearest checkpoint: 864
# Threshold: 88305.34375
# Samples above threshold: 4
# Acquired samples: 25
# Sampling duration: 19.89894437789917 seconds
# New train size: 856
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.9913859367370605 | ACCURACY: 0.8415 | F1 MACRO: 0.9075 | F1 MICRO: 0.9084
# EPOCH 2 | LOSS: 2.4300765991210938 | ACCURACY: 0.9323 | F1 MACRO: 0.956 | F1 MICRO: 0.958
# EPOCH 3 | LOSS: 2.204145908355713 | ACCURACY: 0.9494 | F1 MACRO: 0.966 | F1 MICRO: 0.9682
# EPOCH 4 | LOSS: 1.9720031023025513 | ACCURACY: 0.9568 | F1 MACRO: 0.9718 | F1 MICRO: 0.973
# EPOCH 5 | LOSS: 1.8596550226211548 | ACCURACY: 0.9576 | F1 MACRO: 0.9712 | F1 MICRO: 0.9732
# EPOCH 6 | LOSS: 1.7626334428787231 | ACCURACY: 0.9658 | F1 MACRO: 0.9776 | F1 MICRO: 0.9786
# EPOCH 7 | LOSS: 1.7220560312271118 | ACCURACY: 0.9591 | F1 MACRO: 0.9724 | F1 MICRO: 0.9741
# EPOCH 8 | LOSS: 1.656286597251892 | ACCURACY: 0.9628 | F1 MACRO: 0.9756 | F1 MICRO: 0.9766
# EPOCH 9 | LOSS: 1.589758276939392 | ACCURACY: 0.9613 | F1 MACRO: 0.9742 | F1 MICRO: 0.9756
# in second
# EPOCH 10 | LOSS: 1.541264533996582 | ACCURACY: 0.9606 | F1 MACRO: 0.9745 | F1 MICRO: 0.9754
# aspect: ACCURACY 0.9658 | F1 MACRO 0.9776 | F1 MICRO 0.9786
#               precision    recall  f1-score   support
#
#         fuel       0.98      0.99      0.99       187
#      machine       0.95      0.98      0.97       175
#       others       0.91      0.99      0.95       158
#         part       0.98      0.97      0.98       158
#        price       0.99      0.99      0.99       192
#      service       0.99      1.00      0.99       191
#
#    micro avg       0.97      0.99      0.98      1061
#    macro avg       0.97      0.99      0.98      1061
# weighted avg       0.97      0.99      0.98      1061
#  samples avg       0.97      0.99      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.6135804653167725 | ACCURACY: 0.913 | F1 MACRO: 0.9026 | F1 MICRO: 0.913
# EPOCH 2 | LOSS: 2.7414424419403076 | ACCURACY: 0.917 | F1 MACRO: 0.9101 | F1 MICRO: 0.917
# EPOCH 3 | LOSS: 2.5823235511779785 | ACCURACY: 0.9407 | F1 MACRO: 0.9341 | F1 MICRO: 0.9407
# EPOCH 4 | LOSS: 2.31141996383667 | ACCURACY: 0.9328 | F1 MACRO: 0.9257 | F1 MICRO: 0.9328
# EPOCH 5 | LOSS: 2.167449474334717 | ACCURACY: 0.9249 | F1 MACRO: 0.9179 | F1 MICRO: 0.9249
# EPOCH 6 | LOSS: 2.120903968811035 | ACCURACY: 0.9447 | F1 MACRO: 0.9387 | F1 MICRO: 0.9447
# EPOCH 7 | LOSS: 1.9526170492172241 | ACCURACY: 0.9605 | F1 MACRO: 0.956 | F1 MICRO: 0.9605
# EPOCH 8 | LOSS: 1.9342368841171265 | ACCURACY: 0.9328 | F1 MACRO: 0.9265 | F1 MICRO: 0.9328
# EPOCH 9 | LOSS: 1.9685444831848145 | ACCURACY: 0.9289 | F1 MACRO: 0.9212 | F1 MICRO: 0.9289
# EPOCH 10 | LOSS: 1.8825998306274414 | ACCURACY: 0.9368 | F1 MACRO: 0.9283 | F1 MICRO: 0.9368
# sentiment: ACCURACY 0.9605 | F1 MACRO 0.956 | F1 MICRO 0.9605
#               precision    recall  f1-score   support
#
#     negative       0.91      0.98      0.94        83
#     positive       0.99      0.95      0.97       170
#
#     accuracy                           0.96       253
#    macro avg       0.95      0.96      0.96       253
# weighted avg       0.96      0.96      0.96       253
#
# --------------------------------------------------
# Iteration 856: Accuracy: 0.9599, F1 Micro: 0.9599, F1 Macro: 0.9206
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.92      1.00      0.96        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.99       216
#    macro avg       0.96      0.97      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.81      0.84        16
#      neutral       0.96      0.98      0.97       167
#     positive       0.87      0.82      0.84        33
#
#     accuracy                           0.94       216
#    macro avg       0.90      0.87      0.88       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.82      0.75      0.78        12
#      neutral       0.91      0.99      0.95       152
#     positive       0.95      0.73      0.83        52
#
#     accuracy                           0.91       216
#    macro avg       0.89      0.82      0.85       216
# weighted avg       0.91      0.91      0.91       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.85      1.00      0.92        23
#      neutral       0.97      0.98      0.97       152
#     positive       0.94      0.80      0.87        41
#
#     accuracy                           0.95       216
#    macro avg       0.92      0.93      0.92       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.92      0.89        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.93      0.82      0.87        17
#
#     accuracy                           0.98       216
#    macro avg       0.93      0.91      0.92       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.99      1.00      1.00       185
#     positive       1.00      1.00      1.00        17
#
#     accuracy                           1.00       216
#    macro avg       1.00      0.98      0.99       216
# weighted avg       1.00      1.00      1.00       216
#
# Launching training on 2 GPUs.
# 8 8
# Nearest checkpoint: 864
# Threshold: 88283.6484375
# Samples above threshold: 1
# Acquired samples: 8
# Sampling duration: 19.985508680343628 seconds
# New train size: 864
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.959395170211792 | ACCURACY: 0.8311 | F1 MACRO: 0.9014 | F1 MICRO: 0.9028
# EPOCH 2 | LOSS: 2.460578441619873 | ACCURACY: 0.9308 | F1 MACRO: 0.9545 | F1 MICRO: 0.9568
# EPOCH 3 | LOSS: 2.221756935119629 | ACCURACY: 0.9561 | F1 MACRO: 0.9715 | F1 MICRO: 0.9727
# EPOCH 4 | LOSS: 1.9600011110305786 | ACCURACY: 0.9583 | F1 MACRO: 0.9722 | F1 MICRO: 0.9738
# EPOCH 5 | LOSS: 1.8518600463867188 | ACCURACY: 0.9591 | F1 MACRO: 0.9725 | F1 MICRO: 0.9741
# EPOCH 6 | LOSS: 1.7566109895706177 | ACCURACY: 0.9583 | F1 MACRO: 0.9718 | F1 MICRO: 0.9737
# EPOCH 7 | LOSS: 1.6952048540115356 | ACCURACY: 0.9576 | F1 MACRO: 0.9716 | F1 MICRO: 0.9733
# EPOCH 8 | LOSS: 1.6420003175735474 | ACCURACY: 0.9576 | F1 MACRO: 0.9708 | F1 MICRO: 0.9731
# in second
# EPOCH 9 | LOSS: 1.580309510231018 | ACCURACY: 0.9568 | F1 MACRO: 0.9721 | F1 MICRO: 0.9731
# in second
# EPOCH 10 | LOSS: 1.5257855653762817 | ACCURACY: 0.9583 | F1 MACRO: 0.9727 | F1 MICRO: 0.9739
# aspect: ACCURACY 0.9591 | F1 MACRO 0.9725 | F1 MICRO 0.9741
#               precision    recall  f1-score   support
#
#         fuel       0.98      0.99      0.99       187
#      machine       0.96      0.98      0.97       175
#       others       0.92      0.92      0.92       158
#         part       0.98      0.97      0.97       158
#        price       0.98      0.98      0.98       192
#      service       0.99      1.00      1.00       191
#
#    micro avg       0.97      0.98      0.97      1061
#    macro avg       0.97      0.97      0.97      1061
# weighted avg       0.97      0.98      0.97      1061
#  samples avg       0.97      0.97      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.620183229446411 | ACCURACY: 0.8926 | F1 MACRO: 0.8656 | F1 MICRO: 0.8926
# EPOCH 2 | LOSS: 2.757636785507202 | ACCURACY: 0.9222 | F1 MACRO: 0.9132 | F1 MICRO: 0.9222
# EPOCH 3 | LOSS: 2.4355785846710205 | ACCURACY: 0.9296 | F1 MACRO: 0.9202 | F1 MICRO: 0.9296
# EPOCH 4 | LOSS: 2.287003517150879 | ACCURACY: 0.9037 | F1 MACRO: 0.8939 | F1 MICRO: 0.9037
# EPOCH 5 | LOSS: 2.166252374649048 | ACCURACY: 0.9185 | F1 MACRO: 0.9093 | F1 MICRO: 0.9185
# EPOCH 6 | LOSS: 2.1204211711883545 | ACCURACY: 0.9111 | F1 MACRO: 0.8956 | F1 MICRO: 0.9111
# in second
# EPOCH 7 | LOSS: 1.9088172912597656 | ACCURACY: 0.9259 | F1 MACRO: 0.9162 | F1 MICRO: 0.9259
# in second
# EPOCH 8 | LOSS: 1.8482322692871094 | ACCURACY: 0.9259 | F1 MACRO: 0.9162 | F1 MICRO: 0.9259
# in second
# EPOCH 9 | LOSS: 1.8320152759552002 | ACCURACY: 0.9259 | F1 MACRO: 0.9162 | F1 MICRO: 0.9259
# in second
# EPOCH 10 | LOSS: 1.7962476015090942 | ACCURACY: 0.9259 | F1 MACRO: 0.9157 | F1 MICRO: 0.9259
# sentiment: ACCURACY 0.9296 | F1 MACRO 0.9202 | F1 MICRO 0.9296
#               precision    recall  f1-score   support
#
#     negative       0.85      0.94      0.89        84
#     positive       0.97      0.92      0.95       186
#
#     accuracy                           0.93       270
#    macro avg       0.91      0.93      0.92       270
# weighted avg       0.93      0.93      0.93       270
#
# --------------------------------------------------
# Iteration 864: Accuracy: 0.9522, F1 Micro: 0.9522, F1 Macro: 0.9113
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.96      0.96      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.98      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.81      0.84        16
#      neutral       0.95      0.98      0.96       167
#     positive       0.89      0.76      0.82        33
#
#     accuracy                           0.94       216
#    macro avg       0.90      0.85      0.87       216
# weighted avg       0.93      0.94      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.64      0.75      0.69        12
#      neutral       0.93      0.91      0.92       152
#     positive       0.77      0.79      0.78        52
#
#     accuracy                           0.88       216
#    macro avg       0.78      0.82      0.80       216
# weighted avg       0.88      0.88      0.88       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.96      0.90        23
#      neutral       0.97      0.97      0.97       152
#     positive       0.90      0.85      0.88        41
#
#     accuracy                           0.94       216
#    macro avg       0.91      0.93      0.91       216
# weighted avg       0.95      0.94      0.94       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.92      0.89        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.88      0.82      0.85        17
#
#     accuracy                           0.97       216
#    macro avg       0.91      0.91      0.91       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.99      1.00      1.00       185
#     positive       1.00      1.00      1.00        17
#
#     accuracy                           1.00       216
#    macro avg       1.00      0.98      0.99       216
# weighted avg       1.00      1.00      1.00       216
#
# Total sampling time: 364.59 seconds
# Total runtime: 2839.617762327194 seconds

# %% [markdown]
# ## RUN 4

# %%
active_learning(seeds[3], 3)
# Out:
# ===============================================
# TRIAL 4
# Random seed: 3
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# pytorch_model.bin:   0%|          | 0.00/498M [00:00<?, ?B/s]
# EPOCH 1 | LOSS: 3.5983240604400635 | ACCURACY: 0.7671 | F1 MACRO: 0.8506 | F1 MICRO: 0.8622
# EPOCH 2 | LOSS: 3.323089599609375 | ACCURACY: 0.779 | F1 MACRO: 0.873 | F1 MICRO: 0.8751
# EPOCH 3 | LOSS: 3.3482136726379395 | ACCURACY: 0.7805 | F1 MACRO: 0.8737 | F1 MICRO: 0.8758
# EPOCH 4 | LOSS: 3.22114634513855 | ACCURACY: 0.7842 | F1 MACRO: 0.8743 | F1 MICRO: 0.8767
# EPOCH 5 | LOSS: 3.2356982231140137 | ACCURACY: 0.779 | F1 MACRO: 0.8708 | F1 MICRO: 0.8736
# EPOCH 6 | LOSS: 2.9298696517944336 | ACCURACY: 0.7835 | F1 MACRO: 0.872 | F1 MICRO: 0.8752
# EPOCH 7 | LOSS: 2.8540592193603516 | ACCURACY: 0.7887 | F1 MACRO: 0.8732 | F1 MICRO: 0.8768
# EPOCH 8 | LOSS: 2.7723355293273926 | ACCURACY: 0.7954 | F1 MACRO: 0.8766 | F1 MICRO: 0.8801
# EPOCH 9 | LOSS: 2.754518985748291 | ACCURACY: 0.7932 | F1 MACRO: 0.8757 | F1 MICRO: 0.879
# EPOCH 10 | LOSS: 2.6405434608459473 | ACCURACY: 0.7984 | F1 MACRO: 0.8788 | F1 MICRO: 0.8817
# aspect: ACCURACY 0.7984 | F1 MACRO 0.8788 | F1 MICRO 0.8817
#               precision    recall  f1-score   support
#
#         fuel       0.84      0.98      0.90       187
#      machine       0.81      0.83      0.82       175
#       others       0.78      0.92      0.85       158
#         part       0.77      0.97      0.86       158
#        price       0.86      1.00      0.92       192
#      service       0.85      1.00      0.92       191
#
#    micro avg       0.82      0.95      0.88      1061
#    macro avg       0.82      0.95      0.88      1061
# weighted avg       0.82      0.95      0.88      1061
#  samples avg       0.82      0.95      0.88      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 20.173891067504883 | ACCURACY: 0.8151 | F1 MACRO: 0.4491 | F1 MICRO: 0.8151
# EPOCH 2 | LOSS: 16.506135940551758 | ACCURACY: 0.8151 | F1 MACRO: 0.4491 | F1 MICRO: 0.8151
# EPOCH 3 | LOSS: 14.638459205627441 | ACCURACY: 0.8403 | F1 MACRO: 0.627 | F1 MICRO: 0.8403
# EPOCH 4 | LOSS: 14.243339538574219 | ACCURACY: 0.8739 | F1 MACRO: 0.8073 | F1 MICRO: 0.8739
# EPOCH 5 | LOSS: 13.640288352966309 | ACCURACY: 0.8571 | F1 MACRO: 0.6847 | F1 MICRO: 0.8571
# EPOCH 6 | LOSS: 12.324337005615234 | ACCURACY: 0.8403 | F1 MACRO: 0.6658 | F1 MICRO: 0.8403
# EPOCH 7 | LOSS: 11.676736831665039 | ACCURACY: 0.8403 | F1 MACRO: 0.6658 | F1 MICRO: 0.8403
# in second
# EPOCH 8 | LOSS: 10.77684497833252 | ACCURACY: 0.8151 | F1 MACRO: 0.4491 | F1 MICRO: 0.8151
# in second
# EPOCH 9 | LOSS: 10.498997688293457 | ACCURACY: 0.8151 | F1 MACRO: 0.4491 | F1 MICRO: 0.8151
# in second
# EPOCH 10 | LOSS: 10.478277206420898 | ACCURACY: 0.8235 | F1 MACRO: 0.4946 | F1 MICRO: 0.8235
# sentiment: ACCURACY 0.8739 | F1 MACRO 0.8073 | F1 MICRO 0.8739
#               precision    recall  f1-score   support
#
#     negative       0.63      0.77      0.69        22
#     positive       0.95      0.90      0.92        97
#
#     accuracy                           0.87       119
#    macro avg       0.79      0.83      0.81       119
# weighted avg       0.89      0.87      0.88       119
#
# --------------------------------------------------
# Iteration 54: Accuracy: 0.7924, F1 Micro: 0.7924, F1 Macro: 0.4388
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        11
#      neutral       0.84      0.97      0.90       181
#     positive       0.29      0.08      0.13        24
#
#     accuracy                           0.82       216
#    macro avg       0.38      0.35      0.34       216
# weighted avg       0.74      0.82      0.77       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.50      0.44      0.47        16
#      neutral       0.80      0.78      0.79       167
#     positive       0.15      0.18      0.17        33
#
#     accuracy                           0.66       216
#    macro avg       0.48      0.47      0.47       216
# weighted avg       0.68      0.66      0.67       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.71      0.42      0.53        12
#      neutral       0.79      0.96      0.87       152
#     positive       0.75      0.35      0.47        52
#
#     accuracy                           0.78       216
#    macro avg       0.75      0.57      0.62       216
# weighted avg       0.78      0.78      0.75       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.26      0.39        23
#      neutral       0.77      0.95      0.85       152
#     positive       0.75      0.37      0.49        41
#
#     accuracy                           0.77       216
#    macro avg       0.76      0.53      0.58       216
# weighted avg       0.76      0.77      0.73       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        13
#      neutral       0.86      1.00      0.93       186
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.86       216
#    macro avg       0.29      0.33      0.31       216
# weighted avg       0.74      0.86      0.80       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        14
#      neutral       0.86      1.00      0.92       185
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.86       216
#    macro avg       0.29      0.33      0.31       216
# weighted avg       0.73      0.86      0.79       216
#
# Launching training on 2 GPUs.
# 339 339
# Nearest checkpoint: 540
# Threshold: 87488.9765625
# Samples above threshold: 81
# Acquired samples: 81
# Sampling duration: 6.619887590408325 seconds
# New train size: 135
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.7213194370269775 | ACCURACY: 0.7872 | F1 MACRO: 0.8793 | F1 MICRO: 0.8808
# EPOCH 2 | LOSS: 3.524927854537964 | ACCURACY: 0.7939 | F1 MACRO: 0.8806 | F1 MICRO: 0.883
# EPOCH 3 | LOSS: 3.293921947479248 | ACCURACY: 0.7999 | F1 MACRO: 0.886 | F1 MICRO: 0.8875
# EPOCH 4 | LOSS: 3.0292885303497314 | ACCURACY: 0.8013 | F1 MACRO: 0.8863 | F1 MICRO: 0.888
# EPOCH 5 | LOSS: 2.798945188522339 | ACCURACY: 0.8125 | F1 MACRO: 0.8908 | F1 MICRO: 0.8927
# EPOCH 6 | LOSS: 2.765974283218384 | ACCURACY: 0.8274 | F1 MACRO: 0.8993 | F1 MICRO: 0.9007
# EPOCH 7 | LOSS: 2.713017463684082 | ACCURACY: 0.8475 | F1 MACRO: 0.909 | F1 MICRO: 0.9104
# EPOCH 8 | LOSS: 2.8222033977508545 | ACCURACY: 0.8661 | F1 MACRO: 0.9175 | F1 MICRO: 0.9199
# EPOCH 9 | LOSS: 2.6997344493865967 | ACCURACY: 0.8891 | F1 MACRO: 0.9304 | F1 MICRO: 0.9327
# EPOCH 10 | LOSS: 2.6262476444244385 | ACCURACY: 0.9092 | F1 MACRO: 0.9428 | F1 MICRO: 0.9446
# aspect: ACCURACY 0.9092 | F1 MACRO 0.9428 | F1 MICRO 0.9446
#               precision    recall  f1-score   support
#
#         fuel       0.93      1.00      0.96       187
#      machine       0.91      0.98      0.95       175
#       others       0.90      0.93      0.91       158
#         part       0.85      0.97      0.91       158
#        price       0.95      0.98      0.97       192
#      service       0.93      1.00      0.96       191
#
#    micro avg       0.91      0.98      0.94      1061
#    macro avg       0.91      0.98      0.94      1061
# weighted avg       0.91      0.98      0.94      1061
#  samples avg       0.92      0.98      0.94      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 17.256540298461914 | ACCURACY: 0.8557 | F1 MACRO: 0.8131 | F1 MICRO: 0.8557
# EPOCH 2 | LOSS: 13.247223854064941 | ACCURACY: 0.9353 | F1 MACRO: 0.9275 | F1 MICRO: 0.9353
# EPOCH 3 | LOSS: 11.932892799377441 | ACCURACY: 0.9303 | F1 MACRO: 0.921 | F1 MICRO: 0.9303
# EPOCH 4 | LOSS: 11.505753517150879 | ACCURACY: 0.8806 | F1 MACRO: 0.8546 | F1 MICRO: 0.8806
# EPOCH 5 | LOSS: 10.902396202087402 | ACCURACY: 0.9303 | F1 MACRO: 0.9198 | F1 MICRO: 0.9303
# in second
# EPOCH 6 | LOSS: 9.504494667053223 | ACCURACY: 0.9303 | F1 MACRO: 0.9204 | F1 MICRO: 0.9303
# in second
# EPOCH 7 | LOSS: 9.348638534545898 | ACCURACY: 0.9353 | F1 MACRO: 0.9264 | F1 MICRO: 0.9353
# in second
# EPOCH 8 | LOSS: 9.117121696472168 | ACCURACY: 0.9303 | F1 MACRO: 0.921 | F1 MICRO: 0.9303
# in second
# EPOCH 9 | LOSS: 9.188573837280273 | ACCURACY: 0.9254 | F1 MACRO: 0.9157 | F1 MICRO: 0.9254
# in second
# EPOCH 10 | LOSS: 9.050167083740234 | ACCURACY: 0.9353 | F1 MACRO: 0.9264 | F1 MICRO: 0.9353
# sentiment: ACCURACY 0.9353 | F1 MACRO 0.9275 | F1 MICRO 0.9353
#               precision    recall  f1-score   support
#
#     negative       0.86      0.95      0.90        64
#     positive       0.98      0.93      0.95       137
#
#     accuracy                           0.94       201
#    macro avg       0.92      0.94      0.93       201
# weighted avg       0.94      0.94      0.94       201
#
# --------------------------------------------------
# Iteration 135: Accuracy: 0.9097, F1 Micro: 0.9097, F1 Macro: 0.8136
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.82      0.90        11
#      neutral       0.96      1.00      0.98       181
#     positive       1.00      0.79      0.88        24
#
#     accuracy                           0.97       216
#    macro avg       0.99      0.87      0.92       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.82      0.88      0.85        16
#      neutral       0.91      0.97      0.94       167
#     positive       0.85      0.52      0.64        33
#
#     accuracy                           0.89       216
#    macro avg       0.86      0.79      0.81       216
# weighted avg       0.89      0.89      0.88       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.75      0.75        12
#      neutral       0.87      0.95      0.91       152
#     positive       0.81      0.58      0.67        52
#
#     accuracy                           0.85       216
#    macro avg       0.81      0.76      0.78       216
# weighted avg       0.85      0.85      0.84       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.52      0.65        23
#      neutral       0.87      0.98      0.92       152
#     positive       0.90      0.66      0.76        41
#
#     accuracy                           0.87       216
#    macro avg       0.87      0.72      0.78       216
# weighted avg       0.87      0.87      0.86       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.69      0.72        13
#      neutral       0.96      0.98      0.97       186
#     positive       0.77      0.59      0.67        17
#
#     accuracy                           0.94       216
#    macro avg       0.83      0.75      0.79       216
# weighted avg       0.93      0.94      0.93       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.57      0.73        14
#      neutral       0.93      1.00      0.97       185
#     positive       1.00      0.59      0.74        17
#
#     accuracy                           0.94       216
#    macro avg       0.98      0.72      0.81       216
# weighted avg       0.94      0.94      0.93       216
#
# Launching training on 2 GPUs.
# 598 598
# Nearest checkpoint: 540
# Threshold: 87841.0390625
# Samples above threshold: 73
# Acquired samples: 73
# Sampling duration: 8.56016731262207 seconds
# New train size: 208
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.6863019466400146 | ACCURACY: 0.7917 | F1 MACRO: 0.882 | F1 MICRO: 0.8834
# EPOCH 2 | LOSS: 3.2581167221069336 | ACCURACY: 0.8036 | F1 MACRO: 0.8874 | F1 MICRO: 0.889
# EPOCH 3 | LOSS: 2.8056366443634033 | ACCURACY: 0.8095 | F1 MACRO: 0.8907 | F1 MICRO: 0.8921
# EPOCH 4 | LOSS: 2.6573498249053955 | ACCURACY: 0.8348 | F1 MACRO: 0.9033 | F1 MICRO: 0.9046
# EPOCH 5 | LOSS: 2.591413736343384 | ACCURACY: 0.869 | F1 MACRO: 0.9202 | F1 MICRO: 0.9216
# EPOCH 6 | LOSS: 2.538625717163086 | ACCURACY: 0.9055 | F1 MACRO: 0.9416 | F1 MICRO: 0.9428
# EPOCH 7 | LOSS: 2.5578689575195312 | ACCURACY: 0.9182 | F1 MACRO: 0.9484 | F1 MICRO: 0.95
# EPOCH 8 | LOSS: 2.5028107166290283 | ACCURACY: 0.9315 | F1 MACRO: 0.9564 | F1 MICRO: 0.9579
# EPOCH 9 | LOSS: 2.3136749267578125 | ACCURACY: 0.9293 | F1 MACRO: 0.9541 | F1 MICRO: 0.9564
# EPOCH 10 | LOSS: 2.2810652256011963 | ACCURACY: 0.9397 | F1 MACRO: 0.9613 | F1 MICRO: 0.9628
# aspect: ACCURACY 0.9397 | F1 MACRO 0.9613 | F1 MICRO 0.9628
#               precision    recall  f1-score   support
#
#         fuel       0.97      1.00      0.98       187
#      machine       0.92      1.00      0.96       175
#       others       0.85      0.96      0.90       158
#         part       0.93      0.97      0.95       158
#        price       0.97      0.98      0.98       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.94      0.99      0.96      1061
#    macro avg       0.94      0.99      0.96      1061
# weighted avg       0.94      0.99      0.96      1061
#  samples avg       0.94      0.99      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 13.515509605407715 | ACCURACY: 0.8973 | F1 MACRO: 0.8872 | F1 MICRO: 0.8973
# EPOCH 2 | LOSS: 10.082549095153809 | ACCURACY: 0.942 | F1 MACRO: 0.9332 | F1 MICRO: 0.942
# EPOCH 3 | LOSS: 9.107523918151855 | ACCURACY: 0.9375 | F1 MACRO: 0.9294 | F1 MICRO: 0.9375
# EPOCH 4 | LOSS: 8.822298049926758 | ACCURACY: 0.933 | F1 MACRO: 0.926 | F1 MICRO: 0.933
# EPOCH 5 | LOSS: 8.219656944274902 | ACCURACY: 0.9241 | F1 MACRO: 0.9113 | F1 MICRO: 0.9241
# in second
# EPOCH 6 | LOSS: 7.374268054962158 | ACCURACY: 0.9375 | F1 MACRO: 0.9289 | F1 MICRO: 0.9375
# in second
# EPOCH 7 | LOSS: 7.295517921447754 | ACCURACY: 0.9375 | F1 MACRO: 0.9289 | F1 MICRO: 0.9375
# in second
# EPOCH 8 | LOSS: 7.060385227203369 | ACCURACY: 0.9375 | F1 MACRO: 0.9289 | F1 MICRO: 0.9375
# in second
# EPOCH 9 | LOSS: 7.041977405548096 | ACCURACY: 0.9375 | F1 MACRO: 0.9289 | F1 MICRO: 0.9375
# in second
# EPOCH 10 | LOSS: 7.032437324523926 | ACCURACY: 0.942 | F1 MACRO: 0.9346 | F1 MICRO: 0.942
# sentiment: ACCURACY 0.942 | F1 MACRO 0.9332 | F1 MICRO 0.942
#               precision    recall  f1-score   support
#
#     negative       0.94      0.88      0.91        74
#     positive       0.94      0.97      0.96       150
#
#     accuracy                           0.94       224
#    macro avg       0.94      0.93      0.93       224
# weighted avg       0.94      0.94      0.94       224
#
# --------------------------------------------------
# Iteration 208: Accuracy: 0.929, F1 Micro: 0.929, F1 Macro: 0.8606
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.98      1.00      0.99       181
#     positive       1.00      0.83      0.91        24
#
#     accuracy                           0.98       216
#    macro avg       0.99      0.94      0.97       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.62      0.74        16
#      neutral       0.92      1.00      0.96       167
#     positive       0.91      0.64      0.75        33
#
#     accuracy                           0.92       216
#    macro avg       0.91      0.75      0.82       216
# weighted avg       0.92      0.92      0.91       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.67      0.73        12
#      neutral       0.86      0.96      0.91       152
#     positive       0.86      0.60      0.70        52
#
#     accuracy                           0.86       216
#    macro avg       0.84      0.74      0.78       216
# weighted avg       0.86      0.86      0.85       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.81      0.74      0.77        23
#      neutral       0.92      0.97      0.94       152
#     positive       0.80      0.68      0.74        41
#
#     accuracy                           0.89       216
#    macro avg       0.84      0.80      0.82       216
# weighted avg       0.88      0.89      0.89       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.77      0.80        13
#      neutral       0.97      0.98      0.98       186
#     positive       0.76      0.76      0.76        17
#
#     accuracy                           0.95       216
#    macro avg       0.86      0.84      0.85       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.79      0.88        14
#      neutral       0.98      1.00      0.99       185
#     positive       0.94      0.94      0.94        17
#
#     accuracy                           0.98       216
#    macro avg       0.98      0.91      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Launching training on 2 GPUs.
# 591 591
# Nearest checkpoint: 540
# Threshold: 88297.6484375
# Samples above threshold: 66
# Acquired samples: 66
# Sampling duration: 10.732909440994263 seconds
# New train size: 274
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.3406271934509277 | ACCURACY: 0.7939 | F1 MACRO: 0.883 | F1 MICRO: 0.8844
# EPOCH 2 | LOSS: 2.8484458923339844 | ACCURACY: 0.8073 | F1 MACRO: 0.8888 | F1 MICRO: 0.8904
# EPOCH 3 | LOSS: 2.489616632461548 | ACCURACY: 0.8318 | F1 MACRO: 0.9016 | F1 MICRO: 0.9029
# EPOCH 4 | LOSS: 2.4197003841400146 | ACCURACY: 0.8854 | F1 MACRO: 0.9307 | F1 MICRO: 0.9315
# EPOCH 5 | LOSS: 2.4414169788360596 | ACCURACY: 0.9219 | F1 MACRO: 0.9507 | F1 MICRO: 0.952
# EPOCH 6 | LOSS: 2.333040714263916 | ACCURACY: 0.933 | F1 MACRO: 0.9572 | F1 MICRO: 0.9587
# EPOCH 7 | LOSS: 2.2690117359161377 | ACCURACY: 0.9375 | F1 MACRO: 0.959 | F1 MICRO: 0.9611
# EPOCH 8 | LOSS: 2.0975539684295654 | ACCURACY: 0.936 | F1 MACRO: 0.958 | F1 MICRO: 0.9602
# EPOCH 9 | LOSS: 2.030125379562378 | ACCURACY: 0.9435 | F1 MACRO: 0.9631 | F1 MICRO: 0.9647
# EPOCH 10 | LOSS: 1.9454408884048462 | ACCURACY: 0.9412 | F1 MACRO: 0.9607 | F1 MICRO: 0.9632
# aspect: ACCURACY 0.9435 | F1 MACRO 0.9631 | F1 MICRO 0.9647
#               precision    recall  f1-score   support
#
#         fuel       0.96      1.00      0.98       187
#      machine       0.94      0.98      0.96       175
#       others       0.89      0.94      0.92       158
#         part       0.93      0.97      0.95       158
#        price       0.98      0.98      0.98       192
#      service       0.97      1.00      0.99       191
#
#    micro avg       0.95      0.98      0.96      1061
#    macro avg       0.95      0.98      0.96      1061
# weighted avg       0.95      0.98      0.96      1061
#  samples avg       0.95      0.98      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 9.675779342651367 | ACCURACY: 0.898 | F1 MACRO: 0.8877 | F1 MICRO: 0.898
# EPOCH 2 | LOSS: 7.864829063415527 | ACCURACY: 0.9143 | F1 MACRO: 0.908 | F1 MICRO: 0.9143
# EPOCH 3 | LOSS: 7.059992790222168 | ACCURACY: 0.9347 | F1 MACRO: 0.9271 | F1 MICRO: 0.9347
# EPOCH 4 | LOSS: 6.767512321472168 | ACCURACY: 0.9347 | F1 MACRO: 0.9267 | F1 MICRO: 0.9347
# EPOCH 5 | LOSS: 6.312004566192627 | ACCURACY: 0.9143 | F1 MACRO: 0.908 | F1 MICRO: 0.9143
# EPOCH 6 | LOSS: 6.064499378204346 | ACCURACY: 0.9347 | F1 MACRO: 0.9275 | F1 MICRO: 0.9347
# EPOCH 7 | LOSS: 5.883539199829102 | ACCURACY: 0.9265 | F1 MACRO: 0.9194 | F1 MICRO: 0.9265
# EPOCH 8 | LOSS: 5.788822174072266 | ACCURACY: 0.9224 | F1 MACRO: 0.9156 | F1 MICRO: 0.9224
# EPOCH 9 | LOSS: 5.737505912780762 | ACCURACY: 0.9184 | F1 MACRO: 0.9109 | F1 MICRO: 0.9184
# in second
# EPOCH 10 | LOSS: 5.364486217498779 | ACCURACY: 0.9224 | F1 MACRO: 0.9156 | F1 MICRO: 0.9224
# sentiment: ACCURACY 0.9347 | F1 MACRO 0.9275 | F1 MICRO 0.9347
#               precision    recall  f1-score   support
#
#     negative       0.88      0.93      0.90        82
#     positive       0.96      0.94      0.95       163
#
#     accuracy                           0.93       245
#    macro avg       0.92      0.93      0.93       245
# weighted avg       0.94      0.93      0.94       245
#
# --------------------------------------------------
# Iteration 274: Accuracy: 0.9421, F1 Micro: 0.9421, F1 Macro: 0.8899
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.98      0.99      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.98       216
#    macro avg       0.98      0.94      0.96       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.81      0.84        16
#      neutral       0.94      0.99      0.97       167
#     positive       0.92      0.67      0.77        33
#
#     accuracy                           0.93       216
#    macro avg       0.91      0.82      0.86       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.71      0.83      0.77        12
#      neutral       0.89      0.94      0.92       152
#     positive       0.86      0.69      0.77        52
#
#     accuracy                           0.88       216
#    macro avg       0.82      0.82      0.82       216
# weighted avg       0.87      0.88      0.87       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.81      0.91      0.86        23
#      neutral       0.94      0.98      0.96       152
#     positive       0.94      0.71      0.81        41
#
#     accuracy                           0.92       216
#    macro avg       0.89      0.87      0.87       216
# weighted avg       0.92      0.92      0.92       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.77      0.83        13
#      neutral       0.99      0.98      0.98       186
#     positive       0.71      0.88      0.79        17
#
#     accuracy                           0.96       216
#    macro avg       0.87      0.88      0.87       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.98      1.00      0.99       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       0.99      0.93      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 553 553
# Nearest checkpoint: 540
# Threshold: 88030.625
# Samples above threshold: 59
# Acquired samples: 59
# Sampling duration: 12.166431188583374 seconds
# New train size: 333
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.387019634246826 | ACCURACY: 0.7909 | F1 MACRO: 0.8802 | F1 MICRO: 0.8822
# EPOCH 2 | LOSS: 2.855239152908325 | ACCURACY: 0.8013 | F1 MACRO: 0.8836 | F1 MICRO: 0.886
# EPOCH 3 | LOSS: 2.569342851638794 | ACCURACY: 0.8512 | F1 MACRO: 0.9117 | F1 MICRO: 0.913
# EPOCH 4 | LOSS: 2.52480149269104 | ACCURACY: 0.9174 | F1 MACRO: 0.948 | F1 MICRO: 0.9494
# EPOCH 5 | LOSS: 2.47233247756958 | ACCURACY: 0.9353 | F1 MACRO: 0.958 | F1 MICRO: 0.9599
# EPOCH 6 | LOSS: 2.3631370067596436 | ACCURACY: 0.9464 | F1 MACRO: 0.9648 | F1 MICRO: 0.9666
# EPOCH 7 | LOSS: 2.2104544639587402 | ACCURACY: 0.9464 | F1 MACRO: 0.9656 | F1 MICRO: 0.9667
# EPOCH 8 | LOSS: 2.095747232437134 | ACCURACY: 0.9494 | F1 MACRO: 0.9671 | F1 MICRO: 0.9685
# EPOCH 9 | LOSS: 2.0054314136505127 | ACCURACY: 0.9457 | F1 MACRO: 0.9641 | F1 MICRO: 0.966
# EPOCH 10 | LOSS: 1.9248483180999756 | ACCURACY: 0.9494 | F1 MACRO: 0.9662 | F1 MICRO: 0.9682
# aspect: ACCURACY 0.9494 | F1 MACRO 0.9671 | F1 MICRO 0.9685
#               precision    recall  f1-score   support
#
#         fuel       0.97      1.00      0.98       187
#      machine       0.94      0.99      0.96       175
#       others       0.91      0.94      0.93       158
#         part       0.95      0.98      0.96       158
#        price       0.98      0.98      0.98       192
#      service       0.97      1.00      0.98       191
#
#    micro avg       0.95      0.98      0.97      1061
#    macro avg       0.95      0.98      0.97      1061
# weighted avg       0.95      0.98      0.97      1061
#  samples avg       0.95      0.99      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 8.696455955505371 | ACCURACY: 0.9109 | F1 MACRO: 0.9008 | F1 MICRO: 0.9109
# EPOCH 2 | LOSS: 6.662829399108887 | ACCURACY: 0.9312 | F1 MACRO: 0.9236 | F1 MICRO: 0.9312
# EPOCH 3 | LOSS: 5.883691310882568 | ACCURACY: 0.9312 | F1 MACRO: 0.9236 | F1 MICRO: 0.9312
# EPOCH 4 | LOSS: 5.559196472167969 | ACCURACY: 0.9312 | F1 MACRO: 0.9236 | F1 MICRO: 0.9312
# EPOCH 5 | LOSS: 5.288222789764404 | ACCURACY: 0.9231 | F1 MACRO: 0.9125 | F1 MICRO: 0.9231
# EPOCH 6 | LOSS: 4.947622299194336 | ACCURACY: 0.9433 | F1 MACRO: 0.9365 | F1 MICRO: 0.9433
# EPOCH 7 | LOSS: 5.040227890014648 | ACCURACY: 0.915 | F1 MACRO: 0.902 | F1 MICRO: 0.915
# EPOCH 8 | LOSS: 4.922552108764648 | ACCURACY: 0.9352 | F1 MACRO: 0.9286 | F1 MICRO: 0.9352
# EPOCH 9 | LOSS: 4.8609724044799805 | ACCURACY: 0.9231 | F1 MACRO: 0.9119 | F1 MICRO: 0.9231
# in second
# EPOCH 10 | LOSS: 4.55137300491333 | ACCURACY: 0.9352 | F1 MACRO: 0.9278 | F1 MICRO: 0.9352
# sentiment: ACCURACY 0.9433 | F1 MACRO 0.9365 | F1 MICRO 0.9433
#               precision    recall  f1-score   support
#
#     negative       0.88      0.95      0.92        80
#     positive       0.98      0.94      0.96       167
#
#     accuracy                           0.94       247
#    macro avg       0.93      0.95      0.94       247
# weighted avg       0.95      0.94      0.94       247
#
# --------------------------------------------------
# Iteration 333: Accuracy: 0.9491, F1 Micro: 0.9491, F1 Macro: 0.9006
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.82      0.90        11
#      neutral       0.98      1.00      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.98       216
#    macro avg       0.98      0.91      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.69      0.79        16
#      neutral       0.94      1.00      0.97       167
#     positive       0.92      0.73      0.81        33
#
#     accuracy                           0.94       216
#    macro avg       0.93      0.80      0.86       216
# weighted avg       0.93      0.94      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.77      0.83      0.80        12
#      neutral       0.91      0.95      0.93       152
#     positive       0.88      0.73      0.80        52
#
#     accuracy                           0.89       216
#    macro avg       0.85      0.84      0.84       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.87      0.85        23
#      neutral       0.95      0.97      0.96       152
#     positive       0.89      0.80      0.85        41
#
#     accuracy                           0.93       216
#    macro avg       0.89      0.88      0.89       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.92      0.92        13
#      neutral       0.99      0.98      0.98       186
#     positive       0.79      0.88      0.83        17
#
#     accuracy                           0.97       216
#    macro avg       0.90      0.93      0.91       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.98      1.00      0.99       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       0.99      0.93      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 501 501
# Nearest checkpoint: 540
# Threshold: 88049.71875
# Samples above threshold: 54
# Acquired samples: 54
# Sampling duration: 12.995551109313965 seconds
# New train size: 387
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.397407054901123 | ACCURACY: 0.7932 | F1 MACRO: 0.8736 | F1 MICRO: 0.8794
# EPOCH 2 | LOSS: 2.7039597034454346 | ACCURACY: 0.8103 | F1 MACRO: 0.891 | F1 MICRO: 0.8924
# EPOCH 3 | LOSS: 2.5316247940063477 | ACCURACY: 0.8936 | F1 MACRO: 0.9341 | F1 MICRO: 0.9354
# EPOCH 4 | LOSS: 2.5178046226501465 | ACCURACY: 0.9256 | F1 MACRO: 0.9517 | F1 MICRO: 0.9539
# EPOCH 5 | LOSS: 2.381004810333252 | ACCURACY: 0.9435 | F1 MACRO: 0.9626 | F1 MICRO: 0.9648
# EPOCH 6 | LOSS: 2.194157600402832 | ACCURACY: 0.9487 | F1 MACRO: 0.9659 | F1 MICRO: 0.9679
# EPOCH 7 | LOSS: 2.0715417861938477 | ACCURACY: 0.9501 | F1 MACRO: 0.9673 | F1 MICRO: 0.9689
# EPOCH 8 | LOSS: 2.0120081901550293 | ACCURACY: 0.9449 | F1 MACRO: 0.9635 | F1 MICRO: 0.9654
# EPOCH 9 | LOSS: 1.9271421432495117 | ACCURACY: 0.9554 | F1 MACRO: 0.9708 | F1 MICRO: 0.9721
# EPOCH 10 | LOSS: 1.8771629333496094 | ACCURACY: 0.9501 | F1 MACRO: 0.9671 | F1 MICRO: 0.9687
# aspect: ACCURACY 0.9554 | F1 MACRO 0.9708 | F1 MICRO 0.9721
#               precision    recall  f1-score   support
#
#         fuel       0.98      0.99      0.99       187
#      machine       0.93      0.99      0.96       175
#       others       0.92      0.96      0.93       158
#         part       0.95      0.98      0.96       158
#        price       0.99      0.98      0.99       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.96      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 7.308804035186768 | ACCURACY: 0.9184 | F1 MACRO: 0.9089 | F1 MICRO: 0.9184
# EPOCH 2 | LOSS: 5.600947856903076 | ACCURACY: 0.9224 | F1 MACRO: 0.9151 | F1 MICRO: 0.9224
# EPOCH 3 | LOSS: 5.152128219604492 | ACCURACY: 0.9061 | F1 MACRO: 0.8936 | F1 MICRO: 0.9061
# EPOCH 4 | LOSS: 4.854996204376221 | ACCURACY: 0.9184 | F1 MACRO: 0.9083 | F1 MICRO: 0.9184
# EPOCH 5 | LOSS: 4.5850372314453125 | ACCURACY: 0.9265 | F1 MACRO: 0.9198 | F1 MICRO: 0.9265
# EPOCH 6 | LOSS: 4.340800762176514 | ACCURACY: 0.9265 | F1 MACRO: 0.9194 | F1 MICRO: 0.9265
# EPOCH 7 | LOSS: 4.263697624206543 | ACCURACY: 0.9102 | F1 MACRO: 0.8951 | F1 MICRO: 0.9102
# EPOCH 8 | LOSS: 4.2575364112854 | ACCURACY: 0.9347 | F1 MACRO: 0.9271 | F1 MICRO: 0.9347
# EPOCH 9 | LOSS: 4.211063861846924 | ACCURACY: 0.9306 | F1 MACRO: 0.9209 | F1 MICRO: 0.9306
# EPOCH 10 | LOSS: 4.21198844909668 | ACCURACY: 0.9347 | F1 MACRO: 0.9275 | F1 MICRO: 0.9347
# sentiment: ACCURACY 0.9347 | F1 MACRO 0.9275 | F1 MICRO 0.9347
#               precision    recall  f1-score   support
#
#     negative       0.86      0.95      0.90        80
#     positive       0.97      0.93      0.95       165
#
#     accuracy                           0.93       245
#    macro avg       0.92      0.94      0.93       245
# weighted avg       0.94      0.93      0.94       245
#
# --------------------------------------------------
# Iteration 387: Accuracy: 0.9444, F1 Micro: 0.9444, F1 Macro: 0.8887
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.97      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.62      0.74        16
#      neutral       0.93      0.99      0.96       167
#     positive       0.88      0.70      0.78        33
#
#     accuracy                           0.92       216
#    macro avg       0.91      0.77      0.83       216
# weighted avg       0.92      0.92      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.69      0.75      0.72        12
#      neutral       0.91      0.95      0.93       152
#     positive       0.89      0.75      0.81        52
#
#     accuracy                           0.89       216
#    macro avg       0.83      0.82      0.82       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.82      1.00      0.90        23
#      neutral       0.94      0.98      0.96       152
#     positive       0.93      0.66      0.77        41
#
#     accuracy                           0.92       216
#    macro avg       0.90      0.88      0.88       216
# weighted avg       0.92      0.92      0.92       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.85      0.85        13
#      neutral       0.99      0.98      0.98       186
#     positive       0.74      0.82      0.78        17
#
#     accuracy                           0.96       216
#    macro avg       0.86      0.88      0.87       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.98      1.00      0.99       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       0.99      0.93      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 455 455
# Nearest checkpoint: 540
# Threshold: 87873.7265625
# Samples above threshold: 48
# Acquired samples: 48
# Sampling duration: 13.894506931304932 seconds
# New train size: 435
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.201786994934082 | ACCURACY: 0.8043 | F1 MACRO: 0.887 | F1 MICRO: 0.8889
# EPOCH 2 | LOSS: 2.59043025970459 | ACCURACY: 0.8304 | F1 MACRO: 0.9014 | F1 MICRO: 0.9026
# EPOCH 3 | LOSS: 2.4187018871307373 | ACCURACY: 0.9115 | F1 MACRO: 0.9452 | F1 MICRO: 0.9464
# EPOCH 4 | LOSS: 2.373903274536133 | ACCURACY: 0.9345 | F1 MACRO: 0.958 | F1 MICRO: 0.9593
# EPOCH 5 | LOSS: 2.234325408935547 | ACCURACY: 0.9353 | F1 MACRO: 0.9582 | F1 MICRO: 0.9598
# EPOCH 6 | LOSS: 2.0537400245666504 | ACCURACY: 0.9472 | F1 MACRO: 0.9657 | F1 MICRO: 0.967
# EPOCH 7 | LOSS: 1.9789215326309204 | ACCURACY: 0.9531 | F1 MACRO: 0.9694 | F1 MICRO: 0.9707
# EPOCH 8 | LOSS: 1.8703227043151855 | ACCURACY: 0.9531 | F1 MACRO: 0.969 | F1 MICRO: 0.9706
# EPOCH 9 | LOSS: 1.7912770509719849 | ACCURACY: 0.9509 | F1 MACRO: 0.9672 | F1 MICRO: 0.9691
# EPOCH 10 | LOSS: 1.7741024494171143 | ACCURACY: 0.9554 | F1 MACRO: 0.971 | F1 MICRO: 0.9721
# aspect: ACCURACY 0.9554 | F1 MACRO 0.971 | F1 MICRO 0.9721
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.94      0.98      0.96       175
#       others       0.91      0.97      0.94       158
#         part       0.96      0.97      0.97       158
#        price       0.97      0.99      0.98       192
#      service       0.97      1.00      0.99       191
#
#    micro avg       0.96      0.99      0.97      1061
#    macro avg       0.96      0.99      0.97      1061
# weighted avg       0.96      0.99      0.97      1061
#  samples avg       0.96      0.99      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.677270889282227 | ACCURACY: 0.9255 | F1 MACRO: 0.9174 | F1 MICRO: 0.9255
# EPOCH 2 | LOSS: 5.148990631103516 | ACCURACY: 0.9216 | F1 MACRO: 0.9132 | F1 MICRO: 0.9216
# EPOCH 3 | LOSS: 4.707818031311035 | ACCURACY: 0.9333 | F1 MACRO: 0.9218 | F1 MICRO: 0.9333
# EPOCH 4 | LOSS: 4.296734809875488 | ACCURACY: 0.9373 | F1 MACRO: 0.9276 | F1 MICRO: 0.9373
# EPOCH 5 | LOSS: 4.024336814880371 | ACCURACY: 0.9294 | F1 MACRO: 0.9206 | F1 MICRO: 0.9294
# EPOCH 6 | LOSS: 3.9411003589630127 | ACCURACY: 0.9176 | F1 MACRO: 0.9076 | F1 MICRO: 0.9176
# EPOCH 7 | LOSS: 3.9376375675201416 | ACCURACY: 0.9333 | F1 MACRO: 0.9265 | F1 MICRO: 0.9333
# in second
# EPOCH 8 | LOSS: 3.5758471488952637 | ACCURACY: 0.9294 | F1 MACRO: 0.9215 | F1 MICRO: 0.9294
# in second
# EPOCH 9 | LOSS: 3.501849412918091 | ACCURACY: 0.9294 | F1 MACRO: 0.9215 | F1 MICRO: 0.9294
# in second
# EPOCH 10 | LOSS: 3.4694597721099854 | ACCURACY: 0.9294 | F1 MACRO: 0.9215 | F1 MICRO: 0.9294
# sentiment: ACCURACY 0.9373 | F1 MACRO 0.9276 | F1 MICRO 0.9373
#               precision    recall  f1-score   support
#
#     negative       0.92      0.88      0.90        83
#     positive       0.94      0.97      0.95       172
#
#     accuracy                           0.94       255
#    macro avg       0.93      0.92      0.93       255
# weighted avg       0.94      0.94      0.94       255
#
# --------------------------------------------------
# Iteration 435: Accuracy: 0.9491, F1 Micro: 0.9491, F1 Macro: 0.9002
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.92      0.92      0.92        24
#
#     accuracy                           0.98       216
#    macro avg       0.97      0.94      0.95       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.69      0.79        16
#      neutral       0.96      0.98      0.97       167
#     positive       0.80      0.85      0.82        33
#
#     accuracy                           0.94       216
#    macro avg       0.89      0.84      0.86       216
# weighted avg       0.94      0.94      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.77      0.83      0.80        12
#      neutral       0.91      0.96      0.94       152
#     positive       0.88      0.73      0.80        52
#
#     accuracy                           0.90       216
#    macro avg       0.86      0.84      0.85       216
# weighted avg       0.90      0.90      0.90       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.87      0.85        23
#      neutral       0.96      0.99      0.97       152
#     positive       0.89      0.76      0.82        41
#
#     accuracy                           0.93       216
#    macro avg       0.89      0.87      0.88       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.92      0.92        13
#      neutral       0.99      0.98      0.98       186
#     positive       0.79      0.88      0.83        17
#
#     accuracy                           0.97       216
#    macro avg       0.90      0.93      0.91       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.98      1.00      0.99       185
#     positive       1.00      0.88      0.94        17
#
#     accuracy                           0.98       216
#    macro avg       0.99      0.91      0.95       216
# weighted avg       0.98      0.98      0.98       216
#
# Launching training on 2 GPUs.
# 414 414
# Nearest checkpoint: 540
# Threshold: 87908.8671875
# Samples above threshold: 43
# Acquired samples: 43
# Sampling duration: 14.371964931488037 seconds
# New train size: 478
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.1657769680023193 | ACCURACY: 0.7946 | F1 MACRO: 0.8834 | F1 MICRO: 0.8849
# EPOCH 2 | LOSS: 2.5041956901550293 | ACCURACY: 0.8281 | F1 MACRO: 0.9003 | F1 MICRO: 0.9016
# EPOCH 3 | LOSS: 2.39518666267395 | ACCURACY: 0.9219 | F1 MACRO: 0.9501 | F1 MICRO: 0.9517
# EPOCH 4 | LOSS: 2.363696575164795 | ACCURACY: 0.9427 | F1 MACRO: 0.9623 | F1 MICRO: 0.9642
# EPOCH 5 | LOSS: 2.1909265518188477 | ACCURACY: 0.939 | F1 MACRO: 0.9603 | F1 MICRO: 0.9623
# EPOCH 6 | LOSS: 2.031707763671875 | ACCURACY: 0.9457 | F1 MACRO: 0.9641 | F1 MICRO: 0.9659
# EPOCH 7 | LOSS: 1.923336386680603 | ACCURACY: 0.9501 | F1 MACRO: 0.9673 | F1 MICRO: 0.9687
# EPOCH 8 | LOSS: 1.8643702268600464 | ACCURACY: 0.9509 | F1 MACRO: 0.9679 | F1 MICRO: 0.9694
# EPOCH 9 | LOSS: 1.7790590524673462 | ACCURACY: 0.9546 | F1 MACRO: 0.9701 | F1 MICRO: 0.9715
# EPOCH 10 | LOSS: 1.7334213256835938 | ACCURACY: 0.9606 | F1 MACRO: 0.9737 | F1 MICRO: 0.9751
# aspect: ACCURACY 0.9606 | F1 MACRO 0.9737 | F1 MICRO 0.9751
#               precision    recall  f1-score   support
#
#         fuel       0.98      0.99      0.99       187
#      machine       0.95      0.99      0.97       175
#       others       0.95      0.92      0.93       158
#         part       0.97      0.97      0.97       158
#        price       0.98      0.98      0.98       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.97      0.98      0.98      1061
#    macro avg       0.97      0.98      0.97      1061
# weighted avg       0.97      0.98      0.97      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.337184429168701 | ACCURACY: 0.9248 | F1 MACRO: 0.9141 | F1 MICRO: 0.9248
# EPOCH 2 | LOSS: 4.80206823348999 | ACCURACY: 0.9323 | F1 MACRO: 0.9207 | F1 MICRO: 0.9323
# EPOCH 3 | LOSS: 4.334577560424805 | ACCURACY: 0.9398 | F1 MACRO: 0.9313 | F1 MICRO: 0.9398
# EPOCH 4 | LOSS: 4.165288925170898 | ACCURACY: 0.9624 | F1 MACRO: 0.9556 | F1 MICRO: 0.9624
# EPOCH 5 | LOSS: 3.8494155406951904 | ACCURACY: 0.9549 | F1 MACRO: 0.9484 | F1 MICRO: 0.9549
# EPOCH 6 | LOSS: 3.7174339294433594 | ACCURACY: 0.9323 | F1 MACRO: 0.9244 | F1 MICRO: 0.9323
# EPOCH 7 | LOSS: 3.732069730758667 | ACCURACY: 0.9511 | F1 MACRO: 0.9429 | F1 MICRO: 0.9511
# in second
# EPOCH 8 | LOSS: 3.3741748332977295 | ACCURACY: 0.9511 | F1 MACRO: 0.944 | F1 MICRO: 0.9511
# in second
# EPOCH 9 | LOSS: 3.325556755065918 | ACCURACY: 0.9511 | F1 MACRO: 0.9443 | F1 MICRO: 0.9511
# in second
# EPOCH 10 | LOSS: 3.359679937362671 | ACCURACY: 0.9474 | F1 MACRO: 0.9399 | F1 MICRO: 0.9474
# sentiment: ACCURACY 0.9624 | F1 MACRO 0.9556 | F1 MICRO 0.9624
#               precision    recall  f1-score   support
#
#     negative       0.95      0.93      0.94        82
#     positive       0.97      0.98      0.97       184
#
#     accuracy                           0.96       266
#    macro avg       0.96      0.95      0.96       266
# weighted avg       0.96      0.96      0.96       266
#
# --------------------------------------------------
# Iteration 478: Accuracy: 0.9506, F1 Micro: 0.9506, F1 Macro: 0.9037
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.92      0.92      0.92        24
#
#     accuracy                           0.98       216
#    macro avg       0.97      0.94      0.95       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.62      0.74        16
#      neutral       0.95      0.98      0.96       167
#     positive       0.79      0.79      0.79        33
#
#     accuracy                           0.92       216
#    macro avg       0.88      0.80      0.83       216
# weighted avg       0.92      0.92      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.83      0.83        12
#      neutral       0.93      0.92      0.93       152
#     positive       0.78      0.81      0.79        52
#
#     accuracy                           0.89       216
#    macro avg       0.85      0.85      0.85       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.88      0.91      0.89        23
#      neutral       0.98      0.99      0.98       152
#     positive       0.92      0.88      0.90        41
#
#     accuracy                           0.96       216
#    macro avg       0.93      0.93      0.93       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.85      0.88        13
#      neutral       0.99      0.98      0.99       186
#     positive       0.79      0.88      0.83        17
#
#     accuracy                           0.97       216
#    macro avg       0.90      0.90      0.90       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.98      1.00      0.99       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       0.99      0.93      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 378 378
# Nearest checkpoint: 540
# Threshold: 88000.40625
# Samples above threshold: 39
# Acquired samples: 39
# Sampling duration: 15.722748756408691 seconds
# New train size: 517
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.222226619720459 | ACCURACY: 0.8162 | F1 MACRO: 0.8928 | F1 MICRO: 0.8945
# EPOCH 2 | LOSS: 2.5604569911956787 | ACCURACY: 0.8527 | F1 MACRO: 0.9124 | F1 MICRO: 0.9132
# EPOCH 3 | LOSS: 2.5237696170806885 | ACCURACY: 0.9382 | F1 MACRO: 0.9603 | F1 MICRO: 0.9617
# EPOCH 4 | LOSS: 2.3572123050689697 | ACCURACY: 0.9397 | F1 MACRO: 0.9609 | F1 MICRO: 0.9626
# EPOCH 5 | LOSS: 2.1468253135681152 | ACCURACY: 0.9509 | F1 MACRO: 0.9676 | F1 MICRO: 0.9694
# EPOCH 6 | LOSS: 1.9958195686340332 | ACCURACY: 0.9531 | F1 MACRO: 0.9691 | F1 MICRO: 0.9706
# EPOCH 7 | LOSS: 1.8977611064910889 | ACCURACY: 0.9501 | F1 MACRO: 0.9663 | F1 MICRO: 0.9685
# EPOCH 8 | LOSS: 1.8678150177001953 | ACCURACY: 0.9509 | F1 MACRO: 0.9673 | F1 MICRO: 0.969
# ...
#    macro avg       0.97      0.98      0.97      1061
# weighted avg       0.97      0.98      0.97      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.8208107948303223 | ACCURACY: 0.9301 | F1 MACRO: 0.9185 | F1 MICRO: 0.9301
# EPOCH 2 | LOSS: 2.7392334938049316 | ACCURACY: 0.9044 | F1 MACRO: 0.8954 | F1 MICRO: 0.9044
# EPOCH 3 | LOSS: 2.4836740493774414 | ACCURACY: 0.9301 | F1 MACRO: 0.919 | F1 MICRO: 0.9301
# EPOCH 4 | LOSS: 2.3432199954986572 | ACCURACY: 0.9375 | F1 MACRO: 0.928 | F1 MICRO: 0.9375
# EPOCH 5 | LOSS: 2.16595458984375 | ACCURACY: 0.9485 | F1 MACRO: 0.9401 | F1 MICRO: 0.9485
# EPOCH 6 | LOSS: 2.031418800354004 | ACCURACY: 0.9559 | F1 MACRO: 0.9483 | F1 MICRO: 0.9559
# EPOCH 7 | LOSS: 2.0669045448303223 | ACCURACY: 0.9338 | F1 MACRO: 0.924 | F1 MICRO: 0.9338
# EPOCH 8 | LOSS: 2.011918544769287 | ACCURACY: 0.9228 | F1 MACRO: 0.914 | F1 MICRO: 0.9228
# EPOCH 9 | LOSS: 2.0196187496185303 | ACCURACY: 0.9301 | F1 MACRO: 0.9204 | F1 MICRO: 0.9301
# in second
# EPOCH 10 | LOSS: 1.9101430177688599 | ACCURACY: 0.9265 | F1 MACRO: 0.9174 | F1 MICRO: 0.9265
# sentiment: ACCURACY 0.9559 | F1 MACRO 0.9483 | F1 MICRO 0.9559
#               precision    recall  f1-score   support
#
#     negative       0.93      0.93      0.93        84
#     positive       0.97      0.97      0.97       188
#
#     accuracy                           0.96       272
#    macro avg       0.95      0.95      0.95       272
# weighted avg       0.96      0.96      0.96       272
#
# --------------------------------------------------
# Iteration 831: Accuracy: 0.9537, F1 Micro: 0.9537, F1 Macro: 0.9114
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.92      0.92      0.92        24
#
#     accuracy                           0.98       216
#    macro avg       0.97      0.94      0.95       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.69      0.79        16
#      neutral       0.96      0.98      0.97       167
#     positive       0.79      0.82      0.81        33
#
#     accuracy                           0.93       216
#    macro avg       0.89      0.83      0.85       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.83      0.87        12
#      neutral       0.94      0.91      0.93       152
#     positive       0.77      0.85      0.81        52
#
#     accuracy                           0.89       216
#    macro avg       0.87      0.86      0.87       216
# weighted avg       0.90      0.89      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.88      0.91      0.89        23
#      neutral       0.98      0.98      0.98       152
#     positive       0.90      0.88      0.89        41
#
#     accuracy                           0.95       216
#    macro avg       0.92      0.92      0.92       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.85      0.85        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.82      0.82      0.82        17
#
#     accuracy                           0.97       216
#    macro avg       0.89      0.89      0.89       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.99      1.00      1.00       185
#     positive       1.00      1.00      1.00        17
#
#     accuracy                           1.00       216
#    macro avg       1.00      0.98      0.99       216
# weighted avg       1.00      1.00      1.00       216
#
# Launching training on 2 GPUs.
# 33 33
# Nearest checkpoint: 864
# Threshold: 88203.078125
# Samples above threshold: 4
# Acquired samples: 25
# Sampling duration: 20.57028603553772 seconds
# New train size: 856
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.8902764320373535 | ACCURACY: 0.8095 | F1 MACRO: 0.8908 | F1 MICRO: 0.8921
# EPOCH 2 | LOSS: 2.3772685527801514 | ACCURACY: 0.9375 | F1 MACRO: 0.9598 | F1 MICRO: 0.9613
# EPOCH 3 | LOSS: 2.2080671787261963 | ACCURACY: 0.9501 | F1 MACRO: 0.9671 | F1 MICRO: 0.9688
# EPOCH 4 | LOSS: 1.9708067178726196 | ACCURACY: 0.9568 | F1 MACRO: 0.9717 | F1 MICRO: 0.973
# EPOCH 5 | LOSS: 1.8378357887268066 | ACCURACY: 0.9628 | F1 MACRO: 0.9756 | F1 MICRO: 0.9767
# EPOCH 6 | LOSS: 1.761825680732727 | ACCURACY: 0.9598 | F1 MACRO: 0.9735 | F1 MICRO: 0.9748
# EPOCH 7 | LOSS: 1.6988184452056885 | ACCURACY: 0.9561 | F1 MACRO: 0.9709 | F1 MICRO: 0.9724
# EPOCH 8 | LOSS: 1.6641533374786377 | ACCURACY: 0.9576 | F1 MACRO: 0.9711 | F1 MICRO: 0.9732
# in second
# EPOCH 9 | LOSS: 1.5611129999160767 | ACCURACY: 0.9509 | F1 MACRO: 0.9678 | F1 MICRO: 0.9694
# in second
# EPOCH 10 | LOSS: 1.5118275880813599 | ACCURACY: 0.9576 | F1 MACRO: 0.9721 | F1 MICRO: 0.9735
# aspect: ACCURACY 0.9628 | F1 MACRO 0.9756 | F1 MICRO 0.9767
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.95      0.99      0.97       175
#       others       0.91      0.97      0.94       158
#         part       0.97      0.98      0.97       158
#        price       0.99      0.98      0.99       192
#      service       0.99      1.00      0.99       191
#
#    micro avg       0.97      0.99      0.98      1061
#    macro avg       0.96      0.99      0.98      1061
# weighted avg       0.97      0.99      0.98      1061
#  samples avg       0.96      0.99      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.5920474529266357 | ACCURACY: 0.9151 | F1 MACRO: 0.9077 | F1 MICRO: 0.9151
# EPOCH 2 | LOSS: 2.5619170665740967 | ACCURACY: 0.9228 | F1 MACRO: 0.9144 | F1 MICRO: 0.9228
# EPOCH 3 | LOSS: 2.3591058254241943 | ACCURACY: 0.9382 | F1 MACRO: 0.9304 | F1 MICRO: 0.9382
# EPOCH 4 | LOSS: 2.172349214553833 | ACCURACY: 0.9344 | F1 MACRO: 0.9266 | F1 MICRO: 0.9344
# EPOCH 5 | LOSS: 2.082862138748169 | ACCURACY: 0.9421 | F1 MACRO: 0.9353 | F1 MICRO: 0.9421
# EPOCH 6 | LOSS: 2.0060131549835205 | ACCURACY: 0.9382 | F1 MACRO: 0.9312 | F1 MICRO: 0.9382
# EPOCH 7 | LOSS: 1.9652496576309204 | ACCURACY: 0.9459 | F1 MACRO: 0.9391 | F1 MICRO: 0.9459
# EPOCH 8 | LOSS: 2.001781702041626 | ACCURACY: 0.9305 | F1 MACRO: 0.9225 | F1 MICRO: 0.9305
# EPOCH 9 | LOSS: 1.947737693786621 | ACCURACY: 0.9344 | F1 MACRO: 0.9258 | F1 MICRO: 0.9344
# EPOCH 10 | LOSS: 1.9031914472579956 | ACCURACY: 0.9382 | F1 MACRO: 0.9291 | F1 MICRO: 0.9382
# sentiment: ACCURACY 0.9459 | F1 MACRO 0.9391 | F1 MICRO 0.9459
#               precision    recall  f1-score   support
#
#     negative       0.89      0.95      0.92        83
#     positive       0.98      0.94      0.96       176
#
#     accuracy                           0.95       259
#    macro avg       0.93      0.95      0.94       259
# weighted avg       0.95      0.95      0.95       259
#
# --------------------------------------------------
# Iteration 856: Accuracy: 0.9545, F1 Micro: 0.9545, F1 Macro: 0.9165
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.97      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.81      0.84        16
#      neutral       0.95      0.98      0.96       167
#     positive       0.89      0.76      0.82        33
#
#     accuracy                           0.94       216
#    macro avg       0.90      0.85      0.87       216
# weighted avg       0.93      0.94      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.90      0.75      0.82        12
#      neutral       0.91      0.95      0.93       152
#     positive       0.85      0.75      0.80        52
#
#     accuracy                           0.89       216
#    macro avg       0.88      0.82      0.85       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.79      1.00      0.88        23
#      neutral       0.98      0.97      0.98       152
#     positive       0.94      0.83      0.88        41
#
#     accuracy                           0.95       216
#    macro avg       0.91      0.93      0.91       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.92      0.92        13
#      neutral       0.99      0.98      0.99       186
#     positive       0.83      0.88      0.86        17
#
#     accuracy                           0.97       216
#    macro avg       0.92      0.93      0.92       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.99      1.00      1.00       185
#     positive       0.94      1.00      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.95      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 8 8
# Nearest checkpoint: 864
# Threshold: 88261.59375
# Samples above threshold: 1
# Acquired samples: 8
# Sampling duration: 20.84052848815918 seconds
# New train size: 864
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.871044635772705 | ACCURACY: 0.8103 | F1 MACRO: 0.8909 | F1 MICRO: 0.8925
# EPOCH 2 | LOSS: 2.3864283561706543 | ACCURACY: 0.9375 | F1 MACRO: 0.9593 | F1 MICRO: 0.9611
# EPOCH 3 | LOSS: 2.2238357067108154 | ACCURACY: 0.9494 | F1 MACRO: 0.9669 | F1 MICRO: 0.9685
# EPOCH 4 | LOSS: 1.9901009798049927 | ACCURACY: 0.9621 | F1 MACRO: 0.9754 | F1 MICRO: 0.9764
# EPOCH 5 | LOSS: 1.8392783403396606 | ACCURACY: 0.9606 | F1 MACRO: 0.9739 | F1 MICRO: 0.9753
# EPOCH 6 | LOSS: 1.7593647241592407 | ACCURACY: 0.9583 | F1 MACRO: 0.9722 | F1 MICRO: 0.9737
# EPOCH 7 | LOSS: 1.6909253597259521 | ACCURACY: 0.9613 | F1 MACRO: 0.9744 | F1 MICRO: 0.9757
# in second
# EPOCH 8 | LOSS: 1.6022608280181885 | ACCURACY: 0.942 | F1 MACRO: 0.9634 | F1 MICRO: 0.9643
# in second
# EPOCH 9 | LOSS: 1.5488992929458618 | ACCURACY: 0.9494 | F1 MACRO: 0.9675 | F1 MICRO: 0.9686
# in second
# EPOCH 10 | LOSS: 1.5209952592849731 | ACCURACY: 0.9546 | F1 MACRO: 0.9705 | F1 MICRO: 0.9717
# aspect: ACCURACY 0.9621 | F1 MACRO 0.9754 | F1 MICRO 0.9764
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.95      1.00      0.97       175
#       others       0.88      0.99      0.93       158
#         part       0.97      0.98      0.97       158
#        price       0.99      0.99      0.99       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.96      0.99      0.98      1061
#    macro avg       0.96      0.99      0.98      1061
# weighted avg       0.96      0.99      0.98      1061
#  samples avg       0.96      0.99      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.41459321975708 | ACCURACY: 0.9036 | F1 MACRO: 0.8928 | F1 MICRO: 0.9036
# EPOCH 2 | LOSS: 2.6044065952301025 | ACCURACY: 0.9398 | F1 MACRO: 0.9339 | F1 MICRO: 0.9398
# EPOCH 3 | LOSS: 2.309446096420288 | ACCURACY: 0.9438 | F1 MACRO: 0.9382 | F1 MICRO: 0.9438
# EPOCH 4 | LOSS: 2.051710605621338 | ACCURACY: 0.9398 | F1 MACRO: 0.9302 | F1 MICRO: 0.9398
# EPOCH 5 | LOSS: 1.9146181344985962 | ACCURACY: 0.9598 | F1 MACRO: 0.9556 | F1 MICRO: 0.9598
# EPOCH 6 | LOSS: 1.8715341091156006 | ACCURACY: 0.9357 | F1 MACRO: 0.9297 | F1 MICRO: 0.9357
# EPOCH 7 | LOSS: 1.8326107263565063 | ACCURACY: 0.9317 | F1 MACRO: 0.9259 | F1 MICRO: 0.9317
# EPOCH 8 | LOSS: 1.9041279554367065 | ACCURACY: 0.9357 | F1 MACRO: 0.9286 | F1 MICRO: 0.9357
# in second
# EPOCH 9 | LOSS: 1.776479959487915 | ACCURACY: 0.9357 | F1 MACRO: 0.9293 | F1 MICRO: 0.9357
# in second
# EPOCH 10 | LOSS: 1.72129487991333 | ACCURACY: 0.9357 | F1 MACRO: 0.9293 | F1 MICRO: 0.9357
# sentiment: ACCURACY 0.9598 | F1 MACRO 0.9556 | F1 MICRO 0.9598
#               precision    recall  f1-score   support
#
#     negative       0.90      0.99      0.94        82
#     positive       0.99      0.95      0.97       167
#
#     accuracy                           0.96       249
#    macro avg       0.95      0.97      0.96       249
# weighted avg       0.96      0.96      0.96       249
#
# --------------------------------------------------
# Iteration 864: Accuracy: 0.9545, F1 Micro: 0.9545, F1 Macro: 0.9063
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      1.00      0.99       181
#     positive       1.00      0.92      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.97      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.75      0.77        16
#      neutral       0.94      0.99      0.96       167
#     positive       0.92      0.73      0.81        33
#
#     accuracy                           0.93       216
#    macro avg       0.89      0.82      0.85       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.82      0.75      0.78        12
#      neutral       0.90      0.97      0.93       152
#     positive       0.93      0.71      0.80        52
#
#     accuracy                           0.90       216
#    macro avg       0.88      0.81      0.84       216
# weighted avg       0.90      0.90      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.85      1.00      0.92        23
#      neutral       0.98      0.98      0.98       152
#     positive       0.95      0.85      0.90        41
#
#     accuracy                           0.96       216
#    macro avg       0.93      0.94      0.93       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.92      0.86        13
#      neutral       0.99      0.98      0.99       186
#     positive       0.81      0.76      0.79        17
#
#     accuracy                           0.96       216
#    macro avg       0.87      0.89      0.88       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.99      1.00      0.99       185
#     positive       0.94      0.94      0.94        17
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.93      0.95       216
# weighted avg       0.99      0.99      0.99       216
#
# Total sampling time: 373.91 seconds
# Total runtime: 2865.639190196991 seconds

# %% [markdown]
# ## RUN 5

# %%
active_learning(seeds[4], 4)
# Out:
# ===============================================
# TRIAL 5
# Random seed: 94
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.6675004959106445 | ACCURACY: 0.6421 | F1 MACRO: 0.7118 | F1 MICRO: 0.7611
# EPOCH 2 | LOSS: 3.466869592666626 | ACCURACY: 0.7783 | F1 MACRO: 0.8695 | F1 MICRO: 0.8733
# EPOCH 3 | LOSS: 3.1926214694976807 | ACCURACY: 0.7842 | F1 MACRO: 0.8765 | F1 MICRO: 0.8787
# EPOCH 4 | LOSS: 3.4439992904663086 | ACCURACY: 0.7909 | F1 MACRO: 0.8808 | F1 MICRO: 0.8826
# EPOCH 5 | LOSS: 3.221564292907715 | ACCURACY: 0.7887 | F1 MACRO: 0.8789 | F1 MICRO: 0.881
# EPOCH 6 | LOSS: 3.0427441596984863 | ACCURACY: 0.7835 | F1 MACRO: 0.8741 | F1 MICRO: 0.8771
# EPOCH 7 | LOSS: 3.0137059688568115 | ACCURACY: 0.7746 | F1 MACRO: 0.8644 | F1 MICRO: 0.8696
# in second
# EPOCH 8 | LOSS: 2.810563087463379 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# in second
# EPOCH 9 | LOSS: 2.66365909576416 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# in second
# EPOCH 10 | LOSS: 2.5783791542053223 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# aspect: ACCURACY 0.7909 | F1 MACRO 0.8808 | F1 MICRO 0.8826
#               precision    recall  f1-score   support
#
#         fuel       0.83      1.00      0.91       187
#      machine       0.78      1.00      0.88       175
#       others       0.71      1.00      0.83       158
#         part       0.72      0.97      0.83       158
#        price       0.86      1.00      0.92       192
#      service       0.85      1.00      0.92       191
#
#    micro avg       0.79      1.00      0.88      1061
#    macro avg       0.79      0.99      0.88      1061
# weighted avg       0.80      1.00      0.88      1061
#  samples avg       0.79      1.00      0.88      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.2192490100860596 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# EPOCH 2 | LOSS: 2.4921493530273438 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# EPOCH 3 | LOSS: 2.877603530883789 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# EPOCH 4 | LOSS: 2.834310531616211 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# EPOCH 5 | LOSS: 2.767664909362793 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# EPOCH 6 | LOSS: 2.7191824913024902 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# EPOCH 7 | LOSS: 2.236833095550537 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# EPOCH 8 | LOSS: 2.378979206085205 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# EPOCH 9 | LOSS: 2.2884602546691895 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# EPOCH 10 | LOSS: 2.3449676036834717 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# sentiment: ACCURACY 0.8889 | F1 MACRO 0.4706 | F1 MICRO 0.8889
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00         1
#     positive       0.89      1.00      0.94         8
#
#     accuracy                           0.89         9
#    macro avg       0.44      0.50      0.47         9
# weighted avg       0.79      0.89      0.84         9
#
# --------------------------------------------------
# Iteration 54: Accuracy: 0.7863, F1 Micro: 0.7863, F1 Macro: 0.2973
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        11
#      neutral       0.84      1.00      0.91       181
#     positive       0.00      0.00      0.00        24
#
#     accuracy                           0.84       216
#    macro avg       0.28      0.33      0.30       216
# weighted avg       0.70      0.84      0.76       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        16
#      neutral       0.77      1.00      0.87       167
#     positive       0.00      0.00      0.00        33
#
#     accuracy                           0.77       216
#    macro avg       0.26      0.33      0.29       216
# weighted avg       0.60      0.77      0.67       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        12
#      neutral       0.70      1.00      0.83       152
#     positive       0.00      0.00      0.00        52
#
#     accuracy                           0.70       216
#    macro avg       0.23      0.33      0.28       216
# weighted avg       0.50      0.70      0.58       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        23
#      neutral       0.71      0.96      0.81       152
#     positive       0.22      0.05      0.08        41
#
#     accuracy                           0.69       216
#    macro avg       0.31      0.34      0.30       216
# weighted avg       0.54      0.69      0.59       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        13
#      neutral       0.86      1.00      0.93       186
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.86       216
#    macro avg       0.29      0.33      0.31       216
# weighted avg       0.74      0.86      0.80       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        14
#      neutral       0.86      1.00      0.92       185
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.86       216
#    macro avg       0.29      0.33      0.31       216
# weighted avg       0.73      0.86      0.79       216
#
# Launching training on 2 GPUs.
# 31 31
# Nearest checkpoint: 540
# Threshold: 87665.1875
# Samples above threshold: 81
# Acquired samples: 81
# Sampling duration: 6.168029546737671 seconds
# New train size: 135
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.8139567375183105 | ACCURACY: 0.7887 | F1 MACRO: 0.8796 | F1 MICRO: 0.8814
# EPOCH 2 | LOSS: 3.6622438430786133 | ACCURACY: 0.7902 | F1 MACRO: 0.8809 | F1 MICRO: 0.8825
# EPOCH 3 | LOSS: 3.330231189727783 | ACCURACY: 0.7984 | F1 MACRO: 0.8842 | F1 MICRO: 0.8861
# EPOCH 4 | LOSS: 3.102445602416992 | ACCURACY: 0.8147 | F1 MACRO: 0.891 | F1 MICRO: 0.8934
# EPOCH 5 | LOSS: 2.8150815963745117 | ACCURACY: 0.8311 | F1 MACRO: 0.9016 | F1 MICRO: 0.9029
# EPOCH 6 | LOSS: 2.8133957386016846 | ACCURACY: 0.8467 | F1 MACRO: 0.9087 | F1 MICRO: 0.91
# EPOCH 7 | LOSS: 2.81895112991333 | ACCURACY: 0.8668 | F1 MACRO: 0.9187 | F1 MICRO: 0.9203
# EPOCH 8 | LOSS: 2.776585817337036 | ACCURACY: 0.8854 | F1 MACRO: 0.9276 | F1 MICRO: 0.9299
# EPOCH 9 | LOSS: 2.7756474018096924 | ACCURACY: 0.8981 | F1 MACRO: 0.9353 | F1 MICRO: 0.9375
# EPOCH 10 | LOSS: 2.790303945541382 | ACCURACY: 0.8973 | F1 MACRO: 0.9327 | F1 MICRO: 0.9365
# aspect: ACCURACY 0.8981 | F1 MACRO 0.9353 | F1 MICRO 0.9375
#               precision    recall  f1-score   support
#
#         fuel       0.90      0.99      0.95       187
#      machine       0.86      0.98      0.92       175
#       others       0.88      0.89      0.88       158
#         part       0.91      0.94      0.92       158
#        price       0.95      0.99      0.97       192
#      service       0.95      0.99      0.97       191
#
#    micro avg       0.91      0.97      0.94      1061
#    macro avg       0.91      0.97      0.94      1061
# weighted avg       0.91      0.97      0.94      1061
#  samples avg       0.91      0.97      0.93      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 18.008743286132812 | ACCURACY: 0.8955 | F1 MACRO: 0.8791 | F1 MICRO: 0.8955
# EPOCH 2 | LOSS: 16.458065032958984 | ACCURACY: 0.9091 | F1 MACRO: 0.8952 | F1 MICRO: 0.9091
# EPOCH 3 | LOSS: 12.409502983093262 | ACCURACY: 0.9091 | F1 MACRO: 0.8908 | F1 MICRO: 0.9091
# EPOCH 4 | LOSS: 11.744114875793457 | ACCURACY: 0.9045 | F1 MACRO: 0.8887 | F1 MICRO: 0.9045
# EPOCH 5 | LOSS: 10.922460556030273 | ACCURACY: 0.9136 | F1 MACRO: 0.8928 | F1 MICRO: 0.9136
# EPOCH 6 | LOSS: 10.743260383605957 | ACCURACY: 0.9136 | F1 MACRO: 0.8967 | F1 MICRO: 0.9136
# EPOCH 7 | LOSS: 10.724037170410156 | ACCURACY: 0.9091 | F1 MACRO: 0.8952 | F1 MICRO: 0.9091
# EPOCH 8 | LOSS: 10.15051555633545 | ACCURACY: 0.9091 | F1 MACRO: 0.8898 | F1 MICRO: 0.9091
# EPOCH 9 | LOSS: 9.981106758117676 | ACCURACY: 0.9136 | F1 MACRO: 0.8976 | F1 MICRO: 0.9136
# EPOCH 10 | LOSS: 9.9426851272583 | ACCURACY: 0.9045 | F1 MACRO: 0.8878 | F1 MICRO: 0.9045
# sentiment: ACCURACY 0.9136 | F1 MACRO 0.8976 | F1 MICRO 0.9136
#               precision    recall  f1-score   support
#
#     negative       0.79      0.93      0.86        61
#     positive       0.97      0.91      0.94       159
#
#     accuracy                           0.91       220
#    macro avg       0.88      0.92      0.90       220
# weighted avg       0.92      0.91      0.92       220
#
# --------------------------------------------------
# Iteration 135: Accuracy: 0.9066, F1 Micro: 0.9066, F1 Macro: 0.8058
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.55      0.71        11
#      neutral       0.92      1.00      0.96       181
#     positive       1.00      0.54      0.70        24
#
#     accuracy                           0.93       216
#    macro avg       0.97      0.70      0.79       216
# weighted avg       0.93      0.93      0.92       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.60      0.38      0.46        16
#      neutral       0.88      0.97      0.92       167
#     positive       0.86      0.55      0.67        33
#
#     accuracy                           0.86       216
#    macro avg       0.78      0.63      0.68       216
# weighted avg       0.85      0.86      0.85       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.64      0.75      0.69        12
#      neutral       0.90      0.89      0.89       152
#     positive       0.71      0.71      0.71        52
#
#     accuracy                           0.84       216
#    macro avg       0.75      0.78      0.77       216
# weighted avg       0.84      0.84      0.84       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.82      0.78      0.80        23
#      neutral       0.92      0.96      0.94       152
#     positive       0.86      0.76      0.81        41
#
#     accuracy                           0.90       216
#    macro avg       0.87      0.83      0.85       216
# weighted avg       0.90      0.90      0.90       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.77      0.83        13
#      neutral       0.96      0.99      0.98       186
#     positive       1.00      0.71      0.83        17
#
#     accuracy                           0.96       216
#    macro avg       0.96      0.82      0.88       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.71      0.83        14
#      neutral       0.95      0.99      0.97       185
#     positive       0.92      0.71      0.80        17
#
#     accuracy                           0.95       216
#    macro avg       0.96      0.80      0.87       216
# weighted avg       0.95      0.95      0.95       216
#
# Launching training on 2 GPUs.
# 592 592
# Nearest checkpoint: 540
# Threshold: 87841.0390625
# Samples above threshold: 73
# Acquired samples: 73
# Sampling duration: 9.469178438186646 seconds
# New train size: 208
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.599086046218872 | ACCURACY: 0.7909 | F1 MACRO: 0.8814 | F1 MICRO: 0.883
# EPOCH 2 | LOSS: 3.2839410305023193 | ACCURACY: 0.7954 | F1 MACRO: 0.8837 | F1 MICRO: 0.8852
# EPOCH 3 | LOSS: 2.989680767059326 | ACCURACY: 0.8095 | F1 MACRO: 0.8891 | F1 MICRO: 0.891
# EPOCH 4 | LOSS: 2.735168218612671 | ACCURACY: 0.8318 | F1 MACRO: 0.9004 | F1 MICRO: 0.902
# EPOCH 5 | LOSS: 2.669278383255005 | ACCURACY: 0.8482 | F1 MACRO: 0.9085 | F1 MICRO: 0.9107
# EPOCH 6 | LOSS: 2.5975747108459473 | ACCURACY: 0.8973 | F1 MACRO: 0.9349 | F1 MICRO: 0.937
# EPOCH 7 | LOSS: 2.5926320552825928 | ACCURACY: 0.9241 | F1 MACRO: 0.9515 | F1 MICRO: 0.9531
# EPOCH 8 | LOSS: 2.5093605518341064 | ACCURACY: 0.9286 | F1 MACRO: 0.953 | F1 MICRO: 0.9556
# EPOCH 9 | LOSS: 2.455566167831421 | ACCURACY: 0.9315 | F1 MACRO: 0.9545 | F1 MICRO: 0.9571
# EPOCH 10 | LOSS: 2.326477289199829 | ACCURACY: 0.9375 | F1 MACRO: 0.9588 | F1 MICRO: 0.9609
# aspect: ACCURACY 0.9375 | F1 MACRO 0.9588 | F1 MICRO 0.9609
#               precision    recall  f1-score   support
#
#         fuel       0.97      1.00      0.98       187
#      machine       0.93      0.99      0.96       175
#       others       0.89      0.91      0.90       158
#         part       0.94      0.96      0.95       158
#        price       0.98      0.97      0.98       192
#      service       0.97      1.00      0.99       191
#
#    micro avg       0.95      0.97      0.96      1061
#    macro avg       0.95      0.97      0.96      1061
# weighted avg       0.95      0.97      0.96      1061
#  samples avg       0.95      0.97      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 14.2909517288208 | ACCURACY: 0.904 | F1 MACRO: 0.8918 | F1 MICRO: 0.904
# EPOCH 2 | LOSS: 11.207864761352539 | ACCURACY: 0.928 | F1 MACRO: 0.9167 | F1 MICRO: 0.928
# EPOCH 3 | LOSS: 9.82664966583252 | ACCURACY: 0.936 | F1 MACRO: 0.926 | F1 MICRO: 0.936
# EPOCH 4 | LOSS: 9.577275276184082 | ACCURACY: 0.928 | F1 MACRO: 0.9143 | F1 MICRO: 0.928
# EPOCH 5 | LOSS: 8.924214363098145 | ACCURACY: 0.94 | F1 MACRO: 0.9299 | F1 MICRO: 0.94
# EPOCH 6 | LOSS: 8.568194389343262 | ACCURACY: 0.924 | F1 MACRO: 0.9112 | F1 MICRO: 0.924
# EPOCH 7 | LOSS: 8.198186874389648 | ACCURACY: 0.94 | F1 MACRO: 0.9299 | F1 MICRO: 0.94
# EPOCH 8 | LOSS: 8.021529197692871 | ACCURACY: 0.928 | F1 MACRO: 0.9161 | F1 MICRO: 0.928
# EPOCH 9 | LOSS: 7.980473041534424 | ACCURACY: 0.932 | F1 MACRO: 0.9226 | F1 MICRO: 0.932
# EPOCH 10 | LOSS: 7.788412570953369 | ACCURACY: 0.924 | F1 MACRO: 0.9146 | F1 MICRO: 0.924
# sentiment: ACCURACY 0.94 | F1 MACRO 0.9299 | F1 MICRO 0.94
#               precision    recall  f1-score   support
#
#     negative       0.90      0.91      0.90        77
#     positive       0.96      0.95      0.96       173
#
#     accuracy                           0.94       250
#    macro avg       0.93      0.93      0.93       250
# weighted avg       0.94      0.94      0.94       250
#
# --------------------------------------------------
# Iteration 208: Accuracy: 0.936, F1 Micro: 0.936, F1 Macro: 0.8767
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.90      0.82      0.86        11
#      neutral       0.98      1.00      0.99       181
#     positive       0.95      0.88      0.91        24
#
#     accuracy                           0.98       216
#    macro avg       0.95      0.90      0.92       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.62      0.71        16
#      neutral       0.94      0.99      0.96       167
#     positive       0.86      0.73      0.79        33
#
#     accuracy                           0.92       216
#    macro avg       0.88      0.78      0.82       216
# weighted avg       0.92      0.92      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.82      0.75      0.78        12
#      neutral       0.88      0.90      0.89       152
#     positive       0.72      0.69      0.71        52
#
#     accuracy                           0.84       216
#    macro avg       0.81      0.78      0.79       216
# weighted avg       0.84      0.84      0.84       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.82      0.78      0.80        23
#      neutral       0.96      0.98      0.97       152
#     positive       0.87      0.80      0.84        41
#
#     accuracy                           0.93       216
#    macro avg       0.88      0.86      0.87       216
# weighted avg       0.92      0.93      0.92       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.92      0.89        13
#      neutral       0.99      0.98      0.99       186
#     positive       0.88      0.88      0.88        17
#
#     accuracy                           0.97       216
#    macro avg       0.91      0.93      0.92       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.97      1.00      0.99       185
#     positive       1.00      0.82      0.90        17
#
#     accuracy                           0.98       216
#    macro avg       0.99      0.89      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Launching training on 2 GPUs.
# 612 612
# Nearest checkpoint: 540
# Threshold: 88024.984375
# Samples above threshold: 66
# Acquired samples: 66
# Sampling duration: 11.177231788635254 seconds
# New train size: 274
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.431581735610962 | ACCURACY: 0.7902 | F1 MACRO: 0.8806 | F1 MICRO: 0.8823
# EPOCH 2 | LOSS: 2.9337680339813232 | ACCURACY: 0.8073 | F1 MACRO: 0.889 | F1 MICRO: 0.8907
# EPOCH 3 | LOSS: 2.581017017364502 | ACCURACY: 0.8296 | F1 MACRO: 0.8998 | F1 MICRO: 0.9012
# EPOCH 4 | LOSS: 2.4379725456237793 | ACCURACY: 0.8616 | F1 MACRO: 0.9164 | F1 MICRO: 0.9178
# EPOCH 5 | LOSS: 2.4064838886260986 | ACCURACY: 0.9077 | F1 MACRO: 0.941 | F1 MICRO: 0.943
# EPOCH 6 | LOSS: 2.4037210941314697 | ACCURACY: 0.9182 | F1 MACRO: 0.9466 | F1 MICRO: 0.949
# EPOCH 7 | LOSS: 2.3583338260650635 | ACCURACY: 0.9397 | F1 MACRO: 0.961 | F1 MICRO: 0.9627
# EPOCH 8 | LOSS: 2.2593791484832764 | ACCURACY: 0.9397 | F1 MACRO: 0.9589 | F1 MICRO: 0.962
# EPOCH 9 | LOSS: 2.1067285537719727 | ACCURACY: 0.9509 | F1 MACRO: 0.9675 | F1 MICRO: 0.9692
# EPOCH 10 | LOSS: 1.9539074897766113 | ACCURACY: 0.9435 | F1 MACRO: 0.9617 | F1 MICRO: 0.9645
# aspect: ACCURACY 0.9509 | F1 MACRO 0.9675 | F1 MICRO 0.9692
#               precision    recall  f1-score   support
#
#         fuel       0.97      1.00      0.99       187
#      machine       0.95      0.99      0.97       175
#       others       0.91      0.92      0.91       158
#         part       0.95      0.98      0.97       158
#        price       0.98      0.98      0.98       192
#      service       0.97      1.00      0.99       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.96      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 10.187921524047852 | ACCURACY: 0.9331 | F1 MACRO: 0.9199 | F1 MICRO: 0.9331
# EPOCH 2 | LOSS: 9.308337211608887 | ACCURACY: 0.9291 | F1 MACRO: 0.9179 | F1 MICRO: 0.9291
# EPOCH 3 | LOSS: 7.193199157714844 | ACCURACY: 0.9331 | F1 MACRO: 0.9205 | F1 MICRO: 0.9331
# EPOCH 4 | LOSS: 6.585947513580322 | ACCURACY: 0.937 | F1 MACRO: 0.9231 | F1 MICRO: 0.937
# EPOCH 5 | LOSS: 6.40494441986084 | ACCURACY: 0.937 | F1 MACRO: 0.9243 | F1 MICRO: 0.937
# EPOCH 6 | LOSS: 6.0622124671936035 | ACCURACY: 0.9134 | F1 MACRO: 0.8925 | F1 MICRO: 0.9134
# EPOCH 7 | LOSS: 6.072523593902588 | ACCURACY: 0.9331 | F1 MACRO: 0.9232 | F1 MICRO: 0.9331
# EPOCH 8 | LOSS: 5.874697685241699 | ACCURACY: 0.9331 | F1 MACRO: 0.9205 | F1 MICRO: 0.9331
# in second
# EPOCH 9 | LOSS: 5.5413498878479 | ACCURACY: 0.9409 | F1 MACRO: 0.9309 | F1 MICRO: 0.9409
# in second
# EPOCH 10 | LOSS: 5.408499240875244 | ACCURACY: 0.937 | F1 MACRO: 0.9275 | F1 MICRO: 0.937
# sentiment: ACCURACY 0.937 | F1 MACRO 0.9243 | F1 MICRO 0.937
#               precision    recall  f1-score   support
#
#     negative       0.92      0.87      0.89        77
#     positive       0.94      0.97      0.96       177
#
#     accuracy                           0.94       254
#    macro avg       0.93      0.92      0.92       254
# weighted avg       0.94      0.94      0.94       254
#
# --------------------------------------------------
# Iteration 274: Accuracy: 0.939, F1 Micro: 0.939, F1 Macro: 0.883
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.99      1.00      0.99       181
#     positive       1.00      0.96      0.98        24
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.96      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.90      0.56      0.69        16
#      neutral       0.94      0.99      0.96       167
#     positive       0.84      0.79      0.81        33
#
#     accuracy                           0.93       216
#    macro avg       0.89      0.78      0.82       216
# weighted avg       0.92      0.93      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.90      0.75      0.82        12
#      neutral       0.91      0.89      0.90       152
#     positive       0.72      0.79      0.75        52
#
#     accuracy                           0.86       216
#    macro avg       0.84      0.81      0.82       216
# weighted avg       0.86      0.86      0.86       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.78      0.82        23
#      neutral       0.95      0.99      0.97       152
#     positive       0.86      0.78      0.82        41
#
#     accuracy                           0.93       216
#    macro avg       0.89      0.85      0.87       216
# weighted avg       0.92      0.93      0.92       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.85      0.88        13
#      neutral       0.98      0.99      0.98       186
#     positive       0.88      0.82      0.85        17
#
#     accuracy                           0.97       216
#    macro avg       0.92      0.89      0.90       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.86      0.89        14
#      neutral       0.97      0.99      0.98       185
#     positive       0.93      0.76      0.84        17
#
#     accuracy                           0.97       216
#    macro avg       0.94      0.87      0.90       216
# weighted avg       0.97      0.97      0.97       216
#
# Launching training on 2 GPUs.
# 558 558
# Nearest checkpoint: 540
# Threshold: 88134.2109375
# Samples above threshold: 59
# Acquired samples: 59
# Sampling duration: 12.20759654045105 seconds
# New train size: 333
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.4353995323181152 | ACCURACY: 0.7976 | F1 MACRO: 0.8848 | F1 MICRO: 0.8863
# EPOCH 2 | LOSS: 2.95615553855896 | ACCURACY: 0.7991 | F1 MACRO: 0.8856 | F1 MICRO: 0.887
# EPOCH 3 | LOSS: 2.6000173091888428 | ACCURACY: 0.846 | F1 MACRO: 0.9086 | F1 MICRO: 0.9099
# EPOCH 4 | LOSS: 2.5323898792266846 | ACCURACY: 0.9115 | F1 MACRO: 0.9444 | F1 MICRO: 0.9459
# EPOCH 5 | LOSS: 2.4407382011413574 | ACCURACY: 0.939 | F1 MACRO: 0.9607 | F1 MICRO: 0.9622
# EPOCH 6 | LOSS: 2.4031293392181396 | ACCURACY: 0.9375 | F1 MACRO: 0.9593 | F1 MICRO: 0.961
# EPOCH 7 | LOSS: 2.250518798828125 | ACCURACY: 0.9449 | F1 MACRO: 0.9637 | F1 MICRO: 0.9655
# EPOCH 8 | LOSS: 2.0980021953582764 | ACCURACY: 0.9479 | F1 MACRO: 0.9655 | F1 MICRO: 0.9675
# EPOCH 9 | LOSS: 2.0971944332122803 | ACCURACY: 0.9405 | F1 MACRO: 0.9602 | F1 MICRO: 0.9625
# EPOCH 10 | LOSS: 1.9769282341003418 | ACCURACY: 0.9494 | F1 MACRO: 0.9671 | F1 MICRO: 0.9686
# aspect: ACCURACY 0.9494 | F1 MACRO 0.9671 | F1 MICRO 0.9686
#               precision    recall  f1-score   support
#
#         fuel       0.97      1.00      0.99       187
#      machine       0.94      0.99      0.96       175
#       others       0.90      0.95      0.93       158
#         part       0.92      0.99      0.95       158
#        price       0.98      0.99      0.99       192
#      service       0.97      0.99      0.98       191
#
#    micro avg       0.95      0.99      0.97      1061
#    macro avg       0.95      0.99      0.97      1061
# weighted avg       0.95      0.99      0.97      1061
#  samples avg       0.95      0.99      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 8.599764823913574 | ACCURACY: 0.9262 | F1 MACRO: 0.9152 | F1 MICRO: 0.9262
# EPOCH 2 | LOSS: 7.215545177459717 | ACCURACY: 0.9139 | F1 MACRO: 0.9065 | F1 MICRO: 0.9139
# EPOCH 3 | LOSS: 5.881021022796631 | ACCURACY: 0.9508 | F1 MACRO: 0.9438 | F1 MICRO: 0.9508
# EPOCH 4 | LOSS: 5.47715425491333 | ACCURACY: 0.9508 | F1 MACRO: 0.9449 | F1 MICRO: 0.9508
# EPOCH 5 | LOSS: 5.3622612953186035 | ACCURACY: 0.9344 | F1 MACRO: 0.9265 | F1 MICRO: 0.9344
# EPOCH 6 | LOSS: 5.049375534057617 | ACCURACY: 0.9221 | F1 MACRO: 0.913 | F1 MICRO: 0.9221
# EPOCH 7 | LOSS: 4.968472480773926 | ACCURACY: 0.9385 | F1 MACRO: 0.93 | F1 MICRO: 0.9385
# in second
# EPOCH 8 | LOSS: 4.535847187042236 | ACCURACY: 0.9426 | F1 MACRO: 0.9349 | F1 MICRO: 0.9426
# in second
# EPOCH 9 | LOSS: 4.356258869171143 | ACCURACY: 0.9426 | F1 MACRO: 0.9353 | F1 MICRO: 0.9426
# in second
# EPOCH 10 | LOSS: 4.374497413635254 | ACCURACY: 0.9467 | F1 MACRO: 0.9397 | F1 MICRO: 0.9467
# sentiment: ACCURACY 0.9508 | F1 MACRO 0.9449 | F1 MICRO 0.9508
#               precision    recall  f1-score   support
#
#     negative       0.88      0.97      0.93        78
#     positive       0.99      0.94      0.96       166
#
#     accuracy                           0.95       244
#    macro avg       0.94      0.96      0.94       244
# weighted avg       0.95      0.95      0.95       244
#
# --------------------------------------------------
# Iteration 333: Accuracy: 0.9421, F1 Micro: 0.9421, F1 Macro: 0.8898
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.91      0.91        11
#      neutral       0.98      0.99      0.99       181
#     positive       0.95      0.88      0.91        24
#
#     accuracy                           0.98       216
#    macro avg       0.95      0.93      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.75      0.77        16
#      neutral       0.95      0.99      0.97       167
#     positive       0.93      0.76      0.83        33
#
#     accuracy                           0.94       216
#    macro avg       0.89      0.83      0.86       216
# weighted avg       0.93      0.94      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.90      0.75      0.82        12
#      neutral       0.90      0.93      0.92       152
#     positive       0.80      0.75      0.77        52
#
#     accuracy                           0.88       216
#    macro avg       0.87      0.81      0.84       216
# weighted avg       0.88      0.88      0.88       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.79      0.96      0.86        23
#      neutral       0.93      0.98      0.96       152
#     positive       0.96      0.66      0.78        41
#
#     accuracy                           0.92       216
#    macro avg       0.89      0.87      0.87       216
# weighted avg       0.92      0.92      0.91       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.77      0.87        13
#      neutral       0.97      0.99      0.98       186
#     positive       0.88      0.82      0.85        17
#
#     accuracy                           0.97       216
#    macro avg       0.95      0.86      0.90       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.93      0.93        14
#      neutral       0.98      0.99      0.99       185
#     positive       1.00      0.82      0.90        17
#
#     accuracy                           0.98       216
#    macro avg       0.97      0.92      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Launching training on 2 GPUs.
# 503 503
# Nearest checkpoint: 540
# Threshold: 88276.796875
# Samples above threshold: 54
# Acquired samples: 54
# Sampling duration: 13.01156234741211 seconds
# New train size: 387
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.384955406188965 | ACCURACY: 0.7939 | F1 MACRO: 0.8831 | F1 MICRO: 0.8845
# EPOCH 2 | LOSS: 2.817275047302246 | ACCURACY: 0.8192 | F1 MACRO: 0.8946 | F1 MICRO: 0.8964
# EPOCH 3 | LOSS: 2.5426268577575684 | ACCURACY: 0.875 | F1 MACRO: 0.9253 | F1 MICRO: 0.9261
# EPOCH 4 | LOSS: 2.48720121383667 | ACCURACY: 0.9211 | F1 MACRO: 0.9487 | F1 MICRO: 0.951
# EPOCH 5 | LOSS: 2.4304442405700684 | ACCURACY: 0.9435 | F1 MACRO: 0.963 | F1 MICRO: 0.9647
# EPOCH 6 | LOSS: 2.2754952907562256 | ACCURACY: 0.9509 | F1 MACRO: 0.9677 | F1 MICRO: 0.9694
# EPOCH 7 | LOSS: 2.148559808731079 | ACCURACY: 0.9435 | F1 MACRO: 0.9627 | F1 MICRO: 0.9647
# EPOCH 8 | LOSS: 1.9801123142242432 | ACCURACY: 0.9449 | F1 MACRO: 0.9634 | F1 MICRO: 0.9654
# EPOCH 9 | LOSS: 1.9430108070373535 | ACCURACY: 0.9501 | F1 MACRO: 0.967 | F1 MICRO: 0.9688
# in second
# EPOCH 10 | LOSS: 1.8249443769454956 | ACCURACY: 0.8348 | F1 MACRO: 0.9044 | F1 MICRO: 0.905
# aspect: ACCURACY 0.9509 | F1 MACRO 0.9677 | F1 MICRO 0.9694
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.93      0.98      0.96       175
#       others       0.91      0.94      0.92       158
#         part       0.93      0.99      0.96       158
#        price       0.98      0.99      0.99       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.95      0.98      0.97      1061
#    macro avg       0.95      0.98      0.97      1061
# weighted avg       0.95      0.98      0.97      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 7.087156772613525 | ACCURACY: 0.9274 | F1 MACRO: 0.918 | F1 MICRO: 0.9274
# EPOCH 2 | LOSS: 5.355593204498291 | ACCURACY: 0.9476 | F1 MACRO: 0.9406 | F1 MICRO: 0.9476
# EPOCH 3 | LOSS: 4.886850357055664 | ACCURACY: 0.9315 | F1 MACRO: 0.9178 | F1 MICRO: 0.9315
# EPOCH 4 | LOSS: 4.448341369628906 | ACCURACY: 0.9315 | F1 MACRO: 0.9233 | F1 MICRO: 0.9315
# EPOCH 5 | LOSS: 4.2674407958984375 | ACCURACY: 0.9476 | F1 MACRO: 0.9402 | F1 MICRO: 0.9476
# EPOCH 6 | LOSS: 4.041298866271973 | ACCURACY: 0.9274 | F1 MACRO: 0.9152 | F1 MICRO: 0.9274
# EPOCH 7 | LOSS: 4.015575885772705 | ACCURACY: 0.9435 | F1 MACRO: 0.9345 | F1 MICRO: 0.9435
# EPOCH 8 | LOSS: 3.9546217918395996 | ACCURACY: 0.9355 | F1 MACRO: 0.9276 | F1 MICRO: 0.9355
# in second
# EPOCH 9 | LOSS: 3.7394447326660156 | ACCURACY: 0.9435 | F1 MACRO: 0.9354 | F1 MICRO: 0.9435
# in second
# EPOCH 10 | LOSS: 3.6405820846557617 | ACCURACY: 0.9435 | F1 MACRO: 0.9358 | F1 MICRO: 0.9435
# sentiment: ACCURACY 0.9476 | F1 MACRO 0.9402 | F1 MICRO 0.9476
#               precision    recall  f1-score   support
#
#     negative       0.89      0.95      0.92        78
#     positive       0.98      0.95      0.96       170
#
#     accuracy                           0.95       248
#    macro avg       0.93      0.95      0.94       248
# weighted avg       0.95      0.95      0.95       248
#
# --------------------------------------------------
# Iteration 387: Accuracy: 0.9444, F1 Micro: 0.9444, F1 Macro: 0.8948
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.91      0.91        11
#      neutral       0.99      1.00      0.99       181
#     positive       1.00      0.92      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       0.97      0.94      0.95       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.79      0.69      0.73        16
#      neutral       0.95      0.98      0.96       167
#     positive       0.86      0.76      0.81        33
#
#     accuracy                           0.93       216
#    macro avg       0.87      0.81      0.83       216
# weighted avg       0.92      0.93      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.90      0.75      0.82        12
#      neutral       0.91      0.92      0.92       152
#     positive       0.77      0.77      0.77        52
#
#     accuracy                           0.88       216
#    macro avg       0.86      0.81      0.83       216
# weighted avg       0.87      0.88      0.87       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.87      0.83        23
#      neutral       0.93      0.99      0.96       152
#     positive       1.00      0.71      0.83        41
#
#     accuracy                           0.93       216
#    macro avg       0.91      0.86      0.87       216
# weighted avg       0.93      0.93      0.92       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.92      0.96        13
#      neutral       0.98      0.99      0.99       186
#     positive       0.88      0.82      0.85        17
#
#     accuracy                           0.98       216
#    macro avg       0.95      0.91      0.93       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.93      0.93        14
#      neutral       0.98      0.99      0.99       185
#     positive       1.00      0.82      0.90        17
#
#     accuracy                           0.98       216
#    macro avg       0.97      0.92      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Launching training on 2 GPUs.
# 445 445
# Nearest checkpoint: 540
# Threshold: 88240.53125
# Samples above threshold: 48
# Acquired samples: 48
# Sampling duration: 13.810314893722534 seconds
# New train size: 435
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.2531256675720215 | ACCURACY: 0.7909 | F1 MACRO: 0.8814 | F1 MICRO: 0.883
# EPOCH 2 | LOSS: 2.617176055908203 | ACCURACY: 0.8281 | F1 MACRO: 0.9002 | F1 MICRO: 0.901
# EPOCH 3 | LOSS: 2.4363155364990234 | ACCURACY: 0.8817 | F1 MACRO: 0.9286 | F1 MICRO: 0.9294
# EPOCH 4 | LOSS: 2.3946948051452637 | ACCURACY: 0.9234 | F1 MACRO: 0.9489 | F1 MICRO: 0.9522
# EPOCH 5 | LOSS: 2.3154139518737793 | ACCURACY: 0.9457 | F1 MACRO: 0.9639 | F1 MICRO: 0.9659
# EPOCH 6 | LOSS: 2.1564695835113525 | ACCURACY: 0.9472 | F1 MACRO: 0.9654 | F1 MICRO: 0.967
# EPOCH 7 | LOSS: 2.0350146293640137 | ACCURACY: 0.9516 | F1 MACRO: 0.9676 | F1 MICRO: 0.9697
# EPOCH 8 | LOSS: 1.9114434719085693 | ACCURACY: 0.9509 | F1 MACRO: 0.9676 | F1 MICRO: 0.9693
# EPOCH 9 | LOSS: 1.8182759284973145 | ACCURACY: 0.9539 | F1 MACRO: 0.9693 | F1 MICRO: 0.971
# EPOCH 10 | LOSS: 1.778761386871338 | ACCURACY: 0.9539 | F1 MACRO: 0.9694 | F1 MICRO: 0.9711
# aspect: ACCURACY 0.9539 | F1 MACRO 0.9694 | F1 MICRO 0.9711
#               precision    recall  f1-score   support
#
#         fuel       0.98      0.99      0.99       187
#      machine       0.93      0.99      0.96       175
#       others       0.94      0.92      0.93       158
#         part       0.95      0.98      0.97       158
#        price       0.98      0.99      0.99       192
#      service       0.98      0.99      0.99       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.96      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.92338228225708 | ACCURACY: 0.8872 | F1 MACRO: 0.8607 | F1 MICRO: 0.8872
# EPOCH 2 | LOSS: 6.07710599899292 | ACCURACY: 0.9398 | F1 MACRO: 0.9304 | F1 MICRO: 0.9398
# EPOCH 3 | LOSS: 4.6412529945373535 | ACCURACY: 0.9173 | F1 MACRO: 0.9024 | F1 MICRO: 0.9173
# EPOCH 4 | LOSS: 4.226527214050293 | ACCURACY: 0.9361 | F1 MACRO: 0.928 | F1 MICRO: 0.9361
# EPOCH 5 | LOSS: 4.007226943969727 | ACCURACY: 0.9286 | F1 MACRO: 0.916 | F1 MICRO: 0.9286
# in second
# EPOCH 6 | LOSS: 3.7478408813476562 | ACCURACY: 0.9436 | F1 MACRO: 0.935 | F1 MICRO: 0.9436
# in second
# EPOCH 7 | LOSS: 3.5666821002960205 | ACCURACY: 0.9361 | F1 MACRO: 0.9253 | F1 MICRO: 0.9361
# in second
# EPOCH 8 | LOSS: 3.6448771953582764 | ACCURACY: 0.9398 | F1 MACRO: 0.9308 | F1 MICRO: 0.9398
# in second
# sentiment: ACCURACY 0.9398 | F1 MACRO 0.9304 | F1 MICRO 0.9398
#               precision    recall  f1-score   support
#
#     negative       0.87      0.94      0.90        81
#     positive       0.97      0.94      0.96       185
#
#     accuracy                           0.94       266
#    macro avg       0.92      0.94      0.93       266
# weighted avg       0.94      0.94      0.94       266
#
# --------------------------------------------------
# Iteration 435: Accuracy: 0.9429, F1 Micro: 0.9429, F1 Macro: 0.9012
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.98      0.99      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.98       216
#    macro avg       0.98      0.94      0.96       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.75      0.80        16
#      neutral       0.94      0.98      0.96       167
#     positive       0.89      0.73      0.80        33
#
#     accuracy                           0.93       216
#    macro avg       0.89      0.82      0.85       216
# weighted avg       0.92      0.93      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.69      0.75      0.72        12
#      neutral       0.93      0.86      0.89       152
#     positive       0.69      0.83      0.75        52
#
#     accuracy                           0.85       216
#    macro avg       0.77      0.81      0.79       216
# weighted avg       0.86      0.85      0.85       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.79      0.96      0.86        23
#      neutral       0.94      0.99      0.96       152
#     positive       1.00      0.71      0.83        41
#
#     accuracy                           0.93       216
#    macro avg       0.91      0.88      0.89       216
# weighted avg       0.94      0.93      0.93       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.92      0.96        13
#      neutral       0.98      0.99      0.99       186
#     positive       0.88      0.82      0.85        17
#
#     accuracy                           0.98       216
#    macro avg       0.95      0.91      0.93       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.93      1.00      0.97        14
#      neutral       1.00      0.99      1.00       185
#     positive       1.00      1.00      1.00        17
#
#     accuracy                           1.00       216
#    macro avg       0.98      1.00      0.99       216
# weighted avg       1.00      1.00      1.00       216
#
# Launching training on 2 GPUs.
# 416 416
# Nearest checkpoint: 540
# Threshold: 88235.140625
# Samples above threshold: 43
# Acquired samples: 43
# Sampling duration: 14.725785732269287 seconds
# New train size: 478
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.206023693084717 | ACCURACY: 0.8036 | F1 MACRO: 0.8879 | F1 MICRO: 0.8893
# EPOCH 2 | LOSS: 2.620683431625366 | ACCURACY: 0.8363 | F1 MACRO: 0.904 | F1 MICRO: 0.9045
# EPOCH 3 | LOSS: 2.3738510608673096 | ACCURACY: 0.9167 | F1 MACRO: 0.9473 | F1 MICRO: 0.9485
# EPOCH 4 | LOSS: 2.3707072734832764 | ACCURACY: 0.942 | F1 MACRO: 0.9622 | F1 MICRO: 0.9639
# EPOCH 5 | LOSS: 2.302335262298584 | ACCURACY: 0.9509 | F1 MACRO: 0.9678 | F1 MICRO: 0.9693
# EPOCH 6 | LOSS: 2.07586932182312 | ACCURACY: 0.9442 | F1 MACRO: 0.9625 | F1 MICRO: 0.9649
# EPOCH 7 | LOSS: 1.9354431629180908 | ACCURACY: 0.9546 | F1 MACRO: 0.9701 | F1 MICRO: 0.9715
# EPOCH 8 | LOSS: 1.8646143674850464 | ACCURACY: 0.9554 | F1 MACRO: 0.9704 | F1 MICRO: 0.9721
# EPOCH 9 | LOSS: 1.8116766214370728 | ACCURACY: 0.9501 | F1 MACRO: 0.9662 | F1 MICRO: 0.9685
# EPOCH 10 | LOSS: 1.7460004091262817 | ACCURACY: 0.9568 | F1 MACRO: 0.9702 | F1 MICRO: 0.9726
# aspect: ACCURACY 0.9568 | F1 MACRO 0.9702 | F1 MICRO 0.9726
#               precision    recall  f1-score   support
#
#         fuel       0.99      0.98      0.99       187
#      machine       0.95      0.98      0.96       175
#       others       0.96      0.87      0.91       158
#         part       0.96      0.98      0.97       158
#        price       0.98      1.00      0.99       192
#      service       1.00      1.00      1.00       191
#
#    micro avg       0.97      0.97      0.97      1061
#    macro avg       0.97      0.97      0.97      1061
# weighted avg       0.97      0.97      0.97      1061
#  samples avg       0.97      0.97      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.5043511390686035 | ACCURACY: 0.9055 | F1 MACRO: 0.8955 | F1 MICRO: 0.9055
# EPOCH 2 | LOSS: 5.039712905883789 | ACCURACY: 0.9491 | F1 MACRO: 0.94 | F1 MICRO: 0.9491
# EPOCH 3 | LOSS: 4.422565937042236 | ACCURACY: 0.9273 | F1 MACRO: 0.9174 | F1 MICRO: 0.9273
# EPOCH 4 | LOSS: 4.165976047515869 | ACCURACY: 0.92 | F1 MACRO: 0.9102 | F1 MICRO: 0.92
# EPOCH 5 | LOSS: 4.008787155151367 | ACCURACY: 0.9382 | F1 MACRO: 0.93 | F1 MICRO: 0.9382
# in second
# EPOCH 6 | LOSS: 3.5154528617858887 | ACCURACY: 0.9309 | F1 MACRO: 0.9218 | F1 MICRO: 0.9309
# in second
# EPOCH 7 | LOSS: 3.598555088043213 | ACCURACY: 0.9309 | F1 MACRO: 0.9218 | F1 MICRO: 0.9309
# in second
# EPOCH 8 | LOSS: 3.450364589691162 | ACCURACY: 0.9345 | F1 MACRO: 0.9257 | F1 MICRO: 0.9345
# in second
# EPOCH 9 | LOSS: 3.5144541263580322 | ACCURACY: 0.9382 | F1 MACRO: 0.9296 | F1 MICRO: 0.9382
# in second
# EPOCH 10 | LOSS: 3.421003818511963 | ACCURACY: 0.9382 | F1 MACRO: 0.9296 | F1 MICRO: 0.9382
# sentiment: ACCURACY 0.9491 | F1 MACRO 0.94 | F1 MICRO 0.9491
#               precision    recall  f1-score   support
#
#     negative       0.92      0.92      0.92        84
#     positive       0.96      0.96      0.96       191
#
#     accuracy                           0.95       275
#    macro avg       0.94      0.94      0.94       275
# weighted avg       0.95      0.95      0.95       275
#
# --------------------------------------------------
# Iteration 478: Accuracy: 0.9452, F1 Micro: 0.9452, F1 Macro: 0.9046
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.92      0.96      0.94        24
#
#     accuracy                           0.99       216
#    macro avg       0.97      0.98      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.75      0.83        16
#      neutral       0.94      0.98      0.96       167
#     positive       0.83      0.73      0.77        33
#
#     accuracy                           0.92       216
#    macro avg       0.90      0.82      0.85       216
# weighted avg       0.92      0.92      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.77      0.83      0.80        12
#      neutral       0.95      0.86      0.90       152
#     positive       0.70      0.88      0.78        52
#
#     accuracy                           0.86       216
#    macro avg       0.81      0.86      0.83       216
# weighted avg       0.88      0.86      0.87       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.84      0.91      0.87        23
#      neutral       0.96      0.99      0.97       152
#     positive       0.94      0.76      0.84        41
#
#     accuracy                           0.94       216
#    macro avg       0.91      0.89      0.90       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.92      0.96        13
#      neutral       0.98      0.99      0.99       186
#     positive       0.88      0.82      0.85        17
#
#     accuracy                           0.98       216
#    macro avg       0.95      0.91      0.93       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.86      0.89        14
#      neutral       1.00      0.99      1.00       185
#     positive       0.89      1.00      0.94        17
#
#     accuracy                           0.99       216
#    macro avg       0.94      0.95      0.94       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 382 382
# Nearest checkpoint: 540
# Threshold: 88218.0625
# Samples above threshold: 39
# Acquired samples: 39
# Sampling duration: 15.637571096420288 seconds
# New train size: 517
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.3287558555603027 | ACCURACY: 0.8036 | F1 MACRO: 0.8867 | F1 MICRO: 0.8885
# EPOCH 2 | LOSS: 2.6327803134918213 | ACCURACY: 0.84 | F1 MACRO: 0.905 | F1 MICRO: 0.9061
# EPOCH 3 | LOSS: 2.4673917293548584 | ACCURACY: 0.9427 | F1 MACRO: 0.9629 | F1 MICRO: 0.9643
# EPOCH 4 | LOSS: 2.463489532470703 | ACCURACY: 0.9442 | F1 MACRO: 0.9636 | F1 MICRO: 0.9652
# EPOCH 5 | LOSS: 2.2431843280792236 | ACCURACY: 0.9494 | F1 MACRO: 0.9671 | F1 MICRO: 0.9685
# EPOCH 6 | LOSS: 2.055124282836914 | ACCURACY: 0.9524 | F1 MACRO: 0.9681 | F1 MICRO: 0.97
# EPOCH 7 | LOSS: 1.9590320587158203 | ACCURACY: 0.9479 | F1 MACRO: 0.9647 | F1 MICRO: 0.9671
# EPOCH 8 | LOSS: 1.860163927078247 | ACCURACY: 0.9524 | F1 MACRO: 0.968 | F1 MICRO: 0.9699
# EPOCH 9 | LOSS: 1.816758632659912 | ACCURACY: 0.9509 | F1 MACRO: 0.967 | F1 MICRO: 0.969
# in second
# EPOCH 10 | LOSS: 1.744631052017212 | ACCURACY: 0.8943 | F1 MACRO: 0.9372 | F1 MICRO: 0.9368
# aspect: ACCURACY 0.9524 | F1 MACRO 0.9681 | F1 MICRO 0.97
#               precision    recall  f1-score   support
#
# ...
#    macro avg       0.97      0.98      0.97      1061
# weighted avg       0.97      0.98      0.98      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 4.01766300201416 | ACCURACY: 0.902 | F1 MACRO: 0.8935 | F1 MICRO: 0.902
# EPOCH 2 | LOSS: 3.00642991065979 | ACCURACY: 0.9137 | F1 MACRO: 0.9065 | F1 MICRO: 0.9137
# EPOCH 3 | LOSS: 2.6490323543548584 | ACCURACY: 0.9333 | F1 MACRO: 0.9248 | F1 MICRO: 0.9333
# EPOCH 4 | LOSS: 2.466952085494995 | ACCURACY: 0.9412 | F1 MACRO: 0.9344 | F1 MICRO: 0.9412
# EPOCH 5 | LOSS: 2.301586627960205 | ACCURACY: 0.8941 | F1 MACRO: 0.8832 | F1 MICRO: 0.8941
# EPOCH 6 | LOSS: 2.330357789993286 | ACCURACY: 0.8784 | F1 MACRO: 0.8697 | F1 MICRO: 0.8784
# EPOCH 7 | LOSS: 2.1389923095703125 | ACCURACY: 0.9373 | F1 MACRO: 0.929 | F1 MICRO: 0.9373
# in second
# EPOCH 8 | LOSS: 2.0034124851226807 | ACCURACY: 0.9255 | F1 MACRO: 0.9164 | F1 MICRO: 0.9255
# in second
# EPOCH 9 | LOSS: 1.9610673189163208 | ACCURACY: 0.9216 | F1 MACRO: 0.9123 | F1 MICRO: 0.9216
# in second
# EPOCH 10 | LOSS: 1.9207772016525269 | ACCURACY: 0.9176 | F1 MACRO: 0.9081 | F1 MICRO: 0.9176
# sentiment: ACCURACY 0.9412 | F1 MACRO 0.9344 | F1 MICRO 0.9412
#               precision    recall  f1-score   support
#
#     negative       0.88      0.95      0.91        83
#     positive       0.98      0.94      0.96       172
#
#     accuracy                           0.94       255
#    macro avg       0.93      0.94      0.93       255
# weighted avg       0.94      0.94      0.94       255
#
# --------------------------------------------------
# Iteration 831: Accuracy: 0.956, F1 Micro: 0.956, F1 Macro: 0.903
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.96      0.96      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.95      0.97       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.75      0.80        16
#      neutral       0.94      0.98      0.96       167
#     positive       0.85      0.70      0.77        33
#
#     accuracy                           0.92       216
#    macro avg       0.88      0.81      0.84       216
# weighted avg       0.92      0.92      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.75      0.75        12
#      neutral       0.93      0.97      0.95       152
#     positive       0.87      0.77      0.82        52
#
#     accuracy                           0.91       216
#    macro avg       0.85      0.83      0.84       216
# weighted avg       0.91      0.91      0.91       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.82      1.00      0.90        23
#      neutral       0.99      0.99      0.99       152
#     positive       0.97      0.85      0.91        41
#
#     accuracy                           0.96       216
#    macro avg       0.93      0.95      0.93       216
# weighted avg       0.97      0.96      0.96       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.85      0.85        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.88      0.82      0.85        17
#
#     accuracy                           0.97       216
#    macro avg       0.90      0.89      0.90       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.86      0.89        14
#      neutral       0.99      1.00      1.00       185
#     positive       0.94      0.94      0.94        17
#
#     accuracy                           0.99       216
#    macro avg       0.95      0.93      0.94       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 32 32
# Nearest checkpoint: 864
# Threshold: 88271.265625
# Samples above threshold: 4
# Acquired samples: 25
# Sampling duration: 20.621065616607666 seconds
# New train size: 856
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.0244221687316895 | ACCURACY: 0.8281 | F1 MACRO: 0.8989 | F1 MICRO: 0.9002
# EPOCH 2 | LOSS: 2.3778529167175293 | ACCURACY: 0.9286 | F1 MACRO: 0.9536 | F1 MICRO: 0.9555
# EPOCH 3 | LOSS: 2.2831530570983887 | ACCURACY: 0.9546 | F1 MACRO: 0.9704 | F1 MICRO: 0.9717
# EPOCH 4 | LOSS: 1.9962269067764282 | ACCURACY: 0.9546 | F1 MACRO: 0.97 | F1 MICRO: 0.9716
# EPOCH 5 | LOSS: 1.8906254768371582 | ACCURACY: 0.9509 | F1 MACRO: 0.9664 | F1 MICRO: 0.969
# EPOCH 6 | LOSS: 1.7758018970489502 | ACCURACY: 0.9561 | F1 MACRO: 0.9707 | F1 MICRO: 0.9724
# EPOCH 7 | LOSS: 1.7089508771896362 | ACCURACY: 0.9613 | F1 MACRO: 0.9737 | F1 MICRO: 0.9756
# EPOCH 8 | LOSS: 1.686594843864441 | ACCURACY: 0.9583 | F1 MACRO: 0.9717 | F1 MICRO: 0.9737
# EPOCH 9 | LOSS: 1.6056550741195679 | ACCURACY: 0.9598 | F1 MACRO: 0.9729 | F1 MICRO: 0.9746
# EPOCH 10 | LOSS: 1.5650731325149536 | ACCURACY: 0.965 | F1 MACRO: 0.9767 | F1 MICRO: 0.978
# aspect: ACCURACY 0.965 | F1 MACRO 0.9767 | F1 MICRO 0.978
#               precision    recall  f1-score   support
#
#         fuel       0.98      0.99      0.99       187
#      machine       0.96      0.98      0.97       175
#       others       0.93      0.94      0.93       158
#         part       0.96      0.99      0.98       158
#        price       0.99      0.99      0.99       192
#      service       1.00      1.00      1.00       191
#
#    micro avg       0.97      0.98      0.98      1061
#    macro avg       0.97      0.98      0.98      1061
# weighted avg       0.97      0.98      0.98      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.5272371768951416 | ACCURACY: 0.9242 | F1 MACRO: 0.9121 | F1 MICRO: 0.9242
# EPOCH 2 | LOSS: 2.743100166320801 | ACCURACY: 0.9394 | F1 MACRO: 0.9326 | F1 MICRO: 0.9394
# EPOCH 3 | LOSS: 2.475994348526001 | ACCURACY: 0.947 | F1 MACRO: 0.9407 | F1 MICRO: 0.947
# EPOCH 4 | LOSS: 2.310242176055908 | ACCURACY: 0.9356 | F1 MACRO: 0.9285 | F1 MICRO: 0.9356
# EPOCH 5 | LOSS: 2.228984832763672 | ACCURACY: 0.9318 | F1 MACRO: 0.9237 | F1 MICRO: 0.9318
# EPOCH 6 | LOSS: 2.106996774673462 | ACCURACY: 0.947 | F1 MACRO: 0.9385 | F1 MICRO: 0.947
# EPOCH 7 | LOSS: 2.073356866836548 | ACCURACY: 0.9242 | F1 MACRO: 0.9157 | F1 MICRO: 0.9242
# EPOCH 8 | LOSS: 2.043334484100342 | ACCURACY: 0.928 | F1 MACRO: 0.9197 | F1 MICRO: 0.928
# EPOCH 9 | LOSS: 2.0416314601898193 | ACCURACY: 0.9167 | F1 MACRO: 0.9062 | F1 MICRO: 0.9167
# in second
# EPOCH 10 | LOSS: 1.888615369796753 | ACCURACY: 0.9394 | F1 MACRO: 0.9318 | F1 MICRO: 0.9394
# sentiment: ACCURACY 0.947 | F1 MACRO 0.9385 | F1 MICRO 0.947
#               precision    recall  f1-score   support
#
#     negative       0.94      0.89      0.92        85
#     positive       0.95      0.97      0.96       179
#
#     accuracy                           0.95       264
#    macro avg       0.94      0.93      0.94       264
# weighted avg       0.95      0.95      0.95       264
#
# --------------------------------------------------
# Iteration 856: Accuracy: 0.9576, F1 Micro: 0.9576, F1 Macro: 0.9205
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.82      0.90        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.92      0.96      0.94        24
#
#     accuracy                           0.98       216
#    macro avg       0.97      0.92      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.81      0.84        16
#      neutral       0.96      0.97      0.96       167
#     positive       0.84      0.82      0.83        33
#
#     accuracy                           0.94       216
#    macro avg       0.89      0.87      0.88       216
# weighted avg       0.93      0.94      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.83      0.87        12
#      neutral       0.93      0.93      0.93       152
#     positive       0.79      0.79      0.79        52
#
#     accuracy                           0.89       216
#    macro avg       0.88      0.85      0.86       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.88      1.00      0.94        23
#      neutral       0.97      0.99      0.98       152
#     positive       1.00      0.83      0.91        41
#
#     accuracy                           0.96       216
#    macro avg       0.95      0.94      0.94       216
# weighted avg       0.97      0.96      0.96       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.85      0.88        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.88      0.88      0.88        17
#
#     accuracy                           0.98       216
#    macro avg       0.93      0.91      0.92       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       1.00      1.00      1.00       185
#     positive       0.94      1.00      0.97        17
#
#     accuracy                           1.00       216
#    macro avg       0.98      0.98      0.98       216
# weighted avg       1.00      1.00      1.00       216
#
# Launching training on 2 GPUs.
# 8 8
# Nearest checkpoint: 864
# Threshold: 88294.6796875
# Samples above threshold: 1
# Acquired samples: 8
# Sampling duration: 20.781081199645996 seconds
# New train size: 864
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.9787611961364746 | ACCURACY: 0.8237 | F1 MACRO: 0.8978 | F1 MICRO: 0.899
# EPOCH 2 | LOSS: 2.3877077102661133 | ACCURACY: 0.9234 | F1 MACRO: 0.9496 | F1 MICRO: 0.9523
# EPOCH 3 | LOSS: 2.233565330505371 | ACCURACY: 0.9561 | F1 MACRO: 0.9717 | F1 MICRO: 0.9728
# EPOCH 4 | LOSS: 1.993683099746704 | ACCURACY: 0.9621 | F1 MACRO: 0.9753 | F1 MICRO: 0.9763
# EPOCH 5 | LOSS: 1.8644750118255615 | ACCURACY: 0.9583 | F1 MACRO: 0.9726 | F1 MICRO: 0.9738
# EPOCH 6 | LOSS: 1.7838935852050781 | ACCURACY: 0.9576 | F1 MACRO: 0.9714 | F1 MICRO: 0.9732
# EPOCH 7 | LOSS: 1.720037579536438 | ACCURACY: 0.9643 | F1 MACRO: 0.976 | F1 MICRO: 0.9775
# EPOCH 8 | LOSS: 1.6466511487960815 | ACCURACY: 0.9613 | F1 MACRO: 0.9739 | F1 MICRO: 0.9756
# EPOCH 9 | LOSS: 1.6141786575317383 | ACCURACY: 0.9628 | F1 MACRO: 0.9749 | F1 MICRO: 0.9766
# EPOCH 10 | LOSS: 1.5759574174880981 | ACCURACY: 0.9591 | F1 MACRO: 0.9723 | F1 MICRO: 0.974
# aspect: ACCURACY 0.9643 | F1 MACRO 0.976 | F1 MICRO 0.9775
#               precision    recall  f1-score   support
#
#         fuel       0.99      0.99      0.99       187
#      machine       0.95      0.99      0.97       175
#       others       0.94      0.93      0.93       158
#         part       0.97      0.97      0.97       158
#        price       0.98      1.00      0.99       192
#      service       0.99      1.00      0.99       191
#
#    micro avg       0.97      0.98      0.98      1061
#    macro avg       0.97      0.98      0.98      1061
# weighted avg       0.97      0.98      0.98      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.7490580081939697 | ACCURACY: 0.9 | F1 MACRO: 0.8911 | F1 MICRO: 0.9
# EPOCH 2 | LOSS: 2.7978641986846924 | ACCURACY: 0.9259 | F1 MACRO: 0.9136 | F1 MICRO: 0.9259
# EPOCH 3 | LOSS: 2.4993274211883545 | ACCURACY: 0.9222 | F1 MACRO: 0.9132 | F1 MICRO: 0.9222
# EPOCH 4 | LOSS: 2.285444974899292 | ACCURACY: 0.9185 | F1 MACRO: 0.9098 | F1 MICRO: 0.9185
# EPOCH 5 | LOSS: 2.2092525959014893 | ACCURACY: 0.9074 | F1 MACRO: 0.8943 | F1 MICRO: 0.9074
# in second
# EPOCH 6 | LOSS: 2.018394947052002 | ACCURACY: 0.9185 | F1 MACRO: 0.9078 | F1 MICRO: 0.9185
# in second
# EPOCH 7 | LOSS: 1.9525657892227173 | ACCURACY: 0.9222 | F1 MACRO: 0.9123 | F1 MICRO: 0.9222
# in second
# EPOCH 8 | LOSS: 1.9077510833740234 | ACCURACY: 0.9222 | F1 MACRO: 0.9123 | F1 MICRO: 0.9222
# in second
# EPOCH 9 | LOSS: 1.9206922054290771 | ACCURACY: 0.9222 | F1 MACRO: 0.9123 | F1 MICRO: 0.9222
# in second
# EPOCH 10 | LOSS: 1.8853791952133179 | ACCURACY: 0.9222 | F1 MACRO: 0.9118 | F1 MICRO: 0.9222
# sentiment: ACCURACY 0.9259 | F1 MACRO 0.9136 | F1 MICRO 0.9259
#               precision    recall  f1-score   support
#
#     negative       0.90      0.86      0.88        86
#     positive       0.94      0.96      0.95       184
#
#     accuracy                           0.93       270
#    macro avg       0.92      0.91      0.91       270
# weighted avg       0.93      0.93      0.93       270
#
# --------------------------------------------------
# Iteration 864: Accuracy: 0.9529, F1 Micro: 0.9529, F1 Macro: 0.9063
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.82      0.90        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.88      0.96      0.92        24
#
#     accuracy                           0.98       216
#    macro avg       0.96      0.92      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.81      0.87        16
#      neutral       0.95      0.98      0.96       167
#     positive       0.83      0.76      0.79        33
#
#     accuracy                           0.93       216
#    macro avg       0.90      0.85      0.87       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.79      0.92      0.85        12
#      neutral       0.95      0.92      0.93       152
#     positive       0.78      0.81      0.79        52
#
#     accuracy                           0.89       216
#    macro avg       0.84      0.88      0.86       216
# weighted avg       0.90      0.89      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.87      0.87        23
#      neutral       0.98      0.98      0.98       152
#     positive       0.88      0.88      0.88        41
#
#     accuracy                           0.95       216
#    macro avg       0.91      0.91      0.91       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.85      0.85        13
#      neutral       0.98      0.99      0.99       186
#     positive       0.93      0.82      0.87        17
#
#     accuracy                           0.97       216
#    macro avg       0.92      0.89      0.90       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       1.00      1.00      1.00       185
#     positive       0.89      1.00      0.94        17
#
#     accuracy                           0.99       216
#    macro avg       0.96      0.95      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Total sampling time: 374.66 seconds
# Total runtime: 2907.085139274597 seconds
