# %%
import os
import time
import math
import torch
import random
import warnings
import numpy as np
import pandas as pd
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
from torch.multiprocessing import Manager
from torch.utils.data import DataLoader, Dataset
from torch.utils.data.sampler import SubsetRandomSampler
from sklearn.model_selection import train_test_split
from accelerate import Accelerator, notebook_launcher
from transformers import BertTokenizer, BertModel, BertConfig
from sklearn.metrics import precision_recall_fscore_support, f1_score, classification_report

# %% [markdown]
# # SETUP

# %%
warnings.filterwarnings('ignore')

# %%
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic=True
    torch.backends.cudnn.benchmark=False

set_seed(42)

# %% [markdown]
# # GLOBAL VARIABLES

# %%
manager = Manager()

# Shared resources
aspect_accuracies = manager.list()
aspect_f1_micros = manager.list()
aspect_f1_macros = manager.list()
sentiment_accuracies = manager.list()
sentiment_f1_micros = manager.list()
sentiment_f1_macros = manager.list()
accuracies = manager.list()
f1_micros = manager.list()
f1_macros = manager.list()

new_sample_data = manager.list()
new_sample_labels = manager.list()

# Non shared resources
filename = 'casa-comal'
epochs = 10
batch_size = 16
sequence_length = 48

aspect_list = ['fuel', 'machine', 'others', 'part', 'price', 'service']
aspect_mapping = {'fuel': 0, 'machine': 1, 'others': 2, 'part': 3, 'price': 4, 'service': 5 }
label_mapping = {"negative": 0, "neutral": 1, 'positive': 2}
ignored_keys = ['labels', 'ori_text', 'ori_label', 'ori_indices', 'aspect', 'sampler_loss_weight', 'all_labeled_mask']

# %% [markdown]
# # LOAD AND PREPROCESS DATA

# %%
train_data = pd.read_csv('/kaggle/input/casa-dataset/train_preprocess.csv', encoding='latin-1')
val_data = pd.read_csv('/kaggle/input/casa-dataset/valid_preprocess.csv', encoding='latin-1')
test_data = pd.read_csv('/kaggle/input/casa-dataset/test_preprocess.csv', encoding='latin-1')

data = pd.concat([train_data, val_data, test_data], ignore_index=True)

data.head()
# Out:
#                                             sentence      fuel   machine  \
# 0  Saya memakai Honda Jazz GK5 tahun 2014 ( perta...   neutral   neutral
# 1  Avanza kenapa jadi boros bensin begini dah ah....  negative   neutral
# 2  saran ku dan pengalaman ku , mending beli mobi...  positive  positive
# 3  Dari segi harga juga pajero lebih mahal 30 jut...   neutral   neutral
# 4                     Kalo menurut gw enak pajero si   neutral   neutral
#
#      others     part     price  service
# 0  positive  neutral   neutral  neutral
# 1   neutral  neutral   neutral  neutral
# 2   neutral  neutral   neutral  neutral
# 3   neutral  neutral  positive  neutral
# 4  positive  neutral   neutral  neutral

# %%
train_data, val_data = train_test_split(data, test_size=0.2, random_state=42, shuffle=False)

# %%
train_labels = train_data.columns[1:]
val_labels = val_data.columns[1:]

# Extract features and labels for training and validation
X_train = train_data['sentence'].values
y_train = train_data[train_labels].values
X_val = val_data['sentence'].values
y_val = val_data[val_labels].values

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
# Out:
# (864,) (864, 6)
# (216,) (216, 6)

# %% [markdown]
# # BULDING DATASET

# %%
tokenizer = BertTokenizer.from_pretrained('indobenchmark/indobert-base-p1')
review_token = '[REVIEW]'
aspect_token = '[ASPECT]'
special_tokens_dict = {'additional_special_tokens': [review_token, aspect_token]}
num_added_tokens = tokenizer.add_special_tokens(special_tokens_dict)
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/229k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.53k [00:00<?, ?B/s]

# %%
class AspectDetectionDataset(Dataset):
    def __init__(self, data, labels, tokenizer, label2id, aspect_list, max_length=48):
        # Initialize dataset with data, tokenizer, and label mappings
        self.data = data
        self.tokenizer = tokenizer
        self.label2id = label2id
        self.maxlength = sequence_length  # Maximum token length for input sequences
        self.all_labels_num = len(aspect_list)  # Total number of labels
        self.aspect_list = aspect_list
        self.pair_wise_sampled = None  # Tracks sampling status of label pairs
        self.gt_labels = labels  # Ground truth labels in one-hot format
        self.all_labeled_mask = None  # Indicates whether all labels of a sample have been queried
        self.max_length = max_length
        self.init()  # Initializes sampling and label mask states

    def init(self):
        # Initialize sampled pairs and mask for all data
        self.pair_wise_sampled = torch.ones(len(self.data), self.all_labels_num)
        self.all_labeled_mask = torch.zeros(len(self.data))  # Initially, no data is fully labeled

    def get_label_Cardinality(self):
        # Compute label cardinality, representing average positive labels per sample in the labeled pool
        labed_cnt = torch.sum(self.all_labeled_mask)  # Total number of samples fully labeled
        original_labels = torch.tensor([[self.label2id[label] for label in labels] for labels in self.gt_labels], dtype=torch.float32)
        encoded_labels = torch.tensor([[1 if label == 1 else 0 for label in labels] for labels in original_labels], dtype=torch.float32)
        all_labed_pos_label_cnt = torch.sum(self.all_labeled_mask.unsqueeze(-1) * encoded_labels)
        return all_labed_pos_label_cnt / labed_cnt  # Average number of positive labels per fully labeled sample

    def update_data(self, query_example_indices, query_label_indices=None, init_time=False):
        # Update dataset with new labeled data points and labels after each query cycle
        if query_label_indices is not None:
            ones = torch.ones(self.all_labels_num)
            for example_idx, label_idx in zip(query_example_indices, query_label_indices):
                # Access individual data and update based on queried label
                one_data = self.__getitem__(example_idx)
                one_label = one_data[1][label_idx]
                if one_label == 0:
                    # Set pair-wise sampled state for newly queried labels
                    self.pair_wise_sampled[example_idx][label_idx] = 1
                else:
                    self.pair_wise_sampled[example_idx][label_idx] = 1
                
                # Update all_labeled_mask if all labels for a sample are queried
                if torch.sum(ones - self.pair_wise_sampled[example_idx]) == 0:
                    self.all_labeled_mask[example_idx] = 1
        else:
            # Mark all labels as queried for each example if only examples are specified
            for example_idx in query_example_indices:
                ones = torch.ones(self.all_labels_num)
                self.pair_wise_sampled[example_idx] = ones
                self.all_labeled_mask[example_idx] = 1

    def get_labeled_set(self):
        # Return list of indices for samples that have been fully labeled
        labeled_set = []
        for idx, mask in enumerate(self.all_labeled_mask):
            if mask != 0:
                labeled_set.append(idx)
        return labeled_set

    def __len__(self):
        # Return the number of samples in the dataset
        return len(self.data)

    def __getitem__(self, idx):
        text = self.data[idx] 
        original_labels = torch.tensor([self.label2id[label] for label in self.gt_labels[idx]], dtype=torch.float32)
        encoded_labels = torch.tensor([1 if label == 1 else 0 for label in original_labels], dtype=torch.float32)

        # Tokenize the raw text and apply padding/truncation to reach maxlength
        encoding = self.tokenizer(
            text,
            padding='max_length',
            truncation=True,
            max_length=self.max_length,
            return_tensors="pt"
        )

        input_ids = encoding['input_ids'].squeeze(0)  # Remove batch dimension
        input_type_ids = encoding.get('token_type_ids', torch.zeros_like(input_ids))
        input_mask = encoding['attention_mask'].squeeze(0)
        text_inputs = [input_ids, input_type_ids, input_mask]
        sampler_loss_weight = self.pair_wise_sampled[idx]  # Weight for active learning sample 

        inputs_list = [text_inputs, encoded_labels, idx, sampler_loss_weight, self.all_labeled_mask[idx], text, original_labels]
        return inputs_list

# %%
class SentimentAnalysisDataset(Dataset):
    def __init__(self, data, labels, aspects, indices, tokenizer, label2id, max_length):
        # Initialize dataset with data, tokenizer, and label mappings
        self.data = data
        self.tokenizer = tokenizer
        self.label2id = label2id
        self.maxlength = sequence_length  # Maximum token length for input sequences
        self.all_labels_num = 2
        self.pair_wise_sampled = None  # Tracks sampling status of label pairs
        self.gt_labels = labels  # Ground truth labels in one-hot format
        self.all_labeled_mask = None  # Indicates whether all labels of a sample have been queried
        self.aspects = aspects
        self.indices = indices
        self.max_length = max_length
        self.init()  # Initializes sampling and label mask states

    def init(self):
        # Initialize sampled pairs and mask for all data
        self.pair_wise_sampled = torch.ones(len(self.data), self.all_labels_num)
        self.all_labeled_mask = torch.zeros(len(self.data))  # Initially, no data is fully labeled

    def get_label_Cardinality(self):
        # Compute label cardinality, representing average positive labels per sample in the labeled pool
        labed_cnt = torch.sum(self.all_labeled_mask)  # Total number of samples fully labeled
        all_labed_pos_label_cnt = torch.sum(self.all_labeled_mask.unsqueeze(-1) * self.gt_labels)
        return all_labed_pos_label_cnt / labed_cnt  # Average number of positive labels per fully labeled sample

    def update_data(self, query_example_indices, query_label_indices=None, init_time=False):
        # Update dataset with new labeled data points and labels after each query cycle
        if query_label_indices is not None:
            ones = torch.ones(self.all_labels_num)
            for example_idx, label_idx in zip(query_example_indices, query_label_indices):
                # Access individual data and update based on queried label
                one_data = self.__getitem__(example_idx)
                one_label = one_data[1][label_idx]
                if one_label == 0:
                    # Set pair-wise sampled state for newly queried labels
                    self.pair_wise_sampled[example_idx][label_idx] = 1
                else:
                    self.pair_wise_sampled[example_idx][label_idx] = 1
                
                # Update all_labeled_mask if all labels for a sample are queried
                if torch.sum(ones - self.pair_wise_sampled[example_idx]) == 0:
                    self.all_labeled_mask[example_idx] = 1
        else:
            # Mark all labels as queried for each example if only examples are specified
            for example_idx in query_example_indices:
                ones = torch.ones(self.all_labels_num)
                self.pair_wise_sampled[example_idx] = ones
                self.all_labeled_mask[example_idx] = 1

    def get_labeled_set(self):
        # Return list of indices for samples that have been fully labeled
        labeled_set = []
        for idx, mask in enumerate(self.all_labeled_mask):
            if mask != 0:
                labeled_set.append(idx)
        return labeled_set

    def __len__(self):
        # Return the number of samples in the dataset
        return len(self.data)

    def __getitem__(self, idx):
        text = aspect_token + ' ' + self.aspects[idx] + ' ' + review_token + ' ' + self.data[idx] 

        # Tokenize the raw text and apply padding/truncation to reach maxlength
        encoding = self.tokenizer(
            text,
            padding='max_length',
            truncation=True,
            max_length=self.max_length,
            return_tensors="pt"
        )

        if isinstance(self.gt_labels[idx], str):
            self.gt_labels[idx] = self.label2id[self.gt_labels[idx]]
        elif torch.is_tensor(self.gt_labels[idx]):
            self.gt_labels[idx] = int(self.gt_labels[idx].item())

        encoded_label = 1 if self.gt_labels[idx] == 2 else self.gt_labels[idx]
        one_hot_label = F.one_hot(torch.tensor(encoded_label, dtype=torch.long), num_classes=2).float()

        input_ids = encoding['input_ids'].squeeze(0)  # Remove batch dimension
        input_type_ids = encoding.get('token_type_ids', torch.zeros_like(input_ids))
        input_mask = encoding['attention_mask'].squeeze(0)
        text_inputs = [input_ids, input_type_ids, input_mask]
        sampler_loss_weight = self.pair_wise_sampled[idx]  # Weight for active learning sample 
        original_label = torch.tensor(self.gt_labels[idx], dtype=torch.long)
        aspect = self.aspects[idx]

        inputs_list = [text_inputs, one_hot_label, idx, sampler_loss_weight, self.all_labeled_mask[idx], text, original_label, aspect, self.indices[idx]]
        return inputs_list

# %%
def build_aspect_dataset(X_train, y_train, X_val, y_val, sequence_length, num_workers=4):
    train_dataset = AspectDetectionDataset(X_train, y_train, tokenizer, label_mapping, aspect_list, max_length=sequence_length)
    val_dataset = AspectDetectionDataset(X_val, y_val, tokenizer, label_mapping, aspect_list, max_length=sequence_length)
    
    train_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=batch_size, shuffle=True, pin_memory=True, num_workers=num_workers,
    )
    val_loader = torch.utils.data.DataLoader(
        val_dataset, batch_size=batch_size, shuffle=False, pin_memory=True, num_workers=num_workers, 
    )

    return train_loader, val_loader, train_dataset, val_dataset

# %%
def build_sentiment_dataset(device, train_dataset, val_dataset, aspect_detection_model, tokenizer, max_length=sequence_length):
    train_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=batch_size, shuffle=False, pin_memory=True, num_workers=4, 
    )
    val_loader = torch.utils.data.DataLoader(
        val_dataset, batch_size=batch_size, shuffle=False, pin_memory=True, num_workers=4, 
    )

    aspect_detection_model.to(device)
    aspect_detection_model.eval()

    train_data = []
    train_labels = []
    train_aspects = []
    train_indices = []

    val_data = []
    val_labels = []
    val_aspects = []
    val_indices = []

    # Transform train set
    with torch.no_grad():
        for batch in train_loader:
            input_ids, input_type_ids, input_mask = [x.to(device) for x in batch[0]]
            inputs_list = [input_ids, input_type_ids, input_mask, None]
            
            outputs = aspect_detection_model(inputs_list)
            preds = torch.sigmoid(outputs[0]).round()

            for i in range(len(preds)):
                for j in range(len(preds[i])):
                    if int(preds[i][j]) != 1:
                        train_aspects.append(aspect_list[j])
                        train_data.append(batch[5][i])
                        train_labels.append(batch[6][i][j])
                        train_indices.append(batch[2][i])
            
        # Transform validation set
        for batch in val_loader:
            input_ids, input_type_ids, input_mask = [x.to(device) for x in batch[0]]
            inputs_list = [input_ids, input_type_ids, input_mask, None]
            
            outputs = aspect_detection_model(inputs_list)
            preds = torch.sigmoid(outputs[0]).round()

            for i in range(len(preds)):
                for j in range(len(preds[i])):
                    if int(preds[i][j]) != 1:
                        val_aspects.append(aspect_list[j])
                        val_data.append(batch[5][i])
                        val_labels.append(batch[6][i][j])
                        val_indices.append(batch[2][i])

    train_dataset = SentimentAnalysisDataset(train_data, train_labels, train_aspects, train_indices, tokenizer, label_mapping, max_length=max_length)
    val_dataset = SentimentAnalysisDataset(val_data, val_labels, val_aspects, val_indices, tokenizer, label_mapping, max_length=max_length)

    train_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=batch_size, shuffle=True, pin_memory=True, num_workers=4, 
    )
    val_loader = torch.utils.data.DataLoader(
        val_dataset, batch_size=batch_size, shuffle=False, pin_memory=True, num_workers=4, 
    )

    return train_loader, val_loader, train_dataset, val_dataset

# %% [markdown]
# # DEFINE THE MODEL

# %%
class IndoBERT_Backbone(nn.Module):
    def __init__(self, label_num):
        super(IndoBERT_Backbone, self).__init__()
        self.label_num = label_num
        self.encoder = IndoBERT_Encoder(label_num)
        model_config = BertConfig.from_pretrained("indobenchmark/indobert-base-p1")
        self.clf = nn.Linear(model_config.hidden_size, label_num)
        nn.init.xavier_uniform_(self.clf.weight)

    def forward(self, inputs):
        encoder_out = self.encoder(inputs)
        out = self.clf(encoder_out)
        return out, encoder_out

class IndoBERT_Encoder(nn.Module):
    def __init__(self, label_num):
        super(IndoBERT_Encoder, self).__init__()
        self.label_num = label_num
        self.encoder = BertModel.from_pretrained(
            'indobenchmark/indobert-base-p1',
            num_labels=self.label_num,
        )
        
        self.encoder_init()

    def encoder_init(self):
        all_layers = ['embeddings', 'layer.0', 'layer.1', 'layer.2', 'layer.3', 'layer.4', 'layer.5', 'layer.6',
                      'layer.7', 'layer.8', 'layer.9', 'layer.10', 'layer.11', 'pooler']
        unfreeze_layers = all_layers[7:]
        for name, param in self.encoder.named_parameters():
            param.requires_grad = False
            for ele in unfreeze_layers:
                if ele in name:
                    param.requires_grad = True
                    break

    def forward(self, inputs):
        # Ensure each component in inputs is a tensor
        input_ids = torch.tensor(inputs[0]) if not isinstance(inputs[0], torch.Tensor) else inputs[0]
        token_type_ids = torch.tensor(inputs[1]) if not isinstance(inputs[1], torch.Tensor) else inputs[1]
        attention_mask = torch.tensor(inputs[2]) if not isinstance(inputs[2], torch.Tensor) else inputs[2]
        
        input_ids = input_ids.view(-1, input_ids.size(-1))  # Ensuring batch_size, sequence_length
        token_type_ids = token_type_ids.view(input_ids.size(0), -1)  # Reshaping to [batch_size, sequence_length]
        attention_mask = attention_mask.view(-1, attention_mask.size(-1))
        
        outputs = self.encoder(
            input_ids=input_ids,
            token_type_ids=token_type_ids,
            attention_mask=attention_mask,
        )
        cls_output = outputs.pooler_output
        return cls_output

# %%
class MLP_VAE(nn.Module):
    def __init__(self, hidden_size, device, label_num):
        super(MLP_VAE, self).__init__()
        self.device = device
        self.label_num = label_num
        self.cl_neg_mode = 1
        self.proto_size = 256
        self.hidden_size = hidden_size
        
        # Initial fully connected layer to project input to higher-dimensional space for each label
        self.fc0 = nn.Linear(self.hidden_size, self.label_num * 512)
        self.fc1 = nn.Linear(512, self.proto_size)  # Dimensionality reduction for prototypes

        # Adjust the number of label representations based on contrastive learning mode
        if self.cl_neg_mode == 0:
            cl_label_num = self.label_num  # Standard label number
        elif self.cl_neg_mode == 1:
            cl_label_num = self.label_num + 1  # Add one for negative prototype handling
            self.ins_neg_cnt = torch.zeros(1).to(device)
        elif self.cl_neg_mode == 2:
            cl_label_num = self.label_num * 2  # Double for positive and negative prototypes
            self.ins_neg_cnt = torch.zeros(self.label_num).to(device)
        self.cl_label_num = cl_label_num

        # Register buffer for label prototypes, aligned with CoMAL's prototype-based sampling
        self.register_buffer("prototypes", torch.zeros(self.cl_label_num, self.proto_size))
        self.ins_pos_cnt = torch.zeros(self.label_num).to(device)  # Track count of positive instances

        # Decoder and final aggregation layers
        self.fc3 = nn.Linear(self.proto_size, 512)
        self.agg = nn.Linear(self.label_num * 512, self.hidden_size)
        self.clf = nn.Linear(self.hidden_size, self.label_num)  # Classification layer

    def get_protos(self):
        return self.prototypes  # Return the prototypes for external use

    def reparameterize(self, mu, logvar):
        # VAE reparameterization trick for latent space sampling
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def reset_proto(self):
        # Reset prototype and count buffers
        self.ins_pos_cnt *= 0
        self.ins_neg_cnt *= 0
        self.prototypes *= 0

    def forward(self, x, labels=None, weights=None, reset_proto=False):
        # Project input into sub-representations per label
        sub_rep_ori = self.fc0(x)
        sr_shape = sub_rep_ori.shape
        sub_rep_ori = sub_rep_ori.view(sr_shape[0], self.label_num, -1)  # Split per label

        # Further reduction to prototype size and decoding step
        sub_rep = self.fc1(sub_rep_ori)
        dec_sub_rep = self.fc3(sub_rep)

        dist_1 = None
        sub_rep_norm = F.normalize(sub_rep.data, dim=-1)  # Normalize for distance calculations

        if labels is not None and weights is not None:
            # Generate masks for positive and negative samples
            pos_mask = labels * weights
            neg_mask = (1 - labels) * weights
            pos_mask = pos_mask.unsqueeze(-1)
            neg_mask = neg_mask.unsqueeze(-1)

            # Update prototypes based on positive and negative samples
            feat = torch.sum(sub_rep_norm * pos_mask, dim=0)
            self.prototypes[:self.label_num] = self.prototypes[:self.label_num] * self.ins_pos_cnt.unsqueeze(-1) + feat

            # Handle different contrastive learning modes
            if self.cl_neg_mode == 2:
                feat_neg = torch.sum(sub_rep_norm * neg_mask, dim=0)
                self.prototypes[self.label_num:] = self.prototypes[self.label_num:] * self.ins_neg_cnt.unsqueeze(-1) + feat_neg
                self.ins_neg_cnt += torch.sum(neg_mask.squeeze(-1), dim=0)
            elif self.cl_neg_mode == 1:
                feat_neg = torch.sum(sub_rep_norm * neg_mask, dim=0)
                feat_neg = torch.sum(feat_neg, dim=0)
                self.prototypes[-1] = self.prototypes[-1] * self.ins_neg_cnt + feat_neg
                self.ins_neg_cnt += torch.sum(neg_mask)
            
            # Update positive instance counts and normalize prototypes
            self.ins_pos_cnt += torch.sum(pos_mask.squeeze(-1), dim=0)
            self.prototypes = F.normalize(self.prototypes, p=2, dim=-1)

        # Calculate distances between sub-representations and prototypes
        dist_1 = sub_rep_norm @ self.prototypes.T  

        # Decode and classify reconstructed input
        concat_sub_rep = dec_sub_rep.contiguous().view(dec_sub_rep.shape[0], -1)
        recon_x = self.agg(concat_sub_rep)
        recon_x_clf = self.clf(recon_x)

        if reset_proto:
            self.reset_proto()

        return recon_x, sub_rep, recon_x_clf, dist_1  # Return reconstruction, sub-representation, classification, and distances

# %%
def get_cl_labels(labels, label_num, weight, cl_neg_mode=1):
    cl_labels = torch.zeros_like(labels, dtype=torch.long)
    cl_labels.fill_(label_num)
    example_idx, label_idx = torch.where(labels>=0.5)
    cl_labels[example_idx, label_idx] = label_idx #.float()
    cl_labels = cl_labels * weight + label_num * (1 - weight)
    if cl_neg_mode == 2:
        example_idx, label_idx = torch.where(labels < 0.5)
        cl_neg_labels = label_idx + label_num
        cl_labels[example_idx, label_idx] = cl_neg_labels.float()
        cl_labels = cl_labels * weight + 2 * label_num * (1 - weight)
    cl_labels = cl_labels.to(torch.int)
    return cl_labels

def get_cl_mask(cl_labels, label_num, batch_size, cl_neg_mode=1):
    mask = torch.eq(cl_labels[:batch_size], cl_labels.T).float()
    if cl_neg_mode == 0:
        neg_idx, _ = torch.where(cl_labels[:batch_size] >= label_num)
        neg_mask = torch.ones_like(mask)
        neg_mask[neg_idx] = 0
        neg_mask[:, neg_idx] = 0
        mask *= neg_mask
    elif cl_neg_mode == 1:
        neg_idx, _ = torch.where(cl_labels[:batch_size] > label_num)
        neg_mask = torch.ones_like(mask)
        neg_mask[neg_idx] = 0
        neg_mask[:, neg_idx] = 0
        mask *= neg_mask
    elif cl_neg_mode == 2:
        neg_idx, _ = torch.where(cl_labels[:batch_size] >= label_num * 2)
        neg_mask = torch.ones_like(mask)
        neg_mask[neg_idx] = 0
        neg_mask[:, neg_idx] = 0
        mask *= neg_mask
    else:
        neg_mask = torch.ones_like(mask)
    return mask, neg_mask

# %% [markdown]
# # DEFINE LOSSES

# %%
class SupConLoss(nn.Module):
    """Following Supervised Contrastive Learning:
        https://arxiv.org/pdf/2004.11362.pdf."""

    def __init__(self, temperature=0.07, base_temperature=0.07):
        super().__init__()
        self.temperature = temperature
        self.base_temperature = base_temperature

    def forward(self, features, mask, neg_mask=None, batch_size=-1, device=None, other_features=None):
        if mask is not None:
            # SupCon loss (Partial Label Mode)
            mask = mask.float().detach()
            # compute logits
            if other_features is None:
                anchor_dot_contrast = torch.div(
                    torch.matmul(features[:batch_size], features.T),
                    self.temperature)
            else:
                anchor_dot_contrast = torch.div(
                    torch.matmul(features[:batch_size], other_features.T),
                    self.temperature)

            # for numerical stability
            logits_max, _ = torch.max(anchor_dot_contrast, dim=1, keepdim=True)
            logits = anchor_dot_contrast - logits_max.detach()

            # mask-out self-contrast cases
            if neg_mask is None:
                logits_mask = torch.ones_like(mask)
            else:
                logits_mask = torch.scatter(
                    neg_mask,
                    1,
                    torch.arange(batch_size).view(-1, 1).to(device),
                    0
                )
            mask = mask * logits_mask

            # compute log_prob
            exp_logits = torch.exp(logits) * logits_mask
            log_prob = logits - torch.log(exp_logits.sum(1, keepdim=True) + 1e-12)
            # compute mean of log-likelihood over positive
            mean_log_prob_pos = (mask * log_prob).sum(1) / (mask.sum(1) + 1e-12)
            # loss
            loss = - (self.temperature / self.base_temperature) * mean_log_prob_pos
            loss = loss.mean()
        else:
            q = features[:batch_size]
            k = features[batch_size:batch_size * 2]
            queue = features[batch_size * 2:]
            l_pos = torch.einsum('nc,nc->n', [q, k]).unsqueeze(-1)
            # negative logits: NxK
            l_neg = torch.einsum('nc,kc->nk', [q, queue])
            # logits: Nx(1+K)
            logits = torch.cat([l_pos, l_neg], dim=1)

            # apply temperature
            logits /= self.temperature

            # labels: positive key indicators
            labels = torch.zeros(logits.shape[0], dtype=torch.long).cuda()
            loss = F.cross_entropy(logits, labels)

        return loss

# %% [markdown]
# # MODEL TRAINING AND TESTING

# %%
total_data = len(X_train) + len(X_val)
initial_train_size = int(0.05 * total_data)
checkpoints = [
    int(0.5 * total_data), 
    int(0.6 * total_data), 
    int(0.7 * total_data),
    len(X_train)
]
min_increment = 25

# %%
def compute_metrics(p, label, classes):
    preds = torch.tensor(p.predictions) # Sigmoid and threshold for multi-label
    labels = torch.tensor(p.label_ids)

    hamming_accuracy = (preds == labels).float().mean().item()

    # Standard multi-label precision, recall, and F1 metrics
    precision, recall, f1_micro, _ = precision_recall_fscore_support(labels, preds, average='micro', zero_division=0)
    _, _, f1_macro, _ = precision_recall_fscore_support(labels, preds, average='macro', zero_division=0)

    report = classification_report(
        labels, 
        preds, 
        labels=label,
        target_names=classes,
        zero_division=0
    ) 

    return {
        'accuracy': hamming_accuracy,
        'precision': precision,
        'recall': recall,
        'f1_micro': f1_micro,
        'f1_macro': f1_macro,
        'report': report
    }

# %%
def compute_metrics_overall(p, classes):
    preds = torch.tensor(p.predictions)
    labels = torch.tensor(p.label_ids)

    # Ensure it's in the correct shape
    if preds.shape != labels.shape:
        raise ValueError("Shape mismatch: predictions and labels must have the same shape.")

    # Hamming accuracy: proportion of correctly predicted labels over total labels
    hamming_accuracy = (preds == labels).float().mean().item()

    # Compute per-label (column-wise) precision, recall, F1
    precision_list, recall_list, f1_micro_list, f1_macro_list = [], [], [], []
    
    for i in range(labels.shape[1]):  # Loop through each column (multi-output)
        prec, rec, f1_micro, _ = precision_recall_fscore_support(
            labels[:, i], preds[:, i], average='micro', zero_division=0
        )
        _, _, f1_macro, _ = precision_recall_fscore_support(
            labels[:, i], preds[:, i], average='macro', zero_division=0
        )

        precision_list.append(prec)
        recall_list.append(rec)
        f1_micro_list.append(f1_micro)
        f1_macro_list.append(f1_macro)

    # Compute average metrics across all outputs
    precision = sum(precision_list) / len(precision_list)
    recall = sum(recall_list) / len(recall_list)
    f1_micro = sum(f1_micro_list) / len(f1_micro_list)
    f1_macro = sum(f1_macro_list) / len(f1_macro_list)

    # Generate classification report per output
    reports = [classification_report(labels[:, i], preds[:, i], target_names=classes, zero_division=0) for i in range(labels.shape[1])]

    return {
        'accuracy': hamming_accuracy,
        'precision': precision,
        'recall': recall,
        'f1_micro': f1_micro,
        'f1_macro': f1_macro,
        'reports': reports  # Returns list of reports, one for each output label
    }

# %%
def concat_test_result(outputs):
    outputs[0] = np.concatenate(outputs[0], axis=0)
    outputs[1] = np.concatenate(outputs[1], axis=0)
    outputs[2] = np.concatenate(outputs[2], axis=0)
    outputs[3] = np.concatenate(outputs[3], axis=0)
    outputs[4] = np.concatenate(outputs[4], axis=0)
    return outputs

def neaten_test_result(outputs, logits, labels, test_type):
    labels = labels.data.cpu().numpy()
    prob, pred = torch.topk(logits, 6 if test_type == 'aspect' else 2)
    prob = torch.sigmoid(prob).data.cpu().numpy()
    pred = pred.data.cpu().numpy()
    logits = torch.sigmoid(logits).data.cpu().numpy()
    pred_labels = np.zeros(logits.shape)
    pred_labels[logits >= 0.5] = 1
    outputs[0].append(labels)
    outputs[1].append(pred)
    outputs[2].append(prob)
    outputs[3].append(logits)
    outputs[4].append(pred_labels)
    
    return outputs

# %%
def train_total_sep2(aspect_datasets, dataloaders, trials, aspect_metrics, sentiment_metrics, metrics, current_train_size, label_num=-1, total_patience=3):
    accelerator = Accelerator(mixed_precision='fp16')
    device = accelerator.device
    accelerator.print(accelerator.distributed_type)
    
    tasks = ['aspect', 'sentiment']
    sentiment_val_loader = None

    for task in tasks:
        accelerator.print("--------------------------------------------------")
        if task == 'sentiment':
            accelerator.print("SENTIMENT ANALYSIS")
        else:
            accelerator.print("ASPECT DETECTION")
            
        accelerator.wait_for_everyone()
        best_score = {
            'accuracy': 0,
            'f1_micro': 0,
            'f1_macro': 0
        }  # Track best score for first phase
        best_score2 = {
            'accuracy': 0,
            'f1_micro': 0,
            'f1_macro': 0
        }  # Track best score for second phase
        second_phase = False  # Control flag for switching between training phases
        total_patience_cnt = 0
        models = {}

        # Initialize backbone model for task learning
        label_num = 6 if task == 'aspect' else 2
        models['backbone'] = IndoBERT_Backbone(label_num)
        optim_backbone = torch.optim.AdamW(models['backbone'].parameters(), lr=2e-5, weight_decay=0.01)

        # Initialize VAE module if specified (aligns with CoMAL's contrastive and auxiliary module)
        models['vae_module'] = MLP_VAE(768, device, label_num=label_num)
        optim_module = torch.optim.AdamW(models['vae_module'].parameters(), lr=2e-5, weight_decay=0.01)

        if task == 'sentiment':
            best_aspect_model = torch.load(f"{filename}-aspect-p1-backbone-{trials+1}.pt", weights_only=False)
            train_loader, val_loader, _, _ = build_sentiment_dataset(
                device, aspect_datasets['train'], aspect_datasets['val'], best_aspect_model, tokenizer, max_length=sequence_length
            )
            sentiment_val_loader = val_loader
            
        else:
            train_loader = dataloaders['labeled']
            val_loader = dataloaders['test']

        accelerator.wait_for_everyone()
        models['backbone'], models['vae_module'], train_loader, val_loader = accelerator.prepare(
            models['backbone'], models['vae_module'], train_loader, val_loader
        )

        # Loop over epochs
        for epoch in range(1, epochs+1):
            if second_phase:
                models['backbone'].eval()  # Backbone frozen in second phase
            else:
                models['backbone'].train()
            models['vae_module'].train()

            # Iterate over labeled data for training
            total_loss = 0
            for data in train_loader:
                # Zero the gradients for all optimizers
                optim_backbone.zero_grad()
                optim_module.zero_grad()

                # Prepare inputs and labels for training
                labels, idx, loss_weight = [x.to(device) for x in data[1:4]]
                input_ids, input_type_ids, input_mask = [x.to(device) for x in data[0]]
                inputs_list = [input_ids, input_type_ids, input_mask, None]

                loss = 0

                # Forward pass through backbone model
                clf_out, encoder_cls = models['backbone'](inputs_list)

                # VAE training logic (aligns with CoMAL's multi-label decoupling and contrastive learning)
                loss2 = 0
                module_cls = encoder_cls.detach()  # Detach to prevent gradient flow to backbone

                # Forward pass through VAE module
                recon_x, latent_rep, recon_x_clf, _ = models['vae_module'](module_cls, labels=labels, weights=loss_weight)

                # Compute contrastive loss if enabled (aligns with CoMAL's use of contrastive learning)
                cl_labels = get_cl_labels(labels, label_num, loss_weight).view(-1)
                cl_labels_total = cl_labels.unsqueeze(-1)
                proj_total = latent_rep.view(-1, latent_rep.shape[-1])
                proj_total = F.normalize(proj_total, dim=-1)  # Normalize latent representation
                batch_size = clf_out.shape[0] * label_num
                mask, neg_mask = get_cl_mask(cl_labels_total, label_num, batch_size)

                criterion_cl = SupConLoss()  # Supervised contrastive loss function
                cl_loss = criterion_cl(proj_total, mask, neg_mask, batch_size, device)
                loss2 += cl_loss  # Add contrastive loss

                # Compute reconstruction and classification loss
                criterion_mse = nn.MSELoss()
                recon_mse_loss = criterion_mse(recon_x, module_cls)
                criterion_bce = nn.BCEWithLogitsLoss(weight=loss_weight, reduction='mean')
                recon_bce_loss = criterion_bce(recon_x_clf, labels.float())
                
                loss2 += recon_mse_loss + recon_bce_loss
                
                # Compute classification loss for the backbone (first phase)
                if not second_phase:
                    criterion = nn.BCEWithLogitsLoss(weight=loss_weight, reduction='mean')
                    clf_loss = criterion(clf_out, labels.float())
                    loss += clf_loss  # Add classification loss to total loss

                # Add VAE loss to total loss
                loss += loss2
                # Backpropagation step
                accelerator.backward(loss)
                
                total_loss += loss

                # Update weights based on current phase
                if second_phase:
                    optim_module.step()
                else:
                    optim_module.step()
                    optim_backbone.step()

            # Scheduler step for learning rate adjustment
            if second_phase:
                accelerator.print('in second')
            
            result = {}
            outputs_clf = [[], [], [], [], []]
            outputs_dual = [[], [], [], [], []]
            match task:
                case 'aspect':
                    with torch.no_grad():
                        for data in val_loader:
                            input_ids, input_type_ids, input_mask = [x.to(device, non_blocking=True) for x in data[0]]
                            labels = data[1].to(device)
                            out = [input_ids, input_type_ids, input_mask, None]
                
                            clf_out, encoder_cls = models['backbone'](out)
                            outputs_clf = neaten_test_result(outputs_clf, clf_out, labels, task)

                            if 'vae_module' in models.keys():
                                _, _, recon_x_clf, _ = models['vae_module'](encoder_cls, reset_proto=True)
                                outputs_dual = neaten_test_result(outputs_dual, recon_x_clf, labels, task)

                    if second_phase:
                        outputs_dual = concat_test_result(outputs_dual)
                        preds = torch.tensor(outputs_dual[4], device=device)
                        labels = torch.tensor(outputs_dual[0], device=device)
                    else:
                        outputs_clf = concat_test_result(outputs_clf)
                        preds = torch.tensor(outputs_clf[4], device=device)
                        labels = torch.tensor(outputs_clf[0], device=device)

                    preds = accelerator.gather_for_metrics(preds)
                    labels = accelerator.gather_for_metrics(labels)
                        
                    result = compute_metrics(
                        type('EvalOutput', (object,), {'predictions': preds.cpu().numpy(), 'label_ids': labels.cpu().numpy()}),
                        None,
                        ['fuel', 'machine', 'others', 'part', 'price', 'service']
                    )
                case 'sentiment':
                    sentiment_val_outputs = []
                    with torch.no_grad():
                        for data in val_loader:
                            input_ids, input_type_ids, input_mask = [x.to(device, non_blocking=True) for x in data[0]]
                            labels = data[1].to(device)
                            out = [input_ids, input_type_ids, input_mask, None]
                        
                            clf_out, encoder_cls = models['backbone'](out)
                            clf_out = torch.sigmoid(clf_out)
                        
                            if 'vae_module' in models.keys():
                                _, _, recon_x_clf, _ = models['vae_module'](encoder_cls, reset_proto=True)
                                recon_x_clf = torch.sigmoid(recon_x_clf)

                            for i in range(len(clf_out)):
                                val_output = {
                                    'label': data[1][i],
                                    'aspect': data[7][i],
                                    'ori_indices': data[2][i],
                                    'pred': np.argmax(clf_out[i].cpu().numpy() if not second_phase else recon_x_clf[i].cpu().numpy()),
                                }
                                sentiment_val_outputs.append(val_output)

                    sentiment_val_outputs = accelerator.gather_for_metrics(sentiment_val_outputs)
                    unique_val_outputs = {(x['ori_indices'].item(), x['aspect']): x for x in sentiment_val_outputs}
                    sentiment_val_outputs = list(unique_val_outputs.values())

                    result = compute_metrics(
                        type('EvalOutput', (object,), {'predictions': [item['pred'] for item in sentiment_val_outputs], 'label_ids': [np.argmax(item['label'].cpu().numpy()) for item in sentiment_val_outputs]}),
                        [0, 1],
                        ['negative', 'positive']
                    )

            if second_phase:
                if result["f1_micro"] >= best_score2['f1_micro']:
                    total_patience_cnt = 0
                    best_score2 = result
                    
                    accelerator.wait_for_everyone()
                    unwrapped_vae = accelerator.unwrap_model(models['vae_module'])
                    if accelerator.is_local_main_process:
                        accelerator.save(unwrapped_vae, f"{filename}-{task}-p2-vae-{trials+1}.pt")
                else:
                    total_patience_cnt += 1
                    if total_patience_cnt >= total_patience:
                        break
            else:
                if result["f1_micro"] >= best_score['f1_micro']:
                    best_score = result
                    total_patience_cnt = 0

                    accelerator.wait_for_everyone()
                    unwrapped_backbone = accelerator.unwrap_model(models['backbone'])
                    unwrapped_vae = accelerator.unwrap_model(models['vae_module'])

                    if accelerator.is_local_main_process:
                        accelerator.save(unwrapped_backbone, f"{filename}-{task}-p1-backbone-{trials+1}.pt")
                        accelerator.save(unwrapped_vae, f"{filename}-{task}-p1-vae-{trials+1}.pt")
                else:
                    total_patience_cnt += 1
                    if total_patience_cnt >= total_patience:
                        total_patience_cnt = 0
                        second_phase = True
                
            accelerator.print(f"EPOCH {epoch} | LOSS: {total_loss / len(dataloaders['labeled'])} | ACCURACY: {round(result['accuracy'], 4)} | F1 MACRO: {round(result['f1_macro'], 4)} | F1 MICRO: {round(result['f1_micro'], 4)}")

        if accelerator.is_local_main_process:
            if task == 'aspect':
                aspect_metrics[0].append(best_score['accuracy'])
                aspect_metrics[1].append(best_score['f1_micro'])
                aspect_metrics[2].append(best_score['f1_macro'])
            elif task == 'sentiment':
                sentiment_metrics[0].append(best_score['accuracy'])
                sentiment_metrics[1].append(best_score['f1_micro'])
                sentiment_metrics[2].append(best_score['f1_macro'])
        
        accelerator.print(f"{task}: ACCURACY {round(best_score['accuracy'], 4)} | F1 MACRO {round(best_score['f1_macro'], 4)} | F1 MICRO {round(best_score['f1_micro'], 4)}")
        accelerator.print(best_score['report'])

    # Compute overall metrics
    aspect_labels = []
    aspect_indices = []
    aspect_preds = []

    aspect_outputs = {}
    sentiment_outputs = []

    accelerator.wait_for_everyone()
    
    best_aspect_model = torch.load(f"{filename}-aspect-p1-backbone-{trials+1}.pt", weights_only=False)
    best_sentiment_model = torch.load(f"{filename}-sentiment-p1-backbone-{trials+1}.pt", weights_only=False)

    best_aspect_model, best_sentiment_model, val_loader = accelerator.prepare(best_aspect_model, best_sentiment_model, dataloaders['test'])

    with torch.no_grad():
        for batch in val_loader:
            input_ids, input_type_ids, input_mask = [x.to(device) for x in batch[0]]
            inputs_list = [input_ids, input_type_ids, input_mask, None]
            clf_out, encoder_cls = best_aspect_model(inputs_list)
            preds = torch.sigmoid(clf_out).round()

            aspect_indices.append(accelerator.gather(batch[2]))
            aspect_labels.append(accelerator.gather(batch[6]))
            aspect_preds.append(accelerator.gather(preds))

        aspect_indices = torch.cat(aspect_indices).cpu().numpy()
        aspect_labels = torch.cat(aspect_labels).cpu().numpy()
        aspect_preds = torch.cat(aspect_preds).cpu().numpy()

        accelerator.wait_for_everyone()
        aspect_outputs = [
            {'ori_indices': aspect_indices[i], 
             'ori_labels': aspect_labels[i], 
             'pred': aspect_preds[i]}
            for i in range(len(aspect_preds))
        ]
        aspect_outputs = {x['ori_indices'].item(): x for x in aspect_outputs}
    
        for batch in sentiment_val_loader:
            input_ids, input_type_ids, input_mask = [x.to(device) for x in batch[0]]
            inputs_list = [input_ids, input_type_ids, input_mask, None]
            clf_out, encoder_cls = best_sentiment_model(inputs_list)
            preds = torch.sigmoid(clf_out).round()
    
            for i in range(len(preds)):
                output = {
                    'aspect': batch[7][i],
                    'ori_indices': batch[8][i],
                    'pred': np.argmax(preds[i].cpu().numpy()),
                }
                sentiment_outputs.append(output)

        sentiment_outputs = accelerator.gather_for_metrics(sentiment_outputs)
        sentiment_outputs = {(x['ori_indices'].item(), x['aspect']): x for x in sentiment_outputs}

    # Replcae non neutral aspect to its predicted sentiment
    accelerator.wait_for_everyone()
    if accelerator.is_main_process:
        i = -1
        for (ori_index, aspect), value in sentiment_outputs.items():
            aspect = aspect_mapping[aspect]
            aspect_outputs[ori_index]['pred'][aspect] = 2 if value['pred'] == 1.0 else value['pred']

        result = compute_metrics_overall(
            type('EvalOutput', (object,), {'predictions': [output['pred'] for output in aspect_outputs.values()], 'label_ids': [output['ori_labels'] for output in aspect_outputs.values()]}),
            ['negative', 'neutral', 'positive'],
        )

        accelerator.print("--------------------------------------------------")
        accelerator.print(f"Iteration {current_train_size}: Accuracy: {round(result['accuracy'], 4)}, F1 Micro: {round(result['f1_micro'], 4)}, F1 Macro: {round(result['f1_macro'], 4)}")
        accelerator.print("--------------------------------------------------")
        
        for i in range(len(train_labels)):
            accelerator.print(f"Aspect {aspect_list[i]} report:")
            accelerator.print(result['reports'][i])
            
        metrics[0].append(current_train_size)
        metrics[1].append(result['accuracy'])
        metrics[2].append(result['f1_micro'])
        metrics[3].append(result['f1_macro'])

# %% [markdown]
# # QUERY STRATEGY

# %%
def query_samples(filename, dataset, labeled_set, unlabeled_indices, num_labels, trials, sampling_dur, new_sample_data, new_sample_labels,
                  label_cardinality=None, labeled_subset=None, save_path=None, cl_neg_mode=1, n_samples=min_increment):
    accelerator = Accelerator(mixed_precision='fp16')
    device = accelerator.device

    models = {}
    tasks = ['aspect', 'sentiment']

    for task in tasks:
        models[f'{task}_backbone'] = torch.load(f"{filename}-{task}-p1-backbone-{trials+1}.pt")
        if os.path.exists(f'/kaggle/working/{filename}-{task}-p2-vae-{trials+1}.pt'):
            models[f'{task}_vae_module'] = torch.load(f"{filename}-{task}-p2-vae-{trials+1}.pt")
        else:
            models[f'{task}_vae_module'] = torch.load(f"{filename}-{task}-p1-vae-{trials+1}.pt")

    current_train_size = len(dataset.get_labeled_set())
    
    # Set all models to evaluation mode to freeze parameters during sampling
    for model_name in models.keys():
        models[model_name].to(device)
        models[model_name].eval()

    # Initialize lists to store outputs used for sampling calculations
    aspect_outputs = {}
    sentiment_outputs = {}
    
    labeled_distances = []
    labeled_ground_truths = []
    
    labeled_aspects = []
    labeled_labels = []
    labeled_indices = []
    labeled_texts = []

    unlabeled_aspects = []
    unlabeled_labels = []
    unlabeled_ori_indices = []
    unlabeled_texts = []

    # DataLoader for labeled data subset, sampled randomly
    labeled_dataloader = DataLoader(
        dataset,
        batch_size=batch_size,
        num_workers=4,
        shuffle=False,
        pin_memory=True,
        sampler=SubsetRandomSampler(list(set(labeled_set)))
    )

    start_time = time.time()

    # Process labeled data to extract features and distances for sampling criteria
    for batch in labeled_dataloader:
        text_inputs = batch[0]
        gt_label = batch[1]
        idx = batch[2]
        input_ids, token_type_ids, attention_mask = [x.to(device, non_blocking=True) for x in text_inputs]
        labeled_ground_truths.extend(gt_label)

        with torch.no_grad():
            # Use backbone model to get encoded representations
            predictions, encoded_cls = models['aspect_backbone']([input_ids, token_type_ids, attention_mask, None])

            for i in range(len(predictions)):
                indices = idx[i].item()
                for j in range(len(predictions[i])):
                    if int(predictions[i][j].round()) != 1:
                        labeled_aspects.append(aspect_list[j])
                        labeled_labels.append(gt_label[i][j])
                        labeled_texts.append(batch[5][i])
                        labeled_indices.append(indices)
                    
            _, sub_representation, _, vae_distance = models['aspect_vae_module'](encoded_cls)
            vae_distance = vae_distance.cpu().data
            labeled_distances.extend(vae_distance)

    # Stack outputs for further processing
    labeled_ground_truths = torch.stack(labeled_ground_truths)
    labeled_distances = torch.stack(labeled_distances)

    accelerator.wait_for_everyone()
    if accelerator.is_main_process:
        # Compute self-prototype distances based on CoMAL's contrastive learning mode
        if cl_neg_mode == 1:
            labeled_prototype_distances = labeled_distances[:, :, :-1]  # Exclude last distance for prototype calculation
            labeled_prototype_distances = labeled_prototype_distances * torch.eye(num_labels)  # Keep only diagonal elements
            labeled_prototype_distances = torch.sum(labeled_prototype_distances, dim=-1)  # Sum along prototype axis
            positive_distances = labeled_prototype_distances * labeled_ground_truths  # Mask with ground truth labels
    
        # Calculate max, min, and mean positive distances for uncertainty measurement
        max_positive_distances = torch.max(positive_distances, dim=0)[0]
        min_positive_distances = torch.min(positive_distances + (1 - labeled_ground_truths) * 2, dim=0)[0]
        mean_positive_distances = (max_positive_distances + min_positive_distances) / 2
    
        # DataLoader for unlabeled data to compute sampling scores
        unlabeled_dataloader = DataLoader(
            dataset,
            batch_size=batch_size,
            num_workers=4,
            shuffle=False,
            pin_memory=True,
            sampler=SubsetRandomSampler(list(set(unlabeled_indices)))
        )
    
        # Process unlabeled data to get sampling scores
        for batch in unlabeled_dataloader:
            text_inputs = batch[0]
            labels = batch[1]
            idx = batch[2]
            loss_weight = batch[3]
            input_ids, token_type_ids, attention_mask = [x.to(device) for x in text_inputs]
    
            with torch.no_grad():
                # Get predictions and encoded representations
                predictions, encoded_cls = models['aspect_backbone']([input_ids, token_type_ids, attention_mask, None])
                predictions = predictions.cpu().data
                
                for i in range(len(predictions)):
                    indices = idx[i].item()
                    
                    if indices not in aspect_outputs.keys():
                        aspect_outputs[indices] = {}
                        
                    aspect_outputs[indices]['backbone_predictions'] = predictions[i]
                    aspect_outputs[indices]['loss_weight'] = loss_weight[i]
                    
                    # Collect non neutral aspect for sentiment analysis
                    for j in range(len(predictions[i])):
                        if int(torch.sigmoid(predictions[i][j]).round()) != 1:
                            unlabeled_aspects.append(aspect_list[j])
                            unlabeled_labels.append(labels[i][j])
                            unlabeled_texts.append(batch[5][i])
                            unlabeled_ori_indices.append(indices)
    
                # Get latent representations, reconstructions, and distances
                _, _, _, vae_distance = models['aspect_vae_module'](encoded_cls)

                for i in range(len(vae_distance)):
                    aspect_outputs[idx[i].item()]['backbone_distances'] = vae_distance[i].cpu().data

        # Convert lists to tensors for further computation
        sample_indices = torch.stack([torch.tensor(key, dtype=torch.long) for key in aspect_outputs.keys()])
        sample_weights = torch.stack([aspect_outputs[key]['loss_weight'] for key in aspect_outputs.keys()])
        distance_matrix = torch.stack([aspect_outputs[key]['backbone_distances'] for key in aspect_outputs.keys()])
    
        # Convert predictions to probability and adjust masks for scoring
        backbone_predictions = torch.stack([aspect_outputs[key]['backbone_predictions'] for key, val in aspect_outputs.items()])
        probability_predictions = torch.zeros_like(backbone_predictions) + backbone_predictions
        probability_predictions = torch.sigmoid(probability_predictions)
        unlabeled_mask = torch.ones_like(sample_weights) - sample_weights
    
        # Calculate uncertainty metrics and part scores for sampling
        sample_weights = sample_weights.view(-1)
    
        # Mask predictions based on positive distances
        positive_distance_mask = ((probability_predictions >= 0.5) * unlabeled_mask).float()
        positive_prototype_distances = distance_matrix[:, :, :-1]
        positive_prototype_distances = positive_prototype_distances * torch.eye(num_labels)
        positive_prototype_distances = torch.sum(positive_prototype_distances, dim=-1)
    
        # Compute scores based on uncertainty and diversity metrics
        prediction_mask = (positive_prototype_distances > mean_positive_distances).float()
        distance_count = torch.sum(prediction_mask, dim=-1)
        cardinality_difference = torch.abs(distance_count - label_cardinality)
        score_weight = positive_distance_mask * (positive_prototype_distances + 1) / 2
        score_weight = 1 / torch.sum(score_weight + 1e-10, dim=-1)
        adjusted_score = torch.pow(score_weight, 0.5) * torch.pow(cardinality_difference, 1 - 0.5)
        final_scores = adjusted_score.unsqueeze(-1)
        average_scores = torch.mean(final_scores, dim=-1).cpu().numpy()

        z = 0
        for key in aspect_outputs.keys():
            aspect_outputs[key]['score'] = average_scores[z]
            z += 1

    # -------- SENTIMENT ANALYSIS ---------
    accelerator.wait_for_everyone()
    labeled_sentiment_dataset = SentimentAnalysisDataset(labeled_texts, labeled_labels, labeled_aspects, labeled_indices, tokenizer, label_mapping, max_length=sequence_length)
    unlabeled_sentiment_dataset = SentimentAnalysisDataset(unlabeled_texts, unlabeled_labels, unlabeled_aspects, unlabeled_ori_indices, tokenizer, label_mapping, max_length=sequence_length)
    
    labeled_loader = torch.utils.data.DataLoader(
        labeled_sentiment_dataset, batch_size=batch_size, shuffle=False, pin_memory=True, num_workers=4,
    )
    unlabeled_loader = torch.utils.data.DataLoader(
        unlabeled_sentiment_dataset, batch_size=batch_size, shuffle=False, pin_memory=True, num_workers=4,
    )

    labeled_ground_truths = []
    labeled_distances = []
    for batch in labeled_loader:
        text_inputs = batch[0]
        gt_label = batch[1]
        input_ids, token_type_ids, attention_mask = [x.to(device, non_blocking=True) for x in text_inputs]
        labeled_ground_truths.extend(gt_label)

        with torch.no_grad():
            # Use backbone model to get encoded representations
            predictions, encoded_cls = models['sentiment_backbone']([input_ids, token_type_ids, attention_mask, None])
                    
            _, sub_representation, _, vae_distance = models['sentiment_vae_module'](encoded_cls)
            labeled_distances.extend(vae_distance.cpu().data)

    # Stack outputs for further processing
    labeled_ground_truths = torch.stack(labeled_ground_truths)
    labeled_distances = torch.stack(labeled_distances)

    accelerator.wait_for_everyone()
    if accelerator.is_main_process:
        # Compute self-prototype distances based on CoMAL's contrastive learning mode
        labeled_prototype_distances = labeled_distances[:, :, :-1]  # Exclude last distance for prototype calculation
        labeled_prototype_distances = labeled_prototype_distances * torch.eye(2)  # Keep only diagonal elements
        labeled_prototype_distances = torch.sum(labeled_prototype_distances, dim=-1)  # Sum along prototype axis
        positive_distances = labeled_prototype_distances * labeled_ground_truths  # Mask with ground truth labels
    
        # Calculate max, min, and mean positive distances for uncertainty measurement
        max_positive_distances = torch.max(positive_distances, dim=0)[0]
        min_positive_distances = torch.min(positive_distances + (1 - labeled_ground_truths) * 2, dim=0)[0]
        mean_positive_distances = (max_positive_distances + min_positive_distances) / 2
    
        # Process unlabeled data to get sampling scores
        for batch in unlabeled_loader:
            text_inputs = batch[0]
            idx = batch[8]
            loss_weight = batch[3]
            input_ids, token_type_ids, attention_mask = [x.to(device) for x in text_inputs]
    
            with torch.no_grad():
                # Get predictions and encoded representations
                predictions, encoded_cls = models['sentiment_backbone']([input_ids, token_type_ids, attention_mask, None])
                predictions = predictions.cpu().data
                    
                for i in range(len(predictions)):
                    indices = idx[i].item()
                    if indices not in sentiment_outputs.keys():
                        sentiment_outputs[indices] = {}
                        sentiment_outputs[idx[i].item()]['backbone_predictions'] = [predictions[i]]
                        sentiment_outputs[idx[i].item()]['loss_weight'] = [loss_weight[i]]
                    else:
                        sentiment_outputs[idx[i].item()]['backbone_predictions'].append(predictions[i])
                        sentiment_outputs[idx[i].item()]['loss_weight'].append(loss_weight[i])
    
                # Get latent representations, reconstructions, and distances
                _, _, _, vae_distance = models['sentiment_vae_module'](encoded_cls)

                for i in range(len(vae_distance)):
                    if 'backbone_distances' not in sentiment_outputs[indices].keys():
                        sentiment_outputs[idx[i].item()]['backbone_distances'] = [vae_distance[i].cpu().data]
                    else:
                        sentiment_outputs[idx[i].item()]['backbone_distances'].append(vae_distance[i].cpu().data)

        # print(len(unlabeled_sentiment_dataset), length, len(sentiment_outputs))
        sample_indices = torch.stack([torch.tensor(key, dtype=torch.long) for key in sentiment_outputs.keys()])

        sample_weights = torch.stack([
            torch.mean(torch.stack(sentiment_outputs[key]['loss_weight']), dim=0).round() 
            for key in sentiment_outputs
        ])
        distance_matrix = torch.stack([
            torch.mean(torch.stack(sentiment_outputs[key]['backbone_distances']), dim=0)
            for key in sentiment_outputs
        ])
        backbone_predictions = torch.stack([
            torch.mean(torch.stack(sentiment_outputs[key]['backbone_predictions']), dim=0) 
            for key in sentiment_outputs
        ])
        
        # Convert predictions to probability and adjust masks for scoring
        probability_predictions = torch.zeros_like(backbone_predictions) + backbone_predictions
        probability_predictions = torch.sigmoid(probability_predictions)
        unlabeled_mask = torch.ones_like(sample_weights) - sample_weights
    
        # Calculate uncertainty metrics and part scores for sampling
        sample_weights = sample_weights.view(-1)
    
        # Mask predictions based on positive distances
        positive_distance_mask = ((probability_predictions >= 0.5) * unlabeled_mask).float()
        positive_prototype_distances = distance_matrix[:, :, :-1]
        positive_prototype_distances = positive_prototype_distances * torch.eye(2)
        positive_prototype_distances = torch.sum(positive_prototype_distances, dim=-1)
    
        # Compute scores based on uncertainty and diversity metrics
        prediction_mask = (positive_prototype_distances > mean_positive_distances).float()
        distance_count = torch.sum(prediction_mask, dim=-1)
        cardinality_difference = torch.abs(distance_count - label_cardinality)
        score_weight = positive_distance_mask * (positive_prototype_distances + 1) / 2
        score_weight = 1 / torch.sum(score_weight + 1e-10, dim=-1)
        adjusted_score = torch.pow(score_weight, 0.5) * torch.pow(cardinality_difference, 1 - 0.5)
        final_scores = adjusted_score.unsqueeze(-1)
        average_sentiment_scores = torch.mean(final_scores, dim=-1).cpu().numpy()

        print(len(average_sentiment_scores), len(sentiment_outputs))

        z = 0
        for key in sentiment_outputs.keys():
            aspect_outputs[key]['score'] = (average_sentiment_scores[z] + aspect_outputs[key]['score']) / 2
            z += 1

        ranked_indices = np.argsort(average_scores)
        ranked_indices = ranked_indices[::-1]
        sample_indices = torch.stack([torch.tensor(key, dtype=torch.long) for key in aspect_outputs.keys()])
        
        # Select top samples for annotation
        threshold = np.percentile(average_scores, 90)
        items_greater_than_threshold = average_scores[average_scores >= threshold]
        num_of_candidates = min(math.ceil(0.1 * len(average_scores)), len(items_greater_than_threshold))
    
        nearest_cp = 0
        for cp in checkpoints:
            if cp > current_train_size:
                nearest_cp = cp
                break
    
        if num_of_candidates <= n_samples and n_samples < nearest_cp - current_train_size:
            selected_indices = ranked_indices[:n_samples]
        elif num_of_candidates > n_samples and num_of_candidates < nearest_cp - current_train_size:
            selected_indices = ranked_indices[:max(n_samples, num_of_candidates)]
        else:
            selected_indices = ranked_indices[:nearest_cp - current_train_size]
            
            temp = dataset.get_labeled_set()
            temp.extend([sample_indices[int(x)] for x in selected_indices])
            
            # Save acquired data up to checkpoint
            acquired_data = pd.DataFrame({
                'processed_text': [X_train[i] for i in temp],
                'fuel': [y_train[i][0] for i in temp],
                'machine': [y_train[i][1] for i in temp],
                'others': [y_train[i][2] for i in temp],
                'part': [y_train[i][3] for i in temp],
                'price': [y_train[i][4] for i in temp],
                'service': [y_train[i][5] for i in temp],
            })
    
            acquired_data.to_csv(f'{filename}-{trials+1}-data-{nearest_cp}.csv', index=False)

        for x in selected_indices:
            new_sample_data.append(sample_indices[int(x)])
        new_sample_labels = None
        
        end_time = time.time()
        duration = end_time - start_time
    
        print("Nearest checkpoint:", nearest_cp)
        print("Threshold:", threshold)
        print("Samples above threshold:", num_of_candidates)
        print("Acquired samples:", len(selected_indices))
        print(f"Sampling duration: {duration} seconds")  # Print or return the runtime if needed
    
        sampling_dur.append(duration)

def pred_part_stat(pred, threshold=0.0):
    part_1 = torch.where(pred >= threshold)[0]
    part_0 = torch.where(pred < threshold)[0]
    return part_0, part_1

# %% [markdown]
# # PLOT RESULT

# %%
import matplotlib.pyplot as plt

def plot_result(data_used, accuracies, f1_micros, f1_macros):
    fig, axs = plt.subplots(1, 3, figsize=(21, 5))
    data_used = [round(data / total_data * 100, 1) for data in data_used]

    # Plot for Accuracy
    axs[0].plot(data_used, accuracies, label="Accuracy", color="blue")
    axs[0].set_xlabel("Percentage of data used")
    axs[0].set_title("Accuracy")
    axs[0].set_xticks(data_used)

    # Plot for F1 Micro
    axs[1].plot(data_used, f1_micros, label="F1 Micro", color="orange")
    axs[1].set_xlabel("Percentage of data used")
    axs[1].set_title("F1 Micro")
    axs[1].set_xticks(data_used)

    # Plot for F1 Macro
    axs[2].plot(data_used, f1_macros, label="F1 Macro", color="green")
    axs[2].set_xlabel("Percentage of data used")
    axs[2].set_title("F1 Macro")
    axs[2].set_xticks(data_used)

    # Adjust layout and show the plots
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # MAIN LOOP

# %%
def active_learning(seed, i):
    aspect_accuracies = manager.list()
    aspect_f1_micros = manager.list()
    aspect_f1_macros = manager.list()
    sentiment_accuracies = manager.list()
    sentiment_f1_micros = manager.list()
    sentiment_f1_macros = manager.list()
    accuracies = manager.list()
    f1_micros = manager.list()
    f1_macros = manager.list()
    data_used = manager.list()
    sampling_dur = manager.list()
    new_sample_data = manager.list()
    new_sample_labels = manager.list()
    
    current_train_size = initial_train_size
    start_time = time.time()
    set_seed(seeds[i])

    print("===============================================")
    print("TRIAL {}".format(i+1))
    print("Random seed:", seeds[i])
    
    # Load label information and dataset
    label_num = 6
    _, _, aspect_train_dataset, aspect_val_dataset = build_aspect_dataset(X_train, y_train, X_val, y_val, sequence_length)
    
    # Shuffle and initialize labeled and unlabeled sets
    indices = list(range(len(aspect_train_dataset)))
    random.shuffle(indices)
    labeled_set = indices[:initial_train_size]  # Random initial labeled set
    unlabeled_set = [x for x in indices if x not in labeled_set]  # Define the unlabeled set
    
    # Update dataset with initial labeled set
    aspect_train_dataset.update_data(labeled_set, init_time=True)
    
    # Prepare data loaders for labeled and test sets
    labeled_loader = DataLoader(
        aspect_train_dataset,
        batch_size=batch_size,
        num_workers=4,
        pin_memory=True,
        sampler=SubsetRandomSampler(list(set(labeled_set)))
    )
    test_loader = DataLoader(
        aspect_val_dataset,
        batch_size=batch_size,
        num_workers=4,
        pin_memory=True
    )

    models = {}

    while current_train_size < checkpoints[len(checkpoints) - 1]:
        dataloaders = {
            'labeled': labeled_loader,
            'test': test_loader
        }
        aspect_datasets = {
            'train': aspect_train_dataset,
            'val': aspect_val_dataset
        }
    
        # Train model
        train_args = (
            aspect_datasets,
            dataloaders, 
            i, 
            (aspect_accuracies, aspect_f1_micros, aspect_f1_macros), 
            (sentiment_accuracies, sentiment_f1_micros, sentiment_f1_macros),
            (data_used, accuracies, f1_micros, f1_macros), 
            current_train_size, 
            label_num
        )
        notebook_launcher(train_total_sep2, train_args, num_processes=2)
        
        query_set = list(set(unlabeled_set))
        random.shuffle(query_set)
    
        # Query samples for next cycle, using appropriate selection strategy
        new_sample_data = manager.list()
        new_sample_labels = manager.list()
        sampling_args = (
            filename,
            aspect_train_dataset, 
            labeled_set,
            query_set, 
            label_num,
            i,
            sampling_dur,
            new_sample_data,
            new_sample_labels,
            aspect_train_dataset.get_label_Cardinality()
        )
        notebook_launcher(query_samples, sampling_args, num_processes=2)
        new_sample_data = list(new_sample_data)
        new_sample_labels = list(new_sample_labels)

        # print(len(new_sample_data))
        aspect_train_dataset.update_data(new_sample_data, None)
        labeled_set = aspect_train_dataset.get_labeled_set()
        unlabeled_set = [x for x in indices if x not in labeled_set]
    
        # Refresh data loader with new labeled set
        labeled_loader = DataLoader(
            aspect_train_dataset,
            batch_size=batch_size,
            num_workers=4,
            pin_memory=True,
            sampler=SubsetRandomSampler(list(set(labeled_set)))
        )
        
        # Update current train size
        current_train_size = len(labeled_set)
        print("New train size:", current_train_size)
    
    # DataLoader dictionary to be used for training and testing
    dataloaders = {
        'labeled': labeled_loader,
        'test': test_loader
    }
    
    # Train last iteration
    train_args = (
        aspect_datasets,
        dataloaders, 
        i, 
        (aspect_accuracies, aspect_f1_micros, aspect_f1_macros), 
        (sentiment_accuracies, sentiment_f1_micros, sentiment_f1_macros),
        (data_used, accuracies, f1_micros, f1_macros), 
        current_train_size, 
        label_num
    )
    notebook_launcher(train_total_sep2, train_args, num_processes=2)
    data_used, accuracies, f1_micros, f1_macros, sampling_dur = list(data_used), list(accuracies), list(f1_micros), list(f1_macros), list(sampling_dur)
    aspect_accuracies, aspect_f1_micros, aspect_f1_macros = list(aspect_accuracies), list(aspect_f1_micros), list(aspect_f1_macros)
    sentiment_accuracies, sentiment_f1_micros, sentiment_f1_macros = list(sentiment_accuracies), list(sentiment_f1_micros), list(sentiment_f1_macros)
        
    # Log results
    end_time = time.time()
    duration = end_time - start_time

    print(f"Total sampling time: {np.array(sampling_dur).sum().round(2)} seconds")
    print(f"Total runtime: {duration} seconds")

    plot_result(data_used, accuracies, f1_micros, f1_macros)
    
    results = pd.DataFrame({
        'Data Used': data_used,
        'Aspect Accuracy': aspect_accuracies,
        'Aspect F1 Micro': aspect_f1_micros,
        'Aspect F1 Macro': aspect_f1_macros,
        'Sentiment Accuracy': sentiment_accuracies,
        'Sentiment F1 Micro': sentiment_f1_micros,
        'Sentiment F1 Macro': sentiment_f1_macros,
        'Accuracy': accuracies,
        'F1 Micro': f1_micros,
        'F1 Macro': f1_macros,
    })
    sampling_dur.insert(0, 0)
    
    results['Sampling Duration'] = sampling_dur
    
    results.to_csv(f'{filename}-{i+1}-results.csv', index=False)

# %%
seeds = [50, 81, 14, 3, 94]

# %% [markdown]
# ## RUN 1

# %%
active_learning(seeds[0], 0)
# Out:
# ===============================================
# TRIAL 1
# Random seed: 50
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.4285407066345215 | ACCURACY: 0.7329 | F1 MACRO: 0.8333 | F1 MICRO: 0.8411
# EPOCH 2 | LOSS: 3.2759060859680176 | ACCURACY: 0.7723 | F1 MACRO: 0.86 | F1 MICRO: 0.8681
# EPOCH 3 | LOSS: 3.174009323120117 | ACCURACY: 0.7924 | F1 MACRO: 0.8822 | F1 MICRO: 0.8837
# EPOCH 4 | LOSS: 3.0779800415039062 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# EPOCH 5 | LOSS: 3.0897669792175293 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# EPOCH 6 | LOSS: 2.987666606903076 | ACCURACY: 0.7902 | F1 MACRO: 0.8812 | F1 MICRO: 0.8826
# in second
# EPOCH 7 | LOSS: 2.796860456466675 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# in second
# EPOCH 8 | LOSS: 2.6878042221069336 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# in second
# EPOCH 9 | LOSS: 2.478614330291748 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# in second
# EPOCH 10 | LOSS: 2.386249303817749 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# aspect: ACCURACY 0.7924 | F1 MACRO 0.8822 | F1 MICRO 0.8837
#               precision    recall  f1-score   support
#
#         fuel       0.83      1.00      0.91       187
#      machine       0.78      1.00      0.88       175
#       others       0.71      1.00      0.83       158
#         part       0.72      0.99      0.84       158
#        price       0.86      1.00      0.92       192
#      service       0.85      1.00      0.92       191
#
#    micro avg       0.79      1.00      0.88      1061
#    macro avg       0.79      1.00      0.88      1061
# weighted avg       0.80      1.00      0.89      1061
#  samples avg       0.79      1.00      0.88      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 1.5277245044708252 | ACCURACY: 0.6667 | F1 MACRO: 0.4 | F1 MICRO: 0.6667
# EPOCH 2 | LOSS: 1.3809763193130493 | ACCURACY: 0.6667 | F1 MACRO: 0.4 | F1 MICRO: 0.6667
# EPOCH 3 | LOSS: 1.252987265586853 | ACCURACY: 0.6667 | F1 MACRO: 0.4 | F1 MICRO: 0.6667
# EPOCH 4 | LOSS: 1.17083740234375 | ACCURACY: 0.6667 | F1 MACRO: 0.4 | F1 MICRO: 0.6667
# EPOCH 5 | LOSS: 1.1955150365829468 | ACCURACY: 0.6667 | F1 MACRO: 0.4 | F1 MICRO: 0.6667
# EPOCH 6 | LOSS: 1.1505563259124756 | ACCURACY: 0.6667 | F1 MACRO: 0.4 | F1 MICRO: 0.6667
# EPOCH 7 | LOSS: 1.1758167743682861 | ACCURACY: 0.6667 | F1 MACRO: 0.4 | F1 MICRO: 0.6667
# EPOCH 8 | LOSS: 1.0909439325332642 | ACCURACY: 0.6667 | F1 MACRO: 0.4 | F1 MICRO: 0.6667
# EPOCH 9 | LOSS: 1.068453073501587 | ACCURACY: 0.6667 | F1 MACRO: 0.4 | F1 MICRO: 0.6667
# EPOCH 10 | LOSS: 1.0418633222579956 | ACCURACY: 0.6667 | F1 MACRO: 0.4 | F1 MICRO: 0.6667
# sentiment: ACCURACY 0.6667 | F1 MACRO 0.4 | F1 MICRO 0.6667
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00         1
#     positive       0.67      1.00      0.80         2
#
#     accuracy                           0.67         3
#    macro avg       0.33      0.50      0.40         3
# weighted avg       0.44      0.67      0.53         3
#
# --------------------------------------------------
# Iteration 54: Accuracy: 0.7894, F1 Micro: 0.7894, F1 Macro: 0.2965
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        11
#      neutral       0.84      1.00      0.91       181
#     positive       0.00      0.00      0.00        24
#
#     accuracy                           0.84       216
#    macro avg       0.28      0.33      0.30       216
# weighted avg       0.70      0.84      0.76       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        16
#      neutral       0.77      1.00      0.87       167
#     positive       0.00      0.00      0.00        33
#
#     accuracy                           0.77       216
#    macro avg       0.26      0.33      0.29       216
# weighted avg       0.60      0.77      0.67       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        12
#      neutral       0.70      1.00      0.83       152
#     positive       0.00      0.00      0.00        52
#
#     accuracy                           0.70       216
#    macro avg       0.23      0.33      0.28       216
# weighted avg       0.50      0.70      0.58       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        23
#      neutral       0.72      0.99      0.83       152
#     positive       0.33      0.02      0.05        41
#
#     accuracy                           0.70       216
#    macro avg       0.35      0.34      0.29       216
# weighted avg       0.57      0.70      0.60       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        13
#      neutral       0.86      1.00      0.93       186
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.86       216
#    macro avg       0.29      0.33      0.31       216
# weighted avg       0.74      0.86      0.80       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        14
#      neutral       0.86      1.00      0.92       185
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.86       216
#    macro avg       0.29      0.33      0.31       216
# weighted avg       0.73      0.86      0.79       216
#
# Launching training on 2 GPUs.
# 16 16
# Nearest checkpoint: 540
# Threshold: 88888.890625
# Samples above threshold: 81
# Acquired samples: 81
# Sampling duration: 5.290910243988037 seconds
# New train size: 135
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.812774658203125 | ACCURACY: 0.7857 | F1 MACRO: 0.8754 | F1 MICRO: 0.8784
# EPOCH 2 | LOSS: 3.4438202381134033 | ACCURACY: 0.7909 | F1 MACRO: 0.8816 | F1 MICRO: 0.8831
# EPOCH 3 | LOSS: 3.167056083679199 | ACCURACY: 0.8051 | F1 MACRO: 0.8886 | F1 MICRO: 0.89
# EPOCH 4 | LOSS: 3.036970615386963 | ACCURACY: 0.8192 | F1 MACRO: 0.8946 | F1 MICRO: 0.8961
# EPOCH 5 | LOSS: 2.834019184112549 | ACCURACY: 0.8333 | F1 MACRO: 0.902 | F1 MICRO: 0.9032
# EPOCH 6 | LOSS: 2.7989184856414795 | ACCURACY: 0.8371 | F1 MACRO: 0.9027 | F1 MICRO: 0.9044
# EPOCH 7 | LOSS: 2.806694507598877 | ACCURACY: 0.849 | F1 MACRO: 0.9098 | F1 MICRO: 0.911
# EPOCH 8 | LOSS: 2.6960346698760986 | ACCURACY: 0.8571 | F1 MACRO: 0.9127 | F1 MICRO: 0.9147
# EPOCH 9 | LOSS: 2.6710445880889893 | ACCURACY: 0.8638 | F1 MACRO: 0.9157 | F1 MICRO: 0.918
# EPOCH 10 | LOSS: 2.554992437362671 | ACCURACY: 0.881 | F1 MACRO: 0.9246 | F1 MICRO: 0.9273
# aspect: ACCURACY 0.881 | F1 MACRO 0.9246 | F1 MICRO 0.9273
#               precision    recall  f1-score   support
#
#         fuel       0.89      1.00      0.94       187
#      machine       0.90      0.94      0.92       175
#       others       0.84      0.89      0.86       158
#         part       0.86      0.95      0.90       158
#        price       0.96      0.98      0.97       192
#      service       0.91      1.00      0.95       191
#
#    micro avg       0.90      0.96      0.93      1061
#    macro avg       0.89      0.96      0.92      1061
# weighted avg       0.90      0.96      0.93      1061
#  samples avg       0.90      0.96      0.92      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 15.346585273742676 | ACCURACY: 0.7194 | F1 MACRO: 0.5163 | F1 MICRO: 0.7194
# EPOCH 2 | LOSS: 13.968140602111816 | ACCURACY: 0.8776 | F1 MACRO: 0.8639 | F1 MICRO: 0.8776
# EPOCH 3 | LOSS: 11.569036483764648 | ACCURACY: 0.8673 | F1 MACRO: 0.8408 | F1 MICRO: 0.8673
# EPOCH 4 | LOSS: 10.991159439086914 | ACCURACY: 0.8878 | F1 MACRO: 0.8679 | F1 MICRO: 0.8878
# EPOCH 5 | LOSS: 10.100428581237793 | ACCURACY: 0.8827 | F1 MACRO: 0.8625 | F1 MICRO: 0.8827
# EPOCH 6 | LOSS: 9.432140350341797 | ACCURACY: 0.8878 | F1 MACRO: 0.8625 | F1 MICRO: 0.8878
# EPOCH 7 | LOSS: 8.992109298706055 | ACCURACY: 0.898 | F1 MACRO: 0.8849 | F1 MICRO: 0.898
# EPOCH 8 | LOSS: 9.136101722717285 | ACCURACY: 0.9133 | F1 MACRO: 0.8984 | F1 MICRO: 0.9133
# EPOCH 9 | LOSS: 8.978387832641602 | ACCURACY: 0.8827 | F1 MACRO: 0.8555 | F1 MICRO: 0.8827
# EPOCH 10 | LOSS: 8.607481956481934 | ACCURACY: 0.8827 | F1 MACRO: 0.857 | F1 MICRO: 0.8827
# sentiment: ACCURACY 0.9133 | F1 MACRO 0.8984 | F1 MICRO 0.9133
#               precision    recall  f1-score   support
#
#     negative       0.84      0.88      0.86        59
#     positive       0.95      0.93      0.94       137
#
#     accuracy                           0.91       196
#    macro avg       0.89      0.90      0.90       196
# weighted avg       0.91      0.91      0.91       196
#
# --------------------------------------------------
# Iteration 135: Accuracy: 0.8812, F1 Micro: 0.8812, F1 Macro: 0.7344
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.78      0.64      0.70        11
#      neutral       0.90      1.00      0.95       181
#     positive       0.83      0.21      0.33        24
#
#     accuracy                           0.89       216
#    macro avg       0.84      0.61      0.66       216
# weighted avg       0.89      0.89      0.87       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.78      0.44      0.56        16
#      neutral       0.90      0.96      0.93       167
#     positive       0.72      0.64      0.68        33
#
#     accuracy                           0.87       216
#    macro avg       0.80      0.68      0.72       216
# weighted avg       0.86      0.87      0.86       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.57      0.67      0.62        12
#      neutral       0.86      0.89      0.88       152
#     positive       0.70      0.60      0.65        52
#
#     accuracy                           0.81       216
#    macro avg       0.71      0.72      0.71       216
# weighted avg       0.81      0.81      0.81       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.67      0.70      0.68        23
#      neutral       0.89      0.94      0.91       152
#     positive       0.84      0.63      0.72        41
#
#     accuracy                           0.86       216
#    macro avg       0.80      0.76      0.77       216
# weighted avg       0.86      0.86      0.85       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.69      0.69      0.69        13
#      neutral       0.96      0.97      0.97       186
#     positive       0.75      0.71      0.73        17
#
#     accuracy                           0.93       216
#    macro avg       0.80      0.79      0.79       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.90      0.64      0.75        14
#      neutral       0.93      1.00      0.96       185
#     positive       1.00      0.35      0.52        17
#
#     accuracy                           0.93       216
#    macro avg       0.94      0.67      0.74       216
# weighted avg       0.93      0.93      0.91       216
#
# Launching training on 2 GPUs.
# 543 543
# Nearest checkpoint: 540
# Threshold: 88749.890625
# Samples above threshold: 73
# Acquired samples: 73
# Sampling duration: 9.536682605743408 seconds
# New train size: 208
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.626819133758545 | ACCURACY: 0.7961 | F1 MACRO: 0.884 | F1 MICRO: 0.8855
# EPOCH 2 | LOSS: 3.234981060028076 | ACCURACY: 0.7984 | F1 MACRO: 0.8851 | F1 MICRO: 0.8867
# EPOCH 3 | LOSS: 2.85770583152771 | ACCURACY: 0.8244 | F1 MACRO: 0.8978 | F1 MICRO: 0.899
# EPOCH 4 | LOSS: 2.7796738147735596 | ACCURACY: 0.8363 | F1 MACRO: 0.9027 | F1 MICRO: 0.9043
# EPOCH 5 | LOSS: 2.8246192932128906 | ACCURACY: 0.8497 | F1 MACRO: 0.9085 | F1 MICRO: 0.9104
# EPOCH 6 | LOSS: 2.64823579788208 | ACCURACY: 0.875 | F1 MACRO: 0.9226 | F1 MICRO: 0.9245
# EPOCH 7 | LOSS: 2.520956039428711 | ACCURACY: 0.8988 | F1 MACRO: 0.9356 | F1 MICRO: 0.9381
# EPOCH 8 | LOSS: 2.4960410594940186 | ACCURACY: 0.91 | F1 MACRO: 0.9419 | F1 MICRO: 0.9444
# EPOCH 9 | LOSS: 2.3846988677978516 | ACCURACY: 0.9204 | F1 MACRO: 0.9482 | F1 MICRO: 0.9508
# EPOCH 10 | LOSS: 2.321460485458374 | ACCURACY: 0.9159 | F1 MACRO: 0.9441 | F1 MICRO: 0.9476
# aspect: ACCURACY 0.9204 | F1 MACRO 0.9482 | F1 MICRO 0.9508
#               precision    recall  f1-score   support
#
#         fuel       0.96      1.00      0.98       187
#      machine       0.91      0.99      0.95       175
#       others       0.86      0.89      0.87       158
#         part       0.91      0.97      0.94       158
#        price       0.96      0.98      0.97       192
#      service       0.95      1.00      0.97       191
#
#    micro avg       0.93      0.97      0.95      1061
#    macro avg       0.93      0.97      0.95      1061
# weighted avg       0.93      0.97      0.95      1061
#  samples avg       0.93      0.97      0.95      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 12.362960815429688 | ACCURACY: 0.8734 | F1 MACRO: 0.8526 | F1 MICRO: 0.8734
# EPOCH 2 | LOSS: 11.349143028259277 | ACCURACY: 0.8821 | F1 MACRO: 0.8721 | F1 MICRO: 0.8821
# EPOCH 3 | LOSS: 9.000503540039062 | ACCURACY: 0.9083 | F1 MACRO: 0.8988 | F1 MICRO: 0.9083
# EPOCH 4 | LOSS: 8.690373420715332 | ACCURACY: 0.9258 | F1 MACRO: 0.916 | F1 MICRO: 0.9258
# EPOCH 5 | LOSS: 7.955341339111328 | ACCURACY: 0.9214 | F1 MACRO: 0.9125 | F1 MICRO: 0.9214
# EPOCH 6 | LOSS: 8.020933151245117 | ACCURACY: 0.8952 | F1 MACRO: 0.8723 | F1 MICRO: 0.8952
# EPOCH 7 | LOSS: 7.52114200592041 | ACCURACY: 0.9127 | F1 MACRO: 0.9015 | F1 MICRO: 0.9127
# in second
# EPOCH 8 | LOSS: 6.956009387969971 | ACCURACY: 0.9039 | F1 MACRO: 0.8943 | F1 MICRO: 0.9039
# in second
# EPOCH 9 | LOSS: 6.948610305786133 | ACCURACY: 0.9214 | F1 MACRO: 0.9125 | F1 MICRO: 0.9214
# in second
# EPOCH 10 | LOSS: 6.763776779174805 | ACCURACY: 0.9214 | F1 MACRO: 0.9125 | F1 MICRO: 0.9214
# sentiment: ACCURACY 0.9258 | F1 MACRO 0.916 | F1 MICRO 0.9258
#               precision    recall  f1-score   support
#
#     negative       0.84      0.94      0.89        71
#     positive       0.97      0.92      0.94       158
#
#     accuracy                           0.93       229
#    macro avg       0.91      0.93      0.92       229
# weighted avg       0.93      0.93      0.93       229
#
# --------------------------------------------------
# Iteration 208: Accuracy: 0.912, F1 Micro: 0.912, F1 Macro: 0.8217
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.82      0.90        11
#      neutral       0.98      1.00      0.99       181
#     positive       0.95      0.88      0.91        24
#
#     accuracy                           0.98       216
#    macro avg       0.98      0.90      0.93       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.56      0.64        16
#      neutral       0.93      0.98      0.95       167
#     positive       0.85      0.70      0.77        33
#
#     accuracy                           0.91       216
#    macro avg       0.84      0.75      0.79       216
# weighted avg       0.90      0.91      0.90       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.41      0.75      0.53        12
#      neutral       0.87      0.85      0.86       152
#     positive       0.72      0.63      0.67        52
#
#     accuracy                           0.79       216
#    macro avg       0.67      0.74      0.69       216
# weighted avg       0.81      0.79      0.80       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.77      0.87      0.82        23
#      neutral       0.91      0.97      0.94       152
#     positive       0.97      0.68      0.80        41
#
#     accuracy                           0.90       216
#    macro avg       0.88      0.84      0.85       216
# weighted avg       0.91      0.90      0.90       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.62      0.70        13
#      neutral       0.96      0.98      0.97       186
#     positive       0.75      0.71      0.73        17
#
#     accuracy                           0.94       216
#    macro avg       0.84      0.77      0.80       216
# weighted avg       0.93      0.94      0.93       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.96      1.00      0.98       185
#     positive       0.91      0.59      0.71        17
#
#     accuracy                           0.96       216
#    macro avg       0.96      0.82      0.87       216
# weighted avg       0.96      0.96      0.95       216
#
# Launching training on 2 GPUs.
# 563 563
# Nearest checkpoint: 540
# Threshold: 88614.6875
# Samples above threshold: 66
# Acquired samples: 66
# Sampling duration: 11.079267501831055 seconds
# New train size: 274
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.2996530532836914 | ACCURACY: 0.7939 | F1 MACRO: 0.8825 | F1 MICRO: 0.8841
# EPOCH 2 | LOSS: 2.9453651905059814 | ACCURACY: 0.814 | F1 MACRO: 0.8935 | F1 MICRO: 0.8945
# EPOCH 3 | LOSS: 2.591803789138794 | ACCURACY: 0.8281 | F1 MACRO: 0.8999 | F1 MICRO: 0.9012
# EPOCH 4 | LOSS: 2.5562641620635986 | ACCURACY: 0.8438 | F1 MACRO: 0.9056 | F1 MICRO: 0.9075
# EPOCH 5 | LOSS: 2.609576463699341 | ACCURACY: 0.8869 | F1 MACRO: 0.9294 | F1 MICRO: 0.9313
# EPOCH 6 | LOSS: 2.3939740657806396 | ACCURACY: 0.9174 | F1 MACRO: 0.9469 | F1 MICRO: 0.949
# EPOCH 7 | LOSS: 2.2842535972595215 | ACCURACY: 0.9219 | F1 MACRO: 0.9485 | F1 MICRO: 0.9514
# EPOCH 8 | LOSS: 2.188847064971924 | ACCURACY: 0.9382 | F1 MACRO: 0.9596 | F1 MICRO: 0.9616
# EPOCH 9 | LOSS: 2.0776240825653076 | ACCURACY: 0.933 | F1 MACRO: 0.9562 | F1 MICRO: 0.9583
# EPOCH 10 | LOSS: 1.9991565942764282 | ACCURACY: 0.9271 | F1 MACRO: 0.9511 | F1 MICRO: 0.9542
# aspect: ACCURACY 0.9382 | F1 MACRO 0.9596 | F1 MICRO 0.9616
#               precision    recall  f1-score   support
#
#         fuel       0.97      1.00      0.99       187
#      machine       0.96      0.99      0.97       175
#       others       0.87      0.94      0.90       158
#         part       0.92      0.96      0.94       158
#        price       0.98      0.98      0.98       192
#      service       0.96      1.00      0.98       191
#
#    micro avg       0.94      0.98      0.96      1061
#    macro avg       0.94      0.98      0.96      1061
# weighted avg       0.95      0.98      0.96      1061
#  samples avg       0.95      0.98      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 9.702418327331543 | ACCURACY: 0.8475 | F1 MACRO: 0.8107 | F1 MICRO: 0.8475
# EPOCH 2 | LOSS: 8.123779296875 | ACCURACY: 0.8644 | F1 MACRO: 0.8575 | F1 MICRO: 0.8644
# EPOCH 3 | LOSS: 6.91239070892334 | ACCURACY: 0.928 | F1 MACRO: 0.9212 | F1 MICRO: 0.928
# EPOCH 4 | LOSS: 6.441197872161865 | ACCURACY: 0.9322 | F1 MACRO: 0.9244 | F1 MICRO: 0.9322
# EPOCH 5 | LOSS: 6.048207759857178 | ACCURACY: 0.928 | F1 MACRO: 0.9183 | F1 MICRO: 0.928
# EPOCH 6 | LOSS: 5.895489692687988 | ACCURACY: 0.9364 | F1 MACRO: 0.9284 | F1 MICRO: 0.9364
# EPOCH 7 | LOSS: 5.632130146026611 | ACCURACY: 0.9322 | F1 MACRO: 0.9234 | F1 MICRO: 0.9322
# EPOCH 8 | LOSS: 5.45456600189209 | ACCURACY: 0.9322 | F1 MACRO: 0.9218 | F1 MICRO: 0.9322
# EPOCH 9 | LOSS: 5.650423526763916 | ACCURACY: 0.9364 | F1 MACRO: 0.9297 | F1 MICRO: 0.9364
# EPOCH 10 | LOSS: 5.408814430236816 | ACCURACY: 0.9195 | F1 MACRO: 0.9075 | F1 MICRO: 0.9195
# sentiment: ACCURACY 0.9364 | F1 MACRO 0.9297 | F1 MICRO 0.9364
#               precision    recall  f1-score   support
#
#     negative       0.86      0.96      0.91        77
#     positive       0.98      0.92      0.95       159
#
#     accuracy                           0.94       236
#    macro avg       0.92      0.94      0.93       236
# weighted avg       0.94      0.94      0.94       236
#
# --------------------------------------------------
# Iteration 274: Accuracy: 0.9329, F1 Micro: 0.9329, F1 Macro: 0.8689
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.82      0.90        11
#      neutral       0.98      1.00      0.99       181
#     positive       0.95      0.88      0.91        24
#
#     accuracy                           0.98       216
#    macro avg       0.98      0.90      0.93       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.75      0.77        16
#      neutral       0.95      0.98      0.97       167
#     positive       0.86      0.76      0.81        33
#
#     accuracy                           0.93       216
#    macro avg       0.87      0.83      0.85       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.75      0.75        12
#      neutral       0.88      0.94      0.91       152
#     positive       0.83      0.65      0.73        52
#
#     accuracy                           0.86       216
#    macro avg       0.82      0.78      0.80       216
# weighted avg       0.86      0.86      0.86       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.79      0.96      0.86        23
#      neutral       0.92      0.95      0.94       152
#     positive       0.90      0.68      0.78        41
#
#     accuracy                           0.90       216
#    macro avg       0.87      0.86      0.86       216
# weighted avg       0.91      0.90      0.90       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.85      0.85        13
#      neutral       0.98      0.98      0.98       186
#     positive       0.81      0.76      0.79        17
#
#     accuracy                           0.96       216
#    macro avg       0.88      0.86      0.87       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.97      1.00      0.98       185
#     positive       0.92      0.71      0.80        17
#
#     accuracy                           0.97       216
#    macro avg       0.96      0.85      0.90       216
# weighted avg       0.97      0.97      0.97       216
#
# Launching training on 2 GPUs.
# 537 537
# Nearest checkpoint: 540
# Threshold: 88409.8515625
# Samples above threshold: 59
# Acquired samples: 59
# Sampling duration: 12.331432580947876 seconds
# New train size: 333
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.3776772022247314 | ACCURACY: 0.7917 | F1 MACRO: 0.8818 | F1 MICRO: 0.8833
# EPOCH 2 | LOSS: 2.894634246826172 | ACCURACY: 0.8185 | F1 MACRO: 0.8942 | F1 MICRO: 0.8955
# EPOCH 3 | LOSS: 2.603482723236084 | ACCURACY: 0.8415 | F1 MACRO: 0.906 | F1 MICRO: 0.9072
# EPOCH 4 | LOSS: 2.6593384742736816 | ACCURACY: 0.8743 | F1 MACRO: 0.9219 | F1 MICRO: 0.9242
# EPOCH 5 | LOSS: 2.4974682331085205 | ACCURACY: 0.9219 | F1 MACRO: 0.9496 | F1 MICRO: 0.9518
# EPOCH 6 | LOSS: 2.4302902221679688 | ACCURACY: 0.9286 | F1 MACRO: 0.9529 | F1 MICRO: 0.9555
# EPOCH 7 | LOSS: 2.2941808700561523 | ACCURACY: 0.9182 | F1 MACRO: 0.9418 | F1 MICRO: 0.9484
# EPOCH 8 | LOSS: 2.131382465362549 | ACCURACY: 0.9353 | F1 MACRO: 0.9564 | F1 MICRO: 0.9594
# EPOCH 9 | LOSS: 2.041783094406128 | ACCURACY: 0.9435 | F1 MACRO: 0.9629 | F1 MICRO: 0.9647
# EPOCH 10 | LOSS: 1.9816778898239136 | ACCURACY: 0.9382 | F1 MACRO: 0.9588 | F1 MICRO: 0.9613
# aspect: ACCURACY 0.9435 | F1 MACRO 0.9629 | F1 MICRO 0.9647
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.95      0.98      0.97       175
#       others       0.88      0.94      0.91       158
#         part       0.93      0.97      0.95       158
#        price       0.97      0.98      0.98       192
#      service       0.98      0.99      0.99       191
#
#    micro avg       0.95      0.98      0.96      1061
#    macro avg       0.95      0.98      0.96      1061
# weighted avg       0.95      0.98      0.96      1061
#  samples avg       0.95      0.98      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 8.448637962341309 | ACCURACY: 0.8843 | F1 MACRO: 0.8684 | F1 MICRO: 0.8843
# EPOCH 2 | LOSS: 7.394766807556152 | ACCURACY: 0.9215 | F1 MACRO: 0.9145 | F1 MICRO: 0.9215
# EPOCH 3 | LOSS: 5.966392993927002 | ACCURACY: 0.9298 | F1 MACRO: 0.9209 | F1 MICRO: 0.9298
# EPOCH 4 | LOSS: 5.668492794036865 | ACCURACY: 0.9091 | F1 MACRO: 0.9013 | F1 MICRO: 0.9091
# EPOCH 5 | LOSS: 5.301542282104492 | ACCURACY: 0.9174 | F1 MACRO: 0.9093 | F1 MICRO: 0.9174
# EPOCH 6 | LOSS: 4.993969440460205 | ACCURACY: 0.9215 | F1 MACRO: 0.9136 | F1 MICRO: 0.9215
# in second
# EPOCH 7 | LOSS: 4.755323886871338 | ACCURACY: 0.9298 | F1 MACRO: 0.9231 | F1 MICRO: 0.9298
# in second
# EPOCH 8 | LOSS: 4.610458850860596 | ACCURACY: 0.9298 | F1 MACRO: 0.9231 | F1 MICRO: 0.9298
# in second
# EPOCH 9 | LOSS: 4.601316928863525 | ACCURACY: 0.9298 | F1 MACRO: 0.9231 | F1 MICRO: 0.9298
# in second
# EPOCH 10 | LOSS: 4.553536415100098 | ACCURACY: 0.9298 | F1 MACRO: 0.9231 | F1 MICRO: 0.9298
# sentiment: ACCURACY 0.9298 | F1 MACRO 0.9209 | F1 MICRO 0.9298
#               precision    recall  f1-score   support
#
#     negative       0.88      0.91      0.89        79
#     positive       0.96      0.94      0.95       163
#
#     accuracy                           0.93       242
#    macro avg       0.92      0.93      0.92       242
# weighted avg       0.93      0.93      0.93       242
#
# --------------------------------------------------
# Iteration 333: Accuracy: 0.9344, F1 Micro: 0.9344, F1 Macro: 0.8669
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.82      0.90        11
#      neutral       0.98      1.00      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.98       216
#    macro avg       0.98      0.91      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.77      0.62      0.69        16
#      neutral       0.96      0.96      0.96       167
#     positive       0.81      0.88      0.84        33
#
#     accuracy                           0.93       216
#    macro avg       0.85      0.82      0.83       216
# weighted avg       0.93      0.93      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.62      0.83      0.71        12
#      neutral       0.90      0.95      0.92       152
#     positive       0.85      0.65      0.74        52
#
#     accuracy                           0.87       216
#    macro avg       0.79      0.81      0.79       216
# weighted avg       0.87      0.87      0.87       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.79      0.83      0.81        23
#      neutral       0.92      0.97      0.95       152
#     positive       0.85      0.68      0.76        41
#
#     accuracy                           0.90       216
#    macro avg       0.85      0.83      0.84       216
# weighted avg       0.90      0.90      0.89       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.77      0.83        13
#      neutral       0.97      0.98      0.97       186
#     positive       0.76      0.76      0.76        17
#
#     accuracy                           0.95       216
#    macro avg       0.88      0.84      0.86       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.98      1.00      0.99       185
#     positive       0.94      0.88      0.91        17
#
#     accuracy                           0.98       216
#    macro avg       0.97      0.91      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Launching training on 2 GPUs.
# 493 493
# Nearest checkpoint: 540
# Threshold: 88361.796875
# Samples above threshold: 54
# Acquired samples: 54
# Sampling duration: 13.576059818267822 seconds
# New train size: 387
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.3106133937835693 | ACCURACY: 0.7969 | F1 MACRO: 0.8836 | F1 MICRO: 0.8853
# EPOCH 2 | LOSS: 2.746107816696167 | ACCURACY: 0.8356 | F1 MACRO: 0.9038 | F1 MICRO: 0.9049
# EPOCH 3 | LOSS: 2.5744383335113525 | ACCURACY: 0.8616 | F1 MACRO: 0.9168 | F1 MICRO: 0.9177
# EPOCH 4 | LOSS: 2.489266872406006 | ACCURACY: 0.9234 | F1 MACRO: 0.9518 | F1 MICRO: 0.9531
# EPOCH 5 | LOSS: 2.3340983390808105 | ACCURACY: 0.936 | F1 MACRO: 0.9582 | F1 MICRO: 0.9601
# EPOCH 6 | LOSS: 2.230510711669922 | ACCURACY: 0.9449 | F1 MACRO: 0.9646 | F1 MICRO: 0.9658
# EPOCH 7 | LOSS: 2.0914883613586426 | ACCURACY: 0.9494 | F1 MACRO: 0.9673 | F1 MICRO: 0.9685
# EPOCH 8 | LOSS: 1.9768019914627075 | ACCURACY: 0.9464 | F1 MACRO: 0.9645 | F1 MICRO: 0.9663
# EPOCH 9 | LOSS: 1.9013389348983765 | ACCURACY: 0.9375 | F1 MACRO: 0.9578 | F1 MICRO: 0.9606
# EPOCH 10 | LOSS: 1.8630917072296143 | ACCURACY: 0.9501 | F1 MACRO: 0.9675 | F1 MICRO: 0.9689
# aspect: ACCURACY 0.9501 | F1 MACRO 0.9675 | F1 MICRO 0.9689
#               precision    recall  f1-score   support
#
#         fuel       0.98      0.99      0.99       187
#      machine       0.94      0.97      0.96       175
#       others       0.90      0.94      0.92       158
#         part       0.93      1.00      0.97       158
#        price       0.97      0.98      0.98       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.95      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.95      0.98      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 7.4766526222229 | ACCURACY: 0.8726 | F1 MACRO: 0.847 | F1 MICRO: 0.8726
# EPOCH 2 | LOSS: 6.620501518249512 | ACCURACY: 0.9228 | F1 MACRO: 0.9139 | F1 MICRO: 0.9228
# EPOCH 3 | LOSS: 5.101081371307373 | ACCURACY: 0.9228 | F1 MACRO: 0.9139 | F1 MICRO: 0.9228
# EPOCH 4 | LOSS: 4.553115367889404 | ACCURACY: 0.9305 | F1 MACRO: 0.9225 | F1 MICRO: 0.9305
# EPOCH 5 | LOSS: 4.477051734924316 | ACCURACY: 0.9228 | F1 MACRO: 0.9096 | F1 MICRO: 0.9228
# EPOCH 6 | LOSS: 4.250245094299316 | ACCURACY: 0.9305 | F1 MACRO: 0.9212 | F1 MICRO: 0.9305
# EPOCH 7 | LOSS: 4.282261371612549 | ACCURACY: 0.9228 | F1 MACRO: 0.9144 | F1 MICRO: 0.9228
# EPOCH 8 | LOSS: 4.20591926574707 | ACCURACY: 0.9382 | F1 MACRO: 0.9291 | F1 MICRO: 0.9382
# EPOCH 9 | LOSS: 4.164430618286133 | ACCURACY: 0.9344 | F1 MACRO: 0.9258 | F1 MICRO: 0.9344
# EPOCH 10 | LOSS: 3.9940762519836426 | ACCURACY: 0.9189 | F1 MACRO: 0.9066 | F1 MICRO: 0.9189
# sentiment: ACCURACY 0.9382 | F1 MACRO 0.9291 | F1 MICRO 0.9382
#               precision    recall  f1-score   support
#
#     negative       0.88      0.93      0.90        81
#     positive       0.97      0.94      0.95       178
#
#     accuracy                           0.94       259
#    macro avg       0.92      0.93      0.93       259
# weighted avg       0.94      0.94      0.94       259
#
# --------------------------------------------------
# Iteration 387: Accuracy: 0.9321, F1 Micro: 0.9321, F1 Macro: 0.8623
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.92      0.92      0.92        24
#
#     accuracy                           0.98       216
#    macro avg       0.97      0.94      0.95       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.73      0.69      0.71        16
#      neutral       0.95      0.95      0.95       167
#     positive       0.74      0.76      0.75        33
#
#     accuracy                           0.90       216
#    macro avg       0.81      0.80      0.80       216
# weighted avg       0.90      0.90      0.90       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.50      0.83      0.62        12
#      neutral       0.93      0.89      0.91       152
#     positive       0.80      0.75      0.77        52
#
#     accuracy                           0.86       216
#    macro avg       0.74      0.83      0.77       216
# weighted avg       0.87      0.86      0.86       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.81      0.96      0.88        23
#      neutral       0.94      0.99      0.96       152
#     positive       0.93      0.66      0.77        41
#
#     accuracy                           0.92       216
#    macro avg       0.89      0.87      0.87       216
# weighted avg       0.92      0.92      0.92       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.71      0.77      0.74        13
#      neutral       0.97      0.97      0.97       186
#     positive       0.75      0.71      0.73        17
#
#     accuracy                           0.94       216
#    macro avg       0.81      0.82      0.81       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.99      1.00      1.00       185
#     positive       0.94      1.00      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.95      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 462 462
# Nearest checkpoint: 540
# Threshold: 88411.1875
# Samples above threshold: 48
# Acquired samples: 48
# Sampling duration: 14.427777528762817 seconds
# New train size: 435
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.2139437198638916 | ACCURACY: 0.7857 | F1 MACRO: 0.8721 | F1 MICRO: 0.8768
# EPOCH 2 | LOSS: 2.6250147819519043 | ACCURACY: 0.8371 | F1 MACRO: 0.9047 | F1 MICRO: 0.9056
# EPOCH 3 | LOSS: 2.4893851280212402 | ACCURACY: 0.8832 | F1 MACRO: 0.9283 | F1 MICRO: 0.9296
# EPOCH 4 | LOSS: 2.3842577934265137 | ACCURACY: 0.9234 | F1 MACRO: 0.9502 | F1 MICRO: 0.9526
# EPOCH 5 | LOSS: 2.2086260318756104 | ACCURACY: 0.9375 | F1 MACRO: 0.9593 | F1 MICRO: 0.9613
# EPOCH 6 | LOSS: 2.1148526668548584 | ACCURACY: 0.9449 | F1 MACRO: 0.964 | F1 MICRO: 0.9657
# EPOCH 7 | LOSS: 2.001727342605591 | ACCURACY: 0.942 | F1 MACRO: 0.9617 | F1 MICRO: 0.9638
# EPOCH 8 | LOSS: 1.8831502199172974 | ACCURACY: 0.9464 | F1 MACRO: 0.9647 | F1 MICRO: 0.9665
# EPOCH 9 | LOSS: 1.8202797174453735 | ACCURACY: 0.9531 | F1 MACRO: 0.9694 | F1 MICRO: 0.9707
# EPOCH 10 | LOSS: 1.7399463653564453 | ACCURACY: 0.9427 | F1 MACRO: 0.9619 | F1 MICRO: 0.9639
# aspect: ACCURACY 0.9531 | F1 MACRO 0.9694 | F1 MICRO 0.9707
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.95      0.97      0.96       175
#       others       0.91      0.97      0.94       158
#         part       0.94      0.97      0.96       158
#        price       0.97      0.98      0.98       192
#      service       0.99      1.00      0.99       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.96      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.578511714935303 | ACCURACY: 0.8947 | F1 MACRO: 0.8746 | F1 MICRO: 0.8947
# EPOCH 2 | LOSS: 5.443141460418701 | ACCURACY: 0.919 | F1 MACRO: 0.9069 | F1 MICRO: 0.919
# EPOCH 3 | LOSS: 4.530602931976318 | ACCURACY: 0.919 | F1 MACRO: 0.9113 | F1 MICRO: 0.919
# EPOCH 4 | LOSS: 4.270183086395264 | ACCURACY: 0.9393 | F1 MACRO: 0.9304 | F1 MICRO: 0.9393
# EPOCH 5 | LOSS: 4.033109664916992 | ACCURACY: 0.9433 | F1 MACRO: 0.9369 | F1 MICRO: 0.9433
# EPOCH 6 | LOSS: 3.8681602478027344 | ACCURACY: 0.9433 | F1 MACRO: 0.9372 | F1 MICRO: 0.9433
# EPOCH 7 | LOSS: 3.774118661880493 | ACCURACY: 0.9231 | F1 MACRO: 0.9107 | F1 MICRO: 0.9231
# EPOCH 8 | LOSS: 3.519808530807495 | ACCURACY: 0.9271 | F1 MACRO: 0.9197 | F1 MICRO: 0.9271
# EPOCH 9 | LOSS: 3.594442367553711 | ACCURACY: 0.9352 | F1 MACRO: 0.925 | F1 MICRO: 0.9352
# in second
# EPOCH 10 | LOSS: 3.4410691261291504 | ACCURACY: 0.9352 | F1 MACRO: 0.9278 | F1 MICRO: 0.9352
# sentiment: ACCURACY 0.9433 | F1 MACRO 0.9372 | F1 MICRO 0.9433
#               precision    recall  f1-score   support
#
#     negative       0.87      0.97      0.92        80
#     positive       0.99      0.93      0.96       167
#
#     accuracy                           0.94       247
#    macro avg       0.93      0.95      0.94       247
# weighted avg       0.95      0.94      0.94       247
#
# --------------------------------------------------
# Iteration 435: Accuracy: 0.9452, F1 Micro: 0.9452, F1 Macro: 0.8894
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.92      1.00      0.96        11
#      neutral       0.99      1.00      0.99       181
#     positive       1.00      0.88      0.93        24
#
#     accuracy                           0.99       216
#    macro avg       0.97      0.96      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.75      0.80        16
#      neutral       0.95      0.97      0.96       167
#     positive       0.84      0.82      0.83        33
#
#     accuracy                           0.93       216
#    macro avg       0.88      0.85      0.86       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.47      0.75      0.58        12
#      neutral       0.92      0.95      0.94       152
#     positive       0.92      0.69      0.79        52
#
#     accuracy                           0.88       216
#    macro avg       0.77      0.80      0.77       216
# weighted avg       0.89      0.88      0.88       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.77      1.00      0.87        23
#      neutral       0.95      0.97      0.96       152
#     positive       0.94      0.71      0.81        41
#
#     accuracy                           0.93       216
#    macro avg       0.89      0.89      0.88       216
# weighted avg       0.93      0.93      0.92       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.85      0.88        13
#      neutral       0.97      0.98      0.98       186
#     positive       0.76      0.76      0.76        17
#
#     accuracy                           0.95       216
#    macro avg       0.88      0.86      0.87       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        14
#      neutral       0.99      1.00      1.00       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           1.00       216
#    macro avg       1.00      0.98      0.99       216
# weighted avg       1.00      1.00      1.00       216
#
# Launching training on 2 GPUs.
# 412 412
# Nearest checkpoint: 540
# Threshold: 88278.546875
# Samples above threshold: 43
# Acquired samples: 43
# Sampling duration: 15.285361766815186 seconds
# New train size: 478
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.196280002593994 | ACCURACY: 0.7946 | F1 MACRO: 0.8834 | F1 MICRO: 0.8849
# EPOCH 2 | LOSS: 2.584106922149658 | ACCURACY: 0.8371 | F1 MACRO: 0.902 | F1 MICRO: 0.9042
# EPOCH 3 | LOSS: 2.5092034339904785 | ACCURACY: 0.8988 | F1 MACRO: 0.9378 | F1 MICRO: 0.9388
# EPOCH 4 | LOSS: 2.3612968921661377 | ACCURACY: 0.9338 | F1 MACRO: 0.957 | F1 MICRO: 0.9587
# EPOCH 5 | LOSS: 2.197967529296875 | ACCURACY: 0.9457 | F1 MACRO: 0.965 | F1 MICRO: 0.9663
# EPOCH 6 | LOSS: 2.052767038345337 | ACCURACY: 0.9516 | F1 MACRO: 0.9683 | F1 MICRO: 0.97
# EPOCH 7 | LOSS: 1.9405947923660278 | ACCURACY: 0.9509 | F1 MACRO: 0.9685 | F1 MICRO: 0.9696
# EPOCH 8 | LOSS: 1.88950777053833 | ACCURACY: 0.9546 | F1 MACRO: 0.9705 | F1 MICRO: 0.9717
# EPOCH 9 | LOSS: 1.8066743612289429 | ACCURACY: 0.9494 | F1 MACRO: 0.9668 | F1 MICRO: 0.9683
# EPOCH 10 | LOSS: 1.76914381980896 | ACCURACY: 0.9457 | F1 MACRO: 0.9642 | F1 MICRO: 0.966
# aspect: ACCURACY 0.9546 | F1 MACRO 0.9705 | F1 MICRO 0.9717
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.94      1.00      0.97       175
#       others       0.92      0.96      0.93       158
#         part       0.95      0.98      0.96       158
#        price       0.97      0.98      0.97       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.96      0.99      0.97      1061
#    macro avg       0.96      0.99      0.97      1061
# weighted avg       0.96      0.99      0.97      1061
#  samples avg       0.96      0.99      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.0896782875061035 | ACCURACY: 0.9231 | F1 MACRO: 0.908 | F1 MICRO: 0.9231
# EPOCH 2 | LOSS: 4.915279865264893 | ACCURACY: 0.8947 | F1 MACRO: 0.8704 | F1 MICRO: 0.8947
# EPOCH 3 | LOSS: 4.347693920135498 | ACCURACY: 0.9595 | F1 MACRO: 0.9538 | F1 MICRO: 0.9595
# EPOCH 4 | LOSS: 4.002007484436035 | ACCURACY: 0.9555 | F1 MACRO: 0.9493 | F1 MICRO: 0.9555
# EPOCH 5 | LOSS: 3.7362077236175537 | ACCURACY: 0.9231 | F1 MACRO: 0.908 | F1 MICRO: 0.9231
# EPOCH 6 | LOSS: 3.615269660949707 | ACCURACY: 0.9433 | F1 MACRO: 0.9365 | F1 MICRO: 0.9433
# in second
# EPOCH 7 | LOSS: 3.400578260421753 | ACCURACY: 0.9393 | F1 MACRO: 0.9329 | F1 MICRO: 0.9393
# in second
# EPOCH 8 | LOSS: 3.398073196411133 | ACCURACY: 0.9393 | F1 MACRO: 0.9329 | F1 MICRO: 0.9393
# in second
# EPOCH 9 | LOSS: 3.30732798576355 | ACCURACY: 0.9433 | F1 MACRO: 0.9372 | F1 MICRO: 0.9433
# in second
# EPOCH 10 | LOSS: 3.3035635948181152 | ACCURACY: 0.9433 | F1 MACRO: 0.9372 | F1 MICRO: 0.9433
# sentiment: ACCURACY 0.9595 | F1 MACRO 0.9538 | F1 MICRO 0.9595
#               precision    recall  f1-score   support
#
#     negative       0.94      0.94      0.94        80
#     positive       0.97      0.97      0.97       167
#
#     accuracy                           0.96       247
#    macro avg       0.95      0.95      0.95       247
# weighted avg       0.96      0.96      0.96       247
#
# --------------------------------------------------
# Iteration 478: Accuracy: 0.9437, F1 Micro: 0.9437, F1 Macro: 0.8884
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.90      0.82      0.86        11
#      neutral       0.98      0.99      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.98       216
#    macro avg       0.95      0.91      0.93       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.81      0.81      0.81        16
#      neutral       0.95      0.97      0.96       167
#     positive       0.87      0.79      0.83        33
#
#     accuracy                           0.93       216
#    macro avg       0.88      0.86      0.87       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.62      0.83      0.71        12
#      neutral       0.92      0.92      0.92       152
#     positive       0.85      0.79      0.82        52
#
#     accuracy                           0.88       216
#    macro avg       0.80      0.85      0.82       216
# weighted avg       0.89      0.88      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.96      0.90        23
#      neutral       0.95      0.97      0.96       152
#     positive       0.91      0.76      0.83        41
#
#     accuracy                           0.93       216
#    macro avg       0.90      0.90      0.90       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.85      0.85        13
#      neutral       0.97      0.98      0.98       186
#     positive       0.81      0.76      0.79        17
#
#     accuracy                           0.95       216
#    macro avg       0.88      0.86      0.87       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.99      1.00      0.99       185
#     positive       0.94      0.94      0.94        17
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.93      0.95       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 375 375
# Nearest checkpoint: 540
# Threshold: 88356.2890625
# Samples above threshold: 39
# Acquired samples: 39
# Sampling duration: 16.001790046691895 seconds
# New train size: 517
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.2179932594299316 | ACCURACY: 0.7954 | F1 MACRO: 0.8838 | F1 MICRO: 0.8853
# EPOCH 2 | LOSS: 2.6448214054107666 | ACCURACY: 0.8519 | F1 MACRO: 0.9115 | F1 MICRO: 0.9125
# EPOCH 3 | LOSS: 2.525291919708252 | ACCURACY: 0.9196 | F1 MACRO: 0.9491 | F1 MICRO: 0.9507
# EPOCH 4 | LOSS: 2.3650805950164795 | ACCURACY: 0.9382 | F1 MACRO: 0.9601 | F1 MICRO: 0.9616
# EPOCH 5 | LOSS: 2.201735496520996 | ACCURACY: 0.9457 | F1 MACRO: 0.965 | F1 MICRO: 0.9663
# EPOCH 6 | LOSS: 2.0309598445892334 | ACCURACY: 0.9494 | F1 MACRO: 0.967 | F1 MICRO: 0.9684
# EPOCH 7 | LOSS: 1.9548555612564087 | ACCURACY: 0.9501 | F1 MACRO: 0.9675 | F1 MICRO: 0.9689
# EPOCH 8 | LOSS: 1.8454444408416748 | ACCURACY: 0.9583 | F1 MACRO: 0.972 | F1 MICRO: 0.9738
# EPOCH 9 | LOSS: 1.8102442026138306 | ACCURACY: 0.9561 | F1 MACRO: 0.9708 | F1 MICRO: 0.9725
# ...
# weighted avg       0.96      0.99      0.97      1061
#  samples avg       0.96      0.99      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.4893102645874023 | ACCURACY: 0.8689 | F1 MACRO: 0.8512 | F1 MICRO: 0.8689
# EPOCH 2 | LOSS: 3.030756950378418 | ACCURACY: 0.9344 | F1 MACRO: 0.927 | F1 MICRO: 0.9344
# EPOCH 3 | LOSS: 2.372868061065674 | ACCURACY: 0.9303 | F1 MACRO: 0.9235 | F1 MICRO: 0.9303
# EPOCH 4 | LOSS: 2.214553117752075 | ACCURACY: 0.9385 | F1 MACRO: 0.9328 | F1 MICRO: 0.9385
# EPOCH 5 | LOSS: 2.106222152709961 | ACCURACY: 0.9344 | F1 MACRO: 0.9261 | F1 MICRO: 0.9344
# EPOCH 6 | LOSS: 1.9795408248901367 | ACCURACY: 0.9262 | F1 MACRO: 0.9196 | F1 MICRO: 0.9262
# EPOCH 7 | LOSS: 2.0455634593963623 | ACCURACY: 0.9344 | F1 MACRO: 0.9282 | F1 MICRO: 0.9344
# in second
# EPOCH 8 | LOSS: 1.8749366998672485 | ACCURACY: 0.9262 | F1 MACRO: 0.9196 | F1 MICRO: 0.9262
# in second
# EPOCH 9 | LOSS: 1.8201353549957275 | ACCURACY: 0.9262 | F1 MACRO: 0.9196 | F1 MICRO: 0.9262
# in second
# EPOCH 10 | LOSS: 1.786377191543579 | ACCURACY: 0.9303 | F1 MACRO: 0.9243 | F1 MICRO: 0.9303
# sentiment: ACCURACY 0.9385 | F1 MACRO 0.9328 | F1 MICRO 0.9385
#               precision    recall  f1-score   support
#
#     negative       0.86      0.98      0.91        81
#     positive       0.99      0.92      0.95       163
#
#     accuracy                           0.94       244
#    macro avg       0.92      0.95      0.93       244
# weighted avg       0.94      0.94      0.94       244
#
# --------------------------------------------------
# Iteration 831: Accuracy: 0.9437, F1 Micro: 0.9437, F1 Macro: 0.882
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.92      1.00      0.96        11
#      neutral       0.99      1.00      0.99       181
#     positive       1.00      0.88      0.93        24
#
#     accuracy                           0.99       216
#    macro avg       0.97      0.96      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.75      0.77        16
#      neutral       0.93      1.00      0.97       167
#     positive       0.95      0.64      0.76        33
#
#     accuracy                           0.93       216
#    macro avg       0.90      0.80      0.83       216
# weighted avg       0.93      0.93      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.45      0.75      0.56        12
#      neutral       0.92      0.94      0.93       152
#     positive       0.85      0.67      0.75        52
#
#     accuracy                           0.87       216
#    macro avg       0.74      0.79      0.75       216
# weighted avg       0.88      0.87      0.87       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.85      1.00      0.92        23
#      neutral       0.95      0.99      0.97       152
#     positive       1.00      0.73      0.85        41
#
#     accuracy                           0.94       216
#    macro avg       0.93      0.91      0.91       216
# weighted avg       0.95      0.94      0.94       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.85      0.85        13
#      neutral       0.98      0.97      0.98       186
#     positive       0.70      0.82      0.76        17
#
#     accuracy                           0.95       216
#    macro avg       0.84      0.88      0.86       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.99      1.00      0.99       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.96      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 32 32
# Nearest checkpoint: 864
# Threshold: 88271.265625
# Samples above threshold: 4
# Acquired samples: 25
# Sampling duration: 20.91715168952942 seconds
# New train size: 856
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.925410032272339 | ACCURACY: 0.8363 | F1 MACRO: 0.9032 | F1 MICRO: 0.9048
# EPOCH 2 | LOSS: 2.4202044010162354 | ACCURACY: 0.9308 | F1 MACRO: 0.9554 | F1 MICRO: 0.9571
# EPOCH 3 | LOSS: 2.2176427841186523 | ACCURACY: 0.9494 | F1 MACRO: 0.9673 | F1 MICRO: 0.9685
# EPOCH 4 | LOSS: 2.0027990341186523 | ACCURACY: 0.9554 | F1 MACRO: 0.9705 | F1 MICRO: 0.9719
# EPOCH 5 | LOSS: 1.8457233905792236 | ACCURACY: 0.9516 | F1 MACRO: 0.9676 | F1 MICRO: 0.9696
# EPOCH 6 | LOSS: 1.7673301696777344 | ACCURACY: 0.9583 | F1 MACRO: 0.9722 | F1 MICRO: 0.9737
# EPOCH 7 | LOSS: 1.6937651634216309 | ACCURACY: 0.9554 | F1 MACRO: 0.9703 | F1 MICRO: 0.972
# EPOCH 8 | LOSS: 1.6599804162979126 | ACCURACY: 0.9576 | F1 MACRO: 0.9712 | F1 MICRO: 0.9732
# EPOCH 9 | LOSS: 1.5836615562438965 | ACCURACY: 0.9598 | F1 MACRO: 0.973 | F1 MICRO: 0.9747
# EPOCH 10 | LOSS: 1.5838662385940552 | ACCURACY: 0.9568 | F1 MACRO: 0.9709 | F1 MICRO: 0.9727
# aspect: ACCURACY 0.9598 | F1 MACRO 0.973 | F1 MICRO 0.9747
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.96      0.97      0.97       175
#       others       0.91      0.93      0.92       158
#         part       0.96      0.97      0.97       158
#        price       0.99      0.99      0.99       192
#      service       1.00      1.00      1.00       191
#
#    micro avg       0.97      0.98      0.97      1061
#    macro avg       0.97      0.98      0.97      1061
# weighted avg       0.97      0.98      0.97      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.7153069972991943 | ACCURACY: 0.8652 | F1 MACRO: 0.8549 | F1 MICRO: 0.8652
# EPOCH 2 | LOSS: 3.056772232055664 | ACCURACY: 0.8839 | F1 MACRO: 0.8748 | F1 MICRO: 0.8839
# EPOCH 3 | LOSS: 2.4643161296844482 | ACCURACY: 0.9326 | F1 MACRO: 0.9208 | F1 MICRO: 0.9326
# EPOCH 4 | LOSS: 2.324028491973877 | ACCURACY: 0.9139 | F1 MACRO: 0.9049 | F1 MICRO: 0.9139
# EPOCH 5 | LOSS: 2.23009991645813 | ACCURACY: 0.9101 | F1 MACRO: 0.901 | F1 MICRO: 0.9101
# EPOCH 6 | LOSS: 2.181535005569458 | ACCURACY: 0.9288 | F1 MACRO: 0.9178 | F1 MICRO: 0.9288
# in second
# EPOCH 7 | LOSS: 2.009505033493042 | ACCURACY: 0.9251 | F1 MACRO: 0.9152 | F1 MICRO: 0.9251
# in second
# EPOCH 8 | LOSS: 1.9327894449234009 | ACCURACY: 0.9288 | F1 MACRO: 0.9197 | F1 MICRO: 0.9288
# in second
# EPOCH 9 | LOSS: 1.9320456981658936 | ACCURACY: 0.9251 | F1 MACRO: 0.9152 | F1 MICRO: 0.9251
# in second
# EPOCH 10 | LOSS: 1.9351389408111572 | ACCURACY: 0.9213 | F1 MACRO: 0.9118 | F1 MICRO: 0.9213
# sentiment: ACCURACY 0.9326 | F1 MACRO 0.9208 | F1 MICRO 0.9326
#               precision    recall  f1-score   support
#
#     negative       0.90      0.88      0.89        83
#     positive       0.95      0.96      0.95       184
#
#     accuracy                           0.93       267
#    macro avg       0.92      0.92      0.92       267
# weighted avg       0.93      0.93      0.93       267
#
# --------------------------------------------------
# Iteration 856: Accuracy: 0.9498, F1 Micro: 0.9498, F1 Macro: 0.8943
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.92      0.92      0.92        24
#
#     accuracy                           0.98       216
#    macro avg       0.97      0.94      0.95       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.75      0.80        16
#      neutral       0.97      0.97      0.97       167
#     positive       0.83      0.88      0.85        33
#
#     accuracy                           0.94       216
#    macro avg       0.89      0.87      0.87       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.60      0.75      0.67        12
#      neutral       0.92      0.91      0.92       152
#     positive       0.82      0.79      0.80        52
#
#     accuracy                           0.88       216
#    macro avg       0.78      0.82      0.80       216
# weighted avg       0.88      0.88      0.88       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.81      0.91      0.86        23
#      neutral       0.98      0.98      0.98       152
#     positive       0.92      0.85      0.89        41
#
#     accuracy                           0.95       216
#    macro avg       0.90      0.92      0.91       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.79      0.85      0.81        13
#      neutral       0.99      0.98      0.99       186
#     positive       0.79      0.88      0.83        17
#
#     accuracy                           0.96       216
#    macro avg       0.86      0.90      0.88       216
# weighted avg       0.97      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       1.00      1.00      1.00       185
#     positive       0.89      1.00      0.94        17
#
#     accuracy                           0.99       216
#    macro avg       0.96      0.95      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 8 8
# Nearest checkpoint: 864
# Threshold: 88294.6796875
# Samples above threshold: 1
# Acquired samples: 8
# Sampling duration: 21.859652996063232 seconds
# New train size: 864
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.93326735496521 | ACCURACY: 0.8289 | F1 MACRO: 0.901 | F1 MICRO: 0.9021
# EPOCH 2 | LOSS: 2.4251656532287598 | ACCURACY: 0.9382 | F1 MACRO: 0.9599 | F1 MICRO: 0.9617
# EPOCH 3 | LOSS: 2.192793846130371 | ACCURACY: 0.9539 | F1 MACRO: 0.9699 | F1 MICRO: 0.9713
# EPOCH 4 | LOSS: 1.9771536588668823 | ACCURACY: 0.9598 | F1 MACRO: 0.9735 | F1 MICRO: 0.9748
# EPOCH 5 | LOSS: 1.8499311208724976 | ACCURACY: 0.9598 | F1 MACRO: 0.9736 | F1 MICRO: 0.9748
# EPOCH 6 | LOSS: 1.7582319974899292 | ACCURACY: 0.9576 | F1 MACRO: 0.9717 | F1 MICRO: 0.9733
# EPOCH 7 | LOSS: 1.688629150390625 | ACCURACY: 0.9546 | F1 MACRO: 0.9694 | F1 MICRO: 0.9714
# in second
# EPOCH 8 | LOSS: 1.6046810150146484 | ACCURACY: 0.9479 | F1 MACRO: 0.9671 | F1 MICRO: 0.9679
# in second
# EPOCH 9 | LOSS: 1.5500402450561523 | ACCURACY: 0.9546 | F1 MACRO: 0.9711 | F1 MICRO: 0.9719
# in second
# EPOCH 10 | LOSS: 1.5192784070968628 | ACCURACY: 0.9583 | F1 MACRO: 0.9732 | F1 MICRO: 0.9741
# aspect: ACCURACY 0.9598 | F1 MACRO 0.9735 | F1 MICRO 0.9748
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.94      0.99      0.96       175
#       others       0.92      0.94      0.93       158
#         part       0.97      0.99      0.98       158
#        price       0.98      0.99      0.98       192
#      service       0.99      1.00      0.99       191
#
#    micro avg       0.96      0.99      0.97      1061
#    macro avg       0.96      0.98      0.97      1061
# weighted avg       0.96      0.99      0.97      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.594268798828125 | ACCURACY: 0.9113 | F1 MACRO: 0.901 | F1 MICRO: 0.9113
# EPOCH 2 | LOSS: 2.9001216888427734 | ACCURACY: 0.9194 | F1 MACRO: 0.9119 | F1 MICRO: 0.9194
# EPOCH 3 | LOSS: 2.4478061199188232 | ACCURACY: 0.9395 | F1 MACRO: 0.9334 | F1 MICRO: 0.9395
# EPOCH 4 | LOSS: 2.2388293743133545 | ACCURACY: 0.9476 | F1 MACRO: 0.9406 | F1 MICRO: 0.9476
# EPOCH 5 | LOSS: 2.100783109664917 | ACCURACY: 0.9516 | F1 MACRO: 0.9453 | F1 MICRO: 0.9516
# EPOCH 6 | LOSS: 2.097388505935669 | ACCURACY: 0.9194 | F1 MACRO: 0.9119 | F1 MICRO: 0.9194
# EPOCH 7 | LOSS: 1.9641485214233398 | ACCURACY: 0.9395 | F1 MACRO: 0.9334 | F1 MICRO: 0.9395
# EPOCH 8 | LOSS: 1.9301226139068604 | ACCURACY: 0.9234 | F1 MACRO: 0.9095 | F1 MICRO: 0.9234
# in second
# EPOCH 9 | LOSS: 1.830468773841858 | ACCURACY: 0.9435 | F1 MACRO: 0.9358 | F1 MICRO: 0.9435
# in second
# EPOCH 10 | LOSS: 1.8051741123199463 | ACCURACY: 0.9435 | F1 MACRO: 0.9358 | F1 MICRO: 0.9435
# sentiment: ACCURACY 0.9516 | F1 MACRO 0.9453 | F1 MICRO 0.9516
#               precision    recall  f1-score   support
#
#     negative       0.92      0.94      0.93        81
#     positive       0.97      0.96      0.96       167
#
#     accuracy                           0.95       248
#    macro avg       0.94      0.95      0.95       248
# weighted avg       0.95      0.95      0.95       248
#
# --------------------------------------------------
# Iteration 864: Accuracy: 0.9514, F1 Micro: 0.9514, F1 Macro: 0.903
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.92      1.00      0.96        11
#      neutral       0.99      1.00      0.99       181
#     positive       1.00      0.88      0.93        24
#
#     accuracy                           0.99       216
#    macro avg       0.97      0.96      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.75      0.80        16
#      neutral       0.94      0.98      0.96       167
#     positive       0.89      0.73      0.80        33
#
#     accuracy                           0.93       216
#    macro avg       0.89      0.82      0.85       216
# weighted avg       0.92      0.93      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.82      0.75      0.78        12
#      neutral       0.92      0.93      0.93       152
#     positive       0.84      0.81      0.82        52
#
#     accuracy                           0.89       216
#    macro avg       0.86      0.83      0.84       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.77      1.00      0.87        23
#      neutral       0.97      0.98      0.98       152
#     positive       0.97      0.78      0.86        41
#
#     accuracy                           0.94       216
#    macro avg       0.90      0.92      0.90       216
# weighted avg       0.95      0.94      0.94       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.85      0.88        13
#      neutral       0.98      0.99      0.99       186
#     positive       0.93      0.82      0.87        17
#
#     accuracy                           0.97       216
#    macro avg       0.94      0.89      0.91       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.86      0.89        14
#      neutral       0.99      1.00      1.00       185
#     positive       0.94      0.94      0.94        17
#
#     accuracy                           0.99       216
#    macro avg       0.95      0.93      0.94       216
# weighted avg       0.99      0.99      0.99       216
#
# Total sampling time: 385.8 seconds
# Total runtime: 2830.315057516098 seconds

# %% [markdown]
# ## RUN 2

# %%
active_learning(seeds[1], 1)
# Out:
# ===============================================
# TRIAL 2
# Random seed: 81
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# pytorch_model.bin:   0%|          | 0.00/498M [00:00<?, ?B/s]
# EPOCH 1 | LOSS: 3.5976929664611816 | ACCURACY: 0.7634 | F1 MACRO: 0.8524 | F1 MICRO: 0.8603
# EPOCH 2 | LOSS: 3.2051076889038086 | ACCURACY: 0.7314 | F1 MACRO: 0.7859 | F1 MICRO: 0.8372
# EPOCH 3 | LOSS: 3.1839632987976074 | ACCURACY: 0.7269 | F1 MACRO: 0.7834 | F1 MICRO: 0.8348
# EPOCH 4 | LOSS: 3.163743734359741 | ACCURACY: 0.7515 | F1 MACRO: 0.8361 | F1 MICRO: 0.854
# in second
# EPOCH 5 | LOSS: 2.8541488647460938 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# in second
# EPOCH 6 | LOSS: 2.6820874214172363 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# in second
# EPOCH 7 | LOSS: 2.605513095855713 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# in second
# EPOCH 8 | LOSS: 2.602536916732788 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# in second
# EPOCH 9 | LOSS: 2.466979503631592 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# in second
# EPOCH 10 | LOSS: 2.4038352966308594 | ACCURACY: 0.7909 | F1 MACRO: 0.8816 | F1 MICRO: 0.8831
# aspect: ACCURACY 0.7634 | F1 MACRO 0.8524 | F1 MICRO 0.8603
#               precision    recall  f1-score   support
#
#         fuel       0.84      0.96      0.89       187
#      machine       0.79      1.00      0.88       175
#       others       0.70      0.68      0.69       158
#         part       0.76      0.89      0.82       158
#        price       0.86      1.00      0.92       192
#      service       0.85      0.97      0.90       191
#
#    micro avg       0.81      0.92      0.86      1061
#    macro avg       0.80      0.92      0.85      1061
# weighted avg       0.80      0.92      0.86      1061
#  samples avg       0.81      0.92      0.86      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 18.40941619873047 | ACCURACY: 0.9304 | F1 MACRO: 0.482 | F1 MICRO: 0.9304
# EPOCH 2 | LOSS: 14.951237678527832 | ACCURACY: 0.9304 | F1 MACRO: 0.482 | F1 MICRO: 0.9304
# EPOCH 3 | LOSS: 14.035446166992188 | ACCURACY: 0.9304 | F1 MACRO: 0.482 | F1 MICRO: 0.9304
# EPOCH 4 | LOSS: 13.811029434204102 | ACCURACY: 0.9304 | F1 MACRO: 0.482 | F1 MICRO: 0.9304
# EPOCH 5 | LOSS: 13.885565757751465 | ACCURACY: 0.9391 | F1 MACRO: 0.5953 | F1 MICRO: 0.9391
# EPOCH 6 | LOSS: 12.672772407531738 | ACCURACY: 0.9304 | F1 MACRO: 0.6483 | F1 MICRO: 0.9304
# EPOCH 7 | LOSS: 12.17520523071289 | ACCURACY: 0.913 | F1 MACRO: 0.4773 | F1 MICRO: 0.913
# EPOCH 8 | LOSS: 11.68865966796875 | ACCURACY: 0.8783 | F1 MACRO: 0.6482 | F1 MICRO: 0.8783
# in second
# EPOCH 9 | LOSS: 11.087661743164062 | ACCURACY: 0.9304 | F1 MACRO: 0.482 | F1 MICRO: 0.9304
# in second
# EPOCH 10 | LOSS: 10.67453670501709 | ACCURACY: 0.9304 | F1 MACRO: 0.482 | F1 MICRO: 0.9304
# sentiment: ACCURACY 0.9391 | F1 MACRO 0.5953 | F1 MICRO 0.9391
#               precision    recall  f1-score   support
#
#     negative       1.00      0.12      0.22         8
#     positive       0.94      1.00      0.97       107
#
#     accuracy                           0.94       115
#    macro avg       0.97      0.56      0.60       115
# weighted avg       0.94      0.94      0.92       115
#
# --------------------------------------------------
# Iteration 54: Accuracy: 0.7353, F1 Micro: 0.7353, F1 Macro: 0.3263
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        11
#      neutral       0.84      0.96      0.90       181
#     positive       0.22      0.08      0.12        24
#
#     accuracy                           0.81       216
#    macro avg       0.35      0.35      0.34       216
# weighted avg       0.73      0.81      0.77       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        16
#      neutral       0.78      0.99      0.87       167
#     positive       0.00      0.00      0.00        33
#
#     accuracy                           0.76       216
#    macro avg       0.26      0.33      0.29       216
# weighted avg       0.60      0.76      0.67       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.04      0.08      0.05        12
#      neutral       0.65      0.53      0.58       152
#     positive       0.20      0.25      0.22        52
#
#     accuracy                           0.44       216
#    macro avg       0.30      0.29      0.29       216
# weighted avg       0.51      0.44      0.47       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        23
#      neutral       0.77      0.87      0.81       152
#     positive       0.51      0.44      0.47        41
#
#     accuracy                           0.69       216
#    macro avg       0.43      0.44      0.43       216
# weighted avg       0.64      0.69      0.66       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        13
#      neutral       0.86      1.00      0.93       186
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.86       216
#    macro avg       0.29      0.33      0.31       216
# weighted avg       0.74      0.86      0.80       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        14
#      neutral       0.85      0.98      0.91       185
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.84       216
#    macro avg       0.28      0.33      0.30       216
# weighted avg       0.73      0.84      0.78       216
#
# Launching training on 2 GPUs.
# 345 345
# Nearest checkpoint: 540
# Threshold: 88540.9921875
# Samples above threshold: 81
# Acquired samples: 81
# Sampling duration: 6.316950559616089 seconds
# New train size: 135
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.75654935836792 | ACCURACY: 0.7277 | F1 MACRO: 0.7796 | F1 MICRO: 0.8347
# EPOCH 2 | LOSS: 3.3878891468048096 | ACCURACY: 0.7872 | F1 MACRO: 0.8787 | F1 MICRO: 0.8805
# EPOCH 3 | LOSS: 3.21833872795105 | ACCURACY: 0.7902 | F1 MACRO: 0.8809 | F1 MICRO: 0.8825
# EPOCH 4 | LOSS: 3.105067729949951 | ACCURACY: 0.7552 | F1 MACRO: 0.82 | F1 MICRO: 0.8525
# EPOCH 5 | LOSS: 2.761857271194458 | ACCURACY: 0.8013 | F1 MACRO: 0.8788 | F1 MICRO: 0.8843
# EPOCH 6 | LOSS: 2.677643299102783 | ACCURACY: 0.8199 | F1 MACRO: 0.8942 | F1 MICRO: 0.8964
# EPOCH 7 | LOSS: 2.596860885620117 | ACCURACY: 0.8155 | F1 MACRO: 0.8835 | F1 MICRO: 0.8906
# EPOCH 8 | LOSS: 2.611886739730835 | ACCURACY: 0.8408 | F1 MACRO: 0.8988 | F1 MICRO: 0.9043
# EPOCH 9 | LOSS: 2.5598292350769043 | ACCURACY: 0.869 | F1 MACRO: 0.9174 | F1 MICRO: 0.9211
# EPOCH 10 | LOSS: 2.567671537399292 | ACCURACY: 0.878 | F1 MACRO: 0.9212 | F1 MICRO: 0.9255
# aspect: ACCURACY 0.878 | F1 MACRO 0.9212 | F1 MICRO 0.9255
#               precision    recall  f1-score   support
#
#         fuel       0.90      1.00      0.95       187
#      machine       0.87      0.99      0.93       175
#       others       0.89      0.79      0.84       158
#         part       0.79      0.97      0.87       158
#        price       0.96      0.98      0.97       192
#      service       0.94      1.00      0.97       191
#
#    micro avg       0.89      0.96      0.93      1061
#    macro avg       0.89      0.96      0.92      1061
# weighted avg       0.90      0.96      0.93      1061
#  samples avg       0.90      0.96      0.92      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 15.60869026184082 | ACCURACY: 0.8654 | F1 MACRO: 0.842 | F1 MICRO: 0.8654
# EPOCH 2 | LOSS: 13.05260944366455 | ACCURACY: 0.8942 | F1 MACRO: 0.8624 | F1 MICRO: 0.8942
# EPOCH 3 | LOSS: 11.872453689575195 | ACCURACY: 0.9183 | F1 MACRO: 0.8989 | F1 MICRO: 0.9183
# EPOCH 4 | LOSS: 10.805098533630371 | ACCURACY: 0.9038 | F1 MACRO: 0.8916 | F1 MICRO: 0.9038
# EPOCH 5 | LOSS: 10.157794952392578 | ACCURACY: 0.9375 | F1 MACRO: 0.9235 | F1 MICRO: 0.9375
# EPOCH 6 | LOSS: 9.634735107421875 | ACCURACY: 0.9183 | F1 MACRO: 0.9028 | F1 MICRO: 0.9183
# EPOCH 7 | LOSS: 9.434065818786621 | ACCURACY: 0.9135 | F1 MACRO: 0.8956 | F1 MICRO: 0.9135
# EPOCH 8 | LOSS: 9.076408386230469 | ACCURACY: 0.9279 | F1 MACRO: 0.9099 | F1 MICRO: 0.9279
# in second
# EPOCH 9 | LOSS: 8.450005531311035 | ACCURACY: 0.9423 | F1 MACRO: 0.929 | F1 MICRO: 0.9423
# in second
# EPOCH 10 | LOSS: 8.236350059509277 | ACCURACY: 0.9327 | F1 MACRO: 0.918 | F1 MICRO: 0.9327
# sentiment: ACCURACY 0.9375 | F1 MACRO 0.9235 | F1 MICRO 0.9375
#               precision    recall  f1-score   support
#
#     negative       0.91      0.87      0.89        61
#     positive       0.95      0.97      0.96       147
#
#     accuracy                           0.94       208
#    macro avg       0.93      0.92      0.92       208
# weighted avg       0.94      0.94      0.94       208
#
# --------------------------------------------------
# Iteration 135: Accuracy: 0.8642, F1 Micro: 0.8642, F1 Macro: 0.727
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.88      0.64      0.74        11
#      neutral       0.91      0.99      0.95       181
#     positive       0.90      0.38      0.53        24
#
#     accuracy                           0.91       216
#    macro avg       0.89      0.67      0.74       216
# weighted avg       0.91      0.91      0.89       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.62      0.71        16
#      neutral       0.89      0.99      0.94       167
#     positive       0.89      0.52      0.65        33
#
#     accuracy                           0.89       216
#    macro avg       0.87      0.71      0.77       216
# weighted avg       0.89      0.89      0.88       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.56      0.75      0.64        12
#      neutral       0.89      0.72      0.80       152
#     positive       0.51      0.75      0.61        52
#
#     accuracy                           0.73       216
#    macro avg       0.65      0.74      0.68       216
# weighted avg       0.78      0.73      0.74       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.26      0.40        23
#      neutral       0.79      0.98      0.88       152
#     positive       0.67      0.34      0.45        41
#
#     accuracy                           0.78       216
#    macro avg       0.77      0.53      0.58       216
# weighted avg       0.78      0.78      0.75       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.89      0.62      0.73        13
#      neutral       0.97      0.98      0.97       186
#     positive       0.58      0.65      0.61        17
#
#     accuracy                           0.93       216
#    macro avg       0.81      0.75      0.77       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.94      1.00      0.97       185
#     positive       1.00      0.41      0.58        17
#
#     accuracy                           0.94       216
#    macro avg       0.98      0.76      0.82       216
# weighted avg       0.95      0.94      0.94       216
#
# Launching training on 2 GPUs.
# 556 556
# Nearest checkpoint: 540
# Threshold: 88261.6796875
# Samples above threshold: 73
# Acquired samples: 73
# Sampling duration: 8.864333629608154 seconds
# New train size: 208
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.655322313308716 | ACCURACY: 0.7619 | F1 MACRO: 0.8477 | F1 MICRO: 0.8609
# EPOCH 2 | LOSS: 3.361389398574829 | ACCURACY: 0.7969 | F1 MACRO: 0.8841 | F1 MICRO: 0.8857
# EPOCH 3 | LOSS: 2.9390077590942383 | ACCURACY: 0.7999 | F1 MACRO: 0.88 | F1 MICRO: 0.8837
# EPOCH 4 | LOSS: 2.7278120517730713 | ACCURACY: 0.8326 | F1 MACRO: 0.9016 | F1 MICRO: 0.9032
# EPOCH 5 | LOSS: 2.5815513134002686 | ACCURACY: 0.8393 | F1 MACRO: 0.9016 | F1 MICRO: 0.9046
# EPOCH 6 | LOSS: 2.5388572216033936 | ACCURACY: 0.8891 | F1 MACRO: 0.9303 | F1 MICRO: 0.9328
# EPOCH 7 | LOSS: 2.4803504943847656 | ACCURACY: 0.9092 | F1 MACRO: 0.9418 | F1 MICRO: 0.9441
# EPOCH 8 | LOSS: 2.4217300415039062 | ACCURACY: 0.9144 | F1 MACRO: 0.9444 | F1 MICRO: 0.947
# EPOCH 9 | LOSS: 2.4027793407440186 | ACCURACY: 0.9234 | F1 MACRO: 0.9501 | F1 MICRO: 0.9524
# EPOCH 10 | LOSS: 2.348963499069214 | ACCURACY: 0.9308 | F1 MACRO: 0.9548 | F1 MICRO: 0.957
# aspect: ACCURACY 0.9308 | F1 MACRO 0.9548 | F1 MICRO 0.957
#               precision    recall  f1-score   support
#
#         fuel       0.97      1.00      0.98       187
#      machine       0.91      0.97      0.94       175
#       others       0.88      0.91      0.89       158
#         part       0.91      0.99      0.95       158
#        price       0.98      0.99      0.98       192
#      service       0.96      1.00      0.98       191
#
#    micro avg       0.94      0.98      0.96      1061
#    macro avg       0.94      0.97      0.95      1061
# weighted avg       0.94      0.98      0.96      1061
#  samples avg       0.94      0.98      0.95      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 13.26261043548584 | ACCURACY: 0.9325 | F1 MACRO: 0.9231 | F1 MICRO: 0.9325
# EPOCH 2 | LOSS: 10.462631225585938 | ACCURACY: 0.9156 | F1 MACRO: 0.9078 | F1 MICRO: 0.9156
# EPOCH 3 | LOSS: 9.17058277130127 | ACCURACY: 0.9494 | F1 MACRO: 0.9419 | F1 MICRO: 0.9494
# EPOCH 4 | LOSS: 8.423307418823242 | ACCURACY: 0.9409 | F1 MACRO: 0.9335 | F1 MICRO: 0.9409
# EPOCH 5 | LOSS: 7.865896701812744 | ACCURACY: 0.9494 | F1 MACRO: 0.9411 | F1 MICRO: 0.9494
# EPOCH 6 | LOSS: 7.597949028015137 | ACCURACY: 0.9409 | F1 MACRO: 0.9302 | F1 MICRO: 0.9409
# EPOCH 7 | LOSS: 7.2414751052856445 | ACCURACY: 0.9494 | F1 MACRO: 0.943 | F1 MICRO: 0.9494
# EPOCH 8 | LOSS: 7.2862725257873535 | ACCURACY: 0.9536 | F1 MACRO: 0.9454 | F1 MICRO: 0.9536
# EPOCH 9 | LOSS: 7.212309837341309 | ACCURACY: 0.9451 | F1 MACRO: 0.9373 | F1 MICRO: 0.9451
# EPOCH 10 | LOSS: 7.181664943695068 | ACCURACY: 0.9409 | F1 MACRO: 0.9296 | F1 MICRO: 0.9409
# sentiment: ACCURACY 0.9536 | F1 MACRO 0.9454 | F1 MICRO 0.9536
#               precision    recall  f1-score   support
#
#     negative       0.96      0.89      0.92        75
#     positive       0.95      0.98      0.97       162
#
#     accuracy                           0.95       237
#    macro avg       0.95      0.94      0.95       237
# weighted avg       0.95      0.95      0.95       237
#
# --------------------------------------------------
# Iteration 208: Accuracy: 0.9244, F1 Micro: 0.9244, F1 Macro: 0.8496
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.82      0.90        11
#      neutral       0.98      1.00      0.99       181
#     positive       0.95      0.88      0.91        24
#
#     accuracy                           0.98       216
#    macro avg       0.98      0.90      0.93       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.69      0.79        16
#      neutral       0.92      0.95      0.94       167
#     positive       0.69      0.67      0.68        33
#
#     accuracy                           0.89       216
#    macro avg       0.84      0.77      0.80       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.53      0.67      0.59        12
#      neutral       0.91      0.90      0.91       152
#     positive       0.78      0.77      0.78        52
#
#     accuracy                           0.86       216
#    macro avg       0.74      0.78      0.76       216
# weighted avg       0.86      0.86      0.86       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.78      0.77        23
#      neutral       0.94      0.97      0.95       152
#     positive       0.82      0.68      0.75        41
#
#     accuracy                           0.90       216
#    macro avg       0.84      0.81      0.82       216
# weighted avg       0.90      0.90      0.90       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.77      0.83        13
#      neutral       0.98      0.98      0.98       186
#     positive       0.78      0.82      0.80        17
#
#     accuracy                           0.96       216
#    macro avg       0.89      0.86      0.87       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.96      1.00      0.98       185
#     positive       1.00      0.71      0.83        17
#
#     accuracy                           0.97       216
#    macro avg       0.99      0.85      0.91       216
# weighted avg       0.97      0.97      0.97       216
#
# Launching training on 2 GPUs.
# 588 588
# Nearest checkpoint: 540
# Threshold: 87979.453125
# Samples above threshold: 66
# Acquired samples: 66
# Sampling duration: 10.413477182388306 seconds
# New train size: 274
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.3351848125457764 | ACCURACY: 0.7879 | F1 MACRO: 0.8798 | F1 MICRO: 0.8814
# EPOCH 2 | LOSS: 2.855587959289551 | ACCURACY: 0.8065 | F1 MACRO: 0.888 | F1 MICRO: 0.8899
# EPOCH 3 | LOSS: 2.5724358558654785 | ACCURACY: 0.8214 | F1 MACRO: 0.8951 | F1 MICRO: 0.8969
# EPOCH 4 | LOSS: 2.4111690521240234 | ACCURACY: 0.8378 | F1 MACRO: 0.9036 | F1 MICRO: 0.9055
# EPOCH 5 | LOSS: 2.3452534675598145 | ACCURACY: 0.8914 | F1 MACRO: 0.9316 | F1 MICRO: 0.9339
# EPOCH 6 | LOSS: 2.26407527923584 | ACCURACY: 0.9189 | F1 MACRO: 0.9477 | F1 MICRO: 0.9498
# EPOCH 7 | LOSS: 2.166529893875122 | ACCURACY: 0.9323 | F1 MACRO: 0.9565 | F1 MICRO: 0.958
# EPOCH 8 | LOSS: 2.1624605655670166 | ACCURACY: 0.933 | F1 MACRO: 0.9569 | F1 MICRO: 0.9583
# EPOCH 9 | LOSS: 2.061091184616089 | ACCURACY: 0.9427 | F1 MACRO: 0.9619 | F1 MICRO: 0.9642
# EPOCH 10 | LOSS: 1.9723347425460815 | ACCURACY: 0.9353 | F1 MACRO: 0.9577 | F1 MICRO: 0.9596
# aspect: ACCURACY 0.9427 | F1 MACRO 0.9619 | F1 MICRO 0.9642
#               precision    recall  f1-score   support
#
#         fuel       0.97      1.00      0.98       187
#      machine       0.94      1.00      0.97       175
#       others       0.90      0.88      0.89       158
#         part       0.95      0.98      0.97       158
#        price       0.97      0.99      0.98       192
#      service       0.96      1.00      0.98       191
#
#    micro avg       0.95      0.98      0.96      1061
#    macro avg       0.95      0.98      0.96      1061
# weighted avg       0.95      0.98      0.96      1061
#  samples avg       0.95      0.98      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 10.246511459350586 | ACCURACY: 0.8988 | F1 MACRO: 0.8816 | F1 MICRO: 0.8988
# EPOCH 2 | LOSS: 8.316178321838379 | ACCURACY: 0.9352 | F1 MACRO: 0.9245 | F1 MICRO: 0.9352
# EPOCH 3 | LOSS: 7.220143795013428 | ACCURACY: 0.9474 | F1 MACRO: 0.9405 | F1 MICRO: 0.9474
# EPOCH 4 | LOSS: 6.443375587463379 | ACCURACY: 0.9352 | F1 MACRO: 0.9256 | F1 MICRO: 0.9352
# EPOCH 5 | LOSS: 6.1324968338012695 | ACCURACY: 0.9352 | F1 MACRO: 0.925 | F1 MICRO: 0.9352
# EPOCH 6 | LOSS: 5.950252056121826 | ACCURACY: 0.9352 | F1 MACRO: 0.9256 | F1 MICRO: 0.9352
# in second
# EPOCH 7 | LOSS: 5.5229339599609375 | ACCURACY: 0.9433 | F1 MACRO: 0.9353 | F1 MICRO: 0.9433
# in second
# EPOCH 8 | LOSS: 5.4067158699035645 | ACCURACY: 0.9393 | F1 MACRO: 0.9304 | F1 MICRO: 0.9393
# in second
# EPOCH 9 | LOSS: 5.311586856842041 | ACCURACY: 0.9433 | F1 MACRO: 0.9353 | F1 MICRO: 0.9433
# in second
# EPOCH 10 | LOSS: 5.286345958709717 | ACCURACY: 0.9433 | F1 MACRO: 0.9353 | F1 MICRO: 0.9433
# sentiment: ACCURACY 0.9474 | F1 MACRO 0.9405 | F1 MICRO 0.9474
#               precision    recall  f1-score   support
#
#     negative       0.87      0.97      0.92        77
#     positive       0.99      0.94      0.96       170
#
#     accuracy                           0.95       247
#    macro avg       0.93      0.95      0.94       247
# weighted avg       0.95      0.95      0.95       247
#
# --------------------------------------------------
# Iteration 274: Accuracy: 0.9252, F1 Micro: 0.9252, F1 Macro: 0.8493
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.92      1.00      0.96        11
#      neutral       0.98      1.00      0.99       181
#     positive       1.00      0.83      0.91        24
#
#     accuracy                           0.98       216
#    macro avg       0.97      0.94      0.95       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.65      0.69      0.67        16
#      neutral       0.93      0.97      0.95       167
#     positive       0.84      0.64      0.72        33
#
#     accuracy                           0.90       216
#    macro avg       0.81      0.76      0.78       216
# weighted avg       0.90      0.90      0.89       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.43      0.75      0.55        12
#      neutral       0.92      0.86      0.89       152
#     positive       0.70      0.73      0.72        52
#
#     accuracy                           0.82       216
#    macro avg       0.68      0.78      0.72       216
# weighted avg       0.84      0.82      0.83       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.73      0.96      0.83        23
#      neutral       0.95      0.97      0.96       152
#     positive       0.94      0.71      0.81        41
#
#     accuracy                           0.92       216
#    macro avg       0.87      0.88      0.87       216
# weighted avg       0.93      0.92      0.92       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.85      0.88        13
#      neutral       0.97      0.99      0.98       186
#     positive       0.86      0.71      0.77        17
#
#     accuracy                           0.96       216
#    macro avg       0.92      0.85      0.88       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.86      0.89        14
#      neutral       0.97      1.00      0.98       185
#     positive       1.00      0.71      0.83        17
#
#     accuracy                           0.97       216
#    macro avg       0.96      0.85      0.90       216
# weighted avg       0.97      0.97      0.97       216
#
# Launching training on 2 GPUs.
# 554 554
# Nearest checkpoint: 540
# Threshold: 87961.5
# Samples above threshold: 59
# Acquired samples: 59
# Sampling duration: 11.730433940887451 seconds
# New train size: 333
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.4835684299468994 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# EPOCH 2 | LOSS: 2.9765589237213135 | ACCURACY: 0.7902 | F1 MACRO: 0.8721 | F1 MICRO: 0.8782
# EPOCH 3 | LOSS: 2.609734058380127 | ACCURACY: 0.8341 | F1 MACRO: 0.9024 | F1 MICRO: 0.9037
# EPOCH 4 | LOSS: 2.464996576309204 | ACCURACY: 0.8891 | F1 MACRO: 0.9316 | F1 MICRO: 0.9331
# EPOCH 5 | LOSS: 2.379408121109009 | ACCURACY: 0.9241 | F1 MACRO: 0.9501 | F1 MICRO: 0.9526
# EPOCH 6 | LOSS: 2.3229362964630127 | ACCURACY: 0.942 | F1 MACRO: 0.9625 | F1 MICRO: 0.964
# EPOCH 7 | LOSS: 2.2097370624542236 | ACCURACY: 0.9457 | F1 MACRO: 0.9642 | F1 MICRO: 0.966
# EPOCH 8 | LOSS: 2.165598154067993 | ACCURACY: 0.9472 | F1 MACRO: 0.965 | F1 MICRO: 0.967
# EPOCH 9 | LOSS: 2.0140092372894287 | ACCURACY: 0.9494 | F1 MACRO: 0.9658 | F1 MICRO: 0.9682
# EPOCH 10 | LOSS: 1.9454035758972168 | ACCURACY: 0.9501 | F1 MACRO: 0.9669 | F1 MICRO: 0.9688
# aspect: ACCURACY 0.9501 | F1 MACRO 0.9669 | F1 MICRO 0.9688
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.93      1.00      0.96       175
#       others       0.91      0.92      0.91       158
#         part       0.96      0.96      0.96       158
#        price       0.98      0.98      0.98       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.96      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.96      0.98      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 8.510614395141602 | ACCURACY: 0.9302 | F1 MACRO: 0.9224 | F1 MICRO: 0.9302
# EPOCH 2 | LOSS: 6.599145412445068 | ACCURACY: 0.9341 | F1 MACRO: 0.9247 | F1 MICRO: 0.9341
# EPOCH 3 | LOSS: 6.045508861541748 | ACCURACY: 0.9302 | F1 MACRO: 0.9215 | F1 MICRO: 0.9302
# EPOCH 4 | LOSS: 5.489562034606934 | ACCURACY: 0.9302 | F1 MACRO: 0.922 | F1 MICRO: 0.9302
# EPOCH 5 | LOSS: 5.228373050689697 | ACCURACY: 0.9109 | F1 MACRO: 0.8969 | F1 MICRO: 0.9109
# in second
# EPOCH 6 | LOSS: 4.933424472808838 | ACCURACY: 0.9264 | F1 MACRO: 0.9169 | F1 MICRO: 0.9264
# in second
# EPOCH 7 | LOSS: 4.757422924041748 | ACCURACY: 0.9264 | F1 MACRO: 0.9169 | F1 MICRO: 0.9264
# in second
# EPOCH 8 | LOSS: 4.630726337432861 | ACCURACY: 0.9225 | F1 MACRO: 0.9133 | F1 MICRO: 0.9225
# in second
# EPOCH 9 | LOSS: 4.652524948120117 | ACCURACY: 0.9264 | F1 MACRO: 0.9164 | F1 MICRO: 0.9264
# in second
# EPOCH 10 | LOSS: 4.600046157836914 | ACCURACY: 0.9264 | F1 MACRO: 0.9174 | F1 MICRO: 0.9264
# sentiment: ACCURACY 0.9341 | F1 MACRO 0.9247 | F1 MICRO 0.9341
#               precision    recall  f1-score   support
#
#     negative       0.89      0.90      0.90        83
#     positive       0.95      0.95      0.95       175
#
#     accuracy                           0.93       258
#    macro avg       0.92      0.93      0.92       258
# weighted avg       0.93      0.93      0.93       258
#
# --------------------------------------------------
# Iteration 333: Accuracy: 0.9336, F1 Micro: 0.9336, F1 Macro: 0.8671
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.99      1.00      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.94      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.75      0.83        16
#      neutral       0.94      0.99      0.96       167
#     positive       0.85      0.70      0.77        33
#
#     accuracy                           0.93       216
#    macro avg       0.90      0.81      0.85       216
# weighted avg       0.92      0.93      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.43      0.75      0.55        12
#      neutral       0.92      0.86      0.89       152
#     positive       0.77      0.79      0.78        52
#
#     accuracy                           0.84       216
#    macro avg       0.71      0.80      0.74       216
# weighted avg       0.86      0.84      0.85       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.79      0.83      0.81        23
#      neutral       0.96      0.95      0.95       152
#     positive       0.83      0.85      0.84        41
#
#     accuracy                           0.92       216
#    macro avg       0.86      0.88      0.87       216
# weighted avg       0.92      0.92      0.92       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.73      0.85      0.79        13
#      neutral       0.99      0.98      0.99       186
#     positive       0.88      0.82      0.85        17
#
#     accuracy                           0.96       216
#    macro avg       0.87      0.88      0.87       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.98      1.00      0.99       185
#     positive       0.87      0.76      0.81        17
#
#     accuracy                           0.97       216
#    macro avg       0.95      0.87      0.91       216
# weighted avg       0.97      0.97      0.97       216
#
# Launching training on 2 GPUs.
# 505 505
# Nearest checkpoint: 540
# Threshold: 88021.296875
# Samples above threshold: 54
# Acquired samples: 54
# Sampling duration: 12.961763858795166 seconds
# New train size: 387
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.340791940689087 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# EPOCH 2 | LOSS: 2.8287265300750732 | ACCURACY: 0.8214 | F1 MACRO: 0.8957 | F1 MICRO: 0.8973
# EPOCH 3 | LOSS: 2.4756884574890137 | ACCURACY: 0.8735 | F1 MACRO: 0.9219 | F1 MICRO: 0.9241
# EPOCH 4 | LOSS: 2.4062273502349854 | ACCURACY: 0.9249 | F1 MACRO: 0.9511 | F1 MICRO: 0.9534
# EPOCH 5 | LOSS: 2.312166213989258 | ACCURACY: 0.9382 | F1 MACRO: 0.9607 | F1 MICRO: 0.9618
# EPOCH 6 | LOSS: 2.2079083919525146 | ACCURACY: 0.9472 | F1 MACRO: 0.9657 | F1 MICRO: 0.9671
# EPOCH 7 | LOSS: 2.0740551948547363 | ACCURACY: 0.9427 | F1 MACRO: 0.9615 | F1 MICRO: 0.9641
# EPOCH 8 | LOSS: 1.954385757446289 | ACCURACY: 0.9449 | F1 MACRO: 0.963 | F1 MICRO: 0.9654
# EPOCH 9 | LOSS: 1.9813565015792847 | ACCURACY: 0.9516 | F1 MACRO: 0.968 | F1 MICRO: 0.9698
# EPOCH 10 | LOSS: 1.8721868991851807 | ACCURACY: 0.9449 | F1 MACRO: 0.9633 | F1 MICRO: 0.9654
# aspect: ACCURACY 0.9516 | F1 MACRO 0.968 | F1 MICRO 0.9698
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.93      1.00      0.96       175
#       others       0.90      0.92      0.91       158
#         part       0.95      0.99      0.97       158
#        price       0.98      0.99      0.98       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.95      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 7.357041835784912 | ACCURACY: 0.8947 | F1 MACRO: 0.8806 | F1 MICRO: 0.8947
# EPOCH 2 | LOSS: 5.541565895080566 | ACCURACY: 0.9352 | F1 MACRO: 0.9294 | F1 MICRO: 0.9352
# EPOCH 3 | LOSS: 5.178791522979736 | ACCURACY: 0.9069 | F1 MACRO: 0.8997 | F1 MICRO: 0.9069
# EPOCH 4 | LOSS: 4.7842698097229 | ACCURACY: 0.9069 | F1 MACRO: 0.8992 | F1 MICRO: 0.9069
# EPOCH 5 | LOSS: 4.524603366851807 | ACCURACY: 0.8947 | F1 MACRO: 0.879 | F1 MICRO: 0.8947
# in second
# EPOCH 6 | LOSS: 3.993590831756592 | ACCURACY: 0.9231 | F1 MACRO: 0.9141 | F1 MICRO: 0.9231
# in second
# EPOCH 7 | LOSS: 3.891721487045288 | ACCURACY: 0.9231 | F1 MACRO: 0.915 | F1 MICRO: 0.9231
# in second
# EPOCH 8 | LOSS: 3.8771421909332275 | ACCURACY: 0.9231 | F1 MACRO: 0.915 | F1 MICRO: 0.9231
# in second
# EPOCH 9 | LOSS: 3.7647271156311035 | ACCURACY: 0.9231 | F1 MACRO: 0.915 | F1 MICRO: 0.9231
# in second
# EPOCH 10 | LOSS: 3.7927327156066895 | ACCURACY: 0.9231 | F1 MACRO: 0.9146 | F1 MICRO: 0.9231
# sentiment: ACCURACY 0.9352 | F1 MACRO 0.9294 | F1 MICRO 0.9352
#               precision    recall  f1-score   support
#
#     negative       0.86      0.96      0.91        83
#     positive       0.98      0.92      0.95       164
#
#     accuracy                           0.94       247
#    macro avg       0.92      0.94      0.93       247
# weighted avg       0.94      0.94      0.94       247
#
# --------------------------------------------------
# Iteration 387: Accuracy: 0.9398, F1 Micro: 0.9398, F1 Macro: 0.8718
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.92      1.00      0.96        11
#      neutral       0.99      1.00      0.99       181
#     positive       1.00      0.88      0.93        24
#
#     accuracy                           0.99       216
#    macro avg       0.97      0.96      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.74      0.88      0.80        16
#      neutral       0.95      0.99      0.97       167
#     positive       0.91      0.64      0.75        33
#
#     accuracy                           0.93       216
#    macro avg       0.87      0.83      0.84       216
# weighted avg       0.93      0.93      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.43      0.75      0.55        12
#      neutral       0.91      0.91      0.91       152
#     positive       0.84      0.69      0.76        52
#
#     accuracy                           0.85       216
#    macro avg       0.73      0.79      0.74       216
# weighted avg       0.87      0.85      0.86       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.81      0.96      0.88        23
#      neutral       0.95      0.97      0.96       152
#     positive       0.91      0.76      0.83        41
#
#     accuracy                           0.93       216
#    macro avg       0.89      0.90      0.89       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.79      0.85      0.81        13
#      neutral       0.98      0.99      0.99       186
#     positive       0.86      0.71      0.77        17
#
#     accuracy                           0.96       216
#    macro avg       0.88      0.85      0.86       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.93      0.93        14
#      neutral       0.98      1.00      0.99       185
#     positive       1.00      0.82      0.90        17
#
#     accuracy                           0.98       216
#    macro avg       0.97      0.92      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Launching training on 2 GPUs.
# 454 454
# Nearest checkpoint: 540
# Threshold: 88118.421875
# Samples above threshold: 48
# Acquired samples: 48
# Sampling duration: 13.71505355834961 seconds
# New train size: 435
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.1994316577911377 | ACCURACY: 0.7917 | F1 MACRO: 0.8815 | F1 MICRO: 0.8831
# EPOCH 2 | LOSS: 2.606403112411499 | ACCURACY: 0.8207 | F1 MACRO: 0.8957 | F1 MICRO: 0.8973
# EPOCH 3 | LOSS: 2.381261110305786 | ACCURACY: 0.9077 | F1 MACRO: 0.9425 | F1 MICRO: 0.9439
# EPOCH 4 | LOSS: 2.272756576538086 | ACCURACY: 0.9308 | F1 MACRO: 0.9551 | F1 MICRO: 0.9571
# EPOCH 5 | LOSS: 2.151609182357788 | ACCURACY: 0.9427 | F1 MACRO: 0.9631 | F1 MICRO: 0.9644
# EPOCH 6 | LOSS: 2.0903589725494385 | ACCURACY: 0.9457 | F1 MACRO: 0.964 | F1 MICRO: 0.9661
# EPOCH 7 | LOSS: 1.9699196815490723 | ACCURACY: 0.9546 | F1 MACRO: 0.9701 | F1 MICRO: 0.9717
# EPOCH 8 | LOSS: 1.8559800386428833 | ACCURACY: 0.9531 | F1 MACRO: 0.9689 | F1 MICRO: 0.9707
# EPOCH 9 | LOSS: 1.827093482017517 | ACCURACY: 0.9501 | F1 MACRO: 0.9667 | F1 MICRO: 0.9687
# EPOCH 10 | LOSS: 1.759259819984436 | ACCURACY: 0.9472 | F1 MACRO: 0.965 | F1 MICRO: 0.967
# aspect: ACCURACY 0.9546 | F1 MACRO 0.9701 | F1 MICRO 0.9717
#               precision    recall  f1-score   support
#
#         fuel       0.97      1.00      0.99       187
#      machine       0.94      1.00      0.97       175
#       others       0.91      0.94      0.92       158
#         part       0.94      0.99      0.96       158
#        price       0.98      0.99      0.99       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.96      0.99      0.97      1061
#    macro avg       0.96      0.99      0.97      1061
# weighted avg       0.96      0.99      0.97      1061
#  samples avg       0.96      0.99      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.2918009757995605 | ACCURACY: 0.9231 | F1 MACRO: 0.9107 | F1 MICRO: 0.9231
# EPOCH 2 | LOSS: 4.749629497528076 | ACCURACY: 0.9514 | F1 MACRO: 0.9449 | F1 MICRO: 0.9514
# EPOCH 3 | LOSS: 4.338602066040039 | ACCURACY: 0.9514 | F1 MACRO: 0.9438 | F1 MICRO: 0.9514
# EPOCH 4 | LOSS: 4.006434440612793 | ACCURACY: 0.9474 | F1 MACRO: 0.9415 | F1 MICRO: 0.9474
# EPOCH 5 | LOSS: 3.815730094909668 | ACCURACY: 0.9433 | F1 MACRO: 0.934 | F1 MICRO: 0.9433
# EPOCH 6 | LOSS: 3.7439348697662354 | ACCURACY: 0.9393 | F1 MACRO: 0.93 | F1 MICRO: 0.9393
# in second
# EPOCH 7 | LOSS: 3.37982439994812 | ACCURACY: 0.9312 | F1 MACRO: 0.9195 | F1 MICRO: 0.9312
# in second
# EPOCH 8 | LOSS: 3.342564344406128 | ACCURACY: 0.9352 | F1 MACRO: 0.9245 | F1 MICRO: 0.9352
# in second
# EPOCH 9 | LOSS: 3.2962260246276855 | ACCURACY: 0.9393 | F1 MACRO: 0.93 | F1 MICRO: 0.9393
# in second
# EPOCH 10 | LOSS: 3.191675901412964 | ACCURACY: 0.9352 | F1 MACRO: 0.9245 | F1 MICRO: 0.9352
# sentiment: ACCURACY 0.9514 | F1 MACRO 0.9438 | F1 MICRO 0.9514
#               precision    recall  f1-score   support
#
#     negative       0.95      0.90      0.92        80
#     positive       0.95      0.98      0.96       167
#
#     accuracy                           0.95       247
#    macro avg       0.95      0.94      0.94       247
# weighted avg       0.95      0.95      0.95       247
#
# --------------------------------------------------
# Iteration 435: Accuracy: 0.9406, F1 Micro: 0.9406, F1 Macro: 0.8763
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.64      0.78        11
#      neutral       0.98      1.00      0.99       181
#     positive       0.88      0.88      0.88        24
#
#     accuracy                           0.97       216
#    macro avg       0.95      0.84      0.88       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.69      0.79        16
#      neutral       0.94      0.99      0.97       167
#     positive       0.85      0.70      0.77        33
#
#     accuracy                           0.93       216
#    macro avg       0.90      0.79      0.84       216
# weighted avg       0.92      0.93      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.75      0.75        12
#      neutral       0.91      0.91      0.91       152
#     positive       0.79      0.79      0.79        52
#
#     accuracy                           0.88       216
#    macro avg       0.82      0.82      0.82       216
# weighted avg       0.88      0.88      0.88       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.89      0.74      0.81        23
#      neutral       0.95      0.98      0.96       152
#     positive       0.85      0.83      0.84        41
#
#     accuracy                           0.93       216
#    macro avg       0.90      0.85      0.87       216
# weighted avg       0.92      0.93      0.92       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.92      0.86        13
#      neutral       0.99      0.98      0.98       186
#     positive       0.88      0.88      0.88        17
#
#     accuracy                           0.97       216
#    macro avg       0.89      0.93      0.91       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.93      0.93        14
#      neutral       0.98      1.00      0.99       185
#     positive       1.00      0.82      0.90        17
#
#     accuracy                           0.98       216
#    macro avg       0.97      0.92      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Launching training on 2 GPUs.
# 405 405
# Nearest checkpoint: 540
# Threshold: 88191.703125
# Samples above threshold: 43
# Acquired samples: 43
# Sampling duration: 14.243266582489014 seconds
# New train size: 478
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.216845989227295 | ACCURACY: 0.7909 | F1 MACRO: 0.8816 | F1 MICRO: 0.8831
# EPOCH 2 | LOSS: 2.5671093463897705 | ACCURACY: 0.8356 | F1 MACRO: 0.9038 | F1 MICRO: 0.9051
# EPOCH 3 | LOSS: 2.347832441329956 | ACCURACY: 0.9062 | F1 MACRO: 0.9399 | F1 MICRO: 0.9423
# EPOCH 4 | LOSS: 2.229182243347168 | ACCURACY: 0.933 | F1 MACRO: 0.9568 | F1 MICRO: 0.9584
# EPOCH 5 | LOSS: 2.1251518726348877 | ACCURACY: 0.9442 | F1 MACRO: 0.9637 | F1 MICRO: 0.9654
# EPOCH 6 | LOSS: 2.0624032020568848 | ACCURACY: 0.9487 | F1 MACRO: 0.9666 | F1 MICRO: 0.9679
# EPOCH 7 | LOSS: 1.9432346820831299 | ACCURACY: 0.9509 | F1 MACRO: 0.9677 | F1 MICRO: 0.9694
# EPOCH 8 | LOSS: 1.8159734010696411 | ACCURACY: 0.9576 | F1 MACRO: 0.9722 | F1 MICRO: 0.9735
# EPOCH 9 | LOSS: 1.7610095739364624 | ACCURACY: 0.9531 | F1 MACRO: 0.9683 | F1 MICRO: 0.9705
# EPOCH 10 | LOSS: 1.7297275066375732 | ACCURACY: 0.9561 | F1 MACRO: 0.9702 | F1 MICRO: 0.9724
# aspect: ACCURACY 0.9576 | F1 MACRO 0.9722 | F1 MICRO 0.9735
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.95      0.98      0.97       175
#       others       0.91      0.96      0.94       158
#         part       0.96      0.97      0.97       158
#        price       0.99      0.98      0.99       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.96      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.320581912994385 | ACCURACY: 0.896 | F1 MACRO: 0.8762 | F1 MICRO: 0.896
# EPOCH 2 | LOSS: 4.7534918785095215 | ACCURACY: 0.948 | F1 MACRO: 0.9419 | F1 MICRO: 0.948
# EPOCH 3 | LOSS: 4.27828311920166 | ACCURACY: 0.936 | F1 MACRO: 0.9283 | F1 MICRO: 0.936
# EPOCH 4 | LOSS: 3.946378231048584 | ACCURACY: 0.944 | F1 MACRO: 0.9383 | F1 MICRO: 0.944
# EPOCH 5 | LOSS: 3.801820993423462 | ACCURACY: 0.944 | F1 MACRO: 0.9376 | F1 MICRO: 0.944
# in second
# EPOCH 6 | LOSS: 3.4138243198394775 | ACCURACY: 0.948 | F1 MACRO: 0.9426 | F1 MICRO: 0.948
# in second
# EPOCH 7 | LOSS: 3.2818682193756104 | ACCURACY: 0.944 | F1 MACRO: 0.9383 | F1 MICRO: 0.944
# in second
# EPOCH 8 | LOSS: 3.2353179454803467 | ACCURACY: 0.944 | F1 MACRO: 0.9383 | F1 MICRO: 0.944
# in second
# sentiment: ACCURACY 0.948 | F1 MACRO 0.9419 | F1 MICRO 0.948
#               precision    recall  f1-score   support
#
#     negative       0.90      0.95      0.92        82
#     positive       0.98      0.95      0.96       168
#
#     accuracy                           0.95       250
#    macro avg       0.94      0.95      0.94       250
# weighted avg       0.95      0.95      0.95       250
#
# --------------------------------------------------
# Iteration 478: Accuracy: 0.9498, F1 Micro: 0.9498, F1 Macro: 0.9007
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.99      1.00      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.94      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.88      0.90        16
#      neutral       0.96      0.98      0.97       167
#     positive       0.84      0.79      0.81        33
#
#     accuracy                           0.94       216
#    macro avg       0.91      0.88      0.89       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.75      0.75        12
#      neutral       0.91      0.95      0.93       152
#     positive       0.89      0.77      0.82        52
#
#     accuracy                           0.90       216
#    macro avg       0.85      0.82      0.84       216
# weighted avg       0.90      0.90      0.90       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.81      0.91      0.86        23
#      neutral       0.95      0.97      0.96       152
#     positive       0.91      0.78      0.84        41
#
#     accuracy                           0.93       216
#    macro avg       0.89      0.89      0.89       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.85      0.85        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.81      0.76      0.79        17
#
#     accuracy                           0.97       216
#    macro avg       0.88      0.87      0.88       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.98      1.00      0.99       185
#     positive       1.00      0.82      0.90        17
#
#     accuracy                           0.98       216
#    macro avg       0.99      0.92      0.95       216
# weighted avg       0.98      0.98      0.98       216
#
# Launching training on 2 GPUs.
# 364 364
# Nearest checkpoint: 540
# Threshold: 88336.546875
# Samples above threshold: 39
# Acquired samples: 39
# Sampling duration: 14.913544178009033 seconds
# New train size: 517
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.2521514892578125 | ACCURACY: 0.7961 | F1 MACRO: 0.8841 | F1 MICRO: 0.8855
# EPOCH 2 | LOSS: 2.6255881786346436 | ACCURACY: 0.843 | F1 MACRO: 0.9081 | F1 MICRO: 0.9092
# EPOCH 3 | LOSS: 2.3785407543182373 | ACCURACY: 0.9256 | F1 MACRO: 0.9529 | F1 MICRO: 0.9545
# EPOCH 4 | LOSS: 2.261098623275757 | ACCURACY: 0.942 | F1 MACRO: 0.9626 | F1 MICRO: 0.964
# EPOCH 5 | LOSS: 2.154106378555298 | ACCURACY: 0.9442 | F1 MACRO: 0.963 | F1 MICRO: 0.9651
# EPOCH 6 | LOSS: 2.0206212997436523 | ACCURACY: 0.9546 | F1 MACRO: 0.9698 | F1 MICRO: 0.9716
# EPOCH 7 | LOSS: 1.9445165395736694 | ACCURACY: 0.9568 | F1 MACRO: 0.9716 | F1 MICRO: 0.9731
# EPOCH 8 | LOSS: 1.8418117761611938 | ACCURACY: 0.9598 | F1 MACRO: 0.9732 | F1 MICRO: 0.9748
# EPOCH 9 | LOSS: 1.7860398292541504 | ACCURACY: 0.9598 | F1 MACRO: 0.9734 | F1 MICRO: 0.9749
# ...
#         part       0.98      0.96      0.97       158
#        price       0.98      0.98      0.98       192
#      service       0.99      1.00      1.00       191
#
#    micro avg       0.97      0.98      0.97      1061
#    macro avg       0.97      0.97      0.97      1061
# weighted avg       0.97      0.98      0.97      1061
#  samples avg       0.97      0.97      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.6837313175201416 | ACCURACY: 0.8934 | F1 MACRO: 0.8648 | F1 MICRO: 0.8934
# EPOCH 2 | LOSS: 2.797759771347046 | ACCURACY: 0.9338 | F1 MACRO: 0.9257 | F1 MICRO: 0.9338
# EPOCH 3 | LOSS: 2.4615275859832764 | ACCURACY: 0.9338 | F1 MACRO: 0.922 | F1 MICRO: 0.9338
# EPOCH 4 | LOSS: 2.266996383666992 | ACCURACY: 0.9449 | F1 MACRO: 0.9372 | F1 MICRO: 0.9449
# EPOCH 5 | LOSS: 2.2030296325683594 | ACCURACY: 0.9375 | F1 MACRO: 0.9296 | F1 MICRO: 0.9375
# EPOCH 6 | LOSS: 2.108708143234253 | ACCURACY: 0.9412 | F1 MACRO: 0.9336 | F1 MICRO: 0.9412
# EPOCH 7 | LOSS: 2.0722546577453613 | ACCURACY: 0.9559 | F1 MACRO: 0.949 | F1 MICRO: 0.9559
# EPOCH 8 | LOSS: 2.048215389251709 | ACCURACY: 0.9191 | F1 MACRO: 0.9097 | F1 MICRO: 0.9191
# EPOCH 9 | LOSS: 2.012646198272705 | ACCURACY: 0.9412 | F1 MACRO: 0.9336 | F1 MICRO: 0.9412
# EPOCH 10 | LOSS: 1.9899535179138184 | ACCURACY: 0.9449 | F1 MACRO: 0.9364 | F1 MICRO: 0.9449
# sentiment: ACCURACY 0.9559 | F1 MACRO 0.949 | F1 MICRO 0.9559
#               precision    recall  f1-score   support
#
#     negative       0.91      0.95      0.93        84
#     positive       0.98      0.96      0.97       188
#
#     accuracy                           0.96       272
#    macro avg       0.94      0.95      0.95       272
# weighted avg       0.96      0.96      0.96       272
#
# --------------------------------------------------
# Iteration 831: Accuracy: 0.9529, F1 Micro: 0.9529, F1 Macro: 0.91
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.92      0.92      0.92        24
#
#     accuracy                           0.98       216
#    macro avg       0.97      0.94      0.95       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.88      0.90        16
#      neutral       0.97      0.98      0.97       167
#     positive       0.85      0.85      0.85        33
#
#     accuracy                           0.95       216
#    macro avg       0.92      0.90      0.91       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.62      0.83      0.71        12
#      neutral       0.94      0.90      0.92       152
#     positive       0.80      0.83      0.81        52
#
#     accuracy                           0.88       216
#    macro avg       0.79      0.85      0.82       216
# weighted avg       0.89      0.88      0.88       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.82      1.00      0.90        23
#      neutral       0.98      0.97      0.97       152
#     positive       0.92      0.85      0.89        41
#
#     accuracy                           0.95       216
#    macro avg       0.91      0.94      0.92       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.73      0.85      0.79        13
#      neutral       0.99      0.98      0.98       186
#     positive       0.88      0.88      0.88        17
#
#     accuracy                           0.96       216
#    macro avg       0.87      0.90      0.88       216
# weighted avg       0.97      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.93      1.00      0.97        14
#      neutral       1.00      1.00      1.00       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           1.00       216
#    macro avg       0.98      0.98      0.98       216
# weighted avg       1.00      1.00      1.00       216
#
# Launching training on 2 GPUs.
# 32 32
# Nearest checkpoint: 864
# Threshold: 88248.546875
# Samples above threshold: 4
# Acquired samples: 25
# Sampling duration: 20.39435338973999 seconds
# New train size: 856
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.933392286300659 | ACCURACY: 0.808 | F1 MACRO: 0.8855 | F1 MICRO: 0.8889
# EPOCH 2 | LOSS: 2.3354663848876953 | ACCURACY: 0.9196 | F1 MACRO: 0.948 | F1 MICRO: 0.9501
# EPOCH 3 | LOSS: 2.150827407836914 | ACCURACY: 0.9449 | F1 MACRO: 0.9646 | F1 MICRO: 0.9658
# EPOCH 4 | LOSS: 1.9843823909759521 | ACCURACY: 0.9568 | F1 MACRO: 0.9715 | F1 MICRO: 0.973
# EPOCH 5 | LOSS: 1.8584110736846924 | ACCURACY: 0.9628 | F1 MACRO: 0.9753 | F1 MICRO: 0.9766
# EPOCH 6 | LOSS: 1.7568941116333008 | ACCURACY: 0.9568 | F1 MACRO: 0.971 | F1 MICRO: 0.9728
# EPOCH 7 | LOSS: 1.6905044317245483 | ACCURACY: 0.9509 | F1 MACRO: 0.9667 | F1 MICRO: 0.969
# EPOCH 8 | LOSS: 1.6485577821731567 | ACCURACY: 0.9583 | F1 MACRO: 0.9718 | F1 MICRO: 0.9737
# in second
# EPOCH 9 | LOSS: 1.5351141691207886 | ACCURACY: 0.9531 | F1 MACRO: 0.9698 | F1 MICRO: 0.971
# in second
# EPOCH 10 | LOSS: 1.5163609981536865 | ACCURACY: 0.9591 | F1 MACRO: 0.9734 | F1 MICRO: 0.9745
# aspect: ACCURACY 0.9628 | F1 MACRO 0.9753 | F1 MICRO 0.9766
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.96      0.99      0.97       175
#       others       0.93      0.94      0.93       158
#         part       0.98      0.97      0.98       158
#        price       0.99      0.99      0.99       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.97      0.98      0.98      1061
#    macro avg       0.97      0.98      0.98      1061
# weighted avg       0.97      0.98      0.98      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.567913055419922 | ACCURACY: 0.9396 | F1 MACRO: 0.9311 | F1 MICRO: 0.9396
# EPOCH 2 | LOSS: 2.6385269165039062 | ACCURACY: 0.9321 | F1 MACRO: 0.9239 | F1 MICRO: 0.9321
# EPOCH 3 | LOSS: 2.4365344047546387 | ACCURACY: 0.9283 | F1 MACRO: 0.9127 | F1 MICRO: 0.9283
# EPOCH 4 | LOSS: 2.2541744709014893 | ACCURACY: 0.9358 | F1 MACRO: 0.9287 | F1 MICRO: 0.9358
# in second
# EPOCH 5 | LOSS: 2.016166925430298 | ACCURACY: 0.9396 | F1 MACRO: 0.9323 | F1 MICRO: 0.9396
# in second
# EPOCH 6 | LOSS: 1.9425358772277832 | ACCURACY: 0.9283 | F1 MACRO: 0.9203 | F1 MICRO: 0.9283
# in second
# EPOCH 7 | LOSS: 1.8955358266830444 | ACCURACY: 0.9283 | F1 MACRO: 0.9203 | F1 MICRO: 0.9283
# in second
# sentiment: ACCURACY 0.9396 | F1 MACRO 0.9311 | F1 MICRO 0.9396
#               precision    recall  f1-score   support
#
#     negative       0.88      0.94      0.91        83
#     positive       0.97      0.94      0.96       182
#
#     accuracy                           0.94       265
#    macro avg       0.92      0.94      0.93       265
# weighted avg       0.94      0.94      0.94       265
#
# --------------------------------------------------
# Iteration 856: Accuracy: 0.9437, F1 Micro: 0.9437, F1 Macro: 0.8907
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      1.00      0.99       181
#     positive       1.00      0.92      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.97      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.81      0.84        16
#      neutral       0.96      0.97      0.96       167
#     positive       0.84      0.82      0.83        33
#
#     accuracy                           0.94       216
#    macro avg       0.89      0.87      0.88       216
# weighted avg       0.93      0.94      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.47      0.75      0.58        12
#      neutral       0.93      0.90      0.91       152
#     positive       0.78      0.73      0.75        52
#
#     accuracy                           0.85       216
#    macro avg       0.72      0.79      0.75       216
# weighted avg       0.86      0.85      0.86       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.72      0.91      0.81        23
#      neutral       0.98      0.95      0.97       152
#     positive       0.90      0.85      0.88        41
#
#     accuracy                           0.93       216
#    macro avg       0.87      0.91      0.88       216
# weighted avg       0.94      0.93      0.93       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.79      0.85      0.81        13
#      neutral       0.99      0.98      0.99       186
#     positive       0.82      0.82      0.82        17
#
#     accuracy                           0.96       216
#    macro avg       0.87      0.88      0.87       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.99      1.00      0.99       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.96      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 8 8
# Nearest checkpoint: 864
# Threshold: 88272.6171875
# Samples above threshold: 1
# Acquired samples: 8
# Sampling duration: 20.65815567970276 seconds
# New train size: 864
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.944631576538086 | ACCURACY: 0.8207 | F1 MACRO: 0.896 | F1 MICRO: 0.8975
# EPOCH 2 | LOSS: 2.3285555839538574 | ACCURACY: 0.9345 | F1 MACRO: 0.9576 | F1 MICRO: 0.9594
# EPOCH 3 | LOSS: 2.1578097343444824 | ACCURACY: 0.9531 | F1 MACRO: 0.9694 | F1 MICRO: 0.9709
# EPOCH 4 | LOSS: 1.9996709823608398 | ACCURACY: 0.9591 | F1 MACRO: 0.9737 | F1 MICRO: 0.9745
# EPOCH 5 | LOSS: 1.8579329252243042 | ACCURACY: 0.9621 | F1 MACRO: 0.9749 | F1 MICRO: 0.9761
# EPOCH 6 | LOSS: 1.738457441329956 | ACCURACY: 0.9554 | F1 MACRO: 0.9699 | F1 MICRO: 0.9718
# EPOCH 7 | LOSS: 1.6792716979980469 | ACCURACY: 0.9524 | F1 MACRO: 0.9674 | F1 MICRO: 0.97
# EPOCH 8 | LOSS: 1.6421780586242676 | ACCURACY: 0.9554 | F1 MACRO: 0.9702 | F1 MICRO: 0.9719
# in second
# EPOCH 9 | LOSS: 1.5650575160980225 | ACCURACY: 0.9546 | F1 MACRO: 0.9706 | F1 MICRO: 0.9718
# in second
# EPOCH 10 | LOSS: 1.5186561346054077 | ACCURACY: 0.9613 | F1 MACRO: 0.9747 | F1 MICRO: 0.9758
# aspect: ACCURACY 0.9621 | F1 MACRO 0.9749 | F1 MICRO 0.9761
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.95      0.98      0.96       175
#       others       0.94      0.96      0.95       158
#         part       0.98      0.96      0.97       158
#        price       0.98      0.99      0.99       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.97      0.98      0.98      1061
#    macro avg       0.97      0.98      0.97      1061
# weighted avg       0.97      0.98      0.98      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.554063558578491 | ACCURACY: 0.9436 | F1 MACRO: 0.9345 | F1 MICRO: 0.9436
# EPOCH 2 | LOSS: 2.7125394344329834 | ACCURACY: 0.9436 | F1 MACRO: 0.9345 | F1 MICRO: 0.9436
# EPOCH 3 | LOSS: 2.4155609607696533 | ACCURACY: 0.9549 | F1 MACRO: 0.9481 | F1 MICRO: 0.9549
# EPOCH 4 | LOSS: 2.316171169281006 | ACCURACY: 0.9361 | F1 MACRO: 0.9272 | F1 MICRO: 0.9361
# EPOCH 5 | LOSS: 2.1790571212768555 | ACCURACY: 0.9323 | F1 MACRO: 0.9231 | F1 MICRO: 0.9323
# EPOCH 6 | LOSS: 2.0553224086761475 | ACCURACY: 0.9286 | F1 MACRO: 0.9176 | F1 MICRO: 0.9286
# in second
# EPOCH 7 | LOSS: 1.9105297327041626 | ACCURACY: 0.9511 | F1 MACRO: 0.9443 | F1 MICRO: 0.9511
# in second
# EPOCH 8 | LOSS: 1.8712353706359863 | ACCURACY: 0.9398 | F1 MACRO: 0.9321 | F1 MICRO: 0.9398
# in second
# EPOCH 9 | LOSS: 1.84971022605896 | ACCURACY: 0.9436 | F1 MACRO: 0.9361 | F1 MICRO: 0.9436
# in second
# EPOCH 10 | LOSS: 1.869681715965271 | ACCURACY: 0.9511 | F1 MACRO: 0.9443 | F1 MICRO: 0.9511
# sentiment: ACCURACY 0.9549 | F1 MACRO 0.9481 | F1 MICRO 0.9549
#               precision    recall  f1-score   support
#
#     negative       0.90      0.96      0.93        82
#     positive       0.98      0.95      0.97       184
#
#     accuracy                           0.95       266
#    macro avg       0.94      0.96      0.95       266
# weighted avg       0.96      0.95      0.96       266
#
# --------------------------------------------------
# Iteration 864: Accuracy: 0.9491, F1 Micro: 0.9491, F1 Macro: 0.9021
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      1.00      0.99       181
#     positive       1.00      0.92      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.97      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.88      0.90        16
#      neutral       0.96      0.97      0.96       167
#     positive       0.81      0.79      0.80        33
#
#     accuracy                           0.94       216
#    macro avg       0.90      0.88      0.89       216
# weighted avg       0.93      0.94      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.64      0.75      0.69        12
#      neutral       0.93      0.92      0.93       152
#     positive       0.83      0.83      0.83        52
#
#     accuracy                           0.89       216
#    macro avg       0.80      0.83      0.82       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.76      0.96      0.85        23
#      neutral       0.98      0.95      0.97       152
#     positive       0.87      0.83      0.85        41
#
#     accuracy                           0.93       216
#    macro avg       0.87      0.91      0.89       216
# weighted avg       0.94      0.93      0.93       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.73      0.85      0.79        13
#      neutral       0.98      0.98      0.98       186
#     positive       0.87      0.76      0.81        17
#
#     accuracy                           0.96       216
#    macro avg       0.86      0.86      0.86       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.99      1.00      0.99       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.96      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Total sampling time: 368.69 seconds
# Total runtime: 2879.9946887493134 seconds

# %% [markdown]
# ## RUN 3

# %%
active_learning(seeds[2], 2)
# Out:
# ===============================================
# TRIAL 3
# Random seed: 14
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.5870654582977295 | ACCURACY: 0.7448 | F1 MACRO: 0.8463 | F1 MICRO: 0.8498
# EPOCH 2 | LOSS: 3.536916494369507 | ACCURACY: 0.7812 | F1 MACRO: 0.8738 | F1 MICRO: 0.8763
# EPOCH 3 | LOSS: 3.41666316986084 | ACCURACY: 0.7857 | F1 MACRO: 0.8774 | F1 MICRO: 0.8795
# EPOCH 4 | LOSS: 3.3116543292999268 | ACCURACY: 0.7879 | F1 MACRO: 0.8792 | F1 MICRO: 0.881
# EPOCH 5 | LOSS: 3.2140653133392334 | ACCURACY: 0.7894 | F1 MACRO: 0.8788 | F1 MICRO: 0.881
# EPOCH 6 | LOSS: 3.2702386379241943 | ACCURACY: 0.7902 | F1 MACRO: 0.878 | F1 MICRO: 0.8806
# EPOCH 7 | LOSS: 3.0499675273895264 | ACCURACY: 0.7887 | F1 MACRO: 0.8742 | F1 MICRO: 0.8783
# EPOCH 8 | LOSS: 3.18894100189209 | ACCURACY: 0.7783 | F1 MACRO: 0.8648 | F1 MICRO: 0.8711
# in second
# EPOCH 9 | LOSS: 3.1297123432159424 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# in second
# EPOCH 10 | LOSS: 3.0261359214782715 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# aspect: ACCURACY 0.7894 | F1 MACRO 0.8788 | F1 MICRO 0.881
#               precision    recall  f1-score   support
#
#         fuel       0.83      1.00      0.91       187
#      machine       0.78      1.00      0.88       175
#       others       0.71      0.93      0.80       158
#         part       0.73      0.99      0.84       158
#        price       0.86      1.00      0.92       192
#      service       0.85      1.00      0.92       191
#
#    micro avg       0.80      0.99      0.88      1061
#    macro avg       0.79      0.99      0.88      1061
# weighted avg       0.80      0.99      0.88      1061
#  samples avg       0.80      0.99      0.88      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.530926704406738 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# EPOCH 2 | LOSS: 5.93828010559082 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# EPOCH 3 | LOSS: 5.120326995849609 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# EPOCH 4 | LOSS: 4.854779243469238 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# EPOCH 5 | LOSS: 4.772058963775635 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# EPOCH 6 | LOSS: 4.72989559173584 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# EPOCH 7 | LOSS: 4.586083889007568 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# EPOCH 8 | LOSS: 4.799030303955078 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# EPOCH 9 | LOSS: 4.7115044593811035 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# EPOCH 10 | LOSS: 5.037998676300049 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# sentiment: ACCURACY 0.95 | F1 MACRO 0.4872 | F1 MICRO 0.95
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00         1
#     positive       0.95      1.00      0.97        19
#
#     accuracy                           0.95        20
#    macro avg       0.47      0.50      0.49        20
# weighted avg       0.90      0.95      0.93        20
#
# --------------------------------------------------
# Iteration 54: Accuracy: 0.7901, F1 Micro: 0.7901, F1 Macro: 0.3208
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        11
#      neutral       0.84      1.00      0.91       181
#     positive       0.00      0.00      0.00        24
#
#     accuracy                           0.84       216
#    macro avg       0.28      0.33      0.30       216
# weighted avg       0.70      0.84      0.76       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        16
#      neutral       0.77      1.00      0.87       167
#     positive       0.00      0.00      0.00        33
#
#     accuracy                           0.77       216
#    macro avg       0.26      0.33      0.29       216
# weighted avg       0.60      0.77      0.67       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        12
#      neutral       0.70      0.93      0.80       152
#     positive       0.31      0.08      0.12        52
#
#     accuracy                           0.67       216
#    macro avg       0.34      0.33      0.31       216
# weighted avg       0.57      0.67      0.59       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.50      0.04      0.08        23
#      neutral       0.73      1.00      0.85       152
#     positive       1.00      0.17      0.29        41
#
#     accuracy                           0.74       216
#    macro avg       0.74      0.40      0.41       216
# weighted avg       0.76      0.74      0.66       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        13
#      neutral       0.86      1.00      0.93       186
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.86       216
#    macro avg       0.29      0.33      0.31       216
# weighted avg       0.74      0.86      0.80       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        14
#      neutral       0.86      1.00      0.92       185
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.86       216
#    macro avg       0.29      0.33      0.31       216
# weighted avg       0.73      0.86      0.79       216
#
# Launching training on 2 GPUs.
# 91 91
# Nearest checkpoint: 540
# Threshold: 87312.4140625
# Samples above threshold: 81
# Acquired samples: 81
# Sampling duration: 5.916515827178955 seconds
# New train size: 135
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.6697964668273926 | ACCURACY: 0.7887 | F1 MACRO: 0.8797 | F1 MICRO: 0.8814
# EPOCH 2 | LOSS: 3.4848086833953857 | ACCURACY: 0.7969 | F1 MACRO: 0.8835 | F1 MICRO: 0.8853
# EPOCH 3 | LOSS: 3.369410276412964 | ACCURACY: 0.8095 | F1 MACRO: 0.8907 | F1 MICRO: 0.8921
# EPOCH 4 | LOSS: 3.111637830734253 | ACCURACY: 0.8132 | F1 MACRO: 0.8915 | F1 MICRO: 0.8932
# EPOCH 5 | LOSS: 2.990294933319092 | ACCURACY: 0.8266 | F1 MACRO: 0.8958 | F1 MICRO: 0.8983
# EPOCH 6 | LOSS: 2.8174850940704346 | ACCURACY: 0.8356 | F1 MACRO: 0.9002 | F1 MICRO: 0.9028
# EPOCH 7 | LOSS: 2.8742849826812744 | ACCURACY: 0.8438 | F1 MACRO: 0.906 | F1 MICRO: 0.9081
# EPOCH 8 | LOSS: 2.763920545578003 | ACCURACY: 0.8646 | F1 MACRO: 0.9162 | F1 MICRO: 0.9186
# EPOCH 9 | LOSS: 2.733013391494751 | ACCURACY: 0.8765 | F1 MACRO: 0.9226 | F1 MICRO: 0.9248
# EPOCH 10 | LOSS: 2.626643657684326 | ACCURACY: 0.8817 | F1 MACRO: 0.9256 | F1 MICRO: 0.928
# aspect: ACCURACY 0.8817 | F1 MACRO 0.9256 | F1 MICRO 0.928
#               precision    recall  f1-score   support
#
#         fuel       0.90      1.00      0.95       187
#      machine       0.81      0.97      0.88       175
#       others       0.86      0.86      0.86       158
#         part       0.91      0.95      0.93       158
#        price       0.95      0.99      0.97       192
#      service       0.92      1.00      0.96       191
#
#    micro avg       0.89      0.97      0.93      1061
#    macro avg       0.89      0.96      0.93      1061
# weighted avg       0.90      0.97      0.93      1061
#  samples avg       0.90      0.96      0.92      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 17.210556030273438 | ACCURACY: 0.8211 | F1 MACRO: 0.7562 | F1 MICRO: 0.8211
# EPOCH 2 | LOSS: 13.293437004089355 | ACCURACY: 0.9211 | F1 MACRO: 0.9024 | F1 MICRO: 0.9211
# EPOCH 3 | LOSS: 12.148900032043457 | ACCURACY: 0.9316 | F1 MACRO: 0.9154 | F1 MICRO: 0.9316
# EPOCH 4 | LOSS: 10.71435832977295 | ACCURACY: 0.9316 | F1 MACRO: 0.9134 | F1 MICRO: 0.9316
# EPOCH 5 | LOSS: 10.264034271240234 | ACCURACY: 0.9474 | F1 MACRO: 0.933 | F1 MICRO: 0.9474
# EPOCH 6 | LOSS: 9.683287620544434 | ACCURACY: 0.9474 | F1 MACRO: 0.9312 | F1 MICRO: 0.9474
# EPOCH 7 | LOSS: 9.034947395324707 | ACCURACY: 0.9211 | F1 MACRO: 0.8947 | F1 MICRO: 0.9211
# EPOCH 8 | LOSS: 8.98149585723877 | ACCURACY: 0.9158 | F1 MACRO: 0.8976 | F1 MICRO: 0.9158
# EPOCH 9 | LOSS: 9.00963306427002 | ACCURACY: 0.9211 | F1 MACRO: 0.8989 | F1 MICRO: 0.9211
# in second
# EPOCH 10 | LOSS: 8.321233749389648 | ACCURACY: 0.9211 | F1 MACRO: 0.8989 | F1 MICRO: 0.9211
# sentiment: ACCURACY 0.9474 | F1 MACRO 0.9312 | F1 MICRO 0.9474
#               precision    recall  f1-score   support
#
#     negative       0.90      0.90      0.90        49
#     positive       0.96      0.96      0.96       141
#
#     accuracy                           0.95       190
#    macro avg       0.93      0.93      0.93       190
# weighted avg       0.95      0.95      0.95       190
#
# --------------------------------------------------
# Iteration 135: Accuracy: 0.875, F1 Micro: 0.875, F1 Macro: 0.7054
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.36      0.53        11
#      neutral       0.91      0.99      0.95       181
#     positive       0.93      0.58      0.72        24
#
#     accuracy                           0.92       216
#    macro avg       0.95      0.65      0.73       216
# weighted avg       0.92      0.92      0.90       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        16
#      neutral       0.80      0.98      0.88       167
#     positive       0.64      0.21      0.32        33
#
#     accuracy                           0.79       216
#    macro avg       0.48      0.40      0.40       216
# weighted avg       0.72      0.79      0.73       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.36      0.42      0.38        12
#      neutral       0.86      0.82      0.84       152
#     positive       0.62      0.69      0.65        52
#
#     accuracy                           0.76       216
#    macro avg       0.61      0.64      0.63       216
# weighted avg       0.78      0.76      0.77       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.70      0.83      0.76        23
#      neutral       0.92      0.94      0.93       152
#     positive       0.91      0.73      0.81        41
#
#     accuracy                           0.89       216
#    macro avg       0.84      0.83      0.83       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.62      0.76        13
#      neutral       0.96      0.99      0.98       186
#     positive       0.87      0.76      0.81        17
#
#     accuracy                           0.95       216
#    macro avg       0.94      0.79      0.85       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.64      0.78        14
#      neutral       0.93      1.00      0.97       185
#     positive       0.89      0.47      0.62        17
#
#     accuracy                           0.94       216
#    macro avg       0.94      0.70      0.79       216
# weighted avg       0.94      0.94      0.93       216
#
# Launching training on 2 GPUs.
# 590 590
# Nearest checkpoint: 540
# Threshold: 88191.703125
# Samples above threshold: 73
# Acquired samples: 73
# Sampling duration: 9.189464092254639 seconds
# New train size: 208
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.6963582038879395 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# EPOCH 2 | LOSS: 3.267072916030884 | ACCURACY: 0.8065 | F1 MACRO: 0.8881 | F1 MICRO: 0.8899
# EPOCH 3 | LOSS: 3.0283565521240234 | ACCURACY: 0.8013 | F1 MACRO: 0.8863 | F1 MICRO: 0.8879
# EPOCH 4 | LOSS: 2.8066351413726807 | ACCURACY: 0.8304 | F1 MACRO: 0.9006 | F1 MICRO: 0.9021
# EPOCH 5 | LOSS: 2.6329610347747803 | ACCURACY: 0.8497 | F1 MACRO: 0.9094 | F1 MICRO: 0.9114
# EPOCH 6 | LOSS: 2.796938896179199 | ACCURACY: 0.8765 | F1 MACRO: 0.9249 | F1 MICRO: 0.9262
# EPOCH 7 | LOSS: 2.76985239982605 | ACCURACY: 0.9077 | F1 MACRO: 0.9416 | F1 MICRO: 0.9434
# EPOCH 8 | LOSS: 2.5500588417053223 | ACCURACY: 0.9092 | F1 MACRO: 0.9427 | F1 MICRO: 0.9445
# EPOCH 9 | LOSS: 2.4954373836517334 | ACCURACY: 0.9211 | F1 MACRO: 0.9491 | F1 MICRO: 0.9511
# EPOCH 10 | LOSS: 2.293637990951538 | ACCURACY: 0.9315 | F1 MACRO: 0.9559 | F1 MICRO: 0.9576
# aspect: ACCURACY 0.9315 | F1 MACRO 0.9559 | F1 MICRO 0.9576
#               precision    recall  f1-score   support
#
#         fuel       0.97      1.00      0.98       187
#      machine       0.93      0.95      0.94       175
#       others       0.87      0.94      0.91       158
#         part       0.92      0.98      0.95       158
#        price       0.97      1.00      0.98       192
#      service       0.95      1.00      0.97       191
#
#    micro avg       0.94      0.98      0.96      1061
#    macro avg       0.93      0.98      0.96      1061
# weighted avg       0.94      0.98      0.96      1061
#  samples avg       0.94      0.98      0.95      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 13.442768096923828 | ACCURACY: 0.9052 | F1 MACRO: 0.8875 | F1 MICRO: 0.9052
# EPOCH 2 | LOSS: 10.008557319641113 | ACCURACY: 0.944 | F1 MACRO: 0.9362 | F1 MICRO: 0.944
# EPOCH 3 | LOSS: 9.0840425491333 | ACCURACY: 0.9526 | F1 MACRO: 0.9456 | F1 MICRO: 0.9526
# EPOCH 4 | LOSS: 8.248456954956055 | ACCURACY: 0.9483 | F1 MACRO: 0.9409 | F1 MICRO: 0.9483
# EPOCH 5 | LOSS: 7.783860206604004 | ACCURACY: 0.944 | F1 MACRO: 0.9366 | F1 MICRO: 0.944
# EPOCH 6 | LOSS: 7.580656051635742 | ACCURACY: 0.931 | F1 MACRO: 0.9222 | F1 MICRO: 0.931
# in second
# EPOCH 7 | LOSS: 6.937015533447266 | ACCURACY: 0.944 | F1 MACRO: 0.937 | F1 MICRO: 0.944
# in second
# EPOCH 8 | LOSS: 6.6851091384887695 | ACCURACY: 0.944 | F1 MACRO: 0.937 | F1 MICRO: 0.944
# in second
# EPOCH 9 | LOSS: 6.630168914794922 | ACCURACY: 0.944 | F1 MACRO: 0.937 | F1 MICRO: 0.944
# in second
# EPOCH 10 | LOSS: 6.512187480926514 | ACCURACY: 0.944 | F1 MACRO: 0.937 | F1 MICRO: 0.944
# sentiment: ACCURACY 0.9526 | F1 MACRO 0.9456 | F1 MICRO 0.9526
#               precision    recall  f1-score   support
#
#     negative       0.91      0.95      0.93        73
#     positive       0.97      0.96      0.97       159
#
#     accuracy                           0.95       232
#    macro avg       0.94      0.95      0.95       232
# weighted avg       0.95      0.95      0.95       232
#
# --------------------------------------------------
# Iteration 208: Accuracy: 0.9329, F1 Micro: 0.9329, F1 Macro: 0.8737
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.98      1.00      0.99       181
#     positive       1.00      0.88      0.93        24
#
#     accuracy                           0.98       216
#    macro avg       0.99      0.93      0.96       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.77      0.62      0.69        16
#      neutral       0.93      0.96      0.94       167
#     positive       0.83      0.73      0.77        33
#
#     accuracy                           0.90       216
#    macro avg       0.84      0.77      0.80       216
# weighted avg       0.90      0.90      0.90       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.77      0.83      0.80        12
#      neutral       0.90      0.93      0.92       152
#     positive       0.77      0.69      0.73        52
#
#     accuracy                           0.87       216
#    macro avg       0.81      0.82      0.81       216
# weighted avg       0.86      0.87      0.86       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.84      0.91      0.87        23
#      neutral       0.92      0.97      0.94       152
#     positive       0.97      0.73      0.83        41
#
#     accuracy                           0.92       216
#    macro avg       0.91      0.87      0.88       216
# weighted avg       0.92      0.92      0.91       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.90      0.69      0.78        13
#      neutral       0.96      0.99      0.98       186
#     positive       0.86      0.71      0.77        17
#
#     accuracy                           0.95       216
#    macro avg       0.91      0.80      0.85       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        14
#      neutral       0.97      1.00      0.99       185
#     positive       1.00      0.71      0.83        17
#
#     accuracy                           0.98       216
#    macro avg       0.99      0.90      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Launching training on 2 GPUs.
# 602 602
# Nearest checkpoint: 540
# Threshold: 88614.6875
# Samples above threshold: 66
# Acquired samples: 66
# Sampling duration: 10.700231552124023 seconds
# New train size: 274
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.275190591812134 | ACCURACY: 0.7865 | F1 MACRO: 0.8765 | F1 MICRO: 0.8792
# EPOCH 2 | LOSS: 3.0027804374694824 | ACCURACY: 0.7902 | F1 MACRO: 0.8812 | F1 MICRO: 0.8827
# EPOCH 3 | LOSS: 2.6545917987823486 | ACCURACY: 0.8229 | F1 MACRO: 0.895 | F1 MICRO: 0.8973
# EPOCH 4 | LOSS: 2.546851396560669 | ACCURACY: 0.8638 | F1 MACRO: 0.9183 | F1 MICRO: 0.9196
# EPOCH 5 | LOSS: 2.597867727279663 | ACCURACY: 0.8884 | F1 MACRO: 0.9319 | F1 MICRO: 0.933
# EPOCH 6 | LOSS: 2.400848627090454 | ACCURACY: 0.904 | F1 MACRO: 0.938 | F1 MICRO: 0.9407
# EPOCH 7 | LOSS: 2.330495595932007 | ACCURACY: 0.9263 | F1 MACRO: 0.9518 | F1 MICRO: 0.9542
# EPOCH 8 | LOSS: 2.219620704650879 | ACCURACY: 0.9375 | F1 MACRO: 0.96 | F1 MICRO: 0.9614
# EPOCH 9 | LOSS: 2.0509462356567383 | ACCURACY: 0.9308 | F1 MACRO: 0.9543 | F1 MICRO: 0.9568
# EPOCH 10 | LOSS: 1.980665683746338 | ACCURACY: 0.9375 | F1 MACRO: 0.9583 | F1 MICRO: 0.9606
# aspect: ACCURACY 0.9375 | F1 MACRO 0.96 | F1 MICRO 0.9614
#               precision    recall  f1-score   support
#
#         fuel       0.97      1.00      0.99       187
#      machine       0.90      0.98      0.93       175
#       others       0.87      0.97      0.92       158
#         part       0.94      0.97      0.95       158
#        price       0.98      0.99      0.99       192
#      service       0.96      1.00      0.98       191
#
#    micro avg       0.94      0.99      0.96      1061
#    macro avg       0.94      0.98      0.96      1061
# weighted avg       0.94      0.99      0.96      1061
#  samples avg       0.94      0.99      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 9.738598823547363 | ACCURACY: 0.8889 | F1 MACRO: 0.8758 | F1 MICRO: 0.8889
# EPOCH 2 | LOSS: 7.379518508911133 | ACCURACY: 0.8846 | F1 MACRO: 0.8762 | F1 MICRO: 0.8846
# EPOCH 3 | LOSS: 6.467592239379883 | ACCURACY: 0.9231 | F1 MACRO: 0.9145 | F1 MICRO: 0.9231
# EPOCH 4 | LOSS: 6.075936794281006 | ACCURACY: 0.9188 | F1 MACRO: 0.9065 | F1 MICRO: 0.9188
# EPOCH 5 | LOSS: 5.662049770355225 | ACCURACY: 0.9231 | F1 MACRO: 0.915 | F1 MICRO: 0.9231
# EPOCH 6 | LOSS: 5.449137210845947 | ACCURACY: 0.8974 | F1 MACRO: 0.8814 | F1 MICRO: 0.8974
# EPOCH 7 | LOSS: 5.326316833496094 | ACCURACY: 0.9017 | F1 MACRO: 0.8929 | F1 MICRO: 0.9017
# EPOCH 8 | LOSS: 5.062737941741943 | ACCURACY: 0.8974 | F1 MACRO: 0.8831 | F1 MICRO: 0.8974
# in second
# EPOCH 9 | LOSS: 4.834991455078125 | ACCURACY: 0.9231 | F1 MACRO: 0.9135 | F1 MICRO: 0.9231
# in second
# EPOCH 10 | LOSS: 4.6776604652404785 | ACCURACY: 0.9188 | F1 MACRO: 0.9089 | F1 MICRO: 0.9188
# sentiment: ACCURACY 0.9231 | F1 MACRO 0.915 | F1 MICRO 0.9231
#               precision    recall  f1-score   support
#
#     negative       0.83      0.96      0.89        75
#     positive       0.98      0.91      0.94       159
#
#     accuracy                           0.92       234
#    macro avg       0.90      0.93      0.92       234
# weighted avg       0.93      0.92      0.92       234
#
# --------------------------------------------------
# Iteration 274: Accuracy: 0.9275, F1 Micro: 0.9275, F1 Macro: 0.8496
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.91      0.91        11
#      neutral       0.98      1.00      0.99       181
#     positive       1.00      0.88      0.93        24
#
#     accuracy                           0.98       216
#    macro avg       0.96      0.93      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.65      0.69      0.67        16
#      neutral       0.92      0.98      0.95       167
#     positive       0.86      0.58      0.69        33
#
#     accuracy                           0.89       216
#    macro avg       0.81      0.75      0.77       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.75      0.75        12
#      neutral       0.89      0.98      0.93       152
#     positive       0.92      0.63      0.75        52
#
#     accuracy                           0.88       216
#    macro avg       0.85      0.79      0.81       216
# weighted avg       0.89      0.88      0.88       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.62      0.91      0.74        23
#      neutral       0.94      0.93      0.93       152
#     positive       0.91      0.71      0.79        41
#
#     accuracy                           0.88       216
#    macro avg       0.82      0.85      0.82       216
# weighted avg       0.90      0.88      0.89       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.71      0.77      0.74        13
#      neutral       0.98      0.98      0.98       186
#     positive       0.81      0.76      0.79        17
#
#     accuracy                           0.95       216
#    macro avg       0.84      0.84      0.84       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.93      0.90        14
#      neutral       0.98      0.99      0.99       185
#     positive       1.00      0.76      0.87        17
#
#     accuracy                           0.97       216
#    macro avg       0.95      0.90      0.92       216
# weighted avg       0.97      0.97      0.97       216
#
# Launching training on 2 GPUs.
# 552 552
# Nearest checkpoint: 540
# Threshold: 88616.015625
# Samples above threshold: 59
# Acquired samples: 59
# Sampling duration: 11.649663209915161 seconds
# New train size: 333
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.505143404006958 | ACCURACY: 0.7954 | F1 MACRO: 0.8838 | F1 MICRO: 0.8853
# EPOCH 2 | LOSS: 3.035684823989868 | ACCURACY: 0.7961 | F1 MACRO: 0.8836 | F1 MICRO: 0.8853
# EPOCH 3 | LOSS: 2.6838889122009277 | ACCURACY: 0.8557 | F1 MACRO: 0.914 | F1 MICRO: 0.9152
# EPOCH 4 | LOSS: 2.632843494415283 | ACCURACY: 0.8936 | F1 MACRO: 0.9344 | F1 MICRO: 0.936
# EPOCH 5 | LOSS: 2.5441296100616455 | ACCURACY: 0.9219 | F1 MACRO: 0.9496 | F1 MICRO: 0.9518
# EPOCH 6 | LOSS: 2.4404296875 | ACCURACY: 0.9249 | F1 MACRO: 0.9499 | F1 MICRO: 0.953
# EPOCH 7 | LOSS: 2.2589738368988037 | ACCURACY: 0.9412 | F1 MACRO: 0.9621 | F1 MICRO: 0.9636
# EPOCH 8 | LOSS: 2.1342649459838867 | ACCURACY: 0.9405 | F1 MACRO: 0.9605 | F1 MICRO: 0.9625
# EPOCH 9 | LOSS: 2.0276057720184326 | ACCURACY: 0.9353 | F1 MACRO: 0.9565 | F1 MICRO: 0.9593
# EPOCH 10 | LOSS: 1.9438000917434692 | ACCURACY: 0.942 | F1 MACRO: 0.9622 | F1 MICRO: 0.9637
# aspect: ACCURACY 0.942 | F1 MACRO 0.9622 | F1 MICRO 0.9637
#               precision    recall  f1-score   support
#
#         fuel       0.97      0.99      0.98       187
#      machine       0.92      0.97      0.95       175
#       others       0.91      0.93      0.92       158
#         part       0.94      0.97      0.96       158
#        price       0.98      0.98      0.98       192
#      service       0.96      1.00      0.98       191
#
#    micro avg       0.95      0.98      0.96      1061
#    macro avg       0.95      0.98      0.96      1061
# weighted avg       0.95      0.98      0.96      1061
#  samples avg       0.95      0.97      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 8.683034896850586 | ACCURACY: 0.834 | F1 MACRO: 0.7826 | F1 MICRO: 0.834
# EPOCH 2 | LOSS: 6.695116996765137 | ACCURACY: 0.9407 | F1 MACRO: 0.9292 | F1 MICRO: 0.9407
# EPOCH 3 | LOSS: 5.943206787109375 | ACCURACY: 0.9407 | F1 MACRO: 0.9302 | F1 MICRO: 0.9407
# EPOCH 4 | LOSS: 5.4180006980896 | ACCURACY: 0.9407 | F1 MACRO: 0.9275 | F1 MICRO: 0.9407
# EPOCH 5 | LOSS: 5.186529636383057 | ACCURACY: 0.9368 | F1 MACRO: 0.9248 | F1 MICRO: 0.9368
# EPOCH 6 | LOSS: 5.029058456420898 | ACCURACY: 0.9368 | F1 MACRO: 0.9283 | F1 MICRO: 0.9368
# EPOCH 7 | LOSS: 4.786604404449463 | ACCURACY: 0.9407 | F1 MACRO: 0.9302 | F1 MICRO: 0.9407
# EPOCH 8 | LOSS: 4.772904872894287 | ACCURACY: 0.913 | F1 MACRO: 0.9008 | F1 MICRO: 0.913
# EPOCH 9 | LOSS: 4.544409275054932 | ACCURACY: 0.9368 | F1 MACRO: 0.9283 | F1 MICRO: 0.9368
# EPOCH 10 | LOSS: 4.589375019073486 | ACCURACY: 0.9209 | F1 MACRO: 0.908 | F1 MICRO: 0.9209
# sentiment: ACCURACY 0.9407 | F1 MACRO 0.9302 | F1 MICRO 0.9407
#               precision    recall  f1-score   support
#
#     negative       0.90      0.91      0.90        77
#     positive       0.96      0.95      0.96       176
#
#     accuracy                           0.94       253
#    macro avg       0.93      0.93      0.93       253
# weighted avg       0.94      0.94      0.94       253
#
# --------------------------------------------------
# Iteration 333: Accuracy: 0.936, F1 Micro: 0.936, F1 Macro: 0.8706
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.82      0.90        11
#      neutral       0.98      0.99      0.99       181
#     positive       0.92      0.92      0.92        24
#
#     accuracy                           0.98       216
#    macro avg       0.97      0.91      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.73      0.69      0.71        16
#      neutral       0.94      0.98      0.96       167
#     positive       0.86      0.73      0.79        33
#
#     accuracy                           0.92       216
#    macro avg       0.84      0.80      0.82       216
# weighted avg       0.91      0.92      0.91       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.56      0.75      0.64        12
#      neutral       0.93      0.90      0.92       152
#     positive       0.77      0.79      0.78        52
#
#     accuracy                           0.87       216
#    macro avg       0.76      0.81      0.78       216
# weighted avg       0.87      0.87      0.87       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.81      0.91      0.86        23
#      neutral       0.94      0.97      0.95       152
#     positive       0.94      0.73      0.82        41
#
#     accuracy                           0.92       216
#    macro avg       0.89      0.87      0.88       216
# weighted avg       0.92      0.92      0.92       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.77      0.77      0.77        13
#      neutral       0.98      0.97      0.98       186
#     positive       0.79      0.88      0.83        17
#
#     accuracy                           0.95       216
#    macro avg       0.85      0.87      0.86       216
# weighted avg       0.96      0.95      0.95       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.98      1.00      0.99       185
#     positive       1.00      0.82      0.90        17
#
#     accuracy                           0.98       216
#    macro avg       0.99      0.92      0.95       216
# weighted avg       0.98      0.98      0.98       216
#
# Launching training on 2 GPUs.
# 508 508
# Nearest checkpoint: 540
# Threshold: 88644.5546875
# Samples above threshold: 54
# Acquired samples: 54
# Sampling duration: 12.928680419921875 seconds
# New train size: 387
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.3355700969696045 | ACCURACY: 0.7946 | F1 MACRO: 0.8815 | F1 MICRO: 0.8837
# EPOCH 2 | LOSS: 2.7663118839263916 | ACCURACY: 0.8333 | F1 MACRO: 0.9024 | F1 MICRO: 0.9036
# EPOCH 3 | LOSS: 2.563300132751465 | ACCURACY: 0.8869 | F1 MACRO: 0.9318 | F1 MICRO: 0.9326
# EPOCH 4 | LOSS: 2.494837522506714 | ACCURACY: 0.9234 | F1 MACRO: 0.9509 | F1 MICRO: 0.9526
# EPOCH 5 | LOSS: 2.384669780731201 | ACCURACY: 0.9368 | F1 MACRO: 0.9594 | F1 MICRO: 0.9607
# EPOCH 6 | LOSS: 2.2201874256134033 | ACCURACY: 0.942 | F1 MACRO: 0.9626 | F1 MICRO: 0.9641
# EPOCH 7 | LOSS: 2.0885167121887207 | ACCURACY: 0.9472 | F1 MACRO: 0.9657 | F1 MICRO: 0.9671
# EPOCH 8 | LOSS: 1.9768115282058716 | ACCURACY: 0.9345 | F1 MACRO: 0.9565 | F1 MICRO: 0.9588
# EPOCH 9 | LOSS: 1.9346145391464233 | ACCURACY: 0.9494 | F1 MACRO: 0.9669 | F1 MICRO: 0.9683
# EPOCH 10 | LOSS: 1.864969253540039 | ACCURACY: 0.9479 | F1 MACRO: 0.9653 | F1 MICRO: 0.9673
# aspect: ACCURACY 0.9494 | F1 MACRO 0.9669 | F1 MICRO 0.9683
#               precision    recall  f1-score   support
#
#         fuel       0.97      0.99      0.98       187
#      machine       0.94      0.97      0.96       175
#       others       0.91      0.94      0.92       158
#         part       0.96      0.97      0.97       158
#        price       0.98      0.99      0.98       192
#      service       0.97      1.00      0.98       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.96      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.96      0.98      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 7.540679931640625 | ACCURACY: 0.8725 | F1 MACRO: 0.8585 | F1 MICRO: 0.8725
# EPOCH 2 | LOSS: 6.269416809082031 | ACCURACY: 0.9442 | F1 MACRO: 0.9366 | F1 MICRO: 0.9442
# EPOCH 3 | LOSS: 5.2837748527526855 | ACCURACY: 0.9363 | F1 MACRO: 0.9284 | F1 MICRO: 0.9363
# EPOCH 4 | LOSS: 4.727587699890137 | ACCURACY: 0.9402 | F1 MACRO: 0.9327 | F1 MICRO: 0.9402
# EPOCH 5 | LOSS: 4.644443035125732 | ACCURACY: 0.9442 | F1 MACRO: 0.9377 | F1 MICRO: 0.9442
# EPOCH 6 | LOSS: 4.2631144523620605 | ACCURACY: 0.9283 | F1 MACRO: 0.9144 | F1 MICRO: 0.9283
# EPOCH 7 | LOSS: 4.2220563888549805 | ACCURACY: 0.9402 | F1 MACRO: 0.9323 | F1 MICRO: 0.9402
# EPOCH 8 | LOSS: 4.124966144561768 | ACCURACY: 0.9482 | F1 MACRO: 0.9389 | F1 MICRO: 0.9482
# EPOCH 9 | LOSS: 4.001114368438721 | ACCURACY: 0.9482 | F1 MACRO: 0.9413 | F1 MICRO: 0.9482
# EPOCH 10 | LOSS: 4.015653610229492 | ACCURACY: 0.9363 | F1 MACRO: 0.9251 | F1 MICRO: 0.9363
# sentiment: ACCURACY 0.9482 | F1 MACRO 0.9413 | F1 MICRO 0.9482
#               precision    recall  f1-score   support
#
#     negative       0.88      0.96      0.92        79
#     positive       0.98      0.94      0.96       172
#
#     accuracy                           0.95       251
#    macro avg       0.93      0.95      0.94       251
# weighted avg       0.95      0.95      0.95       251
#
# --------------------------------------------------
# Iteration 387: Accuracy: 0.9383, F1 Micro: 0.9383, F1 Macro: 0.876
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.82      0.90        11
#      neutral       0.98      0.99      0.99       181
#     positive       0.92      0.92      0.92        24
#
#     accuracy                           0.98       216
#    macro avg       0.97      0.91      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.75      0.77        16
#      neutral       0.94      0.96      0.95       167
#     positive       0.80      0.73      0.76        33
#
#     accuracy                           0.91       216
#    macro avg       0.85      0.81      0.83       216
# weighted avg       0.91      0.91      0.91       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.64      0.75      0.69        12
#      neutral       0.92      0.93      0.92       152
#     positive       0.81      0.75      0.78        52
#
#     accuracy                           0.88       216
#    macro avg       0.79      0.81      0.80       216
# weighted avg       0.88      0.88      0.87       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.74      1.00      0.85        23
#      neutral       0.96      0.95      0.96       152
#     positive       0.91      0.76      0.83        41
#
#     accuracy                           0.92       216
#    macro avg       0.87      0.90      0.88       216
# weighted avg       0.93      0.92      0.92       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.85      0.85        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.82      0.82      0.82        17
#
#     accuracy                           0.97       216
#    macro avg       0.89      0.89      0.89       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.93      0.93        14
#      neutral       0.98      1.00      0.99       185
#     positive       1.00      0.76      0.87        17
#
#     accuracy                           0.98       216
#    macro avg       0.97      0.90      0.93       216
# weighted avg       0.98      0.98      0.98       216
#
# Launching training on 2 GPUs.
# 464 464
# Nearest checkpoint: 540
# Threshold: 88411.1875
# Samples above threshold: 48
# Acquired samples: 48
# Sampling duration: 13.710236310958862 seconds
# New train size: 435
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.267300605773926 | ACCURACY: 0.7932 | F1 MACRO: 0.8799 | F1 MICRO: 0.8825
# EPOCH 2 | LOSS: 2.6901278495788574 | ACCURACY: 0.8445 | F1 MACRO: 0.907 | F1 MICRO: 0.9081
# EPOCH 3 | LOSS: 2.570213794708252 | ACCURACY: 0.8891 | F1 MACRO: 0.932 | F1 MICRO: 0.9332
# EPOCH 4 | LOSS: 2.411923408508301 | ACCURACY: 0.939 | F1 MACRO: 0.9603 | F1 MICRO: 0.962
# EPOCH 5 | LOSS: 2.2205233573913574 | ACCURACY: 0.9397 | F1 MACRO: 0.9609 | F1 MICRO: 0.9625
# EPOCH 6 | LOSS: 2.0798871517181396 | ACCURACY: 0.9457 | F1 MACRO: 0.9645 | F1 MICRO: 0.9661
# EPOCH 7 | LOSS: 1.9467601776123047 | ACCURACY: 0.9487 | F1 MACRO: 0.966 | F1 MICRO: 0.9679
# EPOCH 8 | LOSS: 1.86310613155365 | ACCURACY: 0.9487 | F1 MACRO: 0.9654 | F1 MICRO: 0.9676
# EPOCH 9 | LOSS: 1.8155064582824707 | ACCURACY: 0.9375 | F1 MACRO: 0.9556 | F1 MICRO: 0.9601
# EPOCH 10 | LOSS: 1.7964317798614502 | ACCURACY: 0.9435 | F1 MACRO: 0.9617 | F1 MICRO: 0.9643
# aspect: ACCURACY 0.9487 | F1 MACRO 0.966 | F1 MICRO 0.9679
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.94      0.97      0.95       175
#       others       0.91      0.92      0.91       158
#         part       0.94      0.99      0.96       158
#        price       0.98      1.00      0.99       192
#      service       0.97      1.00      0.98       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.95      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.96      0.98      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 7.017718315124512 | ACCURACY: 0.9261 | F1 MACRO: 0.9152 | F1 MICRO: 0.9261
# EPOCH 2 | LOSS: 5.207727909088135 | ACCURACY: 0.9572 | F1 MACRO: 0.9509 | F1 MICRO: 0.9572
# EPOCH 3 | LOSS: 4.595009803771973 | ACCURACY: 0.9611 | F1 MACRO: 0.9555 | F1 MICRO: 0.9611
# EPOCH 4 | LOSS: 4.4439873695373535 | ACCURACY: 0.9455 | F1 MACRO: 0.9388 | F1 MICRO: 0.9455
# EPOCH 5 | LOSS: 4.054873466491699 | ACCURACY: 0.93 | F1 MACRO: 0.9183 | F1 MICRO: 0.93
# EPOCH 6 | LOSS: 3.8950366973876953 | ACCURACY: 0.9494 | F1 MACRO: 0.9427 | F1 MICRO: 0.9494
# in second
# EPOCH 7 | LOSS: 3.6228766441345215 | ACCURACY: 0.9494 | F1 MACRO: 0.9427 | F1 MICRO: 0.9494
# in second
# EPOCH 8 | LOSS: 3.55303692817688 | ACCURACY: 0.9494 | F1 MACRO: 0.9427 | F1 MICRO: 0.9494
# in second
# EPOCH 9 | LOSS: 3.469606876373291 | ACCURACY: 0.9494 | F1 MACRO: 0.9427 | F1 MICRO: 0.9494
# in second
# EPOCH 10 | LOSS: 3.4152753353118896 | ACCURACY: 0.9494 | F1 MACRO: 0.9427 | F1 MICRO: 0.9494
# sentiment: ACCURACY 0.9611 | F1 MACRO 0.9555 | F1 MICRO 0.9611
#               precision    recall  f1-score   support
#
#     negative       0.92      0.96      0.94        81
#     positive       0.98      0.96      0.97       176
#
#     accuracy                           0.96       257
#    macro avg       0.95      0.96      0.96       257
# weighted avg       0.96      0.96      0.96       257
#
# --------------------------------------------------
# Iteration 435: Accuracy: 0.9429, F1 Micro: 0.9429, F1 Macro: 0.8857
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.98      1.00      0.99       181
#     positive       1.00      0.92      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       0.99      0.94      0.97       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.75      0.75        16
#      neutral       0.95      0.96      0.95       167
#     positive       0.84      0.79      0.81        33
#
#     accuracy                           0.92       216
#    macro avg       0.85      0.83      0.84       216
# weighted avg       0.92      0.92      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.53      0.75      0.62        12
#      neutral       0.94      0.89      0.92       152
#     positive       0.78      0.81      0.79        52
#
#     accuracy                           0.87       216
#    macro avg       0.75      0.82      0.78       216
# weighted avg       0.88      0.87      0.87       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.81      0.96      0.88        23
#      neutral       0.96      0.99      0.97       152
#     positive       0.91      0.73      0.81        41
#
#     accuracy                           0.94       216
#    macro avg       0.90      0.89      0.89       216
# weighted avg       0.94      0.94      0.93       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.85      0.85        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.78      0.82      0.80        17
#
#     accuracy                           0.97       216
#    macro avg       0.87      0.89      0.88       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        14
#      neutral       0.98      1.00      0.99       185
#     positive       1.00      0.82      0.90        17
#
#     accuracy                           0.99       216
#    macro avg       0.99      0.94      0.97       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 414 414
# Nearest checkpoint: 540
# Threshold: 88386.984375
# Samples above threshold: 43
# Acquired samples: 43
# Sampling duration: 14.337761163711548 seconds
# New train size: 478
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.255272388458252 | ACCURACY: 0.7946 | F1 MACRO: 0.883 | F1 MICRO: 0.8846
# EPOCH 2 | LOSS: 2.651688814163208 | ACCURACY: 0.8423 | F1 MACRO: 0.9068 | F1 MICRO: 0.9084
# EPOCH 3 | LOSS: 2.5496578216552734 | ACCURACY: 0.9062 | F1 MACRO: 0.9413 | F1 MICRO: 0.9428
# EPOCH 4 | LOSS: 2.440814733505249 | ACCURACY: 0.9219 | F1 MACRO: 0.9484 | F1 MICRO: 0.9511
# EPOCH 5 | LOSS: 2.235050678253174 | ACCURACY: 0.9435 | F1 MACRO: 0.9631 | F1 MICRO: 0.9646
# EPOCH 6 | LOSS: 2.0769970417022705 | ACCURACY: 0.942 | F1 MACRO: 0.9612 | F1 MICRO: 0.9634
# EPOCH 7 | LOSS: 1.961280345916748 | ACCURACY: 0.9487 | F1 MACRO: 0.965 | F1 MICRO: 0.9676
# EPOCH 8 | LOSS: 1.8529788255691528 | ACCURACY: 0.9509 | F1 MACRO: 0.9678 | F1 MICRO: 0.9693
# EPOCH 9 | LOSS: 1.8235243558883667 | ACCURACY: 0.9501 | F1 MACRO: 0.9675 | F1 MICRO: 0.9688
# EPOCH 10 | LOSS: 1.7492438554763794 | ACCURACY: 0.9479 | F1 MACRO: 0.9653 | F1 MICRO: 0.9672
# aspect: ACCURACY 0.9509 | F1 MACRO 0.9678 | F1 MICRO 0.9693
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.94      0.98      0.96       175
#       others       0.88      0.94      0.91       158
#         part       0.97      0.97      0.97       158
#        price       0.98      0.98      0.98       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.96      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.390935897827148 | ACCURACY: 0.8622 | F1 MACRO: 0.8218 | F1 MICRO: 0.8622
# EPOCH 2 | LOSS: 4.7662577629089355 | ACCURACY: 0.9528 | F1 MACRO: 0.9463 | F1 MICRO: 0.9528
# EPOCH 3 | LOSS: 4.203662872314453 | ACCURACY: 0.937 | F1 MACRO: 0.9289 | F1 MICRO: 0.937
# EPOCH 4 | LOSS: 3.985222101211548 | ACCURACY: 0.9449 | F1 MACRO: 0.9357 | F1 MICRO: 0.9449
# EPOCH 5 | LOSS: 3.7715723514556885 | ACCURACY: 0.9331 | F1 MACRO: 0.9216 | F1 MICRO: 0.9331
# in second
# EPOCH 6 | LOSS: 3.446547508239746 | ACCURACY: 0.9409 | F1 MACRO: 0.9322 | F1 MICRO: 0.9409
# in second
# EPOCH 7 | LOSS: 3.3156793117523193 | ACCURACY: 0.9409 | F1 MACRO: 0.9331 | F1 MICRO: 0.9409
# in second
# EPOCH 8 | LOSS: 3.28110671043396 | ACCURACY: 0.9409 | F1 MACRO: 0.9331 | F1 MICRO: 0.9409
# in second
# EPOCH 9 | LOSS: 3.24338698387146 | ACCURACY: 0.9488 | F1 MACRO: 0.9417 | F1 MICRO: 0.9488
# in second
# EPOCH 10 | LOSS: 3.199368715286255 | ACCURACY: 0.9449 | F1 MACRO: 0.937 | F1 MICRO: 0.9449
# sentiment: ACCURACY 0.9528 | F1 MACRO 0.9463 | F1 MICRO 0.9528
#               precision    recall  f1-score   support
#
#     negative       0.90      0.96      0.93        80
#     positive       0.98      0.95      0.96       174
#
#     accuracy                           0.95       254
#    macro avg       0.94      0.96      0.95       254
# weighted avg       0.95      0.95      0.95       254
#
# --------------------------------------------------
# Iteration 478: Accuracy: 0.9491, F1 Micro: 0.9491, F1 Macro: 0.8894
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.90      0.82      0.86        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.96      0.96      0.96        24
#
#     accuracy                           0.98       216
#    macro avg       0.95      0.92      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.75      0.75        16
#      neutral       0.95      0.97      0.96       167
#     positive       0.86      0.76      0.81        33
#
#     accuracy                           0.92       216
#    macro avg       0.85      0.83      0.84       216
# weighted avg       0.92      0.92      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.73      0.67      0.70        12
#      neutral       0.93      0.95      0.94       152
#     positive       0.82      0.79      0.80        52
#
#     accuracy                           0.89       216
#    macro avg       0.83      0.80      0.81       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.82      1.00      0.90        23
#      neutral       0.97      0.97      0.97       152
#     positive       0.92      0.80      0.86        41
#
#     accuracy                           0.94       216
#    macro avg       0.90      0.93      0.91       216
# weighted avg       0.95      0.94      0.94       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.85      0.85        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.88      0.88      0.88        17
#
#     accuracy                           0.97       216
#    macro avg       0.91      0.91      0.91       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.93      0.93        14
#      neutral       0.99      1.00      0.99       185
#     positive       0.93      0.82      0.87        17
#
#     accuracy                           0.98       216
#    macro avg       0.95      0.92      0.93       216
# weighted avg       0.98      0.98      0.98       216
#
# Launching training on 2 GPUs.
# 372 372
# Nearest checkpoint: 540
# Threshold: 88277.328125
# Samples above threshold: 39
# Acquired samples: 39
# Sampling duration: 15.248064279556274 seconds
# New train size: 517
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.2781152725219727 | ACCURACY: 0.8103 | F1 MACRO: 0.8903 | F1 MICRO: 0.8918
# EPOCH 2 | LOSS: 2.6840929985046387 | ACCURACY: 0.8616 | F1 MACRO: 0.9172 | F1 MICRO: 0.9181
# EPOCH 3 | LOSS: 2.5264968872070312 | ACCURACY: 0.9241 | F1 MACRO: 0.951 | F1 MICRO: 0.9531
# EPOCH 4 | LOSS: 2.378037929534912 | ACCURACY: 0.9382 | F1 MACRO: 0.9595 | F1 MICRO: 0.9613
# EPOCH 5 | LOSS: 2.1760623455047607 | ACCURACY: 0.9375 | F1 MACRO: 0.9574 | F1 MICRO: 0.9607
# EPOCH 6 | LOSS: 2.0098419189453125 | ACCURACY: 0.9516 | F1 MACRO: 0.9677 | F1 MICRO: 0.9696
# EPOCH 7 | LOSS: 1.9457756280899048 | ACCURACY: 0.9501 | F1 MACRO: 0.9677 | F1 MICRO: 0.9689
# EPOCH 8 | LOSS: 1.877286434173584 | ACCURACY: 0.9524 | F1 MACRO: 0.9682 | F1 MICRO: 0.9701
# EPOCH 9 | LOSS: 1.8328158855438232 | ACCURACY: 0.9501 | F1 MACRO: 0.9661 | F1 MICRO: 0.9685
# ...
# weighted avg       0.97      0.99      0.98      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.79402756690979 | ACCURACY: 0.8533 | F1 MACRO: 0.8123 | F1 MICRO: 0.8533
# EPOCH 2 | LOSS: 2.9902596473693848 | ACCURACY: 0.9344 | F1 MACRO: 0.9249 | F1 MICRO: 0.9344
# EPOCH 3 | LOSS: 2.5843989849090576 | ACCURACY: 0.9421 | F1 MACRO: 0.9345 | F1 MICRO: 0.9421
# EPOCH 4 | LOSS: 2.377963066101074 | ACCURACY: 0.9459 | F1 MACRO: 0.9398 | F1 MICRO: 0.9459
# EPOCH 5 | LOSS: 2.166529417037964 | ACCURACY: 0.9228 | F1 MACRO: 0.9157 | F1 MICRO: 0.9228
# EPOCH 6 | LOSS: 2.0799078941345215 | ACCURACY: 0.9344 | F1 MACRO: 0.9266 | F1 MICRO: 0.9344
# EPOCH 7 | LOSS: 2.148402452468872 | ACCURACY: 0.9151 | F1 MACRO: 0.9073 | F1 MICRO: 0.9151
# in second
# EPOCH 8 | LOSS: 1.934234380722046 | ACCURACY: 0.9228 | F1 MACRO: 0.9153 | F1 MICRO: 0.9228
# in second
# EPOCH 9 | LOSS: 1.9006094932556152 | ACCURACY: 0.9228 | F1 MACRO: 0.9153 | F1 MICRO: 0.9228
# in second
# EPOCH 10 | LOSS: 1.8651788234710693 | ACCURACY: 0.9228 | F1 MACRO: 0.9153 | F1 MICRO: 0.9228
# sentiment: ACCURACY 0.9459 | F1 MACRO 0.9398 | F1 MICRO 0.9459
#               precision    recall  f1-score   support
#
#     negative       0.89      0.95      0.92        85
#     positive       0.98      0.94      0.96       174
#
#     accuracy                           0.95       259
#    macro avg       0.93      0.95      0.94       259
# weighted avg       0.95      0.95      0.95       259
#
# --------------------------------------------------
# Iteration 831: Accuracy: 0.9552, F1 Micro: 0.9552, F1 Macro: 0.9091
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.96      0.96      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.98      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.75      0.77        16
#      neutral       0.95      0.97      0.96       167
#     positive       0.81      0.76      0.78        33
#
#     accuracy                           0.92       216
#    macro avg       0.85      0.83      0.84       216
# weighted avg       0.92      0.92      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.71      0.83      0.77        12
#      neutral       0.93      0.97      0.95       152
#     positive       0.89      0.75      0.81        52
#
#     accuracy                           0.91       216
#    macro avg       0.84      0.85      0.84       216
# weighted avg       0.91      0.91      0.91       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.91      0.82        23
#      neutral       0.98      0.98      0.98       152
#     positive       0.94      0.83      0.88        41
#
#     accuracy                           0.94       216
#    macro avg       0.89      0.91      0.90       216
# weighted avg       0.95      0.94      0.95       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.79      0.85      0.81        13
#      neutral       0.98      0.99      0.99       186
#     positive       0.93      0.82      0.87        17
#
#     accuracy                           0.97       216
#    macro avg       0.90      0.89      0.89       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        14
#      neutral       1.00      1.00      1.00       185
#     positive       1.00      1.00      1.00        17
#
#     accuracy                           1.00       216
#    macro avg       1.00      1.00      1.00       216
# weighted avg       1.00      1.00      1.00       216
#
# Launching training on 2 GPUs.
# 33 33
# Nearest checkpoint: 864
# Threshold: 88328.0546875
# Samples above threshold: 4
# Acquired samples: 25
# Sampling duration: 20.56653070449829 seconds
# New train size: 856
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.0510528087615967 | ACCURACY: 0.8393 | F1 MACRO: 0.9057 | F1 MICRO: 0.9069
# EPOCH 2 | LOSS: 2.447570323944092 | ACCURACY: 0.9308 | F1 MACRO: 0.9547 | F1 MICRO: 0.9569
# EPOCH 3 | LOSS: 2.2339894771575928 | ACCURACY: 0.9427 | F1 MACRO: 0.9613 | F1 MICRO: 0.9641
# EPOCH 4 | LOSS: 1.999160647392273 | ACCURACY: 0.9583 | F1 MACRO: 0.9728 | F1 MICRO: 0.974
# EPOCH 5 | LOSS: 1.8741642236709595 | ACCURACY: 0.9583 | F1 MACRO: 0.9716 | F1 MICRO: 0.9736
# EPOCH 6 | LOSS: 1.76870596408844 | ACCURACY: 0.965 | F1 MACRO: 0.977 | F1 MICRO: 0.978
# EPOCH 7 | LOSS: 1.7129203081130981 | ACCURACY: 0.9621 | F1 MACRO: 0.975 | F1 MICRO: 0.9762
# EPOCH 8 | LOSS: 1.6520696878433228 | ACCURACY: 0.9591 | F1 MACRO: 0.9726 | F1 MICRO: 0.9741
# EPOCH 9 | LOSS: 1.6130355596542358 | ACCURACY: 0.9613 | F1 MACRO: 0.9741 | F1 MICRO: 0.9756
# in second
# EPOCH 10 | LOSS: 1.5352147817611694 | ACCURACY: 0.9613 | F1 MACRO: 0.975 | F1 MICRO: 0.9758
# aspect: ACCURACY 0.965 | F1 MACRO 0.977 | F1 MICRO 0.978
#               precision    recall  f1-score   support
#
#         fuel       0.98      0.99      0.99       187
#      machine       0.95      0.99      0.97       175
#       others       0.91      0.97      0.94       158
#         part       0.99      0.96      0.97       158
#        price       0.99      0.99      0.99       192
#      service       0.99      1.00      0.99       191
#
#    micro avg       0.97      0.99      0.98      1061
#    macro avg       0.97      0.99      0.98      1061
# weighted avg       0.97      0.99      0.98      1061
#  samples avg       0.97      0.99      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.6875827312469482 | ACCURACY: 0.9015 | F1 MACRO: 0.8898 | F1 MICRO: 0.9015
# EPOCH 2 | LOSS: 2.7128238677978516 | ACCURACY: 0.9394 | F1 MACRO: 0.9314 | F1 MICRO: 0.9394
# EPOCH 3 | LOSS: 2.3999521732330322 | ACCURACY: 0.9205 | F1 MACRO: 0.9108 | F1 MICRO: 0.9205
# EPOCH 4 | LOSS: 2.202155351638794 | ACCURACY: 0.9242 | F1 MACRO: 0.9157 | F1 MICRO: 0.9242
# EPOCH 5 | LOSS: 2.088771343231201 | ACCURACY: 0.947 | F1 MACRO: 0.9396 | F1 MICRO: 0.947
# EPOCH 6 | LOSS: 1.9963990449905396 | ACCURACY: 0.9242 | F1 MACRO: 0.9138 | F1 MICRO: 0.9242
# EPOCH 7 | LOSS: 1.967868447303772 | ACCURACY: 0.9242 | F1 MACRO: 0.9152 | F1 MICRO: 0.9242
# EPOCH 8 | LOSS: 1.9817932844161987 | ACCURACY: 0.9242 | F1 MACRO: 0.9132 | F1 MICRO: 0.9242
# in second
# EPOCH 9 | LOSS: 1.845146894454956 | ACCURACY: 0.9205 | F1 MACRO: 0.9108 | F1 MICRO: 0.9205
# in second
# EPOCH 10 | LOSS: 1.8398457765579224 | ACCURACY: 0.9205 | F1 MACRO: 0.9108 | F1 MICRO: 0.9205
# sentiment: ACCURACY 0.947 | F1 MACRO 0.9396 | F1 MICRO 0.947
#               precision    recall  f1-score   support
#
#     negative       0.90      0.94      0.92        84
#     positive       0.97      0.95      0.96       180
#
#     accuracy                           0.95       264
#    macro avg       0.93      0.95      0.94       264
# weighted avg       0.95      0.95      0.95       264
#
# --------------------------------------------------
# Iteration 856: Accuracy: 0.9529, F1 Micro: 0.9529, F1 Macro: 0.9034
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.92      0.96      0.94        24
#
#     accuracy                           0.99       216
#    macro avg       0.97      0.95      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.75      0.80        16
#      neutral       0.96      0.98      0.97       167
#     positive       0.81      0.79      0.80        33
#
#     accuracy                           0.93       216
#    macro avg       0.88      0.84      0.86       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.75      0.75        12
#      neutral       0.94      0.95      0.94       152
#     positive       0.84      0.81      0.82        52
#
#     accuracy                           0.90       216
#    macro avg       0.84      0.84      0.84       216
# weighted avg       0.90      0.90      0.90       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.76      0.96      0.85        23
#      neutral       0.98      0.96      0.97       152
#     positive       0.89      0.83      0.86        41
#
#     accuracy                           0.94       216
#    macro avg       0.88      0.92      0.89       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.92      0.83        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.93      0.76      0.84        17
#
#     accuracy                           0.97       216
#    macro avg       0.89      0.89      0.89       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.99      1.00      1.00       185
#     positive       1.00      1.00      1.00        17
#
#     accuracy                           1.00       216
#    macro avg       1.00      0.98      0.99       216
# weighted avg       1.00      1.00      1.00       216
#
# Launching training on 2 GPUs.
# 8 8
# Nearest checkpoint: 864
# Threshold: 88283.6484375
# Samples above threshold: 1
# Acquired samples: 8
# Sampling duration: 20.526684999465942 seconds
# New train size: 864
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.959395170211792 | ACCURACY: 0.8311 | F1 MACRO: 0.9014 | F1 MICRO: 0.9028
# EPOCH 2 | LOSS: 2.460578441619873 | ACCURACY: 0.9308 | F1 MACRO: 0.9545 | F1 MICRO: 0.9568
# EPOCH 3 | LOSS: 2.221756935119629 | ACCURACY: 0.9561 | F1 MACRO: 0.9715 | F1 MICRO: 0.9727
# EPOCH 4 | LOSS: 1.9600011110305786 | ACCURACY: 0.9583 | F1 MACRO: 0.9722 | F1 MICRO: 0.9738
# EPOCH 5 | LOSS: 1.8518600463867188 | ACCURACY: 0.9591 | F1 MACRO: 0.9725 | F1 MICRO: 0.9741
# EPOCH 6 | LOSS: 1.7566109895706177 | ACCURACY: 0.9583 | F1 MACRO: 0.9718 | F1 MICRO: 0.9737
# EPOCH 7 | LOSS: 1.6952048540115356 | ACCURACY: 0.9576 | F1 MACRO: 0.9716 | F1 MICRO: 0.9733
# EPOCH 8 | LOSS: 1.6420003175735474 | ACCURACY: 0.9576 | F1 MACRO: 0.9708 | F1 MICRO: 0.9731
# in second
# EPOCH 9 | LOSS: 1.580309510231018 | ACCURACY: 0.9568 | F1 MACRO: 0.9721 | F1 MICRO: 0.9731
# in second
# EPOCH 10 | LOSS: 1.5257855653762817 | ACCURACY: 0.9583 | F1 MACRO: 0.9727 | F1 MICRO: 0.9739
# aspect: ACCURACY 0.9591 | F1 MACRO 0.9725 | F1 MICRO 0.9741
#               precision    recall  f1-score   support
#
#         fuel       0.98      0.99      0.99       187
#      machine       0.96      0.98      0.97       175
#       others       0.92      0.92      0.92       158
#         part       0.98      0.97      0.97       158
#        price       0.98      0.98      0.98       192
#      service       0.99      1.00      1.00       191
#
#    micro avg       0.97      0.98      0.97      1061
#    macro avg       0.97      0.97      0.97      1061
# weighted avg       0.97      0.98      0.97      1061
#  samples avg       0.97      0.97      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.620183229446411 | ACCURACY: 0.8926 | F1 MACRO: 0.8656 | F1 MICRO: 0.8926
# EPOCH 2 | LOSS: 2.757636785507202 | ACCURACY: 0.9222 | F1 MACRO: 0.9132 | F1 MICRO: 0.9222
# EPOCH 3 | LOSS: 2.4355785846710205 | ACCURACY: 0.9296 | F1 MACRO: 0.9202 | F1 MICRO: 0.9296
# EPOCH 4 | LOSS: 2.287003517150879 | ACCURACY: 0.9037 | F1 MACRO: 0.8939 | F1 MICRO: 0.9037
# EPOCH 5 | LOSS: 2.166252374649048 | ACCURACY: 0.9185 | F1 MACRO: 0.9093 | F1 MICRO: 0.9185
# EPOCH 6 | LOSS: 2.1204211711883545 | ACCURACY: 0.9111 | F1 MACRO: 0.8956 | F1 MICRO: 0.9111
# in second
# EPOCH 7 | LOSS: 1.9088172912597656 | ACCURACY: 0.9259 | F1 MACRO: 0.9162 | F1 MICRO: 0.9259
# in second
# EPOCH 8 | LOSS: 1.8482322692871094 | ACCURACY: 0.9259 | F1 MACRO: 0.9162 | F1 MICRO: 0.9259
# in second
# EPOCH 9 | LOSS: 1.8320152759552002 | ACCURACY: 0.9259 | F1 MACRO: 0.9162 | F1 MICRO: 0.9259
# in second
# EPOCH 10 | LOSS: 1.7962476015090942 | ACCURACY: 0.9259 | F1 MACRO: 0.9157 | F1 MICRO: 0.9259
# sentiment: ACCURACY 0.9296 | F1 MACRO 0.9202 | F1 MICRO 0.9296
#               precision    recall  f1-score   support
#
#     negative       0.85      0.94      0.89        84
#     positive       0.97      0.92      0.95       186
#
#     accuracy                           0.93       270
#    macro avg       0.91      0.93      0.92       270
# weighted avg       0.93      0.93      0.93       270
#
# --------------------------------------------------
# Iteration 864: Accuracy: 0.9468, F1 Micro: 0.9468, F1 Macro: 0.8958
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.96      0.96      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.98      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.81      0.81      0.81        16
#      neutral       0.95      0.98      0.96       167
#     positive       0.89      0.73      0.80        33
#
#     accuracy                           0.93       216
#    macro avg       0.88      0.84      0.86       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.50      0.75      0.60        12
#      neutral       0.94      0.90      0.92       152
#     positive       0.77      0.77      0.77        52
#
#     accuracy                           0.86       216
#    macro avg       0.74      0.81      0.76       216
# weighted avg       0.87      0.86      0.87       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.76      0.96      0.85        23
#      neutral       0.98      0.95      0.97       152
#     positive       0.90      0.85      0.88        41
#
#     accuracy                           0.94       216
#    macro avg       0.88      0.92      0.90       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.92      0.89        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.88      0.82      0.85        17
#
#     accuracy                           0.97       216
#    macro avg       0.91      0.91      0.91       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.99      1.00      1.00       185
#     positive       0.94      1.00      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.95      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Total sampling time: 369.09 seconds
# Total runtime: 2917.224900007248 seconds

# %% [markdown]
# ## RUN 4

# %%
active_learning(seeds[3], 3)
# Out:
# ===============================================
# TRIAL 4
# Random seed: 3
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# pytorch_model.bin:   0%|          | 0.00/498M [00:00<?, ?B/s]
# EPOCH 1 | LOSS: 3.5983240604400635 | ACCURACY: 0.7671 | F1 MACRO: 0.8506 | F1 MICRO: 0.8622
# EPOCH 2 | LOSS: 3.323089599609375 | ACCURACY: 0.779 | F1 MACRO: 0.873 | F1 MICRO: 0.8751
# EPOCH 3 | LOSS: 3.3482136726379395 | ACCURACY: 0.7805 | F1 MACRO: 0.8737 | F1 MICRO: 0.8758
# EPOCH 4 | LOSS: 3.22114634513855 | ACCURACY: 0.7842 | F1 MACRO: 0.8743 | F1 MICRO: 0.8767
# EPOCH 5 | LOSS: 3.2356982231140137 | ACCURACY: 0.779 | F1 MACRO: 0.8708 | F1 MICRO: 0.8736
# EPOCH 6 | LOSS: 2.9298696517944336 | ACCURACY: 0.7835 | F1 MACRO: 0.872 | F1 MICRO: 0.8752
# EPOCH 7 | LOSS: 2.8540592193603516 | ACCURACY: 0.7887 | F1 MACRO: 0.8732 | F1 MICRO: 0.8768
# EPOCH 8 | LOSS: 2.7723355293273926 | ACCURACY: 0.7954 | F1 MACRO: 0.8766 | F1 MICRO: 0.8801
# EPOCH 9 | LOSS: 2.754518985748291 | ACCURACY: 0.7932 | F1 MACRO: 0.8757 | F1 MICRO: 0.879
# EPOCH 10 | LOSS: 2.6405434608459473 | ACCURACY: 0.7984 | F1 MACRO: 0.8788 | F1 MICRO: 0.8817
# aspect: ACCURACY 0.7984 | F1 MACRO 0.8788 | F1 MICRO 0.8817
#               precision    recall  f1-score   support
#
#         fuel       0.84      0.98      0.90       187
#      machine       0.81      0.83      0.82       175
#       others       0.78      0.92      0.85       158
#         part       0.77      0.97      0.86       158
#        price       0.86      1.00      0.92       192
#      service       0.85      1.00      0.92       191
#
#    micro avg       0.82      0.95      0.88      1061
#    macro avg       0.82      0.95      0.88      1061
# weighted avg       0.82      0.95      0.88      1061
#  samples avg       0.82      0.95      0.88      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 20.173891067504883 | ACCURACY: 0.8151 | F1 MACRO: 0.4491 | F1 MICRO: 0.8151
# EPOCH 2 | LOSS: 16.506135940551758 | ACCURACY: 0.8151 | F1 MACRO: 0.4491 | F1 MICRO: 0.8151
# EPOCH 3 | LOSS: 14.638459205627441 | ACCURACY: 0.8403 | F1 MACRO: 0.627 | F1 MICRO: 0.8403
# EPOCH 4 | LOSS: 14.243339538574219 | ACCURACY: 0.8739 | F1 MACRO: 0.8073 | F1 MICRO: 0.8739
# EPOCH 5 | LOSS: 13.640288352966309 | ACCURACY: 0.8571 | F1 MACRO: 0.6847 | F1 MICRO: 0.8571
# EPOCH 6 | LOSS: 12.324337005615234 | ACCURACY: 0.8403 | F1 MACRO: 0.6658 | F1 MICRO: 0.8403
# EPOCH 7 | LOSS: 11.676736831665039 | ACCURACY: 0.8403 | F1 MACRO: 0.6658 | F1 MICRO: 0.8403
# in second
# EPOCH 8 | LOSS: 10.77684497833252 | ACCURACY: 0.8151 | F1 MACRO: 0.4491 | F1 MICRO: 0.8151
# in second
# EPOCH 9 | LOSS: 10.498997688293457 | ACCURACY: 0.8151 | F1 MACRO: 0.4491 | F1 MICRO: 0.8151
# in second
# EPOCH 10 | LOSS: 10.478277206420898 | ACCURACY: 0.8235 | F1 MACRO: 0.4946 | F1 MICRO: 0.8235
# sentiment: ACCURACY 0.8739 | F1 MACRO 0.8073 | F1 MICRO 0.8739
#               precision    recall  f1-score   support
#
#     negative       0.63      0.77      0.69        22
#     positive       0.95      0.90      0.92        97
#
#     accuracy                           0.87       119
#    macro avg       0.79      0.83      0.81       119
# weighted avg       0.89      0.87      0.88       119
#
# --------------------------------------------------
# Iteration 54: Accuracy: 0.7855, F1 Micro: 0.7855, F1 Macro: 0.424
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        11
#      neutral       0.84      0.97      0.90       181
#     positive       0.29      0.08      0.13        24
#
#     accuracy                           0.82       216
#    macro avg       0.38      0.35      0.34       216
# weighted avg       0.74      0.82      0.77       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.44      0.44      0.44        16
#      neutral       0.79      0.76      0.78       167
#     positive       0.15      0.18      0.16        33
#
#     accuracy                           0.65       216
#    macro avg       0.46      0.46      0.46       216
# weighted avg       0.67      0.65      0.66       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.29      0.42      0.34        12
#      neutral       0.82      0.93      0.87       152
#     positive       0.67      0.35      0.46        52
#
#     accuracy                           0.76       216
#    macro avg       0.59      0.56      0.56       216
# weighted avg       0.75      0.76      0.74       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.55      0.26      0.35        23
#      neutral       0.78      0.95      0.86       152
#     positive       0.75      0.37      0.49        41
#
#     accuracy                           0.77       216
#    macro avg       0.69      0.53      0.57       216
# weighted avg       0.75      0.77      0.74       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        13
#      neutral       0.86      1.00      0.93       186
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.86       216
#    macro avg       0.29      0.33      0.31       216
# weighted avg       0.74      0.86      0.80       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        14
#      neutral       0.86      1.00      0.92       185
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.86       216
#    macro avg       0.29      0.33      0.31       216
# weighted avg       0.73      0.86      0.79       216
#
# Launching training on 2 GPUs.
# 339 339
# Nearest checkpoint: 540
# Threshold: 87488.9765625
# Samples above threshold: 81
# Acquired samples: 81
# Sampling duration: 6.695214748382568 seconds
# New train size: 135
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.8421471118927 | ACCURACY: 0.782 | F1 MACRO: 0.8752 | F1 MICRO: 0.877
# EPOCH 2 | LOSS: 3.549126386642456 | ACCURACY: 0.7939 | F1 MACRO: 0.8803 | F1 MICRO: 0.8828
# EPOCH 3 | LOSS: 3.1811630725860596 | ACCURACY: 0.7909 | F1 MACRO: 0.8708 | F1 MICRO: 0.8776
# EPOCH 4 | LOSS: 2.9747331142425537 | ACCURACY: 0.8132 | F1 MACRO: 0.8897 | F1 MICRO: 0.892
# EPOCH 5 | LOSS: 2.8517074584960938 | ACCURACY: 0.8155 | F1 MACRO: 0.8912 | F1 MICRO: 0.8932
# EPOCH 6 | LOSS: 2.7908692359924316 | ACCURACY: 0.8229 | F1 MACRO: 0.8953 | F1 MICRO: 0.8971
# EPOCH 7 | LOSS: 2.67456316947937 | ACCURACY: 0.8318 | F1 MACRO: 0.8989 | F1 MICRO: 0.901
# EPOCH 8 | LOSS: 2.6596219539642334 | ACCURACY: 0.8415 | F1 MACRO: 0.9032 | F1 MICRO: 0.9058
# EPOCH 9 | LOSS: 2.6032493114471436 | ACCURACY: 0.8735 | F1 MACRO: 0.9213 | F1 MICRO: 0.9235
# EPOCH 10 | LOSS: 2.523472309112549 | ACCURACY: 0.8832 | F1 MACRO: 0.926 | F1 MICRO: 0.9287
# aspect: ACCURACY 0.8832 | F1 MACRO 0.926 | F1 MICRO 0.9287
#               precision    recall  f1-score   support
#
#         fuel       0.89      1.00      0.94       187
#      machine       0.89      0.95      0.92       175
#       others       0.92      0.85      0.89       158
#         part       0.83      0.97      0.89       158
#        price       0.94      0.99      0.96       192
#      service       0.91      1.00      0.95       191
#
#    micro avg       0.90      0.96      0.93      1061
#    macro avg       0.90      0.96      0.93      1061
# weighted avg       0.90      0.96      0.93      1061
#  samples avg       0.90      0.96      0.93      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 16.650903701782227 | ACCURACY: 0.8905 | F1 MACRO: 0.8728 | F1 MICRO: 0.8905
# EPOCH 2 | LOSS: 12.727397918701172 | ACCURACY: 0.9104 | F1 MACRO: 0.896 | F1 MICRO: 0.9104
# EPOCH 3 | LOSS: 11.649579048156738 | ACCURACY: 0.8905 | F1 MACRO: 0.8591 | F1 MICRO: 0.8905
# EPOCH 4 | LOSS: 11.01225757598877 | ACCURACY: 0.9055 | F1 MACRO: 0.8907 | F1 MICRO: 0.9055
# EPOCH 5 | LOSS: 10.314159393310547 | ACCURACY: 0.9055 | F1 MACRO: 0.8897 | F1 MICRO: 0.9055
# in second
# EPOCH 6 | LOSS: 9.299226760864258 | ACCURACY: 0.9104 | F1 MACRO: 0.8941 | F1 MICRO: 0.9104
# in second
# EPOCH 7 | LOSS: 8.80894947052002 | ACCURACY: 0.9005 | F1 MACRO: 0.8834 | F1 MICRO: 0.9005
# in second
# EPOCH 8 | LOSS: 9.045108795166016 | ACCURACY: 0.8955 | F1 MACRO: 0.8781 | F1 MICRO: 0.8955
# in second
# sentiment: ACCURACY 0.9104 | F1 MACRO 0.896 | F1 MICRO 0.9104
#               precision    recall  f1-score   support
#
#     negative       0.81      0.92      0.86        59
#     positive       0.96      0.91      0.93       142
#
#     accuracy                           0.91       201
#    macro avg       0.88      0.91      0.90       201
# weighted avg       0.92      0.91      0.91       201
#
# --------------------------------------------------
# Iteration 135: Accuracy: 0.8773, F1 Micro: 0.8773, F1 Macro: 0.7309
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.55      0.71        11
#      neutral       0.91      1.00      0.96       181
#     positive       1.00      0.50      0.67        24
#
#     accuracy                           0.92       216
#    macro avg       0.97      0.68      0.78       216
# weighted avg       0.93      0.92      0.91       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.69      0.69      0.69        16
#      neutral       0.90      0.95      0.93       167
#     positive       0.75      0.55      0.63        33
#
#     accuracy                           0.87       216
#    macro avg       0.78      0.73      0.75       216
# weighted avg       0.86      0.87      0.86       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.48      0.92      0.63        12
#      neutral       0.92      0.82      0.86       152
#     positive       0.71      0.79      0.75        52
#
#     accuracy                           0.81       216
#    macro avg       0.70      0.84      0.75       216
# weighted avg       0.84      0.81      0.82       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.62      0.65      0.64        23
#      neutral       0.83      0.95      0.89       152
#     positive       1.00      0.46      0.63        41
#
#     accuracy                           0.82       216
#    macro avg       0.82      0.69      0.72       216
# weighted avg       0.84      0.82      0.81       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.82      0.69      0.75        13
#      neutral       0.96      0.98      0.97       186
#     positive       0.79      0.65      0.71        17
#
#     accuracy                           0.94       216
#    macro avg       0.85      0.77      0.81       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.36      0.53        14
#      neutral       0.89      1.00      0.94       185
#     positive       0.75      0.18      0.29        17
#
#     accuracy                           0.89       216
#    macro avg       0.88      0.51      0.59       216
# weighted avg       0.89      0.89      0.87       216
#
# Launching training on 2 GPUs.
# 589 589
# Nearest checkpoint: 540
# Threshold: 88261.6796875
# Samples above threshold: 73
# Acquired samples: 73
# Sampling duration: 9.469717264175415 seconds
# New train size: 208
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.588322639465332 | ACCURACY: 0.7917 | F1 MACRO: 0.882 | F1 MICRO: 0.8834
# EPOCH 2 | LOSS: 3.1861555576324463 | ACCURACY: 0.8058 | F1 MACRO: 0.8876 | F1 MICRO: 0.8895
# EPOCH 3 | LOSS: 2.8394222259521484 | ACCURACY: 0.8155 | F1 MACRO: 0.892 | F1 MICRO: 0.8937
# EPOCH 4 | LOSS: 2.6331987380981445 | ACCURACY: 0.8214 | F1 MACRO: 0.8952 | F1 MICRO: 0.897
# EPOCH 5 | LOSS: 2.5684456825256348 | ACCURACY: 0.8497 | F1 MACRO: 0.9091 | F1 MICRO: 0.911
# EPOCH 6 | LOSS: 2.5159032344818115 | ACCURACY: 0.8854 | F1 MACRO: 0.93 | F1 MICRO: 0.9311
# EPOCH 7 | LOSS: 2.4208285808563232 | ACCURACY: 0.9152 | F1 MACRO: 0.9464 | F1 MICRO: 0.948
# EPOCH 8 | LOSS: 2.3488447666168213 | ACCURACY: 0.9278 | F1 MACRO: 0.9539 | F1 MICRO: 0.9555
# EPOCH 9 | LOSS: 2.3065249919891357 | ACCURACY: 0.9226 | F1 MACRO: 0.949 | F1 MICRO: 0.9521
# EPOCH 10 | LOSS: 2.2933967113494873 | ACCURACY: 0.9375 | F1 MACRO: 0.9591 | F1 MICRO: 0.9611
# aspect: ACCURACY 0.9375 | F1 MACRO 0.9591 | F1 MICRO 0.9611
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.92      1.00      0.96       175
#       others       0.91      0.89      0.90       158
#         part       0.93      0.98      0.95       158
#        price       0.95      0.99      0.97       192
#      service       0.96      1.00      0.98       191
#
#    micro avg       0.94      0.98      0.96      1061
#    macro avg       0.94      0.98      0.96      1061
# weighted avg       0.94      0.98      0.96      1061
#  samples avg       0.94      0.98      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 12.762165069580078 | ACCURACY: 0.8879 | F1 MACRO: 0.8736 | F1 MICRO: 0.8879
# EPOCH 2 | LOSS: 10.046867370605469 | ACCURACY: 0.9397 | F1 MACRO: 0.9315 | F1 MICRO: 0.9397
# EPOCH 3 | LOSS: 9.093193054199219 | ACCURACY: 0.9353 | F1 MACRO: 0.9253 | F1 MICRO: 0.9353
# EPOCH 4 | LOSS: 8.341954231262207 | ACCURACY: 0.9483 | F1 MACRO: 0.9413 | F1 MICRO: 0.9483
# EPOCH 5 | LOSS: 7.611888885498047 | ACCURACY: 0.9267 | F1 MACRO: 0.9127 | F1 MICRO: 0.9267
# EPOCH 6 | LOSS: 7.743651390075684 | ACCURACY: 0.9224 | F1 MACRO: 0.9141 | F1 MICRO: 0.9224
# EPOCH 7 | LOSS: 7.341198444366455 | ACCURACY: 0.9138 | F1 MACRO: 0.9001 | F1 MICRO: 0.9138
# in second
# EPOCH 8 | LOSS: 6.792128086090088 | ACCURACY: 0.9353 | F1 MACRO: 0.9264 | F1 MICRO: 0.9353
# in second
# EPOCH 9 | LOSS: 6.714614391326904 | ACCURACY: 0.9397 | F1 MACRO: 0.9315 | F1 MICRO: 0.9397
# in second
# EPOCH 10 | LOSS: 6.699885845184326 | ACCURACY: 0.9353 | F1 MACRO: 0.9264 | F1 MICRO: 0.9353
# sentiment: ACCURACY 0.9483 | F1 MACRO 0.9413 | F1 MICRO 0.9483
#               precision    recall  f1-score   support
#
#     negative       0.88      0.97      0.92        72
#     positive       0.99      0.94      0.96       160
#
#     accuracy                           0.95       232
#    macro avg       0.93      0.95      0.94       232
# weighted avg       0.95      0.95      0.95       232
#
# --------------------------------------------------
# Iteration 208: Accuracy: 0.9267, F1 Micro: 0.9267, F1 Macro: 0.849
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.90      0.82      0.86        11
#      neutral       0.98      1.00      0.99       181
#     positive       0.95      0.88      0.91        24
#
#     accuracy                           0.98       216
#    macro avg       0.95      0.90      0.92       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.79      0.69      0.73        16
#      neutral       0.90      0.99      0.95       167
#     positive       0.94      0.52      0.67        33
#
#     accuracy                           0.90       216
#    macro avg       0.88      0.73      0.78       216
# weighted avg       0.90      0.90      0.89       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.67      0.83      0.74        12
#      neutral       0.91      0.91      0.91       152
#     positive       0.78      0.75      0.76        52
#
#     accuracy                           0.87       216
#    macro avg       0.79      0.83      0.81       216
# weighted avg       0.87      0.87      0.87       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.71      0.87      0.78        23
#      neutral       0.93      0.96      0.94       152
#     positive       0.97      0.73      0.83        41
#
#     accuracy                           0.91       216
#    macro avg       0.87      0.85      0.85       216
# weighted avg       0.91      0.91      0.91       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.69      0.72        13
#      neutral       0.96      0.98      0.97       186
#     positive       0.86      0.71      0.77        17
#
#     accuracy                           0.94       216
#    macro avg       0.86      0.79      0.82       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.79      0.88        14
#      neutral       0.96      1.00      0.98       185
#     positive       1.00      0.76      0.87        17
#
#     accuracy                           0.97       216
#    macro avg       0.99      0.85      0.91       216
# weighted avg       0.97      0.97      0.97       216
#
# Launching training on 2 GPUs.
# 590 590
# Nearest checkpoint: 540
# Threshold: 88569.46875
# Samples above threshold: 66
# Acquired samples: 66
# Sampling duration: 10.701686382293701 seconds
# New train size: 274
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.3098464012145996 | ACCURACY: 0.7946 | F1 MACRO: 0.8833 | F1 MICRO: 0.8848
# EPOCH 2 | LOSS: 2.8030223846435547 | ACCURACY: 0.7976 | F1 MACRO: 0.8751 | F1 MICRO: 0.8814
# EPOCH 3 | LOSS: 2.4869086742401123 | ACCURACY: 0.8192 | F1 MACRO: 0.8952 | F1 MICRO: 0.8966
# EPOCH 4 | LOSS: 2.3873064517974854 | ACCURACY: 0.8482 | F1 MACRO: 0.9084 | F1 MICRO: 0.9097
# EPOCH 5 | LOSS: 2.351614236831665 | ACCURACY: 0.9085 | F1 MACRO: 0.9432 | F1 MICRO: 0.9445
# EPOCH 6 | LOSS: 2.2762341499328613 | ACCURACY: 0.9226 | F1 MACRO: 0.95 | F1 MICRO: 0.9523
# EPOCH 7 | LOSS: 2.1749253273010254 | ACCURACY: 0.9368 | F1 MACRO: 0.9583 | F1 MICRO: 0.9606
# EPOCH 8 | LOSS: 2.127934694290161 | ACCURACY: 0.9397 | F1 MACRO: 0.9602 | F1 MICRO: 0.9624
# EPOCH 9 | LOSS: 2.02007794380188 | ACCURACY: 0.9338 | F1 MACRO: 0.9556 | F1 MICRO: 0.9586
# EPOCH 10 | LOSS: 1.9280266761779785 | ACCURACY: 0.9405 | F1 MACRO: 0.9602 | F1 MICRO: 0.9628
# aspect: ACCURACY 0.9405 | F1 MACRO 0.9602 | F1 MICRO 0.9628
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.92      0.99      0.96       175
#       others       0.93      0.88      0.90       158
#         part       0.91      0.97      0.94       158
#        price       0.97      0.99      0.98       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.95      0.98      0.96      1061
#    macro avg       0.95      0.97      0.96      1061
# weighted avg       0.95      0.98      0.96      1061
#  samples avg       0.95      0.97      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 9.859712600708008 | ACCURACY: 0.912 | F1 MACRO: 0.8936 | F1 MICRO: 0.912
# EPOCH 2 | LOSS: 7.645932674407959 | ACCURACY: 0.944 | F1 MACRO: 0.9352 | F1 MICRO: 0.944
# EPOCH 3 | LOSS: 6.70266056060791 | ACCURACY: 0.924 | F1 MACRO: 0.9112 | F1 MICRO: 0.924
# EPOCH 4 | LOSS: 6.207381725311279 | ACCURACY: 0.928 | F1 MACRO: 0.9183 | F1 MICRO: 0.928
# EPOCH 5 | LOSS: 5.92259407043457 | ACCURACY: 0.936 | F1 MACRO: 0.9269 | F1 MICRO: 0.936
# in second
# EPOCH 6 | LOSS: 5.296164035797119 | ACCURACY: 0.932 | F1 MACRO: 0.9231 | F1 MICRO: 0.932
# in second
# EPOCH 7 | LOSS: 5.320324897766113 | ACCURACY: 0.932 | F1 MACRO: 0.9231 | F1 MICRO: 0.932
# in second
# EPOCH 8 | LOSS: 5.2332444190979 | ACCURACY: 0.932 | F1 MACRO: 0.9231 | F1 MICRO: 0.932
# in second
# EPOCH 9 | LOSS: 5.114737033843994 | ACCURACY: 0.932 | F1 MACRO: 0.9231 | F1 MICRO: 0.932
# in second
# EPOCH 10 | LOSS: 5.141143798828125 | ACCURACY: 0.932 | F1 MACRO: 0.9231 | F1 MICRO: 0.932
# sentiment: ACCURACY 0.944 | F1 MACRO 0.9352 | F1 MICRO 0.944
#               precision    recall  f1-score   support
#
#     negative       0.88      0.95      0.91        76
#     positive       0.98      0.94      0.96       174
#
#     accuracy                           0.94       250
#    macro avg       0.93      0.94      0.94       250
# weighted avg       0.95      0.94      0.94       250
#
# --------------------------------------------------
# Iteration 274: Accuracy: 0.9321, F1 Micro: 0.9321, F1 Macro: 0.8615
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.92      0.92      0.92        24
#
#     accuracy                           0.98       216
#    macro avg       0.97      0.94      0.95       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.75      0.80        16
#      neutral       0.93      0.99      0.96       167
#     positive       0.91      0.64      0.75        33
#
#     accuracy                           0.92       216
#    macro avg       0.90      0.79      0.84       216
# weighted avg       0.92      0.92      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.50      0.83      0.62        12
#      neutral       0.95      0.87      0.91       152
#     positive       0.74      0.81      0.77        52
#
#     accuracy                           0.85       216
#    macro avg       0.73      0.84      0.77       216
# weighted avg       0.87      0.85      0.86       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.71      0.87      0.78        23
#      neutral       0.93      0.96      0.94       152
#     positive       0.97      0.73      0.83        41
#
#     accuracy                           0.91       216
#    macro avg       0.87      0.85      0.85       216
# weighted avg       0.91      0.91      0.91       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.77      0.77      0.77        13
#      neutral       0.97      0.99      0.98       186
#     positive       0.86      0.71      0.77        17
#
#     accuracy                           0.95       216
#    macro avg       0.87      0.82      0.84       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.79      0.85        14
#      neutral       0.98      1.00      0.99       185
#     positive       0.94      0.88      0.91        17
#
#     accuracy                           0.98       216
#    macro avg       0.95      0.89      0.92       216
# weighted avg       0.98      0.98      0.98       216
#
# Launching training on 2 GPUs.
# 556 556
# Nearest checkpoint: 540
# Threshold: 88684.625
# Samples above threshold: 59
# Acquired samples: 59
# Sampling duration: 11.66127347946167 seconds
# New train size: 333
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.326361894607544 | ACCURACY: 0.7991 | F1 MACRO: 0.8833 | F1 MICRO: 0.8856
# EPOCH 2 | LOSS: 2.7784860134124756 | ACCURACY: 0.8192 | F1 MACRO: 0.8945 | F1 MICRO: 0.8961
# EPOCH 3 | LOSS: 2.530548572540283 | ACCURACY: 0.8415 | F1 MACRO: 0.9056 | F1 MICRO: 0.9071
# EPOCH 4 | LOSS: 2.4926095008850098 | ACCURACY: 0.9062 | F1 MACRO: 0.9415 | F1 MICRO: 0.9428
# EPOCH 5 | LOSS: 2.410870313644409 | ACCURACY: 0.9293 | F1 MACRO: 0.9548 | F1 MICRO: 0.9564
# EPOCH 6 | LOSS: 2.2533905506134033 | ACCURACY: 0.9449 | F1 MACRO: 0.9643 | F1 MICRO: 0.9657
# EPOCH 7 | LOSS: 2.189582347869873 | ACCURACY: 0.9427 | F1 MACRO: 0.9614 | F1 MICRO: 0.9641
# EPOCH 8 | LOSS: 2.016450881958008 | ACCURACY: 0.9412 | F1 MACRO: 0.9614 | F1 MICRO: 0.9634
# EPOCH 9 | LOSS: 1.9443957805633545 | ACCURACY: 0.9464 | F1 MACRO: 0.9645 | F1 MICRO: 0.9665
# EPOCH 10 | LOSS: 1.8651319742202759 | ACCURACY: 0.9494 | F1 MACRO: 0.9666 | F1 MICRO: 0.9683
# aspect: ACCURACY 0.9494 | F1 MACRO 0.9666 | F1 MICRO 0.9683
#               precision    recall  f1-score   support
#
#         fuel       0.98      0.99      0.99       187
#      machine       0.92      0.99      0.96       175
#       others       0.93      0.93      0.93       158
#         part       0.95      0.95      0.95       158
#        price       0.97      0.99      0.98       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.96      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.96      0.98      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 8.556136131286621 | ACCURACY: 0.9109 | F1 MACRO: 0.9034 | F1 MICRO: 0.9109
# EPOCH 2 | LOSS: 6.638514518737793 | ACCURACY: 0.9393 | F1 MACRO: 0.9325 | F1 MICRO: 0.9393
# EPOCH 3 | LOSS: 5.988868236541748 | ACCURACY: 0.9393 | F1 MACRO: 0.9313 | F1 MICRO: 0.9393
# EPOCH 4 | LOSS: 5.637577533721924 | ACCURACY: 0.9271 | F1 MACRO: 0.9157 | F1 MICRO: 0.9271
# EPOCH 5 | LOSS: 5.320723533630371 | ACCURACY: 0.9352 | F1 MACRO: 0.9256 | F1 MICRO: 0.9352
# EPOCH 6 | LOSS: 5.196887969970703 | ACCURACY: 0.9352 | F1 MACRO: 0.927 | F1 MICRO: 0.9352
# in second
# EPOCH 7 | LOSS: 4.698389530181885 | ACCURACY: 0.9433 | F1 MACRO: 0.9365 | F1 MICRO: 0.9433
# in second
# EPOCH 8 | LOSS: 4.591774940490723 | ACCURACY: 0.9393 | F1 MACRO: 0.9322 | F1 MICRO: 0.9393
# in second
# EPOCH 9 | LOSS: 4.601347923278809 | ACCURACY: 0.9393 | F1 MACRO: 0.9322 | F1 MICRO: 0.9393
# in second
# sentiment: ACCURACY 0.9393 | F1 MACRO 0.9313 | F1 MICRO 0.9393
#               precision    recall  f1-score   support
#
#     negative       0.88      0.94      0.91        79
#     positive       0.97      0.94      0.95       168
#
#     accuracy                           0.94       247
#    macro avg       0.93      0.94      0.93       247
# weighted avg       0.94      0.94      0.94       247
#
# --------------------------------------------------
# Iteration 333: Accuracy: 0.9444, F1 Micro: 0.9444, F1 Macro: 0.8923
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.92      0.92      0.92        24
#
#     accuracy                           0.98       216
#    macro avg       0.97      0.94      0.95       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.75      0.75        16
#      neutral       0.93      0.99      0.96       167
#     positive       0.95      0.64      0.76        33
#
#     accuracy                           0.92       216
#    macro avg       0.88      0.79      0.83       216
# weighted avg       0.92      0.92      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.71      0.83      0.77        12
#      neutral       0.92      0.92      0.92       152
#     positive       0.82      0.77      0.79        52
#
#     accuracy                           0.88       216
#    macro avg       0.82      0.84      0.83       216
# weighted avg       0.88      0.88      0.88       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.74      1.00      0.85        23
#      neutral       0.96      0.95      0.95       152
#     positive       0.97      0.83      0.89        41
#
#     accuracy                           0.93       216
#    macro avg       0.89      0.93      0.90       216
# weighted avg       0.94      0.93      0.93       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.77      0.77      0.77        13
#      neutral       0.98      0.99      0.98       186
#     positive       0.93      0.82      0.87        17
#
#     accuracy                           0.96       216
#    macro avg       0.89      0.86      0.88       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.99      1.00      0.99       185
#     positive       1.00      1.00      1.00        17
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.95      0.97       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 514 514
# Nearest checkpoint: 540
# Threshold: 88729.2109375
# Samples above threshold: 54
# Acquired samples: 54
# Sampling duration: 12.59178352355957 seconds
# New train size: 387
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.356954336166382 | ACCURACY: 0.7969 | F1 MACRO: 0.8832 | F1 MICRO: 0.8851
# EPOCH 2 | LOSS: 2.727271318435669 | ACCURACY: 0.8177 | F1 MACRO: 0.8943 | F1 MICRO: 0.8958
# EPOCH 3 | LOSS: 2.467650890350342 | ACCURACY: 0.8787 | F1 MACRO: 0.9256 | F1 MICRO: 0.9273
# EPOCH 4 | LOSS: 2.4547486305236816 | ACCURACY: 0.9219 | F1 MACRO: 0.95 | F1 MICRO: 0.9518
# EPOCH 5 | LOSS: 2.28572940826416 | ACCURACY: 0.9338 | F1 MACRO: 0.9551 | F1 MICRO: 0.9585
# EPOCH 6 | LOSS: 2.1635539531707764 | ACCURACY: 0.9479 | F1 MACRO: 0.9654 | F1 MICRO: 0.9674
# EPOCH 7 | LOSS: 2.054753541946411 | ACCURACY: 0.9487 | F1 MACRO: 0.966 | F1 MICRO: 0.9679
# EPOCH 8 | LOSS: 1.9582045078277588 | ACCURACY: 0.9405 | F1 MACRO: 0.9596 | F1 MICRO: 0.9625
# EPOCH 9 | LOSS: 1.8489344120025635 | ACCURACY: 0.9509 | F1 MACRO: 0.9679 | F1 MICRO: 0.9694
# EPOCH 10 | LOSS: 1.8320647478103638 | ACCURACY: 0.9435 | F1 MACRO: 0.962 | F1 MICRO: 0.9645
# aspect: ACCURACY 0.9509 | F1 MACRO 0.9679 | F1 MICRO 0.9694
#               precision    recall  f1-score   support
#
#         fuel       0.98      0.99      0.99       187
#      machine       0.93      0.99      0.96       175
#       others       0.91      0.94      0.93       158
#         part       0.94      0.98      0.96       158
#        price       0.97      0.99      0.98       192
#      service       0.98      0.99      0.99       191
#
#    micro avg       0.95      0.98      0.97      1061
#    macro avg       0.95      0.98      0.97      1061
# weighted avg       0.95      0.98      0.97      1061
#  samples avg       0.95      0.98      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.982598304748535 | ACCURACY: 0.9383 | F1 MACRO: 0.932 | F1 MICRO: 0.9383
# EPOCH 2 | LOSS: 5.352558612823486 | ACCURACY: 0.93 | F1 MACRO: 0.9233 | F1 MICRO: 0.93
# EPOCH 3 | LOSS: 4.770742893218994 | ACCURACY: 0.93 | F1 MACRO: 0.922 | F1 MICRO: 0.93
# EPOCH 4 | LOSS: 4.588587760925293 | ACCURACY: 0.9383 | F1 MACRO: 0.9299 | F1 MICRO: 0.9383
# EPOCH 5 | LOSS: 4.276628494262695 | ACCURACY: 0.9424 | F1 MACRO: 0.9344 | F1 MICRO: 0.9424
# EPOCH 6 | LOSS: 4.160647392272949 | ACCURACY: 0.9465 | F1 MACRO: 0.9384 | F1 MICRO: 0.9465
# EPOCH 7 | LOSS: 4.214539527893066 | ACCURACY: 0.93 | F1 MACRO: 0.9211 | F1 MICRO: 0.93
# EPOCH 8 | LOSS: 4.064264297485352 | ACCURACY: 0.93 | F1 MACRO: 0.9229 | F1 MICRO: 0.93
# EPOCH 9 | LOSS: 4.028289794921875 | ACCURACY: 0.9218 | F1 MACRO: 0.9138 | F1 MICRO: 0.9218
# in second
# EPOCH 10 | LOSS: 3.831841230392456 | ACCURACY: 0.93 | F1 MACRO: 0.9233 | F1 MICRO: 0.93
# sentiment: ACCURACY 0.9465 | F1 MACRO 0.9384 | F1 MICRO 0.9465
#               precision    recall  f1-score   support
#
#     negative       0.92      0.91      0.92        78
#     positive       0.96      0.96      0.96       165
#
#     accuracy                           0.95       243
#    macro avg       0.94      0.94      0.94       243
# weighted avg       0.95      0.95      0.95       243
#
# --------------------------------------------------
# Iteration 387: Accuracy: 0.9437, F1 Micro: 0.9437, F1 Macro: 0.8858
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.97      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.75      0.77        16
#      neutral       0.94      1.00      0.97       167
#     positive       0.92      0.67      0.77        33
#
#     accuracy                           0.93       216
#    macro avg       0.89      0.81      0.84       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.56      0.75      0.64        12
#      neutral       0.90      0.91      0.90       152
#     positive       0.83      0.73      0.78        52
#
#     accuracy                           0.86       216
#    macro avg       0.76      0.80      0.77       216
# weighted avg       0.86      0.86      0.86       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.79      0.96      0.86        23
#      neutral       0.97      0.97      0.97       152
#     positive       0.94      0.80      0.87        41
#
#     accuracy                           0.94       216
#    macro avg       0.90      0.91      0.90       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.77      0.83        13
#      neutral       0.97      0.99      0.98       186
#     positive       0.93      0.82      0.87        17
#
#     accuracy                           0.97       216
#    macro avg       0.94      0.86      0.90       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.79      0.85        14
#      neutral       0.99      0.99      0.99       185
#     positive       0.89      1.00      0.94        17
#
#     accuracy                           0.98       216
#    macro avg       0.94      0.93      0.93       216
# weighted avg       0.98      0.98      0.98       216
#
# Launching training on 2 GPUs.
# 458 458
# Nearest checkpoint: 540
# Threshold: 88508.546875
# Samples above threshold: 48
# Acquired samples: 48
# Sampling duration: 13.302627325057983 seconds
# New train size: 435
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.1885480880737305 | ACCURACY: 0.8058 | F1 MACRO: 0.8872 | F1 MICRO: 0.8893
# EPOCH 2 | LOSS: 2.545149803161621 | ACCURACY: 0.8192 | F1 MACRO: 0.8944 | F1 MICRO: 0.8959
# EPOCH 3 | LOSS: 2.3890178203582764 | ACCURACY: 0.8914 | F1 MACRO: 0.9318 | F1 MICRO: 0.934
# EPOCH 4 | LOSS: 2.3668458461761475 | ACCURACY: 0.9315 | F1 MACRO: 0.9555 | F1 MICRO: 0.9576
# EPOCH 5 | LOSS: 2.2054929733276367 | ACCURACY: 0.9464 | F1 MACRO: 0.9651 | F1 MICRO: 0.9668
# EPOCH 6 | LOSS: 2.0539891719818115 | ACCURACY: 0.9494 | F1 MACRO: 0.9667 | F1 MICRO: 0.9684
# EPOCH 7 | LOSS: 1.9625087976455688 | ACCURACY: 0.9501 | F1 MACRO: 0.9671 | F1 MICRO: 0.9689
# EPOCH 8 | LOSS: 1.8769092559814453 | ACCURACY: 0.9457 | F1 MACRO: 0.9638 | F1 MICRO: 0.9659
# EPOCH 9 | LOSS: 1.8142266273498535 | ACCURACY: 0.9494 | F1 MACRO: 0.9654 | F1 MICRO: 0.9682
# EPOCH 10 | LOSS: 1.753970742225647 | ACCURACY: 0.9435 | F1 MACRO: 0.9616 | F1 MICRO: 0.9644
# aspect: ACCURACY 0.9501 | F1 MACRO 0.9671 | F1 MICRO 0.9689
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.95      0.99      0.97       175
#       others       0.90      0.93      0.91       158
#         part       0.94      0.98      0.96       158
#        price       0.97      0.99      0.98       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.95      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.95      0.98      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.456264019012451 | ACCURACY: 0.915 | F1 MACRO: 0.9026 | F1 MICRO: 0.915
# EPOCH 2 | LOSS: 4.927504062652588 | ACCURACY: 0.9271 | F1 MACRO: 0.9168 | F1 MICRO: 0.9271
# EPOCH 3 | LOSS: 4.408367156982422 | ACCURACY: 0.9271 | F1 MACRO: 0.9138 | F1 MICRO: 0.9271
# EPOCH 4 | LOSS: 4.109628677368164 | ACCURACY: 0.919 | F1 MACRO: 0.9103 | F1 MICRO: 0.919
# EPOCH 5 | LOSS: 3.866215467453003 | ACCURACY: 0.9312 | F1 MACRO: 0.9212 | F1 MICRO: 0.9312
# EPOCH 6 | LOSS: 3.8550286293029785 | ACCURACY: 0.9393 | F1 MACRO: 0.9304 | F1 MICRO: 0.9393
# EPOCH 7 | LOSS: 3.723564386367798 | ACCURACY: 0.9271 | F1 MACRO: 0.9173 | F1 MICRO: 0.9271
# EPOCH 8 | LOSS: 3.6410624980926514 | ACCURACY: 0.9352 | F1 MACRO: 0.926 | F1 MICRO: 0.9352
# EPOCH 9 | LOSS: 3.5460593700408936 | ACCURACY: 0.8947 | F1 MACRO: 0.8869 | F1 MICRO: 0.8947
# in second
# EPOCH 10 | LOSS: 3.390857219696045 | ACCURACY: 0.919 | F1 MACRO: 0.9108 | F1 MICRO: 0.919
# sentiment: ACCURACY 0.9393 | F1 MACRO 0.9304 | F1 MICRO 0.9393
#               precision    recall  f1-score   support
#
#     negative       0.90      0.91      0.91        79
#     positive       0.96      0.95      0.96       168
#
#     accuracy                           0.94       247
#    macro avg       0.93      0.93      0.93       247
# weighted avg       0.94      0.94      0.94       247
#
# --------------------------------------------------
# Iteration 435: Accuracy: 0.9421, F1 Micro: 0.9421, F1 Macro: 0.8788
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.82      0.90        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.88      0.92      0.90        24
#
#     accuracy                           0.98       216
#    macro avg       0.96      0.91      0.93       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.81      0.81      0.81        16
#      neutral       0.95      0.99      0.97       167
#     positive       0.92      0.73      0.81        33
#
#     accuracy                           0.94       216
#    macro avg       0.89      0.84      0.86       216
# weighted avg       0.93      0.94      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.45      0.75      0.56        12
#      neutral       0.91      0.90      0.91       152
#     positive       0.85      0.75      0.80        52
#
#     accuracy                           0.86       216
#    macro avg       0.74      0.80      0.76       216
# weighted avg       0.87      0.86      0.86       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.88      0.91      0.89        23
#      neutral       0.95      0.98      0.96       152
#     positive       0.94      0.80      0.87        41
#
#     accuracy                           0.94       216
#    macro avg       0.92      0.90      0.91       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.82      0.69      0.75        13
#      neutral       0.98      0.99      0.98       186
#     positive       0.82      0.82      0.82        17
#
#     accuracy                           0.96       216
#    macro avg       0.87      0.84      0.85       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.98      1.00      0.99       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       0.99      0.93      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 408 408
# Nearest checkpoint: 540
# Threshold: 88386.984375
# Samples above threshold: 43
# Acquired samples: 43
# Sampling duration: 13.904520750045776 seconds
# New train size: 478
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.17618465423584 | ACCURACY: 0.8088 | F1 MACRO: 0.8898 | F1 MICRO: 0.8914
# EPOCH 2 | LOSS: 2.5448849201202393 | ACCURACY: 0.8199 | F1 MACRO: 0.896 | F1 MICRO: 0.8972
# EPOCH 3 | LOSS: 2.3904178142547607 | ACCURACY: 0.878 | F1 MACRO: 0.9209 | F1 MICRO: 0.9251
# EPOCH 4 | LOSS: 2.3389487266540527 | ACCURACY: 0.9375 | F1 MACRO: 0.9596 | F1 MICRO: 0.9613
# EPOCH 5 | LOSS: 2.1412525177001953 | ACCURACY: 0.9427 | F1 MACRO: 0.9622 | F1 MICRO: 0.9642
# EPOCH 6 | LOSS: 2.0318331718444824 | ACCURACY: 0.9472 | F1 MACRO: 0.9652 | F1 MICRO: 0.9671
# EPOCH 7 | LOSS: 1.9170961380004883 | ACCURACY: 0.9494 | F1 MACRO: 0.9668 | F1 MICRO: 0.9685
# EPOCH 8 | LOSS: 1.8348523378372192 | ACCURACY: 0.9457 | F1 MACRO: 0.9633 | F1 MICRO: 0.9659
# EPOCH 9 | LOSS: 1.778995394706726 | ACCURACY: 0.9516 | F1 MACRO: 0.9671 | F1 MICRO: 0.9694
# EPOCH 10 | LOSS: 1.7037075757980347 | ACCURACY: 0.9539 | F1 MACRO: 0.9693 | F1 MICRO: 0.9711
# aspect: ACCURACY 0.9539 | F1 MACRO 0.9693 | F1 MICRO 0.9711
#               precision    recall  f1-score   support
#
#         fuel       0.98      0.99      0.99       187
#      machine       0.93      0.99      0.96       175
#       others       0.92      0.91      0.92       158
#         part       0.96      0.98      0.97       158
#        price       0.98      0.99      0.99       192
#      service       0.99      1.00      0.99       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.96      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.186668395996094 | ACCURACY: 0.93 | F1 MACRO: 0.9209 | F1 MICRO: 0.93
# EPOCH 2 | LOSS: 4.7585015296936035 | ACCURACY: 0.9494 | F1 MACRO: 0.9408 | F1 MICRO: 0.9494
# EPOCH 3 | LOSS: 4.18093204498291 | ACCURACY: 0.9377 | F1 MACRO: 0.9297 | F1 MICRO: 0.9377
# EPOCH 4 | LOSS: 4.005393028259277 | ACCURACY: 0.9416 | F1 MACRO: 0.9343 | F1 MICRO: 0.9416
# EPOCH 5 | LOSS: 3.73527193069458 | ACCURACY: 0.9105 | F1 MACRO: 0.9004 | F1 MICRO: 0.9105
# in second
# EPOCH 6 | LOSS: 3.474092483520508 | ACCURACY: 0.9416 | F1 MACRO: 0.9347 | F1 MICRO: 0.9416
# in second
# EPOCH 7 | LOSS: 3.3923914432525635 | ACCURACY: 0.9377 | F1 MACRO: 0.9305 | F1 MICRO: 0.9377
# in second
# EPOCH 8 | LOSS: 3.3136916160583496 | ACCURACY: 0.9183 | F1 MACRO: 0.91 | F1 MICRO: 0.9183
# in second
# sentiment: ACCURACY 0.9494 | F1 MACRO 0.9408 | F1 MICRO 0.9494
#               precision    recall  f1-score   support
#
#     negative       0.94      0.90      0.92        81
#     positive       0.96      0.97      0.96       176
#
#     accuracy                           0.95       257
#    macro avg       0.95      0.94      0.94       257
# weighted avg       0.95      0.95      0.95       257
#
# --------------------------------------------------
# Iteration 478: Accuracy: 0.9406, F1 Micro: 0.9406, F1 Macro: 0.8781
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.82      0.90        11
#      neutral       0.98      0.99      0.99       181
#     positive       0.92      0.92      0.92        24
#
#     accuracy                           0.98       216
#    macro avg       0.97      0.91      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.81      0.84        16
#      neutral       0.94      0.99      0.96       167
#     positive       0.92      0.70      0.79        33
#
#     accuracy                           0.93       216
#    macro avg       0.91      0.83      0.86       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.50      0.83      0.62        12
#      neutral       0.93      0.87      0.90       152
#     positive       0.76      0.79      0.77        52
#
#     accuracy                           0.85       216
#    macro avg       0.73      0.83      0.77       216
# weighted avg       0.86      0.85      0.85       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.76      0.83      0.79        23
#      neutral       0.97      0.97      0.97       152
#     positive       0.87      0.83      0.85        41
#
#     accuracy                           0.93       216
#    macro avg       0.87      0.88      0.87       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.77      0.87        13
#      neutral       0.99      1.00      0.99       186
#     positive       0.83      0.88      0.86        17
#
#     accuracy                           0.98       216
#    macro avg       0.94      0.88      0.91       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.71      0.83        14
#      neutral       0.99      1.00      0.99       185
#     positive       0.89      1.00      0.94        17
#
#     accuracy                           0.98       216
#    macro avg       0.96      0.90      0.92       216
# weighted avg       0.98      0.98      0.98       216
#
# Launching training on 2 GPUs.
# 372 372
# Nearest checkpoint: 540
# Threshold: 88316.8203125
# Samples above threshold: 39
# Acquired samples: 39
# Sampling duration: 14.849475383758545 seconds
# New train size: 517
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.268099069595337 | ACCURACY: 0.7999 | F1 MACRO: 0.8845 | F1 MICRO: 0.8863
# EPOCH 2 | LOSS: 2.544459104537964 | ACCURACY: 0.8571 | F1 MACRO: 0.9142 | F1 MICRO: 0.9156
# EPOCH 3 | LOSS: 2.446377992630005 | ACCURACY: 0.9278 | F1 MACRO: 0.9533 | F1 MICRO: 0.9552
# EPOCH 4 | LOSS: 2.287904739379883 | ACCURACY: 0.9375 | F1 MACRO: 0.9577 | F1 MICRO: 0.9608
# EPOCH 5 | LOSS: 2.167440891265869 | ACCURACY: 0.9509 | F1 MACRO: 0.9679 | F1 MICRO: 0.9695
# EPOCH 6 | LOSS: 1.9769514799118042 | ACCURACY: 0.9487 | F1 MACRO: 0.9651 | F1 MICRO: 0.9677
# EPOCH 7 | LOSS: 1.907456636428833 | ACCURACY: 0.9509 | F1 MACRO: 0.9676 | F1 MICRO: 0.9692
# EPOCH 8 | LOSS: 1.8252694606781006 | ACCURACY: 0.9531 | F1 MACRO: 0.9692 | F1 MICRO: 0.9706
# EPOCH 9 | LOSS: 1.7769657373428345 | ACCURACY: 0.9479 | F1 MACRO: 0.9649 | F1 MICRO: 0.9672
# EPOCH 10 | LOSS: 1.7265357971191406 | ACCURACY: 0.9487 | F1 MACRO: 0.9656 | F1 MICRO: 0.9677
# aspect: ACCURACY 0.9531 | F1 MACRO 0.9692 | F1 MICRO 0.9706
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.94      0.98      0.96       175
#       others       0.89      0.94      0.91       158
# ...
#    macro avg       0.97      0.98      0.98      1061
# weighted avg       0.97      0.98      0.98      1061
#  samples avg       0.97      0.99      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.6145637035369873 | ACCURACY: 0.9305 | F1 MACRO: 0.9207 | F1 MICRO: 0.9305
# EPOCH 2 | LOSS: 2.672497272491455 | ACCURACY: 0.9344 | F1 MACRO: 0.9258 | F1 MICRO: 0.9344
# EPOCH 3 | LOSS: 2.382793426513672 | ACCURACY: 0.9382 | F1 MACRO: 0.9315 | F1 MICRO: 0.9382
# EPOCH 4 | LOSS: 2.274801731109619 | ACCURACY: 0.9305 | F1 MACRO: 0.9225 | F1 MICRO: 0.9305
# EPOCH 5 | LOSS: 2.16420578956604 | ACCURACY: 0.9382 | F1 MACRO: 0.9315 | F1 MICRO: 0.9382
# EPOCH 6 | LOSS: 2.0468454360961914 | ACCURACY: 0.9382 | F1 MACRO: 0.9315 | F1 MICRO: 0.9382
# EPOCH 7 | LOSS: 2.0321414470672607 | ACCURACY: 0.9382 | F1 MACRO: 0.9295 | F1 MICRO: 0.9382
# EPOCH 8 | LOSS: 2.0234405994415283 | ACCURACY: 0.9421 | F1 MACRO: 0.9353 | F1 MICRO: 0.9421
# EPOCH 9 | LOSS: 1.963997721672058 | ACCURACY: 0.9266 | F1 MACRO: 0.9185 | F1 MICRO: 0.9266
# EPOCH 10 | LOSS: 1.957280158996582 | ACCURACY: 0.9537 | F1 MACRO: 0.9471 | F1 MICRO: 0.9537
# sentiment: ACCURACY 0.9537 | F1 MACRO 0.9471 | F1 MICRO 0.9537
#               precision    recall  f1-score   support
#
#     negative       0.92      0.94      0.93        83
#     positive       0.97      0.96      0.97       176
#
#     accuracy                           0.95       259
#    macro avg       0.94      0.95      0.95       259
# weighted avg       0.95      0.95      0.95       259
#
# --------------------------------------------------
# Iteration 831: Accuracy: 0.9506, F1 Micro: 0.9506, F1 Macro: 0.8911
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.82      0.90        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.88      0.92      0.90        24
#
#     accuracy                           0.98       216
#    macro avg       0.96      0.91      0.93       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.75      0.75        16
#      neutral       0.97      0.96      0.97       167
#     positive       0.82      0.85      0.84        33
#
#     accuracy                           0.93       216
#    macro avg       0.85      0.85      0.85       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.62      0.83      0.71        12
#      neutral       0.92      0.95      0.94       152
#     positive       0.90      0.73      0.81        52
#
#     accuracy                           0.89       216
#    macro avg       0.82      0.84      0.82       216
# weighted avg       0.90      0.89      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.85      1.00      0.92        23
#      neutral       0.98      0.98      0.98       152
#     positive       0.95      0.85      0.90        41
#
#     accuracy                           0.96       216
#    macro avg       0.93      0.94      0.93       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.71      0.77      0.74        13
#      neutral       0.98      0.98      0.98       186
#     positive       0.82      0.82      0.82        17
#
#     accuracy                           0.95       216
#    macro avg       0.84      0.86      0.85       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.93      0.93        14
#      neutral       0.99      1.00      1.00       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       0.97      0.96      0.97       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 33 33
# Nearest checkpoint: 864
# Threshold: 88350.75
# Samples above threshold: 4
# Acquired samples: 25
# Sampling duration: 19.375031232833862 seconds
# New train size: 856
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.8577330112457275 | ACCURACY: 0.8177 | F1 MACRO: 0.8951 | F1 MICRO: 0.8961
# EPOCH 2 | LOSS: 2.404702663421631 | ACCURACY: 0.9375 | F1 MACRO: 0.9597 | F1 MICRO: 0.9613
# EPOCH 3 | LOSS: 2.183012008666992 | ACCURACY: 0.9449 | F1 MACRO: 0.9628 | F1 MICRO: 0.9653
# EPOCH 4 | LOSS: 1.9778599739074707 | ACCURACY: 0.9561 | F1 MACRO: 0.9709 | F1 MICRO: 0.9725
# EPOCH 5 | LOSS: 1.835025429725647 | ACCURACY: 0.9583 | F1 MACRO: 0.972 | F1 MICRO: 0.9739
# EPOCH 6 | LOSS: 1.765586495399475 | ACCURACY: 0.9576 | F1 MACRO: 0.9714 | F1 MICRO: 0.9732
# EPOCH 7 | LOSS: 1.6831976175308228 | ACCURACY: 0.9591 | F1 MACRO: 0.9729 | F1 MICRO: 0.9742
# EPOCH 8 | LOSS: 1.642979621887207 | ACCURACY: 0.9606 | F1 MACRO: 0.9739 | F1 MICRO: 0.9752
# EPOCH 9 | LOSS: 1.5906723737716675 | ACCURACY: 0.9509 | F1 MACRO: 0.9665 | F1 MICRO: 0.9689
# EPOCH 10 | LOSS: 1.5738000869750977 | ACCURACY: 0.9524 | F1 MACRO: 0.9664 | F1 MICRO: 0.9696
# aspect: ACCURACY 0.9606 | F1 MACRO 0.9739 | F1 MICRO 0.9752
#               precision    recall  f1-score   support
#
#         fuel       0.98      0.99      0.99       187
#      machine       0.95      0.98      0.96       175
#       others       0.91      0.94      0.92       158
#         part       0.98      0.99      0.98       158
#        price       0.99      0.98      0.99       192
#      service       0.99      1.00      1.00       191
#
#    micro avg       0.97      0.98      0.98      1061
#    macro avg       0.97      0.98      0.97      1061
# weighted avg       0.97      0.98      0.98      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.408723831176758 | ACCURACY: 0.9321 | F1 MACRO: 0.923 | F1 MICRO: 0.9321
# EPOCH 2 | LOSS: 2.6370911598205566 | ACCURACY: 0.9094 | F1 MACRO: 0.9011 | F1 MICRO: 0.9094
# EPOCH 3 | LOSS: 2.35174298286438 | ACCURACY: 0.9321 | F1 MACRO: 0.9234 | F1 MICRO: 0.9321
# EPOCH 4 | LOSS: 2.2790141105651855 | ACCURACY: 0.9208 | F1 MACRO: 0.9132 | F1 MICRO: 0.9208
# EPOCH 5 | LOSS: 2.081448554992676 | ACCURACY: 0.9094 | F1 MACRO: 0.9015 | F1 MICRO: 0.9094
# EPOCH 6 | LOSS: 2.0777745246887207 | ACCURACY: 0.9396 | F1 MACRO: 0.9294 | F1 MICRO: 0.9396
# EPOCH 7 | LOSS: 2.059091806411743 | ACCURACY: 0.917 | F1 MACRO: 0.9089 | F1 MICRO: 0.917
# EPOCH 8 | LOSS: 1.9717919826507568 | ACCURACY: 0.9396 | F1 MACRO: 0.9334 | F1 MICRO: 0.9396
# EPOCH 9 | LOSS: 1.9456363916397095 | ACCURACY: 0.9585 | F1 MACRO: 0.9531 | F1 MICRO: 0.9585
# EPOCH 10 | LOSS: 1.9527403116226196 | ACCURACY: 0.9509 | F1 MACRO: 0.9449 | F1 MICRO: 0.9509
# sentiment: ACCURACY 0.9585 | F1 MACRO 0.9531 | F1 MICRO 0.9585
#               precision    recall  f1-score   support
#
#     negative       0.91      0.96      0.94        85
#     positive       0.98      0.96      0.97       180
#
#     accuracy                           0.96       265
#    macro avg       0.95      0.96      0.95       265
# weighted avg       0.96      0.96      0.96       265
#
# --------------------------------------------------
# Iteration 856: Accuracy: 0.9537, F1 Micro: 0.9537, F1 Macro: 0.9082
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.97      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.88      0.88      0.88        16
#      neutral       0.97      0.97      0.97       167
#     positive       0.85      0.85      0.85        33
#
#     accuracy                           0.94       216
#    macro avg       0.90      0.90      0.90       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.67      0.83      0.74        12
#      neutral       0.93      0.94      0.93       152
#     positive       0.85      0.77      0.81        52
#
#     accuracy                           0.89       216
#    macro avg       0.82      0.85      0.83       216
# weighted avg       0.90      0.89      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.79      0.96      0.86        23
#      neutral       0.98      0.97      0.98       152
#     positive       0.95      0.85      0.90        41
#
#     accuracy                           0.95       216
#    macro avg       0.90      0.93      0.91       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.85      0.88        13
#      neutral       0.99      0.98      0.98       186
#     positive       0.75      0.88      0.81        17
#
#     accuracy                           0.96       216
#    macro avg       0.89      0.90      0.89       216
# weighted avg       0.97      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.93      0.90        14
#      neutral       0.99      1.00      1.00       185
#     positive       1.00      0.88      0.94        17
#
#     accuracy                           0.99       216
#    macro avg       0.95      0.94      0.94       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 8 8
# Nearest checkpoint: 864
# Threshold: 88316.71875
# Samples above threshold: 1
# Acquired samples: 8
# Sampling duration: 19.634145259857178 seconds
# New train size: 864
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.871044635772705 | ACCURACY: 0.8103 | F1 MACRO: 0.8909 | F1 MICRO: 0.8925
# EPOCH 2 | LOSS: 2.3864283561706543 | ACCURACY: 0.9375 | F1 MACRO: 0.9593 | F1 MICRO: 0.9611
# EPOCH 3 | LOSS: 2.2238357067108154 | ACCURACY: 0.9494 | F1 MACRO: 0.9669 | F1 MICRO: 0.9685
# EPOCH 4 | LOSS: 1.9901009798049927 | ACCURACY: 0.9621 | F1 MACRO: 0.9754 | F1 MICRO: 0.9764
# EPOCH 5 | LOSS: 1.8392783403396606 | ACCURACY: 0.9606 | F1 MACRO: 0.9739 | F1 MICRO: 0.9753
# EPOCH 6 | LOSS: 1.7593647241592407 | ACCURACY: 0.9583 | F1 MACRO: 0.9722 | F1 MICRO: 0.9737
# EPOCH 7 | LOSS: 1.6909253597259521 | ACCURACY: 0.9613 | F1 MACRO: 0.9744 | F1 MICRO: 0.9757
# in second
# EPOCH 8 | LOSS: 1.6022608280181885 | ACCURACY: 0.942 | F1 MACRO: 0.9634 | F1 MICRO: 0.9643
# in second
# EPOCH 9 | LOSS: 1.5488992929458618 | ACCURACY: 0.9494 | F1 MACRO: 0.9675 | F1 MICRO: 0.9686
# in second
# EPOCH 10 | LOSS: 1.5209952592849731 | ACCURACY: 0.9546 | F1 MACRO: 0.9705 | F1 MICRO: 0.9717
# aspect: ACCURACY 0.9621 | F1 MACRO 0.9754 | F1 MICRO 0.9764
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.95      1.00      0.97       175
#       others       0.88      0.99      0.93       158
#         part       0.97      0.98      0.97       158
#        price       0.99      0.99      0.99       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.96      0.99      0.98      1061
#    macro avg       0.96      0.99      0.98      1061
# weighted avg       0.96      0.99      0.98      1061
#  samples avg       0.96      0.99      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.41459321975708 | ACCURACY: 0.9036 | F1 MACRO: 0.8928 | F1 MICRO: 0.9036
# EPOCH 2 | LOSS: 2.6044065952301025 | ACCURACY: 0.9398 | F1 MACRO: 0.9339 | F1 MICRO: 0.9398
# EPOCH 3 | LOSS: 2.309446096420288 | ACCURACY: 0.9438 | F1 MACRO: 0.9382 | F1 MICRO: 0.9438
# EPOCH 4 | LOSS: 2.051710605621338 | ACCURACY: 0.9398 | F1 MACRO: 0.9302 | F1 MICRO: 0.9398
# EPOCH 5 | LOSS: 1.9146181344985962 | ACCURACY: 0.9598 | F1 MACRO: 0.9556 | F1 MICRO: 0.9598
# EPOCH 6 | LOSS: 1.8715341091156006 | ACCURACY: 0.9357 | F1 MACRO: 0.9297 | F1 MICRO: 0.9357
# EPOCH 7 | LOSS: 1.8326107263565063 | ACCURACY: 0.9317 | F1 MACRO: 0.9259 | F1 MICRO: 0.9317
# EPOCH 8 | LOSS: 1.9041279554367065 | ACCURACY: 0.9357 | F1 MACRO: 0.9286 | F1 MICRO: 0.9357
# in second
# EPOCH 9 | LOSS: 1.776479959487915 | ACCURACY: 0.9357 | F1 MACRO: 0.9293 | F1 MICRO: 0.9357
# in second
# EPOCH 10 | LOSS: 1.72129487991333 | ACCURACY: 0.9357 | F1 MACRO: 0.9293 | F1 MICRO: 0.9357
# sentiment: ACCURACY 0.9598 | F1 MACRO 0.9556 | F1 MICRO 0.9598
#               precision    recall  f1-score   support
#
#     negative       0.90      0.99      0.94        82
#     positive       0.99      0.95      0.97       167
#
#     accuracy                           0.96       249
#    macro avg       0.95      0.97      0.96       249
# weighted avg       0.96      0.96      0.96       249
#
# --------------------------------------------------
# Iteration 864: Accuracy: 0.9529, F1 Micro: 0.9529, F1 Macro: 0.9023
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      1.00      0.99       181
#     positive       1.00      0.92      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.97      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.75      0.77        16
#      neutral       0.94      0.99      0.96       167
#     positive       0.92      0.73      0.81        33
#
#     accuracy                           0.93       216
#    macro avg       0.89      0.82      0.85       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.75      0.75        12
#      neutral       0.90      0.97      0.94       152
#     positive       0.93      0.71      0.80        52
#
#     accuracy                           0.90       216
#    macro avg       0.86      0.81      0.83       216
# weighted avg       0.90      0.90      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.79      1.00      0.88        23
#      neutral       0.98      0.97      0.97       152
#     positive       0.95      0.85      0.90        41
#
#     accuracy                           0.95       216
#    macro avg       0.91      0.94      0.92       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.92      0.86        13
#      neutral       0.99      0.98      0.99       186
#     positive       0.81      0.76      0.79        17
#
#     accuracy                           0.96       216
#    macro avg       0.87      0.89      0.88       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.99      1.00      0.99       185
#     positive       0.94      0.94      0.94        17
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.93      0.95       216
# weighted avg       0.99      0.99      0.99       216
#
# Total sampling time: 356.04 seconds
# Total runtime: 2987.2508132457733 seconds

# %% [markdown]
# ## RUN 5

# %%
active_learning(seeds[4], 4)
# Out:
# ===============================================
# TRIAL 5
# Random seed: 94
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.6675004959106445 | ACCURACY: 0.6421 | F1 MACRO: 0.7118 | F1 MICRO: 0.7611
# EPOCH 2 | LOSS: 3.466869592666626 | ACCURACY: 0.7783 | F1 MACRO: 0.8695 | F1 MICRO: 0.8733
# EPOCH 3 | LOSS: 3.1926214694976807 | ACCURACY: 0.7842 | F1 MACRO: 0.8765 | F1 MICRO: 0.8787
# EPOCH 4 | LOSS: 3.4439992904663086 | ACCURACY: 0.7909 | F1 MACRO: 0.8808 | F1 MICRO: 0.8826
# EPOCH 5 | LOSS: 3.221564292907715 | ACCURACY: 0.7887 | F1 MACRO: 0.8789 | F1 MICRO: 0.881
# EPOCH 6 | LOSS: 3.0427441596984863 | ACCURACY: 0.7835 | F1 MACRO: 0.8741 | F1 MICRO: 0.8771
# EPOCH 7 | LOSS: 3.0137059688568115 | ACCURACY: 0.7746 | F1 MACRO: 0.8644 | F1 MICRO: 0.8696
# in second
# EPOCH 8 | LOSS: 2.810563087463379 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# in second
# EPOCH 9 | LOSS: 2.66365909576416 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# in second
# EPOCH 10 | LOSS: 2.5783791542053223 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# aspect: ACCURACY 0.7909 | F1 MACRO 0.8808 | F1 MICRO 0.8826
#               precision    recall  f1-score   support
#
#         fuel       0.83      1.00      0.91       187
#      machine       0.78      1.00      0.88       175
#       others       0.71      1.00      0.83       158
#         part       0.72      0.97      0.83       158
#        price       0.86      1.00      0.92       192
#      service       0.85      1.00      0.92       191
#
#    micro avg       0.79      1.00      0.88      1061
#    macro avg       0.79      0.99      0.88      1061
# weighted avg       0.80      1.00      0.88      1061
#  samples avg       0.79      1.00      0.88      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.2192490100860596 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# EPOCH 2 | LOSS: 2.4921493530273438 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# EPOCH 3 | LOSS: 2.877603530883789 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# EPOCH 4 | LOSS: 2.834310531616211 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# EPOCH 5 | LOSS: 2.767664909362793 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# EPOCH 6 | LOSS: 2.7191824913024902 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# EPOCH 7 | LOSS: 2.236833095550537 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# EPOCH 8 | LOSS: 2.378979206085205 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# EPOCH 9 | LOSS: 2.2884602546691895 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# EPOCH 10 | LOSS: 2.3449676036834717 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# sentiment: ACCURACY 0.8889 | F1 MACRO 0.4706 | F1 MICRO 0.8889
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00         1
#     positive       0.89      1.00      0.94         8
#
#     accuracy                           0.89         9
#    macro avg       0.44      0.50      0.47         9
# weighted avg       0.79      0.89      0.84         9
#
# --------------------------------------------------
# Iteration 54: Accuracy: 0.7847, F1 Micro: 0.7847, F1 Macro: 0.301
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        11
#      neutral       0.84      1.00      0.91       181
#     positive       0.00      0.00      0.00        24
#
#     accuracy                           0.84       216
#    macro avg       0.28      0.33      0.30       216
# weighted avg       0.70      0.84      0.76       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        16
#      neutral       0.77      1.00      0.87       167
#     positive       0.00      0.00      0.00        33
#
#     accuracy                           0.77       216
#    macro avg       0.26      0.33      0.29       216
# weighted avg       0.60      0.77      0.67       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        12
#      neutral       0.70      1.00      0.83       152
#     positive       0.00      0.00      0.00        52
#
#     accuracy                           0.70       216
#    macro avg       0.23      0.33      0.28       216
# weighted avg       0.50      0.70      0.58       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.25      0.04      0.07        23
#      neutral       0.70      0.94      0.81       152
#     positive       0.22      0.05      0.08        41
#
#     accuracy                           0.68       216
#    macro avg       0.39      0.34      0.32       216
# weighted avg       0.56      0.68      0.59       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        13
#      neutral       0.86      1.00      0.93       186
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.86       216
#    macro avg       0.29      0.33      0.31       216
# weighted avg       0.74      0.86      0.80       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        14
#      neutral       0.86      1.00      0.92       185
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.86       216
#    macro avg       0.29      0.33      0.31       216
# weighted avg       0.73      0.86      0.79       216
#
# Launching training on 2 GPUs.
# 31 31
# Nearest checkpoint: 540
# Threshold: 87665.1875
# Samples above threshold: 81
# Acquired samples: 81
# Sampling duration: 5.738238334655762 seconds
# New train size: 135
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.8546266555786133 | ACCURACY: 0.7894 | F1 MACRO: 0.8803 | F1 MICRO: 0.8819
# EPOCH 2 | LOSS: 3.4276301860809326 | ACCURACY: 0.7894 | F1 MACRO: 0.8807 | F1 MICRO: 0.8822
# EPOCH 3 | LOSS: 3.299504518508911 | ACCURACY: 0.7909 | F1 MACRO: 0.8813 | F1 MICRO: 0.8829
# EPOCH 4 | LOSS: 2.9856152534484863 | ACCURACY: 0.7999 | F1 MACRO: 0.8845 | F1 MICRO: 0.8865
# EPOCH 5 | LOSS: 2.8420844078063965 | ACCURACY: 0.8095 | F1 MACRO: 0.8888 | F1 MICRO: 0.8909
# EPOCH 6 | LOSS: 2.782111406326294 | ACCURACY: 0.817 | F1 MACRO: 0.893 | F1 MICRO: 0.8948
# EPOCH 7 | LOSS: 2.691586971282959 | ACCURACY: 0.8393 | F1 MACRO: 0.9035 | F1 MICRO: 0.9054
# EPOCH 8 | LOSS: 2.6700685024261475 | ACCURACY: 0.8534 | F1 MACRO: 0.9092 | F1 MICRO: 0.912
# EPOCH 9 | LOSS: 2.7193734645843506 | ACCURACY: 0.878 | F1 MACRO: 0.9231 | F1 MICRO: 0.9257
# EPOCH 10 | LOSS: 2.6844964027404785 | ACCURACY: 0.8817 | F1 MACRO: 0.9254 | F1 MICRO: 0.928
# aspect: ACCURACY 0.8817 | F1 MACRO 0.9254 | F1 MICRO 0.928
#               precision    recall  f1-score   support
#
#         fuel       0.92      0.98      0.95       187
#      machine       0.85      0.96      0.90       175
#       others       0.79      0.90      0.84       158
#         part       0.88      0.94      0.91       158
#        price       0.94      0.99      0.96       192
#      service       0.96      1.00      0.98       191
#
#    micro avg       0.89      0.97      0.93      1061
#    macro avg       0.89      0.96      0.93      1061
# weighted avg       0.89      0.97      0.93      1061
#  samples avg       0.90      0.97      0.92      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 17.24847412109375 | ACCURACY: 0.896 | F1 MACRO: 0.8737 | F1 MICRO: 0.896
# EPOCH 2 | LOSS: 13.339143753051758 | ACCURACY: 0.9257 | F1 MACRO: 0.9146 | F1 MICRO: 0.9257
# EPOCH 3 | LOSS: 12.331298828125 | ACCURACY: 0.9307 | F1 MACRO: 0.9206 | F1 MICRO: 0.9307
# EPOCH 4 | LOSS: 11.271061897277832 | ACCURACY: 0.9059 | F1 MACRO: 0.8927 | F1 MICRO: 0.9059
# EPOCH 5 | LOSS: 10.488808631896973 | ACCURACY: 0.9158 | F1 MACRO: 0.9015 | F1 MICRO: 0.9158
# EPOCH 6 | LOSS: 10.46202564239502 | ACCURACY: 0.9257 | F1 MACRO: 0.9153 | F1 MICRO: 0.9257
# in second
# EPOCH 7 | LOSS: 9.527350425720215 | ACCURACY: 0.9307 | F1 MACRO: 0.9193 | F1 MICRO: 0.9307
# in second
# EPOCH 8 | LOSS: 9.065634727478027 | ACCURACY: 0.9208 | F1 MACRO: 0.9085 | F1 MICRO: 0.9208
# in second
# EPOCH 9 | LOSS: 9.097424507141113 | ACCURACY: 0.9158 | F1 MACRO: 0.904 | F1 MICRO: 0.9158
# in second
# sentiment: ACCURACY 0.9307 | F1 MACRO 0.9206 | F1 MICRO 0.9307
#               precision    recall  f1-score   support
#
#     negative       0.84      0.95      0.89        61
#     positive       0.98      0.92      0.95       141
#
#     accuracy                           0.93       202
#    macro avg       0.91      0.94      0.92       202
# weighted avg       0.94      0.93      0.93       202
#
# --------------------------------------------------
# Iteration 135: Accuracy: 0.8789, F1 Micro: 0.8789, F1 Macro: 0.7545
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.97      0.98      0.97       181
#     positive       0.83      0.79      0.81        24
#
#     accuracy                           0.95       216
#    macro avg       0.93      0.89      0.91       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.57      0.25      0.35        16
#      neutral       0.87      0.95      0.91       167
#     positive       0.74      0.61      0.67        33
#
#     accuracy                           0.84       216
#    macro avg       0.73      0.60      0.64       216
# weighted avg       0.83      0.84      0.83       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.33      0.50      0.40        12
#      neutral       0.80      0.87      0.84       152
#     positive       0.65      0.42      0.51        52
#
#     accuracy                           0.74       216
#    macro avg       0.60      0.60      0.58       216
# weighted avg       0.74      0.74      0.73       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.60      0.78      0.68        23
#      neutral       0.89      0.93      0.91       152
#     positive       0.75      0.51      0.61        41
#
#     accuracy                           0.83       216
#    macro avg       0.75      0.74      0.73       216
# weighted avg       0.83      0.83      0.83       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.85      0.85        13
#      neutral       0.95      1.00      0.97       186
#     positive       1.00      0.41      0.58        17
#
#     accuracy                           0.94       216
#    macro avg       0.93      0.75      0.80       216
# weighted avg       0.95      0.94      0.94       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.86      0.86        14
#      neutral       0.96      1.00      0.98       185
#     positive       1.00      0.59      0.74        17
#
#     accuracy                           0.96       216
#    macro avg       0.94      0.82      0.86       216
# weighted avg       0.96      0.96      0.95       216
#
# Launching training on 2 GPUs.
# 570 570
# Nearest checkpoint: 540
# Threshold: 88331.5859375
# Samples above threshold: 73
# Acquired samples: 73
# Sampling duration: 9.299872398376465 seconds
# New train size: 208
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.6745941638946533 | ACCURACY: 0.7909 | F1 MACRO: 0.8814 | F1 MICRO: 0.883
# EPOCH 2 | LOSS: 3.3473031520843506 | ACCURACY: 0.7939 | F1 MACRO: 0.8828 | F1 MICRO: 0.8843
# EPOCH 3 | LOSS: 2.962134599685669 | ACCURACY: 0.8021 | F1 MACRO: 0.8864 | F1 MICRO: 0.888
# EPOCH 4 | LOSS: 2.731024742126465 | ACCURACY: 0.8244 | F1 MACRO: 0.8969 | F1 MICRO: 0.8982
# EPOCH 5 | LOSS: 2.6493120193481445 | ACCURACY: 0.8467 | F1 MACRO: 0.9088 | F1 MICRO: 0.91
# EPOCH 6 | LOSS: 2.5705621242523193 | ACCURACY: 0.8795 | F1 MACRO: 0.9256 | F1 MICRO: 0.9274
# EPOCH 7 | LOSS: 2.6105735301971436 | ACCURACY: 0.9077 | F1 MACRO: 0.9408 | F1 MICRO: 0.9432
# EPOCH 8 | LOSS: 2.630993604660034 | ACCURACY: 0.9196 | F1 MACRO: 0.9484 | F1 MICRO: 0.9504
# EPOCH 9 | LOSS: 2.562777042388916 | ACCURACY: 0.9219 | F1 MACRO: 0.9496 | F1 MICRO: 0.9516
# EPOCH 10 | LOSS: 2.432375431060791 | ACCURACY: 0.9286 | F1 MACRO: 0.9537 | F1 MICRO: 0.9558
# aspect: ACCURACY 0.9286 | F1 MACRO 0.9537 | F1 MICRO 0.9558
#               precision    recall  f1-score   support
#
#         fuel       0.97      0.99      0.98       187
#      machine       0.93      0.98      0.96       175
#       others       0.83      0.92      0.87       158
#         part       0.93      0.96      0.95       158
#        price       0.97      0.99      0.98       192
#      service       0.95      1.00      0.98       191
#
#    micro avg       0.93      0.98      0.96      1061
#    macro avg       0.93      0.98      0.95      1061
# weighted avg       0.94      0.98      0.96      1061
#  samples avg       0.94      0.98      0.95      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 13.015942573547363 | ACCURACY: 0.9123 | F1 MACRO: 0.9026 | F1 MICRO: 0.9123
# EPOCH 2 | LOSS: 11.013360023498535 | ACCURACY: 0.9211 | F1 MACRO: 0.9133 | F1 MICRO: 0.9211
# EPOCH 3 | LOSS: 9.221635818481445 | ACCURACY: 0.9123 | F1 MACRO: 0.8992 | F1 MICRO: 0.9123
# EPOCH 4 | LOSS: 8.93529987335205 | ACCURACY: 0.9211 | F1 MACRO: 0.9128 | F1 MICRO: 0.9211
# EPOCH 5 | LOSS: 8.162697792053223 | ACCURACY: 0.9298 | F1 MACRO: 0.9216 | F1 MICRO: 0.9298
# EPOCH 6 | LOSS: 7.914196968078613 | ACCURACY: 0.9123 | F1 MACRO: 0.9048 | F1 MICRO: 0.9123
# EPOCH 7 | LOSS: 7.611149787902832 | ACCURACY: 0.9079 | F1 MACRO: 0.8974 | F1 MICRO: 0.9079
# EPOCH 8 | LOSS: 7.359134197235107 | ACCURACY: 0.9079 | F1 MACRO: 0.9003 | F1 MICRO: 0.9079
# in second
# EPOCH 9 | LOSS: 7.081627368927002 | ACCURACY: 0.9254 | F1 MACRO: 0.9179 | F1 MICRO: 0.9254
# in second
# EPOCH 10 | LOSS: 6.765323162078857 | ACCURACY: 0.9123 | F1 MACRO: 0.9053 | F1 MICRO: 0.9123
# sentiment: ACCURACY 0.9298 | F1 MACRO 0.9216 | F1 MICRO 0.9298
#               precision    recall  f1-score   support
#
#     negative       0.88      0.91      0.90        76
#     positive       0.95      0.94      0.95       152
#
#     accuracy                           0.93       228
#    macro avg       0.92      0.92      0.92       228
# weighted avg       0.93      0.93      0.93       228
#
# --------------------------------------------------
# Iteration 208: Accuracy: 0.9159, F1 Micro: 0.9159, F1 Macro: 0.834
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.98      1.00      0.99       181
#     positive       1.00      0.83      0.91        24
#
#     accuracy                           0.98       216
#    macro avg       0.99      0.94      0.97       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.82      0.56      0.67        16
#      neutral       0.94      0.98      0.96       167
#     positive       0.81      0.76      0.78        33
#
#     accuracy                           0.91       216
#    macro avg       0.85      0.77      0.80       216
# weighted avg       0.91      0.91      0.91       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.47      0.58      0.52        12
#      neutral       0.83      0.91      0.87       152
#     positive       0.79      0.52      0.63        52
#
#     accuracy                           0.80       216
#    macro avg       0.70      0.67      0.67       216
# weighted avg       0.80      0.80      0.79       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.63      0.74      0.68        23
#      neutral       0.92      0.94      0.93       152
#     positive       0.79      0.66      0.72        41
#
#     accuracy                           0.87       216
#    macro avg       0.78      0.78      0.78       216
# weighted avg       0.87      0.87      0.86       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.77      0.77      0.77        13
#      neutral       0.98      0.98      0.98       186
#     positive       0.82      0.82      0.82        17
#
#     accuracy                           0.96       216
#    macro avg       0.86      0.86      0.86       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.93      0.93        14
#      neutral       0.98      1.00      0.99       185
#     positive       1.00      0.76      0.87        17
#
#     accuracy                           0.98       216
#    macro avg       0.97      0.90      0.93       216
# weighted avg       0.98      0.98      0.98       216
#
# Launching training on 2 GPUs.
# 590 590
# Nearest checkpoint: 540
# Threshold: 88206.8515625
# Samples above threshold: 66
# Acquired samples: 66
# Sampling duration: 10.710528135299683 seconds
# New train size: 274
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.3395817279815674 | ACCURACY: 0.7924 | F1 MACRO: 0.882 | F1 MICRO: 0.8836
# EPOCH 2 | LOSS: 2.882148265838623 | ACCURACY: 0.8036 | F1 MACRO: 0.8876 | F1 MICRO: 0.8892
# EPOCH 3 | LOSS: 2.6060595512390137 | ACCURACY: 0.8214 | F1 MACRO: 0.8957 | F1 MICRO: 0.8967
# EPOCH 4 | LOSS: 2.4531807899475098 | ACCURACY: 0.8512 | F1 MACRO: 0.9128 | F1 MICRO: 0.9133
# EPOCH 5 | LOSS: 2.3625006675720215 | ACCURACY: 0.9018 | F1 MACRO: 0.9379 | F1 MICRO: 0.9398
# EPOCH 6 | LOSS: 2.313793659210205 | ACCURACY: 0.9249 | F1 MACRO: 0.9525 | F1 MICRO: 0.9539
# EPOCH 7 | LOSS: 2.3009731769561768 | ACCURACY: 0.9345 | F1 MACRO: 0.9572 | F1 MICRO: 0.9593
# EPOCH 8 | LOSS: 2.230914354324341 | ACCURACY: 0.9412 | F1 MACRO: 0.9618 | F1 MICRO: 0.9634
# EPOCH 9 | LOSS: 2.125426769256592 | ACCURACY: 0.9397 | F1 MACRO: 0.9604 | F1 MICRO: 0.9624
# EPOCH 10 | LOSS: 1.9919514656066895 | ACCURACY: 0.9472 | F1 MACRO: 0.9655 | F1 MICRO: 0.9671
# aspect: ACCURACY 0.9472 | F1 MACRO 0.9655 | F1 MICRO 0.9671
#               precision    recall  f1-score   support
#
#         fuel       0.96      1.00      0.98       187
#      machine       0.93      0.99      0.96       175
#       others       0.89      0.94      0.92       158
#         part       0.95      0.97      0.96       158
#        price       0.99      0.99      0.99       192
#      service       0.97      1.00      0.98       191
#
#    micro avg       0.95      0.98      0.97      1061
#    macro avg       0.95      0.98      0.97      1061
# weighted avg       0.95      0.98      0.97      1061
#  samples avg       0.95      0.98      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 9.876070022583008 | ACCURACY: 0.9073 | F1 MACRO: 0.8979 | F1 MICRO: 0.9073
# EPOCH 2 | LOSS: 7.613382339477539 | ACCURACY: 0.9234 | F1 MACRO: 0.9121 | F1 MICRO: 0.9234
# EPOCH 3 | LOSS: 6.769907474517822 | ACCURACY: 0.9274 | F1 MACRO: 0.917 | F1 MICRO: 0.9274
# EPOCH 4 | LOSS: 6.2905778884887695 | ACCURACY: 0.8952 | F1 MACRO: 0.8872 | F1 MICRO: 0.8952
# EPOCH 5 | LOSS: 6.1135783195495605 | ACCURACY: 0.9113 | F1 MACRO: 0.8998 | F1 MICRO: 0.9113
# EPOCH 6 | LOSS: 5.5879435539245605 | ACCURACY: 0.9355 | F1 MACRO: 0.9276 | F1 MICRO: 0.9355
# EPOCH 7 | LOSS: 5.76362943649292 | ACCURACY: 0.9234 | F1 MACRO: 0.9132 | F1 MICRO: 0.9234
# EPOCH 8 | LOSS: 5.58192777633667 | ACCURACY: 0.9234 | F1 MACRO: 0.9147 | F1 MICRO: 0.9234
# EPOCH 9 | LOSS: 5.456392765045166 | ACCURACY: 0.9234 | F1 MACRO: 0.9126 | F1 MICRO: 0.9234
# in second
# EPOCH 10 | LOSS: 5.145182132720947 | ACCURACY: 0.9234 | F1 MACRO: 0.9147 | F1 MICRO: 0.9234
# sentiment: ACCURACY 0.9355 | F1 MACRO 0.9276 | F1 MICRO 0.9355
#               precision    recall  f1-score   support
#
#     negative       0.86      0.95      0.90        79
#     positive       0.98      0.93      0.95       169
#
#     accuracy                           0.94       248
#    macro avg       0.92      0.94      0.93       248
# weighted avg       0.94      0.94      0.94       248
#
# --------------------------------------------------
# Iteration 274: Accuracy: 0.9406, F1 Micro: 0.9406, F1 Macro: 0.8755
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.98      1.00      0.99       181
#     positive       1.00      0.88      0.93        24
#
#     accuracy                           0.99       216
#    macro avg       0.99      0.96      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.56      0.64        16
#      neutral       0.94      0.98      0.96       167
#     positive       0.84      0.79      0.81        33
#
#     accuracy                           0.92       216
#    macro avg       0.84      0.78      0.80       216
# weighted avg       0.91      0.92      0.91       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.67      0.83      0.74        12
#      neutral       0.93      0.93      0.93       152
#     positive       0.84      0.79      0.81        52
#
#     accuracy                           0.89       216
#    macro avg       0.81      0.85      0.83       216
# weighted avg       0.90      0.89      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.67      0.96      0.79        23
#      neutral       0.96      0.96      0.96       152
#     positive       0.97      0.73      0.83        41
#
#     accuracy                           0.92       216
#    macro avg       0.86      0.88      0.86       216
# weighted avg       0.93      0.92      0.92       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.92      0.86        13
#      neutral       0.98      0.98      0.98       186
#     positive       0.87      0.76      0.81        17
#
#     accuracy                           0.96       216
#    macro avg       0.88      0.89      0.88       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.86      0.89        14
#      neutral       0.97      1.00      0.98       185
#     positive       1.00      0.71      0.83        17
#
#     accuracy                           0.97       216
#    macro avg       0.96      0.85      0.90       216
# weighted avg       0.97      0.97      0.97       216
#
# Launching training on 2 GPUs.
# 562 562
# Nearest checkpoint: 540
# Threshold: 88272.1328125
# Samples above threshold: 59
# Acquired samples: 59
# Sampling duration: 11.81812334060669 seconds
# New train size: 333
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.5394630432128906 | ACCURACY: 0.7924 | F1 MACRO: 0.8822 | F1 MICRO: 0.8837
# EPOCH 2 | LOSS: 2.988337755203247 | ACCURACY: 0.8185 | F1 MACRO: 0.8947 | F1 MICRO: 0.8963
# EPOCH 3 | LOSS: 2.603705406188965 | ACCURACY: 0.8467 | F1 MACRO: 0.9097 | F1 MICRO: 0.9106
# EPOCH 4 | LOSS: 2.512910842895508 | ACCURACY: 0.9085 | F1 MACRO: 0.9432 | F1 MICRO: 0.9444
# EPOCH 5 | LOSS: 2.446659564971924 | ACCURACY: 0.9211 | F1 MACRO: 0.949 | F1 MICRO: 0.9513
# EPOCH 6 | LOSS: 2.4117987155914307 | ACCURACY: 0.9345 | F1 MACRO: 0.9575 | F1 MICRO: 0.9593
# EPOCH 7 | LOSS: 2.31687068939209 | ACCURACY: 0.9405 | F1 MACRO: 0.9601 | F1 MICRO: 0.9625
# EPOCH 8 | LOSS: 2.1408674716949463 | ACCURACY: 0.9442 | F1 MACRO: 0.9639 | F1 MICRO: 0.9654
# EPOCH 9 | LOSS: 2.0276052951812744 | ACCURACY: 0.9464 | F1 MACRO: 0.965 | F1 MICRO: 0.9666
# EPOCH 10 | LOSS: 2.0126280784606934 | ACCURACY: 0.9531 | F1 MACRO: 0.9694 | F1 MICRO: 0.9707
# aspect: ACCURACY 0.9531 | F1 MACRO 0.9694 | F1 MICRO 0.9707
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.93      0.98      0.96       175
#       others       0.90      0.96      0.93       158
#         part       0.96      0.97      0.97       158
#        price       0.98      0.99      0.98       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.96      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 8.851564407348633 | ACCURACY: 0.9274 | F1 MACRO: 0.917 | F1 MICRO: 0.9274
# EPOCH 2 | LOSS: 6.6864013671875 | ACCURACY: 0.9315 | F1 MACRO: 0.9237 | F1 MICRO: 0.9315
# EPOCH 3 | LOSS: 5.956968307495117 | ACCURACY: 0.9355 | F1 MACRO: 0.9284 | F1 MICRO: 0.9355
# EPOCH 4 | LOSS: 5.423599720001221 | ACCURACY: 0.9435 | F1 MACRO: 0.9358 | F1 MICRO: 0.9435
# EPOCH 5 | LOSS: 5.014974117279053 | ACCURACY: 0.9395 | F1 MACRO: 0.9323 | F1 MICRO: 0.9395
# EPOCH 6 | LOSS: 4.775430679321289 | ACCURACY: 0.9395 | F1 MACRO: 0.931 | F1 MICRO: 0.9395
# EPOCH 7 | LOSS: 5.020511150360107 | ACCURACY: 0.9315 | F1 MACRO: 0.9233 | F1 MICRO: 0.9315
# in second
# EPOCH 8 | LOSS: 4.509501934051514 | ACCURACY: 0.9395 | F1 MACRO: 0.9331 | F1 MICRO: 0.9395
# in second
# EPOCH 9 | LOSS: 4.451722145080566 | ACCURACY: 0.9435 | F1 MACRO: 0.937 | F1 MICRO: 0.9435
# in second
# EPOCH 10 | LOSS: 4.423491954803467 | ACCURACY: 0.9355 | F1 MACRO: 0.9284 | F1 MICRO: 0.9355
# sentiment: ACCURACY 0.9435 | F1 MACRO 0.9358 | F1 MICRO 0.9435
#               precision    recall  f1-score   support
#
#     negative       0.90      0.93      0.91        80
#     positive       0.96      0.95      0.96       168
#
#     accuracy                           0.94       248
#    macro avg       0.93      0.94      0.94       248
# weighted avg       0.94      0.94      0.94       248
#
# --------------------------------------------------
# Iteration 333: Accuracy: 0.9414, F1 Micro: 0.9414, F1 Macro: 0.8816
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.98      1.00      0.99       181
#     positive       1.00      0.88      0.93        24
#
#     accuracy                           0.99       216
#    macro avg       0.99      0.96      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.90      0.56      0.69        16
#      neutral       0.94      0.98      0.96       167
#     positive       0.81      0.76      0.78        33
#
#     accuracy                           0.92       216
#    macro avg       0.88      0.77      0.81       216
# weighted avg       0.91      0.92      0.91       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.71      0.83      0.77        12
#      neutral       0.93      0.93      0.93       152
#     positive       0.82      0.79      0.80        52
#
#     accuracy                           0.89       216
#    macro avg       0.82      0.85      0.83       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.69      0.87      0.77        23
#      neutral       0.96      0.96      0.96       152
#     positive       0.89      0.76      0.82        41
#
#     accuracy                           0.91       216
#    macro avg       0.85      0.86      0.85       216
# weighted avg       0.92      0.91      0.91       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.92      0.86        13
#      neutral       0.98      0.99      0.99       186
#     positive       0.93      0.76      0.84        17
#
#     accuracy                           0.97       216
#    macro avg       0.90      0.89      0.89       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.86      0.89        14
#      neutral       0.98      1.00      0.99       185
#     positive       1.00      0.82      0.90        17
#
#     accuracy                           0.98       216
#    macro avg       0.97      0.89      0.93       216
# weighted avg       0.98      0.98      0.98       216
#
# Launching training on 2 GPUs.
# 507 507
# Nearest checkpoint: 540
# Threshold: 88418.4140625
# Samples above threshold: 54
# Acquired samples: 54
# Sampling duration: 12.894850730895996 seconds
# New train size: 387
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.3281850814819336 | ACCURACY: 0.7902 | F1 MACRO: 0.8812 | F1 MICRO: 0.8827
# EPOCH 2 | LOSS: 2.761223793029785 | ACCURACY: 0.8266 | F1 MACRO: 0.8984 | F1 MICRO: 0.9
# EPOCH 3 | LOSS: 2.530912160873413 | ACCURACY: 0.8638 | F1 MACRO: 0.9196 | F1 MICRO: 0.9201
# EPOCH 4 | LOSS: 2.447314500808716 | ACCURACY: 0.9249 | F1 MACRO: 0.9524 | F1 MICRO: 0.9539
# EPOCH 5 | LOSS: 2.3336269855499268 | ACCURACY: 0.9345 | F1 MACRO: 0.9573 | F1 MICRO: 0.9594
# EPOCH 6 | LOSS: 2.245976209640503 | ACCURACY: 0.9472 | F1 MACRO: 0.9651 | F1 MICRO: 0.9669
# EPOCH 7 | LOSS: 2.1472880840301514 | ACCURACY: 0.9568 | F1 MACRO: 0.9714 | F1 MICRO: 0.973
# EPOCH 8 | LOSS: 1.9984853267669678 | ACCURACY: 0.9539 | F1 MACRO: 0.9699 | F1 MICRO: 0.9713
# EPOCH 9 | LOSS: 1.9397659301757812 | ACCURACY: 0.9576 | F1 MACRO: 0.9723 | F1 MICRO: 0.9734
# EPOCH 10 | LOSS: 1.9024146795272827 | ACCURACY: 0.9494 | F1 MACRO: 0.9666 | F1 MICRO: 0.9683
# aspect: ACCURACY 0.9576 | F1 MACRO 0.9723 | F1 MICRO 0.9734
#               precision    recall  f1-score   support
#
#         fuel       0.98      0.99      0.99       187
#      machine       0.95      0.98      0.96       175
#       others       0.91      0.94      0.93       158
#         part       0.98      0.98      0.98       158
#        price       0.98      0.99      0.98       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.96      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 7.559547424316406 | ACCURACY: 0.9186 | F1 MACRO: 0.907 | F1 MICRO: 0.9186
# EPOCH 2 | LOSS: 5.847355365753174 | ACCURACY: 0.9341 | F1 MACRO: 0.9265 | F1 MICRO: 0.9341
# EPOCH 3 | LOSS: 5.317635536193848 | ACCURACY: 0.938 | F1 MACRO: 0.9302 | F1 MICRO: 0.938
# EPOCH 4 | LOSS: 4.839901447296143 | ACCURACY: 0.9302 | F1 MACRO: 0.919 | F1 MICRO: 0.9302
# EPOCH 5 | LOSS: 4.5297064781188965 | ACCURACY: 0.9302 | F1 MACRO: 0.9201 | F1 MICRO: 0.9302
# EPOCH 6 | LOSS: 4.5202436447143555 | ACCURACY: 0.9457 | F1 MACRO: 0.9393 | F1 MICRO: 0.9457
# EPOCH 7 | LOSS: 4.224447727203369 | ACCURACY: 0.9419 | F1 MACRO: 0.9355 | F1 MICRO: 0.9419
# EPOCH 8 | LOSS: 4.273059368133545 | ACCURACY: 0.9302 | F1 MACRO: 0.9196 | F1 MICRO: 0.9302
# EPOCH 9 | LOSS: 4.265288829803467 | ACCURACY: 0.9419 | F1 MACRO: 0.9344 | F1 MICRO: 0.9419
# in second
# EPOCH 10 | LOSS: 4.037377834320068 | ACCURACY: 0.9496 | F1 MACRO: 0.9431 | F1 MICRO: 0.9496
# sentiment: ACCURACY 0.9457 | F1 MACRO 0.9393 | F1 MICRO 0.9457
#               precision    recall  f1-score   support
#
#     negative       0.88      0.96      0.92        83
#     positive       0.98      0.94      0.96       175
#
#     accuracy                           0.95       258
#    macro avg       0.93      0.95      0.94       258
# weighted avg       0.95      0.95      0.95       258
#
# --------------------------------------------------
# Iteration 387: Accuracy: 0.9514, F1 Micro: 0.9514, F1 Macro: 0.9003
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.96      0.96      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.98      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.69      0.69      0.69        16
#      neutral       0.96      0.98      0.97       167
#     positive       0.90      0.79      0.84        33
#
#     accuracy                           0.93       216
#    macro avg       0.85      0.82      0.83       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.71      0.83      0.77        12
#      neutral       0.93      0.95      0.94       152
#     positive       0.85      0.77      0.81        52
#
#     accuracy                           0.90       216
#    macro avg       0.83      0.85      0.84       216
# weighted avg       0.90      0.90      0.90       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.66      1.00      0.79        23
#      neutral       0.98      0.95      0.97       152
#     positive       0.97      0.78      0.86        41
#
#     accuracy                           0.93       216
#    macro avg       0.87      0.91      0.87       216
# weighted avg       0.94      0.93      0.93       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.92      0.89        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.93      0.82      0.87        17
#
#     accuracy                           0.98       216
#    macro avg       0.93      0.91      0.92       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.93      0.93        14
#      neutral       0.99      1.00      0.99       185
#     positive       1.00      0.88      0.94        17
#
#     accuracy                           0.99       216
#    macro avg       0.97      0.94      0.95       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 464 464
# Nearest checkpoint: 540
# Threshold: 88240.53125
# Samples above threshold: 48
# Acquired samples: 48
# Sampling duration: 13.576672077178955 seconds
# New train size: 435
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.260685443878174 | ACCURACY: 0.7909 | F1 MACRO: 0.8814 | F1 MICRO: 0.883
# EPOCH 2 | LOSS: 2.6448428630828857 | ACCURACY: 0.8333 | F1 MACRO: 0.9019 | F1 MICRO: 0.9032
# EPOCH 3 | LOSS: 2.4250011444091797 | ACCURACY: 0.8631 | F1 MACRO: 0.9122 | F1 MICRO: 0.917
# EPOCH 4 | LOSS: 2.3178396224975586 | ACCURACY: 0.9249 | F1 MACRO: 0.9515 | F1 MICRO: 0.9533
# EPOCH 5 | LOSS: 2.2478535175323486 | ACCURACY: 0.9412 | F1 MACRO: 0.962 | F1 MICRO: 0.9635
# EPOCH 6 | LOSS: 2.1445889472961426 | ACCURACY: 0.9531 | F1 MACRO: 0.9696 | F1 MICRO: 0.9708
# EPOCH 7 | LOSS: 2.0125415325164795 | ACCURACY: 0.9539 | F1 MACRO: 0.9693 | F1 MICRO: 0.9711
# EPOCH 8 | LOSS: 1.9715322256088257 | ACCURACY: 0.9509 | F1 MACRO: 0.9672 | F1 MICRO: 0.9691
# EPOCH 9 | LOSS: 1.8295427560806274 | ACCURACY: 0.9591 | F1 MACRO: 0.9729 | F1 MICRO: 0.9743
# EPOCH 10 | LOSS: 1.7708067893981934 | ACCURACY: 0.9546 | F1 MACRO: 0.9697 | F1 MICRO: 0.9715
# aspect: ACCURACY 0.9591 | F1 MACRO 0.9729 | F1 MICRO 0.9743
#               precision    recall  f1-score   support
#
#         fuel       0.98      0.99      0.99       187
#      machine       0.95      0.98      0.97       175
#       others       0.93      0.94      0.93       158
#         part       0.97      0.97      0.97       158
#        price       0.98      0.99      0.99       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.97      0.98      0.97      1061
#    macro avg       0.97      0.98      0.97      1061
# weighted avg       0.97      0.98      0.97      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.875280380249023 | ACCURACY: 0.8996 | F1 MACRO: 0.8824 | F1 MICRO: 0.8996
# EPOCH 2 | LOSS: 5.453408241271973 | ACCURACY: 0.9382 | F1 MACRO: 0.9319 | F1 MICRO: 0.9382
# EPOCH 3 | LOSS: 4.6619415283203125 | ACCURACY: 0.9228 | F1 MACRO: 0.9124 | F1 MICRO: 0.9228
# EPOCH 4 | LOSS: 4.505377769470215 | ACCURACY: 0.9228 | F1 MACRO: 0.9096 | F1 MICRO: 0.9228
# EPOCH 5 | LOSS: 4.188765525817871 | ACCURACY: 0.9344 | F1 MACRO: 0.9249 | F1 MICRO: 0.9344
# in second
# EPOCH 6 | LOSS: 3.8465399742126465 | ACCURACY: 0.9421 | F1 MACRO: 0.9345 | F1 MICRO: 0.9421
# in second
# EPOCH 7 | LOSS: 3.6944758892059326 | ACCURACY: 0.9421 | F1 MACRO: 0.9349 | F1 MICRO: 0.9421
# in second
# EPOCH 8 | LOSS: 3.746704339981079 | ACCURACY: 0.9421 | F1 MACRO: 0.9345 | F1 MICRO: 0.9421
# in second
# EPOCH 9 | LOSS: 3.572563648223877 | ACCURACY: 0.9421 | F1 MACRO: 0.9345 | F1 MICRO: 0.9421
# in second
# EPOCH 10 | LOSS: 3.675213575363159 | ACCURACY: 0.9421 | F1 MACRO: 0.9345 | F1 MICRO: 0.9421
# sentiment: ACCURACY 0.9382 | F1 MACRO 0.9319 | F1 MICRO 0.9382
#               precision    recall  f1-score   support
#
#     negative       0.85      0.99      0.91        83
#     positive       0.99      0.91      0.95       176
#
#     accuracy                           0.94       259
#    macro avg       0.92      0.95      0.93       259
# weighted avg       0.95      0.94      0.94       259
#
# --------------------------------------------------
# Iteration 435: Accuracy: 0.9468, F1 Micro: 0.9468, F1 Macro: 0.8892
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.92      1.00      0.96        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.99       216
#    macro avg       0.96      0.97      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.71      0.75      0.73        16
#      neutral       0.96      0.98      0.97       167
#     positive       0.93      0.79      0.85        33
#
#     accuracy                           0.94       216
#    macro avg       0.86      0.84      0.85       216
# weighted avg       0.94      0.94      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.61      0.92      0.73        12
#      neutral       0.93      0.92      0.92       152
#     positive       0.83      0.75      0.79        52
#
#     accuracy                           0.88       216
#    macro avg       0.79      0.86      0.82       216
# weighted avg       0.89      0.88      0.88       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.66      1.00      0.79        23
#      neutral       0.98      0.96      0.97       152
#     positive       0.97      0.76      0.85        41
#
#     accuracy                           0.93       216
#    macro avg       0.87      0.91      0.87       216
# weighted avg       0.94      0.93      0.93       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.92      0.89        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.93      0.82      0.87        17
#
#     accuracy                           0.98       216
#    macro avg       0.93      0.91      0.92       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.93      0.90        14
#      neutral       0.98      1.00      0.99       185
#     positive       1.00      0.76      0.87        17
#
#     accuracy                           0.98       216
#    macro avg       0.95      0.90      0.92       216
# weighted avg       0.98      0.98      0.98       216
#
# Launching training on 2 GPUs.
# 415 415
# Nearest checkpoint: 540
# Threshold: 88126.5234375
# Samples above threshold: 43
# Acquired samples: 43
# Sampling duration: 14.117955923080444 seconds
# New train size: 478
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.2332496643066406 | ACCURACY: 0.7917 | F1 MACRO: 0.8802 | F1 MICRO: 0.8824
# EPOCH 2 | LOSS: 2.6075425148010254 | ACCURACY: 0.8363 | F1 MACRO: 0.904 | F1 MICRO: 0.905
# EPOCH 3 | LOSS: 2.4171435832977295 | ACCURACY: 0.8958 | F1 MACRO: 0.9363 | F1 MICRO: 0.9372
# EPOCH 4 | LOSS: 2.3001506328582764 | ACCURACY: 0.9375 | F1 MACRO: 0.9601 | F1 MICRO: 0.9612
# EPOCH 5 | LOSS: 2.2226126194000244 | ACCURACY: 0.9449 | F1 MACRO: 0.9639 | F1 MICRO: 0.9656
# EPOCH 6 | LOSS: 2.1040198802948 | ACCURACY: 0.9382 | F1 MACRO: 0.9578 | F1 MICRO: 0.961
# EPOCH 7 | LOSS: 1.9593889713287354 | ACCURACY: 0.9546 | F1 MACRO: 0.9699 | F1 MICRO: 0.9716
# EPOCH 8 | LOSS: 1.8920778036117554 | ACCURACY: 0.9576 | F1 MACRO: 0.972 | F1 MICRO: 0.9734
# EPOCH 9 | LOSS: 1.8366307020187378 | ACCURACY: 0.9568 | F1 MACRO: 0.9717 | F1 MICRO: 0.9729
# EPOCH 10 | LOSS: 1.770310640335083 | ACCURACY: 0.9635 | F1 MACRO: 0.976 | F1 MICRO: 0.9771
# aspect: ACCURACY 0.9635 | F1 MACRO 0.976 | F1 MICRO 0.9771
#               precision    recall  f1-score   support
#
#         fuel       0.98      0.99      0.99       187
#      machine       0.94      0.99      0.96       175
#       others       0.94      0.95      0.95       158
#         part       0.97      0.97      0.97       158
#        price       0.98      0.99      0.99       192
#      service       0.99      1.00      1.00       191
#
#    micro avg       0.97      0.98      0.98      1061
#    macro avg       0.97      0.98      0.98      1061
# weighted avg       0.97      0.98      0.98      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.313754558563232 | ACCURACY: 0.9109 | F1 MACRO: 0.9021 | F1 MICRO: 0.9109
# EPOCH 2 | LOSS: 4.801041126251221 | ACCURACY: 0.9457 | F1 MACRO: 0.939 | F1 MICRO: 0.9457
# EPOCH 3 | LOSS: 4.418410301208496 | ACCURACY: 0.9264 | F1 MACRO: 0.9136 | F1 MICRO: 0.9264
# EPOCH 4 | LOSS: 4.021539688110352 | ACCURACY: 0.9264 | F1 MACRO: 0.9187 | F1 MICRO: 0.9264
# EPOCH 5 | LOSS: 3.7783565521240234 | ACCURACY: 0.9225 | F1 MACRO: 0.9142 | F1 MICRO: 0.9225
# in second
# EPOCH 6 | LOSS: 3.429117441177368 | ACCURACY: 0.9341 | F1 MACRO: 0.9273 | F1 MICRO: 0.9341
# in second
# EPOCH 7 | LOSS: 3.330380439758301 | ACCURACY: 0.9341 | F1 MACRO: 0.9273 | F1 MICRO: 0.9341
# in second
# EPOCH 8 | LOSS: 3.3738741874694824 | ACCURACY: 0.9341 | F1 MACRO: 0.9273 | F1 MICRO: 0.9341
# in second
# EPOCH 9 | LOSS: 3.3087565898895264 | ACCURACY: 0.9341 | F1 MACRO: 0.9273 | F1 MICRO: 0.9341
# in second
# EPOCH 10 | LOSS: 3.2676186561584473 | ACCURACY: 0.9341 | F1 MACRO: 0.9273 | F1 MICRO: 0.9341
# sentiment: ACCURACY 0.9457 | F1 MACRO 0.939 | F1 MICRO 0.9457
#               precision    recall  f1-score   support
#
#     negative       0.89      0.95      0.92        83
#     positive       0.98      0.94      0.96       175
#
#     accuracy                           0.95       258
#    macro avg       0.93      0.95      0.94       258
# weighted avg       0.95      0.95      0.95       258
#
# --------------------------------------------------
# Iteration 478: Accuracy: 0.9529, F1 Micro: 0.9529, F1 Macro: 0.9029
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.97      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.75      0.83        16
#      neutral       0.95      0.99      0.97       167
#     positive       0.90      0.82      0.86        33
#
#     accuracy                           0.94       216
#    macro avg       0.93      0.85      0.89       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.67      0.83      0.74        12
#      neutral       0.94      0.94      0.94       152
#     positive       0.86      0.81      0.83        52
#
#     accuracy                           0.90       216
#    macro avg       0.82      0.86      0.84       216
# weighted avg       0.91      0.90      0.90       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.70      1.00      0.82        23
#      neutral       0.97      0.96      0.97       152
#     positive       0.97      0.78      0.86        41
#
#     accuracy                           0.93       216
#    macro avg       0.88      0.91      0.88       216
# weighted avg       0.94      0.93      0.93       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.85      0.85        13
#      neutral       0.98      0.99      0.99       186
#     positive       0.86      0.71      0.77        17
#
#     accuracy                           0.96       216
#    macro avg       0.89      0.85      0.87       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.93      0.93        14
#      neutral       0.99      1.00      1.00       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       0.97      0.96      0.97       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 378 378
# Nearest checkpoint: 540
# Threshold: 88218.0625
# Samples above threshold: 39
# Acquired samples: 39
# Sampling duration: 14.791561365127563 seconds
# New train size: 517
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.2356228828430176 | ACCURACY: 0.7946 | F1 MACRO: 0.8833 | F1 MICRO: 0.8848
# EPOCH 2 | LOSS: 2.6134395599365234 | ACCURACY: 0.849 | F1 MACRO: 0.9121 | F1 MICRO: 0.9125
# EPOCH 3 | LOSS: 2.447824716567993 | ACCURACY: 0.933 | F1 MACRO: 0.9572 | F1 MICRO: 0.9586
# EPOCH 4 | LOSS: 2.3375911712646484 | ACCURACY: 0.9435 | F1 MACRO: 0.9628 | F1 MICRO: 0.9648
# EPOCH 5 | LOSS: 2.2374320030212402 | ACCURACY: 0.9435 | F1 MACRO: 0.9633 | F1 MICRO: 0.9649
# EPOCH 6 | LOSS: 2.0747673511505127 | ACCURACY: 0.9554 | F1 MACRO: 0.9702 | F1 MICRO: 0.972
# EPOCH 7 | LOSS: 1.909900426864624 | ACCURACY: 0.9531 | F1 MACRO: 0.9686 | F1 MICRO: 0.9704
# EPOCH 8 | LOSS: 1.896470308303833 | ACCURACY: 0.9509 | F1 MACRO: 0.9669 | F1 MICRO: 0.9691
# EPOCH 9 | LOSS: 1.813819169998169 | ACCURACY: 0.9531 | F1 MACRO: 0.9687 | F1 MICRO: 0.9706
# in second
# ...
#    macro avg       0.96      0.99      0.98      1061
# weighted avg       0.97      0.99      0.98      1061
#  samples avg       0.97      0.99      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.891408681869507 | ACCURACY: 0.9219 | F1 MACRO: 0.9139 | F1 MICRO: 0.9219
# EPOCH 2 | LOSS: 3.0736968517303467 | ACCURACY: 0.9336 | F1 MACRO: 0.9245 | F1 MICRO: 0.9336
# EPOCH 3 | LOSS: 2.550743579864502 | ACCURACY: 0.9375 | F1 MACRO: 0.9291 | F1 MICRO: 0.9375
# EPOCH 4 | LOSS: 2.3583974838256836 | ACCURACY: 0.9141 | F1 MACRO: 0.9062 | F1 MICRO: 0.9141
# EPOCH 5 | LOSS: 2.255049467086792 | ACCURACY: 0.9414 | F1 MACRO: 0.9341 | F1 MICRO: 0.9414
# EPOCH 6 | LOSS: 2.1439309120178223 | ACCURACY: 0.9336 | F1 MACRO: 0.9266 | F1 MICRO: 0.9336
# EPOCH 7 | LOSS: 2.149583339691162 | ACCURACY: 0.9492 | F1 MACRO: 0.9426 | F1 MICRO: 0.9492
# EPOCH 8 | LOSS: 2.027277708053589 | ACCURACY: 0.9297 | F1 MACRO: 0.9221 | F1 MICRO: 0.9297
# EPOCH 9 | LOSS: 2.014364719390869 | ACCURACY: 0.957 | F1 MACRO: 0.9514 | F1 MICRO: 0.957
# EPOCH 10 | LOSS: 2.0003974437713623 | ACCURACY: 0.9375 | F1 MACRO: 0.9311 | F1 MICRO: 0.9375
# sentiment: ACCURACY 0.957 | F1 MACRO 0.9514 | F1 MICRO 0.957
#               precision    recall  f1-score   support
#
#     negative       0.92      0.95      0.93        83
#     positive       0.98      0.96      0.97       173
#
#     accuracy                           0.96       256
#    macro avg       0.95      0.96      0.95       256
# weighted avg       0.96      0.96      0.96       256
#
# --------------------------------------------------
# Iteration 831: Accuracy: 0.9568, F1 Micro: 0.9568, F1 Macro: 0.9084
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.82      0.90        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.92      0.96      0.94        24
#
#     accuracy                           0.98       216
#    macro avg       0.97      0.92      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.88      0.88      0.88        16
#      neutral       0.96      0.97      0.97       167
#     positive       0.81      0.79      0.80        33
#
#     accuracy                           0.94       216
#    macro avg       0.88      0.88      0.88       216
# weighted avg       0.93      0.94      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.75      0.75        12
#      neutral       0.92      0.98      0.95       152
#     positive       0.93      0.75      0.83        52
#
#     accuracy                           0.91       216
#    macro avg       0.87      0.83      0.84       216
# weighted avg       0.91      0.91      0.91       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.77      1.00      0.87        23
#      neutral       0.98      0.97      0.98       152
#     positive       0.97      0.83      0.89        41
#
#     accuracy                           0.95       216
#    macro avg       0.91      0.93      0.91       216
# weighted avg       0.96      0.95      0.95       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.92      0.86        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.93      0.76      0.84        17
#
#     accuracy                           0.97       216
#    macro avg       0.91      0.89      0.90       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.93      0.93        14
#      neutral       0.99      0.99      0.99       185
#     positive       1.00      1.00      1.00        17
#
#     accuracy                           0.99       216
#    macro avg       0.97      0.97      0.97       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 32 32
# Nearest checkpoint: 864
# Threshold: 88293.984375
# Samples above threshold: 4
# Acquired samples: 25
# Sampling duration: 19.321430921554565 seconds
# New train size: 856
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.937873125076294 | ACCURACY: 0.8199 | F1 MACRO: 0.8943 | F1 MICRO: 0.8959
# EPOCH 2 | LOSS: 2.394948959350586 | ACCURACY: 0.9301 | F1 MACRO: 0.9554 | F1 MICRO: 0.9568
# EPOCH 3 | LOSS: 2.259368419647217 | ACCURACY: 0.9516 | F1 MACRO: 0.968 | F1 MICRO: 0.9697
# EPOCH 4 | LOSS: 2.0173349380493164 | ACCURACY: 0.9613 | F1 MACRO: 0.9741 | F1 MICRO: 0.9757
# EPOCH 5 | LOSS: 1.892556071281433 | ACCURACY: 0.9539 | F1 MACRO: 0.9682 | F1 MICRO: 0.9708
# EPOCH 6 | LOSS: 1.7758132219314575 | ACCURACY: 0.9613 | F1 MACRO: 0.9749 | F1 MICRO: 0.9759
# EPOCH 7 | LOSS: 1.7088232040405273 | ACCURACY: 0.9621 | F1 MACRO: 0.9744 | F1 MICRO: 0.976
# EPOCH 8 | LOSS: 1.668283462524414 | ACCURACY: 0.9621 | F1 MACRO: 0.9744 | F1 MICRO: 0.976
# EPOCH 9 | LOSS: 1.595813512802124 | ACCURACY: 0.9576 | F1 MACRO: 0.9711 | F1 MICRO: 0.9732
# EPOCH 10 | LOSS: 1.5688883066177368 | ACCURACY: 0.9628 | F1 MACRO: 0.9749 | F1 MICRO: 0.9765
# aspect: ACCURACY 0.9628 | F1 MACRO 0.9749 | F1 MICRO 0.9765
#               precision    recall  f1-score   support
#
#         fuel       0.98      0.99      0.99       187
#      machine       0.96      0.97      0.97       175
#       others       0.93      0.92      0.93       158
#         part       0.97      0.97      0.97       158
#        price       0.99      0.99      0.99       192
#      service       1.00      1.00      1.00       191
#
#    micro avg       0.97      0.98      0.98      1061
#    macro avg       0.97      0.98      0.97      1061
# weighted avg       0.97      0.98      0.98      1061
#  samples avg       0.97      0.97      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.637305974960327 | ACCURACY: 0.9135 | F1 MACRO: 0.9047 | F1 MICRO: 0.9135
# EPOCH 2 | LOSS: 2.8576059341430664 | ACCURACY: 0.9323 | F1 MACRO: 0.9252 | F1 MICRO: 0.9323
# EPOCH 3 | LOSS: 2.464962959289551 | ACCURACY: 0.9211 | F1 MACRO: 0.9065 | F1 MICRO: 0.9211
# EPOCH 4 | LOSS: 2.2903923988342285 | ACCURACY: 0.9098 | F1 MACRO: 0.9018 | F1 MICRO: 0.9098
# EPOCH 5 | LOSS: 2.230238199234009 | ACCURACY: 0.9286 | F1 MACRO: 0.9204 | F1 MICRO: 0.9286
# in second
# EPOCH 6 | LOSS: 1.9993683099746704 | ACCURACY: 0.9323 | F1 MACRO: 0.9252 | F1 MICRO: 0.9323
# in second
# EPOCH 7 | LOSS: 1.9274154901504517 | ACCURACY: 0.9286 | F1 MACRO: 0.9213 | F1 MICRO: 0.9286
# in second
# EPOCH 8 | LOSS: 1.9396953582763672 | ACCURACY: 0.9323 | F1 MACRO: 0.9252 | F1 MICRO: 0.9323
# in second
# EPOCH 9 | LOSS: 1.9414300918579102 | ACCURACY: 0.9361 | F1 MACRO: 0.9288 | F1 MICRO: 0.9361
# in second
# EPOCH 10 | LOSS: 1.8992737531661987 | ACCURACY: 0.9286 | F1 MACRO: 0.9213 | F1 MICRO: 0.9286
# sentiment: ACCURACY 0.9323 | F1 MACRO 0.9252 | F1 MICRO 0.9323
#               precision    recall  f1-score   support
#
#     negative       0.84      0.98      0.90        85
#     positive       0.99      0.91      0.95       181
#
#     accuracy                           0.93       266
#    macro avg       0.91      0.94      0.93       266
# weighted avg       0.94      0.93      0.93       266
#
# --------------------------------------------------
# Iteration 856: Accuracy: 0.9475, F1 Micro: 0.9475, F1 Macro: 0.894
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.92      1.00      0.96        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.95      0.88      0.91        24
#
#     accuracy                           0.98       216
#    macro avg       0.95      0.96      0.95       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.81      0.81      0.81        16
#      neutral       0.95      0.98      0.96       167
#     positive       0.86      0.76      0.81        33
#
#     accuracy                           0.93       216
#    macro avg       0.88      0.85      0.86       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.58      0.92      0.71        12
#      neutral       0.94      0.89      0.92       152
#     positive       0.77      0.79      0.78        52
#
#     accuracy                           0.87       216
#    macro avg       0.77      0.87      0.80       216
# weighted avg       0.88      0.87      0.87       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.74      1.00      0.85        23
#      neutral       0.97      0.98      0.98       152
#     positive       0.97      0.76      0.85        41
#
#     accuracy                           0.94       216
#    macro avg       0.89      0.91      0.89       216
# weighted avg       0.95      0.94      0.94       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.92      0.86        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.93      0.76      0.84        17
#
#     accuracy                           0.97       216
#    macro avg       0.91      0.89      0.90       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.88      1.00      0.93        14
#      neutral       1.00      1.00      1.00       185
#     positive       1.00      0.88      0.94        17
#
#     accuracy                           0.99       216
#    macro avg       0.96      0.96      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 8 8
# Nearest checkpoint: 864
# Threshold: 88283.6484375
# Samples above threshold: 1
# Acquired samples: 8
# Sampling duration: 19.806941747665405 seconds
# New train size: 864
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.9787611961364746 | ACCURACY: 0.8237 | F1 MACRO: 0.8978 | F1 MICRO: 0.899
# EPOCH 2 | LOSS: 2.3877077102661133 | ACCURACY: 0.9234 | F1 MACRO: 0.9496 | F1 MICRO: 0.9523
# EPOCH 3 | LOSS: 2.233565330505371 | ACCURACY: 0.9561 | F1 MACRO: 0.9717 | F1 MICRO: 0.9728
# EPOCH 4 | LOSS: 1.993683099746704 | ACCURACY: 0.9621 | F1 MACRO: 0.9753 | F1 MICRO: 0.9763
# EPOCH 5 | LOSS: 1.8644750118255615 | ACCURACY: 0.9583 | F1 MACRO: 0.9726 | F1 MICRO: 0.9738
# EPOCH 6 | LOSS: 1.7838935852050781 | ACCURACY: 0.9576 | F1 MACRO: 0.9714 | F1 MICRO: 0.9732
# EPOCH 7 | LOSS: 1.720037579536438 | ACCURACY: 0.9643 | F1 MACRO: 0.976 | F1 MICRO: 0.9775
# EPOCH 8 | LOSS: 1.6466511487960815 | ACCURACY: 0.9613 | F1 MACRO: 0.9739 | F1 MICRO: 0.9756
# EPOCH 9 | LOSS: 1.6141786575317383 | ACCURACY: 0.9628 | F1 MACRO: 0.9749 | F1 MICRO: 0.9766
# EPOCH 10 | LOSS: 1.5759574174880981 | ACCURACY: 0.9591 | F1 MACRO: 0.9723 | F1 MICRO: 0.974
# aspect: ACCURACY 0.9643 | F1 MACRO 0.976 | F1 MICRO 0.9775
#               precision    recall  f1-score   support
#
#         fuel       0.99      0.99      0.99       187
#      machine       0.95      0.99      0.97       175
#       others       0.94      0.93      0.93       158
#         part       0.97      0.97      0.97       158
#        price       0.98      1.00      0.99       192
#      service       0.99      1.00      0.99       191
#
#    micro avg       0.97      0.98      0.98      1061
#    macro avg       0.97      0.98      0.98      1061
# weighted avg       0.97      0.98      0.98      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.7490580081939697 | ACCURACY: 0.9 | F1 MACRO: 0.8911 | F1 MICRO: 0.9
# EPOCH 2 | LOSS: 2.7978641986846924 | ACCURACY: 0.9259 | F1 MACRO: 0.9136 | F1 MICRO: 0.9259
# EPOCH 3 | LOSS: 2.4993274211883545 | ACCURACY: 0.9222 | F1 MACRO: 0.9132 | F1 MICRO: 0.9222
# EPOCH 4 | LOSS: 2.285444974899292 | ACCURACY: 0.9185 | F1 MACRO: 0.9098 | F1 MICRO: 0.9185
# EPOCH 5 | LOSS: 2.2092525959014893 | ACCURACY: 0.9074 | F1 MACRO: 0.8943 | F1 MICRO: 0.9074
# in second
# EPOCH 6 | LOSS: 2.018394947052002 | ACCURACY: 0.9185 | F1 MACRO: 0.9078 | F1 MICRO: 0.9185
# in second
# EPOCH 7 | LOSS: 1.9525657892227173 | ACCURACY: 0.9222 | F1 MACRO: 0.9123 | F1 MICRO: 0.9222
# in second
# EPOCH 8 | LOSS: 1.9077510833740234 | ACCURACY: 0.9222 | F1 MACRO: 0.9123 | F1 MICRO: 0.9222
# in second
# EPOCH 9 | LOSS: 1.9206922054290771 | ACCURACY: 0.9222 | F1 MACRO: 0.9123 | F1 MICRO: 0.9222
# in second
# EPOCH 10 | LOSS: 1.8853791952133179 | ACCURACY: 0.9222 | F1 MACRO: 0.9118 | F1 MICRO: 0.9222
# sentiment: ACCURACY 0.9259 | F1 MACRO 0.9136 | F1 MICRO 0.9259
#               precision    recall  f1-score   support
#
#     negative       0.90      0.86      0.88        86
#     positive       0.94      0.96      0.95       184
#
#     accuracy                           0.93       270
#    macro avg       0.92      0.91      0.91       270
# weighted avg       0.93      0.93      0.93       270
#
# --------------------------------------------------
# Iteration 864: Accuracy: 0.9468, F1 Micro: 0.9468, F1 Macro: 0.8842
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.82      0.90        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.88      0.96      0.92        24
#
#     accuracy                           0.98       216
#    macro avg       0.96      0.92      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.75      0.77        16
#      neutral       0.96      0.98      0.97       167
#     positive       0.81      0.76      0.78        33
#
#     accuracy                           0.93       216
#    macro avg       0.86      0.83      0.84       216
# weighted avg       0.92      0.93      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.59      0.83      0.69        12
#      neutral       0.95      0.91      0.93       152
#     positive       0.76      0.79      0.77        52
#
#     accuracy                           0.88       216
#    macro avg       0.77      0.84      0.80       216
# weighted avg       0.89      0.88      0.88       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.87      0.83        23
#      neutral       0.98      0.96      0.97       152
#     positive       0.88      0.90      0.89        41
#
#     accuracy                           0.94       216
#    macro avg       0.89      0.91      0.90       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.92      0.89        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.93      0.82      0.87        17
#
#     accuracy                           0.98       216
#    macro avg       0.93      0.91      0.92       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.79      0.85        14
#      neutral       1.00      1.00      1.00       185
#     positive       0.84      0.94      0.89        17
#
#     accuracy                           0.98       216
#    macro avg       0.92      0.91      0.91       216
# weighted avg       0.98      0.98      0.98       216
#
# Total sampling time: 356.4 seconds
# Total runtime: 2959.138129234314 seconds
