# %%
import os
import time
import math
import torch
import random
import warnings
import numpy as np
import pandas as pd
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
from torch.multiprocessing import Manager
from torch.utils.data import DataLoader, Dataset
from torch.utils.data.sampler import SubsetRandomSampler
from sklearn.model_selection import train_test_split
from accelerate import Accelerator, notebook_launcher
from transformers import BertTokenizer, BertModel, BertConfig
from sklearn.metrics import precision_recall_fscore_support, f1_score, classification_report

# %% [markdown]
# # SETUP

# %%
warnings.filterwarnings('ignore')

# %%
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic=True
    torch.backends.cudnn.benchmark=False

set_seed(42)

# %% [markdown]
# # GLOBAL VARIABLES

# %%
manager = Manager()

# Shared resources
aspect_accuracies = manager.list()
aspect_f1_micros = manager.list()
aspect_f1_macros = manager.list()
sentiment_accuracies = manager.list()
sentiment_f1_micros = manager.list()
sentiment_f1_macros = manager.list()
accuracies = manager.list()
f1_micros = manager.list()
f1_macros = manager.list()

new_sample_data = manager.list()
new_sample_labels = manager.list()

# Non shared resources
filename = 'casa-comal'
epochs = 10
batch_size = 16
sequence_length = 48

aspect_list = ['fuel', 'machine', 'others', 'part', 'price', 'service']
aspect_mapping = {'fuel': 0, 'machine': 1, 'others': 2, 'part': 3, 'price': 4, 'service': 5 }
label_mapping = {"negative": 0, "neutral": 1, 'positive': 2}
ignored_keys = ['labels', 'ori_text', 'ori_label', 'ori_indices', 'aspect', 'sampler_loss_weight', 'all_labeled_mask']

# %% [markdown]
# # LOAD AND PREPROCESS DATA

# %%
train_data = pd.read_csv('/kaggle/input/casa-dataset/train_preprocess.csv', encoding='latin-1')
val_data = pd.read_csv('/kaggle/input/casa-dataset/valid_preprocess.csv', encoding='latin-1')
test_data = pd.read_csv('/kaggle/input/casa-dataset/test_preprocess.csv', encoding='latin-1')

data = pd.concat([train_data, val_data, test_data], ignore_index=True)

data.head()
# Out:
#                                             sentence      fuel   machine  \
# 0  Saya memakai Honda Jazz GK5 tahun 2014 ( perta...   neutral   neutral
# 1  Avanza kenapa jadi boros bensin begini dah ah....  negative   neutral
# 2  saran ku dan pengalaman ku , mending beli mobi...  positive  positive
# 3  Dari segi harga juga pajero lebih mahal 30 jut...   neutral   neutral
# 4                     Kalo menurut gw enak pajero si   neutral   neutral
#
#      others     part     price  service
# 0  positive  neutral   neutral  neutral
# 1   neutral  neutral   neutral  neutral
# 2   neutral  neutral   neutral  neutral
# 3   neutral  neutral  positive  neutral
# 4  positive  neutral   neutral  neutral

# %%
train_data, val_data = train_test_split(data, test_size=0.2, random_state=42, shuffle=False)

# %%
train_labels = train_data.columns[1:]
val_labels = val_data.columns[1:]

# Extract features and labels for training and validation
X_train = train_data['sentence'].values
y_train = train_data[train_labels].values
X_val = val_data['sentence'].values
y_val = val_data[val_labels].values

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
# Out:
# (864,) (864, 6)
# (216,) (216, 6)

# %% [markdown]
# # BULDING DATASET

# %%
tokenizer = BertTokenizer.from_pretrained('indobenchmark/indobert-base-p1')
review_token = '[REVIEW]'
aspect_token = '[ASPECT]'
special_tokens_dict = {'additional_special_tokens': [review_token, aspect_token]}
num_added_tokens = tokenizer.add_special_tokens(special_tokens_dict)
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/229k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.53k [00:00<?, ?B/s]

# %%
class AspectDetectionDataset(Dataset):
    def __init__(self, data, labels, tokenizer, label2id, aspect_list, max_length=48):
        # Initialize dataset with data, tokenizer, and label mappings
        self.data = data
        self.tokenizer = tokenizer
        self.label2id = label2id
        self.maxlength = sequence_length  # Maximum token length for input sequences
        self.all_labels_num = len(aspect_list)  # Total number of labels
        self.aspect_list = aspect_list
        self.pair_wise_sampled = None  # Tracks sampling status of label pairs
        self.gt_labels = labels  # Ground truth labels in one-hot format
        self.all_labeled_mask = None  # Indicates whether all labels of a sample have been queried
        self.max_length = max_length
        self.init()  # Initializes sampling and label mask states

    def init(self):
        # Initialize sampled pairs and mask for all data
        self.pair_wise_sampled = torch.ones(len(self.data), self.all_labels_num)
        self.all_labeled_mask = torch.zeros(len(self.data))  # Initially, no data is fully labeled

    def get_label_Cardinality(self):
        # Compute label cardinality, representing average positive labels per sample in the labeled pool
        labed_cnt = torch.sum(self.all_labeled_mask)  # Total number of samples fully labeled
        original_labels = torch.tensor([[self.label2id[label] for label in labels] for labels in self.gt_labels], dtype=torch.float32)
        encoded_labels = torch.tensor([[1 if label == 1 else 0 for label in labels] for labels in original_labels], dtype=torch.float32)
        all_labed_pos_label_cnt = torch.sum(self.all_labeled_mask.unsqueeze(-1) * encoded_labels)
        return all_labed_pos_label_cnt / labed_cnt  # Average number of positive labels per fully labeled sample

    def update_data(self, query_example_indices, query_label_indices=None, init_time=False):
        # Update dataset with new labeled data points and labels after each query cycle
        if query_label_indices is not None:
            ones = torch.ones(self.all_labels_num)
            for example_idx, label_idx in zip(query_example_indices, query_label_indices):
                # Access individual data and update based on queried label
                one_data = self.__getitem__(example_idx)
                one_label = one_data[1][label_idx]
                if one_label == 0:
                    # Set pair-wise sampled state for newly queried labels
                    self.pair_wise_sampled[example_idx][label_idx] = 1
                else:
                    self.pair_wise_sampled[example_idx][label_idx] = 1
                
                # Update all_labeled_mask if all labels for a sample are queried
                if torch.sum(ones - self.pair_wise_sampled[example_idx]) == 0:
                    self.all_labeled_mask[example_idx] = 1
        else:
            # Mark all labels as queried for each example if only examples are specified
            for example_idx in query_example_indices:
                ones = torch.ones(self.all_labels_num)
                self.pair_wise_sampled[example_idx] = ones
                self.all_labeled_mask[example_idx] = 1

    def get_labeled_set(self):
        # Return list of indices for samples that have been fully labeled
        labeled_set = []
        for idx, mask in enumerate(self.all_labeled_mask):
            if mask != 0:
                labeled_set.append(idx)
        return labeled_set

    def __len__(self):
        # Return the number of samples in the dataset
        return len(self.data)

    def __getitem__(self, idx):
        text = self.data[idx] 
        original_labels = torch.tensor([self.label2id[label] for label in self.gt_labels[idx]], dtype=torch.float32)
        encoded_labels = torch.tensor([1 if label == 1 else 0 for label in original_labels], dtype=torch.float32)

        # Tokenize the raw text and apply padding/truncation to reach maxlength
        encoding = self.tokenizer(
            text,
            padding='max_length',
            truncation=True,
            max_length=self.max_length,
            return_tensors="pt"
        )

        input_ids = encoding['input_ids'].squeeze(0)  # Remove batch dimension
        input_type_ids = encoding.get('token_type_ids', torch.zeros_like(input_ids))
        input_mask = encoding['attention_mask'].squeeze(0)
        text_inputs = [input_ids, input_type_ids, input_mask]
        sampler_loss_weight = self.pair_wise_sampled[idx]  # Weight for active learning sample 

        inputs_list = [text_inputs, encoded_labels, idx, sampler_loss_weight, self.all_labeled_mask[idx], text, original_labels]
        return inputs_list

# %%
class SentimentAnalysisDataset(Dataset):
    def __init__(self, data, labels, aspects, indices, tokenizer, label2id, max_length):
        # Initialize dataset with data, tokenizer, and label mappings
        self.data = data
        self.tokenizer = tokenizer
        self.label2id = label2id
        self.maxlength = sequence_length  # Maximum token length for input sequences
        self.all_labels_num = 2
        self.pair_wise_sampled = None  # Tracks sampling status of label pairs
        self.gt_labels = labels  # Ground truth labels in one-hot format
        self.all_labeled_mask = None  # Indicates whether all labels of a sample have been queried
        self.aspects = aspects
        self.indices = indices
        self.max_length = max_length
        self.init()  # Initializes sampling and label mask states

    def init(self):
        # Initialize sampled pairs and mask for all data
        self.pair_wise_sampled = torch.ones(len(self.data), self.all_labels_num)
        self.all_labeled_mask = torch.zeros(len(self.data))  # Initially, no data is fully labeled

    def get_label_Cardinality(self):
        # Compute label cardinality, representing average positive labels per sample in the labeled pool
        labed_cnt = torch.sum(self.all_labeled_mask)  # Total number of samples fully labeled
        all_labed_pos_label_cnt = torch.sum(self.all_labeled_mask.unsqueeze(-1) * self.gt_labels)
        return all_labed_pos_label_cnt / labed_cnt  # Average number of positive labels per fully labeled sample

    def update_data(self, query_example_indices, query_label_indices=None, init_time=False):
        # Update dataset with new labeled data points and labels after each query cycle
        if query_label_indices is not None:
            ones = torch.ones(self.all_labels_num)
            for example_idx, label_idx in zip(query_example_indices, query_label_indices):
                # Access individual data and update based on queried label
                one_data = self.__getitem__(example_idx)
                one_label = one_data[1][label_idx]
                if one_label == 0:
                    # Set pair-wise sampled state for newly queried labels
                    self.pair_wise_sampled[example_idx][label_idx] = 1
                else:
                    self.pair_wise_sampled[example_idx][label_idx] = 1
                
                # Update all_labeled_mask if all labels for a sample are queried
                if torch.sum(ones - self.pair_wise_sampled[example_idx]) == 0:
                    self.all_labeled_mask[example_idx] = 1
        else:
            # Mark all labels as queried for each example if only examples are specified
            for example_idx in query_example_indices:
                ones = torch.ones(self.all_labels_num)
                self.pair_wise_sampled[example_idx] = ones
                self.all_labeled_mask[example_idx] = 1

    def get_labeled_set(self):
        # Return list of indices for samples that have been fully labeled
        labeled_set = []
        for idx, mask in enumerate(self.all_labeled_mask):
            if mask != 0:
                labeled_set.append(idx)
        return labeled_set

    def __len__(self):
        # Return the number of samples in the dataset
        return len(self.data)

    def __getitem__(self, idx):
        text = aspect_token + ' ' + self.aspects[idx] + ' ' + review_token + ' ' + self.data[idx] 

        # Tokenize the raw text and apply padding/truncation to reach maxlength
        encoding = self.tokenizer(
            text,
            padding='max_length',
            truncation=True,
            max_length=self.max_length,
            return_tensors="pt"
        )

        if isinstance(self.gt_labels[idx], str):
            self.gt_labels[idx] = self.label2id[self.gt_labels[idx]]
        elif torch.is_tensor(self.gt_labels[idx]):
            self.gt_labels[idx] = int(self.gt_labels[idx].item())

        encoded_label = 1 if self.gt_labels[idx] == 2 else self.gt_labels[idx]
        one_hot_label = F.one_hot(torch.tensor(encoded_label, dtype=torch.long), num_classes=2).float()

        input_ids = encoding['input_ids'].squeeze(0)  # Remove batch dimension
        input_type_ids = encoding.get('token_type_ids', torch.zeros_like(input_ids))
        input_mask = encoding['attention_mask'].squeeze(0)
        text_inputs = [input_ids, input_type_ids, input_mask]
        sampler_loss_weight = self.pair_wise_sampled[idx]  # Weight for active learning sample 
        original_label = torch.tensor(self.gt_labels[idx], dtype=torch.long)
        aspect = self.aspects[idx]

        inputs_list = [text_inputs, one_hot_label, idx, sampler_loss_weight, self.all_labeled_mask[idx], text, original_label, aspect, self.indices[idx]]
        return inputs_list

# %%
def build_aspect_dataset(X_train, y_train, X_val, y_val, sequence_length, num_workers=4):
    train_dataset = AspectDetectionDataset(X_train, y_train, tokenizer, label_mapping, aspect_list, max_length=sequence_length)
    val_dataset = AspectDetectionDataset(X_val, y_val, tokenizer, label_mapping, aspect_list, max_length=sequence_length)
    
    train_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=batch_size, shuffle=True, pin_memory=True, num_workers=num_workers,
    )
    val_loader = torch.utils.data.DataLoader(
        val_dataset, batch_size=batch_size, shuffle=False, pin_memory=True, num_workers=num_workers, 
    )

    return train_loader, val_loader, train_dataset, val_dataset

# %%
def build_sentiment_dataset(device, train_dataset, val_dataset, aspect_detection_model, tokenizer, max_length=sequence_length):
    train_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=batch_size, shuffle=False, pin_memory=True, num_workers=4, 
    )
    val_loader = torch.utils.data.DataLoader(
        val_dataset, batch_size=batch_size, shuffle=False, pin_memory=True, num_workers=4, 
    )

    aspect_detection_model.to(device)
    aspect_detection_model.eval()

    train_data = []
    train_labels = []
    train_aspects = []
    train_indices = []

    val_data = []
    val_labels = []
    val_aspects = []
    val_indices = []

    # Transform train set
    with torch.no_grad():
        for batch in train_loader:
            input_ids, input_type_ids, input_mask = [x.to(device) for x in batch[0]]
            inputs_list = [input_ids, input_type_ids, input_mask, None]
            
            outputs = aspect_detection_model(inputs_list)
            preds = torch.sigmoid(outputs[0]).round()

            for i in range(len(preds)):
                for j in range(len(preds[i])):
                    if int(preds[i][j]) != 1:
                        train_aspects.append(aspect_list[j])
                        train_data.append(batch[5][i])
                        train_labels.append(batch[6][i][j])
                        train_indices.append(batch[2][i])
            
        # Transform validation set
        for batch in val_loader:
            input_ids, input_type_ids, input_mask = [x.to(device) for x in batch[0]]
            inputs_list = [input_ids, input_type_ids, input_mask, None]
            
            outputs = aspect_detection_model(inputs_list)
            preds = torch.sigmoid(outputs[0]).round()

            for i in range(len(preds)):
                for j in range(len(preds[i])):
                    if int(preds[i][j]) != 1:
                        val_aspects.append(aspect_list[j])
                        val_data.append(batch[5][i])
                        val_labels.append(batch[6][i][j])
                        val_indices.append(batch[2][i])

    train_dataset = SentimentAnalysisDataset(train_data, train_labels, train_aspects, train_indices, tokenizer, label_mapping, max_length=max_length)
    val_dataset = SentimentAnalysisDataset(val_data, val_labels, val_aspects, val_indices, tokenizer, label_mapping, max_length=max_length)

    train_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=batch_size, shuffle=True, pin_memory=True, num_workers=4, 
    )
    val_loader = torch.utils.data.DataLoader(
        val_dataset, batch_size=batch_size, shuffle=False, pin_memory=True, num_workers=4, 
    )

    return train_loader, val_loader, train_dataset, val_dataset

# %% [markdown]
# # DEFINE THE MODEL

# %%
class IndoBERT_Backbone(nn.Module):
    def __init__(self, label_num):
        super(IndoBERT_Backbone, self).__init__()
        self.label_num = label_num
        self.encoder = IndoBERT_Encoder(label_num)
        model_config = BertConfig.from_pretrained("indobenchmark/indobert-base-p1")
        self.clf = nn.Linear(model_config.hidden_size, label_num)
        nn.init.xavier_uniform_(self.clf.weight)

    def forward(self, inputs):
        encoder_out = self.encoder(inputs)
        out = self.clf(encoder_out)
        return out, encoder_out

class IndoBERT_Encoder(nn.Module):
    def __init__(self, label_num):
        super(IndoBERT_Encoder, self).__init__()
        self.label_num = label_num
        self.encoder = BertModel.from_pretrained(
            'indobenchmark/indobert-base-p1',
            num_labels=self.label_num,
        )
        
        self.encoder_init()

    def encoder_init(self):
        all_layers = ['embeddings', 'layer.0', 'layer.1', 'layer.2', 'layer.3', 'layer.4', 'layer.5', 'layer.6',
                      'layer.7', 'layer.8', 'layer.9', 'layer.10', 'layer.11', 'pooler']
        unfreeze_layers = all_layers[7:]
        for name, param in self.encoder.named_parameters():
            param.requires_grad = False
            for ele in unfreeze_layers:
                if ele in name:
                    param.requires_grad = True
                    break

    def forward(self, inputs):
        # Ensure each component in inputs is a tensor
        input_ids = torch.tensor(inputs[0]) if not isinstance(inputs[0], torch.Tensor) else inputs[0]
        token_type_ids = torch.tensor(inputs[1]) if not isinstance(inputs[1], torch.Tensor) else inputs[1]
        attention_mask = torch.tensor(inputs[2]) if not isinstance(inputs[2], torch.Tensor) else inputs[2]
        
        input_ids = input_ids.view(-1, input_ids.size(-1))  # Ensuring batch_size, sequence_length
        token_type_ids = token_type_ids.view(input_ids.size(0), -1)  # Reshaping to [batch_size, sequence_length]
        attention_mask = attention_mask.view(-1, attention_mask.size(-1))
        
        outputs = self.encoder(
            input_ids=input_ids,
            token_type_ids=token_type_ids,
            attention_mask=attention_mask,
        )
        cls_output = outputs.pooler_output
        return cls_output

# %%
class MLP_VAE(nn.Module):
    def __init__(self, hidden_size, device, label_num):
        super(MLP_VAE, self).__init__()
        self.device = device
        self.label_num = label_num
        self.cl_neg_mode = 1
        self.proto_size = 256
        self.hidden_size = hidden_size
        
        # Initial fully connected layer to project input to higher-dimensional space for each label
        self.fc0 = nn.Linear(self.hidden_size, self.label_num * 512)
        self.fc1 = nn.Linear(512, self.proto_size)  # Dimensionality reduction for prototypes

        # Adjust the number of label representations based on contrastive learning mode
        if self.cl_neg_mode == 0:
            cl_label_num = self.label_num  # Standard label number
        elif self.cl_neg_mode == 1:
            cl_label_num = self.label_num + 1  # Add one for negative prototype handling
            self.ins_neg_cnt = torch.zeros(1).to(device)
        elif self.cl_neg_mode == 2:
            cl_label_num = self.label_num * 2  # Double for positive and negative prototypes
            self.ins_neg_cnt = torch.zeros(self.label_num).to(device)
        self.cl_label_num = cl_label_num

        # Register buffer for label prototypes, aligned with CoMAL's prototype-based sampling
        self.register_buffer("prototypes", torch.zeros(self.cl_label_num, self.proto_size))
        self.ins_pos_cnt = torch.zeros(self.label_num).to(device)  # Track count of positive instances

        # Decoder and final aggregation layers
        self.fc3 = nn.Linear(self.proto_size, 512)
        self.agg = nn.Linear(self.label_num * 512, self.hidden_size)
        self.clf = nn.Linear(self.hidden_size, self.label_num)  # Classification layer

    def get_protos(self):
        return self.prototypes  # Return the prototypes for external use

    def reparameterize(self, mu, logvar):
        # VAE reparameterization trick for latent space sampling
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def reset_proto(self):
        # Reset prototype and count buffers
        self.ins_pos_cnt *= 0
        self.ins_neg_cnt *= 0
        self.prototypes *= 0

    def forward(self, x, labels=None, weights=None, reset_proto=False):
        # Project input into sub-representations per label
        sub_rep_ori = self.fc0(x)
        sr_shape = sub_rep_ori.shape
        sub_rep_ori = sub_rep_ori.view(sr_shape[0], self.label_num, -1)  # Split per label

        # Further reduction to prototype size and decoding step
        sub_rep = self.fc1(sub_rep_ori)
        dec_sub_rep = self.fc3(sub_rep)

        dist_1 = None
        sub_rep_norm = F.normalize(sub_rep.data, dim=-1)  # Normalize for distance calculations

        if labels is not None and weights is not None:
            # Generate masks for positive and negative samples
            pos_mask = labels * weights
            neg_mask = (1 - labels) * weights
            pos_mask = pos_mask.unsqueeze(-1)
            neg_mask = neg_mask.unsqueeze(-1)

            # Update prototypes based on positive and negative samples
            feat = torch.sum(sub_rep_norm * pos_mask, dim=0)
            self.prototypes[:self.label_num] = self.prototypes[:self.label_num] * self.ins_pos_cnt.unsqueeze(-1) + feat

            # Handle different contrastive learning modes
            if self.cl_neg_mode == 2:
                feat_neg = torch.sum(sub_rep_norm * neg_mask, dim=0)
                self.prototypes[self.label_num:] = self.prototypes[self.label_num:] * self.ins_neg_cnt.unsqueeze(-1) + feat_neg
                self.ins_neg_cnt += torch.sum(neg_mask.squeeze(-1), dim=0)
            elif self.cl_neg_mode == 1:
                feat_neg = torch.sum(sub_rep_norm * neg_mask, dim=0)
                feat_neg = torch.sum(feat_neg, dim=0)
                self.prototypes[-1] = self.prototypes[-1] * self.ins_neg_cnt + feat_neg
                self.ins_neg_cnt += torch.sum(neg_mask)
            
            # Update positive instance counts and normalize prototypes
            self.ins_pos_cnt += torch.sum(pos_mask.squeeze(-1), dim=0)
            self.prototypes = F.normalize(self.prototypes, p=2, dim=-1)

        # Calculate distances between sub-representations and prototypes
        dist_1 = sub_rep_norm @ self.prototypes.T  

        # Decode and classify reconstructed input
        concat_sub_rep = dec_sub_rep.contiguous().view(dec_sub_rep.shape[0], -1)
        recon_x = self.agg(concat_sub_rep)
        recon_x_clf = self.clf(recon_x)

        if reset_proto:
            self.reset_proto()

        return recon_x, sub_rep, recon_x_clf, dist_1  # Return reconstruction, sub-representation, classification, and distances

# %%
def get_cl_labels(labels, label_num, weight, cl_neg_mode=1):
    cl_labels = torch.zeros_like(labels, dtype=torch.long)
    cl_labels.fill_(label_num)
    example_idx, label_idx = torch.where(labels>=0.5)
    cl_labels[example_idx, label_idx] = label_idx #.float()
    cl_labels = cl_labels * weight + label_num * (1 - weight)
    if cl_neg_mode == 2:
        example_idx, label_idx = torch.where(labels < 0.5)
        cl_neg_labels = label_idx + label_num
        cl_labels[example_idx, label_idx] = cl_neg_labels.float()
        cl_labels = cl_labels * weight + 2 * label_num * (1 - weight)
    cl_labels = cl_labels.to(torch.int)
    return cl_labels

def get_cl_mask(cl_labels, label_num, batch_size, cl_neg_mode=1):
    mask = torch.eq(cl_labels[:batch_size], cl_labels.T).float()
    if cl_neg_mode == 0:
        neg_idx, _ = torch.where(cl_labels[:batch_size] >= label_num)
        neg_mask = torch.ones_like(mask)
        neg_mask[neg_idx] = 0
        neg_mask[:, neg_idx] = 0
        mask *= neg_mask
    elif cl_neg_mode == 1:
        neg_idx, _ = torch.where(cl_labels[:batch_size] > label_num)
        neg_mask = torch.ones_like(mask)
        neg_mask[neg_idx] = 0
        neg_mask[:, neg_idx] = 0
        mask *= neg_mask
    elif cl_neg_mode == 2:
        neg_idx, _ = torch.where(cl_labels[:batch_size] >= label_num * 2)
        neg_mask = torch.ones_like(mask)
        neg_mask[neg_idx] = 0
        neg_mask[:, neg_idx] = 0
        mask *= neg_mask
    else:
        neg_mask = torch.ones_like(mask)
    return mask, neg_mask

# %% [markdown]
# # DEFINE LOSSES

# %%
class SupConLoss(nn.Module):
    """Following Supervised Contrastive Learning:
        https://arxiv.org/pdf/2004.11362.pdf."""

    def __init__(self, temperature=0.07, base_temperature=0.07):
        super().__init__()
        self.temperature = temperature
        self.base_temperature = base_temperature

    def forward(self, features, mask, neg_mask=None, batch_size=-1, device=None, other_features=None):
        if mask is not None:
            # SupCon loss (Partial Label Mode)
            mask = mask.float().detach()
            # compute logits
            if other_features is None:
                anchor_dot_contrast = torch.div(
                    torch.matmul(features[:batch_size], features.T),
                    self.temperature)
            else:
                anchor_dot_contrast = torch.div(
                    torch.matmul(features[:batch_size], other_features.T),
                    self.temperature)

            # for numerical stability
            logits_max, _ = torch.max(anchor_dot_contrast, dim=1, keepdim=True)
            logits = anchor_dot_contrast - logits_max.detach()

            # mask-out self-contrast cases
            if neg_mask is None:
                logits_mask = torch.ones_like(mask)
            else:
                logits_mask = torch.scatter(
                    neg_mask,
                    1,
                    torch.arange(batch_size).view(-1, 1).to(device),
                    0
                )
            mask = mask * logits_mask

            # compute log_prob
            exp_logits = torch.exp(logits) * logits_mask
            log_prob = logits - torch.log(exp_logits.sum(1, keepdim=True) + 1e-12)
            # compute mean of log-likelihood over positive
            mean_log_prob_pos = (mask * log_prob).sum(1) / (mask.sum(1) + 1e-12)
            # loss
            loss = - (self.temperature / self.base_temperature) * mean_log_prob_pos
            loss = loss.mean()
        else:
            q = features[:batch_size]
            k = features[batch_size:batch_size * 2]
            queue = features[batch_size * 2:]
            l_pos = torch.einsum('nc,nc->n', [q, k]).unsqueeze(-1)
            # negative logits: NxK
            l_neg = torch.einsum('nc,kc->nk', [q, queue])
            # logits: Nx(1+K)
            logits = torch.cat([l_pos, l_neg], dim=1)

            # apply temperature
            logits /= self.temperature

            # labels: positive key indicators
            labels = torch.zeros(logits.shape[0], dtype=torch.long).cuda()
            loss = F.cross_entropy(logits, labels)

        return loss

# %% [markdown]
# # MODEL TRAINING AND TESTING

# %%
total_data = len(X_train) + len(X_val)
initial_train_size = int(0.05 * total_data)
checkpoints = [
    int(0.5 * total_data), 
    int(0.6 * total_data), 
    int(0.7 * total_data),
    len(X_train)
]
min_increment = 25

# %%
def compute_metrics(p, label, classes):
    preds = torch.tensor(p.predictions) # Sigmoid and threshold for multi-label
    labels = torch.tensor(p.label_ids)

    hamming_accuracy = (preds == labels).float().mean().item()

    # Standard multi-label precision, recall, and F1 metrics
    precision, recall, f1_micro, _ = precision_recall_fscore_support(labels, preds, average='micro', zero_division=0)
    _, _, f1_macro, _ = precision_recall_fscore_support(labels, preds, average='macro', zero_division=0)

    report = classification_report(
        labels, 
        preds, 
        labels=label,
        target_names=classes,
        zero_division=0
    ) 

    return {
        'accuracy': hamming_accuracy,
        'precision': precision,
        'recall': recall,
        'f1_micro': f1_micro,
        'f1_macro': f1_macro,
        'report': report
    }

# %%
def compute_metrics_overall(p, classes):
    preds = torch.tensor(p.predictions)
    labels = torch.tensor(p.label_ids)

    # Ensure it's in the correct shape
    if preds.shape != labels.shape:
        raise ValueError("Shape mismatch: predictions and labels must have the same shape.")

    # Hamming accuracy: proportion of correctly predicted labels over total labels
    hamming_accuracy = (preds == labels).float().mean().item()

    # Compute per-label (column-wise) precision, recall, F1
    precision_list, recall_list, f1_micro_list, f1_macro_list = [], [], [], []
    
    for i in range(labels.shape[1]):  # Loop through each column (multi-output)
        prec, rec, f1_micro, _ = precision_recall_fscore_support(
            labels[:, i], preds[:, i], average='micro', zero_division=0
        )
        _, _, f1_macro, _ = precision_recall_fscore_support(
            labels[:, i], preds[:, i], average='macro', zero_division=0
        )

        precision_list.append(prec)
        recall_list.append(rec)
        f1_micro_list.append(f1_micro)
        f1_macro_list.append(f1_macro)

    # Compute average metrics across all outputs
    precision = sum(precision_list) / len(precision_list)
    recall = sum(recall_list) / len(recall_list)
    f1_micro = sum(f1_micro_list) / len(f1_micro_list)
    f1_macro = sum(f1_macro_list) / len(f1_macro_list)

    # Generate classification report per output
    reports = [classification_report(labels[:, i], preds[:, i], target_names=classes, zero_division=0) for i in range(labels.shape[1])]

    return {
        'accuracy': hamming_accuracy,
        'precision': precision,
        'recall': recall,
        'f1_micro': f1_micro,
        'f1_macro': f1_macro,
        'reports': reports  # Returns list of reports, one for each output label
    }

# %%
def concat_test_result(outputs):
    outputs[0] = np.concatenate(outputs[0], axis=0)
    outputs[1] = np.concatenate(outputs[1], axis=0)
    outputs[2] = np.concatenate(outputs[2], axis=0)
    outputs[3] = np.concatenate(outputs[3], axis=0)
    outputs[4] = np.concatenate(outputs[4], axis=0)
    return outputs

def neaten_test_result(outputs, logits, labels, test_type):
    labels = labels.data.cpu().numpy()
    prob, pred = torch.topk(logits, 6 if test_type == 'aspect' else 2)
    prob = torch.sigmoid(prob).data.cpu().numpy()
    pred = pred.data.cpu().numpy()
    logits = torch.sigmoid(logits).data.cpu().numpy()
    pred_labels = np.zeros(logits.shape)
    pred_labels[logits >= 0.5] = 1
    outputs[0].append(labels)
    outputs[1].append(pred)
    outputs[2].append(prob)
    outputs[3].append(logits)
    outputs[4].append(pred_labels)
    
    return outputs

# %%
def train_total_sep2(aspect_datasets, dataloaders, trials, aspect_metrics, sentiment_metrics, metrics, current_train_size, label_num=-1, seed=42, total_patience=3):
    set_seed(seed)
    accelerator = Accelerator(mixed_precision='fp16')
    device = accelerator.device
    accelerator.print(accelerator.distributed_type)
    
    tasks = ['aspect', 'sentiment']
    sentiment_val_loader = None

    nearest_cp = current_train_size
    if nearest_cp not in checkpoints:
        for cp in checkpoints:
            if cp > current_train_size:
                nearest_cp = cp
                break
    percentage = math.ceil(nearest_cp / total_data * 100)

    for task in tasks:
        accelerator.print("--------------------------------------------------")
        if task == 'sentiment':
            accelerator.print("SENTIMENT ANALYSIS")
        else:
            accelerator.print("ASPECT DETECTION")
            
        accelerator.wait_for_everyone()
        best_score = {
            'accuracy': 0,
            'f1_micro': 0,
            'f1_macro': 0
        }  # Track best score for first phase
        best_score2 = {
            'accuracy': 0,
            'f1_micro': 0,
            'f1_macro': 0
        }  # Track best score for second phase
        second_phase = False  # Control flag for switching between training phases
        total_patience_cnt = 0
        models = {}

        # Initialize backbone model for task learning
        label_num = 6 if task == 'aspect' else 2
        models['backbone'] = IndoBERT_Backbone(label_num)
        optim_backbone = torch.optim.AdamW(models['backbone'].parameters(), lr=2e-5, weight_decay=0.01)

        # Initialize VAE module if specified (aligns with CoMAL's contrastive and auxiliary module)
        models['vae_module'] = MLP_VAE(768, device, label_num=label_num)
        optim_module = torch.optim.AdamW(models['vae_module'].parameters(), lr=2e-5, weight_decay=0.01)

        if task == 'sentiment':
            best_aspect_model = IndoBERT_Backbone(6)
            best_aspect_model.load_state_dict(torch.load(f"{filename}-aspect-p1-backbone-{trials+1}-{percentage}.pth"))
            train_loader, val_loader, _, _ = build_sentiment_dataset(
                device, aspect_datasets['train'], aspect_datasets['val'], best_aspect_model, tokenizer, max_length=sequence_length
            )
            sentiment_val_loader = val_loader
            
        else:
            train_loader = dataloaders['labeled']
            val_loader = dataloaders['test']

        accelerator.wait_for_everyone()
        models['backbone'], models['vae_module'], train_loader, val_loader = accelerator.prepare(
            models['backbone'], models['vae_module'], train_loader, val_loader
        )

        # Loop over epochs
        for epoch in range(1, epochs+1):
            if second_phase:
                models['backbone'].eval()  # Backbone frozen in second phase
            else:
                models['backbone'].train()
            models['vae_module'].train()

            # Iterate over labeled data for training
            total_loss = 0
            for data in train_loader:
                # Zero the gradients for all optimizers
                optim_backbone.zero_grad()
                optim_module.zero_grad()

                # Prepare inputs and labels for training
                labels, idx, loss_weight = [x.to(device) for x in data[1:4]]
                input_ids, input_type_ids, input_mask = [x.to(device) for x in data[0]]
                inputs_list = [input_ids, input_type_ids, input_mask, None]

                loss = 0

                # Forward pass through backbone model
                clf_out, encoder_cls = models['backbone'](inputs_list)

                # VAE training logic (aligns with CoMAL's multi-label decoupling and contrastive learning)
                loss2 = 0
                module_cls = encoder_cls.detach()  # Detach to prevent gradient flow to backbone

                # Forward pass through VAE module
                recon_x, latent_rep, recon_x_clf, _ = models['vae_module'](module_cls, labels=labels, weights=loss_weight)

                # Compute contrastive loss if enabled (aligns with CoMAL's use of contrastive learning)
                cl_labels = get_cl_labels(labels, label_num, loss_weight).view(-1)
                cl_labels_total = cl_labels.unsqueeze(-1)
                proj_total = latent_rep.view(-1, latent_rep.shape[-1])
                proj_total = F.normalize(proj_total, dim=-1)  # Normalize latent representation
                batch_size = clf_out.shape[0] * label_num
                mask, neg_mask = get_cl_mask(cl_labels_total, label_num, batch_size)

                criterion_cl = SupConLoss()  # Supervised contrastive loss function
                cl_loss = criterion_cl(proj_total, mask, neg_mask, batch_size, device)
                loss2 += cl_loss  # Add contrastive loss

                # Compute reconstruction and classification loss
                criterion_mse = nn.MSELoss()
                recon_mse_loss = criterion_mse(recon_x, module_cls)
                criterion_bce = nn.BCEWithLogitsLoss()
                recon_bce_loss = criterion_bce(recon_x_clf, labels.float())
                
                loss2 += recon_mse_loss + recon_bce_loss
                
                # Compute classification loss for the backbone (first phase)
                if not second_phase:
                    criterion = nn.BCEWithLogitsLoss()
                    clf_loss = criterion(clf_out, labels.float())
                    loss += clf_loss  # Add classification loss to total loss

                # Add VAE loss to total loss
                loss += loss2
                # Backpropagation step
                accelerator.backward(loss)
                
                total_loss += loss

                # Update weights based on current phase
                if second_phase:
                    optim_module.step()
                else:
                    optim_module.step()
                    optim_backbone.step()

            # Scheduler step for learning rate adjustment
            # if second_phase:
            #     accelerator.print('in second')
            
            result = {}
            outputs_clf = [[], [], [], [], []]
            outputs_dual = [[], [], [], [], []]
            match task:
                case 'aspect':
                    with torch.no_grad():
                        for data in val_loader:
                            input_ids, input_type_ids, input_mask = [x.to(device, non_blocking=True) for x in data[0]]
                            labels = data[1].to(device)
                            out = [input_ids, input_type_ids, input_mask, None]
                
                            clf_out, encoder_cls = models['backbone'](out)
                            outputs_clf = neaten_test_result(outputs_clf, clf_out, labels, task)

                            if 'vae_module' in models.keys():
                                _, _, recon_x_clf, _ = models['vae_module'](encoder_cls, reset_proto=True)
                                outputs_dual = neaten_test_result(outputs_dual, recon_x_clf, labels, task)

                    if second_phase:
                        outputs_dual = concat_test_result(outputs_dual)
                        preds = torch.tensor(outputs_dual[4], device=device)
                        labels = torch.tensor(outputs_dual[0], device=device)
                    else:
                        outputs_clf = concat_test_result(outputs_clf)
                        preds = torch.tensor(outputs_clf[4], device=device)
                        labels = torch.tensor(outputs_clf[0], device=device)

                    preds = accelerator.gather_for_metrics(preds)
                    labels = accelerator.gather_for_metrics(labels)
                        
                    result = compute_metrics(
                        type('EvalOutput', (object,), {'predictions': preds.cpu().numpy(), 'label_ids': labels.cpu().numpy()}),
                        None,
                        ['fuel', 'machine', 'others', 'part', 'price', 'service']
                    )
                case 'sentiment':
                    sentiment_val_outputs = []
                    with torch.no_grad():
                        for data in val_loader:
                            input_ids, input_type_ids, input_mask = [x.to(device, non_blocking=True) for x in data[0]]
                            labels = data[1].to(device)
                            out = [input_ids, input_type_ids, input_mask, None]
                        
                            clf_out, encoder_cls = models['backbone'](out)
                            clf_out = torch.sigmoid(clf_out)
                        
                            if 'vae_module' in models.keys():
                                _, _, recon_x_clf, _ = models['vae_module'](encoder_cls, reset_proto=True)
                                recon_x_clf = torch.sigmoid(recon_x_clf)

                            for i in range(len(clf_out)):
                                val_output = {
                                    'label': data[1][i],
                                    'aspect': data[7][i],
                                    'ori_indices': data[2][i],
                                    'pred': np.argmax(clf_out[i].cpu().numpy() if not second_phase else recon_x_clf[i].cpu().numpy()),
                                }
                                sentiment_val_outputs.append(val_output)

                    sentiment_val_outputs = accelerator.gather_for_metrics(sentiment_val_outputs)
                    unique_val_outputs = {(x['ori_indices'].item(), x['aspect']): x for x in sentiment_val_outputs}
                    sentiment_val_outputs = list(unique_val_outputs.values())

                    result = compute_metrics(
                        type('EvalOutput', (object,), {'predictions': [item['pred'] for item in sentiment_val_outputs], 'label_ids': [np.argmax(item['label'].cpu().numpy()) for item in sentiment_val_outputs]}),
                        [0, 1],
                        ['negative', 'positive']
                    )

            # if second_phase:
            #     if result["f1_micro"] >= best_score2['f1_micro']:
            #         total_patience_cnt = 0
            #         best_score2 = result
                    
            #         accelerator.wait_for_everyone()
            #         unwrapped_vae = accelerator.unwrap_model(models['vae_module'])
            #         if accelerator.is_local_main_process:
            #             accelerator.save(unwrapped_vae.state_dict(), f"{filename}-{task}-p2-vae-{trials+1}-{percentage}.pth")
            #     else:
            #         total_patience_cnt += 1
            #         if total_patience_cnt >= total_patience:
            #             break
            # else:
            if result["f1_micro"] >= best_score['f1_micro']:
                best_score = result

                accelerator.wait_for_everyone()
                unwrapped_backbone = accelerator.unwrap_model(models['backbone'])
                unwrapped_vae = accelerator.unwrap_model(models['vae_module'])

                if accelerator.is_local_main_process:
                    accelerator.save(unwrapped_backbone.state_dict(), f"{filename}-{task}-p1-backbone-{trials+1}-{percentage}.pth")
                    accelerator.save(unwrapped_vae.state_dict(), f"{filename}-{task}-p1-vae-{trials+1}-{percentage}.pth")
            # else:
            #     total_patience_cnt += 1
            #     if total_patience_cnt >= total_patience:
            #         total_patience_cnt = 0
            #         second_phase = True
                
            accelerator.print(f"EPOCH {epoch} | LOSS: {total_loss / len(dataloaders['labeled'])} | ACCURACY: {round(result['accuracy'], 4)} | F1 MACRO: {round(result['f1_macro'], 4)} | F1 MICRO: {round(result['f1_micro'], 4)}")

        if accelerator.is_local_main_process:
            if task == 'aspect':
                aspect_metrics[0].append(best_score['accuracy'])
                aspect_metrics[1].append(best_score['f1_micro'])
                aspect_metrics[2].append(best_score['f1_macro'])
            elif task == 'sentiment':
                sentiment_metrics[0].append(best_score['accuracy'])
                sentiment_metrics[1].append(best_score['f1_micro'])
                sentiment_metrics[2].append(best_score['f1_macro'])
        
        accelerator.print(f"{task}: ACCURACY {round(best_score['accuracy'], 4)} | F1 MACRO {round(best_score['f1_macro'], 4)} | F1 MICRO {round(best_score['f1_micro'], 4)}")
        accelerator.print(best_score['report'])

    # Compute overall metrics
    aspect_labels = []
    aspect_indices = []
    aspect_preds = []

    aspect_outputs = {}
    sentiment_outputs = []

    accelerator.wait_for_everyone()

    best_aspect_model = IndoBERT_Backbone(6)
    best_sentiment_model = IndoBERT_Backbone(2)

    best_aspect_model.load_state_dict(torch.load(f"{filename}-aspect-p1-backbone-{trials+1}-{percentage}.pth"))
    best_sentiment_model.load_state_dict(torch.load(f"{filename}-sentiment-p1-backbone-{trials+1}-{percentage}.pth"))

    best_aspect_model, best_sentiment_model, val_loader = accelerator.prepare(best_aspect_model, best_sentiment_model, dataloaders['test'])

    with torch.no_grad():
        for batch in val_loader:
            input_ids, input_type_ids, input_mask = [x.to(device) for x in batch[0]]
            inputs_list = [input_ids, input_type_ids, input_mask, None]
            clf_out, encoder_cls = best_aspect_model(inputs_list)
            preds = torch.sigmoid(clf_out).round()

            aspect_indices.append(accelerator.gather(batch[2]))
            aspect_labels.append(accelerator.gather(batch[6]))
            aspect_preds.append(accelerator.gather(preds))

        aspect_indices = torch.cat(aspect_indices).cpu().numpy()
        aspect_labels = torch.cat(aspect_labels).cpu().numpy()
        aspect_preds = torch.cat(aspect_preds).cpu().numpy()

        accelerator.wait_for_everyone()
        aspect_outputs = [
            {'ori_indices': aspect_indices[i], 
             'ori_labels': aspect_labels[i], 
             'pred': aspect_preds[i]}
            for i in range(len(aspect_preds))
        ]
        aspect_outputs = {x['ori_indices'].item(): x for x in aspect_outputs}
    
        for batch in sentiment_val_loader:
            input_ids, input_type_ids, input_mask = [x.to(device) for x in batch[0]]
            inputs_list = [input_ids, input_type_ids, input_mask, None]
            clf_out, encoder_cls = best_sentiment_model(inputs_list)
            preds = torch.sigmoid(clf_out).round()
    
            for i in range(len(preds)):
                output = {
                    'aspect': batch[7][i],
                    'ori_indices': batch[8][i],
                    'pred': np.argmax(preds[i].cpu().numpy()),
                }
                sentiment_outputs.append(output)

        sentiment_outputs = accelerator.gather_for_metrics(sentiment_outputs)
        sentiment_outputs = {(x['ori_indices'].item(), x['aspect']): x for x in sentiment_outputs}

    # Replcae non neutral aspect to its predicted sentiment
    accelerator.wait_for_everyone()
    if accelerator.is_main_process:
        i = -1
        for (ori_index, aspect), value in sentiment_outputs.items():
            aspect = aspect_mapping[aspect]
            aspect_outputs[ori_index]['pred'][aspect] = 2 if value['pred'] == 1.0 else value['pred']

        result = compute_metrics_overall(
            type('EvalOutput', (object,), {'predictions': [output['pred'] for output in aspect_outputs.values()], 'label_ids': [output['ori_labels'] for output in aspect_outputs.values()]}),
            ['negative', 'neutral', 'positive'],
        )

        accelerator.print("--------------------------------------------------")
        accelerator.print(f"Iteration {current_train_size}: Accuracy: {round(result['accuracy'], 4)}, F1 Micro: {round(result['f1_micro'], 4)}, F1 Macro: {round(result['f1_macro'], 4)}")
        accelerator.print("--------------------------------------------------")
        
        for i in range(len(train_labels)):
            accelerator.print(f"Aspect {aspect_list[i]} report:")
            accelerator.print(result['reports'][i])
            
        metrics[0].append(current_train_size)
        metrics[1].append(result['accuracy'])
        metrics[2].append(result['f1_micro'])
        metrics[3].append(result['f1_macro'])

# %% [markdown]
# # QUERY STRATEGY

# %%
def query_samples(filename, dataset, labeled_set, unlabeled_indices, num_labels, trials, sampling_dur, new_sample_data, new_sample_labels,
                  label_cardinality=None, labeled_subset=None, save_path=None, cl_neg_mode=1, n_samples=min_increment):
    accelerator = Accelerator(mixed_precision='fp16')
    device = accelerator.device

    models = {}
    tasks = ['aspect', 'sentiment']
    
    current_train_size = len(dataset.get_labeled_set())

    nearest_cp = current_train_size
    if nearest_cp not in checkpoints:
        for cp in checkpoints:
            if cp > current_train_size:
                nearest_cp = cp
                break
    percentage = math.ceil(nearest_cp / total_data * 100)

    for task in tasks:
        backbone = IndoBERT_Backbone(6 if task == 'aspect' else 2)
        vae = MLP_VAE(768, device, 6 if task == 'aspect' else 2)
        backbone.load_state_dict(torch.load(f"{filename}-{task}-p1-backbone-{trials+1}-{percentage}.pth"))
        models[f'{task}_backbone'] = backbone
        
        if os.path.exists(f'/kaggle/working/{filename}-{task}-p2-vae-{trials+1}.pth'):
            vae.load_state_dict(torch.load(f"{filename}-{task}-p2-vae-{trials+1}-{percentage}.pth"))
        else:
            vae.load_state_dict(torch.load(f"{filename}-{task}-p1-vae-{trials+1}-{percentage}.pth"))
        models[f'{task}_vae_module'] = vae

    
    # Set all models to evaluation mode to freeze parameters during sampling
    for model_name in models.keys():
        models[model_name].to(device)
        models[model_name].eval()

    # Initialize lists to store outputs used for sampling calculations
    aspect_outputs = {}
    sentiment_outputs = {}
    
    labeled_distances = []
    labeled_ground_truths = []
    
    labeled_aspects = []
    labeled_labels = []
    labeled_indices = []
    labeled_texts = []

    unlabeled_aspects = []
    unlabeled_labels = []
    unlabeled_ori_indices = []
    unlabeled_texts = []

    # DataLoader for labeled data subset, sampled randomly
    labeled_dataloader = DataLoader(
        dataset,
        batch_size=batch_size,
        num_workers=4,
        shuffle=False,
        pin_memory=True,
        sampler=SubsetRandomSampler(list(set(labeled_set)))
    )

    start_time = time.time()

    # Process labeled data to extract features and distances for sampling criteria
    for batch in labeled_dataloader:
        text_inputs = batch[0]
        gt_label = batch[1]
        idx = batch[2]
        input_ids, token_type_ids, attention_mask = [x.to(device, non_blocking=True) for x in text_inputs]
        labeled_ground_truths.extend(gt_label)

        with torch.no_grad():
            # Use backbone model to get encoded representations
            predictions, encoded_cls = models['aspect_backbone']([input_ids, token_type_ids, attention_mask, None])

            for i in range(len(predictions)):
                indices = idx[i].item()
                for j in range(len(predictions[i])):
                    if int(predictions[i][j].round()) != 1:
                        labeled_aspects.append(aspect_list[j])
                        labeled_labels.append(gt_label[i][j])
                        labeled_texts.append(batch[5][i])
                        labeled_indices.append(indices)
                    
            _, sub_representation, _, vae_distance = models['aspect_vae_module'](encoded_cls)
            vae_distance = vae_distance.cpu().data
            labeled_distances.extend(vae_distance)

    # Stack outputs for further processing
    labeled_ground_truths = torch.stack(labeled_ground_truths)
    labeled_distances = torch.stack(labeled_distances)

    accelerator.wait_for_everyone()
    if accelerator.is_main_process:
        # Compute self-prototype distances based on CoMAL's contrastive learning mode
        if cl_neg_mode == 1:
            labeled_prototype_distances = labeled_distances[:, :, :-1]  # Exclude last distance for prototype calculation
            labeled_prototype_distances = labeled_prototype_distances * torch.eye(num_labels)  # Keep only diagonal elements
            labeled_prototype_distances = torch.sum(labeled_prototype_distances, dim=-1)  # Sum along prototype axis
            positive_distances = labeled_prototype_distances * labeled_ground_truths  # Mask with ground truth labels
    
        # Calculate max, min, and mean positive distances for uncertainty measurement
        max_positive_distances = torch.max(positive_distances, dim=0)[0]
        min_positive_distances = torch.min(positive_distances + (1 - labeled_ground_truths) * 2, dim=0)[0]
        mean_positive_distances = (max_positive_distances + min_positive_distances) / 2
    
        # DataLoader for unlabeled data to compute sampling scores
        unlabeled_dataloader = DataLoader(
            dataset,
            batch_size=batch_size,
            num_workers=4,
            shuffle=False,
            pin_memory=True,
            sampler=SubsetRandomSampler(list(set(unlabeled_indices)))
        )
    
        # Process unlabeled data to get sampling scores
        for batch in unlabeled_dataloader:
            text_inputs = batch[0]
            labels = batch[1]
            idx = batch[2]
            loss_weight = batch[3]
            input_ids, token_type_ids, attention_mask = [x.to(device) for x in text_inputs]
    
            with torch.no_grad():
                # Get predictions and encoded representations
                predictions, encoded_cls = models['aspect_backbone']([input_ids, token_type_ids, attention_mask, None])
                predictions = predictions.cpu().data
                
                for i in range(len(predictions)):
                    indices = idx[i].item()
                    
                    if indices not in aspect_outputs.keys():
                        aspect_outputs[indices] = {}
                        
                    aspect_outputs[indices]['backbone_predictions'] = predictions[i]
                    aspect_outputs[indices]['loss_weight'] = loss_weight[i]
                    
                    # Collect non neutral aspect for sentiment analysis
                    for j in range(len(predictions[i])):
                        if int(torch.sigmoid(predictions[i][j]).round()) != 1:
                            unlabeled_aspects.append(aspect_list[j])
                            unlabeled_labels.append(labels[i][j])
                            unlabeled_texts.append(batch[5][i])
                            unlabeled_ori_indices.append(indices)
    
                # Get latent representations, reconstructions, and distances
                _, _, _, vae_distance = models['aspect_vae_module'](encoded_cls)

                for i in range(len(vae_distance)):
                    aspect_outputs[idx[i].item()]['backbone_distances'] = vae_distance[i].cpu().data

        # Convert lists to tensors for further computation
        sample_indices = torch.stack([torch.tensor(key, dtype=torch.long) for key in aspect_outputs.keys()])
        sample_weights = torch.stack([aspect_outputs[key]['loss_weight'] for key in aspect_outputs.keys()])
        distance_matrix = torch.stack([aspect_outputs[key]['backbone_distances'] for key in aspect_outputs.keys()])
    
        # Convert predictions to probability and adjust masks for scoring
        backbone_predictions = torch.stack([aspect_outputs[key]['backbone_predictions'] for key, val in aspect_outputs.items()])
        probability_predictions = torch.zeros_like(backbone_predictions) + backbone_predictions
        probability_predictions = torch.sigmoid(probability_predictions)
        unlabeled_mask = torch.ones_like(sample_weights) - sample_weights
    
        # Calculate uncertainty metrics and part scores for sampling
        sample_weights = sample_weights.view(-1)
    
        # Mask predictions based on positive distances
        positive_distance_mask = ((probability_predictions >= 0.5) * unlabeled_mask).float()
        positive_prototype_distances = distance_matrix[:, :, :-1]
        positive_prototype_distances = positive_prototype_distances * torch.eye(num_labels)
        positive_prototype_distances = torch.sum(positive_prototype_distances, dim=-1)
    
        # Compute scores based on uncertainty and diversity metrics
        prediction_mask = (positive_prototype_distances > mean_positive_distances).float()
        distance_count = torch.sum(prediction_mask, dim=-1)
        cardinality_difference = torch.abs(distance_count - label_cardinality)
        score_weight = positive_distance_mask * (positive_prototype_distances + 1) / 2
        score_weight = 1 / torch.sum(score_weight + 1e-10, dim=-1)
        adjusted_score = torch.pow(score_weight, 0.5) * torch.pow(cardinality_difference, 1 - 0.5)
        final_scores = adjusted_score.unsqueeze(-1)
        average_scores = torch.mean(final_scores, dim=-1).cpu().numpy()

        z = 0
        for key in aspect_outputs.keys():
            aspect_outputs[key]['score'] = average_scores[z]
            z += 1

    # -------- SENTIMENT ANALYSIS ---------
    accelerator.wait_for_everyone()
    labeled_sentiment_dataset = SentimentAnalysisDataset(labeled_texts, labeled_labels, labeled_aspects, labeled_indices, tokenizer, label_mapping, max_length=sequence_length)
    unlabeled_sentiment_dataset = SentimentAnalysisDataset(unlabeled_texts, unlabeled_labels, unlabeled_aspects, unlabeled_ori_indices, tokenizer, label_mapping, max_length=sequence_length)
    
    labeled_loader = torch.utils.data.DataLoader(
        labeled_sentiment_dataset, batch_size=batch_size, shuffle=False, pin_memory=True, num_workers=4,
    )
    unlabeled_loader = torch.utils.data.DataLoader(
        unlabeled_sentiment_dataset, batch_size=batch_size, shuffle=False, pin_memory=True, num_workers=4,
    )

    labeled_ground_truths = []
    labeled_distances = []
    for batch in labeled_loader:
        text_inputs = batch[0]
        gt_label = batch[1]
        input_ids, token_type_ids, attention_mask = [x.to(device, non_blocking=True) for x in text_inputs]
        labeled_ground_truths.extend(gt_label)

        with torch.no_grad():
            # Use backbone model to get encoded representations
            predictions, encoded_cls = models['sentiment_backbone']([input_ids, token_type_ids, attention_mask, None])
                    
            _, sub_representation, _, vae_distance = models['sentiment_vae_module'](encoded_cls)
            labeled_distances.extend(vae_distance.cpu().data)

    # Stack outputs for further processing
    labeled_ground_truths = torch.stack(labeled_ground_truths)
    labeled_distances = torch.stack(labeled_distances)

    accelerator.wait_for_everyone()
    if accelerator.is_main_process:
        # Compute self-prototype distances based on CoMAL's contrastive learning mode
        labeled_prototype_distances = labeled_distances[:, :, :-1]  # Exclude last distance for prototype calculation
        labeled_prototype_distances = labeled_prototype_distances * torch.eye(2)  # Keep only diagonal elements
        labeled_prototype_distances = torch.sum(labeled_prototype_distances, dim=-1)  # Sum along prototype axis
        positive_distances = labeled_prototype_distances * labeled_ground_truths  # Mask with ground truth labels
    
        # Calculate max, min, and mean positive distances for uncertainty measurement
        max_positive_distances = torch.max(positive_distances, dim=0)[0]
        min_positive_distances = torch.min(positive_distances + (1 - labeled_ground_truths) * 2, dim=0)[0]
        mean_positive_distances = (max_positive_distances + min_positive_distances) / 2
    
        # Process unlabeled data to get sampling scores
        for batch in unlabeled_loader:
            text_inputs = batch[0]
            idx = batch[8]
            loss_weight = batch[3]
            input_ids, token_type_ids, attention_mask = [x.to(device) for x in text_inputs]
    
            with torch.no_grad():
                # Get predictions and encoded representations
                predictions, encoded_cls = models['sentiment_backbone']([input_ids, token_type_ids, attention_mask, None])
                predictions = predictions.cpu().data
                    
                for i in range(len(predictions)):
                    indices = idx[i].item()
                    if indices not in sentiment_outputs.keys():
                        sentiment_outputs[indices] = {}
                        sentiment_outputs[idx[i].item()]['backbone_predictions'] = [predictions[i]]
                        sentiment_outputs[idx[i].item()]['loss_weight'] = [loss_weight[i]]
                    else:
                        sentiment_outputs[idx[i].item()]['backbone_predictions'].append(predictions[i])
                        sentiment_outputs[idx[i].item()]['loss_weight'].append(loss_weight[i])
    
                # Get latent representations, reconstructions, and distances
                _, _, _, vae_distance = models['sentiment_vae_module'](encoded_cls)

                for i in range(len(vae_distance)):
                    if 'backbone_distances' not in sentiment_outputs[indices].keys():
                        sentiment_outputs[idx[i].item()]['backbone_distances'] = [vae_distance[i].cpu().data]
                    else:
                        sentiment_outputs[idx[i].item()]['backbone_distances'].append(vae_distance[i].cpu().data)

        # print(len(unlabeled_sentiment_dataset), length, len(sentiment_outputs))
        sample_indices = torch.stack([torch.tensor(key, dtype=torch.long) for key in sentiment_outputs.keys()])

        sample_weights = torch.stack([
            torch.mean(torch.stack(sentiment_outputs[key]['loss_weight']), dim=0).round() 
            for key in sentiment_outputs
        ])
        distance_matrix = torch.stack([
            torch.mean(torch.stack(sentiment_outputs[key]['backbone_distances']), dim=0)
            for key in sentiment_outputs
        ])
        backbone_predictions = torch.stack([
            torch.mean(torch.stack(sentiment_outputs[key]['backbone_predictions']), dim=0) 
            for key in sentiment_outputs
        ])
        
        # Convert predictions to probability and adjust masks for scoring
        probability_predictions = torch.zeros_like(backbone_predictions) + backbone_predictions
        probability_predictions = torch.sigmoid(probability_predictions)
        unlabeled_mask = torch.ones_like(sample_weights) - sample_weights
    
        # Calculate uncertainty metrics and part scores for sampling
        sample_weights = sample_weights.view(-1)
    
        # Mask predictions based on positive distances
        positive_distance_mask = ((probability_predictions >= 0.5) * unlabeled_mask).float()
        positive_prototype_distances = distance_matrix[:, :, :-1]
        positive_prototype_distances = positive_prototype_distances * torch.eye(2)
        positive_prototype_distances = torch.sum(positive_prototype_distances, dim=-1)
    
        # Compute scores based on uncertainty and diversity metrics
        prediction_mask = (positive_prototype_distances > mean_positive_distances).float()
        distance_count = torch.sum(prediction_mask, dim=-1)
        cardinality_difference = torch.abs(distance_count - label_cardinality)
        score_weight = positive_distance_mask * (positive_prototype_distances + 1) / 2
        score_weight = 1 / torch.sum(score_weight + 1e-10, dim=-1)
        adjusted_score = torch.pow(score_weight, 0.5) * torch.pow(cardinality_difference, 1 - 0.5)
        final_scores = adjusted_score.unsqueeze(-1)
        average_sentiment_scores = torch.mean(final_scores, dim=-1).cpu().numpy()

        print(len(average_sentiment_scores), len(sentiment_outputs))

        z = 0
        for key in sentiment_outputs.keys():
            aspect_outputs[key]['score'] = (average_sentiment_scores[z] + aspect_outputs[key]['score']) / 2
            z += 1

        ranked_indices = np.argsort(average_scores)
        ranked_indices = ranked_indices[::-1]
        sample_indices = torch.stack([torch.tensor(key, dtype=torch.long) for key in aspect_outputs.keys()])
        
        # Select top samples for annotation
        threshold = np.percentile(average_scores, 90)
        items_greater_than_threshold = average_scores[average_scores >= threshold]
        num_of_candidates = min(math.ceil(0.1 * len(average_scores)), len(items_greater_than_threshold))
    
        nearest_cp = 0
        for cp in checkpoints:
            if cp > current_train_size:
                nearest_cp = cp
                break
    
        if num_of_candidates <= n_samples and n_samples < nearest_cp - current_train_size:
            selected_indices = ranked_indices[:n_samples]
        elif num_of_candidates > n_samples and num_of_candidates < nearest_cp - current_train_size:
            selected_indices = ranked_indices[:max(n_samples, num_of_candidates)]
        else:
            selected_indices = ranked_indices[:nearest_cp - current_train_size]
            
            temp = dataset.get_labeled_set()
            temp.extend([unlabeled_indices[int(i)] for i in selected_indices])
            
            # Save acquired data up to checkpoint
            acquired_data = pd.DataFrame({
                'processed_text': [X_train[i] for i in temp],
                'fuel': [y_train[i][0] for i in temp],
                'machine': [y_train[i][1] for i in temp],
                'others': [y_train[i][2] for i in temp],
                'part': [y_train[i][3] for i in temp],
                'price': [y_train[i][4] for i in temp],
                'service': [y_train[i][5] for i in temp],
            })
    
            acquired_data.to_csv(f'{filename}-{trials+1}-data-{nearest_cp}.csv', index=False)

        for x in selected_indices:
            new_sample_data.append(unlabeled_indices[int(x)])
        new_sample_labels = None
        
        end_time = time.time()
        duration = end_time - start_time
    
        print("Nearest checkpoint:", nearest_cp)
        print("Threshold:", threshold)
        print("Samples above threshold:", num_of_candidates)
        print("Acquired samples:", len(selected_indices))
        print(f"Sampling duration: {duration} seconds")  # Print or return the runtime if needed
    
        sampling_dur.append(duration)

def pred_part_stat(pred, threshold=0.0):
    part_1 = torch.where(pred >= threshold)[0]
    part_0 = torch.where(pred < threshold)[0]
    return part_0, part_1

# %% [markdown]
# # PLOT RESULT

# %%
import matplotlib.pyplot as plt

def plot_result(data_used, accuracies, f1_micros, f1_macros):
    fig, axs = plt.subplots(1, 3, figsize=(21, 5))
    data_used = [round(data / total_data * 100, 1) for data in data_used]

    # Plot for Accuracy
    axs[0].plot(data_used, accuracies, label="Accuracy", color="blue")
    axs[0].set_xlabel("Percentage of data used")
    axs[0].set_title("Accuracy")
    axs[0].set_xticks(data_used)

    # Plot for F1 Micro
    axs[1].plot(data_used, f1_micros, label="F1 Micro", color="orange")
    axs[1].set_xlabel("Percentage of data used")
    axs[1].set_title("F1 Micro")
    axs[1].set_xticks(data_used)

    # Plot for F1 Macro
    axs[2].plot(data_used, f1_macros, label="F1 Macro", color="green")
    axs[2].set_xlabel("Percentage of data used")
    axs[2].set_title("F1 Macro")
    axs[2].set_xticks(data_used)

    # Adjust layout and show the plots
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # MAIN LOOP

# %%
def active_learning(seed, i):
    aspect_accuracies = manager.list()
    aspect_f1_micros = manager.list()
    aspect_f1_macros = manager.list()
    sentiment_accuracies = manager.list()
    sentiment_f1_micros = manager.list()
    sentiment_f1_macros = manager.list()
    accuracies = manager.list()
    f1_micros = manager.list()
    f1_macros = manager.list()
    data_used = manager.list()
    sampling_dur = manager.list()
    new_sample_data = manager.list()
    new_sample_labels = manager.list()
    
    current_train_size = initial_train_size
    start_time = time.time()
    set_seed(seeds[i])

    print("===============================================")
    print("TRIAL {}".format(i+1))
    print("Random seed:", seeds[i])
    
    # Load label information and dataset
    label_num = 6
    _, _, aspect_train_dataset, aspect_val_dataset = build_aspect_dataset(X_train, y_train, X_val, y_val, sequence_length)
    
    # Shuffle and initialize labeled and unlabeled sets
    indices = list(range(len(aspect_train_dataset)))
    random.shuffle(indices)
    labeled_set = indices[:initial_train_size]  # Random initial labeled set
    unlabeled_set = [x for x in indices if x not in labeled_set]  # Define the unlabeled set
    
    # Update dataset with initial labeled set
    aspect_train_dataset.update_data(labeled_set, init_time=True)
    
    # Prepare data loaders for labeled and test sets
    labeled_loader = DataLoader(
        aspect_train_dataset,
        batch_size=batch_size,
        num_workers=4,
        pin_memory=True,
        sampler=SubsetRandomSampler(list(set(labeled_set)))
    )
    test_loader = DataLoader(
        aspect_val_dataset,
        batch_size=batch_size,
        num_workers=4,
        pin_memory=True
    )

    models = {}

    while current_train_size < checkpoints[len(checkpoints) - 1]:
        dataloaders = {
            'labeled': labeled_loader,
            'test': test_loader
        }
        aspect_datasets = {
            'train': aspect_train_dataset,
            'val': aspect_val_dataset
        }
    
        # Train model
        train_args = (
            aspect_datasets,
            dataloaders, 
            i, 
            (aspect_accuracies, aspect_f1_micros, aspect_f1_macros), 
            (sentiment_accuracies, sentiment_f1_micros, sentiment_f1_macros),
            (data_used, accuracies, f1_micros, f1_macros), 
            current_train_size, 
            label_num,
            seed
        )
        notebook_launcher(train_total_sep2, train_args, num_processes=2)
        
        query_set = list(set(unlabeled_set))
        # random.shuffle(query_set)
    
        # Query samples for next cycle, using appropriate selection strategy
        new_sample_data = manager.list()
        new_sample_labels = manager.list()
        sampling_args = (
            filename,
            aspect_train_dataset, 
            labeled_set,
            query_set, 
            label_num,
            i,
            sampling_dur,
            new_sample_data,
            new_sample_labels,
            aspect_train_dataset.get_label_Cardinality()
        )
        notebook_launcher(query_samples, sampling_args, num_processes=2)
        new_sample_data = list(new_sample_data)
        new_sample_labels = list(new_sample_labels)

        # print(len(new_sample_data))
        aspect_train_dataset.update_data(new_sample_data, None)
        labeled_set = aspect_train_dataset.get_labeled_set()
        unlabeled_set = [x for x in indices if x not in labeled_set]
    
        # Refresh data loader with new labeled set
        labeled_loader = DataLoader(
            aspect_train_dataset,
            batch_size=batch_size,
            num_workers=4,
            pin_memory=True,
            sampler=SubsetRandomSampler(list(set(labeled_set)))
        )
        
        # Update current train size
        current_train_size = len(labeled_set)
        print("New train size:", current_train_size)
    
    # DataLoader dictionary to be used for training and testing
    dataloaders = {
        'labeled': labeled_loader,
        'test': test_loader
    }
    
    # Train last iteration
    train_args = (
        aspect_datasets,
        dataloaders, 
        i, 
        (aspect_accuracies, aspect_f1_micros, aspect_f1_macros), 
        (sentiment_accuracies, sentiment_f1_micros, sentiment_f1_macros),
        (data_used, accuracies, f1_micros, f1_macros), 
        current_train_size, 
        label_num,
        seed
    )
    notebook_launcher(train_total_sep2, train_args, num_processes=2)
    data_used, accuracies, f1_micros, f1_macros, sampling_dur = list(data_used), list(accuracies), list(f1_micros), list(f1_macros), list(sampling_dur)
    aspect_accuracies, aspect_f1_micros, aspect_f1_macros = list(aspect_accuracies), list(aspect_f1_micros), list(aspect_f1_macros)
    sentiment_accuracies, sentiment_f1_micros, sentiment_f1_macros = list(sentiment_accuracies), list(sentiment_f1_micros), list(sentiment_f1_macros)
        
    # Log results
    end_time = time.time()
    duration = end_time - start_time

    print(f"Total sampling time: {np.array(sampling_dur).sum().round(2)} seconds")
    print(f"Total runtime: {duration} seconds")

    plot_result(data_used, accuracies, f1_micros, f1_macros)
    
    results = pd.DataFrame({
        'Data Used': data_used,
        'Aspect Accuracy': aspect_accuracies,
        'Aspect F1 Micro': aspect_f1_micros,
        'Aspect F1 Macro': aspect_f1_macros,
        'Sentiment Accuracy': sentiment_accuracies,
        'Sentiment F1 Micro': sentiment_f1_micros,
        'Sentiment F1 Macro': sentiment_f1_macros,
        'Accuracy': accuracies,
        'F1 Micro': f1_micros,
        'F1 Macro': f1_macros,
    })
    sampling_dur.insert(0, 0)
    
    results['Sampling Duration'] = sampling_dur
    
    results.to_csv(f'{filename}-{i+1}-results.csv', index=False)

# %%
seeds = [50, 81, 14, 3, 94]

# %% [markdown]
# ## RUN 1

# %%
active_learning(seeds[0], 0)
# Out:
# ===============================================
# TRIAL 1
# Random seed: 50
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.4285407066345215 | ACCURACY: 0.7329 | F1 MACRO: 0.8333 | F1 MICRO: 0.8411
# EPOCH 2 | LOSS: 3.2759060859680176 | ACCURACY: 0.7723 | F1 MACRO: 0.86 | F1 MICRO: 0.8681
# EPOCH 3 | LOSS: 3.174009323120117 | ACCURACY: 0.7924 | F1 MACRO: 0.8822 | F1 MICRO: 0.8837
# EPOCH 4 | LOSS: 3.0779800415039062 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# EPOCH 5 | LOSS: 3.0897669792175293 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# EPOCH 6 | LOSS: 2.987666606903076 | ACCURACY: 0.7902 | F1 MACRO: 0.8812 | F1 MICRO: 0.8826
# EPOCH 7 | LOSS: 2.94840407371521 | ACCURACY: 0.8013 | F1 MACRO: 0.8861 | F1 MICRO: 0.8877
# EPOCH 8 | LOSS: 2.991230010986328 | ACCURACY: 0.8013 | F1 MACRO: 0.8844 | F1 MICRO: 0.8866
# EPOCH 9 | LOSS: 2.8513894081115723 | ACCURACY: 0.8028 | F1 MACRO: 0.8836 | F1 MICRO: 0.8865
# EPOCH 10 | LOSS: 2.883544445037842 | ACCURACY: 0.8088 | F1 MACRO: 0.8871 | F1 MICRO: 0.8895
# aspect: ACCURACY 0.8088 | F1 MACRO 0.8871 | F1 MICRO 0.8895
#               precision    recall  f1-score   support
#
#         fuel       0.83      0.98      0.90       187
#      machine       0.81      0.98      0.89       175
#       others       0.73      0.99      0.84       158
#         part       0.80      0.88      0.84       158
#        price       0.88      0.99      0.93       192
#      service       0.85      1.00      0.92       191
#
#    micro avg       0.82      0.97      0.89      1061
#    macro avg       0.82      0.97      0.89      1061
# weighted avg       0.82      0.97      0.89      1061
#  samples avg       0.82      0.97      0.89      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 16.613174438476562 | ACCURACY: 0.7711 | F1 MACRO: 0.4354 | F1 MICRO: 0.7711
# EPOCH 2 | LOSS: 12.63774299621582 | ACCURACY: 0.7711 | F1 MACRO: 0.4354 | F1 MICRO: 0.7711
# EPOCH 3 | LOSS: 12.741486549377441 | ACCURACY: 0.8795 | F1 MACRO: 0.8294 | F1 MICRO: 0.8795
# EPOCH 4 | LOSS: 13.298925399780273 | ACCURACY: 0.8554 | F1 MACRO: 0.7677 | F1 MICRO: 0.8554
# EPOCH 5 | LOSS: 11.758752822875977 | ACCURACY: 0.9277 | F1 MACRO: 0.8936 | F1 MICRO: 0.9277
# EPOCH 6 | LOSS: 10.29024887084961 | ACCURACY: 0.8795 | F1 MACRO: 0.8353 | F1 MICRO: 0.8795
# EPOCH 7 | LOSS: 9.76569652557373 | ACCURACY: 0.8795 | F1 MACRO: 0.8294 | F1 MICRO: 0.8795
# EPOCH 8 | LOSS: 9.550994873046875 | ACCURACY: 0.8795 | F1 MACRO: 0.8294 | F1 MICRO: 0.8795
# EPOCH 9 | LOSS: 9.035401344299316 | ACCURACY: 0.8916 | F1 MACRO: 0.8435 | F1 MICRO: 0.8916
# EPOCH 10 | LOSS: 9.121665954589844 | ACCURACY: 0.9036 | F1 MACRO: 0.8635 | F1 MICRO: 0.9036
# sentiment: ACCURACY 0.9277 | F1 MACRO 0.8936 | F1 MICRO 0.9277
#               precision    recall  f1-score   support
#
#     negative       0.88      0.79      0.83        19
#     positive       0.94      0.97      0.95        64
#
#     accuracy                           0.93        83
#    macro avg       0.91      0.88      0.89        83
# weighted avg       0.93      0.93      0.93        83
#
# --------------------------------------------------
# Iteration 54: Accuracy: 0.804, F1 Micro: 0.804, F1 Macro: 0.435
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        11
#      neutral       0.84      0.98      0.90       181
#     positive       0.00      0.00      0.00        24
#
#     accuracy                           0.82       216
#    macro avg       0.28      0.33      0.30       216
# weighted avg       0.70      0.82      0.76       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.50      0.06      0.11        16
#      neutral       0.80      0.98      0.88       167
#     positive       0.60      0.18      0.28        33
#
#     accuracy                           0.79       216
#    macro avg       0.63      0.41      0.42       216
# weighted avg       0.75      0.79      0.73       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.25      0.40        12
#      neutral       0.73      0.99      0.84       152
#     positive       0.83      0.10      0.17        52
#
#     accuracy                           0.74       216
#    macro avg       0.85      0.45      0.47       216
# weighted avg       0.77      0.74      0.66       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.35      0.48        23
#      neutral       0.80      0.88      0.84       152
#     positive       0.49      0.46      0.48        41
#
#     accuracy                           0.75       216
#    macro avg       0.70      0.56      0.60       216
# weighted avg       0.74      0.75      0.73       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.15      0.27        13
#      neutral       0.88      0.98      0.93       186
#     positive       0.50      0.24      0.32        17
#
#     accuracy                           0.87       216
#    macro avg       0.79      0.46      0.51       216
# weighted avg       0.86      0.87      0.84       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        14
#      neutral       0.86      1.00      0.92       185
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.86       216
#    macro avg       0.29      0.33      0.31       216
# weighted avg       0.73      0.86      0.79       216
#
# Launching training on 2 GPUs.
# 284 284
# Nearest checkpoint: 540
# Threshold: 88888.890625
# Samples above threshold: 81
# Acquired samples: 81
# Sampling duration: 6.443666219711304 seconds
# New train size: 135
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.7670373916625977 | ACCURACY: 0.7924 | F1 MACRO: 0.8814 | F1 MICRO: 0.8832
# EPOCH 2 | LOSS: 3.4378437995910645 | ACCURACY: 0.7902 | F1 MACRO: 0.8811 | F1 MICRO: 0.8826
# EPOCH 3 | LOSS: 3.235206365585327 | ACCURACY: 0.7976 | F1 MACRO: 0.885 | F1 MICRO: 0.8864
# EPOCH 4 | LOSS: 2.987549304962158 | ACCURACY: 0.8177 | F1 MACRO: 0.8941 | F1 MICRO: 0.8955
# EPOCH 5 | LOSS: 2.8630778789520264 | ACCURACY: 0.8274 | F1 MACRO: 0.8991 | F1 MICRO: 0.9003
# EPOCH 6 | LOSS: 2.9260575771331787 | ACCURACY: 0.8467 | F1 MACRO: 0.9079 | F1 MICRO: 0.9098
# EPOCH 7 | LOSS: 2.9265549182891846 | ACCURACY: 0.8705 | F1 MACRO: 0.9207 | F1 MICRO: 0.9227
# EPOCH 8 | LOSS: 2.8767290115356445 | ACCURACY: 0.8765 | F1 MACRO: 0.9242 | F1 MICRO: 0.926
# EPOCH 9 | LOSS: 2.7485477924346924 | ACCURACY: 0.8981 | F1 MACRO: 0.9354 | F1 MICRO: 0.9377
# EPOCH 10 | LOSS: 2.6172969341278076 | ACCURACY: 0.9003 | F1 MACRO: 0.9366 | F1 MICRO: 0.939
# aspect: ACCURACY 0.9003 | F1 MACRO 0.9366 | F1 MICRO 0.939
#               precision    recall  f1-score   support
#
#         fuel       0.95      1.00      0.98       187
#      machine       0.85      0.99      0.92       175
#       others       0.87      0.89      0.88       158
#         part       0.88      0.96      0.92       158
#        price       0.96      0.97      0.97       192
#      service       0.93      1.00      0.96       191
#
#    micro avg       0.91      0.97      0.94      1061
#    macro avg       0.91      0.97      0.94      1061
# weighted avg       0.91      0.97      0.94      1061
#  samples avg       0.91      0.97      0.94      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 16.429569244384766 | ACCURACY: 0.6946 | F1 MACRO: 0.425 | F1 MICRO: 0.6946
# EPOCH 2 | LOSS: 14.321309089660645 | ACCURACY: 0.9261 | F1 MACRO: 0.9155 | F1 MICRO: 0.9261
# EPOCH 3 | LOSS: 12.039624214172363 | ACCURACY: 0.9212 | F1 MACRO: 0.9087 | F1 MICRO: 0.9212
# EPOCH 4 | LOSS: 11.09307861328125 | ACCURACY: 0.936 | F1 MACRO: 0.9279 | F1 MICRO: 0.936
# EPOCH 5 | LOSS: 10.774579048156738 | ACCURACY: 0.9212 | F1 MACRO: 0.9109 | F1 MICRO: 0.9212
# EPOCH 6 | LOSS: 10.09269905090332 | ACCURACY: 0.9261 | F1 MACRO: 0.9168 | F1 MICRO: 0.9261
# EPOCH 7 | LOSS: 9.525980949401855 | ACCURACY: 0.9064 | F1 MACRO: 0.8974 | F1 MICRO: 0.9064
# EPOCH 8 | LOSS: 9.516929626464844 | ACCURACY: 0.9212 | F1 MACRO: 0.9109 | F1 MICRO: 0.9212
# EPOCH 9 | LOSS: 9.591315269470215 | ACCURACY: 0.9015 | F1 MACRO: 0.8839 | F1 MICRO: 0.9015
# EPOCH 10 | LOSS: 9.33561897277832 | ACCURACY: 0.9261 | F1 MACRO: 0.9148 | F1 MICRO: 0.9261
# sentiment: ACCURACY 0.936 | F1 MACRO 0.9279 | F1 MICRO 0.936
#               precision    recall  f1-score   support
#
#     negative       0.85      0.97      0.90        63
#     positive       0.98      0.92      0.95       140
#
#     accuracy                           0.94       203
#    macro avg       0.92      0.94      0.93       203
# weighted avg       0.94      0.94      0.94       203
#
# --------------------------------------------------
# Iteration 135: Accuracy: 0.9028, F1 Micro: 0.9028, F1 Macro: 0.805
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.91      0.87        11
#      neutral       0.97      0.99      0.98       181
#     positive       1.00      0.79      0.88        24
#
#     accuracy                           0.97       216
#    macro avg       0.94      0.90      0.91       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.38      0.52        16
#      neutral       0.87      1.00      0.93       167
#     positive       0.94      0.45      0.61        33
#
#     accuracy                           0.87       216
#    macro avg       0.89      0.61      0.69       216
# weighted avg       0.88      0.87      0.85       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.75      0.75        12
#      neutral       0.86      0.91      0.89       152
#     positive       0.74      0.60      0.66        52
#
#     accuracy                           0.83       216
#    macro avg       0.78      0.75      0.76       216
# weighted avg       0.82      0.83      0.82       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.77      0.74      0.76        23
#      neutral       0.87      0.95      0.91       152
#     positive       0.89      0.59      0.71        41
#
#     accuracy                           0.86       216
#    macro avg       0.84      0.76      0.79       216
# weighted avg       0.86      0.86      0.85       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.77      0.87        13
#      neutral       0.97      0.98      0.97       186
#     positive       0.72      0.76      0.74        17
#
#     accuracy                           0.95       216
#    macro avg       0.90      0.84      0.86       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.64      0.78        14
#      neutral       0.93      1.00      0.97       185
#     positive       1.00      0.53      0.69        17
#
#     accuracy                           0.94       216
#    macro avg       0.98      0.72      0.81       216
# weighted avg       0.94      0.94      0.93       216
#
# Launching training on 2 GPUs.
# 595 595
# Nearest checkpoint: 540
# Threshold: 88680.3125
# Samples above threshold: 73
# Acquired samples: 73
# Sampling duration: 9.373585939407349 seconds
# New train size: 208
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.5242457389831543 | ACCURACY: 0.7909 | F1 MACRO: 0.8814 | F1 MICRO: 0.883
# EPOCH 2 | LOSS: 3.205972909927368 | ACCURACY: 0.7917 | F1 MACRO: 0.882 | F1 MICRO: 0.8834
# EPOCH 3 | LOSS: 2.854776382446289 | ACCURACY: 0.8185 | F1 MACRO: 0.8944 | F1 MICRO: 0.8959
# EPOCH 4 | LOSS: 2.7154855728149414 | ACCURACY: 0.8348 | F1 MACRO: 0.9023 | F1 MICRO: 0.9038
# EPOCH 5 | LOSS: 2.7681524753570557 | ACCURACY: 0.8527 | F1 MACRO: 0.9096 | F1 MICRO: 0.9123
# EPOCH 6 | LOSS: 2.6789939403533936 | ACCURACY: 0.8817 | F1 MACRO: 0.9269 | F1 MICRO: 0.9289
# EPOCH 7 | LOSS: 2.626312255859375 | ACCURACY: 0.9182 | F1 MACRO: 0.9478 | F1 MICRO: 0.9496
# EPOCH 8 | LOSS: 2.5024666786193848 | ACCURACY: 0.9055 | F1 MACRO: 0.9393 | F1 MICRO: 0.9419
# EPOCH 9 | LOSS: 2.443523406982422 | ACCURACY: 0.9204 | F1 MACRO: 0.9488 | F1 MICRO: 0.9509
# EPOCH 10 | LOSS: 2.3502297401428223 | ACCURACY: 0.9293 | F1 MACRO: 0.9539 | F1 MICRO: 0.9561
# aspect: ACCURACY 0.9293 | F1 MACRO 0.9539 | F1 MICRO 0.9561
#               precision    recall  f1-score   support
#
#         fuel       0.97      1.00      0.99       187
#      machine       0.92      0.98      0.95       175
#       others       0.89      0.92      0.90       158
#         part       0.90      0.96      0.93       158
#        price       0.97      0.98      0.98       192
#      service       0.95      1.00      0.98       191
#
#    micro avg       0.94      0.97      0.96      1061
#    macro avg       0.94      0.97      0.95      1061
# weighted avg       0.94      0.97      0.96      1061
#  samples avg       0.94      0.97      0.95      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 12.480228424072266 | ACCURACY: 0.8828 | F1 MACRO: 0.8676 | F1 MICRO: 0.8828
# EPOCH 2 | LOSS: 10.726587295532227 | ACCURACY: 0.9121 | F1 MACRO: 0.9004 | F1 MICRO: 0.9121
# EPOCH 3 | LOSS: 9.081682205200195 | ACCURACY: 0.9247 | F1 MACRO: 0.9169 | F1 MICRO: 0.9247
# EPOCH 4 | LOSS: 8.471616744995117 | ACCURACY: 0.8996 | F1 MACRO: 0.8842 | F1 MICRO: 0.8996
# EPOCH 5 | LOSS: 7.941308975219727 | ACCURACY: 0.9079 | F1 MACRO: 0.9001 | F1 MICRO: 0.9079
# EPOCH 6 | LOSS: 7.705276012420654 | ACCURACY: 0.9038 | F1 MACRO: 0.8879 | F1 MICRO: 0.9038
# EPOCH 7 | LOSS: 7.662113666534424 | ACCURACY: 0.9121 | F1 MACRO: 0.9034 | F1 MICRO: 0.9121
# EPOCH 8 | LOSS: 7.4739179611206055 | ACCURACY: 0.9163 | F1 MACRO: 0.9072 | F1 MICRO: 0.9163
# EPOCH 9 | LOSS: 7.088616847991943 | ACCURACY: 0.9038 | F1 MACRO: 0.8853 | F1 MICRO: 0.9038
# EPOCH 10 | LOSS: 7.130018711090088 | ACCURACY: 0.9163 | F1 MACRO: 0.9082 | F1 MICRO: 0.9163
# sentiment: ACCURACY 0.9247 | F1 MACRO 0.9169 | F1 MICRO 0.9247
#               precision    recall  f1-score   support
#
#     negative       0.83      0.96      0.89        77
#     positive       0.98      0.91      0.94       162
#
#     accuracy                           0.92       239
#    macro avg       0.91      0.93      0.92       239
# weighted avg       0.93      0.92      0.93       239
#
# --------------------------------------------------
# Iteration 208: Accuracy: 0.9221, F1 Micro: 0.9221, F1 Macro: 0.8429
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.91      0.91        11
#      neutral       0.98      1.00      0.99       181
#     positive       1.00      0.88      0.93        24
#
#     accuracy                           0.98       216
#    macro avg       0.96      0.93      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.78      0.88      0.82        16
#      neutral       0.94      0.98      0.96       167
#     positive       0.91      0.64      0.75        33
#
#     accuracy                           0.92       216
#    macro avg       0.88      0.83      0.84       216
# weighted avg       0.92      0.92      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.67      0.83      0.74        12
#      neutral       0.89      0.92      0.91       152
#     positive       0.75      0.63      0.69        52
#
#     accuracy                           0.85       216
#    macro avg       0.77      0.80      0.78       216
# weighted avg       0.85      0.85      0.84       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.77      0.87      0.82        23
#      neutral       0.91      0.97      0.94       152
#     positive       0.96      0.63      0.76        41
#
#     accuracy                           0.90       216
#    macro avg       0.88      0.83      0.84       216
# weighted avg       0.90      0.90      0.89       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.69      0.85      0.76        13
#      neutral       0.99      0.96      0.98       186
#     positive       0.68      0.76      0.72        17
#
#     accuracy                           0.94       216
#    macro avg       0.79      0.86      0.82       216
# weighted avg       0.95      0.94      0.94       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.71      0.83        14
#      neutral       0.94      1.00      0.97       185
#     positive       1.00      0.53      0.69        17
#
#     accuracy                           0.94       216
#    macro avg       0.98      0.75      0.83       216
# weighted avg       0.95      0.94      0.94       216
#
# Launching training on 2 GPUs.
# 602 602
# Nearest checkpoint: 540
# Threshold: 88659.890625
# Samples above threshold: 66
# Acquired samples: 66
# Sampling duration: 11.036129713058472 seconds
# New train size: 274
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.252784013748169 | ACCURACY: 0.7917 | F1 MACRO: 0.882 | F1 MICRO: 0.8834
# EPOCH 2 | LOSS: 2.856761932373047 | ACCURACY: 0.8073 | F1 MACRO: 0.8885 | F1 MICRO: 0.8901
# EPOCH 3 | LOSS: 2.672482490539551 | ACCURACY: 0.8311 | F1 MACRO: 0.9004 | F1 MICRO: 0.9022
# EPOCH 4 | LOSS: 2.454096794128418 | ACCURACY: 0.8512 | F1 MACRO: 0.9097 | F1 MICRO: 0.9118
# EPOCH 5 | LOSS: 2.3667752742767334 | ACCURACY: 0.8958 | F1 MACRO: 0.9351 | F1 MICRO: 0.9369
# EPOCH 6 | LOSS: 2.341733455657959 | ACCURACY: 0.9152 | F1 MACRO: 0.9453 | F1 MICRO: 0.9478
# EPOCH 7 | LOSS: 2.2715673446655273 | ACCURACY: 0.9338 | F1 MACRO: 0.9575 | F1 MICRO: 0.9592
# EPOCH 8 | LOSS: 2.211824417114258 | ACCURACY: 0.9368 | F1 MACRO: 0.9579 | F1 MICRO: 0.9604
# EPOCH 9 | LOSS: 2.0354208946228027 | ACCURACY: 0.9412 | F1 MACRO: 0.962 | F1 MICRO: 0.9637
# EPOCH 10 | LOSS: 1.9726829528808594 | ACCURACY: 0.9382 | F1 MACRO: 0.9594 | F1 MICRO: 0.9615
# aspect: ACCURACY 0.9412 | F1 MACRO 0.962 | F1 MICRO 0.9637
#               precision    recall  f1-score   support
#
#         fuel       0.97      1.00      0.98       187
#      machine       0.93      1.00      0.96       175
#       others       0.88      0.96      0.92       158
#         part       0.92      0.97      0.94       158
#        price       0.96      0.99      0.98       192
#      service       0.97      1.00      0.98       191
#
#    micro avg       0.94      0.99      0.96      1061
#    macro avg       0.94      0.99      0.96      1061
# weighted avg       0.94      0.99      0.96      1061
#  samples avg       0.94      0.99      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 9.855518341064453 | ACCURACY: 0.8553 | F1 MACRO: 0.8344 | F1 MICRO: 0.8553
# EPOCH 2 | LOSS: 8.688591957092285 | ACCURACY: 0.9254 | F1 MACRO: 0.9169 | F1 MICRO: 0.9254
# EPOCH 3 | LOSS: 6.878026485443115 | ACCURACY: 0.9386 | F1 MACRO: 0.9333 | F1 MICRO: 0.9386
# EPOCH 4 | LOSS: 6.44927453994751 | ACCURACY: 0.9123 | F1 MACRO: 0.9062 | F1 MICRO: 0.9123
# EPOCH 5 | LOSS: 6.2477545738220215 | ACCURACY: 0.8904 | F1 MACRO: 0.8696 | F1 MICRO: 0.8904
# EPOCH 6 | LOSS: 5.962548732757568 | ACCURACY: 0.9342 | F1 MACRO: 0.9276 | F1 MICRO: 0.9342
# EPOCH 7 | LOSS: 5.6620774269104 | ACCURACY: 0.9342 | F1 MACRO: 0.9271 | F1 MICRO: 0.9342
# EPOCH 8 | LOSS: 5.423834323883057 | ACCURACY: 0.9079 | F1 MACRO: 0.9008 | F1 MICRO: 0.9079
# EPOCH 9 | LOSS: 5.462856292724609 | ACCURACY: 0.9386 | F1 MACRO: 0.9322 | F1 MICRO: 0.9386
# EPOCH 10 | LOSS: 5.221226692199707 | ACCURACY: 0.9386 | F1 MACRO: 0.9322 | F1 MICRO: 0.9386
# sentiment: ACCURACY 0.9386 | F1 MACRO 0.9322 | F1 MICRO 0.9386
#               precision    recall  f1-score   support
#
#     negative       0.89      0.94      0.91        77
#     positive       0.97      0.94      0.95       151
#
#     accuracy                           0.94       228
#    macro avg       0.93      0.94      0.93       228
# weighted avg       0.94      0.94      0.94       228
#
# --------------------------------------------------
# Iteration 274: Accuracy: 0.9321, F1 Micro: 0.9321, F1 Macro: 0.8661
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.91      0.91        11
#      neutral       0.98      1.00      0.99       181
#     positive       1.00      0.88      0.93        24
#
#     accuracy                           0.98       216
#    macro avg       0.96      0.93      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.69      0.76        16
#      neutral       0.93      1.00      0.96       167
#     positive       0.91      0.64      0.75        33
#
#     accuracy                           0.92       216
#    macro avg       0.90      0.77      0.82       216
# weighted avg       0.92      0.92      0.91       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.75      0.75        12
#      neutral       0.88      0.94      0.91       152
#     positive       0.78      0.62      0.69        52
#
#     accuracy                           0.85       216
#    macro avg       0.80      0.77      0.78       216
# weighted avg       0.85      0.85      0.85       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.81      0.91      0.86        23
#      neutral       0.91      0.97      0.94       152
#     positive       0.93      0.66      0.77        41
#
#     accuracy                           0.90       216
#    macro avg       0.88      0.85      0.86       216
# weighted avg       0.91      0.90      0.90       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.77      0.80        13
#      neutral       0.97      0.99      0.98       186
#     positive       0.85      0.65      0.73        17
#
#     accuracy                           0.95       216
#    macro avg       0.88      0.80      0.84       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.98      1.00      0.99       185
#     positive       1.00      0.82      0.90        17
#
#     accuracy                           0.98       216
#    macro avg       0.99      0.92      0.95       216
# weighted avg       0.98      0.98      0.98       216
#
# Launching training on 2 GPUs.
# 552 552
# Nearest checkpoint: 540
# Threshold: 88581.6875
# Samples above threshold: 59
# Acquired samples: 59
# Sampling duration: 11.708378076553345 seconds
# New train size: 333
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.3817381858825684 | ACCURACY: 0.7932 | F1 MACRO: 0.8827 | F1 MICRO: 0.8842
# EPOCH 2 | LOSS: 2.896495819091797 | ACCURACY: 0.811 | F1 MACRO: 0.8912 | F1 MICRO: 0.8925
# EPOCH 3 | LOSS: 2.6676273345947266 | ACCURACY: 0.8527 | F1 MACRO: 0.9113 | F1 MICRO: 0.9129
# EPOCH 4 | LOSS: 2.6414635181427 | ACCURACY: 0.8943 | F1 MACRO: 0.9335 | F1 MICRO: 0.9359
# EPOCH 5 | LOSS: 2.4772379398345947 | ACCURACY: 0.9256 | F1 MACRO: 0.9519 | F1 MICRO: 0.9541
# EPOCH 6 | LOSS: 2.327631950378418 | ACCURACY: 0.9382 | F1 MACRO: 0.9592 | F1 MICRO: 0.9615
# EPOCH 7 | LOSS: 2.2375895977020264 | ACCURACY: 0.9353 | F1 MACRO: 0.9576 | F1 MICRO: 0.9597
# EPOCH 8 | LOSS: 2.0774552822113037 | ACCURACY: 0.9457 | F1 MACRO: 0.964 | F1 MICRO: 0.966
# EPOCH 9 | LOSS: 2.020020008087158 | ACCURACY: 0.9368 | F1 MACRO: 0.9574 | F1 MICRO: 0.9603
# EPOCH 10 | LOSS: 1.9429244995117188 | ACCURACY: 0.9501 | F1 MACRO: 0.9673 | F1 MICRO: 0.9689
# aspect: ACCURACY 0.9501 | F1 MACRO 0.9673 | F1 MICRO 0.9689
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.97      0.97      0.97       175
#       others       0.88      0.96      0.92       158
#         part       0.95      0.96      0.96       158
#        price       0.97      0.99      0.98       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.95      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 8.546682357788086 | ACCURACY: 0.8776 | F1 MACRO: 0.8617 | F1 MICRO: 0.8776
# EPOCH 2 | LOSS: 7.5697126388549805 | ACCURACY: 0.9388 | F1 MACRO: 0.9302 | F1 MICRO: 0.9388
# EPOCH 3 | LOSS: 6.044066429138184 | ACCURACY: 0.9265 | F1 MACRO: 0.918 | F1 MICRO: 0.9265
# EPOCH 4 | LOSS: 5.531257152557373 | ACCURACY: 0.9265 | F1 MACRO: 0.9189 | F1 MICRO: 0.9265
# EPOCH 5 | LOSS: 5.36174201965332 | ACCURACY: 0.9224 | F1 MACRO: 0.9121 | F1 MICRO: 0.9224
# EPOCH 6 | LOSS: 5.076876163482666 | ACCURACY: 0.8898 | F1 MACRO: 0.8817 | F1 MICRO: 0.8898
# EPOCH 7 | LOSS: 5.020874500274658 | ACCURACY: 0.9102 | F1 MACRO: 0.8958 | F1 MICRO: 0.9102
# EPOCH 8 | LOSS: 4.7162580490112305 | ACCURACY: 0.9184 | F1 MACRO: 0.9094 | F1 MICRO: 0.9184
# EPOCH 9 | LOSS: 4.580819606781006 | ACCURACY: 0.9388 | F1 MACRO: 0.9311 | F1 MICRO: 0.9388
# EPOCH 10 | LOSS: 4.583611488342285 | ACCURACY: 0.9061 | F1 MACRO: 0.8891 | F1 MICRO: 0.9061
# sentiment: ACCURACY 0.9388 | F1 MACRO 0.9311 | F1 MICRO 0.9388
#               precision    recall  f1-score   support
#
#     negative       0.88      0.94      0.91        79
#     positive       0.97      0.94      0.95       166
#
#     accuracy                           0.94       245
#    macro avg       0.92      0.94      0.93       245
# weighted avg       0.94      0.94      0.94       245
#
# --------------------------------------------------
# Iteration 333: Accuracy: 0.939, F1 Micro: 0.939, F1 Macro: 0.8829
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.98      1.00      0.99       181
#     positive       1.00      0.92      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       0.99      0.94      0.97       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.75      0.80        16
#      neutral       0.97      0.96      0.96       167
#     positive       0.81      0.91      0.86        33
#
#     accuracy                           0.94       216
#    macro avg       0.88      0.87      0.87       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.69      0.75      0.72        12
#      neutral       0.88      0.96      0.92       152
#     positive       0.84      0.60      0.70        52
#
#     accuracy                           0.86       216
#    macro avg       0.80      0.77      0.78       216
# weighted avg       0.86      0.86      0.85       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.79      0.83      0.81        23
#      neutral       0.94      0.97      0.96       152
#     positive       0.86      0.73      0.79        41
#
#     accuracy                           0.91       216
#    macro avg       0.86      0.84      0.85       216
# weighted avg       0.91      0.91      0.91       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.77      0.83        13
#      neutral       0.97      0.99      0.98       186
#     positive       0.87      0.76      0.81        17
#
#     accuracy                           0.96       216
#    macro avg       0.91      0.84      0.87       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.98      1.00      0.99       185
#     positive       1.00      0.82      0.90        17
#
#     accuracy                           0.98       216
#    macro avg       0.99      0.92      0.95       216
# weighted avg       0.98      0.98      0.98       216
#
# Launching training on 2 GPUs.
# 504 504
# Nearest checkpoint: 540
# Threshold: 88588.078125
# Samples above threshold: 54
# Acquired samples: 54
# Sampling duration: 13.016268730163574 seconds
# New train size: 387
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.3033440113067627 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# EPOCH 2 | LOSS: 2.7882375717163086 | ACCURACY: 0.8356 | F1 MACRO: 0.9034 | F1 MICRO: 0.9048
# EPOCH 3 | LOSS: 2.6007606983184814 | ACCURACY: 0.8676 | F1 MACRO: 0.9208 | F1 MICRO: 0.922
# EPOCH 4 | LOSS: 2.5627267360687256 | ACCURACY: 0.9174 | F1 MACRO: 0.9468 | F1 MICRO: 0.9492
# EPOCH 5 | LOSS: 2.383057117462158 | ACCURACY: 0.9256 | F1 MACRO: 0.9507 | F1 MICRO: 0.9536
# EPOCH 6 | LOSS: 2.2287445068359375 | ACCURACY: 0.9442 | F1 MACRO: 0.9639 | F1 MICRO: 0.9653
# EPOCH 7 | LOSS: 2.1063475608825684 | ACCURACY: 0.9494 | F1 MACRO: 0.967 | F1 MICRO: 0.9685
# EPOCH 8 | LOSS: 1.982230305671692 | ACCURACY: 0.9457 | F1 MACRO: 0.9641 | F1 MICRO: 0.9661
# EPOCH 9 | LOSS: 1.9327503442764282 | ACCURACY: 0.9449 | F1 MACRO: 0.9624 | F1 MICRO: 0.9653
# EPOCH 10 | LOSS: 1.8581384420394897 | ACCURACY: 0.9487 | F1 MACRO: 0.9657 | F1 MICRO: 0.9679
# aspect: ACCURACY 0.9494 | F1 MACRO 0.967 | F1 MICRO 0.9685
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.95      0.97      0.96       175
#       others       0.88      0.97      0.92       158
#         part       0.93      0.97      0.95       158
#        price       0.97      1.00      0.98       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.95      0.99      0.97      1061
#    macro avg       0.95      0.98      0.97      1061
# weighted avg       0.95      0.99      0.97      1061
#  samples avg       0.95      0.99      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.908013820648193 | ACCURACY: 0.8423 | F1 MACRO: 0.7979 | F1 MICRO: 0.8423
# EPOCH 2 | LOSS: 6.022173881530762 | ACCURACY: 0.9378 | F1 MACRO: 0.9301 | F1 MICRO: 0.9378
# EPOCH 3 | LOSS: 4.770361423492432 | ACCURACY: 0.917 | F1 MACRO: 0.9052 | F1 MICRO: 0.917
# EPOCH 4 | LOSS: 4.556109428405762 | ACCURACY: 0.9378 | F1 MACRO: 0.9309 | F1 MICRO: 0.9378
# EPOCH 5 | LOSS: 4.308570861816406 | ACCURACY: 0.9295 | F1 MACRO: 0.9207 | F1 MICRO: 0.9295
# EPOCH 6 | LOSS: 4.148120403289795 | ACCURACY: 0.9336 | F1 MACRO: 0.9261 | F1 MICRO: 0.9336
# EPOCH 7 | LOSS: 4.0603928565979 | ACCURACY: 0.9087 | F1 MACRO: 0.895 | F1 MICRO: 0.9087
# EPOCH 8 | LOSS: 3.902493715286255 | ACCURACY: 0.9295 | F1 MACRO: 0.9197 | F1 MICRO: 0.9295
# EPOCH 9 | LOSS: 3.8633270263671875 | ACCURACY: 0.9212 | F1 MACRO: 0.913 | F1 MICRO: 0.9212
# EPOCH 10 | LOSS: 3.7926647663116455 | ACCURACY: 0.9378 | F1 MACRO: 0.9313 | F1 MICRO: 0.9378
# sentiment: ACCURACY 0.9378 | F1 MACRO 0.9313 | F1 MICRO 0.9378
#               precision    recall  f1-score   support
#
#     negative       0.87      0.95      0.91        80
#     positive       0.97      0.93      0.95       161
#
#     accuracy                           0.94       241
#    macro avg       0.92      0.94      0.93       241
# weighted avg       0.94      0.94      0.94       241
#
# --------------------------------------------------
# Iteration 387: Accuracy: 0.939, F1 Micro: 0.939, F1 Macro: 0.8826
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.82      0.90        11
#      neutral       0.98      1.00      0.99       181
#     positive       0.95      0.88      0.91        24
#
#     accuracy                           0.98       216
#    macro avg       0.98      0.90      0.93       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.75      0.77        16
#      neutral       0.95      0.95      0.95       167
#     positive       0.76      0.79      0.78        33
#
#     accuracy                           0.91       216
#    macro avg       0.84      0.83      0.83       216
# weighted avg       0.91      0.91      0.91       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.75      0.75        12
#      neutral       0.88      0.96      0.92       152
#     positive       0.85      0.63      0.73        52
#
#     accuracy                           0.87       216
#    macro avg       0.83      0.78      0.80       216
# weighted avg       0.87      0.87      0.86       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.87      0.85        23
#      neutral       0.94      0.99      0.96       152
#     positive       0.91      0.73      0.81        41
#
#     accuracy                           0.93       216
#    macro avg       0.90      0.86      0.88       216
# weighted avg       0.93      0.93      0.92       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.77      0.87        13
#      neutral       0.97      0.99      0.98       186
#     positive       0.87      0.76      0.81        17
#
#     accuracy                           0.96       216
#    macro avg       0.95      0.84      0.89       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        14
#      neutral       0.98      1.00      0.99       185
#     positive       1.00      0.82      0.90        17
#
#     accuracy                           0.99       216
#    macro avg       0.99      0.94      0.97       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 457 457
# Nearest checkpoint: 540
# Threshold: 88605.8125
# Samples above threshold: 48
# Acquired samples: 48
# Sampling duration: 15.066539764404297 seconds
# New train size: 435
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.1594338417053223 | ACCURACY: 0.7984 | F1 MACRO: 0.8853 | F1 MICRO: 0.8868
# EPOCH 2 | LOSS: 2.5629262924194336 | ACCURACY: 0.8445 | F1 MACRO: 0.9072 | F1 MICRO: 0.9088
# EPOCH 3 | LOSS: 2.463593006134033 | ACCURACY: 0.8891 | F1 MACRO: 0.9316 | F1 MICRO: 0.933
# EPOCH 4 | LOSS: 2.39975643157959 | ACCURACY: 0.9323 | F1 MACRO: 0.9564 | F1 MICRO: 0.9581
# EPOCH 5 | LOSS: 2.222717761993408 | ACCURACY: 0.9397 | F1 MACRO: 0.9601 | F1 MICRO: 0.9623
# EPOCH 6 | LOSS: 2.061756134033203 | ACCURACY: 0.9531 | F1 MACRO: 0.9695 | F1 MICRO: 0.9708
# EPOCH 7 | LOSS: 1.9471839666366577 | ACCURACY: 0.9501 | F1 MACRO: 0.9668 | F1 MICRO: 0.9688
# EPOCH 8 | LOSS: 1.8462249040603638 | ACCURACY: 0.9501 | F1 MACRO: 0.9673 | F1 MICRO: 0.9689
# EPOCH 9 | LOSS: 1.7913604974746704 | ACCURACY: 0.9539 | F1 MACRO: 0.9688 | F1 MICRO: 0.9709
# EPOCH 10 | LOSS: 1.7525675296783447 | ACCURACY: 0.9524 | F1 MACRO: 0.9682 | F1 MICRO: 0.9701
# aspect: ACCURACY 0.9539 | F1 MACRO 0.9688 | F1 MICRO 0.9709
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.95      0.99      0.97       175
#       others       0.94      0.89      0.92       158
#         part       0.96      0.96      0.96       158
#        price       0.97      1.00      0.98       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.97      0.98      0.97      1061
#    macro avg       0.96      0.97      0.97      1061
# weighted avg       0.97      0.98      0.97      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.64143705368042 | ACCURACY: 0.8824 | F1 MACRO: 0.8561 | F1 MICRO: 0.8824
# EPOCH 2 | LOSS: 5.564404487609863 | ACCURACY: 0.9137 | F1 MACRO: 0.9051 | F1 MICRO: 0.9137
# EPOCH 3 | LOSS: 4.718780040740967 | ACCURACY: 0.9216 | F1 MACRO: 0.9107 | F1 MICRO: 0.9216
# EPOCH 4 | LOSS: 4.5460028648376465 | ACCURACY: 0.8902 | F1 MACRO: 0.8815 | F1 MICRO: 0.8902
# EPOCH 5 | LOSS: 4.235858917236328 | ACCURACY: 0.9373 | F1 MACRO: 0.9281 | F1 MICRO: 0.9373
# EPOCH 6 | LOSS: 4.038295269012451 | ACCURACY: 0.8863 | F1 MACRO: 0.877 | F1 MICRO: 0.8863
# EPOCH 7 | LOSS: 4.02895450592041 | ACCURACY: 0.9333 | F1 MACRO: 0.9261 | F1 MICRO: 0.9333
# EPOCH 8 | LOSS: 3.861097574234009 | ACCURACY: 0.9255 | F1 MACRO: 0.9119 | F1 MICRO: 0.9255
# EPOCH 9 | LOSS: 3.950444221496582 | ACCURACY: 0.9451 | F1 MACRO: 0.9375 | F1 MICRO: 0.9451
# EPOCH 10 | LOSS: 3.781815767288208 | ACCURACY: 0.9373 | F1 MACRO: 0.9294 | F1 MICRO: 0.9373
# sentiment: ACCURACY 0.9451 | F1 MACRO 0.9375 | F1 MICRO 0.9451
#               precision    recall  f1-score   support
#
#     negative       0.88      0.95      0.92        80
#     positive       0.98      0.94      0.96       175
#
#     accuracy                           0.95       255
#    macro avg       0.93      0.95      0.94       255
# weighted avg       0.95      0.95      0.95       255
#
# --------------------------------------------------
# Iteration 435: Accuracy: 0.9468, F1 Micro: 0.9468, F1 Macro: 0.8933
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.82      0.90        11
#      neutral       0.98      1.00      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.98       216
#    macro avg       0.98      0.91      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.69      0.76        16
#      neutral       0.95      0.99      0.97       167
#     positive       0.93      0.82      0.87        33
#
#     accuracy                           0.94       216
#    macro avg       0.91      0.83      0.87       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.67      0.83      0.74        12
#      neutral       0.91      0.91      0.91       152
#     positive       0.76      0.73      0.75        52
#
#     accuracy                           0.86       216
#    macro avg       0.78      0.82      0.80       216
# weighted avg       0.86      0.86      0.86       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.84      0.91      0.87        23
#      neutral       0.97      0.97      0.97       152
#     positive       0.89      0.83      0.86        41
#
#     accuracy                           0.94       216
#    macro avg       0.90      0.91      0.90       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.77      0.83        13
#      neutral       0.97      1.00      0.98       186
#     positive       0.92      0.71      0.80        17
#
#     accuracy                           0.96       216
#    macro avg       0.93      0.83      0.87       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.99      1.00      0.99       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.96      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 419 419
# Nearest checkpoint: 540
# Threshold: 88560.2109375
# Samples above threshold: 43
# Acquired samples: 43
# Sampling duration: 14.900507926940918 seconds
# New train size: 478
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.1293818950653076 | ACCURACY: 0.811 | F1 MACRO: 0.8912 | F1 MICRO: 0.8927
# EPOCH 2 | LOSS: 2.607888698577881 | ACCURACY: 0.8504 | F1 MACRO: 0.9096 | F1 MICRO: 0.9113
# EPOCH 3 | LOSS: 2.4630749225616455 | ACCURACY: 0.9062 | F1 MACRO: 0.9397 | F1 MICRO: 0.9421
# EPOCH 4 | LOSS: 2.340273380279541 | ACCURACY: 0.9345 | F1 MACRO: 0.9579 | F1 MICRO: 0.9596
# EPOCH 5 | LOSS: 2.159047842025757 | ACCURACY: 0.9457 | F1 MACRO: 0.9637 | F1 MICRO: 0.9661
# EPOCH 6 | LOSS: 2.028498649597168 | ACCURACY: 0.9568 | F1 MACRO: 0.9717 | F1 MICRO: 0.9731
# EPOCH 7 | LOSS: 1.9201858043670654 | ACCURACY: 0.9591 | F1 MACRO: 0.9735 | F1 MICRO: 0.9745
# EPOCH 8 | LOSS: 1.8695933818817139 | ACCURACY: 0.9539 | F1 MACRO: 0.9696 | F1 MICRO: 0.9712
# EPOCH 9 | LOSS: 1.7917073965072632 | ACCURACY: 0.9509 | F1 MACRO: 0.9678 | F1 MICRO: 0.9694
# EPOCH 10 | LOSS: 1.741420865058899 | ACCURACY: 0.9561 | F1 MACRO: 0.9716 | F1 MICRO: 0.9727
# aspect: ACCURACY 0.9591 | F1 MACRO 0.9735 | F1 MICRO 0.9745
#               precision    recall  f1-score   support
#
#         fuel       0.97      1.00      0.99       187
#      machine       0.95      0.99      0.97       175
#       others       0.90      0.97      0.93       158
#         part       0.97      0.98      0.97       158
#        price       0.97      0.99      0.98       192
#      service       0.99      1.00      0.99       191
#
#    micro avg       0.96      0.99      0.97      1061
#    macro avg       0.96      0.99      0.97      1061
# weighted avg       0.96      0.99      0.97      1061
#  samples avg       0.96      0.99      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.146699905395508 | ACCURACY: 0.905 | F1 MACRO: 0.8916 | F1 MICRO: 0.905
# EPOCH 2 | LOSS: 5.472653865814209 | ACCURACY: 0.938 | F1 MACRO: 0.9314 | F1 MICRO: 0.938
# EPOCH 3 | LOSS: 4.445551872253418 | ACCURACY: 0.9174 | F1 MACRO: 0.9066 | F1 MICRO: 0.9174
# EPOCH 4 | LOSS: 4.027034759521484 | ACCURACY: 0.9298 | F1 MACRO: 0.9223 | F1 MICRO: 0.9298
# EPOCH 5 | LOSS: 3.8604769706726074 | ACCURACY: 0.9339 | F1 MACRO: 0.9271 | F1 MICRO: 0.9339
# EPOCH 6 | LOSS: 3.8450777530670166 | ACCURACY: 0.9256 | F1 MACRO: 0.9184 | F1 MICRO: 0.9256
# EPOCH 7 | LOSS: 3.6538262367248535 | ACCURACY: 0.9298 | F1 MACRO: 0.9231 | F1 MICRO: 0.9298
# EPOCH 8 | LOSS: 3.4512574672698975 | ACCURACY: 0.938 | F1 MACRO: 0.931 | F1 MICRO: 0.938
# EPOCH 9 | LOSS: 3.522620916366577 | ACCURACY: 0.9174 | F1 MACRO: 0.9107 | F1 MICRO: 0.9174
# EPOCH 10 | LOSS: 3.5765929222106934 | ACCURACY: 0.9174 | F1 MACRO: 0.9103 | F1 MICRO: 0.9174
# sentiment: ACCURACY 0.938 | F1 MACRO 0.931 | F1 MICRO 0.938
#               precision    recall  f1-score   support
#
#     negative       0.89      0.93      0.91        81
#     positive       0.96      0.94      0.95       161
#
#     accuracy                           0.94       242
#    macro avg       0.93      0.94      0.93       242
# weighted avg       0.94      0.94      0.94       242
#
# --------------------------------------------------
# Iteration 478: Accuracy: 0.9468, F1 Micro: 0.9468, F1 Macro: 0.8872
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.82      0.90        11
#      neutral       0.98      1.00      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.98       216
#    macro avg       0.98      0.91      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.69      0.79        16
#      neutral       0.95      0.98      0.96       167
#     positive       0.81      0.76      0.78        33
#
#     accuracy                           0.93       216
#    macro avg       0.89      0.81      0.84       216
# weighted avg       0.92      0.93      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.75      0.75        12
#      neutral       0.90      0.97      0.94       152
#     positive       0.90      0.69      0.78        52
#
#     accuracy                           0.89       216
#    macro avg       0.85      0.81      0.82       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.84      0.91      0.87        23
#      neutral       0.96      0.98      0.97       152
#     positive       0.89      0.76      0.82        41
#
#     accuracy                           0.93       216
#    macro avg       0.89      0.88      0.89       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.77      0.83        13
#      neutral       0.97      1.00      0.98       186
#     positive       0.92      0.71      0.80        17
#
#     accuracy                           0.96       216
#    macro avg       0.93      0.83      0.87       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.93      0.93        14
#      neutral       0.99      0.99      0.99       185
#     positive       0.94      0.94      0.94        17
#
#     accuracy                           0.99       216
#    macro avg       0.95      0.95      0.95       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 375 375
# Nearest checkpoint: 540
# Threshold: 88592.75
# Samples above threshold: 39
# Acquired samples: 39
# Sampling duration: 14.886943578720093 seconds
# New train size: 517
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.2075767517089844 | ACCURACY: 0.8125 | F1 MACRO: 0.8925 | F1 MICRO: 0.8934
# EPOCH 2 | LOSS: 2.667475700378418 | ACCURACY: 0.8601 | F1 MACRO: 0.9157 | F1 MICRO: 0.9169
# EPOCH 3 | LOSS: 2.4851717948913574 | ACCURACY: 0.9211 | F1 MACRO: 0.9483 | F1 MICRO: 0.951
# EPOCH 4 | LOSS: 2.3584394454956055 | ACCURACY: 0.936 | F1 MACRO: 0.9567 | F1 MICRO: 0.9599
# EPOCH 5 | LOSS: 2.10642671585083 | ACCURACY: 0.9516 | F1 MACRO: 0.9686 | F1 MICRO: 0.9698
# EPOCH 6 | LOSS: 1.9919590950012207 | ACCURACY: 0.9576 | F1 MACRO: 0.9727 | F1 MICRO: 0.9737
# EPOCH 7 | LOSS: 1.8866609334945679 | ACCURACY: 0.9516 | F1 MACRO: 0.9686 | F1 MICRO: 0.9699
# EPOCH 8 | LOSS: 1.8280112743377686 | ACCURACY: 0.9591 | F1 MACRO: 0.973 | F1 MICRO: 0.9744
# EPOCH 9 | LOSS: 1.7821881771087646 | ACCURACY: 0.9561 | F1 MACRO: 0.9712 | F1 MICRO: 0.9725
# EPOCH 10 | LOSS: 1.738355040550232 | ACCURACY: 0.9539 | F1 MACRO: 0.9694 | F1 MICRO: 0.9712
# aspect: ACCURACY 0.9591 | F1 MACRO 0.973 | F1 MICRO 0.9744
# ...
#
#    micro avg       0.97      0.99      0.98      1061
#    macro avg       0.97      0.98      0.97      1061
# weighted avg       0.97      0.99      0.98      1061
#  samples avg       0.97      0.99      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.7082619667053223 | ACCURACY: 0.9051 | F1 MACRO: 0.8888 | F1 MICRO: 0.9051
# EPOCH 2 | LOSS: 3.0024664402008057 | ACCURACY: 0.913 | F1 MACRO: 0.9031 | F1 MICRO: 0.913
# EPOCH 3 | LOSS: 2.5192158222198486 | ACCURACY: 0.9368 | F1 MACRO: 0.9274 | F1 MICRO: 0.9368
# EPOCH 4 | LOSS: 2.317532777786255 | ACCURACY: 0.9447 | F1 MACRO: 0.9383 | F1 MICRO: 0.9447
# EPOCH 5 | LOSS: 2.2007172107696533 | ACCURACY: 0.9249 | F1 MACRO: 0.9179 | F1 MICRO: 0.9249
# EPOCH 6 | LOSS: 2.1615140438079834 | ACCURACY: 0.9289 | F1 MACRO: 0.9177 | F1 MICRO: 0.9289
# EPOCH 7 | LOSS: 2.0346086025238037 | ACCURACY: 0.9447 | F1 MACRO: 0.9387 | F1 MICRO: 0.9447
# EPOCH 8 | LOSS: 2.0551528930664062 | ACCURACY: 0.9407 | F1 MACRO: 0.9345 | F1 MICRO: 0.9407
# EPOCH 9 | LOSS: 2.029090404510498 | ACCURACY: 0.9447 | F1 MACRO: 0.936 | F1 MICRO: 0.9447
# EPOCH 10 | LOSS: 2.0125744342803955 | ACCURACY: 0.9447 | F1 MACRO: 0.9372 | F1 MICRO: 0.9447
# sentiment: ACCURACY 0.9447 | F1 MACRO 0.9372 | F1 MICRO 0.9447
#               precision    recall  f1-score   support
#
#     negative       0.90      0.93      0.92        82
#     positive       0.96      0.95      0.96       171
#
#     accuracy                           0.94       253
#    macro avg       0.93      0.94      0.94       253
# weighted avg       0.95      0.94      0.94       253
#
# --------------------------------------------------
# Iteration 831: Accuracy: 0.9506, F1 Micro: 0.9506, F1 Macro: 0.9042
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.99      1.00      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.94      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.75      0.80        16
#      neutral       0.93      0.99      0.96       167
#     positive       0.92      0.67      0.77        33
#
#     accuracy                           0.93       216
#    macro avg       0.90      0.80      0.84       216
# weighted avg       0.92      0.93      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.82      0.75      0.78        12
#      neutral       0.92      0.93      0.93       152
#     positive       0.80      0.77      0.78        52
#
#     accuracy                           0.88       216
#    macro avg       0.84      0.82      0.83       216
# weighted avg       0.88      0.88      0.88       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.82      1.00      0.90        23
#      neutral       0.97      0.99      0.98       152
#     positive       0.97      0.78      0.86        41
#
#     accuracy                           0.95       216
#    macro avg       0.92      0.92      0.91       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.92      0.92        13
#      neutral       0.98      0.98      0.98       186
#     positive       0.82      0.82      0.82        17
#
#     accuracy                           0.97       216
#    macro avg       0.91      0.91      0.91       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.99      1.00      1.00       185
#     positive       0.94      1.00      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.95      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 33 33
# Nearest checkpoint: 864
# Threshold: 88339.3984375
# Samples above threshold: 4
# Acquired samples: 25
# Sampling duration: 20.30696725845337 seconds
# New train size: 856
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.8952198028564453 | ACCURACY: 0.8348 | F1 MACRO: 0.9038 | F1 MICRO: 0.9046
# EPOCH 2 | LOSS: 2.439326286315918 | ACCURACY: 0.9397 | F1 MACRO: 0.9616 | F1 MICRO: 0.9627
# EPOCH 3 | LOSS: 2.2327446937561035 | ACCURACY: 0.9487 | F1 MACRO: 0.9657 | F1 MICRO: 0.9678
# EPOCH 4 | LOSS: 1.989907145500183 | ACCURACY: 0.9576 | F1 MACRO: 0.9719 | F1 MICRO: 0.9735
# EPOCH 5 | LOSS: 1.8661441802978516 | ACCURACY: 0.9554 | F1 MACRO: 0.97 | F1 MICRO: 0.9719
# EPOCH 6 | LOSS: 1.7571454048156738 | ACCURACY: 0.9576 | F1 MACRO: 0.9716 | F1 MICRO: 0.9733
# EPOCH 7 | LOSS: 1.7119812965393066 | ACCURACY: 0.9568 | F1 MACRO: 0.9707 | F1 MICRO: 0.9728
# EPOCH 8 | LOSS: 1.6254502534866333 | ACCURACY: 0.9606 | F1 MACRO: 0.9731 | F1 MICRO: 0.975
# EPOCH 9 | LOSS: 1.588404893875122 | ACCURACY: 0.9583 | F1 MACRO: 0.9717 | F1 MICRO: 0.9736
# EPOCH 10 | LOSS: 1.5605705976486206 | ACCURACY: 0.9598 | F1 MACRO: 0.9722 | F1 MICRO: 0.9745
# aspect: ACCURACY 0.9606 | F1 MACRO 0.9731 | F1 MICRO 0.975
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.96      0.97      0.97       175
#       others       0.92      0.90      0.91       158
#         part       0.97      0.99      0.98       158
#        price       0.99      0.98      0.99       192
#      service       1.00      1.00      1.00       191
#
#    micro avg       0.97      0.98      0.98      1061
#    macro avg       0.97      0.97      0.97      1061
# weighted avg       0.97      0.98      0.97      1061
#  samples avg       0.97      0.97      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.590683937072754 | ACCURACY: 0.8942 | F1 MACRO: 0.8817 | F1 MICRO: 0.8942
# EPOCH 2 | LOSS: 3.002976655960083 | ACCURACY: 0.9343 | F1 MACRO: 0.9264 | F1 MICRO: 0.9343
# EPOCH 3 | LOSS: 2.4265291690826416 | ACCURACY: 0.927 | F1 MACRO: 0.9177 | F1 MICRO: 0.927
# EPOCH 4 | LOSS: 2.3356759548187256 | ACCURACY: 0.927 | F1 MACRO: 0.9163 | F1 MICRO: 0.927
# EPOCH 5 | LOSS: 2.2254481315612793 | ACCURACY: 0.9489 | F1 MACRO: 0.9414 | F1 MICRO: 0.9489
# EPOCH 6 | LOSS: 2.2266650199890137 | ACCURACY: 0.9562 | F1 MACRO: 0.9495 | F1 MICRO: 0.9562
# EPOCH 7 | LOSS: 2.101746082305908 | ACCURACY: 0.9489 | F1 MACRO: 0.9414 | F1 MICRO: 0.9489
# EPOCH 8 | LOSS: 2.0977227687835693 | ACCURACY: 0.9234 | F1 MACRO: 0.9148 | F1 MICRO: 0.9234
# EPOCH 9 | LOSS: 2.023045778274536 | ACCURACY: 0.938 | F1 MACRO: 0.9295 | F1 MICRO: 0.938
# EPOCH 10 | LOSS: 1.960631251335144 | ACCURACY: 0.927 | F1 MACRO: 0.9153 | F1 MICRO: 0.927
# sentiment: ACCURACY 0.9562 | F1 MACRO 0.9495 | F1 MICRO 0.9562
#               precision    recall  f1-score   support
#
#     negative       0.92      0.94      0.93        86
#     positive       0.97      0.96      0.97       188
#
#     accuracy                           0.96       274
#    macro avg       0.95      0.95      0.95       274
# weighted avg       0.96      0.96      0.96       274
#
# --------------------------------------------------
# Iteration 856: Accuracy: 0.9545, F1 Micro: 0.9545, F1 Macro: 0.9164
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.92      1.00      0.96        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.95      0.88      0.91        24
#
#     accuracy                           0.98       216
#    macro avg       0.95      0.96      0.95       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.75      0.80        16
#      neutral       0.97      0.97      0.97       167
#     positive       0.83      0.88      0.85        33
#
#     accuracy                           0.94       216
#    macro avg       0.89      0.87      0.87       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.83      0.83        12
#      neutral       0.94      0.91      0.93       152
#     positive       0.75      0.81      0.78        52
#
#     accuracy                           0.88       216
#    macro avg       0.84      0.85      0.85       216
# weighted avg       0.89      0.88      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.88      1.00      0.94        23
#      neutral       0.96      0.98      0.97       152
#     positive       0.94      0.80      0.87        41
#
#     accuracy                           0.95       216
#    macro avg       0.93      0.93      0.93       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.85      0.85        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.83      0.88      0.86        17
#
#     accuracy                           0.97       216
#    macro avg       0.89      0.91      0.90       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        14
#      neutral       1.00      1.00      1.00       185
#     positive       1.00      1.00      1.00        17
#
#     accuracy                           1.00       216
#    macro avg       1.00      1.00      1.00       216
# weighted avg       1.00      1.00      1.00       216
#
# Launching training on 2 GPUs.
# 8 8
# Nearest checkpoint: 864
# Threshold: 88316.71875
# Samples above threshold: 1
# Acquired samples: 8
# Sampling duration: 20.94018054008484 seconds
# New train size: 864
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.93326735496521 | ACCURACY: 0.8289 | F1 MACRO: 0.901 | F1 MICRO: 0.9021
# EPOCH 2 | LOSS: 2.4251656532287598 | ACCURACY: 0.9382 | F1 MACRO: 0.9599 | F1 MICRO: 0.9617
# EPOCH 3 | LOSS: 2.192793846130371 | ACCURACY: 0.9539 | F1 MACRO: 0.9699 | F1 MICRO: 0.9713
# EPOCH 4 | LOSS: 1.9771536588668823 | ACCURACY: 0.9598 | F1 MACRO: 0.9735 | F1 MICRO: 0.9748
# EPOCH 5 | LOSS: 1.8499311208724976 | ACCURACY: 0.9598 | F1 MACRO: 0.9736 | F1 MICRO: 0.9748
# EPOCH 6 | LOSS: 1.7582319974899292 | ACCURACY: 0.9576 | F1 MACRO: 0.9717 | F1 MICRO: 0.9733
# EPOCH 7 | LOSS: 1.688629150390625 | ACCURACY: 0.9546 | F1 MACRO: 0.9694 | F1 MICRO: 0.9714
# EPOCH 8 | LOSS: 1.6498104333877563 | ACCURACY: 0.9606 | F1 MACRO: 0.9737 | F1 MICRO: 0.9752
# EPOCH 9 | LOSS: 1.6006824970245361 | ACCURACY: 0.9606 | F1 MACRO: 0.9728 | F1 MICRO: 0.9751
# EPOCH 10 | LOSS: 1.5709939002990723 | ACCURACY: 0.9613 | F1 MACRO: 0.974 | F1 MICRO: 0.9757
# aspect: ACCURACY 0.9613 | F1 MACRO 0.974 | F1 MICRO 0.9757
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.94      0.99      0.96       175
#       others       0.91      0.93      0.92       158
#         part       0.97      0.97      0.97       158
#        price       0.99      1.00      0.99       192
#      service       1.00      1.00      1.00       191
#
#    micro avg       0.97      0.98      0.98      1061
#    macro avg       0.97      0.98      0.97      1061
# weighted avg       0.97      0.98      0.98      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.616981267929077 | ACCURACY: 0.8774 | F1 MACRO: 0.8682 | F1 MICRO: 0.8774
# EPOCH 2 | LOSS: 2.75150728225708 | ACCURACY: 0.9425 | F1 MACRO: 0.9344 | F1 MICRO: 0.9425
# EPOCH 3 | LOSS: 2.4021975994110107 | ACCURACY: 0.9349 | F1 MACRO: 0.9277 | F1 MICRO: 0.9349
# EPOCH 4 | LOSS: 2.3202672004699707 | ACCURACY: 0.9234 | F1 MACRO: 0.9122 | F1 MICRO: 0.9234
# EPOCH 5 | LOSS: 2.1653666496276855 | ACCURACY: 0.9272 | F1 MACRO: 0.9197 | F1 MICRO: 0.9272
# EPOCH 6 | LOSS: 2.0890512466430664 | ACCURACY: 0.9349 | F1 MACRO: 0.9256 | F1 MICRO: 0.9349
# EPOCH 7 | LOSS: 2.1193883419036865 | ACCURACY: 0.9272 | F1 MACRO: 0.9192 | F1 MICRO: 0.9272
# EPOCH 8 | LOSS: 1.976571798324585 | ACCURACY: 0.9502 | F1 MACRO: 0.9438 | F1 MICRO: 0.9502
# EPOCH 9 | LOSS: 2.0065758228302 | ACCURACY: 0.9387 | F1 MACRO: 0.9314 | F1 MICRO: 0.9387
# EPOCH 10 | LOSS: 1.9776512384414673 | ACCURACY: 0.9425 | F1 MACRO: 0.9359 | F1 MICRO: 0.9425
# sentiment: ACCURACY 0.9502 | F1 MACRO 0.9438 | F1 MICRO 0.9502
#               precision    recall  f1-score   support
#
#     negative       0.89      0.96      0.92        83
#     positive       0.98      0.94      0.96       178
#
#     accuracy                           0.95       261
#    macro avg       0.94      0.95      0.94       261
# weighted avg       0.95      0.95      0.95       261
#
# --------------------------------------------------
# Iteration 864: Accuracy: 0.9545, F1 Micro: 0.9545, F1 Macro: 0.9113
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.92      1.00      0.96        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.95      0.88      0.91        24
#
#     accuracy                           0.98       216
#    macro avg       0.95      0.96      0.95       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.75      0.83        16
#      neutral       0.94      0.99      0.96       167
#     positive       0.89      0.73      0.80        33
#
#     accuracy                           0.93       216
#    macro avg       0.92      0.82      0.86       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.77      0.83      0.80        12
#      neutral       0.93      0.94      0.93       152
#     positive       0.82      0.77      0.79        52
#
#     accuracy                           0.89       216
#    macro avg       0.84      0.85      0.84       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.82      1.00      0.90        23
#      neutral       0.98      0.97      0.98       152
#     positive       0.92      0.83      0.87        41
#
#     accuracy                           0.95       216
#    macro avg       0.91      0.93      0.92       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.77      0.80        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.88      0.88      0.88        17
#
#     accuracy                           0.97       216
#    macro avg       0.90      0.88      0.89       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        14
#      neutral       1.00      1.00      1.00       185
#     positive       1.00      1.00      1.00        17
#
#     accuracy                           1.00       216
#    macro avg       1.00      1.00      1.00       216
# weighted avg       1.00      1.00      1.00       216
#
# Total sampling time: 374.94 seconds
# Total runtime: 3210.1487629413605 seconds

# %% [markdown]
# ## RUN 2

# %%
active_learning(seeds[1], 1)
# Out:
# ===============================================
# TRIAL 2
# Random seed: 81
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# pytorch_model.bin:   0%|          | 0.00/498M [00:00<?, ?B/s]
# EPOCH 1 | LOSS: 3.5976929664611816 | ACCURACY: 0.7634 | F1 MACRO: 0.8524 | F1 MICRO: 0.8603
# EPOCH 2 | LOSS: 3.2051076889038086 | ACCURACY: 0.7314 | F1 MACRO: 0.7859 | F1 MICRO: 0.8372
# EPOCH 3 | LOSS: 3.1839632987976074 | ACCURACY: 0.7269 | F1 MACRO: 0.7834 | F1 MICRO: 0.8348
# EPOCH 4 | LOSS: 3.163743734359741 | ACCURACY: 0.7515 | F1 MACRO: 0.8361 | F1 MICRO: 0.854
# EPOCH 5 | LOSS: 3.048156261444092 | ACCURACY: 0.7746 | F1 MACRO: 0.8634 | F1 MICRO: 0.8701
# EPOCH 6 | LOSS: 2.835909843444824 | ACCURACY: 0.7708 | F1 MACRO: 0.8606 | F1 MICRO: 0.8679
# EPOCH 7 | LOSS: 2.760127067565918 | ACCURACY: 0.779 | F1 MACRO: 0.8634 | F1 MICRO: 0.8716
# EPOCH 8 | LOSS: 2.7907986640930176 | ACCURACY: 0.7708 | F1 MACRO: 0.8477 | F1 MICRO: 0.8642
# EPOCH 9 | LOSS: 2.629132032394409 | ACCURACY: 0.7567 | F1 MACRO: 0.8195 | F1 MICRO: 0.8526
# EPOCH 10 | LOSS: 2.581808567047119 | ACCURACY: 0.7597 | F1 MACRO: 0.8237 | F1 MICRO: 0.8547
# aspect: ACCURACY 0.779 | F1 MACRO 0.8634 | F1 MICRO 0.8716
#               precision    recall  f1-score   support
#
#         fuel       0.83      1.00      0.91       187
#      machine       0.78      1.00      0.88       175
#       others       0.76      0.66      0.71       158
#         part       0.72      1.00      0.84       158
#        price       0.86      1.00      0.92       192
#      service       0.85      1.00      0.92       191
#
#    micro avg       0.81      0.95      0.87      1061
#    macro avg       0.80      0.94      0.86      1061
# weighted avg       0.81      0.95      0.87      1061
#  samples avg       0.81      0.95      0.87      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 10.658291816711426 | ACCURACY: 0.907 | F1 MACRO: 0.4756 | F1 MICRO: 0.907
# EPOCH 2 | LOSS: 10.065308570861816 | ACCURACY: 0.907 | F1 MACRO: 0.4756 | F1 MICRO: 0.907
# EPOCH 3 | LOSS: 8.975017547607422 | ACCURACY: 0.907 | F1 MACRO: 0.4756 | F1 MICRO: 0.907
# EPOCH 4 | LOSS: 8.110350608825684 | ACCURACY: 0.907 | F1 MACRO: 0.4756 | F1 MICRO: 0.907
# EPOCH 5 | LOSS: 7.838434219360352 | ACCURACY: 0.907 | F1 MACRO: 0.4756 | F1 MICRO: 0.907
# EPOCH 6 | LOSS: 8.20789909362793 | ACCURACY: 0.907 | F1 MACRO: 0.4756 | F1 MICRO: 0.907
# EPOCH 7 | LOSS: 7.7577972412109375 | ACCURACY: 0.8953 | F1 MACRO: 0.563 | F1 MICRO: 0.8953
# EPOCH 8 | LOSS: 7.260716915130615 | ACCURACY: 0.8837 | F1 MACRO: 0.6554 | F1 MICRO: 0.8837
# EPOCH 9 | LOSS: 6.669865131378174 | ACCURACY: 0.9419 | F1 MACRO: 0.792 | F1 MICRO: 0.9419
# EPOCH 10 | LOSS: 6.411937236785889 | ACCURACY: 0.9302 | F1 MACRO: 0.7312 | F1 MICRO: 0.9302
# sentiment: ACCURACY 0.9419 | F1 MACRO 0.792 | F1 MICRO 0.9419
#               precision    recall  f1-score   support
#
#     negative       0.80      0.50      0.62         8
#     positive       0.95      0.99      0.97        78
#
#     accuracy                           0.94        86
#    macro avg       0.88      0.74      0.79        86
# weighted avg       0.94      0.94      0.94        86
#
# --------------------------------------------------
# Iteration 54: Accuracy: 0.7685, F1 Micro: 0.7685, F1 Macro: 0.3302
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        11
#      neutral       0.84      1.00      0.91       181
#     positive       0.00      0.00      0.00        24
#
#     accuracy                           0.84       216
#    macro avg       0.28      0.33      0.30       216
# weighted avg       0.70      0.84      0.76       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        16
#      neutral       0.77      1.00      0.87       167
#     positive       0.00      0.00      0.00        33
#
#     accuracy                           0.77       216
#    macro avg       0.26      0.33      0.29       216
# weighted avg       0.60      0.77      0.67       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.50      0.33      0.40        12
#      neutral       0.74      0.64      0.69       152
#     positive       0.29      0.42      0.34        52
#
#     accuracy                           0.57       216
#    macro avg       0.51      0.47      0.48       216
# weighted avg       0.62      0.57      0.59       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        23
#      neutral       0.71      1.00      0.83       152
#     positive       0.50      0.02      0.05        41
#
#     accuracy                           0.71       216
#    macro avg       0.40      0.34      0.29       216
# weighted avg       0.59      0.71      0.59       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        13
#      neutral       0.86      1.00      0.93       186
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.86       216
#    macro avg       0.29      0.33      0.31       216
# weighted avg       0.74      0.86      0.80       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        14
#      neutral       0.86      1.00      0.92       185
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.86       216
#    macro avg       0.29      0.33      0.31       216
# weighted avg       0.73      0.86      0.79       216
#
# Launching training on 2 GPUs.
# 223 223
# Nearest checkpoint: 540
# Threshold: 88540.9921875
# Samples above threshold: 81
# Acquired samples: 81
# Sampling duration: 6.275763511657715 seconds
# New train size: 135
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.782231569290161 | ACCURACY: 0.7247 | F1 MACRO: 0.7688 | F1 MICRO: 0.8321
# EPOCH 2 | LOSS: 3.383819103240967 | ACCURACY: 0.785 | F1 MACRO: 0.8769 | F1 MICRO: 0.879
# EPOCH 3 | LOSS: 3.2303807735443115 | ACCURACY: 0.7879 | F1 MACRO: 0.879 | F1 MICRO: 0.8809
# EPOCH 4 | LOSS: 3.003126621246338 | ACCURACY: 0.7731 | F1 MACRO: 0.8571 | F1 MICRO: 0.8676
# EPOCH 5 | LOSS: 2.837209939956665 | ACCURACY: 0.7954 | F1 MACRO: 0.8714 | F1 MICRO: 0.8798
# EPOCH 6 | LOSS: 2.634943723678589 | ACCURACY: 0.8296 | F1 MACRO: 0.8983 | F1 MICRO: 0.9009
# EPOCH 7 | LOSS: 2.5773046016693115 | ACCURACY: 0.8222 | F1 MACRO: 0.8824 | F1 MICRO: 0.8927
# EPOCH 8 | LOSS: 2.511791944503784 | ACCURACY: 0.846 | F1 MACRO: 0.9017 | F1 MICRO: 0.9072
# EPOCH 9 | LOSS: 2.458190679550171 | ACCURACY: 0.8683 | F1 MACRO: 0.9171 | F1 MICRO: 0.9205
# EPOCH 10 | LOSS: 2.459617853164673 | ACCURACY: 0.8638 | F1 MACRO: 0.9097 | F1 MICRO: 0.9166
# aspect: ACCURACY 0.8683 | F1 MACRO 0.9171 | F1 MICRO 0.9205
#               precision    recall  f1-score   support
#
#         fuel       0.90      1.00      0.95       187
#      machine       0.80      1.00      0.89       175
#       others       0.84      0.84      0.84       158
#         part       0.84      0.95      0.89       158
#        price       0.95      0.99      0.97       192
#      service       0.94      1.00      0.97       191
#
#    micro avg       0.88      0.97      0.92      1061
#    macro avg       0.88      0.96      0.92      1061
# weighted avg       0.88      0.97      0.92      1061
#  samples avg       0.89      0.97      0.92      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 14.88371753692627 | ACCURACY: 0.7582 | F1 MACRO: 0.6191 | F1 MICRO: 0.7582
# EPOCH 2 | LOSS: 11.907562255859375 | ACCURACY: 0.8956 | F1 MACRO: 0.8814 | F1 MICRO: 0.8956
# EPOCH 3 | LOSS: 10.537186622619629 | ACCURACY: 0.8681 | F1 MACRO: 0.8403 | F1 MICRO: 0.8681
# EPOCH 4 | LOSS: 9.935877799987793 | ACCURACY: 0.9121 | F1 MACRO: 0.9014 | F1 MICRO: 0.9121
# EPOCH 5 | LOSS: 9.27624797821045 | ACCURACY: 0.8956 | F1 MACRO: 0.8814 | F1 MICRO: 0.8956
# EPOCH 6 | LOSS: 8.791837692260742 | ACCURACY: 0.8956 | F1 MACRO: 0.8814 | F1 MICRO: 0.8956
# EPOCH 7 | LOSS: 8.720271110534668 | ACCURACY: 0.9011 | F1 MACRO: 0.8871 | F1 MICRO: 0.9011
# EPOCH 8 | LOSS: 8.253231048583984 | ACCURACY: 0.9121 | F1 MACRO: 0.9005 | F1 MICRO: 0.9121
# EPOCH 9 | LOSS: 7.979394912719727 | ACCURACY: 0.9011 | F1 MACRO: 0.889 | F1 MICRO: 0.9011
# EPOCH 10 | LOSS: 7.728791236877441 | ACCURACY: 0.8901 | F1 MACRO: 0.871 | F1 MICRO: 0.8901
# sentiment: ACCURACY 0.9121 | F1 MACRO 0.9005 | F1 MICRO 0.9121
#               precision    recall  f1-score   support
#
#     negative       0.81      0.93      0.87        56
#     positive       0.97      0.90      0.93       126
#
#     accuracy                           0.91       182
#    macro avg       0.89      0.92      0.90       182
# weighted avg       0.92      0.91      0.91       182
#
# --------------------------------------------------
# Iteration 135: Accuracy: 0.8611, F1 Micro: 0.8611, F1 Macro: 0.6992
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.45      0.62        11
#      neutral       0.91      1.00      0.96       181
#     positive       1.00      0.54      0.70        24
#
#     accuracy                           0.92       216
#    macro avg       0.97      0.67      0.76       216
# weighted avg       0.93      0.92      0.91       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.19      0.32        16
#      neutral       0.79      1.00      0.88       167
#     positive       0.50      0.03      0.06        33
#
#     accuracy                           0.79       216
#    macro avg       0.76      0.41      0.42       216
# weighted avg       0.76      0.79      0.72       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.60      0.75      0.67        12
#      neutral       0.84      0.82      0.83       152
#     positive       0.57      0.60      0.58        52
#
#     accuracy                           0.76       216
#    macro avg       0.67      0.72      0.69       216
# weighted avg       0.77      0.76      0.76       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.67      0.52      0.59        23
#      neutral       0.84      0.93      0.88       152
#     positive       0.71      0.49      0.58        41
#
#     accuracy                           0.81       216
#    macro avg       0.74      0.65      0.68       216
# weighted avg       0.79      0.81      0.79       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.77      0.80        13
#      neutral       0.96      0.99      0.98       186
#     positive       0.77      0.59      0.67        17
#
#     accuracy                           0.94       216
#    macro avg       0.86      0.78      0.81       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.94      1.00      0.97       185
#     positive       1.00      0.41      0.58        17
#
#     accuracy                           0.94       216
#    macro avg       0.98      0.76      0.82       216
# weighted avg       0.95      0.94      0.94       216
#
# Launching training on 2 GPUs.
# 531 531
# Nearest checkpoint: 540
# Threshold: 88680.3125
# Samples above threshold: 73
# Acquired samples: 73
# Sampling duration: 9.16880488395691 seconds
# New train size: 208
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.5836470127105713 | ACCURACY: 0.7612 | F1 MACRO: 0.8473 | F1 MICRO: 0.8605
# EPOCH 2 | LOSS: 3.2717738151550293 | ACCURACY: 0.7902 | F1 MACRO: 0.8812 | F1 MICRO: 0.8827
# EPOCH 3 | LOSS: 2.8708298206329346 | ACCURACY: 0.7783 | F1 MACRO: 0.8625 | F1 MICRO: 0.871
# EPOCH 4 | LOSS: 2.6605334281921387 | ACCURACY: 0.8207 | F1 MACRO: 0.8933 | F1 MICRO: 0.8961
# EPOCH 5 | LOSS: 2.5484299659729004 | ACCURACY: 0.8289 | F1 MACRO: 0.8946 | F1 MICRO: 0.899
# EPOCH 6 | LOSS: 2.4703712463378906 | ACCURACY: 0.8586 | F1 MACRO: 0.9126 | F1 MICRO: 0.9156
# EPOCH 7 | LOSS: 2.3843777179718018 | ACCURACY: 0.8854 | F1 MACRO: 0.9276 | F1 MICRO: 0.9304
# EPOCH 8 | LOSS: 2.3514068126678467 | ACCURACY: 0.8929 | F1 MACRO: 0.9295 | F1 MICRO: 0.9339
# EPOCH 9 | LOSS: 2.296381711959839 | ACCURACY: 0.9085 | F1 MACRO: 0.9403 | F1 MICRO: 0.9436
# EPOCH 10 | LOSS: 2.2702596187591553 | ACCURACY: 0.9174 | F1 MACRO: 0.9456 | F1 MICRO: 0.949
# aspect: ACCURACY 0.9174 | F1 MACRO 0.9456 | F1 MICRO 0.949
#               precision    recall  f1-score   support
#
#         fuel       0.96      1.00      0.98       187
#      machine       0.90      1.00      0.95       175
#       others       0.89      0.88      0.88       158
#         part       0.86      0.94      0.89       158
#        price       0.96      1.00      0.98       192
#      service       0.97      1.00      0.98       191
#
#    micro avg       0.93      0.97      0.95      1061
#    macro avg       0.92      0.97      0.95      1061
# weighted avg       0.93      0.97      0.95      1061
#  samples avg       0.93      0.97      0.94      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 12.842394828796387 | ACCURACY: 0.9099 | F1 MACRO: 0.9004 | F1 MICRO: 0.9099
# EPOCH 2 | LOSS: 10.235369682312012 | ACCURACY: 0.9313 | F1 MACRO: 0.9234 | F1 MICRO: 0.9313
# EPOCH 3 | LOSS: 8.816142082214355 | ACCURACY: 0.9099 | F1 MACRO: 0.8949 | F1 MICRO: 0.9099
# EPOCH 4 | LOSS: 8.49657917022705 | ACCURACY: 0.9099 | F1 MACRO: 0.9004 | F1 MICRO: 0.9099
# EPOCH 5 | LOSS: 7.688228130340576 | ACCURACY: 0.9185 | F1 MACRO: 0.9076 | F1 MICRO: 0.9185
# EPOCH 6 | LOSS: 7.75923490524292 | ACCURACY: 0.9185 | F1 MACRO: 0.9104 | F1 MICRO: 0.9185
# EPOCH 7 | LOSS: 7.49815034866333 | ACCURACY: 0.9227 | F1 MACRO: 0.9127 | F1 MICRO: 0.9227
# EPOCH 8 | LOSS: 7.000967502593994 | ACCURACY: 0.9142 | F1 MACRO: 0.9017 | F1 MICRO: 0.9142
# EPOCH 9 | LOSS: 6.964837551116943 | ACCURACY: 0.9056 | F1 MACRO: 0.8971 | F1 MICRO: 0.9056
# EPOCH 10 | LOSS: 7.019234657287598 | ACCURACY: 0.9142 | F1 MACRO: 0.9054 | F1 MICRO: 0.9142
# sentiment: ACCURACY 0.9313 | F1 MACRO 0.9234 | F1 MICRO 0.9313
#               precision    recall  f1-score   support
#
#     negative       0.85      0.96      0.90        74
#     positive       0.98      0.92      0.95       159
#
#     accuracy                           0.93       233
#    macro avg       0.91      0.94      0.92       233
# weighted avg       0.94      0.93      0.93       233
#
# --------------------------------------------------
# Iteration 208: Accuracy: 0.909, F1 Micro: 0.909, F1 Macro: 0.8359
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.98      1.00      0.99       181
#     positive       1.00      0.92      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       0.99      0.94      0.97       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.75      0.83        16
#      neutral       0.90      0.99      0.95       167
#     positive       0.89      0.52      0.65        33
#
#     accuracy                           0.90       216
#    macro avg       0.91      0.75      0.81       216
# weighted avg       0.90      0.90      0.89       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.69      0.75      0.72        12
#      neutral       0.88      0.85      0.86       152
#     positive       0.64      0.69      0.67        52
#
#     accuracy                           0.81       216
#    macro avg       0.74      0.76      0.75       216
# weighted avg       0.81      0.81      0.81       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.69      0.78      0.73        23
#      neutral       0.86      0.95      0.90       152
#     positive       0.86      0.46      0.60        41
#
#     accuracy                           0.84       216
#    macro avg       0.80      0.73      0.75       216
# weighted avg       0.84      0.84      0.83       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.77      0.80        13
#      neutral       0.97      0.99      0.98       186
#     positive       0.79      0.65      0.71        17
#
#     accuracy                           0.95       216
#    macro avg       0.86      0.80      0.83       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.93      0.93        14
#      neutral       0.97      1.00      0.99       185
#     positive       1.00      0.71      0.83        17
#
#     accuracy                           0.97       216
#    macro avg       0.97      0.88      0.91       216
# weighted avg       0.97      0.97      0.97       216
#
# Launching training on 2 GPUs.
# 592 592
# Nearest checkpoint: 540
# Threshold: 88795.3515625
# Samples above threshold: 66
# Acquired samples: 66
# Sampling duration: 11.123019456863403 seconds
# New train size: 274
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.269120454788208 | ACCURACY: 0.7835 | F1 MACRO: 0.8761 | F1 MICRO: 0.8783
# EPOCH 2 | LOSS: 2.8802077770233154 | ACCURACY: 0.7999 | F1 MACRO: 0.8852 | F1 MICRO: 0.8869
# EPOCH 3 | LOSS: 2.5836386680603027 | ACCURACY: 0.8199 | F1 MACRO: 0.894 | F1 MICRO: 0.8962
# EPOCH 4 | LOSS: 2.3860456943511963 | ACCURACY: 0.8452 | F1 MACRO: 0.9072 | F1 MICRO: 0.9091
# EPOCH 5 | LOSS: 2.2812108993530273 | ACCURACY: 0.8854 | F1 MACRO: 0.9277 | F1 MICRO: 0.9307
# EPOCH 6 | LOSS: 2.2195889949798584 | ACCURACY: 0.9159 | F1 MACRO: 0.9454 | F1 MICRO: 0.9482
# EPOCH 7 | LOSS: 2.1818368434906006 | ACCURACY: 0.9122 | F1 MACRO: 0.9401 | F1 MICRO: 0.9453
# EPOCH 8 | LOSS: 2.0879123210906982 | ACCURACY: 0.933 | F1 MACRO: 0.9564 | F1 MICRO: 0.9585
# EPOCH 9 | LOSS: 2.04929780960083 | ACCURACY: 0.9353 | F1 MACRO: 0.9567 | F1 MICRO: 0.9596
# EPOCH 10 | LOSS: 1.9582535028457642 | ACCURACY: 0.9368 | F1 MACRO: 0.9581 | F1 MICRO: 0.9606
# aspect: ACCURACY 0.9368 | F1 MACRO 0.9581 | F1 MICRO 0.9606
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.93      0.99      0.96       175
#       others       0.87      0.92      0.90       158
#         part       0.93      0.94      0.93       158
#        price       0.96      1.00      0.98       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.94      0.98      0.96      1061
#    macro avg       0.94      0.97      0.96      1061
# weighted avg       0.94      0.98      0.96      1061
#  samples avg       0.95      0.98      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 9.85262393951416 | ACCURACY: 0.877 | F1 MACRO: 0.8522 | F1 MICRO: 0.877
# EPOCH 2 | LOSS: 7.771361351013184 | ACCURACY: 0.9098 | F1 MACRO: 0.899 | F1 MICRO: 0.9098
# EPOCH 3 | LOSS: 7.012356758117676 | ACCURACY: 0.9221 | F1 MACRO: 0.9135 | F1 MICRO: 0.9221
# EPOCH 4 | LOSS: 6.370224952697754 | ACCURACY: 0.918 | F1 MACRO: 0.9107 | F1 MICRO: 0.918
# EPOCH 5 | LOSS: 6.08596658706665 | ACCURACY: 0.9139 | F1 MACRO: 0.902 | F1 MICRO: 0.9139
# EPOCH 6 | LOSS: 5.913906574249268 | ACCURACY: 0.9098 | F1 MACRO: 0.8964 | F1 MICRO: 0.9098
# EPOCH 7 | LOSS: 5.734023094177246 | ACCURACY: 0.8852 | F1 MACRO: 0.869 | F1 MICRO: 0.8852
# EPOCH 8 | LOSS: 5.6759934425354 | ACCURACY: 0.8852 | F1 MACRO: 0.8662 | F1 MICRO: 0.8852
# EPOCH 9 | LOSS: 5.667749881744385 | ACCURACY: 0.9139 | F1 MACRO: 0.9039 | F1 MICRO: 0.9139
# EPOCH 10 | LOSS: 5.526207447052002 | ACCURACY: 0.918 | F1 MACRO: 0.9058 | F1 MICRO: 0.918
# sentiment: ACCURACY 0.9221 | F1 MACRO 0.9135 | F1 MICRO 0.9221
#               precision    recall  f1-score   support
#
#     negative       0.84      0.94      0.89        79
#     positive       0.97      0.92      0.94       165
#
#     accuracy                           0.92       244
#    macro avg       0.90      0.93      0.91       244
# weighted avg       0.93      0.92      0.92       244
#
# --------------------------------------------------
# Iteration 274: Accuracy: 0.9275, F1 Micro: 0.9275, F1 Macro: 0.8696
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.98      1.00      0.99       181
#     positive       1.00      0.92      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       0.99      0.94      0.97       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.81      0.84        16
#      neutral       0.94      0.99      0.97       167
#     positive       0.96      0.70      0.81        33
#
#     accuracy                           0.94       216
#    macro avg       0.92      0.83      0.87       216
# weighted avg       0.94      0.94      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.69      0.75      0.72        12
#      neutral       0.87      0.89      0.88       152
#     positive       0.67      0.62      0.64        52
#
#     accuracy                           0.81       216
#    macro avg       0.74      0.75      0.75       216
# weighted avg       0.81      0.81      0.81       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.71      0.87      0.78        23
#      neutral       0.94      0.95      0.94       152
#     positive       0.82      0.68      0.75        41
#
#     accuracy                           0.89       216
#    macro avg       0.82      0.83      0.82       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.77      0.83        13
#      neutral       0.96      1.00      0.98       186
#     positive       0.92      0.65      0.76        17
#
#     accuracy                           0.96       216
#    macro avg       0.93      0.81      0.86       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.98      1.00      0.99       185
#     positive       1.00      0.82      0.90        17
#
#     accuracy                           0.98       216
#    macro avg       0.99      0.92      0.95       216
# weighted avg       0.98      0.98      0.98       216
#
# Launching training on 2 GPUs.
# 560 560
# Nearest checkpoint: 540
# Threshold: 88616.015625
# Samples above threshold: 59
# Acquired samples: 59
# Sampling duration: 13.067097187042236 seconds
# New train size: 333
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.387725591659546 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# EPOCH 2 | LOSS: 2.8489513397216797 | ACCURACY: 0.8065 | F1 MACRO: 0.8887 | F1 MICRO: 0.8904
# EPOCH 3 | LOSS: 2.532698154449463 | ACCURACY: 0.846 | F1 MACRO: 0.9082 | F1 MICRO: 0.9093
# EPOCH 4 | LOSS: 2.415053606033325 | ACCURACY: 0.8891 | F1 MACRO: 0.9308 | F1 MICRO: 0.9331
# EPOCH 5 | LOSS: 2.353834390640259 | ACCURACY: 0.9174 | F1 MACRO: 0.9451 | F1 MICRO: 0.9487
# EPOCH 6 | LOSS: 2.2443556785583496 | ACCURACY: 0.9323 | F1 MACRO: 0.9549 | F1 MICRO: 0.9577
# EPOCH 7 | LOSS: 2.126466989517212 | ACCURACY: 0.9301 | F1 MACRO: 0.9527 | F1 MICRO: 0.9563
# EPOCH 8 | LOSS: 2.108002185821533 | ACCURACY: 0.9375 | F1 MACRO: 0.9581 | F1 MICRO: 0.9609
# EPOCH 9 | LOSS: 2.014692544937134 | ACCURACY: 0.9427 | F1 MACRO: 0.9619 | F1 MICRO: 0.9642
# EPOCH 10 | LOSS: 1.9123430252075195 | ACCURACY: 0.9382 | F1 MACRO: 0.9587 | F1 MICRO: 0.9615
# aspect: ACCURACY 0.9427 | F1 MACRO 0.9619 | F1 MICRO 0.9642
#               precision    recall  f1-score   support
#
#         fuel       0.97      1.00      0.98       187
#      machine       0.94      1.00      0.97       175
#       others       0.89      0.91      0.90       158
#         part       0.95      0.94      0.95       158
#        price       0.97      1.00      0.98       192
#      service       0.97      1.00      0.99       191
#
#    micro avg       0.95      0.98      0.96      1061
#    macro avg       0.95      0.98      0.96      1061
# weighted avg       0.95      0.98      0.96      1061
#  samples avg       0.95      0.98      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 8.383564949035645 | ACCURACY: 0.9208 | F1 MACRO: 0.9117 | F1 MICRO: 0.9208
# EPOCH 2 | LOSS: 6.683679580688477 | ACCURACY: 0.9333 | F1 MACRO: 0.9271 | F1 MICRO: 0.9333
# EPOCH 3 | LOSS: 6.035735130310059 | ACCURACY: 0.925 | F1 MACRO: 0.9161 | F1 MICRO: 0.925
# EPOCH 4 | LOSS: 5.5059428215026855 | ACCURACY: 0.9208 | F1 MACRO: 0.9137 | F1 MICRO: 0.9208
# EPOCH 5 | LOSS: 5.153354167938232 | ACCURACY: 0.9083 | F1 MACRO: 0.8962 | F1 MICRO: 0.9083
# EPOCH 6 | LOSS: 5.0794548988342285 | ACCURACY: 0.9083 | F1 MACRO: 0.8962 | F1 MICRO: 0.9083
# EPOCH 7 | LOSS: 4.923586845397949 | ACCURACY: 0.9292 | F1 MACRO: 0.921 | F1 MICRO: 0.9292
# EPOCH 8 | LOSS: 4.74177360534668 | ACCURACY: 0.9167 | F1 MACRO: 0.9084 | F1 MICRO: 0.9167
# EPOCH 9 | LOSS: 4.736650466918945 | ACCURACY: 0.9042 | F1 MACRO: 0.8897 | F1 MICRO: 0.9042
# EPOCH 10 | LOSS: 4.6305012702941895 | ACCURACY: 0.9042 | F1 MACRO: 0.8911 | F1 MICRO: 0.9042
# sentiment: ACCURACY 0.9333 | F1 MACRO 0.9271 | F1 MICRO 0.9333
#               precision    recall  f1-score   support
#
#     negative       0.85      0.97      0.91        79
#     positive       0.99      0.91      0.95       161
#
#     accuracy                           0.93       240
#    macro avg       0.92      0.94      0.93       240
# weighted avg       0.94      0.93      0.93       240
#
# --------------------------------------------------
# Iteration 333: Accuracy: 0.9344, F1 Micro: 0.9344, F1 Macro: 0.8741
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.98      1.00      0.99       181
#     positive       1.00      0.92      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       0.99      0.94      0.97       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.81      0.87        16
#      neutral       0.93      1.00      0.97       167
#     positive       0.96      0.67      0.79        33
#
#     accuracy                           0.94       216
#    macro avg       0.94      0.83      0.87       216
# weighted avg       0.94      0.94      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.69      0.75      0.72        12
#      neutral       0.89      0.92      0.91       152
#     positive       0.76      0.67      0.71        52
#
#     accuracy                           0.85       216
#    macro avg       0.78      0.78      0.78       216
# weighted avg       0.85      0.85      0.85       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.73      0.96      0.83        23
#      neutral       0.94      0.95      0.94       152
#     positive       0.88      0.71      0.78        41
#
#     accuracy                           0.90       216
#    macro avg       0.85      0.87      0.85       216
# weighted avg       0.91      0.90      0.90       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.77      0.83        13
#      neutral       0.96      1.00      0.98       186
#     positive       0.92      0.65      0.76        17
#
#     accuracy                           0.96       216
#    macro avg       0.93      0.81      0.86       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.93      0.93        14
#      neutral       0.97      1.00      0.99       185
#     positive       1.00      0.71      0.83        17
#
#     accuracy                           0.97       216
#    macro avg       0.97      0.88      0.91       216
# weighted avg       0.97      0.97      0.97       216
#
# Launching training on 2 GPUs.
# 509 509
# Nearest checkpoint: 540
# Threshold: 88588.078125
# Samples above threshold: 54
# Acquired samples: 54
# Sampling duration: 13.589418411254883 seconds
# New train size: 387
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.309032440185547 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# EPOCH 2 | LOSS: 2.6979405879974365 | ACCURACY: 0.7894 | F1 MACRO: 0.8581 | F1 MICRO: 0.8739
# EPOCH 3 | LOSS: 2.461322784423828 | ACCURACY: 0.8646 | F1 MACRO: 0.917 | F1 MICRO: 0.9195
# EPOCH 4 | LOSS: 2.3442094326019287 | ACCURACY: 0.9107 | F1 MACRO: 0.9418 | F1 MICRO: 0.945
# EPOCH 5 | LOSS: 2.272068977355957 | ACCURACY: 0.9323 | F1 MACRO: 0.9545 | F1 MICRO: 0.9577
# EPOCH 6 | LOSS: 2.1450254917144775 | ACCURACY: 0.9487 | F1 MACRO: 0.9667 | F1 MICRO: 0.9682
# EPOCH 7 | LOSS: 2.0444729328155518 | ACCURACY: 0.9449 | F1 MACRO: 0.9637 | F1 MICRO: 0.9657
# EPOCH 8 | LOSS: 1.9927289485931396 | ACCURACY: 0.936 | F1 MACRO: 0.9563 | F1 MICRO: 0.9599
# EPOCH 9 | LOSS: 1.8595638275146484 | ACCURACY: 0.9427 | F1 MACRO: 0.961 | F1 MICRO: 0.9641
# EPOCH 10 | LOSS: 1.8219133615493774 | ACCURACY: 0.939 | F1 MACRO: 0.9585 | F1 MICRO: 0.9617
# aspect: ACCURACY 0.9487 | F1 MACRO 0.9667 | F1 MICRO 0.9682
#               precision    recall  f1-score   support
#
#         fuel       0.97      1.00      0.99       187
#      machine       0.93      1.00      0.96       175
#       others       0.90      0.94      0.92       158
#         part       0.93      0.99      0.96       158
#        price       0.97      0.99      0.98       192
#      service       0.97      1.00      0.99       191
#
#    micro avg       0.95      0.99      0.97      1061
#    macro avg       0.95      0.99      0.97      1061
# weighted avg       0.95      0.99      0.97      1061
#  samples avg       0.95      0.99      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.899065971374512 | ACCURACY: 0.9407 | F1 MACRO: 0.9346 | F1 MICRO: 0.9407
# EPOCH 2 | LOSS: 5.435764789581299 | ACCURACY: 0.928 | F1 MACRO: 0.9178 | F1 MICRO: 0.928
# EPOCH 3 | LOSS: 4.827599048614502 | ACCURACY: 0.9364 | F1 MACRO: 0.9301 | F1 MICRO: 0.9364
# EPOCH 4 | LOSS: 4.421809196472168 | ACCURACY: 0.9407 | F1 MACRO: 0.9342 | F1 MICRO: 0.9407
# EPOCH 5 | LOSS: 4.257791996002197 | ACCURACY: 0.9322 | F1 MACRO: 0.9224 | F1 MICRO: 0.9322
# EPOCH 6 | LOSS: 4.104433536529541 | ACCURACY: 0.9364 | F1 MACRO: 0.9284 | F1 MICRO: 0.9364
# EPOCH 7 | LOSS: 3.90727162361145 | ACCURACY: 0.9407 | F1 MACRO: 0.9342 | F1 MICRO: 0.9407
# EPOCH 8 | LOSS: 3.887643337249756 | ACCURACY: 0.9237 | F1 MACRO: 0.9114 | F1 MICRO: 0.9237
# EPOCH 9 | LOSS: 3.849501848220825 | ACCURACY: 0.911 | F1 MACRO: 0.9042 | F1 MICRO: 0.911
# EPOCH 10 | LOSS: 3.888071298599243 | ACCURACY: 0.9534 | F1 MACRO: 0.9475 | F1 MICRO: 0.9534
# sentiment: ACCURACY 0.9534 | F1 MACRO 0.9475 | F1 MICRO 0.9534
#               precision    recall  f1-score   support
#
#     negative       0.92      0.94      0.93        78
#     positive       0.97      0.96      0.97       158
#
#     accuracy                           0.95       236
#    macro avg       0.95      0.95      0.95       236
# weighted avg       0.95      0.95      0.95       236
#
# --------------------------------------------------
# Iteration 387: Accuracy: 0.9421, F1 Micro: 0.9421, F1 Macro: 0.8846
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.98      1.00      0.99       181
#     positive       1.00      0.88      0.93        24
#
#     accuracy                           0.98       216
#    macro avg       0.99      0.93      0.96       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.75      0.83        16
#      neutral       0.94      1.00      0.97       167
#     positive       0.92      0.73      0.81        33
#
#     accuracy                           0.94       216
#    macro avg       0.93      0.83      0.87       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.82      0.75      0.78        12
#      neutral       0.90      0.93      0.92       152
#     positive       0.81      0.73      0.77        52
#
#     accuracy                           0.88       216
#    macro avg       0.84      0.80      0.82       216
# weighted avg       0.87      0.88      0.87       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.87      0.83        23
#      neutral       0.94      0.99      0.96       152
#     positive       0.94      0.71      0.81        41
#
#     accuracy                           0.92       216
#    macro avg       0.89      0.85      0.87       216
# weighted avg       0.92      0.92      0.92       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.77      0.80        13
#      neutral       0.97      0.99      0.98       186
#     positive       0.92      0.71      0.80        17
#
#     accuracy                           0.96       216
#    macro avg       0.91      0.82      0.86       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.98      1.00      0.99       185
#     positive       0.93      0.82      0.87        17
#
#     accuracy                           0.98       216
#    macro avg       0.97      0.89      0.93       216
# weighted avg       0.98      0.98      0.98       216
#
# Launching training on 2 GPUs.
# 451 451
# Nearest checkpoint: 540
# Threshold: 88654.40625
# Samples above threshold: 48
# Acquired samples: 48
# Sampling duration: 13.744237184524536 seconds
# New train size: 435
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.1930150985717773 | ACCURACY: 0.7946 | F1 MACRO: 0.8834 | F1 MICRO: 0.8849
# EPOCH 2 | LOSS: 2.5723371505737305 | ACCURACY: 0.8311 | F1 MACRO: 0.9007 | F1 MICRO: 0.9023
# EPOCH 3 | LOSS: 2.352065324783325 | ACCURACY: 0.8713 | F1 MACRO: 0.9178 | F1 MICRO: 0.9218
# EPOCH 4 | LOSS: 2.2456960678100586 | ACCURACY: 0.9293 | F1 MACRO: 0.9539 | F1 MICRO: 0.9562
# EPOCH 5 | LOSS: 2.147327423095703 | ACCURACY: 0.9345 | F1 MACRO: 0.9574 | F1 MICRO: 0.9594
# EPOCH 6 | LOSS: 2.028263807296753 | ACCURACY: 0.9382 | F1 MACRO: 0.9596 | F1 MICRO: 0.9616
# EPOCH 7 | LOSS: 1.9255797863006592 | ACCURACY: 0.9435 | F1 MACRO: 0.9623 | F1 MICRO: 0.9646
# EPOCH 8 | LOSS: 1.8203431367874146 | ACCURACY: 0.9449 | F1 MACRO: 0.9636 | F1 MICRO: 0.9655
# EPOCH 9 | LOSS: 1.7688809633255005 | ACCURACY: 0.9405 | F1 MACRO: 0.9585 | F1 MICRO: 0.9625
# EPOCH 10 | LOSS: 1.7539961338043213 | ACCURACY: 0.9368 | F1 MACRO: 0.9554 | F1 MICRO: 0.9601
# aspect: ACCURACY 0.9449 | F1 MACRO 0.9636 | F1 MICRO 0.9655
#               precision    recall  f1-score   support
#
#         fuel       0.97      1.00      0.99       187
#      machine       0.94      0.97      0.96       175
#       others       0.89      0.91      0.90       158
#         part       0.96      0.97      0.97       158
#        price       0.97      1.00      0.98       192
#      service       0.97      1.00      0.99       191
#
#    micro avg       0.95      0.98      0.97      1061
#    macro avg       0.95      0.98      0.96      1061
# weighted avg       0.95      0.98      0.97      1061
#  samples avg       0.95      0.98      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.644935131072998 | ACCURACY: 0.9331 | F1 MACRO: 0.9227 | F1 MICRO: 0.9331
# EPOCH 2 | LOSS: 5.224402904510498 | ACCURACY: 0.9094 | F1 MACRO: 0.9008 | F1 MICRO: 0.9094
# EPOCH 3 | LOSS: 4.6058454513549805 | ACCURACY: 0.9331 | F1 MACRO: 0.9205 | F1 MICRO: 0.9331
# EPOCH 4 | LOSS: 4.32993745803833 | ACCURACY: 0.937 | F1 MACRO: 0.9297 | F1 MICRO: 0.937
# EPOCH 5 | LOSS: 3.932382583618164 | ACCURACY: 0.937 | F1 MACRO: 0.9275 | F1 MICRO: 0.937
# EPOCH 6 | LOSS: 4.0645551681518555 | ACCURACY: 0.9449 | F1 MACRO: 0.9361 | F1 MICRO: 0.9449
# EPOCH 7 | LOSS: 3.913710117340088 | ACCURACY: 0.937 | F1 MACRO: 0.928 | F1 MICRO: 0.937
# EPOCH 8 | LOSS: 3.868067502975464 | ACCURACY: 0.9094 | F1 MACRO: 0.9013 | F1 MICRO: 0.9094
# EPOCH 9 | LOSS: 3.673736810684204 | ACCURACY: 0.9291 | F1 MACRO: 0.9195 | F1 MICRO: 0.9291
# EPOCH 10 | LOSS: 3.675276041030884 | ACCURACY: 0.9331 | F1 MACRO: 0.9251 | F1 MICRO: 0.9331
# sentiment: ACCURACY 0.9449 | F1 MACRO 0.9361 | F1 MICRO 0.9449
#               precision    recall  f1-score   support
#
#     negative       0.91      0.91      0.91        80
#     positive       0.96      0.96      0.96       174
#
#     accuracy                           0.94       254
#    macro avg       0.94      0.94      0.94       254
# weighted avg       0.94      0.94      0.94       254
#
# --------------------------------------------------
# Iteration 435: Accuracy: 0.9421, F1 Micro: 0.9421, F1 Macro: 0.8848
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.82      0.90        11
#      neutral       0.98      1.00      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.98       216
#    macro avg       0.98      0.91      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.75      0.83        16
#      neutral       0.96      0.98      0.97       167
#     positive       0.82      0.82      0.82        33
#
#     accuracy                           0.94       216
#    macro avg       0.90      0.85      0.87       216
# weighted avg       0.93      0.94      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.64      0.75      0.69        12
#      neutral       0.90      0.91      0.90       152
#     positive       0.76      0.71      0.73        52
#
#     accuracy                           0.85       216
#    macro avg       0.77      0.79      0.78       216
# weighted avg       0.85      0.85      0.85       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.87      0.83        23
#      neutral       0.97      0.99      0.98       152
#     positive       0.89      0.78      0.83        41
#
#     accuracy                           0.94       216
#    macro avg       0.89      0.88      0.88       216
# weighted avg       0.93      0.94      0.93       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.77      0.83        13
#      neutral       0.97      1.00      0.99       186
#     positive       0.93      0.76      0.84        17
#
#     accuracy                           0.97       216
#    macro avg       0.94      0.84      0.89       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.98      1.00      0.99       185
#     positive       1.00      0.82      0.90        17
#
#     accuracy                           0.98       216
#    macro avg       0.99      0.92      0.95       216
# weighted avg       0.98      0.98      0.98       216
#
# Launching training on 2 GPUs.
# 415 415
# Nearest checkpoint: 540
# Threshold: 88538.578125
# Samples above threshold: 43
# Acquired samples: 43
# Sampling duration: 15.483843088150024 seconds
# New train size: 478
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.0837807655334473 | ACCURACY: 0.7954 | F1 MACRO: 0.8824 | F1 MICRO: 0.8843
# EPOCH 2 | LOSS: 2.5389299392700195 | ACCURACY: 0.8363 | F1 MACRO: 0.901 | F1 MICRO: 0.9036
# EPOCH 3 | LOSS: 2.3250021934509277 | ACCURACY: 0.8936 | F1 MACRO: 0.9318 | F1 MICRO: 0.9348
# EPOCH 4 | LOSS: 2.208247661590576 | ACCURACY: 0.9293 | F1 MACRO: 0.9547 | F1 MICRO: 0.9564
# EPOCH 5 | LOSS: 2.104013442993164 | ACCURACY: 0.9464 | F1 MACRO: 0.9646 | F1 MICRO: 0.9666
# EPOCH 6 | LOSS: 1.9961093664169312 | ACCURACY: 0.9487 | F1 MACRO: 0.9664 | F1 MICRO: 0.968
# EPOCH 7 | LOSS: 1.9204633235931396 | ACCURACY: 0.9531 | F1 MACRO: 0.9689 | F1 MICRO: 0.9707
# EPOCH 8 | LOSS: 1.8208690881729126 | ACCURACY: 0.9412 | F1 MACRO: 0.9583 | F1 MICRO: 0.9628
# EPOCH 9 | LOSS: 1.7817597389221191 | ACCURACY: 0.9524 | F1 MACRO: 0.9687 | F1 MICRO: 0.9703
# EPOCH 10 | LOSS: 1.7226693630218506 | ACCURACY: 0.9516 | F1 MACRO: 0.9679 | F1 MICRO: 0.9698
# aspect: ACCURACY 0.9531 | F1 MACRO 0.9689 | F1 MICRO 0.9707
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.95      1.00      0.97       175
#       others       0.88      0.92      0.90       158
#         part       0.96      0.97      0.97       158
#        price       0.97      1.00      0.98       192
#      service       0.99      0.99      0.99       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.96      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.1216325759887695 | ACCURACY: 0.937 | F1 MACRO: 0.9287 | F1 MICRO: 0.937
# EPOCH 2 | LOSS: 4.689061641693115 | ACCURACY: 0.9202 | F1 MACRO: 0.9119 | F1 MICRO: 0.9202
# EPOCH 3 | LOSS: 4.294118404388428 | ACCURACY: 0.9328 | F1 MACRO: 0.9268 | F1 MICRO: 0.9328
# EPOCH 4 | LOSS: 3.8957877159118652 | ACCURACY: 0.958 | F1 MACRO: 0.9535 | F1 MICRO: 0.958
# EPOCH 5 | LOSS: 3.6124627590179443 | ACCURACY: 0.9328 | F1 MACRO: 0.9227 | F1 MICRO: 0.9328
# EPOCH 6 | LOSS: 3.5940661430358887 | ACCURACY: 0.9286 | F1 MACRO: 0.9202 | F1 MICRO: 0.9286
# EPOCH 7 | LOSS: 3.40570330619812 | ACCURACY: 0.9454 | F1 MACRO: 0.9404 | F1 MICRO: 0.9454
# EPOCH 8 | LOSS: 3.4387216567993164 | ACCURACY: 0.9412 | F1 MACRO: 0.9341 | F1 MICRO: 0.9412
# EPOCH 9 | LOSS: 3.2801854610443115 | ACCURACY: 0.9496 | F1 MACRO: 0.9442 | F1 MICRO: 0.9496
# EPOCH 10 | LOSS: 3.3929660320281982 | ACCURACY: 0.937 | F1 MACRO: 0.9267 | F1 MICRO: 0.937
# sentiment: ACCURACY 0.958 | F1 MACRO 0.9535 | F1 MICRO 0.958
#               precision    recall  f1-score   support
#
#     negative       0.92      0.96      0.94        80
#     positive       0.98      0.96      0.97       158
#
#     accuracy                           0.96       238
#    macro avg       0.95      0.96      0.95       238
# weighted avg       0.96      0.96      0.96       238
#
# --------------------------------------------------
# Iteration 478: Accuracy: 0.9522, F1 Micro: 0.9522, F1 Macro: 0.9103
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.98      1.00      0.99       181
#     positive       1.00      0.92      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       0.99      0.94      0.97       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.81      0.87        16
#      neutral       0.94      1.00      0.97       167
#     positive       0.96      0.70      0.81        33
#
#     accuracy                           0.94       216
#    macro avg       0.94      0.84      0.88       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.75      0.75        12
#      neutral       0.89      0.95      0.92       152
#     positive       0.83      0.67      0.74        52
#
#     accuracy                           0.87       216
#    macro avg       0.82      0.79      0.80       216
# weighted avg       0.87      0.87      0.87       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.88      1.00      0.94        23
#      neutral       0.97      0.99      0.98       152
#     positive       0.97      0.83      0.89        41
#
#     accuracy                           0.96       216
#    macro avg       0.94      0.94      0.94       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.77      0.87        13
#      neutral       0.97      1.00      0.98       186
#     positive       0.93      0.76      0.84        17
#
#     accuracy                           0.97       216
#    macro avg       0.97      0.84      0.90       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.99      1.00      0.99       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.96      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 376 376
# Nearest checkpoint: 540
# Threshold: 88612.421875
# Samples above threshold: 39
# Acquired samples: 39
# Sampling duration: 15.973777532577515 seconds
# New train size: 517
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.183887243270874 | ACCURACY: 0.7976 | F1 MACRO: 0.8847 | F1 MICRO: 0.8862
# EPOCH 2 | LOSS: 2.611229181289673 | ACCURACY: 0.8281 | F1 MACRO: 0.8941 | F1 MICRO: 0.8985
# EPOCH 3 | LOSS: 2.3513998985290527 | ACCURACY: 0.907 | F1 MACRO: 0.9388 | F1 MICRO: 0.9423
# EPOCH 4 | LOSS: 2.245873212814331 | ACCURACY: 0.9256 | F1 MACRO: 0.9493 | F1 MICRO: 0.9534
# EPOCH 5 | LOSS: 2.1237869262695312 | ACCURACY: 0.9472 | F1 MACRO: 0.9656 | F1 MICRO: 0.967
# EPOCH 6 | LOSS: 2.006843090057373 | ACCURACY: 0.9472 | F1 MACRO: 0.9654 | F1 MICRO: 0.9672
# EPOCH 7 | LOSS: 1.9026786088943481 | ACCURACY: 0.9479 | F1 MACRO: 0.9654 | F1 MICRO: 0.9675
# EPOCH 8 | LOSS: 1.829349398612976 | ACCURACY: 0.9487 | F1 MACRO: 0.9655 | F1 MICRO: 0.9678
# EPOCH 9 | LOSS: 1.8049485683441162 | ACCURACY: 0.9524 | F1 MACRO: 0.9678 | F1 MICRO: 0.97
# EPOCH 10 | LOSS: 1.7239398956298828 | ACCURACY: 0.9464 | F1 MACRO: 0.9636 | F1 MICRO: 0.9663
# aspect: ACCURACY 0.9524 | F1 MACRO 0.9678 | F1 MICRO 0.97
# ...
#
#    micro avg       0.97      0.99      0.98      1061
#    macro avg       0.97      0.99      0.98      1061
# weighted avg       0.97      0.99      0.98      1061
#  samples avg       0.97      0.99      0.98      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.826425790786743 | ACCURACY: 0.9035 | F1 MACRO: 0.8866 | F1 MICRO: 0.9035
# EPOCH 2 | LOSS: 2.847275495529175 | ACCURACY: 0.9421 | F1 MACRO: 0.9333 | F1 MICRO: 0.9421
# EPOCH 3 | LOSS: 2.524869203567505 | ACCURACY: 0.9459 | F1 MACRO: 0.9387 | F1 MICRO: 0.9459
# EPOCH 4 | LOSS: 2.422055959701538 | ACCURACY: 0.9459 | F1 MACRO: 0.9391 | F1 MICRO: 0.9459
# EPOCH 5 | LOSS: 2.2460391521453857 | ACCURACY: 0.9421 | F1 MACRO: 0.9353 | F1 MICRO: 0.9421
# EPOCH 6 | LOSS: 2.192676305770874 | ACCURACY: 0.9382 | F1 MACRO: 0.9312 | F1 MICRO: 0.9382
# EPOCH 7 | LOSS: 2.089332103729248 | ACCURACY: 0.9421 | F1 MACRO: 0.9337 | F1 MICRO: 0.9421
# EPOCH 8 | LOSS: 2.123645305633545 | ACCURACY: 0.9421 | F1 MACRO: 0.9341 | F1 MICRO: 0.9421
# EPOCH 9 | LOSS: 2.0461325645446777 | ACCURACY: 0.9537 | F1 MACRO: 0.9475 | F1 MICRO: 0.9537
# EPOCH 10 | LOSS: 2.0629019737243652 | ACCURACY: 0.9305 | F1 MACRO: 0.9234 | F1 MICRO: 0.9305
# sentiment: ACCURACY 0.9537 | F1 MACRO 0.9475 | F1 MICRO 0.9537
#               precision    recall  f1-score   support
#
#     negative       0.91      0.95      0.93        83
#     positive       0.98      0.95      0.97       176
#
#     accuracy                           0.95       259
#    macro avg       0.94      0.95      0.95       259
# weighted avg       0.95      0.95      0.95       259
#
# --------------------------------------------------
# Iteration 831: Accuracy: 0.9576, F1 Micro: 0.9576, F1 Macro: 0.9214
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.97      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.75      0.83        16
#      neutral       0.95      0.98      0.97       167
#     positive       0.87      0.82      0.84        33
#
#     accuracy                           0.94       216
#    macro avg       0.92      0.85      0.88       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.75      0.75        12
#      neutral       0.91      0.95      0.93       152
#     positive       0.85      0.75      0.80        52
#
#     accuracy                           0.89       216
#    macro avg       0.84      0.82      0.82       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.85      1.00      0.92        23
#      neutral       0.97      0.98      0.98       152
#     positive       0.94      0.83      0.88        41
#
#     accuracy                           0.95       216
#    macro avg       0.92      0.94      0.93       216
# weighted avg       0.96      0.95      0.95       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.92      0.92        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.88      0.82      0.85        17
#
#     accuracy                           0.98       216
#    macro avg       0.93      0.91      0.92       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        14
#      neutral       1.00      1.00      1.00       185
#     positive       1.00      1.00      1.00        17
#
#     accuracy                           1.00       216
#    macro avg       1.00      1.00      1.00       216
# weighted avg       1.00      1.00      1.00       216
#
# Launching training on 2 GPUs.
# 33 33
# Nearest checkpoint: 864
# Threshold: 88282.625
# Samples above threshold: 4
# Acquired samples: 25
# Sampling duration: 22.233050107955933 seconds
# New train size: 856
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.937633991241455 | ACCURACY: 0.8393 | F1 MACRO: 0.9047 | F1 MICRO: 0.9065
# EPOCH 2 | LOSS: 2.3340511322021484 | ACCURACY: 0.9368 | F1 MACRO: 0.9591 | F1 MICRO: 0.9607
# EPOCH 3 | LOSS: 2.1672170162200928 | ACCURACY: 0.9524 | F1 MACRO: 0.9694 | F1 MICRO: 0.9705
# EPOCH 4 | LOSS: 1.9735772609710693 | ACCURACY: 0.9539 | F1 MACRO: 0.9693 | F1 MICRO: 0.9711
# EPOCH 5 | LOSS: 1.8472014665603638 | ACCURACY: 0.9539 | F1 MACRO: 0.9683 | F1 MICRO: 0.9708
# EPOCH 6 | LOSS: 1.7338062524795532 | ACCURACY: 0.9621 | F1 MACRO: 0.9751 | F1 MICRO: 0.9763
# EPOCH 7 | LOSS: 1.687025547027588 | ACCURACY: 0.9531 | F1 MACRO: 0.968 | F1 MICRO: 0.9705
# EPOCH 8 | LOSS: 1.6362278461456299 | ACCURACY: 0.9591 | F1 MACRO: 0.9729 | F1 MICRO: 0.9744
# EPOCH 9 | LOSS: 1.5647788047790527 | ACCURACY: 0.9554 | F1 MACRO: 0.97 | F1 MICRO: 0.9718
# EPOCH 10 | LOSS: 1.5671106576919556 | ACCURACY: 0.9591 | F1 MACRO: 0.9721 | F1 MICRO: 0.974
# aspect: ACCURACY 0.9621 | F1 MACRO 0.9751 | F1 MICRO 0.9763
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.94      0.99      0.96       175
#       others       0.91      0.97      0.94       158
#         part       0.97      0.97      0.97       158
#        price       0.98      1.00      0.99       192
#      service       0.99      1.00      1.00       191
#
#    micro avg       0.96      0.99      0.98      1061
#    macro avg       0.96      0.99      0.98      1061
# weighted avg       0.96      0.99      0.98      1061
#  samples avg       0.96      0.99      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.5954151153564453 | ACCURACY: 0.9134 | F1 MACRO: 0.8967 | F1 MICRO: 0.9134
# EPOCH 2 | LOSS: 2.7604901790618896 | ACCURACY: 0.9252 | F1 MACRO: 0.9181 | F1 MICRO: 0.9252
# EPOCH 3 | LOSS: 2.391497850418091 | ACCURACY: 0.9488 | F1 MACRO: 0.9417 | F1 MICRO: 0.9488
# EPOCH 4 | LOSS: 2.208617925643921 | ACCURACY: 0.9291 | F1 MACRO: 0.9226 | F1 MICRO: 0.9291
# EPOCH 5 | LOSS: 2.077324390411377 | ACCURACY: 0.9606 | F1 MACRO: 0.9555 | F1 MICRO: 0.9606
# EPOCH 6 | LOSS: 2.068774700164795 | ACCURACY: 0.9331 | F1 MACRO: 0.9267 | F1 MICRO: 0.9331
# EPOCH 7 | LOSS: 2.032238245010376 | ACCURACY: 0.937 | F1 MACRO: 0.9308 | F1 MICRO: 0.937
# EPOCH 8 | LOSS: 1.9546643495559692 | ACCURACY: 0.9291 | F1 MACRO: 0.9195 | F1 MICRO: 0.9291
# EPOCH 9 | LOSS: 1.9929543733596802 | ACCURACY: 0.9291 | F1 MACRO: 0.9218 | F1 MICRO: 0.9291
# EPOCH 10 | LOSS: 1.9354461431503296 | ACCURACY: 0.9488 | F1 MACRO: 0.9427 | F1 MICRO: 0.9488
# sentiment: ACCURACY 0.9606 | F1 MACRO 0.9555 | F1 MICRO 0.9606
#               precision    recall  f1-score   support
#
#     negative       0.93      0.95      0.94        83
#     positive       0.98      0.96      0.97       171
#
#     accuracy                           0.96       254
#    macro avg       0.95      0.96      0.96       254
# weighted avg       0.96      0.96      0.96       254
#
# --------------------------------------------------
# Iteration 856: Accuracy: 0.9599, F1 Micro: 0.9599, F1 Macro: 0.9219
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.97      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.75      0.83        16
#      neutral       0.96      0.98      0.97       167
#     positive       0.82      0.82      0.82        33
#
#     accuracy                           0.94       216
#    macro avg       0.90      0.85      0.87       216
# weighted avg       0.93      0.94      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.82      0.75      0.78        12
#      neutral       0.91      0.98      0.95       152
#     positive       0.93      0.75      0.83        52
#
#     accuracy                           0.91       216
#    macro avg       0.89      0.83      0.85       216
# weighted avg       0.91      0.91      0.91       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.82      1.00      0.90        23
#      neutral       0.97      0.98      0.98       152
#     positive       0.94      0.80      0.87        41
#
#     accuracy                           0.95       216
#    macro avg       0.91      0.93      0.92       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.85      0.88        13
#      neutral       0.98      1.00      0.99       186
#     positive       0.93      0.82      0.87        17
#
#     accuracy                           0.98       216
#    macro avg       0.94      0.89      0.92       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        14
#      neutral       1.00      1.00      1.00       185
#     positive       1.00      1.00      1.00        17
#
#     accuracy                           1.00       216
#    macro avg       1.00      1.00      1.00       216
# weighted avg       1.00      1.00      1.00       216
#
# Launching training on 2 GPUs.
# 8 8
# Nearest checkpoint: 864
# Threshold: 88294.6796875
# Samples above threshold: 1
# Acquired samples: 8
# Sampling duration: 22.004050731658936 seconds
# New train size: 864
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.944631576538086 | ACCURACY: 0.8207 | F1 MACRO: 0.896 | F1 MICRO: 0.8975
# EPOCH 2 | LOSS: 2.3285555839538574 | ACCURACY: 0.9345 | F1 MACRO: 0.9576 | F1 MICRO: 0.9594
# EPOCH 3 | LOSS: 2.1578097343444824 | ACCURACY: 0.9531 | F1 MACRO: 0.9694 | F1 MICRO: 0.9709
# EPOCH 4 | LOSS: 1.9996709823608398 | ACCURACY: 0.9591 | F1 MACRO: 0.9737 | F1 MICRO: 0.9745
# EPOCH 5 | LOSS: 1.8579329252243042 | ACCURACY: 0.9621 | F1 MACRO: 0.9749 | F1 MICRO: 0.9761
# EPOCH 6 | LOSS: 1.738457441329956 | ACCURACY: 0.9554 | F1 MACRO: 0.9699 | F1 MICRO: 0.9718
# EPOCH 7 | LOSS: 1.6792716979980469 | ACCURACY: 0.9524 | F1 MACRO: 0.9674 | F1 MICRO: 0.97
# EPOCH 8 | LOSS: 1.6421780586242676 | ACCURACY: 0.9554 | F1 MACRO: 0.9702 | F1 MICRO: 0.9719
# EPOCH 9 | LOSS: 1.5799070596694946 | ACCURACY: 0.9606 | F1 MACRO: 0.9739 | F1 MICRO: 0.9752
# EPOCH 10 | LOSS: 1.5680789947509766 | ACCURACY: 0.9576 | F1 MACRO: 0.9718 | F1 MICRO: 0.9733
# aspect: ACCURACY 0.9621 | F1 MACRO 0.9749 | F1 MICRO 0.9761
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.95      0.98      0.96       175
#       others       0.94      0.96      0.95       158
#         part       0.98      0.96      0.97       158
#        price       0.98      0.99      0.99       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.97      0.98      0.98      1061
#    macro avg       0.97      0.98      0.97      1061
# weighted avg       0.97      0.98      0.98      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.618929862976074 | ACCURACY: 0.9398 | F1 MACRO: 0.9304 | F1 MICRO: 0.9398
# EPOCH 2 | LOSS: 2.7068328857421875 | ACCURACY: 0.9549 | F1 MACRO: 0.9475 | F1 MICRO: 0.9549
# EPOCH 3 | LOSS: 2.416053533554077 | ACCURACY: 0.9474 | F1 MACRO: 0.9399 | F1 MICRO: 0.9474
# EPOCH 4 | LOSS: 2.294466018676758 | ACCURACY: 0.9286 | F1 MACRO: 0.92 | F1 MICRO: 0.9286
# EPOCH 5 | LOSS: 2.1829257011413574 | ACCURACY: 0.9511 | F1 MACRO: 0.944 | F1 MICRO: 0.9511
# EPOCH 6 | LOSS: 2.0697505474090576 | ACCURACY: 0.9398 | F1 MACRO: 0.9295 | F1 MICRO: 0.9398
# EPOCH 7 | LOSS: 2.0304789543151855 | ACCURACY: 0.9398 | F1 MACRO: 0.9304 | F1 MICRO: 0.9398
# EPOCH 8 | LOSS: 1.9929022789001465 | ACCURACY: 0.9135 | F1 MACRO: 0.9047 | F1 MICRO: 0.9135
# EPOCH 9 | LOSS: 1.9976959228515625 | ACCURACY: 0.9436 | F1 MACRO: 0.9354 | F1 MICRO: 0.9436
# EPOCH 10 | LOSS: 1.9488682746887207 | ACCURACY: 0.9436 | F1 MACRO: 0.9332 | F1 MICRO: 0.9436
# sentiment: ACCURACY 0.9549 | F1 MACRO 0.9475 | F1 MICRO 0.9549
#               precision    recall  f1-score   support
#
#     negative       0.92      0.94      0.93        82
#     positive       0.97      0.96      0.97       184
#
#     accuracy                           0.95       266
#    macro avg       0.94      0.95      0.95       266
# weighted avg       0.96      0.95      0.96       266
#
# --------------------------------------------------
# Iteration 864: Accuracy: 0.9529, F1 Micro: 0.9529, F1 Macro: 0.9137
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      1.00      0.99       181
#     positive       1.00      0.92      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.97      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.81      0.87        16
#      neutral       0.95      0.97      0.96       167
#     positive       0.81      0.79      0.80        33
#
#     accuracy                           0.93       216
#    macro avg       0.90      0.86      0.88       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.82      0.75      0.78        12
#      neutral       0.93      0.93      0.93       152
#     positive       0.83      0.83      0.83        52
#
#     accuracy                           0.90       216
#    macro avg       0.86      0.84      0.85       216
# weighted avg       0.90      0.90      0.90       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.81      0.91      0.86        23
#      neutral       0.98      0.96      0.97       152
#     positive       0.85      0.85      0.85        41
#
#     accuracy                           0.94       216
#    macro avg       0.88      0.91      0.89       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.85      0.88        13
#      neutral       0.98      0.99      0.99       186
#     positive       0.88      0.82      0.85        17
#
#     accuracy                           0.97       216
#    macro avg       0.93      0.89      0.91       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.99      1.00      0.99       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.96      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Total sampling time: 393.53 seconds
# Total runtime: 3146.0870549678802 seconds

# %% [markdown]
# ## RUN 3

# %%
active_learning(seeds[2], 2)
# Out:
# ===============================================
# TRIAL 3
# Random seed: 14
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.5870654582977295 | ACCURACY: 0.7448 | F1 MACRO: 0.8463 | F1 MICRO: 0.8498
# EPOCH 2 | LOSS: 3.536916494369507 | ACCURACY: 0.7812 | F1 MACRO: 0.8738 | F1 MICRO: 0.8763
# EPOCH 3 | LOSS: 3.41666316986084 | ACCURACY: 0.7857 | F1 MACRO: 0.8774 | F1 MICRO: 0.8795
# EPOCH 4 | LOSS: 3.3116543292999268 | ACCURACY: 0.7879 | F1 MACRO: 0.8792 | F1 MICRO: 0.881
# EPOCH 5 | LOSS: 3.2140653133392334 | ACCURACY: 0.7894 | F1 MACRO: 0.8788 | F1 MICRO: 0.881
# EPOCH 6 | LOSS: 3.2702386379241943 | ACCURACY: 0.7902 | F1 MACRO: 0.878 | F1 MICRO: 0.8806
# EPOCH 7 | LOSS: 3.0499675273895264 | ACCURACY: 0.7887 | F1 MACRO: 0.8742 | F1 MICRO: 0.8783
# EPOCH 8 | LOSS: 3.18894100189209 | ACCURACY: 0.7783 | F1 MACRO: 0.8648 | F1 MICRO: 0.8711
# EPOCH 9 | LOSS: 3.179757595062256 | ACCURACY: 0.7716 | F1 MACRO: 0.8591 | F1 MICRO: 0.8652
# EPOCH 10 | LOSS: 3.173837900161743 | ACCURACY: 0.7798 | F1 MACRO: 0.8646 | F1 MICRO: 0.8699
# aspect: ACCURACY 0.7894 | F1 MACRO 0.8788 | F1 MICRO 0.881
#               precision    recall  f1-score   support
#
#         fuel       0.83      1.00      0.91       187
#      machine       0.78      1.00      0.88       175
#       others       0.71      0.93      0.80       158
#         part       0.73      0.99      0.84       158
#        price       0.86      1.00      0.92       192
#      service       0.85      1.00      0.92       191
#
#    micro avg       0.80      0.99      0.88      1061
#    macro avg       0.79      0.99      0.88      1061
# weighted avg       0.80      0.99      0.88      1061
#  samples avg       0.80      0.99      0.88      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.551836967468262 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# EPOCH 2 | LOSS: 5.958315849304199 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# EPOCH 3 | LOSS: 5.1441192626953125 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# EPOCH 4 | LOSS: 4.865445613861084 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# EPOCH 5 | LOSS: 4.694942951202393 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# EPOCH 6 | LOSS: 4.679878234863281 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# EPOCH 7 | LOSS: 4.508140563964844 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# EPOCH 8 | LOSS: 4.764486789703369 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# EPOCH 9 | LOSS: 4.76905632019043 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# EPOCH 10 | LOSS: 4.528667449951172 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# sentiment: ACCURACY 0.95 | F1 MACRO 0.4872 | F1 MICRO 0.95
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00         1
#     positive       0.95      1.00      0.97        19
#
#     accuracy                           0.95        20
#    macro avg       0.47      0.50      0.49        20
# weighted avg       0.90      0.95      0.93        20
#
# --------------------------------------------------
# Iteration 54: Accuracy: 0.7917, F1 Micro: 0.7917, F1 Macro: 0.3167
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        11
#      neutral       0.84      1.00      0.91       181
#     positive       0.00      0.00      0.00        24
#
#     accuracy                           0.84       216
#    macro avg       0.28      0.33      0.30       216
# weighted avg       0.70      0.84      0.76       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        16
#      neutral       0.77      1.00      0.87       167
#     positive       0.00      0.00      0.00        33
#
#     accuracy                           0.77       216
#    macro avg       0.26      0.33      0.29       216
# weighted avg       0.60      0.77      0.67       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        12
#      neutral       0.71      0.95      0.81       152
#     positive       0.31      0.08      0.12        52
#
#     accuracy                           0.69       216
#    macro avg       0.34      0.34      0.31       216
# weighted avg       0.57      0.69      0.60       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        23
#      neutral       0.73      1.00      0.84       152
#     positive       1.00      0.17      0.29        41
#
#     accuracy                           0.74       216
#    macro avg       0.58      0.39      0.38       216
# weighted avg       0.70      0.74      0.65       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        13
#      neutral       0.86      1.00      0.93       186
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.86       216
#    macro avg       0.29      0.33      0.31       216
# weighted avg       0.74      0.86      0.80       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        14
#      neutral       0.86      1.00      0.92       185
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.86       216
#    macro avg       0.29      0.33      0.31       216
# weighted avg       0.73      0.86      0.79       216
#
# Launching training on 2 GPUs.
# 91 91
# Nearest checkpoint: 540
# Threshold: 87312.4140625
# Samples above threshold: 81
# Acquired samples: 81
# Sampling duration: 5.7513861656188965 seconds
# New train size: 135
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.7829372882843018 | ACCURACY: 0.7746 | F1 MACRO: 0.8657 | F1 MICRO: 0.871
# EPOCH 2 | LOSS: 3.520453691482544 | ACCURACY: 0.7924 | F1 MACRO: 0.8808 | F1 MICRO: 0.8828
# EPOCH 3 | LOSS: 3.4487504959106445 | ACCURACY: 0.7879 | F1 MACRO: 0.8743 | F1 MICRO: 0.8785
# EPOCH 4 | LOSS: 3.0968339443206787 | ACCURACY: 0.7857 | F1 MACRO: 0.8682 | F1 MICRO: 0.875
# EPOCH 5 | LOSS: 3.0196127891540527 | ACCURACY: 0.8155 | F1 MACRO: 0.8898 | F1 MICRO: 0.8927
# EPOCH 6 | LOSS: 2.9278383255004883 | ACCURACY: 0.8192 | F1 MACRO: 0.8916 | F1 MICRO: 0.8946
# EPOCH 7 | LOSS: 2.827197313308716 | ACCURACY: 0.8333 | F1 MACRO: 0.8974 | F1 MICRO: 0.9013
# EPOCH 8 | LOSS: 2.7851390838623047 | ACCURACY: 0.8594 | F1 MACRO: 0.9119 | F1 MICRO: 0.9154
# EPOCH 9 | LOSS: 2.7149646282196045 | ACCURACY: 0.8765 | F1 MACRO: 0.9213 | F1 MICRO: 0.9248
# EPOCH 10 | LOSS: 2.644597053527832 | ACCURACY: 0.8765 | F1 MACRO: 0.9198 | F1 MICRO: 0.9241
# aspect: ACCURACY 0.8765 | F1 MACRO 0.9213 | F1 MICRO 0.9248
#               precision    recall  f1-score   support
#
#         fuel       0.89      1.00      0.94       187
#      machine       0.81      0.98      0.89       175
#       others       0.88      0.81      0.84       158
#         part       0.87      0.97      0.92       158
#        price       0.96      0.99      0.98       192
#      service       0.93      0.99      0.96       191
#
#    micro avg       0.89      0.96      0.92      1061
#    macro avg       0.89      0.96      0.92      1061
# weighted avg       0.89      0.96      0.92      1061
#  samples avg       0.90      0.96      0.92      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 16.7314395904541 | ACCURACY: 0.8325 | F1 MACRO: 0.7855 | F1 MICRO: 0.8325
# EPOCH 2 | LOSS: 13.03349494934082 | ACCURACY: 0.8916 | F1 MACRO: 0.8686 | F1 MICRO: 0.8916
# EPOCH 3 | LOSS: 12.393294334411621 | ACCURACY: 0.9015 | F1 MACRO: 0.8707 | F1 MICRO: 0.9015
# EPOCH 4 | LOSS: 11.401226997375488 | ACCURACY: 0.9113 | F1 MACRO: 0.8772 | F1 MICRO: 0.9113
# EPOCH 5 | LOSS: 10.581284523010254 | ACCURACY: 0.936 | F1 MACRO: 0.9175 | F1 MICRO: 0.936
# EPOCH 6 | LOSS: 10.108139991760254 | ACCURACY: 0.9212 | F1 MACRO: 0.8953 | F1 MICRO: 0.9212
# EPOCH 7 | LOSS: 9.523598670959473 | ACCURACY: 0.9064 | F1 MACRO: 0.8794 | F1 MICRO: 0.9064
# EPOCH 8 | LOSS: 9.104113578796387 | ACCURACY: 0.931 | F1 MACRO: 0.9106 | F1 MICRO: 0.931
# EPOCH 9 | LOSS: 8.962920188903809 | ACCURACY: 0.9261 | F1 MACRO: 0.9048 | F1 MICRO: 0.9261
# EPOCH 10 | LOSS: 8.998359680175781 | ACCURACY: 0.9409 | F1 MACRO: 0.9234 | F1 MICRO: 0.9409
# sentiment: ACCURACY 0.9409 | F1 MACRO 0.9234 | F1 MICRO 0.9409
#               precision    recall  f1-score   support
#
#     negative       0.84      0.94      0.89        50
#     positive       0.98      0.94      0.96       153
#
#     accuracy                           0.94       203
#    macro avg       0.91      0.94      0.92       203
# weighted avg       0.95      0.94      0.94       203
#
# --------------------------------------------------
# Iteration 135: Accuracy: 0.8727, F1 Micro: 0.8727, F1 Macro: 0.7209
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.45      0.62        11
#      neutral       0.92      1.00      0.96       181
#     positive       1.00      0.62      0.77        24
#
#     accuracy                           0.93       216
#    macro avg       0.97      0.69      0.78       216
# weighted avg       0.94      0.93      0.92       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.12      0.22        16
#      neutral       0.81      0.98      0.89       167
#     positive       0.62      0.24      0.35        33
#
#     accuracy                           0.80       216
#    macro avg       0.81      0.45      0.49       216
# weighted avg       0.80      0.80      0.75       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.67      0.67      0.67        12
#      neutral       0.87      0.78      0.82       152
#     positive       0.57      0.73      0.64        52
#
#     accuracy                           0.76       216
#    macro avg       0.70      0.73      0.71       216
# weighted avg       0.78      0.76      0.77       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.84      0.70      0.76        23
#      neutral       0.88      0.97      0.92       152
#     positive       0.90      0.66      0.76        41
#
#     accuracy                           0.88       216
#    macro avg       0.87      0.77      0.81       216
# weighted avg       0.88      0.88      0.87       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.62      0.70        13
#      neutral       0.96      0.99      0.98       186
#     positive       0.80      0.71      0.75        17
#
#     accuracy                           0.94       216
#    macro avg       0.85      0.77      0.81       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.89      0.57      0.70        14
#      neutral       0.92      0.99      0.95       185
#     positive       1.00      0.35      0.52        17
#
#     accuracy                           0.92       216
#    macro avg       0.93      0.64      0.72       216
# weighted avg       0.92      0.92      0.90       216
#
# Launching training on 2 GPUs.
# 563 563
# Nearest checkpoint: 540
# Threshold: 87981.4765625
# Samples above threshold: 73
# Acquired samples: 73
# Sampling duration: 10.328732252120972 seconds
# New train size: 208
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.6877641677856445 | ACCURACY: 0.7909 | F1 MACRO: 0.8813 | F1 MICRO: 0.8829
# EPOCH 2 | LOSS: 3.373588800430298 | ACCURACY: 0.7969 | F1 MACRO: 0.8809 | F1 MICRO: 0.8839
# EPOCH 3 | LOSS: 3.048902750015259 | ACCURACY: 0.8028 | F1 MACRO: 0.8854 | F1 MICRO: 0.8877
# EPOCH 4 | LOSS: 2.7916510105133057 | ACCURACY: 0.8341 | F1 MACRO: 0.901 | F1 MICRO: 0.9029
# EPOCH 5 | LOSS: 2.6827452182769775 | ACCURACY: 0.8393 | F1 MACRO: 0.9015 | F1 MICRO: 0.9048
# EPOCH 6 | LOSS: 2.612220287322998 | ACCURACY: 0.8891 | F1 MACRO: 0.9308 | F1 MICRO: 0.9331
# EPOCH 7 | LOSS: 2.5787429809570312 | ACCURACY: 0.9003 | F1 MACRO: 0.9359 | F1 MICRO: 0.9388
# EPOCH 8 | LOSS: 2.5216012001037598 | ACCURACY: 0.9055 | F1 MACRO: 0.9389 | F1 MICRO: 0.9417
# EPOCH 9 | LOSS: 2.4162919521331787 | ACCURACY: 0.9144 | F1 MACRO: 0.9445 | F1 MICRO: 0.9473
# EPOCH 10 | LOSS: 2.314970016479492 | ACCURACY: 0.9144 | F1 MACRO: 0.9446 | F1 MICRO: 0.9471
# aspect: ACCURACY 0.9144 | F1 MACRO 0.9445 | F1 MICRO 0.9473
#               precision    recall  f1-score   support
#
#         fuel       0.96      1.00      0.98       187
#      machine       0.86      0.99      0.92       175
#       others       0.89      0.86      0.88       158
#         part       0.88      0.99      0.93       158
#        price       0.96      1.00      0.98       192
#      service       0.96      0.99      0.98       191
#
#    micro avg       0.92      0.97      0.95      1061
#    macro avg       0.92      0.97      0.94      1061
# weighted avg       0.92      0.97      0.95      1061
#  samples avg       0.92      0.97      0.94      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 13.597146034240723 | ACCURACY: 0.8777 | F1 MACRO: 0.8621 | F1 MICRO: 0.8777
# EPOCH 2 | LOSS: 10.440507888793945 | ACCURACY: 0.9258 | F1 MACRO: 0.9136 | F1 MICRO: 0.9258
# EPOCH 3 | LOSS: 9.263182640075684 | ACCURACY: 0.9389 | F1 MACRO: 0.9301 | F1 MICRO: 0.9389
# EPOCH 4 | LOSS: 8.32217788696289 | ACCURACY: 0.917 | F1 MACRO: 0.9027 | F1 MICRO: 0.917
# EPOCH 5 | LOSS: 8.049592971801758 | ACCURACY: 0.8952 | F1 MACRO: 0.8734 | F1 MICRO: 0.8952
# EPOCH 6 | LOSS: 7.520455837249756 | ACCURACY: 0.9345 | F1 MACRO: 0.9264 | F1 MICRO: 0.9345
# EPOCH 7 | LOSS: 7.150340557098389 | ACCURACY: 0.9389 | F1 MACRO: 0.9315 | F1 MICRO: 0.9389
# EPOCH 8 | LOSS: 7.212067604064941 | ACCURACY: 0.9345 | F1 MACRO: 0.9254 | F1 MICRO: 0.9345
# EPOCH 9 | LOSS: 6.977080821990967 | ACCURACY: 0.9389 | F1 MACRO: 0.9286 | F1 MICRO: 0.9389
# EPOCH 10 | LOSS: 6.66038703918457 | ACCURACY: 0.9389 | F1 MACRO: 0.9296 | F1 MICRO: 0.9389
# sentiment: ACCURACY 0.9389 | F1 MACRO 0.9296 | F1 MICRO 0.9389
#               precision    recall  f1-score   support
#
#     negative       0.89      0.92      0.90        72
#     positive       0.96      0.95      0.96       157
#
#     accuracy                           0.94       229
#    macro avg       0.93      0.93      0.93       229
# weighted avg       0.94      0.94      0.94       229
#
# --------------------------------------------------
# Iteration 208: Accuracy: 0.909, F1 Micro: 0.909, F1 Macro: 0.8288
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.73      0.84        11
#      neutral       0.97      1.00      0.99       181
#     positive       0.91      0.83      0.87        24
#
#     accuracy                           0.97       216
#    macro avg       0.96      0.85      0.90       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.50      0.62        16
#      neutral       0.87      0.98      0.92       167
#     positive       0.79      0.45      0.58        33
#
#     accuracy                           0.86       216
#    macro avg       0.82      0.64      0.70       216
# weighted avg       0.85      0.86      0.85       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.67      0.83      0.74        12
#      neutral       0.90      0.84      0.87       152
#     positive       0.67      0.75      0.71        52
#
#     accuracy                           0.82       216
#    macro avg       0.74      0.81      0.77       216
# weighted avg       0.83      0.82      0.82       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.94      0.74      0.83        23
#      neutral       0.87      0.98      0.92       152
#     positive       0.85      0.56      0.68        41
#
#     accuracy                           0.88       216
#    macro avg       0.89      0.76      0.81       216
# weighted avg       0.88      0.88      0.87       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.77      0.83        13
#      neutral       0.98      0.99      0.99       186
#     positive       0.88      0.82      0.85        17
#
#     accuracy                           0.97       216
#    macro avg       0.92      0.86      0.89       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.93      0.93        14
#      neutral       0.96      0.99      0.98       185
#     positive       1.00      0.65      0.79        17
#
#     accuracy                           0.96       216
#    macro avg       0.96      0.86      0.90       216
# weighted avg       0.96      0.96      0.96       216
#
# Launching training on 2 GPUs.
# 590 590
# Nearest checkpoint: 540
# Threshold: 88388.3515625
# Samples above threshold: 66
# Acquired samples: 66
# Sampling duration: 11.375714778900146 seconds
# New train size: 274
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.3114118576049805 | ACCURACY: 0.7917 | F1 MACRO: 0.8818 | F1 MICRO: 0.8833
# EPOCH 2 | LOSS: 2.947521209716797 | ACCURACY: 0.8021 | F1 MACRO: 0.8847 | F1 MICRO: 0.8871
# EPOCH 3 | LOSS: 2.6571714878082275 | ACCURACY: 0.8296 | F1 MACRO: 0.8999 | F1 MICRO: 0.9014
# EPOCH 4 | LOSS: 2.455706834793091 | ACCURACY: 0.8571 | F1 MACRO: 0.9139 | F1 MICRO: 0.9153
# EPOCH 5 | LOSS: 2.416092872619629 | ACCURACY: 0.8936 | F1 MACRO: 0.9313 | F1 MICRO: 0.9345
# EPOCH 6 | LOSS: 2.4084911346435547 | ACCURACY: 0.9077 | F1 MACRO: 0.9401 | F1 MICRO: 0.943
# EPOCH 7 | LOSS: 2.291776180267334 | ACCURACY: 0.9204 | F1 MACRO: 0.9481 | F1 MICRO: 0.9508
# EPOCH 8 | LOSS: 2.146296501159668 | ACCURACY: 0.9338 | F1 MACRO: 0.9572 | F1 MICRO: 0.959
# EPOCH 9 | LOSS: 2.0716989040374756 | ACCURACY: 0.9382 | F1 MACRO: 0.9594 | F1 MICRO: 0.9615
# EPOCH 10 | LOSS: 1.9799065589904785 | ACCURACY: 0.9301 | F1 MACRO: 0.9531 | F1 MICRO: 0.9561
# aspect: ACCURACY 0.9382 | F1 MACRO 0.9594 | F1 MICRO 0.9615
#               precision    recall  f1-score   support
#
#         fuel       0.97      1.00      0.99       187
#      machine       0.91      0.99      0.95       175
#       others       0.91      0.92      0.92       158
#         part       0.94      0.94      0.94       158
#        price       0.97      1.00      0.99       192
#      service       0.97      0.99      0.98       191
#
#    micro avg       0.95      0.98      0.96      1061
#    macro avg       0.95      0.97      0.96      1061
# weighted avg       0.95      0.98      0.96      1061
#  samples avg       0.95      0.98      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 10.09862232208252 | ACCURACY: 0.8659 | F1 MACRO: 0.8423 | F1 MICRO: 0.8659
# EPOCH 2 | LOSS: 7.962538719177246 | ACCURACY: 0.9065 | F1 MACRO: 0.8963 | F1 MICRO: 0.9065
# EPOCH 3 | LOSS: 7.137864112854004 | ACCURACY: 0.8902 | F1 MACRO: 0.8809 | F1 MICRO: 0.8902
# EPOCH 4 | LOSS: 6.771933078765869 | ACCURACY: 0.8943 | F1 MACRO: 0.8788 | F1 MICRO: 0.8943
# EPOCH 5 | LOSS: 6.382922649383545 | ACCURACY: 0.8943 | F1 MACRO: 0.878 | F1 MICRO: 0.8943
# EPOCH 6 | LOSS: 5.895178318023682 | ACCURACY: 0.8902 | F1 MACRO: 0.8776 | F1 MICRO: 0.8902
# EPOCH 7 | LOSS: 5.8085432052612305 | ACCURACY: 0.9065 | F1 MACRO: 0.8924 | F1 MICRO: 0.9065
# EPOCH 8 | LOSS: 5.654946327209473 | ACCURACY: 0.9024 | F1 MACRO: 0.8874 | F1 MICRO: 0.9024
# EPOCH 9 | LOSS: 5.441446781158447 | ACCURACY: 0.9187 | F1 MACRO: 0.9096 | F1 MICRO: 0.9187
# EPOCH 10 | LOSS: 5.390779972076416 | ACCURACY: 0.9065 | F1 MACRO: 0.8975 | F1 MICRO: 0.9065
# sentiment: ACCURACY 0.9187 | F1 MACRO 0.9096 | F1 MICRO 0.9187
#               precision    recall  f1-score   support
#
#     negative       0.81      0.96      0.88        77
#     positive       0.98      0.90      0.94       169
#
#     accuracy                           0.92       246
#    macro avg       0.90      0.93      0.91       246
# weighted avg       0.93      0.92      0.92       246
#
# --------------------------------------------------
# Iteration 274: Accuracy: 0.9282, F1 Micro: 0.9282, F1 Macro: 0.8546
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.82      0.90        11
#      neutral       0.98      1.00      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.98       216
#    macro avg       0.98      0.91      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.73      0.69      0.71        16
#      neutral       0.92      0.98      0.94       167
#     positive       0.83      0.58      0.68        33
#
#     accuracy                           0.89       216
#    macro avg       0.83      0.75      0.78       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.82      0.75      0.78        12
#      neutral       0.92      0.93      0.92       152
#     positive       0.81      0.81      0.81        52
#
#     accuracy                           0.89       216
#    macro avg       0.85      0.83      0.84       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.69      0.87      0.77        23
#      neutral       0.93      0.94      0.93       152
#     positive       0.85      0.68      0.76        41
#
#     accuracy                           0.88       216
#    macro avg       0.82      0.83      0.82       216
# weighted avg       0.89      0.88      0.88       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.77      0.77      0.77        13
#      neutral       0.97      0.99      0.98       186
#     positive       0.92      0.65      0.76        17
#
#     accuracy                           0.95       216
#    macro avg       0.88      0.80      0.84       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.86      0.89        14
#      neutral       0.97      0.99      0.98       185
#     positive       1.00      0.76      0.87        17
#
#     accuracy                           0.97       216
#    macro avg       0.96      0.87      0.91       216
# weighted avg       0.97      0.97      0.97       216
#
# Launching training on 2 GPUs.
# 559 559
# Nearest checkpoint: 540
# Threshold: 88444.2421875
# Samples above threshold: 59
# Acquired samples: 59
# Sampling duration: 12.60182809829712 seconds
# New train size: 333
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.428487539291382 | ACCURACY: 0.7946 | F1 MACRO: 0.8833 | F1 MICRO: 0.8848
# EPOCH 2 | LOSS: 2.989264726638794 | ACCURACY: 0.8118 | F1 MACRO: 0.8915 | F1 MICRO: 0.893
# EPOCH 3 | LOSS: 2.672577381134033 | ACCURACY: 0.8564 | F1 MACRO: 0.9132 | F1 MICRO: 0.9147
# EPOCH 4 | LOSS: 2.5531580448150635 | ACCURACY: 0.8951 | F1 MACRO: 0.9328 | F1 MICRO: 0.9356
# EPOCH 5 | LOSS: 2.5213162899017334 | ACCURACY: 0.9211 | F1 MACRO: 0.9505 | F1 MICRO: 0.9517
# EPOCH 6 | LOSS: 2.3630194664001465 | ACCURACY: 0.933 | F1 MACRO: 0.9558 | F1 MICRO: 0.9582
# EPOCH 7 | LOSS: 2.1865439414978027 | ACCURACY: 0.9308 | F1 MACRO: 0.9531 | F1 MICRO: 0.9567
# EPOCH 8 | LOSS: 2.078066110610962 | ACCURACY: 0.9397 | F1 MACRO: 0.9601 | F1 MICRO: 0.9622
# EPOCH 9 | LOSS: 2.0417890548706055 | ACCURACY: 0.9375 | F1 MACRO: 0.9584 | F1 MICRO: 0.9609
# EPOCH 10 | LOSS: 1.9547584056854248 | ACCURACY: 0.9345 | F1 MACRO: 0.9564 | F1 MICRO: 0.9591
# aspect: ACCURACY 0.9397 | F1 MACRO 0.9601 | F1 MICRO 0.9622
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.92      0.98      0.95       175
#       others       0.90      0.91      0.91       158
#         part       0.95      0.95      0.95       158
#        price       0.98      0.98      0.98       192
#      service       0.97      0.99      0.98       191
#
#    micro avg       0.95      0.97      0.96      1061
#    macro avg       0.95      0.97      0.96      1061
# weighted avg       0.95      0.97      0.96      1061
#  samples avg       0.95      0.97      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 9.035665512084961 | ACCURACY: 0.8876 | F1 MACRO: 0.87 | F1 MICRO: 0.8876
# EPOCH 2 | LOSS: 7.241815567016602 | ACCURACY: 0.907 | F1 MACRO: 0.8881 | F1 MICRO: 0.907
# EPOCH 3 | LOSS: 6.306613922119141 | ACCURACY: 0.9109 | F1 MACRO: 0.894 | F1 MICRO: 0.9109
# EPOCH 4 | LOSS: 5.764817714691162 | ACCURACY: 0.9264 | F1 MACRO: 0.9159 | F1 MICRO: 0.9264
# EPOCH 5 | LOSS: 5.731825351715088 | ACCURACY: 0.9302 | F1 MACRO: 0.9201 | F1 MICRO: 0.9302
# EPOCH 6 | LOSS: 5.383376598358154 | ACCURACY: 0.8953 | F1 MACRO: 0.8826 | F1 MICRO: 0.8953
# EPOCH 7 | LOSS: 5.183505058288574 | ACCURACY: 0.9302 | F1 MACRO: 0.9179 | F1 MICRO: 0.9302
# EPOCH 8 | LOSS: 5.046207904815674 | ACCURACY: 0.9147 | F1 MACRO: 0.9035 | F1 MICRO: 0.9147
# EPOCH 9 | LOSS: 4.970378398895264 | ACCURACY: 0.9264 | F1 MACRO: 0.9148 | F1 MICRO: 0.9264
# EPOCH 10 | LOSS: 4.889838695526123 | ACCURACY: 0.9186 | F1 MACRO: 0.9052 | F1 MICRO: 0.9186
# sentiment: ACCURACY 0.9302 | F1 MACRO 0.9179 | F1 MICRO 0.9302
#               precision    recall  f1-score   support
#
#     negative       0.89      0.89      0.89        79
#     positive       0.95      0.95      0.95       179
#
#     accuracy                           0.93       258
#    macro avg       0.92      0.92      0.92       258
# weighted avg       0.93      0.93      0.93       258
#
# --------------------------------------------------
# Iteration 333: Accuracy: 0.9298, F1 Micro: 0.9298, F1 Macro: 0.8642
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.82      0.90        11
#      neutral       0.98      1.00      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.98       216
#    macro avg       0.98      0.91      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.69      0.79        16
#      neutral       0.93      0.97      0.95       167
#     positive       0.73      0.67      0.70        33
#
#     accuracy                           0.90       216
#    macro avg       0.86      0.77      0.81       216
# weighted avg       0.90      0.90      0.90       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.82      0.75      0.78        12
#      neutral       0.93      0.88      0.91       152
#     positive       0.70      0.83      0.76        52
#
#     accuracy                           0.86       216
#    macro avg       0.82      0.82      0.82       216
# weighted avg       0.87      0.86      0.86       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.81      0.74      0.77        23
#      neutral       0.94      0.97      0.96       152
#     positive       0.82      0.76      0.78        41
#
#     accuracy                           0.91       216
#    macro avg       0.86      0.82      0.84       216
# weighted avg       0.90      0.91      0.91       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.77      0.80        13
#      neutral       0.97      0.99      0.98       186
#     positive       0.86      0.71      0.77        17
#
#     accuracy                           0.95       216
#    macro avg       0.89      0.82      0.85       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.86      0.89        14
#      neutral       0.97      0.99      0.98       185
#     positive       1.00      0.82      0.90        17
#
#     accuracy                           0.97       216
#    macro avg       0.97      0.89      0.93       216
# weighted avg       0.97      0.97      0.97       216
#
# Launching training on 2 GPUs.
# 512 512
# Nearest checkpoint: 540
# Threshold: 88475.0078125
# Samples above threshold: 54
# Acquired samples: 54
# Sampling duration: 13.50023627281189 seconds
# New train size: 387
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.398521661758423 | ACCURACY: 0.7991 | F1 MACRO: 0.8853 | F1 MICRO: 0.8868
# EPOCH 2 | LOSS: 2.866631031036377 | ACCURACY: 0.8207 | F1 MACRO: 0.8893 | F1 MICRO: 0.8937
# EPOCH 3 | LOSS: 2.5748183727264404 | ACCURACY: 0.8906 | F1 MACRO: 0.9335 | F1 MICRO: 0.9348
# EPOCH 4 | LOSS: 2.482328414916992 | ACCURACY: 0.9174 | F1 MACRO: 0.9463 | F1 MICRO: 0.9489
# EPOCH 5 | LOSS: 2.3831968307495117 | ACCURACY: 0.9278 | F1 MACRO: 0.953 | F1 MICRO: 0.9552
# EPOCH 6 | LOSS: 2.1824753284454346 | ACCURACY: 0.9368 | F1 MACRO: 0.9583 | F1 MICRO: 0.9606
# EPOCH 7 | LOSS: 2.038886785507202 | ACCURACY: 0.9435 | F1 MACRO: 0.9621 | F1 MICRO: 0.9645
# EPOCH 8 | LOSS: 1.9777079820632935 | ACCURACY: 0.9449 | F1 MACRO: 0.9634 | F1 MICRO: 0.9655
# EPOCH 9 | LOSS: 1.9246042966842651 | ACCURACY: 0.9412 | F1 MACRO: 0.9596 | F1 MICRO: 0.963
# EPOCH 10 | LOSS: 1.860961675643921 | ACCURACY: 0.9435 | F1 MACRO: 0.9602 | F1 MICRO: 0.9642
# aspect: ACCURACY 0.9449 | F1 MACRO 0.9634 | F1 MICRO 0.9655
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.92      0.99      0.95       175
#       others       0.93      0.89      0.91       158
#         part       0.93      0.99      0.96       158
#        price       0.97      0.98      0.98       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.95      0.98      0.97      1061
#    macro avg       0.95      0.97      0.96      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.95      0.98      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 7.524831295013428 | ACCURACY: 0.8456 | F1 MACRO: 0.7987 | F1 MICRO: 0.8456
# EPOCH 2 | LOSS: 5.8615899085998535 | ACCURACY: 0.9459 | F1 MACRO: 0.9375 | F1 MICRO: 0.9459
# EPOCH 3 | LOSS: 5.180661678314209 | ACCURACY: 0.9498 | F1 MACRO: 0.9429 | F1 MICRO: 0.9498
# EPOCH 4 | LOSS: 4.796544551849365 | ACCURACY: 0.9498 | F1 MACRO: 0.9426 | F1 MICRO: 0.9498
# EPOCH 5 | LOSS: 4.4902753829956055 | ACCURACY: 0.9459 | F1 MACRO: 0.9375 | F1 MICRO: 0.9459
# EPOCH 6 | LOSS: 4.255548477172852 | ACCURACY: 0.9112 | F1 MACRO: 0.9018 | F1 MICRO: 0.9112
# EPOCH 7 | LOSS: 4.0357770919799805 | ACCURACY: 0.9266 | F1 MACRO: 0.9125 | F1 MICRO: 0.9266
# EPOCH 8 | LOSS: 4.114116668701172 | ACCURACY: 0.9073 | F1 MACRO: 0.8989 | F1 MICRO: 0.9073
# EPOCH 9 | LOSS: 4.061375141143799 | ACCURACY: 0.9421 | F1 MACRO: 0.9329 | F1 MICRO: 0.9421
# EPOCH 10 | LOSS: 3.843600273132324 | ACCURACY: 0.9151 | F1 MACRO: 0.9068 | F1 MICRO: 0.9151
# sentiment: ACCURACY 0.9498 | F1 MACRO 0.9426 | F1 MICRO 0.9498
#               precision    recall  f1-score   support
#
#     negative       0.92      0.93      0.92        83
#     positive       0.97      0.96      0.96       176
#
#     accuracy                           0.95       259
#    macro avg       0.94      0.94      0.94       259
# weighted avg       0.95      0.95      0.95       259
#
# --------------------------------------------------
# Iteration 387: Accuracy: 0.9444, F1 Micro: 0.9444, F1 Macro: 0.9
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.99      1.00      1.00       181
#     positive       0.96      0.96      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.96      0.97       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.75      0.83        16
#      neutral       0.93      0.98      0.95       167
#     positive       0.85      0.67      0.75        33
#
#     accuracy                           0.92       216
#    macro avg       0.90      0.80      0.84       216
# weighted avg       0.91      0.92      0.91       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.83      0.83        12
#      neutral       0.94      0.89      0.92       152
#     positive       0.73      0.85      0.79        52
#
#     accuracy                           0.88       216
#    macro avg       0.84      0.86      0.85       216
# weighted avg       0.89      0.88      0.88       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.85      1.00      0.92        23
#      neutral       0.94      0.99      0.96       152
#     positive       0.97      0.68      0.80        41
#
#     accuracy                           0.93       216
#    macro avg       0.92      0.89      0.89       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.85      0.85        13
#      neutral       0.98      0.98      0.98       186
#     positive       0.82      0.82      0.82        17
#
#     accuracy                           0.96       216
#    macro avg       0.88      0.88      0.88       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.98      1.00      0.99       185
#     positive       1.00      0.88      0.94        17
#
#     accuracy                           0.99       216
#    macro avg       0.99      0.94      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 465 465
# Nearest checkpoint: 540
# Threshold: 88605.8125
# Samples above threshold: 48
# Acquired samples: 48
# Sampling duration: 14.697139739990234 seconds
# New train size: 435
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.2745211124420166 | ACCURACY: 0.8021 | F1 MACRO: 0.8867 | F1 MICRO: 0.8882
# EPOCH 2 | LOSS: 2.7336721420288086 | ACCURACY: 0.814 | F1 MACRO: 0.8816 | F1 MICRO: 0.8894
# EPOCH 3 | LOSS: 2.5102498531341553 | ACCURACY: 0.8862 | F1 MACRO: 0.928 | F1 MICRO: 0.931
# EPOCH 4 | LOSS: 2.4573276042938232 | ACCURACY: 0.9345 | F1 MACRO: 0.9578 | F1 MICRO: 0.9596
# EPOCH 5 | LOSS: 2.298492431640625 | ACCURACY: 0.9353 | F1 MACRO: 0.9576 | F1 MICRO: 0.9597
# EPOCH 6 | LOSS: 2.0652644634246826 | ACCURACY: 0.942 | F1 MACRO: 0.962 | F1 MICRO: 0.9638
# EPOCH 7 | LOSS: 1.963429570198059 | ACCURACY: 0.9479 | F1 MACRO: 0.965 | F1 MICRO: 0.9672
# EPOCH 8 | LOSS: 1.8375744819641113 | ACCURACY: 0.9568 | F1 MACRO: 0.9712 | F1 MICRO: 0.9728
# EPOCH 9 | LOSS: 1.8058408498764038 | ACCURACY: 0.9539 | F1 MACRO: 0.9694 | F1 MICRO: 0.9711
# EPOCH 10 | LOSS: 1.7933026552200317 | ACCURACY: 0.9494 | F1 MACRO: 0.9665 | F1 MICRO: 0.9683
# aspect: ACCURACY 0.9568 | F1 MACRO 0.9712 | F1 MICRO 0.9728
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.95      0.98      0.96       175
#       others       0.95      0.92      0.94       158
#         part       0.96      0.97      0.96       158
#        price       0.98      0.99      0.99       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.97      0.98      0.97      1061
#    macro avg       0.97      0.98      0.97      1061
# weighted avg       0.97      0.98      0.97      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.671506404876709 | ACCURACY: 0.8951 | F1 MACRO: 0.8759 | F1 MICRO: 0.8951
# EPOCH 2 | LOSS: 5.263985633850098 | ACCURACY: 0.9213 | F1 MACRO: 0.9085 | F1 MICRO: 0.9213
# EPOCH 3 | LOSS: 4.774919033050537 | ACCURACY: 0.9513 | F1 MACRO: 0.9444 | F1 MICRO: 0.9513
# EPOCH 4 | LOSS: 4.364747047424316 | ACCURACY: 0.9251 | F1 MACRO: 0.9152 | F1 MICRO: 0.9251
# EPOCH 5 | LOSS: 4.1135077476501465 | ACCURACY: 0.9213 | F1 MACRO: 0.9066 | F1 MICRO: 0.9213
# EPOCH 6 | LOSS: 4.057218074798584 | ACCURACY: 0.9064 | F1 MACRO: 0.8918 | F1 MICRO: 0.9064
# EPOCH 7 | LOSS: 4.019267559051514 | ACCURACY: 0.9326 | F1 MACRO: 0.925 | F1 MICRO: 0.9326
# EPOCH 8 | LOSS: 3.837376832962036 | ACCURACY: 0.9326 | F1 MACRO: 0.9208 | F1 MICRO: 0.9326
# EPOCH 9 | LOSS: 3.730463743209839 | ACCURACY: 0.9363 | F1 MACRO: 0.9282 | F1 MICRO: 0.9363
# EPOCH 10 | LOSS: 3.7639758586883545 | ACCURACY: 0.9026 | F1 MACRO: 0.8922 | F1 MICRO: 0.9026
# sentiment: ACCURACY 0.9513 | F1 MACRO 0.9444 | F1 MICRO 0.9513
#               precision    recall  f1-score   support
#
#     negative       0.90      0.95      0.92        84
#     positive       0.98      0.95      0.96       183
#
#     accuracy                           0.95       267
#    macro avg       0.94      0.95      0.94       267
# weighted avg       0.95      0.95      0.95       267
#
# --------------------------------------------------
# Iteration 435: Accuracy: 0.9529, F1 Micro: 0.9529, F1 Macro: 0.9156
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.82      0.90        11
#      neutral       0.99      1.00      0.99       181
#     positive       0.96      0.96      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.93      0.95       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.82      0.88      0.85        16
#      neutral       0.96      0.96      0.96       167
#     positive       0.84      0.82      0.83        33
#
#     accuracy                           0.94       216
#    macro avg       0.88      0.89      0.88       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        12
#      neutral       0.94      0.93      0.93       152
#     positive       0.80      0.83      0.81        52
#
#     accuracy                           0.91       216
#    macro avg       0.91      0.92      0.92       216
# weighted avg       0.91      0.91      0.91       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.82      1.00      0.90        23
#      neutral       0.97      0.97      0.97       152
#     positive       0.94      0.83      0.88        41
#
#     accuracy                           0.94       216
#    macro avg       0.91      0.93      0.92       216
# weighted avg       0.95      0.94      0.94       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.77      0.80        13
#      neutral       0.98      0.99      0.98       186
#     positive       0.88      0.82      0.85        17
#
#     accuracy                           0.96       216
#    macro avg       0.90      0.86      0.88       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.98      1.00      0.99       185
#     positive       1.00      0.82      0.90        17
#
#     accuracy                           0.98       216
#    macro avg       0.99      0.92      0.95       216
# weighted avg       0.98      0.98      0.98       216
#
# Launching training on 2 GPUs.
# 421 421
# Nearest checkpoint: 540
# Threshold: 88516.9375
# Samples above threshold: 43
# Acquired samples: 43
# Sampling duration: 15.416505813598633 seconds
# New train size: 478
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.2287261486053467 | ACCURACY: 0.7969 | F1 MACRO: 0.8839 | F1 MICRO: 0.8856
# EPOCH 2 | LOSS: 2.6276371479034424 | ACCURACY: 0.8423 | F1 MACRO: 0.9051 | F1 MICRO: 0.9069
# EPOCH 3 | LOSS: 2.530242443084717 | ACCURACY: 0.9085 | F1 MACRO: 0.9414 | F1 MICRO: 0.9438
# EPOCH 4 | LOSS: 2.436837911605835 | ACCURACY: 0.9293 | F1 MACRO: 0.9544 | F1 MICRO: 0.9562
# EPOCH 5 | LOSS: 2.222846031188965 | ACCURACY: 0.9397 | F1 MACRO: 0.9601 | F1 MICRO: 0.9623
# EPOCH 6 | LOSS: 2.0115623474121094 | ACCURACY: 0.9457 | F1 MACRO: 0.9643 | F1 MICRO: 0.9661
# EPOCH 7 | LOSS: 1.9209305047988892 | ACCURACY: 0.9516 | F1 MACRO: 0.9677 | F1 MICRO: 0.9696
# EPOCH 8 | LOSS: 1.8484586477279663 | ACCURACY: 0.9561 | F1 MACRO: 0.9707 | F1 MICRO: 0.9725
# EPOCH 9 | LOSS: 1.7945843935012817 | ACCURACY: 0.9561 | F1 MACRO: 0.9715 | F1 MICRO: 0.9726
# EPOCH 10 | LOSS: 1.734170913696289 | ACCURACY: 0.9561 | F1 MACRO: 0.9716 | F1 MICRO: 0.9726
# aspect: ACCURACY 0.9561 | F1 MACRO 0.9716 | F1 MICRO 0.9726
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.94      0.97      0.96       175
#       others       0.89      0.97      0.93       158
#         part       0.96      0.99      0.97       158
#        price       0.97      0.99      0.98       192
#      service       0.99      0.99      0.99       191
#
#    micro avg       0.96      0.99      0.97      1061
#    macro avg       0.96      0.99      0.97      1061
# weighted avg       0.96      0.99      0.97      1061
#  samples avg       0.96      0.99      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.316610813140869 | ACCURACY: 0.8566 | F1 MACRO: 0.8191 | F1 MICRO: 0.8566
# EPOCH 2 | LOSS: 4.984241008758545 | ACCURACY: 0.9385 | F1 MACRO: 0.9321 | F1 MICRO: 0.9385
# EPOCH 3 | LOSS: 4.34663200378418 | ACCURACY: 0.9303 | F1 MACRO: 0.9235 | F1 MICRO: 0.9303
# EPOCH 4 | LOSS: 4.033482551574707 | ACCURACY: 0.9467 | F1 MACRO: 0.9381 | F1 MICRO: 0.9467
# EPOCH 5 | LOSS: 3.7171456813812256 | ACCURACY: 0.9385 | F1 MACRO: 0.9296 | F1 MICRO: 0.9385
# EPOCH 6 | LOSS: 3.606079339981079 | ACCURACY: 0.9139 | F1 MACRO: 0.9069 | F1 MICRO: 0.9139
# EPOCH 7 | LOSS: 3.5429847240448 | ACCURACY: 0.9426 | F1 MACRO: 0.934 | F1 MICRO: 0.9426
# EPOCH 8 | LOSS: 3.4110770225524902 | ACCURACY: 0.9426 | F1 MACRO: 0.934 | F1 MICRO: 0.9426
# EPOCH 9 | LOSS: 3.346759796142578 | ACCURACY: 0.9426 | F1 MACRO: 0.9368 | F1 MICRO: 0.9426
# EPOCH 10 | LOSS: 3.417447805404663 | ACCURACY: 0.9467 | F1 MACRO: 0.9397 | F1 MICRO: 0.9467
# sentiment: ACCURACY 0.9467 | F1 MACRO 0.9397 | F1 MICRO 0.9467
#               precision    recall  f1-score   support
#
#     negative       0.91      0.93      0.92        80
#     positive       0.96      0.96      0.96       164
#
#     accuracy                           0.95       244
#    macro avg       0.94      0.94      0.94       244
# weighted avg       0.95      0.95      0.95       244
#
# --------------------------------------------------
# Iteration 478: Accuracy: 0.9529, F1 Micro: 0.9529, F1 Macro: 0.9034
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.82      0.90        11
#      neutral       0.99      1.00      0.99       181
#     positive       0.96      0.96      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.93      0.95       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.75      0.83        16
#      neutral       0.94      0.97      0.96       167
#     positive       0.77      0.73      0.75        33
#
#     accuracy                           0.92       216
#    macro avg       0.88      0.82      0.84       216
# weighted avg       0.91      0.92      0.91       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.82      0.75      0.78        12
#      neutral       0.90      0.98      0.94       152
#     positive       0.93      0.71      0.80        52
#
#     accuracy                           0.90       216
#    macro avg       0.88      0.81      0.84       216
# weighted avg       0.90      0.90      0.90       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.92      1.00      0.96        23
#      neutral       0.96      0.99      0.97       152
#     positive       0.97      0.83      0.89        41
#
#     accuracy                           0.96       216
#    macro avg       0.95      0.94      0.94       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.90      0.69      0.78        13
#      neutral       0.98      0.99      0.99       186
#     positive       0.82      0.82      0.82        17
#
#     accuracy                           0.96       216
#    macro avg       0.90      0.84      0.86       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.99      1.00      0.99       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.96      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 376 376
# Nearest checkpoint: 540
# Threshold: 88632.09375
# Samples above threshold: 39
# Acquired samples: 39
# Sampling duration: 15.928163290023804 seconds
# New train size: 517
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.289039373397827 | ACCURACY: 0.7984 | F1 MACRO: 0.885 | F1 MICRO: 0.8866
# EPOCH 2 | LOSS: 2.6968774795532227 | ACCURACY: 0.8705 | F1 MACRO: 0.9225 | F1 MICRO: 0.9233
# EPOCH 3 | LOSS: 2.491102695465088 | ACCURACY: 0.9234 | F1 MACRO: 0.9496 | F1 MICRO: 0.9522
# EPOCH 4 | LOSS: 2.3749990463256836 | ACCURACY: 0.9301 | F1 MACRO: 0.9514 | F1 MICRO: 0.9558
# EPOCH 5 | LOSS: 2.1227662563323975 | ACCURACY: 0.9442 | F1 MACRO: 0.9635 | F1 MICRO: 0.9651
# EPOCH 6 | LOSS: 2.0035629272460938 | ACCURACY: 0.9539 | F1 MACRO: 0.9702 | F1 MICRO: 0.9713
# EPOCH 7 | LOSS: 1.8853033781051636 | ACCURACY: 0.9576 | F1 MACRO: 0.972 | F1 MICRO: 0.9735
# EPOCH 8 | LOSS: 1.8428959846496582 | ACCURACY: 0.9546 | F1 MACRO: 0.9701 | F1 MICRO: 0.9715
# EPOCH 9 | LOSS: 1.8033013343811035 | ACCURACY: 0.9531 | F1 MACRO: 0.9689 | F1 MICRO: 0.9706
# EPOCH 10 | LOSS: 1.7121968269348145 | ACCURACY: 0.9598 | F1 MACRO: 0.9736 | F1 MICRO: 0.9749
# aspect: ACCURACY 0.9598 | F1 MACRO 0.9736 | F1 MICRO 0.9749
#               precision    recall  f1-score   support
#
# ...
#
#    micro avg       0.97      0.98      0.98      1061
#    macro avg       0.97      0.98      0.97      1061
# weighted avg       0.97      0.98      0.98      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.699479579925537 | ACCURACY: 0.9111 | F1 MACRO: 0.9005 | F1 MICRO: 0.9111
# EPOCH 2 | LOSS: 2.7775516510009766 | ACCURACY: 0.9333 | F1 MACRO: 0.9241 | F1 MICRO: 0.9333
# EPOCH 3 | LOSS: 2.524646043777466 | ACCURACY: 0.9333 | F1 MACRO: 0.9206 | F1 MICRO: 0.9333
# EPOCH 4 | LOSS: 2.3417251110076904 | ACCURACY: 0.9407 | F1 MACRO: 0.9333 | F1 MICRO: 0.9407
# EPOCH 5 | LOSS: 2.1958768367767334 | ACCURACY: 0.9407 | F1 MACRO: 0.933 | F1 MICRO: 0.9407
# EPOCH 6 | LOSS: 2.1390419006347656 | ACCURACY: 0.9259 | F1 MACRO: 0.9167 | F1 MICRO: 0.9259
# EPOCH 7 | LOSS: 2.0681445598602295 | ACCURACY: 0.937 | F1 MACRO: 0.929 | F1 MICRO: 0.937
# EPOCH 8 | LOSS: 2.030243396759033 | ACCURACY: 0.9407 | F1 MACRO: 0.933 | F1 MICRO: 0.9407
# EPOCH 9 | LOSS: 2.001405715942383 | ACCURACY: 0.9407 | F1 MACRO: 0.9304 | F1 MICRO: 0.9407
# EPOCH 10 | LOSS: 2.023106336593628 | ACCURACY: 0.9185 | F1 MACRO: 0.9093 | F1 MICRO: 0.9185
# sentiment: ACCURACY 0.9407 | F1 MACRO 0.9304 | F1 MICRO 0.9407
#               precision    recall  f1-score   support
#
#     negative       0.91      0.89      0.90        84
#     positive       0.95      0.96      0.96       186
#
#     accuracy                           0.94       270
#    macro avg       0.93      0.93      0.93       270
# weighted avg       0.94      0.94      0.94       270
#
# --------------------------------------------------
# Iteration 831: Accuracy: 0.9506, F1 Micro: 0.9506, F1 Macro: 0.8974
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.82      0.90        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.88      0.96      0.92        24
#
#     accuracy                           0.98       216
#    macro avg       0.96      0.92      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.90      0.56      0.69        16
#      neutral       0.97      0.97      0.97       167
#     positive       0.74      0.88      0.81        33
#
#     accuracy                           0.93       216
#    macro avg       0.87      0.80      0.82       216
# weighted avg       0.93      0.93      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.83      0.83        12
#      neutral       0.93      0.93      0.93       152
#     positive       0.79      0.81      0.80        52
#
#     accuracy                           0.89       216
#    macro avg       0.85      0.86      0.85       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.81      0.91      0.86        23
#      neutral       0.97      0.98      0.97       152
#     positive       0.89      0.78      0.83        41
#
#     accuracy                           0.94       216
#    macro avg       0.89      0.89      0.89       216
# weighted avg       0.94      0.94      0.93       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.85      0.85        13
#      neutral       0.98      0.99      0.99       186
#     positive       0.93      0.82      0.87        17
#
#     accuracy                           0.97       216
#    macro avg       0.92      0.89      0.90       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       1.00      1.00      1.00       185
#     positive       0.94      1.00      0.97        17
#
#     accuracy                           1.00       216
#    macro avg       0.98      0.98      0.98       216
# weighted avg       1.00      1.00      1.00       216
#
# Launching training on 2 GPUs.
# 33 33
# Nearest checkpoint: 864
# Threshold: 88293.984375
# Samples above threshold: 4
# Acquired samples: 25
# Sampling duration: 21.52934193611145 seconds
# New train size: 856
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.9803953170776367 | ACCURACY: 0.8341 | F1 MACRO: 0.9015 | F1 MICRO: 0.9033
# EPOCH 2 | LOSS: 2.437547206878662 | ACCURACY: 0.936 | F1 MACRO: 0.9585 | F1 MICRO: 0.96
# EPOCH 3 | LOSS: 2.211056709289551 | ACCURACY: 0.9539 | F1 MACRO: 0.9699 | F1 MICRO: 0.9713
# EPOCH 4 | LOSS: 1.973510980606079 | ACCURACY: 0.9591 | F1 MACRO: 0.9727 | F1 MICRO: 0.9743
# EPOCH 5 | LOSS: 1.8551266193389893 | ACCURACY: 0.9598 | F1 MACRO: 0.9726 | F1 MICRO: 0.9746
# EPOCH 6 | LOSS: 1.7661124467849731 | ACCURACY: 0.9621 | F1 MACRO: 0.9746 | F1 MICRO: 0.9761
# EPOCH 7 | LOSS: 1.6893430948257446 | ACCURACY: 0.9561 | F1 MACRO: 0.9707 | F1 MICRO: 0.9724
# EPOCH 8 | LOSS: 1.6490012407302856 | ACCURACY: 0.9546 | F1 MACRO: 0.9691 | F1 MICRO: 0.9713
# EPOCH 9 | LOSS: 1.5727342367172241 | ACCURACY: 0.9606 | F1 MACRO: 0.9731 | F1 MICRO: 0.975
# EPOCH 10 | LOSS: 1.585739254951477 | ACCURACY: 0.9591 | F1 MACRO: 0.9731 | F1 MICRO: 0.9743
# aspect: ACCURACY 0.9621 | F1 MACRO 0.9746 | F1 MICRO 0.9761
#               precision    recall  f1-score   support
#
#         fuel       0.99      0.99      0.99       187
#      machine       0.95      0.98      0.96       175
#       others       0.93      0.94      0.93       158
#         part       0.97      0.97      0.97       158
#        price       0.99      0.99      0.99       192
#      service       0.99      1.00      1.00       191
#
#    micro avg       0.97      0.98      0.98      1061
#    macro avg       0.97      0.98      0.97      1061
# weighted avg       0.97      0.98      0.98      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.721881866455078 | ACCURACY: 0.8731 | F1 MACRO: 0.8371 | F1 MICRO: 0.8731
# EPOCH 2 | LOSS: 2.8059122562408447 | ACCURACY: 0.9515 | F1 MACRO: 0.9435 | F1 MICRO: 0.9515
# EPOCH 3 | LOSS: 2.5096147060394287 | ACCURACY: 0.9328 | F1 MACRO: 0.9209 | F1 MICRO: 0.9328
# EPOCH 4 | LOSS: 2.257091999053955 | ACCURACY: 0.9478 | F1 MACRO: 0.9404 | F1 MICRO: 0.9478
# EPOCH 5 | LOSS: 2.092451810836792 | ACCURACY: 0.9403 | F1 MACRO: 0.9319 | F1 MICRO: 0.9403
# EPOCH 6 | LOSS: 2.090724468231201 | ACCURACY: 0.944 | F1 MACRO: 0.9348 | F1 MICRO: 0.944
# EPOCH 7 | LOSS: 1.9932409524917603 | ACCURACY: 0.9328 | F1 MACRO: 0.9243 | F1 MICRO: 0.9328
# EPOCH 8 | LOSS: 1.979408860206604 | ACCURACY: 0.9104 | F1 MACRO: 0.9002 | F1 MICRO: 0.9104
# EPOCH 9 | LOSS: 1.9759260416030884 | ACCURACY: 0.9254 | F1 MACRO: 0.9121 | F1 MICRO: 0.9254
# EPOCH 10 | LOSS: 1.9156734943389893 | ACCURACY: 0.9142 | F1 MACRO: 0.8986 | F1 MICRO: 0.9142
# sentiment: ACCURACY 0.9515 | F1 MACRO 0.9435 | F1 MICRO 0.9515
#               precision    recall  f1-score   support
#
#     negative       0.92      0.93      0.92        83
#     positive       0.97      0.96      0.96       185
#
#     accuracy                           0.95       268
#    macro avg       0.94      0.94      0.94       268
# weighted avg       0.95      0.95      0.95       268
#
# --------------------------------------------------
# Iteration 856: Accuracy: 0.9545, F1 Micro: 0.9545, F1 Macro: 0.9186
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.96      0.96      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.98      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.81      0.84        16
#      neutral       0.95      0.97      0.96       167
#     positive       0.83      0.76      0.79        33
#
#     accuracy                           0.93       216
#    macro avg       0.88      0.85      0.86       216
# weighted avg       0.92      0.93      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.90      0.75      0.82        12
#      neutral       0.93      0.92      0.92       152
#     positive       0.78      0.83      0.80        52
#
#     accuracy                           0.89       216
#    macro avg       0.87      0.83      0.85       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.96      0.90        23
#      neutral       0.98      0.97      0.98       152
#     positive       0.92      0.88      0.90        41
#
#     accuracy                           0.95       216
#    macro avg       0.92      0.94      0.92       216
# weighted avg       0.96      0.95      0.95       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.85      0.85        13
#      neutral       0.98      0.99      0.99       186
#     positive       0.93      0.82      0.87        17
#
#     accuracy                           0.97       216
#    macro avg       0.92      0.89      0.90       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.99      1.00      1.00       185
#     positive       1.00      1.00      1.00        17
#
#     accuracy                           1.00       216
#    macro avg       1.00      0.98      0.99       216
# weighted avg       1.00      1.00      1.00       216
#
# Launching training on 2 GPUs.
# 8 8
# Nearest checkpoint: 864
# Threshold: 88294.6796875
# Samples above threshold: 1
# Acquired samples: 8
# Sampling duration: 23.766847848892212 seconds
# New train size: 864
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.959395170211792 | ACCURACY: 0.8311 | F1 MACRO: 0.9014 | F1 MICRO: 0.9028
# EPOCH 2 | LOSS: 2.460578441619873 | ACCURACY: 0.9308 | F1 MACRO: 0.9545 | F1 MICRO: 0.9568
# EPOCH 3 | LOSS: 2.221756935119629 | ACCURACY: 0.9561 | F1 MACRO: 0.9715 | F1 MICRO: 0.9727
# EPOCH 4 | LOSS: 1.9600011110305786 | ACCURACY: 0.9583 | F1 MACRO: 0.9722 | F1 MICRO: 0.9738
# EPOCH 5 | LOSS: 1.8518600463867188 | ACCURACY: 0.9591 | F1 MACRO: 0.9725 | F1 MICRO: 0.9741
# EPOCH 6 | LOSS: 1.7566109895706177 | ACCURACY: 0.9583 | F1 MACRO: 0.9718 | F1 MICRO: 0.9737
# EPOCH 7 | LOSS: 1.6952048540115356 | ACCURACY: 0.9576 | F1 MACRO: 0.9716 | F1 MICRO: 0.9733
# EPOCH 8 | LOSS: 1.6420003175735474 | ACCURACY: 0.9576 | F1 MACRO: 0.9708 | F1 MICRO: 0.9731
# EPOCH 9 | LOSS: 1.5988481044769287 | ACCURACY: 0.9539 | F1 MACRO: 0.9685 | F1 MICRO: 0.9708
# EPOCH 10 | LOSS: 1.5628594160079956 | ACCURACY: 0.9621 | F1 MACRO: 0.9751 | F1 MICRO: 0.9762
# aspect: ACCURACY 0.9621 | F1 MACRO 0.9751 | F1 MICRO 0.9762
#               precision    recall  f1-score   support
#
#         fuel       0.98      0.99      0.99       187
#      machine       0.95      0.99      0.97       175
#       others       0.92      0.97      0.94       158
#         part       0.98      0.96      0.97       158
#        price       0.98      0.98      0.98       192
#      service       0.99      1.00      1.00       191
#
#    micro avg       0.97      0.98      0.98      1061
#    macro avg       0.97      0.98      0.98      1061
# weighted avg       0.97      0.98      0.98      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.527407646179199 | ACCURACY: 0.9109 | F1 MACRO: 0.9021 | F1 MICRO: 0.9109
# EPOCH 2 | LOSS: 2.7476625442504883 | ACCURACY: 0.8953 | F1 MACRO: 0.8883 | F1 MICRO: 0.8953
# EPOCH 3 | LOSS: 2.400134563446045 | ACCURACY: 0.9302 | F1 MACRO: 0.922 | F1 MICRO: 0.9302
# EPOCH 4 | LOSS: 2.202571392059326 | ACCURACY: 0.9225 | F1 MACRO: 0.9123 | F1 MICRO: 0.9225
# EPOCH 5 | LOSS: 2.132927894592285 | ACCURACY: 0.9341 | F1 MACRO: 0.9261 | F1 MICRO: 0.9341
# EPOCH 6 | LOSS: 2.061800003051758 | ACCURACY: 0.9496 | F1 MACRO: 0.9428 | F1 MICRO: 0.9496
# EPOCH 7 | LOSS: 2.0568947792053223 | ACCURACY: 0.9302 | F1 MACRO: 0.9196 | F1 MICRO: 0.9302
# EPOCH 8 | LOSS: 1.992138385772705 | ACCURACY: 0.938 | F1 MACRO: 0.9324 | F1 MICRO: 0.938
# EPOCH 9 | LOSS: 1.9735304117202759 | ACCURACY: 0.9419 | F1 MACRO: 0.9351 | F1 MICRO: 0.9419
# EPOCH 10 | LOSS: 1.956946611404419 | ACCURACY: 0.9264 | F1 MACRO: 0.9199 | F1 MICRO: 0.9264
# sentiment: ACCURACY 0.9496 | F1 MACRO 0.9428 | F1 MICRO 0.9496
#               precision    recall  f1-score   support
#
#     negative       0.93      0.92      0.92        85
#     positive       0.96      0.97      0.96       173
#
#     accuracy                           0.95       258
#    macro avg       0.94      0.94      0.94       258
# weighted avg       0.95      0.95      0.95       258
#
# --------------------------------------------------
# Iteration 864: Accuracy: 0.9622, F1 Micro: 0.9622, F1 Macro: 0.9249
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.92      0.96      0.94        24
#
#     accuracy                           0.99       216
#    macro avg       0.97      0.95      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.75      0.80        16
#      neutral       0.95      0.98      0.96       167
#     positive       0.86      0.76      0.81        33
#
#     accuracy                           0.93       216
#    macro avg       0.89      0.83      0.86       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.83      0.87        12
#      neutral       0.94      0.97      0.95       152
#     positive       0.91      0.83      0.87        52
#
#     accuracy                           0.93       216
#    macro avg       0.92      0.88      0.90       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.88      0.96      0.92        23
#      neutral       0.97      0.98      0.98       152
#     positive       0.92      0.85      0.89        41
#
#     accuracy                           0.95       216
#    macro avg       0.92      0.93      0.93       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.85      0.88        13
#      neutral       0.98      0.99      0.99       186
#     positive       0.88      0.82      0.85        17
#
#     accuracy                           0.97       216
#    macro avg       0.93      0.89      0.91       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        14
#      neutral       1.00      1.00      1.00       185
#     positive       1.00      1.00      1.00        17
#
#     accuracy                           1.00       216
#    macro avg       1.00      1.00      1.00       216
# weighted avg       1.00      1.00      1.00       216
#
# Total sampling time: 410.48 seconds
# Total runtime: 3467.089498758316 seconds

# %% [markdown]
# ## RUN 4

# %%
active_learning(seeds[3], 3)
# Out:
# ===============================================
# TRIAL 4
# Random seed: 3
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.5983240604400635 | ACCURACY: 0.7671 | F1 MACRO: 0.8506 | F1 MICRO: 0.8622
# EPOCH 2 | LOSS: 3.323089599609375 | ACCURACY: 0.779 | F1 MACRO: 0.873 | F1 MICRO: 0.8751
# EPOCH 3 | LOSS: 3.3482136726379395 | ACCURACY: 0.7805 | F1 MACRO: 0.8737 | F1 MICRO: 0.8758
# EPOCH 4 | LOSS: 3.22114634513855 | ACCURACY: 0.7842 | F1 MACRO: 0.8743 | F1 MICRO: 0.8767
# EPOCH 5 | LOSS: 3.2356982231140137 | ACCURACY: 0.779 | F1 MACRO: 0.8708 | F1 MICRO: 0.8736
# EPOCH 6 | LOSS: 2.9298696517944336 | ACCURACY: 0.7835 | F1 MACRO: 0.872 | F1 MICRO: 0.8752
# EPOCH 7 | LOSS: 2.8540592193603516 | ACCURACY: 0.7887 | F1 MACRO: 0.8732 | F1 MICRO: 0.8768
# EPOCH 8 | LOSS: 2.7723355293273926 | ACCURACY: 0.7954 | F1 MACRO: 0.8766 | F1 MICRO: 0.8801
# EPOCH 9 | LOSS: 2.754518985748291 | ACCURACY: 0.7932 | F1 MACRO: 0.8757 | F1 MICRO: 0.879
# EPOCH 10 | LOSS: 2.6405434608459473 | ACCURACY: 0.7984 | F1 MACRO: 0.8788 | F1 MICRO: 0.8817
# aspect: ACCURACY 0.7984 | F1 MACRO 0.8788 | F1 MICRO 0.8817
#               precision    recall  f1-score   support
#
#         fuel       0.84      0.98      0.90       187
#      machine       0.81      0.83      0.82       175
#       others       0.78      0.92      0.85       158
#         part       0.77      0.97      0.86       158
#        price       0.86      1.00      0.92       192
#      service       0.85      1.00      0.92       191
#
#    micro avg       0.82      0.95      0.88      1061
#    macro avg       0.82      0.95      0.88      1061
# weighted avg       0.82      0.95      0.88      1061
#  samples avg       0.82      0.95      0.88      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 20.173891067504883 | ACCURACY: 0.8151 | F1 MACRO: 0.4491 | F1 MICRO: 0.8151
# EPOCH 2 | LOSS: 16.506135940551758 | ACCURACY: 0.8151 | F1 MACRO: 0.4491 | F1 MICRO: 0.8151
# EPOCH 3 | LOSS: 14.638459205627441 | ACCURACY: 0.8403 | F1 MACRO: 0.627 | F1 MICRO: 0.8403
# EPOCH 4 | LOSS: 14.243339538574219 | ACCURACY: 0.8739 | F1 MACRO: 0.8073 | F1 MICRO: 0.8739
# EPOCH 5 | LOSS: 13.640288352966309 | ACCURACY: 0.8571 | F1 MACRO: 0.6847 | F1 MICRO: 0.8571
# EPOCH 6 | LOSS: 12.324337005615234 | ACCURACY: 0.8403 | F1 MACRO: 0.6658 | F1 MICRO: 0.8403
# EPOCH 7 | LOSS: 11.676736831665039 | ACCURACY: 0.8403 | F1 MACRO: 0.6658 | F1 MICRO: 0.8403
# EPOCH 8 | LOSS: 10.873038291931152 | ACCURACY: 0.8655 | F1 MACRO: 0.7255 | F1 MICRO: 0.8655
# EPOCH 9 | LOSS: 10.567813873291016 | ACCURACY: 0.8571 | F1 MACRO: 0.701 | F1 MICRO: 0.8571
# EPOCH 10 | LOSS: 10.329504013061523 | ACCURACY: 0.8571 | F1 MACRO: 0.6847 | F1 MICRO: 0.8571
# sentiment: ACCURACY 0.8739 | F1 MACRO 0.8073 | F1 MICRO 0.8739
#               precision    recall  f1-score   support
#
#     negative       0.63      0.77      0.69        22
#     positive       0.95      0.90      0.92        97
#
#     accuracy                           0.87       119
#    macro avg       0.79      0.83      0.81       119
# weighted avg       0.89      0.87      0.88       119
#
# --------------------------------------------------
# Iteration 54: Accuracy: 0.7924, F1 Micro: 0.7924, F1 Macro: 0.4388
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        11
#      neutral       0.84      0.97      0.90       181
#     positive       0.29      0.08      0.13        24
#
#     accuracy                           0.82       216
#    macro avg       0.38      0.35      0.34       216
# weighted avg       0.74      0.82      0.77       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.50      0.44      0.47        16
#      neutral       0.80      0.78      0.79       167
#     positive       0.15      0.18      0.17        33
#
#     accuracy                           0.66       216
#    macro avg       0.48      0.47      0.47       216
# weighted avg       0.68      0.66      0.67       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.71      0.42      0.53        12
#      neutral       0.79      0.96      0.87       152
#     positive       0.75      0.35      0.47        52
#
#     accuracy                           0.78       216
#    macro avg       0.75      0.57      0.62       216
# weighted avg       0.78      0.78      0.75       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.26      0.39        23
#      neutral       0.77      0.95      0.85       152
#     positive       0.75      0.37      0.49        41
#
#     accuracy                           0.77       216
#    macro avg       0.76      0.53      0.58       216
# weighted avg       0.76      0.77      0.73       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        13
#      neutral       0.86      1.00      0.93       186
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.86       216
#    macro avg       0.29      0.33      0.31       216
# weighted avg       0.74      0.86      0.80       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        14
#      neutral       0.86      1.00      0.92       185
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.86       216
#    macro avg       0.29      0.33      0.31       216
# weighted avg       0.73      0.86      0.79       216
#
# Launching training on 2 GPUs.
# 339 339
# Nearest checkpoint: 540
# Threshold: 87488.9765625
# Samples above threshold: 81
# Acquired samples: 81
# Sampling duration: 6.243406057357788 seconds
# New train size: 135
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.783291816711426 | ACCURACY: 0.7954 | F1 MACRO: 0.8837 | F1 MICRO: 0.8852
# EPOCH 2 | LOSS: 3.504960298538208 | ACCURACY: 0.7984 | F1 MACRO: 0.884 | F1 MICRO: 0.8859
# EPOCH 3 | LOSS: 3.2804183959960938 | ACCURACY: 0.8043 | F1 MACRO: 0.8865 | F1 MICRO: 0.8885
# EPOCH 4 | LOSS: 2.8977606296539307 | ACCURACY: 0.8051 | F1 MACRO: 0.8864 | F1 MICRO: 0.8886
# EPOCH 5 | LOSS: 2.78747820854187 | ACCURACY: 0.8162 | F1 MACRO: 0.893 | F1 MICRO: 0.8947
# EPOCH 6 | LOSS: 2.732089042663574 | ACCURACY: 0.8304 | F1 MACRO: 0.8994 | F1 MICRO: 0.9012
# EPOCH 7 | LOSS: 2.688485860824585 | ACCURACY: 0.8378 | F1 MACRO: 0.9017 | F1 MICRO: 0.9042
# EPOCH 8 | LOSS: 2.7435553073883057 | ACCURACY: 0.8631 | F1 MACRO: 0.9158 | F1 MICRO: 0.9182
# EPOCH 9 | LOSS: 2.676260471343994 | ACCURACY: 0.881 | F1 MACRO: 0.9253 | F1 MICRO: 0.928
# EPOCH 10 | LOSS: 2.630406618118286 | ACCURACY: 0.8876 | F1 MACRO: 0.9279 | F1 MICRO: 0.9311
# aspect: ACCURACY 0.8876 | F1 MACRO 0.9279 | F1 MICRO 0.9311
#               precision    recall  f1-score   support
#
#         fuel       0.89      0.99      0.94       187
#      machine       0.85      0.99      0.92       175
#       others       0.92      0.82      0.87       158
#         part       0.86      0.96      0.90       158
#        price       0.96      0.98      0.97       192
#      service       0.93      1.00      0.96       191
#
#    micro avg       0.90      0.96      0.93      1061
#    macro avg       0.90      0.96      0.93      1061
# weighted avg       0.90      0.96      0.93      1061
#  samples avg       0.91      0.96      0.93      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 17.57423973083496 | ACCURACY: 0.872 | F1 MACRO: 0.8386 | F1 MICRO: 0.872
# EPOCH 2 | LOSS: 13.010506629943848 | ACCURACY: 0.9289 | F1 MACRO: 0.9183 | F1 MICRO: 0.9289
# EPOCH 3 | LOSS: 11.813488960266113 | ACCURACY: 0.9336 | F1 MACRO: 0.9208 | F1 MICRO: 0.9336
# EPOCH 4 | LOSS: 11.099642753601074 | ACCURACY: 0.9242 | F1 MACRO: 0.9103 | F1 MICRO: 0.9242
# EPOCH 5 | LOSS: 10.739668846130371 | ACCURACY: 0.9384 | F1 MACRO: 0.9274 | F1 MICRO: 0.9384
# EPOCH 6 | LOSS: 10.33448600769043 | ACCURACY: 0.9431 | F1 MACRO: 0.9333 | F1 MICRO: 0.9431
# EPOCH 7 | LOSS: 10.086959838867188 | ACCURACY: 0.9147 | F1 MACRO: 0.9024 | F1 MICRO: 0.9147
# EPOCH 8 | LOSS: 9.628758430480957 | ACCURACY: 0.9289 | F1 MACRO: 0.9131 | F1 MICRO: 0.9289
# EPOCH 9 | LOSS: 9.399983406066895 | ACCURACY: 0.9147 | F1 MACRO: 0.9008 | F1 MICRO: 0.9147
# EPOCH 10 | LOSS: 9.606103897094727 | ACCURACY: 0.9289 | F1 MACRO: 0.9189 | F1 MICRO: 0.9289
# sentiment: ACCURACY 0.9431 | F1 MACRO 0.9333 | F1 MICRO 0.9431
#               precision    recall  f1-score   support
#
#     negative       0.87      0.95      0.91        62
#     positive       0.98      0.94      0.96       149
#
#     accuracy                           0.94       211
#    macro avg       0.92      0.95      0.93       211
# weighted avg       0.95      0.94      0.94       211
#
# --------------------------------------------------
# Iteration 135: Accuracy: 0.8997, F1 Micro: 0.8997, F1 Macro: 0.7897
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.36      0.53        11
#      neutral       0.91      1.00      0.95       181
#     positive       1.00      0.54      0.70        24
#
#     accuracy                           0.92       216
#    macro avg       0.97      0.64      0.73       216
# weighted avg       0.92      0.92      0.90       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.62      0.77        16
#      neutral       0.87      0.99      0.93       167
#     positive       0.87      0.39      0.54        33
#
#     accuracy                           0.88       216
#    macro avg       0.91      0.67      0.75       216
# weighted avg       0.88      0.88      0.86       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.67      0.83      0.74        12
#      neutral       0.92      0.88      0.90       152
#     positive       0.71      0.77      0.74        52
#
#     accuracy                           0.85       216
#    macro avg       0.77      0.83      0.79       216
# weighted avg       0.85      0.85      0.85       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.78      0.82        23
#      neutral       0.88      0.95      0.91       152
#     positive       0.81      0.63      0.71        41
#
#     accuracy                           0.87       216
#    macro avg       0.85      0.79      0.81       216
# weighted avg       0.87      0.87      0.87       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.82      0.69      0.75        13
#      neutral       0.96      0.98      0.97       186
#     positive       0.80      0.71      0.75        17
#
#     accuracy                           0.94       216
#    macro avg       0.86      0.79      0.82       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.64      0.78        14
#      neutral       0.94      1.00      0.97       185
#     positive       1.00      0.59      0.74        17
#
#     accuracy                           0.94       216
#    macro avg       0.98      0.74      0.83       216
# weighted avg       0.95      0.94      0.94       216
#
# Launching training on 2 GPUs.
# 600 600
# Nearest checkpoint: 540
# Threshold: 88051.6015625
# Samples above threshold: 73
# Acquired samples: 73
# Sampling duration: 9.887439250946045 seconds
# New train size: 208
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.631113052368164 | ACCURACY: 0.7909 | F1 MACRO: 0.8816 | F1 MICRO: 0.8831
# EPOCH 2 | LOSS: 3.19872784614563 | ACCURACY: 0.8095 | F1 MACRO: 0.8889 | F1 MICRO: 0.8909
# EPOCH 3 | LOSS: 2.843287944793701 | ACCURACY: 0.8125 | F1 MACRO: 0.8904 | F1 MICRO: 0.8919
# EPOCH 4 | LOSS: 2.593050718307495 | ACCURACY: 0.8378 | F1 MACRO: 0.9046 | F1 MICRO: 0.9057
# EPOCH 5 | LOSS: 2.5723114013671875 | ACCURACY: 0.8467 | F1 MACRO: 0.9084 | F1 MICRO: 0.9097
# EPOCH 6 | LOSS: 2.579268217086792 | ACCURACY: 0.881 | F1 MACRO: 0.9262 | F1 MICRO: 0.9282
# EPOCH 7 | LOSS: 2.5018444061279297 | ACCURACY: 0.907 | F1 MACRO: 0.9405 | F1 MICRO: 0.9429
# EPOCH 8 | LOSS: 2.3452248573303223 | ACCURACY: 0.9189 | F1 MACRO: 0.9479 | F1 MICRO: 0.9501
# EPOCH 9 | LOSS: 2.3226706981658936 | ACCURACY: 0.9368 | F1 MACRO: 0.9588 | F1 MICRO: 0.9607
# EPOCH 10 | LOSS: 2.2969279289245605 | ACCURACY: 0.9293 | F1 MACRO: 0.9528 | F1 MICRO: 0.9559
# aspect: ACCURACY 0.9368 | F1 MACRO 0.9588 | F1 MICRO 0.9607
#               precision    recall  f1-score   support
#
#         fuel       0.97      1.00      0.98       187
#      machine       0.91      0.99      0.95       175
#       others       0.92      0.92      0.92       158
#         part       0.90      0.96      0.93       158
#        price       0.97      0.99      0.98       192
#      service       0.97      1.00      0.98       191
#
#    micro avg       0.94      0.98      0.96      1061
#    macro avg       0.94      0.98      0.96      1061
# weighted avg       0.94      0.98      0.96      1061
#  samples avg       0.94      0.98      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 13.182219505310059 | ACCURACY: 0.9256 | F1 MACRO: 0.9165 | F1 MICRO: 0.9256
# EPOCH 2 | LOSS: 10.032119750976562 | ACCURACY: 0.9132 | F1 MACRO: 0.8989 | F1 MICRO: 0.9132
# EPOCH 3 | LOSS: 9.303529739379883 | ACCURACY: 0.9215 | F1 MACRO: 0.911 | F1 MICRO: 0.9215
# EPOCH 4 | LOSS: 8.668335914611816 | ACCURACY: 0.9174 | F1 MACRO: 0.9088 | F1 MICRO: 0.9174
# EPOCH 5 | LOSS: 8.018742561340332 | ACCURACY: 0.9298 | F1 MACRO: 0.9204 | F1 MICRO: 0.9298
# EPOCH 6 | LOSS: 8.100123405456543 | ACCURACY: 0.9174 | F1 MACRO: 0.9083 | F1 MICRO: 0.9174
# EPOCH 7 | LOSS: 7.742892742156982 | ACCURACY: 0.9215 | F1 MACRO: 0.9121 | F1 MICRO: 0.9215
# EPOCH 8 | LOSS: 7.414371967315674 | ACCURACY: 0.9132 | F1 MACRO: 0.9017 | F1 MICRO: 0.9132
# EPOCH 9 | LOSS: 7.171367168426514 | ACCURACY: 0.9174 | F1 MACRO: 0.9088 | F1 MICRO: 0.9174
# EPOCH 10 | LOSS: 7.460043430328369 | ACCURACY: 0.8926 | F1 MACRO: 0.877 | F1 MICRO: 0.8926
# sentiment: ACCURACY 0.9298 | F1 MACRO 0.9204 | F1 MICRO 0.9298
#               precision    recall  f1-score   support
#
#     negative       0.87      0.92      0.89        77
#     positive       0.96      0.93      0.95       165
#
#     accuracy                           0.93       242
#    macro avg       0.91      0.93      0.92       242
# weighted avg       0.93      0.93      0.93       242
#
# --------------------------------------------------
# Iteration 208: Accuracy: 0.9306, F1 Micro: 0.9306, F1 Macro: 0.8766
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.98      1.00      0.99       181
#     positive       1.00      0.88      0.93        24
#
#     accuracy                           0.99       216
#    macro avg       0.99      0.96      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.75      0.83        16
#      neutral       0.92      0.99      0.95       167
#     positive       0.86      0.58      0.69        33
#
#     accuracy                           0.91       216
#    macro avg       0.90      0.77      0.82       216
# weighted avg       0.91      0.91      0.90       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.71      0.83      0.77        12
#      neutral       0.92      0.91      0.91       152
#     positive       0.75      0.75      0.75        52
#
#     accuracy                           0.87       216
#    macro avg       0.79      0.83      0.81       216
# weighted avg       0.87      0.87      0.87       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.78      0.77        23
#      neutral       0.89      0.95      0.92       152
#     positive       0.87      0.66      0.75        41
#
#     accuracy                           0.88       216
#    macro avg       0.84      0.80      0.81       216
# weighted avg       0.87      0.88      0.87       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.77      0.83        13
#      neutral       0.98      0.99      0.98       186
#     positive       0.88      0.88      0.88        17
#
#     accuracy                           0.97       216
#    macro avg       0.92      0.88      0.90       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.97      1.00      0.99       185
#     positive       1.00      0.82      0.90        17
#
#     accuracy                           0.98       216
#    macro avg       0.99      0.89      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Launching training on 2 GPUs.
# 612 612
# Nearest checkpoint: 540
# Threshold: 88388.3515625
# Samples above threshold: 66
# Acquired samples: 66
# Sampling duration: 10.817781448364258 seconds
# New train size: 274
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.3185293674468994 | ACCURACY: 0.7924 | F1 MACRO: 0.8822 | F1 MICRO: 0.8837
# EPOCH 2 | LOSS: 2.8143954277038574 | ACCURACY: 0.808 | F1 MACRO: 0.8875 | F1 MICRO: 0.8896
# EPOCH 3 | LOSS: 2.484513998031616 | ACCURACY: 0.8281 | F1 MACRO: 0.8998 | F1 MICRO: 0.9012
# EPOCH 4 | LOSS: 2.3544068336486816 | ACCURACY: 0.8527 | F1 MACRO: 0.9119 | F1 MICRO: 0.9129
# EPOCH 5 | LOSS: 2.4004828929901123 | ACCURACY: 0.9018 | F1 MACRO: 0.9387 | F1 MICRO: 0.9404
# EPOCH 6 | LOSS: 2.315833806991577 | ACCURACY: 0.9167 | F1 MACRO: 0.9452 | F1 MICRO: 0.9482
# EPOCH 7 | LOSS: 2.210221290588379 | ACCURACY: 0.9293 | F1 MACRO: 0.9533 | F1 MICRO: 0.9561
# EPOCH 8 | LOSS: 2.1282248497009277 | ACCURACY: 0.9353 | F1 MACRO: 0.9564 | F1 MICRO: 0.9595
# EPOCH 9 | LOSS: 2.0093371868133545 | ACCURACY: 0.9397 | F1 MACRO: 0.96 | F1 MICRO: 0.9624
# EPOCH 10 | LOSS: 1.9538332223892212 | ACCURACY: 0.939 | F1 MACRO: 0.9598 | F1 MICRO: 0.9619
# aspect: ACCURACY 0.9397 | F1 MACRO 0.96 | F1 MICRO 0.9624
#               precision    recall  f1-score   support
#
#         fuel       0.97      1.00      0.98       187
#      machine       0.93      0.99      0.96       175
#       others       0.89      0.90      0.90       158
#         part       0.93      0.96      0.95       158
#        price       0.96      1.00      0.98       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.95      0.98      0.96      1061
#    macro avg       0.95      0.97      0.96      1061
# weighted avg       0.95      0.98      0.96      1061
#  samples avg       0.95      0.98      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 10.159360885620117 | ACCURACY: 0.9048 | F1 MACRO: 0.8908 | F1 MICRO: 0.9048
# EPOCH 2 | LOSS: 7.609766006469727 | ACCURACY: 0.9286 | F1 MACRO: 0.921 | F1 MICRO: 0.9286
# EPOCH 3 | LOSS: 6.928279399871826 | ACCURACY: 0.9325 | F1 MACRO: 0.9239 | F1 MICRO: 0.9325
# EPOCH 4 | LOSS: 6.53945779800415 | ACCURACY: 0.9325 | F1 MACRO: 0.9256 | F1 MICRO: 0.9325
# EPOCH 5 | LOSS: 6.21753454208374 | ACCURACY: 0.9127 | F1 MACRO: 0.9034 | F1 MICRO: 0.9127
# EPOCH 6 | LOSS: 5.8926167488098145 | ACCURACY: 0.9087 | F1 MACRO: 0.8993 | F1 MICRO: 0.9087
# EPOCH 7 | LOSS: 5.839488506317139 | ACCURACY: 0.9087 | F1 MACRO: 0.8988 | F1 MICRO: 0.9087
# EPOCH 8 | LOSS: 5.844022750854492 | ACCURACY: 0.9008 | F1 MACRO: 0.8894 | F1 MICRO: 0.9008
# EPOCH 9 | LOSS: 5.643071174621582 | ACCURACY: 0.9325 | F1 MACRO: 0.9243 | F1 MICRO: 0.9325
# EPOCH 10 | LOSS: 5.466532230377197 | ACCURACY: 0.9325 | F1 MACRO: 0.9234 | F1 MICRO: 0.9325
# sentiment: ACCURACY 0.9325 | F1 MACRO 0.9234 | F1 MICRO 0.9325
#               precision    recall  f1-score   support
#
#     negative       0.88      0.91      0.90        81
#     positive       0.96      0.94      0.95       171
#
#     accuracy                           0.93       252
#    macro avg       0.92      0.93      0.92       252
# weighted avg       0.93      0.93      0.93       252
#
# --------------------------------------------------
# Iteration 274: Accuracy: 0.9375, F1 Micro: 0.9375, F1 Macro: 0.8851
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.92      0.92      0.92        24
#
#     accuracy                           0.98       216
#    macro avg       0.97      0.94      0.95       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.81      0.84        16
#      neutral       0.93      0.99      0.96       167
#     positive       0.88      0.64      0.74        33
#
#     accuracy                           0.92       216
#    macro avg       0.89      0.81      0.84       216
# weighted avg       0.92      0.92      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.75      0.75        12
#      neutral       0.93      0.92      0.92       152
#     positive       0.77      0.79      0.78        52
#
#     accuracy                           0.88       216
#    macro avg       0.82      0.82      0.82       216
# weighted avg       0.88      0.88      0.88       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.76      0.83      0.79        23
#      neutral       0.92      0.95      0.94       152
#     positive       0.83      0.71      0.76        41
#
#     accuracy                           0.89       216
#    macro avg       0.84      0.83      0.83       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.77      0.87        13
#      neutral       0.97      0.99      0.98       186
#     positive       0.87      0.76      0.81        17
#
#     accuracy                           0.96       216
#    macro avg       0.95      0.84      0.89       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.99      1.00      0.99       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.96      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 571 571
# Nearest checkpoint: 540
# Threshold: 88409.8515625
# Samples above threshold: 59
# Acquired samples: 59
# Sampling duration: 12.469771385192871 seconds
# New train size: 333
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.353114604949951 | ACCURACY: 0.8028 | F1 MACRO: 0.8854 | F1 MICRO: 0.8875
# EPOCH 2 | LOSS: 2.831418037414551 | ACCURACY: 0.8043 | F1 MACRO: 0.8875 | F1 MICRO: 0.8892
# EPOCH 3 | LOSS: 2.522805690765381 | ACCURACY: 0.8557 | F1 MACRO: 0.9145 | F1 MICRO: 0.9152
# EPOCH 4 | LOSS: 2.476661205291748 | ACCURACY: 0.91 | F1 MACRO: 0.9435 | F1 MICRO: 0.945
# EPOCH 5 | LOSS: 2.458038806915283 | ACCURACY: 0.9263 | F1 MACRO: 0.9525 | F1 MICRO: 0.9544
# EPOCH 6 | LOSS: 2.3295958042144775 | ACCURACY: 0.9382 | F1 MACRO: 0.9586 | F1 MICRO: 0.9613
# EPOCH 7 | LOSS: 2.2137744426727295 | ACCURACY: 0.939 | F1 MACRO: 0.9601 | F1 MICRO: 0.9621
# EPOCH 8 | LOSS: 2.0608556270599365 | ACCURACY: 0.9435 | F1 MACRO: 0.9625 | F1 MICRO: 0.9647
# EPOCH 9 | LOSS: 1.9850341081619263 | ACCURACY: 0.9442 | F1 MACRO: 0.9624 | F1 MICRO: 0.9649
# EPOCH 10 | LOSS: 1.9241279363632202 | ACCURACY: 0.9405 | F1 MACRO: 0.9599 | F1 MICRO: 0.9625
# aspect: ACCURACY 0.9442 | F1 MACRO 0.9624 | F1 MICRO 0.9649
#               precision    recall  f1-score   support
#
#         fuel       0.98      0.99      0.99       187
#      machine       0.93      0.99      0.96       175
#       others       0.93      0.88      0.90       158
#         part       0.93      0.97      0.95       158
#        price       0.97      0.99      0.98       192
#      service       0.99      1.00      0.99       191
#
#    micro avg       0.96      0.97      0.96      1061
#    macro avg       0.96      0.97      0.96      1061
# weighted avg       0.96      0.97      0.96      1061
#  samples avg       0.96      0.97      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 8.949468612670898 | ACCURACY: 0.9358 | F1 MACRO: 0.9262 | F1 MICRO: 0.9358
# EPOCH 2 | LOSS: 6.671418190002441 | ACCURACY: 0.9434 | F1 MACRO: 0.9348 | F1 MICRO: 0.9434
# EPOCH 3 | LOSS: 6.208536148071289 | ACCURACY: 0.9132 | F1 MACRO: 0.9025 | F1 MICRO: 0.9132
# EPOCH 4 | LOSS: 5.662693500518799 | ACCURACY: 0.9245 | F1 MACRO: 0.9129 | F1 MICRO: 0.9245
# EPOCH 5 | LOSS: 5.55868673324585 | ACCURACY: 0.9132 | F1 MACRO: 0.9007 | F1 MICRO: 0.9132
# EPOCH 6 | LOSS: 5.357016086578369 | ACCURACY: 0.917 | F1 MACRO: 0.9001 | F1 MICRO: 0.917
# EPOCH 7 | LOSS: 5.095627307891846 | ACCURACY: 0.917 | F1 MACRO: 0.9022 | F1 MICRO: 0.917
# EPOCH 8 | LOSS: 5.0214619636535645 | ACCURACY: 0.9245 | F1 MACRO: 0.9129 | F1 MICRO: 0.9245
# EPOCH 9 | LOSS: 4.970052719116211 | ACCURACY: 0.9132 | F1 MACRO: 0.9001 | F1 MICRO: 0.9132
# EPOCH 10 | LOSS: 5.050074577331543 | ACCURACY: 0.9019 | F1 MACRO: 0.886 | F1 MICRO: 0.9019
# sentiment: ACCURACY 0.9434 | F1 MACRO 0.9348 | F1 MICRO 0.9434
#               precision    recall  f1-score   support
#
#     negative       0.88      0.95      0.91        81
#     positive       0.98      0.94      0.96       184
#
#     accuracy                           0.94       265
#    macro avg       0.93      0.95      0.93       265
# weighted avg       0.95      0.94      0.94       265
#
# --------------------------------------------------
# Iteration 333: Accuracy: 0.9414, F1 Micro: 0.9414, F1 Macro: 0.8989
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.97      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.81      0.84        16
#      neutral       0.93      0.99      0.96       167
#     positive       0.92      0.67      0.77        33
#
#     accuracy                           0.93       216
#    macro avg       0.91      0.82      0.86       216
# weighted avg       0.92      0.93      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.69      0.75      0.72        12
#      neutral       0.95      0.87      0.91       152
#     positive       0.69      0.85      0.76        52
#
#     accuracy                           0.86       216
#    macro avg       0.78      0.82      0.80       216
# weighted avg       0.87      0.86      0.86       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.87      0.83        23
#      neutral       0.93      0.97      0.95       152
#     positive       0.94      0.71      0.81        41
#
#     accuracy                           0.91       216
#    macro avg       0.89      0.85      0.86       216
# weighted avg       0.91      0.91      0.91       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.85      0.88        13
#      neutral       0.98      0.99      0.99       186
#     positive       0.88      0.88      0.88        17
#
#     accuracy                           0.97       216
#    macro avg       0.93      0.91      0.92       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.99      1.00      1.00       185
#     positive       1.00      1.00      1.00        17
#
#     accuracy                           1.00       216
#    macro avg       1.00      0.98      0.99       216
# weighted avg       1.00      1.00      1.00       216
#
# Launching training on 2 GPUs.
# 513 513
# Nearest checkpoint: 540
# Threshold: 88305.140625
# Samples above threshold: 54
# Acquired samples: 54
# Sampling duration: 13.13166880607605 seconds
# New train size: 387
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.305419445037842 | ACCURACY: 0.7984 | F1 MACRO: 0.884 | F1 MICRO: 0.8859
# EPOCH 2 | LOSS: 2.659391403198242 | ACCURACY: 0.8199 | F1 MACRO: 0.8939 | F1 MICRO: 0.8956
# EPOCH 3 | LOSS: 2.491825580596924 | ACCURACY: 0.8735 | F1 MACRO: 0.923 | F1 MICRO: 0.9243
# EPOCH 4 | LOSS: 2.4471561908721924 | ACCURACY: 0.9368 | F1 MACRO: 0.9592 | F1 MICRO: 0.9608
# EPOCH 5 | LOSS: 2.358990430831909 | ACCURACY: 0.933 | F1 MACRO: 0.9539 | F1 MICRO: 0.9579
# EPOCH 6 | LOSS: 2.1972873210906982 | ACCURACY: 0.9464 | F1 MACRO: 0.9642 | F1 MICRO: 0.9665
# EPOCH 7 | LOSS: 2.03155517578125 | ACCURACY: 0.9509 | F1 MACRO: 0.9679 | F1 MICRO: 0.9693
# EPOCH 8 | LOSS: 1.941361665725708 | ACCURACY: 0.9442 | F1 MACRO: 0.9626 | F1 MICRO: 0.9649
# EPOCH 9 | LOSS: 1.8751310110092163 | ACCURACY: 0.9457 | F1 MACRO: 0.9633 | F1 MICRO: 0.9658
# EPOCH 10 | LOSS: 1.8397948741912842 | ACCURACY: 0.9472 | F1 MACRO: 0.9643 | F1 MICRO: 0.9667
# aspect: ACCURACY 0.9509 | F1 MACRO 0.9679 | F1 MICRO 0.9693
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.96      0.97      0.96       175
#       others       0.88      0.95      0.91       158
#         part       0.96      0.98      0.97       158
#        price       0.97      0.99      0.98       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.95      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 7.354289531707764 | ACCURACY: 0.9057 | F1 MACRO: 0.8981 | F1 MICRO: 0.9057
# EPOCH 2 | LOSS: 5.455641269683838 | ACCURACY: 0.9139 | F1 MACRO: 0.9069 | F1 MICRO: 0.9139
# EPOCH 3 | LOSS: 4.9850616455078125 | ACCURACY: 0.918 | F1 MACRO: 0.912 | F1 MICRO: 0.918
# EPOCH 4 | LOSS: 4.555452346801758 | ACCURACY: 0.9303 | F1 MACRO: 0.9212 | F1 MICRO: 0.9303
# EPOCH 5 | LOSS: 4.49711275100708 | ACCURACY: 0.9303 | F1 MACRO: 0.9231 | F1 MICRO: 0.9303
# EPOCH 6 | LOSS: 4.380298614501953 | ACCURACY: 0.9262 | F1 MACRO: 0.9204 | F1 MICRO: 0.9262
# EPOCH 7 | LOSS: 4.2239532470703125 | ACCURACY: 0.9344 | F1 MACRO: 0.9289 | F1 MICRO: 0.9344
# EPOCH 8 | LOSS: 4.2180256843566895 | ACCURACY: 0.9221 | F1 MACRO: 0.9125 | F1 MICRO: 0.9221
# EPOCH 9 | LOSS: 4.123538017272949 | ACCURACY: 0.9262 | F1 MACRO: 0.9158 | F1 MICRO: 0.9262
# EPOCH 10 | LOSS: 4.009436130523682 | ACCURACY: 0.8975 | F1 MACRO: 0.8826 | F1 MICRO: 0.8975
# sentiment: ACCURACY 0.9344 | F1 MACRO 0.9289 | F1 MICRO 0.9344
#               precision    recall  f1-score   support
#
#     negative       0.85      0.98      0.91        82
#     positive       0.99      0.91      0.95       162
#
#     accuracy                           0.93       244
#    macro avg       0.92      0.94      0.93       244
# weighted avg       0.94      0.93      0.94       244
#
# --------------------------------------------------
# Iteration 387: Accuracy: 0.9414, F1 Micro: 0.9414, F1 Macro: 0.8914
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.98      1.00      0.99       181
#     positive       1.00      0.88      0.93        24
#
#     accuracy                           0.99       216
#    macro avg       0.99      0.96      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.74      0.88      0.80        16
#      neutral       0.95      0.98      0.96       167
#     positive       0.92      0.70      0.79        33
#
#     accuracy                           0.93       216
#    macro avg       0.87      0.85      0.85       216
# weighted avg       0.93      0.93      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.82      0.75      0.78        12
#      neutral       0.88      0.95      0.91       152
#     positive       0.82      0.63      0.72        52
#
#     accuracy                           0.87       216
#    macro avg       0.84      0.78      0.80       216
# weighted avg       0.86      0.87      0.86       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.74      1.00      0.85        23
#      neutral       0.95      0.97      0.96       152
#     positive       0.97      0.71      0.82        41
#
#     accuracy                           0.92       216
#    macro avg       0.89      0.89      0.88       216
# weighted avg       0.93      0.92      0.92       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.77      0.83        13
#      neutral       0.97      0.99      0.98       186
#     positive       0.88      0.82      0.85        17
#
#     accuracy                           0.96       216
#    macro avg       0.92      0.86      0.89       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.93      0.93        14
#      neutral       0.99      1.00      0.99       185
#     positive       1.00      0.88      0.94        17
#
#     accuracy                           0.99       216
#    macro avg       0.97      0.94      0.95       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 460 460
# Nearest checkpoint: 540
# Threshold: 88459.8828125
# Samples above threshold: 48
# Acquired samples: 48
# Sampling duration: 13.884841203689575 seconds
# New train size: 435
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.1858973503112793 | ACCURACY: 0.8013 | F1 MACRO: 0.8832 | F1 MICRO: 0.8858
# EPOCH 2 | LOSS: 2.5279948711395264 | ACCURACY: 0.8393 | F1 MACRO: 0.9065 | F1 MICRO: 0.9073
# EPOCH 3 | LOSS: 2.3726069927215576 | ACCURACY: 0.8943 | F1 MACRO: 0.9329 | F1 MICRO: 0.9355
# EPOCH 4 | LOSS: 2.310698986053467 | ACCURACY: 0.933 | F1 MACRO: 0.9561 | F1 MICRO: 0.9584
# EPOCH 5 | LOSS: 2.1861302852630615 | ACCURACY: 0.9435 | F1 MACRO: 0.9626 | F1 MICRO: 0.9647
# EPOCH 6 | LOSS: 2.0299181938171387 | ACCURACY: 0.9479 | F1 MACRO: 0.9655 | F1 MICRO: 0.9674
# EPOCH 7 | LOSS: 1.906390905380249 | ACCURACY: 0.9524 | F1 MACRO: 0.9687 | F1 MICRO: 0.9702
# EPOCH 8 | LOSS: 1.8171905279159546 | ACCURACY: 0.9479 | F1 MACRO: 0.9649 | F1 MICRO: 0.9672
# EPOCH 9 | LOSS: 1.7672944068908691 | ACCURACY: 0.9442 | F1 MACRO: 0.9622 | F1 MICRO: 0.9648
# EPOCH 10 | LOSS: 1.7522838115692139 | ACCURACY: 0.9568 | F1 MACRO: 0.9713 | F1 MICRO: 0.9728
# aspect: ACCURACY 0.9568 | F1 MACRO 0.9713 | F1 MICRO 0.9728
#               precision    recall  f1-score   support
#
#         fuel       0.98      0.99      0.99       187
#      machine       0.94      0.99      0.96       175
#       others       0.94      0.91      0.93       158
#         part       0.97      0.97      0.97       158
#        price       0.97      0.99      0.98       192
#      service       0.99      1.00      0.99       191
#
#    micro avg       0.97      0.98      0.97      1061
#    macro avg       0.97      0.98      0.97      1061
# weighted avg       0.97      0.98      0.97      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.920601844787598 | ACCURACY: 0.9261 | F1 MACRO: 0.9157 | F1 MICRO: 0.9261
# EPOCH 2 | LOSS: 5.048455238342285 | ACCURACY: 0.9377 | F1 MACRO: 0.9297 | F1 MICRO: 0.9377
# EPOCH 3 | LOSS: 4.6724348068237305 | ACCURACY: 0.9377 | F1 MACRO: 0.9297 | F1 MICRO: 0.9377
# EPOCH 4 | LOSS: 4.313188552856445 | ACCURACY: 0.9377 | F1 MACRO: 0.9312 | F1 MICRO: 0.9377
# EPOCH 5 | LOSS: 3.9962246417999268 | ACCURACY: 0.9339 | F1 MACRO: 0.9271 | F1 MICRO: 0.9339
# EPOCH 6 | LOSS: 4.0178070068359375 | ACCURACY: 0.8988 | F1 MACRO: 0.8776 | F1 MICRO: 0.8988
# EPOCH 7 | LOSS: 3.890270948410034 | ACCURACY: 0.9339 | F1 MACRO: 0.9241 | F1 MICRO: 0.9339
# EPOCH 8 | LOSS: 3.892721176147461 | ACCURACY: 0.9222 | F1 MACRO: 0.9116 | F1 MICRO: 0.9222
# EPOCH 9 | LOSS: 3.7583556175231934 | ACCURACY: 0.9261 | F1 MACRO: 0.9172 | F1 MICRO: 0.9261
# EPOCH 10 | LOSS: 3.6473751068115234 | ACCURACY: 0.93 | F1 MACRO: 0.9209 | F1 MICRO: 0.93
# sentiment: ACCURACY 0.9377 | F1 MACRO 0.9312 | F1 MICRO 0.9377
#               precision    recall  f1-score   support
#
#     negative       0.86      0.96      0.91        84
#     positive       0.98      0.92      0.95       173
#
#     accuracy                           0.94       257
#    macro avg       0.92      0.94      0.93       257
# weighted avg       0.94      0.94      0.94       257
#
# --------------------------------------------------
# Iteration 435: Accuracy: 0.9468, F1 Micro: 0.9468, F1 Macro: 0.8999
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.82      0.90        11
#      neutral       0.98      0.99      0.99       181
#     positive       0.92      0.92      0.92        24
#
#     accuracy                           0.98       216
#    macro avg       0.97      0.91      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.88      0.88      0.88        16
#      neutral       0.94      0.99      0.96       167
#     positive       0.92      0.67      0.77        33
#
#     accuracy                           0.93       216
#    macro avg       0.91      0.84      0.87       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.79      0.92      0.85        12
#      neutral       0.93      0.91      0.92       152
#     positive       0.75      0.77      0.76        52
#
#     accuracy                           0.88       216
#    macro avg       0.82      0.86      0.84       216
# weighted avg       0.88      0.88      0.88       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.81      0.96      0.88        23
#      neutral       0.96      0.98      0.97       152
#     positive       0.94      0.76      0.84        41
#
#     accuracy                           0.94       216
#    macro avg       0.90      0.90      0.90       216
# weighted avg       0.94      0.94      0.93       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.85      0.85        13
#      neutral       0.98      1.00      0.99       186
#     positive       0.93      0.76      0.84        17
#
#     accuracy                           0.97       216
#    macro avg       0.92      0.87      0.89       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.93      0.93        14
#      neutral       0.99      1.00      1.00       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       0.97      0.96      0.97       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 417 417
# Nearest checkpoint: 540
# Threshold: 88473.640625
# Samples above threshold: 43
# Acquired samples: 43
# Sampling duration: 14.63872766494751 seconds
# New train size: 478
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.0577099323272705 | ACCURACY: 0.8125 | F1 MACRO: 0.8905 | F1 MICRO: 0.8925
# EPOCH 2 | LOSS: 2.486855983734131 | ACCURACY: 0.8497 | F1 MACRO: 0.9113 | F1 MICRO: 0.9121
# EPOCH 3 | LOSS: 2.3718161582946777 | ACCURACY: 0.9159 | F1 MACRO: 0.9457 | F1 MICRO: 0.948
# EPOCH 4 | LOSS: 2.305041551589966 | ACCURACY: 0.9442 | F1 MACRO: 0.9639 | F1 MICRO: 0.9653
# EPOCH 5 | LOSS: 2.126483201980591 | ACCURACY: 0.9487 | F1 MACRO: 0.9664 | F1 MICRO: 0.968
# EPOCH 6 | LOSS: 1.9778704643249512 | ACCURACY: 0.9457 | F1 MACRO: 0.964 | F1 MICRO: 0.966
# EPOCH 7 | LOSS: 1.8728712797164917 | ACCURACY: 0.9487 | F1 MACRO: 0.9656 | F1 MICRO: 0.9678
# EPOCH 8 | LOSS: 1.8161636590957642 | ACCURACY: 0.9435 | F1 MACRO: 0.9609 | F1 MICRO: 0.9643
# EPOCH 9 | LOSS: 1.7687422037124634 | ACCURACY: 0.9487 | F1 MACRO: 0.9652 | F1 MICRO: 0.9677
# EPOCH 10 | LOSS: 1.7239418029785156 | ACCURACY: 0.9487 | F1 MACRO: 0.9655 | F1 MICRO: 0.9676
# aspect: ACCURACY 0.9487 | F1 MACRO 0.9664 | F1 MICRO 0.968
#               precision    recall  f1-score   support
#
#         fuel       0.97      1.00      0.99       187
#      machine       0.94      0.99      0.96       175
#       others       0.90      0.94      0.92       158
#         part       0.94      0.97      0.96       158
#        price       0.97      0.98      0.98       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.95      0.98      0.97      1061
#    macro avg       0.95      0.98      0.97      1061
# weighted avg       0.95      0.98      0.97      1061
#  samples avg       0.95      0.98      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 5.971965789794922 | ACCURACY: 0.92 | F1 MACRO: 0.9104 | F1 MICRO: 0.92
# EPOCH 2 | LOSS: 4.601199626922607 | ACCURACY: 0.932 | F1 MACRO: 0.9249 | F1 MICRO: 0.932
# EPOCH 3 | LOSS: 4.294211387634277 | ACCURACY: 0.932 | F1 MACRO: 0.924 | F1 MICRO: 0.932
# EPOCH 4 | LOSS: 3.9195122718811035 | ACCURACY: 0.94 | F1 MACRO: 0.933 | F1 MICRO: 0.94
# EPOCH 5 | LOSS: 3.7290666103363037 | ACCURACY: 0.924 | F1 MACRO: 0.9146 | F1 MICRO: 0.924
# EPOCH 6 | LOSS: 3.547736406326294 | ACCURACY: 0.944 | F1 MACRO: 0.9365 | F1 MICRO: 0.944
# EPOCH 7 | LOSS: 3.434448480606079 | ACCURACY: 0.908 | F1 MACRO: 0.8925 | F1 MICRO: 0.908
# EPOCH 8 | LOSS: 3.386335849761963 | ACCURACY: 0.92 | F1 MACRO: 0.9109 | F1 MICRO: 0.92
# EPOCH 9 | LOSS: 3.450603723526001 | ACCURACY: 0.92 | F1 MACRO: 0.9132 | F1 MICRO: 0.92
# EPOCH 10 | LOSS: 3.3766849040985107 | ACCURACY: 0.892 | F1 MACRO: 0.8689 | F1 MICRO: 0.892
# sentiment: ACCURACY 0.944 | F1 MACRO 0.9365 | F1 MICRO 0.944
#               precision    recall  f1-score   support
#
#     negative       0.90      0.93      0.91        81
#     positive       0.96      0.95      0.96       169
#
#     accuracy                           0.94       250
#    macro avg       0.93      0.94      0.94       250
# weighted avg       0.94      0.94      0.94       250
#
# --------------------------------------------------
# Iteration 478: Accuracy: 0.9421, F1 Micro: 0.9421, F1 Macro: 0.8941
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.82      0.90        11
#      neutral       0.98      1.00      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.98       216
#    macro avg       0.98      0.91      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.75      0.83        16
#      neutral       0.94      0.99      0.97       167
#     positive       0.88      0.70      0.78        33
#
#     accuracy                           0.93       216
#    macro avg       0.92      0.81      0.86       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.75      0.75        12
#      neutral       0.90      0.93      0.92       152
#     positive       0.79      0.73      0.76        52
#
#     accuracy                           0.87       216
#    macro avg       0.82      0.80      0.81       216
# weighted avg       0.87      0.87      0.87       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.79      0.96      0.86        23
#      neutral       0.94      0.95      0.94       152
#     positive       0.88      0.71      0.78        41
#
#     accuracy                           0.91       216
#    macro avg       0.87      0.87      0.86       216
# weighted avg       0.91      0.91      0.91       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.85      0.88        13
#      neutral       0.98      0.99      0.99       186
#     positive       0.88      0.88      0.88        17
#
#     accuracy                           0.97       216
#    macro avg       0.93      0.91      0.92       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.99      1.00      0.99       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.96      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 372 372
# Nearest checkpoint: 540
# Threshold: 88533.6875
# Samples above threshold: 39
# Acquired samples: 39
# Sampling duration: 14.994884967803955 seconds
# New train size: 517
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.1713762283325195 | ACCURACY: 0.811 | F1 MACRO: 0.8899 | F1 MICRO: 0.8918
# EPOCH 2 | LOSS: 2.567871570587158 | ACCURACY: 0.8371 | F1 MACRO: 0.9007 | F1 MICRO: 0.9036
# EPOCH 3 | LOSS: 2.4458701610565186 | ACCURACY: 0.9256 | F1 MACRO: 0.9519 | F1 MICRO: 0.9538
# EPOCH 4 | LOSS: 2.326479911804199 | ACCURACY: 0.9412 | F1 MACRO: 0.9609 | F1 MICRO: 0.9632
# EPOCH 5 | LOSS: 2.1226117610931396 | ACCURACY: 0.9539 | F1 MACRO: 0.9696 | F1 MICRO: 0.9712
# EPOCH 6 | LOSS: 1.9707286357879639 | ACCURACY: 0.9531 | F1 MACRO: 0.9697 | F1 MICRO: 0.9708
# EPOCH 7 | LOSS: 1.89607572555542 | ACCURACY: 0.9516 | F1 MACRO: 0.9681 | F1 MICRO: 0.9698
# EPOCH 8 | LOSS: 1.8325355052947998 | ACCURACY: 0.9546 | F1 MACRO: 0.9694 | F1 MICRO: 0.9714
# EPOCH 9 | LOSS: 1.7786731719970703 | ACCURACY: 0.9464 | F1 MACRO: 0.9639 | F1 MICRO: 0.9663
# EPOCH 10 | LOSS: 1.7247155904769897 | ACCURACY: 0.9539 | F1 MACRO: 0.9697 | F1 MICRO: 0.9711
# aspect: ACCURACY 0.9546 | F1 MACRO 0.9694 | F1 MICRO 0.9714
# ...
#
#    micro avg       0.97      0.98      0.97      1061
#    macro avg       0.96      0.98      0.97      1061
# weighted avg       0.97      0.98      0.97      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.633159875869751 | ACCURACY: 0.9302 | F1 MACRO: 0.9196 | F1 MICRO: 0.9302
# EPOCH 2 | LOSS: 2.7446401119232178 | ACCURACY: 0.9419 | F1 MACRO: 0.9355 | F1 MICRO: 0.9419
# EPOCH 3 | LOSS: 2.5121467113494873 | ACCURACY: 0.9574 | F1 MACRO: 0.9513 | F1 MICRO: 0.9574
# EPOCH 4 | LOSS: 2.2941973209381104 | ACCURACY: 0.9419 | F1 MACRO: 0.9344 | F1 MICRO: 0.9419
# EPOCH 5 | LOSS: 2.164557933807373 | ACCURACY: 0.938 | F1 MACRO: 0.9306 | F1 MICRO: 0.938
# EPOCH 6 | LOSS: 2.108649730682373 | ACCURACY: 0.9341 | F1 MACRO: 0.9269 | F1 MICRO: 0.9341
# EPOCH 7 | LOSS: 2.1187949180603027 | ACCURACY: 0.9419 | F1 MACRO: 0.9348 | F1 MICRO: 0.9419
# EPOCH 8 | LOSS: 2.0305795669555664 | ACCURACY: 0.9264 | F1 MACRO: 0.9148 | F1 MICRO: 0.9264
# EPOCH 9 | LOSS: 2.0365045070648193 | ACCURACY: 0.9341 | F1 MACRO: 0.9273 | F1 MICRO: 0.9341
# EPOCH 10 | LOSS: 2.0745136737823486 | ACCURACY: 0.9341 | F1 MACRO: 0.9269 | F1 MICRO: 0.9341
# sentiment: ACCURACY 0.9574 | F1 MACRO 0.9513 | F1 MICRO 0.9574
#               precision    recall  f1-score   support
#
#     negative       0.93      0.94      0.93        83
#     positive       0.97      0.97      0.97       175
#
#     accuracy                           0.96       258
#    macro avg       0.95      0.95      0.95       258
# weighted avg       0.96      0.96      0.96       258
#
# --------------------------------------------------
# Iteration 831: Accuracy: 0.9614, F1 Micro: 0.9614, F1 Macro: 0.9304
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.97      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.75      0.80        16
#      neutral       0.95      0.97      0.96       167
#     positive       0.84      0.79      0.81        33
#
#     accuracy                           0.93       216
#    macro avg       0.88      0.84      0.86       216
# weighted avg       0.92      0.93      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.83      0.87        12
#      neutral       0.92      0.97      0.95       152
#     positive       0.93      0.79      0.85        52
#
#     accuracy                           0.92       216
#    macro avg       0.92      0.87      0.89       216
# weighted avg       0.92      0.92      0.92       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.88      1.00      0.94        23
#      neutral       0.98      0.98      0.98       152
#     positive       0.95      0.88      0.91        41
#
#     accuracy                           0.96       216
#    macro avg       0.94      0.95      0.94       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.85      0.88        13
#      neutral       0.98      0.99      0.99       186
#     positive       0.88      0.88      0.88        17
#
#     accuracy                           0.97       216
#    macro avg       0.93      0.91      0.92       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        14
#      neutral       1.00      1.00      1.00       185
#     positive       1.00      1.00      1.00        17
#
#     accuracy                           1.00       216
#    macro avg       1.00      1.00      1.00       216
# weighted avg       1.00      1.00      1.00       216
#
# Launching training on 2 GPUs.
# 33 33
# Nearest checkpoint: 864
# Threshold: 88237.1796875
# Samples above threshold: 4
# Acquired samples: 25
# Sampling duration: 20.369396209716797 seconds
# New train size: 856
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.886979341506958 | ACCURACY: 0.8185 | F1 MACRO: 0.8952 | F1 MICRO: 0.8966
# EPOCH 2 | LOSS: 2.3797764778137207 | ACCURACY: 0.9375 | F1 MACRO: 0.9598 | F1 MICRO: 0.9614
# EPOCH 3 | LOSS: 2.208876371383667 | ACCURACY: 0.9487 | F1 MACRO: 0.9659 | F1 MICRO: 0.9679
# EPOCH 4 | LOSS: 1.965683937072754 | ACCURACY: 0.9561 | F1 MACRO: 0.9704 | F1 MICRO: 0.9724
# EPOCH 5 | LOSS: 1.8618048429489136 | ACCURACY: 0.9568 | F1 MACRO: 0.9704 | F1 MICRO: 0.9727
# EPOCH 6 | LOSS: 1.7489509582519531 | ACCURACY: 0.9568 | F1 MACRO: 0.9713 | F1 MICRO: 0.9729
# EPOCH 7 | LOSS: 1.680881381034851 | ACCURACY: 0.9583 | F1 MACRO: 0.9728 | F1 MICRO: 0.9739
# EPOCH 8 | LOSS: 1.6499683856964111 | ACCURACY: 0.9554 | F1 MACRO: 0.9698 | F1 MICRO: 0.9718
# EPOCH 9 | LOSS: 1.566142201423645 | ACCURACY: 0.9554 | F1 MACRO: 0.9694 | F1 MICRO: 0.9717
# EPOCH 10 | LOSS: 1.5839476585388184 | ACCURACY: 0.9606 | F1 MACRO: 0.974 | F1 MICRO: 0.9752
# aspect: ACCURACY 0.9606 | F1 MACRO 0.974 | F1 MICRO 0.9752
#               precision    recall  f1-score   support
#
#         fuel       0.98      0.99      0.99       187
#      machine       0.95      0.98      0.96       175
#       others       0.93      0.94      0.93       158
#         part       0.97      0.98      0.98       158
#        price       0.99      0.98      0.98       192
#      service       0.99      1.00      0.99       191
#
#    micro avg       0.97      0.98      0.98      1061
#    macro avg       0.97      0.98      0.97      1061
# weighted avg       0.97      0.98      0.98      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.530601739883423 | ACCURACY: 0.9405 | F1 MACRO: 0.9308 | F1 MICRO: 0.9405
# EPOCH 2 | LOSS: 2.686663866043091 | ACCURACY: 0.9405 | F1 MACRO: 0.9312 | F1 MICRO: 0.9405
# EPOCH 3 | LOSS: 2.4495105743408203 | ACCURACY: 0.9591 | F1 MACRO: 0.9526 | F1 MICRO: 0.9591
# EPOCH 4 | LOSS: 2.2211949825286865 | ACCURACY: 0.9368 | F1 MACRO: 0.9276 | F1 MICRO: 0.9368
# EPOCH 5 | LOSS: 2.06986141204834 | ACCURACY: 0.9368 | F1 MACRO: 0.9267 | F1 MICRO: 0.9368
# EPOCH 6 | LOSS: 2.0523955821990967 | ACCURACY: 0.948 | F1 MACRO: 0.9409 | F1 MICRO: 0.948
# EPOCH 7 | LOSS: 1.9420051574707031 | ACCURACY: 0.9368 | F1 MACRO: 0.9288 | F1 MICRO: 0.9368
# EPOCH 8 | LOSS: 1.9785470962524414 | ACCURACY: 0.9405 | F1 MACRO: 0.9308 | F1 MICRO: 0.9405
# EPOCH 9 | LOSS: 1.9288972616195679 | ACCURACY: 0.9405 | F1 MACRO: 0.932 | F1 MICRO: 0.9405
# EPOCH 10 | LOSS: 1.982677936553955 | ACCURACY: 0.9219 | F1 MACRO: 0.913 | F1 MICRO: 0.9219
# sentiment: ACCURACY 0.9591 | F1 MACRO 0.9526 | F1 MICRO 0.9591
#               precision    recall  f1-score   support
#
#     negative       0.92      0.95      0.93        83
#     positive       0.98      0.96      0.97       186
#
#     accuracy                           0.96       269
#    macro avg       0.95      0.96      0.95       269
# weighted avg       0.96      0.96      0.96       269
#
# --------------------------------------------------
# Iteration 856: Accuracy: 0.9537, F1 Micro: 0.9537, F1 Macro: 0.9137
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.97      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.81      0.84        16
#      neutral       0.96      0.97      0.97       167
#     positive       0.85      0.85      0.85        33
#
#     accuracy                           0.94       216
#    macro avg       0.89      0.88      0.88       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.75      0.75        12
#      neutral       0.92      0.93      0.92       152
#     positive       0.80      0.77      0.78        52
#
#     accuracy                           0.88       216
#    macro avg       0.82      0.82      0.82       216
# weighted avg       0.88      0.88      0.88       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.85      1.00      0.92        23
#      neutral       0.97      0.98      0.98       152
#     positive       0.94      0.83      0.88        41
#
#     accuracy                           0.95       216
#    macro avg       0.92      0.94      0.93       216
# weighted avg       0.96      0.95      0.95       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.85      0.85        13
#      neutral       0.99      0.98      0.99       186
#     positive       0.79      0.88      0.83        17
#
#     accuracy                           0.97       216
#    macro avg       0.88      0.90      0.89       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.99      1.00      1.00       185
#     positive       1.00      1.00      1.00        17
#
#     accuracy                           1.00       216
#    macro avg       1.00      0.98      0.99       216
# weighted avg       1.00      1.00      1.00       216
#
# Launching training on 2 GPUs.
# 8 8
# Nearest checkpoint: 864
# Threshold: 88294.6796875
# Samples above threshold: 1
# Acquired samples: 8
# Sampling duration: 20.609872817993164 seconds
# New train size: 864
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.871044635772705 | ACCURACY: 0.8103 | F1 MACRO: 0.8909 | F1 MICRO: 0.8925
# EPOCH 2 | LOSS: 2.3864283561706543 | ACCURACY: 0.9375 | F1 MACRO: 0.9593 | F1 MICRO: 0.9611
# EPOCH 3 | LOSS: 2.2238357067108154 | ACCURACY: 0.9494 | F1 MACRO: 0.9669 | F1 MICRO: 0.9685
# EPOCH 4 | LOSS: 1.9901009798049927 | ACCURACY: 0.9621 | F1 MACRO: 0.9754 | F1 MICRO: 0.9764
# EPOCH 5 | LOSS: 1.8392783403396606 | ACCURACY: 0.9606 | F1 MACRO: 0.9739 | F1 MICRO: 0.9753
# EPOCH 6 | LOSS: 1.7593647241592407 | ACCURACY: 0.9583 | F1 MACRO: 0.9722 | F1 MICRO: 0.9737
# EPOCH 7 | LOSS: 1.6909253597259521 | ACCURACY: 0.9613 | F1 MACRO: 0.9744 | F1 MICRO: 0.9757
# EPOCH 8 | LOSS: 1.6550432443618774 | ACCURACY: 0.9598 | F1 MACRO: 0.9729 | F1 MICRO: 0.9746
# EPOCH 9 | LOSS: 1.6230053901672363 | ACCURACY: 0.9539 | F1 MACRO: 0.9688 | F1 MICRO: 0.9709
# EPOCH 10 | LOSS: 1.568304181098938 | ACCURACY: 0.9628 | F1 MACRO: 0.9753 | F1 MICRO: 0.9766
# aspect: ACCURACY 0.9628 | F1 MACRO 0.9753 | F1 MICRO 0.9766
#               precision    recall  f1-score   support
#
#         fuel       0.98      0.99      0.99       187
#      machine       0.94      0.99      0.96       175
#       others       0.93      0.94      0.93       158
#         part       0.97      0.98      0.97       158
#        price       0.98      0.99      0.99       192
#      service       1.00      1.00      1.00       191
#
#    micro avg       0.97      0.98      0.98      1061
#    macro avg       0.97      0.98      0.98      1061
# weighted avg       0.97      0.98      0.98      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.447143077850342 | ACCURACY: 0.9283 | F1 MACRO: 0.9194 | F1 MICRO: 0.9283
# EPOCH 2 | LOSS: 2.7199764251708984 | ACCURACY: 0.9396 | F1 MACRO: 0.9327 | F1 MICRO: 0.9396
# EPOCH 3 | LOSS: 2.3900938034057617 | ACCURACY: 0.9509 | F1 MACRO: 0.9449 | F1 MICRO: 0.9509
# EPOCH 4 | LOSS: 2.1915934085845947 | ACCURACY: 0.9396 | F1 MACRO: 0.9331 | F1 MICRO: 0.9396
# EPOCH 5 | LOSS: 2.1380422115325928 | ACCURACY: 0.9472 | F1 MACRO: 0.9405 | F1 MICRO: 0.9472
# EPOCH 6 | LOSS: 2.059580087661743 | ACCURACY: 0.9472 | F1 MACRO: 0.9382 | F1 MICRO: 0.9472
# EPOCH 7 | LOSS: 2.060148239135742 | ACCURACY: 0.917 | F1 MACRO: 0.8969 | F1 MICRO: 0.917
# EPOCH 8 | LOSS: 2.109840154647827 | ACCURACY: 0.9434 | F1 MACRO: 0.9371 | F1 MICRO: 0.9434
# EPOCH 9 | LOSS: 2.006499767303467 | ACCURACY: 0.9509 | F1 MACRO: 0.9439 | F1 MICRO: 0.9509
# EPOCH 10 | LOSS: 1.9280502796173096 | ACCURACY: 0.9208 | F1 MACRO: 0.9128 | F1 MICRO: 0.9208
# sentiment: ACCURACY 0.9509 | F1 MACRO 0.9439 | F1 MICRO 0.9509
#               precision    recall  f1-score   support
#
#     negative       0.91      0.94      0.92        84
#     positive       0.97      0.96      0.96       181
#
#     accuracy                           0.95       265
#    macro avg       0.94      0.95      0.94       265
# weighted avg       0.95      0.95      0.95       265
#
# --------------------------------------------------
# Iteration 864: Accuracy: 0.9568, F1 Micro: 0.9568, F1 Macro: 0.9209
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.96      0.96      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.98      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.81      0.84        16
#      neutral       0.95      0.98      0.97       167
#     positive       0.90      0.79      0.84        33
#
#     accuracy                           0.94       216
#    macro avg       0.91      0.86      0.88       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.83      0.83        12
#      neutral       0.92      0.93      0.93       152
#     positive       0.80      0.77      0.78        52
#
#     accuracy                           0.89       216
#    macro avg       0.85      0.85      0.85       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.85      1.00      0.92        23
#      neutral       0.97      0.98      0.98       152
#     positive       0.94      0.83      0.88        41
#
#     accuracy                           0.95       216
#    macro avg       0.92      0.94      0.93       216
# weighted avg       0.96      0.95      0.95       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.85      0.85        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.88      0.88      0.88        17
#
#     accuracy                           0.97       216
#    macro avg       0.91      0.91      0.91       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.93      1.00      0.97        14
#      neutral       1.00      1.00      1.00       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           1.00       216
#    macro avg       0.98      0.98      0.98       216
# weighted avg       1.00      1.00      1.00       216
#
# Total sampling time: 371.12 seconds
# Total runtime: 3316.6963567733765 seconds

# %% [markdown]
# ## RUN 5

# %%
active_learning(seeds[4], 4)
# Out:
# ===============================================
# TRIAL 5
# Random seed: 94
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.6675004959106445 | ACCURACY: 0.6421 | F1 MACRO: 0.7118 | F1 MICRO: 0.7611
# EPOCH 2 | LOSS: 3.466869592666626 | ACCURACY: 0.7783 | F1 MACRO: 0.8695 | F1 MICRO: 0.8733
# EPOCH 3 | LOSS: 3.1926214694976807 | ACCURACY: 0.7842 | F1 MACRO: 0.8765 | F1 MICRO: 0.8787
# EPOCH 4 | LOSS: 3.4439992904663086 | ACCURACY: 0.7909 | F1 MACRO: 0.8808 | F1 MICRO: 0.8826
# EPOCH 5 | LOSS: 3.221564292907715 | ACCURACY: 0.7887 | F1 MACRO: 0.8789 | F1 MICRO: 0.881
# EPOCH 6 | LOSS: 3.0427441596984863 | ACCURACY: 0.7835 | F1 MACRO: 0.8741 | F1 MICRO: 0.8771
# EPOCH 7 | LOSS: 3.0137059688568115 | ACCURACY: 0.7746 | F1 MACRO: 0.8644 | F1 MICRO: 0.8696
# EPOCH 8 | LOSS: 3.0414557456970215 | ACCURACY: 0.756 | F1 MACRO: 0.8459 | F1 MICRO: 0.856
# EPOCH 9 | LOSS: 2.8761725425720215 | ACCURACY: 0.753 | F1 MACRO: 0.838 | F1 MICRO: 0.8531
# EPOCH 10 | LOSS: 2.9247355461120605 | ACCURACY: 0.756 | F1 MACRO: 0.8426 | F1 MICRO: 0.8545
# aspect: ACCURACY 0.7909 | F1 MACRO 0.8808 | F1 MICRO 0.8826
#               precision    recall  f1-score   support
#
#         fuel       0.83      1.00      0.91       187
#      machine       0.78      1.00      0.88       175
#       others       0.71      1.00      0.83       158
#         part       0.72      0.97      0.83       158
#        price       0.86      1.00      0.92       192
#      service       0.85      1.00      0.92       191
#
#    micro avg       0.79      1.00      0.88      1061
#    macro avg       0.79      0.99      0.88      1061
# weighted avg       0.80      1.00      0.88      1061
#  samples avg       0.79      1.00      0.88      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.1537935733795166 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# EPOCH 2 | LOSS: 2.5117390155792236 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# EPOCH 3 | LOSS: 2.941178798675537 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# EPOCH 4 | LOSS: 2.8505773544311523 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# EPOCH 5 | LOSS: 2.809542655944824 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# EPOCH 6 | LOSS: 2.7293100357055664 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# EPOCH 7 | LOSS: 2.207124948501587 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# EPOCH 8 | LOSS: 2.3954319953918457 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# EPOCH 9 | LOSS: 2.3182926177978516 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# EPOCH 10 | LOSS: 2.355624198913574 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# sentiment: ACCURACY 0.8889 | F1 MACRO 0.4706 | F1 MICRO 0.8889
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00         1
#     positive       0.89      1.00      0.94         8
#
#     accuracy                           0.89         9
#    macro avg       0.44      0.50      0.47         9
# weighted avg       0.79      0.89      0.84         9
#
# --------------------------------------------------
# Iteration 54: Accuracy: 0.7863, F1 Micro: 0.7863, F1 Macro: 0.2973
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        11
#      neutral       0.84      1.00      0.91       181
#     positive       0.00      0.00      0.00        24
#
#     accuracy                           0.84       216
#    macro avg       0.28      0.33      0.30       216
# weighted avg       0.70      0.84      0.76       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        16
#      neutral       0.77      1.00      0.87       167
#     positive       0.00      0.00      0.00        33
#
#     accuracy                           0.77       216
#    macro avg       0.26      0.33      0.29       216
# weighted avg       0.60      0.77      0.67       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        12
#      neutral       0.70      1.00      0.83       152
#     positive       0.00      0.00      0.00        52
#
#     accuracy                           0.70       216
#    macro avg       0.23      0.33      0.28       216
# weighted avg       0.50      0.70      0.58       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        23
#      neutral       0.71      0.96      0.81       152
#     positive       0.22      0.05      0.08        41
#
#     accuracy                           0.69       216
#    macro avg       0.31      0.34      0.30       216
# weighted avg       0.54      0.69      0.59       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        13
#      neutral       0.86      1.00      0.93       186
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.86       216
#    macro avg       0.29      0.33      0.31       216
# weighted avg       0.74      0.86      0.80       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        14
#      neutral       0.86      1.00      0.92       185
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.86       216
#    macro avg       0.29      0.33      0.31       216
# weighted avg       0.73      0.86      0.79       216
#
# Launching training on 2 GPUs.
# 31 31
# Nearest checkpoint: 540
# Threshold: 87665.1875
# Samples above threshold: 81
# Acquired samples: 81
# Sampling duration: 5.7683188915252686 seconds
# New train size: 135
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.7884488105773926 | ACCURACY: 0.7879 | F1 MACRO: 0.8792 | F1 MICRO: 0.881
# EPOCH 2 | LOSS: 3.635481595993042 | ACCURACY: 0.7917 | F1 MACRO: 0.8818 | F1 MICRO: 0.8833
# EPOCH 3 | LOSS: 3.2244513034820557 | ACCURACY: 0.7969 | F1 MACRO: 0.8837 | F1 MICRO: 0.8854
# EPOCH 4 | LOSS: 3.0154778957366943 | ACCURACY: 0.7954 | F1 MACRO: 0.8798 | F1 MICRO: 0.883
# EPOCH 5 | LOSS: 2.871161937713623 | ACCURACY: 0.8147 | F1 MACRO: 0.8906 | F1 MICRO: 0.8926
# EPOCH 6 | LOSS: 2.7909770011901855 | ACCURACY: 0.8408 | F1 MACRO: 0.9056 | F1 MICRO: 0.907
# EPOCH 7 | LOSS: 2.7080764770507812 | ACCURACY: 0.8504 | F1 MACRO: 0.9088 | F1 MICRO: 0.9113
# EPOCH 8 | LOSS: 2.6529386043548584 | ACCURACY: 0.8757 | F1 MACRO: 0.9212 | F1 MICRO: 0.9245
# EPOCH 9 | LOSS: 2.6252756118774414 | ACCURACY: 0.8839 | F1 MACRO: 0.9251 | F1 MICRO: 0.9286
# EPOCH 10 | LOSS: 2.683722972869873 | ACCURACY: 0.8988 | F1 MACRO: 0.9345 | F1 MICRO: 0.9377
# aspect: ACCURACY 0.8988 | F1 MACRO 0.9345 | F1 MICRO 0.9377
#               precision    recall  f1-score   support
#
#         fuel       0.90      1.00      0.95       187
#      machine       0.89      0.99      0.94       175
#       others       0.82      0.89      0.85       158
#         part       0.92      0.90      0.91       158
#        price       0.97      0.99      0.98       192
#      service       0.96      1.00      0.98       191
#
#    micro avg       0.91      0.96      0.94      1061
#    macro avg       0.91      0.96      0.93      1061
# weighted avg       0.91      0.96      0.94      1061
#  samples avg       0.92      0.96      0.93      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 18.47299575805664 | ACCURACY: 0.854 | F1 MACRO: 0.8053 | F1 MICRO: 0.854
# EPOCH 2 | LOSS: 15.2887544631958 | ACCURACY: 0.9292 | F1 MACRO: 0.9144 | F1 MICRO: 0.9292
# EPOCH 3 | LOSS: 12.82190990447998 | ACCURACY: 0.9248 | F1 MACRO: 0.911 | F1 MICRO: 0.9248
# EPOCH 4 | LOSS: 11.915616035461426 | ACCURACY: 0.9204 | F1 MACRO: 0.9053 | F1 MICRO: 0.9204
# EPOCH 5 | LOSS: 11.623290061950684 | ACCURACY: 0.9115 | F1 MACRO: 0.893 | F1 MICRO: 0.9115
# EPOCH 6 | LOSS: 11.35507583618164 | ACCURACY: 0.9204 | F1 MACRO: 0.9019 | F1 MICRO: 0.9204
# EPOCH 7 | LOSS: 10.787967681884766 | ACCURACY: 0.9292 | F1 MACRO: 0.9128 | F1 MICRO: 0.9292
# EPOCH 8 | LOSS: 10.704291343688965 | ACCURACY: 0.9159 | F1 MACRO: 0.9021 | F1 MICRO: 0.9159
# EPOCH 9 | LOSS: 10.580082893371582 | ACCURACY: 0.9204 | F1 MACRO: 0.9019 | F1 MICRO: 0.9204
# EPOCH 10 | LOSS: 10.176487922668457 | ACCURACY: 0.9292 | F1 MACRO: 0.9166 | F1 MICRO: 0.9292
# sentiment: ACCURACY 0.9292 | F1 MACRO 0.9166 | F1 MICRO 0.9292
#               precision    recall  f1-score   support
#
#     negative       0.84      0.94      0.88        65
#     positive       0.97      0.93      0.95       161
#
#     accuracy                           0.93       226
#    macro avg       0.90      0.93      0.92       226
# weighted avg       0.93      0.93      0.93       226
#
# --------------------------------------------------
# Iteration 135: Accuracy: 0.8981, F1 Micro: 0.8981, F1 Macro: 0.8032
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.36      0.53        11
#      neutral       0.91      1.00      0.96       181
#     positive       1.00      0.58      0.74        24
#
#     accuracy                           0.92       216
#    macro avg       0.97      0.65      0.74       216
# weighted avg       0.93      0.92      0.91       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.69      0.76        16
#      neutral       0.91      0.98      0.95       167
#     positive       0.91      0.64      0.75        33
#
#     accuracy                           0.91       216
#    macro avg       0.89      0.77      0.82       216
# weighted avg       0.91      0.91      0.90       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.58      0.74        12
#      neutral       0.85      0.86      0.85       152
#     positive       0.61      0.63      0.62        52
#
#     accuracy                           0.79       216
#    macro avg       0.82      0.69      0.74       216
# weighted avg       0.80      0.79      0.79       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.72      0.78      0.75        23
#      neutral       0.91      0.91      0.91       152
#     positive       0.74      0.68      0.71        41
#
#     accuracy                           0.86       216
#    macro avg       0.79      0.79      0.79       216
# weighted avg       0.86      0.86      0.86       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.77      0.83        13
#      neutral       0.97      0.99      0.98       186
#     positive       0.86      0.71      0.77        17
#
#     accuracy                           0.96       216
#    macro avg       0.91      0.82      0.86       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.71      0.83        14
#      neutral       0.95      0.99      0.97       185
#     positive       0.92      0.71      0.80        17
#
#     accuracy                           0.95       216
#    macro avg       0.96      0.80      0.87       216
# weighted avg       0.95      0.95      0.95       216
#
# Launching training on 2 GPUs.
# 627 627
# Nearest checkpoint: 540
# Threshold: 88051.6015625
# Samples above threshold: 73
# Acquired samples: 73
# Sampling duration: 9.537648677825928 seconds
# New train size: 208
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.6990914344787598 | ACCURACY: 0.7902 | F1 MACRO: 0.8812 | F1 MICRO: 0.8827
# EPOCH 2 | LOSS: 3.255734443664551 | ACCURACY: 0.7954 | F1 MACRO: 0.8838 | F1 MICRO: 0.8853
# EPOCH 3 | LOSS: 2.839773416519165 | ACCURACY: 0.7946 | F1 MACRO: 0.879 | F1 MICRO: 0.8824
# EPOCH 4 | LOSS: 2.660597324371338 | ACCURACY: 0.8214 | F1 MACRO: 0.8972 | F1 MICRO: 0.898
# EPOCH 5 | LOSS: 2.596813678741455 | ACCURACY: 0.8452 | F1 MACRO: 0.907 | F1 MICRO: 0.9089
# EPOCH 6 | LOSS: 2.6266555786132812 | ACCURACY: 0.878 | F1 MACRO: 0.9237 | F1 MICRO: 0.9263
# EPOCH 7 | LOSS: 2.5335192680358887 | ACCURACY: 0.9144 | F1 MACRO: 0.9448 | F1 MICRO: 0.9473
# EPOCH 8 | LOSS: 2.5596296787261963 | ACCURACY: 0.9256 | F1 MACRO: 0.9511 | F1 MICRO: 0.9538
# EPOCH 9 | LOSS: 2.520214080810547 | ACCURACY: 0.9286 | F1 MACRO: 0.953 | F1 MICRO: 0.9557
# EPOCH 10 | LOSS: 2.4092657566070557 | ACCURACY: 0.9278 | F1 MACRO: 0.9524 | F1 MICRO: 0.9551
# aspect: ACCURACY 0.9286 | F1 MACRO 0.953 | F1 MICRO 0.9557
#               precision    recall  f1-score   support
#
#         fuel       0.95      1.00      0.97       187
#      machine       0.94      0.99      0.96       175
#       others       0.87      0.89      0.88       158
#         part       0.91      0.97      0.94       158
#        price       0.97      1.00      0.99       192
#      service       0.96      1.00      0.98       191
#
#    micro avg       0.94      0.98      0.96      1061
#    macro avg       0.93      0.97      0.95      1061
# weighted avg       0.94      0.98      0.96      1061
#  samples avg       0.94      0.98      0.95      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 13.325400352478027 | ACCURACY: 0.9198 | F1 MACRO: 0.9117 | F1 MICRO: 0.9198
# EPOCH 2 | LOSS: 11.258313179016113 | ACCURACY: 0.9283 | F1 MACRO: 0.921 | F1 MICRO: 0.9283
# EPOCH 3 | LOSS: 8.901193618774414 | ACCURACY: 0.9241 | F1 MACRO: 0.9166 | F1 MICRO: 0.9241
# EPOCH 4 | LOSS: 8.445823669433594 | ACCURACY: 0.9367 | F1 MACRO: 0.9281 | F1 MICRO: 0.9367
# EPOCH 5 | LOSS: 7.997738838195801 | ACCURACY: 0.9156 | F1 MACRO: 0.9003 | F1 MICRO: 0.9156
# EPOCH 6 | LOSS: 7.587867259979248 | ACCURACY: 0.9409 | F1 MACRO: 0.934 | F1 MICRO: 0.9409
# EPOCH 7 | LOSS: 7.534883499145508 | ACCURACY: 0.9409 | F1 MACRO: 0.9335 | F1 MICRO: 0.9409
# EPOCH 8 | LOSS: 7.456314563751221 | ACCURACY: 0.9241 | F1 MACRO: 0.917 | F1 MICRO: 0.9241
# EPOCH 9 | LOSS: 7.418765544891357 | ACCURACY: 0.9325 | F1 MACRO: 0.9254 | F1 MICRO: 0.9325
# EPOCH 10 | LOSS: 7.457851886749268 | ACCURACY: 0.9367 | F1 MACRO: 0.9266 | F1 MICRO: 0.9367
# sentiment: ACCURACY 0.9409 | F1 MACRO 0.9335 | F1 MICRO 0.9409
#               precision    recall  f1-score   support
#
#     negative       0.89      0.94      0.91        77
#     positive       0.97      0.94      0.96       160
#
#     accuracy                           0.94       237
#    macro avg       0.93      0.94      0.93       237
# weighted avg       0.94      0.94      0.94       237
#
# --------------------------------------------------
# Iteration 208: Accuracy: 0.929, F1 Micro: 0.929, F1 Macro: 0.871
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.91      0.91        11
#      neutral       0.98      1.00      0.99       181
#     positive       1.00      0.83      0.91        24
#
#     accuracy                           0.98       216
#    macro avg       0.96      0.91      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.73      0.69      0.71        16
#      neutral       0.93      0.98      0.95       167
#     positive       0.83      0.61      0.70        33
#
#     accuracy                           0.90       216
#    macro avg       0.83      0.76      0.79       216
# weighted avg       0.90      0.90      0.90       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.75      0.86        12
#      neutral       0.88      0.90      0.89       152
#     positive       0.71      0.69      0.70        52
#
#     accuracy                           0.84       216
#    macro avg       0.86      0.78      0.82       216
# weighted avg       0.84      0.84      0.84       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.87      0.85        23
#      neutral       0.91      0.97      0.94       152
#     positive       0.93      0.68      0.79        41
#
#     accuracy                           0.91       216
#    macro avg       0.89      0.84      0.86       216
# weighted avg       0.91      0.91      0.90       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.77      0.83        13
#      neutral       0.97      1.00      0.99       186
#     positive       0.93      0.76      0.84        17
#
#     accuracy                           0.97       216
#    macro avg       0.94      0.84      0.89       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.93      0.93        14
#      neutral       0.98      0.99      0.99       185
#     positive       1.00      0.82      0.90        17
#
#     accuracy                           0.98       216
#    macro avg       0.97      0.92      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Launching training on 2 GPUs.
# 591 591
# Nearest checkpoint: 540
# Threshold: 88478.9609375
# Samples above threshold: 66
# Acquired samples: 66
# Sampling duration: 11.093271017074585 seconds
# New train size: 274
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.293461561203003 | ACCURACY: 0.7902 | F1 MACRO: 0.8812 | F1 MICRO: 0.8827
# EPOCH 2 | LOSS: 2.8352038860321045 | ACCURACY: 0.7976 | F1 MACRO: 0.884 | F1 MICRO: 0.8858
# EPOCH 3 | LOSS: 2.562809467315674 | ACCURACY: 0.8356 | F1 MACRO: 0.9036 | F1 MICRO: 0.9046
# EPOCH 4 | LOSS: 2.4259989261627197 | ACCURACY: 0.8579 | F1 MACRO: 0.9154 | F1 MICRO: 0.9162
# EPOCH 5 | LOSS: 2.4255096912384033 | ACCURACY: 0.9085 | F1 MACRO: 0.9413 | F1 MICRO: 0.9437
# EPOCH 6 | LOSS: 2.3227288722991943 | ACCURACY: 0.9211 | F1 MACRO: 0.9484 | F1 MICRO: 0.9512
# EPOCH 7 | LOSS: 2.317326784133911 | ACCURACY: 0.9435 | F1 MACRO: 0.9626 | F1 MICRO: 0.9647
# EPOCH 8 | LOSS: 2.2354116439819336 | ACCURACY: 0.9368 | F1 MACRO: 0.9579 | F1 MICRO: 0.9604
# EPOCH 9 | LOSS: 2.0829482078552246 | ACCURACY: 0.9435 | F1 MACRO: 0.9634 | F1 MICRO: 0.9649
# EPOCH 10 | LOSS: 2.00201153755188 | ACCURACY: 0.939 | F1 MACRO: 0.9587 | F1 MICRO: 0.9616
# aspect: ACCURACY 0.9435 | F1 MACRO 0.9634 | F1 MICRO 0.9649
#               precision    recall  f1-score   support
#
#         fuel       0.97      1.00      0.99       187
#      machine       0.95      0.99      0.97       175
#       others       0.83      0.97      0.90       158
#         part       0.97      0.94      0.96       158
#        price       0.97      0.99      0.98       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.95      0.98      0.96      1061
#    macro avg       0.95      0.98      0.96      1061
# weighted avg       0.95      0.98      0.97      1061
#  samples avg       0.95      0.99      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 9.768543243408203 | ACCURACY: 0.8686 | F1 MACRO: 0.8445 | F1 MICRO: 0.8686
# EPOCH 2 | LOSS: 8.716371536254883 | ACCURACY: 0.911 | F1 MACRO: 0.9042 | F1 MICRO: 0.911
# EPOCH 3 | LOSS: 6.93569803237915 | ACCURACY: 0.9068 | F1 MACRO: 0.8925 | F1 MICRO: 0.9068
# EPOCH 4 | LOSS: 6.181480884552002 | ACCURACY: 0.9153 | F1 MACRO: 0.9054 | F1 MICRO: 0.9153
# EPOCH 5 | LOSS: 5.898249626159668 | ACCURACY: 0.911 | F1 MACRO: 0.9027 | F1 MICRO: 0.911
# EPOCH 6 | LOSS: 5.696447372436523 | ACCURACY: 0.9025 | F1 MACRO: 0.8922 | F1 MICRO: 0.9025
# EPOCH 7 | LOSS: 5.576483249664307 | ACCURACY: 0.9068 | F1 MACRO: 0.8983 | F1 MICRO: 0.9068
# EPOCH 8 | LOSS: 5.7107110023498535 | ACCURACY: 0.9195 | F1 MACRO: 0.9093 | F1 MICRO: 0.9195
# EPOCH 9 | LOSS: 5.487475872039795 | ACCURACY: 0.8941 | F1 MACRO: 0.8842 | F1 MICRO: 0.8941
# EPOCH 10 | LOSS: 5.441456317901611 | ACCURACY: 0.9068 | F1 MACRO: 0.8933 | F1 MICRO: 0.9068
# sentiment: ACCURACY 0.9195 | F1 MACRO 0.9093 | F1 MICRO 0.9195
#               precision    recall  f1-score   support
#
#     negative       0.87      0.88      0.88        78
#     positive       0.94      0.94      0.94       158
#
#     accuracy                           0.92       236
#    macro avg       0.91      0.91      0.91       236
# weighted avg       0.92      0.92      0.92       236
#
# --------------------------------------------------
# Iteration 274: Accuracy: 0.9336, F1 Micro: 0.9336, F1 Macro: 0.8689
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.82      0.90        11
#      neutral       0.98      1.00      0.99       181
#     positive       0.95      0.88      0.91        24
#
#     accuracy                           0.98       216
#    macro avg       0.98      0.90      0.93       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.69      0.76        16
#      neutral       0.94      0.99      0.96       167
#     positive       0.86      0.73      0.79        33
#
#     accuracy                           0.93       216
#    macro avg       0.88      0.80      0.84       216
# weighted avg       0.92      0.93      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.67      0.73        12
#      neutral       0.86      0.95      0.90       152
#     positive       0.79      0.58      0.67        52
#
#     accuracy                           0.84       216
#    macro avg       0.82      0.73      0.76       216
# weighted avg       0.84      0.84      0.83       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.74      0.74      0.74        23
#      neutral       0.95      0.96      0.95       152
#     positive       0.85      0.80      0.83        41
#
#     accuracy                           0.91       216
#    macro avg       0.84      0.83      0.84       216
# weighted avg       0.91      0.91      0.91       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.77      0.80        13
#      neutral       0.97      0.99      0.98       186
#     positive       0.93      0.76      0.84        17
#
#     accuracy                           0.96       216
#    macro avg       0.91      0.84      0.87       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.98      1.00      0.99       185
#     positive       1.00      0.88      0.94        17
#
#     accuracy                           0.99       216
#    macro avg       0.99      0.94      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 550 550
# Nearest checkpoint: 540
# Threshold: 88478.6171875
# Samples above threshold: 59
# Acquired samples: 59
# Sampling duration: 12.368157386779785 seconds
# New train size: 333
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.430173397064209 | ACCURACY: 0.7924 | F1 MACRO: 0.8822 | F1 MICRO: 0.8837
# EPOCH 2 | LOSS: 2.950700044631958 | ACCURACY: 0.7999 | F1 MACRO: 0.8854 | F1 MICRO: 0.8871
# EPOCH 3 | LOSS: 2.580533027648926 | ACCURACY: 0.8341 | F1 MACRO: 0.901 | F1 MICRO: 0.9025
# EPOCH 4 | LOSS: 2.5193097591400146 | ACCURACY: 0.8884 | F1 MACRO: 0.9272 | F1 MICRO: 0.9313
# EPOCH 5 | LOSS: 2.51601243019104 | ACCURACY: 0.9189 | F1 MACRO: 0.9476 | F1 MICRO: 0.95
# EPOCH 6 | LOSS: 2.4268319606781006 | ACCURACY: 0.9345 | F1 MACRO: 0.956 | F1 MICRO: 0.9589
# EPOCH 7 | LOSS: 2.3127057552337646 | ACCURACY: 0.9427 | F1 MACRO: 0.9615 | F1 MICRO: 0.964
# EPOCH 8 | LOSS: 2.1775588989257812 | ACCURACY: 0.942 | F1 MACRO: 0.9612 | F1 MICRO: 0.9637
# EPOCH 9 | LOSS: 2.0273258686065674 | ACCURACY: 0.9405 | F1 MACRO: 0.9603 | F1 MICRO: 0.9627
# EPOCH 10 | LOSS: 1.9793076515197754 | ACCURACY: 0.9412 | F1 MACRO: 0.9606 | F1 MICRO: 0.9631
# aspect: ACCURACY 0.9427 | F1 MACRO 0.9615 | F1 MICRO 0.964
#               precision    recall  f1-score   support
#
#         fuel       0.97      1.00      0.99       187
#      machine       0.95      0.99      0.97       175
#       others       0.91      0.87      0.89       158
#         part       0.94      0.96      0.95       158
#        price       0.96      0.99      0.98       192
#      service       0.97      1.00      0.99       191
#
#    micro avg       0.96      0.97      0.96      1061
#    macro avg       0.95      0.97      0.96      1061
# weighted avg       0.96      0.97      0.96      1061
#  samples avg       0.96      0.97      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 8.999359130859375 | ACCURACY: 0.9278 | F1 MACRO: 0.9167 | F1 MICRO: 0.9278
# EPOCH 2 | LOSS: 7.063770294189453 | ACCURACY: 0.8859 | F1 MACRO: 0.854 | F1 MICRO: 0.8859
# EPOCH 3 | LOSS: 6.492469310760498 | ACCURACY: 0.9049 | F1 MACRO: 0.8896 | F1 MICRO: 0.9049
# EPOCH 4 | LOSS: 5.689751148223877 | ACCURACY: 0.924 | F1 MACRO: 0.9114 | F1 MICRO: 0.924
# EPOCH 5 | LOSS: 5.383691787719727 | ACCURACY: 0.9125 | F1 MACRO: 0.8991 | F1 MICRO: 0.9125
# EPOCH 6 | LOSS: 5.301122665405273 | ACCURACY: 0.9125 | F1 MACRO: 0.8956 | F1 MICRO: 0.9125
# EPOCH 7 | LOSS: 5.067848205566406 | ACCURACY: 0.9049 | F1 MACRO: 0.8923 | F1 MICRO: 0.9049
# EPOCH 8 | LOSS: 5.0649518966674805 | ACCURACY: 0.9125 | F1 MACRO: 0.8948 | F1 MICRO: 0.9125
# EPOCH 9 | LOSS: 4.921064376831055 | ACCURACY: 0.924 | F1 MACRO: 0.9114 | F1 MICRO: 0.924
# EPOCH 10 | LOSS: 4.867463111877441 | ACCURACY: 0.9125 | F1 MACRO: 0.8971 | F1 MICRO: 0.9125
# sentiment: ACCURACY 0.9278 | F1 MACRO 0.9167 | F1 MICRO 0.9278
#               precision    recall  f1-score   support
#
#     negative       0.84      0.94      0.89        79
#     positive       0.97      0.92      0.95       184
#
#     accuracy                           0.93       263
#    macro avg       0.91      0.93      0.92       263
# weighted avg       0.93      0.93      0.93       263
#
# --------------------------------------------------
# Iteration 333: Accuracy: 0.9352, F1 Micro: 0.9352, F1 Macro: 0.8779
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.98      1.00      0.99       181
#     positive       1.00      0.92      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       0.99      0.94      0.97       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.82      0.88      0.85        16
#      neutral       0.95      0.98      0.97       167
#     positive       0.93      0.76      0.83        33
#
#     accuracy                           0.94       216
#    macro avg       0.90      0.87      0.88       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.62      0.83      0.71        12
#      neutral       0.93      0.84      0.88       152
#     positive       0.67      0.81      0.73        52
#
#     accuracy                           0.83       216
#    macro avg       0.74      0.83      0.77       216
# weighted avg       0.85      0.83      0.83       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.81      0.91      0.86        23
#      neutral       0.94      0.98      0.96       152
#     positive       1.00      0.76      0.86        41
#
#     accuracy                           0.93       216
#    macro avg       0.91      0.88      0.89       216
# weighted avg       0.94      0.93      0.93       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.77      0.80        13
#      neutral       0.97      0.99      0.98       186
#     positive       0.92      0.71      0.80        17
#
#     accuracy                           0.96       216
#    macro avg       0.91      0.82      0.86       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.79      0.85        14
#      neutral       0.97      1.00      0.99       185
#     positive       0.93      0.76      0.84        17
#
#     accuracy                           0.97       216
#    macro avg       0.94      0.85      0.89       216
# weighted avg       0.97      0.97      0.97       216
#
# Launching training on 2 GPUs.
# 512 512
# Nearest checkpoint: 540
# Threshold: 88361.796875
# Samples above threshold: 54
# Acquired samples: 54
# Sampling duration: 12.976004362106323 seconds
# New train size: 387
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.335472345352173 | ACCURACY: 0.7902 | F1 MACRO: 0.8812 | F1 MICRO: 0.8827
# EPOCH 2 | LOSS: 2.7635531425476074 | ACCURACY: 0.8028 | F1 MACRO: 0.8741 | F1 MICRO: 0.8832
# EPOCH 3 | LOSS: 2.513665199279785 | ACCURACY: 0.8586 | F1 MACRO: 0.9156 | F1 MICRO: 0.9167
# EPOCH 4 | LOSS: 2.4492626190185547 | ACCURACY: 0.9226 | F1 MACRO: 0.9503 | F1 MICRO: 0.9521
# EPOCH 5 | LOSS: 2.4122116565704346 | ACCURACY: 0.9182 | F1 MACRO: 0.9438 | F1 MICRO: 0.9485
# EPOCH 6 | LOSS: 2.2420644760131836 | ACCURACY: 0.9449 | F1 MACRO: 0.9637 | F1 MICRO: 0.9657
# EPOCH 7 | LOSS: 2.135852575302124 | ACCURACY: 0.9501 | F1 MACRO: 0.9677 | F1 MICRO: 0.969
# EPOCH 8 | LOSS: 2.0081279277801514 | ACCURACY: 0.9427 | F1 MACRO: 0.962 | F1 MICRO: 0.964
# EPOCH 9 | LOSS: 1.9217219352722168 | ACCURACY: 0.9442 | F1 MACRO: 0.9632 | F1 MICRO: 0.9651
# EPOCH 10 | LOSS: 1.8586270809173584 | ACCURACY: 0.9516 | F1 MACRO: 0.9681 | F1 MICRO: 0.9698
# aspect: ACCURACY 0.9516 | F1 MACRO 0.9681 | F1 MICRO 0.9698
#               precision    recall  f1-score   support
#
#         fuel       0.98      0.99      0.99       187
#      machine       0.95      0.98      0.96       175
#       others       0.90      0.93      0.92       158
#         part       0.95      0.98      0.96       158
#        price       0.97      0.99      0.98       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.96      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 7.426415920257568 | ACCURACY: 0.9255 | F1 MACRO: 0.9119 | F1 MICRO: 0.9255
# EPOCH 2 | LOSS: 5.863050937652588 | ACCURACY: 0.9333 | F1 MACRO: 0.9238 | F1 MICRO: 0.9333
# EPOCH 3 | LOSS: 5.133299350738525 | ACCURACY: 0.9451 | F1 MACRO: 0.9371 | F1 MICRO: 0.9451
# EPOCH 4 | LOSS: 4.767749786376953 | ACCURACY: 0.9412 | F1 MACRO: 0.9336 | F1 MICRO: 0.9412
# EPOCH 5 | LOSS: 4.557215213775635 | ACCURACY: 0.9373 | F1 MACRO: 0.9271 | F1 MICRO: 0.9373
# EPOCH 6 | LOSS: 4.397266864776611 | ACCURACY: 0.9412 | F1 MACRO: 0.931 | F1 MICRO: 0.9412
# EPOCH 7 | LOSS: 4.228431701660156 | ACCURACY: 0.9333 | F1 MACRO: 0.9243 | F1 MICRO: 0.9333
# EPOCH 8 | LOSS: 4.076491832733154 | ACCURACY: 0.9255 | F1 MACRO: 0.9178 | F1 MICRO: 0.9255
# EPOCH 9 | LOSS: 4.173724174499512 | ACCURACY: 0.9373 | F1 MACRO: 0.9286 | F1 MICRO: 0.9373
# EPOCH 10 | LOSS: 4.071203708648682 | ACCURACY: 0.9333 | F1 MACRO: 0.9238 | F1 MICRO: 0.9333
# sentiment: ACCURACY 0.9451 | F1 MACRO 0.9371 | F1 MICRO 0.9451
#               precision    recall  f1-score   support
#
#     negative       0.89      0.94      0.91        80
#     positive       0.97      0.95      0.96       175
#
#     accuracy                           0.95       255
#    macro avg       0.93      0.94      0.94       255
# weighted avg       0.95      0.95      0.95       255
#
# --------------------------------------------------
# Iteration 387: Accuracy: 0.9468, F1 Micro: 0.9468, F1 Macro: 0.9036
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.96      0.96      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.95      0.97       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.81      0.84        16
#      neutral       0.96      0.98      0.97       167
#     positive       0.88      0.85      0.86        33
#
#     accuracy                           0.94       216
#    macro avg       0.90      0.88      0.89       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.82      0.75      0.78        12
#      neutral       0.91      0.92      0.92       152
#     positive       0.75      0.73      0.74        52
#
#     accuracy                           0.87       216
#    macro avg       0.82      0.80      0.81       216
# weighted avg       0.86      0.87      0.87       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.87      0.83        23
#      neutral       0.94      0.99      0.96       152
#     positive       0.94      0.71      0.81        41
#
#     accuracy                           0.92       216
#    macro avg       0.89      0.85      0.87       216
# weighted avg       0.92      0.92      0.92       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.77      0.83        13
#      neutral       0.98      0.99      0.99       186
#     positive       0.94      0.88      0.91        17
#
#     accuracy                           0.97       216
#    macro avg       0.94      0.88      0.91       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.99      1.00      0.99       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.96      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 461 461
# Nearest checkpoint: 540
# Threshold: 88532.875
# Samples above threshold: 48
# Acquired samples: 48
# Sampling duration: 13.691740274429321 seconds
# New train size: 435
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.230593204498291 | ACCURACY: 0.7939 | F1 MACRO: 0.8826 | F1 MICRO: 0.8842
# EPOCH 2 | LOSS: 2.5937016010284424 | ACCURACY: 0.8356 | F1 MACRO: 0.9024 | F1 MICRO: 0.904
# EPOCH 3 | LOSS: 2.4371590614318848 | ACCURACY: 0.8631 | F1 MACRO: 0.9127 | F1 MICRO: 0.917
# EPOCH 4 | LOSS: 2.3348820209503174 | ACCURACY: 0.9323 | F1 MACRO: 0.9562 | F1 MICRO: 0.958
# EPOCH 5 | LOSS: 2.2704100608825684 | ACCURACY: 0.9435 | F1 MACRO: 0.9623 | F1 MICRO: 0.9646
# EPOCH 6 | LOSS: 2.095346450805664 | ACCURACY: 0.9427 | F1 MACRO: 0.9621 | F1 MICRO: 0.9642
# EPOCH 7 | LOSS: 1.9857417345046997 | ACCURACY: 0.9397 | F1 MACRO: 0.9596 | F1 MICRO: 0.9621
# EPOCH 8 | LOSS: 1.8667373657226562 | ACCURACY: 0.9509 | F1 MACRO: 0.9676 | F1 MICRO: 0.9692
# EPOCH 9 | LOSS: 1.834316611289978 | ACCURACY: 0.9479 | F1 MACRO: 0.9655 | F1 MICRO: 0.9674
# EPOCH 10 | LOSS: 1.7823004722595215 | ACCURACY: 0.9516 | F1 MACRO: 0.9677 | F1 MICRO: 0.9697
# aspect: ACCURACY 0.9516 | F1 MACRO 0.9677 | F1 MICRO 0.9697
#               precision    recall  f1-score   support
#
#         fuel       0.97      0.99      0.98       187
#      machine       0.94      0.99      0.97       175
#       others       0.91      0.92      0.91       158
#         part       0.96      0.96      0.96       158
#        price       0.97      1.00      0.99       192
#      service       0.99      1.00      0.99       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.96      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.96      0.98      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 7.301236152648926 | ACCURACY: 0.9243 | F1 MACRO: 0.9167 | F1 MICRO: 0.9243
# EPOCH 2 | LOSS: 5.746078014373779 | ACCURACY: 0.9283 | F1 MACRO: 0.9204 | F1 MICRO: 0.9283
# EPOCH 3 | LOSS: 4.723052501678467 | ACCURACY: 0.9522 | F1 MACRO: 0.9457 | F1 MICRO: 0.9522
# EPOCH 4 | LOSS: 4.4816060066223145 | ACCURACY: 0.9243 | F1 MACRO: 0.9071 | F1 MICRO: 0.9243
# EPOCH 5 | LOSS: 4.22735595703125 | ACCURACY: 0.9482 | F1 MACRO: 0.9409 | F1 MICRO: 0.9482
# EPOCH 6 | LOSS: 4.255860328674316 | ACCURACY: 0.9402 | F1 MACRO: 0.9314 | F1 MICRO: 0.9402
# EPOCH 7 | LOSS: 4.1470208168029785 | ACCURACY: 0.9562 | F1 MACRO: 0.9497 | F1 MICRO: 0.9562
# EPOCH 8 | LOSS: 4.008376121520996 | ACCURACY: 0.9442 | F1 MACRO: 0.9366 | F1 MICRO: 0.9442
# EPOCH 9 | LOSS: 3.979750633239746 | ACCURACY: 0.9442 | F1 MACRO: 0.9349 | F1 MICRO: 0.9442
# EPOCH 10 | LOSS: 3.8568148612976074 | ACCURACY: 0.9442 | F1 MACRO: 0.9339 | F1 MICRO: 0.9442
# sentiment: ACCURACY 0.9562 | F1 MACRO 0.9497 | F1 MICRO 0.9562
#               precision    recall  f1-score   support
#
#     negative       0.91      0.95      0.93        79
#     positive       0.98      0.96      0.97       172
#
#     accuracy                           0.96       251
#    macro avg       0.95      0.95      0.95       251
# weighted avg       0.96      0.96      0.96       251
#
# --------------------------------------------------
# Iteration 435: Accuracy: 0.9537, F1 Micro: 0.9537, F1 Macro: 0.9071
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.98      0.99      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.98       216
#    macro avg       0.98      0.94      0.96       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.69      0.79        16
#      neutral       0.95      0.99      0.97       167
#     positive       0.87      0.79      0.83        33
#
#     accuracy                           0.94       216
#    macro avg       0.91      0.82      0.86       216
# weighted avg       0.93      0.94      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.82      0.75      0.78        12
#      neutral       0.93      0.94      0.94       152
#     positive       0.83      0.83      0.83        52
#
#     accuracy                           0.90       216
#    macro avg       0.86      0.84      0.85       216
# weighted avg       0.90      0.90      0.90       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.79      0.96      0.86        23
#      neutral       0.97      0.99      0.98       152
#     positive       0.97      0.78      0.86        41
#
#     accuracy                           0.94       216
#    macro avg       0.91      0.91      0.90       216
# weighted avg       0.95      0.94      0.94       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.77      0.87        13
#      neutral       0.97      1.00      0.98       186
#     positive       0.93      0.76      0.84        17
#
#     accuracy                           0.97       216
#    macro avg       0.97      0.84      0.90       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.99      1.00      0.99       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.96      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 418 418
# Nearest checkpoint: 540
# Threshold: 88430.328125
# Samples above threshold: 43
# Acquired samples: 43
# Sampling duration: 14.448806762695312 seconds
# New train size: 478
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.1521503925323486 | ACCURACY: 0.7894 | F1 MACRO: 0.8768 | F1 MICRO: 0.88
# EPOCH 2 | LOSS: 2.5238473415374756 | ACCURACY: 0.8333 | F1 MACRO: 0.8984 | F1 MICRO: 0.901
# EPOCH 3 | LOSS: 2.3720736503601074 | ACCURACY: 0.8988 | F1 MACRO: 0.9373 | F1 MICRO: 0.9386
# EPOCH 4 | LOSS: 2.295687198638916 | ACCURACY: 0.9435 | F1 MACRO: 0.9638 | F1 MICRO: 0.965
# EPOCH 5 | LOSS: 2.2190167903900146 | ACCURACY: 0.9405 | F1 MACRO: 0.96 | F1 MICRO: 0.9627
# EPOCH 6 | LOSS: 2.044368028640747 | ACCURACY: 0.9427 | F1 MACRO: 0.9622 | F1 MICRO: 0.9642
# EPOCH 7 | LOSS: 1.9325846433639526 | ACCURACY: 0.9494 | F1 MACRO: 0.966 | F1 MICRO: 0.9682
# EPOCH 8 | LOSS: 1.8962990045547485 | ACCURACY: 0.9442 | F1 MACRO: 0.9615 | F1 MICRO: 0.9648
# EPOCH 9 | LOSS: 1.8188787698745728 | ACCURACY: 0.9539 | F1 MACRO: 0.9696 | F1 MICRO: 0.9711
# EPOCH 10 | LOSS: 1.7374355792999268 | ACCURACY: 0.9606 | F1 MACRO: 0.9742 | F1 MICRO: 0.9753
# aspect: ACCURACY 0.9606 | F1 MACRO 0.9742 | F1 MICRO 0.9753
#               precision    recall  f1-score   support
#
#         fuel       0.97      0.99      0.98       187
#      machine       0.95      0.99      0.97       175
#       others       0.92      0.94      0.93       158
#         part       0.98      0.99      0.98       158
#        price       0.97      1.00      0.99       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.96      0.99      0.98      1061
#    macro avg       0.96      0.99      0.97      1061
# weighted avg       0.96      0.99      0.98      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.399730682373047 | ACCURACY: 0.9395 | F1 MACRO: 0.9323 | F1 MICRO: 0.9395
# EPOCH 2 | LOSS: 4.795714378356934 | ACCURACY: 0.9234 | F1 MACRO: 0.9157 | F1 MICRO: 0.9234
# EPOCH 3 | LOSS: 4.201461315155029 | ACCURACY: 0.9355 | F1 MACRO: 0.9257 | F1 MICRO: 0.9355
# EPOCH 4 | LOSS: 4.016364097595215 | ACCURACY: 0.9516 | F1 MACRO: 0.9446 | F1 MICRO: 0.9516
# EPOCH 5 | LOSS: 3.8168249130249023 | ACCURACY: 0.9113 | F1 MACRO: 0.8941 | F1 MICRO: 0.9113
# EPOCH 6 | LOSS: 3.5229344367980957 | ACCURACY: 0.9435 | F1 MACRO: 0.9366 | F1 MICRO: 0.9435
# EPOCH 7 | LOSS: 3.5970618724823 | ACCURACY: 0.9234 | F1 MACRO: 0.9089 | F1 MICRO: 0.9234
# EPOCH 8 | LOSS: 3.5224382877349854 | ACCURACY: 0.9315 | F1 MACRO: 0.9191 | F1 MICRO: 0.9315
# EPOCH 9 | LOSS: 3.5044336318969727 | ACCURACY: 0.9234 | F1 MACRO: 0.9115 | F1 MICRO: 0.9234
# EPOCH 10 | LOSS: 3.38765811920166 | ACCURACY: 0.9395 | F1 MACRO: 0.9323 | F1 MICRO: 0.9395
# sentiment: ACCURACY 0.9516 | F1 MACRO 0.9446 | F1 MICRO 0.9516
#               precision    recall  f1-score   support
#
#     negative       0.91      0.94      0.92        79
#     positive       0.97      0.96      0.96       169
#
#     accuracy                           0.95       248
#    macro avg       0.94      0.95      0.94       248
# weighted avg       0.95      0.95      0.95       248
#
# --------------------------------------------------
# Iteration 478: Accuracy: 0.9483, F1 Micro: 0.9483, F1 Macro: 0.8977
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.98      0.99      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.98       216
#    macro avg       0.98      0.94      0.96       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.75      0.83        16
#      neutral       0.95      0.99      0.97       167
#     positive       0.90      0.79      0.84        33
#
#     accuracy                           0.94       216
#    macro avg       0.92      0.84      0.88       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.75      0.75        12
#      neutral       0.91      0.93      0.92       152
#     positive       0.79      0.73      0.76        52
#
#     accuracy                           0.88       216
#    macro avg       0.82      0.80      0.81       216
# weighted avg       0.87      0.88      0.87       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.79      0.96      0.86        23
#      neutral       0.97      0.99      0.98       152
#     positive       0.97      0.78      0.86        41
#
#     accuracy                           0.94       216
#    macro avg       0.91      0.91      0.90       216
# weighted avg       0.95      0.94      0.94       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.77      0.83        13
#      neutral       0.97      1.00      0.98       186
#     positive       0.92      0.71      0.80        17
#
#     accuracy                           0.96       216
#    macro avg       0.93      0.83      0.87       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.98      1.00      0.99       185
#     positive       1.00      0.88      0.94        17
#
#     accuracy                           0.99       216
#    macro avg       0.99      0.94      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# 374 374
# Nearest checkpoint: 540
# Threshold: 88553.3828125
# Samples above threshold: 39
# Acquired samples: 39
# Sampling duration: 15.332758903503418 seconds
# New train size: 517
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 3.2414491176605225 | ACCURACY: 0.8043 | F1 MACRO: 0.8874 | F1 MICRO: 0.8889
# EPOCH 2 | LOSS: 2.600166082382202 | ACCURACY: 0.8467 | F1 MACRO: 0.9087 | F1 MICRO: 0.91
# EPOCH 3 | LOSS: 2.430450201034546 | ACCURACY: 0.9271 | F1 MACRO: 0.9522 | F1 MICRO: 0.9545
# EPOCH 4 | LOSS: 2.3819985389709473 | ACCURACY: 0.9412 | F1 MACRO: 0.9597 | F1 MICRO: 0.9629
# EPOCH 5 | LOSS: 2.168093204498291 | ACCURACY: 0.9479 | F1 MACRO: 0.9653 | F1 MICRO: 0.9672
# EPOCH 6 | LOSS: 2.017556667327881 | ACCURACY: 0.9554 | F1 MACRO: 0.9713 | F1 MICRO: 0.9724
# EPOCH 7 | LOSS: 1.929905652999878 | ACCURACY: 0.9516 | F1 MACRO: 0.9684 | F1 MICRO: 0.9698
# EPOCH 8 | LOSS: 1.832383394241333 | ACCURACY: 0.9501 | F1 MACRO: 0.9665 | F1 MICRO: 0.9686
# EPOCH 9 | LOSS: 1.8017797470092773 | ACCURACY: 0.9487 | F1 MACRO: 0.9649 | F1 MICRO: 0.9676
# EPOCH 10 | LOSS: 1.728346347808838 | ACCURACY: 0.9539 | F1 MACRO: 0.9694 | F1 MICRO: 0.9711
# aspect: ACCURACY 0.9554 | F1 MACRO 0.9713 | F1 MICRO 0.9724
# ...
#      service       0.99      1.00      1.00       191
#
#    micro avg       0.97      0.98      0.97      1061
#    macro avg       0.96      0.98      0.97      1061
# weighted avg       0.97      0.98      0.97      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.8467373847961426 | ACCURACY: 0.8821 | F1 MACRO: 0.8593 | F1 MICRO: 0.8821
# EPOCH 2 | LOSS: 2.985179901123047 | ACCURACY: 0.9278 | F1 MACRO: 0.9204 | F1 MICRO: 0.9278
# EPOCH 3 | LOSS: 2.5941998958587646 | ACCURACY: 0.9392 | F1 MACRO: 0.9313 | F1 MICRO: 0.9392
# EPOCH 4 | LOSS: 2.432711362838745 | ACCURACY: 0.9392 | F1 MACRO: 0.9296 | F1 MICRO: 0.9392
# EPOCH 5 | LOSS: 2.228490114212036 | ACCURACY: 0.9202 | F1 MACRO: 0.9096 | F1 MICRO: 0.9202
# EPOCH 6 | LOSS: 2.2300662994384766 | ACCURACY: 0.9392 | F1 MACRO: 0.9321 | F1 MICRO: 0.9392
# EPOCH 7 | LOSS: 2.092590570449829 | ACCURACY: 0.924 | F1 MACRO: 0.9155 | F1 MICRO: 0.924
# EPOCH 8 | LOSS: 2.090869426727295 | ACCURACY: 0.9506 | F1 MACRO: 0.943 | F1 MICRO: 0.9506
# EPOCH 9 | LOSS: 2.0579071044921875 | ACCURACY: 0.9354 | F1 MACRO: 0.9263 | F1 MICRO: 0.9354
# EPOCH 10 | LOSS: 2.0418777465820312 | ACCURACY: 0.9354 | F1 MACRO: 0.9288 | F1 MICRO: 0.9354
# sentiment: ACCURACY 0.9506 | F1 MACRO 0.943 | F1 MICRO 0.9506
#               precision    recall  f1-score   support
#
#     negative       0.94      0.91      0.92        85
#     positive       0.96      0.97      0.96       178
#
#     accuracy                           0.95       263
#    macro avg       0.95      0.94      0.94       263
# weighted avg       0.95      0.95      0.95       263
#
# --------------------------------------------------
# Iteration 831: Accuracy: 0.9568, F1 Micro: 0.9568, F1 Macro: 0.9212
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.97      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.75      0.83        16
#      neutral       0.95      0.98      0.96       167
#     positive       0.83      0.76      0.79        33
#
#     accuracy                           0.93       216
#    macro avg       0.90      0.83      0.86       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.92      0.92        12
#      neutral       0.95      0.92      0.93       152
#     positive       0.77      0.83      0.80        52
#
#     accuracy                           0.90       216
#    macro avg       0.88      0.89      0.88       216
# weighted avg       0.90      0.90      0.90       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.88      1.00      0.94        23
#      neutral       0.97      0.99      0.98       152
#     positive       1.00      0.83      0.91        41
#
#     accuracy                           0.96       216
#    macro avg       0.95      0.94      0.94       216
# weighted avg       0.97      0.96      0.96       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.77      0.80        13
#      neutral       0.98      0.99      0.99       186
#     positive       0.93      0.82      0.87        17
#
#     accuracy                           0.97       216
#    macro avg       0.92      0.86      0.89       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       1.00      1.00      1.00       185
#     positive       0.94      1.00      0.97        17
#
#     accuracy                           1.00       216
#    macro avg       0.98      0.98      0.98       216
# weighted avg       1.00      1.00      1.00       216
#
# Launching training on 2 GPUs.
# 33 33
# Nearest checkpoint: 864
# Threshold: 88350.75
# Samples above threshold: 4
# Acquired samples: 25
# Sampling duration: 20.402517080307007 seconds
# New train size: 856
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.948241710662842 | ACCURACY: 0.8259 | F1 MACRO: 0.897 | F1 MICRO: 0.8988
# EPOCH 2 | LOSS: 2.4089274406433105 | ACCURACY: 0.9278 | F1 MACRO: 0.9512 | F1 MICRO: 0.9545
# EPOCH 3 | LOSS: 2.208099126815796 | ACCURACY: 0.9561 | F1 MACRO: 0.9712 | F1 MICRO: 0.9725
# EPOCH 4 | LOSS: 2.0596096515655518 | ACCURACY: 0.9576 | F1 MACRO: 0.9718 | F1 MICRO: 0.9734
# EPOCH 5 | LOSS: 1.8845590353012085 | ACCURACY: 0.9561 | F1 MACRO: 0.9698 | F1 MICRO: 0.9723
# EPOCH 6 | LOSS: 1.7902262210845947 | ACCURACY: 0.9539 | F1 MACRO: 0.9693 | F1 MICRO: 0.971
# EPOCH 7 | LOSS: 1.69927978515625 | ACCURACY: 0.9591 | F1 MACRO: 0.9718 | F1 MICRO: 0.974
# EPOCH 8 | LOSS: 1.671041488647461 | ACCURACY: 0.9583 | F1 MACRO: 0.9715 | F1 MICRO: 0.9736
# EPOCH 9 | LOSS: 1.614965558052063 | ACCURACY: 0.9568 | F1 MACRO: 0.9706 | F1 MICRO: 0.9727
# EPOCH 10 | LOSS: 1.5824414491653442 | ACCURACY: 0.9643 | F1 MACRO: 0.9763 | F1 MICRO: 0.9775
# aspect: ACCURACY 0.9643 | F1 MACRO 0.9763 | F1 MICRO 0.9775
#               precision    recall  f1-score   support
#
#         fuel       0.98      0.99      0.99       187
#      machine       0.96      0.97      0.97       175
#       others       0.93      0.95      0.94       158
#         part       0.97      0.99      0.98       158
#        price       0.98      0.99      0.99       192
#      service       1.00      1.00      1.00       191
#
#    micro avg       0.97      0.98      0.98      1061
#    macro avg       0.97      0.98      0.98      1061
# weighted avg       0.97      0.98      0.98      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.722618341445923 | ACCURACY: 0.9139 | F1 MACRO: 0.9058 | F1 MICRO: 0.9139
# EPOCH 2 | LOSS: 2.9109227657318115 | ACCURACY: 0.9101 | F1 MACRO: 0.9029 | F1 MICRO: 0.9101
# EPOCH 3 | LOSS: 2.414153814315796 | ACCURACY: 0.9251 | F1 MACRO: 0.9171 | F1 MICRO: 0.9251
# EPOCH 4 | LOSS: 2.3422446250915527 | ACCURACY: 0.9288 | F1 MACRO: 0.9178 | F1 MICRO: 0.9288
# EPOCH 5 | LOSS: 2.2017574310302734 | ACCURACY: 0.9326 | F1 MACRO: 0.9254 | F1 MICRO: 0.9326
# EPOCH 6 | LOSS: 2.0969223976135254 | ACCURACY: 0.9363 | F1 MACRO: 0.9282 | F1 MICRO: 0.9363
# EPOCH 7 | LOSS: 2.138982057571411 | ACCURACY: 0.9288 | F1 MACRO: 0.921 | F1 MICRO: 0.9288
# EPOCH 8 | LOSS: 2.043818950653076 | ACCURACY: 0.9213 | F1 MACRO: 0.906 | F1 MICRO: 0.9213
# EPOCH 9 | LOSS: 2.0322978496551514 | ACCURACY: 0.9438 | F1 MACRO: 0.9359 | F1 MICRO: 0.9438
# EPOCH 10 | LOSS: 1.98417067527771 | ACCURACY: 0.9438 | F1 MACRO: 0.937 | F1 MICRO: 0.9438
# sentiment: ACCURACY 0.9438 | F1 MACRO 0.937 | F1 MICRO 0.9438
#               precision    recall  f1-score   support
#
#     negative       0.88      0.95      0.92        86
#     positive       0.98      0.94      0.96       181
#
#     accuracy                           0.94       267
#    macro avg       0.93      0.95      0.94       267
# weighted avg       0.95      0.94      0.94       267
#
# --------------------------------------------------
# Iteration 856: Accuracy: 0.9529, F1 Micro: 0.9529, F1 Macro: 0.9117
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.91      0.91        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.92      0.92      0.92        24
#
#     accuracy                           0.98       216
#    macro avg       0.94      0.94      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.81      0.84        16
#      neutral       0.95      0.97      0.96       167
#     positive       0.84      0.79      0.81        33
#
#     accuracy                           0.93       216
#    macro avg       0.89      0.86      0.87       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.83      0.87        12
#      neutral       0.93      0.92      0.93       152
#     positive       0.76      0.81      0.79        52
#
#     accuracy                           0.89       216
#    macro avg       0.87      0.85      0.86       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.82      1.00      0.90        23
#      neutral       0.97      0.99      0.98       152
#     positive       0.97      0.78      0.86        41
#
#     accuracy                           0.95       216
#    macro avg       0.92      0.92      0.91       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.92      0.89        13
#      neutral       0.98      0.99      0.99       186
#     positive       0.93      0.76      0.84        17
#
#     accuracy                           0.97       216
#    macro avg       0.92      0.89      0.91       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.93      1.00      0.97        14
#      neutral       1.00      1.00      1.00       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           1.00       216
#    macro avg       0.98      0.98      0.98       216
# weighted avg       1.00      1.00      1.00       216
#
# Launching training on 2 GPUs.
# 8 8
# Nearest checkpoint: 864
# Threshold: 88327.75
# Samples above threshold: 1
# Acquired samples: 8
# Sampling duration: 20.795639276504517 seconds
# New train size: 864
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.9787611961364746 | ACCURACY: 0.8237 | F1 MACRO: 0.8978 | F1 MICRO: 0.899
# EPOCH 2 | LOSS: 2.3877077102661133 | ACCURACY: 0.9234 | F1 MACRO: 0.9496 | F1 MICRO: 0.9523
# EPOCH 3 | LOSS: 2.233565330505371 | ACCURACY: 0.9561 | F1 MACRO: 0.9717 | F1 MICRO: 0.9728
# EPOCH 4 | LOSS: 1.993683099746704 | ACCURACY: 0.9621 | F1 MACRO: 0.9753 | F1 MICRO: 0.9763
# EPOCH 5 | LOSS: 1.8644750118255615 | ACCURACY: 0.9583 | F1 MACRO: 0.9726 | F1 MICRO: 0.9738
# EPOCH 6 | LOSS: 1.7838935852050781 | ACCURACY: 0.9576 | F1 MACRO: 0.9714 | F1 MICRO: 0.9732
# EPOCH 7 | LOSS: 1.720037579536438 | ACCURACY: 0.9643 | F1 MACRO: 0.976 | F1 MICRO: 0.9775
# EPOCH 8 | LOSS: 1.6466511487960815 | ACCURACY: 0.9613 | F1 MACRO: 0.9739 | F1 MICRO: 0.9756
# EPOCH 9 | LOSS: 1.6141786575317383 | ACCURACY: 0.9628 | F1 MACRO: 0.9749 | F1 MICRO: 0.9766
# EPOCH 10 | LOSS: 1.5759574174880981 | ACCURACY: 0.9591 | F1 MACRO: 0.9723 | F1 MICRO: 0.974
# aspect: ACCURACY 0.9643 | F1 MACRO 0.976 | F1 MICRO 0.9775
#               precision    recall  f1-score   support
#
#         fuel       0.99      0.99      0.99       187
#      machine       0.95      0.99      0.97       175
#       others       0.94      0.93      0.93       158
#         part       0.97      0.97      0.97       158
#        price       0.98      1.00      0.99       192
#      service       0.99      1.00      0.99       191
#
#    micro avg       0.97      0.98      0.98      1061
#    macro avg       0.97      0.98      0.98      1061
# weighted avg       0.97      0.98      0.98      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.7490580081939697 | ACCURACY: 0.9 | F1 MACRO: 0.8911 | F1 MICRO: 0.9
# EPOCH 2 | LOSS: 2.7978641986846924 | ACCURACY: 0.9259 | F1 MACRO: 0.9136 | F1 MICRO: 0.9259
# EPOCH 3 | LOSS: 2.4993274211883545 | ACCURACY: 0.9222 | F1 MACRO: 0.9132 | F1 MICRO: 0.9222
# EPOCH 4 | LOSS: 2.285444974899292 | ACCURACY: 0.9185 | F1 MACRO: 0.9098 | F1 MICRO: 0.9185
# EPOCH 5 | LOSS: 2.2092525959014893 | ACCURACY: 0.9074 | F1 MACRO: 0.8943 | F1 MICRO: 0.9074
# EPOCH 6 | LOSS: 2.161383867263794 | ACCURACY: 0.9037 | F1 MACRO: 0.8954 | F1 MICRO: 0.9037
# EPOCH 7 | LOSS: 2.1001436710357666 | ACCURACY: 0.9222 | F1 MACRO: 0.9123 | F1 MICRO: 0.9222
# EPOCH 8 | LOSS: 2.0228018760681152 | ACCURACY: 0.9296 | F1 MACRO: 0.9159 | F1 MICRO: 0.9296
# EPOCH 9 | LOSS: 2.0410008430480957 | ACCURACY: 0.9222 | F1 MACRO: 0.9141 | F1 MICRO: 0.9222
# EPOCH 10 | LOSS: 1.9869427680969238 | ACCURACY: 0.9407 | F1 MACRO: 0.9337 | F1 MICRO: 0.9407
# sentiment: ACCURACY 0.9407 | F1 MACRO 0.9337 | F1 MICRO 0.9407
#               precision    recall  f1-score   support
#
#     negative       0.86      0.97      0.91        86
#     positive       0.98      0.93      0.96       184
#
#     accuracy                           0.94       270
#    macro avg       0.92      0.95      0.93       270
# weighted avg       0.95      0.94      0.94       270
#
# --------------------------------------------------
# Iteration 864: Accuracy: 0.9514, F1 Micro: 0.9514, F1 Macro: 0.9076
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.92      1.00      0.96        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.99       216
#    macro avg       0.96      0.97      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.75      0.77        16
#      neutral       0.95      0.98      0.96       167
#     positive       0.79      0.70      0.74        33
#
#     accuracy                           0.92       216
#    macro avg       0.85      0.81      0.83       216
# weighted avg       0.91      0.92      0.91       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.79      0.92      0.85        12
#      neutral       0.95      0.92      0.93       152
#     positive       0.76      0.79      0.77        52
#
#     accuracy                           0.89       216
#    macro avg       0.83      0.88      0.85       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.77      1.00      0.87        23
#      neutral       0.98      0.98      0.98       152
#     positive       0.94      0.78      0.85        41
#
#     accuracy                           0.94       216
#    macro avg       0.90      0.92      0.90       216
# weighted avg       0.95      0.94      0.94       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.92      0.89        13
#      neutral       0.98      0.99      0.99       186
#     positive       1.00      0.82      0.90        17
#
#     accuracy                           0.98       216
#    macro avg       0.95      0.91      0.93       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.93      1.00      0.97        14
#      neutral       1.00      1.00      1.00       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           1.00       216
#    macro avg       0.98      0.98      0.98       216
# weighted avg       1.00      1.00      1.00       216
#
# Total sampling time: 393.81 seconds
# Total runtime: 3469.32977104187 seconds
