# %%
import os
import time
import math
import torch
import random
import warnings
import numpy as np
import pandas as pd
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
from torch.multiprocessing import Manager
from torch.utils.data import DataLoader, Dataset
from torch.utils.data.sampler import SubsetRandomSampler
from sklearn.model_selection import train_test_split
from accelerate import Accelerator, notebook_launcher
from transformers import BertTokenizer, BertModel, BertConfig
from sklearn.metrics import precision_recall_fscore_support, f1_score, classification_report

# %% [markdown]
# # SETUP

# %%
warnings.filterwarnings('ignore')

# %%
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic=True
    torch.backends.cudnn.benchmark=False

set_seed(42)

# %% [markdown]
# # GLOBAL VARIABLES

# %%
manager = Manager()

# Shared resources
aspect_accuracies = manager.list()
aspect_f1_micros = manager.list()
aspect_f1_macros = manager.list()
sentiment_accuracies = manager.list()
sentiment_f1_micros = manager.list()
sentiment_f1_macros = manager.list()
accuracies = manager.list()
f1_micros = manager.list()
f1_macros = manager.list()

new_sample_data = manager.list()
new_sample_labels = manager.list()

# Non shared resources
filename = 'casa-comal'
epochs = 10
batch_size = 16
sequence_length = 48

aspect_list = ['fuel', 'machine', 'others', 'part', 'price', 'service']
aspect_mapping = {'fuel': 0, 'machine': 1, 'others': 2, 'part': 3, 'price': 4, 'service': 5 }
label_mapping = {"negative": 0, "neutral": 1, 'positive': 2}
ignored_keys = ['labels', 'ori_text', 'ori_label', 'ori_indices', 'aspect', 'sampler_loss_weight', 'all_labeled_mask']

# %% [markdown]
# # LOAD AND PREPROCESS DATA

# %%
train_data = pd.read_csv('/kaggle/input/casa-dataset/train_preprocess.csv', encoding='latin-1')
val_data = pd.read_csv('/kaggle/input/casa-dataset/valid_preprocess.csv', encoding='latin-1')
test_data = pd.read_csv('/kaggle/input/casa-dataset/test_preprocess.csv', encoding='latin-1')

data = pd.concat([train_data, val_data, test_data], ignore_index=True)

data.head()
# Out:
#                                             sentence      fuel   machine  \
# 0  Saya memakai Honda Jazz GK5 tahun 2014 ( perta...   neutral   neutral
# 1  Avanza kenapa jadi boros bensin begini dah ah....  negative   neutral
# 2  saran ku dan pengalaman ku , mending beli mobi...  positive  positive
# 3  Dari segi harga juga pajero lebih mahal 30 jut...   neutral   neutral
# 4                     Kalo menurut gw enak pajero si   neutral   neutral
#
#      others     part     price  service
# 0  positive  neutral   neutral  neutral
# 1   neutral  neutral   neutral  neutral
# 2   neutral  neutral   neutral  neutral
# 3   neutral  neutral  positive  neutral
# 4  positive  neutral   neutral  neutral

# %%
train_data, val_data = train_test_split(data, test_size=0.2, random_state=42, shuffle=False)

# %%
train_labels = train_data.columns[1:]
val_labels = val_data.columns[1:]

# Extract features and labels for training and validation
X_train = train_data['sentence'].values
y_train = train_data[train_labels].values
X_val = val_data['sentence'].values
y_val = val_data[val_labels].values

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
# Out:
# (864,) (864, 6)
# (216,) (216, 6)

# %% [markdown]
# # BULDING DATASET

# %%
tokenizer = BertTokenizer.from_pretrained('indobenchmark/indobert-base-p1')
review_token = '[REVIEW]'
aspect_token = '[ASPECT]'
special_tokens_dict = {'additional_special_tokens': [review_token, aspect_token]}
num_added_tokens = tokenizer.add_special_tokens(special_tokens_dict)
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/229k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.53k [00:00<?, ?B/s]

# %%
class AspectDetectionDataset(Dataset):
    def __init__(self, data, labels, tokenizer, label2id, aspect_list, max_length=48):
        # Initialize dataset with data, tokenizer, and label mappings
        self.data = data
        self.tokenizer = tokenizer
        self.label2id = label2id
        self.maxlength = sequence_length  # Maximum token length for input sequences
        self.all_labels_num = len(aspect_list)  # Total number of labels
        self.aspect_list = aspect_list
        self.pair_wise_sampled = None  # Tracks sampling status of label pairs
        self.gt_labels = labels  # Ground truth labels in one-hot format
        self.all_labeled_mask = None  # Indicates whether all labels of a sample have been queried
        self.max_length = max_length
        self.init()  # Initializes sampling and label mask states

    def init(self):
        # Initialize sampled pairs and mask for all data
        self.pair_wise_sampled = torch.ones(len(self.data), self.all_labels_num)
        self.all_labeled_mask = torch.zeros(len(self.data))  # Initially, no data is fully labeled

    def get_label_Cardinality(self):
        # Compute label cardinality, representing average positive labels per sample in the labeled pool
        labed_cnt = torch.sum(self.all_labeled_mask)  # Total number of samples fully labeled
        original_labels = torch.tensor([[self.label2id[label] for label in labels] for labels in self.gt_labels], dtype=torch.float32)
        encoded_labels = torch.tensor([[1 if label == 1 else 0 for label in labels] for labels in original_labels], dtype=torch.float32)
        all_labed_pos_label_cnt = torch.sum(self.all_labeled_mask.unsqueeze(-1) * encoded_labels)
        return all_labed_pos_label_cnt / labed_cnt  # Average number of positive labels per fully labeled sample

    def update_data(self, query_example_indices, query_label_indices=None, init_time=False):
        # Update dataset with new labeled data points and labels after each query cycle
        if query_label_indices is not None:
            ones = torch.ones(self.all_labels_num)
            for example_idx, label_idx in zip(query_example_indices, query_label_indices):
                # Access individual data and update based on queried label
                one_data = self.__getitem__(example_idx)
                one_label = one_data[1][label_idx]
                if one_label == 0:
                    # Set pair-wise sampled state for newly queried labels
                    self.pair_wise_sampled[example_idx][label_idx] = 1
                else:
                    self.pair_wise_sampled[example_idx][label_idx] = 1
                
                # Update all_labeled_mask if all labels for a sample are queried
                if torch.sum(ones - self.pair_wise_sampled[example_idx]) == 0:
                    self.all_labeled_mask[example_idx] = 1
        else:
            # Mark all labels as queried for each example if only examples are specified
            for example_idx in query_example_indices:
                ones = torch.ones(self.all_labels_num)
                self.pair_wise_sampled[example_idx] = ones
                self.all_labeled_mask[example_idx] = 1

    def get_labeled_set(self):
        # Return list of indices for samples that have been fully labeled
        labeled_set = []
        for idx, mask in enumerate(self.all_labeled_mask):
            if mask != 0:
                labeled_set.append(idx)
        return labeled_set

    def __len__(self):
        # Return the number of samples in the dataset
        return len(self.data)

    def __getitem__(self, idx):
        text = self.data[idx] 
        original_labels = torch.tensor([self.label2id[label] for label in self.gt_labels[idx]], dtype=torch.float32)
        encoded_labels = torch.tensor([1 if label == 1 else 0 for label in original_labels], dtype=torch.float32)

        # Tokenize the raw text and apply padding/truncation to reach maxlength
        encoding = self.tokenizer(
            text,
            padding='max_length',
            truncation=True,
            max_length=self.max_length,
            return_tensors="pt"
        )

        input_ids = encoding['input_ids'].squeeze(0)  # Remove batch dimension
        input_type_ids = encoding.get('token_type_ids', torch.zeros_like(input_ids))
        input_mask = encoding['attention_mask'].squeeze(0)
        text_inputs = [input_ids, input_type_ids, input_mask]
        sampler_loss_weight = self.pair_wise_sampled[idx]  # Weight for active learning sample 

        inputs_list = [text_inputs, encoded_labels, idx, sampler_loss_weight, self.all_labeled_mask[idx], text, original_labels]
        return inputs_list

# %%
class SentimentAnalysisDataset(Dataset):
    def __init__(self, data, labels, aspects, indices, tokenizer, label2id, max_length):
        # Initialize dataset with data, tokenizer, and label mappings
        self.data = data
        self.tokenizer = tokenizer
        self.label2id = label2id
        self.maxlength = sequence_length  # Maximum token length for input sequences
        self.all_labels_num = 2
        self.pair_wise_sampled = None  # Tracks sampling status of label pairs
        self.gt_labels = labels  # Ground truth labels in one-hot format
        self.all_labeled_mask = None  # Indicates whether all labels of a sample have been queried
        self.aspects = aspects
        self.indices = indices
        self.max_length = max_length
        self.init()  # Initializes sampling and label mask states

    def init(self):
        # Initialize sampled pairs and mask for all data
        self.pair_wise_sampled = torch.ones(len(self.data), self.all_labels_num)
        self.all_labeled_mask = torch.zeros(len(self.data))  # Initially, no data is fully labeled

    def get_label_Cardinality(self):
        # Compute label cardinality, representing average positive labels per sample in the labeled pool
        labed_cnt = torch.sum(self.all_labeled_mask)  # Total number of samples fully labeled
        all_labed_pos_label_cnt = torch.sum(self.all_labeled_mask.unsqueeze(-1) * self.gt_labels)
        return all_labed_pos_label_cnt / labed_cnt  # Average number of positive labels per fully labeled sample

    def update_data(self, query_example_indices, query_label_indices=None, init_time=False):
        # Update dataset with new labeled data points and labels after each query cycle
        if query_label_indices is not None:
            ones = torch.ones(self.all_labels_num)
            for example_idx, label_idx in zip(query_example_indices, query_label_indices):
                # Access individual data and update based on queried label
                one_data = self.__getitem__(example_idx)
                one_label = one_data[1][label_idx]
                if one_label == 0:
                    # Set pair-wise sampled state for newly queried labels
                    self.pair_wise_sampled[example_idx][label_idx] = 1
                else:
                    self.pair_wise_sampled[example_idx][label_idx] = 1
                
                # Update all_labeled_mask if all labels for a sample are queried
                if torch.sum(ones - self.pair_wise_sampled[example_idx]) == 0:
                    self.all_labeled_mask[example_idx] = 1
        else:
            # Mark all labels as queried for each example if only examples are specified
            for example_idx in query_example_indices:
                ones = torch.ones(self.all_labels_num)
                self.pair_wise_sampled[example_idx] = ones
                self.all_labeled_mask[example_idx] = 1

    def get_labeled_set(self):
        # Return list of indices for samples that have been fully labeled
        labeled_set = []
        for idx, mask in enumerate(self.all_labeled_mask):
            if mask != 0:
                labeled_set.append(idx)
        return labeled_set

    def __len__(self):
        # Return the number of samples in the dataset
        return len(self.data)

    def __getitem__(self, idx):
        text = aspect_token + ' ' + self.aspects[idx] + ' ' + review_token + ' ' + self.data[idx] 

        # Tokenize the raw text and apply padding/truncation to reach maxlength
        encoding = self.tokenizer(
            text,
            padding='max_length',
            truncation=True,
            max_length=self.max_length,
            return_tensors="pt"
        )

        if isinstance(self.gt_labels[idx], str):
            self.gt_labels[idx] = self.label2id[self.gt_labels[idx]]
        elif torch.is_tensor(self.gt_labels[idx]):
            self.gt_labels[idx] = int(self.gt_labels[idx].item())

        encoded_label = 1 if self.gt_labels[idx] == 2 else self.gt_labels[idx]
        one_hot_label = F.one_hot(torch.tensor(encoded_label, dtype=torch.long), num_classes=2).float()

        input_ids = encoding['input_ids'].squeeze(0)  # Remove batch dimension
        input_type_ids = encoding.get('token_type_ids', torch.zeros_like(input_ids))
        input_mask = encoding['attention_mask'].squeeze(0)
        text_inputs = [input_ids, input_type_ids, input_mask]
        sampler_loss_weight = self.pair_wise_sampled[idx]  # Weight for active learning sample 
        original_label = torch.tensor(self.gt_labels[idx], dtype=torch.long)
        aspect = self.aspects[idx]

        inputs_list = [text_inputs, one_hot_label, idx, sampler_loss_weight, self.all_labeled_mask[idx], text, original_label, aspect, self.indices[idx]]
        return inputs_list

# %%
def build_aspect_dataset(X_train, y_train, X_val, y_val, sequence_length, num_workers=4):
    train_dataset = AspectDetectionDataset(X_train, y_train, tokenizer, label_mapping, aspect_list, max_length=sequence_length)
    val_dataset = AspectDetectionDataset(X_val, y_val, tokenizer, label_mapping, aspect_list, max_length=sequence_length)
    
    train_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=batch_size, shuffle=True, pin_memory=True, num_workers=num_workers,
    )
    val_loader = torch.utils.data.DataLoader(
        val_dataset, batch_size=batch_size, shuffle=False, pin_memory=True, num_workers=num_workers, 
    )

    return train_loader, val_loader, train_dataset, val_dataset

# %%
def build_sentiment_dataset(device, train_dataset, val_dataset, aspect_detection_model, tokenizer, max_length=sequence_length):
    train_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=batch_size, shuffle=False, pin_memory=True, num_workers=4, 
    )
    val_loader = torch.utils.data.DataLoader(
        val_dataset, batch_size=batch_size, shuffle=False, pin_memory=True, num_workers=4, 
    )

    aspect_detection_model.to(device)
    aspect_detection_model.eval()

    train_data = []
    train_labels = []
    train_aspects = []
    train_indices = []

    val_data = []
    val_labels = []
    val_aspects = []
    val_indices = []

    # Transform train set
    with torch.no_grad():
        for batch in train_loader:
            input_ids, input_type_ids, input_mask = [x.to(device) for x in batch[0]]
            inputs_list = [input_ids, input_type_ids, input_mask, None]
            
            outputs = aspect_detection_model(inputs_list)
            preds = torch.sigmoid(outputs[0]).round()

            for i in range(len(preds)):
                for j in range(len(preds[i])):
                    if int(preds[i][j]) != 1:
                        train_aspects.append(aspect_list[j])
                        train_data.append(batch[5][i])
                        train_labels.append(batch[6][i][j])
                        train_indices.append(batch[2][i])
            
        # Transform validation set
        for batch in val_loader:
            input_ids, input_type_ids, input_mask = [x.to(device) for x in batch[0]]
            inputs_list = [input_ids, input_type_ids, input_mask, None]
            
            outputs = aspect_detection_model(inputs_list)
            preds = torch.sigmoid(outputs[0]).round()

            for i in range(len(preds)):
                for j in range(len(preds[i])):
                    if int(preds[i][j]) != 1:
                        val_aspects.append(aspect_list[j])
                        val_data.append(batch[5][i])
                        val_labels.append(batch[6][i][j])
                        val_indices.append(batch[2][i])

    train_dataset = SentimentAnalysisDataset(train_data, train_labels, train_aspects, train_indices, tokenizer, label_mapping, max_length=max_length)
    val_dataset = SentimentAnalysisDataset(val_data, val_labels, val_aspects, val_indices, tokenizer, label_mapping, max_length=max_length)

    train_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=batch_size, shuffle=True, pin_memory=True, num_workers=4, 
    )
    val_loader = torch.utils.data.DataLoader(
        val_dataset, batch_size=batch_size, shuffle=False, pin_memory=True, num_workers=4, 
    )

    return train_loader, val_loader, train_dataset, val_dataset

# %% [markdown]
# # DEFINE THE MODEL

# %%
class IndoBERT_Backbone(nn.Module):
    def __init__(self, label_num):
        super(IndoBERT_Backbone, self).__init__()
        self.label_num = label_num
        self.encoder = IndoBERT_Encoder(label_num)
        model_config = BertConfig.from_pretrained("indobenchmark/indobert-base-p1")
        self.clf = nn.Linear(model_config.hidden_size, label_num)
        nn.init.xavier_uniform_(self.clf.weight)

    def forward(self, inputs):
        encoder_out = self.encoder(inputs)
        out = self.clf(encoder_out)
        return out, encoder_out

class IndoBERT_Encoder(nn.Module):
    def __init__(self, label_num):
        super(IndoBERT_Encoder, self).__init__()
        self.label_num = label_num
        self.encoder = BertModel.from_pretrained(
            'indobenchmark/indobert-base-p1',
            num_labels=self.label_num,
        )
        
        self.encoder_init()

    def encoder_init(self):
        all_layers = ['embeddings', 'layer.0', 'layer.1', 'layer.2', 'layer.3', 'layer.4', 'layer.5', 'layer.6',
                      'layer.7', 'layer.8', 'layer.9', 'layer.10', 'layer.11', 'pooler']
        unfreeze_layers = all_layers[7:]
        for name, param in self.encoder.named_parameters():
            param.requires_grad = False
            for ele in unfreeze_layers:
                if ele in name:
                    param.requires_grad = True
                    break

    def forward(self, inputs):
        # Ensure each component in inputs is a tensor
        input_ids = torch.tensor(inputs[0]) if not isinstance(inputs[0], torch.Tensor) else inputs[0]
        token_type_ids = torch.tensor(inputs[1]) if not isinstance(inputs[1], torch.Tensor) else inputs[1]
        attention_mask = torch.tensor(inputs[2]) if not isinstance(inputs[2], torch.Tensor) else inputs[2]
        
        input_ids = input_ids.view(-1, input_ids.size(-1))  # Ensuring batch_size, sequence_length
        token_type_ids = token_type_ids.view(input_ids.size(0), -1)  # Reshaping to [batch_size, sequence_length]
        attention_mask = attention_mask.view(-1, attention_mask.size(-1))
        
        outputs = self.encoder(
            input_ids=input_ids,
            token_type_ids=token_type_ids,
            attention_mask=attention_mask,
        )
        cls_output = outputs.pooler_output
        return cls_output

# %%
class MLP_VAE(nn.Module):
    def __init__(self, hidden_size, device, label_num):
        super(MLP_VAE, self).__init__()
        self.device = device
        self.label_num = label_num
        self.cl_neg_mode = 2
        self.proto_size = 64
        self.hidden_size = hidden_size
        
        # Initial fully connected layer to project input to higher-dimensional space for each label
        self.fc0 = nn.Linear(self.hidden_size, self.label_num * 512)
        self.fc1 = nn.Linear(512, self.proto_size)  # Dimensionality reduction for prototypes

        # Adjust the number of label representations based on contrastive learning mode
        if self.cl_neg_mode == 0:
            cl_label_num = self.label_num  # Standard label number
        elif self.cl_neg_mode == 1:
            cl_label_num = self.label_num + 1  # Add one for negative prototype handling
            self.ins_neg_cnt = torch.zeros(1).to(device)
        elif self.cl_neg_mode == 2:
            cl_label_num = self.label_num * 2  # Double for positive and negative prototypes
            self.ins_neg_cnt = torch.zeros(self.label_num).to(device)
        self.cl_label_num = cl_label_num

        # Register buffer for label prototypes, aligned with CoMAL's prototype-based sampling
        self.register_buffer("prototypes", torch.zeros(self.cl_label_num, self.proto_size))
        self.ins_pos_cnt = torch.zeros(self.label_num).to(device)  # Track count of positive instances

        # Decoder and final aggregation layers
        self.fc3 = nn.Linear(self.proto_size, 512)
        self.agg = nn.Linear(self.label_num * 512, self.hidden_size)
        self.clf = nn.Linear(self.hidden_size, self.label_num)  # Classification layer

    def get_protos(self):
        return self.prototypes  # Return the prototypes for external use

    def reparameterize(self, mu, logvar):
        # VAE reparameterization trick for latent space sampling
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def reset_proto(self):
        # Reset prototype and count buffers
        self.ins_pos_cnt *= 0
        self.ins_neg_cnt *= 0
        self.prototypes *= 0

    def forward(self, x, labels=None, weights=None, reset_proto=False):
        if reset_proto:
            self.reset_proto()
        
        # Project input into sub-representations per label
        sub_rep_ori = self.fc0(x)
        sr_shape = sub_rep_ori.shape
        sub_rep_ori = sub_rep_ori.view(sr_shape[0], self.label_num, -1)  # Split per label

        # Further reduction to prototype size and decoding step
        sub_rep = self.fc1(sub_rep_ori)
        dec_sub_rep = self.fc3(sub_rep)

        dist_1 = None
        sub_rep_norm = F.normalize(sub_rep.data, dim=-1)  # Normalize for distance calculations

        if labels is not None and weights is not None:
            # Generate masks for positive and negative samples
            pos_mask = labels * weights
            neg_mask = (1 - labels) * weights
            pos_mask = pos_mask.unsqueeze(-1)
            neg_mask = neg_mask.unsqueeze(-1)

            # Update positive instance counts
            self.ins_pos_cnt += torch.sum(pos_mask.squeeze(-1), dim=0)

            # Update prototypes based on positive and negative samples
            feat = torch.sum(sub_rep_norm * pos_mask, dim=0)
            self.prototypes[:self.label_num] = self.prototypes[:self.label_num] * self.ins_pos_cnt.unsqueeze(-1) + feat

            # Handle different contrastive learning modes
            if self.cl_neg_mode == 2:
                feat_neg = torch.sum(sub_rep_norm * neg_mask, dim=0)
                self.ins_neg_cnt += torch.sum(neg_mask.squeeze(-1), dim=0)
                self.prototypes[self.label_num:] = self.prototypes[self.label_num:] * self.ins_neg_cnt.unsqueeze(-1) + feat_neg
            elif self.cl_neg_mode == 1:
                feat_neg = torch.sum(sub_rep_norm * neg_mask, dim=0)
                feat_neg = torch.sum(feat_neg, dim=0)
                self.ins_neg_cnt += torch.sum(neg_mask)
                self.prototypes[-1] = self.prototypes[-1] * self.ins_neg_cnt + feat_neg
            
            self.prototypes = F.normalize(self.prototypes, p=2, dim=-1)

        # Calculate distances between sub-representations and prototypes
        if self.cl_neg_mode == 2:
            dist_1 = torch.einsum('bld,ld->bl', [sub_rep_norm, self.prototypes[:self.label_num]])
            # print(dist_1[:3])
            dist_neg_1 = torch.einsum('bld,ld->bl', [sub_rep_norm, self.prototypes[self.label_num:]])
            dist_1 = torch.cat([dist_1, dist_neg_1], dim=1)  # Combine distances for positive and negative prototypes

        else:
            dist_1 = sub_rep_norm @ self.prototypes.T  

        # Decode and classify reconstructed input
        concat_sub_rep = dec_sub_rep.contiguous().view(dec_sub_rep.shape[0], -1)
        recon_x = self.agg(concat_sub_rep)
        recon_x_clf = self.clf(recon_x)

        return recon_x, sub_rep, recon_x_clf, dist_1  # Return reconstruction, sub-representation, classification, and distances

# %%
def get_cl_labels(labels, label_num, weight, cl_neg_mode=2):
    cl_labels = torch.zeros_like(labels, dtype=torch.long)
    cl_labels.fill_(label_num)
    example_idx, label_idx = torch.where(labels>=0.5)
    cl_labels[example_idx, label_idx] = label_idx #.float()
    cl_labels = cl_labels * weight + label_num * (1 - weight)
    if cl_neg_mode == 2:
        example_idx, label_idx = torch.where(labels < 0.5)
        cl_neg_labels = label_idx + label_num
        cl_labels[example_idx, label_idx] = cl_neg_labels.float()
        cl_labels = cl_labels * weight + 2 * label_num * (1 - weight)
    cl_labels = cl_labels.to(torch.int)
    return cl_labels

def get_cl_mask(cl_labels, label_num, batch_size, cl_neg_mode=2):
    mask = torch.eq(cl_labels[:batch_size], cl_labels.T).float()
    if cl_neg_mode == 0:
        neg_idx, _ = torch.where(cl_labels[:batch_size] >= label_num)
        neg_mask = torch.ones_like(mask)
        neg_mask[neg_idx] = 0
        neg_mask[:, neg_idx] = 0
        mask *= neg_mask
    elif cl_neg_mode == 1:
        neg_idx, _ = torch.where(cl_labels[:batch_size] > label_num)
        neg_mask = torch.ones_like(mask)
        neg_mask[neg_idx] = 0
        neg_mask[:, neg_idx] = 0
        mask *= neg_mask
    elif cl_neg_mode == 2:
        neg_idx, _ = torch.where(cl_labels[:batch_size] >= label_num * 2)
        neg_mask = torch.ones_like(mask)
        neg_mask[neg_idx] = 0
        neg_mask[:, neg_idx] = 0
        mask *= neg_mask
    else:
        neg_mask = torch.ones_like(mask)
    return mask, neg_mask

# %% [markdown]
# # DEFINE LOSSES

# %%
class SupConLoss(nn.Module):
    """Following Supervised Contrastive Learning:
        https://arxiv.org/pdf/2004.11362.pdf."""

    def __init__(self, temperature=0.07, base_temperature=0.07):
        super().__init__()
        self.temperature = temperature
        self.base_temperature = base_temperature

    def forward(self, features, mask, neg_mask=None, batch_size=-1, device=None, other_features=None):
        if mask is not None:
            # SupCon loss (Partial Label Mode)
            mask = mask.float().detach()
            # compute logits
            if other_features is None:
                anchor_dot_contrast = torch.div(
                    torch.matmul(features[:batch_size], features.T),
                    self.temperature)
            else:
                anchor_dot_contrast = torch.div(
                    torch.matmul(features[:batch_size], other_features.T),
                    self.temperature)

            # for numerical stability
            logits_max, _ = torch.max(anchor_dot_contrast, dim=1, keepdim=True)
            logits = anchor_dot_contrast - logits_max.detach()

            # mask-out self-contrast cases
            if neg_mask is None:
                logits_mask = torch.ones_like(mask)
            else:
                logits_mask = torch.scatter(
                    neg_mask,
                    1,
                    torch.arange(batch_size).view(-1, 1).to(device),
                    0
                )
            mask = mask * logits_mask

            # compute log_prob
            exp_logits = torch.exp(logits) * logits_mask
            log_prob = logits - torch.log(exp_logits.sum(1, keepdim=True) + 1e-12)
            # compute mean of log-likelihood over positive
            mean_log_prob_pos = (mask * log_prob).sum(1) / (mask.sum(1) + 1e-12)
            # loss
            loss = - (self.temperature / self.base_temperature) * mean_log_prob_pos
            loss = loss.mean()
        else:
            q = features[:batch_size]
            k = features[batch_size:batch_size * 2]
            queue = features[batch_size * 2:]
            l_pos = torch.einsum('nc,nc->n', [q, k]).unsqueeze(-1)
            # negative logits: NxK
            l_neg = torch.einsum('nc,kc->nk', [q, queue])
            # logits: Nx(1+K)
            logits = torch.cat([l_pos, l_neg], dim=1)

            # apply temperature
            logits /= self.temperature

            # labels: positive key indicators
            labels = torch.zeros(logits.shape[0], dtype=torch.long).cuda()
            loss = F.cross_entropy(logits, labels)

        return loss

# %% [markdown]
# # MODEL TRAINING AND TESTING

# %%
total_data = len(X_train) + len(X_val)
initial_train_size = int(0.05 * total_data)
checkpoints = [
    int(0.5 * total_data), 
    int(0.6 * total_data), 
    int(0.7 * total_data),
    len(X_train)
]
min_increment = 25

# %%
def compute_metrics(p, label, classes):
    preds = torch.tensor(p.predictions) # Sigmoid and threshold for multi-label
    labels = torch.tensor(p.label_ids)

    hamming_accuracy = (preds == labels).float().mean().item()

    # Standard multi-label precision, recall, and F1 metrics
    precision, recall, f1_micro, _ = precision_recall_fscore_support(labels, preds, average='micro', zero_division=0)
    _, _, f1_macro, _ = precision_recall_fscore_support(labels, preds, average='macro', zero_division=0)

    report = classification_report(
        labels, 
        preds, 
        labels=label,
        target_names=classes,
        zero_division=0
    ) 

    return {
        'accuracy': hamming_accuracy,
        'precision': precision,
        'recall': recall,
        'f1_micro': f1_micro,
        'f1_macro': f1_macro,
        'report': report
    }

# %%
def compute_metrics_overall(p, classes):
    preds = torch.tensor(p.predictions)
    labels = torch.tensor(p.label_ids)

    # Ensure it's in the correct shape
    if preds.shape != labels.shape:
        raise ValueError("Shape mismatch: predictions and labels must have the same shape.")

    # Hamming accuracy: proportion of correctly predicted labels over total labels
    hamming_accuracy = (preds == labels).float().mean().item()

    # Compute per-label (column-wise) precision, recall, F1
    precision_list, recall_list, f1_micro_list, f1_macro_list = [], [], [], []
    
    for i in range(labels.shape[1]):  # Loop through each column (multi-output)
        prec, rec, f1_micro, _ = precision_recall_fscore_support(
            labels[:, i], preds[:, i], average='micro', zero_division=0
        )
        _, _, f1_macro, _ = precision_recall_fscore_support(
            labels[:, i], preds[:, i], average='macro', zero_division=0
        )

        precision_list.append(prec)
        recall_list.append(rec)
        f1_micro_list.append(f1_micro)
        f1_macro_list.append(f1_macro)

    # Compute average metrics across all outputs
    precision = sum(precision_list) / len(precision_list)
    recall = sum(recall_list) / len(recall_list)
    f1_micro = sum(f1_micro_list) / len(f1_micro_list)
    f1_macro = sum(f1_macro_list) / len(f1_macro_list)

    # Generate classification report per output
    reports = [classification_report(labels[:, i], preds[:, i], target_names=classes, zero_division=0) for i in range(labels.shape[1])]

    return {
        'accuracy': hamming_accuracy,
        'precision': precision,
        'recall': recall,
        'f1_micro': f1_micro,
        'f1_macro': f1_macro,
        'reports': reports  # Returns list of reports, one for each output label
    }

# %%
def concat_test_result(outputs):
    outputs[0] = np.concatenate(outputs[0], axis=0)
    outputs[1] = np.concatenate(outputs[1], axis=0)
    outputs[2] = np.concatenate(outputs[2], axis=0)
    outputs[3] = np.concatenate(outputs[3], axis=0)
    outputs[4] = np.concatenate(outputs[4], axis=0)
    return outputs

def neaten_test_result(outputs, logits, labels, test_type):
    labels = labels.data.cpu().numpy()
    prob, pred = torch.topk(logits, 6 if test_type == 'aspect' else 2)
    prob = torch.sigmoid(prob).data.cpu().numpy()
    pred = pred.data.cpu().numpy()
    logits = torch.sigmoid(logits).data.cpu().numpy()
    pred_labels = np.zeros(logits.shape)
    pred_labels[logits >= 0.5] = 1
    outputs[0].append(labels)
    outputs[1].append(pred)
    outputs[2].append(prob)
    outputs[3].append(logits)
    outputs[4].append(pred_labels)
    
    return outputs

# %%
def train_total_sep2(aspect_datasets, dataloaders, trials, aspect_metrics, sentiment_metrics, metrics, current_train_size, label_num=-1, seed=42, total_patience=3):
    set_seed(seed)
    accelerator = Accelerator(mixed_precision='fp16')
    device = accelerator.device
    accelerator.print(accelerator.distributed_type)
    
    tasks = ['aspect', 'sentiment']
    sentiment_val_loader = None

    nearest_cp = current_train_size
    if nearest_cp not in checkpoints:
        for cp in checkpoints:
            if cp > current_train_size:
                nearest_cp = cp
                break
    percentage = math.ceil(nearest_cp / total_data * 100)

    for task in tasks:
        accelerator.print("--------------------------------------------------")
        if task == 'sentiment':
            accelerator.print("SENTIMENT ANALYSIS")
        else:
            accelerator.print("ASPECT DETECTION")
            
        accelerator.wait_for_everyone()
        best_score = {
            'accuracy': 0,
            'f1_micro': 0,
            'f1_macro': 0
        }  # Track best score for first phase
        best_score2 = {
            'accuracy': 0,
            'f1_micro': 0,
            'f1_macro': 0
        }  # Track best score for second phase
        second_phase = False  # Control flag for switching between training phases
        total_patience_cnt = 0
        models = {}

        # Initialize backbone model for task learning
        label_num = 6 if task == 'aspect' else 2
        models['backbone'] = IndoBERT_Backbone(label_num)
        optim_backbone = torch.optim.AdamW(models['backbone'].parameters(), lr=2e-5, weight_decay=0.01)

        # Initialize VAE module if specified (aligns with CoMAL's contrastive and auxiliary module)
        models['vae_module'] = MLP_VAE(768, device, label_num=label_num)
        optim_module = torch.optim.AdamW(models['vae_module'].parameters(), lr=2e-5, weight_decay=0.01)

        if task == 'sentiment':
            best_aspect_model = IndoBERT_Backbone(6)
            best_aspect_model.load_state_dict(torch.load(f"{filename}-aspect-p1-backbone-{trials+1}-{percentage}.pth"))
            train_loader, val_loader, _, _ = build_sentiment_dataset(
                device, aspect_datasets['train'], aspect_datasets['val'], best_aspect_model, tokenizer, max_length=sequence_length
            )
            sentiment_val_loader = val_loader
            
        else:
            train_loader = dataloaders['labeled']
            val_loader = dataloaders['test']

        accelerator.wait_for_everyone()
        models['backbone'], models['vae_module'], train_loader, val_loader = accelerator.prepare(
            models['backbone'], models['vae_module'], train_loader, val_loader
        )

        # Loop over epochs
        for epoch in range(1, epochs+1):
            if second_phase:
                models['backbone'].eval()  # Backbone frozen in second phase
            else:
                models['backbone'].train()
            models['vae_module'].train()

            # Iterate over labeled data for training
            total_loss = 0
            for data in train_loader:
                # Zero the gradients for all optimizers
                optim_backbone.zero_grad()
                optim_module.zero_grad()

                # Prepare inputs and labels for training
                labels, idx, loss_weight = [x.to(device) for x in data[1:4]]
                input_ids, input_type_ids, input_mask = [x.to(device) for x in data[0]]
                inputs_list = [input_ids, input_type_ids, input_mask, None]

                loss = 0

                # Forward pass through backbone model
                clf_out, encoder_cls = models['backbone'](inputs_list)

                # VAE training logic (aligns with CoMAL's multi-label decoupling and contrastive learning)
                loss2 = 0
                module_cls = encoder_cls.detach()  # Detach to prevent gradient flow to backbone

                # Forward pass through VAE module
                recon_x, latent_rep, recon_x_clf, _ = models['vae_module'](module_cls, labels=labels, weights=loss_weight, reset_proto=True)

                # Compute contrastive loss if enabled (aligns with CoMAL's use of contrastive learning)
                cl_labels = get_cl_labels(labels, label_num, loss_weight).view(-1)
                cl_labels_total = cl_labels.unsqueeze(-1)
                proj_total = latent_rep.view(-1, latent_rep.shape[-1])
                proj_total = F.normalize(proj_total, dim=-1)  # Normalize latent representation
                batch_size = clf_out.shape[0] * label_num
                mask, neg_mask = get_cl_mask(cl_labels_total, label_num, batch_size)

                criterion_cl = SupConLoss()  # Supervised contrastive loss function
                cl_loss = criterion_cl(proj_total, mask, neg_mask, batch_size, device)
                loss2 += cl_loss  # Add contrastive loss

                # Compute reconstruction and classification loss
                criterion_mse = nn.MSELoss()
                recon_mse_loss = criterion_mse(recon_x, module_cls)
                criterion_bce = nn.BCEWithLogitsLoss()
                recon_bce_loss = criterion_bce(recon_x_clf, labels.float())
                
                loss2 += recon_mse_loss + recon_bce_loss
                
                # Compute classification loss for the backbone (first phase)
                if not second_phase:
                    criterion = nn.BCEWithLogitsLoss()
                    clf_loss = criterion(clf_out, labels.float())
                    loss += clf_loss  # Add classification loss to total loss

                # Add VAE loss to total loss
                loss += loss2
                # Backpropagation step
                accelerator.backward(loss)
                
                total_loss += loss

                # Update weights based on current phase
                if second_phase:
                    optim_module.step()
                else:
                    optim_module.step()
                    optim_backbone.step()

            # Scheduler step for learning rate adjustment
            # if second_phase:
            #     accelerator.print('in second')
            
            result = {}
            outputs_clf = [[], [], [], [], []]
            outputs_dual = [[], [], [], [], []]
            match task:
                case 'aspect':
                    with torch.no_grad():
                        for data in val_loader:
                            input_ids, input_type_ids, input_mask = [x.to(device, non_blocking=True) for x in data[0]]
                            labels = data[1].to(device)
                            out = [input_ids, input_type_ids, input_mask, None]
                
                            clf_out, encoder_cls = models['backbone'](out)
                            outputs_clf = neaten_test_result(outputs_clf, clf_out, labels, task)

                            if 'vae_module' in models.keys():
                                _, _, recon_x_clf, _ = models['vae_module'](encoder_cls, reset_proto=False)
                                outputs_dual = neaten_test_result(outputs_dual, recon_x_clf, labels, task)

                    if second_phase:
                        outputs_dual = concat_test_result(outputs_dual)
                        preds = torch.tensor(outputs_dual[4], device=device)
                        labels = torch.tensor(outputs_dual[0], device=device)
                    else:
                        outputs_clf = concat_test_result(outputs_clf)
                        preds = torch.tensor(outputs_clf[4], device=device)
                        labels = torch.tensor(outputs_clf[0], device=device)

                    preds = accelerator.gather_for_metrics(preds)
                    labels = accelerator.gather_for_metrics(labels)
                        
                    result = compute_metrics(
                        type('EvalOutput', (object,), {'predictions': preds.cpu().numpy(), 'label_ids': labels.cpu().numpy()}),
                        None,
                        ['fuel', 'machine', 'others', 'part', 'price', 'service']
                    )
                case 'sentiment':
                    sentiment_val_outputs = []
                    with torch.no_grad():
                        for data in val_loader:
                            input_ids, input_type_ids, input_mask = [x.to(device, non_blocking=True) for x in data[0]]
                            labels = data[1].to(device)
                            out = [input_ids, input_type_ids, input_mask, None]
                        
                            clf_out, encoder_cls = models['backbone'](out)
                            clf_out = torch.sigmoid(clf_out)
                        
                            if 'vae_module' in models.keys():
                                _, _, recon_x_clf, _ = models['vae_module'](encoder_cls, reset_proto=False)
                                recon_x_clf = torch.sigmoid(recon_x_clf)

                            for i in range(len(clf_out)):
                                val_output = {
                                    'label': data[1][i],
                                    'aspect': data[7][i],
                                    'ori_indices': data[2][i],
                                    'pred': np.argmax(clf_out[i].cpu().numpy() if not second_phase else recon_x_clf[i].cpu().numpy()),
                                }
                                sentiment_val_outputs.append(val_output)

                    sentiment_val_outputs = accelerator.gather_for_metrics(sentiment_val_outputs)
                    unique_val_outputs = {(x['ori_indices'].item(), x['aspect']): x for x in sentiment_val_outputs}
                    sentiment_val_outputs = list(unique_val_outputs.values())

                    result = compute_metrics(
                        type('EvalOutput', (object,), {'predictions': [item['pred'] for item in sentiment_val_outputs], 'label_ids': [np.argmax(item['label'].cpu().numpy()) for item in sentiment_val_outputs]}),
                        [0, 1],
                        ['negative', 'positive']
                    )

            # if second_phase:
            #     if result["f1_micro"] >= best_score2['f1_micro']:
            #         total_patience_cnt = 0
            #         best_score2 = result
                    
            #         accelerator.wait_for_everyone()
            #         unwrapped_vae = accelerator.unwrap_model(models['vae_module'])
            #         if accelerator.is_local_main_process:
            #             accelerator.save(unwrapped_vae.state_dict(), f"{filename}-{task}-p2-vae-{trials+1}-{percentage}.pth")
            #     else:
            #         total_patience_cnt += 1
            #         if total_patience_cnt >= total_patience:
            #             break
            # else:
            if result["f1_micro"] >= best_score['f1_micro']:
                best_score = result

                accelerator.wait_for_everyone()
                unwrapped_backbone = accelerator.unwrap_model(models['backbone'])
                unwrapped_vae = accelerator.unwrap_model(models['vae_module'])
                
                if accelerator.is_local_main_process:
                    accelerator.save(unwrapped_backbone.state_dict(), f"{filename}-{task}-p1-backbone-{trials+1}-{percentage}.pth")
                    accelerator.save(unwrapped_vae.state_dict(), f"{filename}-{task}-p1-vae-{trials+1}-{percentage}.pth")
            # else:
            #     total_patience_cnt += 1
            #     if total_patience_cnt >= total_patience:
            #         total_patience_cnt = 0
            #         second_phase = True
                
            accelerator.print(f"EPOCH {epoch} | LOSS: {total_loss / len(dataloaders['labeled'])} | ACCURACY: {round(result['accuracy'], 4)} | F1 MACRO: {round(result['f1_macro'], 4)} | F1 MICRO: {round(result['f1_micro'], 4)}")

        if accelerator.is_local_main_process:
            if task == 'aspect':
                aspect_metrics[0].append(best_score['accuracy'])
                aspect_metrics[1].append(best_score['f1_micro'])
                aspect_metrics[2].append(best_score['f1_macro'])
            elif task == 'sentiment':
                sentiment_metrics[0].append(best_score['accuracy'])
                sentiment_metrics[1].append(best_score['f1_micro'])
                sentiment_metrics[2].append(best_score['f1_macro'])
        
        accelerator.print(f"{task}: ACCURACY {round(best_score['accuracy'], 4)} | F1 MACRO {round(best_score['f1_macro'], 4)} | F1 MICRO {round(best_score['f1_micro'], 4)}")
        accelerator.print(best_score['report'])

    # Compute overall metrics
    aspect_labels = []
    aspect_indices = []
    aspect_preds = []

    aspect_outputs = {}
    sentiment_outputs = []

    accelerator.wait_for_everyone()

    best_aspect_model = IndoBERT_Backbone(6)
    best_sentiment_model = IndoBERT_Backbone(2)

    best_aspect_model.load_state_dict(torch.load(f"{filename}-aspect-p1-backbone-{trials+1}-{percentage}.pth"))
    best_sentiment_model.load_state_dict(torch.load(f"{filename}-sentiment-p1-backbone-{trials+1}-{percentage}.pth"))

    best_aspect_model, best_sentiment_model, val_loader = accelerator.prepare(best_aspect_model, best_sentiment_model, dataloaders['test'])

    with torch.no_grad():
        for batch in val_loader:
            input_ids, input_type_ids, input_mask = [x.to(device) for x in batch[0]]
            inputs_list = [input_ids, input_type_ids, input_mask, None]
            clf_out, encoder_cls = best_aspect_model(inputs_list)
            preds = torch.sigmoid(clf_out).round()

            aspect_indices.append(accelerator.gather(batch[2]))
            aspect_labels.append(accelerator.gather(batch[6]))
            aspect_preds.append(accelerator.gather(preds))

        aspect_indices = torch.cat(aspect_indices).cpu().numpy()
        aspect_labels = torch.cat(aspect_labels).cpu().numpy()
        aspect_preds = torch.cat(aspect_preds).cpu().numpy()

        accelerator.wait_for_everyone()
        aspect_outputs = [
            {'ori_indices': aspect_indices[i], 
             'ori_labels': aspect_labels[i], 
             'pred': aspect_preds[i]}
            for i in range(len(aspect_preds))
        ]
        aspect_outputs = {x['ori_indices'].item(): x for x in aspect_outputs}
    
        for batch in sentiment_val_loader:
            input_ids, input_type_ids, input_mask = [x.to(device) for x in batch[0]]
            inputs_list = [input_ids, input_type_ids, input_mask, None]
            clf_out, encoder_cls = best_sentiment_model(inputs_list)
            preds = torch.sigmoid(clf_out).round()
    
            for i in range(len(preds)):
                output = {
                    'aspect': batch[7][i],
                    'ori_indices': batch[8][i],
                    'pred': np.argmax(preds[i].cpu().numpy()),
                }
                sentiment_outputs.append(output)

        sentiment_outputs = accelerator.gather_for_metrics(sentiment_outputs)
        sentiment_outputs = {(x['ori_indices'].item(), x['aspect']): x for x in sentiment_outputs}

    # Replcae non neutral aspect to its predicted sentiment
    accelerator.wait_for_everyone()
    if accelerator.is_main_process:
        i = -1
        for (ori_index, aspect), value in sentiment_outputs.items():
            aspect = aspect_mapping[aspect]
            aspect_outputs[ori_index]['pred'][aspect] = 2 if value['pred'] == 1.0 else value['pred']

        result = compute_metrics_overall(
            type('EvalOutput', (object,), {'predictions': [output['pred'] for output in aspect_outputs.values()], 'label_ids': [output['ori_labels'] for output in aspect_outputs.values()]}),
            ['negative', 'neutral', 'positive'],
        )

        accelerator.print("--------------------------------------------------")
        accelerator.print(f"Iteration {current_train_size}: Accuracy: {round(result['accuracy'], 4)}, F1 Micro: {round(result['f1_micro'], 4)}, F1 Macro: {round(result['f1_macro'], 4)}")
        accelerator.print("--------------------------------------------------")
        
        for i in range(len(train_labels)):
            accelerator.print(f"Aspect {aspect_list[i]} report:")
            accelerator.print(result['reports'][i])
            
        metrics[0].append(current_train_size)
        metrics[1].append(result['accuracy'])
        metrics[2].append(result['f1_micro'])
        metrics[3].append(result['f1_macro'])

# %% [markdown]
# # QUERY STRATEGY

# %%
def query_samples(filename, dataset, labeled_set, unlabeled_indices, num_labels, trials, sampling_dur, new_sample_data, new_sample_labels,
                  label_cardinality=None, labeled_subset=None, save_path=None, cl_neg_mode=2, n_samples=min_increment):
    accelerator = Accelerator(mixed_precision='fp16')
    device = accelerator.device

    models = {}
    tasks = ['aspect', 'sentiment']
    
    current_train_size = len(dataset.get_labeled_set())

    nearest_cp = current_train_size
    if nearest_cp not in checkpoints:
        for cp in checkpoints:
            if cp > current_train_size:
                nearest_cp = cp
                break
    percentage = math.ceil(nearest_cp / total_data * 100)

    for task in tasks:
        backbone = IndoBERT_Backbone(6 if task == 'aspect' else 2)
        vae = MLP_VAE(768, device, 6 if task == 'aspect' else 2)
        backbone.load_state_dict(torch.load(f"{filename}-{task}-p1-backbone-{trials+1}-{percentage}.pth"))
        models[f'{task}_backbone'] = backbone
        
        if os.path.exists(f'/kaggle/working/{filename}-{task}-p2-vae-{trials+1}.pth'):
            vae.load_state_dict(torch.load(f"{filename}-{task}-p2-vae-{trials+1}-{percentage}.pth"))
        else:
            vae.load_state_dict(torch.load(f"{filename}-{task}-p1-vae-{trials+1}-{percentage}.pth"))
        models[f'{task}_vae_module'] = vae

    # Set all models to evaluation mode to freeze parameters during sampling
    for model_name in models.keys():
        models[model_name].to(device)
        models[model_name].eval()

    # Initialize lists to store outputs used for sampling calculations
    aspect_outputs = {}
    sentiment_outputs = {}
    
    labeled_distances = []
    labeled_ground_truths = []
    
    labeled_aspects = []
    labeled_labels = []
    labeled_indices = []
    labeled_texts = []

    unlabeled_aspects = []
    unlabeled_labels = []
    unlabeled_ori_indices = []
    unlabeled_texts = []

    # DataLoader for labeled data subset, sampled randomly
    labeled_dataloader = DataLoader(
        dataset,
        batch_size=batch_size,
        num_workers=4,
        shuffle=False,
        pin_memory=True,
        sampler=SubsetRandomSampler(list(set(labeled_set)))
    )

    start_time = time.time()

    # Process labeled data to extract features and distances for sampling criteria
    for batch in labeled_dataloader:
        text_inputs = batch[0]
        gt_label = batch[1]
        idx = batch[2]
        input_ids, token_type_ids, attention_mask = [x.to(device, non_blocking=True) for x in text_inputs]
        labeled_ground_truths.extend(gt_label)

        with torch.no_grad():
            # Use backbone model to get encoded representations
            predictions, encoded_cls = models['aspect_backbone']([input_ids, token_type_ids, attention_mask, None])

            for i in range(len(predictions)):
                indices = idx[i].item()
                for j in range(len(predictions[i])):
                    if int(predictions[i][j].round()) != 1:
                        labeled_aspects.append(aspect_list[j])
                        labeled_labels.append(gt_label[i][j])
                        labeled_texts.append(batch[5][i])
                        labeled_indices.append(indices)
                    
            _, sub_representation, _, vae_distance = models['aspect_vae_module'](encoded_cls)
            vae_distance = vae_distance.cpu().data
            labeled_distances.extend(vae_distance)

    # print(vae_distance[:10])

    # Stack outputs for further processing
    labeled_ground_truths = torch.stack(labeled_ground_truths)
    labeled_distances = torch.stack(labeled_distances)

    accelerator.wait_for_everyone()
    if accelerator.is_main_process:
        # Compute self-prototype distances based on CoMAL's contrastive learning mode
        if cl_neg_mode == 1:
            labeled_prototype_distances = labeled_distances[:, :, :-1]  # Exclude last distance for prototype calculation
            labeled_prototype_distances = labeled_prototype_distances * torch.eye(num_labels)  # Keep only diagonal elements
            labeled_prototype_distances = torch.sum(labeled_prototype_distances, dim=-1)  # Sum along prototype axis
            positive_distances = labeled_prototype_distances * labeled_ground_truths  # Mask with ground truth labels
        elif cl_neg_mode == 2:
            # Split distances into positive and negative based on contrastive learning mode
            positive_distances, negative_distances = labeled_distances.chunk(2, dim=-1)
            positive_distances = positive_distances * labeled_ground_truths
    
        # Calculate max, min, and mean positive distances for uncertainty measurement
        max_positive_distances = torch.max(positive_distances, dim=0)[0]
        min_positive_distances = torch.min(positive_distances + (1 - labeled_ground_truths) * 2, dim=0)[0]
        mean_positive_distances = (max_positive_distances + min_positive_distances) / 2
    
        # DataLoader for unlabeled data to compute sampling scores
        unlabeled_dataloader = DataLoader(
            dataset,
            batch_size=batch_size,
            num_workers=4,
            shuffle=False,
            pin_memory=True,
            sampler=SubsetRandomSampler(list(set(unlabeled_indices)))
        )
    
        # Process unlabeled data to get sampling scores
        for batch in unlabeled_dataloader:
            text_inputs = batch[0]
            labels = batch[1]
            idx = batch[2]
            loss_weight = batch[3]
            input_ids, token_type_ids, attention_mask = [x.to(device) for x in text_inputs]
    
            with torch.no_grad():
                # Get predictions and encoded representations
                predictions, encoded_cls = models['aspect_backbone']([input_ids, token_type_ids, attention_mask, None])
                predictions = predictions.cpu().data
                
                for i in range(len(predictions)):
                    indices = idx[i].item()
                    
                    if indices not in aspect_outputs.keys():
                        aspect_outputs[indices] = {}
                        
                    aspect_outputs[indices]['backbone_predictions'] = predictions[i]
                    aspect_outputs[indices]['loss_weight'] = loss_weight[i]
                    
                    # Collect non neutral aspect for sentiment analysis
                    for j in range(len(predictions[i])):
                        if int(torch.sigmoid(predictions[i][j]).round()) != 1:
                            unlabeled_aspects.append(aspect_list[j])
                            unlabeled_labels.append(labels[i][j])
                            unlabeled_texts.append(batch[5][i])
                            unlabeled_ori_indices.append(indices)
    
                # Get latent representations, reconstructions, and distances
                _, _, _, vae_distance = models['aspect_vae_module'](encoded_cls)

                for i in range(len(vae_distance)):
                    aspect_outputs[idx[i].item()]['backbone_distances'] = vae_distance[i].cpu().data

        # Convert lists to tensors for further computation
        sample_indices = torch.stack([torch.tensor(key, dtype=torch.long) for key in aspect_outputs.keys()])
        sample_weights = torch.stack([aspect_outputs[key]['loss_weight'] for key in aspect_outputs.keys()])
        distance_matrix = torch.stack([aspect_outputs[key]['backbone_distances'] for key in aspect_outputs.keys()])
    
        # Convert predictions to probability and adjust masks for scoring
        backbone_predictions = torch.stack([aspect_outputs[key]['backbone_predictions'] for key, val in aspect_outputs.items()])
        probability_predictions = torch.zeros_like(backbone_predictions) + backbone_predictions
        probability_predictions = torch.sigmoid(probability_predictions)
        unlabeled_mask = torch.ones_like(sample_weights)
    
        # Calculate uncertainty metrics and part scores for sampling
        sample_weights = sample_weights.view(-1)
    
        # Mask predictions based on positive distances
        positive_distance_mask = ((probability_predictions >= 0.5) * unlabeled_mask).float()
        
        if cl_neg_mode == 2:
            positive_prototype_distances, negative_prototype_distances = distance_matrix.chunk(2, dim=-1)
        elif cl_neg_mode == 1:
            positive_prototype_distances = distance_matrix[:, :, :-1]
            positive_prototype_distances = positive_prototype_distances * torch.eye(num_labels)
            positive_prototype_distances = torch.sum(positive_prototype_distances, dim=-1)
    
        # Compute scores based on uncertainty and diversity metrics
        prediction_mask = (positive_prototype_distances > mean_positive_distances).float()
        distance_count = torch.sum(prediction_mask, dim=-1)
        cardinality_difference = torch.abs(distance_count - label_cardinality)
        score_weight = positive_distance_mask * (positive_prototype_distances + 1) / 2

        # Create a mask for nonzero elements
        nonzero_mask = score_weight > 0
    
        # Sum only nonzero elements per row
        sum_nonzero = (score_weight * nonzero_mask).sum(dim=-1)
        
        # Count nonzero elements per row
        count_nonzero = nonzero_mask.sum(dim=-1)
        
        # Avoid division by zero (optional, but recommended)
        count_nonzero = count_nonzero.clamp(min=1)
        
        # Compute mean
        score_weight = sum_nonzero / count_nonzero
        adjusted_score = torch.pow(score_weight, 0.5) + torch.pow(cardinality_difference, 1 - 0.5)
        final_scores = adjusted_score.unsqueeze(-1)
        average_scores = torch.mean(final_scores, dim=-1).cpu().numpy()

        z = 0
        for key in aspect_outputs.keys():
            aspect_outputs[key]['score'] = average_scores[z]
            z += 1

    # -------- SENTIMENT ANALYSIS ---------
    accelerator.wait_for_everyone()
    labeled_sentiment_dataset = SentimentAnalysisDataset(labeled_texts, labeled_labels, labeled_aspects, labeled_indices, tokenizer, label_mapping, max_length=sequence_length)
    unlabeled_sentiment_dataset = SentimentAnalysisDataset(unlabeled_texts, unlabeled_labels, unlabeled_aspects, unlabeled_ori_indices, tokenizer, label_mapping, max_length=sequence_length)
    
    labeled_loader = torch.utils.data.DataLoader(
        labeled_sentiment_dataset, batch_size=batch_size, shuffle=False, pin_memory=True, num_workers=4,
    )
    unlabeled_loader = torch.utils.data.DataLoader(
        unlabeled_sentiment_dataset, batch_size=batch_size, shuffle=False, pin_memory=True, num_workers=4,
    )

    labeled_ground_truths = []
    labeled_distances = []
    for batch in labeled_loader:
        text_inputs = batch[0]
        gt_label = batch[1]
        gt_label /= 2
        input_ids, token_type_ids, attention_mask = [x.to(device, non_blocking=True) for x in text_inputs]
        labeled_ground_truths.extend(gt_label)

        with torch.no_grad():
            # Use backbone model to get encoded representations
            predictions, encoded_cls = models['sentiment_backbone']([input_ids, token_type_ids, attention_mask, None])
                    
            _, sub_representation, _, vae_distance = models['sentiment_vae_module'](encoded_cls)
            labeled_distances.extend(vae_distance.cpu().data)

    # Stack outputs for further processing
    labeled_ground_truths = torch.stack(labeled_ground_truths)
    labeled_distances = torch.stack(labeled_distances)

    accelerator.wait_for_everyone()
    if accelerator.is_main_process:
        if cl_neg_mode == 1:
            labeled_prototype_distances = labeled_distances[:, :, :-1]  # Exclude last distance for prototype calculation
            labeled_prototype_distances = labeled_prototype_distances * torch.eye(num_labels)  # Keep only diagonal elements
            labeled_prototype_distances = torch.sum(labeled_prototype_distances, dim=-1)  # Sum along prototype axis
            positive_distances = labeled_prototype_distances * labeled_ground_truths  # Mask with ground truth labels
        elif cl_neg_mode == 2:
            # Split distances into positive and negative based on contrastive learning mode
            positive_distances, negative_distances = labeled_distances.chunk(2, dim=-1)
            positive_distances = positive_distances * labeled_ground_truths
    
        # Calculate max, min, and mean positive distances for uncertainty measurement
        max_positive_distances = torch.max(positive_distances, dim=0)[0]
        min_positive_distances = torch.min(positive_distances + (1 - labeled_ground_truths) * 2, dim=0)[0]
        mean_positive_distances = (max_positive_distances + min_positive_distances) / 2
    
        # Process unlabeled data to get sampling scores
        for batch in unlabeled_loader:
            text_inputs = batch[0]
            idx = batch[8]
            loss_weight = batch[3]
            input_ids, token_type_ids, attention_mask = [x.to(device) for x in text_inputs]
    
            with torch.no_grad():
                # Get predictions and encoded representations
                predictions, encoded_cls = models['sentiment_backbone']([input_ids, token_type_ids, attention_mask, None])
                predictions = predictions.cpu().data
                    
                for i in range(len(predictions)):
                    indices = idx[i].item()
                    if indices not in sentiment_outputs.keys():
                        sentiment_outputs[indices] = {}
                        sentiment_outputs[idx[i].item()]['backbone_predictions'] = [predictions[i]]
                        sentiment_outputs[idx[i].item()]['loss_weight'] = [loss_weight[i]]
                    else:
                        sentiment_outputs[idx[i].item()]['backbone_predictions'].append(predictions[i])
                        sentiment_outputs[idx[i].item()]['loss_weight'].append(loss_weight[i])
    
                # Get latent representations, reconstructions, and distances
                _, _, _, vae_distance = models['sentiment_vae_module'](encoded_cls)

                for i in range(len(vae_distance)):
                    indices = idx[i].item()
                    if 'backbone_distances' not in sentiment_outputs[indices].keys():
                        sentiment_outputs[indices]['backbone_distances'] = [vae_distance[i].cpu().data]
                    else:
                        sentiment_outputs[indices]['backbone_distances'].append(vae_distance[i].cpu().data)

        # print(len(unlabeled_sentiment_dataset), length, len(sentiment_outputs))
        sample_indices = torch.stack([torch.tensor(key, dtype=torch.long) for key in sentiment_outputs.keys()])

        sample_weights = torch.stack([
            torch.mean(torch.stack(sentiment_outputs[key]['loss_weight']), dim=0).round() 
            for key in sentiment_outputs
        ])
        distance_matrix = torch.stack([
            torch.mean(torch.stack(sentiment_outputs[key]['backbone_distances']), dim=0)
            for key in sentiment_outputs
        ])
        backbone_predictions = torch.stack([
            torch.mean(torch.stack(sentiment_outputs[key]['backbone_predictions']), dim=0) 
            for key in sentiment_outputs
        ])
        
        # Convert predictions to probability and adjust masks for scoring
        probability_predictions = torch.zeros_like(backbone_predictions) + backbone_predictions
        probability_predictions = torch.sigmoid(probability_predictions)
        unlabeled_mask = torch.ones_like(sample_weights)
    
        # Calculate uncertainty metrics and part scores for sampling
        sample_weights = sample_weights.view(-1)
    
        # Mask predictions based on positive distances
        positive_distance_mask = ((probability_predictions >= 0.5) * unlabeled_mask).float()
        negative_distance_mask = ((probability_predictions < 0.5) * unlabeled_mask).float()

        if cl_neg_mode == 2:
            positive_prototype_distances, negative_prototype_distances = distance_matrix.chunk(2, dim=-1)
        elif cl_neg_mode == 1:
            positive_prototype_distances = distance_matrix[:, :, :-1]
            positive_prototype_distances = positive_prototype_distances * torch.eye(2)
            positive_prototype_distances = torch.sum(positive_prototype_distances, dim=-1)
    
        # Compute scores based on uncertainty and diversity metrics
        prediction_mask = (positive_prototype_distances > mean_positive_distances).float()
        distance_count = torch.sum(prediction_mask, dim=-1)
        cardinality_difference = torch.abs(distance_count - label_cardinality)
        score_weight = positive_distance_mask * (positive_prototype_distances + 1) / 2
        score_weight_negative = negative_distance_mask * (negative_prototype_distances + 1) / 2
        score_weight = score_weight + score_weight_negative
        # Create a mask for nonzero elements
        nonzero_mask = score_weight > 0
    
        # Sum only nonzero elements per row
        sum_nonzero = (score_weight * nonzero_mask).sum(dim=-1)
        
        # Count nonzero elements per row
        count_nonzero = nonzero_mask.sum(dim=-1)
        
        # Avoid division by zero (optional, but recommended)
        count_nonzero = count_nonzero.clamp(min=1)
        
        # Compute mean
        score_weight = sum_nonzero / count_nonzero
        adjusted_score = torch.pow(score_weight, 0.5) + torch.pow(cardinality_difference, 1 - 0.5)
        final_scores = adjusted_score.unsqueeze(-1)
        average_sentiment_scores = torch.mean(final_scores, dim=-1).cpu().numpy()

        z = 0
        for key in sentiment_outputs.keys():
            aspect_outputs[key]['score'] = (average_sentiment_scores[z] + aspect_outputs[key]['score']) / 2
            z += 1

        scores = np.array([output['score'] for output in aspect_outputs.values()])

        ranked_indices = np.argsort(scores)
        ranked_indices = ranked_indices[::-1]
        sample_indices = torch.stack([torch.tensor(key, dtype=torch.long) for key in aspect_outputs.keys()])
        
        # Select top samples for annotation
        threshold = np.percentile(scores, 90)
        items_greater_than_threshold = scores[scores >= threshold]
        num_of_candidates = min(math.ceil(0.1 * len(scores)), len(items_greater_than_threshold))
    
        nearest_cp = 0
        for cp in checkpoints:
            if cp > current_train_size:
                nearest_cp = cp
                break
    
        if num_of_candidates <= n_samples and n_samples < nearest_cp - current_train_size:
            selected_indices = ranked_indices[:n_samples]
        elif num_of_candidates > n_samples and num_of_candidates < nearest_cp - current_train_size:
            selected_indices = ranked_indices[:max(n_samples, num_of_candidates)]
        else:
            selected_indices = ranked_indices[:nearest_cp - current_train_size]
            
            temp = dataset.get_labeled_set()
            temp.extend([unlabeled_indices[int(i)] for i in selected_indices])
            
            # Save acquired data up to checkpoint
            acquired_data = pd.DataFrame({
                'processed_text': [X_train[i] for i in temp],
                'fuel': [y_train[i][0] for i in temp],
                'machine': [y_train[i][1] for i in temp],
                'others': [y_train[i][2] for i in temp],
                'part': [y_train[i][3] for i in temp],
                'price': [y_train[i][4] for i in temp],
                'service': [y_train[i][5] for i in temp],
            })
    
            acquired_data.to_csv(f'{filename}-{trials+1}-data-{nearest_cp}.csv', index=False)

        for x in selected_indices:
            new_sample_data.append(unlabeled_indices[int(x)])
        new_sample_labels = None
        
        end_time = time.time()
        duration = end_time - start_time
    
        print("Nearest checkpoint:", nearest_cp)
        print("Threshold:", threshold)
        print("Samples above threshold:", num_of_candidates)
        print("Acquired samples:", len(selected_indices))
        print(f"Sampling duration: {duration} seconds")  # Print or return the runtime if needed
    
        sampling_dur.append(duration)

def pred_part_stat(pred, threshold=0.0):
    part_1 = torch.where(pred >= threshold)[0]
    part_0 = torch.where(pred < threshold)[0]
    return part_0, part_1

# %% [markdown]
# # PLOT RESULT

# %%
import matplotlib.pyplot as plt

def plot_result(data_used, accuracies, f1_micros, f1_macros):
    fig, axs = plt.subplots(1, 3, figsize=(21, 5))
    data_used = [round(data / total_data * 100, 1) for data in data_used]

    # Plot for Accuracy
    axs[0].plot(data_used, accuracies, label="Accuracy", color="blue")
    axs[0].set_xlabel("Percentage of data used")
    axs[0].set_title("Accuracy")
    axs[0].set_xticks(data_used)

    # Plot for F1 Micro
    axs[1].plot(data_used, f1_micros, label="F1 Micro", color="orange")
    axs[1].set_xlabel("Percentage of data used")
    axs[1].set_title("F1 Micro")
    axs[1].set_xticks(data_used)

    # Plot for F1 Macro
    axs[2].plot(data_used, f1_macros, label="F1 Macro", color="green")
    axs[2].set_xlabel("Percentage of data used")
    axs[2].set_title("F1 Macro")
    axs[2].set_xticks(data_used)

    # Adjust layout and show the plots
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # MAIN LOOP

# %%
def active_learning(seed, i):
    aspect_accuracies = manager.list()
    aspect_f1_micros = manager.list()
    aspect_f1_macros = manager.list()
    sentiment_accuracies = manager.list()
    sentiment_f1_micros = manager.list()
    sentiment_f1_macros = manager.list()
    accuracies = manager.list()
    f1_micros = manager.list()
    f1_macros = manager.list()
    data_used = manager.list()
    sampling_dur = manager.list()
    new_sample_data = manager.list()
    new_sample_labels = manager.list()
    
    current_train_size = initial_train_size
    start_time = time.time()
    set_seed(seeds[i])

    print("===============================================")
    print("TRIAL {}".format(i+1))
    print("Random seed:", seeds[i])
    
    # Load label information and dataset
    label_num = 6
    _, _, aspect_train_dataset, aspect_val_dataset = build_aspect_dataset(X_train, y_train, X_val, y_val, sequence_length)
    
    # Shuffle and initialize labeled and unlabeled sets
    indices = list(range(len(aspect_train_dataset)))
    random.shuffle(indices)
    labeled_set = indices[:initial_train_size]  # Random initial labeled set
    unlabeled_set = [x for x in indices if x not in labeled_set]  # Define the unlabeled set
    
    # Update dataset with initial labeled set
    aspect_train_dataset.update_data(labeled_set, init_time=True)
    
    # Prepare data loaders for labeled and test sets
    labeled_loader = DataLoader(
        aspect_train_dataset,
        batch_size=batch_size,
        num_workers=4,
        pin_memory=True,
        sampler=SubsetRandomSampler(list(set(labeled_set)))
    )
    test_loader = DataLoader(
        aspect_val_dataset,
        batch_size=batch_size,
        num_workers=4,
        pin_memory=True
    )

    models = {}

    while current_train_size < checkpoints[len(checkpoints) - 1]:
        dataloaders = {
            'labeled': labeled_loader,
            'test': test_loader
        }
        aspect_datasets = {
            'train': aspect_train_dataset,
            'val': aspect_val_dataset
        }
    
        # Train model
        train_args = (
            aspect_datasets,
            dataloaders, 
            i, 
            (aspect_accuracies, aspect_f1_micros, aspect_f1_macros), 
            (sentiment_accuracies, sentiment_f1_micros, sentiment_f1_macros),
            (data_used, accuracies, f1_micros, f1_macros), 
            current_train_size, 
            label_num,
            seed
        )
        notebook_launcher(train_total_sep2, train_args, num_processes=2)
        
        query_set = list(set(unlabeled_set))
        # random.shuffle(query_set)
    
        # Query samples for next cycle, using appropriate selection strategy
        new_sample_data = manager.list()
        new_sample_labels = manager.list()
        sampling_args = (
            filename,
            aspect_train_dataset, 
            labeled_set,
            query_set, 
            label_num,
            i,
            sampling_dur,
            new_sample_data,
            new_sample_labels,
            aspect_train_dataset.get_label_Cardinality()
        )
        notebook_launcher(query_samples, sampling_args, num_processes=2)
        new_sample_data = list(new_sample_data)
        new_sample_labels = list(new_sample_labels)

        # print(len(new_sample_data))
        aspect_train_dataset.update_data(new_sample_data, None)
        labeled_set = aspect_train_dataset.get_labeled_set()
        unlabeled_set = [x for x in indices if x not in labeled_set]
    
        # Refresh data loader with new labeled set
        labeled_loader = DataLoader(
            aspect_train_dataset,
            batch_size=batch_size,
            num_workers=4,
            pin_memory=True,
            sampler=SubsetRandomSampler(list(set(labeled_set)))
        )
        
        # Update current train size
        current_train_size = len(labeled_set)
        print("New train size:", current_train_size)
    
    # DataLoader dictionary to be used for training and testing
    dataloaders = {
        'labeled': labeled_loader,
        'test': test_loader
    }
    
    # Train last iteration
    train_args = (
        aspect_datasets,
        dataloaders, 
        i, 
        (aspect_accuracies, aspect_f1_micros, aspect_f1_macros), 
        (sentiment_accuracies, sentiment_f1_micros, sentiment_f1_macros),
        (data_used, accuracies, f1_micros, f1_macros), 
        current_train_size, 
        label_num,
        seed
    )
    notebook_launcher(train_total_sep2, train_args, num_processes=2)
    data_used, accuracies, f1_micros, f1_macros, sampling_dur = list(data_used), list(accuracies), list(f1_micros), list(f1_macros), list(sampling_dur)
    aspect_accuracies, aspect_f1_micros, aspect_f1_macros = list(aspect_accuracies), list(aspect_f1_micros), list(aspect_f1_macros)
    sentiment_accuracies, sentiment_f1_micros, sentiment_f1_macros = list(sentiment_accuracies), list(sentiment_f1_micros), list(sentiment_f1_macros)
        
    # Log results
    end_time = time.time()
    duration = end_time - start_time

    print(f"Total sampling time: {np.array(sampling_dur).sum().round(2)} seconds")
    print(f"Total runtime: {duration} seconds")

    plot_result(data_used, accuracies, f1_micros, f1_macros)
    
    results = pd.DataFrame({
        'Data Used': data_used,
        'Aspect Accuracy': aspect_accuracies,
        'Aspect F1 Micro': aspect_f1_micros,
        'Aspect F1 Macro': aspect_f1_macros,
        'Sentiment Accuracy': sentiment_accuracies,
        'Sentiment F1 Micro': sentiment_f1_micros,
        'Sentiment F1 Macro': sentiment_f1_macros,
        'Accuracy': accuracies,
        'F1 Micro': f1_micros,
        'F1 Macro': f1_macros,
    })
    sampling_dur.insert(0, 0)
    
    results['Sampling Duration'] = sampling_dur
    
    results.to_csv(f'{filename}-{i+1}-results.csv', index=False)

# %%
seeds = [50, 81, 14, 3, 94]

# %% [markdown]
# ## RUN 1

# %%
active_learning(seeds[0], 0)
# Out:
# ===============================================
# TRIAL 1
# Random seed: 50
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.5586140155792236 | ACCURACY: 0.7329 | F1 MACRO: 0.8333 | F1 MICRO: 0.8411
# EPOCH 2 | LOSS: 2.4213733673095703 | ACCURACY: 0.7723 | F1 MACRO: 0.86 | F1 MICRO: 0.8681
# EPOCH 3 | LOSS: 2.3085861206054688 | ACCURACY: 0.7924 | F1 MACRO: 0.8822 | F1 MICRO: 0.8837
# EPOCH 4 | LOSS: 2.198923349380493 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# EPOCH 5 | LOSS: 2.193657398223877 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# EPOCH 6 | LOSS: 2.155442237854004 | ACCURACY: 0.7902 | F1 MACRO: 0.8812 | F1 MICRO: 0.8826
# EPOCH 7 | LOSS: 2.153994560241699 | ACCURACY: 0.8013 | F1 MACRO: 0.8861 | F1 MICRO: 0.8877
# EPOCH 8 | LOSS: 2.2027814388275146 | ACCURACY: 0.8013 | F1 MACRO: 0.8844 | F1 MICRO: 0.8866
# EPOCH 9 | LOSS: 2.126356363296509 | ACCURACY: 0.8028 | F1 MACRO: 0.8836 | F1 MICRO: 0.8865
# EPOCH 10 | LOSS: 2.1520628929138184 | ACCURACY: 0.8088 | F1 MACRO: 0.8871 | F1 MICRO: 0.8895
# aspect: ACCURACY 0.8088 | F1 MACRO 0.8871 | F1 MICRO 0.8895
#               precision    recall  f1-score   support
#
#         fuel       0.83      0.98      0.90       187
#      machine       0.81      0.98      0.89       175
#       others       0.73      0.99      0.84       158
#         part       0.80      0.88      0.84       158
#        price       0.88      0.99      0.93       192
#      service       0.85      1.00      0.92       191
#
#    micro avg       0.82      0.97      0.89      1061
#    macro avg       0.82      0.97      0.89      1061
# weighted avg       0.82      0.97      0.89      1061
#  samples avg       0.82      0.97      0.89      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 12.644472122192383 | ACCURACY: 0.7711 | F1 MACRO: 0.4354 | F1 MICRO: 0.7711
# EPOCH 2 | LOSS: 11.18961238861084 | ACCURACY: 0.7711 | F1 MACRO: 0.4354 | F1 MICRO: 0.7711
# EPOCH 3 | LOSS: 10.907063484191895 | ACCURACY: 0.8795 | F1 MACRO: 0.8353 | F1 MICRO: 0.8795
# EPOCH 4 | LOSS: 10.993146896362305 | ACCURACY: 0.8313 | F1 MACRO: 0.7152 | F1 MICRO: 0.8313
# EPOCH 5 | LOSS: 9.698177337646484 | ACCURACY: 0.8916 | F1 MACRO: 0.8371 | F1 MICRO: 0.8916
# EPOCH 6 | LOSS: 9.276512145996094 | ACCURACY: 0.8795 | F1 MACRO: 0.8406 | F1 MICRO: 0.8795
# EPOCH 7 | LOSS: 8.901294708251953 | ACCURACY: 0.8675 | F1 MACRO: 0.8009 | F1 MICRO: 0.8675
# EPOCH 8 | LOSS: 8.915127754211426 | ACCURACY: 0.8916 | F1 MACRO: 0.8492 | F1 MICRO: 0.8916
# EPOCH 9 | LOSS: 8.410571098327637 | ACCURACY: 0.9036 | F1 MACRO: 0.8635 | F1 MICRO: 0.9036
# EPOCH 10 | LOSS: 8.143811225891113 | ACCURACY: 0.8916 | F1 MACRO: 0.8628 | F1 MICRO: 0.8916
# sentiment: ACCURACY 0.9036 | F1 MACRO 0.8635 | F1 MICRO 0.9036
#               precision    recall  f1-score   support
#
#     negative       0.79      0.79      0.79        19
#     positive       0.94      0.94      0.94        64
#
#     accuracy                           0.90        83
#    macro avg       0.86      0.86      0.86        83
# weighted avg       0.90      0.90      0.90        83
#
# --------------------------------------------------
# Iteration 54: Accuracy: 0.8048, F1 Micro: 0.8048, F1 Macro: 0.4357
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        11
#      neutral       0.84      0.98      0.90       181
#     positive       0.00      0.00      0.00        24
#
#     accuracy                           0.82       216
#    macro avg       0.28      0.33      0.30       216
# weighted avg       0.70      0.82      0.76       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.67      0.12      0.21        16
#      neutral       0.80      0.98      0.88       167
#     positive       0.67      0.18      0.29        33
#
#     accuracy                           0.80       216
#    macro avg       0.71      0.43      0.46       216
# weighted avg       0.77      0.80      0.74       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.17      0.29        12
#      neutral       0.73      0.99      0.84       152
#     positive       0.71      0.10      0.17        52
#
#     accuracy                           0.73       216
#    macro avg       0.81      0.42      0.43       216
# weighted avg       0.74      0.73      0.65       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.35      0.48        23
#      neutral       0.80      0.88      0.84       152
#     positive       0.51      0.49      0.50        41
#
#     accuracy                           0.75       216
#    macro avg       0.71      0.57      0.61       216
# weighted avg       0.75      0.75      0.74       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.15      0.27        13
#      neutral       0.88      0.98      0.93       186
#     positive       0.50      0.24      0.32        17
#
#     accuracy                           0.87       216
#    macro avg       0.79      0.46      0.51       216
# weighted avg       0.86      0.87      0.84       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        14
#      neutral       0.86      1.00      0.92       185
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.86       216
#    macro avg       0.29      0.33      0.31       216
# weighted avg       0.73      0.86      0.79       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.51654794216156
# Samples above threshold: 81
# Acquired samples: 81
# Sampling duration: 6.871364116668701 seconds
# New train size: 135
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.615598440170288 | ACCURACY: 0.7865 | F1 MACRO: 0.8745 | F1 MICRO: 0.8781
# EPOCH 2 | LOSS: 2.4183473587036133 | ACCURACY: 0.7902 | F1 MACRO: 0.8812 | F1 MICRO: 0.8827
# EPOCH 3 | LOSS: 2.3182525634765625 | ACCURACY: 0.7991 | F1 MACRO: 0.8857 | F1 MICRO: 0.8871
# EPOCH 4 | LOSS: 2.2655043601989746 | ACCURACY: 0.8147 | F1 MACRO: 0.8925 | F1 MICRO: 0.8941
# EPOCH 5 | LOSS: 2.2197177410125732 | ACCURACY: 0.8214 | F1 MACRO: 0.8956 | F1 MICRO: 0.8972
# EPOCH 6 | LOSS: 2.1585304737091064 | ACCURACY: 0.8393 | F1 MACRO: 0.9042 | F1 MICRO: 0.9061
# EPOCH 7 | LOSS: 2.1715126037597656 | ACCURACY: 0.8467 | F1 MACRO: 0.9076 | F1 MICRO: 0.9097
# EPOCH 8 | LOSS: 2.172799587249756 | ACCURACY: 0.8571 | F1 MACRO: 0.9128 | F1 MICRO: 0.9152
# EPOCH 9 | LOSS: 2.103379964828491 | ACCURACY: 0.8743 | F1 MACRO: 0.9212 | F1 MICRO: 0.924
# EPOCH 10 | LOSS: 2.113755226135254 | ACCURACY: 0.8906 | F1 MACRO: 0.9299 | F1 MICRO: 0.9332
# aspect: ACCURACY 0.8906 | F1 MACRO 0.9299 | F1 MICRO 0.9332
#               precision    recall  f1-score   support
#
#         fuel       0.95      1.00      0.97       187
#      machine       0.85      0.98      0.91       175
#       others       0.83      0.85      0.84       158
#         part       0.88      0.96      0.92       158
#        price       0.95      0.99      0.97       192
#      service       0.94      1.00      0.97       191
#
#    micro avg       0.90      0.97      0.93      1061
#    macro avg       0.90      0.96      0.93      1061
# weighted avg       0.90      0.97      0.93      1061
#  samples avg       0.91      0.97      0.93      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 13.421614646911621 | ACCURACY: 0.7723 | F1 MACRO: 0.6481 | F1 MICRO: 0.7723
# EPOCH 2 | LOSS: 12.027592658996582 | ACCURACY: 0.9158 | F1 MACRO: 0.9024 | F1 MICRO: 0.9158
# EPOCH 3 | LOSS: 10.583052635192871 | ACCURACY: 0.901 | F1 MACRO: 0.8826 | F1 MICRO: 0.901
# EPOCH 4 | LOSS: 9.963323593139648 | ACCURACY: 0.8762 | F1 MACRO: 0.8525 | F1 MICRO: 0.8762
# EPOCH 5 | LOSS: 9.898773193359375 | ACCURACY: 0.8861 | F1 MACRO: 0.863 | F1 MICRO: 0.8861
# EPOCH 6 | LOSS: 9.129155158996582 | ACCURACY: 0.9257 | F1 MACRO: 0.9131 | F1 MICRO: 0.9257
# EPOCH 7 | LOSS: 8.88351058959961 | ACCURACY: 0.9158 | F1 MACRO: 0.9006 | F1 MICRO: 0.9158
# EPOCH 8 | LOSS: 8.758405685424805 | ACCURACY: 0.901 | F1 MACRO: 0.8778 | F1 MICRO: 0.901
# EPOCH 9 | LOSS: 8.208062171936035 | ACCURACY: 0.8911 | F1 MACRO: 0.872 | F1 MICRO: 0.8911
# EPOCH 10 | LOSS: 8.121431350708008 | ACCURACY: 0.901 | F1 MACRO: 0.8815 | F1 MICRO: 0.901
# sentiment: ACCURACY 0.9257 | F1 MACRO 0.9131 | F1 MICRO 0.9257
#               precision    recall  f1-score   support
#
#     negative       0.86      0.90      0.88        61
#     positive       0.96      0.94      0.95       141
#
#     accuracy                           0.93       202
#    macro avg       0.91      0.92      0.91       202
# weighted avg       0.93      0.93      0.93       202
#
# --------------------------------------------------
# Iteration 135: Accuracy: 0.8858, F1 Micro: 0.8858, F1 Macro: 0.7691
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.91      0.91        11
#      neutral       0.95      1.00      0.98       181
#     positive       1.00      0.62      0.77        24
#
#     accuracy                           0.95       216
#    macro avg       0.95      0.84      0.88       216
# weighted avg       0.96      0.95      0.95       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.31      0.45        16
#      neutral       0.85      0.99      0.92       167
#     positive       0.76      0.39      0.52        33
#
#     accuracy                           0.85       216
#    macro avg       0.82      0.56      0.63       216
# weighted avg       0.84      0.85      0.82       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.62      0.67      0.64        12
#      neutral       0.84      0.88      0.86       152
#     positive       0.66      0.56      0.60        52
#
#     accuracy                           0.79       216
#    macro avg       0.70      0.70      0.70       216
# weighted avg       0.78      0.79      0.78       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.48      0.61        23
#      neutral       0.87      0.95      0.91       152
#     positive       0.70      0.63      0.67        41
#
#     accuracy                           0.84       216
#    macro avg       0.81      0.69      0.73       216
# weighted avg       0.83      0.84      0.83       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.77      0.83        13
#      neutral       0.96      0.98      0.97       186
#     positive       0.80      0.71      0.75        17
#
#     accuracy                           0.95       216
#    macro avg       0.89      0.82      0.85       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.71      0.80        14
#      neutral       0.94      0.99      0.97       185
#     positive       1.00      0.53      0.69        17
#
#     accuracy                           0.94       216
#    macro avg       0.95      0.75      0.82       216
# weighted avg       0.94      0.94      0.93       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.512867546081543
# Samples above threshold: 73
# Acquired samples: 73
# Sampling duration: 9.739737749099731 seconds
# New train size: 208
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.606462240219116 | ACCURACY: 0.7939 | F1 MACRO: 0.8829 | F1 MICRO: 0.8844
# EPOCH 2 | LOSS: 2.3031067848205566 | ACCURACY: 0.7909 | F1 MACRO: 0.8814 | F1 MICRO: 0.883
# EPOCH 3 | LOSS: 2.213838577270508 | ACCURACY: 0.8185 | F1 MACRO: 0.8941 | F1 MICRO: 0.8956
# EPOCH 4 | LOSS: 2.1631247997283936 | ACCURACY: 0.8371 | F1 MACRO: 0.9038 | F1 MICRO: 0.9053
# EPOCH 5 | LOSS: 2.142519474029541 | ACCURACY: 0.8564 | F1 MACRO: 0.9129 | F1 MICRO: 0.9149
# EPOCH 6 | LOSS: 2.0765280723571777 | ACCURACY: 0.8817 | F1 MACRO: 0.9264 | F1 MICRO: 0.9287
# EPOCH 7 | LOSS: 2.043138027191162 | ACCURACY: 0.9211 | F1 MACRO: 0.9497 | F1 MICRO: 0.9517
# EPOCH 8 | LOSS: 1.9553782939910889 | ACCURACY: 0.9182 | F1 MACRO: 0.9464 | F1 MICRO: 0.9494
# EPOCH 9 | LOSS: 1.8971234560012817 | ACCURACY: 0.9323 | F1 MACRO: 0.9571 | F1 MICRO: 0.9584
# EPOCH 10 | LOSS: 1.8103899955749512 | ACCURACY: 0.9315 | F1 MACRO: 0.955 | F1 MICRO: 0.9575
# aspect: ACCURACY 0.9323 | F1 MACRO 0.9571 | F1 MICRO 0.9584
#               precision    recall  f1-score   support
#
#         fuel       0.97      1.00      0.99       187
#      machine       0.93      0.99      0.96       175
#       others       0.85      0.97      0.90       158
#         part       0.92      0.98      0.95       158
#        price       0.97      0.98      0.98       192
#      service       0.94      1.00      0.97       191
#
#    micro avg       0.93      0.99      0.96      1061
#    macro avg       0.93      0.99      0.96      1061
# weighted avg       0.93      0.99      0.96      1061
#  samples avg       0.93      0.99      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 10.504135131835938 | ACCURACY: 0.8128 | F1 MACRO: 0.7398 | F1 MICRO: 0.8128
# EPOCH 2 | LOSS: 9.408873558044434 | ACCURACY: 0.9087 | F1 MACRO: 0.895 | F1 MICRO: 0.9087
# EPOCH 3 | LOSS: 8.393345832824707 | ACCURACY: 0.9269 | F1 MACRO: 0.914 | F1 MICRO: 0.9269
# EPOCH 4 | LOSS: 7.894646167755127 | ACCURACY: 0.9315 | F1 MACRO: 0.9221 | F1 MICRO: 0.9315
# EPOCH 5 | LOSS: 7.431109428405762 | ACCURACY: 0.9224 | F1 MACRO: 0.913 | F1 MICRO: 0.9224
# EPOCH 6 | LOSS: 7.357504367828369 | ACCURACY: 0.9361 | F1 MACRO: 0.9286 | F1 MICRO: 0.9361
# EPOCH 7 | LOSS: 7.067570686340332 | ACCURACY: 0.9269 | F1 MACRO: 0.9166 | F1 MICRO: 0.9269
# EPOCH 8 | LOSS: 6.822772979736328 | ACCURACY: 0.8858 | F1 MACRO: 0.8573 | F1 MICRO: 0.8858
# EPOCH 9 | LOSS: 6.664130687713623 | ACCURACY: 0.9315 | F1 MACRO: 0.9237 | F1 MICRO: 0.9315
# EPOCH 10 | LOSS: 6.6595330238342285 | ACCURACY: 0.9406 | F1 MACRO: 0.9325 | F1 MICRO: 0.9406
# sentiment: ACCURACY 0.9406 | F1 MACRO 0.9325 | F1 MICRO 0.9406
#               precision    recall  f1-score   support
#
#     negative       0.89      0.93      0.91        70
#     positive       0.97      0.95      0.96       149
#
#     accuracy                           0.94       219
#    macro avg       0.93      0.94      0.93       219
# weighted avg       0.94      0.94      0.94       219
#
# --------------------------------------------------
# Iteration 208: Accuracy: 0.9259, F1 Micro: 0.9259, F1 Macro: 0.8511
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.98      1.00      0.99       181
#     positive       1.00      0.88      0.93        24
#
#     accuracy                           0.98       216
#    macro avg       0.99      0.93      0.96       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.69      0.79        16
#      neutral       0.94      0.99      0.97       167
#     positive       0.89      0.73      0.80        33
#
#     accuracy                           0.93       216
#    macro avg       0.91      0.80      0.85       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.89      0.67      0.76        12
#      neutral       0.84      0.95      0.90       152
#     positive       0.83      0.56      0.67        52
#
#     accuracy                           0.84       216
#    macro avg       0.85      0.73      0.77       216
# weighted avg       0.84      0.84      0.83       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.78      0.82        23
#      neutral       0.92      0.97      0.95       152
#     positive       0.91      0.76      0.83        41
#
#     accuracy                           0.91       216
#    macro avg       0.90      0.84      0.86       216
# weighted avg       0.91      0.91      0.91       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.73      0.85      0.79        13
#      neutral       0.98      0.97      0.98       186
#     positive       0.75      0.71      0.73        17
#
#     accuracy                           0.94       216
#    macro avg       0.82      0.84      0.83       216
# weighted avg       0.95      0.94      0.94       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.64      0.78        14
#      neutral       0.94      1.00      0.97       185
#     positive       1.00      0.59      0.74        17
#
#     accuracy                           0.94       216
#    macro avg       0.98      0.74      0.83       216
# weighted avg       0.95      0.94      0.94       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.522719383239746
# Samples above threshold: 66
# Acquired samples: 66
# Sampling duration: 11.024842500686646 seconds
# New train size: 274
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.385484457015991 | ACCURACY: 0.7902 | F1 MACRO: 0.8812 | F1 MICRO: 0.8827
# EPOCH 2 | LOSS: 2.121807813644409 | ACCURACY: 0.8073 | F1 MACRO: 0.8877 | F1 MICRO: 0.8896
# EPOCH 3 | LOSS: 2.032580614089966 | ACCURACY: 0.8289 | F1 MACRO: 0.8986 | F1 MICRO: 0.9
# EPOCH 4 | LOSS: 1.9511882066726685 | ACCURACY: 0.8534 | F1 MACRO: 0.9093 | F1 MICRO: 0.9122
# EPOCH 5 | LOSS: 1.913232445716858 | ACCURACY: 0.9018 | F1 MACRO: 0.9374 | F1 MICRO: 0.9401
# EPOCH 6 | LOSS: 1.8671188354492188 | ACCURACY: 0.9211 | F1 MACRO: 0.9488 | F1 MICRO: 0.9512
# EPOCH 7 | LOSS: 1.7962251901626587 | ACCURACY: 0.9249 | F1 MACRO: 0.9504 | F1 MICRO: 0.9533
# EPOCH 8 | LOSS: 1.7237403392791748 | ACCURACY: 0.933 | F1 MACRO: 0.9569 | F1 MICRO: 0.9586
# EPOCH 9 | LOSS: 1.6549898386001587 | ACCURACY: 0.9315 | F1 MACRO: 0.9549 | F1 MICRO: 0.9573
# EPOCH 10 | LOSS: 1.6075605154037476 | ACCURACY: 0.939 | F1 MACRO: 0.9605 | F1 MICRO: 0.9621
# aspect: ACCURACY 0.939 | F1 MACRO 0.9605 | F1 MICRO 0.9621
#               precision    recall  f1-score   support
#
#         fuel       0.97      1.00      0.99       187
#      machine       0.94      0.97      0.96       175
#       others       0.90      0.96      0.93       158
#         part       0.92      0.96      0.94       158
#        price       0.97      0.99      0.98       192
#      service       0.95      1.00      0.97       191
#
#    micro avg       0.94      0.98      0.96      1061
#    macro avg       0.94      0.98      0.96      1061
# weighted avg       0.94      0.98      0.96      1061
#  samples avg       0.94      0.98      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 8.259078025817871 | ACCURACY: 0.9221 | F1 MACRO: 0.906 | F1 MICRO: 0.9221
# EPOCH 2 | LOSS: 7.24977970123291 | ACCURACY: 0.9016 | F1 MACRO: 0.8911 | F1 MICRO: 0.9016
# EPOCH 3 | LOSS: 6.457250118255615 | ACCURACY: 0.9344 | F1 MACRO: 0.9246 | F1 MICRO: 0.9344
# EPOCH 4 | LOSS: 6.0124592781066895 | ACCURACY: 0.9344 | F1 MACRO: 0.9236 | F1 MICRO: 0.9344
# EPOCH 5 | LOSS: 5.653814315795898 | ACCURACY: 0.9344 | F1 MACRO: 0.923 | F1 MICRO: 0.9344
# EPOCH 6 | LOSS: 5.5385565757751465 | ACCURACY: 0.9385 | F1 MACRO: 0.9286 | F1 MICRO: 0.9385
# EPOCH 7 | LOSS: 5.371642589569092 | ACCURACY: 0.9057 | F1 MACRO: 0.8843 | F1 MICRO: 0.9057
# EPOCH 8 | LOSS: 5.276251316070557 | ACCURACY: 0.9221 | F1 MACRO: 0.9082 | F1 MICRO: 0.9221
# EPOCH 9 | LOSS: 5.313490867614746 | ACCURACY: 0.9262 | F1 MACRO: 0.9173 | F1 MICRO: 0.9262
# EPOCH 10 | LOSS: 5.107458114624023 | ACCURACY: 0.9467 | F1 MACRO: 0.939 | F1 MICRO: 0.9467
# sentiment: ACCURACY 0.9467 | F1 MACRO 0.939 | F1 MICRO 0.9467
#               precision    recall  f1-score   support
#
#     negative       0.88      0.96      0.92        75
#     positive       0.98      0.94      0.96       169
#
#     accuracy                           0.95       244
#    macro avg       0.93      0.95      0.94       244
# weighted avg       0.95      0.95      0.95       244
#
# --------------------------------------------------
# Iteration 274: Accuracy: 0.9375, F1 Micro: 0.9375, F1 Macro: 0.8805
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.98      1.00      0.99       181
#     positive       1.00      0.92      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       0.99      0.94      0.97       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.75      0.83        16
#      neutral       0.97      0.96      0.97       167
#     positive       0.78      0.88      0.83        33
#
#     accuracy                           0.94       216
#    macro avg       0.89      0.86      0.87       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.69      0.75      0.72        12
#      neutral       0.89      0.93      0.91       152
#     positive       0.80      0.67      0.73        52
#
#     accuracy                           0.86       216
#    macro avg       0.79      0.78      0.79       216
# weighted avg       0.85      0.86      0.85       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.77      0.87      0.82        23
#      neutral       0.93      0.98      0.96       152
#     positive       0.97      0.71      0.82        41
#
#     accuracy                           0.92       216
#    macro avg       0.89      0.85      0.86       216
# weighted avg       0.92      0.92      0.91       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.69      0.82        13
#      neutral       0.97      0.99      0.98       186
#     positive       0.88      0.82      0.85        17
#
#     accuracy                           0.96       216
#    macro avg       0.95      0.84      0.88       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.96      1.00      0.98       185
#     positive       1.00      0.71      0.83        17
#
#     accuracy                           0.97       216
#    macro avg       0.99      0.85      0.91       216
# weighted avg       0.97      0.97      0.97       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.5215590238571166
# Samples above threshold: 59
# Acquired samples: 59
# Sampling duration: 23.07042384147644 seconds
# New train size: 333
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.4378561973571777 | ACCURACY: 0.7917 | F1 MACRO: 0.882 | F1 MICRO: 0.8834
# EPOCH 2 | LOSS: 2.1526384353637695 | ACCURACY: 0.817 | F1 MACRO: 0.8943 | F1 MICRO: 0.8956
# EPOCH 3 | LOSS: 2.0681073665618896 | ACCURACY: 0.8512 | F1 MACRO: 0.911 | F1 MICRO: 0.9126
# EPOCH 4 | LOSS: 2.0749082565307617 | ACCURACY: 0.8929 | F1 MACRO: 0.9321 | F1 MICRO: 0.9346
# EPOCH 5 | LOSS: 1.9419970512390137 | ACCURACY: 0.9293 | F1 MACRO: 0.9541 | F1 MICRO: 0.9562
# EPOCH 6 | LOSS: 1.876543402671814 | ACCURACY: 0.9323 | F1 MACRO: 0.9562 | F1 MICRO: 0.9579
# EPOCH 7 | LOSS: 1.7922002077102661 | ACCURACY: 0.9435 | F1 MACRO: 0.963 | F1 MICRO: 0.9648
# EPOCH 8 | LOSS: 1.7128548622131348 | ACCURACY: 0.9442 | F1 MACRO: 0.9627 | F1 MICRO: 0.965
# EPOCH 9 | LOSS: 1.6629693508148193 | ACCURACY: 0.9479 | F1 MACRO: 0.9649 | F1 MICRO: 0.9674
# EPOCH 10 | LOSS: 1.6114290952682495 | ACCURACY: 0.9487 | F1 MACRO: 0.9664 | F1 MICRO: 0.9679
# aspect: ACCURACY 0.9487 | F1 MACRO 0.9664 | F1 MICRO 0.9679
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.95      0.99      0.97       175
#       others       0.90      0.94      0.92       158
#         part       0.95      0.96      0.96       158
#        price       0.98      0.98      0.98       192
#      service       0.96      1.00      0.98       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.95      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.95      0.98      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 7.13474178314209 | ACCURACY: 0.919 | F1 MACRO: 0.9069 | F1 MICRO: 0.919
# EPOCH 2 | LOSS: 6.238873481750488 | ACCURACY: 0.9393 | F1 MACRO: 0.929 | F1 MICRO: 0.9393
# EPOCH 3 | LOSS: 5.486269950866699 | ACCURACY: 0.9433 | F1 MACRO: 0.9349 | F1 MICRO: 0.9433
# EPOCH 4 | LOSS: 5.239904880523682 | ACCURACY: 0.9433 | F1 MACRO: 0.9335 | F1 MICRO: 0.9433
# EPOCH 5 | LOSS: 5.065589427947998 | ACCURACY: 0.9474 | F1 MACRO: 0.9393 | F1 MICRO: 0.9474
# EPOCH 6 | LOSS: 4.893327236175537 | ACCURACY: 0.919 | F1 MACRO: 0.9028 | F1 MICRO: 0.919
# EPOCH 7 | LOSS: 4.717647552490234 | ACCURACY: 0.9433 | F1 MACRO: 0.9361 | F1 MICRO: 0.9433
# EPOCH 8 | LOSS: 4.706160068511963 | ACCURACY: 0.9109 | F1 MACRO: 0.8913 | F1 MICRO: 0.9109
# EPOCH 9 | LOSS: 4.480599880218506 | ACCURACY: 0.9433 | F1 MACRO: 0.9349 | F1 MICRO: 0.9433
# EPOCH 10 | LOSS: 4.326064586639404 | ACCURACY: 0.919 | F1 MACRO: 0.9087 | F1 MICRO: 0.919
# sentiment: ACCURACY 0.9474 | F1 MACRO 0.9393 | F1 MICRO 0.9474
#               precision    recall  f1-score   support
#
#     negative       0.89      0.95      0.92        76
#     positive       0.98      0.95      0.96       171
#
#     accuracy                           0.95       247
#    macro avg       0.93      0.95      0.94       247
# weighted avg       0.95      0.95      0.95       247
#
# --------------------------------------------------
# Iteration 333: Accuracy: 0.9444, F1 Micro: 0.9444, F1 Macro: 0.8878
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      1.00      0.99       181
#     positive       1.00      0.92      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.97      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.69      0.79        16
#      neutral       0.96      0.98      0.97       167
#     positive       0.82      0.85      0.84        33
#
#     accuracy                           0.94       216
#    macro avg       0.90      0.84      0.86       216
# weighted avg       0.94      0.94      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.67      0.73        12
#      neutral       0.90      0.94      0.92       152
#     positive       0.83      0.75      0.79        52
#
#     accuracy                           0.88       216
#    macro avg       0.84      0.79      0.81       216
# weighted avg       0.88      0.88      0.88       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.84      0.91      0.87        23
#      neutral       0.95      0.99      0.97       152
#     positive       0.94      0.76      0.84        41
#
#     accuracy                           0.94       216
#    macro avg       0.91      0.89      0.89       216
# weighted avg       0.94      0.94      0.93       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.82      0.69      0.75        13
#      neutral       0.97      0.98      0.98       186
#     positive       0.82      0.82      0.82        17
#
#     accuracy                           0.95       216
#    macro avg       0.87      0.83      0.85       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.97      1.00      0.98       185
#     positive       1.00      0.76      0.87        17
#
#     accuracy                           0.97       216
#    macro avg       0.99      0.87      0.92       216
# weighted avg       0.97      0.97      0.97       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.587977409362793
# Samples above threshold: 54
# Acquired samples: 54
# Sampling duration: 13.615692615509033 seconds
# New train size: 387
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.404982566833496 | ACCURACY: 0.7954 | F1 MACRO: 0.8838 | F1 MICRO: 0.8853
# EPOCH 2 | LOSS: 2.1241095066070557 | ACCURACY: 0.8363 | F1 MACRO: 0.9048 | F1 MICRO: 0.9057
# EPOCH 3 | LOSS: 2.047994375228882 | ACCURACY: 0.8743 | F1 MACRO: 0.9236 | F1 MICRO: 0.9249
# EPOCH 4 | LOSS: 1.9679838418960571 | ACCURACY: 0.9182 | F1 MACRO: 0.9457 | F1 MICRO: 0.9489
# EPOCH 5 | LOSS: 1.8800253868103027 | ACCURACY: 0.9412 | F1 MACRO: 0.9618 | F1 MICRO: 0.9634
# EPOCH 6 | LOSS: 1.7890022993087769 | ACCURACY: 0.9494 | F1 MACRO: 0.9671 | F1 MICRO: 0.9685
# EPOCH 7 | LOSS: 1.7076048851013184 | ACCURACY: 0.9472 | F1 MACRO: 0.9651 | F1 MICRO: 0.9669
# EPOCH 8 | LOSS: 1.641969919204712 | ACCURACY: 0.9546 | F1 MACRO: 0.9705 | F1 MICRO: 0.9717
# EPOCH 9 | LOSS: 1.6066672801971436 | ACCURACY: 0.9554 | F1 MACRO: 0.9705 | F1 MICRO: 0.972
# EPOCH 10 | LOSS: 1.5506591796875 | ACCURACY: 0.9561 | F1 MACRO: 0.9711 | F1 MICRO: 0.9725
# aspect: ACCURACY 0.9561 | F1 MACRO 0.9711 | F1 MICRO 0.9725
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.97      0.97      0.97       175
#       others       0.91      0.97      0.94       158
#         part       0.94      0.97      0.96       158
#        price       0.98      0.98      0.98       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.96      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.097218990325928 | ACCURACY: 0.9222 | F1 MACRO: 0.9121 | F1 MICRO: 0.9222
# EPOCH 2 | LOSS: 5.490853786468506 | ACCURACY: 0.9261 | F1 MACRO: 0.9177 | F1 MICRO: 0.9261
# EPOCH 3 | LOSS: 4.794473171234131 | ACCURACY: 0.9261 | F1 MACRO: 0.9147 | F1 MICRO: 0.9261
# EPOCH 4 | LOSS: 4.7512526512146 | ACCURACY: 0.9222 | F1 MACRO: 0.9136 | F1 MICRO: 0.9222
# EPOCH 5 | LOSS: 4.456718444824219 | ACCURACY: 0.9416 | F1 MACRO: 0.9317 | F1 MICRO: 0.9416
# EPOCH 6 | LOSS: 4.30070686340332 | ACCURACY: 0.9455 | F1 MACRO: 0.9381 | F1 MICRO: 0.9455
# EPOCH 7 | LOSS: 4.048121929168701 | ACCURACY: 0.9144 | F1 MACRO: 0.9008 | F1 MICRO: 0.9144
# EPOCH 8 | LOSS: 4.0199103355407715 | ACCURACY: 0.93 | F1 MACRO: 0.9218 | F1 MICRO: 0.93
# EPOCH 9 | LOSS: 3.986929178237915 | ACCURACY: 0.93 | F1 MACRO: 0.9214 | F1 MICRO: 0.93
# EPOCH 10 | LOSS: 3.810058116912842 | ACCURACY: 0.93 | F1 MACRO: 0.9194 | F1 MICRO: 0.93
# sentiment: ACCURACY 0.9455 | F1 MACRO 0.9381 | F1 MICRO 0.9455
#               precision    recall  f1-score   support
#
#     negative       0.89      0.95      0.92        81
#     positive       0.98      0.94      0.96       176
#
#     accuracy                           0.95       257
#    macro avg       0.93      0.95      0.94       257
# weighted avg       0.95      0.95      0.95       257
#
# --------------------------------------------------
# Iteration 387: Accuracy: 0.9483, F1 Micro: 0.9483, F1 Macro: 0.8972
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      1.00      0.99       181
#     positive       1.00      0.92      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.97      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.75      0.77        16
#      neutral       0.96      0.96      0.96       167
#     positive       0.77      0.82      0.79        33
#
#     accuracy                           0.92       216
#    macro avg       0.85      0.84      0.84       216
# weighted avg       0.92      0.92      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.75      0.75        12
#      neutral       0.92      0.96      0.94       152
#     positive       0.87      0.75      0.80        52
#
#     accuracy                           0.90       216
#    macro avg       0.84      0.82      0.83       216
# weighted avg       0.90      0.90      0.90       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.79      0.96      0.86        23
#      neutral       0.95      0.98      0.96       152
#     positive       0.94      0.71      0.81        41
#
#     accuracy                           0.93       216
#    macro avg       0.89      0.88      0.88       216
# weighted avg       0.93      0.93      0.92       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.92      0.86        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.87      0.76      0.81        17
#
#     accuracy                           0.97       216
#    macro avg       0.89      0.89      0.89       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.98      1.00      0.99       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       0.99      0.93      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.444600963592529
# Samples above threshold: 48
# Acquired samples: 48
# Sampling duration: 14.45957899093628 seconds
# New train size: 435
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.292759895324707 | ACCURACY: 0.7924 | F1 MACRO: 0.8823 | F1 MICRO: 0.8838
# EPOCH 2 | LOSS: 2.037785530090332 | ACCURACY: 0.8385 | F1 MACRO: 0.9041 | F1 MICRO: 0.9056
# EPOCH 3 | LOSS: 1.9710019826889038 | ACCURACY: 0.8966 | F1 MACRO: 0.9361 | F1 MICRO: 0.9374
# EPOCH 4 | LOSS: 1.8899263143539429 | ACCURACY: 0.9323 | F1 MACRO: 0.9547 | F1 MICRO: 0.9576
# EPOCH 5 | LOSS: 1.779451847076416 | ACCURACY: 0.9427 | F1 MACRO: 0.9623 | F1 MICRO: 0.9643
# EPOCH 6 | LOSS: 1.7203150987625122 | ACCURACY: 0.9561 | F1 MACRO: 0.9712 | F1 MICRO: 0.9726
# EPOCH 7 | LOSS: 1.6359201669692993 | ACCURACY: 0.9568 | F1 MACRO: 0.9718 | F1 MICRO: 0.973
# EPOCH 8 | LOSS: 1.5864452123641968 | ACCURACY: 0.9494 | F1 MACRO: 0.9666 | F1 MICRO: 0.9683
# EPOCH 9 | LOSS: 1.5527814626693726 | ACCURACY: 0.9554 | F1 MACRO: 0.9702 | F1 MICRO: 0.9719
# EPOCH 10 | LOSS: 1.4950653314590454 | ACCURACY: 0.9576 | F1 MACRO: 0.9711 | F1 MICRO: 0.9732
# aspect: ACCURACY 0.9576 | F1 MACRO 0.9711 | F1 MICRO 0.9732
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.95      0.97      0.96       175
#       others       0.95      0.89      0.92       158
#         part       0.97      0.98      0.97       158
#        price       0.99      0.99      0.99       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.97      0.97      0.97      1061
#    macro avg       0.97      0.97      0.97      1061
# weighted avg       0.97      0.97      0.97      1061
#  samples avg       0.97      0.97      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 5.743354320526123 | ACCURACY: 0.9022 | F1 MACRO: 0.8896 | F1 MICRO: 0.9022
# EPOCH 2 | LOSS: 4.818724155426025 | ACCURACY: 0.9529 | F1 MACRO: 0.9449 | F1 MICRO: 0.9529
# EPOCH 3 | LOSS: 4.405365943908691 | ACCURACY: 0.9275 | F1 MACRO: 0.9099 | F1 MICRO: 0.9275
# EPOCH 4 | LOSS: 3.9776406288146973 | ACCURACY: 0.9312 | F1 MACRO: 0.919 | F1 MICRO: 0.9312
# EPOCH 5 | LOSS: 3.9857707023620605 | ACCURACY: 0.9493 | F1 MACRO: 0.9401 | F1 MICRO: 0.9493
# EPOCH 6 | LOSS: 3.713390350341797 | ACCURACY: 0.9348 | F1 MACRO: 0.9249 | F1 MICRO: 0.9348
# EPOCH 7 | LOSS: 3.706373929977417 | ACCURACY: 0.9239 | F1 MACRO: 0.9099 | F1 MICRO: 0.9239
# EPOCH 8 | LOSS: 3.6168270111083984 | ACCURACY: 0.9348 | F1 MACRO: 0.9254 | F1 MICRO: 0.9348
# EPOCH 9 | LOSS: 3.588352680206299 | ACCURACY: 0.9203 | F1 MACRO: 0.9039 | F1 MICRO: 0.9203
# EPOCH 10 | LOSS: 3.4222567081451416 | ACCURACY: 0.9493 | F1 MACRO: 0.9413 | F1 MICRO: 0.9493
# sentiment: ACCURACY 0.9529 | F1 MACRO 0.9449 | F1 MICRO 0.9529
#               precision    recall  f1-score   support
#
#     negative       0.90      0.95      0.92        83
#     positive       0.98      0.95      0.97       193
#
#     accuracy                           0.95       276
#    macro avg       0.94      0.95      0.94       276
# weighted avg       0.95      0.95      0.95       276
#
# --------------------------------------------------
# Iteration 435: Accuracy: 0.9491, F1 Micro: 0.9491, F1 Macro: 0.9098
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      1.00      0.99       181
#     positive       1.00      0.92      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.97      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.81      0.84        16
#      neutral       0.97      0.96      0.97       167
#     positive       0.83      0.88      0.85        33
#
#     accuracy                           0.94       216
#    macro avg       0.89      0.89      0.89       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.69      0.75      0.72        12
#      neutral       0.93      0.88      0.90       152
#     positive       0.70      0.81      0.75        52
#
#     accuracy                           0.85       216
#    macro avg       0.77      0.81      0.79       216
# weighted avg       0.86      0.85      0.86       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.85      1.00      0.92        23
#      neutral       0.96      0.98      0.97       152
#     positive       0.94      0.78      0.85        41
#
#     accuracy                           0.94       216
#    macro avg       0.92      0.92      0.91       216
# weighted avg       0.95      0.94      0.94       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.85      0.85        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.88      0.88      0.88        17
#
#     accuracy                           0.98       216
#    macro avg       0.91      0.91      0.91       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.99      1.00      0.99       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.96      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.5226356983184814
# Samples above threshold: 43
# Acquired samples: 43
# Sampling duration: 15.290100336074829 seconds
# New train size: 478
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.268925905227661 | ACCURACY: 0.7902 | F1 MACRO: 0.8812 | F1 MICRO: 0.8827
# EPOCH 2 | LOSS: 2.0213897228240967 | ACCURACY: 0.8467 | F1 MACRO: 0.9096 | F1 MICRO: 0.9107
# EPOCH 3 | LOSS: 1.921712875366211 | ACCURACY: 0.9048 | F1 MACRO: 0.9396 | F1 MICRO: 0.9417
# EPOCH 4 | LOSS: 1.8643733263015747 | ACCURACY: 0.9464 | F1 MACRO: 0.9658 | F1 MICRO: 0.9669
# EPOCH 5 | LOSS: 1.7765228748321533 | ACCURACY: 0.9524 | F1 MACRO: 0.9692 | F1 MICRO: 0.9705
# EPOCH 6 | LOSS: 1.6746981143951416 | ACCURACY: 0.9606 | F1 MACRO: 0.9738 | F1 MICRO: 0.9752
# EPOCH 7 | LOSS: 1.6075314283370972 | ACCURACY: 0.9561 | F1 MACRO: 0.9706 | F1 MICRO: 0.9724
# EPOCH 8 | LOSS: 1.565043568611145 | ACCURACY: 0.9583 | F1 MACRO: 0.972 | F1 MICRO: 0.9738
# EPOCH 9 | LOSS: 1.517767310142517 | ACCURACY: 0.9583 | F1 MACRO: 0.9727 | F1 MICRO: 0.9739
# EPOCH 10 | LOSS: 1.4861451387405396 | ACCURACY: 0.9583 | F1 MACRO: 0.9725 | F1 MICRO: 0.974
# aspect: ACCURACY 0.9606 | F1 MACRO 0.9738 | F1 MICRO 0.9752
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.95      0.99      0.97       175
#       others       0.94      0.94      0.94       158
#         part       0.96      0.97      0.97       158
#        price       0.98      0.99      0.99       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.97      0.98      0.98      1061
#    macro avg       0.97      0.98      0.97      1061
# weighted avg       0.97      0.98      0.98      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 4.979722499847412 | ACCURACY: 0.8924 | F1 MACRO: 0.8809 | F1 MICRO: 0.8924
# EPOCH 2 | LOSS: 4.323098182678223 | ACCURACY: 0.9283 | F1 MACRO: 0.919 | F1 MICRO: 0.9283
# EPOCH 3 | LOSS: 3.845323324203491 | ACCURACY: 0.9163 | F1 MACRO: 0.9005 | F1 MICRO: 0.9163
# EPOCH 4 | LOSS: 3.670614242553711 | ACCURACY: 0.9363 | F1 MACRO: 0.9276 | F1 MICRO: 0.9363
# EPOCH 5 | LOSS: 3.4430553913116455 | ACCURACY: 0.9243 | F1 MACRO: 0.9175 | F1 MICRO: 0.9243
# EPOCH 6 | LOSS: 3.493591070175171 | ACCURACY: 0.9283 | F1 MACRO: 0.9195 | F1 MICRO: 0.9283
# EPOCH 7 | LOSS: 3.220137596130371 | ACCURACY: 0.9323 | F1 MACRO: 0.9254 | F1 MICRO: 0.9323
# EPOCH 8 | LOSS: 3.1593682765960693 | ACCURACY: 0.9363 | F1 MACRO: 0.9266 | F1 MICRO: 0.9363
# EPOCH 9 | LOSS: 3.067410945892334 | ACCURACY: 0.9482 | F1 MACRO: 0.942 | F1 MICRO: 0.9482
# EPOCH 10 | LOSS: 3.0050973892211914 | ACCURACY: 0.9402 | F1 MACRO: 0.9339 | F1 MICRO: 0.9402
# sentiment: ACCURACY 0.9482 | F1 MACRO 0.942 | F1 MICRO 0.9482
#               precision    recall  f1-score   support
#
#     negative       0.90      0.95      0.92        82
#     positive       0.98      0.95      0.96       169
#
#     accuracy                           0.95       251
#    macro avg       0.94      0.95      0.94       251
# weighted avg       0.95      0.95      0.95       251
#
# --------------------------------------------------
# Iteration 478: Accuracy: 0.9545, F1 Micro: 0.9545, F1 Macro: 0.9047
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.90      0.82      0.86        11
#      neutral       0.98      1.00      0.99       181
#     positive       0.95      0.88      0.91        24
#
#     accuracy                           0.98       216
#    macro avg       0.95      0.90      0.92       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.69      0.79        16
#      neutral       0.95      0.99      0.97       167
#     positive       0.83      0.76      0.79        33
#
#     accuracy                           0.93       216
#    macro avg       0.90      0.81      0.85       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.90      0.75      0.82        12
#      neutral       0.92      0.95      0.94       152
#     positive       0.86      0.81      0.83        52
#
#     accuracy                           0.91       216
#    macro avg       0.89      0.84      0.86       216
# weighted avg       0.91      0.91      0.91       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.82      1.00      0.90        23
#      neutral       0.97      0.99      0.98       152
#     positive       0.97      0.78      0.86        41
#
#     accuracy                           0.95       216
#    macro avg       0.92      0.92      0.91       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.85      0.85        13
#      neutral       0.98      0.99      0.99       186
#     positive       0.93      0.82      0.87        17
#
#     accuracy                           0.97       216
#    macro avg       0.92      0.89      0.90       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        14
#      neutral       0.99      1.00      0.99       185
#     positive       1.00      0.88      0.94        17
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.96      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.524510383605957
# Samples above threshold: 39
# Acquired samples: 39
# Sampling duration: 15.524880409240723 seconds
# New train size: 517
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.2960870265960693 | ACCURACY: 0.7924 | F1 MACRO: 0.8823 | F1 MICRO: 0.8838
# EPOCH 2 | LOSS: 2.0722310543060303 | ACCURACY: 0.8594 | F1 MACRO: 0.916 | F1 MICRO: 0.9174
# EPOCH 3 | LOSS: 1.9538873434066772 | ACCURACY: 0.9241 | F1 MACRO: 0.9504 | F1 MICRO: 0.9528
# EPOCH 4 | LOSS: 1.8758645057678223 | ACCURACY: 0.9472 | F1 MACRO: 0.9659 | F1 MICRO: 0.9673
# EPOCH 5 | LOSS: 1.7593449354171753 | ACCURACY: 0.9561 | F1 MACRO: 0.9714 | F1 MICRO: 0.9727
# EPOCH 6 | LOSS: 1.691806435585022 | ACCURACY: 0.9598 | F1 MACRO: 0.9738 | F1 MICRO: 0.9749
# EPOCH 7 | LOSS: 1.6177692413330078 | ACCURACY: 0.9464 | F1 MACRO: 0.9639 | F1 MICRO: 0.9663
# EPOCH 8 | LOSS: 1.552179217338562 | ACCURACY: 0.9576 | F1 MACRO: 0.9722 | F1 MICRO: 0.9735
# EPOCH 9 | LOSS: 1.5031908750534058 | ACCURACY: 0.9613 | F1 MACRO: 0.9744 | F1 MICRO: 0.9757
# EPOCH 10 | LOSS: 1.4791306257247925 | ACCURACY: 0.9554 | F1 MACRO: 0.9701 | F1 MICRO: 0.9718
# aspect: ACCURACY 0.9613 | F1 MACRO 0.9744 | F1 MICRO 0.9757
#               precision    recall  f1-score   support
#
# ...
#
#    micro avg       0.97      0.98      0.98      1061
#    macro avg       0.97      0.98      0.98      1061
# weighted avg       0.97      0.98      0.98      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.034644842147827 | ACCURACY: 0.8852 | F1 MACRO: 0.8732 | F1 MICRO: 0.8852
# EPOCH 2 | LOSS: 2.6087119579315186 | ACCURACY: 0.9296 | F1 MACRO: 0.9197 | F1 MICRO: 0.9296
# EPOCH 3 | LOSS: 2.398139715194702 | ACCURACY: 0.9185 | F1 MACRO: 0.9098 | F1 MICRO: 0.9185
# EPOCH 4 | LOSS: 2.2169857025146484 | ACCURACY: 0.9444 | F1 MACRO: 0.937 | F1 MICRO: 0.9444
# EPOCH 5 | LOSS: 2.0546436309814453 | ACCURACY: 0.9481 | F1 MACRO: 0.9403 | F1 MICRO: 0.9481
# EPOCH 6 | LOSS: 2.0400240421295166 | ACCURACY: 0.9148 | F1 MACRO: 0.9059 | F1 MICRO: 0.9148
# EPOCH 7 | LOSS: 1.9410556554794312 | ACCURACY: 0.9222 | F1 MACRO: 0.9137 | F1 MICRO: 0.9222
# EPOCH 8 | LOSS: 1.8807151317596436 | ACCURACY: 0.9481 | F1 MACRO: 0.9395 | F1 MICRO: 0.9481
# EPOCH 9 | LOSS: 1.8663783073425293 | ACCURACY: 0.937 | F1 MACRO: 0.929 | F1 MICRO: 0.937
# EPOCH 10 | LOSS: 1.8031672239303589 | ACCURACY: 0.937 | F1 MACRO: 0.929 | F1 MICRO: 0.937
# sentiment: ACCURACY 0.9481 | F1 MACRO 0.9395 | F1 MICRO 0.9481
#               precision    recall  f1-score   support
#
#     negative       0.92      0.92      0.92        84
#     positive       0.96      0.96      0.96       186
#
#     accuracy                           0.95       270
#    macro avg       0.94      0.94      0.94       270
# weighted avg       0.95      0.95      0.95       270
#
# --------------------------------------------------
# Iteration 831: Accuracy: 0.9545, F1 Micro: 0.9545, F1 Macro: 0.914
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.92      0.92      0.92        24
#
#     accuracy                           0.98       216
#    macro avg       0.97      0.94      0.95       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.75      0.80        16
#      neutral       0.95      0.98      0.96       167
#     positive       0.84      0.79      0.81        33
#
#     accuracy                           0.93       216
#    macro avg       0.88      0.84      0.86       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.83      0.83        12
#      neutral       0.94      0.92      0.93       152
#     positive       0.78      0.83      0.80        52
#
#     accuracy                           0.89       216
#    macro avg       0.85      0.86      0.86       216
# weighted avg       0.90      0.89      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.88      0.96      0.92        23
#      neutral       0.97      0.97      0.97       152
#     positive       0.90      0.85      0.88        41
#
#     accuracy                           0.95       216
#    macro avg       0.92      0.93      0.92       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.85      0.85        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.94      0.88      0.91        17
#
#     accuracy                           0.98       216
#    macro avg       0.92      0.91      0.92       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       1.00      1.00      1.00       185
#     positive       0.94      1.00      0.97        17
#
#     accuracy                           1.00       216
#    macro avg       0.98      0.98      0.98       216
# weighted avg       1.00      1.00      1.00       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 864
# Threshold: 2.543697214126587
# Samples above threshold: 4
# Acquired samples: 25
# Sampling duration: 21.167479991912842 seconds
# New train size: 856
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.171815872192383 | ACCURACY: 0.8423 | F1 MACRO: 0.9076 | F1 MICRO: 0.9083
# EPOCH 2 | LOSS: 1.9268163442611694 | ACCURACY: 0.9308 | F1 MACRO: 0.956 | F1 MICRO: 0.9574
# EPOCH 3 | LOSS: 1.7772507667541504 | ACCURACY: 0.9501 | F1 MACRO: 0.967 | F1 MICRO: 0.9687
# EPOCH 4 | LOSS: 1.6564840078353882 | ACCURACY: 0.9598 | F1 MACRO: 0.9737 | F1 MICRO: 0.9749
# EPOCH 5 | LOSS: 1.5741634368896484 | ACCURACY: 0.9591 | F1 MACRO: 0.9732 | F1 MICRO: 0.9744
# EPOCH 6 | LOSS: 1.5080475807189941 | ACCURACY: 0.9583 | F1 MACRO: 0.9727 | F1 MICRO: 0.9739
# EPOCH 7 | LOSS: 1.4506466388702393 | ACCURACY: 0.9591 | F1 MACRO: 0.9732 | F1 MICRO: 0.9744
# EPOCH 8 | LOSS: 1.4066901206970215 | ACCURACY: 0.9606 | F1 MACRO: 0.9742 | F1 MICRO: 0.9752
# EPOCH 9 | LOSS: 1.379317283630371 | ACCURACY: 0.9568 | F1 MACRO: 0.9705 | F1 MICRO: 0.9727
# EPOCH 10 | LOSS: 1.3426347970962524 | ACCURACY: 0.9628 | F1 MACRO: 0.9744 | F1 MICRO: 0.9764
# aspect: ACCURACY 0.9628 | F1 MACRO 0.9744 | F1 MICRO 0.9764
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.97      0.97      0.97       175
#       others       0.95      0.91      0.93       158
#         part       0.98      0.96      0.97       158
#        price       0.99      0.99      0.99       192
#      service       1.00      1.00      1.00       191
#
#    micro avg       0.98      0.97      0.98      1061
#    macro avg       0.98      0.97      0.97      1061
# weighted avg       0.98      0.97      0.98      1061
#  samples avg       0.98      0.97      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 2.990492105484009 | ACCURACY: 0.92 | F1 MACRO: 0.9057 | F1 MICRO: 0.92
# EPOCH 2 | LOSS: 2.4471352100372314 | ACCURACY: 0.9127 | F1 MACRO: 0.8942 | F1 MICRO: 0.9127
# EPOCH 3 | LOSS: 2.189542055130005 | ACCURACY: 0.9236 | F1 MACRO: 0.9085 | F1 MICRO: 0.9236
# EPOCH 4 | LOSS: 2.056049108505249 | ACCURACY: 0.9236 | F1 MACRO: 0.9115 | F1 MICRO: 0.9236
# EPOCH 5 | LOSS: 1.9516870975494385 | ACCURACY: 0.9382 | F1 MACRO: 0.9304 | F1 MICRO: 0.9382
# EPOCH 6 | LOSS: 1.9389982223510742 | ACCURACY: 0.92 | F1 MACRO: 0.9115 | F1 MICRO: 0.92
# EPOCH 7 | LOSS: 1.8009206056594849 | ACCURACY: 0.9527 | F1 MACRO: 0.9445 | F1 MICRO: 0.9527
# EPOCH 8 | LOSS: 1.8464746475219727 | ACCURACY: 0.9309 | F1 MACRO: 0.923 | F1 MICRO: 0.9309
# EPOCH 9 | LOSS: 1.7657558917999268 | ACCURACY: 0.9236 | F1 MACRO: 0.9109 | F1 MICRO: 0.9236
# EPOCH 10 | LOSS: 1.7680922746658325 | ACCURACY: 0.9382 | F1 MACRO: 0.9296 | F1 MICRO: 0.9382
# sentiment: ACCURACY 0.9527 | F1 MACRO 0.9445 | F1 MICRO 0.9527
#               precision    recall  f1-score   support
#
#     negative       0.95      0.90      0.92        87
#     positive       0.95      0.98      0.97       188
#
#     accuracy                           0.95       275
#    macro avg       0.95      0.94      0.94       275
# weighted avg       0.95      0.95      0.95       275
#
# --------------------------------------------------
# Iteration 856: Accuracy: 0.9514, F1 Micro: 0.9514, F1 Macro: 0.9169
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.97      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.81      0.87        16
#      neutral       0.95      0.98      0.96       167
#     positive       0.81      0.76      0.78        33
#
#     accuracy                           0.93       216
#    macro avg       0.90      0.85      0.87       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.83      0.83        12
#      neutral       0.94      0.90      0.92       152
#     positive       0.72      0.81      0.76        52
#
#     accuracy                           0.88       216
#    macro avg       0.83      0.85      0.84       216
# weighted avg       0.88      0.88      0.88       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.81      0.96      0.88        23
#      neutral       0.98      0.97      0.98       152
#     positive       0.89      0.83      0.86        41
#
#     accuracy                           0.94       216
#    macro avg       0.90      0.92      0.91       216
# weighted avg       0.95      0.94      0.94       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.92      0.92        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.88      0.88      0.88        17
#
#     accuracy                           0.98       216
#    macro avg       0.93      0.93      0.93       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       1.00      1.00      1.00       185
#     positive       0.94      1.00      0.97        17
#
#     accuracy                           1.00       216
#    macro avg       0.98      0.98      0.98       216
# weighted avg       1.00      1.00      1.00       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 864
# Threshold: 2.5973432540893553
# Samples above threshold: 1
# Acquired samples: 8
# Sampling duration: 21.842816591262817 seconds
# New train size: 864
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.191413402557373 | ACCURACY: 0.8289 | F1 MACRO: 0.901 | F1 MICRO: 0.9021
# EPOCH 2 | LOSS: 1.9121179580688477 | ACCURACY: 0.9382 | F1 MACRO: 0.9599 | F1 MICRO: 0.9617
# EPOCH 3 | LOSS: 1.7720669507980347 | ACCURACY: 0.9539 | F1 MACRO: 0.9699 | F1 MICRO: 0.9713
# EPOCH 4 | LOSS: 1.660385012626648 | ACCURACY: 0.9598 | F1 MACRO: 0.9735 | F1 MICRO: 0.9748
# EPOCH 5 | LOSS: 1.5740506649017334 | ACCURACY: 0.9598 | F1 MACRO: 0.9736 | F1 MICRO: 0.9748
# EPOCH 6 | LOSS: 1.5003366470336914 | ACCURACY: 0.9576 | F1 MACRO: 0.9717 | F1 MICRO: 0.9733
# EPOCH 7 | LOSS: 1.445361852645874 | ACCURACY: 0.9546 | F1 MACRO: 0.9694 | F1 MICRO: 0.9714
# EPOCH 8 | LOSS: 1.415745735168457 | ACCURACY: 0.9606 | F1 MACRO: 0.9737 | F1 MICRO: 0.9752
# EPOCH 9 | LOSS: 1.361783504486084 | ACCURACY: 0.9606 | F1 MACRO: 0.9728 | F1 MICRO: 0.9751
# EPOCH 10 | LOSS: 1.3360518217086792 | ACCURACY: 0.9613 | F1 MACRO: 0.974 | F1 MICRO: 0.9757
# aspect: ACCURACY 0.9613 | F1 MACRO 0.974 | F1 MICRO 0.9757
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.94      0.99      0.96       175
#       others       0.91      0.93      0.92       158
#         part       0.97      0.97      0.97       158
#        price       0.99      1.00      0.99       192
#      service       1.00      1.00      1.00       191
#
#    micro avg       0.97      0.98      0.98      1061
#    macro avg       0.97      0.98      0.97      1061
# weighted avg       0.97      0.98      0.98      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 2.9323666095733643 | ACCURACY: 0.8889 | F1 MACRO: 0.8786 | F1 MICRO: 0.8889
# EPOCH 2 | LOSS: 2.4185826778411865 | ACCURACY: 0.9349 | F1 MACRO: 0.9273 | F1 MICRO: 0.9349
# EPOCH 3 | LOSS: 2.173388719558716 | ACCURACY: 0.931 | F1 MACRO: 0.9237 | F1 MICRO: 0.931
# EPOCH 4 | LOSS: 2.106809616088867 | ACCURACY: 0.9272 | F1 MACRO: 0.9183 | F1 MICRO: 0.9272
# EPOCH 5 | LOSS: 1.9813913106918335 | ACCURACY: 0.9502 | F1 MACRO: 0.9441 | F1 MICRO: 0.9502
# EPOCH 6 | LOSS: 1.905631184577942 | ACCURACY: 0.9387 | F1 MACRO: 0.9302 | F1 MICRO: 0.9387
# EPOCH 7 | LOSS: 1.8940120935440063 | ACCURACY: 0.9425 | F1 MACRO: 0.9352 | F1 MICRO: 0.9425
# EPOCH 8 | LOSS: 1.79111647605896 | ACCURACY: 0.9425 | F1 MACRO: 0.9344 | F1 MICRO: 0.9425
# EPOCH 9 | LOSS: 1.8088853359222412 | ACCURACY: 0.931 | F1 MACRO: 0.9224 | F1 MICRO: 0.931
# EPOCH 10 | LOSS: 1.7979257106781006 | ACCURACY: 0.9157 | F1 MACRO: 0.9067 | F1 MICRO: 0.9157
# sentiment: ACCURACY 0.9502 | F1 MACRO 0.9441 | F1 MICRO 0.9502
#               precision    recall  f1-score   support
#
#     negative       0.88      0.98      0.93        83
#     positive       0.99      0.94      0.96       178
#
#     accuracy                           0.95       261
#    macro avg       0.93      0.96      0.94       261
# weighted avg       0.95      0.95      0.95       261
#
# --------------------------------------------------
# Iteration 864: Accuracy: 0.9537, F1 Micro: 0.9537, F1 Macro: 0.9081
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.92      1.00      0.96        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.95      0.88      0.91        24
#
#     accuracy                           0.98       216
#    macro avg       0.95      0.96      0.95       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.75      0.83        16
#      neutral       0.94      0.99      0.96       167
#     positive       0.89      0.73      0.80        33
#
#     accuracy                           0.93       216
#    macro avg       0.92      0.82      0.86       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.77      0.83      0.80        12
#      neutral       0.93      0.94      0.93       152
#     positive       0.82      0.77      0.79        52
#
#     accuracy                           0.89       216
#    macro avg       0.84      0.85      0.84       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.82      1.00      0.90        23
#      neutral       0.98      0.97      0.98       152
#     positive       0.92      0.83      0.87        41
#
#     accuracy                           0.95       216
#    macro avg       0.91      0.93      0.92       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.79      0.85      0.81        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.93      0.82      0.87        17
#
#     accuracy                           0.97       216
#    macro avg       0.90      0.89      0.89       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.93      1.00      0.97        14
#      neutral       1.00      1.00      1.00       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           1.00       216
#    macro avg       0.98      0.98      0.98       216
# weighted avg       1.00      1.00      1.00       216
#
# Total sampling time: 397.54 seconds
# Total runtime: 3047.1440494060516 seconds

# %% [markdown]
# ## RUN 2

# %%
active_learning(seeds[1], 1)
# Out:
# ===============================================
# TRIAL 2
# Random seed: 81
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.6551575660705566 | ACCURACY: 0.7634 | F1 MACRO: 0.8524 | F1 MICRO: 0.8603
# EPOCH 2 | LOSS: 2.2953057289123535 | ACCURACY: 0.7314 | F1 MACRO: 0.7859 | F1 MICRO: 0.8372
# EPOCH 3 | LOSS: 2.2718558311462402 | ACCURACY: 0.7269 | F1 MACRO: 0.7834 | F1 MICRO: 0.8348
# EPOCH 4 | LOSS: 2.1684341430664062 | ACCURACY: 0.7515 | F1 MACRO: 0.8361 | F1 MICRO: 0.854
# EPOCH 5 | LOSS: 2.1205921173095703 | ACCURACY: 0.7746 | F1 MACRO: 0.8634 | F1 MICRO: 0.8701
# EPOCH 6 | LOSS: 2.0397868156433105 | ACCURACY: 0.7708 | F1 MACRO: 0.8606 | F1 MICRO: 0.8679
# EPOCH 7 | LOSS: 2.0059454441070557 | ACCURACY: 0.779 | F1 MACRO: 0.8634 | F1 MICRO: 0.8716
# EPOCH 8 | LOSS: 2.054938793182373 | ACCURACY: 0.7708 | F1 MACRO: 0.8477 | F1 MICRO: 0.8642
# EPOCH 9 | LOSS: 1.9649527072906494 | ACCURACY: 0.7567 | F1 MACRO: 0.8195 | F1 MICRO: 0.8526
# EPOCH 10 | LOSS: 1.9658112525939941 | ACCURACY: 0.7597 | F1 MACRO: 0.8237 | F1 MICRO: 0.8547
# aspect: ACCURACY 0.779 | F1 MACRO 0.8634 | F1 MICRO 0.8716
#               precision    recall  f1-score   support
#
#         fuel       0.83      1.00      0.91       187
#      machine       0.78      1.00      0.88       175
#       others       0.76      0.66      0.71       158
#         part       0.72      1.00      0.84       158
#        price       0.86      1.00      0.92       192
#      service       0.85      1.00      0.92       191
#
#    micro avg       0.81      0.95      0.87      1061
#    macro avg       0.80      0.94      0.86      1061
# weighted avg       0.81      0.95      0.87      1061
#  samples avg       0.81      0.95      0.87      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 8.655595779418945 | ACCURACY: 0.907 | F1 MACRO: 0.4756 | F1 MICRO: 0.907
# EPOCH 2 | LOSS: 8.490882873535156 | ACCURACY: 0.907 | F1 MACRO: 0.4756 | F1 MICRO: 0.907
# EPOCH 3 | LOSS: 8.232906341552734 | ACCURACY: 0.907 | F1 MACRO: 0.4756 | F1 MICRO: 0.907
# EPOCH 4 | LOSS: 7.491517066955566 | ACCURACY: 0.907 | F1 MACRO: 0.4756 | F1 MICRO: 0.907
# EPOCH 5 | LOSS: 7.389594554901123 | ACCURACY: 0.907 | F1 MACRO: 0.4756 | F1 MICRO: 0.907
# EPOCH 6 | LOSS: 7.796169757843018 | ACCURACY: 0.8953 | F1 MACRO: 0.4724 | F1 MICRO: 0.8953
# EPOCH 7 | LOSS: 7.377608776092529 | ACCURACY: 0.8953 | F1 MACRO: 0.4724 | F1 MICRO: 0.8953
# EPOCH 8 | LOSS: 6.78053617477417 | ACCURACY: 0.8953 | F1 MACRO: 0.563 | F1 MICRO: 0.8953
# EPOCH 9 | LOSS: 6.370694637298584 | ACCURACY: 0.9302 | F1 MACRO: 0.7667 | F1 MICRO: 0.9302
# EPOCH 10 | LOSS: 6.21047306060791 | ACCURACY: 0.8953 | F1 MACRO: 0.7063 | F1 MICRO: 0.8953
# sentiment: ACCURACY 0.9302 | F1 MACRO 0.7667 | F1 MICRO 0.9302
#               precision    recall  f1-score   support
#
#     negative       0.67      0.50      0.57         8
#     positive       0.95      0.97      0.96        78
#
#     accuracy                           0.93        86
#    macro avg       0.81      0.74      0.77        86
# weighted avg       0.92      0.93      0.93        86
#
# --------------------------------------------------
# Iteration 54: Accuracy: 0.7685, F1 Micro: 0.7685, F1 Macro: 0.3312
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        11
#      neutral       0.84      1.00      0.91       181
#     positive       0.00      0.00      0.00        24
#
#     accuracy                           0.84       216
#    macro avg       0.28      0.33      0.30       216
# weighted avg       0.70      0.84      0.76       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        16
#      neutral       0.77      1.00      0.87       167
#     positive       0.00      0.00      0.00        33
#
#     accuracy                           0.77       216
#    macro avg       0.26      0.33      0.29       216
# weighted avg       0.60      0.77      0.67       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.57      0.33      0.42        12
#      neutral       0.74      0.64      0.69       152
#     positive       0.29      0.42      0.34        52
#
#     accuracy                           0.57       216
#    macro avg       0.53      0.47      0.48       216
# weighted avg       0.62      0.57      0.59       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        23
#      neutral       0.71      1.00      0.83       152
#     positive       0.50      0.02      0.05        41
#
#     accuracy                           0.71       216
#    macro avg       0.40      0.34      0.29       216
# weighted avg       0.59      0.71      0.59       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        13
#      neutral       0.86      1.00      0.93       186
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.86       216
#    macro avg       0.29      0.33      0.31       216
# weighted avg       0.74      0.86      0.80       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        14
#      neutral       0.86      1.00      0.92       185
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.86       216
#    macro avg       0.29      0.33      0.31       216
# weighted avg       0.73      0.86      0.79       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.622144675254822
# Samples above threshold: 81
# Acquired samples: 81
# Sampling duration: 6.877247333526611 seconds
# New train size: 135
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.700975179672241 | ACCURACY: 0.7329 | F1 MACRO: 0.8068 | F1 MICRO: 0.8407
# EPOCH 2 | LOSS: 2.4081451892852783 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# EPOCH 3 | LOSS: 2.307811737060547 | ACCURACY: 0.7917 | F1 MACRO: 0.8812 | F1 MICRO: 0.8829
# EPOCH 4 | LOSS: 2.2442948818206787 | ACCURACY: 0.7865 | F1 MACRO: 0.8638 | F1 MICRO: 0.8741
# EPOCH 5 | LOSS: 2.166389226913452 | ACCURACY: 0.8118 | F1 MACRO: 0.8903 | F1 MICRO: 0.8923
# EPOCH 6 | LOSS: 2.122018575668335 | ACCURACY: 0.8318 | F1 MACRO: 0.9015 | F1 MICRO: 0.9028
# EPOCH 7 | LOSS: 2.093491792678833 | ACCURACY: 0.8341 | F1 MACRO: 0.8997 | F1 MICRO: 0.9023
# EPOCH 8 | LOSS: 2.044800281524658 | ACCURACY: 0.8534 | F1 MACRO: 0.9118 | F1 MICRO: 0.9135
# EPOCH 9 | LOSS: 2.036327838897705 | ACCURACY: 0.8698 | F1 MACRO: 0.9204 | F1 MICRO: 0.9221
# EPOCH 10 | LOSS: 1.9744455814361572 | ACCURACY: 0.8765 | F1 MACRO: 0.9235 | F1 MICRO: 0.9255
# aspect: ACCURACY 0.8765 | F1 MACRO 0.9235 | F1 MICRO 0.9255
#               precision    recall  f1-score   support
#
#         fuel       0.88      0.99      0.93       187
#      machine       0.84      0.99      0.91       175
#       others       0.84      0.93      0.89       158
#         part       0.90      0.91      0.90       158
#        price       0.94      0.99      0.96       192
#      service       0.90      1.00      0.95       191
#
#    micro avg       0.88      0.97      0.93      1061
#    macro avg       0.88      0.97      0.92      1061
# weighted avg       0.88      0.97      0.93      1061
#  samples avg       0.89      0.97      0.92      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 11.518153190612793 | ACCURACY: 0.6901 | F1 MACRO: 0.4083 | F1 MICRO: 0.6901
# EPOCH 2 | LOSS: 10.571666717529297 | ACCURACY: 0.8947 | F1 MACRO: 0.8845 | F1 MICRO: 0.8947
# EPOCH 3 | LOSS: 9.445976257324219 | ACCURACY: 0.9006 | F1 MACRO: 0.8761 | F1 MICRO: 0.9006
# EPOCH 4 | LOSS: 8.894502639770508 | ACCURACY: 0.9298 | F1 MACRO: 0.9171 | F1 MICRO: 0.9298
# EPOCH 5 | LOSS: 8.096190452575684 | ACCURACY: 0.9357 | F1 MACRO: 0.9273 | F1 MICRO: 0.9357
# EPOCH 6 | LOSS: 7.408843040466309 | ACCURACY: 0.9123 | F1 MACRO: 0.8921 | F1 MICRO: 0.9123
# EPOCH 7 | LOSS: 7.198324680328369 | ACCURACY: 0.924 | F1 MACRO: 0.9141 | F1 MICRO: 0.924
# EPOCH 8 | LOSS: 6.819868087768555 | ACCURACY: 0.924 | F1 MACRO: 0.9125 | F1 MICRO: 0.924
# EPOCH 9 | LOSS: 6.680368900299072 | ACCURACY: 0.9006 | F1 MACRO: 0.8855 | F1 MICRO: 0.9006
# EPOCH 10 | LOSS: 6.568608283996582 | ACCURACY: 0.9006 | F1 MACRO: 0.8832 | F1 MICRO: 0.9006
# sentiment: ACCURACY 0.9357 | F1 MACRO 0.9273 | F1 MICRO 0.9357
#               precision    recall  f1-score   support
#
#     negative       0.85      0.96      0.90        53
#     positive       0.98      0.92      0.95       118
#
#     accuracy                           0.94       171
#    macro avg       0.92      0.94      0.93       171
# weighted avg       0.94      0.94      0.94       171
#
# --------------------------------------------------
# Iteration 135: Accuracy: 0.8765, F1 Micro: 0.8765, F1 Macro: 0.7033
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.45      0.62        11
#      neutral       0.89      1.00      0.94       181
#     positive       1.00      0.29      0.45        24
#
#     accuracy                           0.89       216
#    macro avg       0.96      0.58      0.67       216
# weighted avg       0.91      0.89      0.87       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.38      0.52        16
#      neutral       0.85      0.99      0.91       167
#     positive       0.86      0.36      0.51        33
#
#     accuracy                           0.85       216
#    macro avg       0.85      0.58      0.65       216
# weighted avg       0.85      0.85      0.82       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.67      0.73        12
#      neutral       0.84      0.93      0.88       152
#     positive       0.74      0.56      0.64        52
#
#     accuracy                           0.82       216
#    macro avg       0.80      0.72      0.75       216
# weighted avg       0.82      0.82      0.82       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.78      0.77        23
#      neutral       0.92      0.92      0.92       152
#     positive       0.74      0.71      0.72        41
#
#     accuracy                           0.87       216
#    macro avg       0.80      0.80      0.80       216
# weighted avg       0.86      0.87      0.87       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.90      0.69      0.78        13
#      neutral       0.94      1.00      0.97       186
#     positive       0.89      0.47      0.62        17
#
#     accuracy                           0.94       216
#    macro avg       0.91      0.72      0.79       216
# weighted avg       0.94      0.94      0.93       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.29      0.44        14
#      neutral       0.89      1.00      0.94       185
#     positive       0.75      0.18      0.29        17
#
#     accuracy                           0.89       216
#    macro avg       0.88      0.49      0.56       216
# weighted avg       0.89      0.89      0.86       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.517767143249512
# Samples above threshold: 73
# Acquired samples: 73
# Sampling duration: 9.461878776550293 seconds
# New train size: 208
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.597780704498291 | ACCURACY: 0.7589 | F1 MACRO: 0.848 | F1 MICRO: 0.8599
# EPOCH 2 | LOSS: 2.29079270362854 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# EPOCH 3 | LOSS: 2.195158004760742 | ACCURACY: 0.7999 | F1 MACRO: 0.8808 | F1 MICRO: 0.8846
# EPOCH 4 | LOSS: 2.117981195449829 | ACCURACY: 0.8199 | F1 MACRO: 0.8942 | F1 MICRO: 0.8964
# EPOCH 5 | LOSS: 2.074404239654541 | ACCURACY: 0.8445 | F1 MACRO: 0.9083 | F1 MICRO: 0.9094
# EPOCH 6 | LOSS: 2.0350735187530518 | ACCURACY: 0.8646 | F1 MACRO: 0.9172 | F1 MICRO: 0.9192
# EPOCH 7 | LOSS: 1.967642068862915 | ACCURACY: 0.8981 | F1 MACRO: 0.9371 | F1 MICRO: 0.9384
# EPOCH 8 | LOSS: 1.9159331321716309 | ACCURACY: 0.9107 | F1 MACRO: 0.9432 | F1 MICRO: 0.9453
# EPOCH 9 | LOSS: 1.8662742376327515 | ACCURACY: 0.9152 | F1 MACRO: 0.9462 | F1 MICRO: 0.948
# EPOCH 10 | LOSS: 1.8890613317489624 | ACCURACY: 0.9211 | F1 MACRO: 0.9489 | F1 MICRO: 0.9514
# aspect: ACCURACY 0.9211 | F1 MACRO 0.9489 | F1 MICRO 0.9514
#               precision    recall  f1-score   support
#
#         fuel       0.94      1.00      0.97       187
#      machine       0.91      1.00      0.95       175
#       others       0.86      0.88      0.87       158
#         part       0.92      0.98      0.95       158
#        price       0.97      0.99      0.98       192
#      service       0.95      1.00      0.98       191
#
#    micro avg       0.93      0.98      0.95      1061
#    macro avg       0.92      0.98      0.95      1061
# weighted avg       0.93      0.98      0.95      1061
#  samples avg       0.93      0.98      0.95      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 10.168681144714355 | ACCURACY: 0.8789 | F1 MACRO: 0.86 | F1 MICRO: 0.8789
# EPOCH 2 | LOSS: 9.08189868927002 | ACCURACY: 0.8924 | F1 MACRO: 0.8741 | F1 MICRO: 0.8924
# EPOCH 3 | LOSS: 7.913907051086426 | ACCURACY: 0.9327 | F1 MACRO: 0.9275 | F1 MICRO: 0.9327
# EPOCH 4 | LOSS: 7.400145530700684 | ACCURACY: 0.9103 | F1 MACRO: 0.9002 | F1 MICRO: 0.9103
# EPOCH 5 | LOSS: 6.640460968017578 | ACCURACY: 0.9238 | F1 MACRO: 0.916 | F1 MICRO: 0.9238
# EPOCH 6 | LOSS: 6.405538558959961 | ACCURACY: 0.9283 | F1 MACRO: 0.922 | F1 MICRO: 0.9283
# EPOCH 7 | LOSS: 6.1805620193481445 | ACCURACY: 0.9013 | F1 MACRO: 0.8909 | F1 MICRO: 0.9013
# EPOCH 8 | LOSS: 6.121863842010498 | ACCURACY: 0.9283 | F1 MACRO: 0.9216 | F1 MICRO: 0.9283
# EPOCH 9 | LOSS: 5.836825847625732 | ACCURACY: 0.9148 | F1 MACRO: 0.9029 | F1 MICRO: 0.9148
# EPOCH 10 | LOSS: 6.168548583984375 | ACCURACY: 0.9238 | F1 MACRO: 0.9169 | F1 MICRO: 0.9238
# sentiment: ACCURACY 0.9327 | F1 MACRO 0.9275 | F1 MICRO 0.9327
#               precision    recall  f1-score   support
#
#     negative       0.85      0.97      0.91        76
#     positive       0.99      0.91      0.95       147
#
#     accuracy                           0.93       223
#    macro avg       0.92      0.94      0.93       223
# weighted avg       0.94      0.93      0.93       223
#
# --------------------------------------------------
# Iteration 208: Accuracy: 0.9159, F1 Micro: 0.9159, F1 Macro: 0.833
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.91      0.91        11
#      neutral       0.95      1.00      0.97       181
#     positive       1.00      0.58      0.74        24
#
#     accuracy                           0.95       216
#    macro avg       0.95      0.83      0.87       216
# weighted avg       0.95      0.95      0.94       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.81      0.84        16
#      neutral       0.92      0.99      0.95       167
#     positive       0.90      0.55      0.68        33
#
#     accuracy                           0.91       216
#    macro avg       0.89      0.78      0.82       216
# weighted avg       0.91      0.91      0.90       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.60      0.75      0.67        12
#      neutral       0.88      0.89      0.89       152
#     positive       0.70      0.62      0.65        52
#
#     accuracy                           0.82       216
#    macro avg       0.72      0.75      0.74       216
# weighted avg       0.82      0.82      0.82       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.87      0.85        23
#      neutral       0.91      0.99      0.95       152
#     positive       0.93      0.63      0.75        41
#
#     accuracy                           0.91       216
#    macro avg       0.89      0.83      0.85       216
# weighted avg       0.91      0.91      0.90       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.77      0.77      0.77        13
#      neutral       0.97      0.98      0.98       186
#     positive       0.79      0.65      0.71        17
#
#     accuracy                           0.94       216
#    macro avg       0.84      0.80      0.82       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.96      1.00      0.98       185
#     positive       1.00      0.65      0.79        17
#
#     accuracy                           0.96       216
#    macro avg       0.99      0.83      0.90       216
# weighted avg       0.96      0.96      0.96       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.5199915170669556
# Samples above threshold: 66
# Acquired samples: 66
# Sampling duration: 12.048393487930298 seconds
# New train size: 274
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.325965404510498 | ACCURACY: 0.7872 | F1 MACRO: 0.8785 | F1 MICRO: 0.8804
# EPOCH 2 | LOSS: 2.1009953022003174 | ACCURACY: 0.7999 | F1 MACRO: 0.8845 | F1 MICRO: 0.8865
# EPOCH 3 | LOSS: 1.99723219871521 | ACCURACY: 0.8266 | F1 MACRO: 0.8983 | F1 MICRO: 0.9
# EPOCH 4 | LOSS: 1.9325119256973267 | ACCURACY: 0.8482 | F1 MACRO: 0.9089 | F1 MICRO: 0.9107
# EPOCH 5 | LOSS: 1.8695632219314575 | ACCURACY: 0.8951 | F1 MACRO: 0.9351 | F1 MICRO: 0.9364
# EPOCH 6 | LOSS: 1.8282276391983032 | ACCURACY: 0.9182 | F1 MACRO: 0.9476 | F1 MICRO: 0.9495
# EPOCH 7 | LOSS: 1.7752611637115479 | ACCURACY: 0.9278 | F1 MACRO: 0.9537 | F1 MICRO: 0.9555
# EPOCH 8 | LOSS: 1.7275911569595337 | ACCURACY: 0.9301 | F1 MACRO: 0.9548 | F1 MICRO: 0.9566
# EPOCH 9 | LOSS: 1.6909862756729126 | ACCURACY: 0.939 | F1 MACRO: 0.9604 | F1 MICRO: 0.9622
# EPOCH 10 | LOSS: 1.6541143655776978 | ACCURACY: 0.9368 | F1 MACRO: 0.9582 | F1 MICRO: 0.9606
# aspect: ACCURACY 0.939 | F1 MACRO 0.9604 | F1 MICRO 0.9622
#               precision    recall  f1-score   support
#
#         fuel       0.95      1.00      0.97       187
#      machine       0.93      1.00      0.96       175
#       others       0.88      0.92      0.90       158
#         part       0.94      0.97      0.96       158
#        price       0.98      0.99      0.99       192
#      service       0.96      1.00      0.98       191
#
#    micro avg       0.94      0.98      0.96      1061
#    macro avg       0.94      0.98      0.96      1061
# weighted avg       0.94      0.98      0.96      1061
#  samples avg       0.94      0.98      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 8.028491973876953 | ACCURACY: 0.8274 | F1 MACRO: 0.7799 | F1 MICRO: 0.8274
# EPOCH 2 | LOSS: 7.048144340515137 | ACCURACY: 0.9292 | F1 MACRO: 0.9202 | F1 MICRO: 0.9292
# EPOCH 3 | LOSS: 6.102060317993164 | ACCURACY: 0.9204 | F1 MACRO: 0.9083 | F1 MICRO: 0.9204
# EPOCH 4 | LOSS: 5.644301891326904 | ACCURACY: 0.9204 | F1 MACRO: 0.9134 | F1 MICRO: 0.9204
# EPOCH 5 | LOSS: 5.508681774139404 | ACCURACY: 0.9071 | F1 MACRO: 0.8918 | F1 MICRO: 0.9071
# EPOCH 6 | LOSS: 5.177537441253662 | ACCURACY: 0.9381 | F1 MACRO: 0.9323 | F1 MICRO: 0.9381
# EPOCH 7 | LOSS: 4.844834327697754 | ACCURACY: 0.9292 | F1 MACRO: 0.9207 | F1 MICRO: 0.9292
# EPOCH 8 | LOSS: 4.925074100494385 | ACCURACY: 0.9469 | F1 MACRO: 0.9405 | F1 MICRO: 0.9469
# EPOCH 9 | LOSS: 4.7510504722595215 | ACCURACY: 0.9425 | F1 MACRO: 0.9358 | F1 MICRO: 0.9425
# EPOCH 10 | LOSS: 4.697153568267822 | ACCURACY: 0.9425 | F1 MACRO: 0.9369 | F1 MICRO: 0.9425
# sentiment: ACCURACY 0.9469 | F1 MACRO 0.9405 | F1 MICRO 0.9469
#               precision    recall  f1-score   support
#
#     negative       0.92      0.92      0.92        76
#     positive       0.96      0.96      0.96       150
#
#     accuracy                           0.95       226
#    macro avg       0.94      0.94      0.94       226
# weighted avg       0.95      0.95      0.95       226
#
# --------------------------------------------------
# Iteration 274: Accuracy: 0.9313, F1 Micro: 0.9313, F1 Macro: 0.8689
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.96      1.00      0.98       181
#     positive       1.00      0.75      0.86        24
#
#     accuracy                           0.97       216
#    macro avg       0.99      0.89      0.93       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.69      0.79        16
#      neutral       0.91      0.99      0.95       167
#     positive       0.86      0.58      0.69        33
#
#     accuracy                           0.91       216
#    macro avg       0.90      0.75      0.81       216
# weighted avg       0.91      0.91      0.90       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.90      0.75      0.82        12
#      neutral       0.89      0.95      0.92       152
#     positive       0.82      0.71      0.76        52
#
#     accuracy                           0.88       216
#    macro avg       0.87      0.80      0.83       216
# weighted avg       0.88      0.88      0.88       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.87      0.85        23
#      neutral       0.92      0.97      0.95       152
#     positive       0.85      0.68      0.76        41
#
#     accuracy                           0.90       216
#    macro avg       0.87      0.84      0.85       216
# weighted avg       0.90      0.90      0.90       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.77      0.80        13
#      neutral       0.97      0.99      0.98       186
#     positive       0.87      0.76      0.81        17
#
#     accuracy                           0.96       216
#    macro avg       0.89      0.84      0.86       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.97      1.00      0.98       185
#     positive       1.00      0.76      0.87        17
#
#     accuracy                           0.97       216
#    macro avg       0.99      0.87      0.92       216
# weighted avg       0.97      0.97      0.97       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.5236438035964968
# Samples above threshold: 59
# Acquired samples: 59
# Sampling duration: 13.085775136947632 seconds
# New train size: 333
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.420316219329834 | ACCURACY: 0.7902 | F1 MACRO: 0.8812 | F1 MICRO: 0.8827
# EPOCH 2 | LOSS: 2.1511423587799072 | ACCURACY: 0.8006 | F1 MACRO: 0.8822 | F1 MICRO: 0.8854
# EPOCH 3 | LOSS: 2.063582181930542 | ACCURACY: 0.8356 | F1 MACRO: 0.9039 | F1 MICRO: 0.9049
# EPOCH 4 | LOSS: 1.980602502822876 | ACCURACY: 0.8772 | F1 MACRO: 0.9219 | F1 MICRO: 0.9253
# EPOCH 5 | LOSS: 1.938666582107544 | ACCURACY: 0.9167 | F1 MACRO: 0.9475 | F1 MICRO: 0.9491
# EPOCH 6 | LOSS: 1.8551284074783325 | ACCURACY: 0.9278 | F1 MACRO: 0.9535 | F1 MICRO: 0.9552
# EPOCH 7 | LOSS: 1.8179975748062134 | ACCURACY: 0.9368 | F1 MACRO: 0.9595 | F1 MICRO: 0.9608
# EPOCH 8 | LOSS: 1.7536990642547607 | ACCURACY: 0.942 | F1 MACRO: 0.9616 | F1 MICRO: 0.9638
# EPOCH 9 | LOSS: 1.669237494468689 | ACCURACY: 0.9382 | F1 MACRO: 0.9582 | F1 MICRO: 0.9613
# EPOCH 10 | LOSS: 1.625076174736023 | ACCURACY: 0.9464 | F1 MACRO: 0.9652 | F1 MICRO: 0.9668
# aspect: ACCURACY 0.9464 | F1 MACRO 0.9652 | F1 MICRO 0.9668
#               precision    recall  f1-score   support
#
#         fuel       0.97      1.00      0.98       187
#      machine       0.93      1.00      0.96       175
#       others       0.88      0.95      0.91       158
#         part       0.95      0.97      0.96       158
#        price       0.97      0.99      0.98       192
#      service       0.97      1.00      0.99       191
#
#    micro avg       0.95      0.99      0.97      1061
#    macro avg       0.95      0.99      0.97      1061
# weighted avg       0.95      0.99      0.97      1061
#  samples avg       0.95      0.99      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.896327495574951 | ACCURACY: 0.9048 | F1 MACRO: 0.8948 | F1 MICRO: 0.9048
# EPOCH 2 | LOSS: 5.650524616241455 | ACCURACY: 0.9177 | F1 MACRO: 0.9104 | F1 MICRO: 0.9177
# EPOCH 3 | LOSS: 5.103382587432861 | ACCURACY: 0.9394 | F1 MACRO: 0.9331 | F1 MICRO: 0.9394
# EPOCH 4 | LOSS: 4.8755059242248535 | ACCURACY: 0.9177 | F1 MACRO: 0.9109 | F1 MICRO: 0.9177
# EPOCH 5 | LOSS: 4.41746711730957 | ACCURACY: 0.8961 | F1 MACRO: 0.8883 | F1 MICRO: 0.8961
# EPOCH 6 | LOSS: 4.512350082397461 | ACCURACY: 0.9134 | F1 MACRO: 0.9038 | F1 MICRO: 0.9134
# EPOCH 7 | LOSS: 4.257953643798828 | ACCURACY: 0.8961 | F1 MACRO: 0.8899 | F1 MICRO: 0.8961
# EPOCH 8 | LOSS: 4.105715751647949 | ACCURACY: 0.9264 | F1 MACRO: 0.9152 | F1 MICRO: 0.9264
# EPOCH 9 | LOSS: 4.2461347579956055 | ACCURACY: 0.9264 | F1 MACRO: 0.9146 | F1 MICRO: 0.9264
# EPOCH 10 | LOSS: 4.1327223777771 | ACCURACY: 0.9437 | F1 MACRO: 0.938 | F1 MICRO: 0.9437
# sentiment: ACCURACY 0.9437 | F1 MACRO 0.938 | F1 MICRO 0.9437
#               precision    recall  f1-score   support
#
#     negative       0.87      0.97      0.92        76
#     positive       0.99      0.93      0.96       155
#
#     accuracy                           0.94       231
#    macro avg       0.93      0.95      0.94       231
# weighted avg       0.95      0.94      0.94       231
#
# --------------------------------------------------
# Iteration 333: Accuracy: 0.9406, F1 Micro: 0.9406, F1 Macro: 0.8824
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.98      1.00      0.99       181
#     positive       1.00      0.88      0.93        24
#
#     accuracy                           0.98       216
#    macro avg       0.99      0.93      0.96       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.75      0.83        16
#      neutral       0.92      0.99      0.95       167
#     positive       0.91      0.61      0.73        33
#
#     accuracy                           0.92       216
#    macro avg       0.92      0.78      0.84       216
# weighted avg       0.92      0.92      0.91       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.75      0.75        12
#      neutral       0.90      0.96      0.93       152
#     positive       0.90      0.71      0.80        52
#
#     accuracy                           0.89       216
#    macro avg       0.85      0.81      0.82       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.81      0.91      0.86        23
#      neutral       0.95      0.97      0.96       152
#     positive       0.89      0.76      0.82        41
#
#     accuracy                           0.92       216
#    macro avg       0.88      0.88      0.88       216
# weighted avg       0.92      0.92      0.92       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.77      0.80        13
#      neutral       0.97      0.99      0.98       186
#     positive       0.93      0.76      0.84        17
#
#     accuracy                           0.96       216
#    macro avg       0.91      0.84      0.87       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.97      1.00      0.98       185
#     positive       1.00      0.76      0.87        17
#
#     accuracy                           0.97       216
#    macro avg       0.99      0.87      0.92       216
# weighted avg       0.97      0.97      0.97       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.452221155166626
# Samples above threshold: 54
# Acquired samples: 54
# Sampling duration: 13.644492387771606 seconds
# New train size: 387
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.3170127868652344 | ACCURACY: 0.7894 | F1 MACRO: 0.8809 | F1 MICRO: 0.8823
# EPOCH 2 | LOSS: 2.1017982959747314 | ACCURACY: 0.8147 | F1 MACRO: 0.8931 | F1 MICRO: 0.8946
# EPOCH 3 | LOSS: 1.9994525909423828 | ACCURACY: 0.8668 | F1 MACRO: 0.9203 | F1 MICRO: 0.9213
# EPOCH 4 | LOSS: 1.932039499282837 | ACCURACY: 0.9122 | F1 MACRO: 0.943 | F1 MICRO: 0.9457
# EPOCH 5 | LOSS: 1.8596091270446777 | ACCURACY: 0.9308 | F1 MACRO: 0.9543 | F1 MICRO: 0.9567
# EPOCH 6 | LOSS: 1.8018455505371094 | ACCURACY: 0.9375 | F1 MACRO: 0.9583 | F1 MICRO: 0.961
# EPOCH 7 | LOSS: 1.7106157541275024 | ACCURACY: 0.9397 | F1 MACRO: 0.9599 | F1 MICRO: 0.9624
# EPOCH 8 | LOSS: 1.6595234870910645 | ACCURACY: 0.9479 | F1 MACRO: 0.9659 | F1 MICRO: 0.9675
# EPOCH 9 | LOSS: 1.5872503519058228 | ACCURACY: 0.9531 | F1 MACRO: 0.9689 | F1 MICRO: 0.9707
# EPOCH 10 | LOSS: 1.564913272857666 | ACCURACY: 0.9472 | F1 MACRO: 0.9653 | F1 MICRO: 0.967
# aspect: ACCURACY 0.9531 | F1 MACRO 0.9689 | F1 MICRO 0.9707
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.93      1.00      0.96       175
#       others       0.92      0.91      0.91       158
#         part       0.94      0.99      0.97       158
#        price       0.97      0.99      0.98       192
#      service       0.99      1.00      0.99       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.96      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 5.889111042022705 | ACCURACY: 0.9098 | F1 MACRO: 0.9001 | F1 MICRO: 0.9098
# EPOCH 2 | LOSS: 4.8829121589660645 | ACCURACY: 0.9016 | F1 MACRO: 0.8944 | F1 MICRO: 0.9016
# EPOCH 3 | LOSS: 4.485077857971191 | ACCURACY: 0.9262 | F1 MACRO: 0.9188 | F1 MICRO: 0.9262
# EPOCH 4 | LOSS: 4.17014741897583 | ACCURACY: 0.9385 | F1 MACRO: 0.9286 | F1 MICRO: 0.9385
# EPOCH 5 | LOSS: 3.819767951965332 | ACCURACY: 0.9303 | F1 MACRO: 0.9191 | F1 MICRO: 0.9303
# EPOCH 6 | LOSS: 3.7460732460021973 | ACCURACY: 0.9426 | F1 MACRO: 0.9345 | F1 MICRO: 0.9426
# EPOCH 7 | LOSS: 3.615495204925537 | ACCURACY: 0.9344 | F1 MACRO: 0.9241 | F1 MICRO: 0.9344
# EPOCH 8 | LOSS: 3.5736589431762695 | ACCURACY: 0.9385 | F1 MACRO: 0.9317 | F1 MICRO: 0.9385
# EPOCH 9 | LOSS: 3.587648868560791 | ACCURACY: 0.9467 | F1 MACRO: 0.9412 | F1 MICRO: 0.9467
# EPOCH 10 | LOSS: 3.437075614929199 | ACCURACY: 0.9549 | F1 MACRO: 0.9493 | F1 MICRO: 0.9549
# sentiment: ACCURACY 0.9549 | F1 MACRO 0.9493 | F1 MICRO 0.9549
#               precision    recall  f1-score   support
#
#     negative       0.90      0.96      0.93        79
#     positive       0.98      0.95      0.97       165
#
#     accuracy                           0.95       244
#    macro avg       0.94      0.96      0.95       244
# weighted avg       0.96      0.95      0.96       244
#
# --------------------------------------------------
# Iteration 387: Accuracy: 0.9429, F1 Micro: 0.9429, F1 Macro: 0.8964
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.98      1.00      0.99       181
#     positive       1.00      0.88      0.93        24
#
#     accuracy                           0.98       216
#    macro avg       0.99      0.93      0.96       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.81      0.84        16
#      neutral       0.93      0.98      0.95       167
#     positive       0.88      0.64      0.74        33
#
#     accuracy                           0.92       216
#    macro avg       0.89      0.81      0.84       216
# weighted avg       0.91      0.92      0.91       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.83      0.87        12
#      neutral       0.92      0.91      0.92       152
#     positive       0.76      0.79      0.77        52
#
#     accuracy                           0.88       216
#    macro avg       0.86      0.85      0.85       216
# weighted avg       0.88      0.88      0.88       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.87      0.87        23
#      neutral       0.93      0.99      0.96       152
#     positive       0.94      0.73      0.82        41
#
#     accuracy                           0.93       216
#    macro avg       0.91      0.86      0.88       216
# weighted avg       0.93      0.93      0.92       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.77      0.83        13
#      neutral       0.98      1.00      0.99       186
#     positive       0.87      0.76      0.81        17
#
#     accuracy                           0.97       216
#    macro avg       0.92      0.84      0.88       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.98      1.00      0.99       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       0.99      0.93      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.592582368850708
# Samples above threshold: 48
# Acquired samples: 48
# Sampling duration: 14.470551490783691 seconds
# New train size: 435
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.2228164672851562 | ACCURACY: 0.7976 | F1 MACRO: 0.8848 | F1 MICRO: 0.8863
# EPOCH 2 | LOSS: 2.024402379989624 | ACCURACY: 0.8259 | F1 MACRO: 0.8989 | F1 MICRO: 0.9003
# EPOCH 3 | LOSS: 1.9187113046646118 | ACCURACY: 0.8624 | F1 MACRO: 0.9148 | F1 MICRO: 0.9173
# EPOCH 4 | LOSS: 1.8431658744812012 | ACCURACY: 0.9249 | F1 MACRO: 0.95 | F1 MICRO: 0.953
# EPOCH 5 | LOSS: 1.7790920734405518 | ACCURACY: 0.9397 | F1 MACRO: 0.9615 | F1 MICRO: 0.9626
# EPOCH 6 | LOSS: 1.6879647970199585 | ACCURACY: 0.9464 | F1 MACRO: 0.965 | F1 MICRO: 0.9666
# EPOCH 7 | LOSS: 1.5987334251403809 | ACCURACY: 0.9479 | F1 MACRO: 0.9661 | F1 MICRO: 0.9676
# EPOCH 8 | LOSS: 1.5710896253585815 | ACCURACY: 0.9501 | F1 MACRO: 0.9674 | F1 MICRO: 0.9689
# EPOCH 9 | LOSS: 1.5048702955245972 | ACCURACY: 0.9524 | F1 MACRO: 0.9691 | F1 MICRO: 0.9704
# EPOCH 10 | LOSS: 1.4767175912857056 | ACCURACY: 0.9442 | F1 MACRO: 0.9625 | F1 MICRO: 0.965
# aspect: ACCURACY 0.9524 | F1 MACRO 0.9691 | F1 MICRO 0.9704
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.93      0.98      0.96       175
#       others       0.89      0.96      0.92       158
#         part       0.95      0.99      0.97       158
#        price       0.97      0.99      0.98       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.95      0.99      0.97      1061
#    macro avg       0.95      0.99      0.97      1061
# weighted avg       0.95      0.99      0.97      1061
#  samples avg       0.95      0.99      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 5.159848213195801 | ACCURACY: 0.9079 | F1 MACRO: 0.8953 | F1 MICRO: 0.9079
# EPOCH 2 | LOSS: 4.3487348556518555 | ACCURACY: 0.9372 | F1 MACRO: 0.9279 | F1 MICRO: 0.9372
# EPOCH 3 | LOSS: 3.9884212017059326 | ACCURACY: 0.9372 | F1 MACRO: 0.9306 | F1 MICRO: 0.9372
# EPOCH 4 | LOSS: 3.595139980316162 | ACCURACY: 0.954 | F1 MACRO: 0.9497 | F1 MICRO: 0.954
# EPOCH 5 | LOSS: 3.404136896133423 | ACCURACY: 0.9498 | F1 MACRO: 0.9433 | F1 MICRO: 0.9498
# EPOCH 6 | LOSS: 3.276052951812744 | ACCURACY: 0.9247 | F1 MACRO: 0.9187 | F1 MICRO: 0.9247
# EPOCH 7 | LOSS: 3.2684619426727295 | ACCURACY: 0.9498 | F1 MACRO: 0.9449 | F1 MICRO: 0.9498
# EPOCH 8 | LOSS: 3.104858636856079 | ACCURACY: 0.9414 | F1 MACRO: 0.9361 | F1 MICRO: 0.9414
# EPOCH 9 | LOSS: 3.10793399810791 | ACCURACY: 0.9498 | F1 MACRO: 0.9429 | F1 MICRO: 0.9498
# EPOCH 10 | LOSS: 3.0864405632019043 | ACCURACY: 0.9498 | F1 MACRO: 0.9446 | F1 MICRO: 0.9498
# sentiment: ACCURACY 0.954 | F1 MACRO 0.9497 | F1 MICRO 0.954
#               precision    recall  f1-score   support
#
#     negative       0.89      0.99      0.93        80
#     positive       0.99      0.94      0.96       159
#
#     accuracy                           0.95       239
#    macro avg       0.94      0.96      0.95       239
# weighted avg       0.96      0.95      0.95       239
#
# --------------------------------------------------
# Iteration 435: Accuracy: 0.9491, F1 Micro: 0.9491, F1 Macro: 0.9014
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.98      1.00      0.99       181
#     positive       1.00      0.88      0.93        24
#
#     accuracy                           0.98       216
#    macro avg       0.99      0.93      0.96       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.88      0.90        16
#      neutral       0.95      0.98      0.96       167
#     positive       0.86      0.73      0.79        33
#
#     accuracy                           0.94       216
#    macro avg       0.91      0.86      0.88       216
# weighted avg       0.93      0.94      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.71      0.83      0.77        12
#      neutral       0.91      0.97      0.94       152
#     positive       0.90      0.71      0.80        52
#
#     accuracy                           0.90       216
#    macro avg       0.84      0.84      0.83       216
# weighted avg       0.90      0.90      0.90       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.81      0.96      0.88        23
#      neutral       0.96      0.98      0.97       152
#     positive       0.94      0.76      0.84        41
#
#     accuracy                           0.94       216
#    macro avg       0.90      0.90      0.90       216
# weighted avg       0.94      0.94      0.93       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.77      0.87        13
#      neutral       0.97      1.00      0.98       186
#     positive       0.93      0.76      0.84        17
#
#     accuracy                           0.97       216
#    macro avg       0.97      0.84      0.90       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.97      1.00      0.99       185
#     positive       1.00      0.82      0.90        17
#
#     accuracy                           0.98       216
#    macro avg       0.99      0.89      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.5927867889404297
# Samples above threshold: 43
# Acquired samples: 43
# Sampling duration: 15.104574918746948 seconds
# New train size: 478
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.2304534912109375 | ACCURACY: 0.7976 | F1 MACRO: 0.8848 | F1 MICRO: 0.8863
# EPOCH 2 | LOSS: 2.006467580795288 | ACCURACY: 0.8356 | F1 MACRO: 0.9029 | F1 MICRO: 0.9045
# EPOCH 3 | LOSS: 1.895798683166504 | ACCURACY: 0.8929 | F1 MACRO: 0.9328 | F1 MICRO: 0.9349
# EPOCH 4 | LOSS: 1.8275578022003174 | ACCURACY: 0.933 | F1 MACRO: 0.9572 | F1 MICRO: 0.9585
# EPOCH 5 | LOSS: 1.7293269634246826 | ACCURACY: 0.9449 | F1 MACRO: 0.9644 | F1 MICRO: 0.9657
# EPOCH 6 | LOSS: 1.6478266716003418 | ACCURACY: 0.9472 | F1 MACRO: 0.9655 | F1 MICRO: 0.9672
# EPOCH 7 | LOSS: 1.603899359703064 | ACCURACY: 0.9464 | F1 MACRO: 0.9647 | F1 MICRO: 0.9664
# EPOCH 8 | LOSS: 1.5244457721710205 | ACCURACY: 0.9524 | F1 MACRO: 0.9684 | F1 MICRO: 0.9702
# EPOCH 9 | LOSS: 1.4971226453781128 | ACCURACY: 0.9487 | F1 MACRO: 0.9666 | F1 MICRO: 0.9681
# EPOCH 10 | LOSS: 1.462916612625122 | ACCURACY: 0.9501 | F1 MACRO: 0.9675 | F1 MICRO: 0.9689
# aspect: ACCURACY 0.9524 | F1 MACRO 0.9684 | F1 MICRO 0.9702
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.94      0.99      0.96       175
#       others       0.92      0.91      0.91       158
#         part       0.95      0.99      0.97       158
#        price       0.98      0.99      0.99       192
#      service       0.97      1.00      0.99       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.96      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 5.0387372970581055 | ACCURACY: 0.9194 | F1 MACRO: 0.9071 | F1 MICRO: 0.9194
# EPOCH 2 | LOSS: 4.178529262542725 | ACCURACY: 0.9556 | F1 MACRO: 0.9501 | F1 MICRO: 0.9556
# EPOCH 3 | LOSS: 3.7248377799987793 | ACCURACY: 0.9435 | F1 MACRO: 0.9362 | F1 MICRO: 0.9435
# EPOCH 4 | LOSS: 3.388361692428589 | ACCURACY: 0.9395 | F1 MACRO: 0.9315 | F1 MICRO: 0.9395
# EPOCH 5 | LOSS: 3.239553928375244 | ACCURACY: 0.9234 | F1 MACRO: 0.9165 | F1 MICRO: 0.9234
# EPOCH 6 | LOSS: 3.3452906608581543 | ACCURACY: 0.9234 | F1 MACRO: 0.9165 | F1 MICRO: 0.9234
# EPOCH 7 | LOSS: 3.0599327087402344 | ACCURACY: 0.9194 | F1 MACRO: 0.9083 | F1 MICRO: 0.9194
# EPOCH 8 | LOSS: 3.0972187519073486 | ACCURACY: 0.9234 | F1 MACRO: 0.9132 | F1 MICRO: 0.9234
# EPOCH 9 | LOSS: 2.958857297897339 | ACCURACY: 0.9435 | F1 MACRO: 0.9362 | F1 MICRO: 0.9435
# EPOCH 10 | LOSS: 2.9150807857513428 | ACCURACY: 0.9315 | F1 MACRO: 0.9249 | F1 MICRO: 0.9315
# sentiment: ACCURACY 0.9556 | F1 MACRO 0.9501 | F1 MICRO 0.9556
#               precision    recall  f1-score   support
#
#     negative       0.92      0.95      0.93        81
#     positive       0.98      0.96      0.97       167
#
#     accuracy                           0.96       248
#    macro avg       0.95      0.95      0.95       248
# weighted avg       0.96      0.96      0.96       248
#
# --------------------------------------------------
# Iteration 478: Accuracy: 0.9475, F1 Micro: 0.9475, F1 Macro: 0.9016
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      1.00      0.99       181
#     positive       1.00      0.92      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.97      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.75      0.83        16
#      neutral       0.93      0.99      0.96       167
#     positive       0.88      0.70      0.78        33
#
#     accuracy                           0.93       216
#    macro avg       0.91      0.81      0.86       216
# weighted avg       0.92      0.93      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.67      0.83      0.74        12
#      neutral       0.92      0.93      0.92       152
#     positive       0.79      0.73      0.76        52
#
#     accuracy                           0.88       216
#    macro avg       0.79      0.83      0.81       216
# weighted avg       0.88      0.88      0.87       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.81      0.91      0.86        23
#      neutral       0.95      0.99      0.97       152
#     positive       0.94      0.73      0.82        41
#
#     accuracy                           0.93       216
#    macro avg       0.90      0.88      0.88       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.92      0.92        13
#      neutral       0.98      1.00      0.99       186
#     positive       0.93      0.76      0.84        17
#
#     accuracy                           0.98       216
#    macro avg       0.95      0.90      0.92       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.98      1.00      0.99       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       0.99      0.93      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.5879740715026855
# Samples above threshold: 39
# Acquired samples: 39
# Sampling duration: 15.782254219055176 seconds
# New train size: 517
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.2795870304107666 | ACCURACY: 0.7976 | F1 MACRO: 0.8846 | F1 MICRO: 0.8862
# EPOCH 2 | LOSS: 2.052907705307007 | ACCURACY: 0.843 | F1 MACRO: 0.9082 | F1 MICRO: 0.9091
# EPOCH 3 | LOSS: 1.926396131515503 | ACCURACY: 0.9204 | F1 MACRO: 0.95 | F1 MICRO: 0.9513
# EPOCH 4 | LOSS: 1.8451073169708252 | ACCURACY: 0.9323 | F1 MACRO: 0.9564 | F1 MICRO: 0.9578
# EPOCH 5 | LOSS: 1.7759439945220947 | ACCURACY: 0.9375 | F1 MACRO: 0.9587 | F1 MICRO: 0.961
# EPOCH 6 | LOSS: 1.6788326501846313 | ACCURACY: 0.9479 | F1 MACRO: 0.9657 | F1 MICRO: 0.9675
# EPOCH 7 | LOSS: 1.6111751794815063 | ACCURACY: 0.9561 | F1 MACRO: 0.9715 | F1 MICRO: 0.9726
# EPOCH 8 | LOSS: 1.5541380643844604 | ACCURACY: 0.9539 | F1 MACRO: 0.9696 | F1 MICRO: 0.9712
# EPOCH 9 | LOSS: 1.5113729238510132 | ACCURACY: 0.9561 | F1 MACRO: 0.971 | F1 MICRO: 0.9725
# EPOCH 10 | LOSS: 1.4592338800430298 | ACCURACY: 0.9531 | F1 MACRO: 0.9691 | F1 MICRO: 0.9707
# aspect: ACCURACY 0.9561 | F1 MACRO 0.9715 | F1 MICRO 0.9726
# ...
#
#    micro avg       0.97      0.98      0.97      1061
#    macro avg       0.97      0.98      0.97      1061
# weighted avg       0.97      0.98      0.97      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 3.0185513496398926 | ACCURACY: 0.8906 | F1 MACRO: 0.8706 | F1 MICRO: 0.8906
# EPOCH 2 | LOSS: 2.5152359008789062 | ACCURACY: 0.9396 | F1 MACRO: 0.9319 | F1 MICRO: 0.9396
# EPOCH 3 | LOSS: 2.2971386909484863 | ACCURACY: 0.9472 | F1 MACRO: 0.9401 | F1 MICRO: 0.9472
# EPOCH 4 | LOSS: 1.9974192380905151 | ACCURACY: 0.9358 | F1 MACRO: 0.9291 | F1 MICRO: 0.9358
# EPOCH 5 | LOSS: 1.9733620882034302 | ACCURACY: 0.9396 | F1 MACRO: 0.9323 | F1 MICRO: 0.9396
# EPOCH 6 | LOSS: 1.8900656700134277 | ACCURACY: 0.9472 | F1 MACRO: 0.939 | F1 MICRO: 0.9472
# EPOCH 7 | LOSS: 1.8465096950531006 | ACCURACY: 0.9321 | F1 MACRO: 0.9239 | F1 MICRO: 0.9321
# EPOCH 8 | LOSS: 1.8010783195495605 | ACCURACY: 0.9208 | F1 MACRO: 0.9128 | F1 MICRO: 0.9208
# EPOCH 9 | LOSS: 1.7882763147354126 | ACCURACY: 0.9208 | F1 MACRO: 0.9124 | F1 MICRO: 0.9208
# EPOCH 10 | LOSS: 1.742601752281189 | ACCURACY: 0.9509 | F1 MACRO: 0.9445 | F1 MICRO: 0.9509
# sentiment: ACCURACY 0.9509 | F1 MACRO 0.9445 | F1 MICRO 0.9509
#               precision    recall  f1-score   support
#
#     negative       0.89      0.96      0.93        84
#     positive       0.98      0.94      0.96       181
#
#     accuracy                           0.95       265
#    macro avg       0.94      0.95      0.94       265
# weighted avg       0.95      0.95      0.95       265
#
# --------------------------------------------------
# Iteration 831: Accuracy: 0.956, F1 Micro: 0.956, F1 Macro: 0.9101
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.97      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.81      0.84        16
#      neutral       0.96      0.98      0.97       167
#     positive       0.87      0.79      0.83        33
#
#     accuracy                           0.94       216
#    macro avg       0.90      0.86      0.88       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.82      0.75      0.78        12
#      neutral       0.92      0.95      0.93       152
#     positive       0.83      0.77      0.80        52
#
#     accuracy                           0.89       216
#    macro avg       0.86      0.82      0.84       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.82      1.00      0.90        23
#      neutral       0.99      0.97      0.98       152
#     positive       0.92      0.85      0.89        41
#
#     accuracy                           0.95       216
#    macro avg       0.91      0.94      0.92       216
# weighted avg       0.96      0.95      0.95       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.85      0.88        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.83      0.88      0.86        17
#
#     accuracy                           0.98       216
#    macro avg       0.91      0.91      0.91       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.93      0.90        14
#      neutral       1.00      1.00      1.00       185
#     positive       0.94      0.88      0.91        17
#
#     accuracy                           0.99       216
#    macro avg       0.93      0.94      0.94       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 864
# Threshold: 2.366306114196777
# Samples above threshold: 4
# Acquired samples: 25
# Sampling duration: 21.4263858795166 seconds
# New train size: 856
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.146968364715576 | ACCURACY: 0.8065 | F1 MACRO: 0.8786 | F1 MICRO: 0.8857
# EPOCH 2 | LOSS: 1.889530062675476 | ACCURACY: 0.9271 | F1 MACRO: 0.953 | F1 MICRO: 0.9548
# EPOCH 3 | LOSS: 1.7560937404632568 | ACCURACY: 0.9494 | F1 MACRO: 0.967 | F1 MICRO: 0.9684
# EPOCH 4 | LOSS: 1.665170431137085 | ACCURACY: 0.9561 | F1 MACRO: 0.9708 | F1 MICRO: 0.9724
# EPOCH 5 | LOSS: 1.5685235261917114 | ACCURACY: 0.9568 | F1 MACRO: 0.9704 | F1 MICRO: 0.9727
# EPOCH 6 | LOSS: 1.5088139772415161 | ACCURACY: 0.9561 | F1 MACRO: 0.9698 | F1 MICRO: 0.9722
# EPOCH 7 | LOSS: 1.4567701816558838 | ACCURACY: 0.9524 | F1 MACRO: 0.9676 | F1 MICRO: 0.9701
# EPOCH 8 | LOSS: 1.3949426412582397 | ACCURACY: 0.9531 | F1 MACRO: 0.9684 | F1 MICRO: 0.9704
# EPOCH 9 | LOSS: 1.3551266193389893 | ACCURACY: 0.9531 | F1 MACRO: 0.9682 | F1 MICRO: 0.9704
# EPOCH 10 | LOSS: 1.344178557395935 | ACCURACY: 0.9554 | F1 MACRO: 0.9696 | F1 MICRO: 0.9718
# aspect: ACCURACY 0.9568 | F1 MACRO 0.9704 | F1 MICRO 0.9727
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.95      0.98      0.97       175
#       others       0.93      0.87      0.90       158
#         part       0.98      0.97      0.98       158
#        price       0.99      0.99      0.99       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.97      0.97      0.97      1061
#    macro avg       0.97      0.97      0.97      1061
# weighted avg       0.97      0.97      0.97      1061
#  samples avg       0.97      0.97      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 2.9525249004364014 | ACCURACY: 0.8922 | F1 MACRO: 0.8686 | F1 MICRO: 0.8922
# EPOCH 2 | LOSS: 2.46077299118042 | ACCURACY: 0.9331 | F1 MACRO: 0.9249 | F1 MICRO: 0.9331
# EPOCH 3 | LOSS: 2.218449831008911 | ACCURACY: 0.9517 | F1 MACRO: 0.945 | F1 MICRO: 0.9517
# EPOCH 4 | LOSS: 2.012300968170166 | ACCURACY: 0.9294 | F1 MACRO: 0.9213 | F1 MICRO: 0.9294
# EPOCH 5 | LOSS: 1.927223801612854 | ACCURACY: 0.9405 | F1 MACRO: 0.9336 | F1 MICRO: 0.9405
# EPOCH 6 | LOSS: 1.8360813856124878 | ACCURACY: 0.9294 | F1 MACRO: 0.9213 | F1 MICRO: 0.9294
# EPOCH 7 | LOSS: 1.8415424823760986 | ACCURACY: 0.9405 | F1 MACRO: 0.9332 | F1 MICRO: 0.9405
# EPOCH 8 | LOSS: 1.8029522895812988 | ACCURACY: 0.9405 | F1 MACRO: 0.9328 | F1 MICRO: 0.9405
# EPOCH 9 | LOSS: 1.7470241785049438 | ACCURACY: 0.9331 | F1 MACRO: 0.9249 | F1 MICRO: 0.9331
# EPOCH 10 | LOSS: 1.6961944103240967 | ACCURACY: 0.9442 | F1 MACRO: 0.9372 | F1 MICRO: 0.9442
# sentiment: ACCURACY 0.9517 | F1 MACRO 0.945 | F1 MICRO 0.9517
#               precision    recall  f1-score   support
#
#     negative       0.89      0.96      0.93        84
#     positive       0.98      0.95      0.96       185
#
#     accuracy                           0.95       269
#    macro avg       0.94      0.96      0.94       269
# weighted avg       0.95      0.95      0.95       269
#
# --------------------------------------------------
# Iteration 856: Accuracy: 0.9498, F1 Micro: 0.9498, F1 Macro: 0.9085
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.99      1.00      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.94      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.81      0.84        16
#      neutral       0.95      0.99      0.97       167
#     positive       0.89      0.73      0.80        33
#
#     accuracy                           0.94       216
#    macro avg       0.90      0.84      0.87       216
# weighted avg       0.93      0.94      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.71      0.83      0.77        12
#      neutral       0.93      0.89      0.91       152
#     positive       0.72      0.79      0.75        52
#
#     accuracy                           0.86       216
#    macro avg       0.79      0.84      0.81       216
# weighted avg       0.87      0.86      0.86       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.96      0.90        23
#      neutral       0.97      0.98      0.98       152
#     positive       0.92      0.83      0.87        41
#
#     accuracy                           0.95       216
#    macro avg       0.91      0.92      0.92       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.92      0.89        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.88      0.82      0.85        17
#
#     accuracy                           0.97       216
#    macro avg       0.91      0.91      0.91       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.99      1.00      1.00       185
#     positive       1.00      1.00      1.00        17
#
#     accuracy                           1.00       216
#    macro avg       1.00      0.98      0.99       216
# weighted avg       1.00      1.00      1.00       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 864
# Threshold: 2.236439347267151
# Samples above threshold: 1
# Acquired samples: 8
# Sampling duration: 21.220664978027344 seconds
# New train size: 864
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.160921096801758 | ACCURACY: 0.8207 | F1 MACRO: 0.896 | F1 MICRO: 0.8975
# EPOCH 2 | LOSS: 1.8933725357055664 | ACCURACY: 0.9345 | F1 MACRO: 0.9576 | F1 MICRO: 0.9594
# EPOCH 3 | LOSS: 1.7635235786437988 | ACCURACY: 0.9531 | F1 MACRO: 0.9694 | F1 MICRO: 0.9709
# EPOCH 4 | LOSS: 1.6609212160110474 | ACCURACY: 0.9591 | F1 MACRO: 0.9737 | F1 MICRO: 0.9745
# EPOCH 5 | LOSS: 1.5755035877227783 | ACCURACY: 0.9621 | F1 MACRO: 0.9749 | F1 MICRO: 0.9761
# EPOCH 6 | LOSS: 1.4864988327026367 | ACCURACY: 0.9554 | F1 MACRO: 0.9699 | F1 MICRO: 0.9718
# EPOCH 7 | LOSS: 1.433734655380249 | ACCURACY: 0.9524 | F1 MACRO: 0.9674 | F1 MICRO: 0.97
# EPOCH 8 | LOSS: 1.409224510192871 | ACCURACY: 0.9554 | F1 MACRO: 0.9702 | F1 MICRO: 0.9719
# EPOCH 9 | LOSS: 1.3432869911193848 | ACCURACY: 0.9606 | F1 MACRO: 0.9739 | F1 MICRO: 0.9752
# EPOCH 10 | LOSS: 1.3317967653274536 | ACCURACY: 0.9576 | F1 MACRO: 0.9718 | F1 MICRO: 0.9733
# aspect: ACCURACY 0.9621 | F1 MACRO 0.9749 | F1 MICRO 0.9761
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.95      0.98      0.96       175
#       others       0.94      0.96      0.95       158
#         part       0.98      0.96      0.97       158
#        price       0.98      0.99      0.99       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.97      0.98      0.98      1061
#    macro avg       0.97      0.98      0.97      1061
# weighted avg       0.97      0.98      0.98      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 2.8817734718322754 | ACCURACY: 0.9211 | F1 MACRO: 0.9065 | F1 MICRO: 0.9211
# EPOCH 2 | LOSS: 2.407210111618042 | ACCURACY: 0.9474 | F1 MACRO: 0.9383 | F1 MICRO: 0.9474
# EPOCH 3 | LOSS: 2.1297919750213623 | ACCURACY: 0.9511 | F1 MACRO: 0.9436 | F1 MICRO: 0.9511
# EPOCH 4 | LOSS: 2.0404186248779297 | ACCURACY: 0.9323 | F1 MACRO: 0.924 | F1 MICRO: 0.9323
# EPOCH 5 | LOSS: 1.9441059827804565 | ACCURACY: 0.9511 | F1 MACRO: 0.944 | F1 MICRO: 0.9511
# EPOCH 6 | LOSS: 1.854464054107666 | ACCURACY: 0.9361 | F1 MACRO: 0.9263 | F1 MICRO: 0.9361
# EPOCH 7 | LOSS: 1.8046965599060059 | ACCURACY: 0.9511 | F1 MACRO: 0.9436 | F1 MICRO: 0.9511
# EPOCH 8 | LOSS: 1.7479474544525146 | ACCURACY: 0.9098 | F1 MACRO: 0.9008 | F1 MICRO: 0.9098
# EPOCH 9 | LOSS: 1.7611398696899414 | ACCURACY: 0.9511 | F1 MACRO: 0.944 | F1 MICRO: 0.9511
# EPOCH 10 | LOSS: 1.7293150424957275 | ACCURACY: 0.9248 | F1 MACRO: 0.916 | F1 MICRO: 0.9248
# sentiment: ACCURACY 0.9511 | F1 MACRO 0.944 | F1 MICRO 0.9511
#               precision    recall  f1-score   support
#
#     negative       0.89      0.96      0.92        82
#     positive       0.98      0.95      0.96       184
#
#     accuracy                           0.95       266
#    macro avg       0.94      0.95      0.94       266
# weighted avg       0.95      0.95      0.95       266
#
# --------------------------------------------------
# Iteration 864: Accuracy: 0.9537, F1 Micro: 0.9537, F1 Macro: 0.914
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      1.00      0.99       181
#     positive       1.00      0.92      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.97      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.81      0.84        16
#      neutral       0.95      0.97      0.96       167
#     positive       0.84      0.79      0.81        33
#
#     accuracy                           0.93       216
#    macro avg       0.89      0.86      0.87       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.75      0.75        12
#      neutral       0.93      0.93      0.93       152
#     positive       0.82      0.81      0.82        52
#
#     accuracy                           0.89       216
#    macro avg       0.83      0.83      0.83       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.82      1.00      0.90        23
#      neutral       0.98      0.96      0.97       152
#     positive       0.90      0.85      0.88        41
#
#     accuracy                           0.94       216
#    macro avg       0.90      0.94      0.92       216
# weighted avg       0.95      0.94      0.94       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.85      0.88        13
#      neutral       0.98      0.99      0.99       186
#     positive       0.88      0.82      0.85        17
#
#     accuracy                           0.97       216
#    macro avg       0.93      0.89      0.91       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.99      1.00      0.99       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.96      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Total sampling time: 385.86 seconds
# Total runtime: 4097.099601507187 seconds

# %% [markdown]
# ## RUN 3

# %%
active_learning(seeds[2], 2)
# Out:
# ===============================================
# TRIAL 3
# Random seed: 14
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.6044185161590576 | ACCURACY: 0.7448 | F1 MACRO: 0.8463 | F1 MICRO: 0.8498
# EPOCH 2 | LOSS: 2.551307201385498 | ACCURACY: 0.7812 | F1 MACRO: 0.8738 | F1 MICRO: 0.8763
# EPOCH 3 | LOSS: 2.4036574363708496 | ACCURACY: 0.7857 | F1 MACRO: 0.8774 | F1 MICRO: 0.8795
# EPOCH 4 | LOSS: 2.2824435234069824 | ACCURACY: 0.7879 | F1 MACRO: 0.8792 | F1 MICRO: 0.881
# EPOCH 5 | LOSS: 2.1998348236083984 | ACCURACY: 0.7894 | F1 MACRO: 0.8788 | F1 MICRO: 0.881
# EPOCH 6 | LOSS: 2.214709758758545 | ACCURACY: 0.7902 | F1 MACRO: 0.878 | F1 MICRO: 0.8806
# EPOCH 7 | LOSS: 2.119546413421631 | ACCURACY: 0.7887 | F1 MACRO: 0.8742 | F1 MICRO: 0.8783
# EPOCH 8 | LOSS: 2.202039957046509 | ACCURACY: 0.7783 | F1 MACRO: 0.8648 | F1 MICRO: 0.8711
# EPOCH 9 | LOSS: 2.234957695007324 | ACCURACY: 0.7716 | F1 MACRO: 0.8591 | F1 MICRO: 0.8652
# EPOCH 10 | LOSS: 2.199897289276123 | ACCURACY: 0.7798 | F1 MACRO: 0.8646 | F1 MICRO: 0.8699
# aspect: ACCURACY 0.7894 | F1 MACRO 0.8788 | F1 MICRO 0.881
#               precision    recall  f1-score   support
#
#         fuel       0.83      1.00      0.91       187
#      machine       0.78      1.00      0.88       175
#       others       0.71      0.93      0.80       158
#         part       0.73      0.99      0.84       158
#        price       0.86      1.00      0.92       192
#      service       0.85      1.00      0.92       191
#
#    micro avg       0.80      0.99      0.88      1061
#    macro avg       0.79      0.99      0.88      1061
# weighted avg       0.80      0.99      0.88      1061
#  samples avg       0.80      0.99      0.88      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 4.942103385925293 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# EPOCH 2 | LOSS: 4.364520072937012 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# EPOCH 3 | LOSS: 4.156309127807617 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# EPOCH 4 | LOSS: 3.899397611618042 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# EPOCH 5 | LOSS: 3.796949863433838 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# EPOCH 6 | LOSS: 3.6440765857696533 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# EPOCH 7 | LOSS: 3.4411444664001465 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# EPOCH 8 | LOSS: 3.21216082572937 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# EPOCH 9 | LOSS: 3.130927085876465 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# EPOCH 10 | LOSS: 3.002899169921875 | ACCURACY: 0.95 | F1 MACRO: 0.4872 | F1 MICRO: 0.95
# sentiment: ACCURACY 0.95 | F1 MACRO 0.4872 | F1 MICRO 0.95
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00         1
#     positive       0.95      1.00      0.97        19
#
#     accuracy                           0.95        20
#    macro avg       0.47      0.50      0.49        20
# weighted avg       0.90      0.95      0.93        20
#
# --------------------------------------------------
# Iteration 54: Accuracy: 0.7917, F1 Micro: 0.7917, F1 Macro: 0.3167
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        11
#      neutral       0.84      1.00      0.91       181
#     positive       0.00      0.00      0.00        24
#
#     accuracy                           0.84       216
#    macro avg       0.28      0.33      0.30       216
# weighted avg       0.70      0.84      0.76       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        16
#      neutral       0.77      1.00      0.87       167
#     positive       0.00      0.00      0.00        33
#
#     accuracy                           0.77       216
#    macro avg       0.26      0.33      0.29       216
# weighted avg       0.60      0.77      0.67       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        12
#      neutral       0.71      0.95      0.81       152
#     positive       0.31      0.08      0.12        52
#
#     accuracy                           0.69       216
#    macro avg       0.34      0.34      0.31       216
# weighted avg       0.57      0.69      0.60       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        23
#      neutral       0.73      1.00      0.84       152
#     positive       1.00      0.17      0.29        41
#
#     accuracy                           0.74       216
#    macro avg       0.58      0.39      0.38       216
# weighted avg       0.70      0.74      0.65       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        13
#      neutral       0.86      1.00      0.93       186
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.86       216
#    macro avg       0.29      0.33      0.31       216
# weighted avg       0.74      0.86      0.80       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        14
#      neutral       0.86      1.00      0.92       185
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.86       216
#    macro avg       0.29      0.33      0.31       216
# weighted avg       0.73      0.86      0.79       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.5279074192047117
# Samples above threshold: 81
# Acquired samples: 81
# Sampling duration: 7.392462730407715 seconds
# New train size: 135
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.7897379398345947 | ACCURACY: 0.7879 | F1 MACRO: 0.8792 | F1 MICRO: 0.881
# EPOCH 2 | LOSS: 2.533238649368286 | ACCURACY: 0.7984 | F1 MACRO: 0.8851 | F1 MICRO: 0.8867
# EPOCH 3 | LOSS: 2.4793689250946045 | ACCURACY: 0.8043 | F1 MACRO: 0.8857 | F1 MICRO: 0.888
# EPOCH 4 | LOSS: 2.402233839035034 | ACCURACY: 0.8073 | F1 MACRO: 0.8851 | F1 MICRO: 0.8882
# EPOCH 5 | LOSS: 2.2519960403442383 | ACCURACY: 0.8185 | F1 MACRO: 0.891 | F1 MICRO: 0.894
# EPOCH 6 | LOSS: 2.182987689971924 | ACCURACY: 0.8259 | F1 MACRO: 0.8943 | F1 MICRO: 0.8975
# EPOCH 7 | LOSS: 2.1808507442474365 | ACCURACY: 0.8408 | F1 MACRO: 0.9015 | F1 MICRO: 0.9048
# EPOCH 8 | LOSS: 2.1200594902038574 | ACCURACY: 0.8638 | F1 MACRO: 0.9147 | F1 MICRO: 0.9179
# EPOCH 9 | LOSS: 2.1163992881774902 | ACCURACY: 0.8817 | F1 MACRO: 0.9238 | F1 MICRO: 0.9272
# EPOCH 10 | LOSS: 2.0461173057556152 | ACCURACY: 0.8958 | F1 MACRO: 0.9333 | F1 MICRO: 0.936
# aspect: ACCURACY 0.8958 | F1 MACRO 0.9333 | F1 MICRO 0.936
#               precision    recall  f1-score   support
#
#         fuel       0.96      1.00      0.98       187
#      machine       0.83      0.94      0.88       175
#       others       0.86      0.88      0.87       158
#         part       0.90      0.96      0.93       158
#        price       0.96      0.99      0.98       192
#      service       0.93      1.00      0.96       191
#
#    micro avg       0.91      0.96      0.94      1061
#    macro avg       0.91      0.96      0.93      1061
# weighted avg       0.91      0.96      0.94      1061
#  samples avg       0.91      0.96      0.93      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 14.121417999267578 | ACCURACY: 0.9471 | F1 MACRO: 0.9339 | F1 MICRO: 0.9471
# EPOCH 2 | LOSS: 12.117819786071777 | ACCURACY: 0.9183 | F1 MACRO: 0.8956 | F1 MICRO: 0.9183
# EPOCH 3 | LOSS: 11.213428497314453 | ACCURACY: 0.875 | F1 MACRO: 0.8157 | F1 MICRO: 0.875
# EPOCH 4 | LOSS: 10.874979019165039 | ACCURACY: 0.9327 | F1 MACRO: 0.9196 | F1 MICRO: 0.9327
# EPOCH 5 | LOSS: 10.711201667785645 | ACCURACY: 0.9327 | F1 MACRO: 0.9145 | F1 MICRO: 0.9327
# EPOCH 6 | LOSS: 9.830460548400879 | ACCURACY: 0.9231 | F1 MACRO: 0.9072 | F1 MICRO: 0.9231
# EPOCH 7 | LOSS: 9.251812934875488 | ACCURACY: 0.9327 | F1 MACRO: 0.9154 | F1 MICRO: 0.9327
# EPOCH 8 | LOSS: 9.119964599609375 | ACCURACY: 0.9279 | F1 MACRO: 0.9056 | F1 MICRO: 0.9279
# EPOCH 9 | LOSS: 8.950047492980957 | ACCURACY: 0.9375 | F1 MACRO: 0.9192 | F1 MICRO: 0.9375
# EPOCH 10 | LOSS: 8.881484031677246 | ACCURACY: 0.9375 | F1 MACRO: 0.921 | F1 MICRO: 0.9375
# sentiment: ACCURACY 0.9471 | F1 MACRO 0.9339 | F1 MICRO 0.9471
#               precision    recall  f1-score   support
#
#     negative       0.88      0.93      0.90        56
#     positive       0.97      0.95      0.96       152
#
#     accuracy                           0.95       208
#    macro avg       0.93      0.94      0.93       208
# weighted avg       0.95      0.95      0.95       208
#
# --------------------------------------------------
# Iteration 135: Accuracy: 0.8927, F1 Micro: 0.8927, F1 Macro: 0.7726
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.96      1.00      0.98       181
#     positive       1.00      0.71      0.83        24
#
#     accuracy                           0.96       216
#    macro avg       0.99      0.87      0.92       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.60      0.19      0.29        16
#      neutral       0.83      0.93      0.88       167
#     positive       0.56      0.42      0.48        33
#
#     accuracy                           0.80       216
#    macro avg       0.66      0.51      0.55       216
# weighted avg       0.77      0.80      0.77       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.50      0.63        12
#      neutral       0.88      0.91      0.89       152
#     positive       0.75      0.75      0.75        52
#
#     accuracy                           0.85       216
#    macro avg       0.83      0.72      0.76       216
# weighted avg       0.85      0.85      0.84       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.81      0.74      0.77        23
#      neutral       0.88      0.95      0.91       152
#     positive       0.83      0.61      0.70        41
#
#     accuracy                           0.87       216
#    macro avg       0.84      0.77      0.80       216
# weighted avg       0.86      0.87      0.86       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.82      0.69      0.75        13
#      neutral       0.97      0.99      0.98       186
#     positive       0.86      0.71      0.77        17
#
#     accuracy                           0.95       216
#    macro avg       0.88      0.80      0.84       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.57      0.73        14
#      neutral       0.93      1.00      0.96       185
#     positive       1.00      0.47      0.64        17
#
#     accuracy                           0.93       216
#    macro avg       0.97      0.68      0.78       216
# weighted avg       0.94      0.93      0.92       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.6375788688659667
# Samples above threshold: 73
# Acquired samples: 73
# Sampling duration: 10.19322943687439 seconds
# New train size: 208
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.721041679382324 | ACCURACY: 0.7917 | F1 MACRO: 0.8818 | F1 MICRO: 0.8833
# EPOCH 2 | LOSS: 2.3968188762664795 | ACCURACY: 0.7961 | F1 MACRO: 0.8789 | F1 MICRO: 0.8826
# EPOCH 3 | LOSS: 2.236382007598877 | ACCURACY: 0.7924 | F1 MACRO: 0.8774 | F1 MICRO: 0.8807
# EPOCH 4 | LOSS: 2.1953847408294678 | ACCURACY: 0.8341 | F1 MACRO: 0.8994 | F1 MICRO: 0.9021
# EPOCH 5 | LOSS: 2.1094727516174316 | ACCURACY: 0.8564 | F1 MACRO: 0.9129 | F1 MICRO: 0.9147
# EPOCH 6 | LOSS: 2.054110288619995 | ACCURACY: 0.8973 | F1 MACRO: 0.9354 | F1 MICRO: 0.9375
# EPOCH 7 | LOSS: 2.0061163902282715 | ACCURACY: 0.9077 | F1 MACRO: 0.9405 | F1 MICRO: 0.9431
# EPOCH 8 | LOSS: 2.0057055950164795 | ACCURACY: 0.9159 | F1 MACRO: 0.9454 | F1 MICRO: 0.9478
# EPOCH 9 | LOSS: 1.8971842527389526 | ACCURACY: 0.9241 | F1 MACRO: 0.9509 | F1 MICRO: 0.953
# EPOCH 10 | LOSS: 1.8419686555862427 | ACCURACY: 0.9308 | F1 MACRO: 0.9556 | F1 MICRO: 0.9571
# aspect: ACCURACY 0.9308 | F1 MACRO 0.9556 | F1 MICRO 0.9571
#               precision    recall  f1-score   support
#
#         fuel       0.97      0.99      0.98       187
#      machine       0.92      0.99      0.95       175
#       others       0.90      0.91      0.91       158
#         part       0.94      0.97      0.96       158
#        price       0.95      0.99      0.97       192
#      service       0.93      1.00      0.96       191
#
#    micro avg       0.94      0.98      0.96      1061
#    macro avg       0.94      0.98      0.96      1061
# weighted avg       0.94      0.98      0.96      1061
#  samples avg       0.94      0.98      0.95      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 10.708377838134766 | ACCURACY: 0.9259 | F1 MACRO: 0.9119 | F1 MICRO: 0.9259
# EPOCH 2 | LOSS: 8.836512565612793 | ACCURACY: 0.9547 | F1 MACRO: 0.9459 | F1 MICRO: 0.9547
# EPOCH 3 | LOSS: 8.124818801879883 | ACCURACY: 0.9506 | F1 MACRO: 0.9426 | F1 MICRO: 0.9506
# EPOCH 4 | LOSS: 7.492760181427002 | ACCURACY: 0.9424 | F1 MACRO: 0.932 | F1 MICRO: 0.9424
# EPOCH 5 | LOSS: 7.192141056060791 | ACCURACY: 0.9506 | F1 MACRO: 0.9398 | F1 MICRO: 0.9506
# EPOCH 6 | LOSS: 6.747284889221191 | ACCURACY: 0.9465 | F1 MACRO: 0.9356 | F1 MICRO: 0.9465
# EPOCH 7 | LOSS: 6.498244762420654 | ACCURACY: 0.9424 | F1 MACRO: 0.9304 | F1 MICRO: 0.9424
# EPOCH 8 | LOSS: 6.29507303237915 | ACCURACY: 0.9177 | F1 MACRO: 0.9062 | F1 MICRO: 0.9177
# EPOCH 9 | LOSS: 6.530677318572998 | ACCURACY: 0.9383 | F1 MACRO: 0.9257 | F1 MICRO: 0.9383
# EPOCH 10 | LOSS: 6.289411544799805 | ACCURACY: 0.9383 | F1 MACRO: 0.9269 | F1 MICRO: 0.9383
# sentiment: ACCURACY 0.9547 | F1 MACRO 0.9459 | F1 MICRO 0.9547
#               precision    recall  f1-score   support
#
#     negative       0.92      0.93      0.92        72
#     positive       0.97      0.96      0.97       171
#
#     accuracy                           0.95       243
#    macro avg       0.94      0.95      0.95       243
# weighted avg       0.95      0.95      0.95       243
#
# --------------------------------------------------
# Iteration 208: Accuracy: 0.9282, F1 Micro: 0.9282, F1 Macro: 0.86
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.98      0.99      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.98       216
#    macro avg       0.98      0.94      0.96       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.75      0.80        16
#      neutral       0.92      0.95      0.93       167
#     positive       0.71      0.67      0.69        33
#
#     accuracy                           0.89       216
#    macro avg       0.83      0.79      0.81       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.90      0.75      0.82        12
#      neutral       0.91      0.90      0.91       152
#     positive       0.75      0.81      0.78        52
#
#     accuracy                           0.87       216
#    macro avg       0.85      0.82      0.83       216
# weighted avg       0.87      0.87      0.87       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.87      0.87        23
#      neutral       0.94      0.99      0.96       152
#     positive       0.94      0.76      0.84        41
#
#     accuracy                           0.93       216
#    macro avg       0.92      0.87      0.89       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.69      0.82        13
#      neutral       0.97      0.99      0.98       186
#     positive       0.88      0.82      0.85        17
#
#     accuracy                           0.96       216
#    macro avg       0.95      0.84      0.88       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.57      0.73        14
#      neutral       0.93      1.00      0.97       185
#     positive       0.90      0.53      0.67        17
#
#     accuracy                           0.94       216
#    macro avg       0.94      0.70      0.79       216
# weighted avg       0.94      0.94      0.93       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.5835922956466675
# Samples above threshold: 66
# Acquired samples: 66
# Sampling duration: 11.541608333587646 seconds
# New train size: 274
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.4631056785583496 | ACCURACY: 0.7909 | F1 MACRO: 0.8816 | F1 MICRO: 0.8831
# EPOCH 2 | LOSS: 2.122236490249634 | ACCURACY: 0.7946 | F1 MACRO: 0.8796 | F1 MICRO: 0.8827
# EPOCH 3 | LOSS: 2.030644655227661 | ACCURACY: 0.8199 | F1 MACRO: 0.8927 | F1 MICRO: 0.8952
# EPOCH 4 | LOSS: 1.9748677015304565 | ACCURACY: 0.8616 | F1 MACRO: 0.9149 | F1 MICRO: 0.9176
# EPOCH 5 | LOSS: 1.916698694229126 | ACCURACY: 0.8988 | F1 MACRO: 0.9363 | F1 MICRO: 0.9385
# EPOCH 6 | LOSS: 1.8619673252105713 | ACCURACY: 0.9204 | F1 MACRO: 0.9486 | F1 MICRO: 0.9509
# EPOCH 7 | LOSS: 1.834861159324646 | ACCURACY: 0.9211 | F1 MACRO: 0.9462 | F1 MICRO: 0.9505
# EPOCH 8 | LOSS: 1.7477208375930786 | ACCURACY: 0.9375 | F1 MACRO: 0.9593 | F1 MICRO: 0.9611
# EPOCH 9 | LOSS: 1.665748953819275 | ACCURACY: 0.9397 | F1 MACRO: 0.9603 | F1 MICRO: 0.9624
# EPOCH 10 | LOSS: 1.6304466724395752 | ACCURACY: 0.9397 | F1 MACRO: 0.9599 | F1 MICRO: 0.9621
# aspect: ACCURACY 0.9397 | F1 MACRO 0.9603 | F1 MICRO 0.9624
#               precision    recall  f1-score   support
#
#         fuel       0.98      0.99      0.99       187
#      machine       0.91      0.99      0.95       175
#       others       0.93      0.89      0.91       158
#         part       0.93      0.98      0.96       158
#        price       0.98      0.99      0.99       192
#      service       0.95      1.00      0.98       191
#
#    micro avg       0.95      0.98      0.96      1061
#    macro avg       0.95      0.97      0.96      1061
# weighted avg       0.95      0.98      0.96      1061
#  samples avg       0.95      0.97      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 7.567895889282227 | ACCURACY: 0.9146 | F1 MACRO: 0.9043 | F1 MICRO: 0.9146
# EPOCH 2 | LOSS: 6.401006698608398 | ACCURACY: 0.9431 | F1 MACRO: 0.9347 | F1 MICRO: 0.9431
# EPOCH 3 | LOSS: 5.821444988250732 | ACCURACY: 0.9512 | F1 MACRO: 0.9425 | F1 MICRO: 0.9512
# EPOCH 4 | LOSS: 5.5279436111450195 | ACCURACY: 0.9106 | F1 MACRO: 0.8861 | F1 MICRO: 0.9106
# EPOCH 5 | LOSS: 5.239003658294678 | ACCURACY: 0.9472 | F1 MACRO: 0.9379 | F1 MICRO: 0.9472
# EPOCH 6 | LOSS: 5.032125949859619 | ACCURACY: 0.9309 | F1 MACRO: 0.921 | F1 MICRO: 0.9309
# EPOCH 7 | LOSS: 4.671058177947998 | ACCURACY: 0.9309 | F1 MACRO: 0.9175 | F1 MICRO: 0.9309
# EPOCH 8 | LOSS: 4.716320514678955 | ACCURACY: 0.9106 | F1 MACRO: 0.9006 | F1 MICRO: 0.9106
# EPOCH 9 | LOSS: 4.848764896392822 | ACCURACY: 0.9553 | F1 MACRO: 0.9486 | F1 MICRO: 0.9553
# EPOCH 10 | LOSS: 4.445840358734131 | ACCURACY: 0.9431 | F1 MACRO: 0.9352 | F1 MICRO: 0.9431
# sentiment: ACCURACY 0.9553 | F1 MACRO 0.9486 | F1 MICRO 0.9553
#               precision    recall  f1-score   support
#
#     negative       0.89      0.97      0.93        75
#     positive       0.99      0.95      0.97       171
#
#     accuracy                           0.96       246
#    macro avg       0.94      0.96      0.95       246
# weighted avg       0.96      0.96      0.96       246
#
# --------------------------------------------------
# Iteration 274: Accuracy: 0.9352, F1 Micro: 0.9352, F1 Macro: 0.8758
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.98      0.99      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.98       216
#    macro avg       0.98      0.94      0.96       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.76      0.81      0.79        16
#      neutral       0.93      0.98      0.95       167
#     positive       0.91      0.64      0.75        33
#
#     accuracy                           0.91       216
#    macro avg       0.87      0.81      0.83       216
# weighted avg       0.91      0.91      0.91       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.83      0.87        12
#      neutral       0.93      0.89      0.91       152
#     positive       0.73      0.83      0.77        52
#
#     accuracy                           0.88       216
#    macro avg       0.86      0.85      0.85       216
# weighted avg       0.88      0.88      0.88       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.87      0.85        23
#      neutral       0.93      0.99      0.96       152
#     positive       1.00      0.71      0.83        41
#
#     accuracy                           0.93       216
#    macro avg       0.92      0.86      0.88       216
# weighted avg       0.93      0.93      0.92       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.77      0.80        13
#      neutral       0.98      0.99      0.99       186
#     positive       0.82      0.82      0.82        17
#
#     accuracy                           0.96       216
#    macro avg       0.88      0.86      0.87       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.71      0.83        14
#      neutral       0.95      1.00      0.97       185
#     positive       1.00      0.65      0.79        17
#
#     accuracy                           0.95       216
#    macro avg       0.98      0.79      0.86       216
# weighted avg       0.96      0.95      0.95       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.5223312377929688
# Samples above threshold: 59
# Acquired samples: 59
# Sampling duration: 12.578277587890625 seconds
# New train size: 333
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.490152597427368 | ACCURACY: 0.7917 | F1 MACRO: 0.882 | F1 MICRO: 0.8834
# EPOCH 2 | LOSS: 2.1904637813568115 | ACCURACY: 0.8073 | F1 MACRO: 0.8871 | F1 MICRO: 0.8893
# EPOCH 3 | LOSS: 2.071204900741577 | ACCURACY: 0.8557 | F1 MACRO: 0.9132 | F1 MICRO: 0.9148
# EPOCH 4 | LOSS: 2.0275914669036865 | ACCURACY: 0.9144 | F1 MACRO: 0.9463 | F1 MICRO: 0.948
# EPOCH 5 | LOSS: 1.972036361694336 | ACCURACY: 0.9278 | F1 MACRO: 0.9515 | F1 MICRO: 0.9547
# EPOCH 6 | LOSS: 1.8693126440048218 | ACCURACY: 0.9308 | F1 MACRO: 0.9545 | F1 MICRO: 0.9568
# EPOCH 7 | LOSS: 1.8014702796936035 | ACCURACY: 0.9442 | F1 MACRO: 0.9637 | F1 MICRO: 0.9653
# EPOCH 8 | LOSS: 1.7398959398269653 | ACCURACY: 0.9479 | F1 MACRO: 0.966 | F1 MICRO: 0.9675
# EPOCH 9 | LOSS: 1.6326110363006592 | ACCURACY: 0.9323 | F1 MACRO: 0.9538 | F1 MICRO: 0.9573
# EPOCH 10 | LOSS: 1.5898261070251465 | ACCURACY: 0.9494 | F1 MACRO: 0.9671 | F1 MICRO: 0.9685
# aspect: ACCURACY 0.9494 | F1 MACRO 0.9671 | F1 MICRO 0.9685
#               precision    recall  f1-score   support
#
#         fuel       0.98      0.99      0.99       187
#      machine       0.94      0.99      0.96       175
#       others       0.92      0.94      0.93       158
#         part       0.93      0.98      0.96       158
#        price       0.97      0.99      0.98       192
#      service       0.96      1.00      0.98       191
#
#    micro avg       0.95      0.98      0.97      1061
#    macro avg       0.95      0.98      0.97      1061
# weighted avg       0.95      0.98      0.97      1061
#  samples avg       0.95      0.98      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.555344581604004 | ACCURACY: 0.9474 | F1 MACRO: 0.938 | F1 MICRO: 0.9474
# EPOCH 2 | LOSS: 5.5560173988342285 | ACCURACY: 0.9231 | F1 MACRO: 0.913 | F1 MICRO: 0.9231
# EPOCH 3 | LOSS: 5.0875043869018555 | ACCURACY: 0.9352 | F1 MACRO: 0.926 | F1 MICRO: 0.9352
# EPOCH 4 | LOSS: 4.641797065734863 | ACCURACY: 0.9312 | F1 MACRO: 0.9222 | F1 MICRO: 0.9312
# EPOCH 5 | LOSS: 4.454418659210205 | ACCURACY: 0.9474 | F1 MACRO: 0.9355 | F1 MICRO: 0.9474
# EPOCH 6 | LOSS: 4.281071186065674 | ACCURACY: 0.9514 | F1 MACRO: 0.9438 | F1 MICRO: 0.9514
# EPOCH 7 | LOSS: 4.131655693054199 | ACCURACY: 0.9433 | F1 MACRO: 0.934 | F1 MICRO: 0.9433
# EPOCH 8 | LOSS: 4.070121765136719 | ACCURACY: 0.9271 | F1 MACRO: 0.9178 | F1 MICRO: 0.9271
# EPOCH 9 | LOSS: 3.8866868019104004 | ACCURACY: 0.9595 | F1 MACRO: 0.9518 | F1 MICRO: 0.9595
# EPOCH 10 | LOSS: 4.007758617401123 | ACCURACY: 0.9555 | F1 MACRO: 0.9483 | F1 MICRO: 0.9555
# sentiment: ACCURACY 0.9595 | F1 MACRO 0.9518 | F1 MICRO 0.9595
#               precision    recall  f1-score   support
#
#     negative       0.95      0.92      0.93        75
#     positive       0.97      0.98      0.97       172
#
#     accuracy                           0.96       247
#    macro avg       0.96      0.95      0.95       247
# weighted avg       0.96      0.96      0.96       247
#
# --------------------------------------------------
# Iteration 333: Accuracy: 0.9452, F1 Micro: 0.9452, F1 Macro: 0.8905
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.82      0.90        11
#      neutral       0.98      0.99      0.99       181
#     positive       0.92      0.92      0.92        24
#
#     accuracy                           0.98       216
#    macro avg       0.97      0.91      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.69      0.79        16
#      neutral       0.95      0.97      0.96       167
#     positive       0.79      0.79      0.79        33
#
#     accuracy                           0.92       216
#    macro avg       0.88      0.82      0.84       216
# weighted avg       0.92      0.92      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.83      0.87        12
#      neutral       0.93      0.93      0.93       152
#     positive       0.81      0.83      0.82        52
#
#     accuracy                           0.90       216
#    macro avg       0.88      0.86      0.87       216
# weighted avg       0.90      0.90      0.90       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.89      0.74      0.81        23
#      neutral       0.93      0.99      0.96       152
#     positive       0.91      0.78      0.84        41
#
#     accuracy                           0.93       216
#    macro avg       0.91      0.84      0.87       216
# weighted avg       0.92      0.93      0.92       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.69      0.82        13
#      neutral       0.97      1.00      0.99       186
#     positive       0.94      0.88      0.91        17
#
#     accuracy                           0.97       216
#    macro avg       0.97      0.86      0.90       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.79      0.88        14
#      neutral       0.97      1.00      0.99       185
#     positive       0.93      0.82      0.87        17
#
#     accuracy                           0.97       216
#    macro avg       0.97      0.87      0.91       216
# weighted avg       0.97      0.97      0.97       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.585632085800171
# Samples above threshold: 54
# Acquired samples: 54
# Sampling duration: 13.616353988647461 seconds
# New train size: 387
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.481367826461792 | ACCURACY: 0.7976 | F1 MACRO: 0.882 | F1 MICRO: 0.8846
# EPOCH 2 | LOSS: 2.1644740104675293 | ACCURACY: 0.811 | F1 MACRO: 0.8886 | F1 MICRO: 0.8913
# EPOCH 3 | LOSS: 2.031731128692627 | ACCURACY: 0.8839 | F1 MACRO: 0.9293 | F1 MICRO: 0.9308
# EPOCH 4 | LOSS: 1.99043607711792 | ACCURACY: 0.9263 | F1 MACRO: 0.9513 | F1 MICRO: 0.9541
# EPOCH 5 | LOSS: 1.9144339561462402 | ACCURACY: 0.9397 | F1 MACRO: 0.9611 | F1 MICRO: 0.9626
# EPOCH 6 | LOSS: 1.806420087814331 | ACCURACY: 0.9241 | F1 MACRO: 0.9466 | F1 MICRO: 0.952
# EPOCH 7 | LOSS: 1.716063141822815 | ACCURACY: 0.9293 | F1 MACRO: 0.9515 | F1 MICRO: 0.9552
# EPOCH 8 | LOSS: 1.646571159362793 | ACCURACY: 0.9449 | F1 MACRO: 0.9633 | F1 MICRO: 0.9654
# EPOCH 9 | LOSS: 1.5981719493865967 | ACCURACY: 0.9405 | F1 MACRO: 0.9596 | F1 MICRO: 0.9624
# EPOCH 10 | LOSS: 1.5608233213424683 | ACCURACY: 0.9427 | F1 MACRO: 0.9613 | F1 MICRO: 0.9639
# aspect: ACCURACY 0.9449 | F1 MACRO 0.9633 | F1 MICRO 0.9654
#               precision    recall  f1-score   support
#
#         fuel       0.99      0.99      0.99       187
#      machine       0.92      0.98      0.95       175
#       others       0.93      0.89      0.91       158
#         part       0.95      0.96      0.96       158
#        price       0.97      0.99      0.98       192
#      service       0.97      1.00      0.98       191
#
#    micro avg       0.96      0.97      0.97      1061
#    macro avg       0.96      0.97      0.96      1061
# weighted avg       0.96      0.97      0.97      1061
#  samples avg       0.96      0.97      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 5.574552059173584 | ACCURACY: 0.93 | F1 MACRO: 0.9189 | F1 MICRO: 0.93
# EPOCH 2 | LOSS: 4.635293483734131 | ACCURACY: 0.9416 | F1 MACRO: 0.9322 | F1 MICRO: 0.9416
# EPOCH 3 | LOSS: 4.333556652069092 | ACCURACY: 0.9339 | F1 MACRO: 0.9215 | F1 MICRO: 0.9339
# EPOCH 4 | LOSS: 4.013408184051514 | ACCURACY: 0.9339 | F1 MACRO: 0.9197 | F1 MICRO: 0.9339
# EPOCH 5 | LOSS: 3.7383410930633545 | ACCURACY: 0.9261 | F1 MACRO: 0.9122 | F1 MICRO: 0.9261
# EPOCH 6 | LOSS: 3.550800085067749 | ACCURACY: 0.93 | F1 MACRO: 0.9183 | F1 MICRO: 0.93
# EPOCH 7 | LOSS: 3.4753212928771973 | ACCURACY: 0.9105 | F1 MACRO: 0.8866 | F1 MICRO: 0.9105
# EPOCH 8 | LOSS: 3.450753688812256 | ACCURACY: 0.9261 | F1 MACRO: 0.9129 | F1 MICRO: 0.9261
# EPOCH 9 | LOSS: 3.2899413108825684 | ACCURACY: 0.9339 | F1 MACRO: 0.9236 | F1 MICRO: 0.9339
# EPOCH 10 | LOSS: 3.2966597080230713 | ACCURACY: 0.9183 | F1 MACRO: 0.905 | F1 MICRO: 0.9183
# sentiment: ACCURACY 0.9416 | F1 MACRO 0.9322 | F1 MICRO 0.9416
#               precision    recall  f1-score   support
#
#     negative       0.86      0.96      0.91        76
#     positive       0.98      0.93      0.96       181
#
#     accuracy                           0.94       257
#    macro avg       0.92      0.95      0.93       257
# weighted avg       0.95      0.94      0.94       257
#
# --------------------------------------------------
# Iteration 387: Accuracy: 0.9398, F1 Micro: 0.9398, F1 Macro: 0.8875
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.96      0.96      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.98      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.75      0.80        16
#      neutral       0.94      0.98      0.96       167
#     positive       0.89      0.73      0.80        33
#
#     accuracy                           0.93       216
#    macro avg       0.89      0.82      0.85       216
# weighted avg       0.92      0.93      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.62      0.83      0.71        12
#      neutral       0.93      0.89      0.91       152
#     positive       0.76      0.81      0.79        52
#
#     accuracy                           0.87       216
#    macro avg       0.77      0.84      0.80       216
# weighted avg       0.87      0.87      0.87       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.87      0.85        23
#      neutral       0.93      0.97      0.95       152
#     positive       0.91      0.76      0.83        41
#
#     accuracy                           0.92       216
#    macro avg       0.89      0.86      0.88       216
# weighted avg       0.92      0.92      0.91       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.77      0.80        13
#      neutral       0.98      0.99      0.99       186
#     positive       0.93      0.82      0.87        17
#
#     accuracy                           0.97       216
#    macro avg       0.92      0.86      0.89       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.79      0.88        14
#      neutral       0.97      1.00      0.98       185
#     positive       1.00      0.82      0.90        17
#
#     accuracy                           0.97       216
#    macro avg       0.99      0.87      0.92       216
# weighted avg       0.97      0.97      0.97       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.3515963554382324
# Samples above threshold: 48
# Acquired samples: 48
# Sampling duration: 14.085281610488892 seconds
# New train size: 435
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.3621652126312256 | ACCURACY: 0.7946 | F1 MACRO: 0.8811 | F1 MICRO: 0.8834
# EPOCH 2 | LOSS: 2.0553457736968994 | ACCURACY: 0.8363 | F1 MACRO: 0.9035 | F1 MICRO: 0.9048
# EPOCH 3 | LOSS: 1.950161099433899 | ACCURACY: 0.8996 | F1 MACRO: 0.9372 | F1 MICRO: 0.9392
# EPOCH 4 | LOSS: 1.9132035970687866 | ACCURACY: 0.9375 | F1 MACRO: 0.9583 | F1 MICRO: 0.9609
# EPOCH 5 | LOSS: 1.8032724857330322 | ACCURACY: 0.9457 | F1 MACRO: 0.9642 | F1 MICRO: 0.9661
# EPOCH 6 | LOSS: 1.7005451917648315 | ACCURACY: 0.9472 | F1 MACRO: 0.9649 | F1 MICRO: 0.9668
# EPOCH 7 | LOSS: 1.6143708229064941 | ACCURACY: 0.9427 | F1 MACRO: 0.961 | F1 MICRO: 0.9638
# EPOCH 8 | LOSS: 1.5558289289474487 | ACCURACY: 0.9479 | F1 MACRO: 0.9646 | F1 MICRO: 0.9671
# EPOCH 9 | LOSS: 1.5133507251739502 | ACCURACY: 0.9546 | F1 MACRO: 0.9701 | F1 MICRO: 0.9716
# EPOCH 10 | LOSS: 1.4745361804962158 | ACCURACY: 0.9464 | F1 MACRO: 0.9646 | F1 MICRO: 0.9664
# aspect: ACCURACY 0.9546 | F1 MACRO 0.9701 | F1 MICRO 0.9716
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.93      0.99      0.96       175
#       others       0.93      0.94      0.93       158
#         part       0.96      0.96      0.96       158
#        price       0.97      1.00      0.99       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.96      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 5.038485050201416 | ACCURACY: 0.9186 | F1 MACRO: 0.9039 | F1 MICRO: 0.9186
# EPOCH 2 | LOSS: 4.311654567718506 | ACCURACY: 0.8953 | F1 MACRO: 0.8862 | F1 MICRO: 0.8953
# EPOCH 3 | LOSS: 3.9117119312286377 | ACCURACY: 0.9302 | F1 MACRO: 0.922 | F1 MICRO: 0.9302
# EPOCH 4 | LOSS: 3.5758843421936035 | ACCURACY: 0.9147 | F1 MACRO: 0.9057 | F1 MICRO: 0.9147
# EPOCH 5 | LOSS: 3.3938002586364746 | ACCURACY: 0.938 | F1 MACRO: 0.927 | F1 MICRO: 0.938
# EPOCH 6 | LOSS: 3.3855526447296143 | ACCURACY: 0.9419 | F1 MACRO: 0.9332 | F1 MICRO: 0.9419
# EPOCH 7 | LOSS: 3.1945197582244873 | ACCURACY: 0.9419 | F1 MACRO: 0.9323 | F1 MICRO: 0.9419
# EPOCH 8 | LOSS: 3.1407387256622314 | ACCURACY: 0.9225 | F1 MACRO: 0.9112 | F1 MICRO: 0.9225
# EPOCH 9 | LOSS: 3.161879062652588 | ACCURACY: 0.9535 | F1 MACRO: 0.9477 | F1 MICRO: 0.9535
# EPOCH 10 | LOSS: 3.133265256881714 | ACCURACY: 0.9186 | F1 MACRO: 0.9024 | F1 MICRO: 0.9186
# sentiment: ACCURACY 0.9535 | F1 MACRO 0.9477 | F1 MICRO 0.9535
#               precision    recall  f1-score   support
#
#     negative       0.88      0.99      0.93        81
#     positive       0.99      0.94      0.97       177
#
#     accuracy                           0.95       258
#    macro avg       0.94      0.96      0.95       258
# weighted avg       0.96      0.95      0.95       258
#
# --------------------------------------------------
# Iteration 435: Accuracy: 0.9468, F1 Micro: 0.9468, F1 Macro: 0.8967
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.92      1.00      0.96        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.95      0.88      0.91        24
#
#     accuracy                           0.98       216
#    macro avg       0.95      0.96      0.95       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.75      0.77        16
#      neutral       0.94      0.98      0.96       167
#     positive       0.88      0.70      0.78        33
#
#     accuracy                           0.92       216
#    macro avg       0.87      0.81      0.84       216
# weighted avg       0.92      0.92      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.83      0.83        12
#      neutral       0.93      0.92      0.92       152
#     positive       0.81      0.83      0.82        52
#
#     accuracy                           0.89       216
#    macro avg       0.86      0.86      0.86       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.79      1.00      0.88        23
#      neutral       0.96      0.97      0.97       152
#     positive       0.91      0.73      0.81        41
#
#     accuracy                           0.93       216
#    macro avg       0.89      0.90      0.89       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.79      0.85      0.81        13
#      neutral       0.98      0.99      0.99       186
#     positive       0.93      0.76      0.84        17
#
#     accuracy                           0.97       216
#    macro avg       0.90      0.87      0.88       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.98      1.00      0.99       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       0.99      0.93      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.3498823165893556
# Samples above threshold: 43
# Acquired samples: 43
# Sampling duration: 15.876490116119385 seconds
# New train size: 478
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.357515811920166 | ACCURACY: 0.7999 | F1 MACRO: 0.8858 | F1 MICRO: 0.8873
# EPOCH 2 | LOSS: 2.0531938076019287 | ACCURACY: 0.8497 | F1 MACRO: 0.9097 | F1 MICRO: 0.9112
# EPOCH 3 | LOSS: 1.9326268434524536 | ACCURACY: 0.9159 | F1 MACRO: 0.9462 | F1 MICRO: 0.9481
# EPOCH 4 | LOSS: 1.8832939863204956 | ACCURACY: 0.9375 | F1 MACRO: 0.9589 | F1 MICRO: 0.961
# EPOCH 5 | LOSS: 1.7520626783370972 | ACCURACY: 0.9479 | F1 MACRO: 0.9657 | F1 MICRO: 0.9674
# EPOCH 6 | LOSS: 1.68104088306427 | ACCURACY: 0.9472 | F1 MACRO: 0.9646 | F1 MICRO: 0.9668
# EPOCH 7 | LOSS: 1.6033803224563599 | ACCURACY: 0.9501 | F1 MACRO: 0.9656 | F1 MICRO: 0.9684
# EPOCH 8 | LOSS: 1.5698314905166626 | ACCURACY: 0.9524 | F1 MACRO: 0.9681 | F1 MICRO: 0.97
# EPOCH 9 | LOSS: 1.5175763368606567 | ACCURACY: 0.9531 | F1 MACRO: 0.9677 | F1 MICRO: 0.9704
# EPOCH 10 | LOSS: 1.4690444469451904 | ACCURACY: 0.9546 | F1 MACRO: 0.9697 | F1 MICRO: 0.9714
# aspect: ACCURACY 0.9546 | F1 MACRO 0.9697 | F1 MICRO 0.9714
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.95      0.97      0.96       175
#       others       0.93      0.91      0.92       158
#         part       0.97      0.97      0.97       158
#        price       0.98      0.99      0.99       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.97      0.98      0.97      1061
#    macro avg       0.97      0.97      0.97      1061
# weighted avg       0.97      0.98      0.97      1061
#  samples avg       0.97      0.97      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 4.7724223136901855 | ACCURACY: 0.8755 | F1 MACRO: 0.8335 | F1 MICRO: 0.8755
# EPOCH 2 | LOSS: 4.080723762512207 | ACCURACY: 0.9377 | F1 MACRO: 0.9267 | F1 MICRO: 0.9377
# EPOCH 3 | LOSS: 3.95158052444458 | ACCURACY: 0.9158 | F1 MACRO: 0.9033 | F1 MICRO: 0.9158
# EPOCH 4 | LOSS: 3.551790952682495 | ACCURACY: 0.9304 | F1 MACRO: 0.921 | F1 MICRO: 0.9304
# EPOCH 5 | LOSS: 3.314879894256592 | ACCURACY: 0.9377 | F1 MACRO: 0.9285 | F1 MICRO: 0.9377
# EPOCH 6 | LOSS: 3.1890623569488525 | ACCURACY: 0.9194 | F1 MACRO: 0.9013 | F1 MICRO: 0.9194
# EPOCH 7 | LOSS: 3.2134299278259277 | ACCURACY: 0.9231 | F1 MACRO: 0.9127 | F1 MICRO: 0.9231
# EPOCH 8 | LOSS: 3.0228679180145264 | ACCURACY: 0.9451 | F1 MACRO: 0.9361 | F1 MICRO: 0.9451
# EPOCH 9 | LOSS: 3.0362563133239746 | ACCURACY: 0.9341 | F1 MACRO: 0.9245 | F1 MICRO: 0.9341
# EPOCH 10 | LOSS: 3.0344126224517822 | ACCURACY: 0.9267 | F1 MACRO: 0.9166 | F1 MICRO: 0.9267
# sentiment: ACCURACY 0.9451 | F1 MACRO 0.9361 | F1 MICRO 0.9451
#               precision    recall  f1-score   support
#
#     negative       0.89      0.94      0.91        83
#     positive       0.97      0.95      0.96       190
#
#     accuracy                           0.95       273
#    macro avg       0.93      0.94      0.94       273
# weighted avg       0.95      0.95      0.95       273
#
# --------------------------------------------------
# Iteration 478: Accuracy: 0.9506, F1 Micro: 0.9506, F1 Macro: 0.9055
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.82      0.90        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.88      0.92      0.90        24
#
#     accuracy                           0.98       216
#    macro avg       0.96      0.91      0.93       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.75      0.80        16
#      neutral       0.96      0.97      0.96       167
#     positive       0.85      0.85      0.85        33
#
#     accuracy                           0.94       216
#    macro avg       0.89      0.86      0.87       216
# weighted avg       0.93      0.94      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.67      0.83      0.74        12
#      neutral       0.94      0.89      0.92       152
#     positive       0.74      0.81      0.77        52
#
#     accuracy                           0.87       216
#    macro avg       0.78      0.85      0.81       216
# weighted avg       0.88      0.87      0.87       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.88      1.00      0.94        23
#      neutral       0.97      0.98      0.97       152
#     positive       0.94      0.83      0.88        41
#
#     accuracy                           0.95       216
#    macro avg       0.93      0.94      0.93       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.85      0.88        13
#      neutral       0.98      0.99      0.99       186
#     positive       0.94      0.88      0.91        17
#
#     accuracy                           0.98       216
#    macro avg       0.95      0.91      0.93       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.99      1.00      1.00       185
#     positive       0.94      1.00      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.95      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.3574126958847046
# Samples above threshold: 39
# Acquired samples: 39
# Sampling duration: 15.622876644134521 seconds
# New train size: 517
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.3312551975250244 | ACCURACY: 0.7909 | F1 MACRO: 0.8782 | F1 MICRO: 0.8811
# EPOCH 2 | LOSS: 2.038217306137085 | ACCURACY: 0.8676 | F1 MACRO: 0.9198 | F1 MICRO: 0.9214
# EPOCH 3 | LOSS: 1.9546500444412231 | ACCURACY: 0.9293 | F1 MACRO: 0.9536 | F1 MICRO: 0.956
# EPOCH 4 | LOSS: 1.8473089933395386 | ACCURACY: 0.9472 | F1 MACRO: 0.9656 | F1 MICRO: 0.9671
# EPOCH 5 | LOSS: 1.7430814504623413 | ACCURACY: 0.942 | F1 MACRO: 0.9614 | F1 MICRO: 0.9636
# EPOCH 6 | LOSS: 1.6701688766479492 | ACCURACY: 0.9516 | F1 MACRO: 0.9676 | F1 MICRO: 0.9695
# EPOCH 7 | LOSS: 1.591914415359497 | ACCURACY: 0.9397 | F1 MACRO: 0.9573 | F1 MICRO: 0.9617
# EPOCH 8 | LOSS: 1.5432113409042358 | ACCURACY: 0.9531 | F1 MACRO: 0.9681 | F1 MICRO: 0.9703
# EPOCH 9 | LOSS: 1.5121605396270752 | ACCURACY: 0.9487 | F1 MACRO: 0.9649 | F1 MICRO: 0.9674
# EPOCH 10 | LOSS: 1.457470178604126 | ACCURACY: 0.9494 | F1 MACRO: 0.9657 | F1 MICRO: 0.9681
# aspect: ACCURACY 0.9531 | F1 MACRO 0.9681 | F1 MICRO 0.9703
#               precision    recall  f1-score   support
#
# ...
# EPOCH 2 | LOSS: 2.4579830169677734 | ACCURACY: 0.9301 | F1 MACRO: 0.919 | F1 MICRO: 0.9301
# EPOCH 3 | LOSS: 2.234386920928955 | ACCURACY: 0.9412 | F1 MACRO: 0.9324 | F1 MICRO: 0.9412
# EPOCH 4 | LOSS: 2.0360774993896484 | ACCURACY: 0.9301 | F1 MACRO: 0.9209 | F1 MICRO: 0.9301
# EPOCH 5 | LOSS: 1.943496823310852 | ACCURACY: 0.9412 | F1 MACRO: 0.9302 | F1 MICRO: 0.9412
# EPOCH 6 | LOSS: 1.9342787265777588 | ACCURACY: 0.9338 | F1 MACRO: 0.9235 | F1 MICRO: 0.9338
# EPOCH 7 | LOSS: 1.8530068397521973 | ACCURACY: 0.9265 | F1 MACRO: 0.9165 | F1 MICRO: 0.9265
# EPOCH 8 | LOSS: 1.7994496822357178 | ACCURACY: 0.9301 | F1 MACRO: 0.9174 | F1 MICRO: 0.9301
# EPOCH 9 | LOSS: 1.7986258268356323 | ACCURACY: 0.8971 | F1 MACRO: 0.8751 | F1 MICRO: 0.8971
# EPOCH 10 | LOSS: 1.7505673170089722 | ACCURACY: 0.9301 | F1 MACRO: 0.9209 | F1 MICRO: 0.9301
# sentiment: ACCURACY 0.9412 | F1 MACRO 0.9302 | F1 MICRO 0.9412
#               precision    recall  f1-score   support
#
#     negative       0.94      0.87      0.90        85
#     positive       0.94      0.97      0.96       187
#
#     accuracy                           0.94       272
#    macro avg       0.94      0.92      0.93       272
# weighted avg       0.94      0.94      0.94       272
#
# --------------------------------------------------
# Iteration 831: Accuracy: 0.9506, F1 Micro: 0.9506, F1 Macro: 0.9103
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.92      0.96      0.94        24
#
#     accuracy                           0.99       216
#    macro avg       0.97      0.95      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.81      0.87        16
#      neutral       0.95      0.98      0.96       167
#     positive       0.83      0.76      0.79        33
#
#     accuracy                           0.93       216
#    macro avg       0.90      0.85      0.87       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.75      0.75        12
#      neutral       0.93      0.91      0.92       152
#     positive       0.73      0.79      0.76        52
#
#     accuracy                           0.87       216
#    macro avg       0.80      0.82      0.81       216
# weighted avg       0.87      0.87      0.87       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.96      0.90        23
#      neutral       0.97      0.97      0.97       152
#     positive       0.89      0.83      0.86        41
#
#     accuracy                           0.94       216
#    macro avg       0.90      0.92      0.91       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.85      0.88        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.89      0.94      0.91        17
#
#     accuracy                           0.98       216
#    macro avg       0.93      0.93      0.93       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       1.00      1.00      1.00       185
#     positive       0.94      1.00      0.97        17
#
#     accuracy                           1.00       216
#    macro avg       0.98      0.98      0.98       216
# weighted avg       1.00      1.00      1.00       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 864
# Threshold: 2.3631965637207033
# Samples above threshold: 4
# Acquired samples: 25
# Sampling duration: 21.2137770652771 seconds
# New train size: 856
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.211721181869507 | ACCURACY: 0.8482 | F1 MACRO: 0.9101 | F1 MICRO: 0.9114
# EPOCH 2 | LOSS: 1.9297986030578613 | ACCURACY: 0.933 | F1 MACRO: 0.9564 | F1 MICRO: 0.9584
# EPOCH 3 | LOSS: 1.775444746017456 | ACCURACY: 0.9539 | F1 MACRO: 0.9699 | F1 MICRO: 0.9713
# EPOCH 4 | LOSS: 1.6441465616226196 | ACCURACY: 0.9568 | F1 MACRO: 0.9713 | F1 MICRO: 0.9729
# EPOCH 5 | LOSS: 1.5660134553909302 | ACCURACY: 0.9606 | F1 MACRO: 0.9737 | F1 MICRO: 0.9752
# EPOCH 6 | LOSS: 1.5059144496917725 | ACCURACY: 0.9673 | F1 MACRO: 0.9786 | F1 MICRO: 0.9795
# EPOCH 7 | LOSS: 1.455837368965149 | ACCURACY: 0.9583 | F1 MACRO: 0.9719 | F1 MICRO: 0.9737
# EPOCH 8 | LOSS: 1.4087690114974976 | ACCURACY: 0.9606 | F1 MACRO: 0.9739 | F1 MICRO: 0.9752
# EPOCH 9 | LOSS: 1.3745282888412476 | ACCURACY: 0.9635 | F1 MACRO: 0.9756 | F1 MICRO: 0.977
# EPOCH 10 | LOSS: 1.3351318836212158 | ACCURACY: 0.9554 | F1 MACRO: 0.97 | F1 MICRO: 0.9717
# aspect: ACCURACY 0.9673 | F1 MACRO 0.9786 | F1 MICRO 0.9795
#               precision    recall  f1-score   support
#
#         fuel       0.99      0.99      0.99       187
#      machine       0.96      0.98      0.97       175
#       others       0.90      0.99      0.95       158
#         part       0.98      0.97      0.98       158
#        price       0.98      0.99      0.99       192
#      service       0.99      1.00      1.00       191
#
#    micro avg       0.97      0.99      0.98      1061
#    macro avg       0.97      0.99      0.98      1061
# weighted avg       0.97      0.99      0.98      1061
#  samples avg       0.97      0.99      0.98      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 2.8282954692840576 | ACCURACY: 0.8814 | F1 MACRO: 0.8746 | F1 MICRO: 0.8814
# EPOCH 2 | LOSS: 2.3227405548095703 | ACCURACY: 0.917 | F1 MACRO: 0.903 | F1 MICRO: 0.917
# EPOCH 3 | LOSS: 2.0896852016448975 | ACCURACY: 0.9328 | F1 MACRO: 0.9265 | F1 MICRO: 0.9328
# EPOCH 4 | LOSS: 1.9770265817642212 | ACCURACY: 0.9328 | F1 MACRO: 0.9269 | F1 MICRO: 0.9328
# EPOCH 5 | LOSS: 1.8148345947265625 | ACCURACY: 0.9565 | F1 MACRO: 0.9517 | F1 MICRO: 0.9565
# EPOCH 6 | LOSS: 1.7976257801055908 | ACCURACY: 0.9249 | F1 MACRO: 0.9191 | F1 MICRO: 0.9249
# EPOCH 7 | LOSS: 1.7058316469192505 | ACCURACY: 0.9486 | F1 MACRO: 0.9429 | F1 MICRO: 0.9486
# EPOCH 8 | LOSS: 1.657854676246643 | ACCURACY: 0.9209 | F1 MACRO: 0.9133 | F1 MICRO: 0.9209
# EPOCH 9 | LOSS: 1.6635782718658447 | ACCURACY: 0.9407 | F1 MACRO: 0.9352 | F1 MICRO: 0.9407
# EPOCH 10 | LOSS: 1.6503866910934448 | ACCURACY: 0.9328 | F1 MACRO: 0.9265 | F1 MICRO: 0.9328
# sentiment: ACCURACY 0.9565 | F1 MACRO 0.9517 | F1 MICRO 0.9565
#               precision    recall  f1-score   support
#
#     negative       0.91      0.96      0.94        84
#     positive       0.98      0.95      0.97       169
#
#     accuracy                           0.96       253
#    macro avg       0.95      0.96      0.95       253
# weighted avg       0.96      0.96      0.96       253
# Error during conversion: ChunkedEncodingError(ProtocolError('Response ended prematurely'))
# --------------------------------------------------
# Iteration 856: Accuracy: 0.9591, F1 Micro: 0.9591, F1 Macro: 0.9212
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.96      0.96      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.98      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.87      0.81      0.84        16
#      neutral       0.95      0.98      0.96       167
#     positive       0.87      0.79      0.83        33
#
#     accuracy                           0.94       216
#    macro avg       0.90      0.86      0.88       216
# weighted avg       0.93      0.94      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.90      0.75      0.82        12
#      neutral       0.90      0.99      0.94       152
#     positive       0.95      0.71      0.81        52
#
#     accuracy                           0.91       216
#    macro avg       0.92      0.82      0.86       216
# weighted avg       0.91      0.91      0.90       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.82      1.00      0.90        23
#      neutral       0.98      0.97      0.98       152
#     positive       0.95      0.85      0.90        41
#
#     accuracy                           0.95       216
#    macro avg       0.92      0.94      0.93       216
# weighted avg       0.96      0.95      0.95       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.92      0.89        13
#      neutral       0.98      0.99      0.99       186
#     positive       0.93      0.76      0.84        17
#
#     accuracy                           0.97       216
#    macro avg       0.92      0.89      0.91       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       1.00      1.00      1.00       185
#     positive       0.94      1.00      0.97        17
#
#     accuracy                           1.00       216
#    macro avg       0.98      0.98      0.98       216
# weighted avg       1.00      1.00      1.00       216
#
# Launching training on 2 GPUs.
# Error during conversion: ChunkedEncodingError(ProtocolError('Response ended prematurely'))
# Nearest checkpoint: 864
# Threshold: 2.3566619873046877
# Samples above threshold: 1
# Acquired samples: 8
# Sampling duration: 22.01206612586975 seconds
# New train size: 864
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# Error during conversion: ChunkedEncodingError(ProtocolError('Response ended prematurely'))
# Error during conversion: ChunkedEncodingError(ProtocolError('Response ended prematurely'))
# EPOCH 1 | LOSS: 2.195751190185547 | ACCURACY: 0.8311 | F1 MACRO: 0.9014 | F1 MICRO: 0.9028
# EPOCH 2 | LOSS: 1.9339746236801147 | ACCURACY: 0.9308 | F1 MACRO: 0.9545 | F1 MICRO: 0.9568
# EPOCH 3 | LOSS: 1.765094518661499 | ACCURACY: 0.9561 | F1 MACRO: 0.9715 | F1 MICRO: 0.9727
# EPOCH 4 | LOSS: 1.6397866010665894 | ACCURACY: 0.9583 | F1 MACRO: 0.9722 | F1 MICRO: 0.9738
# EPOCH 5 | LOSS: 1.573371171951294 | ACCURACY: 0.9591 | F1 MACRO: 0.9725 | F1 MICRO: 0.9741
# EPOCH 6 | LOSS: 1.4948567152023315 | ACCURACY: 0.9583 | F1 MACRO: 0.9718 | F1 MICRO: 0.9737
# EPOCH 7 | LOSS: 1.444743275642395 | ACCURACY: 0.9576 | F1 MACRO: 0.9716 | F1 MICRO: 0.9733
# EPOCH 8 | LOSS: 1.4062752723693848 | ACCURACY: 0.9576 | F1 MACRO: 0.9708 | F1 MICRO: 0.9731
# EPOCH 9 | LOSS: 1.3524152040481567 | ACCURACY: 0.9539 | F1 MACRO: 0.9685 | F1 MICRO: 0.9708
# EPOCH 10 | LOSS: 1.322127342224121 | ACCURACY: 0.9621 | F1 MACRO: 0.9751 | F1 MICRO: 0.9762
# aspect: ACCURACY 0.9621 | F1 MACRO 0.9751 | F1 MICRO 0.9762
#               precision    recall  f1-score   support
#
#         fuel       0.98      0.99      0.99       187
#      machine       0.95      0.99      0.97       175
#       others       0.92      0.97      0.94       158
#         part       0.98      0.96      0.97       158
#        price       0.98      0.98      0.98       192
#      service       0.99      1.00      1.00       191
#
#    micro avg       0.97      0.98      0.98      1061
#    macro avg       0.97      0.98      0.98      1061
# weighted avg       0.97      0.98      0.98      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 2.74219012260437 | ACCURACY: 0.9341 | F1 MACRO: 0.9269 | F1 MICRO: 0.9341
# EPOCH 2 | LOSS: 2.367717742919922 | ACCURACY: 0.9225 | F1 MACRO: 0.9155 | F1 MICRO: 0.9225
# EPOCH 3 | LOSS: 2.0985605716705322 | ACCURACY: 0.9302 | F1 MACRO: 0.9206 | F1 MICRO: 0.9302
# EPOCH 4 | LOSS: 1.9428192377090454 | ACCURACY: 0.9147 | F1 MACRO: 0.9029 | F1 MICRO: 0.9147
# EPOCH 5 | LOSS: 1.8998197317123413 | ACCURACY: 0.9264 | F1 MACRO: 0.9164 | F1 MICRO: 0.9264
# EPOCH 6 | LOSS: 1.7899503707885742 | ACCURACY: 0.9419 | F1 MACRO: 0.9344 | F1 MICRO: 0.9419
# EPOCH 7 | LOSS: 1.7975046634674072 | ACCURACY: 0.938 | F1 MACRO: 0.9302 | F1 MICRO: 0.938
# EPOCH 8 | LOSS: 1.7337934970855713 | ACCURACY: 0.9341 | F1 MACRO: 0.928 | F1 MICRO: 0.9341
# EPOCH 9 | LOSS: 1.7514311075210571 | ACCURACY: 0.9264 | F1 MACRO: 0.9183 | F1 MICRO: 0.9264
# EPOCH 10 | LOSS: 1.7848955392837524 | ACCURACY: 0.9225 | F1 MACRO: 0.9155 | F1 MICRO: 0.9225
# sentiment: ACCURACY 0.9419 | F1 MACRO 0.9344 | F1 MICRO 0.9419
#               precision    recall  f1-score   support
#
#     negative       0.91      0.92      0.91        85
#     positive       0.96      0.95      0.96       173
#
#     accuracy                           0.94       258
#    macro avg       0.93      0.94      0.93       258
# weighted avg       0.94      0.94      0.94       258
#
# --------------------------------------------------
# Iteration 864: Accuracy: 0.9606, F1 Micro: 0.9606, F1 Macro: 0.9161
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.82      0.90        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.88      0.96      0.92        24
#
#     accuracy                           0.98       216
#    macro avg       0.96      0.92      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.75      0.80        16
#      neutral       0.95      0.98      0.96       167
#     positive       0.86      0.76      0.81        33
#
#     accuracy                           0.93       216
#    macro avg       0.89      0.83      0.86       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.83      0.83        12
#      neutral       0.94      0.97      0.95       152
#     positive       0.91      0.81      0.86        52
#
#     accuracy                           0.93       216
#    macro avg       0.89      0.87      0.88       216
# weighted avg       0.93      0.93      0.92       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.88      1.00      0.94        23
#      neutral       0.97      0.98      0.98       152
#     positive       0.95      0.85      0.90        41
#
#     accuracy                           0.96       216
#    macro avg       0.93      0.94      0.94       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.77      0.83        13
#      neutral       0.98      0.99      0.99       186
#     positive       0.82      0.82      0.82        17
#
#     accuracy                           0.97       216
#    macro avg       0.91      0.86      0.88       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        14
#      neutral       1.00      1.00      1.00       185
#     positive       1.00      1.00      1.00        17
#
#     accuracy                           1.00       216
#    macro avg       1.00      1.00      1.00       216
# weighted avg       1.00      1.00      1.00       216
#
# Total sampling time: 388.23 seconds
# Total runtime: 3169.9422512054443 seconds

# %% [markdown]
# ## RUN 4

# %%
active_learning(seeds[3], 3)
# Out:
# ===============================================
# TRIAL 4
# Random seed: 3
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# pytorch_model.bin:   0%|          | 0.00/498M [00:00<?, ?B/s]
# EPOCH 1 | LOSS: 2.4209768772125244 | ACCURACY: 0.7671 | F1 MACRO: 0.8506 | F1 MICRO: 0.8622
# EPOCH 2 | LOSS: 2.3106493949890137 | ACCURACY: 0.779 | F1 MACRO: 0.873 | F1 MICRO: 0.8751
# EPOCH 3 | LOSS: 2.2206153869628906 | ACCURACY: 0.7805 | F1 MACRO: 0.8737 | F1 MICRO: 0.8758
# EPOCH 4 | LOSS: 2.176391124725342 | ACCURACY: 0.7842 | F1 MACRO: 0.8743 | F1 MICRO: 0.8767
# EPOCH 5 | LOSS: 2.183481216430664 | ACCURACY: 0.779 | F1 MACRO: 0.8708 | F1 MICRO: 0.8736
# EPOCH 6 | LOSS: 2.0890560150146484 | ACCURACY: 0.7835 | F1 MACRO: 0.872 | F1 MICRO: 0.8752
# EPOCH 7 | LOSS: 2.0452208518981934 | ACCURACY: 0.7887 | F1 MACRO: 0.8732 | F1 MICRO: 0.8768
# EPOCH 8 | LOSS: 2.0331506729125977 | ACCURACY: 0.7954 | F1 MACRO: 0.8766 | F1 MICRO: 0.8801
# EPOCH 9 | LOSS: 1.9813693761825562 | ACCURACY: 0.7932 | F1 MACRO: 0.8757 | F1 MICRO: 0.879
# EPOCH 10 | LOSS: 1.9889097213745117 | ACCURACY: 0.7984 | F1 MACRO: 0.8788 | F1 MICRO: 0.8817
# aspect: ACCURACY 0.7984 | F1 MACRO 0.8788 | F1 MICRO 0.8817
#               precision    recall  f1-score   support
#
#         fuel       0.84      0.98      0.90       187
#      machine       0.81      0.83      0.82       175
#       others       0.78      0.92      0.85       158
#         part       0.77      0.97      0.86       158
#        price       0.86      1.00      0.92       192
#      service       0.85      1.00      0.92       191
#
#    micro avg       0.82      0.95      0.88      1061
#    macro avg       0.82      0.95      0.88      1061
# weighted avg       0.82      0.95      0.88      1061
#  samples avg       0.82      0.95      0.88      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 15.308319091796875 | ACCURACY: 0.8151 | F1 MACRO: 0.4491 | F1 MICRO: 0.8151
# EPOCH 2 | LOSS: 13.768593788146973 | ACCURACY: 0.8151 | F1 MACRO: 0.4491 | F1 MICRO: 0.8151
# EPOCH 3 | LOSS: 13.021461486816406 | ACCURACY: 0.8403 | F1 MACRO: 0.627 | F1 MICRO: 0.8403
# EPOCH 4 | LOSS: 12.512032508850098 | ACCURACY: 0.8487 | F1 MACRO: 0.7398 | F1 MICRO: 0.8487
# EPOCH 5 | LOSS: 11.851521492004395 | ACCURACY: 0.8655 | F1 MACRO: 0.7255 | F1 MICRO: 0.8655
# EPOCH 6 | LOSS: 11.114638328552246 | ACCURACY: 0.8403 | F1 MACRO: 0.6818 | F1 MICRO: 0.8403
# EPOCH 7 | LOSS: 10.688600540161133 | ACCURACY: 0.8403 | F1 MACRO: 0.6658 | F1 MICRO: 0.8403
# EPOCH 8 | LOSS: 9.901611328125 | ACCURACY: 0.8655 | F1 MACRO: 0.7255 | F1 MICRO: 0.8655
# EPOCH 9 | LOSS: 10.01877212524414 | ACCURACY: 0.8319 | F1 MACRO: 0.6995 | F1 MICRO: 0.8319
# EPOCH 10 | LOSS: 9.622542381286621 | ACCURACY: 0.8571 | F1 MACRO: 0.701 | F1 MICRO: 0.8571
# sentiment: ACCURACY 0.8655 | F1 MACRO 0.7255 | F1 MICRO 0.8655
#               precision    recall  f1-score   support
#
#     negative       0.75      0.41      0.53        22
#     positive       0.88      0.97      0.92        97
#
#     accuracy                           0.87       119
#    macro avg       0.81      0.69      0.73       119
# weighted avg       0.85      0.87      0.85       119
#
# --------------------------------------------------
# Iteration 54: Accuracy: 0.7855, F1 Micro: 0.7855, F1 Macro: 0.4013
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        11
#      neutral       0.84      0.97      0.90       181
#     positive       0.29      0.08      0.13        24
#
#     accuracy                           0.82       216
#    macro avg       0.38      0.35      0.34       216
# weighted avg       0.74      0.82      0.77       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        16
#      neutral       0.80      0.78      0.79       167
#     positive       0.12      0.18      0.14        33
#
#     accuracy                           0.63       216
#    macro avg       0.31      0.32      0.31       216
# weighted avg       0.63      0.63      0.63       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.60      0.25      0.35        12
#      neutral       0.79      0.96      0.87       152
#     positive       0.69      0.35      0.46        52
#
#     accuracy                           0.77       216
#    macro avg       0.69      0.52      0.56       216
# weighted avg       0.76      0.77      0.74       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.26      0.39        23
#      neutral       0.77      0.95      0.85       152
#     positive       0.75      0.37      0.49        41
#
#     accuracy                           0.77       216
#    macro avg       0.76      0.53      0.58       216
# weighted avg       0.76      0.77      0.73       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        13
#      neutral       0.86      1.00      0.93       186
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.86       216
#    macro avg       0.29      0.33      0.31       216
# weighted avg       0.74      0.86      0.80       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        14
#      neutral       0.86      1.00      0.92       185
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.86       216
#    macro avg       0.29      0.33      0.31       216
# weighted avg       0.73      0.86      0.79       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.5639223575592043
# Samples above threshold: 81
# Acquired samples: 81
# Sampling duration: 6.6751813888549805 seconds
# New train size: 135
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.6259303092956543 | ACCURACY: 0.7827 | F1 MACRO: 0.8764 | F1 MICRO: 0.878
# EPOCH 2 | LOSS: 2.4308595657348633 | ACCURACY: 0.7894 | F1 MACRO: 0.8804 | F1 MICRO: 0.882
# EPOCH 3 | LOSS: 2.3301875591278076 | ACCURACY: 0.7976 | F1 MACRO: 0.884 | F1 MICRO: 0.8858
# EPOCH 4 | LOSS: 2.279438018798828 | ACCURACY: 0.8088 | F1 MACRO: 0.8879 | F1 MICRO: 0.8901
# EPOCH 5 | LOSS: 2.1931920051574707 | ACCURACY: 0.8222 | F1 MACRO: 0.8958 | F1 MICRO: 0.8976
# EPOCH 6 | LOSS: 2.169463634490967 | ACCURACY: 0.8356 | F1 MACRO: 0.9027 | F1 MICRO: 0.9045
# EPOCH 7 | LOSS: 2.0919508934020996 | ACCURACY: 0.8542 | F1 MACRO: 0.9122 | F1 MICRO: 0.9139
# EPOCH 8 | LOSS: 2.077393054962158 | ACCURACY: 0.8668 | F1 MACRO: 0.9174 | F1 MICRO: 0.92
# EPOCH 9 | LOSS: 2.024604320526123 | ACCURACY: 0.8824 | F1 MACRO: 0.9263 | F1 MICRO: 0.9288
# EPOCH 10 | LOSS: 2.00114369392395 | ACCURACY: 0.8921 | F1 MACRO: 0.9315 | F1 MICRO: 0.9341
# aspect: ACCURACY 0.8921 | F1 MACRO 0.9315 | F1 MICRO 0.9341
#               precision    recall  f1-score   support
#
#         fuel       0.91      1.00      0.95       187
#      machine       0.91      0.97      0.94       175
#       others       0.88      0.87      0.88       158
#         part       0.77      0.98      0.86       158
#        price       0.98      0.98      0.98       192
#      service       0.96      0.99      0.98       191
#
#    micro avg       0.90      0.97      0.93      1061
#    macro avg       0.90      0.97      0.93      1061
# weighted avg       0.91      0.97      0.94      1061
#  samples avg       0.91      0.97      0.93      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 13.29687786102295 | ACCURACY: 0.8838 | F1 MACRO: 0.8678 | F1 MICRO: 0.8838
# EPOCH 2 | LOSS: 11.925384521484375 | ACCURACY: 0.904 | F1 MACRO: 0.8848 | F1 MICRO: 0.904
# EPOCH 3 | LOSS: 11.112889289855957 | ACCURACY: 0.904 | F1 MACRO: 0.8916 | F1 MICRO: 0.904
# EPOCH 4 | LOSS: 10.546446800231934 | ACCURACY: 0.899 | F1 MACRO: 0.8826 | F1 MICRO: 0.899
# EPOCH 5 | LOSS: 9.562283515930176 | ACCURACY: 0.904 | F1 MACRO: 0.8848 | F1 MICRO: 0.904
# EPOCH 6 | LOSS: 9.318450927734375 | ACCURACY: 0.9192 | F1 MACRO: 0.9025 | F1 MICRO: 0.9192
# EPOCH 7 | LOSS: 8.936726570129395 | ACCURACY: 0.9091 | F1 MACRO: 0.8903 | F1 MICRO: 0.9091
# EPOCH 8 | LOSS: 8.78571891784668 | ACCURACY: 0.899 | F1 MACRO: 0.8741 | F1 MICRO: 0.899
# EPOCH 9 | LOSS: 8.666974067687988 | ACCURACY: 0.8889 | F1 MACRO: 0.872 | F1 MICRO: 0.8889
# EPOCH 10 | LOSS: 8.493736267089844 | ACCURACY: 0.8838 | F1 MACRO: 0.851 | F1 MICRO: 0.8838
# sentiment: ACCURACY 0.9192 | F1 MACRO 0.9025 | F1 MICRO 0.9192
#               precision    recall  f1-score   support
#
#     negative       0.88      0.85      0.86        59
#     positive       0.94      0.95      0.94       139
#
#     accuracy                           0.92       198
#    macro avg       0.91      0.90      0.90       198
# weighted avg       0.92      0.92      0.92       198
#
# --------------------------------------------------
# Iteration 135: Accuracy: 0.8889, F1 Micro: 0.8889, F1 Macro: 0.7652
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.45      0.62        11
#      neutral       0.93      1.00      0.97       181
#     positive       0.94      0.67      0.78        24
#
#     accuracy                           0.94       216
#    macro avg       0.96      0.71      0.79       216
# weighted avg       0.94      0.94      0.93       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.69      0.79        16
#      neutral       0.92      0.96      0.94       167
#     positive       0.67      0.61      0.63        33
#
#     accuracy                           0.88       216
#    macro avg       0.83      0.75      0.79       216
# weighted avg       0.88      0.88      0.88       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.59      0.83      0.69        12
#      neutral       0.88      0.90      0.89       152
#     positive       0.77      0.65      0.71        52
#
#     accuracy                           0.84       216
#    macro avg       0.75      0.80      0.76       216
# weighted avg       0.84      0.84      0.84       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.17      0.29        23
#      neutral       0.77      0.97      0.86       152
#     positive       0.79      0.37      0.50        41
#
#     accuracy                           0.77       216
#    macro avg       0.79      0.50      0.55       216
# weighted avg       0.78      0.77      0.73       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.90      0.69      0.78        13
#      neutral       0.97      0.98      0.98       186
#     positive       0.71      0.71      0.71        17
#
#     accuracy                           0.94       216
#    macro avg       0.86      0.79      0.82       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.79      0.88        14
#      neutral       0.95      1.00      0.98       185
#     positive       1.00      0.65      0.79        17
#
#     accuracy                           0.96       216
#    macro avg       0.98      0.81      0.88       216
# weighted avg       0.96      0.96      0.96       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.5889904499053955
# Samples above threshold: 73
# Acquired samples: 73
# Sampling duration: 9.63717532157898 seconds
# New train size: 208
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.511519193649292 | ACCURACY: 0.7879 | F1 MACRO: 0.8798 | F1 MICRO: 0.8813
# EPOCH 2 | LOSS: 2.308408498764038 | ACCURACY: 0.7999 | F1 MACRO: 0.8853 | F1 MICRO: 0.8869
# EPOCH 3 | LOSS: 2.209343671798706 | ACCURACY: 0.8147 | F1 MACRO: 0.8914 | F1 MICRO: 0.8933
# EPOCH 4 | LOSS: 2.129805564880371 | ACCURACY: 0.8311 | F1 MACRO: 0.9018 | F1 MICRO: 0.9031
# EPOCH 5 | LOSS: 2.0624470710754395 | ACCURACY: 0.8646 | F1 MACRO: 0.9186 | F1 MICRO: 0.9201
# EPOCH 6 | LOSS: 2.0636117458343506 | ACCURACY: 0.9048 | F1 MACRO: 0.9406 | F1 MICRO: 0.9422
# EPOCH 7 | LOSS: 1.9914789199829102 | ACCURACY: 0.9144 | F1 MACRO: 0.946 | F1 MICRO: 0.9478
# EPOCH 8 | LOSS: 1.9426062107086182 | ACCURACY: 0.9219 | F1 MACRO: 0.9491 | F1 MICRO: 0.9516
# EPOCH 9 | LOSS: 1.870596170425415 | ACCURACY: 0.9301 | F1 MACRO: 0.9545 | F1 MICRO: 0.9567
# EPOCH 10 | LOSS: 1.788120150566101 | ACCURACY: 0.9315 | F1 MACRO: 0.9546 | F1 MICRO: 0.9574
# aspect: ACCURACY 0.9315 | F1 MACRO 0.9546 | F1 MICRO 0.9574
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.91      0.99      0.95       175
#       others       0.89      0.89      0.89       158
#         part       0.90      0.96      0.93       158
#        price       0.98      0.98      0.98       192
#      service       0.97      1.00      0.99       191
#
#    micro avg       0.94      0.97      0.96      1061
#    macro avg       0.94      0.97      0.95      1061
# weighted avg       0.94      0.97      0.96      1061
#  samples avg       0.94      0.97      0.95      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 10.46087646484375 | ACCURACY: 0.8988 | F1 MACRO: 0.8855 | F1 MICRO: 0.8988
# EPOCH 2 | LOSS: 9.302271842956543 | ACCURACY: 0.9352 | F1 MACRO: 0.926 | F1 MICRO: 0.9352
# EPOCH 3 | LOSS: 8.40458869934082 | ACCURACY: 0.9231 | F1 MACRO: 0.9155 | F1 MICRO: 0.9231
# EPOCH 4 | LOSS: 7.804793357849121 | ACCURACY: 0.915 | F1 MACRO: 0.9071 | F1 MICRO: 0.915
# EPOCH 5 | LOSS: 7.556324005126953 | ACCURACY: 0.9028 | F1 MACRO: 0.8946 | F1 MICRO: 0.9028
# EPOCH 6 | LOSS: 7.436992168426514 | ACCURACY: 0.9069 | F1 MACRO: 0.8992 | F1 MICRO: 0.9069
# EPOCH 7 | LOSS: 7.162417888641357 | ACCURACY: 0.919 | F1 MACRO: 0.9113 | F1 MICRO: 0.919
# EPOCH 8 | LOSS: 6.823675155639648 | ACCURACY: 0.9271 | F1 MACRO: 0.9178 | F1 MICRO: 0.9271
# EPOCH 9 | LOSS: 6.699040412902832 | ACCURACY: 0.9271 | F1 MACRO: 0.9168 | F1 MICRO: 0.9271
# EPOCH 10 | LOSS: 6.443868637084961 | ACCURACY: 0.915 | F1 MACRO: 0.9066 | F1 MICRO: 0.915
# sentiment: ACCURACY 0.9352 | F1 MACRO 0.926 | F1 MICRO 0.9352
#               precision    recall  f1-score   support
#
#     negative       0.90      0.90      0.90        80
#     positive       0.95      0.95      0.95       167
#
#     accuracy                           0.94       247
#    macro avg       0.93      0.93      0.93       247
# weighted avg       0.94      0.94      0.94       247
#
# --------------------------------------------------
# Iteration 208: Accuracy: 0.9321, F1 Micro: 0.9321, F1 Macro: 0.8756
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      1.00      0.99       181
#     positive       1.00      0.92      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.97      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.81      0.87        16
#      neutral       0.93      0.99      0.96       167
#     positive       0.87      0.61      0.71        33
#
#     accuracy                           0.92       216
#    macro avg       0.91      0.80      0.85       216
# weighted avg       0.92      0.92      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.60      0.75      0.67        12
#      neutral       0.88      0.91      0.90       152
#     positive       0.77      0.63      0.69        52
#
#     accuracy                           0.84       216
#    macro avg       0.75      0.77      0.75       216
# weighted avg       0.84      0.84      0.84       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.77      0.74      0.76        23
#      neutral       0.92      0.96      0.94       152
#     positive       0.83      0.73      0.78        41
#
#     accuracy                           0.89       216
#    macro avg       0.84      0.81      0.83       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.85      0.85        13
#      neutral       0.99      0.98      0.98       186
#     positive       0.74      0.82      0.78        17
#
#     accuracy                           0.96       216
#    macro avg       0.86      0.88      0.87       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.99      1.00      0.99       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       1.00      0.96      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.7566088438034058
# Samples above threshold: 66
# Acquired samples: 66
# Sampling duration: 11.472859382629395 seconds
# New train size: 274
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.33261775970459 | ACCURACY: 0.7894 | F1 MACRO: 0.8805 | F1 MICRO: 0.882
# EPOCH 2 | LOSS: 2.085932493209839 | ACCURACY: 0.8095 | F1 MACRO: 0.8878 | F1 MICRO: 0.8902
# EPOCH 3 | LOSS: 1.995361566543579 | ACCURACY: 0.8274 | F1 MACRO: 0.8998 | F1 MICRO: 0.9011
# EPOCH 4 | LOSS: 1.929299235343933 | ACCURACY: 0.8735 | F1 MACRO: 0.924 | F1 MICRO: 0.9252
# EPOCH 5 | LOSS: 1.9047805070877075 | ACCURACY: 0.9152 | F1 MACRO: 0.9468 | F1 MICRO: 0.9482
# EPOCH 6 | LOSS: 1.8614836931228638 | ACCURACY: 0.9323 | F1 MACRO: 0.9563 | F1 MICRO: 0.9582
# EPOCH 7 | LOSS: 1.7465240955352783 | ACCURACY: 0.9397 | F1 MACRO: 0.9605 | F1 MICRO: 0.9626
# EPOCH 8 | LOSS: 1.682041883468628 | ACCURACY: 0.9479 | F1 MACRO: 0.9659 | F1 MICRO: 0.9677
# EPOCH 9 | LOSS: 1.6180263757705688 | ACCURACY: 0.936 | F1 MACRO: 0.9565 | F1 MICRO: 0.96
# EPOCH 10 | LOSS: 1.5880906581878662 | ACCURACY: 0.936 | F1 MACRO: 0.9563 | F1 MICRO: 0.9599
# aspect: ACCURACY 0.9479 | F1 MACRO 0.9659 | F1 MICRO 0.9677
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.95      0.99      0.97       175
#       others       0.87      0.95      0.91       158
#         part       0.91      0.99      0.95       158
#        price       0.98      0.99      0.99       192
#      service       0.98      1.00      0.99       191
#
#    micro avg       0.95      0.99      0.97      1061
#    macro avg       0.95      0.99      0.97      1061
# weighted avg       0.95      0.99      0.97      1061
#  samples avg       0.95      0.99      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 7.5461554527282715 | ACCURACY: 0.8856 | F1 MACRO: 0.8694 | F1 MICRO: 0.8856
# EPOCH 2 | LOSS: 6.438040256500244 | ACCURACY: 0.911 | F1 MACRO: 0.9042 | F1 MICRO: 0.911
# EPOCH 3 | LOSS: 5.89329195022583 | ACCURACY: 0.928 | F1 MACRO: 0.9183 | F1 MICRO: 0.928
# EPOCH 4 | LOSS: 5.672170639038086 | ACCURACY: 0.9364 | F1 MACRO: 0.9305 | F1 MICRO: 0.9364
# EPOCH 5 | LOSS: 5.234632968902588 | ACCURACY: 0.9195 | F1 MACRO: 0.9115 | F1 MICRO: 0.9195
# EPOCH 6 | LOSS: 5.092663288116455 | ACCURACY: 0.9237 | F1 MACRO: 0.9159 | F1 MICRO: 0.9237
# EPOCH 7 | LOSS: 5.130435466766357 | ACCURACY: 0.9068 | F1 MACRO: 0.8989 | F1 MICRO: 0.9068
# EPOCH 8 | LOSS: 4.800213813781738 | ACCURACY: 0.9153 | F1 MACRO: 0.9081 | F1 MICRO: 0.9153
# EPOCH 9 | LOSS: 4.762981414794922 | ACCURACY: 0.9068 | F1 MACRO: 0.8983 | F1 MICRO: 0.9068
# EPOCH 10 | LOSS: 4.635443210601807 | ACCURACY: 0.9153 | F1 MACRO: 0.9076 | F1 MICRO: 0.9153
# sentiment: ACCURACY 0.9364 | F1 MACRO 0.9305 | F1 MICRO 0.9364
#               precision    recall  f1-score   support
#
#     negative       0.86      0.96      0.91        79
#     positive       0.98      0.92      0.95       157
#
#     accuracy                           0.94       236
#    macro avg       0.92      0.94      0.93       236
# weighted avg       0.94      0.94      0.94       236
#
# --------------------------------------------------
# Iteration 274: Accuracy: 0.9352, F1 Micro: 0.9352, F1 Macro: 0.8737
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.92      1.00      0.96        11
#      neutral       0.99      1.00      0.99       181
#     positive       1.00      0.88      0.93        24
#
#     accuracy                           0.99       216
#    macro avg       0.97      0.96      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.81      0.81      0.81        16
#      neutral       0.94      0.99      0.96       167
#     positive       0.88      0.67      0.76        33
#
#     accuracy                           0.93       216
#    macro avg       0.88      0.82      0.85       216
# weighted avg       0.92      0.93      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.64      0.75      0.69        12
#      neutral       0.88      0.93      0.91       152
#     positive       0.80      0.63      0.71        52
#
#     accuracy                           0.85       216
#    macro avg       0.78      0.77      0.77       216
# weighted avg       0.85      0.85      0.85       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.78      0.78      0.78        23
#      neutral       0.90      0.98      0.94       152
#     positive       0.96      0.63      0.76        41
#
#     accuracy                           0.89       216
#    macro avg       0.88      0.80      0.83       216
# weighted avg       0.90      0.89      0.89       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.92      0.86        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.93      0.76      0.84        17
#
#     accuracy                           0.97       216
#    macro avg       0.91      0.89      0.90       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.93      0.93        14
#      neutral       0.98      1.00      0.99       185
#     positive       1.00      0.82      0.90        17
#
#     accuracy                           0.98       216
#    macro avg       0.97      0.92      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.598599362373352
# Samples above threshold: 59
# Acquired samples: 59
# Sampling duration: 12.622527599334717 seconds
# New train size: 333
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.398085594177246 | ACCURACY: 0.7932 | F1 MACRO: 0.8818 | F1 MICRO: 0.8836
# EPOCH 2 | LOSS: 2.163625955581665 | ACCURACY: 0.8125 | F1 MACRO: 0.891 | F1 MICRO: 0.8926
# EPOCH 3 | LOSS: 2.0412564277648926 | ACCURACY: 0.8601 | F1 MACRO: 0.9177 | F1 MICRO: 0.9183
# EPOCH 4 | LOSS: 2.022444009780884 | ACCURACY: 0.9211 | F1 MACRO: 0.9507 | F1 MICRO: 0.9518
# EPOCH 5 | LOSS: 1.9235869646072388 | ACCURACY: 0.936 | F1 MACRO: 0.9586 | F1 MICRO: 0.9604
# EPOCH 6 | LOSS: 1.8663392066955566 | ACCURACY: 0.9449 | F1 MACRO: 0.9638 | F1 MICRO: 0.9658
# EPOCH 7 | LOSS: 1.7410571575164795 | ACCURACY: 0.9509 | F1 MACRO: 0.9679 | F1 MICRO: 0.9695
# EPOCH 8 | LOSS: 1.6767356395721436 | ACCURACY: 0.9397 | F1 MACRO: 0.9588 | F1 MICRO: 0.9621
# EPOCH 9 | LOSS: 1.6344929933547974 | ACCURACY: 0.9509 | F1 MACRO: 0.9671 | F1 MICRO: 0.9693
# EPOCH 10 | LOSS: 1.5863885879516602 | ACCURACY: 0.9531 | F1 MACRO: 0.9682 | F1 MICRO: 0.9706
# aspect: ACCURACY 0.9531 | F1 MACRO 0.9682 | F1 MICRO 0.9706
#               precision    recall  f1-score   support
#
#         fuel       0.98      0.99      0.99       187
#      machine       0.94      0.99      0.97       175
#       others       0.92      0.89      0.90       158
#         part       0.93      0.99      0.96       158
#        price       0.99      0.99      0.99       192
#      service       0.99      1.00      1.00       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.96      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.706660747528076 | ACCURACY: 0.9 | F1 MACRO: 0.8895 | F1 MICRO: 0.9
# EPOCH 2 | LOSS: 5.8824052810668945 | ACCURACY: 0.908 | F1 MACRO: 0.8994 | F1 MICRO: 0.908
# EPOCH 3 | LOSS: 5.5126142501831055 | ACCURACY: 0.92 | F1 MACRO: 0.9119 | F1 MICRO: 0.92
# EPOCH 4 | LOSS: 5.03217077255249 | ACCURACY: 0.924 | F1 MACRO: 0.9118 | F1 MICRO: 0.924
# EPOCH 5 | LOSS: 4.806463718414307 | ACCURACY: 0.924 | F1 MACRO: 0.916 | F1 MICRO: 0.924
# EPOCH 6 | LOSS: 4.782623767852783 | ACCURACY: 0.924 | F1 MACRO: 0.9118 | F1 MICRO: 0.924
# EPOCH 7 | LOSS: 4.563889503479004 | ACCURACY: 0.932 | F1 MACRO: 0.9245 | F1 MICRO: 0.932
# EPOCH 8 | LOSS: 4.467818737030029 | ACCURACY: 0.912 | F1 MACRO: 0.9035 | F1 MICRO: 0.912
# EPOCH 9 | LOSS: 4.367443561553955 | ACCURACY: 0.916 | F1 MACRO: 0.9061 | F1 MICRO: 0.916
# EPOCH 10 | LOSS: 4.2417097091674805 | ACCURACY: 0.936 | F1 MACRO: 0.9265 | F1 MICRO: 0.936
# sentiment: ACCURACY 0.936 | F1 MACRO 0.9265 | F1 MICRO 0.936
#               precision    recall  f1-score   support
#
#     negative       0.90      0.90      0.90        80
#     positive       0.95      0.95      0.95       170
#
#     accuracy                           0.94       250
#    macro avg       0.93      0.93      0.93       250
# weighted avg       0.94      0.94      0.94       250
#
# --------------------------------------------------
# Iteration 333: Accuracy: 0.9414, F1 Micro: 0.9414, F1 Macro: 0.8905
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.92      1.00      0.96        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.95      0.88      0.91        24
#
#     accuracy                           0.98       216
#    macro avg       0.95      0.96      0.95       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.75      0.80        16
#      neutral       0.93      0.98      0.96       167
#     positive       0.77      0.61      0.68        33
#
#     accuracy                           0.91       216
#    macro avg       0.85      0.78      0.81       216
# weighted avg       0.90      0.91      0.90       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.75      0.75        12
#      neutral       0.91      0.91      0.91       152
#     positive       0.78      0.77      0.78        52
#
#     accuracy                           0.87       216
#    macro avg       0.81      0.81      0.81       216
# weighted avg       0.87      0.87      0.87       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.79      0.83      0.81        23
#      neutral       0.93      0.99      0.96       152
#     positive       0.97      0.71      0.82        41
#
#     accuracy                           0.92       216
#    macro avg       0.89      0.84      0.86       216
# weighted avg       0.92      0.92      0.91       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.85      0.88        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.88      0.88      0.88        17
#
#     accuracy                           0.98       216
#    macro avg       0.93      0.91      0.92       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.99      1.00      1.00       185
#     positive       1.00      1.00      1.00        17
#
#     accuracy                           1.00       216
#    macro avg       1.00      0.98      0.99       216
# weighted avg       1.00      1.00      1.00       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.594052314758301
# Samples above threshold: 54
# Acquired samples: 54
# Sampling duration: 13.725094556808472 seconds
# New train size: 387
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.307677984237671 | ACCURACY: 0.7969 | F1 MACRO: 0.8838 | F1 MICRO: 0.8855
# EPOCH 2 | LOSS: 2.1282572746276855 | ACCURACY: 0.8229 | F1 MACRO: 0.8962 | F1 MICRO: 0.8978
# EPOCH 3 | LOSS: 1.9980757236480713 | ACCURACY: 0.8839 | F1 MACRO: 0.9296 | F1 MICRO: 0.9306
# EPOCH 4 | LOSS: 1.9310026168823242 | ACCURACY: 0.9375 | F1 MACRO: 0.9597 | F1 MICRO: 0.9613
# EPOCH 5 | LOSS: 1.8590242862701416 | ACCURACY: 0.9509 | F1 MACRO: 0.968 | F1 MICRO: 0.9695
# EPOCH 6 | LOSS: 1.752389669418335 | ACCURACY: 0.9472 | F1 MACRO: 0.9655 | F1 MICRO: 0.9673
# EPOCH 7 | LOSS: 1.6986297369003296 | ACCURACY: 0.939 | F1 MACRO: 0.9578 | F1 MICRO: 0.9618
# EPOCH 8 | LOSS: 1.6343320608139038 | ACCURACY: 0.9449 | F1 MACRO: 0.9627 | F1 MICRO: 0.9655
# EPOCH 9 | LOSS: 1.5765353441238403 | ACCURACY: 0.9539 | F1 MACRO: 0.9687 | F1 MICRO: 0.9711
# EPOCH 10 | LOSS: 1.567923665046692 | ACCURACY: 0.9554 | F1 MACRO: 0.9697 | F1 MICRO: 0.972
# aspect: ACCURACY 0.9554 | F1 MACRO 0.9697 | F1 MICRO 0.972
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.95      1.00      0.97       175
#       others       0.92      0.91      0.91       158
#         part       0.93      0.97      0.95       158
#        price       0.98      1.00      0.99       192
#      service       0.99      1.00      1.00       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.96      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 5.789963722229004 | ACCURACY: 0.884 | F1 MACRO: 0.875 | F1 MICRO: 0.884
# EPOCH 2 | LOSS: 4.94840145111084 | ACCURACY: 0.924 | F1 MACRO: 0.9141 | F1 MICRO: 0.924
# EPOCH 3 | LOSS: 4.494307994842529 | ACCURACY: 0.924 | F1 MACRO: 0.9156 | F1 MICRO: 0.924
# EPOCH 4 | LOSS: 4.209171295166016 | ACCURACY: 0.924 | F1 MACRO: 0.9173 | F1 MICRO: 0.924
# EPOCH 5 | LOSS: 3.9560868740081787 | ACCURACY: 0.924 | F1 MACRO: 0.9177 | F1 MICRO: 0.924
# EPOCH 6 | LOSS: 3.8869035243988037 | ACCURACY: 0.928 | F1 MACRO: 0.9207 | F1 MICRO: 0.928
# EPOCH 7 | LOSS: 3.7794461250305176 | ACCURACY: 0.92 | F1 MACRO: 0.9093 | F1 MICRO: 0.92
# EPOCH 8 | LOSS: 3.5539941787719727 | ACCURACY: 0.928 | F1 MACRO: 0.9215 | F1 MICRO: 0.928
# EPOCH 9 | LOSS: 3.5913429260253906 | ACCURACY: 0.924 | F1 MACRO: 0.9177 | F1 MICRO: 0.924
# EPOCH 10 | LOSS: 3.501711368560791 | ACCURACY: 0.924 | F1 MACRO: 0.9173 | F1 MICRO: 0.924
# sentiment: ACCURACY 0.928 | F1 MACRO 0.9215 | F1 MICRO 0.928
#               precision    recall  f1-score   support
#
#     negative       0.83      0.98      0.90        82
#     positive       0.99      0.90      0.94       168
#
#     accuracy                           0.93       250
#    macro avg       0.91      0.94      0.92       250
# weighted avg       0.94      0.93      0.93       250
#
# --------------------------------------------------
# Iteration 387: Accuracy: 0.9437, F1 Micro: 0.9437, F1 Macro: 0.8898
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.85      1.00      0.92        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.95      0.83      0.89        24
#
#     accuracy                           0.98       216
#    macro avg       0.93      0.94      0.93       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.94      0.88        16
#      neutral       0.94      0.99      0.97       167
#     positive       0.95      0.64      0.76        33
#
#     accuracy                           0.94       216
#    macro avg       0.91      0.86      0.87       216
# weighted avg       0.94      0.94      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.60      0.75      0.67        12
#      neutral       0.92      0.93      0.92       152
#     positive       0.81      0.73      0.77        52
#
#     accuracy                           0.87       216
#    macro avg       0.77      0.80      0.79       216
# weighted avg       0.87      0.87      0.87       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.78      0.91      0.84        23
#      neutral       0.93      0.97      0.95       152
#     positive       0.93      0.66      0.77        41
#
#     accuracy                           0.91       216
#    macro avg       0.88      0.85      0.85       216
# weighted avg       0.91      0.91      0.90       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.92      0.92        13
#      neutral       0.99      1.00      0.99       186
#     positive       0.93      0.82      0.87        17
#
#     accuracy                           0.98       216
#    macro avg       0.95      0.92      0.93       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.93      0.93        14
#      neutral       0.99      1.00      1.00       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       0.97      0.96      0.97       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.597887897491455
# Samples above threshold: 48
# Acquired samples: 48
# Sampling duration: 14.766054630279541 seconds
# New train size: 435
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.2674436569213867 | ACCURACY: 0.8021 | F1 MACRO: 0.8866 | F1 MICRO: 0.8882
# EPOCH 2 | LOSS: 2.028820037841797 | ACCURACY: 0.8341 | F1 MACRO: 0.9035 | F1 MICRO: 0.9047
# EPOCH 3 | LOSS: 1.9154112339019775 | ACCURACY: 0.9189 | F1 MACRO: 0.9496 | F1 MICRO: 0.9508
# EPOCH 4 | LOSS: 1.8718386888504028 | ACCURACY: 0.9323 | F1 MACRO: 0.9554 | F1 MICRO: 0.9579
# EPOCH 5 | LOSS: 1.7521648406982422 | ACCURACY: 0.9457 | F1 MACRO: 0.9643 | F1 MICRO: 0.9662
# EPOCH 6 | LOSS: 1.6799153089523315 | ACCURACY: 0.9464 | F1 MACRO: 0.9642 | F1 MICRO: 0.9666
# EPOCH 7 | LOSS: 1.6111680269241333 | ACCURACY: 0.9516 | F1 MACRO: 0.9679 | F1 MICRO: 0.9698
# EPOCH 8 | LOSS: 1.5447906255722046 | ACCURACY: 0.9487 | F1 MACRO: 0.966 | F1 MICRO: 0.968
# EPOCH 9 | LOSS: 1.5062247514724731 | ACCURACY: 0.9554 | F1 MACRO: 0.9697 | F1 MICRO: 0.972
# EPOCH 10 | LOSS: 1.4646157026290894 | ACCURACY: 0.9583 | F1 MACRO: 0.9722 | F1 MICRO: 0.9739
# aspect: ACCURACY 0.9583 | F1 MACRO 0.9722 | F1 MICRO 0.9739
#               precision    recall  f1-score   support
#
#         fuel       0.98      0.99      0.99       187
#      machine       0.95      0.99      0.97       175
#       others       0.91      0.94      0.92       158
#         part       0.96      0.97      0.97       158
#        price       0.98      1.00      0.99       192
#      service       0.99      1.00      1.00       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.96      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 5.295435905456543 | ACCURACY: 0.9073 | F1 MACRO: 0.8968 | F1 MICRO: 0.9073
# EPOCH 2 | LOSS: 4.46217679977417 | ACCURACY: 0.9355 | F1 MACRO: 0.928 | F1 MICRO: 0.9355
# EPOCH 3 | LOSS: 3.9620048999786377 | ACCURACY: 0.9315 | F1 MACRO: 0.9237 | F1 MICRO: 0.9315
# EPOCH 4 | LOSS: 3.715308666229248 | ACCURACY: 0.9274 | F1 MACRO: 0.919 | F1 MICRO: 0.9274
# EPOCH 5 | LOSS: 3.5770885944366455 | ACCURACY: 0.9234 | F1 MACRO: 0.9137 | F1 MICRO: 0.9234
# EPOCH 6 | LOSS: 3.4641573429107666 | ACCURACY: 0.9194 | F1 MACRO: 0.91 | F1 MICRO: 0.9194
# EPOCH 7 | LOSS: 3.3534772396087646 | ACCURACY: 0.9476 | F1 MACRO: 0.9417 | F1 MICRO: 0.9476
# EPOCH 8 | LOSS: 3.2725789546966553 | ACCURACY: 0.9355 | F1 MACRO: 0.9288 | F1 MICRO: 0.9355
# EPOCH 9 | LOSS: 3.284468173980713 | ACCURACY: 0.9355 | F1 MACRO: 0.9288 | F1 MICRO: 0.9355
# EPOCH 10 | LOSS: 3.229820489883423 | ACCURACY: 0.9274 | F1 MACRO: 0.9203 | F1 MICRO: 0.9274
# sentiment: ACCURACY 0.9476 | F1 MACRO 0.9417 | F1 MICRO 0.9476
#               precision    recall  f1-score   support
#
#     negative       0.90      0.95      0.92        82
#     positive       0.98      0.95      0.96       166
#
#     accuracy                           0.95       248
#    macro avg       0.94      0.95      0.94       248
# weighted avg       0.95      0.95      0.95       248
#
# --------------------------------------------------
# Iteration 435: Accuracy: 0.9498, F1 Micro: 0.9498, F1 Macro: 0.9096
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.97      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.75      0.83        16
#      neutral       0.93      0.99      0.96       167
#     positive       0.85      0.67      0.75        33
#
#     accuracy                           0.92       216
#    macro avg       0.90      0.80      0.84       216
# weighted avg       0.92      0.92      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.69      0.75      0.72        12
#      neutral       0.92      0.95      0.93       152
#     positive       0.85      0.75      0.80        52
#
#     accuracy                           0.89       216
#    macro avg       0.82      0.82      0.82       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.81      0.96      0.88        23
#      neutral       0.94      0.97      0.95       152
#     positive       0.94      0.71      0.81        41
#
#     accuracy                           0.92       216
#    macro avg       0.90      0.88      0.88       216
# weighted avg       0.92      0.92      0.92       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.92      0.96        13
#      neutral       0.99      1.00      0.99       186
#     positive       0.94      0.88      0.91        17
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.94      0.95       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.99      1.00      1.00       185
#     positive       1.00      1.00      1.00        17
#
#     accuracy                           1.00       216
#    macro avg       1.00      0.98      0.99       216
# weighted avg       1.00      1.00      1.00       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.5262059211730956
# Samples above threshold: 43
# Acquired samples: 43
# Sampling duration: 15.524973392486572 seconds
# New train size: 478
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.2336790561676025 | ACCURACY: 0.8028 | F1 MACRO: 0.8865 | F1 MICRO: 0.8881
# EPOCH 2 | LOSS: 2.011939287185669 | ACCURACY: 0.8207 | F1 MACRO: 0.8965 | F1 MICRO: 0.8978
# EPOCH 3 | LOSS: 1.9166269302368164 | ACCURACY: 0.9115 | F1 MACRO: 0.9449 | F1 MICRO: 0.9461
# EPOCH 4 | LOSS: 1.8623244762420654 | ACCURACY: 0.9442 | F1 MACRO: 0.9637 | F1 MICRO: 0.9653
# EPOCH 5 | LOSS: 1.756890892982483 | ACCURACY: 0.9472 | F1 MACRO: 0.965 | F1 MICRO: 0.967
# EPOCH 6 | LOSS: 1.654133915901184 | ACCURACY: 0.9487 | F1 MACRO: 0.966 | F1 MICRO: 0.968
# EPOCH 7 | LOSS: 1.5937285423278809 | ACCURACY: 0.9516 | F1 MACRO: 0.9678 | F1 MICRO: 0.9698
# EPOCH 8 | LOSS: 1.539826512336731 | ACCURACY: 0.9531 | F1 MACRO: 0.9681 | F1 MICRO: 0.9704
# EPOCH 9 | LOSS: 1.5156511068344116 | ACCURACY: 0.9501 | F1 MACRO: 0.966 | F1 MICRO: 0.9686
# EPOCH 10 | LOSS: 1.4525755643844604 | ACCURACY: 0.9539 | F1 MACRO: 0.9693 | F1 MICRO: 0.9711
# aspect: ACCURACY 0.9539 | F1 MACRO 0.9693 | F1 MICRO 0.9711
#               precision    recall  f1-score   support
#
#         fuel       0.98      0.99      0.99       187
#      machine       0.94      0.99      0.96       175
#       others       0.91      0.92      0.91       158
#         part       0.95      0.99      0.97       158
#        price       0.98      0.99      0.99       192
#      service       0.99      1.00      1.00       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.96      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 4.754056930541992 | ACCURACY: 0.8645 | F1 MACRO: 0.8358 | F1 MICRO: 0.8645
# EPOCH 2 | LOSS: 4.1078362464904785 | ACCURACY: 0.9402 | F1 MACRO: 0.9331 | F1 MICRO: 0.9402
# EPOCH 3 | LOSS: 3.737328290939331 | ACCURACY: 0.9323 | F1 MACRO: 0.925 | F1 MICRO: 0.9323
# EPOCH 4 | LOSS: 3.398029327392578 | ACCURACY: 0.9283 | F1 MACRO: 0.9224 | F1 MICRO: 0.9283
# EPOCH 5 | LOSS: 3.229802370071411 | ACCURACY: 0.9442 | F1 MACRO: 0.9397 | F1 MICRO: 0.9442
# EPOCH 6 | LOSS: 3.2268269062042236 | ACCURACY: 0.9323 | F1 MACRO: 0.925 | F1 MICRO: 0.9323
# EPOCH 7 | LOSS: 3.0907607078552246 | ACCURACY: 0.9363 | F1 MACRO: 0.9276 | F1 MICRO: 0.9363
# EPOCH 8 | LOSS: 2.95088267326355 | ACCURACY: 0.9402 | F1 MACRO: 0.9346 | F1 MICRO: 0.9402
# EPOCH 9 | LOSS: 2.975299596786499 | ACCURACY: 0.9402 | F1 MACRO: 0.9346 | F1 MICRO: 0.9402
# EPOCH 10 | LOSS: 2.920199394226074 | ACCURACY: 0.9363 | F1 MACRO: 0.9288 | F1 MICRO: 0.9363
# sentiment: ACCURACY 0.9442 | F1 MACRO 0.9397 | F1 MICRO 0.9442
#               precision    recall  f1-score   support
#
#     negative       0.87      0.99      0.92        85
#     positive       0.99      0.92      0.96       166
#
#     accuracy                           0.94       251
#    macro avg       0.93      0.95      0.94       251
# weighted avg       0.95      0.94      0.95       251
#
# --------------------------------------------------
# Iteration 478: Accuracy: 0.9483, F1 Micro: 0.9483, F1 Macro: 0.9029
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.92      1.00      0.96        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.95      0.88      0.91        24
#
#     accuracy                           0.98       216
#    macro avg       0.95      0.96      0.95       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.94      0.88        16
#      neutral       0.93      0.99      0.96       167
#     positive       0.95      0.58      0.72        33
#
#     accuracy                           0.93       216
#    macro avg       0.91      0.84      0.85       216
# weighted avg       0.93      0.93      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.71      0.83      0.77        12
#      neutral       0.93      0.93      0.93       152
#     positive       0.82      0.77      0.79        52
#
#     accuracy                           0.89       216
#    macro avg       0.82      0.85      0.83       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.82      1.00      0.90        23
#      neutral       0.94      0.99      0.96       152
#     positive       0.96      0.66      0.78        41
#
#     accuracy                           0.93       216
#    macro avg       0.91      0.88      0.88       216
# weighted avg       0.93      0.93      0.92       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.92      0.92        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.88      0.88      0.88        17
#
#     accuracy                           0.98       216
#    macro avg       0.93      0.93      0.93       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.93      0.93        14
#      neutral       0.99      1.00      1.00       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       0.97      0.96      0.97       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.4175467491149902
# Samples above threshold: 39
# Acquired samples: 39
# Sampling duration: 16.309242725372314 seconds
# New train size: 517
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.271331310272217 | ACCURACY: 0.8192 | F1 MACRO: 0.8942 | F1 MICRO: 0.8958
# EPOCH 2 | LOSS: 2.0433671474456787 | ACCURACY: 0.8519 | F1 MACRO: 0.911 | F1 MICRO: 0.9127
# EPOCH 3 | LOSS: 1.9640880823135376 | ACCURACY: 0.9323 | F1 MACRO: 0.9576 | F1 MICRO: 0.9585
# EPOCH 4 | LOSS: 1.8436927795410156 | ACCURACY: 0.9397 | F1 MACRO: 0.9601 | F1 MICRO: 0.9625
# EPOCH 5 | LOSS: 1.7200580835342407 | ACCURACY: 0.9464 | F1 MACRO: 0.9645 | F1 MICRO: 0.9667
# EPOCH 6 | LOSS: 1.6510828733444214 | ACCURACY: 0.9546 | F1 MACRO: 0.97 | F1 MICRO: 0.9717
# EPOCH 7 | LOSS: 1.5933575630187988 | ACCURACY: 0.9516 | F1 MACRO: 0.9676 | F1 MICRO: 0.9696
# EPOCH 8 | LOSS: 1.548289179801941 | ACCURACY: 0.9546 | F1 MACRO: 0.9695 | F1 MICRO: 0.9715
# EPOCH 9 | LOSS: 1.4992163181304932 | ACCURACY: 0.9442 | F1 MACRO: 0.9606 | F1 MICRO: 0.9646
# EPOCH 10 | LOSS: 1.4776018857955933 | ACCURACY: 0.9531 | F1 MACRO: 0.9686 | F1 MICRO: 0.9706
# aspect: ACCURACY 0.9546 | F1 MACRO 0.97 | F1 MICRO 0.9717
# ...
#
#    micro avg       0.97      0.98      0.97      1061
#    macro avg       0.97      0.98      0.97      1061
# weighted avg       0.97      0.98      0.97      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 2.930239200592041 | ACCURACY: 0.9064 | F1 MACRO: 0.8872 | F1 MICRO: 0.9064
# EPOCH 2 | LOSS: 2.4885809421539307 | ACCURACY: 0.9213 | F1 MACRO: 0.9046 | F1 MICRO: 0.9213
# EPOCH 3 | LOSS: 2.252214193344116 | ACCURACY: 0.9401 | F1 MACRO: 0.9314 | F1 MICRO: 0.9401
# EPOCH 4 | LOSS: 2.089815378189087 | ACCURACY: 0.9288 | F1 MACRO: 0.9197 | F1 MICRO: 0.9288
# EPOCH 5 | LOSS: 1.9574799537658691 | ACCURACY: 0.9176 | F1 MACRO: 0.9088 | F1 MICRO: 0.9176
# EPOCH 6 | LOSS: 1.9465994834899902 | ACCURACY: 0.9438 | F1 MACRO: 0.9355 | F1 MICRO: 0.9438
# EPOCH 7 | LOSS: 1.8622119426727295 | ACCURACY: 0.9213 | F1 MACRO: 0.9108 | F1 MICRO: 0.9213
# EPOCH 8 | LOSS: 1.8800442218780518 | ACCURACY: 0.9326 | F1 MACRO: 0.9218 | F1 MICRO: 0.9326
# EPOCH 9 | LOSS: 1.7994381189346313 | ACCURACY: 0.9288 | F1 MACRO: 0.9193 | F1 MICRO: 0.9288
# EPOCH 10 | LOSS: 1.7895458936691284 | ACCURACY: 0.9326 | F1 MACRO: 0.9237 | F1 MICRO: 0.9326
# sentiment: ACCURACY 0.9438 | F1 MACRO 0.9355 | F1 MICRO 0.9438
#               precision    recall  f1-score   support
#
#     negative       0.88      0.95      0.91        82
#     positive       0.98      0.94      0.96       185
#
#     accuracy                           0.94       267
#    macro avg       0.93      0.95      0.94       267
# weighted avg       0.95      0.94      0.94       267
#
# --------------------------------------------------
# Iteration 831: Accuracy: 0.9452, F1 Micro: 0.9452, F1 Macro: 0.8948
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.92      1.00      0.96        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.95      0.88      0.91        24
#
#     accuracy                           0.98       216
#    macro avg       0.95      0.96      0.95       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.69      0.76        16
#      neutral       0.93      0.99      0.96       167
#     positive       0.88      0.67      0.76        33
#
#     accuracy                           0.92       216
#    macro avg       0.89      0.78      0.83       216
# weighted avg       0.92      0.92      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.75      0.75        12
#      neutral       0.93      0.89      0.91       152
#     positive       0.72      0.81      0.76        52
#
#     accuracy                           0.87       216
#    macro avg       0.80      0.82      0.81       216
# weighted avg       0.87      0.87      0.87       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.77      1.00      0.87        23
#      neutral       0.98      0.97      0.97       152
#     positive       0.92      0.80      0.86        41
#
#     accuracy                           0.94       216
#    macro avg       0.89      0.92      0.90       216
# weighted avg       0.95      0.94      0.94       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.85      0.88        13
#      neutral       0.98      0.99      0.99       186
#     positive       0.88      0.88      0.88        17
#
#     accuracy                           0.97       216
#    macro avg       0.93      0.91      0.92       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.99      1.00      1.00       185
#     positive       0.94      1.00      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.95      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 864
# Threshold: 2.529405212402344
# Samples above threshold: 4
# Acquired samples: 25
# Sampling duration: 21.655000686645508 seconds
# New train size: 856
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.13893985748291 | ACCURACY: 0.8147 | F1 MACRO: 0.8929 | F1 MICRO: 0.8944
# EPOCH 2 | LOSS: 1.903826117515564 | ACCURACY: 0.9338 | F1 MACRO: 0.9561 | F1 MICRO: 0.9586
# EPOCH 3 | LOSS: 1.779728651046753 | ACCURACY: 0.9516 | F1 MACRO: 0.9683 | F1 MICRO: 0.9699
# EPOCH 4 | LOSS: 1.6459375619888306 | ACCURACY: 0.9576 | F1 MACRO: 0.9719 | F1 MICRO: 0.9735
# EPOCH 5 | LOSS: 1.5607948303222656 | ACCURACY: 0.9628 | F1 MACRO: 0.9749 | F1 MICRO: 0.9765
# EPOCH 6 | LOSS: 1.490774154663086 | ACCURACY: 0.9606 | F1 MACRO: 0.9734 | F1 MICRO: 0.9751
# EPOCH 7 | LOSS: 1.4421013593673706 | ACCURACY: 0.9583 | F1 MACRO: 0.9723 | F1 MICRO: 0.9738
# EPOCH 8 | LOSS: 1.384653925895691 | ACCURACY: 0.9591 | F1 MACRO: 0.9719 | F1 MICRO: 0.974
# EPOCH 9 | LOSS: 1.3480350971221924 | ACCURACY: 0.9598 | F1 MACRO: 0.9736 | F1 MICRO: 0.9748
# EPOCH 10 | LOSS: 1.3388636112213135 | ACCURACY: 0.9628 | F1 MACRO: 0.9751 | F1 MICRO: 0.9765
# aspect: ACCURACY 0.9628 | F1 MACRO 0.9751 | F1 MICRO 0.9765
#               precision    recall  f1-score   support
#
#         fuel       0.98      0.99      0.99       187
#      machine       0.95      0.98      0.96       175
#       others       0.95      0.92      0.93       158
#         part       0.98      0.98      0.98       158
#        price       0.98      0.99      0.99       192
#      service       0.99      1.00      1.00       191
#
#    micro avg       0.97      0.98      0.98      1061
#    macro avg       0.97      0.98      0.98      1061
# weighted avg       0.97      0.98      0.98      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 2.786994695663452 | ACCURACY: 0.9228 | F1 MACRO: 0.9131 | F1 MICRO: 0.9228
# EPOCH 2 | LOSS: 2.4203708171844482 | ACCURACY: 0.9228 | F1 MACRO: 0.9144 | F1 MICRO: 0.9228
# EPOCH 3 | LOSS: 2.1692984104156494 | ACCURACY: 0.9412 | F1 MACRO: 0.9311 | F1 MICRO: 0.9412
# EPOCH 4 | LOSS: 1.9427735805511475 | ACCURACY: 0.9265 | F1 MACRO: 0.9179 | F1 MICRO: 0.9265
# EPOCH 5 | LOSS: 1.8878438472747803 | ACCURACY: 0.9044 | F1 MACRO: 0.8954 | F1 MICRO: 0.9044
# EPOCH 6 | LOSS: 1.9097840785980225 | ACCURACY: 0.9375 | F1 MACRO: 0.9288 | F1 MICRO: 0.9375
# EPOCH 7 | LOSS: 1.8231453895568848 | ACCURACY: 0.9559 | F1 MACRO: 0.948 | F1 MICRO: 0.9559
# EPOCH 8 | LOSS: 1.7936489582061768 | ACCURACY: 0.9522 | F1 MACRO: 0.9456 | F1 MICRO: 0.9522
# EPOCH 9 | LOSS: 1.7167935371398926 | ACCURACY: 0.9375 | F1 MACRO: 0.9288 | F1 MICRO: 0.9375
# EPOCH 10 | LOSS: 1.718658208847046 | ACCURACY: 0.9375 | F1 MACRO: 0.9288 | F1 MICRO: 0.9375
# sentiment: ACCURACY 0.9559 | F1 MACRO 0.948 | F1 MICRO 0.9559
#               precision    recall  f1-score   support
#
#     negative       0.95      0.91      0.93        85
#     positive       0.96      0.98      0.97       187
#
#     accuracy                           0.96       272
#    macro avg       0.95      0.94      0.95       272
# weighted avg       0.96      0.96      0.96       272
#
# --------------------------------------------------
# Iteration 856: Accuracy: 0.9599, F1 Micro: 0.9599, F1 Macro: 0.9314
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.97      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.88      0.90        16
#      neutral       0.96      0.98      0.97       167
#     positive       0.84      0.82      0.83        33
#
#     accuracy                           0.94       216
#    macro avg       0.91      0.89      0.90       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.83      0.91        12
#      neutral       0.93      0.92      0.93       152
#     positive       0.79      0.85      0.81        52
#
#     accuracy                           0.90       216
#    macro avg       0.91      0.87      0.88       216
# weighted avg       0.90      0.90      0.90       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.96      0.94        23
#      neutral       0.98      0.98      0.98       152
#     positive       0.93      0.90      0.91        41
#
#     accuracy                           0.96       216
#    macro avg       0.94      0.95      0.94       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.85      0.88        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.84      0.94      0.89        17
#
#     accuracy                           0.98       216
#    macro avg       0.92      0.93      0.92       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.99      1.00      1.00       185
#     positive       0.94      1.00      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.95      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 864
# Threshold: 2.436022686958313
# Samples above threshold: 1
# Acquired samples: 8
# Sampling duration: 22.79740619659424 seconds
# New train size: 864
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.146637439727783 | ACCURACY: 0.8103 | F1 MACRO: 0.8909 | F1 MICRO: 0.8925
# EPOCH 2 | LOSS: 1.9082932472229004 | ACCURACY: 0.9375 | F1 MACRO: 0.9593 | F1 MICRO: 0.9611
# EPOCH 3 | LOSS: 1.771404504776001 | ACCURACY: 0.9494 | F1 MACRO: 0.9669 | F1 MICRO: 0.9685
# EPOCH 4 | LOSS: 1.6549352407455444 | ACCURACY: 0.9621 | F1 MACRO: 0.9754 | F1 MICRO: 0.9764
# EPOCH 5 | LOSS: 1.5597339868545532 | ACCURACY: 0.9606 | F1 MACRO: 0.9739 | F1 MICRO: 0.9753
# EPOCH 6 | LOSS: 1.4883400201797485 | ACCURACY: 0.9583 | F1 MACRO: 0.9722 | F1 MICRO: 0.9737
# EPOCH 7 | LOSS: 1.436292290687561 | ACCURACY: 0.9613 | F1 MACRO: 0.9744 | F1 MICRO: 0.9757
# EPOCH 8 | LOSS: 1.4054296016693115 | ACCURACY: 0.9598 | F1 MACRO: 0.9729 | F1 MICRO: 0.9746
# EPOCH 9 | LOSS: 1.3571693897247314 | ACCURACY: 0.9539 | F1 MACRO: 0.9688 | F1 MICRO: 0.9709
# EPOCH 10 | LOSS: 1.3192222118377686 | ACCURACY: 0.9628 | F1 MACRO: 0.9753 | F1 MICRO: 0.9766
# aspect: ACCURACY 0.9628 | F1 MACRO 0.9753 | F1 MICRO 0.9766
#               precision    recall  f1-score   support
#
#         fuel       0.98      0.99      0.99       187
#      machine       0.94      0.99      0.96       175
#       others       0.93      0.94      0.93       158
#         part       0.97      0.98      0.97       158
#        price       0.98      0.99      0.99       192
#      service       1.00      1.00      1.00       191
#
#    micro avg       0.97      0.98      0.98      1061
#    macro avg       0.97      0.98      0.98      1061
# weighted avg       0.97      0.98      0.98      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 2.778221607208252 | ACCURACY: 0.9208 | F1 MACRO: 0.9114 | F1 MICRO: 0.9208
# EPOCH 2 | LOSS: 2.462538957595825 | ACCURACY: 0.9245 | F1 MACRO: 0.9163 | F1 MICRO: 0.9245
# EPOCH 3 | LOSS: 2.136725425720215 | ACCURACY: 0.9472 | F1 MACRO: 0.9394 | F1 MICRO: 0.9472
# EPOCH 4 | LOSS: 1.978213906288147 | ACCURACY: 0.9358 | F1 MACRO: 0.9287 | F1 MICRO: 0.9358
# EPOCH 5 | LOSS: 1.9472280740737915 | ACCURACY: 0.9434 | F1 MACRO: 0.9364 | F1 MICRO: 0.9434
# EPOCH 6 | LOSS: 1.8930785655975342 | ACCURACY: 0.9472 | F1 MACRO: 0.9394 | F1 MICRO: 0.9472
# EPOCH 7 | LOSS: 1.8177382946014404 | ACCURACY: 0.9434 | F1 MACRO: 0.934 | F1 MICRO: 0.9434
# EPOCH 8 | LOSS: 1.8102753162384033 | ACCURACY: 0.9358 | F1 MACRO: 0.9287 | F1 MICRO: 0.9358
# EPOCH 9 | LOSS: 1.7698777914047241 | ACCURACY: 0.9547 | F1 MACRO: 0.9477 | F1 MICRO: 0.9547
# EPOCH 10 | LOSS: 1.6837552785873413 | ACCURACY: 0.9245 | F1 MACRO: 0.9168 | F1 MICRO: 0.9245
# sentiment: ACCURACY 0.9547 | F1 MACRO 0.9477 | F1 MICRO 0.9547
#               precision    recall  f1-score   support
#
#     negative       0.93      0.93      0.93        84
#     positive       0.97      0.97      0.97       181
#
#     accuracy                           0.95       265
#    macro avg       0.95      0.95      0.95       265
# weighted avg       0.95      0.95      0.95       265
#
# --------------------------------------------------
# Iteration 864: Accuracy: 0.9568, F1 Micro: 0.9568, F1 Macro: 0.9217
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.96      0.96      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.98      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.75      0.80        16
#      neutral       0.95      0.98      0.97       167
#     positive       0.87      0.79      0.83        33
#
#     accuracy                           0.94       216
#    macro avg       0.89      0.84      0.86       216
# weighted avg       0.93      0.94      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.83      0.91        12
#      neutral       0.92      0.93      0.93       152
#     positive       0.81      0.81      0.81        52
#
#     accuracy                           0.90       216
#    macro avg       0.91      0.86      0.88       216
# weighted avg       0.90      0.90      0.90       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.82      1.00      0.90        23
#      neutral       0.97      0.98      0.98       152
#     positive       0.94      0.80      0.87        41
#
#     accuracy                           0.95       216
#    macro avg       0.91      0.93      0.92       216
# weighted avg       0.95      0.95      0.95       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.85      0.85        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.88      0.88      0.88        17
#
#     accuracy                           0.97       216
#    macro avg       0.91      0.91      0.91       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       1.00      1.00      1.00       185
#     positive       0.94      1.00      0.97        17
#
#     accuracy                           1.00       216
#    macro avg       0.98      0.98      0.98       216
# weighted avg       1.00      1.00      1.00       216
#
# Total sampling time: 398.61 seconds
# Total runtime: 3559.802982568741 seconds

# %% [markdown]
# ## RUN 5

# %%
active_learning(seeds[4], 4)
# Out:
# ===============================================
# TRIAL 5
# Random seed: 94
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.497373580932617 | ACCURACY: 0.6421 | F1 MACRO: 0.7118 | F1 MICRO: 0.7611
# EPOCH 2 | LOSS: 2.349304676055908 | ACCURACY: 0.7783 | F1 MACRO: 0.8695 | F1 MICRO: 0.8733
# EPOCH 3 | LOSS: 2.2493953704833984 | ACCURACY: 0.7842 | F1 MACRO: 0.8765 | F1 MICRO: 0.8787
# EPOCH 4 | LOSS: 2.32956600189209 | ACCURACY: 0.7909 | F1 MACRO: 0.8808 | F1 MICRO: 0.8826
# EPOCH 5 | LOSS: 2.2326745986938477 | ACCURACY: 0.7887 | F1 MACRO: 0.8789 | F1 MICRO: 0.881
# EPOCH 6 | LOSS: 2.120467185974121 | ACCURACY: 0.7835 | F1 MACRO: 0.8741 | F1 MICRO: 0.8771
# EPOCH 7 | LOSS: 2.098897933959961 | ACCURACY: 0.7746 | F1 MACRO: 0.8644 | F1 MICRO: 0.8696
# EPOCH 8 | LOSS: 2.1051363945007324 | ACCURACY: 0.756 | F1 MACRO: 0.8459 | F1 MICRO: 0.856
# EPOCH 9 | LOSS: 2.0498454570770264 | ACCURACY: 0.753 | F1 MACRO: 0.838 | F1 MICRO: 0.8531
# EPOCH 10 | LOSS: 2.0569725036621094 | ACCURACY: 0.756 | F1 MACRO: 0.8426 | F1 MICRO: 0.8545
# aspect: ACCURACY 0.7909 | F1 MACRO 0.8808 | F1 MICRO 0.8826
#               precision    recall  f1-score   support
#
#         fuel       0.83      1.00      0.91       187
#      machine       0.78      1.00      0.88       175
#       others       0.71      1.00      0.83       158
#         part       0.72      0.97      0.83       158
#        price       0.86      1.00      0.92       192
#      service       0.85      1.00      0.92       191
#
#    micro avg       0.79      1.00      0.88      1061
#    macro avg       0.79      0.99      0.88      1061
# weighted avg       0.80      1.00      0.88      1061
#  samples avg       0.79      1.00      0.88      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 2.3588268756866455 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# EPOCH 2 | LOSS: 2.1165332794189453 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# EPOCH 3 | LOSS: 2.079097032546997 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# EPOCH 4 | LOSS: 2.1182808876037598 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# EPOCH 5 | LOSS: 1.9011080265045166 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# EPOCH 6 | LOSS: 1.9617512226104736 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# EPOCH 7 | LOSS: 1.8013947010040283 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# EPOCH 8 | LOSS: 1.9254977703094482 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# EPOCH 9 | LOSS: 1.8662495613098145 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# EPOCH 10 | LOSS: 1.8784759044647217 | ACCURACY: 0.8889 | F1 MACRO: 0.4706 | F1 MICRO: 0.8889
# sentiment: ACCURACY 0.8889 | F1 MACRO 0.4706 | F1 MICRO 0.8889
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00         1
#     positive       0.89      1.00      0.94         8
#
#     accuracy                           0.89         9
#    macro avg       0.44      0.50      0.47         9
# weighted avg       0.79      0.89      0.84         9
#
# --------------------------------------------------
# Iteration 54: Accuracy: 0.7863, F1 Micro: 0.7863, F1 Macro: 0.2973
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        11
#      neutral       0.84      1.00      0.91       181
#     positive       0.00      0.00      0.00        24
#
#     accuracy                           0.84       216
#    macro avg       0.28      0.33      0.30       216
# weighted avg       0.70      0.84      0.76       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        16
#      neutral       0.77      1.00      0.87       167
#     positive       0.00      0.00      0.00        33
#
#     accuracy                           0.77       216
#    macro avg       0.26      0.33      0.29       216
# weighted avg       0.60      0.77      0.67       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        12
#      neutral       0.70      1.00      0.83       152
#     positive       0.00      0.00      0.00        52
#
#     accuracy                           0.70       216
#    macro avg       0.23      0.33      0.28       216
# weighted avg       0.50      0.70      0.58       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        23
#      neutral       0.71      0.96      0.81       152
#     positive       0.22      0.05      0.08        41
#
#     accuracy                           0.69       216
#    macro avg       0.31      0.34      0.30       216
# weighted avg       0.54      0.69      0.59       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        13
#      neutral       0.86      1.00      0.93       186
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.86       216
#    macro avg       0.29      0.33      0.31       216
# weighted avg       0.74      0.86      0.80       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00        14
#      neutral       0.86      1.00      0.92       185
#     positive       0.00      0.00      0.00        17
#
#     accuracy                           0.86       216
#    macro avg       0.29      0.33      0.31       216
# weighted avg       0.73      0.86      0.79       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.7527729272842434
# Samples above threshold: 81
# Acquired samples: 81
# Sampling duration: 5.839438199996948 seconds
# New train size: 135
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.6275694370269775 | ACCURACY: 0.7894 | F1 MACRO: 0.8803 | F1 MICRO: 0.8819
# EPOCH 2 | LOSS: 2.4969966411590576 | ACCURACY: 0.7894 | F1 MACRO: 0.8801 | F1 MICRO: 0.8818
# EPOCH 3 | LOSS: 2.3656742572784424 | ACCURACY: 0.7917 | F1 MACRO: 0.8812 | F1 MICRO: 0.8829
# EPOCH 4 | LOSS: 2.2820847034454346 | ACCURACY: 0.8021 | F1 MACRO: 0.8854 | F1 MICRO: 0.8874
# EPOCH 5 | LOSS: 2.202571392059326 | ACCURACY: 0.8103 | F1 MACRO: 0.8885 | F1 MICRO: 0.8908
# EPOCH 6 | LOSS: 2.1685867309570312 | ACCURACY: 0.8311 | F1 MACRO: 0.8972 | F1 MICRO: 0.9005
# EPOCH 7 | LOSS: 2.1232657432556152 | ACCURACY: 0.8497 | F1 MACRO: 0.9045 | F1 MICRO: 0.9093
# EPOCH 8 | LOSS: 2.0815744400024414 | ACCURACY: 0.872 | F1 MACRO: 0.92 | F1 MICRO: 0.9227
# EPOCH 9 | LOSS: 2.0657920837402344 | ACCURACY: 0.8891 | F1 MACRO: 0.9279 | F1 MICRO: 0.9316
# EPOCH 10 | LOSS: 2.0671846866607666 | ACCURACY: 0.9033 | F1 MACRO: 0.9361 | F1 MICRO: 0.94
# aspect: ACCURACY 0.9033 | F1 MACRO 0.9361 | F1 MICRO 0.94
#               precision    recall  f1-score   support
#
#         fuel       0.94      1.00      0.97       187
#      machine       0.90      0.97      0.93       175
#       others       0.86      0.84      0.85       158
#         part       0.87      0.95      0.91       158
#        price       0.98      0.98      0.98       192
#      service       0.95      1.00      0.98       191
#
#    micro avg       0.92      0.96      0.94      1061
#    macro avg       0.92      0.96      0.94      1061
# weighted avg       0.92      0.96      0.94      1061
#  samples avg       0.92      0.96      0.94      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 14.236184120178223 | ACCURACY: 0.8898 | F1 MACRO: 0.8738 | F1 MICRO: 0.8898
# EPOCH 2 | LOSS: 12.833378791809082 | ACCURACY: 0.9068 | F1 MACRO: 0.894 | F1 MICRO: 0.9068
# EPOCH 3 | LOSS: 11.868359565734863 | ACCURACY: 0.9025 | F1 MACRO: 0.8895 | F1 MICRO: 0.9025
# EPOCH 4 | LOSS: 11.1016845703125 | ACCURACY: 0.9153 | F1 MACRO: 0.9001 | F1 MICRO: 0.9153
# EPOCH 5 | LOSS: 10.519679069519043 | ACCURACY: 0.8941 | F1 MACRO: 0.8691 | F1 MICRO: 0.8941
# EPOCH 6 | LOSS: 10.495494842529297 | ACCURACY: 0.911 | F1 MACRO: 0.8985 | F1 MICRO: 0.911
# EPOCH 7 | LOSS: 9.897100448608398 | ACCURACY: 0.8941 | F1 MACRO: 0.8756 | F1 MICRO: 0.8941
# EPOCH 8 | LOSS: 9.822588920593262 | ACCURACY: 0.9153 | F1 MACRO: 0.903 | F1 MICRO: 0.9153
# EPOCH 9 | LOSS: 9.4578857421875 | ACCURACY: 0.9195 | F1 MACRO: 0.9054 | F1 MICRO: 0.9195
# EPOCH 10 | LOSS: 9.370675086975098 | ACCURACY: 0.9322 | F1 MACRO: 0.9207 | F1 MICRO: 0.9322
# sentiment: ACCURACY 0.9322 | F1 MACRO 0.9207 | F1 MICRO 0.9322
#               precision    recall  f1-score   support
#
#     negative       0.86      0.93      0.89        70
#     positive       0.97      0.93      0.95       166
#
#     accuracy                           0.93       236
#    macro avg       0.91      0.93      0.92       236
# weighted avg       0.94      0.93      0.93       236
#
# --------------------------------------------------
# Iteration 135: Accuracy: 0.8974, F1 Micro: 0.8974, F1 Macro: 0.8102
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.82      0.90        11
#      neutral       0.95      1.00      0.98       181
#     positive       1.00      0.71      0.83        24
#
#     accuracy                           0.96       216
#    macro avg       0.98      0.84      0.90       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.64      0.44      0.52        16
#      neutral       0.90      0.96      0.93       167
#     positive       0.75      0.64      0.69        33
#
#     accuracy                           0.87       216
#    macro avg       0.76      0.68      0.71       216
# weighted avg       0.86      0.87      0.86       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.70      0.58      0.64        12
#      neutral       0.87      0.84      0.86       152
#     positive       0.61      0.69      0.65        52
#
#     accuracy                           0.79       216
#    macro avg       0.73      0.71      0.71       216
# weighted avg       0.80      0.79      0.79       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.81      0.74      0.77        23
#      neutral       0.86      0.95      0.90       152
#     positive       0.78      0.51      0.62        41
#
#     accuracy                           0.84       216
#    macro avg       0.81      0.73      0.76       216
# weighted avg       0.84      0.84      0.83       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.92      0.89        13
#      neutral       0.99      0.98      0.99       186
#     positive       0.82      0.82      0.82        17
#
#     accuracy                           0.97       216
#    macro avg       0.89      0.91      0.90       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.95      0.99      0.97       185
#     positive       0.91      0.59      0.71        17
#
#     accuracy                           0.95       216
#    macro avg       0.95      0.81      0.87       216
# weighted avg       0.95      0.95      0.95       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.75587158203125
# Samples above threshold: 73
# Acquired samples: 73
# Sampling duration: 10.082300901412964 seconds
# New train size: 208
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.573845386505127 | ACCURACY: 0.7894 | F1 MACRO: 0.8807 | F1 MICRO: 0.8822
# EPOCH 2 | LOSS: 2.3381967544555664 | ACCURACY: 0.7909 | F1 MACRO: 0.8814 | F1 MICRO: 0.883
# EPOCH 3 | LOSS: 2.205599546432495 | ACCURACY: 0.8192 | F1 MACRO: 0.8956 | F1 MICRO: 0.8969
# EPOCH 4 | LOSS: 2.1276614665985107 | ACCURACY: 0.8423 | F1 MACRO: 0.9066 | F1 MICRO: 0.9079
# EPOCH 5 | LOSS: 2.064800262451172 | ACCURACY: 0.8601 | F1 MACRO: 0.9153 | F1 MICRO: 0.9168
# EPOCH 6 | LOSS: 1.9724276065826416 | ACCURACY: 0.9092 | F1 MACRO: 0.9408 | F1 MICRO: 0.9439
# EPOCH 7 | LOSS: 1.985661506652832 | ACCURACY: 0.9137 | F1 MACRO: 0.9425 | F1 MICRO: 0.946
# EPOCH 8 | LOSS: 1.9505813121795654 | ACCURACY: 0.9204 | F1 MACRO: 0.9466 | F1 MICRO: 0.9504
# EPOCH 9 | LOSS: 1.8422614336013794 | ACCURACY: 0.9241 | F1 MACRO: 0.949 | F1 MICRO: 0.9524
# EPOCH 10 | LOSS: 1.8236563205718994 | ACCURACY: 0.9338 | F1 MACRO: 0.956 | F1 MICRO: 0.9587
# aspect: ACCURACY 0.9338 | F1 MACRO 0.956 | F1 MICRO 0.9587
#               precision    recall  f1-score   support
#
#         fuel       0.97      1.00      0.99       187
#      machine       0.94      1.00      0.97       175
#       others       0.89      0.87      0.88       158
#         part       0.91      0.97      0.94       158
#        price       0.98      0.97      0.98       192
#      service       0.96      1.00      0.98       191
#
#    micro avg       0.95      0.97      0.96      1061
#    macro avg       0.94      0.97      0.96      1061
# weighted avg       0.95      0.97      0.96      1061
#  samples avg       0.95      0.97      0.95      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 10.436063766479492 | ACCURACY: 0.9259 | F1 MACRO: 0.9177 | F1 MICRO: 0.9259
# EPOCH 2 | LOSS: 9.030542373657227 | ACCURACY: 0.9342 | F1 MACRO: 0.925 | F1 MICRO: 0.9342
# EPOCH 3 | LOSS: 8.251749038696289 | ACCURACY: 0.93 | F1 MACRO: 0.9229 | F1 MICRO: 0.93
# EPOCH 4 | LOSS: 7.707792282104492 | ACCURACY: 0.9383 | F1 MACRO: 0.9299 | F1 MICRO: 0.9383
# EPOCH 5 | LOSS: 7.584206581115723 | ACCURACY: 0.9342 | F1 MACRO: 0.9255 | F1 MICRO: 0.9342
# EPOCH 6 | LOSS: 7.036149978637695 | ACCURACY: 0.9259 | F1 MACRO: 0.9126 | F1 MICRO: 0.9259
# EPOCH 7 | LOSS: 6.706605911254883 | ACCURACY: 0.9465 | F1 MACRO: 0.9388 | F1 MICRO: 0.9465
# EPOCH 8 | LOSS: 6.739043235778809 | ACCURACY: 0.9383 | F1 MACRO: 0.9303 | F1 MICRO: 0.9383
# EPOCH 9 | LOSS: 6.410351753234863 | ACCURACY: 0.9383 | F1 MACRO: 0.9303 | F1 MICRO: 0.9383
# EPOCH 10 | LOSS: 6.53590726852417 | ACCURACY: 0.9465 | F1 MACRO: 0.9388 | F1 MICRO: 0.9465
# sentiment: ACCURACY 0.9465 | F1 MACRO 0.9388 | F1 MICRO 0.9465
#               precision    recall  f1-score   support
#
#     negative       0.92      0.91      0.92        79
#     positive       0.96      0.96      0.96       164
#
#     accuracy                           0.95       243
#    macro avg       0.94      0.94      0.94       243
# weighted avg       0.95      0.95      0.95       243
#
# --------------------------------------------------
# Iteration 208: Accuracy: 0.9236, F1 Micro: 0.9236, F1 Macro: 0.8611
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.98      0.99      0.99       181
#     positive       0.95      0.88      0.91        24
#
#     accuracy                           0.98       216
#    macro avg       0.98      0.93      0.95       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.62      0.74        16
#      neutral       0.93      0.99      0.96       167
#     positive       0.79      0.67      0.72        33
#
#     accuracy                           0.91       216
#    macro avg       0.88      0.76      0.81       216
# weighted avg       0.91      0.91      0.91       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.90      0.75      0.82        12
#      neutral       0.89      0.86      0.87       152
#     positive       0.62      0.69      0.65        52
#
#     accuracy                           0.81       216
#    macro avg       0.80      0.77      0.78       216
# weighted avg       0.82      0.81      0.82       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.95      0.78      0.86        23
#      neutral       0.91      1.00      0.95       152
#     positive       0.93      0.68      0.79        41
#
#     accuracy                           0.92       216
#    macro avg       0.93      0.82      0.87       216
# weighted avg       0.92      0.92      0.91       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.92      0.86        13
#      neutral       0.99      0.98      0.99       186
#     positive       0.88      0.82      0.85        17
#
#     accuracy                           0.97       216
#    macro avg       0.89      0.91      0.90       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.79      0.88        14
#      neutral       0.96      0.99      0.98       185
#     positive       0.85      0.65      0.73        17
#
#     accuracy                           0.95       216
#    macro avg       0.93      0.81      0.86       216
# weighted avg       0.95      0.95      0.95       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.580668568611145
# Samples above threshold: 66
# Acquired samples: 66
# Sampling duration: 11.462568283081055 seconds
# New train size: 274
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.3201355934143066 | ACCURACY: 0.7917 | F1 MACRO: 0.882 | F1 MICRO: 0.8834
# EPOCH 2 | LOSS: 2.1358964443206787 | ACCURACY: 0.8051 | F1 MACRO: 0.8884 | F1 MICRO: 0.8899
# EPOCH 3 | LOSS: 1.993001937866211 | ACCURACY: 0.8415 | F1 MACRO: 0.9059 | F1 MICRO: 0.9074
# EPOCH 4 | LOSS: 1.9456117153167725 | ACCURACY: 0.872 | F1 MACRO: 0.9232 | F1 MICRO: 0.924
# EPOCH 5 | LOSS: 1.889055848121643 | ACCURACY: 0.8891 | F1 MACRO: 0.9289 | F1 MICRO: 0.9319
# EPOCH 6 | LOSS: 1.8370145559310913 | ACCURACY: 0.9226 | F1 MACRO: 0.9489 | F1 MICRO: 0.9517
# EPOCH 7 | LOSS: 1.7848567962646484 | ACCURACY: 0.9323 | F1 MACRO: 0.9548 | F1 MICRO: 0.9575
# EPOCH 8 | LOSS: 1.7542282342910767 | ACCURACY: 0.9368 | F1 MACRO: 0.9582 | F1 MICRO: 0.9606
# EPOCH 9 | LOSS: 1.6444751024246216 | ACCURACY: 0.9308 | F1 MACRO: 0.9519 | F1 MICRO: 0.9565
# EPOCH 10 | LOSS: 1.6067662239074707 | ACCURACY: 0.942 | F1 MACRO: 0.9618 | F1 MICRO: 0.9638
# aspect: ACCURACY 0.942 | F1 MACRO 0.9618 | F1 MICRO 0.9638
#               precision    recall  f1-score   support
#
#         fuel       0.97      0.99      0.98       187
#      machine       0.93      1.00      0.96       175
#       others       0.89      0.91      0.90       158
#         part       0.93      0.97      0.95       158
#        price       0.99      0.98      0.98       192
#      service       0.97      1.00      0.99       191
#
#    micro avg       0.95      0.98      0.96      1061
#    macro avg       0.95      0.98      0.96      1061
# weighted avg       0.95      0.98      0.96      1061
#  samples avg       0.95      0.98      0.96      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 7.774702548980713 | ACCURACY: 0.9139 | F1 MACRO: 0.897 | F1 MICRO: 0.9139
# EPOCH 2 | LOSS: 6.7675371170043945 | ACCURACY: 0.9303 | F1 MACRO: 0.9191 | F1 MICRO: 0.9303
# EPOCH 3 | LOSS: 6.230433940887451 | ACCURACY: 0.9426 | F1 MACRO: 0.9361 | F1 MICRO: 0.9426
# EPOCH 4 | LOSS: 5.766749858856201 | ACCURACY: 0.9344 | F1 MACRO: 0.9278 | F1 MICRO: 0.9344
# EPOCH 5 | LOSS: 5.623807430267334 | ACCURACY: 0.918 | F1 MACRO: 0.9107 | F1 MICRO: 0.918
# EPOCH 6 | LOSS: 5.362307071685791 | ACCURACY: 0.9262 | F1 MACRO: 0.9196 | F1 MICRO: 0.9262
# EPOCH 7 | LOSS: 5.2058329582214355 | ACCURACY: 0.9262 | F1 MACRO: 0.914 | F1 MICRO: 0.9262
# EPOCH 8 | LOSS: 5.027973175048828 | ACCURACY: 0.9467 | F1 MACRO: 0.9394 | F1 MICRO: 0.9467
# EPOCH 9 | LOSS: 4.978943347930908 | ACCURACY: 0.9713 | F1 MACRO: 0.9678 | F1 MICRO: 0.9713
# EPOCH 10 | LOSS: 4.8942952156066895 | ACCURACY: 0.9467 | F1 MACRO: 0.9401 | F1 MICRO: 0.9467
# sentiment: ACCURACY 0.9713 | F1 MACRO 0.9678 | F1 MICRO 0.9713
#               precision    recall  f1-score   support
#
#     negative       0.93      0.99      0.96        79
#     positive       0.99      0.96      0.98       165
#
#     accuracy                           0.97       244
#    macro avg       0.96      0.98      0.97       244
# weighted avg       0.97      0.97      0.97       244
#
# --------------------------------------------------
# Iteration 274: Accuracy: 0.9452, F1 Micro: 0.9452, F1 Macro: 0.8943
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.91      0.91        11
#      neutral       0.98      1.00      0.99       181
#     positive       1.00      0.88      0.93        24
#
#     accuracy                           0.98       216
#    macro avg       0.96      0.93      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.75      0.75        16
#      neutral       0.94      0.99      0.97       167
#     positive       0.91      0.64      0.75        33
#
#     accuracy                           0.92       216
#    macro avg       0.87      0.79      0.82       216
# weighted avg       0.92      0.92      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.75      0.86        12
#      neutral       0.91      0.92      0.92       152
#     positive       0.77      0.79      0.78        52
#
#     accuracy                           0.88       216
#    macro avg       0.89      0.82      0.85       216
# weighted avg       0.88      0.88      0.88       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.91      0.91        23
#      neutral       0.94      1.00      0.97       152
#     positive       1.00      0.76      0.86        41
#
#     accuracy                           0.94       216
#    macro avg       0.95      0.89      0.91       216
# weighted avg       0.95      0.94      0.94       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.92      0.86        13
#      neutral       0.98      0.98      0.98       186
#     positive       0.87      0.76      0.81        17
#
#     accuracy                           0.96       216
#    macro avg       0.88      0.89      0.88       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.98      1.00      0.99       185
#     positive       1.00      0.88      0.94        17
#
#     accuracy                           0.98       216
#    macro avg       0.99      0.91      0.95       216
# weighted avg       0.98      0.98      0.98       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.569407320022583
# Samples above threshold: 59
# Acquired samples: 59
# Sampling duration: 12.553422689437866 seconds
# New train size: 333
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.473001480102539 | ACCURACY: 0.7939 | F1 MACRO: 0.8829 | F1 MICRO: 0.8844
# EPOCH 2 | LOSS: 2.168541193008423 | ACCURACY: 0.814 | F1 MACRO: 0.8931 | F1 MICRO: 0.8942
# EPOCH 3 | LOSS: 2.0531041622161865 | ACCURACY: 0.8519 | F1 MACRO: 0.9115 | F1 MICRO: 0.9127
# EPOCH 4 | LOSS: 1.982810616493225 | ACCURACY: 0.9226 | F1 MACRO: 0.9511 | F1 MICRO: 0.9526
# EPOCH 5 | LOSS: 1.9295505285263062 | ACCURACY: 0.933 | F1 MACRO: 0.9561 | F1 MICRO: 0.9583
# EPOCH 6 | LOSS: 1.845313310623169 | ACCURACY: 0.939 | F1 MACRO: 0.9599 | F1 MICRO: 0.962
# EPOCH 7 | LOSS: 1.7650190591812134 | ACCURACY: 0.9397 | F1 MACRO: 0.9607 | F1 MICRO: 0.9624
# EPOCH 8 | LOSS: 1.6967376470565796 | ACCURACY: 0.9464 | F1 MACRO: 0.9644 | F1 MICRO: 0.9665
# EPOCH 9 | LOSS: 1.6319395303726196 | ACCURACY: 0.9457 | F1 MACRO: 0.9642 | F1 MICRO: 0.966
# EPOCH 10 | LOSS: 1.592603087425232 | ACCURACY: 0.9516 | F1 MACRO: 0.9682 | F1 MICRO: 0.9698
# aspect: ACCURACY 0.9516 | F1 MACRO 0.9682 | F1 MICRO 0.9698
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.93      0.99      0.96       175
#       others       0.91      0.93      0.92       158
#         part       0.94      0.99      0.96       158
#        price       0.98      0.98      0.98       192
#      service       0.97      1.00      0.99       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.95      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 6.684840679168701 | ACCURACY: 0.9218 | F1 MACRO: 0.9074 | F1 MICRO: 0.9218
# EPOCH 2 | LOSS: 5.824571132659912 | ACCURACY: 0.9506 | F1 MACRO: 0.9434 | F1 MICRO: 0.9506
# EPOCH 3 | LOSS: 5.131969928741455 | ACCURACY: 0.963 | F1 MACRO: 0.9564 | F1 MICRO: 0.963
# EPOCH 4 | LOSS: 4.733354091644287 | ACCURACY: 0.9342 | F1 MACRO: 0.9255 | F1 MICRO: 0.9342
# EPOCH 5 | LOSS: 4.492618560791016 | ACCURACY: 0.9506 | F1 MACRO: 0.9444 | F1 MICRO: 0.9506
# EPOCH 6 | LOSS: 4.342617988586426 | ACCURACY: 0.9588 | F1 MACRO: 0.9534 | F1 MICRO: 0.9588
# EPOCH 7 | LOSS: 4.432261943817139 | ACCURACY: 0.9177 | F1 MACRO: 0.8988 | F1 MICRO: 0.9177
# EPOCH 8 | LOSS: 4.262979507446289 | ACCURACY: 0.9259 | F1 MACRO: 0.9177 | F1 MICRO: 0.9259
# EPOCH 9 | LOSS: 4.146336078643799 | ACCURACY: 0.9383 | F1 MACRO: 0.9299 | F1 MICRO: 0.9383
# EPOCH 10 | LOSS: 4.084918022155762 | ACCURACY: 0.9424 | F1 MACRO: 0.9352 | F1 MICRO: 0.9424
# sentiment: ACCURACY 0.963 | F1 MACRO 0.9564 | F1 MICRO 0.963
#               precision    recall  f1-score   support
#
#     negative       0.97      0.91      0.94        77
#     positive       0.96      0.99      0.97       166
#
#     accuracy                           0.96       243
#    macro avg       0.97      0.95      0.96       243
# weighted avg       0.96      0.96      0.96       243
#
# --------------------------------------------------
# Iteration 333: Accuracy: 0.9437, F1 Micro: 0.9437, F1 Macro: 0.8942
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.98      1.00      0.99       181
#     positive       1.00      0.92      0.96        24
#
#     accuracy                           0.99       216
#    macro avg       0.99      0.94      0.97       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.92      0.75      0.83        16
#      neutral       0.93      0.99      0.96       167
#     positive       0.88      0.70      0.78        33
#
#     accuracy                           0.93       216
#    macro avg       0.91      0.81      0.86       216
# weighted avg       0.92      0.93      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.83      0.83        12
#      neutral       0.92      0.92      0.92       152
#     positive       0.78      0.77      0.78        52
#
#     accuracy                           0.88       216
#    macro avg       0.84      0.84      0.84       216
# weighted avg       0.88      0.88      0.88       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.90      0.78      0.84        23
#      neutral       0.94      0.99      0.96       152
#     positive       0.91      0.78      0.84        41
#
#     accuracy                           0.93       216
#    macro avg       0.92      0.85      0.88       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.85      0.85        13
#      neutral       0.98      0.99      0.98       186
#     positive       0.87      0.76      0.81        17
#
#     accuracy                           0.96       216
#    macro avg       0.90      0.87      0.88       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.97      1.00      0.99       185
#     positive       1.00      0.82      0.90        17
#
#     accuracy                           0.98       216
#    macro avg       0.99      0.89      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.5928292274475098
# Samples above threshold: 54
# Acquired samples: 54
# Sampling duration: 13.671370506286621 seconds
# New train size: 387
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.4232161045074463 | ACCURACY: 0.7902 | F1 MACRO: 0.8812 | F1 MICRO: 0.8827
# EPOCH 2 | LOSS: 2.1130292415618896 | ACCURACY: 0.8199 | F1 MACRO: 0.8903 | F1 MICRO: 0.8943
# EPOCH 3 | LOSS: 1.993060827255249 | ACCURACY: 0.8884 | F1 MACRO: 0.9316 | F1 MICRO: 0.9331
# EPOCH 4 | LOSS: 1.9448505640029907 | ACCURACY: 0.9286 | F1 MACRO: 0.9523 | F1 MICRO: 0.9553
# EPOCH 5 | LOSS: 1.8735545873641968 | ACCURACY: 0.9397 | F1 MACRO: 0.9603 | F1 MICRO: 0.9624
# EPOCH 6 | LOSS: 1.7903501987457275 | ACCURACY: 0.9464 | F1 MACRO: 0.9636 | F1 MICRO: 0.9663
# EPOCH 7 | LOSS: 1.7335963249206543 | ACCURACY: 0.9487 | F1 MACRO: 0.9652 | F1 MICRO: 0.9678
# EPOCH 8 | LOSS: 1.6259585618972778 | ACCURACY: 0.9531 | F1 MACRO: 0.9695 | F1 MICRO: 0.9708
# EPOCH 9 | LOSS: 1.609613299369812 | ACCURACY: 0.9539 | F1 MACRO: 0.9699 | F1 MICRO: 0.9712
# EPOCH 10 | LOSS: 1.5325422286987305 | ACCURACY: 0.9524 | F1 MACRO: 0.9684 | F1 MICRO: 0.9702
# aspect: ACCURACY 0.9539 | F1 MACRO 0.9699 | F1 MICRO 0.9712
#               precision    recall  f1-score   support
#
#         fuel       0.99      1.00      0.99       187
#      machine       0.94      0.99      0.96       175
#       others       0.90      0.94      0.92       158
#         part       0.97      0.99      0.98       158
#        price       0.98      0.98      0.98       192
#      service       0.97      1.00      0.98       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.96      0.98      0.97      1061
# weighted avg       0.96      0.98      0.97      1061
#  samples avg       0.96      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 5.7408270835876465 | ACCURACY: 0.9518 | F1 MACRO: 0.9455 | F1 MICRO: 0.9518
# EPOCH 2 | LOSS: 4.983102798461914 | ACCURACY: 0.9518 | F1 MACRO: 0.944 | F1 MICRO: 0.9518
# EPOCH 3 | LOSS: 4.517838001251221 | ACCURACY: 0.9518 | F1 MACRO: 0.9436 | F1 MICRO: 0.9518
# EPOCH 4 | LOSS: 4.120687007904053 | ACCURACY: 0.9438 | F1 MACRO: 0.9371 | F1 MICRO: 0.9438
# EPOCH 5 | LOSS: 3.83540678024292 | ACCURACY: 0.9478 | F1 MACRO: 0.9395 | F1 MICRO: 0.9478
# EPOCH 6 | LOSS: 3.927021026611328 | ACCURACY: 0.9317 | F1 MACRO: 0.9209 | F1 MICRO: 0.9317
# EPOCH 7 | LOSS: 3.686302661895752 | ACCURACY: 0.9438 | F1 MACRO: 0.9355 | F1 MICRO: 0.9438
# EPOCH 8 | LOSS: 3.605604887008667 | ACCURACY: 0.9317 | F1 MACRO: 0.922 | F1 MICRO: 0.9317
# EPOCH 9 | LOSS: 3.6662533283233643 | ACCURACY: 0.9317 | F1 MACRO: 0.9209 | F1 MICRO: 0.9317
# EPOCH 10 | LOSS: 3.581444263458252 | ACCURACY: 0.9116 | F1 MACRO: 0.8994 | F1 MICRO: 0.9116
# sentiment: ACCURACY 0.9518 | F1 MACRO 0.9436 | F1 MICRO 0.9518
#               precision    recall  f1-score   support
#
#     negative       0.95      0.90      0.92        79
#     positive       0.95      0.98      0.97       170
#
#     accuracy                           0.95       249
#    macro avg       0.95      0.94      0.94       249
# weighted avg       0.95      0.95      0.95       249
#
# --------------------------------------------------
# Iteration 387: Accuracy: 0.9498, F1 Micro: 0.9498, F1 Macro: 0.9075
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.91      0.95        11
#      neutral       0.99      1.00      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.94      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.75      0.80        16
#      neutral       0.94      0.99      0.96       167
#     positive       0.93      0.76      0.83        33
#
#     accuracy                           0.94       216
#    macro avg       0.91      0.83      0.87       216
# weighted avg       0.93      0.94      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.83      0.87        12
#      neutral       0.92      0.92      0.92       152
#     positive       0.75      0.75      0.75        52
#
#     accuracy                           0.88       216
#    macro avg       0.86      0.83      0.85       216
# weighted avg       0.87      0.88      0.87       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.91      0.91        23
#      neutral       0.96      0.99      0.97       152
#     positive       0.97      0.88      0.92        41
#
#     accuracy                           0.96       216
#    macro avg       0.95      0.93      0.94       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.77      0.83        13
#      neutral       0.97      0.99      0.98       186
#     positive       0.93      0.82      0.87        17
#
#     accuracy                           0.97       216
#    macro avg       0.94      0.86      0.90       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.97      1.00      0.99       185
#     positive       1.00      0.82      0.90        17
#
#     accuracy                           0.98       216
#    macro avg       0.99      0.89      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.597177028656006
# Samples above threshold: 48
# Acquired samples: 48
# Sampling duration: 14.762650728225708 seconds
# New train size: 435
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.279654026031494 | ACCURACY: 0.7961 | F1 MACRO: 0.8833 | F1 MICRO: 0.8851
# EPOCH 2 | LOSS: 2.0418899059295654 | ACCURACY: 0.8125 | F1 MACRO: 0.8923 | F1 MICRO: 0.8936
# EPOCH 3 | LOSS: 1.939727783203125 | ACCURACY: 0.904 | F1 MACRO: 0.9409 | F1 MICRO: 0.9419
# EPOCH 4 | LOSS: 1.8824965953826904 | ACCURACY: 0.9263 | F1 MACRO: 0.9522 | F1 MICRO: 0.9545
# EPOCH 5 | LOSS: 1.8074268102645874 | ACCURACY: 0.9464 | F1 MACRO: 0.9649 | F1 MICRO: 0.9666
# EPOCH 6 | LOSS: 1.7305660247802734 | ACCURACY: 0.9405 | F1 MACRO: 0.9604 | F1 MICRO: 0.9626
# EPOCH 7 | LOSS: 1.6471518278121948 | ACCURACY: 0.9524 | F1 MACRO: 0.9688 | F1 MICRO: 0.9703
# EPOCH 8 | LOSS: 1.5930298566818237 | ACCURACY: 0.9487 | F1 MACRO: 0.9654 | F1 MICRO: 0.9677
# EPOCH 9 | LOSS: 1.5501703023910522 | ACCURACY: 0.9501 | F1 MACRO: 0.9673 | F1 MICRO: 0.9689
# EPOCH 10 | LOSS: 1.489005446434021 | ACCURACY: 0.9576 | F1 MACRO: 0.9721 | F1 MICRO: 0.9734
# aspect: ACCURACY 0.9576 | F1 MACRO 0.9721 | F1 MICRO 0.9734
#               precision    recall  f1-score   support
#
#         fuel       0.98      1.00      0.99       187
#      machine       0.97      0.96      0.96       175
#       others       0.91      0.94      0.93       158
#         part       0.96      0.99      0.98       158
#        price       0.99      0.99      0.99       192
#      service       0.97      1.00      0.98       191
#
#    micro avg       0.96      0.98      0.97      1061
#    macro avg       0.96      0.98      0.97      1061
# weighted avg       0.97      0.98      0.97      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 5.335387229919434 | ACCURACY: 0.931 | F1 MACRO: 0.9189 | F1 MICRO: 0.931
# EPOCH 2 | LOSS: 4.653971195220947 | ACCURACY: 0.954 | F1 MACRO: 0.947 | F1 MICRO: 0.954
# EPOCH 3 | LOSS: 4.170201301574707 | ACCURACY: 0.931 | F1 MACRO: 0.922 | F1 MICRO: 0.931
# EPOCH 4 | LOSS: 3.8839519023895264 | ACCURACY: 0.9195 | F1 MACRO: 0.9097 | F1 MICRO: 0.9195
# EPOCH 5 | LOSS: 3.660989999771118 | ACCURACY: 0.9234 | F1 MACRO: 0.9122 | F1 MICRO: 0.9234
# EPOCH 6 | LOSS: 3.7113022804260254 | ACCURACY: 0.9234 | F1 MACRO: 0.9072 | F1 MICRO: 0.9234
# EPOCH 7 | LOSS: 3.4050610065460205 | ACCURACY: 0.9349 | F1 MACRO: 0.922 | F1 MICRO: 0.9349
# EPOCH 8 | LOSS: 3.406113624572754 | ACCURACY: 0.9272 | F1 MACRO: 0.9164 | F1 MICRO: 0.9272
# EPOCH 9 | LOSS: 3.348841905593872 | ACCURACY: 0.9272 | F1 MACRO: 0.9183 | F1 MICRO: 0.9272
# EPOCH 10 | LOSS: 3.3219635486602783 | ACCURACY: 0.9272 | F1 MACRO: 0.9164 | F1 MICRO: 0.9272
# sentiment: ACCURACY 0.954 | F1 MACRO 0.947 | F1 MICRO 0.954
#               precision    recall  f1-score   support
#
#     negative       0.91      0.95      0.93        81
#     positive       0.98      0.96      0.97       180
#
#     accuracy                           0.95       261
#    macro avg       0.94      0.95      0.95       261
# weighted avg       0.96      0.95      0.95       261
#
# --------------------------------------------------
# Iteration 435: Accuracy: 0.9452, F1 Micro: 0.9452, F1 Macro: 0.8949
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.97      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.75      0.75      0.75        16
#      neutral       0.96      0.95      0.95       167
#     positive       0.81      0.88      0.84        33
#
#     accuracy                           0.92       216
#    macro avg       0.84      0.86      0.85       216
# weighted avg       0.92      0.92      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.82      0.75      0.78        12
#      neutral       0.92      0.93      0.92       152
#     positive       0.76      0.75      0.76        52
#
#     accuracy                           0.88       216
#    macro avg       0.83      0.81      0.82       216
# weighted avg       0.87      0.88      0.87       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.84      0.91      0.87        23
#      neutral       0.96      1.00      0.98       152
#     positive       0.97      0.76      0.85        41
#
#     accuracy                           0.94       216
#    macro avg       0.92      0.89      0.90       216
# weighted avg       0.95      0.94      0.94       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.85      0.85        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.82      0.82      0.82        17
#
#     accuracy                           0.97       216
#    macro avg       0.89      0.89      0.89       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.97      1.00      0.99       185
#     positive       1.00      0.82      0.90        17
#
#     accuracy                           0.98       216
#    macro avg       0.99      0.89      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.589628553390503
# Samples above threshold: 43
# Acquired samples: 43
# Sampling duration: 15.071751832962036 seconds
# New train size: 478
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.3005354404449463 | ACCURACY: 0.7954 | F1 MACRO: 0.8835 | F1 MICRO: 0.8851
# EPOCH 2 | LOSS: 2.029367685317993 | ACCURACY: 0.8259 | F1 MACRO: 0.8987 | F1 MICRO: 0.8998
# EPOCH 3 | LOSS: 1.9211393594741821 | ACCURACY: 0.9182 | F1 MACRO: 0.9483 | F1 MICRO: 0.9496
# EPOCH 4 | LOSS: 1.860556721687317 | ACCURACY: 0.9397 | F1 MACRO: 0.9616 | F1 MICRO: 0.9627
# EPOCH 5 | LOSS: 1.7724800109863281 | ACCURACY: 0.9509 | F1 MACRO: 0.9683 | F1 MICRO: 0.9694
# EPOCH 6 | LOSS: 1.6915075778961182 | ACCURACY: 0.9464 | F1 MACRO: 0.9642 | F1 MICRO: 0.9664
# EPOCH 7 | LOSS: 1.6195107698440552 | ACCURACY: 0.9494 | F1 MACRO: 0.9659 | F1 MICRO: 0.9682
# EPOCH 8 | LOSS: 1.5640653371810913 | ACCURACY: 0.9516 | F1 MACRO: 0.9672 | F1 MICRO: 0.9696
# EPOCH 9 | LOSS: 1.5217318534851074 | ACCURACY: 0.9546 | F1 MACRO: 0.9701 | F1 MICRO: 0.9716
# EPOCH 10 | LOSS: 1.5001157522201538 | ACCURACY: 0.9613 | F1 MACRO: 0.9743 | F1 MICRO: 0.9756
# aspect: ACCURACY 0.9613 | F1 MACRO 0.9743 | F1 MICRO 0.9756
#               precision    recall  f1-score   support
#
#         fuel       0.98      0.99      0.99       187
#      machine       0.96      0.97      0.97       175
#       others       0.91      0.94      0.93       158
#         part       0.98      0.97      0.98       158
#        price       0.98      0.99      0.99       192
#      service       0.99      1.00      1.00       191
#
#    micro avg       0.97      0.98      0.98      1061
#    macro avg       0.97      0.98      0.97      1061
# weighted avg       0.97      0.98      0.98      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 4.9482221603393555 | ACCURACY: 0.9167 | F1 MACRO: 0.9078 | F1 MICRO: 0.9167
# EPOCH 2 | LOSS: 4.183845043182373 | ACCURACY: 0.9508 | F1 MACRO: 0.9438 | F1 MICRO: 0.9508
# EPOCH 3 | LOSS: 3.766512632369995 | ACCURACY: 0.9205 | F1 MACRO: 0.9126 | F1 MICRO: 0.9205
# EPOCH 4 | LOSS: 3.5375590324401855 | ACCURACY: 0.9394 | F1 MACRO: 0.9302 | F1 MICRO: 0.9394
# EPOCH 5 | LOSS: 3.3544747829437256 | ACCURACY: 0.9356 | F1 MACRO: 0.9235 | F1 MICRO: 0.9356
# EPOCH 6 | LOSS: 3.185666084289551 | ACCURACY: 0.928 | F1 MACRO: 0.9206 | F1 MICRO: 0.928
# EPOCH 7 | LOSS: 3.1106903553009033 | ACCURACY: 0.9318 | F1 MACRO: 0.9219 | F1 MICRO: 0.9318
# EPOCH 8 | LOSS: 3.2285051345825195 | ACCURACY: 0.9545 | F1 MACRO: 0.9483 | F1 MICRO: 0.9545
# EPOCH 9 | LOSS: 3.1424925327301025 | ACCURACY: 0.9432 | F1 MACRO: 0.9347 | F1 MICRO: 0.9432
# EPOCH 10 | LOSS: 3.0847699642181396 | ACCURACY: 0.9318 | F1 MACRO: 0.9237 | F1 MICRO: 0.9318
# sentiment: ACCURACY 0.9545 | F1 MACRO 0.9483 | F1 MICRO 0.9545
#               precision    recall  f1-score   support
#
#     negative       0.91      0.95      0.93        84
#     positive       0.98      0.96      0.97       180
#
#     accuracy                           0.95       264
#    macro avg       0.94      0.95      0.95       264
# weighted avg       0.96      0.95      0.95       264
#
# --------------------------------------------------
# Iteration 478: Accuracy: 0.9537, F1 Micro: 0.9537, F1 Macro: 0.9136
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.97      0.98       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.93      0.81      0.87        16
#      neutral       0.96      0.98      0.97       167
#     positive       0.85      0.85      0.85        33
#
#     accuracy                           0.94       216
#    macro avg       0.91      0.88      0.90       216
# weighted avg       0.94      0.94      0.94       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.90      0.75      0.82        12
#      neutral       0.91      0.92      0.92       152
#     positive       0.75      0.75      0.75        52
#
#     accuracy                           0.87       216
#    macro avg       0.85      0.81      0.83       216
# weighted avg       0.87      0.87      0.87       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.96      0.90        23
#      neutral       0.98      0.99      0.99       152
#     positive       0.94      0.83      0.88        41
#
#     accuracy                           0.96       216
#    macro avg       0.92      0.93      0.92       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.92      0.86        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.93      0.76      0.84        17
#
#     accuracy                           0.97       216
#    macro avg       0.91      0.89      0.90       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.86      0.92        14
#      neutral       0.99      1.00      1.00       185
#     positive       0.94      1.00      0.97        17
#
#     accuracy                           0.99       216
#    macro avg       0.98      0.95      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 540
# Threshold: 2.3633357286453247
# Samples above threshold: 39
# Acquired samples: 39
# Sampling duration: 15.921539306640625 seconds
# New train size: 517
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.3216702938079834 | ACCURACY: 0.8073 | F1 MACRO: 0.8891 | F1 MICRO: 0.8904
# EPOCH 2 | LOSS: 2.0752623081207275 | ACCURACY: 0.8251 | F1 MACRO: 0.8919 | F1 MICRO: 0.8961
# EPOCH 3 | LOSS: 1.969563603401184 | ACCURACY: 0.9256 | F1 MACRO: 0.9518 | F1 MICRO: 0.9538
# EPOCH 4 | LOSS: 1.8626465797424316 | ACCURACY: 0.9449 | F1 MACRO: 0.9633 | F1 MICRO: 0.9655
# EPOCH 5 | LOSS: 1.7843862771987915 | ACCURACY: 0.9472 | F1 MACRO: 0.964 | F1 MICRO: 0.9667
# EPOCH 6 | LOSS: 1.6714481115341187 | ACCURACY: 0.9464 | F1 MACRO: 0.964 | F1 MICRO: 0.9663
# EPOCH 7 | LOSS: 1.6134530305862427 | ACCURACY: 0.9487 | F1 MACRO: 0.9657 | F1 MICRO: 0.9678
# EPOCH 8 | LOSS: 1.5951898097991943 | ACCURACY: 0.9516 | F1 MACRO: 0.9677 | F1 MICRO: 0.9696
# EPOCH 9 | LOSS: 1.5370134115219116 | ACCURACY: 0.9576 | F1 MACRO: 0.9715 | F1 MICRO: 0.9732
# EPOCH 10 | LOSS: 1.4968810081481934 | ACCURACY: 0.9598 | F1 MACRO: 0.9735 | F1 MICRO: 0.9748
# aspect: ACCURACY 0.9598 | F1 MACRO 0.9735 | F1 MICRO 0.9748
# ...
#
#    micro avg       0.97      0.98      0.98      1061
#    macro avg       0.97      0.98      0.98      1061
# weighted avg       0.97      0.98      0.98      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 2.8358497619628906 | ACCURACY: 0.9283 | F1 MACRO: 0.918 | F1 MICRO: 0.9283
# EPOCH 2 | LOSS: 2.437469244003296 | ACCURACY: 0.9057 | F1 MACRO: 0.8972 | F1 MICRO: 0.9057
# EPOCH 3 | LOSS: 2.240778684616089 | ACCURACY: 0.9321 | F1 MACRO: 0.9221 | F1 MICRO: 0.9321
# EPOCH 4 | LOSS: 2.0057077407836914 | ACCURACY: 0.9321 | F1 MACRO: 0.9243 | F1 MICRO: 0.9321
# EPOCH 5 | LOSS: 1.9651168584823608 | ACCURACY: 0.9245 | F1 MACRO: 0.9154 | F1 MICRO: 0.9245
# EPOCH 6 | LOSS: 1.8180391788482666 | ACCURACY: 0.9132 | F1 MACRO: 0.8926 | F1 MICRO: 0.9132
# EPOCH 7 | LOSS: 1.8252415657043457 | ACCURACY: 0.9358 | F1 MACRO: 0.9279 | F1 MICRO: 0.9358
# EPOCH 8 | LOSS: 1.7698026895523071 | ACCURACY: 0.9208 | F1 MACRO: 0.9124 | F1 MICRO: 0.9208
# EPOCH 9 | LOSS: 1.7212660312652588 | ACCURACY: 0.9321 | F1 MACRO: 0.9225 | F1 MICRO: 0.9321
# EPOCH 10 | LOSS: 1.7088313102722168 | ACCURACY: 0.9245 | F1 MACRO: 0.9144 | F1 MICRO: 0.9245
# sentiment: ACCURACY 0.9358 | F1 MACRO 0.9279 | F1 MICRO 0.9358
#               precision    recall  f1-score   support
#
#     negative       0.86      0.95      0.90        84
#     positive       0.98      0.93      0.95       181
#
#     accuracy                           0.94       265
#    macro avg       0.92      0.94      0.93       265
# weighted avg       0.94      0.94      0.94       265
#
# --------------------------------------------------
# Iteration 831: Accuracy: 0.9514, F1 Micro: 0.9514, F1 Macro: 0.898
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.92      1.00      0.96        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.99       216
#    macro avg       0.96      0.97      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.75      0.80        16
#      neutral       0.94      0.98      0.96       167
#     positive       0.82      0.70      0.75        33
#
#     accuracy                           0.92       216
#    macro avg       0.87      0.81      0.84       216
# weighted avg       0.91      0.92      0.91       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.78      0.58      0.67        12
#      neutral       0.94      0.93      0.93       152
#     positive       0.74      0.81      0.77        52
#
#     accuracy                           0.88       216
#    macro avg       0.82      0.77      0.79       216
# weighted avg       0.88      0.88      0.88       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.82      1.00      0.90        23
#      neutral       0.99      0.99      0.99       152
#     positive       0.97      0.85      0.91        41
#
#     accuracy                           0.96       216
#    macro avg       0.93      0.95      0.93       216
# weighted avg       0.97      0.96      0.96       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.77      0.80        13
#      neutral       0.98      0.99      0.99       186
#     positive       0.93      0.82      0.87        17
#
#     accuracy                           0.97       216
#    macro avg       0.92      0.86      0.89       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       0.93      1.00      0.97        14
#      neutral       1.00      1.00      1.00       185
#     positive       1.00      0.94      0.97        17
#
#     accuracy                           1.00       216
#    macro avg       0.98      0.98      0.98       216
# weighted avg       1.00      1.00      1.00       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 864
# Threshold: 2.367106246948242
# Samples above threshold: 4
# Acquired samples: 25
# Sampling duration: 21.97267174720764 seconds
# New train size: 856
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.1504886150360107 | ACCURACY: 0.8199 | F1 MACRO: 0.8949 | F1 MICRO: 0.8967
# EPOCH 2 | LOSS: 1.901431918144226 | ACCURACY: 0.9345 | F1 MACRO: 0.9574 | F1 MICRO: 0.9592
# EPOCH 3 | LOSS: 1.7883261442184448 | ACCURACY: 0.9509 | F1 MACRO: 0.9673 | F1 MICRO: 0.9692
# EPOCH 4 | LOSS: 1.6689414978027344 | ACCURACY: 0.9576 | F1 MACRO: 0.9721 | F1 MICRO: 0.9735
# EPOCH 5 | LOSS: 1.5813223123550415 | ACCURACY: 0.9524 | F1 MACRO: 0.9672 | F1 MICRO: 0.9698
# EPOCH 6 | LOSS: 1.5213090181350708 | ACCURACY: 0.9568 | F1 MACRO: 0.9709 | F1 MICRO: 0.9727
# EPOCH 7 | LOSS: 1.472239375114441 | ACCURACY: 0.9591 | F1 MACRO: 0.9725 | F1 MICRO: 0.9742
# EPOCH 8 | LOSS: 1.4183869361877441 | ACCURACY: 0.9635 | F1 MACRO: 0.9754 | F1 MICRO: 0.977
# EPOCH 9 | LOSS: 1.3738698959350586 | ACCURACY: 0.9613 | F1 MACRO: 0.974 | F1 MICRO: 0.9755
# EPOCH 10 | LOSS: 1.3526384830474854 | ACCURACY: 0.9598 | F1 MACRO: 0.9719 | F1 MICRO: 0.9744
# aspect: ACCURACY 0.9635 | F1 MACRO 0.9754 | F1 MICRO 0.977
#               precision    recall  f1-score   support
#
#         fuel       0.98      0.99      0.99       187
#      machine       0.96      0.97      0.97       175
#       others       0.94      0.91      0.93       158
#         part       0.96      1.00      0.98       158
#        price       0.99      0.99      0.99       192
#      service       0.99      1.00      1.00       191
#
#    micro avg       0.97      0.98      0.98      1061
#    macro avg       0.97      0.98      0.98      1061
# weighted avg       0.97      0.98      0.98      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 2.7261011600494385 | ACCURACY: 0.9446 | F1 MACRO: 0.9378 | F1 MICRO: 0.9446
# EPOCH 2 | LOSS: 2.330974578857422 | ACCURACY: 0.9225 | F1 MACRO: 0.9085 | F1 MICRO: 0.9225
# EPOCH 3 | LOSS: 2.1240055561065674 | ACCURACY: 0.9446 | F1 MACRO: 0.9381 | F1 MICRO: 0.9446
# EPOCH 4 | LOSS: 1.8797314167022705 | ACCURACY: 0.9262 | F1 MACRO: 0.9177 | F1 MICRO: 0.9262
# EPOCH 5 | LOSS: 1.8570213317871094 | ACCURACY: 0.9262 | F1 MACRO: 0.9181 | F1 MICRO: 0.9262
# EPOCH 6 | LOSS: 1.812497854232788 | ACCURACY: 0.941 | F1 MACRO: 0.9323 | F1 MICRO: 0.941
# EPOCH 7 | LOSS: 1.74273681640625 | ACCURACY: 0.9446 | F1 MACRO: 0.9378 | F1 MICRO: 0.9446
# EPOCH 8 | LOSS: 1.7115639448165894 | ACCURACY: 0.9299 | F1 MACRO: 0.9216 | F1 MICRO: 0.9299
# EPOCH 9 | LOSS: 1.7290176153182983 | ACCURACY: 0.952 | F1 MACRO: 0.9455 | F1 MICRO: 0.952
# EPOCH 10 | LOSS: 1.6905241012573242 | ACCURACY: 0.9225 | F1 MACRO: 0.9143 | F1 MICRO: 0.9225
# sentiment: ACCURACY 0.952 | F1 MACRO 0.9455 | F1 MICRO 0.952
#               precision    recall  f1-score   support
#
#     negative       0.90      0.95      0.93        86
#     positive       0.98      0.95      0.96       185
#
#     accuracy                           0.95       271
#    macro avg       0.94      0.95      0.95       271
# weighted avg       0.95      0.95      0.95       271
#
# --------------------------------------------------
# Iteration 856: Accuracy: 0.9537, F1 Micro: 0.9537, F1 Macro: 0.9129
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.92      1.00      0.96        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.96      0.92      0.94        24
#
#     accuracy                           0.99       216
#    macro avg       0.96      0.97      0.96       216
# weighted avg       0.99      0.99      0.99       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.75      0.77        16
#      neutral       0.96      0.98      0.97       167
#     positive       0.84      0.79      0.81        33
#
#     accuracy                           0.93       216
#    macro avg       0.87      0.84      0.85       216
# weighted avg       0.93      0.93      0.93       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.83      0.83        12
#      neutral       0.95      0.90      0.93       152
#     positive       0.72      0.83      0.77        52
#
#     accuracy                           0.88       216
#    macro avg       0.83      0.85      0.84       216
# weighted avg       0.89      0.88      0.88       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.92      1.00      0.96        23
#      neutral       0.96      0.99      0.98       152
#     positive       0.97      0.80      0.88        41
#
#     accuracy                           0.96       216
#    macro avg       0.95      0.93      0.94       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.92      0.86        13
#      neutral       0.99      0.99      0.99       186
#     positive       0.93      0.76      0.84        17
#
#     accuracy                           0.97       216
#    macro avg       0.91      0.89      0.90       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.93      0.96        14
#      neutral       0.99      1.00      1.00       185
#     positive       1.00      1.00      1.00        17
#
#     accuracy                           1.00       216
#    macro avg       1.00      0.98      0.99       216
# weighted avg       1.00      1.00      1.00       216
#
# Launching training on 2 GPUs.
# Nearest checkpoint: 864
# Threshold: 2.593587064743042
# Samples above threshold: 1
# Acquired samples: 8
# Sampling duration: 22.642242431640625 seconds
# New train size: 864
# Launching training on 2 GPUs.
# DistributedType.MULTI_GPU
# --------------------------------------------------
# ASPECT DETECTION
# EPOCH 1 | LOSS: 2.1837573051452637 | ACCURACY: 0.8237 | F1 MACRO: 0.8978 | F1 MICRO: 0.899
# EPOCH 2 | LOSS: 1.9001260995864868 | ACCURACY: 0.9234 | F1 MACRO: 0.9496 | F1 MICRO: 0.9523
# EPOCH 3 | LOSS: 1.7702423334121704 | ACCURACY: 0.9561 | F1 MACRO: 0.9717 | F1 MICRO: 0.9728
# EPOCH 4 | LOSS: 1.6550695896148682 | ACCURACY: 0.9621 | F1 MACRO: 0.9753 | F1 MICRO: 0.9763
# EPOCH 5 | LOSS: 1.5761377811431885 | ACCURACY: 0.9583 | F1 MACRO: 0.9726 | F1 MICRO: 0.9738
# EPOCH 6 | LOSS: 1.5146681070327759 | ACCURACY: 0.9576 | F1 MACRO: 0.9714 | F1 MICRO: 0.9732
# EPOCH 7 | LOSS: 1.460758090019226 | ACCURACY: 0.9643 | F1 MACRO: 0.976 | F1 MICRO: 0.9775
# EPOCH 8 | LOSS: 1.4083391427993774 | ACCURACY: 0.9613 | F1 MACRO: 0.9739 | F1 MICRO: 0.9756
# EPOCH 9 | LOSS: 1.371211051940918 | ACCURACY: 0.9628 | F1 MACRO: 0.9749 | F1 MICRO: 0.9766
# EPOCH 10 | LOSS: 1.3416197299957275 | ACCURACY: 0.9591 | F1 MACRO: 0.9723 | F1 MICRO: 0.974
# aspect: ACCURACY 0.9643 | F1 MACRO 0.976 | F1 MICRO 0.9775
#               precision    recall  f1-score   support
#
#         fuel       0.99      0.99      0.99       187
#      machine       0.95      0.99      0.97       175
#       others       0.94      0.93      0.93       158
#         part       0.97      0.97      0.97       158
#        price       0.98      1.00      0.99       192
#      service       0.99      1.00      0.99       191
#
#    micro avg       0.97      0.98      0.98      1061
#    macro avg       0.97      0.98      0.98      1061
# weighted avg       0.97      0.98      0.98      1061
#  samples avg       0.97      0.98      0.97      1061
#
# --------------------------------------------------
# SENTIMENT ANALYSIS
# EPOCH 1 | LOSS: 2.741065502166748 | ACCURACY: 0.9111 | F1 MACRO: 0.9026 | F1 MICRO: 0.9111
# EPOCH 2 | LOSS: 2.3203184604644775 | ACCURACY: 0.9407 | F1 MACRO: 0.9326 | F1 MICRO: 0.9407
# EPOCH 3 | LOSS: 2.12758207321167 | ACCURACY: 0.9296 | F1 MACRO: 0.9211 | F1 MICRO: 0.9296
# EPOCH 4 | LOSS: 1.9238808155059814 | ACCURACY: 0.9407 | F1 MACRO: 0.9326 | F1 MICRO: 0.9407
# EPOCH 5 | LOSS: 1.8644416332244873 | ACCURACY: 0.9111 | F1 MACRO: 0.8963 | F1 MICRO: 0.9111
# EPOCH 6 | LOSS: 1.8546109199523926 | ACCURACY: 0.9296 | F1 MACRO: 0.9219 | F1 MICRO: 0.9296
# EPOCH 7 | LOSS: 1.76847243309021 | ACCURACY: 0.9222 | F1 MACRO: 0.9137 | F1 MICRO: 0.9222
# EPOCH 8 | LOSS: 1.7077528238296509 | ACCURACY: 0.9037 | F1 MACRO: 0.8819 | F1 MICRO: 0.9037
# EPOCH 9 | LOSS: 1.7231879234313965 | ACCURACY: 0.9185 | F1 MACRO: 0.9093 | F1 MICRO: 0.9185
# EPOCH 10 | LOSS: 1.6964071989059448 | ACCURACY: 0.9407 | F1 MACRO: 0.9333 | F1 MICRO: 0.9407
# sentiment: ACCURACY 0.9407 | F1 MACRO 0.9333 | F1 MICRO 0.9407
#               precision    recall  f1-score   support
#
#     negative       0.87      0.95      0.91        86
#     positive       0.98      0.93      0.96       184
#
#     accuracy                           0.94       270
#    macro avg       0.92      0.94      0.93       270
# weighted avg       0.94      0.94      0.94       270
#
# --------------------------------------------------
# Iteration 864: Accuracy: 0.9537, F1 Micro: 0.9537, F1 Macro: 0.9114
# --------------------------------------------------
# Aspect fuel report:
#               precision    recall  f1-score   support
#
#     negative       0.91      0.91      0.91        11
#      neutral       0.99      0.99      0.99       181
#     positive       0.92      0.92      0.92        24
#
#     accuracy                           0.98       216
#    macro avg       0.94      0.94      0.94       216
# weighted avg       0.98      0.98      0.98       216
#
# Aspect machine report:
#               precision    recall  f1-score   support
#
#     negative       0.86      0.75      0.80        16
#      neutral       0.95      0.98      0.96       167
#     positive       0.80      0.73      0.76        33
#
#     accuracy                           0.92       216
#    macro avg       0.87      0.82      0.84       216
# weighted avg       0.92      0.92      0.92       216
#
# Aspect others report:
#               precision    recall  f1-score   support
#
#     negative       0.79      0.92      0.85        12
#      neutral       0.95      0.92      0.93       152
#     positive       0.76      0.79      0.77        52
#
#     accuracy                           0.89       216
#    macro avg       0.83      0.88      0.85       216
# weighted avg       0.89      0.89      0.89       216
#
# Aspect part report:
#               precision    recall  f1-score   support
#
#     negative       0.85      1.00      0.92        23
#      neutral       0.98      0.98      0.98       152
#     positive       0.95      0.85      0.90        41
#
#     accuracy                           0.96       216
#    macro avg       0.93      0.94      0.93       216
# weighted avg       0.96      0.96      0.96       216
#
# Aspect price report:
#               precision    recall  f1-score   support
#
#     negative       0.85      0.85      0.85        13
#      neutral       0.98      0.99      0.99       186
#     positive       0.93      0.82      0.87        17
#
#     accuracy                           0.97       216
#    macro avg       0.92      0.89      0.90       216
# weighted avg       0.97      0.97      0.97       216
#
# Aspect service report:
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00        14
#      neutral       1.00      1.00      1.00       185
#     positive       1.00      1.00      1.00        17
#
#     accuracy                           1.00       216
#    macro avg       1.00      1.00      1.00       216
# weighted avg       1.00      1.00      1.00       216
#
# Total sampling time: 396.26 seconds
# Total runtime: 3495.0840656757355 seconds
