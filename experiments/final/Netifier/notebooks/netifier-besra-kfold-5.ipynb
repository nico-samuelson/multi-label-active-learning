# %% [markdown]
# # IMPORTS

# %%
import os
import math
import time
import torch
import warnings
import numpy as np
import pandas as pd
from collections import defaultdict
from scipy.stats import beta
from scipy.special import betaln
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_fscore_support, classification_report
from accelerate import Accelerator, notebook_launcher
from torch.multiprocessing import Manager
from torch.utils.data import DataLoader, Dataset
from transformers import BertTokenizer, BertForSequenceClassification

# %% [markdown]
# # SETUP

# %%
from transformers import logging
logging.set_verbosity_error()
warnings.filterwarnings('ignore')

# %%
if os.path.exists('/kaggle/working/results') == False:
    os.mkdir('/kaggle/working/results')

if os.path.exists('/kaggle/working/acquired_data') == False:
    os.mkdir('/kaggle/working/acquired_data')

# %%
def set_seed(seed):
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic=True
    torch.backends.cudnn.benchmark=False

set_seed(42)

# %% [markdown]
# # GLOBAL VARIABLES

# %%
manager = Manager()

# Shared resources
accuracies = manager.list()
f1_micros = manager.list()
f1_macros = manager.list()
data_used = manager.list()
sampling_dur = manager.list()
new_samples = manager.list()

# Non shared resources
filename = 'netifier-besra-kfold'
epochs = 10
batch_size = 32
sequence_length = 96
min_increment = 200

# %% [markdown]
# # LOAD AND PREPROCESS DATA

# %%
train_data = pd.read_csv('/kaggle/input/netifier-3/processed_train.csv', encoding='latin-1')
val_data = pd.read_csv('/kaggle/input/netifier-3/processed_test.csv', encoding='latin-1')

data = pd.concat([train_data, val_data], ignore_index=True)
data.shape
# Out:
# (7773, 7)

# %%
data.head()
# Out:
#                                        original_text     source  pornografi  \
# 0  [QUOTE=jessepinkman16;5a50ac34d89b093f368b456e...     kaskus           0
# 1  @verosvante kita2 aja nitizen yang pada kepo,t...  instagram           0
# 2  "#SidangAhok smg sipenista agama n ateknya mat...    twitter           0
# 3  @bolususulembang.jkt barusan baca undang2 ini....  instagram           0
# 4  bikin anak mulu lu nof \nkaga mikir apa kasian...     kaskus           0
#
#    sara  radikalisme  pencemaran_nama_baik  \
# 0     0            0                     1
# 1     0            0                     0
# 2     1            1                     1
# 3     0            0                     0
# 4     0            0                     0
#
#                                       processed_text
# 0  jabar memang provinsi barokah boleh juga dan n...
# 1  kita saja nitizen yang pada penasaran toh kelu...
# 2  sidangahok semoga sipenista agama dan ateknya ...
# 3  jakarta barusan baca undang ini tetap dibedaka...
# 4  buat anak melulu kamu nof nkaga mikir apa kasi...

# %% [markdown]
# # BUILD DATASET & DATALOADERS

# %%
class NetifierDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_length=96, use_float=True):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = self.texts[idx]
        labels = self.labels[idx]
        encoding = self.tokenizer(text, truncation=True, padding='max_length', max_length=self.max_length, return_tensors='pt')
        item = {key: val.squeeze() for key, val in encoding.items()}
        item['labels'] = torch.tensor(labels, dtype=torch.float)
        return item

    def get_per_class_probs(self):
        """
        Calculate the spread of labels (0 and 1) for each class in the dataset.
        Returns:
            dict: A dictionary where keys are class indices and values are [count_0, count_1].
        """

        # Initialize a dictionary to store counts for each class
        label_counts = defaultdict(lambda: [0, 0])  # [count_0, count_1] for each class

        for i in range(len(self)):
            # Get the labels for the i-th sample
            labels = self[i]['labels']

            # Update counts for each class
            for class_idx, label in enumerate(labels):
                label_counts[class_idx][int(label)] += 1

        for key in label_counts.keys():
            total = sum(label_counts[key])
            label_counts[key] = [x / total for x in label_counts[key]]

        return label_counts

    def get_global_probs(self):
        """
        Calculate the global count of 0s and 1s across all classes in the dataset.
        Returns:
            dict: A dictionary with keys '0' and '1' representing their global counts.
        """
        global_counts = {'0': 0, '1': 0}

        for i in range(len(self)):
            # Get the labels for the i-th sample
            labels = self[i]['labels']

            # Update global counts
            for label in labels:
                global_counts[str(int(label))] += 1

        total = global_counts['0'] + global_counts['1']
        for key in global_counts.keys():
            global_counts[key] /= total

        return global_counts


# Initialize BERT tokenizer and model
tokenizer = BertTokenizer.from_pretrained('indobenchmark/indobert-base-p1')
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]

# %%
def get_dataloaders(X_train, y_train, X_val, y_val, sequence_length=96, num_workers=4):
    train_dataset = NetifierDataset(X_train, y_train, tokenizer, max_length=sequence_length)
    val_dataset = NetifierDataset(X_val, y_val, tokenizer, max_length=sequence_length)
    train_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=batch_size, shuffle=True, pin_memory=True, num_workers=num_workers
    )
    val_loader = torch.utils.data.DataLoader(
        val_dataset, batch_size=batch_size, shuffle=False, pin_memory=True, num_workers=num_workers
    )

    return train_loader, val_loader

# %% [markdown]
# # TRAIN THE MODEL

# %%
def compute_metrics(p):
    preds = torch.tensor(p.predictions) # Sigmoid and threshold for multi-label
    labels = torch.tensor(p.label_ids)

    # Hamming accuracy: proportion of correctly predicted labels over total labels
    accuracy = (preds == labels).float().mean().item()

    # Standard multi-label precision, recall, and F1 metrics
    precision, recall, f1_micro, _ = precision_recall_fscore_support(labels, preds, average='micro', zero_division=0)
    _, _, f1_macro, _ = precision_recall_fscore_support(labels, preds, average='macro', zero_division=0)

    report = classification_report(
        labels, 
        preds, 
        target_names=['pornografi', 'sara', 'radikalisme', 'pencemaran_nama_baik'],
        zero_division=0
    )  

    return {
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1_micro': f1_micro,
        'f1_macro': f1_macro,
        'report': report
    }

# %%
def train_model(current_train_size, train_indices, metrics, trials, i, X_train_fold, y_train_fold, X_val_fold, y_val_fold, train_labels):
    accelerator = Accelerator(mixed_precision='fp16')
    device = accelerator.device

    # Define DataLoaders using the fold's data
    current_X_train = [X_train_fold[idx] for idx in train_indices]
    current_y_train = [y_train_fold[idx] for idx in train_indices]
    train_loader, val_loader = get_dataloaders(current_X_train, current_y_train, X_val_fold, y_val_fold)

    with accelerator.main_process_first():
        model = BertForSequenceClassification.from_pretrained(
            'indobenchmark/indobert-base-p1',
            num_labels=len(train_labels),
            problem_type="multi_label_classification"
        )
        
    optimizer = torch.optim.AdamW(model.parameters(), lr=2e-5, weight_decay=0.01)
    loss_fn = torch.nn.BCEWithLogitsLoss()

    # Freeze layers
    for name, param in model.named_parameters():
        if "encoder.layer" in name:
            try:
                if int(name.split(".")[3]) < 6:
                    param.requires_grad = False
            except ValueError:
                continue

    model, optimizer, train_loader, val_loader = accelerator.prepare(model, optimizer, train_loader, val_loader)

    best_result = None
    for epoch in range(epochs):
        model.train()
        epoch_loss = 0
        
        for batch in train_loader:
            inputs = {key: val for key, val in batch.items() if key != 'labels'}
            labels = batch['labels']
            optimizer.zero_grad()
            outputs = model(**inputs)
            loss = loss_fn(outputs.logits, labels)
            accelerator.backward(loss)
            optimizer.step()
            epoch_loss += loss.item()

        # Evaluation
        model.eval()
        all_preds, all_labels = [], []
        with torch.no_grad():
            for batch in val_loader:
                inputs = {key: val for key, val in batch.items() if key != 'labels'}
                labels = batch['labels']
                outputs = model(**inputs)
                preds = torch.sigmoid(outputs.logits).round()
                all_preds.append(accelerator.gather(preds))
                all_labels.append(accelerator.gather(labels))
        
        all_preds = torch.cat(all_preds).cpu().numpy()
        all_labels = torch.cat(all_labels).cpu().numpy()
        result = compute_metrics(type('EvalOutput', (object,), {'predictions': all_preds, 'label_ids': all_labels}))

        if best_result is None or result['f1_micro'] >= best_result['f1_micro']:
            accelerator.wait_for_everyone()
            unwrapped_model = accelerator.unwrap_model(model)
            # Differentiate saved models by fold and ensemble member index 'i'
            unwrapped_model.save_pretrained(
                f'{filename}-fold-{trials+1}-model-{i+1}',
                is_main_process=accelerator.is_main_process,
                save_function=accelerator.save,
            )
            best_result = result

        accelerator.print(f"Epoch {epoch + 1}/{epochs}, Train Loss: {round(epoch_loss / len(train_loader), 4)}, Accuracy: {round(result['accuracy'], 4)}, F1 Micro: {round(result['f1_micro'], 4)}, F1 Macro: {round(result['f1_macro'], 4)}")

    # Update shared metrics lists
    if accelerator.is_local_main_process:
        metrics[0].append(best_result['accuracy'])
        metrics[1].append(best_result['f1_micro'])
        metrics[2].append(best_result['f1_macro'])

# %% [markdown]
# # PLOT RESULT

# %%
import matplotlib.pyplot as plt

def plot_result(data_used, accuracies, f1_micros, f1_macros):
    fig, axs = plt.subplots(1, 3, figsize=(21, 5))
    data_used = [round(data / total_data * 100, 1) for data in data_used]

    # Plot for Accuracy
    axs[0].plot(data_used, accuracies, label="Accuracy", color="blue")
    axs[0].set_xlabel("Percentage of data used")
    axs[0].set_title("Accuracy")
    axs[0].set_xticks(data_used)

    # Plot for F1 Micro
    axs[1].plot(data_used, f1_micros, label="F1 Micro", color="orange")
    axs[1].set_xlabel("Percentage of data used")
    axs[1].set_title("F1 Micro")
    axs[1].set_xticks(data_used)

    # Plot for F1 Macro
    axs[2].plot(data_used, f1_macros, label="F1 Macro", color="green")
    axs[2].set_xlabel("Percentage of data used")
    axs[2].set_title("F1 Macro")
    axs[2].set_xticks(data_used)

    # Adjust layout and show the plots
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # QUERY STRATEGY

# %%
def beta_score(predicted_prob_one, true_outcome, alpha_param=0.1, beta_param=3.0):
    epsilon = 1e-9
    safe_prob = np.clip(predicted_prob_one, epsilon, 1.0 - epsilon)

    if true_outcome == 1:
        # Arguments for the betaln function when the true outcome is 1
        arg1 = alpha_param
        arg2 = beta_param + 1
        arg3 = alpha_param + safe_prob
        arg4 = beta_param + 1 - safe_prob
        if not (arg1 > 0 and arg2 > 0 and arg3 > 0 and arg4 > 0):
            return -1e9
        return -betaln(arg1, arg2) + betaln(arg3, arg4)
    elif true_outcome == 0:
        # Arguments for the betaln function when the true outcome is 0
        arg1 = alpha_param + 1
        arg2 = beta_param
        arg3 = alpha_param + 1 - safe_prob
        arg4 = beta_param + safe_prob
        if not (arg1 > 0 and arg2 > 0 and arg3 > 0 and arg4 > 0):
            return -1e9
        return -betaln(arg1, arg2) + betaln(arg3, arg4)
    else:
        raise ValueError("Invalid label: true_outcome must be 0 or 1.")

def calculate_expected_beta_score(predicted_prob_one, alpha_param, beta_param):
    score_if_one = beta_score(predicted_prob_one, 1, alpha_param, beta_param)
    score_if_zero = beta_score(predicted_prob_one, 0, alpha_param, beta_param)
    
    expected_score = predicted_prob_one * score_if_one + (1.0 - predicted_prob_one) * score_if_zero
    return expected_score

def get_ensemble_predictions_for_batch(ensemble_models, input_ids, attention_mask, device):
    individual_model_probs_list = []
    with torch.no_grad():
        for model_instance in ensemble_models:
            model_instance.eval()
            model_instance.to(device)
            outputs = model_instance(input_ids.to(device), attention_mask=attention_mask.to(device))
            probs = torch.sigmoid(outputs.logits)
            individual_model_probs_list.append(probs)

        if not individual_model_probs_list:
            return torch.empty(0, device=device), []

        individual_probs_tensor = torch.stack(individual_model_probs_list)
        average_probs = torch.mean(individual_probs_tensor, dim=0)

    return average_probs, individual_model_probs_list

def besra_sampling(
    ensemble_models,
    unlabeled_data,
    train_indices,
    remaining_indices,
    estimation_data,
    tokenizer,
    num_classes,
    sampling_dur,
    new_samples,
    trials,
    X_train_fold,
    y_train_fold,
    alpha_param=0.1,
    beta_param=3.0,
    n_clusters=min_increment,
):
    accelerator = Accelerator(mixed_precision="fp16")
    device = accelerator.device

    unlabeled_dataset = NetifierDataset(unlabeled_data,
                                        np.zeros((len(unlabeled_data), num_classes)),
                                        tokenizer,
                                        max_length=sequence_length) 
    unlabeled_dataloader = DataLoader(unlabeled_dataset, batch_size=batch_size, num_workers=4, pin_memory=True) 

    current_train_size = len(train_indices)

    estimation_dataset = NetifierDataset(estimation_data,
                                        np.zeros((len(estimation_data), num_classes)),
                                        tokenizer,
                                        max_length=sequence_length) # sequence_length
    estimation_dataloader = DataLoader(estimation_dataset, batch_size=len(estimation_dataset), num_workers=4, pin_memory=True)
    estimation_dataloader, unlabeled_dataloader = accelerator.prepare(estimation_dataloader, unlabeled_dataloader)

    for model in ensemble_models:
        model.to(device)
        model.eval()

    start_time = time.time()
    candidate_scores = []
    all_estimation_avg_probs = []
    all_estimation_individual_probs_by_model = []
    all_candidate_avg_probs = []
    all_candidate_individual_probs_by_model = []

    # Pre compute predictions for all estimation and candidate samples
    for est_batch in estimation_dataloader:
        est_input_ids = est_batch['input_ids']
        est_attention_mask = est_batch['attention_mask']
        est_avg_probs_batch, est_indiv_probs_batch = get_ensemble_predictions_for_batch(ensemble_models, est_input_ids, est_attention_mask, device)
        all_estimation_avg_probs.append(accelerator.gather_for_metrics(est_avg_probs_batch))

        if not all_estimation_individual_probs_by_model:
            all_estimation_individual_probs_by_model = [[] for _ in est_indiv_probs_batch]
        for model_idx, probs in enumerate(est_indiv_probs_batch):
            all_estimation_individual_probs_by_model[model_idx].append(accelerator.gather_for_metrics(probs))

    for cand_batch in unlabeled_dataloader:
        cand_input_ids = cand_batch['input_ids']
        cand_attention_mask = cand_batch['attention_mask']
        cand_avg_probs_batch, cand_indiv_probs_batch = get_ensemble_predictions_for_batch(ensemble_models, cand_input_ids, cand_attention_mask, device)
        all_candidate_avg_probs.append(accelerator.gather_for_metrics(cand_avg_probs_batch))

        if not all_candidate_individual_probs_by_model:
             all_candidate_individual_probs_by_model = [[] for _ in cand_indiv_probs_batch]
        for model_idx, probs in enumerate(cand_indiv_probs_batch):
            all_candidate_individual_probs_by_model[model_idx].append(accelerator.gather_for_metrics(probs))

    # Concatenate all batch predictions into single tensors
    all_estimation_avg_probs = torch.cat(all_estimation_avg_probs, dim=0)
    all_estimation_individual_probs = [torch.cat(model_probs, dim=0) for model_probs in all_estimation_individual_probs_by_model]
    all_candidate_avg_probs = torch.cat(all_candidate_avg_probs, dim=0)
    all_candidate_individual_probs = [torch.cat(model_probs, dim=0) for model_probs in all_candidate_individual_probs_by_model]

    accelerator.wait_for_everyone()

    # Score change calculation
    for candidate_index in range(len(all_candidate_avg_probs)):
        candidate_avg_probs_for_sample = all_candidate_avg_probs[candidate_index]
        candidate_individual_probs_for_sample = [m_probs[candidate_index] for m_probs in all_candidate_individual_probs]
        candidate_delta_q_score = 0.0

        for estimation_index in range(len(all_estimation_avg_probs)):
            estimation_avg_probs_for_sample = all_estimation_avg_probs[estimation_index]
            estimation_individual_probs_for_sample = [m_probs[estimation_index] for m_probs in all_estimation_individual_probs]

            # Calculate the initial expected score on the estimation sample before any update
            initial_expected_score_on_estimation_sample = 0.0
            for estimation_class_index in range(num_classes):
                prob_one_avg_for_est_class = estimation_avg_probs_for_sample[estimation_class_index].item()
                initial_expected_score_on_estimation_sample += calculate_expected_beta_score(prob_one_avg_for_est_class, alpha_param, beta_param)

            delta_q_for_one_estimation_sample = 0.0
            for candidate_class_index in range(num_classes):
                expected_score_after_update = 0.0
                for hypothetical_candidate_label in [0, 1]:
                    prob_one_avg_for_candidate_class = candidate_avg_probs_for_sample[candidate_class_index].item()
                    prob_of_hypothetical_label_avg = prob_one_avg_for_candidate_class if hypothetical_candidate_label == 1 else (1.0 - prob_one_avg_for_candidate_class)

                    # Bayesian Update by model reweighting
                    model_weights = []
                    for model_index in range(len(ensemble_models)):
                        prob_one_individual_for_candidate_class = candidate_individual_probs_for_sample[model_index][candidate_class_index].item()
                        prob_of_hypothetical_label_individual = prob_one_individual_for_candidate_class if hypothetical_candidate_label == 1 else (1.0 - prob_one_individual_for_candidate_class)
                        model_weights.append(prob_of_hypothetical_label_individual)

                    sum_model_weights = sum(model_weights)
                    if sum_model_weights < 1e-9:
                        normalized_model_weights = [1.0 / len(ensemble_models)] * len(ensemble_models)
                    else:
                        normalized_model_weights = [w / sum_model_weights for w in model_weights]

                    reweighted_prob_one_for_est_class = 0.0

                    # Reweight the individual model probabilities for the candidate class
                    for model_index in range(len(ensemble_models)):
                        prob_one_individual_for_est_class = estimation_individual_probs_for_sample[model_index][candidate_class_index].item()
                        reweighted_prob_one_for_est_class += normalized_model_weights[model_index] * prob_one_individual_for_est_class

                    # Calculate new scores
                    updated_expected_score_on_estimation_sample = calculate_expected_beta_score(reweighted_prob_one_for_est_class, alpha_param, beta_param)
                    expected_score_after_update += prob_of_hypothetical_label_avg * updated_expected_score_on_estimation_sample

                delta_q_for_one_estimation_sample += (expected_score_after_update - initial_expected_score_on_estimation_sample)
            candidate_delta_q_score += delta_q_for_one_estimation_sample
        candidate_scores.append(candidate_delta_q_score)

    # K-Means Clustering and Selection
    accelerator.wait_for_everyone()
    if accelerator.is_main_process:
        candidate_scores = np.array(candidate_scores)
        candidate_scores = candidate_scores.reshape(-1, 1)
    
        accelerator.print(f"BESRA Uncertainty Score Threshold {np.percentile(candidate_scores, 90)}")
    
        target_samples = math.ceil(0.1 * len(unlabeled_data)) 
        collected_indices = set()
        thresholds = []
    
        # Check nearest checkpoint
        nearest_cp = 0
        arrived_at_cp = False
        for cp in checkpoints:
            if cp > current_train_size:
                nearest_cp = cp
                break
    
        # Determine number of maximum samples to be acquired
        if target_samples <= n_clusters and n_clusters < nearest_cp - current_train_size:
            target_samples = n_clusters
        elif target_samples > n_clusters and target_samples < nearest_cp - current_train_size:
            target_samples = target_samples
        else:
            arrived_at_cp = True
            target_samples = nearest_cp - current_train_size
    
        # No clustering needed when there's little data left
        if current_train_size >= checkpoints[len(checkpoints)-1] - min_increment:
            end_time = time.time()
            duration = end_time - start_time
            
            temp = train_indices.copy()
            temp.extend(remaining_indices)
            
            # Save acquired data up to checkpoint
            acquired_data = pd.DataFrame({
                'processed_text': [X_train_fold[i] for i in temp],
                'pornografi': [y_train_fold[i][0] for i in temp],
                'sara': [y_train_fold[i][1] for i in temp],
                'radikalisme': [y_train_fold[i][2] for i in temp],
                'pencemaran_nama_baik': [y_train_fold[i][3] for i in temp],
            })
            acquired_data.to_csv(f'acquired_data/{filename}-{trials+1}-data-{nearest_cp}.csv', index=False)
    
            print("Nearest checkpoint:", nearest_cp)
            print("Acquired samples:", len(remaining_indices))
            print(f"Sampling duration: {duration} seconds")
            
            sampling_dur.append(duration)
            for i in remaining_indices:
                new_samples.append(i)
    
        else:
            # Cluster the data based on its embeddings
            kmeans=KMeans(n_clusters=n_clusters, n_init=1)
            kmeans.fit(candidate_scores)
            
            for cluster_id in range(n_clusters):
                # Cluster center and indices of samples in the current cluster
                cluster_center = kmeans.cluster_centers_[cluster_id]
                cluster_indices = np.where(kmeans.labels_ == cluster_id)[0]
            
                if cluster_indices.size == 0:
                    # Skip clusters with no members
                    print(f"Cluster {cluster_id} has no members, skipping.")
                    continue
            
                # Calculate distances of each point in the cluster from the cluster center
                cluster_distances = np.linalg.norm(candidate_scores[cluster_indices] - cluster_center, axis=1)
            
                # Determine the local threshold (10th percentile of closest distances to cluster center)
                local_threshold = np.percentile(cluster_distances, 90)
                thresholds.append(local_threshold)
            
                below_threshold_indices = cluster_indices[cluster_distances >= local_threshold]
                collected_indices.update(below_threshold_indices)
    
            # To handle multiple points with same distance
            if len(collected_indices) > target_samples:
                collected_indices = np.array(list(collected_indices))
                np.random.shuffle(collected_indices)
                collected_indices = collected_indices[:target_samples]
                
            end_time = time.time() 
            duration = end_time - start_time 
    
            if arrived_at_cp:
                temp = train_indices.copy()
                temp.extend(collected_indices)
                
                # Save acquired data up to checkpoint
                acquired_data = pd.DataFrame({
                    'processed_text': [X_train_fold[i] for i in temp],
                    'pornografi': [y_train_fold[i][0] for i in temp],
                    'sara': [y_train_fold[i][1] for i in temp],
                    'radikalisme': [y_train_fold[i][2] for i in temp],
                    'pencemaran_nama_baik': [y_train_fold[i][3] for i in temp],
                })
        
                acquired_data.to_csv(f'acquired_data/{filename}-{trials+1}-data-{nearest_cp}.csv', index=False)
            
            print("Nearest checkpoint:", nearest_cp)
            # print(f"Thresholds: {thresholds}")
            print("Acquired samples:", len(collected_indices))
            print(f"Sampling duration: {duration} seconds")
            
            sampling_dur.append(duration)
            for i in collected_indices:
                new_samples.append(remaining_indices[i])
    
            # threshold_data = pd.DataFrame({
            #     'Threshold': thresholds
            # })
            # threshold_data.to_csv(f"results/{filename}-thresholds-{trials+1}-{current_train_size}.csv", index=False)

# %% [markdown]
# # MAIN LOOP

# %%
from sklearn.model_selection import KFold

N_SPLITS = 5
RANDOM_SEED = 42

# Prepare data for K-Fold
label_columns = data.columns[2:6]
X = data['processed_text'].values
y = data[label_columns].values
kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_SEED)

all_fold_accuracies = []
all_fold_f1_micros = []
all_fold_f1_macros = []
all_fold_data_used = []

for fold, (train_index, val_index) in enumerate(kf.split(X)):
    if fold == 4:
        print("===============================================")
        print(f"STARTING FOLD {fold + 1}/{N_SPLITS}")
        print("===============================================")
    
        X_train_fold, X_val_fold = X[train_index], X[val_index]
        y_train_fold, y_val_fold = y[train_index], y[val_index]
    
        train_fold_df = pd.DataFrame(X_train_fold, columns=['processed_text'])
        train_fold_df[label_columns] = y_train_fold
    
        val_fold_df = pd.DataFrame(X_val_fold, columns=['processed_text'])
        val_fold_df[label_columns] = y_val_fold
    
        fold_data_dir = 'kfold_splits'
        if not os.path.exists(fold_data_dir):
            os.makedirs(fold_data_dir)
    
        train_fold_df.to_csv(f'{fold_data_dir}/train_fold_{fold + 1}.csv', index=False)
        val_fold_df.to_csv(f'{fold_data_dir}/val_fold_{fold + 1}.csv', index=False)
    
        # Shared resources for this fold's processes
        accuracies = manager.list()
        f1_micros = manager.list()
        f1_macros = manager.list()
        data_used = manager.list()
        sampling_dur = manager.list()
        
        set_seed(RANDOM_SEED + fold)
        
        # Define the initial labeled pool from the current fold's training data
        total_train_fold_size = len(X_train_fold) + len(X_val_fold)
        initial_train_size = int(0.05 * total_train_fold_size)
        
        train_indices = np.random.choice(range(len(X_train_fold)), initial_train_size, replace=False).tolist()
        remaining_indices = list(set(range(len(X_train_fold))) - set(train_indices))
        current_train_size = initial_train_size
    
        checkpoints = [
            int(0.5 * total_train_fold_size), 
            int(0.6 * total_train_fold_size),
            int(0.7 * total_train_fold_size),
            len(X_train_fold)
        ]
        
        fold_start_time = time.time()
        
        while current_train_size < total_train_fold_size:
            model_accuracies = manager.list()
            model_f1_micros = manager.list()
            model_f1_macros = manager.list()
    
            ensemble_seeds = [RANDOM_SEED + fold + j for j in range(3)]
            for j, seed in enumerate(ensemble_seeds):
                set_seed(seed)
                train_args = (
                    current_train_size, train_indices, (model_accuracies, model_f1_micros, model_f1_macros), 
                    fold, j, X_train_fold, y_train_fold, X_val_fold, y_val_fold, label_columns
                )
                notebook_launcher(train_model, train_args, num_processes=2)
    
            data_used.append(current_train_size)
            accuracies.append(np.mean(model_accuracies))
            f1_micros.append(np.mean(model_f1_micros))
            f1_macros.append(np.mean(model_f1_macros))
            print(f"\nFold {fold+1} - Averaged F1-Micro for {current_train_size} samples: {np.mean(model_f1_micros):.4f}\n")
            
            # Stop if we've reached the last checkpoint
            if current_train_size >= checkpoints[-1]:
                break
    
            ensemble_models = []
            for j in range(3):
                model = BertForSequenceClassification.from_pretrained(f'{filename}-fold-{fold+1}-model-{j+1}')
                ensemble_models.append(model)
    
            # Perform query strategy
            estimation_pool_indices = np.random.choice(remaining_indices, size=min(32, int(0.1 * len(remaining_indices))), replace=False).tolist()
            estimation_pool_data = [X_train_fold[i] for i in estimation_pool_indices]
            new_samples_shared = manager.list()
            
            sampling_args = (
                ensemble_models, 
                [X_train_fold[i] for i in remaining_indices], 
                train_indices, 
                remaining_indices, 
                estimation_pool_data,
                tokenizer, 
                y_train_fold.shape[1],
                sampling_dur, 
                new_samples_shared, 
                fold,
                X_train_fold,
                y_train_fold
            )
            notebook_launcher(besra_sampling, sampling_args, num_processes=2)
            
            # Update the pools
            newly_acquired_indices = list(new_samples_shared)
            train_indices.extend(newly_acquired_indices)
            remaining_indices = list(set(remaining_indices) - set(newly_acquired_indices))
        
            current_train_size = len(train_indices)
            print(f"\nFold {fold + 1} - New train size: {current_train_size}\n")
        
        fold_end_time = time.time()
        print(f"\nFOLD {fold + 1} COMPLETED in {fold_end_time - fold_start_time:.2f} seconds")
        
        # Store the results for this fold
        all_fold_data_used.append(list(data_used))
        all_fold_accuracies.append(list(accuracies))
        all_fold_f1_micros.append(list(f1_micros))
        all_fold_f1_macros.append(list(f1_macros))
# Out:
# ===============================================
# STARTING FOLD 5/5
# ===============================================
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.5439, Accuracy: 0.7891, F1 Micro: 0.0, F1 Macro: 0.0
# Epoch 2/10, Train Loss: 0.4673, Accuracy: 0.7939, F1 Micro: 0.0449, F1 Macro: 0.0404
# Epoch 3/10, Train Loss: 0.421, Accuracy: 0.8194, F1 Micro: 0.2561, F1 Macro: 0.1786
# Epoch 4/10, Train Loss: 0.39, Accuracy: 0.8313, F1 Micro: 0.3933, F1 Macro: 0.3032
# Epoch 5/10, Train Loss: 0.3375, Accuracy: 0.8416, F1 Micro: 0.4483, F1 Macro: 0.3709
# Epoch 6/10, Train Loss: 0.2901, Accuracy: 0.8577, F1 Micro: 0.5902, F1 Macro: 0.5609
# Epoch 7/10, Train Loss: 0.2547, Accuracy: 0.8578, F1 Micro: 0.5852, F1 Macro: 0.5546
# Epoch 8/10, Train Loss: 0.2265, Accuracy: 0.867, F1 Micro: 0.6411, F1 Macro: 0.6284
# Epoch 9/10, Train Loss: 0.174, Accuracy: 0.8655, F1 Micro: 0.6682, F1 Macro: 0.6603
# Epoch 10/10, Train Loss: 0.1497, Accuracy: 0.8669, F1 Micro: 0.6611, F1 Macro: 0.6529
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.5711, Accuracy: 0.7891, F1 Micro: 0.0, F1 Macro: 0.0
# Epoch 2/10, Train Loss: 0.4693, Accuracy: 0.7891, F1 Micro: 0.0, F1 Macro: 0.0
# Epoch 3/10, Train Loss: 0.4318, Accuracy: 0.8206, F1 Micro: 0.2613, F1 Macro: 0.193
# Epoch 4/10, Train Loss: 0.3987, Accuracy: 0.8325, F1 Micro: 0.3724, F1 Macro: 0.2764
# Epoch 5/10, Train Loss: 0.3434, Accuracy: 0.8369, F1 Micro: 0.4476, F1 Macro: 0.3802
# Epoch 6/10, Train Loss: 0.2913, Accuracy: 0.8531, F1 Micro: 0.5852, F1 Macro: 0.5689
# Epoch 7/10, Train Loss: 0.2557, Accuracy: 0.8562, F1 Micro: 0.599, F1 Macro: 0.5716
# Epoch 8/10, Train Loss: 0.2292, Accuracy: 0.8625, F1 Micro: 0.6434, F1 Macro: 0.6389
# Epoch 9/10, Train Loss: 0.1791, Accuracy: 0.8645, F1 Micro: 0.6457, F1 Macro: 0.6248
# Epoch 10/10, Train Loss: 0.1455, Accuracy: 0.8648, F1 Micro: 0.6558, F1 Macro: 0.6483
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.5991, Accuracy: 0.7891, F1 Micro: 0.0, F1 Macro: 0.0
# Epoch 2/10, Train Loss: 0.4731, Accuracy: 0.7891, F1 Micro: 0.0, F1 Macro: 0.0
# Epoch 3/10, Train Loss: 0.43, Accuracy: 0.8163, F1 Micro: 0.2314, F1 Macro: 0.166
# Epoch 4/10, Train Loss: 0.401, Accuracy: 0.8313, F1 Micro: 0.3829, F1 Macro: 0.2957
# Epoch 5/10, Train Loss: 0.3505, Accuracy: 0.8364, F1 Micro: 0.4325, F1 Macro: 0.3403
# Epoch 6/10, Train Loss: 0.3055, Accuracy: 0.8466, F1 Micro: 0.4869, F1 Macro: 0.4215
# Epoch 7/10, Train Loss: 0.2681, Accuracy: 0.8566, F1 Micro: 0.5706, F1 Macro: 0.5149
# Epoch 8/10, Train Loss: 0.2475, Accuracy: 0.8598, F1 Micro: 0.6181, F1 Macro: 0.6031
# Epoch 9/10, Train Loss: 0.1954, Accuracy: 0.8637, F1 Micro: 0.645, F1 Macro: 0.633
# Epoch 10/10, Train Loss: 0.1604, Accuracy: 0.8641, F1 Micro: 0.6326, F1 Macro: 0.6236
#
# Fold 5 - Averaged F1-Micro for 388 samples: 0.6563
#
# Launching training on 2 GPUs.
# BESRA Uncertainty Score Threshold 144.14532426812613
# Nearest checkpoint: 3886
# Acquired samples: 584
# Sampling duration: 274.6062092781067 seconds
#
# Fold 5 - New train size: 972
#
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.5155, Accuracy: 0.8019, F1 Micro: 0.1145, F1 Macro: 0.0943
# Epoch 2/10, Train Loss: 0.403, Accuracy: 0.8391, F1 Micro: 0.4492, F1 Macro: 0.3663
# Epoch 3/10, Train Loss: 0.3287, Accuracy: 0.8687, F1 Micro: 0.6669, F1 Macro: 0.6639
# Epoch 4/10, Train Loss: 0.2748, Accuracy: 0.8794, F1 Micro: 0.682, F1 Macro: 0.6668
# Epoch 5/10, Train Loss: 0.2163, Accuracy: 0.8827, F1 Micro: 0.7262, F1 Macro: 0.7231
# Epoch 6/10, Train Loss: 0.1682, Accuracy: 0.8855, F1 Micro: 0.7167, F1 Macro: 0.7098
# Epoch 7/10, Train Loss: 0.1321, Accuracy: 0.8878, F1 Micro: 0.7284, F1 Macro: 0.7237
# Epoch 8/10, Train Loss: 0.0988, Accuracy: 0.8867, F1 Micro: 0.7101, F1 Macro: 0.7022
# Epoch 9/10, Train Loss: 0.0783, Accuracy: 0.8878, F1 Micro: 0.7153, F1 Macro: 0.7056
# Epoch 10/10, Train Loss: 0.0615, Accuracy: 0.8888, F1 Micro: 0.7181, F1 Macro: 0.7112
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.5309, Accuracy: 0.7905, F1 Micro: 0.0132, F1 Macro: 0.0124
# Epoch 2/10, Train Loss: 0.4137, Accuracy: 0.8333, F1 Micro: 0.3913, F1 Macro: 0.2992
# Epoch 3/10, Train Loss: 0.3309, Accuracy: 0.8673, F1 Micro: 0.6556, F1 Macro: 0.6442
# Epoch 4/10, Train Loss: 0.2807, Accuracy: 0.8778, F1 Micro: 0.6988, F1 Macro: 0.6891
# Epoch 5/10, Train Loss: 0.2216, Accuracy: 0.8805, F1 Micro: 0.7178, F1 Macro: 0.7123
# Epoch 6/10, Train Loss: 0.1791, Accuracy: 0.8839, F1 Micro: 0.7062, F1 Macro: 0.7
# Epoch 7/10, Train Loss: 0.1446, Accuracy: 0.8877, F1 Micro: 0.7312, F1 Macro: 0.7251
# Epoch 8/10, Train Loss: 0.107, Accuracy: 0.8819, F1 Micro: 0.6873, F1 Macro: 0.6793
# Epoch 9/10, Train Loss: 0.0911, Accuracy: 0.8908, F1 Micro: 0.7277, F1 Macro: 0.7182
# Epoch 10/10, Train Loss: 0.0653, Accuracy: 0.8902, F1 Micro: 0.7303, F1 Macro: 0.7265
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.5392, Accuracy: 0.7959, F1 Micro: 0.0631, F1 Macro: 0.0554
# Epoch 2/10, Train Loss: 0.4056, Accuracy: 0.8392, F1 Micro: 0.4453, F1 Macro: 0.3541
# Epoch 3/10, Train Loss: 0.3298, Accuracy: 0.8634, F1 Micro: 0.6337, F1 Macro: 0.622
# Epoch 4/10, Train Loss: 0.2793, Accuracy: 0.8811, F1 Micro: 0.7031, F1 Macro: 0.6933
# Epoch 5/10, Train Loss: 0.2225, Accuracy: 0.8808, F1 Micro: 0.7258, F1 Macro: 0.7246
# Epoch 6/10, Train Loss: 0.1782, Accuracy: 0.8825, F1 Micro: 0.691, F1 Macro: 0.6796
# Epoch 7/10, Train Loss: 0.1465, Accuracy: 0.8831, F1 Micro: 0.727, F1 Macro: 0.7242
# Epoch 8/10, Train Loss: 0.1133, Accuracy: 0.8795, F1 Micro: 0.6751, F1 Macro: 0.6629
# Epoch 9/10, Train Loss: 0.0852, Accuracy: 0.8872, F1 Micro: 0.7278, F1 Macro: 0.7205
# Epoch 10/10, Train Loss: 0.0643, Accuracy: 0.8873, F1 Micro: 0.7327, F1 Macro: 0.7274
#
# Fold 5 - Averaged F1-Micro for 972 samples: 0.7308
#
# Launching training on 2 GPUs.
# BESRA Uncertainty Score Threshold 161.08596400500866
# Nearest checkpoint: 3886
# Acquired samples: 525
# Sampling duration: 248.4800009727478 seconds
#
# Fold 5 - New train size: 1497
#
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.503, Accuracy: 0.8313, F1 Micro: 0.3662, F1 Macro: 0.306
# Epoch 2/10, Train Loss: 0.3632, Accuracy: 0.8637, F1 Micro: 0.6159, F1 Macro: 0.6089
# Epoch 3/10, Train Loss: 0.284, Accuracy: 0.8841, F1 Micro: 0.7238, F1 Macro: 0.7224
# Epoch 4/10, Train Loss: 0.2451, Accuracy: 0.8853, F1 Micro: 0.7024, F1 Macro: 0.7
# Epoch 5/10, Train Loss: 0.1904, Accuracy: 0.8927, F1 Micro: 0.7508, F1 Macro: 0.7483
# Epoch 6/10, Train Loss: 0.1366, Accuracy: 0.8905, F1 Micro: 0.7317, F1 Macro: 0.7297
# Epoch 7/10, Train Loss: 0.1179, Accuracy: 0.8927, F1 Micro: 0.7401, F1 Macro: 0.7328
# Epoch 8/10, Train Loss: 0.082, Accuracy: 0.8944, F1 Micro: 0.7418, F1 Macro: 0.7371
# Epoch 9/10, Train Loss: 0.0616, Accuracy: 0.8883, F1 Micro: 0.702, F1 Macro: 0.693
# Epoch 10/10, Train Loss: 0.0478, Accuracy: 0.8916, F1 Micro: 0.7441, F1 Macro: 0.739
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.5193, Accuracy: 0.8225, F1 Micro: 0.2783, F1 Macro: 0.1959
# Epoch 2/10, Train Loss: 0.3655, Accuracy: 0.8634, F1 Micro: 0.6246, F1 Macro: 0.6193
# Epoch 3/10, Train Loss: 0.2835, Accuracy: 0.8828, F1 Micro: 0.714, F1 Macro: 0.7122
# Epoch 4/10, Train Loss: 0.2469, Accuracy: 0.8877, F1 Micro: 0.7184, F1 Macro: 0.7128
# Epoch 5/10, Train Loss: 0.1912, Accuracy: 0.8916, F1 Micro: 0.7473, F1 Macro: 0.7443
# Epoch 6/10, Train Loss: 0.144, Accuracy: 0.8925, F1 Micro: 0.7398, F1 Macro: 0.7379
# Epoch 7/10, Train Loss: 0.1228, Accuracy: 0.8933, F1 Micro: 0.7508, F1 Macro: 0.747
# Epoch 8/10, Train Loss: 0.0925, Accuracy: 0.8927, F1 Micro: 0.7359, F1 Macro: 0.7334
# Epoch 9/10, Train Loss: 0.0682, Accuracy: 0.8956, F1 Micro: 0.7487, F1 Macro: 0.7447
# Epoch 10/10, Train Loss: 0.0515, Accuracy: 0.8958, F1 Micro: 0.7461, F1 Macro: 0.7409
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.5267, Accuracy: 0.8242, F1 Micro: 0.3043, F1 Macro: 0.2287
# Epoch 2/10, Train Loss: 0.3704, Accuracy: 0.8602, F1 Micro: 0.5904, F1 Macro: 0.566
# Epoch 3/10, Train Loss: 0.2952, Accuracy: 0.8778, F1 Micro: 0.7138, F1 Macro: 0.7165
# Epoch 4/10, Train Loss: 0.2567, Accuracy: 0.8902, F1 Micro: 0.737, F1 Macro: 0.7322
# Epoch 5/10, Train Loss: 0.198, Accuracy: 0.8859, F1 Micro: 0.7384, F1 Macro: 0.7352
# Epoch 6/10, Train Loss: 0.153, Accuracy: 0.8881, F1 Micro: 0.724, F1 Macro: 0.7236
# Epoch 7/10, Train Loss: 0.1266, Accuracy: 0.8927, F1 Micro: 0.7494, F1 Macro: 0.7435
# Epoch 8/10, Train Loss: 0.0958, Accuracy: 0.8911, F1 Micro: 0.731, F1 Macro: 0.7263
# Epoch 9/10, Train Loss: 0.0673, Accuracy: 0.8936, F1 Micro: 0.746, F1 Macro: 0.7389
# Epoch 10/10, Train Loss: 0.0521, Accuracy: 0.8928, F1 Micro: 0.736, F1 Macro: 0.7312
#
# Fold 5 - Averaged F1-Micro for 1497 samples: 0.7503
#
# Launching training on 2 GPUs.
# BESRA Uncertainty Score Threshold 202.69166379624934
# Nearest checkpoint: 3886
# Acquired samples: 473
# Sampling duration: 223.378999710083 seconds
#
# Fold 5 - New train size: 1970
#
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.4881, Accuracy: 0.8406, F1 Micro: 0.471, F1 Macro: 0.388
# Epoch 2/10, Train Loss: 0.3478, Accuracy: 0.8728, F1 Micro: 0.6512, F1 Macro: 0.6401
# Epoch 3/10, Train Loss: 0.2724, Accuracy: 0.888, F1 Micro: 0.7473, F1 Macro: 0.7501
# Epoch 4/10, Train Loss: 0.2237, Accuracy: 0.8983, F1 Micro: 0.7472, F1 Macro: 0.7442
# Epoch 5/10, Train Loss: 0.1834, Accuracy: 0.9006, F1 Micro: 0.7554, F1 Macro: 0.7512
# Epoch 6/10, Train Loss: 0.1357, Accuracy: 0.898, F1 Micro: 0.7542, F1 Macro: 0.7478
# Epoch 7/10, Train Loss: 0.0997, Accuracy: 0.8989, F1 Micro: 0.7537, F1 Macro: 0.7481
# Epoch 8/10, Train Loss: 0.0786, Accuracy: 0.8963, F1 Micro: 0.744, F1 Macro: 0.7351
# Epoch 9/10, Train Loss: 0.0546, Accuracy: 0.8961, F1 Micro: 0.7641, F1 Macro: 0.7637
# Epoch 10/10, Train Loss: 0.0426, Accuracy: 0.9009, F1 Micro: 0.7664, F1 Macro: 0.7607
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.503, Accuracy: 0.8372, F1 Micro: 0.4318, F1 Macro: 0.3584
# Epoch 2/10, Train Loss: 0.3463, Accuracy: 0.8758, F1 Micro: 0.6607, F1 Macro: 0.6495
# Epoch 3/10, Train Loss: 0.2711, Accuracy: 0.8838, F1 Micro: 0.7397, F1 Macro: 0.7428
# Epoch 4/10, Train Loss: 0.2254, Accuracy: 0.8963, F1 Micro: 0.743, F1 Macro: 0.7388
# Epoch 5/10, Train Loss: 0.1803, Accuracy: 0.8967, F1 Micro: 0.7397, F1 Macro: 0.7347
# Epoch 6/10, Train Loss: 0.1406, Accuracy: 0.8944, F1 Micro: 0.7378, F1 Macro: 0.7337
# Epoch 7/10, Train Loss: 0.1113, Accuracy: 0.8989, F1 Micro: 0.761, F1 Macro: 0.7608
# Epoch 8/10, Train Loss: 0.0885, Accuracy: 0.8923, F1 Micro: 0.7177, F1 Macro: 0.7061
# Epoch 9/10, Train Loss: 0.0657, Accuracy: 0.8952, F1 Micro: 0.7448, F1 Macro: 0.7355
# Epoch 10/10, Train Loss: 0.0463, Accuracy: 0.8964, F1 Micro: 0.7472, F1 Macro: 0.7405
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.5007, Accuracy: 0.8398, F1 Micro: 0.4545, F1 Macro: 0.3746
# Epoch 2/10, Train Loss: 0.3529, Accuracy: 0.8705, F1 Micro: 0.6356, F1 Macro: 0.6254
# Epoch 3/10, Train Loss: 0.28, Accuracy: 0.8892, F1 Micro: 0.7454, F1 Macro: 0.747
# Epoch 4/10, Train Loss: 0.2271, Accuracy: 0.8933, F1 Micro: 0.7362, F1 Macro: 0.7316
# Epoch 5/10, Train Loss: 0.1866, Accuracy: 0.8973, F1 Micro: 0.7435, F1 Macro: 0.7392
# Epoch 6/10, Train Loss: 0.1444, Accuracy: 0.8947, F1 Micro: 0.7291, F1 Macro: 0.7243
# Epoch 7/10, Train Loss: 0.1082, Accuracy: 0.8967, F1 Micro: 0.7508, F1 Macro: 0.7465
# Epoch 8/10, Train Loss: 0.0858, Accuracy: 0.897, F1 Micro: 0.7542, F1 Macro: 0.7501
# Epoch 9/10, Train Loss: 0.0614, Accuracy: 0.8941, F1 Micro: 0.7496, F1 Macro: 0.7461
# Epoch 10/10, Train Loss: 0.0472, Accuracy: 0.8975, F1 Micro: 0.763, F1 Macro: 0.7573
#
# Fold 5 - Averaged F1-Micro for 1970 samples: 0.7635
#
# Launching training on 2 GPUs.
# BESRA Uncertainty Score Threshold 195.85857540968718
# Nearest checkpoint: 3886
# Acquired samples: 425
# Sampling duration: 199.5010588169098 seconds
#
# Fold 5 - New train size: 2395
#
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.4656, Accuracy: 0.8514, F1 Micro: 0.5199, F1 Macro: 0.4959
# Epoch 2/10, Train Loss: 0.3203, Accuracy: 0.887, F1 Micro: 0.7159, F1 Macro: 0.7167
# Epoch 3/10, Train Loss: 0.2575, Accuracy: 0.8989, F1 Micro: 0.7442, F1 Macro: 0.7381
# Epoch 4/10, Train Loss: 0.211, Accuracy: 0.8973, F1 Micro: 0.7462, F1 Macro: 0.7372
# Epoch 5/10, Train Loss: 0.1574, Accuracy: 0.8975, F1 Micro: 0.7409, F1 Macro: 0.7221
# Epoch 6/10, Train Loss: 0.1211, Accuracy: 0.8945, F1 Micro: 0.7251, F1 Macro: 0.7053
# Epoch 7/10, Train Loss: 0.1006, Accuracy: 0.8981, F1 Micro: 0.7427, F1 Macro: 0.7332
# Epoch 8/10, Train Loss: 0.0782, Accuracy: 0.8959, F1 Micro: 0.7625, F1 Macro: 0.7606
# Epoch 9/10, Train Loss: 0.0582, Accuracy: 0.8942, F1 Micro: 0.7544, F1 Macro: 0.7545
# Epoch 10/10, Train Loss: 0.0436, Accuracy: 0.898, F1 Micro: 0.7591, F1 Macro: 0.7553
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.4766, Accuracy: 0.8578, F1 Micro: 0.6199, F1 Macro: 0.6192
# Epoch 2/10, Train Loss: 0.3176, Accuracy: 0.8878, F1 Micro: 0.7366, F1 Macro: 0.7358
# Epoch 3/10, Train Loss: 0.2572, Accuracy: 0.8964, F1 Micro: 0.7383, F1 Macro: 0.7321
# Epoch 4/10, Train Loss: 0.2124, Accuracy: 0.8961, F1 Micro: 0.7457, F1 Macro: 0.7444
# Epoch 5/10, Train Loss: 0.1632, Accuracy: 0.8963, F1 Micro: 0.743, F1 Macro: 0.7286
# Epoch 6/10, Train Loss: 0.1225, Accuracy: 0.8956, F1 Micro: 0.7267, F1 Macro: 0.7106
# Epoch 7/10, Train Loss: 0.0993, Accuracy: 0.8989, F1 Micro: 0.7576, F1 Macro: 0.7527
# Epoch 8/10, Train Loss: 0.0763, Accuracy: 0.897, F1 Micro: 0.7555, F1 Macro: 0.7519
# Epoch 9/10, Train Loss: 0.0548, Accuracy: 0.8939, F1 Micro: 0.7492, F1 Macro: 0.7443
# Epoch 10/10, Train Loss: 0.0453, Accuracy: 0.8998, F1 Micro: 0.7503, F1 Macro: 0.7387
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.4761, Accuracy: 0.8427, F1 Micro: 0.4692, F1 Macro: 0.4136
# Epoch 2/10, Train Loss: 0.3258, Accuracy: 0.8839, F1 Micro: 0.702, F1 Macro: 0.7046
# Epoch 3/10, Train Loss: 0.2622, Accuracy: 0.8928, F1 Micro: 0.7184, F1 Macro: 0.7079
# Epoch 4/10, Train Loss: 0.2199, Accuracy: 0.8941, F1 Micro: 0.7354, F1 Macro: 0.7304
# Epoch 5/10, Train Loss: 0.1761, Accuracy: 0.8973, F1 Micro: 0.7308, F1 Macro: 0.714
# Epoch 6/10, Train Loss: 0.1253, Accuracy: 0.8973, F1 Micro: 0.7313, F1 Macro: 0.7186
# Epoch 7/10, Train Loss: 0.1002, Accuracy: 0.8983, F1 Micro: 0.7526, F1 Macro: 0.744
# Epoch 8/10, Train Loss: 0.0806, Accuracy: 0.8963, F1 Micro: 0.7382, F1 Macro: 0.7292
# Epoch 9/10, Train Loss: 0.0568, Accuracy: 0.8964, F1 Micro: 0.7508, F1 Macro: 0.7462
# Epoch 10/10, Train Loss: 0.0465, Accuracy: 0.8961, F1 Micro: 0.7543, F1 Macro: 0.7492
#
# Fold 5 - Averaged F1-Micro for 2395 samples: 0.7581
#
# Launching training on 2 GPUs.
# BESRA Uncertainty Score Threshold 278.19295473463677
# Nearest checkpoint: 3886
# Acquired samples: 383
# Sampling duration: 180.28339314460754 seconds
#
# Fold 5 - New train size: 2778
#
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.4497, Accuracy: 0.8547, F1 Micro: 0.5245, F1 Macro: 0.4747
# Epoch 2/10, Train Loss: 0.3013, Accuracy: 0.8861, F1 Micro: 0.7026, F1 Macro: 0.6797
# Epoch 3/10, Train Loss: 0.2496, Accuracy: 0.8958, F1 Micro: 0.7447, F1 Macro: 0.7409
# Epoch 4/10, Train Loss: 0.1963, Accuracy: 0.8984, F1 Micro: 0.7451, F1 Macro: 0.7378
# Epoch 5/10, Train Loss: 0.1611, Accuracy: 0.9013, F1 Micro: 0.7582, F1 Macro: 0.7563
# Epoch 6/10, Train Loss: 0.1238, Accuracy: 0.8994, F1 Micro: 0.7604, F1 Macro: 0.7568
# Epoch 7/10, Train Loss: 0.0836, Accuracy: 0.8992, F1 Micro: 0.7565, F1 Macro: 0.7483
# Epoch 8/10, Train Loss: 0.0652, Accuracy: 0.8967, F1 Micro: 0.7542, F1 Macro: 0.7485
# Epoch 9/10, Train Loss: 0.0514, Accuracy: 0.9019, F1 Micro: 0.7636, F1 Macro: 0.7554
# Epoch 10/10, Train Loss: 0.0382, Accuracy: 0.9014, F1 Micro: 0.7587, F1 Macro: 0.7488
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.4624, Accuracy: 0.8558, F1 Micro: 0.5478, F1 Macro: 0.5041
# Epoch 2/10, Train Loss: 0.3066, Accuracy: 0.8853, F1 Micro: 0.6866, F1 Macro: 0.6666
# Epoch 3/10, Train Loss: 0.2507, Accuracy: 0.8977, F1 Micro: 0.7636, F1 Macro: 0.7644
# Epoch 4/10, Train Loss: 0.2025, Accuracy: 0.8988, F1 Micro: 0.7544, F1 Macro: 0.7501
# Epoch 5/10, Train Loss: 0.16, Accuracy: 0.9008, F1 Micro: 0.7547, F1 Macro: 0.7488
# Epoch 6/10, Train Loss: 0.1266, Accuracy: 0.8938, F1 Micro: 0.7561, F1 Macro: 0.7557
# Epoch 7/10, Train Loss: 0.089, Accuracy: 0.9013, F1 Micro: 0.7579, F1 Macro: 0.7451
# Epoch 8/10, Train Loss: 0.0696, Accuracy: 0.9014, F1 Micro: 0.76, F1 Macro: 0.751
# Epoch 9/10, Train Loss: 0.0552, Accuracy: 0.8989, F1 Micro: 0.7442, F1 Macro: 0.7294
# Epoch 10/10, Train Loss: 0.0396, Accuracy: 0.8998, F1 Micro: 0.7507, F1 Macro: 0.7447
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.46, Accuracy: 0.8556, F1 Micro: 0.5286, F1 Macro: 0.4594
# Epoch 2/10, Train Loss: 0.3061, Accuracy: 0.8856, F1 Micro: 0.688, F1 Macro: 0.6643
# Epoch 3/10, Train Loss: 0.256, Accuracy: 0.8975, F1 Micro: 0.7552, F1 Macro: 0.7549
# Epoch 4/10, Train Loss: 0.2063, Accuracy: 0.9002, F1 Micro: 0.7534, F1 Macro: 0.7472
# Epoch 5/10, Train Loss: 0.1668, Accuracy: 0.898, F1 Micro: 0.7503, F1 Macro: 0.7468
# Epoch 6/10, Train Loss: 0.1264, Accuracy: 0.8961, F1 Micro: 0.7581, F1 Macro: 0.7539
# Epoch 7/10, Train Loss: 0.0864, Accuracy: 0.8978, F1 Micro: 0.75, F1 Macro: 0.7379
# Epoch 8/10, Train Loss: 0.0693, Accuracy: 0.8938, F1 Micro: 0.7589, F1 Macro: 0.7563
# Epoch 9/10, Train Loss: 0.0567, Accuracy: 0.8983, F1 Micro: 0.7501, F1 Macro: 0.7395
# Epoch 10/10, Train Loss: 0.0418, Accuracy: 0.9006, F1 Micro: 0.7571, F1 Macro: 0.7514
#
# Fold 5 - Averaged F1-Micro for 2778 samples: 0.7620
#
# Launching training on 2 GPUs.
# BESRA Uncertainty Score Threshold 175.24950125599224
# Nearest checkpoint: 3886
# Acquired samples: 345
# Sampling duration: 164.05127215385437 seconds
#
# Fold 5 - New train size: 3123
#
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.4353, Accuracy: 0.8656, F1 Micro: 0.6007, F1 Macro: 0.5851
# Epoch 2/10, Train Loss: 0.2877, Accuracy: 0.8934, F1 Micro: 0.7248, F1 Macro: 0.7218
# Epoch 3/10, Train Loss: 0.24, Accuracy: 0.8964, F1 Micro: 0.7554, F1 Macro: 0.7514
# Epoch 4/10, Train Loss: 0.191, Accuracy: 0.8989, F1 Micro: 0.7667, F1 Macro: 0.7668
# Epoch 5/10, Train Loss: 0.1648, Accuracy: 0.9014, F1 Micro: 0.7648, F1 Macro: 0.7601
# Epoch 6/10, Train Loss: 0.1134, Accuracy: 0.9041, F1 Micro: 0.7672, F1 Macro: 0.7626
# Epoch 7/10, Train Loss: 0.081, Accuracy: 0.8964, F1 Micro: 0.7585, F1 Macro: 0.7563
# Epoch 8/10, Train Loss: 0.063, Accuracy: 0.9016, F1 Micro: 0.7639, F1 Macro: 0.7597
# Epoch 9/10, Train Loss: 0.0474, Accuracy: 0.9005, F1 Micro: 0.7676, F1 Macro: 0.7633
# Epoch 10/10, Train Loss: 0.042, Accuracy: 0.9006, F1 Micro: 0.7716, F1 Macro: 0.767
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.4426, Accuracy: 0.8655, F1 Micro: 0.6034, F1 Macro: 0.5939
# Epoch 2/10, Train Loss: 0.2884, Accuracy: 0.8923, F1 Micro: 0.7223, F1 Macro: 0.7231
# Epoch 3/10, Train Loss: 0.2404, Accuracy: 0.8955, F1 Micro: 0.7543, F1 Macro: 0.7536
# Epoch 4/10, Train Loss: 0.1931, Accuracy: 0.898, F1 Micro: 0.7614, F1 Macro: 0.7571
# Epoch 5/10, Train Loss: 0.1617, Accuracy: 0.9033, F1 Micro: 0.7653, F1 Macro: 0.7604
# Epoch 6/10, Train Loss: 0.1183, Accuracy: 0.8998, F1 Micro: 0.7604, F1 Macro: 0.7566
# Epoch 7/10, Train Loss: 0.0847, Accuracy: 0.8992, F1 Micro: 0.7614, F1 Macro: 0.7563
# Epoch 8/10, Train Loss: 0.0655, Accuracy: 0.8995, F1 Micro: 0.7614, F1 Macro: 0.7594
# Epoch 9/10, Train Loss: 0.0511, Accuracy: 0.8964, F1 Micro: 0.76, F1 Macro: 0.7543
# Epoch 10/10, Train Loss: 0.0447, Accuracy: 0.8961, F1 Micro: 0.7621, F1 Macro: 0.7565
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.4495, Accuracy: 0.8623, F1 Micro: 0.5771, F1 Macro: 0.5479
# Epoch 2/10, Train Loss: 0.2965, Accuracy: 0.8931, F1 Micro: 0.7313, F1 Macro: 0.729
# Epoch 3/10, Train Loss: 0.2479, Accuracy: 0.8948, F1 Micro: 0.7566, F1 Macro: 0.7533
# Epoch 4/10, Train Loss: 0.1979, Accuracy: 0.8973, F1 Micro: 0.7614, F1 Macro: 0.7562
# Epoch 5/10, Train Loss: 0.1704, Accuracy: 0.9016, F1 Micro: 0.7601, F1 Macro: 0.7544
# Epoch 6/10, Train Loss: 0.1205, Accuracy: 0.9022, F1 Micro: 0.7508, F1 Macro: 0.7453
# Epoch 7/10, Train Loss: 0.0865, Accuracy: 0.9, F1 Micro: 0.7563, F1 Macro: 0.7525
# Epoch 8/10, Train Loss: 0.0659, Accuracy: 0.9031, F1 Micro: 0.7508, F1 Macro: 0.7426
# Epoch 9/10, Train Loss: 0.0523, Accuracy: 0.9009, F1 Micro: 0.7586, F1 Macro: 0.7502
# Epoch 10/10, Train Loss: 0.0453, Accuracy: 0.8973, F1 Micro: 0.7654, F1 Macro: 0.7596
#
# Fold 5 - Averaged F1-Micro for 3123 samples: 0.7674
#
# Launching training on 2 GPUs.
# BESRA Uncertainty Score Threshold 188.8089904668731
# Nearest checkpoint: 3886
# Acquired samples: 310
# Sampling duration: 147.64145803451538 seconds
#
# Fold 5 - New train size: 3433
#
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.426, Accuracy: 0.8756, F1 Micro: 0.6601, F1 Macro: 0.6542
# Epoch 2/10, Train Loss: 0.2864, Accuracy: 0.8938, F1 Micro: 0.7234, F1 Macro: 0.7192
# Epoch 3/10, Train Loss: 0.223, Accuracy: 0.8992, F1 Micro: 0.7485, F1 Macro: 0.7381
# Epoch 4/10, Train Loss: 0.1786, Accuracy: 0.9003, F1 Micro: 0.7383, F1 Macro: 0.7287
# Epoch 5/10, Train Loss: 0.1468, Accuracy: 0.8941, F1 Micro: 0.7594, F1 Macro: 0.7584
# Epoch 6/10, Train Loss: 0.1025, Accuracy: 0.9, F1 Micro: 0.7628, F1 Macro: 0.7613
# Epoch 7/10, Train Loss: 0.079, Accuracy: 0.902, F1 Micro: 0.7569, F1 Macro: 0.7524
# Epoch 8/10, Train Loss: 0.0574, Accuracy: 0.9014, F1 Micro: 0.7688, F1 Macro: 0.7674
# Epoch 9/10, Train Loss: 0.0458, Accuracy: 0.8972, F1 Micro: 0.7616, F1 Macro: 0.7597
# Epoch 10/10, Train Loss: 0.0374, Accuracy: 0.9008, F1 Micro: 0.7682, F1 Macro: 0.7659
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.4353, Accuracy: 0.8702, F1 Micro: 0.6376, F1 Macro: 0.6262
# Epoch 2/10, Train Loss: 0.2887, Accuracy: 0.8939, F1 Micro: 0.7268, F1 Macro: 0.7196
# Epoch 3/10, Train Loss: 0.2255, Accuracy: 0.8983, F1 Micro: 0.7372, F1 Macro: 0.7216
# Epoch 4/10, Train Loss: 0.1832, Accuracy: 0.8966, F1 Micro: 0.7139, F1 Macro: 0.7039
# Epoch 5/10, Train Loss: 0.1537, Accuracy: 0.9003, F1 Micro: 0.7525, F1 Macro: 0.7413
# Epoch 6/10, Train Loss: 0.1067, Accuracy: 0.9002, F1 Micro: 0.759, F1 Macro: 0.7532
# Epoch 7/10, Train Loss: 0.0839, Accuracy: 0.9016, F1 Micro: 0.7579, F1 Macro: 0.7536
# Epoch 8/10, Train Loss: 0.0615, Accuracy: 0.902, F1 Micro: 0.7637, F1 Macro: 0.7567
# Epoch 9/10, Train Loss: 0.0476, Accuracy: 0.897, F1 Micro: 0.7622, F1 Macro: 0.7619
# Epoch 10/10, Train Loss: 0.0378, Accuracy: 0.8989, F1 Micro: 0.766, F1 Macro: 0.7645
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.4368, Accuracy: 0.8708, F1 Micro: 0.6387, F1 Macro: 0.6229
# Epoch 2/10, Train Loss: 0.2935, Accuracy: 0.8916, F1 Micro: 0.7142, F1 Macro: 0.7097
# Epoch 3/10, Train Loss: 0.2335, Accuracy: 0.8994, F1 Micro: 0.7627, F1 Macro: 0.7594
# Epoch 4/10, Train Loss: 0.186, Accuracy: 0.902, F1 Micro: 0.7371, F1 Macro: 0.7304
# Epoch 5/10, Train Loss: 0.1547, Accuracy: 0.9003, F1 Micro: 0.7488, F1 Macro: 0.7391
# Epoch 6/10, Train Loss: 0.1101, Accuracy: 0.8975, F1 Micro: 0.7508, F1 Macro: 0.7465
# Epoch 7/10, Train Loss: 0.0846, Accuracy: 0.8984, F1 Micro: 0.7614, F1 Macro: 0.7615
# Epoch 8/10, Train Loss: 0.0648, Accuracy: 0.8984, F1 Micro: 0.7616, F1 Macro: 0.7577
# Epoch 9/10, Train Loss: 0.0472, Accuracy: 0.9011, F1 Micro: 0.7621, F1 Macro: 0.7631
# Epoch 10/10, Train Loss: 0.0402, Accuracy: 0.8998, F1 Micro: 0.7616, F1 Macro: 0.7575
#
# Fold 5 - Averaged F1-Micro for 3433 samples: 0.7658
#
# Launching training on 2 GPUs.
# BESRA Uncertainty Score Threshold 211.84327665969516
# Nearest checkpoint: 3886
# Acquired samples: 279
# Sampling duration: 133.42551469802856 seconds
#
# Fold 5 - New train size: 3712
#
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.4236, Accuracy: 0.8781, F1 Micro: 0.6887, F1 Macro: 0.6788
# Epoch 2/10, Train Loss: 0.2853, Accuracy: 0.8931, F1 Micro: 0.724, F1 Macro: 0.7056
# Epoch 3/10, Train Loss: 0.2377, Accuracy: 0.8942, F1 Micro: 0.7673, F1 Macro: 0.7694
# Epoch 4/10, Train Loss: 0.1801, Accuracy: 0.8994, F1 Micro: 0.77, F1 Macro: 0.7684
# Epoch 5/10, Train Loss: 0.1386, Accuracy: 0.9005, F1 Micro: 0.7635, F1 Macro: 0.759
# Epoch 6/10, Train Loss: 0.1011, Accuracy: 0.9033, F1 Micro: 0.7645, F1 Macro: 0.7607
# Epoch 7/10, Train Loss: 0.0769, Accuracy: 0.8995, F1 Micro: 0.7686, F1 Macro: 0.7665
# Epoch 8/10, Train Loss: 0.0634, Accuracy: 0.9025, F1 Micro: 0.7666, F1 Macro: 0.7611
# Epoch 9/10, Train Loss: 0.0445, Accuracy: 0.9022, F1 Micro: 0.7692, F1 Macro: 0.7642
# Epoch 10/10, Train Loss: 0.0405, Accuracy: 0.9052, F1 Micro: 0.7663, F1 Macro: 0.7619
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.4308, Accuracy: 0.8786, F1 Micro: 0.6999, F1 Macro: 0.6909
# Epoch 2/10, Train Loss: 0.2878, Accuracy: 0.8919, F1 Micro: 0.723, F1 Macro: 0.7004
# Epoch 3/10, Train Loss: 0.2421, Accuracy: 0.8984, F1 Micro: 0.7745, F1 Macro: 0.772
# Epoch 4/10, Train Loss: 0.1829, Accuracy: 0.8981, F1 Micro: 0.7688, F1 Macro: 0.7698
# Epoch 5/10, Train Loss: 0.1418, Accuracy: 0.9, F1 Micro: 0.7635, F1 Macro: 0.7579
# Epoch 6/10, Train Loss: 0.1091, Accuracy: 0.9041, F1 Micro: 0.7702, F1 Macro: 0.7658
# Epoch 7/10, Train Loss: 0.0751, Accuracy: 0.9003, F1 Micro: 0.769, F1 Macro: 0.7641
# Epoch 8/10, Train Loss: 0.0611, Accuracy: 0.9038, F1 Micro: 0.7701, F1 Macro: 0.7666
# Epoch 9/10, Train Loss: 0.0447, Accuracy: 0.9011, F1 Micro: 0.767, F1 Macro: 0.7623
# Epoch 10/10, Train Loss: 0.0399, Accuracy: 0.9025, F1 Micro: 0.7656, F1 Macro: 0.7615
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.433, Accuracy: 0.8795, F1 Micro: 0.6897, F1 Macro: 0.6867
# Epoch 2/10, Train Loss: 0.2882, Accuracy: 0.89, F1 Micro: 0.7129, F1 Macro: 0.6842
# Epoch 3/10, Train Loss: 0.2488, Accuracy: 0.9019, F1 Micro: 0.7681, F1 Macro: 0.7619
# Epoch 4/10, Train Loss: 0.1886, Accuracy: 0.9009, F1 Micro: 0.7693, F1 Macro: 0.7684
# Epoch 5/10, Train Loss: 0.1443, Accuracy: 0.8978, F1 Micro: 0.7651, F1 Macro: 0.7608
# Epoch 6/10, Train Loss: 0.1069, Accuracy: 0.9016, F1 Micro: 0.7621, F1 Macro: 0.7573
# Epoch 7/10, Train Loss: 0.0796, Accuracy: 0.8977, F1 Micro: 0.7662, F1 Macro: 0.762
# Epoch 8/10, Train Loss: 0.0655, Accuracy: 0.8977, F1 Micro: 0.7603, F1 Macro: 0.7533
# Epoch 9/10, Train Loss: 0.044, Accuracy: 0.8994, F1 Micro: 0.766, F1 Macro: 0.7588
# Epoch 10/10, Train Loss: 0.041, Accuracy: 0.9017, F1 Micro: 0.7618, F1 Macro: 0.7544
#
# Fold 5 - Averaged F1-Micro for 3712 samples: 0.7712
#
# Launching training on 2 GPUs.
# BESRA Uncertainty Score Threshold 169.45081251597904
# Nearest checkpoint: 3886
# Acquired samples: 174
# Sampling duration: 119.90318274497986 seconds
#
# Fold 5 - New train size: 3886
#
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.42, Accuracy: 0.8802, F1 Micro: 0.6993, F1 Macro: 0.676
# Epoch 2/10, Train Loss: 0.2881, Accuracy: 0.8966, F1 Micro: 0.7568, F1 Macro: 0.7533
# Epoch 3/10, Train Loss: 0.2256, Accuracy: 0.9031, F1 Micro: 0.7707, F1 Macro: 0.7689
# Epoch 4/10, Train Loss: 0.1879, Accuracy: 0.9048, F1 Micro: 0.7744, F1 Macro: 0.771
# Epoch 5/10, Train Loss: 0.1415, Accuracy: 0.8952, F1 Micro: 0.7658, F1 Macro: 0.7641
# Epoch 6/10, Train Loss: 0.1059, Accuracy: 0.9045, F1 Micro: 0.7714, F1 Macro: 0.7659
# Epoch 7/10, Train Loss: 0.0778, Accuracy: 0.8956, F1 Micro: 0.7682, F1 Macro: 0.7656
# Epoch 8/10, Train Loss: 0.0606, Accuracy: 0.9023, F1 Micro: 0.7655, F1 Macro: 0.7633
# Epoch 9/10, Train Loss: 0.0471, Accuracy: 0.9, F1 Micro: 0.7714, F1 Macro: 0.7695
# Epoch 10/10, Train Loss: 0.0377, Accuracy: 0.9086, F1 Micro: 0.7771, F1 Macro: 0.7723
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.4274, Accuracy: 0.8795, F1 Micro: 0.6844, F1 Macro: 0.6631
# Epoch 2/10, Train Loss: 0.2908, Accuracy: 0.898, F1 Micro: 0.7552, F1 Macro: 0.7476
# Epoch 3/10, Train Loss: 0.2319, Accuracy: 0.9014, F1 Micro: 0.7666, F1 Macro: 0.7633
# Epoch 4/10, Train Loss: 0.1889, Accuracy: 0.9039, F1 Micro: 0.7779, F1 Macro: 0.7788
# Epoch 5/10, Train Loss: 0.1466, Accuracy: 0.8992, F1 Micro: 0.7682, F1 Macro: 0.7655
# Epoch 6/10, Train Loss: 0.1089, Accuracy: 0.9008, F1 Micro: 0.7675, F1 Macro: 0.7638
# Epoch 7/10, Train Loss: 0.088, Accuracy: 0.9006, F1 Micro: 0.7675, F1 Macro: 0.7628
# Epoch 8/10, Train Loss: 0.0601, Accuracy: 0.9036, F1 Micro: 0.7531, F1 Macro: 0.7457
# Epoch 9/10, Train Loss: 0.0479, Accuracy: 0.9006, F1 Micro: 0.7585, F1 Macro: 0.7479
# Epoch 10/10, Train Loss: 0.0412, Accuracy: 0.9058, F1 Micro: 0.7664, F1 Macro: 0.7591
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.4279, Accuracy: 0.8798, F1 Micro: 0.6863, F1 Macro: 0.6557
# Epoch 2/10, Train Loss: 0.2904, Accuracy: 0.8944, F1 Micro: 0.7522, F1 Macro: 0.747
# Epoch 3/10, Train Loss: 0.2321, Accuracy: 0.8991, F1 Micro: 0.7632, F1 Macro: 0.7633
# Epoch 4/10, Train Loss: 0.1931, Accuracy: 0.9036, F1 Micro: 0.7719, F1 Macro: 0.7725
# Epoch 5/10, Train Loss: 0.1448, Accuracy: 0.8952, F1 Micro: 0.7656, F1 Macro: 0.7646
# Epoch 6/10, Train Loss: 0.1103, Accuracy: 0.8986, F1 Micro: 0.7661, F1 Macro: 0.7654
# Epoch 7/10, Train Loss: 0.0784, Accuracy: 0.8939, F1 Micro: 0.7643, F1 Macro: 0.7645
# Epoch 8/10, Train Loss: 0.0589, Accuracy: 0.9042, F1 Micro: 0.7634, F1 Macro: 0.7603
# Epoch 9/10, Train Loss: 0.047, Accuracy: 0.8977, F1 Micro: 0.7643, F1 Macro: 0.7627
# Epoch 10/10, Train Loss: 0.0431, Accuracy: 0.8972, F1 Micro: 0.7607, F1 Macro: 0.7576
#
# Fold 5 - Averaged F1-Micro for 3886 samples: 0.7756
#
# Launching training on 2 GPUs.
# BESRA Uncertainty Score Threshold 201.52818901817307
# Nearest checkpoint: 4663
# Acquired samples: 234
# Sampling duration: 111.79802680015564 seconds
#
# Fold 5 - New train size: 4120
#
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.4032, Accuracy: 0.873, F1 Micro: 0.65, F1 Macro: 0.6417
# Epoch 2/10, Train Loss: 0.2823, Accuracy: 0.8975, F1 Micro: 0.7652, F1 Macro: 0.7622
# Epoch 3/10, Train Loss: 0.221, Accuracy: 0.9013, F1 Micro: 0.7756, F1 Macro: 0.7732
# Epoch 4/10, Train Loss: 0.1852, Accuracy: 0.9059, F1 Micro: 0.7708, F1 Macro: 0.7675
# Epoch 5/10, Train Loss: 0.143, Accuracy: 0.9067, F1 Micro: 0.7811, F1 Macro: 0.7767
# Epoch 6/10, Train Loss: 0.1061, Accuracy: 0.9064, F1 Micro: 0.7718, F1 Macro: 0.7663
# Epoch 7/10, Train Loss: 0.079, Accuracy: 0.903, F1 Micro: 0.7726, F1 Macro: 0.7713
# Epoch 8/10, Train Loss: 0.0597, Accuracy: 0.9056, F1 Micro: 0.7733, F1 Macro: 0.7634
# Epoch 9/10, Train Loss: 0.0447, Accuracy: 0.8989, F1 Micro: 0.7705, F1 Macro: 0.7689
# Epoch 10/10, Train Loss: 0.0336, Accuracy: 0.9062, F1 Micro: 0.7691, F1 Macro: 0.7612
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.4085, Accuracy: 0.8772, F1 Micro: 0.6776, F1 Macro: 0.6728
# Epoch 2/10, Train Loss: 0.2866, Accuracy: 0.8945, F1 Micro: 0.7649, F1 Macro: 0.763
# Epoch 3/10, Train Loss: 0.2236, Accuracy: 0.898, F1 Micro: 0.7685, F1 Macro: 0.766
# Epoch 4/10, Train Loss: 0.1929, Accuracy: 0.9062, F1 Micro: 0.7724, F1 Macro: 0.7651
# Epoch 5/10, Train Loss: 0.1504, Accuracy: 0.9025, F1 Micro: 0.7709, F1 Macro: 0.7697
# Epoch 6/10, Train Loss: 0.1128, Accuracy: 0.9052, F1 Micro: 0.7677, F1 Macro: 0.7614
# Epoch 7/10, Train Loss: 0.0823, Accuracy: 0.9039, F1 Micro: 0.7646, F1 Macro: 0.7571
# Epoch 8/10, Train Loss: 0.0611, Accuracy: 0.9, F1 Micro: 0.7603, F1 Macro: 0.7512
# Epoch 9/10, Train Loss: 0.0454, Accuracy: 0.9005, F1 Micro: 0.761, F1 Macro: 0.7551
# Epoch 10/10, Train Loss: 0.0358, Accuracy: 0.8998, F1 Micro: 0.7692, F1 Macro: 0.7661
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.4145, Accuracy: 0.8744, F1 Micro: 0.654, F1 Macro: 0.6466
# Epoch 2/10, Train Loss: 0.2884, Accuracy: 0.8934, F1 Micro: 0.7597, F1 Macro: 0.7592
# Epoch 3/10, Train Loss: 0.2249, Accuracy: 0.8978, F1 Micro: 0.7697, F1 Macro: 0.7696
# Epoch 4/10, Train Loss: 0.1948, Accuracy: 0.9011, F1 Micro: 0.7662, F1 Macro: 0.7604
# Epoch 5/10, Train Loss: 0.1482, Accuracy: 0.9005, F1 Micro: 0.7624, F1 Macro: 0.7565
# Epoch 6/10, Train Loss: 0.1132, Accuracy: 0.9011, F1 Micro: 0.7596, F1 Macro: 0.7498
# Epoch 7/10, Train Loss: 0.0755, Accuracy: 0.8994, F1 Micro: 0.7672, F1 Macro: 0.7658
# Epoch 8/10, Train Loss: 0.061, Accuracy: 0.8972, F1 Micro: 0.7686, F1 Macro: 0.7673
# Epoch 9/10, Train Loss: 0.0472, Accuracy: 0.9023, F1 Micro: 0.7657, F1 Macro: 0.7582
# Epoch 10/10, Train Loss: 0.0364, Accuracy: 0.9036, F1 Micro: 0.7704, F1 Macro: 0.7661
#
# Fold 5 - Averaged F1-Micro for 4120 samples: 0.7746
#
# Launching training on 2 GPUs.
# BESRA Uncertainty Score Threshold 206.32860595359406
# Nearest checkpoint: 4663
# Acquired samples: 210
# Sampling duration: 100.01177835464478 seconds
#
# Fold 5 - New train size: 4330
#
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.4029, Accuracy: 0.878, F1 Micro: 0.6664, F1 Macro: 0.6536
# Epoch 2/10, Train Loss: 0.2714, Accuracy: 0.9, F1 Micro: 0.7442, F1 Macro: 0.7274
# Epoch 3/10, Train Loss: 0.2168, Accuracy: 0.8983, F1 Micro: 0.7748, F1 Macro: 0.7778
# Epoch 4/10, Train Loss: 0.1744, Accuracy: 0.9022, F1 Micro: 0.7681, F1 Macro: 0.7631
# Epoch 5/10, Train Loss: 0.1315, Accuracy: 0.9013, F1 Micro: 0.7735, F1 Macro: 0.768
# Epoch 6/10, Train Loss: 0.1096, Accuracy: 0.9022, F1 Micro: 0.7592, F1 Macro: 0.7512
# Epoch 7/10, Train Loss: 0.0761, Accuracy: 0.9072, F1 Micro: 0.7777, F1 Macro: 0.7753
# Epoch 8/10, Train Loss: 0.0565, Accuracy: 0.895, F1 Micro: 0.7627, F1 Macro: 0.7617
# Epoch 9/10, Train Loss: 0.0463, Accuracy: 0.9053, F1 Micro: 0.7653, F1 Macro: 0.7597
# Epoch 10/10, Train Loss: 0.038, Accuracy: 0.9025, F1 Micro: 0.7697, F1 Macro: 0.7637
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.4105, Accuracy: 0.8767, F1 Micro: 0.6574, F1 Macro: 0.6419
# Epoch 2/10, Train Loss: 0.2765, Accuracy: 0.9009, F1 Micro: 0.7494, F1 Macro: 0.7389
# Epoch 3/10, Train Loss: 0.2233, Accuracy: 0.8986, F1 Micro: 0.7752, F1 Macro: 0.7787
# Epoch 4/10, Train Loss: 0.1819, Accuracy: 0.902, F1 Micro: 0.7737, F1 Macro: 0.774
# Epoch 5/10, Train Loss: 0.1409, Accuracy: 0.9014, F1 Micro: 0.772, F1 Macro: 0.7655
# Epoch 6/10, Train Loss: 0.1133, Accuracy: 0.9016, F1 Micro: 0.7674, F1 Macro: 0.7647
# Epoch 7/10, Train Loss: 0.0796, Accuracy: 0.9019, F1 Micro: 0.7672, F1 Macro: 0.7634
# Epoch 8/10, Train Loss: 0.0609, Accuracy: 0.8994, F1 Micro: 0.7724, F1 Macro: 0.7697
# Epoch 9/10, Train Loss: 0.0466, Accuracy: 0.9038, F1 Micro: 0.7651, F1 Macro: 0.7589
# Epoch 10/10, Train Loss: 0.0396, Accuracy: 0.9009, F1 Micro: 0.7659, F1 Macro: 0.7622
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.412, Accuracy: 0.8784, F1 Micro: 0.6561, F1 Macro: 0.6394
# Epoch 2/10, Train Loss: 0.2775, Accuracy: 0.8994, F1 Micro: 0.7451, F1 Macro: 0.74
# Epoch 3/10, Train Loss: 0.225, Accuracy: 0.8992, F1 Micro: 0.7666, F1 Macro: 0.7661
# Epoch 4/10, Train Loss: 0.1821, Accuracy: 0.9052, F1 Micro: 0.7712, F1 Macro: 0.7653
# Epoch 5/10, Train Loss: 0.1433, Accuracy: 0.8955, F1 Micro: 0.7606, F1 Macro: 0.7568
# Epoch 6/10, Train Loss: 0.1129, Accuracy: 0.905, F1 Micro: 0.7627, F1 Macro: 0.7559
# Epoch 7/10, Train Loss: 0.0773, Accuracy: 0.9022, F1 Micro: 0.7668, F1 Macro: 0.7615
# Epoch 8/10, Train Loss: 0.0574, Accuracy: 0.8989, F1 Micro: 0.7624, F1 Macro: 0.7522
# Epoch 9/10, Train Loss: 0.0428, Accuracy: 0.9048, F1 Micro: 0.7684, F1 Macro: 0.7652
# Epoch 10/10, Train Loss: 0.0361, Accuracy: 0.9047, F1 Micro: 0.771, F1 Macro: 0.7704
#
# Fold 5 - Averaged F1-Micro for 4330 samples: 0.7747
#
# Launching training on 2 GPUs.
# BESRA Uncertainty Score Threshold 120.89874819681673
# Nearest checkpoint: 4663
# Acquired samples: 200
# Sampling duration: 90.48896360397339 seconds
#
# Fold 5 - New train size: 4530
#
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.4048, Accuracy: 0.8819, F1 Micro: 0.6879, F1 Macro: 0.6774
# Epoch 2/10, Train Loss: 0.2713, Accuracy: 0.9017, F1 Micro: 0.7627, F1 Macro: 0.7591
# Epoch 3/10, Train Loss: 0.2178, Accuracy: 0.9023, F1 Micro: 0.774, F1 Macro: 0.7704
# Epoch 4/10, Train Loss: 0.1788, Accuracy: 0.9027, F1 Micro: 0.7529, F1 Macro: 0.7346
# Epoch 5/10, Train Loss: 0.1373, Accuracy: 0.9069, F1 Micro: 0.7725, F1 Macro: 0.7698
# Epoch 6/10, Train Loss: 0.1059, Accuracy: 0.9027, F1 Micro: 0.7661, F1 Macro: 0.7615
# Epoch 7/10, Train Loss: 0.0807, Accuracy: 0.9036, F1 Micro: 0.7688, F1 Macro: 0.766
# Epoch 8/10, Train Loss: 0.0527, Accuracy: 0.9047, F1 Micro: 0.7707, F1 Macro: 0.7621
# Epoch 9/10, Train Loss: 0.0428, Accuracy: 0.9069, F1 Micro: 0.7761, F1 Macro: 0.7703
# Epoch 10/10, Train Loss: 0.0307, Accuracy: 0.9027, F1 Micro: 0.7675, F1 Macro: 0.7603
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.41, Accuracy: 0.882, F1 Micro: 0.6962, F1 Macro: 0.6871
# Epoch 2/10, Train Loss: 0.2712, Accuracy: 0.9014, F1 Micro: 0.7643, F1 Macro: 0.7602
# Epoch 3/10, Train Loss: 0.2179, Accuracy: 0.9028, F1 Micro: 0.7698, F1 Macro: 0.7677
# Epoch 4/10, Train Loss: 0.1812, Accuracy: 0.903, F1 Micro: 0.7685, F1 Macro: 0.7567
# Epoch 5/10, Train Loss: 0.1356, Accuracy: 0.9038, F1 Micro: 0.7596, F1 Macro: 0.7534
# Epoch 6/10, Train Loss: 0.105, Accuracy: 0.9023, F1 Micro: 0.761, F1 Macro: 0.7544
# Epoch 7/10, Train Loss: 0.0791, Accuracy: 0.9023, F1 Micro: 0.7614, F1 Macro: 0.747
# Epoch 8/10, Train Loss: 0.0588, Accuracy: 0.9059, F1 Micro: 0.7668, F1 Macro: 0.753
# Epoch 9/10, Train Loss: 0.0497, Accuracy: 0.9045, F1 Micro: 0.7697, F1 Macro: 0.7623
# Epoch 10/10, Train Loss: 0.0376, Accuracy: 0.903, F1 Micro: 0.7668, F1 Macro: 0.7627
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.4169, Accuracy: 0.8769, F1 Micro: 0.6523, F1 Macro: 0.6358
# Epoch 2/10, Train Loss: 0.2754, Accuracy: 0.9017, F1 Micro: 0.764, F1 Macro: 0.7609
# Epoch 3/10, Train Loss: 0.2187, Accuracy: 0.9062, F1 Micro: 0.7756, F1 Macro: 0.7703
# Epoch 4/10, Train Loss: 0.1799, Accuracy: 0.9017, F1 Micro: 0.7563, F1 Macro: 0.7442
# Epoch 5/10, Train Loss: 0.1392, Accuracy: 0.9033, F1 Micro: 0.7677, F1 Macro: 0.768
# Epoch 6/10, Train Loss: 0.1046, Accuracy: 0.9014, F1 Micro: 0.7548, F1 Macro: 0.7461
# Epoch 7/10, Train Loss: 0.078, Accuracy: 0.9023, F1 Micro: 0.77, F1 Macro: 0.7629
# Epoch 8/10, Train Loss: 0.0589, Accuracy: 0.9075, F1 Micro: 0.7746, F1 Macro: 0.7645
# Epoch 9/10, Train Loss: 0.0452, Accuracy: 0.9056, F1 Micro: 0.774, F1 Macro: 0.7709
# Epoch 10/10, Train Loss: 0.0339, Accuracy: 0.9042, F1 Micro: 0.7781, F1 Macro: 0.777
#
# Fold 5 - Averaged F1-Micro for 4530 samples: 0.7747
#
# Launching training on 2 GPUs.
# BESRA Uncertainty Score Threshold 254.96956555385353
# Nearest checkpoint: 4663
# Acquired samples: 133
# Sampling duration: 80.89987516403198 seconds
#
# Fold 5 - New train size: 4663
#
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.3983, Accuracy: 0.8834, F1 Micro: 0.7283, F1 Macro: 0.7269
# Epoch 2/10, Train Loss: 0.2574, Accuracy: 0.8991, F1 Micro: 0.7443, F1 Macro: 0.7222
# Epoch 3/10, Train Loss: 0.2127, Accuracy: 0.9067, F1 Micro: 0.7788, F1 Macro: 0.7761
# Epoch 4/10, Train Loss: 0.1706, Accuracy: 0.9077, F1 Micro: 0.7742, F1 Macro: 0.7691
# Epoch 5/10, Train Loss: 0.1306, Accuracy: 0.9081, F1 Micro: 0.7759, F1 Macro: 0.7693
# Epoch 6/10, Train Loss: 0.0915, Accuracy: 0.9045, F1 Micro: 0.7642, F1 Macro: 0.759
# Epoch 7/10, Train Loss: 0.0758, Accuracy: 0.9041, F1 Micro: 0.779, F1 Macro: 0.7783
# Epoch 8/10, Train Loss: 0.0576, Accuracy: 0.9058, F1 Micro: 0.7739, F1 Macro: 0.7712
# Epoch 9/10, Train Loss: 0.0448, Accuracy: 0.9023, F1 Micro: 0.7698, F1 Macro: 0.7642
# Epoch 10/10, Train Loss: 0.034, Accuracy: 0.9073, F1 Micro: 0.7729, F1 Macro: 0.764
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.4032, Accuracy: 0.8814, F1 Micro: 0.7219, F1 Macro: 0.7138
# Epoch 2/10, Train Loss: 0.26, Accuracy: 0.8975, F1 Micro: 0.7401, F1 Macro: 0.7184
# Epoch 3/10, Train Loss: 0.2156, Accuracy: 0.9055, F1 Micro: 0.781, F1 Macro: 0.7807
# Epoch 4/10, Train Loss: 0.1705, Accuracy: 0.9056, F1 Micro: 0.7721, F1 Macro: 0.7718
# Epoch 5/10, Train Loss: 0.1353, Accuracy: 0.9022, F1 Micro: 0.7559, F1 Macro: 0.7434
# Epoch 6/10, Train Loss: 0.0988, Accuracy: 0.8998, F1 Micro: 0.7627, F1 Macro: 0.759
# Epoch 7/10, Train Loss: 0.0804, Accuracy: 0.9014, F1 Micro: 0.7676, F1 Macro: 0.7636
# Epoch 8/10, Train Loss: 0.0526, Accuracy: 0.9028, F1 Micro: 0.7705, F1 Macro: 0.7679
# Epoch 9/10, Train Loss: 0.0475, Accuracy: 0.9036, F1 Micro: 0.7731, F1 Macro: 0.7718
# Epoch 10/10, Train Loss: 0.0362, Accuracy: 0.9048, F1 Micro: 0.7657, F1 Macro: 0.7589
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.4051, Accuracy: 0.8861, F1 Micro: 0.7199, F1 Macro: 0.7119
# Epoch 2/10, Train Loss: 0.2641, Accuracy: 0.8984, F1 Micro: 0.7368, F1 Macro: 0.7168
# Epoch 3/10, Train Loss: 0.2159, Accuracy: 0.9055, F1 Micro: 0.7747, F1 Macro: 0.7735
# Epoch 4/10, Train Loss: 0.1749, Accuracy: 0.9069, F1 Micro: 0.7732, F1 Macro: 0.7701
# Epoch 5/10, Train Loss: 0.1379, Accuracy: 0.902, F1 Micro: 0.7567, F1 Macro: 0.7451
# Epoch 6/10, Train Loss: 0.1019, Accuracy: 0.9009, F1 Micro: 0.7468, F1 Macro: 0.735
# Epoch 7/10, Train Loss: 0.0785, Accuracy: 0.9008, F1 Micro: 0.7678, F1 Macro: 0.7668
# Epoch 8/10, Train Loss: 0.0578, Accuracy: 0.8984, F1 Micro: 0.7648, F1 Macro: 0.7617
# Epoch 9/10, Train Loss: 0.0464, Accuracy: 0.8991, F1 Micro: 0.7628, F1 Macro: 0.7563
# Epoch 10/10, Train Loss: 0.032, Accuracy: 0.9047, F1 Micro: 0.7613, F1 Macro: 0.7501
#
# Fold 5 - Averaged F1-Micro for 4663 samples: 0.7782
#
# Launching training on 2 GPUs.
# BESRA Uncertainty Score Threshold 154.5383590809078
# Nearest checkpoint: 5441
# Acquired samples: 200
# Sampling duration: 74.91410994529724 seconds
#
# Fold 5 - New train size: 4863
#
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.3913, Accuracy: 0.8858, F1 Micro: 0.6973, F1 Macro: 0.6957
# Epoch 2/10, Train Loss: 0.2606, Accuracy: 0.9023, F1 Micro: 0.7563, F1 Macro: 0.7448
# Epoch 3/10, Train Loss: 0.212, Accuracy: 0.9077, F1 Micro: 0.7762, F1 Macro: 0.7723
# Epoch 4/10, Train Loss: 0.1798, Accuracy: 0.8973, F1 Micro: 0.7745, F1 Macro: 0.7744
# Epoch 5/10, Train Loss: 0.1348, Accuracy: 0.9023, F1 Micro: 0.7696, F1 Macro: 0.7628
# Epoch 6/10, Train Loss: 0.1025, Accuracy: 0.9023, F1 Micro: 0.7756, F1 Macro: 0.7735
# Epoch 7/10, Train Loss: 0.0701, Accuracy: 0.9036, F1 Micro: 0.7785, F1 Macro: 0.7762
# Epoch 8/10, Train Loss: 0.0546, Accuracy: 0.9077, F1 Micro: 0.7777, F1 Macro: 0.7722
# Epoch 9/10, Train Loss: 0.0409, Accuracy: 0.9038, F1 Micro: 0.7757, F1 Macro: 0.7711
# Epoch 10/10, Train Loss: 0.0325, Accuracy: 0.9041, F1 Micro: 0.7681, F1 Macro: 0.7632
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.3984, Accuracy: 0.8805, F1 Micro: 0.6664, F1 Macro: 0.66
# Epoch 2/10, Train Loss: 0.2627, Accuracy: 0.8998, F1 Micro: 0.7475, F1 Macro: 0.7346
# Epoch 3/10, Train Loss: 0.2133, Accuracy: 0.9023, F1 Micro: 0.7695, F1 Macro: 0.7677
# Epoch 4/10, Train Loss: 0.1828, Accuracy: 0.8952, F1 Micro: 0.7714, F1 Macro: 0.7727
# Epoch 5/10, Train Loss: 0.1372, Accuracy: 0.9059, F1 Micro: 0.7745, F1 Macro: 0.7703
# Epoch 6/10, Train Loss: 0.1038, Accuracy: 0.902, F1 Micro: 0.7776, F1 Macro: 0.7767
# Epoch 7/10, Train Loss: 0.0784, Accuracy: 0.9009, F1 Micro: 0.7676, F1 Macro: 0.7634
# Epoch 8/10, Train Loss: 0.0608, Accuracy: 0.908, F1 Micro: 0.7818, F1 Macro: 0.7786
# Epoch 9/10, Train Loss: 0.0406, Accuracy: 0.903, F1 Micro: 0.7679, F1 Macro: 0.7621
# Epoch 10/10, Train Loss: 0.0341, Accuracy: 0.8988, F1 Micro: 0.7696, F1 Macro: 0.7673
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.4022, Accuracy: 0.8836, F1 Micro: 0.6915, F1 Macro: 0.6855
# Epoch 2/10, Train Loss: 0.2686, Accuracy: 0.9, F1 Micro: 0.7494, F1 Macro: 0.7411
# Epoch 3/10, Train Loss: 0.2139, Accuracy: 0.905, F1 Micro: 0.7751, F1 Macro: 0.7705
# Epoch 4/10, Train Loss: 0.1855, Accuracy: 0.8927, F1 Micro: 0.7712, F1 Macro: 0.7717
# Epoch 5/10, Train Loss: 0.1412, Accuracy: 0.903, F1 Micro: 0.7687, F1 Macro: 0.7625
# Epoch 6/10, Train Loss: 0.1015, Accuracy: 0.9002, F1 Micro: 0.7748, F1 Macro: 0.7745
# Epoch 7/10, Train Loss: 0.0749, Accuracy: 0.8981, F1 Micro: 0.7691, F1 Macro: 0.7666
# Epoch 8/10, Train Loss: 0.0579, Accuracy: 0.902, F1 Micro: 0.7721, F1 Macro: 0.7705
# Epoch 9/10, Train Loss: 0.0434, Accuracy: 0.9039, F1 Micro: 0.7694, F1 Macro: 0.7624
# Epoch 10/10, Train Loss: 0.0318, Accuracy: 0.9042, F1 Micro: 0.7729, F1 Macro: 0.7668
#
# Fold 5 - Averaged F1-Micro for 4863 samples: 0.7785
#
# Launching training on 2 GPUs.
# BESRA Uncertainty Score Threshold 198.64721342538954
# Nearest checkpoint: 5441
# Acquired samples: 200
# Sampling duration: 66.16127610206604 seconds
#
# Fold 5 - New train size: 5063
#
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.3789, Accuracy: 0.8888, F1 Micro: 0.7321, F1 Macro: 0.7315
# Epoch 2/10, Train Loss: 0.2543, Accuracy: 0.8998, F1 Micro: 0.7713, F1 Macro: 0.7719
# Epoch 3/10, Train Loss: 0.2121, Accuracy: 0.9077, F1 Micro: 0.7772, F1 Macro: 0.7716
# Epoch 4/10, Train Loss: 0.1694, Accuracy: 0.9056, F1 Micro: 0.7719, F1 Macro: 0.7655
# Epoch 5/10, Train Loss: 0.1286, Accuracy: 0.905, F1 Micro: 0.7791, F1 Macro: 0.7765
# Epoch 6/10, Train Loss: 0.093, Accuracy: 0.9064, F1 Micro: 0.7702, F1 Macro: 0.763
# Epoch 7/10, Train Loss: 0.0675, Accuracy: 0.9025, F1 Micro: 0.7492, F1 Macro: 0.7416
# Epoch 8/10, Train Loss: 0.0531, Accuracy: 0.9045, F1 Micro: 0.7733, F1 Macro: 0.7688
# Epoch 9/10, Train Loss: 0.0414, Accuracy: 0.9017, F1 Micro: 0.7697, F1 Macro: 0.7634
# Epoch 10/10, Train Loss: 0.0344, Accuracy: 0.9089, F1 Micro: 0.7748, F1 Macro: 0.7671
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.3861, Accuracy: 0.8872, F1 Micro: 0.731, F1 Macro: 0.7314
# Epoch 2/10, Train Loss: 0.2584, Accuracy: 0.8983, F1 Micro: 0.7666, F1 Macro: 0.7663
# Epoch 3/10, Train Loss: 0.2129, Accuracy: 0.9078, F1 Micro: 0.7812, F1 Macro: 0.7764
# Epoch 4/10, Train Loss: 0.1728, Accuracy: 0.8997, F1 Micro: 0.7654, F1 Macro: 0.7606
# Epoch 5/10, Train Loss: 0.1334, Accuracy: 0.9038, F1 Micro: 0.7744, F1 Macro: 0.7703
# Epoch 6/10, Train Loss: 0.0986, Accuracy: 0.9031, F1 Micro: 0.7419, F1 Macro: 0.7214
# Epoch 7/10, Train Loss: 0.0706, Accuracy: 0.9006, F1 Micro: 0.7655, F1 Macro: 0.7598
# Epoch 8/10, Train Loss: 0.0536, Accuracy: 0.9042, F1 Micro: 0.776, F1 Macro: 0.7769
# Epoch 9/10, Train Loss: 0.0441, Accuracy: 0.9033, F1 Micro: 0.7718, F1 Macro: 0.7695
# Epoch 10/10, Train Loss: 0.0322, Accuracy: 0.9033, F1 Micro: 0.7696, F1 Macro: 0.7663
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.3878, Accuracy: 0.8845, F1 Micro: 0.7256, F1 Macro: 0.7273
# Epoch 2/10, Train Loss: 0.2611, Accuracy: 0.9003, F1 Micro: 0.769, F1 Macro: 0.7642
# Epoch 3/10, Train Loss: 0.2164, Accuracy: 0.9047, F1 Micro: 0.7719, F1 Macro: 0.7644
# Epoch 4/10, Train Loss: 0.1744, Accuracy: 0.905, F1 Micro: 0.7695, F1 Macro: 0.7612
# Epoch 5/10, Train Loss: 0.1344, Accuracy: 0.903, F1 Micro: 0.7731, F1 Macro: 0.7694
# Epoch 6/10, Train Loss: 0.0923, Accuracy: 0.9019, F1 Micro: 0.7486, F1 Macro: 0.7421
# Epoch 7/10, Train Loss: 0.0728, Accuracy: 0.9031, F1 Micro: 0.7576, F1 Macro: 0.7506
# Epoch 8/10, Train Loss: 0.0514, Accuracy: 0.9045, F1 Micro: 0.7748, F1 Macro: 0.7733
# Epoch 9/10, Train Loss: 0.0415, Accuracy: 0.9047, F1 Micro: 0.7744, F1 Macro: 0.7662
# Epoch 10/10, Train Loss: 0.0357, Accuracy: 0.9044, F1 Micro: 0.7742, F1 Macro: 0.7713
#
# Fold 5 - Averaged F1-Micro for 5063 samples: 0.7783
#
# Launching training on 2 GPUs.
# BESRA Uncertainty Score Threshold 226.45555745319177
# Nearest checkpoint: 5441
# Acquired samples: 200
# Sampling duration: 55.66685962677002 seconds
#
# Fold 5 - New train size: 5263
#
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.3761, Accuracy: 0.8908, F1 Micro: 0.721, F1 Macro: 0.7154
# Epoch 2/10, Train Loss: 0.2528, Accuracy: 0.9009, F1 Micro: 0.771, F1 Macro: 0.7716
# Epoch 3/10, Train Loss: 0.2011, Accuracy: 0.9061, F1 Micro: 0.7651, F1 Macro: 0.7595
# Epoch 4/10, Train Loss: 0.1648, Accuracy: 0.905, F1 Micro: 0.7614, F1 Macro: 0.7536
# Epoch 5/10, Train Loss: 0.1196, Accuracy: 0.9019, F1 Micro: 0.7628, F1 Macro: 0.7554
# Epoch 6/10, Train Loss: 0.095, Accuracy: 0.9048, F1 Micro: 0.7799, F1 Macro: 0.7799
# Epoch 7/10, Train Loss: 0.0689, Accuracy: 0.9059, F1 Micro: 0.7706, F1 Macro: 0.7627
# Epoch 8/10, Train Loss: 0.0538, Accuracy: 0.9086, F1 Micro: 0.7703, F1 Macro: 0.7647
# Epoch 9/10, Train Loss: 0.0457, Accuracy: 0.9083, F1 Micro: 0.7743, F1 Macro: 0.7667
# Epoch 10/10, Train Loss: 0.0321, Accuracy: 0.9066, F1 Micro: 0.7827, F1 Macro: 0.7805
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.384, Accuracy: 0.8902, F1 Micro: 0.7122, F1 Macro: 0.7011
# Epoch 2/10, Train Loss: 0.2571, Accuracy: 0.9022, F1 Micro: 0.7707, F1 Macro: 0.7707
# Epoch 3/10, Train Loss: 0.2031, Accuracy: 0.905, F1 Micro: 0.7685, F1 Macro: 0.7651
# Epoch 4/10, Train Loss: 0.1666, Accuracy: 0.9083, F1 Micro: 0.7738, F1 Macro: 0.7675
# Epoch 5/10, Train Loss: 0.1242, Accuracy: 0.9041, F1 Micro: 0.7581, F1 Macro: 0.7484
# Epoch 6/10, Train Loss: 0.099, Accuracy: 0.9006, F1 Micro: 0.7781, F1 Macro: 0.7786
# Epoch 7/10, Train Loss: 0.0723, Accuracy: 0.905, F1 Micro: 0.7706, F1 Macro: 0.7646
# Epoch 8/10, Train Loss: 0.0583, Accuracy: 0.9023, F1 Micro: 0.7637, F1 Macro: 0.7562
# Epoch 9/10, Train Loss: 0.0404, Accuracy: 0.9019, F1 Micro: 0.7564, F1 Macro: 0.7412
# Epoch 10/10, Train Loss: 0.0359, Accuracy: 0.905, F1 Micro: 0.754, F1 Macro: 0.7479
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.3846, Accuracy: 0.8889, F1 Micro: 0.7099, F1 Macro: 0.7045
# Epoch 2/10, Train Loss: 0.2629, Accuracy: 0.9017, F1 Micro: 0.7629, F1 Macro: 0.7629
# Epoch 3/10, Train Loss: 0.2036, Accuracy: 0.9047, F1 Micro: 0.7626, F1 Macro: 0.7567
# Epoch 4/10, Train Loss: 0.1671, Accuracy: 0.9073, F1 Micro: 0.7657, F1 Macro: 0.756
# Epoch 5/10, Train Loss: 0.1215, Accuracy: 0.9028, F1 Micro: 0.7676, F1 Macro: 0.7637
# Epoch 6/10, Train Loss: 0.0978, Accuracy: 0.9055, F1 Micro: 0.7818, F1 Macro: 0.779
# Epoch 7/10, Train Loss: 0.0708, Accuracy: 0.9069, F1 Micro: 0.7639, F1 Macro: 0.754
# Epoch 8/10, Train Loss: 0.0529, Accuracy: 0.9052, F1 Micro: 0.7637, F1 Macro: 0.7551
# Epoch 9/10, Train Loss: 0.0448, Accuracy: 0.9034, F1 Micro: 0.7597, F1 Macro: 0.7516
# Epoch 10/10, Train Loss: 0.0308, Accuracy: 0.9078, F1 Micro: 0.7836, F1 Macro: 0.7803
#
# Fold 5 - Averaged F1-Micro for 5263 samples: 0.7815
#
# Launching training on 2 GPUs.
# BESRA Uncertainty Score Threshold 235.3900811114824
# Nearest checkpoint: 5441
# Acquired samples: 178
# Sampling duration: 46.39161539077759 seconds
#
# Fold 5 - New train size: 5441
#
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.373, Accuracy: 0.8898, F1 Micro: 0.742, F1 Macro: 0.7367
# Epoch 2/10, Train Loss: 0.2426, Accuracy: 0.9011, F1 Micro: 0.7653, F1 Macro: 0.7561
# Epoch 3/10, Train Loss: 0.2009, Accuracy: 0.9044, F1 Micro: 0.7817, F1 Macro: 0.7803
# Epoch 4/10, Train Loss: 0.1636, Accuracy: 0.9059, F1 Micro: 0.7755, F1 Macro: 0.7696
# Epoch 5/10, Train Loss: 0.1248, Accuracy: 0.9042, F1 Micro: 0.7737, F1 Macro: 0.7728
# Epoch 6/10, Train Loss: 0.0882, Accuracy: 0.8995, F1 Micro: 0.7743, F1 Macro: 0.7742
# Epoch 7/10, Train Loss: 0.0659, Accuracy: 0.8994, F1 Micro: 0.775, F1 Macro: 0.7748
# Epoch 8/10, Train Loss: 0.0512, Accuracy: 0.9038, F1 Micro: 0.7693, F1 Macro: 0.7612
# Epoch 9/10, Train Loss: 0.0399, Accuracy: 0.903, F1 Micro: 0.7769, F1 Macro: 0.7741
# Epoch 10/10, Train Loss: 0.0323, Accuracy: 0.9056, F1 Micro: 0.7746, F1 Macro: 0.7729
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.3786, Accuracy: 0.89, F1 Micro: 0.7414, F1 Macro: 0.7328
# Epoch 2/10, Train Loss: 0.2433, Accuracy: 0.8991, F1 Micro: 0.7628, F1 Macro: 0.7531
# Epoch 3/10, Train Loss: 0.2022, Accuracy: 0.9038, F1 Micro: 0.7766, F1 Macro: 0.7732
# Epoch 4/10, Train Loss: 0.1634, Accuracy: 0.9056, F1 Micro: 0.7722, F1 Macro: 0.7649
# Epoch 5/10, Train Loss: 0.1262, Accuracy: 0.905, F1 Micro: 0.7748, F1 Macro: 0.7725
# Epoch 6/10, Train Loss: 0.0929, Accuracy: 0.9013, F1 Micro: 0.7768, F1 Macro: 0.7777
# Epoch 7/10, Train Loss: 0.0728, Accuracy: 0.8953, F1 Micro: 0.7705, F1 Macro: 0.7707
# Epoch 8/10, Train Loss: 0.0533, Accuracy: 0.9036, F1 Micro: 0.7786, F1 Macro: 0.7776
# Epoch 9/10, Train Loss: 0.0407, Accuracy: 0.9058, F1 Micro: 0.7744, F1 Macro: 0.7681
# Epoch 10/10, Train Loss: 0.0317, Accuracy: 0.9069, F1 Micro: 0.7799, F1 Macro: 0.7758
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.3828, Accuracy: 0.8911, F1 Micro: 0.7379, F1 Macro: 0.7292
# Epoch 2/10, Train Loss: 0.2456, Accuracy: 0.9013, F1 Micro: 0.7635, F1 Macro: 0.7545
# Epoch 3/10, Train Loss: 0.2061, Accuracy: 0.9031, F1 Micro: 0.7754, F1 Macro: 0.7747
# Epoch 4/10, Train Loss: 0.1689, Accuracy: 0.9039, F1 Micro: 0.7713, F1 Macro: 0.7641
# Epoch 5/10, Train Loss: 0.1322, Accuracy: 0.9022, F1 Micro: 0.7785, F1 Macro: 0.7771
# Epoch 6/10, Train Loss: 0.0954, Accuracy: 0.9022, F1 Micro: 0.7764, F1 Macro: 0.7752
# Epoch 7/10, Train Loss: 0.0711, Accuracy: 0.9042, F1 Micro: 0.7719, F1 Macro: 0.7685
# Epoch 8/10, Train Loss: 0.0536, Accuracy: 0.898, F1 Micro: 0.7774, F1 Macro: 0.7803
# Epoch 9/10, Train Loss: 0.0461, Accuracy: 0.9027, F1 Micro: 0.7771, F1 Macro: 0.7758
# Epoch 10/10, Train Loss: 0.0323, Accuracy: 0.907, F1 Micro: 0.7842, F1 Macro: 0.783
#
# Fold 5 - Averaged F1-Micro for 5441 samples: 0.7819
#
# Launching training on 2 GPUs.
# BESRA Uncertainty Score Threshold 173.37504820627353
# Nearest checkpoint: 6219
# Acquired samples: 200
# Sampling duration: 39.36001396179199 seconds
#
# Fold 5 - New train size: 5641
#
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.3676, Accuracy: 0.8877, F1 Micro: 0.6939, F1 Macro: 0.6761
# Epoch 2/10, Train Loss: 0.2497, Accuracy: 0.9042, F1 Micro: 0.7768, F1 Macro: 0.771
# Epoch 3/10, Train Loss: 0.2046, Accuracy: 0.9036, F1 Micro: 0.769, F1 Macro: 0.7638
# Epoch 4/10, Train Loss: 0.1591, Accuracy: 0.8998, F1 Micro: 0.7795, F1 Macro: 0.7815
# Epoch 5/10, Train Loss: 0.1242, Accuracy: 0.9066, F1 Micro: 0.7782, F1 Macro: 0.7755
# Epoch 6/10, Train Loss: 0.0959, Accuracy: 0.9067, F1 Micro: 0.7685, F1 Macro: 0.7587
# Epoch 7/10, Train Loss: 0.0728, Accuracy: 0.9033, F1 Micro: 0.7755, F1 Macro: 0.7747
# Epoch 8/10, Train Loss: 0.0493, Accuracy: 0.9017, F1 Micro: 0.7788, F1 Macro: 0.7794
# Epoch 9/10, Train Loss: 0.0394, Accuracy: 0.8972, F1 Micro: 0.7694, F1 Macro: 0.7712
# Epoch 10/10, Train Loss: 0.0327, Accuracy: 0.9036, F1 Micro: 0.7739, F1 Macro: 0.7696
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.3763, Accuracy: 0.8819, F1 Micro: 0.6739, F1 Macro: 0.653
# Epoch 2/10, Train Loss: 0.2501, Accuracy: 0.9022, F1 Micro: 0.772, F1 Macro: 0.7664
# Epoch 3/10, Train Loss: 0.2051, Accuracy: 0.9053, F1 Micro: 0.7722, F1 Macro: 0.765
# Epoch 4/10, Train Loss: 0.1603, Accuracy: 0.8994, F1 Micro: 0.7775, F1 Macro: 0.7782
# Epoch 5/10, Train Loss: 0.1278, Accuracy: 0.9031, F1 Micro: 0.775, F1 Macro: 0.7739
# Epoch 6/10, Train Loss: 0.0991, Accuracy: 0.9033, F1 Micro: 0.7644, F1 Macro: 0.7527
# Epoch 7/10, Train Loss: 0.0747, Accuracy: 0.9041, F1 Micro: 0.7777, F1 Macro: 0.7778
# Epoch 8/10, Train Loss: 0.055, Accuracy: 0.9041, F1 Micro: 0.7795, F1 Macro: 0.7798
# Epoch 9/10, Train Loss: 0.0377, Accuracy: 0.9036, F1 Micro: 0.7778, F1 Macro: 0.7762
# Epoch 10/10, Train Loss: 0.032, Accuracy: 0.905, F1 Micro: 0.7738, F1 Macro: 0.7689
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.3795, Accuracy: 0.885, F1 Micro: 0.6895, F1 Macro: 0.6732
# Epoch 2/10, Train Loss: 0.2508, Accuracy: 0.9022, F1 Micro: 0.7725, F1 Macro: 0.7672
# Epoch 3/10, Train Loss: 0.2084, Accuracy: 0.9048, F1 Micro: 0.7657, F1 Macro: 0.7588
# Epoch 4/10, Train Loss: 0.1622, Accuracy: 0.9036, F1 Micro: 0.7813, F1 Macro: 0.7804
# Epoch 5/10, Train Loss: 0.1292, Accuracy: 0.9053, F1 Micro: 0.766, F1 Macro: 0.7587
# Epoch 6/10, Train Loss: 0.0992, Accuracy: 0.9025, F1 Micro: 0.767, F1 Macro: 0.7556
# Epoch 7/10, Train Loss: 0.0746, Accuracy: 0.9028, F1 Micro: 0.778, F1 Macro: 0.7773
# Epoch 8/10, Train Loss: 0.0545, Accuracy: 0.9067, F1 Micro: 0.7781, F1 Macro: 0.7716
# Epoch 9/10, Train Loss: 0.0378, Accuracy: 0.9, F1 Micro: 0.7671, F1 Macro: 0.7614
# Epoch 10/10, Train Loss: 0.0311, Accuracy: 0.9072, F1 Micro: 0.7748, F1 Macro: 0.7658
#
# Fold 5 - Averaged F1-Micro for 5641 samples: 0.7801
#
# Launching training on 2 GPUs.
# BESRA Uncertainty Score Threshold 174.64973846771653
# Nearest checkpoint: 6219
# Acquired samples: 200
# Sampling duration: 29.641167640686035 seconds
#
# Fold 5 - New train size: 5841
#
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.3669, Accuracy: 0.8922, F1 Micro: 0.7454, F1 Macro: 0.7365
# Epoch 2/10, Train Loss: 0.2408, Accuracy: 0.897, F1 Micro: 0.7745, F1 Macro: 0.7741
# Epoch 3/10, Train Loss: 0.2057, Accuracy: 0.9, F1 Micro: 0.7773, F1 Macro: 0.776
# Epoch 4/10, Train Loss: 0.1675, Accuracy: 0.9072, F1 Micro: 0.7762, F1 Macro: 0.7708
# Epoch 5/10, Train Loss: 0.1248, Accuracy: 0.9087, F1 Micro: 0.7805, F1 Macro: 0.7735
# Epoch 6/10, Train Loss: 0.0896, Accuracy: 0.9028, F1 Micro: 0.7561, F1 Macro: 0.7412
# Epoch 7/10, Train Loss: 0.0689, Accuracy: 0.9047, F1 Micro: 0.7775, F1 Macro: 0.7744
# Epoch 8/10, Train Loss: 0.0527, Accuracy: 0.9033, F1 Micro: 0.7635, F1 Macro: 0.7536
# Epoch 9/10, Train Loss: 0.0357, Accuracy: 0.9047, F1 Micro: 0.7657, F1 Macro: 0.7582
# Epoch 10/10, Train Loss: 0.0289, Accuracy: 0.9039, F1 Micro: 0.7761, F1 Macro: 0.7743
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.3747, Accuracy: 0.8938, F1 Micro: 0.7463, F1 Macro: 0.7342
# Epoch 2/10, Train Loss: 0.2438, Accuracy: 0.8989, F1 Micro: 0.7773, F1 Macro: 0.7782
# Epoch 3/10, Train Loss: 0.2041, Accuracy: 0.9019, F1 Micro: 0.7786, F1 Macro: 0.7778
# Epoch 4/10, Train Loss: 0.167, Accuracy: 0.9036, F1 Micro: 0.776, F1 Macro: 0.7731
# Epoch 5/10, Train Loss: 0.1265, Accuracy: 0.9084, F1 Micro: 0.7779, F1 Macro: 0.7726
# Epoch 6/10, Train Loss: 0.0878, Accuracy: 0.9042, F1 Micro: 0.7529, F1 Macro: 0.7418
# Epoch 7/10, Train Loss: 0.0738, Accuracy: 0.9056, F1 Micro: 0.7722, F1 Macro: 0.7666
# Epoch 8/10, Train Loss: 0.0529, Accuracy: 0.9036, F1 Micro: 0.7726, F1 Macro: 0.7687
# Epoch 9/10, Train Loss: 0.0391, Accuracy: 0.9039, F1 Micro: 0.7769, F1 Macro: 0.7742
# Epoch 10/10, Train Loss: 0.0316, Accuracy: 0.9087, F1 Micro: 0.7783, F1 Macro: 0.7752
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.3764, Accuracy: 0.8925, F1 Micro: 0.7435, F1 Macro: 0.7308
# Epoch 2/10, Train Loss: 0.2466, Accuracy: 0.8992, F1 Micro: 0.7758, F1 Macro: 0.7741
# Epoch 3/10, Train Loss: 0.2045, Accuracy: 0.9, F1 Micro: 0.7751, F1 Macro: 0.773
# Epoch 4/10, Train Loss: 0.167, Accuracy: 0.9038, F1 Micro: 0.7755, F1 Macro: 0.7724
# Epoch 5/10, Train Loss: 0.1261, Accuracy: 0.9073, F1 Micro: 0.7783, F1 Macro: 0.774
# Epoch 6/10, Train Loss: 0.0859, Accuracy: 0.9041, F1 Micro: 0.7546, F1 Macro: 0.7408
# Epoch 7/10, Train Loss: 0.0714, Accuracy: 0.9027, F1 Micro: 0.7787, F1 Macro: 0.7801
# Epoch 8/10, Train Loss: 0.0505, Accuracy: 0.9047, F1 Micro: 0.7754, F1 Macro: 0.7711
# Epoch 9/10, Train Loss: 0.0381, Accuracy: 0.9044, F1 Micro: 0.7776, F1 Macro: 0.7746
# Epoch 10/10, Train Loss: 0.0281, Accuracy: 0.9028, F1 Micro: 0.7715, F1 Macro: 0.771
#
# Fold 5 - Averaged F1-Micro for 5841 samples: 0.7792
#
# Launching training on 2 GPUs.
# BESRA Uncertainty Score Threshold 324.67614346216396
# Nearest checkpoint: 6219
# Acquired samples: 200
# Sampling duration: 19.425511121749878 seconds
#
# Fold 5 - New train size: 6041
#
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.361, Accuracy: 0.893, F1 Micro: 0.7352, F1 Macro: 0.732
# Epoch 2/10, Train Loss: 0.2408, Accuracy: 0.9053, F1 Micro: 0.7831, F1 Macro: 0.7819
# Epoch 3/10, Train Loss: 0.1943, Accuracy: 0.9058, F1 Micro: 0.7562, F1 Macro: 0.7446
# Epoch 4/10, Train Loss: 0.1555, Accuracy: 0.9069, F1 Micro: 0.7817, F1 Macro: 0.7773
# Epoch 5/10, Train Loss: 0.1234, Accuracy: 0.908, F1 Micro: 0.785, F1 Macro: 0.7834
# Epoch 6/10, Train Loss: 0.0884, Accuracy: 0.9042, F1 Micro: 0.7703, F1 Macro: 0.7668
# Epoch 7/10, Train Loss: 0.063, Accuracy: 0.9044, F1 Micro: 0.783, F1 Macro: 0.7841
# Epoch 8/10, Train Loss: 0.0522, Accuracy: 0.9083, F1 Micro: 0.7817, F1 Macro: 0.776
# Epoch 9/10, Train Loss: 0.0366, Accuracy: 0.9042, F1 Micro: 0.7819, F1 Macro: 0.7811
# Epoch 10/10, Train Loss: 0.0322, Accuracy: 0.9047, F1 Micro: 0.7803, F1 Macro: 0.7774
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.3663, Accuracy: 0.8928, F1 Micro: 0.7351, F1 Macro: 0.7355
# Epoch 2/10, Train Loss: 0.2394, Accuracy: 0.9047, F1 Micro: 0.7803, F1 Macro: 0.7792
# Epoch 3/10, Train Loss: 0.1926, Accuracy: 0.9044, F1 Micro: 0.7471, F1 Macro: 0.7346
# Epoch 4/10, Train Loss: 0.157, Accuracy: 0.9047, F1 Micro: 0.779, F1 Macro: 0.7766
# Epoch 5/10, Train Loss: 0.1266, Accuracy: 0.9052, F1 Micro: 0.7809, F1 Macro: 0.7799
# Epoch 6/10, Train Loss: 0.0906, Accuracy: 0.9031, F1 Micro: 0.7681, F1 Macro: 0.7667
# Epoch 7/10, Train Loss: 0.0636, Accuracy: 0.9059, F1 Micro: 0.7811, F1 Macro: 0.7781
# Epoch 8/10, Train Loss: 0.0477, Accuracy: 0.9028, F1 Micro: 0.7755, F1 Macro: 0.774
# Epoch 9/10, Train Loss: 0.0392, Accuracy: 0.9077, F1 Micro: 0.7804, F1 Macro: 0.7756
# Epoch 10/10, Train Loss: 0.0323, Accuracy: 0.9014, F1 Micro: 0.7648, F1 Macro: 0.7589
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.3688, Accuracy: 0.8903, F1 Micro: 0.7355, F1 Macro: 0.7346
# Epoch 2/10, Train Loss: 0.2452, Accuracy: 0.902, F1 Micro: 0.7798, F1 Macro: 0.7801
# Epoch 3/10, Train Loss: 0.1964, Accuracy: 0.9047, F1 Micro: 0.7574, F1 Macro: 0.7465
# Epoch 4/10, Train Loss: 0.161, Accuracy: 0.9055, F1 Micro: 0.7794, F1 Macro: 0.7757
# Epoch 5/10, Train Loss: 0.1291, Accuracy: 0.9034, F1 Micro: 0.7764, F1 Macro: 0.7737
# Epoch 6/10, Train Loss: 0.094, Accuracy: 0.9016, F1 Micro: 0.7711, F1 Macro: 0.7707
# Epoch 7/10, Train Loss: 0.0669, Accuracy: 0.9006, F1 Micro: 0.7804, F1 Macro: 0.7792
# Epoch 8/10, Train Loss: 0.0558, Accuracy: 0.9055, F1 Micro: 0.772, F1 Macro: 0.7658
# Epoch 9/10, Train Loss: 0.0395, Accuracy: 0.8989, F1 Micro: 0.7734, F1 Macro: 0.7707
# Epoch 10/10, Train Loss: 0.0312, Accuracy: 0.9016, F1 Micro: 0.7744, F1 Macro: 0.771
#
# Fold 5 - Averaged F1-Micro for 6041 samples: 0.7821
#
# Launching training on 2 GPUs.
# BESRA Uncertainty Score Threshold 166.12318650388016
# Nearest checkpoint: 6219
# Acquired samples: 178
# Sampling duration: 6.675543546676636 seconds
#
# Fold 5 - New train size: 6219
#
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.3582, Accuracy: 0.8972, F1 Micro: 0.7436, F1 Macro: 0.7384
# Epoch 2/10, Train Loss: 0.2264, Accuracy: 0.9038, F1 Micro: 0.7786, F1 Macro: 0.7762
# Epoch 3/10, Train Loss: 0.1861, Accuracy: 0.9033, F1 Micro: 0.7763, F1 Macro: 0.7702
# Epoch 4/10, Train Loss: 0.1565, Accuracy: 0.8964, F1 Micro: 0.7719, F1 Macro: 0.7735
# Epoch 5/10, Train Loss: 0.1086, Accuracy: 0.9055, F1 Micro: 0.7757, F1 Macro: 0.7681
# Epoch 6/10, Train Loss: 0.0877, Accuracy: 0.9095, F1 Micro: 0.7746, F1 Macro: 0.7675
# Epoch 7/10, Train Loss: 0.0628, Accuracy: 0.9069, F1 Micro: 0.7822, F1 Macro: 0.7826
# Epoch 8/10, Train Loss: 0.0437, Accuracy: 0.9056, F1 Micro: 0.7861, F1 Macro: 0.7848
# Epoch 9/10, Train Loss: 0.0302, Accuracy: 0.9066, F1 Micro: 0.7718, F1 Macro: 0.7633
# Epoch 10/10, Train Loss: 0.0293, Accuracy: 0.9092, F1 Micro: 0.7862, F1 Macro: 0.7846
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.3642, Accuracy: 0.8959, F1 Micro: 0.7394, F1 Macro: 0.7378
# Epoch 2/10, Train Loss: 0.2293, Accuracy: 0.903, F1 Micro: 0.7726, F1 Macro: 0.7715
# Epoch 3/10, Train Loss: 0.1889, Accuracy: 0.907, F1 Micro: 0.7802, F1 Macro: 0.7745
# Epoch 4/10, Train Loss: 0.1567, Accuracy: 0.895, F1 Micro: 0.7724, F1 Macro: 0.7728
# Epoch 5/10, Train Loss: 0.1126, Accuracy: 0.9058, F1 Micro: 0.7675, F1 Macro: 0.7562
# Epoch 6/10, Train Loss: 0.0885, Accuracy: 0.9077, F1 Micro: 0.7747, F1 Macro: 0.7715
# Epoch 7/10, Train Loss: 0.0654, Accuracy: 0.9047, F1 Micro: 0.7727, F1 Macro: 0.7698
# Epoch 8/10, Train Loss: 0.0461, Accuracy: 0.9059, F1 Micro: 0.7824, F1 Macro: 0.7807
# Epoch 9/10, Train Loss: 0.0348, Accuracy: 0.9075, F1 Micro: 0.7725, F1 Macro: 0.7648
# Epoch 10/10, Train Loss: 0.0293, Accuracy: 0.9027, F1 Micro: 0.7714, F1 Macro: 0.7697
# Launching training on 2 GPUs.
# Epoch 1/10, Train Loss: 0.3652, Accuracy: 0.8922, F1 Micro: 0.7315, F1 Macro: 0.7288
# Epoch 2/10, Train Loss: 0.2276, Accuracy: 0.9031, F1 Micro: 0.7768, F1 Macro: 0.7746
# Epoch 3/10, Train Loss: 0.1903, Accuracy: 0.9038, F1 Micro: 0.7725, F1 Macro: 0.7669
# Epoch 4/10, Train Loss: 0.1564, Accuracy: 0.9033, F1 Micro: 0.7803, F1 Macro: 0.7781
# Epoch 5/10, Train Loss: 0.1116, Accuracy: 0.9081, F1 Micro: 0.7751, F1 Macro: 0.767
# Epoch 6/10, Train Loss: 0.0888, Accuracy: 0.9066, F1 Micro: 0.7816, F1 Macro: 0.7802
# Epoch 7/10, Train Loss: 0.0652, Accuracy: 0.9081, F1 Micro: 0.7776, F1 Macro: 0.7713
# Epoch 8/10, Train Loss: 0.0461, Accuracy: 0.9042, F1 Micro: 0.7832, F1 Macro: 0.7835
# Epoch 9/10, Train Loss: 0.0331, Accuracy: 0.9089, F1 Micro: 0.7718, F1 Macro: 0.7655
# Epoch 10/10, Train Loss: 0.0278, Accuracy: 0.9077, F1 Micro: 0.7864, F1 Macro: 0.7845
#
# Fold 5 - Averaged F1-Micro for 6219 samples: 0.7850
#
#
# FOLD 5 COMPLETED in 12304.72 seconds

# %%
import matplotlib.pyplot as plt
import numpy as np

common_data_points = sorted(list(set(point for fold_points in all_fold_data_used for point in fold_points)))

# Interpolate metrics for each fold to the common data points
avg_accuracies = []
avg_f1_micros = []
avg_f1_macros = []
std_accuracies = []
std_f1_micros = []
std_f1_macros = []

for point in common_data_points:
    point_accuracies = []
    point_f1_micros = []
    point_f1_macros = []
    for i in range(1):
        sorted_indices = np.argsort(all_fold_data_used[i])
        sorted_data = np.array(all_fold_data_used[i])[sorted_indices]
        
        sorted_acc = np.array(all_fold_accuracies[i])[sorted_indices]
        sorted_f1m = np.array(all_fold_f1_micros[i])[sorted_indices]
        sorted_f1ma = np.array(all_fold_f1_macros[i])[sorted_indices]
        
        # Use interpolation to estimate the metric value at the common 'point'
        point_accuracies.append(np.interp(point, sorted_data, sorted_acc))
        point_f1_micros.append(np.interp(point, sorted_data, sorted_f1m))
        point_f1_macros.append(np.interp(point, sorted_data, sorted_f1ma))
    
    avg_accuracies.append(np.mean(point_accuracies))
    avg_f1_micros.append(np.mean(point_f1_micros))
    avg_f1_macros.append(np.mean(point_f1_macros))
    
    std_accuracies.append(np.std(point_accuracies))
    std_f1_micros.append(np.std(point_f1_micros))
    std_f1_macros.append(np.std(point_f1_macros))

# Convert to numpy arrays for easier plotting
avg_accuracies = np.array(avg_accuracies)
avg_f1_micros = np.array(avg_f1_micros)
avg_f1_macros = np.array(avg_f1_macros)
std_accuracies = np.array(std_accuracies)
std_f1_micros = np.array(std_f1_micros)
std_f1_macros = np.array(std_f1_macros)

fig, axs = plt.subplots(1, 3, figsize=(21, 5))
data_used_percent = [round(data / len(X) * 100, 1) for data in common_data_points]

# Plot for Accuracy
axs[0].plot(data_used_percent, avg_accuracies, label="Avg Accuracy", color="blue")
axs[0].fill_between(data_used_percent, avg_accuracies - std_accuracies, avg_accuracies + std_accuracies, color='blue', alpha=0.2)
axs[0].set_xlabel("Percentage of data used")
axs[0].set_title("Average Accuracy Across Folds")

# Plot for F1 Micro
axs[1].plot(data_used_percent, avg_f1_micros, label="Avg F1 Micro", color="orange")
axs[1].fill_between(data_used_percent, avg_f1_micros - std_f1_micros, avg_f1_micros + std_f1_micros, color='orange', alpha=0.2)
axs[1].set_xlabel("Percentage of data used")
axs[1].set_title("Average F1 Micro Across Folds")

# Plot for F1 Macro
axs[2].plot(data_used_percent, avg_f1_macros, label="Avg F1 Macro", color="green")
axs[2].fill_between(data_used_percent, avg_f1_macros - std_f1_macros, avg_f1_macros + std_f1_macros, color='green', alpha=0.2)
axs[2].set_xlabel("Percentage of data used")
axs[2].set_title("Average F1 Macro Across Folds")

# Adjust layout and show the plots
plt.tight_layout()
plt.show()

for i in range(1):
    result = pd.DataFrame({
        'Data Used': all_fold_data_used[i],
        'Accuracy': all_fold_accuracies[i],
        'F1 Micro': all_fold_f1_micros[i],
        'F1 Macro': all_fold_f1_macros[i],
    })

    result.to_csv(f'results/{filename}-5-results.csv', index=False)
