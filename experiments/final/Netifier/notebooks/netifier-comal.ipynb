# %%
import numpy as np
import pandas as pd
import re
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
import torch.optim.lr_scheduler as lr_scheduler
import time
import tqdm
import os
import random
import math
from transformers import BertTokenizer, BertModel, BertConfig, BertForSequenceClassification, AdamW
from torch.utils.data import DataLoader, Dataset
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, f1_score, classification_report
from sklearn.metrics.pairwise import pairwise_distances
from torch.utils.data.sampler import SubsetRandomSampler

# %%
os.mkdir('/kaggle/working/netifier-comal-p1')
os.mkdir('/kaggle/working/netifier-comal-p2')

# %%
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)

# %%
train_data = pd.read_csv('/kaggle/input/netifier-2/processed_train.csv', encoding='latin-1')
test_data = pd.read_csv('/kaggle/input/netifier-2/processed_test.csv', encoding='latin-1')

data = pd.concat([train_data, test_data], ignore_index=True)
data.shape
# Out:
# (7773, 7)

# %%
data.head()
# Out:
#                                        original_text     source  pornografi  \
# 0  [QUOTE=jessepinkman16;5a50ac34d89b093f368b456e...     kaskus           0
# 1  @verosvante kita2 aja nitizen yang pada kepo,t...  instagram           0
# 2  "#SidangAhok smg sipenista agama n ateknya mat...    twitter           0
# 3  @bolususulembang.jkt barusan baca undang2 ini....  instagram           0
# 4  bikin anak mulu lu nof \nkaga mikir apa kasian...     kaskus           0
#
#    sara  radikalisme  pencemaran_nama_baik  \
# 0     0            0                     1
# 1     0            0                     0
# 2     1            1                     1
# 3     0            0                     0
# 4     0            0                     0
#
#                                       processed_text
# 0  jabar memang provinsi barokah boleh juga dan n...
# 1  kita saja nitizen yang pada penasaran toh kelu...
# 2  sidangahok semoga sipenista agama dan ateknya ...
# 3  jakarta barusan baca undang ini tetap dibedaka...
# 4  buat anak melulu kamu nof nkaga mikir apa kasi...

# %%
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42, shuffle=False)

train_labels = train_data.columns[2:6]
test_labels = test_data.columns[2:6]

# Extract features and labels for training and validation
X_train = train_data['processed_text'].values
y_train = train_data[train_labels].values
X_test = test_data['processed_text'].values
y_test = test_data[test_labels].values

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (6218,) (6218, 4)
# (1555,) (1555, 4)

# %%
filename = 'netifier-comal'
epochs = 10
total_data = len(train_data) + len(test_data)
initial_train_size = int(0.05 * total_data)
checkpoints = [
    int(0.5 * total_data), 
    int(0.6 * total_data), 
    int(0.7 * total_data),
    len(X_train)
]
min_increment = 200

accuracies = []
f1_micros = []
f1_macros = []
sampling_dur = []
data_used = []

# %% [markdown]
# # BULDING DATASET

# %%
class ClfDataset(Dataset):
    def __init__(self, data, labels, tokenizer, label2id):
        # Initialize dataset with data, tokenizer, and label mappings
        self.data = data
        self.tokenizer = tokenizer
        self.label2id = label2id
        self.maxlength = 128  # Maximum token length for input sequences
        self.all_labels_num = len(label2id)  # Total number of labels
        self.pair_wise_sampled = None  # Tracks sampling status of label pairs
        self.gt_labels = labels  # Ground truth labels in one-hot format
        self.all_labeled_mask = None  # Indicates whether all labels of a sample have been queried
        self.init()  # Initializes sampling and label mask states

    def init(self):
        # Initialize sampled pairs and mask for all data
        self.pair_wise_sampled = torch.ones(len(self.data), self.all_labels_num)
        self.all_labeled_mask = torch.zeros(len(self.data))  # Initially, no data is fully labeled

    def get_label_Cardinality(self):
        # Compute label cardinality, representing average positive labels per sample in the labeled pool
        labed_cnt = torch.sum(self.all_labeled_mask)  # Total number of samples fully labeled
        all_labed_pos_label_cnt = torch.sum(self.all_labeled_mask.unsqueeze(-1) * self.gt_labels)
        return all_labed_pos_label_cnt / labed_cnt  # Average number of positive labels per fully labeled sample

    def update_data(self, query_example_indices, query_label_indices=None, init_time=False):
        # Update dataset with new labeled data points and labels after each query cycle
        if query_label_indices is not None:
            ones = torch.ones(self.all_labels_num)
            for example_idx, label_idx in zip(query_example_indices, query_label_indices):
                # Access individual data and update based on queried label
                one_data = self.__getitem__(example_idx)
                one_label = one_data[1][label_idx]
                if one_label == 0:
                    # Set pair-wise sampled state for newly queried labels
                    self.pair_wise_sampled[example_idx][label_idx] = 1
                else:
                    self.pair_wise_sampled[example_idx][label_idx] = 1
                
                # Update all_labeled_mask if all labels for a sample are queried
                if torch.sum(ones - self.pair_wise_sampled[example_idx]) == 0:
                    self.all_labeled_mask[example_idx] = 1
        else:
            # Mark all labels as queried for each example if only examples are specified
            for example_idx in query_example_indices:
                ones = torch.ones(self.all_labels_num)
                self.pair_wise_sampled[example_idx] = ones
                self.all_labeled_mask[example_idx] = 1

    def get_labeled_set(self):
        # Return list of indices for samples that have been fully labeled
        labeled_set = []
        for idx, mask in enumerate(self.all_labeled_mask):
            if mask != 0:
                labeled_set.append(idx)
        return labeled_set

    def __len__(self):
        # Return the number of samples in the dataset
        return len(self.data)

    def __getitem__(self, idx):
        item = self.data[idx] 
        labels = self.gt_labels[idx]

        # Tokenize the raw text and apply padding/truncation to reach maxlength
        encoding = self.tokenizer(
            item,
            padding='max_length',
            truncation=True,
            max_length=self.maxlength,
            return_tensors="pt"
        )

        # Extract tokenized fields
        input_ids = encoding['input_ids'].squeeze(0)  # Remove batch dimension
        input_type_ids = encoding.get('token_type_ids', torch.zeros_like(input_ids))
        input_mask = encoding['attention_mask'].squeeze(0)

        text_inputs = [input_ids, input_type_ids, input_mask]
        sampler_loss_weight = self.pair_wise_sampled[idx]  # Weight for active learning sample selection

        # Return inputs for model: tokenized text, labels, sample index, sampling weights, labeling status
        inputs_list = [text_inputs, labels, idx, sampler_loss_weight, self.all_labeled_mask[idx]]
        return inputs_list

# %%
def load_data(label2id):
    tokenizer = BertTokenizer.from_pretrained('indobenchmark/indobert-base-p1')
    
    train_dataset = ClfDataset(
        data=train_data['processed_text'].values,
        labels=train_data[train_data.columns[2:6]].values,
        tokenizer=tokenizer,
        label2id=label2id,
    )
    test_dataset = ClfDataset(
        data=test_data['processed_text'].values,
        labels=test_data[test_data.columns[2:6]].values,
        tokenizer=tokenizer,
        label2id=label2id,
    )
    
    return train_dataset, test_dataset, len(train_data), len(test_data)

def load_label():
    label_freq_desc = [['pornografi', 1574], ['sara', 1124], ['radikalisme', 1154], ['pencemaran_nama_baik', 2180]]
    label_weight = [x[1] for x in label_freq_desc]
    label_index = [x[0] for x in label_freq_desc]
    labels = label_index
    label2id = {j: i for i, j in enumerate(labels)}
    print('label num', len(labels))
    return len(labels), label2id

def label2list(label):
    print(label)
    outputs = [[] for _ in range(label.shape[0])]
    x,y = np.where(label==1)
    for xx,yy in zip(x,y):
        outputs[xx].append(yy)
    return outputs

# %% [markdown]
# # DEFINE THE MODEL

# %%
class IndoBERT_Backbone(nn.Module):
    def __init__(self, label_num):
        super(IndoBERT_Backbone, self).__init__()
        self.label_num = label_num
        self.encoder = IndoBERT_Encoder(label_num)
        model_config = BertConfig.from_pretrained("indobenchmark/indobert-base-p1")
        self.clf = nn.Linear(model_config.hidden_size, label_num)
        nn.init.xavier_uniform_(self.clf.weight)

    def forward(self, inputs):
        encoder_out = self.encoder(inputs)
        out = self.clf(encoder_out)
        return out, encoder_out

class IndoBERT_Encoder(nn.Module):
    def __init__(self, label_num):
        super(IndoBERT_Encoder, self).__init__()
        self.label_num = label_num
        self.encoder = BertModel.from_pretrained(
            'indobenchmark/indobert-base-p1',
            num_labels=self.label_num,
        )
        
        self.encoder_init()

    def encoder_init(self):
        all_layers = ['embeddings', 'layer.0', 'layer.1', 'layer.2', 'layer.3', 'layer.4', 'layer.5', 'layer.6',
                      'layer.7', 'layer.8', 'layer.9', 'layer.10', 'layer.11', 'pooler']
        unfreeze_layers = all_layers[7:]
        for name, param in self.encoder.named_parameters():
            param.requires_grad = False
            for ele in unfreeze_layers:
                if ele in name:
                    param.requires_grad = True
                    break

    def forward(self, inputs):
        # Ensure each component in inputs is a tensor
        input_ids = torch.tensor(inputs[0]) if not isinstance(inputs[0], torch.Tensor) else inputs[0]
        token_type_ids = torch.tensor(inputs[1]) if not isinstance(inputs[1], torch.Tensor) else inputs[1]
        attention_mask = torch.tensor(inputs[2]) if not isinstance(inputs[2], torch.Tensor) else inputs[2]
        
        input_ids = input_ids.view(-1, input_ids.size(-1))  # Ensuring batch_size, sequence_length
        token_type_ids = token_type_ids.view(input_ids.size(0), -1)  # Reshaping to [batch_size, sequence_length]
        attention_mask = attention_mask.view(-1, attention_mask.size(-1))
        
        outputs = self.encoder(
            input_ids=input_ids,
            token_type_ids=token_type_ids,
            attention_mask=attention_mask,
        )
        cls_output = outputs.pooler_output
        return cls_output

# %%
class MLP_VAE(nn.Module):
    def __init__(self, hidden_size, device):
        super(MLP_VAE, self).__init__()
        self.device = device
        self.label_num = 4
        self.cl_neg_mode = 1
        self.proto_size = 256
        self.hidden_size = hidden_size
        
        # Initial fully connected layer to project input to higher-dimensional space for each label
        self.fc0 = nn.Linear(self.hidden_size, 4 * 512)
        self.fc1 = nn.Linear(512, self.proto_size)  # Dimensionality reduction for prototypes

        # Adjust the number of label representations based on contrastive learning mode
        if self.cl_neg_mode == 0:
            cl_label_num = self.label_num  # Standard label number
        elif self.cl_neg_mode == 1:
            cl_label_num = self.label_num + 1  # Add one for negative prototype handling
            self.ins_neg_cnt = torch.zeros(1).to(device)
        elif self.cl_neg_mode == 2:
            cl_label_num = self.label_num * 2  # Double for positive and negative prototypes
            self.ins_neg_cnt = torch.zeros(self.label_num).to(device)
        self.cl_label_num = cl_label_num

        # Register buffer for label prototypes, aligned with CoMAL's prototype-based sampling
        self.register_buffer("prototypes", torch.zeros(self.cl_label_num, self.proto_size))
        self.ins_pos_cnt = torch.zeros(self.label_num).to(device)  # Track count of positive instances

        # Decoder and final aggregation layers
        self.fc3 = nn.Linear(self.proto_size, 512)
        self.agg = nn.Linear(self.label_num * 512, self.hidden_size)
        self.clf = nn.Linear(self.hidden_size, self.label_num)  # Classification layer

    def get_protos(self):
        return self.prototypes  # Return the prototypes for external use

    def reparameterize(self, mu, logvar):
        # VAE reparameterization trick for latent space sampling
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def reset_proto(self):
        # Reset prototype and count buffers
        self.ins_pos_cnt *= 0
        self.ins_neg_cnt *= 0
        self.prototypes *= 0

    def forward(self, x, labels=None, weights=None):
        # Project input into sub-representations per label
        sub_rep_ori = self.fc0(x)
        sr_shape = sub_rep_ori.shape
        sub_rep_ori = sub_rep_ori.view(sr_shape[0], self.label_num, -1)  # Split per label

        # Further reduction to prototype size and decoding step
        sub_rep = self.fc1(sub_rep_ori)
        dec_sub_rep = self.fc3(sub_rep)

        dist_1 = None
        sub_rep_norm = F.normalize(sub_rep.data, dim=-1)  # Normalize for distance calculations

        if labels is not None and weights is not None:
            # Generate masks for positive and negative samples
            pos_mask = labels * weights
            neg_mask = (1 - labels) * weights
            pos_mask = pos_mask.unsqueeze(-1)
            neg_mask = neg_mask.unsqueeze(-1)

            # Update prototypes based on positive and negative samples
            feat = torch.sum(sub_rep_norm * pos_mask, dim=0)
            self.prototypes[:self.label_num] = self.prototypes[:self.label_num] * self.ins_pos_cnt.unsqueeze(-1) + feat

            # Handle different contrastive learning modes
            if self.cl_neg_mode == 2:
                feat_neg = torch.sum(sub_rep_norm * neg_mask, dim=0)
                self.prototypes[self.label_num:] = self.prototypes[self.label_num:] * self.ins_neg_cnt.unsqueeze(-1) + feat_neg
                self.ins_neg_cnt += torch.sum(neg_mask.squeeze(-1), dim=0)
            elif self.cl_neg_mode == 1:
                feat_neg = torch.sum(sub_rep_norm * neg_mask, dim=0)
                feat_neg = torch.sum(feat_neg, dim=0)
                self.prototypes[-1] = self.prototypes[-1] * self.ins_neg_cnt + feat_neg
                self.ins_neg_cnt += torch.sum(neg_mask)
            
            # Update positive instance counts and normalize prototypes
            self.ins_pos_cnt += torch.sum(pos_mask.squeeze(-1), dim=0)
            self.prototypes = F.normalize(self.prototypes, p=2, dim=-1)

        # Calculate distances between sub-representations and prototypes
        if self.cl_neg_mode == 2:
            dist_1 = torch.einsum('bld,ld->bl', [sub_rep_norm, self.prototypes[:self.label_num]])
            dist_neg_1 = torch.einsum('bld,ld->bl', [sub_rep_norm, self.prototypes[self.label_num:]])
            dist_1 = torch.cat([dist_1, dist_neg_1], dim=1)  # Combine distances for positive and negative prototypes
        elif self.cl_neg_mode == 0 or self.cl_neg_mode == 1:
            dist_1 = sub_rep_norm @ self.prototypes.T  # Standard matrix multiplication for distance calculation

        # Decode and classify reconstructed input
        concat_sub_rep = dec_sub_rep.contiguous().view(dec_sub_rep.shape[0], -1)
        recon_x = self.agg(concat_sub_rep)
        recon_x_clf = self.clf(recon_x)

        return recon_x, sub_rep, recon_x_clf, dist_1  # Return reconstruction, sub-representation, classification, and distances

# %%
def get_cl_labels(labels, label_num, weight, cl_neg_mode=1):
    cl_labels = torch.zeros_like(labels, dtype=torch.long)
    cl_labels.fill_(label_num)
    example_idx, label_idx = torch.where(labels>=0.5)
    cl_labels[example_idx, label_idx] = label_idx #.float()
    cl_labels = cl_labels * weight + label_num * (1 - weight)
    if cl_neg_mode == 2:
        example_idx, label_idx = torch.where(labels < 0.5)
        cl_neg_labels = label_idx + label_num
        cl_labels[example_idx, label_idx] = cl_neg_labels.float()
        cl_labels = cl_labels * weight + 2 * label_num * (1 - weight)
    cl_labels = cl_labels.to(torch.int)
    return cl_labels

def get_cl_mask(cl_labels, label_num, batch_size, cl_neg_mode=1):
    mask = torch.eq(cl_labels[:batch_size], cl_labels.T).float()
    if cl_neg_mode == 0:
        neg_idx, _ = torch.where(cl_labels[:batch_size] >= label_num)
        neg_mask = torch.ones_like(mask)
        neg_mask[neg_idx] = 0
        neg_mask[:, neg_idx] = 0
        mask *= neg_mask
    elif cl_neg_mode == 1:
        neg_idx, _ = torch.where(cl_labels[:batch_size] > label_num)
        neg_mask = torch.ones_like(mask)
        neg_mask[neg_idx] = 0
        neg_mask[:, neg_idx] = 0
        mask *= neg_mask
    elif cl_neg_mode == 2:
        neg_idx, _ = torch.where(cl_labels[:batch_size] >= label_num * 2)
        neg_mask = torch.ones_like(mask)
        neg_mask[neg_idx] = 0
        neg_mask[:, neg_idx] = 0
        mask *= neg_mask
    else:
        neg_mask = torch.ones_like(mask)
    return mask, neg_mask

# %% [markdown]
# # DEFINE LOSSES

# %%
class SupConLoss(nn.Module):
    """Following Supervised Contrastive Learning:
        https://arxiv.org/pdf/2004.11362.pdf."""

    def __init__(self, temperature=0.07, base_temperature=0.07):
        super().__init__()
        self.temperature = temperature
        self.base_temperature = base_temperature

    def forward(self, features, mask, neg_mask=None, batch_size=-1, device=None, other_features=None):
        if mask is not None:
            # SupCon loss (Partial Label Mode)
            mask = mask.float().detach()
            # compute logits
            if other_features is None:
                anchor_dot_contrast = torch.div(
                    torch.matmul(features[:batch_size], features.T),
                    self.temperature)
            else:
                anchor_dot_contrast = torch.div(
                    torch.matmul(features[:batch_size], other_features.T),
                    self.temperature)

            # for numerical stability
            logits_max, _ = torch.max(anchor_dot_contrast, dim=1, keepdim=True)
            logits = anchor_dot_contrast - logits_max.detach()

            # mask-out self-contrast cases
            if neg_mask is None:
                logits_mask = torch.ones_like(mask)
            else:
                logits_mask = torch.scatter(
                    neg_mask,
                    1,
                    torch.arange(batch_size).view(-1, 1).to(device),
                    0
                )
            mask = mask * logits_mask

            # compute log_prob
            exp_logits = torch.exp(logits) * logits_mask
            log_prob = logits - torch.log(exp_logits.sum(1, keepdim=True) + 1e-12)
            # compute mean of log-likelihood over positive
            mean_log_prob_pos = (mask * log_prob).sum(1) / (mask.sum(1) + 1e-12)
            # loss
            loss = - (self.temperature / self.base_temperature) * mean_log_prob_pos
            loss = loss.mean()
        else:
            q = features[:batch_size]
            k = features[batch_size:batch_size * 2]
            queue = features[batch_size * 2:]
            l_pos = torch.einsum('nc,nc->n', [q, k]).unsqueeze(-1)
            # negative logits: NxK
            l_neg = torch.einsum('nc,kc->nk', [q, queue])
            # logits: Nx(1+K)
            logits = torch.cat([l_pos, l_neg], dim=1)

            # apply temperature
            logits /= self.temperature

            # labels: positive key indicators
            labels = torch.zeros(logits.shape[0], dtype=torch.long).cuda()
            loss = F.cross_entropy(logits, labels)

        return loss

# %% [markdown]
# # MODEL TRAINING AND TESTING

# %%
def train_total_sep2(models, optimizers, schedulers, dataloaders, trials, current_train_size, label_num=-1, total_patience=3):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
    best_score = {
        'accuracy': 0,
        'f1_micro': 0,
        'f1_macro': 0
    }  # Track best score for first phase
    best_score2 = {
        'accuracy': 0,
        'f1_micro': 0,
        'f1_macro': 0
    }  # Track best score for second phase
    second_phase = False  # Control flag for switching between training phases
    total_patience_cnt = 0

    # Loop over epochs
    for epoch in range(1, epochs+1):
        # Set all models to training mode
        for key in models.keys():
            models[key].train()
        if second_phase:
            models['backbone'].eval()  # Backbone frozen in second phase

        models['vae_module'].reset_proto()

        # Iterate over labeled data for training
        total_loss = 0
        for data in dataloaders['labeled']:
            # Zero the gradients for all optimizers
            for key in optimizers.keys():
                optimizers[key].zero_grad()

            # Prepare inputs and labels for training
            labels, idx, loss_weight, _ = [x.to(device) for x in data[1:]]
            input_ids, input_type_ids, input_mask = [x.to(device) for x in data[0]]
            loss = 0  # Initialize loss
            inputs_list = [input_ids, input_type_ids, input_mask, None]

            # Forward pass through backbone model
            clf_out, encoder_cls = models['backbone'](inputs_list)

            # VAE training logic (aligns with CoMAL's multi-label decoupling and contrastive learning)
            loss2 = 0
            module_cls = encoder_cls.detach()  # Detach to prevent gradient flow to backbone

            # List of keys for VAE-related modules
            dual_key_list = ['vae_module']

            # Forward pass through VAE module
            recon_x, latent_rep, recon_x_clf, _ = models['vae_module'](module_cls, labels=labels, weights=loss_weight)

            # Compute contrastive loss if enabled (aligns with CoMAL's use of contrastive learning)
            cl_labels = get_cl_labels(labels, label_num, loss_weight).view(-1)
            cl_labels_total = cl_labels.unsqueeze(-1)
            proj_total = latent_rep.view(-1, latent_rep.shape[-1])
            proj_total = F.normalize(proj_total, dim=-1)  # Normalize latent representation
            batch_size = clf_out.shape[0] * label_num
            mask, neg_mask = get_cl_mask(cl_labels_total, label_num, batch_size)

            criterion_cl = SupConLoss()  # Supervised contrastive loss function
            cl_loss = criterion_cl(proj_total, mask, neg_mask, batch_size, device)
            loss2 += cl_loss  # Add contrastive loss

            # Compute reconstruction and classification loss
            criterion_mse = nn.MSELoss()
            recon_mse_loss = criterion_mse(recon_x, module_cls)
            criterion_bce = nn.BCEWithLogitsLoss(weight=loss_weight, reduction='mean')
            recon_bce_loss = criterion_bce(recon_x_clf, labels.float())
            
            loss2 += recon_mse_loss + recon_bce_loss
            
            # Compute classification loss for the backbone (first phase)
            if not second_phase:
                criterion = nn.BCEWithLogitsLoss(weight=loss_weight, reduction='mean')
                clf_loss = criterion(clf_out, labels.float())
                loss += clf_loss  # Add classification loss to total loss

            # Add VAE loss to total loss
            loss += loss2
            # Backpropagation step
            loss.backward()
            
            total_loss += loss

            # Update weights based on current phase
            if second_phase:
                for key in dual_key_list:
                    optimizers[key].step()  # Update only VAE-related modules
            else:
                for key in optimizers.keys():
                    optimizers[key].step()  # Update all models

        # Scheduler step for learning rate adjustment
        if second_phase:
            print('in second')
            for key in dual_key_list:
                schedulers[key].step()
            score = test(models, epoch, dataloaders, test_dual=True)
            
            if score["f1_micro"] >= best_score2['f1_micro']:
                total_patience_cnt = 0
                best_score2 = score
                torch.save(models['backbone'], f"/kaggle/working/{filename}-p2/backbone-{trials+1}.pt")
                torch.save(models['vae_module'], f"/kaggle/working/{filename}-p2/vae-{trials+1}.pt")
            else:
                total_patience_cnt += 1
                if total_patience_cnt >= total_patience:
                    break
        else:
            for key in schedulers.keys():
                schedulers[key].step()
            score = test(models, epoch, dataloaders)
            
            if score["f1_micro"] >= best_score['f1_micro']:
                best_score = score
                total_patience_cnt = 0
                torch.save(models['backbone'], f"/kaggle/working/{filename}-p1/backbone-{trials+1}.pt")
                torch.save(models['vae_module'], f"/kaggle/working/{filename}-p1/vae-{trials+1}.pt")
            else:
                total_patience_cnt += 1
                if total_patience_cnt >= total_patience:
                    total_patience_cnt = 0
                    second_phase = True
                
        print(f"EPOCH {epoch} | LOSS: {total_loss / len(dataloaders['labeled'])} | ACCURACY: {score['accuracy'].round(4)} | F1 MACRO: {score['f1_macro'].round(4)} | F1 MICRO: {score['f1_micro'].round(4)}")

    data_used.append(current_train_size)
    accuracies.append(best_score["accuracy"])
    f1_macros.append(best_score["f1_macro"])
    f1_micros.append(best_score["f1_micro"])
    
    print(f"Iteration {current_train_size}: ACCURACY {best_score['accuracy'].round(4)} | F1 MACRO {best_score['f1_macro'].round(4)} | F1 MICRO {best_score['f1_micro'].round(4)}")
    print(best_score['report'])

# %%
def test(models, epoch, dataloaders, test_dual=False, final_test=False):
    outputs_clf = [[], [], [], [], []]
    outputs_dis = [[], [], [], [], []]
    outputs_dual = [[], [], [], [], []]
    outputs_z = [[], [], [], [], []]
    
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
    for key in models.keys():
        models[key].eval()
        
    with torch.no_grad():
        for data in dataloaders['test']:
            input_ids, input_type_ids, input_mask = [x.to(device) for x in data[0]]
            labels = data[1].to(device)
            out = [input_ids, input_type_ids, input_mask, None]

            clf_out, encoder_cls = models['backbone'](out)
            outputs_clf = neaten_test_result(outputs_clf, clf_out, labels)
            _, _, recon_x_clf, _ = models['vae_module'](encoder_cls)
            outputs_dual = neaten_test_result(outputs_dual, recon_x_clf, labels)
            
    outputs_clf = concat_test_result(outputs_clf)

    result = {}
                                 
    if 'vae_module' in models.keys() and not final_test:
        outputs_dual = concat_test_result(outputs_dual)
        true_labels_vae = outputs_dual[0]
        predicted_vae = []

        result['accuracy'] = accuracy_score(outputs_dual[0], outputs_dual[4])
        result['precision'], result['recall'], result['f1_macro'], _ = precision_recall_fscore_support(
            outputs_dual[0], outputs_dual[4], zero_division=0, average='macro'
        )
        result['f1_micro'] = f1_score(outputs_dual[0], outputs_dual[4], zero_division=0, average='micro')
        result['report'] = classification_report(
            outputs_dual[0], 
            outputs_dual[4], 
            target_names=['pornografi', 'sara', 'radikalisme', 'pencemaran_nama_baik'],
            zero_division=0
        )
    else:
        result['accuracy'] = accuracy_score(outputs_clf[0], outputs_clf[4])
        result['precision'], result['recall'], result['f1_macro'], _ = precision_recall_fscore_support(
            outputs_clf[0], outputs_clf[4], zero_division=0, average='macro'
        )
        result['f1_micro'] = f1_score(outputs_clf[0], outputs_clf[4], zero_division=0, average='micro')
        result['report'] = classification_report(
            outputs_clf[0], 
            outputs_clf[4], 
            target_names=['pornografi', 'sara', 'radikalisme', 'pencemaran_nama_baik'],
            zero_division=0
        )
            
    return result

def concat_test_result(outputs):
    outputs[0] = np.concatenate(outputs[0], axis=0)
    outputs[1] = np.concatenate(outputs[1], axis=0)
    outputs[2] = np.concatenate(outputs[2], axis=0)
    outputs[3] = np.concatenate(outputs[3], axis=0)
    outputs[4] = np.concatenate(outputs[4], axis=0)
    return outputs

def neaten_test_result(outputs, logits, labels):
    labels = labels.data.cpu().numpy()
    prob, pred = torch.topk(logits, 4)
    prob = torch.sigmoid(prob).data.cpu().numpy()
    pred = pred.data.cpu().numpy()
    logits = logits.data.cpu().numpy()
    pred_labels = np.zeros(logits.shape)
    pred_labels[logits >= 0.5] = 1
    outputs[0].append(labels)
    outputs[1].append(pred)
    outputs[2].append(prob)
    outputs[3].append(logits)
    outputs[4].append(pred_labels)
    
    return outputs

# %% [markdown]
# # QUERY STRATEGY

# %%
def query_samples(models, dataset, labeled_set, unlabeled_indices, device, num_labels, trials,
                  label_cardinality=None, labeled_subset=None, save_path=None, cl_neg_mode=1, n_samples=200):
    start_time = time.time()

    current_train_size = len(dataset.get_labeled_set())
    
    # Set all models to evaluation mode to freeze parameters during sampling
    for model_name in models.keys():
        models[model_name].eval()

    # Initialize lists to store outputs used for sampling calculations
    predictions, sample_indices = [], []
    sample_weights = []
    backbone_predictions = []
    backbone_distances = []
    ground_truth_labels = []
    vae_predictions = []
    sub_representations = []

    # If training with the VAE module, initialize labeled data processing
    labeled_sub_representations = []
    labeled_distances = []
    labeled_ground_truths = []

    # DataLoader for labeled data subset, sampled randomly
    labeled_dataloader = DataLoader(
        dataset,
        batch_size=16,
        num_workers=4,
        pin_memory=True,
        sampler=SubsetRandomSampler(list(set(labeled_set)))
    )

    # Process labeled data to extract features and distances for sampling criteria
    for text_inputs, gt_label, idx, _, _ in labeled_dataloader:
        input_ids, token_type_ids, attention_mask = [x.to(device) for x in text_inputs]
        labeled_ground_truths.extend(gt_label)

        with torch.no_grad():
            # Use backbone model to get encoded representations
            _, encoded_cls = models['backbone']([input_ids, token_type_ids, attention_mask, None])

            # If VAE module is present, obtain sub-representations and distances
            if 'vae_module' in models.keys():
                _, sub_representation, _, vae_distance = models['vae_module'](encoded_cls)
                sub_representation = sub_representation.cpu().data  # N, L, d
                vae_distance = vae_distance.cpu().data
                labeled_distances.extend(vae_distance)
                labeled_sub_representations.extend(F.normalize(sub_representation, dim=-1))  # Normalized for comparison

    # Stack outputs for further processing
    labeled_ground_truths = torch.stack(labeled_ground_truths)  # N, L
    labeled_sub_representations = torch.stack(labeled_sub_representations)  # N, L, d
    labeled_distances = torch.stack(labeled_distances)  # N, L+1

    # Compute self-prototype distances based on CoMAL's contrastive learning mode
    if cl_neg_mode == 1:
        labeled_prototype_distances = labeled_distances[:, :, :-1]  # Exclude last distance for prototype calculation
        labeled_prototype_distances = labeled_prototype_distances * torch.eye(num_labels)  # Keep only diagonal elements
        labeled_prototype_distances = torch.sum(labeled_prototype_distances, dim=-1)  # Sum along prototype axis
        positive_distances = labeled_prototype_distances * labeled_ground_truths  # Mask with ground truth labels
    elif cl_neg_mode == 2:
        # Split distances into positive and negative based on contrastive learning mode
        positive_distances, negative_distances = labeled_distances.chunk(2, dim=-1)
        positive_distances = positive_distances * labeled_ground_truths

    # Calculate max, min, and mean positive distances for uncertainty measurement
    max_positive_distances = torch.max(positive_distances, dim=0)[0]
    min_positive_distances = torch.min(positive_distances + (1 - labeled_ground_truths) * 2, dim=0)[0]
    mean_positive_distances = (max_positive_distances + min_positive_distances) / 2

    # DataLoader for unlabeled data to compute sampling scores
    unlabeled_dataloader = DataLoader(
        dataset,
        batch_size=16,
        num_workers=4,
        pin_memory=True,
        sampler=SubsetRandomSampler(list(set(unlabeled_indices)))
    )

    # Process unlabeled data to get sampling scores
    for text_inputs, labels, idx, loss_weight, _ in unlabeled_dataloader:
        input_ids, token_type_ids, attention_mask = [x.to(device) for x in text_inputs]

        with torch.no_grad():
            # Get predictions and encoded representations
            predictions, encoded_cls = models['backbone']([input_ids, token_type_ids, attention_mask, None])
            predictions = predictions.cpu().data
            backbone_predictions.extend(predictions)

            # If VAE module exists, get latent representations, reconstructions, and distances
            if 'vae_module' in models.keys():
                recon_x, latent_rep, recon_x_clf, vae_distance = models['vae_module'](encoded_cls)
                latent_rep = latent_rep.cpu().data
                vae_distance = vae_distance.cpu().data
                recon_x_clf = recon_x_clf.cpu().data
                vae_predictions.extend(recon_x_clf)
                backbone_distances.extend(vae_distance)
                sub_representations.extend(F.normalize(latent_rep, dim=-1))  # Normalized latent space representation
            else:
                vae_predictions.extend(predictions)

        # Append sample indices, loss weights, and ground truth labels for use in ranking
        sample_indices.extend(idx)
        sample_weights.extend(loss_weight)
        ground_truth_labels.extend(labels)

    # Convert lists to tensors for further computation
    sample_indices = torch.stack(sample_indices)
    sample_weights = torch.stack(sample_weights)
    ground_truth_labels = torch.stack(ground_truth_labels)

    # If VAE module is used, stack additional representations and save if needed
    if 'vae_module' in models.keys():
        sub_representations = torch.stack(sub_representations)

        # Stack and prepare distance matrix for final scoring
        distance_matrix = torch.stack(backbone_distances)

    # Convert predictions to probability and adjust masks for scoring
    backbone_predictions = torch.stack(backbone_predictions)
    probability_predictions = torch.sigmoid(backbone_predictions)
    unlabeled_mask = torch.ones_like(sample_weights) - sample_weights

    # Calculate uncertainty metrics and part scores for sampling
    sample_weights = sample_weights.view(-1)
    unlabeled_part, labeled_part = pred_part_stat(sample_weights, threshold=0.5)
    unlabeled_labelwise_indices = list(set(unlabeled_part // num_labels))
    unlabeled_labelwise_indices = torch.tensor(unlabeled_labelwise_indices)

    # Mask predictions based on positive distances
    positive_distance_mask = ((probability_predictions >= 0.5) * unlabeled_mask).float()
    if cl_neg_mode == 2:
        positive_prototype_distances, negative_prototype_distances = distance_matrix.chunk(2, dim=-1)
    elif cl_neg_mode == 0 or cl_neg_mode == 1:
        if cl_neg_mode == 0:
            positive_prototype_distances = distance_matrix
        elif cl_neg_mode == 1:
            positive_prototype_distances = distance_matrix[:, :, :-1]
        positive_prototype_distances = positive_prototype_distances * torch.eye(num_labels)
        positive_prototype_distances = torch.sum(positive_prototype_distances, dim=-1)

    # Compute scores based on uncertainty and diversity metrics
    prediction_mask = (positive_prototype_distances > mean_positive_distances).float()
    distance_count = torch.sum(prediction_mask, dim=-1)
    cardinality_difference = torch.abs(distance_count - label_cardinality)
    score_weight = positive_distance_mask * (positive_prototype_distances + 1) / 2
    score_weight = 1 / torch.sum(score_weight + 1e-10, dim=-1)
    adjusted_score = torch.pow(score_weight, 0.5) * torch.pow(cardinality_difference, 1 - 0.5)
    final_scores = adjusted_score.unsqueeze(-1)
    average_scores = torch.mean(final_scores, dim=-1).cpu().numpy()
    
    ranked_indices = np.argsort(average_scores)
    ranked_indices = ranked_indices[::-1]

    # print("DISTANCE")
    # print(score_weight)
    # print("CARDINALITY:")
    # print(cardinality_difference)
    # print([average_scores[i] for i in ranked_indices])

    # Select top samples for annotation
    threshold = np.percentile(average_scores, 90)
    items_greater_than_threshold = average_scores[average_scores >= threshold]
    num_of_candidates = min(math.ceil(0.1 * len(average_scores)), len(items_greater_than_threshold))

    nearest_cp = 0
    for cp in checkpoints:
        if cp > current_train_size:
            nearest_cp = cp
            break

    if num_of_candidates <= n_samples and n_samples < nearest_cp - current_train_size:
        selected_indices = ranked_indices[:n_samples]
    elif num_of_candidates > n_samples and num_of_candidates < nearest_cp - current_train_size:
        selected_indices = ranked_indices[:num_of_candidates]
    else:
        selected_indices = ranked_indices[:nearest_cp - current_train_size]
        
        temp = dataset.get_labeled_set()
        temp.extend(selected_indices)
        
        # Save acquired data up to checkpoint
        acquired_data = pd.DataFrame({
            'processed_text': [X_train[i] for i in temp],
            'pornografi': [y_train[i][0] for i in temp],
            'sara': [y_train[i][1] for i in temp],
            'radikalisme': [y_train[i][2] for i in temp],
            'pencemaran_nama_baik': [y_train[i][3] for i in temp],
        })

        acquired_data.to_csv(f'{filename}-{trials+1}-data-{nearest_cp}.csv', index=False)
    
    # selected_indices = ranked_indices[:n_samples]
    queried_sample_indices = [sample_indices[int(x)] for x in selected_indices]
    queried_label_indices = None

    # Initialize empty tensors for annotation indices
    annotation_sample_indices = torch.tensor([])
    annotation_label_indices = torch.tensor([])
    
    end_time = time.time()
    duration = end_time - start_time

    print("Nearest checkpoint:", nearest_cp)
    print("Threshold:", threshold)
    print("Samples above threshold:", num_of_candidates)
    print("Acquired samples:", len(selected_indices))
    print(f"Sampling duration: {duration} seconds")  # Print or return the runtime if needed

    sampling_dur.append(duration)
    
    return queried_sample_indices, queried_label_indices, annotation_sample_indices, annotation_label_indices

def pred_part_stat(pred, threshold=0.0):
    # pred_round = torch.round(pred)
    part_1 = torch.where(pred >= threshold)[0]
    part_0 = torch.where(pred < threshold)[0]
    return part_0, part_1

# %% [markdown]
# # MAIN LOOP

# %%
import matplotlib.pyplot as plt

def plot_result(data_used, accuracies, f1_micros, f1_macros):
    fig, axs = plt.subplots(1, 3, figsize=(21, 5))
    data_used = [round(data / total_data * 100, 1) for data in data_used]

    # Plot for Accuracy
    axs[0].plot(data_used, accuracies, label="Accuracy", color="blue")
    axs[0].set_xlabel("Percentage of data used")
    axs[0].set_title("Accuracy")
    axs[0].set_xticks(data_used)

    # Plot for F1 Micro
    axs[1].plot(data_used, f1_micros, label="F1 Micro", color="orange")
    axs[1].set_xlabel("Percentage of data used")
    axs[1].set_title("F1 Micro")
    axs[1].set_xticks(data_used)

    # Plot for F1 Macro
    axs[2].plot(data_used, f1_macros, label="F1 Macro", color="green")
    axs[2].set_xlabel("Percentage of data used")
    axs[2].set_title("F1 Macro")
    axs[2].set_xticks(data_used)

    # Adjust layout and show the plots
    plt.tight_layout()
    plt.show()

# %%
def active_learning(seed, i):
    accuracies.clear()
    f1_micros.clear()
    f1_macros.clear()
    sampling_dur.clear()
    data_used.clear()
    
    current_train_size = initial_train_size
    start_time = time.time()
    set_seed(seeds[i])

    print("===============================================")
    print("TRIAL {}".format(i+1))
    print("Random seed:", seeds[i])

    # Set the active learning method and GPU configuration
    device = 'cuda' if torch.cuda.is_available() else "cpu"
    
    # Load BERT model configuration and setup hidden layer size
    # model_config = BertConfig.from_pretrained("indobenchmark/indobert-base-p1").config
    
    # Load label information and dataset
    label_num, label2id = load_label()
    label_num = 4
    train_dataset, test_dataset, num_train, num_test = load_data(label2id)
    
    # Shuffle and initialize labeled and unlabeled sets
    indices = list(range(num_train))
    random.shuffle(indices)
    labeled_set = indices[:initial_train_size]  # Random initial labeled set
    unlabeled_set = [x for x in indices if x not in labeled_set]  # Define the unlabeled set
    
    # Update dataset with initial labeled set
    train_dataset.update_data(labeled_set, init_time=True)
    
    # Prepare data loaders for labeled and test sets
    labeled_loader = DataLoader(
        train_dataset,
        batch_size=16,
        num_workers=4,
        pin_memory=True,
        sampler=SubsetRandomSampler(list(set(labeled_set)))
    )
    test_loader = DataLoader(
        test_dataset,
        batch_size=16,
        num_workers=4,
        pin_memory=True
    )
    unlabeled_loader = DataLoader(
        train_dataset,
        batch_size=16,
        num_workers=4,
        pin_memory=True,
        sampler=SubsetRandomSampler(list(set(indices)))
    )

    while current_train_size < checkpoints[len(checkpoints) - 1]:
        # random.shuffle(unlabeled_set)  # Shuffle for randomness in each cycle
    
        # DataLoader dictionary to be used for training and testing
        dataloaders = {
            'labeled': labeled_loader,
            'test': test_loader
        }
    
        models = {}
        optimizers = {}
        schedulers = {}
    
        # Initialize backbone model for task learning
        backbone = IndoBERT_Backbone(label_num).to(device)
        models['backbone'] = backbone
        optim_backbone = torch.optim.AdamW(backbone.parameters(), lr=1e-4, eps=1e-8)
        sched_backbone = lr_scheduler.MultiStepLR(optim_backbone, milestones=[5], gamma=0.5)
        optimizers['backbone'] = optim_backbone
        schedulers['backbone'] = sched_backbone
    
        # Initialize VAE module if specified (aligns with CoMAL's contrastive and auxiliary module)
        dual_module = MLP_VAE(768, device).to(device)
        models['vae_module'] = dual_module
        optim_module = torch.optim.AdamW(dual_module.parameters(), lr=1e-4, eps=1e-8)
        sched_module = lr_scheduler.MultiStepLR(optim_module, milestones=[5], gamma=0.5)
        optimizers['vae_module'] = optim_module
        schedulers['vae_module'] = sched_module
    
        # Train model using different strategies (single training phase or separated phases)
        train_total_sep2(models, optimizers, schedulers, dataloaders, i, current_train_size=current_train_size, label_num=label_num)
    
        # Test the model and log results, ensuring evaluation matches CoMAL's iterative approach
        score = test(models, 10, dataloaders, final_test=True)
    
        # Prepare subset for querying based on method
        query_set = list(set(unlabeled_set))
        random.shuffle(query_set)
        subset = query_set[:]
    
        # Query samples for next cycle, using appropriate selection strategy
        query_example_indices, query_label_indices, annotate_example_indices, annotate_label_indices = query_samples(
            models, 
            train_dataset, 
            labeled_set,
            subset, 
            device, 
            label_num,
            i,
            label_cardinality=train_dataset.get_label_Cardinality(),
            n_samples=min_increment
        )
    
        # Update dataset with new queried data, maintaining CoMAL's active learning loop
        train_dataset.update_data(query_example_indices, query_label_indices)
        labeled_set = train_dataset.get_labeled_set()
        unlabeled_set = [x for x in indices if x not in labeled_set]
    
        # Refresh data loader with new labeled set
        labeled_loader = DataLoader(
            train_dataset,
            batch_size=16,
            num_workers=4,
            pin_memory=True,
            sampler=SubsetRandomSampler(list(set(labeled_set)))
        )
        
        # Update current train size
        current_train_size = len(labeled_set)
        print("New train size:", current_train_size)
    
    # DataLoader dictionary to be used for training and testing
    dataloaders = {
        'labeled': labeled_loader,
        'test': test_loader
    }
    
    models = {}
    optimizers = {}
    schedulers = {}
    
    # Initialize backbone model for task learning
    backbone = IndoBERT_Backbone(label_num).to(device)
    models['backbone'] = backbone
    optim_backbone = torch.optim.AdamW(backbone.parameters(), lr=1e-4, eps=1e-8)
    sched_backbone = lr_scheduler.MultiStepLR(optim_backbone, milestones=[5], gamma=0.5)
    optimizers['backbone'] = optim_backbone
    schedulers['backbone'] = sched_backbone
    
    # Initialize VAE module if specified (aligns with CoMAL's contrastive and auxiliary module)
    dual_module = MLP_VAE(768, device).to(device)
    models['vae_module'] = dual_module
    optim_module = torch.optim.AdamW(dual_module.parameters(), lr=1e-4, eps=1e-8)
    sched_module = lr_scheduler.MultiStepLR(optim_module, milestones=[5], gamma=0.5)
    optimizers['vae_module'] = optim_module
    schedulers['vae_module'] = sched_module
    
    # Train model using different strategies (single training phase or separated phases)
    train_total_sep2(models, optimizers, schedulers, dataloaders, i, current_train_size=current_train_size, label_num=label_num)
    
    # Test the model and log results, ensuring evaluation matches CoMAL's iterative approach
    score = test(models, 10, dataloaders, final_test=True)
        
    # Log results
    end_time = time.time()
    duration = end_time - start_time

    print(f"Total sampling time: {np.array(sampling_dur).sum().round(2)} seconds")
    print(f"Total runtime: {duration} seconds")

    plot_result(data_used, accuracies, f1_micros, f1_macros)
    
    results = pd.DataFrame({
        'Data Used': data_used,
        'Accuracy': accuracies,
        'F1 Micro': f1_micros,
        'F1 Macro': f1_macros,
    })
    sampling_dur.insert(0, 0)
    
    results['Sampling Duration'] = sampling_dur
    
    results.to_csv(f'{filename}-{i+1}-results.csv', index=False)

# %%
seeds = [50, 81, 14, 3, 94]

# %% [markdown]
# ## RUN 1

# %%
active_learning(seeds[0], 0)
# Out:
# ===============================================
# TRIAL 1
# Random seed: 50
# label num 4
# tokenizer_config.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/229k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.53k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/498M [00:00<?, ?B/s]
# EPOCH 1 | LOSS: 6.283120155334473 | ACCURACY: 0.4367 | F1 MACRO: 0.0 | F1 MICRO: 0.0
# EPOCH 2 | LOSS: 4.67326021194458 | ACCURACY: 0.4817 | F1 MACRO: 0.1446 | F1 MICRO: 0.1704
# EPOCH 3 | LOSS: 4.363685131072998 | ACCURACY: 0.6148 | F1 MACRO: 0.5798 | F1 MICRO: 0.597
# EPOCH 4 | LOSS: 4.122753620147705 | ACCURACY: 0.5929 | F1 MACRO: 0.4337 | F1 MICRO: 0.5094
# EPOCH 5 | LOSS: 3.982344627380371 | ACCURACY: 0.636 | F1 MACRO: 0.6005 | F1 MICRO: 0.6356
# EPOCH 6 | LOSS: 3.695112466812134 | ACCURACY: 0.6309 | F1 MACRO: 0.6431 | F1 MICRO: 0.6476
# EPOCH 7 | LOSS: 3.557173728942871 | ACCURACY: 0.6315 | F1 MACRO: 0.6673 | F1 MICRO: 0.6761
# EPOCH 8 | LOSS: 3.5060224533081055 | ACCURACY: 0.6334 | F1 MACRO: 0.6544 | F1 MICRO: 0.6656
# EPOCH 9 | LOSS: 3.4945590496063232 | ACCURACY: 0.6315 | F1 MACRO: 0.6633 | F1 MICRO: 0.6705
# EPOCH 10 | LOSS: 3.4381749629974365 | ACCURACY: 0.6328 | F1 MACRO: 0.6626 | F1 MICRO: 0.6691
# Iteration 388: ACCURACY 0.6315 | F1 MACRO 0.6673 | F1 MICRO 0.6761
#                       precision    recall  f1-score   support
#
#           pornografi       0.95      0.75      0.84       362
#                 sara       0.61      0.52      0.56       237
#          radikalisme       0.67      0.59      0.63       235
# pencemaran_nama_baik       0.67      0.61      0.64       492
#
#            micro avg       0.73      0.63      0.68      1326
#            macro avg       0.72      0.62      0.67      1326
#         weighted avg       0.73      0.63      0.68      1326
#          samples avg       0.37      0.35      0.35      1326
#
# Nearest checkpoint: 3886
# Threshold: 51959.04296875
# Samples above threshold: 583
# Acquired samples: 583
# Sampling duration: 21.79213047027588 seconds
# New train size: 971
# EPOCH 1 | LOSS: 5.261507511138916 | ACCURACY: 0.5794 | F1 MACRO: 0.2744 | F1 MICRO: 0.4049
# EPOCH 2 | LOSS: 4.2944560050964355 | ACCURACY: 0.5093 | F1 MACRO: 0.6639 | F1 MICRO: 0.6547
# EPOCH 3 | LOSS: 4.006965160369873 | ACCURACY: 0.6167 | F1 MACRO: 0.6363 | F1 MICRO: 0.6382
# EPOCH 4 | LOSS: 3.7919886112213135 | ACCURACY: 0.6418 | F1 MACRO: 0.6717 | F1 MICRO: 0.6721
# EPOCH 5 | LOSS: 3.5291576385498047 | ACCURACY: 0.6283 | F1 MACRO: 0.6202 | F1 MICRO: 0.6374
# EPOCH 6 | LOSS: 3.2993271350860596 | ACCURACY: 0.6707 | F1 MACRO: 0.7147 | F1 MICRO: 0.7178
# EPOCH 7 | LOSS: 3.200815200805664 | ACCURACY: 0.6675 | F1 MACRO: 0.7149 | F1 MICRO: 0.7181
# EPOCH 8 | LOSS: 3.159010171890259 | ACCURACY: 0.6727 | F1 MACRO: 0.727 | F1 MICRO: 0.7325
# EPOCH 9 | LOSS: 3.127129077911377 | ACCURACY: 0.6772 | F1 MACRO: 0.7235 | F1 MICRO: 0.7301
# EPOCH 10 | LOSS: 3.119182825088501 | ACCURACY: 0.6643 | F1 MACRO: 0.7177 | F1 MICRO: 0.7231
# Iteration 971: ACCURACY 0.6727 | F1 MACRO 0.727 | F1 MICRO 0.7325
#                       precision    recall  f1-score   support
#
#           pornografi       0.91      0.80      0.85       362
#                 sara       0.66      0.65      0.66       237
#          radikalisme       0.71      0.69      0.70       235
# pencemaran_nama_baik       0.70      0.71      0.70       492
#
#            micro avg       0.75      0.72      0.73      1326
#            macro avg       0.74      0.71      0.73      1326
#         weighted avg       0.75      0.72      0.73      1326
#          samples avg       0.40      0.39      0.39      1326
#
# Nearest checkpoint: 3886
# Threshold: 62289.80859375
# Samples above threshold: 525
# Acquired samples: 525
# Sampling duration: 21.91755175590515 seconds
# New train size: 1496
# EPOCH 1 | LOSS: 5.039247989654541 | ACCURACY: 0.5723 | F1 MACRO: 0.5368 | F1 MICRO: 0.5278
# EPOCH 2 | LOSS: 4.351877212524414 | ACCURACY: 0.6071 | F1 MACRO: 0.633 | F1 MICRO: 0.627
# EPOCH 3 | LOSS: 4.040507793426514 | ACCURACY: 0.6373 | F1 MACRO: 0.7066 | F1 MICRO: 0.7174
# EPOCH 4 | LOSS: 3.802037000656128 | ACCURACY: 0.681 | F1 MACRO: 0.7284 | F1 MICRO: 0.7344
# EPOCH 5 | LOSS: 3.6984572410583496 | ACCURACY: 0.6643 | F1 MACRO: 0.7207 | F1 MICRO: 0.7218
# EPOCH 6 | LOSS: 3.4468538761138916 | ACCURACY: 0.6887 | F1 MACRO: 0.738 | F1 MICRO: 0.7425
# EPOCH 7 | LOSS: 3.3298470973968506 | ACCURACY: 0.6952 | F1 MACRO: 0.7366 | F1 MICRO: 0.7414
# EPOCH 8 | LOSS: 3.2974584102630615 | ACCURACY: 0.7055 | F1 MACRO: 0.7376 | F1 MICRO: 0.7452
# EPOCH 9 | LOSS: 3.2878501415252686 | ACCURACY: 0.6881 | F1 MACRO: 0.7107 | F1 MICRO: 0.7154
# EPOCH 10 | LOSS: 3.2718071937561035 | ACCURACY: 0.6817 | F1 MACRO: 0.6864 | F1 MICRO: 0.6961
# Iteration 1496: ACCURACY 0.7055 | F1 MACRO 0.7376 | F1 MICRO 0.7452
#                       precision    recall  f1-score   support
#
#           pornografi       0.96      0.86      0.91       362
#                 sara       0.67      0.52      0.59       237
#          radikalisme       0.77      0.79      0.78       235
# pencemaran_nama_baik       0.75      0.62      0.68       492
#
#            micro avg       0.80      0.70      0.75      1326
#            macro avg       0.79      0.70      0.74      1326
#         weighted avg       0.79      0.70      0.74      1326
#          samples avg       0.41      0.39      0.39      1326
#
# Nearest checkpoint: 3886
# Threshold: 54047.41015625
# Samples above threshold: 473
# Acquired samples: 473
# Sampling duration: 21.648853063583374 seconds
# New train size: 1969
# EPOCH 1 | LOSS: 4.944465637207031 | ACCURACY: 0.6309 | F1 MACRO: 0.6489 | F1 MICRO: 0.6498
# EPOCH 2 | LOSS: 4.326237678527832 | ACCURACY: 0.5633 | F1 MACRO: 0.6562 | F1 MICRO: 0.6573
# EPOCH 3 | LOSS: 4.082197189331055 | ACCURACY: 0.6051 | F1 MACRO: 0.7103 | F1 MICRO: 0.7037
# EPOCH 4 | LOSS: 3.9990153312683105 | ACCURACY: 0.6122 | F1 MACRO: 0.6334 | F1 MICRO: 0.6656
# EPOCH 5 | LOSS: 3.7484500408172607 | ACCURACY: 0.6675 | F1 MACRO: 0.7449 | F1 MICRO: 0.7435
# EPOCH 6 | LOSS: 3.5585174560546875 | ACCURACY: 0.6842 | F1 MACRO: 0.7277 | F1 MICRO: 0.7385
# EPOCH 7 | LOSS: 3.38923716545105 | ACCURACY: 0.71 | F1 MACRO: 0.752 | F1 MICRO: 0.7583
# EPOCH 8 | LOSS: 3.3375473022460938 | ACCURACY: 0.7029 | F1 MACRO: 0.7565 | F1 MICRO: 0.756
# EPOCH 9 | LOSS: 3.3194427490234375 | ACCURACY: 0.6977 | F1 MACRO: 0.7357 | F1 MICRO: 0.7456
# EPOCH 10 | LOSS: 3.295140266418457 | ACCURACY: 0.7029 | F1 MACRO: 0.751 | F1 MICRO: 0.7551
# Iteration 1969: ACCURACY 0.71 | F1 MACRO 0.752 | F1 MICRO 0.7583
#                       precision    recall  f1-score   support
#
#           pornografi       0.96      0.84      0.90       362
#                 sara       0.72      0.54      0.62       237
#          radikalisme       0.74      0.85      0.79       235
# pencemaran_nama_baik       0.74      0.66      0.70       492
#
#            micro avg       0.80      0.72      0.76      1326
#            macro avg       0.79      0.72      0.75      1326
#         weighted avg       0.80      0.72      0.76      1326
#          samples avg       0.43      0.41      0.41      1326
#
# Nearest checkpoint: 3886
# Threshold: 53043.484375
# Samples above threshold: 425
# Acquired samples: 425
# Sampling duration: 21.932763814926147 seconds
# New train size: 2394
# EPOCH 1 | LOSS: 4.9661784172058105 | ACCURACY: 0.5132 | F1 MACRO: 0.5446 | F1 MICRO: 0.5418
# EPOCH 2 | LOSS: 4.459589004516602 | ACCURACY: 0.6257 | F1 MACRO: 0.5857 | F1 MICRO: 0.5994
# EPOCH 3 | LOSS: 4.2219624519348145 | ACCURACY: 0.6797 | F1 MACRO: 0.7357 | F1 MICRO: 0.7359
# EPOCH 4 | LOSS: 4.217964172363281 | ACCURACY: 0.6392 | F1 MACRO: 0.6447 | F1 MICRO: 0.6586
# EPOCH 5 | LOSS: 3.918201208114624 | ACCURACY: 0.69 | F1 MACRO: 0.7339 | F1 MICRO: 0.748
# EPOCH 6 | LOSS: 3.6502130031585693 | ACCURACY: 0.7074 | F1 MACRO: 0.7489 | F1 MICRO: 0.7564
# EPOCH 7 | LOSS: 3.522216796875 | ACCURACY: 0.7048 | F1 MACRO: 0.7622 | F1 MICRO: 0.7705
# EPOCH 8 | LOSS: 3.4524049758911133 | ACCURACY: 0.7183 | F1 MACRO: 0.7359 | F1 MICRO: 0.7466
# EPOCH 9 | LOSS: 3.418050527572632 | ACCURACY: 0.7196 | F1 MACRO: 0.7466 | F1 MICRO: 0.7586
# EPOCH 10 | LOSS: 3.38018536567688 | ACCURACY: 0.719 | F1 MACRO: 0.7587 | F1 MICRO: 0.7645
# Iteration 2394: ACCURACY 0.7048 | F1 MACRO 0.7622 | F1 MICRO 0.7705
#                       precision    recall  f1-score   support
#
#           pornografi       0.95      0.85      0.90       362
#                 sara       0.68      0.58      0.63       237
#          radikalisme       0.73      0.84      0.78       235
# pencemaran_nama_baik       0.68      0.82      0.74       492
#
#            micro avg       0.75      0.79      0.77      1326
#            macro avg       0.76      0.77      0.76      1326
#         weighted avg       0.76      0.79      0.77      1326
#          samples avg       0.46      0.45      0.45      1326
#
# Nearest checkpoint: 3886
# Threshold: 50519.44140625
# Samples above threshold: 383
# Acquired samples: 383
# Sampling duration: 21.64396619796753 seconds
# New train size: 2777
# EPOCH 1 | LOSS: 4.937412738800049 | ACCURACY: 0.5781 | F1 MACRO: 0.4296 | F1 MICRO: 0.4929
# EPOCH 2 | LOSS: 4.366113185882568 | ACCURACY: 0.6341 | F1 MACRO: 0.658 | F1 MICRO: 0.6627
# EPOCH 3 | LOSS: 4.183278560638428 | ACCURACY: 0.6514 | F1 MACRO: 0.6521 | F1 MICRO: 0.6937
# EPOCH 4 | LOSS: 3.9615283012390137 | ACCURACY: 0.6296 | F1 MACRO: 0.726 | F1 MICRO: 0.7238
# EPOCH 5 | LOSS: 3.7743263244628906 | ACCURACY: 0.692 | F1 MACRO: 0.7328 | F1 MICRO: 0.7348
# EPOCH 6 | LOSS: 3.5667426586151123 | ACCURACY: 0.7029 | F1 MACRO: 0.7301 | F1 MICRO: 0.7368
# EPOCH 7 | LOSS: 3.4610893726348877 | ACCURACY: 0.7106 | F1 MACRO: 0.7589 | F1 MICRO: 0.7652
# EPOCH 8 | LOSS: 3.4026756286621094 | ACCURACY: 0.7158 | F1 MACRO: 0.7431 | F1 MICRO: 0.7474
# EPOCH 9 | LOSS: 3.3791465759277344 | ACCURACY: 0.7235 | F1 MACRO: 0.7588 | F1 MICRO: 0.7609
# EPOCH 10 | LOSS: 3.3815596103668213 | ACCURACY: 0.717 | F1 MACRO: 0.7563 | F1 MICRO: 0.7598
# Iteration 2777: ACCURACY 0.7106 | F1 MACRO 0.7589 | F1 MICRO 0.7652
#                       precision    recall  f1-score   support
#
#           pornografi       0.97      0.86      0.91       362
#                 sara       0.69      0.56      0.62       237
#          radikalisme       0.79      0.78      0.79       235
# pencemaran_nama_baik       0.70      0.74      0.72       492
#
#            micro avg       0.79      0.75      0.77      1326
#            macro avg       0.79      0.73      0.76      1326
#         weighted avg       0.79      0.75      0.77      1326
#          samples avg       0.44      0.43      0.42      1326
#
# Nearest checkpoint: 3886
# Threshold: 51332.62109375
# Samples above threshold: 345
# Acquired samples: 345
# Sampling duration: 21.95144510269165 seconds
# New train size: 3122
# EPOCH 1 | LOSS: 4.896108150482178 | ACCURACY: 0.6367 | F1 MACRO: 0.705 | F1 MICRO: 0.7151
# EPOCH 2 | LOSS: 4.396612644195557 | ACCURACY: 0.6006 | F1 MACRO: 0.5087 | F1 MICRO: 0.6384
# EPOCH 3 | LOSS: 4.201944351196289 | ACCURACY: 0.6559 | F1 MACRO: 0.6519 | F1 MICRO: 0.6664
# EPOCH 4 | LOSS: 3.9831786155700684 | ACCURACY: 0.5801 | F1 MACRO: 0.4921 | F1 MICRO: 0.5067
# in second
# EPOCH 5 | LOSS: 3.5958683490753174 | ACCURACY: 0.6881 | F1 MACRO: 0.7085 | F1 MICRO: 0.7206
# in second
# EPOCH 6 | LOSS: 3.5419185161590576 | ACCURACY: 0.7042 | F1 MACRO: 0.7522 | F1 MICRO: 0.751
# in second
# EPOCH 7 | LOSS: 3.5252020359039307 | ACCURACY: 0.7061 | F1 MACRO: 0.7515 | F1 MICRO: 0.7529
# in second
# EPOCH 8 | LOSS: 3.5222983360290527 | ACCURACY: 0.6881 | F1 MACRO: 0.7337 | F1 MICRO: 0.7304
# in second
# EPOCH 9 | LOSS: 3.5168914794921875 | ACCURACY: 0.6887 | F1 MACRO: 0.7166 | F1 MICRO: 0.7191
# in second
# Iteration 3122: ACCURACY 0.6367 | F1 MACRO 0.705 | F1 MICRO 0.7151
#                       precision    recall  f1-score   support
#
#           pornografi       0.94      0.83      0.88       362
#                 sara       0.64      0.59      0.62       237
#          radikalisme       0.62      0.64      0.63       235
# pencemaran_nama_baik       0.62      0.76      0.69       492
#
#            micro avg       0.70      0.73      0.72      1326
#            macro avg       0.71      0.71      0.71      1326
#         weighted avg       0.71      0.73      0.72      1326
#          samples avg       0.37      0.39      0.37      1326
#
# Nearest checkpoint: 3886
# Threshold: 50080.01171875
# Samples above threshold: 310
# Acquired samples: 310
# Sampling duration: 21.63112449645996 seconds
# New train size: 3432
# EPOCH 1 | LOSS: 4.886819362640381 | ACCURACY: 0.6109 | F1 MACRO: 0.6696 | F1 MICRO: 0.6891
# EPOCH 2 | LOSS: 4.406966209411621 | ACCURACY: 0.6907 | F1 MACRO: 0.726 | F1 MICRO: 0.741
# EPOCH 3 | LOSS: 4.162744522094727 | ACCURACY: 0.6842 | F1 MACRO: 0.7474 | F1 MICRO: 0.7541
# EPOCH 4 | LOSS: 3.947376012802124 | ACCURACY: 0.7074 | F1 MACRO: 0.7414 | F1 MICRO: 0.7498
# EPOCH 5 | LOSS: 3.7914888858795166 | ACCURACY: 0.6984 | F1 MACRO: 0.7205 | F1 MICRO: 0.7264
# EPOCH 6 | LOSS: 3.5426900386810303 | ACCURACY: 0.701 | F1 MACRO: 0.7394 | F1 MICRO: 0.742
# in second
# EPOCH 7 | LOSS: 3.3383090496063232 | ACCURACY: 0.7042 | F1 MACRO: 0.7372 | F1 MICRO: 0.7431
# in second
# EPOCH 8 | LOSS: 3.317086935043335 | ACCURACY: 0.7087 | F1 MACRO: 0.7392 | F1 MICRO: 0.7454
# in second
# EPOCH 9 | LOSS: 3.3097763061523438 | ACCURACY: 0.7074 | F1 MACRO: 0.746 | F1 MICRO: 0.7498
# in second
# EPOCH 10 | LOSS: 3.297651529312134 | ACCURACY: 0.7068 | F1 MACRO: 0.7439 | F1 MICRO: 0.7473
# Iteration 3432: ACCURACY 0.6842 | F1 MACRO 0.7474 | F1 MICRO 0.7541
#                       precision    recall  f1-score   support
#
#           pornografi       0.84      0.91      0.87       362
#                 sara       0.67      0.61      0.64       237
#          radikalisme       0.68      0.89      0.77       235
# pencemaran_nama_baik       0.68      0.74      0.71       492
#
#            micro avg       0.72      0.79      0.75      1326
#            macro avg       0.72      0.79      0.75      1326
#         weighted avg       0.72      0.79      0.75      1326
#          samples avg       0.43      0.44      0.43      1326
#
# Nearest checkpoint: 3886
# Threshold: 50341.19921875
# Samples above threshold: 279
# Acquired samples: 279
# Sampling duration: 21.906494140625 seconds
# New train size: 3711
# EPOCH 1 | LOSS: 4.929025650024414 | ACCURACY: 0.6006 | F1 MACRO: 0.3898 | F1 MICRO: 0.4854
# EPOCH 2 | LOSS: 4.3870768547058105 | ACCURACY: 0.6875 | F1 MACRO: 0.7369 | F1 MICRO: 0.7462
# EPOCH 3 | LOSS: 4.2347917556762695 | ACCURACY: 0.6977 | F1 MACRO: 0.7454 | F1 MICRO: 0.753
# EPOCH 4 | LOSS: 4.033075332641602 | ACCURACY: 0.6804 | F1 MACRO: 0.7261 | F1 MICRO: 0.726
# EPOCH 5 | LOSS: 3.863471269607544 | ACCURACY: 0.7048 | F1 MACRO: 0.7499 | F1 MICRO: 0.7538
# EPOCH 6 | LOSS: 3.6128761768341064 | ACCURACY: 0.7196 | F1 MACRO: 0.7618 | F1 MICRO: 0.7712
# EPOCH 7 | LOSS: 3.4929842948913574 | ACCURACY: 0.7254 | F1 MACRO: 0.7628 | F1 MICRO: 0.7658
# EPOCH 8 | LOSS: 3.439757823944092 | ACCURACY: 0.708 | F1 MACRO: 0.7605 | F1 MICRO: 0.7666
# EPOCH 9 | LOSS: 3.416834831237793 | ACCURACY: 0.7164 | F1 MACRO: 0.7718 | F1 MICRO: 0.775
# EPOCH 10 | LOSS: 3.402341604232788 | ACCURACY: 0.719 | F1 MACRO: 0.7628 | F1 MICRO: 0.7726
# Iteration 3711: ACCURACY 0.7164 | F1 MACRO 0.7718 | F1 MICRO 0.775
#                       precision    recall  f1-score   support
#
#           pornografi       0.95      0.90      0.93       362
#                 sara       0.65      0.65      0.65       237
#          radikalisme       0.75      0.83      0.79       235
# pencemaran_nama_baik       0.70      0.75      0.72       492
#
#            micro avg       0.76      0.79      0.78      1326
#            macro avg       0.76      0.78      0.77      1326
#         weighted avg       0.77      0.79      0.78      1326
#          samples avg       0.45      0.44      0.44      1326
#
# Nearest checkpoint: 3886
# Threshold: 48985.9453125
# Samples above threshold: 251
# Acquired samples: 175
# Sampling duration: 21.821580171585083 seconds
# New train size: 3886
# EPOCH 1 | LOSS: 4.893754959106445 | ACCURACY: 0.6232 | F1 MACRO: 0.617 | F1 MICRO: 0.6157
# EPOCH 2 | LOSS: 4.408116817474365 | ACCURACY: 0.7074 | F1 MACRO: 0.759 | F1 MICRO: 0.765
# EPOCH 3 | LOSS: 4.173501014709473 | ACCURACY: 0.6489 | F1 MACRO: 0.4641 | F1 MICRO: 0.5593
# EPOCH 4 | LOSS: 3.9734346866607666 | ACCURACY: 0.6669 | F1 MACRO: 0.5777 | F1 MICRO: 0.6691
# EPOCH 5 | LOSS: 3.843977212905884 | ACCURACY: 0.708 | F1 MACRO: 0.7323 | F1 MICRO: 0.7435
# in second
# EPOCH 6 | LOSS: 3.4653172492980957 | ACCURACY: 0.7228 | F1 MACRO: 0.7655 | F1 MICRO: 0.7711
# in second
# EPOCH 7 | LOSS: 3.4418137073516846 | ACCURACY: 0.7241 | F1 MACRO: 0.7613 | F1 MICRO: 0.7688
# in second
# EPOCH 8 | LOSS: 3.432037830352783 | ACCURACY: 0.7293 | F1 MACRO: 0.7627 | F1 MICRO: 0.7707
# in second
# Iteration 3886: ACCURACY 0.7074 | F1 MACRO 0.759 | F1 MICRO 0.765
#                       precision    recall  f1-score   support
#
#           pornografi       0.91      0.87      0.89       362
#                 sara       0.62      0.64      0.63       237
#          radikalisme       0.74      0.84      0.79       235
# pencemaran_nama_baik       0.74      0.72      0.73       492
#
#            micro avg       0.76      0.77      0.77      1326
#            macro avg       0.75      0.77      0.76      1326
#         weighted avg       0.76      0.77      0.77      1326
#          samples avg       0.45      0.44      0.44      1326
#
# Nearest checkpoint: 4663
# Threshold: 49313.34765625
# Samples above threshold: 234
# Acquired samples: 234
# Sampling duration: 21.811365604400635 seconds
# New train size: 4120
# EPOCH 1 | LOSS: 4.874743938446045 | ACCURACY: 0.5916 | F1 MACRO: 0.3796 | F1 MICRO: 0.4387
# EPOCH 2 | LOSS: 4.381516933441162 | ACCURACY: 0.6457 | F1 MACRO: 0.5635 | F1 MICRO: 0.655
# EPOCH 3 | LOSS: 4.161705493927002 | ACCURACY: 0.7055 | F1 MACRO: 0.75 | F1 MICRO: 0.7552
# EPOCH 4 | LOSS: 3.9846301078796387 | ACCURACY: 0.6752 | F1 MACRO: 0.7045 | F1 MICRO: 0.7252
# EPOCH 5 | LOSS: 3.799375534057617 | ACCURACY: 0.7048 | F1 MACRO: 0.7535 | F1 MICRO: 0.7579
# EPOCH 6 | LOSS: 3.550550937652588 | ACCURACY: 0.7177 | F1 MACRO: 0.7803 | F1 MICRO: 0.7806
# EPOCH 7 | LOSS: 3.462473154067993 | ACCURACY: 0.7215 | F1 MACRO: 0.7651 | F1 MICRO: 0.7715
# EPOCH 8 | LOSS: 3.4162116050720215 | ACCURACY: 0.7196 | F1 MACRO: 0.764 | F1 MICRO: 0.775
# EPOCH 9 | LOSS: 3.4119176864624023 | ACCURACY: 0.7183 | F1 MACRO: 0.7735 | F1 MICRO: 0.7765
# in second
# EPOCH 10 | LOSS: 3.3261160850524902 | ACCURACY: 0.7183 | F1 MACRO: 0.769 | F1 MICRO: 0.7727
# Iteration 4120: ACCURACY 0.7177 | F1 MACRO 0.7803 | F1 MICRO 0.7806
#                       precision    recall  f1-score   support
#
#           pornografi       0.94      0.91      0.93       362
#                 sara       0.62      0.71      0.66       237
#          radikalisme       0.75      0.87      0.81       235
# pencemaran_nama_baik       0.68      0.79      0.73       492
#
#            micro avg       0.74      0.83      0.78      1326
#            macro avg       0.74      0.82      0.78      1326
#         weighted avg       0.75      0.83      0.78      1326
#          samples avg       0.46      0.47      0.45      1326
#
# Nearest checkpoint: 4663
# Threshold: 48901.7734375
# Samples above threshold: 210
# Acquired samples: 210
# Sampling duration: 21.70038390159607 seconds
# New train size: 4330
# EPOCH 1 | LOSS: 4.815707683563232 | ACCURACY: 0.6219 | F1 MACRO: 0.5041 | F1 MICRO: 0.543
# EPOCH 2 | LOSS: 4.3707404136657715 | ACCURACY: 0.6437 | F1 MACRO: 0.6209 | F1 MICRO: 0.6403
# EPOCH 3 | LOSS: 4.166913986206055 | ACCURACY: 0.7016 | F1 MACRO: 0.7347 | F1 MICRO: 0.7414
# EPOCH 4 | LOSS: 3.9879331588745117 | ACCURACY: 0.6939 | F1 MACRO: 0.695 | F1 MICRO: 0.7069
# EPOCH 5 | LOSS: 3.816143274307251 | ACCURACY: 0.7093 | F1 MACRO: 0.7786 | F1 MICRO: 0.7826
# EPOCH 6 | LOSS: 3.558063507080078 | ACCURACY: 0.7222 | F1 MACRO: 0.7614 | F1 MICRO: 0.7615
# EPOCH 7 | LOSS: 3.4674220085144043 | ACCURACY: 0.7299 | F1 MACRO: 0.7728 | F1 MICRO: 0.7785
# EPOCH 8 | LOSS: 3.416706085205078 | ACCURACY: 0.7299 | F1 MACRO: 0.7771 | F1 MICRO: 0.7775
# in second
# EPOCH 9 | LOSS: 3.337270736694336 | ACCURACY: 0.7318 | F1 MACRO: 0.7722 | F1 MICRO: 0.7756
# in second
# EPOCH 10 | LOSS: 3.3255317211151123 | ACCURACY: 0.7357 | F1 MACRO: 0.776 | F1 MICRO: 0.7779
# Iteration 4330: ACCURACY 0.7093 | F1 MACRO 0.7786 | F1 MICRO 0.7826
#                       precision    recall  f1-score   support
#
#           pornografi       0.94      0.90      0.92       362
#                 sara       0.63      0.71      0.67       237
#          radikalisme       0.75      0.81      0.78       235
# pencemaran_nama_baik       0.67      0.84      0.75       492
#
#            micro avg       0.74      0.83      0.78      1326
#            macro avg       0.75      0.82      0.78      1326
#         weighted avg       0.75      0.83      0.79      1326
#          samples avg       0.47      0.47      0.46      1326
#
# Nearest checkpoint: 4663
# Threshold: 48182.91796875
# Samples above threshold: 189
# Acquired samples: 200
# Sampling duration: 21.661739110946655 seconds
# New train size: 4530
# EPOCH 1 | LOSS: 4.811537742614746 | ACCURACY: 0.6051 | F1 MACRO: 0.4561 | F1 MICRO: 0.5481
# EPOCH 2 | LOSS: 4.443994522094727 | ACCURACY: 0.5891 | F1 MACRO: 0.7121 | F1 MICRO: 0.7146
# EPOCH 3 | LOSS: 4.235223293304443 | ACCURACY: 0.6296 | F1 MACRO: 0.4115 | F1 MICRO: 0.5352
# EPOCH 4 | LOSS: 4.029926776885986 | ACCURACY: 0.6585 | F1 MACRO: 0.5646 | F1 MICRO: 0.6471
# EPOCH 5 | LOSS: 3.8591442108154297 | ACCURACY: 0.6984 | F1 MACRO: 0.7387 | F1 MICRO: 0.7563
# EPOCH 6 | LOSS: 3.613694667816162 | ACCURACY: 0.7305 | F1 MACRO: 0.7708 | F1 MICRO: 0.7767
# EPOCH 7 | LOSS: 3.49308705329895 | ACCURACY: 0.7222 | F1 MACRO: 0.7685 | F1 MICRO: 0.772
# EPOCH 8 | LOSS: 3.463135004043579 | ACCURACY: 0.7299 | F1 MACRO: 0.7722 | F1 MICRO: 0.7834
# EPOCH 9 | LOSS: 3.44464373588562 | ACCURACY: 0.7106 | F1 MACRO: 0.7667 | F1 MICRO: 0.7718
# EPOCH 10 | LOSS: 3.4145162105560303 | ACCURACY: 0.7293 | F1 MACRO: 0.7748 | F1 MICRO: 0.7781
# Iteration 4530: ACCURACY 0.7299 | F1 MACRO 0.7722 | F1 MICRO 0.7834
#                       precision    recall  f1-score   support
#
#           pornografi       0.95      0.91      0.93       362
#                 sara       0.71      0.56      0.63       237
#          radikalisme       0.79      0.79      0.79       235
# pencemaran_nama_baik       0.72      0.77      0.75       492
#
#            micro avg       0.79      0.77      0.78      1326
#            macro avg       0.79      0.76      0.77      1326
#         weighted avg       0.79      0.77      0.78      1326
#          samples avg       0.46      0.44      0.44      1326
#
# Nearest checkpoint: 4663
# Threshold: 47399.25
# Samples above threshold: 169
# Acquired samples: 133
# Sampling duration: 22.049674034118652 seconds
# New train size: 4663
# EPOCH 1 | LOSS: 4.863300323486328 | ACCURACY: 0.6071 | F1 MACRO: 0.6532 | F1 MICRO: 0.6554
# EPOCH 2 | LOSS: 4.404548168182373 | ACCURACY: 0.5897 | F1 MACRO: 0.4087 | F1 MICRO: 0.4572
# EPOCH 3 | LOSS: 4.228260040283203 | ACCURACY: 0.6373 | F1 MACRO: 0.5545 | F1 MICRO: 0.6468
# EPOCH 4 | LOSS: 4.119120121002197 | ACCURACY: 0.6875 | F1 MACRO: 0.6669 | F1 MICRO: 0.7022
# EPOCH 5 | LOSS: 3.965951442718506 | ACCURACY: 0.7035 | F1 MACRO: 0.7361 | F1 MICRO: 0.745
# EPOCH 6 | LOSS: 3.6780407428741455 | ACCURACY: 0.7241 | F1 MACRO: 0.7695 | F1 MICRO: 0.7722
# EPOCH 7 | LOSS: 3.542496681213379 | ACCURACY: 0.7305 | F1 MACRO: 0.7721 | F1 MICRO: 0.7788
# EPOCH 8 | LOSS: 3.498553991317749 | ACCURACY: 0.7293 | F1 MACRO: 0.761 | F1 MICRO: 0.7735
# EPOCH 9 | LOSS: 3.4676315784454346 | ACCURACY: 0.7235 | F1 MACRO: 0.7559 | F1 MICRO: 0.7606
# EPOCH 10 | LOSS: 3.4524049758911133 | ACCURACY: 0.7235 | F1 MACRO: 0.7726 | F1 MICRO: 0.7823
# Iteration 4663: ACCURACY 0.7235 | F1 MACRO 0.7726 | F1 MICRO 0.7823
#                       precision    recall  f1-score   support
#
#           pornografi       0.95      0.88      0.92       362
#                 sara       0.73      0.56      0.63       237
#          radikalisme       0.79      0.80      0.79       235
# pencemaran_nama_baik       0.69      0.82      0.75       492
#
#            micro avg       0.78      0.79      0.78      1326
#            macro avg       0.79      0.77      0.77      1326
#         weighted avg       0.79      0.79      0.78      1326
#          samples avg       0.45      0.45      0.44      1326
#
# Nearest checkpoint: 5441
# Threshold: 47084.18359375
# Samples above threshold: 156
# Acquired samples: 200
# Sampling duration: 21.62600040435791 seconds
# New train size: 4863
# EPOCH 1 | LOSS: 4.844688892364502 | ACCURACY: 0.6418 | F1 MACRO: 0.4988 | F1 MICRO: 0.5733
# EPOCH 2 | LOSS: 4.434126377105713 | ACCURACY: 0.6675 | F1 MACRO: 0.65 | F1 MICRO: 0.6872
# EPOCH 3 | LOSS: 4.235192775726318 | ACCURACY: 0.6714 | F1 MACRO: 0.6886 | F1 MICRO: 0.7031
# EPOCH 4 | LOSS: 4.040838718414307 | ACCURACY: 0.7068 | F1 MACRO: 0.6932 | F1 MICRO: 0.7307
# EPOCH 5 | LOSS: 3.9122471809387207 | ACCURACY: 0.7196 | F1 MACRO: 0.7794 | F1 MICRO: 0.7834
# EPOCH 6 | LOSS: 3.630807638168335 | ACCURACY: 0.7299 | F1 MACRO: 0.7664 | F1 MICRO: 0.7764
# EPOCH 7 | LOSS: 3.546233654022217 | ACCURACY: 0.735 | F1 MACRO: 0.7632 | F1 MICRO: 0.773
# EPOCH 8 | LOSS: 3.4889631271362305 | ACCURACY: 0.7473 | F1 MACRO: 0.7815 | F1 MICRO: 0.791
# EPOCH 9 | LOSS: 3.482201099395752 | ACCURACY: 0.7325 | F1 MACRO: 0.7644 | F1 MICRO: 0.7725
# EPOCH 10 | LOSS: 3.4632463455200195 | ACCURACY: 0.7267 | F1 MACRO: 0.7736 | F1 MICRO: 0.7817
# Iteration 4863: ACCURACY 0.7473 | F1 MACRO 0.7815 | F1 MICRO 0.791
#                       precision    recall  f1-score   support
#
#           pornografi       0.96      0.90      0.93       362
#                 sara       0.74      0.57      0.64       237
#          radikalisme       0.76      0.85      0.80       235
# pencemaran_nama_baik       0.74      0.76      0.75       492
#
#            micro avg       0.80      0.78      0.79      1326
#            macro avg       0.80      0.77      0.78      1326
#         weighted avg       0.80      0.78      0.79      1326
#          samples avg       0.45      0.44      0.44      1326
#
# Nearest checkpoint: 5441
# Threshold: 46444.640625
# Samples above threshold: 136
# Acquired samples: 200
# Sampling duration: 21.679755926132202 seconds
# New train size: 5063
# EPOCH 1 | LOSS: 4.842162609100342 | ACCURACY: 0.699 | F1 MACRO: 0.745 | F1 MICRO: 0.7514
# EPOCH 2 | LOSS: 4.427121639251709 | ACCURACY: 0.6971 | F1 MACRO: 0.7391 | F1 MICRO: 0.7361
# EPOCH 3 | LOSS: 4.215958118438721 | ACCURACY: 0.6945 | F1 MACRO: 0.7548 | F1 MICRO: 0.7541
# EPOCH 4 | LOSS: 4.065618991851807 | ACCURACY: 0.5884 | F1 MACRO: 0.5474 | F1 MICRO: 0.631
# EPOCH 5 | LOSS: 3.910477876663208 | ACCURACY: 0.7042 | F1 MACRO: 0.7375 | F1 MICRO: 0.7514
# EPOCH 6 | LOSS: 3.6551599502563477 | ACCURACY: 0.71 | F1 MACRO: 0.7661 | F1 MICRO: 0.7703
# EPOCH 7 | LOSS: 3.5443732738494873 | ACCURACY: 0.7312 | F1 MACRO: 0.7667 | F1 MICRO: 0.7734
# EPOCH 8 | LOSS: 3.507750988006592 | ACCURACY: 0.7293 | F1 MACRO: 0.7773 | F1 MICRO: 0.782
# EPOCH 9 | LOSS: 3.4805781841278076 | ACCURACY: 0.7203 | F1 MACRO: 0.7522 | F1 MICRO: 0.7605
# EPOCH 10 | LOSS: 3.470151424407959 | ACCURACY: 0.7125 | F1 MACRO: 0.7754 | F1 MICRO: 0.7793
# Iteration 5063: ACCURACY 0.7293 | F1 MACRO 0.7773 | F1 MICRO 0.782
#                       precision    recall  f1-score   support
#
#           pornografi       0.93      0.91      0.92       362
#                 sara       0.64      0.67      0.66       237
#          radikalisme       0.74      0.89      0.81       235
# pencemaran_nama_baik       0.76      0.70      0.73       492
#
#            micro avg       0.78      0.78      0.78      1326
#            macro avg       0.77      0.79      0.78      1326
#         weighted avg       0.78      0.78      0.78      1326
#          samples avg       0.44      0.44      0.43      1326
#
# Nearest checkpoint: 5441
# Threshold: 19887.595703125
# Samples above threshold: 116
# Acquired samples: 200
# Sampling duration: 21.694024562835693 seconds
# New train size: 5263
# EPOCH 1 | LOSS: 4.799255847930908 | ACCURACY: 0.5987 | F1 MACRO: 0.254 | F1 MICRO: 0.4007
# EPOCH 2 | LOSS: 4.408188819885254 | ACCURACY: 0.5023 | F1 MACRO: 0.312 | F1 MICRO: 0.3333
# EPOCH 3 | LOSS: 4.22554874420166 | ACCURACY: 0.6868 | F1 MACRO: 0.7605 | F1 MICRO: 0.7558
# EPOCH 4 | LOSS: 4.06254243850708 | ACCURACY: 0.6971 | F1 MACRO: 0.7191 | F1 MICRO: 0.7391
# EPOCH 5 | LOSS: 3.8807106018066406 | ACCURACY: 0.6842 | F1 MACRO: 0.6566 | F1 MICRO: 0.7149
# EPOCH 6 | LOSS: 3.6261980533599854 | ACCURACY: 0.7248 | F1 MACRO: 0.7502 | F1 MICRO: 0.7582
# EPOCH 7 | LOSS: 3.5209031105041504 | ACCURACY: 0.7254 | F1 MACRO: 0.7792 | F1 MICRO: 0.7865
# EPOCH 8 | LOSS: 3.480290412902832 | ACCURACY: 0.7318 | F1 MACRO: 0.7767 | F1 MICRO: 0.7791
# EPOCH 9 | LOSS: 3.4690916538238525 | ACCURACY: 0.7299 | F1 MACRO: 0.7639 | F1 MICRO: 0.7656
# EPOCH 10 | LOSS: 3.473134994506836 | ACCURACY: 0.7183 | F1 MACRO: 0.7747 | F1 MICRO: 0.7798
# Iteration 5263: ACCURACY 0.7254 | F1 MACRO 0.7792 | F1 MICRO 0.7865
#                       precision    recall  f1-score   support
#
#           pornografi       0.95      0.90      0.93       362
#                 sara       0.67      0.62      0.65       237
#          radikalisme       0.74      0.86      0.80       235
# pencemaran_nama_baik       0.73      0.76      0.75       492
#
#            micro avg       0.78      0.79      0.79      1326
#            macro avg       0.78      0.79      0.78      1326
#         weighted avg       0.78      0.79      0.79      1326
#          samples avg       0.46      0.45      0.45      1326
#
# Nearest checkpoint: 5441
# Threshold: 20129.26171875
# Samples above threshold: 96
# Acquired samples: 178
# Sampling duration: 21.786814212799072 seconds
# New train size: 5441
# EPOCH 1 | LOSS: 4.8027849197387695 | ACCURACY: 0.6579 | F1 MACRO: 0.7228 | F1 MICRO: 0.7236
# EPOCH 2 | LOSS: 4.369901180267334 | ACCURACY: 0.6457 | F1 MACRO: 0.6116 | F1 MICRO: 0.6786
# EPOCH 3 | LOSS: 4.213667869567871 | ACCURACY: 0.6502 | F1 MACRO: 0.5629 | F1 MICRO: 0.6598
# EPOCH 4 | LOSS: 4.081892013549805 | ACCURACY: 0.6855 | F1 MACRO: 0.7102 | F1 MICRO: 0.7043
# in second
# EPOCH 5 | LOSS: 3.64208722114563 | ACCURACY: 0.7235 | F1 MACRO: 0.7602 | F1 MICRO: 0.7656
# in second
# EPOCH 6 | LOSS: 3.605969190597534 | ACCURACY: 0.726 | F1 MACRO: 0.7676 | F1 MICRO: 0.7733
# in second
# EPOCH 7 | LOSS: 3.59838604927063 | ACCURACY: 0.7228 | F1 MACRO: 0.7551 | F1 MICRO: 0.7638
# in second
# EPOCH 8 | LOSS: 3.596853017807007 | ACCURACY: 0.728 | F1 MACRO: 0.7593 | F1 MICRO: 0.7695
# in second
# Iteration 5441: ACCURACY 0.6579 | F1 MACRO 0.7228 | F1 MICRO 0.7236
#                       precision    recall  f1-score   support
#
#           pornografi       0.91      0.69      0.78       362
#                 sara       0.56      0.65      0.60       237
#          radikalisme       0.74      0.86      0.80       235
# pencemaran_nama_baik       0.68      0.75      0.71       492
#
#            micro avg       0.71      0.74      0.72      1326
#            macro avg       0.72      0.74      0.72      1326
#         weighted avg       0.73      0.74      0.73      1326
#          samples avg       0.38      0.40      0.38      1326
#
# Nearest checkpoint: 6218
# Threshold: 19785.654296875
# Samples above threshold: 78
# Acquired samples: 200
# Sampling duration: 21.910074949264526 seconds
# New train size: 5641
# EPOCH 1 | LOSS: 4.789966583251953 | ACCURACY: 0.636 | F1 MACRO: 0.6408 | F1 MICRO: 0.6481
# EPOCH 2 | LOSS: 4.3336076736450195 | ACCURACY: 0.636 | F1 MACRO: 0.5401 | F1 MICRO: 0.631
# EPOCH 3 | LOSS: 4.1741485595703125 | ACCURACY: 0.719 | F1 MACRO: 0.7645 | F1 MICRO: 0.7679
# EPOCH 4 | LOSS: 4.0495429039001465 | ACCURACY: 0.7293 | F1 MACRO: 0.7621 | F1 MICRO: 0.7725
# EPOCH 5 | LOSS: 3.835500717163086 | ACCURACY: 0.7228 | F1 MACRO: 0.7472 | F1 MICRO: 0.7619
# EPOCH 6 | LOSS: 3.6021883487701416 | ACCURACY: 0.7305 | F1 MACRO: 0.7481 | F1 MICRO: 0.7583
# EPOCH 7 | LOSS: 3.507966995239258 | ACCURACY: 0.728 | F1 MACRO: 0.7714 | F1 MICRO: 0.779
# EPOCH 8 | LOSS: 3.4676384925842285 | ACCURACY: 0.7383 | F1 MACRO: 0.7878 | F1 MICRO: 0.7895
# EPOCH 9 | LOSS: 3.4676520824432373 | ACCURACY: 0.7312 | F1 MACRO: 0.7858 | F1 MICRO: 0.7912
# EPOCH 10 | LOSS: 3.4560134410858154 | ACCURACY: 0.7325 | F1 MACRO: 0.7667 | F1 MICRO: 0.768
# Iteration 5641: ACCURACY 0.7312 | F1 MACRO 0.7858 | F1 MICRO 0.7912
#                       precision    recall  f1-score   support
#
#           pornografi       0.93      0.92      0.92       362
#                 sara       0.71      0.66      0.68       237
#          radikalisme       0.75      0.82      0.79       235
# pencemaran_nama_baik       0.70      0.81      0.75       492
#
#            micro avg       0.77      0.81      0.79      1326
#            macro avg       0.77      0.80      0.79      1326
#         weighted avg       0.77      0.81      0.79      1326
#          samples avg       0.47      0.47      0.46      1326
#
# Nearest checkpoint: 6218
# Threshold: 19454.5390625
# Samples above threshold: 58
# Acquired samples: 200
# Sampling duration: 21.5900821685791 seconds
# New train size: 5841
# EPOCH 1 | LOSS: 4.744926929473877 | ACCURACY: 0.5981 | F1 MACRO: 0.5295 | F1 MICRO: 0.6694
# EPOCH 2 | LOSS: 4.34111213684082 | ACCURACY: 0.6624 | F1 MACRO: 0.7563 | F1 MICRO: 0.7493
# EPOCH 3 | LOSS: 4.190897464752197 | ACCURACY: 0.6463 | F1 MACRO: 0.6036 | F1 MICRO: 0.6367
# EPOCH 4 | LOSS: 4.013408184051514 | ACCURACY: 0.6772 | F1 MACRO: 0.6317 | F1 MICRO: 0.6901
# EPOCH 5 | LOSS: 3.8695733547210693 | ACCURACY: 0.7029 | F1 MACRO: 0.7709 | F1 MICRO: 0.7781
# EPOCH 6 | LOSS: 3.6242825984954834 | ACCURACY: 0.717 | F1 MACRO: 0.7826 | F1 MICRO: 0.7861
# EPOCH 7 | LOSS: 3.521373987197876 | ACCURACY: 0.7196 | F1 MACRO: 0.7419 | F1 MICRO: 0.7508
# EPOCH 8 | LOSS: 3.4878876209259033 | ACCURACY: 0.7453 | F1 MACRO: 0.7878 | F1 MICRO: 0.7918
# EPOCH 9 | LOSS: 3.4667952060699463 | ACCURACY: 0.735 | F1 MACRO: 0.7485 | F1 MICRO: 0.764
# EPOCH 10 | LOSS: 3.442319393157959 | ACCURACY: 0.7209 | F1 MACRO: 0.783 | F1 MICRO: 0.7837
# Iteration 5841: ACCURACY 0.7453 | F1 MACRO 0.7878 | F1 MICRO 0.7918
#                       precision    recall  f1-score   support
#
#           pornografi       0.95      0.91      0.93       362
#                 sara       0.72      0.65      0.68       237
#          radikalisme       0.74      0.87      0.80       235
# pencemaran_nama_baik       0.73      0.75      0.74       492
#
#            micro avg       0.79      0.80      0.79      1326
#            macro avg       0.78      0.80      0.79      1326
#         weighted avg       0.79      0.80      0.79      1326
#          samples avg       0.46      0.46      0.45      1326
#
# Nearest checkpoint: 6218
# Threshold: 19196.76171875
# Samples above threshold: 38
# Acquired samples: 200
# Sampling duration: 21.695076942443848 seconds
# New train size: 6041
# EPOCH 1 | LOSS: 4.653560161590576 | ACCURACY: 0.6514 | F1 MACRO: 0.6842 | F1 MICRO: 0.6894
# EPOCH 2 | LOSS: 4.3035454750061035 | ACCURACY: 0.7029 | F1 MACRO: 0.7467 | F1 MICRO: 0.7454
# EPOCH 3 | LOSS: 4.144683361053467 | ACCURACY: 0.7235 | F1 MACRO: 0.7686 | F1 MICRO: 0.7696
# EPOCH 4 | LOSS: 3.938568115234375 | ACCURACY: 0.6695 | F1 MACRO: 0.753 | F1 MICRO: 0.7577
# EPOCH 5 | LOSS: 3.8441267013549805 | ACCURACY: 0.7119 | F1 MACRO: 0.7302 | F1 MICRO: 0.7404
# EPOCH 6 | LOSS: 3.585759401321411 | ACCURACY: 0.737 | F1 MACRO: 0.7706 | F1 MICRO: 0.7787
# EPOCH 7 | LOSS: 3.493626117706299 | ACCURACY: 0.7479 | F1 MACRO: 0.7854 | F1 MICRO: 0.7926
# EPOCH 8 | LOSS: 3.473130464553833 | ACCURACY: 0.7267 | F1 MACRO: 0.7803 | F1 MICRO: 0.7854
# EPOCH 9 | LOSS: 3.4383656978607178 | ACCURACY: 0.7299 | F1 MACRO: 0.7874 | F1 MICRO: 0.7919
# EPOCH 10 | LOSS: 3.434715509414673 | ACCURACY: 0.7492 | F1 MACRO: 0.779 | F1 MICRO: 0.7867
# Iteration 6041: ACCURACY 0.7479 | F1 MACRO 0.7854 | F1 MICRO 0.7926
#                       precision    recall  f1-score   support
#
#           pornografi       0.97      0.90      0.93       362
#                 sara       0.68      0.65      0.66       237
#          radikalisme       0.77      0.81      0.79       235
# pencemaran_nama_baik       0.74      0.78      0.76       492
#
#            micro avg       0.79      0.79      0.79      1326
#            macro avg       0.79      0.78      0.79      1326
#         weighted avg       0.80      0.79      0.79      1326
#          samples avg       0.46      0.46      0.45      1326
#
# Nearest checkpoint: 6218
# Threshold: 18843.3984375
# Samples above threshold: 18
# Acquired samples: 177
# Sampling duration: 21.799947261810303 seconds
# New train size: 6218
# EPOCH 1 | LOSS: 4.69032621383667 | ACCURACY: 0.6605 | F1 MACRO: 0.6798 | F1 MICRO: 0.7115
# EPOCH 2 | LOSS: 4.268599510192871 | ACCURACY: 0.6881 | F1 MACRO: 0.7454 | F1 MICRO: 0.757
# EPOCH 3 | LOSS: 4.131917953491211 | ACCURACY: 0.6682 | F1 MACRO: 0.7394 | F1 MICRO: 0.7365
# EPOCH 4 | LOSS: 3.965510368347168 | ACCURACY: 0.7068 | F1 MACRO: 0.7418 | F1 MICRO: 0.7557
# EPOCH 5 | LOSS: 3.8418662548065186 | ACCURACY: 0.6791 | F1 MACRO: 0.6738 | F1 MICRO: 0.721
# in second
# EPOCH 6 | LOSS: 3.5266318321228027 | ACCURACY: 0.7318 | F1 MACRO: 0.7598 | F1 MICRO: 0.771
# in second
# EPOCH 7 | LOSS: 3.504727363586426 | ACCURACY: 0.7235 | F1 MACRO: 0.7586 | F1 MICRO: 0.768
# in second
# EPOCH 8 | LOSS: 3.499271869659424 | ACCURACY: 0.7241 | F1 MACRO: 0.756 | F1 MICRO: 0.7661
# in second
# EPOCH 9 | LOSS: 3.490002393722534 | ACCURACY: 0.719 | F1 MACRO: 0.7718 | F1 MICRO: 0.7777
# in second
# EPOCH 10 | LOSS: 3.4875271320343018 | ACCURACY: 0.726 | F1 MACRO: 0.7644 | F1 MICRO: 0.7714
# Iteration 6218: ACCURACY 0.6881 | F1 MACRO 0.7454 | F1 MICRO 0.757
#                       precision    recall  f1-score   support
#
#           pornografi       0.97      0.84      0.90       362
#                 sara       0.68      0.59      0.63       237
#          radikalisme       0.81      0.64      0.71       235
# pencemaran_nama_baik       0.65      0.84      0.74       492
#
#            micro avg       0.75      0.76      0.76      1326
#            macro avg       0.78      0.73      0.75      1326
#         weighted avg       0.77      0.76      0.76      1326
#          samples avg       0.45      0.44      0.43      1326
#
# Total sampling time: 457.25 seconds
# Total runtime: 8130.726983308792 seconds

# %% [markdown]
# ## RUN 2

# %%
active_learning(seeds[1], 1)
# Out:
# ===============================================
# TRIAL 2
# Random seed: 81
# label num 4
# EPOCH 1 | LOSS: 6.351085186004639 | ACCURACY: 0.4367 | F1 MACRO: 0.0 | F1 MICRO: 0.0
# EPOCH 2 | LOSS: 4.946178913116455 | ACCURACY: 0.5138 | F1 MACRO: 0.1253 | F1 MICRO: 0.1672
# EPOCH 3 | LOSS: 4.4984564781188965 | ACCURACY: 0.5627 | F1 MACRO: 0.3539 | F1 MICRO: 0.5265
# EPOCH 4 | LOSS: 4.24172306060791 | ACCURACY: 0.6071 | F1 MACRO: 0.5851 | F1 MICRO: 0.6058
# EPOCH 5 | LOSS: 4.152370929718018 | ACCURACY: 0.5434 | F1 MACRO: 0.6723 | F1 MICRO: 0.6816
# EPOCH 6 | LOSS: 3.8908932209014893 | ACCURACY: 0.645 | F1 MACRO: 0.6184 | F1 MICRO: 0.6601
# EPOCH 7 | LOSS: 3.7049498558044434 | ACCURACY: 0.6559 | F1 MACRO: 0.6433 | F1 MICRO: 0.6828
# EPOCH 8 | LOSS: 3.608799934387207 | ACCURACY: 0.6559 | F1 MACRO: 0.6492 | F1 MICRO: 0.6862
# EPOCH 9 | LOSS: 3.5972201824188232 | ACCURACY: 0.6534 | F1 MACRO: 0.6562 | F1 MICRO: 0.6822
# EPOCH 10 | LOSS: 3.515899896621704 | ACCURACY: 0.6508 | F1 MACRO: 0.6426 | F1 MICRO: 0.6711
# Iteration 388: ACCURACY 0.6559 | F1 MACRO 0.6492 | F1 MICRO 0.6862
#                       precision    recall  f1-score   support
#
#           pornografi       0.93      0.84      0.88       362
#                 sara       0.75      0.28      0.41       237
#          radikalisme       0.75      0.59      0.66       235
# pencemaran_nama_baik       0.73      0.58      0.65       492
#
#            micro avg       0.80      0.60      0.69      1326
#            macro avg       0.79      0.57      0.65      1326
#         weighted avg       0.79      0.60      0.67      1326
#          samples avg       0.37      0.34      0.35      1326
#
# Nearest checkpoint: 3886
# Threshold: 46667.28125
# Samples above threshold: 583
# Acquired samples: 583
# Sampling duration: 22.085685968399048 seconds
# New train size: 971
# EPOCH 1 | LOSS: 5.376914024353027 | ACCURACY: 0.4675 | F1 MACRO: 0.4042 | F1 MICRO: 0.4274
# EPOCH 2 | LOSS: 4.573349952697754 | ACCURACY: 0.5428 | F1 MACRO: 0.4399 | F1 MICRO: 0.4802
# EPOCH 3 | LOSS: 4.1910271644592285 | ACCURACY: 0.6244 | F1 MACRO: 0.7182 | F1 MICRO: 0.7173
# EPOCH 4 | LOSS: 3.9262022972106934 | ACCURACY: 0.6714 | F1 MACRO: 0.7169 | F1 MICRO: 0.7219
# EPOCH 5 | LOSS: 3.7004647254943848 | ACCURACY: 0.6444 | F1 MACRO: 0.7195 | F1 MICRO: 0.7305
# EPOCH 6 | LOSS: 3.5515329837799072 | ACCURACY: 0.6887 | F1 MACRO: 0.7288 | F1 MICRO: 0.7382
# EPOCH 7 | LOSS: 3.3203201293945312 | ACCURACY: 0.6855 | F1 MACRO: 0.7197 | F1 MICRO: 0.7288
# EPOCH 8 | LOSS: 3.252713203430176 | ACCURACY: 0.692 | F1 MACRO: 0.7312 | F1 MICRO: 0.7353
# EPOCH 9 | LOSS: 3.2302064895629883 | ACCURACY: 0.681 | F1 MACRO: 0.7284 | F1 MICRO: 0.7351
# in second
# EPOCH 10 | LOSS: 3.1771836280822754 | ACCURACY: 0.6804 | F1 MACRO: 0.7107 | F1 MICRO: 0.722
# Iteration 971: ACCURACY 0.6887 | F1 MACRO 0.7288 | F1 MICRO 0.7382
#                       precision    recall  f1-score   support
#
#           pornografi       0.91      0.86      0.88       362
#                 sara       0.69      0.54      0.61       237
#          radikalisme       0.72      0.75      0.74       235
# pencemaran_nama_baik       0.74      0.64      0.69       492
#
#            micro avg       0.78      0.70      0.74      1326
#            macro avg       0.77      0.70      0.73      1326
#         weighted avg       0.77      0.70      0.74      1326
#          samples avg       0.40      0.39      0.39      1326
#
# Nearest checkpoint: 3886
# Threshold: 58009.375
# Samples above threshold: 525
# Acquired samples: 525
# Sampling duration: 21.78170347213745 seconds
# New train size: 1496
# EPOCH 1 | LOSS: 5.142440319061279 | ACCURACY: 0.6476 | F1 MACRO: 0.6667 | F1 MICRO: 0.6672
# EPOCH 2 | LOSS: 4.375032424926758 | ACCURACY: 0.6219 | F1 MACRO: 0.6785 | F1 MICRO: 0.7027
# EPOCH 3 | LOSS: 4.140395641326904 | ACCURACY: 0.6392 | F1 MACRO: 0.6243 | F1 MICRO: 0.6209
# EPOCH 4 | LOSS: 3.951812982559204 | ACCURACY: 0.683 | F1 MACRO: 0.7133 | F1 MICRO: 0.7146
# EPOCH 5 | LOSS: 3.7049055099487305 | ACCURACY: 0.6592 | F1 MACRO: 0.722 | F1 MICRO: 0.718
# EPOCH 6 | LOSS: 3.461949110031128 | ACCURACY: 0.69 | F1 MACRO: 0.73 | F1 MICRO: 0.7431
# EPOCH 7 | LOSS: 3.3759753704071045 | ACCURACY: 0.6881 | F1 MACRO: 0.7235 | F1 MICRO: 0.7281
# EPOCH 8 | LOSS: 3.3155698776245117 | ACCURACY: 0.6997 | F1 MACRO: 0.7298 | F1 MICRO: 0.7378
# EPOCH 9 | LOSS: 3.3024215698242188 | ACCURACY: 0.699 | F1 MACRO: 0.7325 | F1 MICRO: 0.7395
# in second
# EPOCH 10 | LOSS: 3.2463903427124023 | ACCURACY: 0.6984 | F1 MACRO: 0.7229 | F1 MICRO: 0.7335
# Iteration 1496: ACCURACY 0.69 | F1 MACRO 0.73 | F1 MICRO 0.7431
#                       precision    recall  f1-score   support
#
#           pornografi       0.94      0.85      0.89       362
#                 sara       0.74      0.49      0.59       237
#          radikalisme       0.77      0.70      0.73       235
# pencemaran_nama_baik       0.69      0.73      0.71       492
#
#            micro avg       0.78      0.71      0.74      1326
#            macro avg       0.78      0.69      0.73      1326
#         weighted avg       0.78      0.71      0.74      1326
#          samples avg       0.43      0.41      0.41      1326
#
# Nearest checkpoint: 3886
# Threshold: 53783.953125
# Samples above threshold: 473
# Acquired samples: 473
# Sampling duration: 22.036165475845337 seconds
# New train size: 1969
# EPOCH 1 | LOSS: 5.059685230255127 | ACCURACY: 0.5511 | F1 MACRO: 0.3783 | F1 MICRO: 0.4456
# EPOCH 2 | LOSS: 4.4271674156188965 | ACCURACY: 0.6399 | F1 MACRO: 0.7063 | F1 MICRO: 0.717
# EPOCH 3 | LOSS: 4.199906826019287 | ACCURACY: 0.6283 | F1 MACRO: 0.5135 | F1 MICRO: 0.5785
# EPOCH 4 | LOSS: 4.000680446624756 | ACCURACY: 0.5936 | F1 MACRO: 0.557 | F1 MICRO: 0.5816
# EPOCH 5 | LOSS: 3.8692235946655273 | ACCURACY: 0.6862 | F1 MACRO: 0.7124 | F1 MICRO: 0.7287
# EPOCH 6 | LOSS: 3.620858669281006 | ACCURACY: 0.6984 | F1 MACRO: 0.6941 | F1 MICRO: 0.7113
# EPOCH 7 | LOSS: 3.488312005996704 | ACCURACY: 0.7061 | F1 MACRO: 0.7233 | F1 MICRO: 0.7352
# EPOCH 8 | LOSS: 3.409785270690918 | ACCURACY: 0.7042 | F1 MACRO: 0.7261 | F1 MICRO: 0.7385
# EPOCH 9 | LOSS: 3.4896273612976074 | ACCURACY: 0.7119 | F1 MACRO: 0.743 | F1 MICRO: 0.7493
# EPOCH 10 | LOSS: 3.3858606815338135 | ACCURACY: 0.7003 | F1 MACRO: 0.7455 | F1 MICRO: 0.7507
# Iteration 1969: ACCURACY 0.7003 | F1 MACRO 0.7455 | F1 MICRO 0.7507
#                       precision    recall  f1-score   support
#
#           pornografi       0.92      0.84      0.88       362
#                 sara       0.68      0.59      0.64       237
#          radikalisme       0.73      0.79      0.76       235
# pencemaran_nama_baik       0.70      0.72      0.71       492
#
#            micro avg       0.76      0.74      0.75      1326
#            macro avg       0.76      0.74      0.75      1326
#         weighted avg       0.76      0.74      0.75      1326
#          samples avg       0.43      0.43      0.42      1326
#
# Nearest checkpoint: 3886
# Threshold: 50114.14453125
# Samples above threshold: 425
# Acquired samples: 425
# Sampling duration: 21.750109910964966 seconds
# New train size: 2394
# EPOCH 1 | LOSS: 4.964062690734863 | ACCURACY: 0.4257 | F1 MACRO: 0.1539 | F1 MICRO: 0.1567
# EPOCH 2 | LOSS: 4.41795015335083 | ACCURACY: 0.6572 | F1 MACRO: 0.6739 | F1 MICRO: 0.6852
# EPOCH 3 | LOSS: 4.176417350769043 | ACCURACY: 0.6804 | F1 MACRO: 0.738 | F1 MICRO: 0.7443
# EPOCH 4 | LOSS: 3.9337737560272217 | ACCURACY: 0.6527 | F1 MACRO: 0.6019 | F1 MICRO: 0.6312
# EPOCH 5 | LOSS: 3.8513896465301514 | ACCURACY: 0.6373 | F1 MACRO: 0.6364 | F1 MICRO: 0.6424
# EPOCH 6 | LOSS: 3.5741770267486572 | ACCURACY: 0.7138 | F1 MACRO: 0.7457 | F1 MICRO: 0.7584
# EPOCH 7 | LOSS: 3.4540629386901855 | ACCURACY: 0.7183 | F1 MACRO: 0.7416 | F1 MICRO: 0.7535
# EPOCH 8 | LOSS: 3.4373886585235596 | ACCURACY: 0.7125 | F1 MACRO: 0.7248 | F1 MICRO: 0.7404
# EPOCH 9 | LOSS: 3.400773525238037 | ACCURACY: 0.71 | F1 MACRO: 0.7618 | F1 MICRO: 0.7675
# EPOCH 10 | LOSS: 3.3889894485473633 | ACCURACY: 0.7183 | F1 MACRO: 0.7375 | F1 MICRO: 0.7479
# Iteration 2394: ACCURACY 0.71 | F1 MACRO 0.7618 | F1 MICRO 0.7675
#                       precision    recall  f1-score   support
#
#           pornografi       0.93      0.87      0.90       362
#                 sara       0.65      0.61      0.63       237
#          radikalisme       0.76      0.83      0.79       235
# pencemaran_nama_baik       0.74      0.71      0.72       492
#
#            micro avg       0.78      0.76      0.77      1326
#            macro avg       0.77      0.76      0.76      1326
#         weighted avg       0.78      0.76      0.77      1326
#          samples avg       0.44      0.43      0.42      1326
#
# Nearest checkpoint: 3886
# Threshold: 51734.734375
# Samples above threshold: 383
# Acquired samples: 383
# Sampling duration: 22.36514973640442 seconds
# New train size: 2777
# EPOCH 1 | LOSS: 4.909603118896484 | ACCURACY: 0.4772 | F1 MACRO: 0.1101 | F1 MICRO: 0.1428
# EPOCH 2 | LOSS: 4.311307907104492 | ACCURACY: 0.6939 | F1 MACRO: 0.7312 | F1 MICRO: 0.7322
# EPOCH 3 | LOSS: 4.124526500701904 | ACCURACY: 0.6733 | F1 MACRO: 0.6817 | F1 MICRO: 0.7166
# EPOCH 4 | LOSS: 3.8421616554260254 | ACCURACY: 0.6675 | F1 MACRO: 0.7278 | F1 MICRO: 0.729
# EPOCH 5 | LOSS: 3.7811942100524902 | ACCURACY: 0.69 | F1 MACRO: 0.7151 | F1 MICRO: 0.7194
# in second
# EPOCH 6 | LOSS: 3.44645357131958 | ACCURACY: 0.7158 | F1 MACRO: 0.7489 | F1 MICRO: 0.7537
# in second
# EPOCH 7 | LOSS: 3.410144567489624 | ACCURACY: 0.7138 | F1 MACRO: 0.7494 | F1 MICRO: 0.7549
# in second
# EPOCH 8 | LOSS: 3.3969662189483643 | ACCURACY: 0.7113 | F1 MACRO: 0.7461 | F1 MICRO: 0.7519
# in second
# EPOCH 9 | LOSS: 3.3844597339630127 | ACCURACY: 0.7106 | F1 MACRO: 0.7485 | F1 MICRO: 0.7524
# in second
# EPOCH 10 | LOSS: 3.374481439590454 | ACCURACY: 0.719 | F1 MACRO: 0.7554 | F1 MICRO: 0.7591
# Iteration 2777: ACCURACY 0.6939 | F1 MACRO 0.7312 | F1 MICRO 0.7322
#                       precision    recall  f1-score   support
#
#           pornografi       0.96      0.77      0.85       362
#                 sara       0.69      0.53      0.60       237
#          radikalisme       0.76      0.85      0.80       235
# pencemaran_nama_baik       0.71      0.63      0.67       492
#
#            micro avg       0.78      0.69      0.73      1326
#            macro avg       0.78      0.69      0.73      1326
#         weighted avg       0.79      0.69      0.73      1326
#          samples avg       0.38      0.38      0.37      1326
#
# Nearest checkpoint: 3886
# Threshold: 50874.59765625
# Samples above threshold: 345
# Acquired samples: 345
# Sampling duration: 21.7093985080719 seconds
# New train size: 3122
# EPOCH 1 | LOSS: 4.8775482177734375 | ACCURACY: 0.5807 | F1 MACRO: 0.6916 | F1 MICRO: 0.6878
# EPOCH 2 | LOSS: 4.4007182121276855 | ACCURACY: 0.6232 | F1 MACRO: 0.6339 | F1 MICRO: 0.6632
# EPOCH 3 | LOSS: 4.190201759338379 | ACCURACY: 0.6514 | F1 MACRO: 0.7097 | F1 MICRO: 0.7164
# EPOCH 4 | LOSS: 3.9241693019866943 | ACCURACY: 0.674 | F1 MACRO: 0.6867 | F1 MICRO: 0.6904
# EPOCH 5 | LOSS: 3.813748359680176 | ACCURACY: 0.6772 | F1 MACRO: 0.6626 | F1 MICRO: 0.6738
# EPOCH 6 | LOSS: 3.546704053878784 | ACCURACY: 0.719 | F1 MACRO: 0.7717 | F1 MICRO: 0.7714
# EPOCH 7 | LOSS: 3.4219765663146973 | ACCURACY: 0.7196 | F1 MACRO: 0.7587 | F1 MICRO: 0.7592
# EPOCH 8 | LOSS: 3.388490915298462 | ACCURACY: 0.7177 | F1 MACRO: 0.7601 | F1 MICRO: 0.7613
# EPOCH 9 | LOSS: 3.3549253940582275 | ACCURACY: 0.7183 | F1 MACRO: 0.7694 | F1 MICRO: 0.7749
# EPOCH 10 | LOSS: 3.3496625423431396 | ACCURACY: 0.7138 | F1 MACRO: 0.7535 | F1 MICRO: 0.7576
# Iteration 3122: ACCURACY 0.7183 | F1 MACRO 0.7694 | F1 MICRO 0.7749
#                       precision    recall  f1-score   support
#
#           pornografi       0.96      0.86      0.91       362
#                 sara       0.74      0.59      0.65       237
#          radikalisme       0.73      0.84      0.78       235
# pencemaran_nama_baik       0.70      0.76      0.73       492
#
#            micro avg       0.78      0.77      0.77      1326
#            macro avg       0.78      0.76      0.77      1326
#         weighted avg       0.78      0.77      0.78      1326
#          samples avg       0.45      0.44      0.44      1326
#
# Nearest checkpoint: 3886
# Threshold: 49718.94140625
# Samples above threshold: 310
# Acquired samples: 310
# Sampling duration: 21.76426410675049 seconds
# New train size: 3432
# EPOCH 1 | LOSS: 4.91964864730835 | ACCURACY: 0.5685 | F1 MACRO: 0.5064 | F1 MICRO: 0.5075
# EPOCH 2 | LOSS: 4.362851619720459 | ACCURACY: 0.6733 | F1 MACRO: 0.689 | F1 MICRO: 0.7084
# EPOCH 3 | LOSS: 4.176137924194336 | ACCURACY: 0.6714 | F1 MACRO: 0.7175 | F1 MICRO: 0.731
# EPOCH 4 | LOSS: 3.931971788406372 | ACCURACY: 0.6579 | F1 MACRO: 0.5703 | F1 MICRO: 0.6288
# EPOCH 5 | LOSS: 3.807292938232422 | ACCURACY: 0.6669 | F1 MACRO: 0.6946 | F1 MICRO: 0.7008
# EPOCH 6 | LOSS: 3.5234668254852295 | ACCURACY: 0.7228 | F1 MACRO: 0.7584 | F1 MICRO: 0.7645
# EPOCH 7 | LOSS: 3.423931837081909 | ACCURACY: 0.717 | F1 MACRO: 0.7654 | F1 MICRO: 0.7701
# EPOCH 8 | LOSS: 3.3771743774414062 | ACCURACY: 0.7273 | F1 MACRO: 0.7747 | F1 MICRO: 0.7811
# EPOCH 9 | LOSS: 3.372040271759033 | ACCURACY: 0.7138 | F1 MACRO: 0.742 | F1 MICRO: 0.7564
# EPOCH 10 | LOSS: 3.388678789138794 | ACCURACY: 0.7042 | F1 MACRO: 0.7207 | F1 MICRO: 0.7366
# Iteration 3432: ACCURACY 0.7273 | F1 MACRO 0.7747 | F1 MICRO 0.7811
#                       precision    recall  f1-score   support
#
#           pornografi       0.95      0.91      0.93       362
#                 sara       0.66      0.65      0.65       237
#          radikalisme       0.75      0.81      0.78       235
# pencemaran_nama_baik       0.73      0.75      0.74       492
#
#            micro avg       0.78      0.78      0.78      1326
#            macro avg       0.77      0.78      0.77      1326
#         weighted avg       0.78      0.78      0.78      1326
#          samples avg       0.45      0.44      0.44      1326
#
# Nearest checkpoint: 3886
# Threshold: 50333.96484375
# Samples above threshold: 279
# Acquired samples: 279
# Sampling duration: 22.03178644180298 seconds
# New train size: 3711
# EPOCH 1 | LOSS: 4.90474796295166 | ACCURACY: 0.5447 | F1 MACRO: 0.6261 | F1 MICRO: 0.6451
# EPOCH 2 | LOSS: 4.450477123260498 | ACCURACY: 0.6122 | F1 MACRO: 0.7365 | F1 MICRO: 0.7247
# EPOCH 3 | LOSS: 4.164330005645752 | ACCURACY: 0.6913 | F1 MACRO: 0.7081 | F1 MICRO: 0.72
# EPOCH 4 | LOSS: 3.9753026962280273 | ACCURACY: 0.683 | F1 MACRO: 0.6884 | F1 MICRO: 0.6994
# EPOCH 5 | LOSS: 3.7810215950012207 | ACCURACY: 0.7068 | F1 MACRO: 0.7124 | F1 MICRO: 0.7198
# in second
# EPOCH 6 | LOSS: 3.4681825637817383 | ACCURACY: 0.7267 | F1 MACRO: 0.7538 | F1 MICRO: 0.759
# in second
# EPOCH 7 | LOSS: 3.4348855018615723 | ACCURACY: 0.7222 | F1 MACRO: 0.7456 | F1 MICRO: 0.7526
# in second
# EPOCH 8 | LOSS: 3.423238515853882 | ACCURACY: 0.7222 | F1 MACRO: 0.7493 | F1 MICRO: 0.7535
# in second
# Iteration 3711: ACCURACY 0.6122 | F1 MACRO 0.7365 | F1 MICRO 0.7247
#                       precision    recall  f1-score   support
#
#           pornografi       0.94      0.83      0.89       362
#                 sara       0.48      0.88      0.62       237
#          radikalisme       0.68      0.89      0.77       235
# pencemaran_nama_baik       0.57      0.81      0.67       492
#
#            micro avg       0.64      0.84      0.72      1326
#            macro avg       0.67      0.85      0.74      1326
#         weighted avg       0.68      0.84      0.74      1326
#          samples avg       0.40      0.47      0.42      1326
#
# Nearest checkpoint: 3886
# Threshold: 49919.09375
# Samples above threshold: 251
# Acquired samples: 175
# Sampling duration: 21.795666694641113 seconds
# New train size: 3886
# EPOCH 1 | LOSS: 4.87215518951416 | ACCURACY: 0.6103 | F1 MACRO: 0.6819 | F1 MICRO: 0.6802
# EPOCH 2 | LOSS: 4.414132118225098 | ACCURACY: 0.627 | F1 MACRO: 0.6119 | F1 MICRO: 0.6587
# EPOCH 3 | LOSS: 4.186711311340332 | ACCURACY: 0.6887 | F1 MACRO: 0.7208 | F1 MICRO: 0.7362
# EPOCH 4 | LOSS: 4.004803657531738 | ACCURACY: 0.6412 | F1 MACRO: 0.5818 | F1 MICRO: 0.618
# EPOCH 5 | LOSS: 3.8228871822357178 | ACCURACY: 0.7196 | F1 MACRO: 0.7411 | F1 MICRO: 0.7517
# EPOCH 6 | LOSS: 3.5735321044921875 | ACCURACY: 0.7338 | F1 MACRO: 0.7826 | F1 MICRO: 0.7826
# EPOCH 7 | LOSS: 3.4501686096191406 | ACCURACY: 0.7145 | F1 MACRO: 0.7828 | F1 MICRO: 0.7824
# EPOCH 8 | LOSS: 3.4149715900421143 | ACCURACY: 0.7293 | F1 MACRO: 0.7634 | F1 MICRO: 0.7682
# EPOCH 9 | LOSS: 3.3850090503692627 | ACCURACY: 0.7312 | F1 MACRO: 0.779 | F1 MICRO: 0.7758
# in second
# EPOCH 10 | LOSS: 3.2905454635620117 | ACCURACY: 0.735 | F1 MACRO: 0.7834 | F1 MICRO: 0.7827
# Iteration 3886: ACCURACY 0.7338 | F1 MACRO 0.7826 | F1 MICRO 0.7826
#                       precision    recall  f1-score   support
#
#           pornografi       0.96      0.89      0.92       362
#                 sara       0.70      0.67      0.69       237
#          radikalisme       0.79      0.83      0.80       235
# pencemaran_nama_baik       0.73      0.70      0.72       492
#
#            micro avg       0.80      0.77      0.78      1326
#            macro avg       0.80      0.77      0.78      1326
#         weighted avg       0.80      0.77      0.78      1326
#          samples avg       0.44      0.43      0.43      1326
#
# Nearest checkpoint: 4663
# Threshold: 49825.99609375
# Samples above threshold: 234
# Acquired samples: 234
# Sampling duration: 21.927459239959717 seconds
# New train size: 4120
# EPOCH 1 | LOSS: 4.903745174407959 | ACCURACY: 0.5177 | F1 MACRO: 0.4374 | F1 MICRO: 0.4361
# EPOCH 2 | LOSS: 4.381270885467529 | ACCURACY: 0.681 | F1 MACRO: 0.6985 | F1 MICRO: 0.7083
# EPOCH 3 | LOSS: 4.189846038818359 | ACCURACY: 0.6714 | F1 MACRO: 0.7295 | F1 MICRO: 0.729
# EPOCH 4 | LOSS: 4.025164604187012 | ACCURACY: 0.6688 | F1 MACRO: 0.6954 | F1 MICRO: 0.7085
# EPOCH 5 | LOSS: 3.861392021179199 | ACCURACY: 0.7042 | F1 MACRO: 0.7513 | F1 MICRO: 0.7576
# EPOCH 6 | LOSS: 3.5476183891296387 | ACCURACY: 0.7132 | F1 MACRO: 0.7589 | F1 MICRO: 0.7646
# EPOCH 7 | LOSS: 3.468733549118042 | ACCURACY: 0.7325 | F1 MACRO: 0.7693 | F1 MICRO: 0.7728
# EPOCH 8 | LOSS: 3.4213993549346924 | ACCURACY: 0.7267 | F1 MACRO: 0.7588 | F1 MICRO: 0.7685
# EPOCH 9 | LOSS: 3.3973913192749023 | ACCURACY: 0.7228 | F1 MACRO: 0.7408 | F1 MICRO: 0.7491
# EPOCH 10 | LOSS: 3.3740527629852295 | ACCURACY: 0.7248 | F1 MACRO: 0.7632 | F1 MICRO: 0.7686
# Iteration 4120: ACCURACY 0.7325 | F1 MACRO 0.7693 | F1 MICRO 0.7728
#                       precision    recall  f1-score   support
#
#           pornografi       0.95      0.89      0.92       362
#                 sara       0.69      0.61      0.64       237
#          radikalisme       0.81      0.82      0.81       235
# pencemaran_nama_baik       0.78      0.64      0.70       492
#
#            micro avg       0.82      0.73      0.77      1326
#            macro avg       0.81      0.74      0.77      1326
#         weighted avg       0.81      0.73      0.77      1326
#          samples avg       0.42      0.41      0.41      1326
#
# Nearest checkpoint: 4663
# Threshold: 48938.98828125
# Samples above threshold: 210
# Acquired samples: 210
# Sampling duration: 21.679595708847046 seconds
# New train size: 4330
# EPOCH 1 | LOSS: 4.968737602233887 | ACCURACY: 0.6212 | F1 MACRO: 0.6573 | F1 MICRO: 0.6527
# EPOCH 2 | LOSS: 4.418590068817139 | ACCURACY: 0.6341 | F1 MACRO: 0.382 | F1 MICRO: 0.4945
# EPOCH 3 | LOSS: 4.230060577392578 | ACCURACY: 0.5865 | F1 MACRO: 0.2567 | F1 MICRO: 0.358
# EPOCH 4 | LOSS: 4.041632652282715 | ACCURACY: 0.692 | F1 MACRO: 0.7581 | F1 MICRO: 0.7667
# EPOCH 5 | LOSS: 3.865152359008789 | ACCURACY: 0.6598 | F1 MACRO: 0.5585 | F1 MICRO: 0.6548
# EPOCH 6 | LOSS: 3.5920608043670654 | ACCURACY: 0.7042 | F1 MACRO: 0.7215 | F1 MICRO: 0.725
# EPOCH 7 | LOSS: 3.476278066635132 | ACCURACY: 0.7196 | F1 MACRO: 0.7649 | F1 MICRO: 0.774
# EPOCH 8 | LOSS: 3.4298205375671387 | ACCURACY: 0.7151 | F1 MACRO: 0.7696 | F1 MICRO: 0.7805
# EPOCH 9 | LOSS: 3.416926383972168 | ACCURACY: 0.7376 | F1 MACRO: 0.7675 | F1 MICRO: 0.7785
# EPOCH 10 | LOSS: 3.42384934425354 | ACCURACY: 0.735 | F1 MACRO: 0.7533 | F1 MICRO: 0.7643
# Iteration 4330: ACCURACY 0.7151 | F1 MACRO 0.7696 | F1 MICRO 0.7805
#                       precision    recall  f1-score   support
#
#           pornografi       0.86      0.94      0.90       362
#                 sara       0.72      0.59      0.65       237
#          radikalisme       0.77      0.79      0.78       235
# pencemaran_nama_baik       0.67      0.84      0.75       492
#
#            micro avg       0.75      0.82      0.78      1326
#            macro avg       0.76      0.79      0.77      1326
#         weighted avg       0.75      0.82      0.78      1326
#          samples avg       0.46      0.47      0.45      1326
#
# Nearest checkpoint: 4663
# Threshold: 48242.796875
# Samples above threshold: 189
# Acquired samples: 200
# Sampling duration: 21.948987245559692 seconds
# New train size: 4530
# EPOCH 1 | LOSS: 4.822908401489258 | ACCURACY: 0.5897 | F1 MACRO: 0.5648 | F1 MICRO: 0.5593
# EPOCH 2 | LOSS: 4.4377970695495605 | ACCURACY: 0.7061 | F1 MACRO: 0.7608 | F1 MICRO: 0.7662
# EPOCH 3 | LOSS: 4.20930814743042 | ACCURACY: 0.6489 | F1 MACRO: 0.5171 | F1 MICRO: 0.5972
# EPOCH 4 | LOSS: 3.9974846839904785 | ACCURACY: 0.6817 | F1 MACRO: 0.685 | F1 MICRO: 0.7238
# EPOCH 5 | LOSS: 3.812655448913574 | ACCURACY: 0.7042 | F1 MACRO: 0.727 | F1 MICRO: 0.7418
# in second
# EPOCH 6 | LOSS: 3.5195720195770264 | ACCURACY: 0.7138 | F1 MACRO: 0.7525 | F1 MICRO: 0.7589
# in second
# EPOCH 7 | LOSS: 3.494483470916748 | ACCURACY: 0.7113 | F1 MACRO: 0.7474 | F1 MICRO: 0.755
# in second
# EPOCH 8 | LOSS: 3.489713668823242 | ACCURACY: 0.7132 | F1 MACRO: 0.7539 | F1 MICRO: 0.7624
# in second
# EPOCH 9 | LOSS: 3.476862907409668 | ACCURACY: 0.7119 | F1 MACRO: 0.7546 | F1 MICRO: 0.7588
# in second
# EPOCH 10 | LOSS: 3.47162127494812 | ACCURACY: 0.7158 | F1 MACRO: 0.748 | F1 MICRO: 0.7579
# Iteration 4530: ACCURACY 0.7061 | F1 MACRO 0.7608 | F1 MICRO 0.7662
#                       precision    recall  f1-score   support
#
#           pornografi       0.93      0.86      0.89       362
#                 sara       0.63      0.65      0.64       237
#          radikalisme       0.75      0.80      0.77       235
# pencemaran_nama_baik       0.68      0.80      0.74       492
#
#            micro avg       0.74      0.79      0.77      1326
#            macro avg       0.75      0.78      0.76      1326
#         weighted avg       0.75      0.79      0.77      1326
#          samples avg       0.42      0.44      0.42      1326
#
# Nearest checkpoint: 4663
# Threshold: 47654.7109375
# Samples above threshold: 169
# Acquired samples: 133
# Sampling duration: 21.75340247154236 seconds
# New train size: 4663
# EPOCH 1 | LOSS: 4.995237827301025 | ACCURACY: 0.5466 | F1 MACRO: 0.4976 | F1 MICRO: 0.487
# EPOCH 2 | LOSS: 4.409491062164307 | ACCURACY: 0.6457 | F1 MACRO: 0.4774 | F1 MICRO: 0.5928
# EPOCH 3 | LOSS: 4.228713512420654 | ACCURACY: 0.6309 | F1 MACRO: 0.5885 | F1 MICRO: 0.617
# EPOCH 4 | LOSS: 4.024174690246582 | ACCURACY: 0.701 | F1 MACRO: 0.7374 | F1 MICRO: 0.7474
# EPOCH 5 | LOSS: 3.8742387294769287 | ACCURACY: 0.7254 | F1 MACRO: 0.7377 | F1 MICRO: 0.7578
# EPOCH 6 | LOSS: 3.624758005142212 | ACCURACY: 0.7267 | F1 MACRO: 0.7318 | F1 MICRO: 0.7519
# EPOCH 7 | LOSS: 3.5207080841064453 | ACCURACY: 0.7273 | F1 MACRO: 0.7779 | F1 MICRO: 0.7834
# EPOCH 8 | LOSS: 3.4604082107543945 | ACCURACY: 0.735 | F1 MACRO: 0.7836 | F1 MICRO: 0.7898
# EPOCH 9 | LOSS: 3.4493956565856934 | ACCURACY: 0.7151 | F1 MACRO: 0.7577 | F1 MICRO: 0.7672
# EPOCH 10 | LOSS: 3.433145761489868 | ACCURACY: 0.7196 | F1 MACRO: 0.747 | F1 MICRO: 0.7605
# Iteration 4663: ACCURACY 0.735 | F1 MACRO 0.7836 | F1 MICRO 0.7898
#                       precision    recall  f1-score   support
#
#           pornografi       0.96      0.91      0.93       362
#                 sara       0.65      0.64      0.65       237
#          radikalisme       0.79      0.83      0.80       235
# pencemaran_nama_baik       0.71      0.80      0.75       492
#
#            micro avg       0.78      0.80      0.79      1326
#            macro avg       0.78      0.79      0.78      1326
#         weighted avg       0.78      0.80      0.79      1326
#          samples avg       0.47      0.46      0.46      1326
#
# Nearest checkpoint: 5441
# Threshold: 47560.0234375
# Samples above threshold: 156
# Acquired samples: 200
# Sampling duration: 21.751825094223022 seconds
# New train size: 4863
# EPOCH 1 | LOSS: 4.858830451965332 | ACCURACY: 0.6386 | F1 MACRO: 0.4861 | F1 MICRO: 0.5716
# EPOCH 2 | LOSS: 4.392404079437256 | ACCURACY: 0.6907 | F1 MACRO: 0.7493 | F1 MICRO: 0.7496
# EPOCH 3 | LOSS: 4.212031364440918 | ACCURACY: 0.7087 | F1 MACRO: 0.7569 | F1 MICRO: 0.754
# EPOCH 4 | LOSS: 4.034444808959961 | ACCURACY: 0.6945 | F1 MACRO: 0.7567 | F1 MICRO: 0.7562
# EPOCH 5 | LOSS: 3.8521816730499268 | ACCURACY: 0.6926 | F1 MACRO: 0.7477 | F1 MICRO: 0.7529
# EPOCH 6 | LOSS: 3.6175200939178467 | ACCURACY: 0.7325 | F1 MACRO: 0.7796 | F1 MICRO: 0.7835
# EPOCH 7 | LOSS: 3.5008602142333984 | ACCURACY: 0.7344 | F1 MACRO: 0.7928 | F1 MICRO: 0.7927
# EPOCH 8 | LOSS: 3.467888355255127 | ACCURACY: 0.7286 | F1 MACRO: 0.7812 | F1 MICRO: 0.7807
# EPOCH 9 | LOSS: 3.437204599380493 | ACCURACY: 0.7196 | F1 MACRO: 0.7767 | F1 MICRO: 0.78
# EPOCH 10 | LOSS: 3.4365322589874268 | ACCURACY: 0.7267 | F1 MACRO: 0.7709 | F1 MICRO: 0.7798
# Iteration 4863: ACCURACY 0.7344 | F1 MACRO 0.7928 | F1 MICRO 0.7927
#                       precision    recall  f1-score   support
#
#           pornografi       0.93      0.91      0.92       362
#                 sara       0.65      0.76      0.70       237
#          radikalisme       0.78      0.84      0.81       235
# pencemaran_nama_baik       0.75      0.72      0.74       492
#
#            micro avg       0.79      0.80      0.79      1326
#            macro avg       0.78      0.81      0.79      1326
#         weighted avg       0.79      0.80      0.79      1326
#          samples avg       0.46      0.46      0.45      1326
#
# Nearest checkpoint: 5441
# Threshold: 46929.140625
# Samples above threshold: 136
# Acquired samples: 200
# Sampling duration: 21.93437957763672 seconds
# New train size: 5063
# EPOCH 1 | LOSS: 4.838995456695557 | ACCURACY: 0.6412 | F1 MACRO: 0.4812 | F1 MICRO: 0.5708
# EPOCH 2 | LOSS: 4.377365589141846 | ACCURACY: 0.5942 | F1 MACRO: 0.474 | F1 MICRO: 0.5553
# EPOCH 3 | LOSS: 4.178442001342773 | ACCURACY: 0.6932 | F1 MACRO: 0.7351 | F1 MICRO: 0.7495
# EPOCH 4 | LOSS: 4.006739616394043 | ACCURACY: 0.7376 | F1 MACRO: 0.7698 | F1 MICRO: 0.7804
# EPOCH 5 | LOSS: 3.8568878173828125 | ACCURACY: 0.719 | F1 MACRO: 0.7403 | F1 MICRO: 0.7468
# EPOCH 6 | LOSS: 3.6109893321990967 | ACCURACY: 0.7357 | F1 MACRO: 0.7691 | F1 MICRO: 0.7798
# EPOCH 7 | LOSS: 3.521221160888672 | ACCURACY: 0.7248 | F1 MACRO: 0.7771 | F1 MICRO: 0.7788
# in second
# EPOCH 8 | LOSS: 3.413668155670166 | ACCURACY: 0.7363 | F1 MACRO: 0.7738 | F1 MICRO: 0.779
# in second
# EPOCH 9 | LOSS: 3.39377498626709 | ACCURACY: 0.7357 | F1 MACRO: 0.772 | F1 MICRO: 0.7765
# in second
# EPOCH 10 | LOSS: 3.388835906982422 | ACCURACY: 0.7395 | F1 MACRO: 0.7722 | F1 MICRO: 0.7787
# Iteration 5063: ACCURACY 0.7376 | F1 MACRO 0.7698 | F1 MICRO 0.7804
#                       precision    recall  f1-score   support
#
#           pornografi       0.89      0.92      0.90       362
#                 sara       0.69      0.59      0.64       237
#          radikalisme       0.73      0.86      0.79       235
# pencemaran_nama_baik       0.75      0.74      0.74       492
#
#            micro avg       0.78      0.79      0.78      1326
#            macro avg       0.77      0.78      0.77      1326
#         weighted avg       0.77      0.79      0.78      1326
#          samples avg       0.45      0.45      0.44      1326
#
# Nearest checkpoint: 5441
# Threshold: 35323.13046875375
# Samples above threshold: 116
# Acquired samples: 200
# Sampling duration: 21.68799662590027 seconds
# New train size: 5263
# EPOCH 1 | LOSS: 4.8322014808654785 | ACCURACY: 0.5711 | F1 MACRO: 0.4742 | F1 MICRO: 0.5116
# EPOCH 2 | LOSS: 4.391845703125 | ACCURACY: 0.6502 | F1 MACRO: 0.5882 | F1 MICRO: 0.6276
# EPOCH 3 | LOSS: 4.204819679260254 | ACCURACY: 0.6424 | F1 MACRO: 0.711 | F1 MICRO: 0.7032
# EPOCH 4 | LOSS: 4.030056476593018 | ACCURACY: 0.7119 | F1 MACRO: 0.7488 | F1 MICRO: 0.7599
# EPOCH 5 | LOSS: 3.8525490760803223 | ACCURACY: 0.7035 | F1 MACRO: 0.7769 | F1 MICRO: 0.7787
# EPOCH 6 | LOSS: 3.6414859294891357 | ACCURACY: 0.7402 | F1 MACRO: 0.7907 | F1 MICRO: 0.7944
# EPOCH 7 | LOSS: 3.525003671646118 | ACCURACY: 0.7383 | F1 MACRO: 0.7745 | F1 MICRO: 0.7834
# EPOCH 8 | LOSS: 3.4832515716552734 | ACCURACY: 0.7421 | F1 MACRO: 0.7828 | F1 MICRO: 0.7925
# EPOCH 9 | LOSS: 3.461338996887207 | ACCURACY: 0.7203 | F1 MACRO: 0.7538 | F1 MICRO: 0.7631
# in second
# EPOCH 10 | LOSS: 3.387044906616211 | ACCURACY: 0.7254 | F1 MACRO: 0.7573 | F1 MICRO: 0.7642
# Iteration 5263: ACCURACY 0.7402 | F1 MACRO 0.7907 | F1 MICRO 0.7944
#                       precision    recall  f1-score   support
#
#           pornografi       0.92      0.91      0.92       362
#                 sara       0.62      0.78      0.69       237
#          radikalisme       0.75      0.85      0.79       235
# pencemaran_nama_baik       0.73      0.79      0.76       492
#
#            micro avg       0.76      0.83      0.79      1326
#            macro avg       0.75      0.83      0.79      1326
#         weighted avg       0.77      0.83      0.80      1326
#          samples avg       0.46      0.47      0.46      1326
#
# Nearest checkpoint: 5441
# Threshold: 19432.869140625
# Samples above threshold: 96
# Acquired samples: 178
# Sampling duration: 22.089693069458008 seconds
# New train size: 5441
# EPOCH 1 | LOSS: 4.782746315002441 | ACCURACY: 0.5936 | F1 MACRO: 0.5607 | F1 MICRO: 0.5725
# EPOCH 2 | LOSS: 4.366325855255127 | ACCURACY: 0.7113 | F1 MACRO: 0.7464 | F1 MICRO: 0.7635
# EPOCH 3 | LOSS: 4.17476224899292 | ACCURACY: 0.681 | F1 MACRO: 0.6197 | F1 MICRO: 0.697
# EPOCH 4 | LOSS: 4.028907299041748 | ACCURACY: 0.672 | F1 MACRO: 0.6772 | F1 MICRO: 0.6792
# EPOCH 5 | LOSS: 3.8582491874694824 | ACCURACY: 0.7235 | F1 MACRO: 0.7538 | F1 MICRO: 0.7642
# EPOCH 6 | LOSS: 3.6175873279571533 | ACCURACY: 0.7305 | F1 MACRO: 0.771 | F1 MICRO: 0.7791
# EPOCH 7 | LOSS: 3.5068886280059814 | ACCURACY: 0.7421 | F1 MACRO: 0.7878 | F1 MICRO: 0.7912
# EPOCH 8 | LOSS: 3.47666335105896 | ACCURACY: 0.7428 | F1 MACRO: 0.7719 | F1 MICRO: 0.7799
# EPOCH 9 | LOSS: 3.4415459632873535 | ACCURACY: 0.6894 | F1 MACRO: 0.7686 | F1 MICRO: 0.7706
# EPOCH 10 | LOSS: 3.4439733028411865 | ACCURACY: 0.7428 | F1 MACRO: 0.7707 | F1 MICRO: 0.7766
# Iteration 5441: ACCURACY 0.7421 | F1 MACRO 0.7878 | F1 MICRO 0.7912
#                       precision    recall  f1-score   support
#
#           pornografi       0.95      0.89      0.92       362
#                 sara       0.66      0.75      0.70       237
#          radikalisme       0.71      0.86      0.77       235
# pencemaran_nama_baik       0.74      0.78      0.76       492
#
#            micro avg       0.77      0.82      0.79      1326
#            macro avg       0.76      0.82      0.79      1326
#         weighted avg       0.78      0.82      0.79      1326
#          samples avg       0.46      0.46      0.45      1326
#
# Nearest checkpoint: 6218
# Threshold: 19516.767578125
# Samples above threshold: 78
# Acquired samples: 200
# Sampling duration: 21.63044834136963 seconds
# New train size: 5641
# EPOCH 1 | LOSS: 4.750051021575928 | ACCURACY: 0.6746 | F1 MACRO: 0.7088 | F1 MICRO: 0.7164
# EPOCH 2 | LOSS: 4.370112419128418 | ACCURACY: 0.69 | F1 MACRO: 0.7061 | F1 MICRO: 0.7236
# EPOCH 3 | LOSS: 4.183096408843994 | ACCURACY: 0.6701 | F1 MACRO: 0.5939 | F1 MICRO: 0.6969
# EPOCH 4 | LOSS: 4.02780818939209 | ACCURACY: 0.7016 | F1 MACRO: 0.763 | F1 MICRO: 0.7706
# EPOCH 5 | LOSS: 3.8578498363494873 | ACCURACY: 0.7273 | F1 MACRO: 0.7602 | F1 MICRO: 0.7671
# EPOCH 6 | LOSS: 3.623978853225708 | ACCURACY: 0.7376 | F1 MACRO: 0.7879 | F1 MICRO: 0.7939
# EPOCH 7 | LOSS: 3.5154623985290527 | ACCURACY: 0.7363 | F1 MACRO: 0.787 | F1 MICRO: 0.791
# EPOCH 8 | LOSS: 3.4767959117889404 | ACCURACY: 0.7357 | F1 MACRO: 0.789 | F1 MICRO: 0.7908
# EPOCH 9 | LOSS: 3.463798761367798 | ACCURACY: 0.7434 | F1 MACRO: 0.7628 | F1 MICRO: 0.7745
# in second
# EPOCH 10 | LOSS: 3.3713293075561523 | ACCURACY: 0.7479 | F1 MACRO: 0.775 | F1 MICRO: 0.7841
# Iteration 5641: ACCURACY 0.7376 | F1 MACRO 0.7879 | F1 MICRO 0.7939
#                       precision    recall  f1-score   support
#
#           pornografi       0.91      0.92      0.92       362
#                 sara       0.71      0.68      0.69       237
#          radikalisme       0.79      0.77      0.78       235
# pencemaran_nama_baik       0.72      0.80      0.76       492
#
#            micro avg       0.78      0.80      0.79      1326
#            macro avg       0.79      0.79      0.79      1326
#         weighted avg       0.79      0.80      0.79      1326
#          samples avg       0.46      0.46      0.45      1326
#
# Nearest checkpoint: 6218
# Threshold: 19386.076171875
# Samples above threshold: 58
# Acquired samples: 200
# Sampling duration: 21.6009464263916 seconds
# New train size: 5841
# EPOCH 1 | LOSS: 4.692702770233154 | ACCURACY: 0.6656 | F1 MACRO: 0.6969 | F1 MICRO: 0.7087
# EPOCH 2 | LOSS: 4.319014549255371 | ACCURACY: 0.7029 | F1 MACRO: 0.7716 | F1 MICRO: 0.7688
# EPOCH 3 | LOSS: 4.151654243469238 | ACCURACY: 0.6862 | F1 MACRO: 0.6598 | F1 MICRO: 0.7094
# EPOCH 4 | LOSS: 3.9837899208068848 | ACCURACY: 0.6727 | F1 MACRO: 0.7665 | F1 MICRO: 0.7598
# EPOCH 5 | LOSS: 3.8478097915649414 | ACCURACY: 0.7203 | F1 MACRO: 0.7461 | F1 MICRO: 0.7534
# in second
# EPOCH 6 | LOSS: 3.508112668991089 | ACCURACY: 0.7338 | F1 MACRO: 0.7725 | F1 MICRO: 0.7772
# in second
# EPOCH 7 | LOSS: 3.4927661418914795 | ACCURACY: 0.7357 | F1 MACRO: 0.7766 | F1 MICRO: 0.7827
# in second
# EPOCH 8 | LOSS: 3.4850265979766846 | ACCURACY: 0.7376 | F1 MACRO: 0.7725 | F1 MICRO: 0.7808
# in second
# EPOCH 9 | LOSS: 3.4790518283843994 | ACCURACY: 0.7299 | F1 MACRO: 0.7808 | F1 MICRO: 0.7857
# in second
# EPOCH 10 | LOSS: 3.474041223526001 | ACCURACY: 0.7383 | F1 MACRO: 0.7738 | F1 MICRO: 0.782
# Iteration 5841: ACCURACY 0.7029 | F1 MACRO 0.7716 | F1 MICRO 0.7688
#                       precision    recall  f1-score   support
#
#           pornografi       0.98      0.77      0.86       362
#                 sara       0.59      0.76      0.67       237
#          radikalisme       0.77      0.86      0.81       235
# pencemaran_nama_baik       0.66      0.86      0.74       492
#
#            micro avg       0.73      0.82      0.77      1326
#            macro avg       0.75      0.81      0.77      1326
#         weighted avg       0.76      0.82      0.78      1326
#          samples avg       0.45      0.45      0.44      1326
#
# Nearest checkpoint: 6218
# Threshold: 19040.048828125
# Samples above threshold: 38
# Acquired samples: 200
# Sampling duration: 21.91871452331543 seconds
# New train size: 6041
# EPOCH 1 | LOSS: 4.72625732421875 | ACCURACY: 0.6707 | F1 MACRO: 0.7365 | F1 MICRO: 0.7493
# EPOCH 2 | LOSS: 4.29110050201416 | ACCURACY: 0.6296 | F1 MACRO: 0.5736 | F1 MICRO: 0.6916
# EPOCH 3 | LOSS: 4.130983829498291 | ACCURACY: 0.6605 | F1 MACRO: 0.5466 | F1 MICRO: 0.6467
# EPOCH 4 | LOSS: 3.9985408782958984 | ACCURACY: 0.7074 | F1 MACRO: 0.7163 | F1 MICRO: 0.7299
# in second
# EPOCH 5 | LOSS: 3.5756380558013916 | ACCURACY: 0.7248 | F1 MACRO: 0.7508 | F1 MICRO: 0.7645
# in second
# EPOCH 6 | LOSS: 3.548253297805786 | ACCURACY: 0.7293 | F1 MACRO: 0.7588 | F1 MICRO: 0.7665
# in second
# EPOCH 7 | LOSS: 3.538954496383667 | ACCURACY: 0.728 | F1 MACRO: 0.7571 | F1 MICRO: 0.7667
# in second
# EPOCH 8 | LOSS: 3.532109260559082 | ACCURACY: 0.7254 | F1 MACRO: 0.7571 | F1 MICRO: 0.765
# in second
# EPOCH 9 | LOSS: 3.5312392711639404 | ACCURACY: 0.7299 | F1 MACRO: 0.7646 | F1 MICRO: 0.7732
# in second
# EPOCH 10 | LOSS: 3.526505947113037 | ACCURACY: 0.7273 | F1 MACRO: 0.742 | F1 MICRO: 0.7562
# Iteration 6041: ACCURACY 0.6707 | F1 MACRO 0.7365 | F1 MICRO 0.7493
#                       precision    recall  f1-score   support
#
#           pornografi       0.96      0.84      0.90       362
#                 sara       0.67      0.54      0.60       237
#          radikalisme       0.59      0.91      0.72       235
# pencemaran_nama_baik       0.64      0.87      0.74       492
#
#            micro avg       0.70      0.81      0.75      1326
#            macro avg       0.72      0.79      0.74      1326
#         weighted avg       0.72      0.81      0.75      1326
#          samples avg       0.47      0.46      0.45      1326
#
# Nearest checkpoint: 6218
# Threshold: 18788.4140625
# Samples above threshold: 18
# Acquired samples: 177
# Sampling duration: 21.807168006896973 seconds
# New train size: 6218
# EPOCH 1 | LOSS: 4.715458869934082 | ACCURACY: 0.6765 | F1 MACRO: 0.6728 | F1 MICRO: 0.6828
# EPOCH 2 | LOSS: 4.283979415893555 | ACCURACY: 0.699 | F1 MACRO: 0.7429 | F1 MICRO: 0.743
# EPOCH 3 | LOSS: 4.118016242980957 | ACCURACY: 0.7177 | F1 MACRO: 0.7267 | F1 MICRO: 0.7404
# EPOCH 4 | LOSS: 3.977440595626831 | ACCURACY: 0.6296 | F1 MACRO: 0.4055 | F1 MICRO: 0.5623
# EPOCH 5 | LOSS: 3.82444429397583 | ACCURACY: 0.7068 | F1 MACRO: 0.7774 | F1 MICRO: 0.7804
# EPOCH 6 | LOSS: 3.614382266998291 | ACCURACY: 0.7357 | F1 MACRO: 0.761 | F1 MICRO: 0.7748
# EPOCH 7 | LOSS: 3.4942049980163574 | ACCURACY: 0.7293 | F1 MACRO: 0.7818 | F1 MICRO: 0.7883
# EPOCH 8 | LOSS: 3.47218656539917 | ACCURACY: 0.7473 | F1 MACRO: 0.7805 | F1 MICRO: 0.7905
# EPOCH 9 | LOSS: 3.4561007022857666 | ACCURACY: 0.737 | F1 MACRO: 0.7867 | F1 MICRO: 0.7911
# EPOCH 10 | LOSS: 3.444171905517578 | ACCURACY: 0.7228 | F1 MACRO: 0.7561 | F1 MICRO: 0.7757
# Iteration 6218: ACCURACY 0.737 | F1 MACRO 0.7867 | F1 MICRO 0.7911
#                       precision    recall  f1-score   support
#
#           pornografi       0.93      0.93      0.93       362
#                 sara       0.63      0.73      0.68       237
#          radikalisme       0.75      0.83      0.79       235
# pencemaran_nama_baik       0.70      0.82      0.75       492
#
#            micro avg       0.75      0.83      0.79      1326
#            macro avg       0.75      0.82      0.79      1326
#         weighted avg       0.76      0.83      0.79      1326
#          samples avg       0.46      0.47      0.46      1326
#
# Total sampling time: 459.05 seconds
# Total runtime: 8062.047866344452 seconds

# %% [markdown]
# ## RUN 3

# %%
active_learning(seeds[2], 2)
# Out:
# ===============================================
# TRIAL 3
# Random seed: 14
# label num 4
# EPOCH 1 | LOSS: 6.142989158630371 | ACCURACY: 0.4367 | F1 MACRO: 0.0 | F1 MICRO: 0.0
# EPOCH 2 | LOSS: 4.830717086791992 | ACCURACY: 0.4367 | F1 MACRO: 0.0 | F1 MICRO: 0.0
# EPOCH 3 | LOSS: 4.716850280761719 | ACCURACY: 0.5428 | F1 MACRO: 0.4289 | F1 MICRO: 0.4937
# EPOCH 4 | LOSS: 4.50679349899292 | ACCURACY: 0.5569 | F1 MACRO: 0.3424 | F1 MICRO: 0.4323
# EPOCH 5 | LOSS: 4.082455158233643 | ACCURACY: 0.627 | F1 MACRO: 0.5545 | F1 MICRO: 0.5848
# EPOCH 6 | LOSS: 3.9140560626983643 | ACCURACY: 0.618 | F1 MACRO: 0.6126 | F1 MICRO: 0.6634
# EPOCH 7 | LOSS: 3.6994717121124268 | ACCURACY: 0.6424 | F1 MACRO: 0.6824 | F1 MICRO: 0.691
# EPOCH 8 | LOSS: 3.6074013710021973 | ACCURACY: 0.6322 | F1 MACRO: 0.6586 | F1 MICRO: 0.6689
# EPOCH 9 | LOSS: 3.599766731262207 | ACCURACY: 0.6495 | F1 MACRO: 0.6795 | F1 MICRO: 0.6799
# EPOCH 10 | LOSS: 3.5326805114746094 | ACCURACY: 0.645 | F1 MACRO: 0.6988 | F1 MICRO: 0.6983
# Iteration 388: ACCURACY 0.645 | F1 MACRO 0.6988 | F1 MICRO 0.6983
#                       precision    recall  f1-score   support
#
#           pornografi       0.96      0.80      0.87       362
#                 sara       0.58      0.59      0.58       237
#          radikalisme       0.69      0.74      0.71       235
# pencemaran_nama_baik       0.67      0.58      0.62       492
#
#            micro avg       0.73      0.67      0.70      1326
#            macro avg       0.73      0.68      0.70      1326
#         weighted avg       0.74      0.67      0.70      1326
#          samples avg       0.39      0.37      0.37      1326
#
# Nearest checkpoint: 3886
# Threshold: 53184.66015625
# Samples above threshold: 583
# Acquired samples: 583
# Sampling duration: 21.872077703475952 seconds
# New train size: 971
# EPOCH 1 | LOSS: 5.441134452819824 | ACCURACY: 0.5505 | F1 MACRO: 0.3631 | F1 MICRO: 0.4089
# EPOCH 2 | LOSS: 4.545639514923096 | ACCURACY: 0.5749 | F1 MACRO: 0.5607 | F1 MICRO: 0.588
# EPOCH 3 | LOSS: 4.117115020751953 | ACCURACY: 0.6084 | F1 MACRO: 0.6776 | F1 MICRO: 0.6761
# EPOCH 4 | LOSS: 3.9906880855560303 | ACCURACY: 0.6431 | F1 MACRO: 0.6933 | F1 MICRO: 0.6969
# EPOCH 5 | LOSS: 3.619131088256836 | ACCURACY: 0.5968 | F1 MACRO: 0.6779 | F1 MICRO: 0.678
# EPOCH 6 | LOSS: 3.4051520824432373 | ACCURACY: 0.6566 | F1 MACRO: 0.7053 | F1 MICRO: 0.7089
# EPOCH 7 | LOSS: 3.26108717918396 | ACCURACY: 0.6746 | F1 MACRO: 0.693 | F1 MICRO: 0.6991
# EPOCH 8 | LOSS: 3.229405403137207 | ACCURACY: 0.6637 | F1 MACRO: 0.712 | F1 MICRO: 0.7163
# EPOCH 9 | LOSS: 3.1751129627227783 | ACCURACY: 0.6675 | F1 MACRO: 0.7148 | F1 MICRO: 0.7187
# EPOCH 10 | LOSS: 3.1610095500946045 | ACCURACY: 0.6669 | F1 MACRO: 0.671 | F1 MICRO: 0.6861
# Iteration 971: ACCURACY 0.6675 | F1 MACRO 0.7148 | F1 MICRO 0.7187
#                       precision    recall  f1-score   support
#
#           pornografi       0.91      0.84      0.88       362
#                 sara       0.62      0.58      0.60       237
#          radikalisme       0.68      0.78      0.72       235
# pencemaran_nama_baik       0.68      0.64      0.66       492
#
#            micro avg       0.73      0.71      0.72      1326
#            macro avg       0.72      0.71      0.71      1326
#         weighted avg       0.73      0.71      0.72      1326
#          samples avg       0.40      0.40      0.39      1326
#
# Nearest checkpoint: 3886
# Threshold: 61895.89453125
# Samples above threshold: 525
# Acquired samples: 525
# Sampling duration: 21.811975717544556 seconds
# New train size: 1496
# EPOCH 1 | LOSS: 5.075681686401367 | ACCURACY: 0.573 | F1 MACRO: 0.5141 | F1 MICRO: 0.5354
# EPOCH 2 | LOSS: 4.402072429656982 | ACCURACY: 0.6264 | F1 MACRO: 0.5864 | F1 MICRO: 0.5966
# EPOCH 3 | LOSS: 4.024331092834473 | ACCURACY: 0.6611 | F1 MACRO: 0.7095 | F1 MICRO: 0.7071
# EPOCH 4 | LOSS: 3.763000726699829 | ACCURACY: 0.6392 | F1 MACRO: 0.6334 | F1 MICRO: 0.6397
# EPOCH 5 | LOSS: 3.6936838626861572 | ACCURACY: 0.6752 | F1 MACRO: 0.7035 | F1 MICRO: 0.7218
# EPOCH 6 | LOSS: 3.455963611602783 | ACCURACY: 0.6817 | F1 MACRO: 0.6956 | F1 MICRO: 0.7037
# EPOCH 7 | LOSS: 3.3391809463500977 | ACCURACY: 0.6868 | F1 MACRO: 0.7084 | F1 MICRO: 0.7217
# EPOCH 8 | LOSS: 3.315187692642212 | ACCURACY: 0.6939 | F1 MACRO: 0.7223 | F1 MICRO: 0.7251
# EPOCH 9 | LOSS: 3.300516128540039 | ACCURACY: 0.6855 | F1 MACRO: 0.7251 | F1 MICRO: 0.732
# EPOCH 10 | LOSS: 3.2758569717407227 | ACCURACY: 0.6907 | F1 MACRO: 0.7027 | F1 MICRO: 0.7049
# Iteration 1496: ACCURACY 0.6855 | F1 MACRO 0.7251 | F1 MICRO 0.732
#                       precision    recall  f1-score   support
#
#           pornografi       0.96      0.78      0.86       362
#                 sara       0.72      0.53      0.61       237
#          radikalisme       0.75      0.71      0.73       235
# pencemaran_nama_baik       0.69      0.71      0.70       492
#
#            micro avg       0.77      0.70      0.73      1326
#            macro avg       0.78      0.68      0.73      1326
#         weighted avg       0.78      0.70      0.73      1326
#          samples avg       0.41      0.39      0.39      1326
#
# Nearest checkpoint: 3886
# Threshold: 52669.38671875
# Samples above threshold: 473
# Acquired samples: 473
# Sampling duration: 22.13119077682495 seconds
# New train size: 1969
# EPOCH 1 | LOSS: 5.378637313842773 | ACCURACY: 0.5048 | F1 MACRO: 0.5037 | F1 MICRO: 0.5215
# EPOCH 2 | LOSS: 4.387932777404785 | ACCURACY: 0.5955 | F1 MACRO: 0.6788 | F1 MICRO: 0.6767
# EPOCH 3 | LOSS: 4.221884727478027 | ACCURACY: 0.6251 | F1 MACRO: 0.592 | F1 MICRO: 0.6554
# EPOCH 4 | LOSS: 4.048266410827637 | ACCURACY: 0.6457 | F1 MACRO: 0.7213 | F1 MICRO: 0.7227
# EPOCH 5 | LOSS: 3.8386435508728027 | ACCURACY: 0.6064 | F1 MACRO: 0.5601 | F1 MICRO: 0.5982
# EPOCH 6 | LOSS: 3.620433807373047 | ACCURACY: 0.6836 | F1 MACRO: 0.711 | F1 MICRO: 0.7218
# EPOCH 7 | LOSS: 3.5314650535583496 | ACCURACY: 0.6913 | F1 MACRO: 0.7402 | F1 MICRO: 0.7448
# EPOCH 8 | LOSS: 3.437274694442749 | ACCURACY: 0.7035 | F1 MACRO: 0.7427 | F1 MICRO: 0.7447
# EPOCH 9 | LOSS: 3.3945271968841553 | ACCURACY: 0.708 | F1 MACRO: 0.7438 | F1 MICRO: 0.75
# EPOCH 10 | LOSS: 3.3753373622894287 | ACCURACY: 0.6926 | F1 MACRO: 0.7373 | F1 MICRO: 0.7363
# Iteration 1969: ACCURACY 0.708 | F1 MACRO 0.7438 | F1 MICRO 0.75
#                       precision    recall  f1-score   support
#
#           pornografi       0.94      0.87      0.90       362
#                 sara       0.68      0.54      0.60       237
#          radikalisme       0.76      0.81      0.79       235
# pencemaran_nama_baik       0.72      0.65      0.69       492
#
#            micro avg       0.78      0.72      0.75      1326
#            macro avg       0.78      0.72      0.74      1326
#         weighted avg       0.78      0.72      0.75      1326
#          samples avg       0.43      0.41      0.41      1326
#
# Nearest checkpoint: 3886
# Threshold: 51747.03125
# Samples above threshold: 425
# Acquired samples: 425
# Sampling duration: 21.977972745895386 seconds
# New train size: 2394
# EPOCH 1 | LOSS: 5.070338726043701 | ACCURACY: 0.5331 | F1 MACRO: 0.3788 | F1 MICRO: 0.4021
# EPOCH 2 | LOSS: 4.373696804046631 | ACCURACY: 0.6379 | F1 MACRO: 0.7119 | F1 MICRO: 0.7083
# EPOCH 3 | LOSS: 4.132801055908203 | ACCURACY: 0.6322 | F1 MACRO: 0.5871 | F1 MICRO: 0.6219
# EPOCH 4 | LOSS: 3.9148898124694824 | ACCURACY: 0.6058 | F1 MACRO: 0.5949 | F1 MICRO: 0.6002
# EPOCH 5 | LOSS: 3.7811203002929688 | ACCURACY: 0.6437 | F1 MACRO: 0.6917 | F1 MICRO: 0.6856
# in second
# EPOCH 6 | LOSS: 3.491116523742676 | ACCURACY: 0.681 | F1 MACRO: 0.7111 | F1 MICRO: 0.7193
# in second
# EPOCH 7 | LOSS: 3.4520580768585205 | ACCURACY: 0.6804 | F1 MACRO: 0.7285 | F1 MICRO: 0.7296
# in second
# EPOCH 8 | LOSS: 3.435149908065796 | ACCURACY: 0.681 | F1 MACRO: 0.717 | F1 MICRO: 0.7177
# in second
# EPOCH 9 | LOSS: 3.427934169769287 | ACCURACY: 0.6875 | F1 MACRO: 0.7141 | F1 MICRO: 0.7213
# in second
# Iteration 2394: ACCURACY 0.6379 | F1 MACRO 0.7119 | F1 MICRO 0.7083
#                       precision    recall  f1-score   support
#
#           pornografi       0.94      0.80      0.86       362
#                 sara       0.49      0.82      0.61       237
#          radikalisme       0.62      0.82      0.70       235
# pencemaran_nama_baik       0.63      0.71      0.67       492
#
#            micro avg       0.65      0.77      0.71      1326
#            macro avg       0.67      0.79      0.71      1326
#         weighted avg       0.69      0.77      0.72      1326
#          samples avg       0.39      0.42      0.39      1326
#
# Nearest checkpoint: 3886
# Threshold: 50715.43359375
# Samples above threshold: 383
# Acquired samples: 383
# Sampling duration: 22.147423028945923 seconds
# New train size: 2777
# EPOCH 1 | LOSS: 4.906790733337402 | ACCURACY: 0.49 | F1 MACRO: 0.5303 | F1 MICRO: 0.555
# EPOCH 2 | LOSS: 4.439780235290527 | ACCURACY: 0.6206 | F1 MACRO: 0.6209 | F1 MICRO: 0.6176
# EPOCH 3 | LOSS: 4.199899196624756 | ACCURACY: 0.6026 | F1 MACRO: 0.6303 | F1 MICRO: 0.6452
# EPOCH 4 | LOSS: 3.9739789962768555 | ACCURACY: 0.6701 | F1 MACRO: 0.7329 | F1 MICRO: 0.732
# EPOCH 5 | LOSS: 3.8637821674346924 | ACCURACY: 0.6875 | F1 MACRO: 0.7286 | F1 MICRO: 0.7344
# EPOCH 6 | LOSS: 3.592930316925049 | ACCURACY: 0.7048 | F1 MACRO: 0.7532 | F1 MICRO: 0.7549
# EPOCH 7 | LOSS: 3.4334568977355957 | ACCURACY: 0.699 | F1 MACRO: 0.7337 | F1 MICRO: 0.7341
# EPOCH 8 | LOSS: 3.4097938537597656 | ACCURACY: 0.7068 | F1 MACRO: 0.7456 | F1 MICRO: 0.749
# EPOCH 9 | LOSS: 3.3743479251861572 | ACCURACY: 0.7106 | F1 MACRO: 0.7478 | F1 MICRO: 0.7501
# in second
# EPOCH 10 | LOSS: 3.311774253845215 | ACCURACY: 0.7093 | F1 MACRO: 0.7479 | F1 MICRO: 0.749
# Iteration 2777: ACCURACY 0.7048 | F1 MACRO 0.7532 | F1 MICRO 0.7549
#                       precision    recall  f1-score   support
#
#           pornografi       0.94      0.85      0.89       362
#                 sara       0.66      0.63      0.64       237
#          radikalisme       0.74      0.82      0.78       235
# pencemaran_nama_baik       0.71      0.68      0.70       492
#
#            micro avg       0.77      0.74      0.75      1326
#            macro avg       0.76      0.74      0.75      1326
#         weighted avg       0.77      0.74      0.76      1326
#          samples avg       0.43      0.42      0.42      1326
#
# Nearest checkpoint: 3886
# Threshold: 49837.69140625
# Samples above threshold: 345
# Acquired samples: 345
# Sampling duration: 21.862508296966553 seconds
# New train size: 3122
# EPOCH 1 | LOSS: 4.910970687866211 | ACCURACY: 0.5775 | F1 MACRO: 0.4487 | F1 MICRO: 0.4896
# EPOCH 2 | LOSS: 4.42605447769165 | ACCURACY: 0.6289 | F1 MACRO: 0.6788 | F1 MICRO: 0.6986
# EPOCH 3 | LOSS: 4.214797496795654 | ACCURACY: 0.6855 | F1 MACRO: 0.7478 | F1 MICRO: 0.7455
# EPOCH 4 | LOSS: 3.9758286476135254 | ACCURACY: 0.6772 | F1 MACRO: 0.7416 | F1 MICRO: 0.7368
# EPOCH 5 | LOSS: 3.784641981124878 | ACCURACY: 0.683 | F1 MACRO: 0.68 | F1 MICRO: 0.6992
# EPOCH 6 | LOSS: 3.5478062629699707 | ACCURACY: 0.7003 | F1 MACRO: 0.7582 | F1 MICRO: 0.76
# EPOCH 7 | LOSS: 3.442838430404663 | ACCURACY: 0.708 | F1 MACRO: 0.7421 | F1 MICRO: 0.7464
# EPOCH 8 | LOSS: 3.380730390548706 | ACCURACY: 0.7145 | F1 MACRO: 0.7389 | F1 MICRO: 0.746
# EPOCH 9 | LOSS: 3.3649861812591553 | ACCURACY: 0.719 | F1 MACRO: 0.7634 | F1 MICRO: 0.7683
# EPOCH 10 | LOSS: 3.336256265640259 | ACCURACY: 0.7138 | F1 MACRO: 0.7585 | F1 MICRO: 0.7636
# Iteration 3122: ACCURACY 0.719 | F1 MACRO 0.7634 | F1 MICRO 0.7683
#                       precision    recall  f1-score   support
#
#           pornografi       0.95      0.88      0.91       362
#                 sara       0.69      0.61      0.65       237
#          radikalisme       0.76      0.80      0.78       235
# pencemaran_nama_baik       0.73      0.71      0.72       492
#
#            micro avg       0.78      0.75      0.77      1326
#            macro avg       0.78      0.75      0.76      1326
#         weighted avg       0.79      0.75      0.77      1326
#          samples avg       0.42      0.42      0.42      1326
#
# Nearest checkpoint: 3886
# Threshold: 50517.8203125
# Samples above threshold: 310
# Acquired samples: 310
# Sampling duration: 21.784526109695435 seconds
# New train size: 3432
# EPOCH 1 | LOSS: 4.960022449493408 | ACCURACY: 0.5987 | F1 MACRO: 0.2695 | F1 MICRO: 0.4112
# EPOCH 2 | LOSS: 4.402534008026123 | ACCURACY: 0.6161 | F1 MACRO: 0.5725 | F1 MICRO: 0.6179
# EPOCH 3 | LOSS: 4.182651996612549 | ACCURACY: 0.6424 | F1 MACRO: 0.6629 | F1 MICRO: 0.6758
# EPOCH 4 | LOSS: 3.983358383178711 | ACCURACY: 0.6958 | F1 MACRO: 0.7233 | F1 MICRO: 0.7357
# EPOCH 5 | LOSS: 3.8453428745269775 | ACCURACY: 0.6842 | F1 MACRO: 0.7338 | F1 MICRO: 0.7414
# EPOCH 6 | LOSS: 3.613598585128784 | ACCURACY: 0.7183 | F1 MACRO: 0.7504 | F1 MICRO: 0.7553
# EPOCH 7 | LOSS: 3.4541056156158447 | ACCURACY: 0.7241 | F1 MACRO: 0.7663 | F1 MICRO: 0.7717
# EPOCH 8 | LOSS: 3.435904026031494 | ACCURACY: 0.7235 | F1 MACRO: 0.7673 | F1 MICRO: 0.7759
# EPOCH 9 | LOSS: 3.412992000579834 | ACCURACY: 0.7132 | F1 MACRO: 0.7476 | F1 MICRO: 0.7517
# EPOCH 10 | LOSS: 3.3875885009765625 | ACCURACY: 0.7215 | F1 MACRO: 0.77 | F1 MICRO: 0.773
# Iteration 3432: ACCURACY 0.7235 | F1 MACRO 0.7673 | F1 MICRO 0.7759
#                       precision    recall  f1-score   support
#
#           pornografi       0.90      0.90      0.90       362
#                 sara       0.67      0.60      0.63       237
#          radikalisme       0.77      0.83      0.80       235
# pencemaran_nama_baik       0.75      0.73      0.74       492
#
#            micro avg       0.78      0.77      0.78      1326
#            macro avg       0.77      0.77      0.77      1326
#         weighted avg       0.78      0.77      0.77      1326
#          samples avg       0.44      0.44      0.43      1326
#
# Nearest checkpoint: 3886
# Threshold: 48783.2734375
# Samples above threshold: 279
# Acquired samples: 279
# Sampling duration: 21.79129981994629 seconds
# New train size: 3711
# EPOCH 1 | LOSS: 4.864673614501953 | ACCURACY: 0.5653 | F1 MACRO: 0.3221 | F1 MICRO: 0.4635
# EPOCH 2 | LOSS: 4.427454471588135 | ACCURACY: 0.6566 | F1 MACRO: 0.68 | F1 MICRO: 0.6995
# EPOCH 3 | LOSS: 4.179074287414551 | ACCURACY: 0.6977 | F1 MACRO: 0.7269 | F1 MICRO: 0.7304
# EPOCH 4 | LOSS: 3.9658660888671875 | ACCURACY: 0.6842 | F1 MACRO: 0.7006 | F1 MICRO: 0.7099
# EPOCH 5 | LOSS: 3.7931196689605713 | ACCURACY: 0.6714 | F1 MACRO: 0.655 | F1 MICRO: 0.671
# EPOCH 6 | LOSS: 3.5515778064727783 | ACCURACY: 0.7203 | F1 MACRO: 0.77 | F1 MICRO: 0.7761
# EPOCH 7 | LOSS: 3.4742414951324463 | ACCURACY: 0.7151 | F1 MACRO: 0.7378 | F1 MICRO: 0.75
# EPOCH 8 | LOSS: 3.420196533203125 | ACCURACY: 0.7273 | F1 MACRO: 0.7631 | F1 MICRO: 0.7698
# EPOCH 9 | LOSS: 3.3936100006103516 | ACCURACY: 0.7106 | F1 MACRO: 0.7613 | F1 MICRO: 0.7677
# in second
# EPOCH 10 | LOSS: 3.3187928199768066 | ACCURACY: 0.7228 | F1 MACRO: 0.7626 | F1 MICRO: 0.7706
# Iteration 3711: ACCURACY 0.7203 | F1 MACRO 0.77 | F1 MICRO 0.7761
#                       precision    recall  f1-score   support
#
#           pornografi       0.92      0.88      0.90       362
#                 sara       0.69      0.60      0.64       237
#          radikalisme       0.75      0.85      0.80       235
# pencemaran_nama_baik       0.68      0.80      0.74       492
#
#            micro avg       0.76      0.80      0.78      1326
#            macro avg       0.76      0.78      0.77      1326
#         weighted avg       0.76      0.80      0.78      1326
#          samples avg       0.45      0.45      0.44      1326
#
# Nearest checkpoint: 3886
# Threshold: 49164.3984375
# Samples above threshold: 251
# Acquired samples: 175
# Sampling duration: 21.84348750114441 seconds
# New train size: 3886
# EPOCH 1 | LOSS: 4.924463272094727 | ACCURACY: 0.6129 | F1 MACRO: 0.5536 | F1 MICRO: 0.5896
# EPOCH 2 | LOSS: 4.390669345855713 | ACCURACY: 0.6965 | F1 MACRO: 0.773 | F1 MICRO: 0.7683
# EPOCH 3 | LOSS: 4.200730323791504 | ACCURACY: 0.6688 | F1 MACRO: 0.7574 | F1 MICRO: 0.7599
# EPOCH 4 | LOSS: 3.975550413131714 | ACCURACY: 0.6521 | F1 MACRO: 0.7047 | F1 MICRO: 0.7067
# EPOCH 5 | LOSS: 3.809985399246216 | ACCURACY: 0.6534 | F1 MACRO: 0.7389 | F1 MICRO: 0.7364
# in second
# EPOCH 6 | LOSS: 3.53413724899292 | ACCURACY: 0.6958 | F1 MACRO: 0.7482 | F1 MICRO: 0.752
# in second
# EPOCH 7 | LOSS: 3.4851295948028564 | ACCURACY: 0.6932 | F1 MACRO: 0.7401 | F1 MICRO: 0.7469
# in second
# EPOCH 8 | LOSS: 3.4688854217529297 | ACCURACY: 0.6965 | F1 MACRO: 0.7539 | F1 MICRO: 0.7515
# in second
# Iteration 3886: ACCURACY 0.6965 | F1 MACRO 0.773 | F1 MICRO 0.7683
#                       precision    recall  f1-score   support
#
#           pornografi       0.97      0.81      0.88       362
#                 sara       0.60      0.78      0.68       237
#          radikalisme       0.78      0.84      0.81       235
# pencemaran_nama_baik       0.71      0.74      0.72       492
#
#            micro avg       0.75      0.79      0.77      1326
#            macro avg       0.76      0.79      0.77      1326
#         weighted avg       0.77      0.79      0.77      1326
#          samples avg       0.45      0.44      0.44      1326
#
# Nearest checkpoint: 4663
# Threshold: 48867.77734375
# Samples above threshold: 234
# Acquired samples: 234
# Sampling duration: 21.982465028762817 seconds
# New train size: 4120
# EPOCH 1 | LOSS: 4.883022785186768 | ACCURACY: 0.573 | F1 MACRO: 0.4708 | F1 MICRO: 0.5552
# EPOCH 2 | LOSS: 4.432591438293457 | ACCURACY: 0.6257 | F1 MACRO: 0.6331 | F1 MICRO: 0.6394
# EPOCH 3 | LOSS: 4.230345726013184 | ACCURACY: 0.6977 | F1 MACRO: 0.7507 | F1 MICRO: 0.7478
# EPOCH 4 | LOSS: 4.0889763832092285 | ACCURACY: 0.6257 | F1 MACRO: 0.4879 | F1 MICRO: 0.5905
# EPOCH 5 | LOSS: 3.9359912872314453 | ACCURACY: 0.6785 | F1 MACRO: 0.6997 | F1 MICRO: 0.6965
# EPOCH 6 | LOSS: 3.6147961616516113 | ACCURACY: 0.7203 | F1 MACRO: 0.7683 | F1 MICRO: 0.7768
# EPOCH 7 | LOSS: 3.5022788047790527 | ACCURACY: 0.7177 | F1 MACRO: 0.7702 | F1 MICRO: 0.7746
# EPOCH 8 | LOSS: 3.4538745880126953 | ACCURACY: 0.7222 | F1 MACRO: 0.7767 | F1 MICRO: 0.7783
# EPOCH 9 | LOSS: 3.4006242752075195 | ACCURACY: 0.7293 | F1 MACRO: 0.7803 | F1 MICRO: 0.7834
# EPOCH 10 | LOSS: 3.3981544971466064 | ACCURACY: 0.7286 | F1 MACRO: 0.7836 | F1 MICRO: 0.7858
# Iteration 4120: ACCURACY 0.7286 | F1 MACRO 0.7836 | F1 MICRO 0.7858
#                       precision    recall  f1-score   support
#
#           pornografi       0.92      0.90      0.91       362
#                 sara       0.68      0.71      0.70       237
#          radikalisme       0.76      0.83      0.80       235
# pencemaran_nama_baik       0.76      0.70      0.73       492
#
#            micro avg       0.79      0.78      0.79      1326
#            macro avg       0.78      0.79      0.78      1326
#         weighted avg       0.79      0.78      0.79      1326
#          samples avg       0.45      0.44      0.44      1326
#
# Nearest checkpoint: 4663
# Threshold: 71542.46875
# Samples above threshold: 210
# Acquired samples: 210
# Sampling duration: 21.631335496902466 seconds
# New train size: 4330
# EPOCH 1 | LOSS: 4.875263690948486 | ACCURACY: 0.6006 | F1 MACRO: 0.2593 | F1 MICRO: 0.3993
# EPOCH 2 | LOSS: 4.419763565063477 | ACCURACY: 0.6566 | F1 MACRO: 0.7633 | F1 MICRO: 0.7537
# EPOCH 3 | LOSS: 4.19797420501709 | ACCURACY: 0.6624 | F1 MACRO: 0.7085 | F1 MICRO: 0.6986
# EPOCH 4 | LOSS: 4.037795543670654 | ACCURACY: 0.7138 | F1 MACRO: 0.7301 | F1 MICRO: 0.7534
# EPOCH 5 | LOSS: 3.854680061340332 | ACCURACY: 0.6752 | F1 MACRO: 0.6897 | F1 MICRO: 0.7213
# in second
# EPOCH 6 | LOSS: 3.506579637527466 | ACCURACY: 0.7106 | F1 MACRO: 0.7275 | F1 MICRO: 0.7434
# in second
# EPOCH 7 | LOSS: 3.4828248023986816 | ACCURACY: 0.7093 | F1 MACRO: 0.748 | F1 MICRO: 0.7566
# in second
# EPOCH 8 | LOSS: 3.47053861618042 | ACCURACY: 0.7125 | F1 MACRO: 0.7515 | F1 MICRO: 0.7601
# in second
# EPOCH 9 | LOSS: 3.457289218902588 | ACCURACY: 0.7074 | F1 MACRO: 0.751 | F1 MICRO: 0.7565
# in second
# EPOCH 10 | LOSS: 3.448662281036377 | ACCURACY: 0.7203 | F1 MACRO: 0.7575 | F1 MICRO: 0.7659
# Iteration 4330: ACCURACY 0.6566 | F1 MACRO 0.7633 | F1 MICRO 0.7537
#                       precision    recall  f1-score   support
#
#           pornografi       0.92      0.88      0.90       362
#                 sara       0.50      0.91      0.65       237
#          radikalisme       0.77      0.82      0.80       235
# pencemaran_nama_baik       0.58      0.92      0.71       492
#
#            micro avg       0.66      0.89      0.75      1326
#            macro avg       0.70      0.88      0.76      1326
#         weighted avg       0.69      0.89      0.77      1326
#          samples avg       0.46      0.50      0.47      1326
#
# Nearest checkpoint: 4663
# Threshold: 48612.38671875
# Samples above threshold: 189
# Acquired samples: 200
# Sampling duration: 21.908281087875366 seconds
# New train size: 4530
# EPOCH 1 | LOSS: 4.858431339263916 | ACCURACY: 0.5569 | F1 MACRO: 0.6878 | F1 MICRO: 0.6735
# EPOCH 2 | LOSS: 4.4301629066467285 | ACCURACY: 0.6328 | F1 MACRO: 0.5389 | F1 MICRO: 0.628
# EPOCH 3 | LOSS: 4.23821496963501 | ACCURACY: 0.6116 | F1 MACRO: 0.5178 | F1 MICRO: 0.5477
# EPOCH 4 | LOSS: 4.088840484619141 | ACCURACY: 0.6418 | F1 MACRO: 0.7364 | F1 MICRO: 0.7321
# EPOCH 5 | LOSS: 3.9019861221313477 | ACCURACY: 0.708 | F1 MACRO: 0.7719 | F1 MICRO: 0.7764
# EPOCH 6 | LOSS: 3.6529829502105713 | ACCURACY: 0.7267 | F1 MACRO: 0.7576 | F1 MICRO: 0.7631
# EPOCH 7 | LOSS: 3.503380060195923 | ACCURACY: 0.7344 | F1 MACRO: 0.772 | F1 MICRO: 0.7823
# EPOCH 8 | LOSS: 3.4693939685821533 | ACCURACY: 0.7293 | F1 MACRO: 0.7641 | F1 MICRO: 0.773
# EPOCH 9 | LOSS: 3.4248483180999756 | ACCURACY: 0.7325 | F1 MACRO: 0.782 | F1 MICRO: 0.7815
# EPOCH 10 | LOSS: 3.41867995262146 | ACCURACY: 0.7241 | F1 MACRO: 0.7762 | F1 MICRO: 0.7784
# Iteration 4530: ACCURACY 0.7344 | F1 MACRO 0.772 | F1 MICRO 0.7823
#                       precision    recall  f1-score   support
#
#           pornografi       0.97      0.86      0.91       362
#                 sara       0.75      0.54      0.63       237
#          radikalisme       0.77      0.83      0.80       235
# pencemaran_nama_baik       0.75      0.74      0.74       492
#
#            micro avg       0.82      0.75      0.78      1326
#            macro avg       0.81      0.74      0.77      1326
#         weighted avg       0.82      0.75      0.78      1326
#          samples avg       0.44      0.43      0.43      1326
#
# Nearest checkpoint: 4663
# Threshold: 48064.06640625
# Samples above threshold: 169
# Acquired samples: 133
# Sampling duration: 21.7989239692688 seconds
# New train size: 4663
# EPOCH 1 | LOSS: 4.8467817306518555 | ACCURACY: 0.6875 | F1 MACRO: 0.7448 | F1 MICRO: 0.7434
# EPOCH 2 | LOSS: 4.427408218383789 | ACCURACY: 0.6508 | F1 MACRO: 0.6966 | F1 MICRO: 0.693
# EPOCH 3 | LOSS: 4.2221574783325195 | ACCURACY: 0.7145 | F1 MACRO: 0.7646 | F1 MICRO: 0.7655
# EPOCH 4 | LOSS: 4.016808986663818 | ACCURACY: 0.6585 | F1 MACRO: 0.6381 | F1 MICRO: 0.6436
# EPOCH 5 | LOSS: 3.874786853790283 | ACCURACY: 0.6926 | F1 MACRO: 0.7459 | F1 MICRO: 0.7497
# EPOCH 6 | LOSS: 3.5924034118652344 | ACCURACY: 0.728 | F1 MACRO: 0.7502 | F1 MICRO: 0.7627
# in second
# EPOCH 7 | LOSS: 3.3918919563293457 | ACCURACY: 0.7325 | F1 MACRO: 0.7682 | F1 MICRO: 0.775
# in second
# EPOCH 8 | LOSS: 3.3817355632781982 | ACCURACY: 0.7286 | F1 MACRO: 0.7596 | F1 MICRO: 0.7681
# in second
# EPOCH 9 | LOSS: 3.372584342956543 | ACCURACY: 0.7293 | F1 MACRO: 0.7702 | F1 MICRO: 0.7762
# in second
# EPOCH 10 | LOSS: 3.367030620574951 | ACCURACY: 0.7254 | F1 MACRO: 0.7622 | F1 MICRO: 0.7703
# Iteration 4663: ACCURACY 0.7145 | F1 MACRO 0.7646 | F1 MICRO 0.7655
#                       precision    recall  f1-score   support
#
#           pornografi       0.97      0.84      0.90       362
#                 sara       0.65      0.64      0.64       237
#          radikalisme       0.78      0.83      0.80       235
# pencemaran_nama_baik       0.72      0.71      0.71       492
#
#            micro avg       0.78      0.75      0.77      1326
#            macro avg       0.78      0.75      0.76      1326
#         weighted avg       0.78      0.75      0.77      1326
#          samples avg       0.41      0.42      0.41      1326
#
# Nearest checkpoint: 5441
# Threshold: 47695.10546875
# Samples above threshold: 156
# Acquired samples: 200
# Sampling duration: 21.71051001548767 seconds
# New train size: 4863
# EPOCH 1 | LOSS: 4.817731857299805 | ACCURACY: 0.6476 | F1 MACRO: 0.5425 | F1 MICRO: 0.6501
# EPOCH 2 | LOSS: 4.41519021987915 | ACCURACY: 0.6682 | F1 MACRO: 0.6616 | F1 MICRO: 0.6725
# EPOCH 3 | LOSS: 4.206937789916992 | ACCURACY: 0.6212 | F1 MACRO: 0.6169 | F1 MICRO: 0.6797
# EPOCH 4 | LOSS: 4.0201311111450195 | ACCURACY: 0.6907 | F1 MACRO: 0.7029 | F1 MICRO: 0.7188
# EPOCH 5 | LOSS: 3.8909196853637695 | ACCURACY: 0.7061 | F1 MACRO: 0.7688 | F1 MICRO: 0.7701
# EPOCH 6 | LOSS: 3.6187074184417725 | ACCURACY: 0.7273 | F1 MACRO: 0.7525 | F1 MICRO: 0.7603
# EPOCH 7 | LOSS: 3.494070053100586 | ACCURACY: 0.7273 | F1 MACRO: 0.7804 | F1 MICRO: 0.7821
# EPOCH 8 | LOSS: 3.4676458835601807 | ACCURACY: 0.7299 | F1 MACRO: 0.7791 | F1 MICRO: 0.7826
# EPOCH 9 | LOSS: 3.4405405521392822 | ACCURACY: 0.7402 | F1 MACRO: 0.7658 | F1 MICRO: 0.7769
# EPOCH 10 | LOSS: 3.4210968017578125 | ACCURACY: 0.7299 | F1 MACRO: 0.7625 | F1 MICRO: 0.7701
# Iteration 4863: ACCURACY 0.7299 | F1 MACRO 0.7791 | F1 MICRO 0.7826
#                       precision    recall  f1-score   support
#
#           pornografi       0.95      0.89      0.92       362
#                 sara       0.67      0.66      0.67       237
#          radikalisme       0.78      0.81      0.80       235
# pencemaran_nama_baik       0.73      0.75      0.74       492
#
#            micro avg       0.78      0.78      0.78      1326
#            macro avg       0.78      0.78      0.78      1326
#         weighted avg       0.79      0.78      0.78      1326
#          samples avg       0.45      0.44      0.44      1326
#
# Nearest checkpoint: 5441
# Threshold: 46912.70703125
# Samples above threshold: 136
# Acquired samples: 200
# Sampling duration: 21.70553231239319 seconds
# New train size: 5063
# EPOCH 1 | LOSS: 4.787875652313232 | ACCURACY: 0.555 | F1 MACRO: 0.3827 | F1 MICRO: 0.5599
# EPOCH 2 | LOSS: 4.40099573135376 | ACCURACY: 0.6765 | F1 MACRO: 0.6776 | F1 MICRO: 0.7499
# EPOCH 3 | LOSS: 4.200212478637695 | ACCURACY: 0.6714 | F1 MACRO: 0.6738 | F1 MICRO: 0.7025
# EPOCH 4 | LOSS: 4.008833408355713 | ACCURACY: 0.692 | F1 MACRO: 0.6923 | F1 MICRO: 0.7262
# EPOCH 5 | LOSS: 3.857647657394409 | ACCURACY: 0.7125 | F1 MACRO: 0.7699 | F1 MICRO: 0.7714
# EPOCH 6 | LOSS: 3.594674587249756 | ACCURACY: 0.7158 | F1 MACRO: 0.7648 | F1 MICRO: 0.7676
# EPOCH 7 | LOSS: 3.5074098110198975 | ACCURACY: 0.7299 | F1 MACRO: 0.7744 | F1 MICRO: 0.7823
# EPOCH 8 | LOSS: 3.4585235118865967 | ACCURACY: 0.7273 | F1 MACRO: 0.7722 | F1 MICRO: 0.7772
# EPOCH 9 | LOSS: 3.4505226612091064 | ACCURACY: 0.7344 | F1 MACRO: 0.7739 | F1 MICRO: 0.7785
# EPOCH 10 | LOSS: 3.4442739486694336 | ACCURACY: 0.7299 | F1 MACRO: 0.7641 | F1 MICRO: 0.772
# Iteration 5063: ACCURACY 0.7299 | F1 MACRO 0.7744 | F1 MICRO 0.7823
#                       precision    recall  f1-score   support
#
#           pornografi       0.92      0.91      0.92       362
#                 sara       0.64      0.65      0.65       237
#          radikalisme       0.75      0.82      0.78       235
# pencemaran_nama_baik       0.72      0.78      0.75       492
#
#            micro avg       0.77      0.80      0.78      1326
#            macro avg       0.76      0.79      0.77      1326
#         weighted avg       0.77      0.80      0.78      1326
#          samples avg       0.46      0.46      0.45      1326
#
# Nearest checkpoint: 5441
# Threshold: 46383.10546875
# Samples above threshold: 116
# Acquired samples: 200
# Sampling duration: 21.64809226989746 seconds
# New train size: 5263
# EPOCH 1 | LOSS: 4.813728332519531 | ACCURACY: 0.4791 | F1 MACRO: 0.5224 | F1 MICRO: 0.5489
# EPOCH 2 | LOSS: 4.434628486633301 | ACCURACY: 0.6823 | F1 MACRO: 0.675 | F1 MICRO: 0.7015
# EPOCH 3 | LOSS: 4.258454322814941 | ACCURACY: 0.7042 | F1 MACRO: 0.7413 | F1 MICRO: 0.7569
# EPOCH 4 | LOSS: 4.07819128036499 | ACCURACY: 0.6932 | F1 MACRO: 0.7039 | F1 MICRO: 0.7171
# EPOCH 5 | LOSS: 3.913506269454956 | ACCURACY: 0.7318 | F1 MACRO: 0.7727 | F1 MICRO: 0.7782
# EPOCH 6 | LOSS: 3.647361993789673 | ACCURACY: 0.7209 | F1 MACRO: 0.7782 | F1 MICRO: 0.7791
# EPOCH 7 | LOSS: 3.543811798095703 | ACCURACY: 0.7415 | F1 MACRO: 0.7794 | F1 MICRO: 0.7879
# EPOCH 8 | LOSS: 3.5087809562683105 | ACCURACY: 0.7434 | F1 MACRO: 0.7918 | F1 MICRO: 0.7955
# EPOCH 9 | LOSS: 3.490161657333374 | ACCURACY: 0.7395 | F1 MACRO: 0.7863 | F1 MICRO: 0.7909
# EPOCH 10 | LOSS: 3.4675753116607666 | ACCURACY: 0.7357 | F1 MACRO: 0.7842 | F1 MICRO: 0.7879
# Iteration 5263: ACCURACY 0.7434 | F1 MACRO 0.7918 | F1 MICRO 0.7955
#                       precision    recall  f1-score   support
#
#           pornografi       0.96      0.86      0.91       362
#                 sara       0.71      0.65      0.68       237
#          radikalisme       0.76      0.89      0.82       235
# pencemaran_nama_baik       0.74      0.77      0.76       492
#
#            micro avg       0.79      0.80      0.80      1326
#            macro avg       0.79      0.79      0.79      1326
#         weighted avg       0.80      0.80      0.80      1326
#          samples avg       0.46      0.45      0.45      1326
#
# Nearest checkpoint: 5441
# Threshold: 53683.4375
# Samples above threshold: 96
# Acquired samples: 178
# Sampling duration: 21.715508699417114 seconds
# New train size: 5441
# EPOCH 1 | LOSS: 4.79953670501709 | ACCURACY: 0.6772 | F1 MACRO: 0.6925 | F1 MICRO: 0.7222
# EPOCH 2 | LOSS: 4.394979000091553 | ACCURACY: 0.6958 | F1 MACRO: 0.6884 | F1 MICRO: 0.7209
# EPOCH 3 | LOSS: 4.269378185272217 | ACCURACY: 0.7029 | F1 MACRO: 0.7357 | F1 MICRO: 0.7451
# EPOCH 4 | LOSS: 4.019594192504883 | ACCURACY: 0.6367 | F1 MACRO: 0.6982 | F1 MICRO: 0.7237
# EPOCH 5 | LOSS: 3.8834304809570312 | ACCURACY: 0.7222 | F1 MACRO: 0.763 | F1 MICRO: 0.7673
# EPOCH 6 | LOSS: 3.6378672122955322 | ACCURACY: 0.7338 | F1 MACRO: 0.7827 | F1 MICRO: 0.7838
# EPOCH 7 | LOSS: 3.5165438652038574 | ACCURACY: 0.7318 | F1 MACRO: 0.787 | F1 MICRO: 0.7897
# EPOCH 8 | LOSS: 3.4802896976470947 | ACCURACY: 0.7318 | F1 MACRO: 0.7734 | F1 MICRO: 0.7832
# EPOCH 9 | LOSS: 3.474552869796753 | ACCURACY: 0.7286 | F1 MACRO: 0.768 | F1 MICRO: 0.7723
# EPOCH 10 | LOSS: 3.4476616382598877 | ACCURACY: 0.7267 | F1 MACRO: 0.7571 | F1 MICRO: 0.7648
# Iteration 5441: ACCURACY 0.7318 | F1 MACRO 0.787 | F1 MICRO 0.7897
#                       precision    recall  f1-score   support
#
#           pornografi       0.94      0.92      0.93       362
#                 sara       0.65      0.73      0.69       237
#          radikalisme       0.75      0.83      0.79       235
# pencemaran_nama_baik       0.72      0.76      0.74       492
#
#            micro avg       0.77      0.81      0.79      1326
#            macro avg       0.77      0.81      0.79      1326
#         weighted avg       0.78      0.81      0.79      1326
#          samples avg       0.46      0.46      0.45      1326
#
# Nearest checkpoint: 6218
# Threshold: 19575.537109375
# Samples above threshold: 78
# Acquired samples: 200
# Sampling duration: 21.635748863220215 seconds
# New train size: 5641
# EPOCH 1 | LOSS: 4.786137104034424 | ACCURACY: 0.609 | F1 MACRO: 0.4684 | F1 MICRO: 0.5086
# EPOCH 2 | LOSS: 4.359827041625977 | ACCURACY: 0.7113 | F1 MACRO: 0.7221 | F1 MICRO: 0.7304
# EPOCH 3 | LOSS: 4.216768264770508 | ACCURACY: 0.7145 | F1 MACRO: 0.7771 | F1 MICRO: 0.7805
# EPOCH 4 | LOSS: 4.03825044631958 | ACCURACY: 0.6662 | F1 MACRO: 0.7518 | F1 MICRO: 0.7484
# EPOCH 5 | LOSS: 3.882863998413086 | ACCURACY: 0.7293 | F1 MACRO: 0.7816 | F1 MICRO: 0.783
# EPOCH 6 | LOSS: 3.656432628631592 | ACCURACY: 0.7177 | F1 MACRO: 0.7679 | F1 MICRO: 0.7724
# EPOCH 7 | LOSS: 3.543201446533203 | ACCURACY: 0.7299 | F1 MACRO: 0.774 | F1 MICRO: 0.7803
# EPOCH 8 | LOSS: 3.4959208965301514 | ACCURACY: 0.7376 | F1 MACRO: 0.7786 | F1 MICRO: 0.7895
# EPOCH 9 | LOSS: 3.471651554107666 | ACCURACY: 0.7441 | F1 MACRO: 0.7829 | F1 MICRO: 0.7908
# EPOCH 10 | LOSS: 3.456299066543579 | ACCURACY: 0.7363 | F1 MACRO: 0.7689 | F1 MICRO: 0.7865
# Iteration 5641: ACCURACY 0.7441 | F1 MACRO 0.7829 | F1 MICRO 0.7908
#                       precision    recall  f1-score   support
#
#           pornografi       0.96      0.90      0.93       362
#                 sara       0.69      0.62      0.65       237
#          radikalisme       0.82      0.77      0.80       235
# pencemaran_nama_baik       0.71      0.80      0.76       492
#
#            micro avg       0.79      0.79      0.79      1326
#            macro avg       0.80      0.77      0.78      1326
#         weighted avg       0.80      0.79      0.79      1326
#          samples avg       0.45      0.45      0.44      1326
#
# Nearest checkpoint: 6218
# Threshold: 19397.50390625
# Samples above threshold: 58
# Acquired samples: 200
# Sampling duration: 21.648969650268555 seconds
# New train size: 5841
# EPOCH 1 | LOSS: 4.778956413269043 | ACCURACY: 0.6322 | F1 MACRO: 0.5524 | F1 MICRO: 0.6132
# EPOCH 2 | LOSS: 4.348742961883545 | ACCURACY: 0.6328 | F1 MACRO: 0.5015 | F1 MICRO: 0.5571
# EPOCH 3 | LOSS: 4.179811954498291 | ACCURACY: 0.6714 | F1 MACRO: 0.6748 | F1 MICRO: 0.6914
# EPOCH 4 | LOSS: 4.035744667053223 | ACCURACY: 0.7087 | F1 MACRO: 0.7306 | F1 MICRO: 0.74
# EPOCH 5 | LOSS: 3.8725221157073975 | ACCURACY: 0.6887 | F1 MACRO: 0.6824 | F1 MICRO: 0.7144
# EPOCH 6 | LOSS: 3.644439458847046 | ACCURACY: 0.7151 | F1 MACRO: 0.7558 | F1 MICRO: 0.7658
# EPOCH 7 | LOSS: 3.520998239517212 | ACCURACY: 0.7215 | F1 MACRO: 0.7231 | F1 MICRO: 0.7453
# EPOCH 8 | LOSS: 3.4966249465942383 | ACCURACY: 0.7196 | F1 MACRO: 0.7677 | F1 MICRO: 0.7766
# EPOCH 9 | LOSS: 3.452204942703247 | ACCURACY: 0.7299 | F1 MACRO: 0.7731 | F1 MICRO: 0.7788
# EPOCH 10 | LOSS: 3.449894428253174 | ACCURACY: 0.6932 | F1 MACRO: 0.7443 | F1 MICRO: 0.7587
# Iteration 5841: ACCURACY 0.7299 | F1 MACRO 0.7731 | F1 MICRO 0.7788
#                       precision    recall  f1-score   support
#
#           pornografi       0.94      0.92      0.93       362
#                 sara       0.72      0.61      0.66       237
#          radikalisme       0.78      0.80      0.79       235
# pencemaran_nama_baik       0.73      0.71      0.72       492
#
#            micro avg       0.79      0.76      0.78      1326
#            macro avg       0.79      0.76      0.77      1326
#         weighted avg       0.79      0.76      0.78      1326
#          samples avg       0.45      0.44      0.44      1326
#
# Nearest checkpoint: 6218
# Threshold: 19129.7578125
# Samples above threshold: 38
# Acquired samples: 200
# Sampling duration: 21.552570819854736 seconds
# New train size: 6041
# EPOCH 1 | LOSS: 4.662881851196289 | ACCURACY: 0.6553 | F1 MACRO: 0.5845 | F1 MICRO: 0.7007
# EPOCH 2 | LOSS: 4.290380001068115 | ACCURACY: 0.699 | F1 MACRO: 0.7552 | F1 MICRO: 0.7578
# EPOCH 3 | LOSS: 4.110511302947998 | ACCURACY: 0.7035 | F1 MACRO: 0.7528 | F1 MICRO: 0.7556
# EPOCH 4 | LOSS: 3.990227460861206 | ACCURACY: 0.701 | F1 MACRO: 0.7752 | F1 MICRO: 0.7701
# EPOCH 5 | LOSS: 3.8172247409820557 | ACCURACY: 0.7087 | F1 MACRO: 0.7583 | F1 MICRO: 0.7552
# EPOCH 6 | LOSS: 3.5763707160949707 | ACCURACY: 0.7209 | F1 MACRO: 0.7665 | F1 MICRO: 0.7726
# EPOCH 7 | LOSS: 3.4996228218078613 | ACCURACY: 0.7395 | F1 MACRO: 0.7731 | F1 MICRO: 0.7791
# EPOCH 8 | LOSS: 3.4552652835845947 | ACCURACY: 0.7383 | F1 MACRO: 0.7681 | F1 MICRO: 0.7797
# EPOCH 9 | LOSS: 3.446744203567505 | ACCURACY: 0.7241 | F1 MACRO: 0.7798 | F1 MICRO: 0.7811
# EPOCH 10 | LOSS: 3.4299495220184326 | ACCURACY: 0.7357 | F1 MACRO: 0.7779 | F1 MICRO: 0.7861
# Iteration 6041: ACCURACY 0.7357 | F1 MACRO 0.7779 | F1 MICRO 0.7861
#                       precision    recall  f1-score   support
#
#           pornografi       0.91      0.92      0.92       362
#                 sara       0.64      0.65      0.64       237
#          radikalisme       0.77      0.83      0.80       235
# pencemaran_nama_baik       0.74      0.77      0.75       492
#
#            micro avg       0.77      0.80      0.79      1326
#            macro avg       0.76      0.79      0.78      1326
#         weighted avg       0.77      0.80      0.79      1326
#          samples avg       0.46      0.46      0.45      1326
#
# Nearest checkpoint: 6218
# Threshold: 18821.42578125
# Samples above threshold: 18
# Acquired samples: 177
# Sampling duration: 21.709407806396484 seconds
# New train size: 6218
# EPOCH 1 | LOSS: 4.654281139373779 | ACCURACY: 0.6309 | F1 MACRO: 0.6298 | F1 MICRO: 0.6313
# EPOCH 2 | LOSS: 4.294371604919434 | ACCURACY: 0.6051 | F1 MACRO: 0.5322 | F1 MICRO: 0.5717
# EPOCH 3 | LOSS: 4.1179609298706055 | ACCURACY: 0.7158 | F1 MACRO: 0.7694 | F1 MICRO: 0.7752
# EPOCH 4 | LOSS: 3.9555842876434326 | ACCURACY: 0.6797 | F1 MACRO: 0.6576 | F1 MICRO: 0.6685
# EPOCH 5 | LOSS: 3.811283588409424 | ACCURACY: 0.7203 | F1 MACRO: 0.7693 | F1 MICRO: 0.7695
# EPOCH 6 | LOSS: 3.581202268600464 | ACCURACY: 0.737 | F1 MACRO: 0.7745 | F1 MICRO: 0.7777
# EPOCH 7 | LOSS: 3.4823176860809326 | ACCURACY: 0.726 | F1 MACRO: 0.7599 | F1 MICRO: 0.763
# EPOCH 8 | LOSS: 3.4586944580078125 | ACCURACY: 0.7305 | F1 MACRO: 0.7662 | F1 MICRO: 0.7697
# EPOCH 9 | LOSS: 3.4521889686584473 | ACCURACY: 0.7376 | F1 MACRO: 0.77 | F1 MICRO: 0.7728
# in second
# EPOCH 10 | LOSS: 3.363034248352051 | ACCURACY: 0.7434 | F1 MACRO: 0.7743 | F1 MICRO: 0.7789
# Iteration 6218: ACCURACY 0.737 | F1 MACRO 0.7745 | F1 MICRO 0.7777
#                       precision    recall  f1-score   support
#
#           pornografi       0.97      0.86      0.91       362
#                 sara       0.67      0.68      0.68       237
#          radikalisme       0.72      0.84      0.78       235
# pencemaran_nama_baik       0.73      0.75      0.74       492
#
#            micro avg       0.77      0.78      0.78      1326
#            macro avg       0.77      0.78      0.77      1326
#         weighted avg       0.78      0.78      0.78      1326
#          samples avg       0.44      0.44      0.44      1326
#
# Total sampling time: 457.87 seconds
# Total runtime: 8355.40578866005 seconds

# %% [markdown]
# ## RUN 4

# %%
active_learning(seeds[3], 3)
# Out:
# ===============================================
# TRIAL 4
# Random seed: 3
# label num 4
# tokenizer_config.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/229k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.53k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/498M [00:00<?, ?B/s]
# EPOCH 1 | LOSS: 6.219765663146973 | ACCURACY: 0.4367 | F1 MACRO: 0.0 | F1 MICRO: 0.0
# EPOCH 2 | LOSS: 4.743707656860352 | ACCURACY: 0.5357 | F1 MACRO: 0.186 | F1 MICRO: 0.2813
# EPOCH 3 | LOSS: 4.296788215637207 | ACCURACY: 0.6096 | F1 MACRO: 0.6242 | F1 MICRO: 0.6384
# EPOCH 4 | LOSS: 4.066462516784668 | ACCURACY: 0.5743 | F1 MACRO: 0.4803 | F1 MICRO: 0.5135
# EPOCH 5 | LOSS: 3.8680479526519775 | ACCURACY: 0.5691 | F1 MACRO: 0.4277 | F1 MICRO: 0.4762
# EPOCH 6 | LOSS: 3.6969592571258545 | ACCURACY: 0.6161 | F1 MACRO: 0.5791 | F1 MICRO: 0.6208
# in second
# EPOCH 7 | LOSS: 3.544543743133545 | ACCURACY: 0.6186 | F1 MACRO: 0.5869 | F1 MICRO: 0.6432
# in second
# EPOCH 8 | LOSS: 3.4865200519561768 | ACCURACY: 0.6289 | F1 MACRO: 0.6054 | F1 MICRO: 0.6497
# in second
# EPOCH 9 | LOSS: 3.4754347801208496 | ACCURACY: 0.6193 | F1 MACRO: 0.6114 | F1 MICRO: 0.6532
# in second
# EPOCH 10 | LOSS: 3.4525206089019775 | ACCURACY: 0.6264 | F1 MACRO: 0.6087 | F1 MICRO: 0.6483
# Iteration 388: ACCURACY 0.6096 | F1 MACRO 0.6242 | F1 MICRO 0.6384
#                       precision    recall  f1-score   support
#
#           pornografi       0.94      0.79      0.86       362
#                 sara       0.54      0.59      0.56       237
#          radikalisme       0.51      0.45      0.48       235
# pencemaran_nama_baik       0.64      0.56      0.60       492
#
#            micro avg       0.67      0.61      0.64      1326
#            macro avg       0.66      0.60      0.62      1326
#         weighted avg       0.68      0.61      0.64      1326
#          samples avg       0.32      0.33      0.31      1326
#
# Nearest checkpoint: 3886
# Threshold: 52880.91796875
# Samples above threshold: 583
# Acquired samples: 583
# Sampling duration: 22.145832777023315 seconds
# New train size: 971
# EPOCH 1 | LOSS: 5.258018493652344 | ACCURACY: 0.5119 | F1 MACRO: 0.6456 | F1 MICRO: 0.6448
# EPOCH 2 | LOSS: 4.407304286956787 | ACCURACY: 0.5961 | F1 MACRO: 0.6613 | F1 MICRO: 0.6828
# EPOCH 3 | LOSS: 4.048484802246094 | ACCURACY: 0.6032 | F1 MACRO: 0.4161 | F1 MICRO: 0.5024
# EPOCH 4 | LOSS: 3.8267710208892822 | ACCURACY: 0.6232 | F1 MACRO: 0.6428 | F1 MICRO: 0.6548
# EPOCH 5 | LOSS: 3.569143295288086 | ACCURACY: 0.6412 | F1 MACRO: 0.66 | F1 MICRO: 0.6594
# in second
# EPOCH 6 | LOSS: 3.2964749336242676 | ACCURACY: 0.6495 | F1 MACRO: 0.6914 | F1 MICRO: 0.6957
# in second
# EPOCH 7 | LOSS: 3.228764533996582 | ACCURACY: 0.6463 | F1 MACRO: 0.6957 | F1 MICRO: 0.6977
# in second
# EPOCH 8 | LOSS: 3.209226131439209 | ACCURACY: 0.6521 | F1 MACRO: 0.6961 | F1 MICRO: 0.7027
# in second
# EPOCH 9 | LOSS: 3.191720485687256 | ACCURACY: 0.6508 | F1 MACRO: 0.6972 | F1 MICRO: 0.7012
# in second
# EPOCH 10 | LOSS: 3.181898832321167 | ACCURACY: 0.6469 | F1 MACRO: 0.692 | F1 MICRO: 0.6985
# Iteration 971: ACCURACY 0.5961 | F1 MACRO 0.6613 | F1 MICRO 0.6828
#                       precision    recall  f1-score   support
#
#           pornografi       0.78      0.85      0.82       362
#                 sara       0.61      0.56      0.58       237
#          radikalisme       0.69      0.49      0.57       235
# pencemaran_nama_baik       0.60      0.76      0.67       492
#
#            micro avg       0.67      0.70      0.68      1326
#            macro avg       0.67      0.67      0.66      1326
#         weighted avg       0.67      0.70      0.68      1326
#          samples avg       0.37      0.38      0.36      1326
#
# Nearest checkpoint: 3886
# Threshold: 59951.91796875
# Samples above threshold: 525
# Acquired samples: 525
# Sampling duration: 22.21108055114746 seconds
# New train size: 1496
# EPOCH 1 | LOSS: 5.142078876495361 | ACCURACY: 0.5788 | F1 MACRO: 0.4924 | F1 MICRO: 0.5527
# EPOCH 2 | LOSS: 4.3580169677734375 | ACCURACY: 0.5878 | F1 MACRO: 0.5789 | F1 MICRO: 0.5704
# EPOCH 3 | LOSS: 4.1404619216918945 | ACCURACY: 0.6559 | F1 MACRO: 0.6505 | F1 MICRO: 0.6693
# EPOCH 4 | LOSS: 3.857466459274292 | ACCURACY: 0.6334 | F1 MACRO: 0.6731 | F1 MICRO: 0.6761
# EPOCH 5 | LOSS: 3.6746678352355957 | ACCURACY: 0.5569 | F1 MACRO: 0.6133 | F1 MICRO: 0.6028
# EPOCH 6 | LOSS: 3.522031307220459 | ACCURACY: 0.6624 | F1 MACRO: 0.7196 | F1 MICRO: 0.7245
# EPOCH 7 | LOSS: 3.2893309593200684 | ACCURACY: 0.6669 | F1 MACRO: 0.7264 | F1 MICRO: 0.7262
# EPOCH 8 | LOSS: 3.2494421005249023 | ACCURACY: 0.6637 | F1 MACRO: 0.7219 | F1 MICRO: 0.7279
# EPOCH 9 | LOSS: 3.2064425945281982 | ACCURACY: 0.6752 | F1 MACRO: 0.7245 | F1 MICRO: 0.7287
# EPOCH 10 | LOSS: 3.210353374481201 | ACCURACY: 0.674 | F1 MACRO: 0.7173 | F1 MICRO: 0.724
# Iteration 1496: ACCURACY 0.6752 | F1 MACRO 0.7245 | F1 MICRO 0.7287
#                       precision    recall  f1-score   support
#
#           pornografi       0.94      0.85      0.89       362
#                 sara       0.67      0.57      0.61       237
#          radikalisme       0.74      0.72      0.73       235
# pencemaran_nama_baik       0.68      0.66      0.67       492
#
#            micro avg       0.76      0.70      0.73      1326
#            macro avg       0.76      0.70      0.72      1326
#         weighted avg       0.76      0.70      0.73      1326
#          samples avg       0.40      0.40      0.39      1326
#
# Nearest checkpoint: 3886
# Threshold: 57812.16015625
# Samples above threshold: 473
# Acquired samples: 473
# Sampling duration: 21.98430371284485 seconds
# New train size: 1969
# EPOCH 1 | LOSS: 4.934264659881592 | ACCURACY: 0.5994 | F1 MACRO: 0.4027 | F1 MICRO: 0.52
# EPOCH 2 | LOSS: 4.276214599609375 | ACCURACY: 0.6373 | F1 MACRO: 0.6554 | F1 MICRO: 0.6658
# EPOCH 3 | LOSS: 4.005990982055664 | ACCURACY: 0.5942 | F1 MACRO: 0.5523 | F1 MICRO: 0.5931
# EPOCH 4 | LOSS: 3.830031394958496 | ACCURACY: 0.6682 | F1 MACRO: 0.6424 | F1 MICRO: 0.6646
# EPOCH 5 | LOSS: 3.6826364994049072 | ACCURACY: 0.6682 | F1 MACRO: 0.5946 | F1 MICRO: 0.6453
# in second
# EPOCH 6 | LOSS: 3.3767776489257812 | ACCURACY: 0.7093 | F1 MACRO: 0.7145 | F1 MICRO: 0.7233
# in second
# EPOCH 7 | LOSS: 3.3265380859375 | ACCURACY: 0.7087 | F1 MACRO: 0.719 | F1 MICRO: 0.7266
# in second
# EPOCH 8 | LOSS: 3.307891845703125 | ACCURACY: 0.7151 | F1 MACRO: 0.7369 | F1 MICRO: 0.7448
# in second
# EPOCH 9 | LOSS: 3.3012642860412598 | ACCURACY: 0.7158 | F1 MACRO: 0.7303 | F1 MICRO: 0.7376
# in second
# EPOCH 10 | LOSS: 3.277109384536743 | ACCURACY: 0.7125 | F1 MACRO: 0.7286 | F1 MICRO: 0.7366
# Iteration 1969: ACCURACY 0.6373 | F1 MACRO 0.6554 | F1 MICRO 0.6658
#                       precision    recall  f1-score   support
#
#           pornografi       0.93      0.81      0.87       362
#                 sara       0.66      0.46      0.54       237
#          radikalisme       0.78      0.53      0.63       235
# pencemaran_nama_baik       0.65      0.53      0.58       492
#
#            micro avg       0.76      0.60      0.67      1326
#            macro avg       0.75      0.58      0.66      1326
#         weighted avg       0.75      0.60      0.66      1326
#          samples avg       0.33      0.32      0.32      1326
#
# Nearest checkpoint: 3886
# Threshold: 54484.05078125
# Samples above threshold: 425
# Acquired samples: 425
# Sampling duration: 22.347647190093994 seconds
# New train size: 2394
# EPOCH 1 | LOSS: 4.919600486755371 | ACCURACY: 0.537 | F1 MACRO: 0.498 | F1 MICRO: 0.4961
# EPOCH 2 | LOSS: 4.377121448516846 | ACCURACY: 0.5878 | F1 MACRO: 0.2503 | F1 MICRO: 0.3776
# EPOCH 3 | LOSS: 4.092553615570068 | ACCURACY: 0.6206 | F1 MACRO: 0.6728 | F1 MICRO: 0.6812
# EPOCH 4 | LOSS: 3.8673319816589355 | ACCURACY: 0.6701 | F1 MACRO: 0.7104 | F1 MICRO: 0.7132
# EPOCH 5 | LOSS: 3.717038154602051 | ACCURACY: 0.6682 | F1 MACRO: 0.7479 | F1 MICRO: 0.7485
# EPOCH 6 | LOSS: 3.4965438842773438 | ACCURACY: 0.7138 | F1 MACRO: 0.7561 | F1 MICRO: 0.7616
# EPOCH 7 | LOSS: 3.4060089588165283 | ACCURACY: 0.7055 | F1 MACRO: 0.7356 | F1 MICRO: 0.7488
# EPOCH 8 | LOSS: 3.353236675262451 | ACCURACY: 0.7061 | F1 MACRO: 0.7672 | F1 MICRO: 0.7713
# EPOCH 9 | LOSS: 3.3510754108428955 | ACCURACY: 0.6939 | F1 MACRO: 0.7586 | F1 MICRO: 0.759
# EPOCH 10 | LOSS: 3.3356668949127197 | ACCURACY: 0.7003 | F1 MACRO: 0.7497 | F1 MICRO: 0.7526
# Iteration 2394: ACCURACY 0.7061 | F1 MACRO 0.7672 | F1 MICRO 0.7713
#                       precision    recall  f1-score   support
#
#           pornografi       0.95      0.86      0.90       362
#                 sara       0.60      0.74      0.67       237
#          radikalisme       0.74      0.77      0.76       235
# pencemaran_nama_baik       0.70      0.80      0.75       492
#
#            micro avg       0.75      0.80      0.77      1326
#            macro avg       0.75      0.79      0.77      1326
#         weighted avg       0.76      0.80      0.78      1326
#          samples avg       0.45      0.45      0.44      1326
#
# Nearest checkpoint: 3886
# Threshold: 51471.65625
# Samples above threshold: 383
# Acquired samples: 383
# Sampling duration: 22.031468629837036 seconds
# New train size: 2777
# EPOCH 1 | LOSS: 4.8867926597595215 | ACCURACY: 0.5961 | F1 MACRO: 0.6781 | F1 MICRO: 0.6687
# EPOCH 2 | LOSS: 4.402050018310547 | ACCURACY: 0.5961 | F1 MACRO: 0.4206 | F1 MICRO: 0.5077
# EPOCH 3 | LOSS: 4.190028190612793 | ACCURACY: 0.6797 | F1 MACRO: 0.6883 | F1 MICRO: 0.706
# EPOCH 4 | LOSS: 3.9655725955963135 | ACCURACY: 0.6399 | F1 MACRO: 0.6673 | F1 MICRO: 0.6584
# EPOCH 5 | LOSS: 3.800334930419922 | ACCURACY: 0.6913 | F1 MACRO: 0.7069 | F1 MICRO: 0.7247
# EPOCH 6 | LOSS: 3.5306007862091064 | ACCURACY: 0.7106 | F1 MACRO: 0.7514 | F1 MICRO: 0.7579
# EPOCH 7 | LOSS: 3.4588496685028076 | ACCURACY: 0.7035 | F1 MACRO: 0.7373 | F1 MICRO: 0.7497
# EPOCH 8 | LOSS: 3.4204132556915283 | ACCURACY: 0.7113 | F1 MACRO: 0.757 | F1 MICRO: 0.765
# EPOCH 9 | LOSS: 3.3974757194519043 | ACCURACY: 0.7093 | F1 MACRO: 0.7364 | F1 MICRO: 0.7512
# EPOCH 10 | LOSS: 3.393350601196289 | ACCURACY: 0.7093 | F1 MACRO: 0.7331 | F1 MICRO: 0.7425
# Iteration 2777: ACCURACY 0.7113 | F1 MACRO 0.757 | F1 MICRO 0.765
#                       precision    recall  f1-score   support
#
#           pornografi       0.95      0.87      0.91       362
#                 sara       0.65      0.60      0.62       237
#          radikalisme       0.75      0.78      0.77       235
# pencemaran_nama_baik       0.70      0.77      0.73       492
#
#            micro avg       0.76      0.77      0.77      1326
#            macro avg       0.76      0.76      0.76      1326
#         weighted avg       0.77      0.77      0.77      1326
#          samples avg       0.43      0.43      0.42      1326
#
# Nearest checkpoint: 3886
# Threshold: 49466.0
# Samples above threshold: 345
# Acquired samples: 345
# Sampling duration: 22.312913417816162 seconds
# New train size: 3122
# EPOCH 1 | LOSS: 4.874781608581543 | ACCURACY: 0.5241 | F1 MACRO: 0.2328 | F1 MICRO: 0.2704
# EPOCH 2 | LOSS: 4.438113212585449 | ACCURACY: 0.6045 | F1 MACRO: 0.6758 | F1 MICRO: 0.6802
# EPOCH 3 | LOSS: 4.250653266906738 | ACCURACY: 0.6785 | F1 MACRO: 0.6972 | F1 MICRO: 0.7171
# EPOCH 4 | LOSS: 3.95314359664917 | ACCURACY: 0.6553 | F1 MACRO: 0.6081 | F1 MICRO: 0.6476
# EPOCH 5 | LOSS: 3.8213369846343994 | ACCURACY: 0.6592 | F1 MACRO: 0.5887 | F1 MICRO: 0.6288
# EPOCH 6 | LOSS: 3.5731916427612305 | ACCURACY: 0.7035 | F1 MACRO: 0.7196 | F1 MICRO: 0.7401
# EPOCH 7 | LOSS: 3.464434862136841 | ACCURACY: 0.7035 | F1 MACRO: 0.7446 | F1 MICRO: 0.7536
# EPOCH 8 | LOSS: 3.4265427589416504 | ACCURACY: 0.7029 | F1 MACRO: 0.7699 | F1 MICRO: 0.7736
# EPOCH 9 | LOSS: 3.3798768520355225 | ACCURACY: 0.7113 | F1 MACRO: 0.731 | F1 MICRO: 0.7458
# EPOCH 10 | LOSS: 3.360872507095337 | ACCURACY: 0.7042 | F1 MACRO: 0.7474 | F1 MICRO: 0.7584
# Iteration 3122: ACCURACY 0.7029 | F1 MACRO 0.7699 | F1 MICRO 0.7736
#                       precision    recall  f1-score   support
#
#           pornografi       0.94      0.85      0.89       362
#                 sara       0.64      0.68      0.66       237
#          radikalisme       0.73      0.86      0.79       235
# pencemaran_nama_baik       0.73      0.76      0.74       492
#
#            micro avg       0.76      0.79      0.77      1326
#            macro avg       0.76      0.79      0.77      1326
#         weighted avg       0.77      0.79      0.78      1326
#          samples avg       0.44      0.44      0.43      1326
#
# Nearest checkpoint: 3886
# Threshold: 50167.8828125
# Samples above threshold: 310
# Acquired samples: 310
# Sampling duration: 21.95035719871521 seconds
# New train size: 3432
# EPOCH 1 | LOSS: 4.992053985595703 | ACCURACY: 0.4804 | F1 MACRO: 0.1155 | F1 MICRO: 0.1518
# EPOCH 2 | LOSS: 4.416704177856445 | ACCURACY: 0.5395 | F1 MACRO: 0.4874 | F1 MICRO: 0.5518
# EPOCH 3 | LOSS: 4.172987461090088 | ACCURACY: 0.6289 | F1 MACRO: 0.7479 | F1 MICRO: 0.744
# EPOCH 4 | LOSS: 4.011613845825195 | ACCURACY: 0.6746 | F1 MACRO: 0.6402 | F1 MICRO: 0.6873
# EPOCH 5 | LOSS: 3.8167879581451416 | ACCURACY: 0.7158 | F1 MACRO: 0.7609 | F1 MICRO: 0.763
# EPOCH 6 | LOSS: 3.578172445297241 | ACCURACY: 0.7125 | F1 MACRO: 0.7528 | F1 MICRO: 0.7616
# EPOCH 7 | LOSS: 3.4900004863739014 | ACCURACY: 0.7164 | F1 MACRO: 0.7532 | F1 MICRO: 0.7619
# EPOCH 8 | LOSS: 3.444018602371216 | ACCURACY: 0.7145 | F1 MACRO: 0.7469 | F1 MICRO: 0.7648
# EPOCH 9 | LOSS: 3.4258265495300293 | ACCURACY: 0.7042 | F1 MACRO: 0.7327 | F1 MICRO: 0.7396
# EPOCH 10 | LOSS: 3.414933204650879 | ACCURACY: 0.7042 | F1 MACRO: 0.7662 | F1 MICRO: 0.7693
# Iteration 3432: ACCURACY 0.7042 | F1 MACRO 0.7662 | F1 MICRO 0.7693
#                       precision    recall  f1-score   support
#
#           pornografi       0.95      0.87      0.91       362
#                 sara       0.66      0.67      0.67       237
#          radikalisme       0.78      0.74      0.76       235
# pencemaran_nama_baik       0.66      0.81      0.73       492
#
#            micro avg       0.75      0.79      0.77      1326
#            macro avg       0.76      0.77      0.77      1326
#         weighted avg       0.76      0.79      0.77      1326
#          samples avg       0.44      0.45      0.44      1326
#
# Nearest checkpoint: 3886
# Threshold: 49974.751953125
# Samples above threshold: 279
# Acquired samples: 279
# Sampling duration: 21.913061380386353 seconds
# New train size: 3711
# EPOCH 1 | LOSS: 4.82780647277832 | ACCURACY: 0.6084 | F1 MACRO: 0.6693 | F1 MICRO: 0.6755
# EPOCH 2 | LOSS: 4.357417583465576 | ACCURACY: 0.6444 | F1 MACRO: 0.6855 | F1 MICRO: 0.681
# EPOCH 3 | LOSS: 4.147179126739502 | ACCURACY: 0.6759 | F1 MACRO: 0.7462 | F1 MICRO: 0.7514
# EPOCH 4 | LOSS: 3.949486255645752 | ACCURACY: 0.7093 | F1 MACRO: 0.7269 | F1 MICRO: 0.7413
# EPOCH 5 | LOSS: 3.76826810836792 | ACCURACY: 0.7087 | F1 MACRO: 0.7175 | F1 MICRO: 0.7503
# EPOCH 6 | LOSS: 3.5316498279571533 | ACCURACY: 0.7286 | F1 MACRO: 0.7656 | F1 MICRO: 0.7711
# EPOCH 7 | LOSS: 3.4424378871917725 | ACCURACY: 0.7119 | F1 MACRO: 0.7492 | F1 MICRO: 0.762
# EPOCH 8 | LOSS: 3.399346351623535 | ACCURACY: 0.7196 | F1 MACRO: 0.7493 | F1 MICRO: 0.7568
# EPOCH 9 | LOSS: 3.3760907649993896 | ACCURACY: 0.7087 | F1 MACRO: 0.7556 | F1 MICRO: 0.7593
# in second
# EPOCH 10 | LOSS: 3.316380500793457 | ACCURACY: 0.717 | F1 MACRO: 0.7559 | F1 MICRO: 0.761
# Iteration 3711: ACCURACY 0.7286 | F1 MACRO 0.7656 | F1 MICRO 0.7711
#                       precision    recall  f1-score   support
#
#           pornografi       0.97      0.83      0.89       362
#                 sara       0.67      0.64      0.65       237
#          radikalisme       0.75      0.80      0.77       235
# pencemaran_nama_baik       0.75      0.73      0.74       492
#
#            micro avg       0.79      0.75      0.77      1326
#            macro avg       0.79      0.75      0.77      1326
#         weighted avg       0.80      0.75      0.77      1326
#          samples avg       0.43      0.42      0.42      1326
#
# Nearest checkpoint: 3886
# Threshold: 49068.38671875
# Samples above threshold: 251
# Acquired samples: 175
# Sampling duration: 22.073665142059326 seconds
# New train size: 3886
# EPOCH 1 | LOSS: 4.880813121795654 | ACCURACY: 0.6457 | F1 MACRO: 0.6227 | F1 MICRO: 0.6728
# EPOCH 2 | LOSS: 4.39247989654541 | ACCURACY: 0.6444 | F1 MACRO: 0.6978 | F1 MICRO: 0.7014
# EPOCH 3 | LOSS: 4.164914131164551 | ACCURACY: 0.6251 | F1 MACRO: 0.5346 | F1 MICRO: 0.6014
# EPOCH 4 | LOSS: 3.9815456867218018 | ACCURACY: 0.6881 | F1 MACRO: 0.7045 | F1 MICRO: 0.7162
# EPOCH 5 | LOSS: 3.8399510383605957 | ACCURACY: 0.6907 | F1 MACRO: 0.7322 | F1 MICRO: 0.7374
# EPOCH 6 | LOSS: 3.570216178894043 | ACCURACY: 0.7068 | F1 MACRO: 0.7118 | F1 MICRO: 0.7359
# EPOCH 7 | LOSS: 3.4582343101501465 | ACCURACY: 0.7158 | F1 MACRO: 0.7367 | F1 MICRO: 0.7497
# EPOCH 8 | LOSS: 3.444746732711792 | ACCURACY: 0.7177 | F1 MACRO: 0.7633 | F1 MICRO: 0.767
# EPOCH 9 | LOSS: 3.3980367183685303 | ACCURACY: 0.7254 | F1 MACRO: 0.7648 | F1 MICRO: 0.7704
# EPOCH 10 | LOSS: 3.4025604724884033 | ACCURACY: 0.7228 | F1 MACRO: 0.7487 | F1 MICRO: 0.7581
# Iteration 3886: ACCURACY 0.7254 | F1 MACRO 0.7648 | F1 MICRO 0.7704
#                       precision    recall  f1-score   support
#
#           pornografi       0.95      0.87      0.91       362
#                 sara       0.71      0.58      0.64       237
#          radikalisme       0.76      0.84      0.80       235
# pencemaran_nama_baik       0.75      0.69      0.72       492
#
#            micro avg       0.80      0.75      0.77      1326
#            macro avg       0.79      0.75      0.76      1326
#         weighted avg       0.80      0.75      0.77      1326
#          samples avg       0.43      0.42      0.42      1326
#
# Nearest checkpoint: 4663
# Threshold: 48834.85546875
# Samples above threshold: 234
# Acquired samples: 234
# Sampling duration: 22.02386212348938 seconds
# New train size: 4120
# EPOCH 1 | LOSS: 4.831272602081299 | ACCURACY: 0.6077 | F1 MACRO: 0.5538 | F1 MICRO: 0.6297
# EPOCH 2 | LOSS: 4.38761568069458 | ACCURACY: 0.6193 | F1 MACRO: 0.7143 | F1 MICRO: 0.7024
# EPOCH 3 | LOSS: 4.213118076324463 | ACCURACY: 0.6283 | F1 MACRO: 0.3928 | F1 MICRO: 0.5713
# EPOCH 4 | LOSS: 3.988086700439453 | ACCURACY: 0.7125 | F1 MACRO: 0.7602 | F1 MICRO: 0.7609
# EPOCH 5 | LOSS: 3.830195188522339 | ACCURACY: 0.7158 | F1 MACRO: 0.758 | F1 MICRO: 0.7645
# EPOCH 6 | LOSS: 3.6005735397338867 | ACCURACY: 0.7325 | F1 MACRO: 0.7639 | F1 MICRO: 0.7753
# EPOCH 7 | LOSS: 3.495784044265747 | ACCURACY: 0.726 | F1 MACRO: 0.7865 | F1 MICRO: 0.7863
# EPOCH 8 | LOSS: 3.4633090496063232 | ACCURACY: 0.7293 | F1 MACRO: 0.7369 | F1 MICRO: 0.7554
# EPOCH 9 | LOSS: 3.4378700256347656 | ACCURACY: 0.7299 | F1 MACRO: 0.7631 | F1 MICRO: 0.7679
# EPOCH 10 | LOSS: 3.421168327331543 | ACCURACY: 0.7267 | F1 MACRO: 0.7712 | F1 MICRO: 0.778
# Iteration 4120: ACCURACY 0.726 | F1 MACRO 0.7865 | F1 MICRO 0.7863
#                       precision    recall  f1-score   support
#
#           pornografi       0.94      0.88      0.91       362
#                 sara       0.68      0.72      0.70       237
#          radikalisme       0.75      0.86      0.80       235
# pencemaran_nama_baik       0.70      0.77      0.74       492
#
#            micro avg       0.77      0.81      0.79      1326
#            macro avg       0.77      0.81      0.79      1326
#         weighted avg       0.77      0.81      0.79      1326
#          samples avg       0.47      0.46      0.45      1326
#
# Nearest checkpoint: 4663
# Threshold: 51706.3203125
# Samples above threshold: 210
# Acquired samples: 210
# Sampling duration: 22.288044452667236 seconds
# New train size: 4330
# EPOCH 1 | LOSS: 4.810113906860352 | ACCURACY: 0.6881 | F1 MACRO: 0.7162 | F1 MICRO: 0.7257
# EPOCH 2 | LOSS: 4.375265598297119 | ACCURACY: 0.7164 | F1 MACRO: 0.7661 | F1 MICRO: 0.7727
# EPOCH 3 | LOSS: 4.148980617523193 | ACCURACY: 0.6785 | F1 MACRO: 0.6318 | F1 MICRO: 0.6816
# EPOCH 4 | LOSS: 3.9923672676086426 | ACCURACY: 0.7125 | F1 MACRO: 0.7434 | F1 MICRO: 0.7459
# EPOCH 5 | LOSS: 3.7818262577056885 | ACCURACY: 0.6875 | F1 MACRO: 0.7686 | F1 MICRO: 0.77
# in second
# EPOCH 6 | LOSS: 3.490408182144165 | ACCURACY: 0.7248 | F1 MACRO: 0.7555 | F1 MICRO: 0.7686
# in second
# EPOCH 7 | LOSS: 3.4657702445983887 | ACCURACY: 0.7241 | F1 MACRO: 0.7495 | F1 MICRO: 0.7609
# in second
# EPOCH 8 | LOSS: 3.458199977874756 | ACCURACY: 0.7222 | F1 MACRO: 0.7643 | F1 MICRO: 0.7704
# in second
# EPOCH 9 | LOSS: 3.4408340454101562 | ACCURACY: 0.7235 | F1 MACRO: 0.7541 | F1 MICRO: 0.7632
# in second
# EPOCH 10 | LOSS: 3.438558340072632 | ACCURACY: 0.7209 | F1 MACRO: 0.7489 | F1 MICRO: 0.7633
# Iteration 4330: ACCURACY 0.7164 | F1 MACRO 0.7661 | F1 MICRO 0.7727
#                       precision    recall  f1-score   support
#
#           pornografi       0.96      0.83      0.89       362
#                 sara       0.69      0.57      0.62       237
#          radikalisme       0.76      0.86      0.81       235
# pencemaran_nama_baik       0.68      0.81      0.74       492
#
#            micro avg       0.76      0.78      0.77      1326
#            macro avg       0.78      0.77      0.77      1326
#         weighted avg       0.78      0.78      0.77      1326
#          samples avg       0.45      0.44      0.44      1326
#
# Nearest checkpoint: 4663
# Threshold: 48296.62109375
# Samples above threshold: 189
# Acquired samples: 200
# Sampling duration: 21.963438272476196 seconds
# New train size: 4530
# EPOCH 1 | LOSS: 4.828698635101318 | ACCURACY: 0.6463 | F1 MACRO: 0.6391 | F1 MICRO: 0.6451
# EPOCH 2 | LOSS: 4.41123104095459 | ACCURACY: 0.6418 | F1 MACRO: 0.5614 | F1 MICRO: 0.678
# EPOCH 3 | LOSS: 4.222410202026367 | ACCURACY: 0.6129 | F1 MACRO: 0.4803 | F1 MICRO: 0.5992
# EPOCH 4 | LOSS: 4.067363739013672 | ACCURACY: 0.6418 | F1 MACRO: 0.698 | F1 MICRO: 0.708
# EPOCH 5 | LOSS: 3.856081962585449 | ACCURACY: 0.6508 | F1 MACRO: 0.6992 | F1 MICRO: 0.7055
# EPOCH 6 | LOSS: 3.662583351135254 | ACCURACY: 0.7293 | F1 MACRO: 0.7681 | F1 MICRO: 0.7791
# EPOCH 7 | LOSS: 3.513113260269165 | ACCURACY: 0.717 | F1 MACRO: 0.7753 | F1 MICRO: 0.7753
# EPOCH 8 | LOSS: 3.4672603607177734 | ACCURACY: 0.735 | F1 MACRO: 0.7802 | F1 MICRO: 0.7889
# EPOCH 9 | LOSS: 3.445146322250366 | ACCURACY: 0.7338 | F1 MACRO: 0.7805 | F1 MICRO: 0.7865
# EPOCH 10 | LOSS: 3.425670623779297 | ACCURACY: 0.7473 | F1 MACRO: 0.7763 | F1 MICRO: 0.7866
# Iteration 4530: ACCURACY 0.735 | F1 MACRO 0.7802 | F1 MICRO 0.7889
#                       precision    recall  f1-score   support
#
#           pornografi       0.95      0.89      0.92       362
#                 sara       0.71      0.62      0.66       237
#          radikalisme       0.76      0.81      0.78       235
# pencemaran_nama_baik       0.72      0.80      0.76       492
#
#            micro avg       0.79      0.79      0.79      1326
#            macro avg       0.79      0.78      0.78      1326
#         weighted avg       0.79      0.79      0.79      1326
#          samples avg       0.45      0.45      0.44      1326
#
# Nearest checkpoint: 4663
# Threshold: 47903.046875
# Samples above threshold: 169
# Acquired samples: 133
# Sampling duration: 22.363473176956177 seconds
# New train size: 4663
# EPOCH 1 | LOSS: 4.792766094207764 | ACCURACY: 0.6437 | F1 MACRO: 0.605 | F1 MICRO: 0.6422
# EPOCH 2 | LOSS: 4.405645370483398 | ACCURACY: 0.6592 | F1 MACRO: 0.6015 | F1 MICRO: 0.6972
# EPOCH 3 | LOSS: 4.181818008422852 | ACCURACY: 0.6675 | F1 MACRO: 0.5097 | F1 MICRO: 0.6168
# EPOCH 4 | LOSS: 3.9718639850616455 | ACCURACY: 0.6688 | F1 MACRO: 0.7076 | F1 MICRO: 0.7108
# EPOCH 5 | LOSS: 3.860522508621216 | ACCURACY: 0.6881 | F1 MACRO: 0.7558 | F1 MICRO: 0.7606
# EPOCH 6 | LOSS: 3.5987982749938965 | ACCURACY: 0.7305 | F1 MACRO: 0.7555 | F1 MICRO: 0.766
# EPOCH 7 | LOSS: 3.489938974380493 | ACCURACY: 0.7222 | F1 MACRO: 0.7512 | F1 MICRO: 0.7611
# EPOCH 8 | LOSS: 3.4490418434143066 | ACCURACY: 0.7312 | F1 MACRO: 0.778 | F1 MICRO: 0.7826
# EPOCH 9 | LOSS: 3.4299447536468506 | ACCURACY: 0.7273 | F1 MACRO: 0.7716 | F1 MICRO: 0.7768
# EPOCH 10 | LOSS: 3.4213314056396484 | ACCURACY: 0.7151 | F1 MACRO: 0.78 | F1 MICRO: 0.7809
# Iteration 4663: ACCURACY 0.7312 | F1 MACRO 0.778 | F1 MICRO 0.7826
#                       precision    recall  f1-score   support
#
#           pornografi       0.96      0.89      0.92       362
#                 sara       0.72      0.65      0.69       237
#          radikalisme       0.75      0.79      0.77       235
# pencemaran_nama_baik       0.75      0.72      0.73       492
#
#            micro avg       0.80      0.77      0.78      1326
#            macro avg       0.79      0.76      0.78      1326
#         weighted avg       0.80      0.77      0.78      1326
#          samples avg       0.43      0.43      0.42      1326
#
# Nearest checkpoint: 5441
# Threshold: 47492.3359375
# Samples above threshold: 156
# Acquired samples: 200
# Sampling duration: 22.060805082321167 seconds
# New train size: 4863
# EPOCH 1 | LOSS: 4.841867923736572 | ACCURACY: 0.6129 | F1 MACRO: 0.2829 | F1 MICRO: 0.4385
# EPOCH 2 | LOSS: 4.385927677154541 | ACCURACY: 0.6084 | F1 MACRO: 0.4918 | F1 MICRO: 0.5786
# EPOCH 3 | LOSS: 4.199343681335449 | ACCURACY: 0.6965 | F1 MACRO: 0.7059 | F1 MICRO: 0.7177
# EPOCH 4 | LOSS: 3.999497652053833 | ACCURACY: 0.7003 | F1 MACRO: 0.7491 | F1 MICRO: 0.7576
# EPOCH 5 | LOSS: 3.8431806564331055 | ACCURACY: 0.7305 | F1 MACRO: 0.7748 | F1 MICRO: 0.7781
# EPOCH 6 | LOSS: 3.6248574256896973 | ACCURACY: 0.7305 | F1 MACRO: 0.7567 | F1 MICRO: 0.7708
# EPOCH 7 | LOSS: 3.4995124340057373 | ACCURACY: 0.7305 | F1 MACRO: 0.7815 | F1 MICRO: 0.7824
# EPOCH 8 | LOSS: 3.4703457355499268 | ACCURACY: 0.7479 | F1 MACRO: 0.7831 | F1 MICRO: 0.7901
# EPOCH 9 | LOSS: 3.449753999710083 | ACCURACY: 0.7363 | F1 MACRO: 0.7688 | F1 MICRO: 0.7782
# EPOCH 10 | LOSS: 3.4386837482452393 | ACCURACY: 0.7299 | F1 MACRO: 0.7559 | F1 MICRO: 0.7647
# Iteration 4863: ACCURACY 0.7479 | F1 MACRO 0.7831 | F1 MICRO 0.7901
#                       precision    recall  f1-score   support
#
#           pornografi       0.96      0.91      0.93       362
#                 sara       0.70      0.64      0.67       237
#          radikalisme       0.78      0.80      0.79       235
# pencemaran_nama_baik       0.77      0.72      0.74       492
#
#            micro avg       0.81      0.77      0.79      1326
#            macro avg       0.80      0.77      0.78      1326
#         weighted avg       0.81      0.77      0.79      1326
#          samples avg       0.45      0.44      0.44      1326
#
# Nearest checkpoint: 5441
# Threshold: 46912.70703125
# Samples above threshold: 136
# Acquired samples: 200
# Sampling duration: 22.074682474136353 seconds
# New train size: 5063
# EPOCH 1 | LOSS: 4.829227924346924 | ACCURACY: 0.6051 | F1 MACRO: 0.338 | F1 MICRO: 0.4956
# EPOCH 2 | LOSS: 4.44722318649292 | ACCURACY: 0.6277 | F1 MACRO: 0.6125 | F1 MICRO: 0.6283
# EPOCH 3 | LOSS: 4.24687385559082 | ACCURACY: 0.7016 | F1 MACRO: 0.7571 | F1 MICRO: 0.77
# EPOCH 4 | LOSS: 4.116094589233398 | ACCURACY: 0.701 | F1 MACRO: 0.6909 | F1 MICRO: 0.7191
# EPOCH 5 | LOSS: 3.943359851837158 | ACCURACY: 0.6785 | F1 MACRO: 0.7111 | F1 MICRO: 0.717
# EPOCH 6 | LOSS: 3.6778688430786133 | ACCURACY: 0.7376 | F1 MACRO: 0.7679 | F1 MICRO: 0.7757
# EPOCH 7 | LOSS: 3.564516305923462 | ACCURACY: 0.7293 | F1 MACRO: 0.7813 | F1 MICRO: 0.7875
# EPOCH 8 | LOSS: 3.511284828186035 | ACCURACY: 0.7383 | F1 MACRO: 0.7945 | F1 MICRO: 0.798
# EPOCH 9 | LOSS: 3.4853525161743164 | ACCURACY: 0.7402 | F1 MACRO: 0.7879 | F1 MICRO: 0.7913
# EPOCH 10 | LOSS: 3.4716262817382812 | ACCURACY: 0.7318 | F1 MACRO: 0.7778 | F1 MICRO: 0.7842
# Iteration 5063: ACCURACY 0.7383 | F1 MACRO 0.7945 | F1 MICRO 0.798
#                       precision    recall  f1-score   support
#
#           pornografi       0.90      0.93      0.92       362
#                 sara       0.67      0.73      0.70       237
#          radikalisme       0.74      0.88      0.80       235
# pencemaran_nama_baik       0.73      0.79      0.76       492
#
#            micro avg       0.76      0.83      0.80      1326
#            macro avg       0.76      0.83      0.79      1326
#         weighted avg       0.77      0.83      0.80      1326
#          samples avg       0.47      0.47      0.46      1326
#
# Nearest checkpoint: 5441
# Threshold: 46345.828125
# Samples above threshold: 116
# Acquired samples: 200
# Sampling duration: 22.019434213638306 seconds
# New train size: 5263
# EPOCH 1 | LOSS: 4.892819404602051 | ACCURACY: 0.5987 | F1 MACRO: 0.4634 | F1 MICRO: 0.5098
# EPOCH 2 | LOSS: 4.420279026031494 | ACCURACY: 0.7087 | F1 MACRO: 0.752 | F1 MICRO: 0.7653
# EPOCH 3 | LOSS: 4.214577674865723 | ACCURACY: 0.6913 | F1 MACRO: 0.749 | F1 MICRO: 0.7589
# EPOCH 4 | LOSS: 4.091884136199951 | ACCURACY: 0.6958 | F1 MACRO: 0.738 | F1 MICRO: 0.7351
# EPOCH 5 | LOSS: 3.916627883911133 | ACCURACY: 0.7228 | F1 MACRO: 0.7465 | F1 MICRO: 0.7516
# in second
# EPOCH 6 | LOSS: 3.549917221069336 | ACCURACY: 0.7331 | F1 MACRO: 0.7618 | F1 MICRO: 0.7721
# in second
# EPOCH 7 | LOSS: 3.5324926376342773 | ACCURACY: 0.7395 | F1 MACRO: 0.7607 | F1 MICRO: 0.7698
# in second
# EPOCH 8 | LOSS: 3.5163605213165283 | ACCURACY: 0.7389 | F1 MACRO: 0.7718 | F1 MICRO: 0.778
# in second
# EPOCH 9 | LOSS: 3.518843412399292 | ACCURACY: 0.7305 | F1 MACRO: 0.7674 | F1 MICRO: 0.7734
# in second
# EPOCH 10 | LOSS: 3.5115325450897217 | ACCURACY: 0.7357 | F1 MACRO: 0.7694 | F1 MICRO: 0.7769
# Iteration 5263: ACCURACY 0.7087 | F1 MACRO 0.752 | F1 MICRO 0.7653
#                       precision    recall  f1-score   support
#
#           pornografi       0.88      0.92      0.90       362
#                 sara       0.71      0.53      0.61       237
#          radikalisme       0.78      0.77      0.77       235
# pencemaran_nama_baik       0.69      0.78      0.73       492
#
#            micro avg       0.76      0.77      0.77      1326
#            macro avg       0.76      0.75      0.75      1326
#         weighted avg       0.76      0.77      0.76      1326
#          samples avg       0.44      0.44      0.43      1326
#
# Nearest checkpoint: 5441
# Threshold: 19675.7890625
# Samples above threshold: 96
# Acquired samples: 178
# Sampling duration: 22.113210439682007 seconds
# New train size: 5441
# EPOCH 1 | LOSS: 4.762179374694824 | ACCURACY: 0.4624 | F1 MACRO: 0.3602 | F1 MICRO: 0.3367
# EPOCH 2 | LOSS: 4.401912689208984 | ACCURACY: 0.6514 | F1 MACRO: 0.7509 | F1 MICRO: 0.7515
# EPOCH 3 | LOSS: 4.220484256744385 | ACCURACY: 0.6283 | F1 MACRO: 0.3344 | F1 MICRO: 0.4787
# EPOCH 4 | LOSS: 4.029810428619385 | ACCURACY: 0.7273 | F1 MACRO: 0.7537 | F1 MICRO: 0.7596
# EPOCH 5 | LOSS: 3.9480152130126953 | ACCURACY: 0.6791 | F1 MACRO: 0.7171 | F1 MICRO: 0.7155
# EPOCH 6 | LOSS: 3.6342945098876953 | ACCURACY: 0.7441 | F1 MACRO: 0.788 | F1 MICRO: 0.7958
# EPOCH 7 | LOSS: 3.5116846561431885 | ACCURACY: 0.7035 | F1 MACRO: 0.7364 | F1 MICRO: 0.7393
# EPOCH 8 | LOSS: 3.481053352355957 | ACCURACY: 0.7305 | F1 MACRO: 0.7776 | F1 MICRO: 0.7788
# EPOCH 9 | LOSS: 3.499906539916992 | ACCURACY: 0.726 | F1 MACRO: 0.7815 | F1 MICRO: 0.7865
# in second
# EPOCH 10 | LOSS: 3.3762876987457275 | ACCURACY: 0.7312 | F1 MACRO: 0.7707 | F1 MICRO: 0.7816
# Iteration 5441: ACCURACY 0.7441 | F1 MACRO 0.788 | F1 MICRO 0.7958
#                       precision    recall  f1-score   support
#
#           pornografi       0.93      0.91      0.92       362
#                 sara       0.69      0.62      0.65       237
#          radikalisme       0.79      0.85      0.82       235
# pencemaran_nama_baik       0.74      0.78      0.76       492
#
#            micro avg       0.79      0.80      0.80      1326
#            macro avg       0.79      0.79      0.79      1326
#         weighted avg       0.79      0.80      0.80      1326
#          samples avg       0.47      0.46      0.46      1326
#
# Nearest checkpoint: 6218
# Threshold: 19493.2109375
# Samples above threshold: 78
# Acquired samples: 200
# Sampling duration: 21.98098063468933 seconds
# New train size: 5641
# EPOCH 1 | LOSS: 4.76677131652832 | ACCURACY: 0.6643 | F1 MACRO: 0.7452 | F1 MICRO: 0.7415
# EPOCH 2 | LOSS: 4.370500087738037 | ACCURACY: 0.6932 | F1 MACRO: 0.7147 | F1 MICRO: 0.7151
# EPOCH 3 | LOSS: 4.2002081871032715 | ACCURACY: 0.6733 | F1 MACRO: 0.726 | F1 MICRO: 0.7465
# EPOCH 4 | LOSS: 4.01611328125 | ACCURACY: 0.7151 | F1 MACRO: 0.7788 | F1 MICRO: 0.7791
# EPOCH 5 | LOSS: 3.8526628017425537 | ACCURACY: 0.737 | F1 MACRO: 0.7721 | F1 MICRO: 0.7775
# EPOCH 6 | LOSS: 3.611801862716675 | ACCURACY: 0.7293 | F1 MACRO: 0.7713 | F1 MICRO: 0.773
# EPOCH 7 | LOSS: 3.5142078399658203 | ACCURACY: 0.7203 | F1 MACRO: 0.7825 | F1 MICRO: 0.7881
# EPOCH 8 | LOSS: 3.483207941055298 | ACCURACY: 0.728 | F1 MACRO: 0.766 | F1 MICRO: 0.773
# EPOCH 9 | LOSS: 3.4736247062683105 | ACCURACY: 0.7466 | F1 MACRO: 0.7808 | F1 MICRO: 0.7901
# EPOCH 10 | LOSS: 3.4572978019714355 | ACCURACY: 0.7344 | F1 MACRO: 0.7767 | F1 MICRO: 0.783
# Iteration 5641: ACCURACY 0.7466 | F1 MACRO 0.7808 | F1 MICRO 0.7901
#                       precision    recall  f1-score   support
#
#           pornografi       0.96      0.91      0.93       362
#                 sara       0.72      0.59      0.65       237
#          radikalisme       0.78      0.81      0.79       235
# pencemaran_nama_baik       0.75      0.74      0.75       492
#
#            micro avg       0.81      0.77      0.79      1326
#            macro avg       0.80      0.76      0.78      1326
#         weighted avg       0.81      0.77      0.79      1326
#          samples avg       0.45      0.44      0.44      1326
#
# Nearest checkpoint: 6218
# Threshold: 19408.921875
# Samples above threshold: 58
# Acquired samples: 200
# Sampling duration: 22.212620973587036 seconds
# New train size: 5841
# EPOCH 1 | LOSS: 4.7593994140625 | ACCURACY: 0.5498 | F1 MACRO: 0.4288 | F1 MICRO: 0.4878
# EPOCH 2 | LOSS: 4.318914890289307 | ACCURACY: 0.7106 | F1 MACRO: 0.7482 | F1 MICRO: 0.7496
# EPOCH 3 | LOSS: 4.183625221252441 | ACCURACY: 0.6617 | F1 MACRO: 0.5023 | F1 MICRO: 0.6174
# EPOCH 4 | LOSS: 4.004508972167969 | ACCURACY: 0.6006 | F1 MACRO: 0.5085 | F1 MICRO: 0.5472
# EPOCH 5 | LOSS: 3.8913936614990234 | ACCURACY: 0.681 | F1 MACRO: 0.6805 | F1 MICRO: 0.6898
# in second
# EPOCH 6 | LOSS: 3.520838975906372 | ACCURACY: 0.7299 | F1 MACRO: 0.763 | F1 MICRO: 0.7696
# in second
# EPOCH 7 | LOSS: 3.500199317932129 | ACCURACY: 0.7273 | F1 MACRO: 0.7544 | F1 MICRO: 0.7578
# in second
# EPOCH 8 | LOSS: 3.4917311668395996 | ACCURACY: 0.7338 | F1 MACRO: 0.7646 | F1 MICRO: 0.7708
# in second
# EPOCH 9 | LOSS: 3.488069772720337 | ACCURACY: 0.7325 | F1 MACRO: 0.7637 | F1 MICRO: 0.7727
# in second
# EPOCH 10 | LOSS: 3.4832663536071777 | ACCURACY: 0.7338 | F1 MACRO: 0.7684 | F1 MICRO: 0.7732
# Iteration 5841: ACCURACY 0.7106 | F1 MACRO 0.7482 | F1 MICRO 0.7496
#                       precision    recall  f1-score   support
#
#           pornografi       0.99      0.78      0.87       362
#                 sara       0.72      0.55      0.62       237
#          radikalisme       0.77      0.87      0.82       235
# pencemaran_nama_baik       0.79      0.60      0.68       492
#
#            micro avg       0.82      0.69      0.75      1326
#            macro avg       0.82      0.70      0.75      1326
#         weighted avg       0.83      0.69      0.75      1326
#          samples avg       0.40      0.39      0.39      1326
#
# Nearest checkpoint: 6218
# Threshold: 19107.369140625
# Samples above threshold: 38
# Acquired samples: 200
# Sampling duration: 21.94110941886902 seconds
# New train size: 6041
# EPOCH 1 | LOSS: 4.658466815948486 | ACCURACY: 0.69 | F1 MACRO: 0.7403 | F1 MICRO: 0.7537
# EPOCH 2 | LOSS: 4.298249244689941 | ACCURACY: 0.6534 | F1 MACRO: 0.5792 | F1 MICRO: 0.6966
# EPOCH 3 | LOSS: 4.111623287200928 | ACCURACY: 0.683 | F1 MACRO: 0.6271 | F1 MICRO: 0.7077
# EPOCH 4 | LOSS: 3.9502131938934326 | ACCURACY: 0.726 | F1 MACRO: 0.7526 | F1 MICRO: 0.7686
# EPOCH 5 | LOSS: 3.8315112590789795 | ACCURACY: 0.7074 | F1 MACRO: 0.7468 | F1 MICRO: 0.758
# EPOCH 6 | LOSS: 3.5825693607330322 | ACCURACY: 0.728 | F1 MACRO: 0.7761 | F1 MICRO: 0.7791
# EPOCH 7 | LOSS: 3.481318712234497 | ACCURACY: 0.735 | F1 MACRO: 0.7701 | F1 MICRO: 0.7788
# EPOCH 8 | LOSS: 3.4705328941345215 | ACCURACY: 0.7511 | F1 MACRO: 0.7746 | F1 MICRO: 0.788
# EPOCH 9 | LOSS: 3.4323503971099854 | ACCURACY: 0.7479 | F1 MACRO: 0.7938 | F1 MICRO: 0.7999
# EPOCH 10 | LOSS: 3.4330849647521973 | ACCURACY: 0.7531 | F1 MACRO: 0.7809 | F1 MICRO: 0.7914
# Iteration 6041: ACCURACY 0.7479 | F1 MACRO 0.7938 | F1 MICRO 0.7999
#                       precision    recall  f1-score   support
#
#           pornografi       0.95      0.92      0.94       362
#                 sara       0.65      0.75      0.69       237
#          radikalisme       0.77      0.78      0.78       235
# pencemaran_nama_baik       0.74      0.80      0.77       492
#
#            micro avg       0.78      0.82      0.80      1326
#            macro avg       0.78      0.81      0.79      1326
#         weighted avg       0.78      0.82      0.80      1326
#          samples avg       0.47      0.47      0.46      1326
#
# Nearest checkpoint: 6218
# Threshold: 18788.4140625
# Samples above threshold: 18
# Acquired samples: 177
# Sampling duration: 22.094160318374634 seconds
# New train size: 6218
# EPOCH 1 | LOSS: 4.7463178634643555 | ACCURACY: 0.6225 | F1 MACRO: 0.408 | F1 MICRO: 0.4992
# EPOCH 2 | LOSS: 4.305266857147217 | ACCURACY: 0.6508 | F1 MACRO: 0.5109 | F1 MICRO: 0.6514
# EPOCH 3 | LOSS: 4.14536190032959 | ACCURACY: 0.692 | F1 MACRO: 0.7266 | F1 MICRO: 0.7505
# EPOCH 4 | LOSS: 4.000802516937256 | ACCURACY: 0.6669 | F1 MACRO: 0.6501 | F1 MICRO: 0.6866
# EPOCH 5 | LOSS: 3.847696304321289 | ACCURACY: 0.7068 | F1 MACRO: 0.7608 | F1 MICRO: 0.7648
# EPOCH 6 | LOSS: 3.6200737953186035 | ACCURACY: 0.726 | F1 MACRO: 0.7686 | F1 MICRO: 0.7787
# EPOCH 7 | LOSS: 3.515207529067993 | ACCURACY: 0.7524 | F1 MACRO: 0.7709 | F1 MICRO: 0.7833
# EPOCH 8 | LOSS: 3.4812121391296387 | ACCURACY: 0.7408 | F1 MACRO: 0.7732 | F1 MICRO: 0.7804
# EPOCH 9 | LOSS: 3.452638626098633 | ACCURACY: 0.7113 | F1 MACRO: 0.7537 | F1 MICRO: 0.7699
# EPOCH 10 | LOSS: 3.4452919960021973 | ACCURACY: 0.7248 | F1 MACRO: 0.7594 | F1 MICRO: 0.7691
# Iteration 6218: ACCURACY 0.7524 | F1 MACRO 0.7709 | F1 MICRO 0.7833
#                       precision    recall  f1-score   support
#
#           pornografi       0.96      0.90      0.93       362
#                 sara       0.65      0.58      0.61       237
#          radikalisme       0.80      0.78      0.79       235
# pencemaran_nama_baik       0.79      0.72      0.75       492
#
#            micro avg       0.81      0.75      0.78      1326
#            macro avg       0.80      0.75      0.77      1326
#         weighted avg       0.81      0.75      0.78      1326
#          samples avg       0.44      0.43      0.43      1326
#
# Total sampling time: 464.11 seconds
# Total runtime: 8405.583680152893 seconds

# %% [markdown]
# ## RUN 5

# %%
active_learning(seeds[4], 4)
# Out:
# ===============================================
# TRIAL 5
# Random seed: 94
# label num 4
# EPOCH 1 | LOSS: 6.286500930786133 | ACCURACY: 0.4476 | F1 MACRO: 0.0224 | F1 MICRO: 0.0253
# EPOCH 2 | LOSS: 4.7250075340271 | ACCURACY: 0.5518 | F1 MACRO: 0.1887 | F1 MICRO: 0.2844
# EPOCH 3 | LOSS: 4.3939738273620605 | ACCURACY: 0.5698 | F1 MACRO: 0.3692 | F1 MICRO: 0.4232
# EPOCH 4 | LOSS: 4.095714092254639 | ACCURACY: 0.627 | F1 MACRO: 0.6263 | F1 MICRO: 0.6414
# EPOCH 5 | LOSS: 3.7472774982452393 | ACCURACY: 0.6437 | F1 MACRO: 0.6205 | F1 MICRO: 0.6433
# EPOCH 6 | LOSS: 3.640009880065918 | ACCURACY: 0.6559 | F1 MACRO: 0.6721 | F1 MICRO: 0.6768
# EPOCH 7 | LOSS: 3.5869317054748535 | ACCURACY: 0.6399 | F1 MACRO: 0.6607 | F1 MICRO: 0.6791
# EPOCH 8 | LOSS: 3.512850284576416 | ACCURACY: 0.6521 | F1 MACRO: 0.6439 | F1 MICRO: 0.6524
# EPOCH 9 | LOSS: 3.4917056560516357 | ACCURACY: 0.6572 | F1 MACRO: 0.6886 | F1 MICRO: 0.6975
# EPOCH 10 | LOSS: 3.452946662902832 | ACCURACY: 0.6534 | F1 MACRO: 0.6738 | F1 MICRO: 0.6875
# Iteration 388: ACCURACY 0.6572 | F1 MACRO 0.6886 | F1 MICRO 0.6975
#                       precision    recall  f1-score   support
#
#           pornografi       0.91      0.81      0.86       362
#                 sara       0.63      0.49      0.55       237
#          radikalisme       0.75      0.66      0.70       235
# pencemaran_nama_baik       0.69      0.60      0.64       492
#
#            micro avg       0.76      0.65      0.70      1326
#            macro avg       0.75      0.64      0.69      1326
#         weighted avg       0.75      0.65      0.70      1326
#          samples avg       0.38      0.37      0.36      1326
#
# Nearest checkpoint: 3886
# Threshold: 52697.8359375
# Samples above threshold: 583
# Acquired samples: 583
# Sampling duration: 22.16231369972229 seconds
# New train size: 971
# EPOCH 1 | LOSS: 5.1342267990112305 | ACCURACY: 0.5228 | F1 MACRO: 0.4874 | F1 MICRO: 0.4806
# EPOCH 2 | LOSS: 4.316222190856934 | ACCURACY: 0.6219 | F1 MACRO: 0.5853 | F1 MICRO: 0.6247
# EPOCH 3 | LOSS: 3.877727746963501 | ACCURACY: 0.6354 | F1 MACRO: 0.6573 | F1 MICRO: 0.6633
# EPOCH 4 | LOSS: 3.611327648162842 | ACCURACY: 0.6534 | F1 MACRO: 0.6769 | F1 MICRO: 0.6777
# EPOCH 5 | LOSS: 3.4503989219665527 | ACCURACY: 0.6289 | F1 MACRO: 0.6985 | F1 MICRO: 0.7038
# EPOCH 6 | LOSS: 3.3087518215179443 | ACCURACY: 0.6862 | F1 MACRO: 0.7356 | F1 MICRO: 0.7384
# EPOCH 7 | LOSS: 3.1716530323028564 | ACCURACY: 0.6797 | F1 MACRO: 0.7296 | F1 MICRO: 0.7278
# EPOCH 8 | LOSS: 3.161492109298706 | ACCURACY: 0.692 | F1 MACRO: 0.7211 | F1 MICRO: 0.7235
# EPOCH 9 | LOSS: 3.1351675987243652 | ACCURACY: 0.681 | F1 MACRO: 0.7264 | F1 MICRO: 0.7271
# in second
# EPOCH 10 | LOSS: 3.0766968727111816 | ACCURACY: 0.6894 | F1 MACRO: 0.7253 | F1 MICRO: 0.7284
# Iteration 971: ACCURACY 0.6862 | F1 MACRO 0.7356 | F1 MICRO 0.7384
#                       precision    recall  f1-score   support
#
#           pornografi       0.92      0.83      0.87       362
#                 sara       0.68      0.57      0.62       237
#          radikalisme       0.75      0.80      0.77       235
# pencemaran_nama_baik       0.71      0.65      0.68       492
#
#            micro avg       0.77      0.71      0.74      1326
#            macro avg       0.76      0.71      0.74      1326
#         weighted avg       0.77      0.71      0.74      1326
#          samples avg       0.39      0.40      0.39      1326
#
# Nearest checkpoint: 3886
# Threshold: 61226.73046875
# Samples above threshold: 525
# Acquired samples: 525
# Sampling duration: 22.458771467208862 seconds
# New train size: 1496
# EPOCH 1 | LOSS: 4.969052314758301 | ACCURACY: 0.6553 | F1 MACRO: 0.699 | F1 MICRO: 0.7055
# EPOCH 2 | LOSS: 4.346345901489258 | ACCURACY: 0.6096 | F1 MACRO: 0.7167 | F1 MICRO: 0.7209
# EPOCH 3 | LOSS: 4.101977825164795 | ACCURACY: 0.6463 | F1 MACRO: 0.6795 | F1 MICRO: 0.684
# EPOCH 4 | LOSS: 3.8025076389312744 | ACCURACY: 0.6399 | F1 MACRO: 0.5975 | F1 MICRO: 0.6121
# EPOCH 5 | LOSS: 3.6086251735687256 | ACCURACY: 0.683 | F1 MACRO: 0.7307 | F1 MICRO: 0.729
# EPOCH 6 | LOSS: 3.385913133621216 | ACCURACY: 0.7023 | F1 MACRO: 0.713 | F1 MICRO: 0.7255
# EPOCH 7 | LOSS: 3.2843596935272217 | ACCURACY: 0.6945 | F1 MACRO: 0.6987 | F1 MICRO: 0.7041
# EPOCH 8 | LOSS: 3.251325845718384 | ACCURACY: 0.6965 | F1 MACRO: 0.7035 | F1 MICRO: 0.7127
# in second
# EPOCH 9 | LOSS: 3.175661087036133 | ACCURACY: 0.6965 | F1 MACRO: 0.7095 | F1 MICRO: 0.7178
# in second
# EPOCH 10 | LOSS: 3.1640329360961914 | ACCURACY: 0.6932 | F1 MACRO: 0.704 | F1 MICRO: 0.7147
# Iteration 1496: ACCURACY 0.683 | F1 MACRO 0.7307 | F1 MICRO 0.729
#                       precision    recall  f1-score   support
#
#           pornografi       0.98      0.72      0.83       362
#                 sara       0.64      0.62      0.63       237
#          radikalisme       0.76      0.79      0.78       235
# pencemaran_nama_baik       0.75      0.63      0.68       492
#
#            micro avg       0.78      0.68      0.73      1326
#            macro avg       0.78      0.69      0.73      1326
#         weighted avg       0.79      0.68      0.73      1326
#          samples avg       0.40      0.39      0.39      1326
#
# Nearest checkpoint: 3886
# Threshold: 55692.046875
# Samples above threshold: 473
# Acquired samples: 473
# Sampling duration: 22.124659538269043 seconds
# New train size: 1969
# EPOCH 1 | LOSS: 5.090908050537109 | ACCURACY: 0.5846 | F1 MACRO: 0.4557 | F1 MICRO: 0.4832
# EPOCH 2 | LOSS: 4.3925957679748535 | ACCURACY: 0.6482 | F1 MACRO: 0.5973 | F1 MICRO: 0.6184
# EPOCH 3 | LOSS: 4.117083549499512 | ACCURACY: 0.6045 | F1 MACRO: 0.2747 | F1 MICRO: 0.418
# EPOCH 4 | LOSS: 3.944962739944458 | ACCURACY: 0.6662 | F1 MACRO: 0.7408 | F1 MICRO: 0.7387
# EPOCH 5 | LOSS: 3.8669493198394775 | ACCURACY: 0.6804 | F1 MACRO: 0.7093 | F1 MICRO: 0.7084
# EPOCH 6 | LOSS: 3.6742913722991943 | ACCURACY: 0.7055 | F1 MACRO: 0.7215 | F1 MICRO: 0.7325
# EPOCH 7 | LOSS: 3.558945894241333 | ACCURACY: 0.6932 | F1 MACRO: 0.7331 | F1 MICRO: 0.7411
# EPOCH 8 | LOSS: 3.3434791564941406 | ACCURACY: 0.71 | F1 MACRO: 0.7334 | F1 MICRO: 0.7383
# EPOCH 9 | LOSS: 3.2754428386688232 | ACCURACY: 0.7087 | F1 MACRO: 0.7555 | F1 MICRO: 0.756
# EPOCH 10 | LOSS: 3.2568514347076416 | ACCURACY: 0.7164 | F1 MACRO: 0.7514 | F1 MICRO: 0.758
# Iteration 1969: ACCURACY 0.7164 | F1 MACRO 0.7514 | F1 MICRO 0.758
#                       precision    recall  f1-score   support
#
#           pornografi       0.95      0.86      0.90       362
#                 sara       0.71      0.56      0.62       237
#          radikalisme       0.73      0.82      0.78       235
# pencemaran_nama_baik       0.73      0.68      0.70       492
#
#            micro avg       0.79      0.73      0.76      1326
#            macro avg       0.78      0.73      0.75      1326
#         weighted avg       0.79      0.73      0.76      1326
#          samples avg       0.43      0.42      0.41      1326
#
# Nearest checkpoint: 3886
# Threshold: 53674.0546875
# Samples above threshold: 425
# Acquired samples: 425
# Sampling duration: 22.250386476516724 seconds
# New train size: 2394
# EPOCH 1 | LOSS: 4.999579906463623 | ACCURACY: 0.5781 | F1 MACRO: 0.5031 | F1 MICRO: 0.5129
# EPOCH 2 | LOSS: 4.397628307342529 | ACCURACY: 0.4791 | F1 MACRO: 0.3891 | F1 MICRO: 0.3678
# EPOCH 3 | LOSS: 4.150702476501465 | ACCURACY: 0.6373 | F1 MACRO: 0.6388 | F1 MICRO: 0.653
# EPOCH 4 | LOSS: 3.9500176906585693 | ACCURACY: 0.654 | F1 MACRO: 0.6995 | F1 MICRO: 0.7007
# EPOCH 5 | LOSS: 3.7462306022644043 | ACCURACY: 0.6714 | F1 MACRO: 0.746 | F1 MICRO: 0.7458
# EPOCH 6 | LOSS: 3.526773691177368 | ACCURACY: 0.717 | F1 MACRO: 0.7605 | F1 MICRO: 0.7672
# EPOCH 7 | LOSS: 3.3961727619171143 | ACCURACY: 0.7177 | F1 MACRO: 0.7418 | F1 MICRO: 0.7501
# EPOCH 8 | LOSS: 3.3511219024658203 | ACCURACY: 0.7177 | F1 MACRO: 0.7595 | F1 MICRO: 0.7644
# EPOCH 9 | LOSS: 3.3310775756835938 | ACCURACY: 0.7209 | F1 MACRO: 0.7561 | F1 MICRO: 0.7612
# in second
# EPOCH 10 | LOSS: 3.2707457542419434 | ACCURACY: 0.719 | F1 MACRO: 0.7493 | F1 MICRO: 0.7563
# Iteration 2394: ACCURACY 0.717 | F1 MACRO 0.7605 | F1 MICRO 0.7672
#                       precision    recall  f1-score   support
#
#           pornografi       0.92      0.90      0.91       362
#                 sara       0.69      0.59      0.64       237
#          radikalisme       0.76      0.80      0.78       235
# pencemaran_nama_baik       0.73      0.70      0.71       492
#
#            micro avg       0.78      0.75      0.77      1326
#            macro avg       0.78      0.75      0.76      1326
#         weighted avg       0.78      0.75      0.77      1326
#          samples avg       0.43      0.43      0.42      1326
#
# Nearest checkpoint: 3886
# Threshold: 51043.8203125
# Samples above threshold: 383
# Acquired samples: 383
# Sampling duration: 21.915196657180786 seconds
# New train size: 2777
# EPOCH 1 | LOSS: 4.906124591827393 | ACCURACY: 0.5768 | F1 MACRO: 0.5123 | F1 MICRO: 0.5358
# EPOCH 2 | LOSS: 4.351673126220703 | ACCURACY: 0.6096 | F1 MACRO: 0.5217 | F1 MICRO: 0.5766
# EPOCH 3 | LOSS: 4.127971172332764 | ACCURACY: 0.6797 | F1 MACRO: 0.6941 | F1 MICRO: 0.7085
# EPOCH 4 | LOSS: 3.8928208351135254 | ACCURACY: 0.6868 | F1 MACRO: 0.718 | F1 MICRO: 0.7345
# EPOCH 5 | LOSS: 3.755857229232788 | ACCURACY: 0.692 | F1 MACRO: 0.7332 | F1 MICRO: 0.7488
# EPOCH 6 | LOSS: 3.5267059803009033 | ACCURACY: 0.7087 | F1 MACRO: 0.746 | F1 MICRO: 0.757
# EPOCH 7 | LOSS: 3.4185709953308105 | ACCURACY: 0.7209 | F1 MACRO: 0.764 | F1 MICRO: 0.7683
# EPOCH 8 | LOSS: 3.3919448852539062 | ACCURACY: 0.7273 | F1 MACRO: 0.7429 | F1 MICRO: 0.7603
# EPOCH 9 | LOSS: 3.365419626235962 | ACCURACY: 0.7196 | F1 MACRO: 0.7455 | F1 MICRO: 0.7621
# EPOCH 10 | LOSS: 3.34548282623291 | ACCURACY: 0.7132 | F1 MACRO: 0.7554 | F1 MICRO: 0.7592
# Iteration 2777: ACCURACY 0.7209 | F1 MACRO 0.764 | F1 MICRO 0.7683
#                       precision    recall  f1-score   support
#
#           pornografi       0.97      0.85      0.90       362
#                 sara       0.66      0.68      0.67       237
#          radikalisme       0.76      0.74      0.75       235
# pencemaran_nama_baik       0.74      0.72      0.73       492
#
#            micro avg       0.78      0.75      0.77      1326
#            macro avg       0.78      0.75      0.76      1326
#         weighted avg       0.79      0.75      0.77      1326
#          samples avg       0.42      0.42      0.42      1326
#
# Nearest checkpoint: 3886
# Threshold: 51033.609375
# Samples above threshold: 345
# Acquired samples: 345
# Sampling duration: 22.482020139694214 seconds
# New train size: 3122
# EPOCH 1 | LOSS: 4.962244033813477 | ACCURACY: 0.6489 | F1 MACRO: 0.6282 | F1 MICRO: 0.6356
# EPOCH 2 | LOSS: 4.459232807159424 | ACCURACY: 0.6502 | F1 MACRO: 0.6084 | F1 MICRO: 0.6544
# EPOCH 3 | LOSS: 4.241911888122559 | ACCURACY: 0.618 | F1 MACRO: 0.3151 | F1 MICRO: 0.4582
# EPOCH 4 | LOSS: 4.074264049530029 | ACCURACY: 0.6675 | F1 MACRO: 0.6348 | F1 MICRO: 0.6673
# EPOCH 5 | LOSS: 3.8846373558044434 | ACCURACY: 0.708 | F1 MACRO: 0.7172 | F1 MICRO: 0.7365
# EPOCH 6 | LOSS: 3.5776524543762207 | ACCURACY: 0.7138 | F1 MACRO: 0.749 | F1 MICRO: 0.7584
# EPOCH 7 | LOSS: 3.4649691581726074 | ACCURACY: 0.7048 | F1 MACRO: 0.7295 | F1 MICRO: 0.7486
# EPOCH 8 | LOSS: 3.4115753173828125 | ACCURACY: 0.7215 | F1 MACRO: 0.7409 | F1 MICRO: 0.7587
# EPOCH 9 | LOSS: 3.4047389030456543 | ACCURACY: 0.7241 | F1 MACRO: 0.7466 | F1 MICRO: 0.7622
# EPOCH 10 | LOSS: 3.365433931350708 | ACCURACY: 0.7145 | F1 MACRO: 0.7263 | F1 MICRO: 0.743
# Iteration 3122: ACCURACY 0.7241 | F1 MACRO 0.7466 | F1 MICRO 0.7622
#                       precision    recall  f1-score   support
#
#           pornografi       0.95      0.89      0.92       362
#                 sara       0.75      0.51      0.61       237
#          radikalisme       0.74      0.72      0.73       235
# pencemaran_nama_baik       0.77      0.68      0.72       492
#
#            micro avg       0.82      0.72      0.76      1326
#            macro avg       0.80      0.70      0.75      1326
#         weighted avg       0.81      0.72      0.76      1326
#          samples avg       0.42      0.41      0.41      1326
#
# Nearest checkpoint: 3886
# Threshold: 50359.05859375
# Samples above threshold: 310
# Acquired samples: 310
# Sampling duration: 21.969279050827026 seconds
# New train size: 3432
# EPOCH 1 | LOSS: 4.923238754272461 | ACCURACY: 0.6502 | F1 MACRO: 0.685 | F1 MICRO: 0.6806
# EPOCH 2 | LOSS: 4.385149955749512 | ACCURACY: 0.6225 | F1 MACRO: 0.6046 | F1 MICRO: 0.626
# EPOCH 3 | LOSS: 4.189996242523193 | ACCURACY: 0.6379 | F1 MACRO: 0.5341 | F1 MICRO: 0.6191
# EPOCH 4 | LOSS: 3.954517364501953 | ACCURACY: 0.6823 | F1 MACRO: 0.649 | F1 MICRO: 0.703
# EPOCH 5 | LOSS: 3.7624351978302 | ACCURACY: 0.6913 | F1 MACRO: 0.7541 | F1 MICRO: 0.752
# EPOCH 6 | LOSS: 3.542646646499634 | ACCURACY: 0.7344 | F1 MACRO: 0.7733 | F1 MICRO: 0.7822
# EPOCH 7 | LOSS: 3.4616687297821045 | ACCURACY: 0.7132 | F1 MACRO: 0.7623 | F1 MICRO: 0.7665
# EPOCH 8 | LOSS: 3.4140114784240723 | ACCURACY: 0.7138 | F1 MACRO: 0.7524 | F1 MICRO: 0.7566
# EPOCH 9 | LOSS: 3.392259120941162 | ACCURACY: 0.7248 | F1 MACRO: 0.7552 | F1 MICRO: 0.7651
# in second
# EPOCH 10 | LOSS: 3.3176867961883545 | ACCURACY: 0.7228 | F1 MACRO: 0.758 | F1 MICRO: 0.7661
# Iteration 3432: ACCURACY 0.7344 | F1 MACRO 0.7733 | F1 MICRO 0.7822
#                       precision    recall  f1-score   support
#
#           pornografi       0.94      0.91      0.93       362
#                 sara       0.64      0.60      0.62       237
#          radikalisme       0.76      0.84      0.80       235
# pencemaran_nama_baik       0.73      0.75      0.74       492
#
#            micro avg       0.78      0.79      0.78      1326
#            macro avg       0.77      0.78      0.77      1326
#         weighted avg       0.78      0.79      0.78      1326
#          samples avg       0.45      0.45      0.44      1326
#
# Nearest checkpoint: 3886
# Threshold: 48880.234375
# Samples above threshold: 279
# Acquired samples: 279
# Sampling duration: 21.90454626083374 seconds
# New train size: 3711
# EPOCH 1 | LOSS: 4.896059513092041 | ACCURACY: 0.5678 | F1 MACRO: 0.2197 | F1 MICRO: 0.3137
# EPOCH 2 | LOSS: 4.462172508239746 | ACCURACY: 0.6971 | F1 MACRO: 0.7405 | F1 MICRO: 0.7445
# EPOCH 3 | LOSS: 4.237374782562256 | ACCURACY: 0.7113 | F1 MACRO: 0.76 | F1 MICRO: 0.7633
# EPOCH 4 | LOSS: 4.034422397613525 | ACCURACY: 0.701 | F1 MACRO: 0.7269 | F1 MICRO: 0.7342
# EPOCH 5 | LOSS: 3.87481689453125 | ACCURACY: 0.6733 | F1 MACRO: 0.6648 | F1 MICRO: 0.6818
# EPOCH 6 | LOSS: 3.6266210079193115 | ACCURACY: 0.7183 | F1 MACRO: 0.7402 | F1 MICRO: 0.7544
# in second
# EPOCH 7 | LOSS: 3.393704414367676 | ACCURACY: 0.7215 | F1 MACRO: 0.7474 | F1 MICRO: 0.7611
# in second
# EPOCH 8 | LOSS: 3.377134084701538 | ACCURACY: 0.7164 | F1 MACRO: 0.747 | F1 MICRO: 0.7552
# in second
# EPOCH 9 | LOSS: 3.371290445327759 | ACCURACY: 0.7145 | F1 MACRO: 0.7467 | F1 MICRO: 0.7557
# in second
# Iteration 3711: ACCURACY 0.7113 | F1 MACRO 0.76 | F1 MICRO 0.7633
#                       precision    recall  f1-score   support
#
#           pornografi       0.95      0.85      0.90       362
#                 sara       0.60      0.66      0.63       237
#          radikalisme       0.72      0.88      0.79       235
# pencemaran_nama_baik       0.72      0.72      0.72       492
#
#            micro avg       0.75      0.77      0.76      1326
#            macro avg       0.75      0.78      0.76      1326
#         weighted avg       0.76      0.77      0.77      1326
#          samples avg       0.44      0.44      0.43      1326
#
# Nearest checkpoint: 3886
# Threshold: 48917.1328125
# Samples above threshold: 251
# Acquired samples: 175
# Sampling duration: 22.248268127441406 seconds
# New train size: 3886
# EPOCH 1 | LOSS: 4.903563022613525 | ACCURACY: 0.6264 | F1 MACRO: 0.6735 | F1 MICRO: 0.6667
# EPOCH 2 | LOSS: 4.44256067276001 | ACCURACY: 0.6752 | F1 MACRO: 0.7014 | F1 MICRO: 0.7237
# EPOCH 3 | LOSS: 4.206563949584961 | ACCURACY: 0.6277 | F1 MACRO: 0.5021 | F1 MICRO: 0.5945
# EPOCH 4 | LOSS: 4.002571105957031 | ACCURACY: 0.6373 | F1 MACRO: 0.5875 | F1 MICRO: 0.6107
# EPOCH 5 | LOSS: 3.8632454872131348 | ACCURACY: 0.6875 | F1 MACRO: 0.7129 | F1 MICRO: 0.7378
# EPOCH 6 | LOSS: 3.6098477840423584 | ACCURACY: 0.7389 | F1 MACRO: 0.7676 | F1 MICRO: 0.7807
# EPOCH 7 | LOSS: 3.482377529144287 | ACCURACY: 0.7093 | F1 MACRO: 0.7047 | F1 MICRO: 0.7168
# EPOCH 8 | LOSS: 3.4299561977386475 | ACCURACY: 0.7293 | F1 MACRO: 0.7557 | F1 MICRO: 0.7709
# EPOCH 9 | LOSS: 3.3935909271240234 | ACCURACY: 0.735 | F1 MACRO: 0.7654 | F1 MICRO: 0.7774
# in second
# EPOCH 10 | LOSS: 3.3182005882263184 | ACCURACY: 0.7383 | F1 MACRO: 0.7728 | F1 MICRO: 0.7844
# Iteration 3886: ACCURACY 0.7389 | F1 MACRO 0.7676 | F1 MICRO 0.7807
#                       precision    recall  f1-score   support
#
#           pornografi       0.90      0.90      0.90       362
#                 sara       0.69      0.59      0.63       237
#          radikalisme       0.74      0.81      0.77       235
# pencemaran_nama_baik       0.75      0.77      0.76       492
#
#            micro avg       0.78      0.78      0.78      1326
#            macro avg       0.77      0.77      0.77      1326
#         weighted avg       0.78      0.78      0.78      1326
#          samples avg       0.45      0.45      0.44      1326
#
# Nearest checkpoint: 4663
# Threshold: 49130.3671875
# Samples above threshold: 234
# Acquired samples: 234
# Sampling duration: 22.011203289031982 seconds
# New train size: 4120
# EPOCH 1 | LOSS: 4.842940330505371 | ACCURACY: 0.6482 | F1 MACRO: 0.6751 | F1 MICRO: 0.6692
# EPOCH 2 | LOSS: 4.4141716957092285 | ACCURACY: 0.6322 | F1 MACRO: 0.6794 | F1 MICRO: 0.7192
# EPOCH 3 | LOSS: 4.171025276184082 | ACCURACY: 0.683 | F1 MACRO: 0.6639 | F1 MICRO: 0.6888
# EPOCH 4 | LOSS: 3.9673476219177246 | ACCURACY: 0.6797 | F1 MACRO: 0.7594 | F1 MICRO: 0.7554
# EPOCH 5 | LOSS: 3.7827093601226807 | ACCURACY: 0.7164 | F1 MACRO: 0.7545 | F1 MICRO: 0.7636
# EPOCH 6 | LOSS: 3.5703744888305664 | ACCURACY: 0.737 | F1 MACRO: 0.7691 | F1 MICRO: 0.782
# EPOCH 7 | LOSS: 3.477592945098877 | ACCURACY: 0.7151 | F1 MACRO: 0.7224 | F1 MICRO: 0.7421
# EPOCH 8 | LOSS: 3.4442875385284424 | ACCURACY: 0.7363 | F1 MACRO: 0.7524 | F1 MICRO: 0.7599
# EPOCH 9 | LOSS: 3.3963046073913574 | ACCURACY: 0.7389 | F1 MACRO: 0.785 | F1 MICRO: 0.7926
# EPOCH 10 | LOSS: 3.391916275024414 | ACCURACY: 0.7363 | F1 MACRO: 0.7872 | F1 MICRO: 0.7919
# Iteration 4120: ACCURACY 0.7389 | F1 MACRO 0.785 | F1 MICRO 0.7926
#                       precision    recall  f1-score   support
#
#           pornografi       0.94      0.90      0.92       362
#                 sara       0.71      0.61      0.66       237
#          radikalisme       0.77      0.84      0.81       235
# pencemaran_nama_baik       0.73      0.78      0.76       492
#
#            micro avg       0.79      0.79      0.79      1326
#            macro avg       0.79      0.78      0.78      1326
#         weighted avg       0.79      0.79      0.79      1326
#          samples avg       0.46      0.45      0.45      1326
#
# Nearest checkpoint: 4663
# Threshold: 48333.890625
# Samples above threshold: 210
# Acquired samples: 210
# Sampling duration: 22.143701553344727 seconds
# New train size: 4330
# EPOCH 1 | LOSS: 4.880765914916992 | ACCURACY: 0.5833 | F1 MACRO: 0.2512 | F1 MICRO: 0.3726
# EPOCH 2 | LOSS: 4.407894134521484 | ACCURACY: 0.7068 | F1 MACRO: 0.7387 | F1 MICRO: 0.7546
# EPOCH 3 | LOSS: 4.224535942077637 | ACCURACY: 0.6971 | F1 MACRO: 0.7306 | F1 MICRO: 0.7455
# EPOCH 4 | LOSS: 4.020529270172119 | ACCURACY: 0.6752 | F1 MACRO: 0.6205 | F1 MICRO: 0.6833
# EPOCH 5 | LOSS: 3.923220157623291 | ACCURACY: 0.6772 | F1 MACRO: 0.6509 | F1 MICRO: 0.7029
# in second
# EPOCH 6 | LOSS: 3.5528781414031982 | ACCURACY: 0.7222 | F1 MACRO: 0.7545 | F1 MICRO: 0.7635
# in second
# EPOCH 7 | LOSS: 3.518653631210327 | ACCURACY: 0.7222 | F1 MACRO: 0.7495 | F1 MICRO: 0.7594
# in second
# EPOCH 8 | LOSS: 3.5049729347229004 | ACCURACY: 0.7151 | F1 MACRO: 0.7444 | F1 MICRO: 0.7548
# in second
# EPOCH 9 | LOSS: 3.495067834854126 | ACCURACY: 0.7222 | F1 MACRO: 0.7543 | F1 MICRO: 0.7658
# in second
# EPOCH 10 | LOSS: 3.485225200653076 | ACCURACY: 0.7158 | F1 MACRO: 0.7548 | F1 MICRO: 0.7625
# Iteration 4330: ACCURACY 0.7068 | F1 MACRO 0.7387 | F1 MICRO 0.7546
#                       precision    recall  f1-score   support
#
#           pornografi       0.95      0.85      0.90       362
#                 sara       0.73      0.53      0.61       237
#          radikalisme       0.79      0.65      0.71       235
# pencemaran_nama_baik       0.75      0.72      0.73       492
#
#            micro avg       0.81      0.71      0.75      1326
#            macro avg       0.80      0.69      0.74      1326
#         weighted avg       0.81      0.71      0.75      1326
#          samples avg       0.42      0.40      0.40      1326
#
# Nearest checkpoint: 4663
# Threshold: 47882.41015625
# Samples above threshold: 189
# Acquired samples: 200
# Sampling duration: 21.861868858337402 seconds
# New train size: 4530
# EPOCH 1 | LOSS: 4.959199905395508 | ACCURACY: 0.4836 | F1 MACRO: 0.4382 | F1 MICRO: 0.4373
# EPOCH 2 | LOSS: 4.426196575164795 | ACCURACY: 0.6084 | F1 MACRO: 0.5398 | F1 MICRO: 0.6043
# EPOCH 3 | LOSS: 4.237349987030029 | ACCURACY: 0.6302 | F1 MACRO: 0.5635 | F1 MICRO: 0.6426
# EPOCH 4 | LOSS: 4.073420524597168 | ACCURACY: 0.6482 | F1 MACRO: 0.4937 | F1 MICRO: 0.6491
# EPOCH 5 | LOSS: 3.914438486099243 | ACCURACY: 0.7286 | F1 MACRO: 0.7571 | F1 MICRO: 0.7635
# EPOCH 6 | LOSS: 3.653115749359131 | ACCURACY: 0.7254 | F1 MACRO: 0.7691 | F1 MICRO: 0.7749
# EPOCH 7 | LOSS: 3.5206525325775146 | ACCURACY: 0.7158 | F1 MACRO: 0.7703 | F1 MICRO: 0.7685
# EPOCH 8 | LOSS: 3.4740521907806396 | ACCURACY: 0.7273 | F1 MACRO: 0.7727 | F1 MICRO: 0.7814
# EPOCH 9 | LOSS: 3.448197841644287 | ACCURACY: 0.7273 | F1 MACRO: 0.7826 | F1 MICRO: 0.7877
# EPOCH 10 | LOSS: 3.440905809402466 | ACCURACY: 0.7235 | F1 MACRO: 0.7656 | F1 MICRO: 0.774
# Iteration 4530: ACCURACY 0.7273 | F1 MACRO 0.7826 | F1 MICRO 0.7877
#                       precision    recall  f1-score   support
#
#           pornografi       0.94      0.89      0.91       362
#                 sara       0.65      0.74      0.69       237
#          radikalisme       0.74      0.80      0.77       235
# pencemaran_nama_baik       0.75      0.77      0.76       492
#
#            micro avg       0.78      0.80      0.79      1326
#            macro avg       0.77      0.80      0.78      1326
#         weighted avg       0.78      0.80      0.79      1326
#          samples avg       0.45      0.45      0.44      1326
#
# Nearest checkpoint: 4663
# Threshold: 52403.59375
# Samples above threshold: 169
# Acquired samples: 133
# Sampling duration: 22.163798570632935 seconds
# New train size: 4663
# EPOCH 1 | LOSS: 4.842796325683594 | ACCURACY: 0.6527 | F1 MACRO: 0.5418 | F1 MICRO: 0.6402
# EPOCH 2 | LOSS: 4.420289516448975 | ACCURACY: 0.6605 | F1 MACRO: 0.5983 | F1 MICRO: 0.7079
# EPOCH 3 | LOSS: 4.227603912353516 | ACCURACY: 0.6887 | F1 MACRO: 0.6859 | F1 MICRO: 0.7019
# EPOCH 4 | LOSS: 3.9991509914398193 | ACCURACY: 0.7267 | F1 MACRO: 0.7385 | F1 MICRO: 0.7599
# EPOCH 5 | LOSS: 3.854487657546997 | ACCURACY: 0.6971 | F1 MACRO: 0.7531 | F1 MICRO: 0.7686
# EPOCH 6 | LOSS: 3.5910582542419434 | ACCURACY: 0.7273 | F1 MACRO: 0.7721 | F1 MICRO: 0.7826
# EPOCH 7 | LOSS: 3.4778575897216797 | ACCURACY: 0.7395 | F1 MACRO: 0.7801 | F1 MICRO: 0.7868
# EPOCH 8 | LOSS: 3.4500415325164795 | ACCURACY: 0.7441 | F1 MACRO: 0.7926 | F1 MICRO: 0.7985
# EPOCH 9 | LOSS: 3.417307138442993 | ACCURACY: 0.728 | F1 MACRO: 0.7618 | F1 MICRO: 0.7753
# EPOCH 10 | LOSS: 3.4125828742980957 | ACCURACY: 0.7402 | F1 MACRO: 0.7766 | F1 MICRO: 0.7886
# Iteration 4663: ACCURACY 0.7441 | F1 MACRO 0.7926 | F1 MICRO 0.7985
#                       precision    recall  f1-score   support
#
#           pornografi       0.94      0.92      0.93       362
#                 sara       0.68      0.68      0.68       237
#          radikalisme       0.78      0.83      0.80       235
# pencemaran_nama_baik       0.74      0.78      0.76       492
#
#            micro avg       0.79      0.81      0.80      1326
#            macro avg       0.78      0.80      0.79      1326
#         weighted avg       0.79      0.81      0.80      1326
#          samples avg       0.46      0.46      0.45      1326
#
# Nearest checkpoint: 5441
# Threshold: 47537.47265625
# Samples above threshold: 156
# Acquired samples: 200
# Sampling duration: 22.14479970932007 seconds
# New train size: 4863
# EPOCH 1 | LOSS: 4.794016361236572 | ACCURACY: 0.6662 | F1 MACRO: 0.683 | F1 MICRO: 0.691
# EPOCH 2 | LOSS: 4.448363304138184 | ACCURACY: 0.7151 | F1 MACRO: 0.7403 | F1 MICRO: 0.7509
# EPOCH 3 | LOSS: 4.210351467132568 | ACCURACY: 0.683 | F1 MACRO: 0.7584 | F1 MICRO: 0.7638
# EPOCH 4 | LOSS: 4.0171589851379395 | ACCURACY: 0.6977 | F1 MACRO: 0.7461 | F1 MICRO: 0.755
# EPOCH 5 | LOSS: 3.887594223022461 | ACCURACY: 0.6913 | F1 MACRO: 0.7794 | F1 MICRO: 0.7793
# EPOCH 6 | LOSS: 3.626511812210083 | ACCURACY: 0.7331 | F1 MACRO: 0.7557 | F1 MICRO: 0.7645
# EPOCH 7 | LOSS: 3.49812388420105 | ACCURACY: 0.7305 | F1 MACRO: 0.756 | F1 MICRO: 0.7643
# EPOCH 8 | LOSS: 3.4724819660186768 | ACCURACY: 0.7196 | F1 MACRO: 0.7393 | F1 MICRO: 0.7496
# in second
# EPOCH 9 | LOSS: 3.3853964805603027 | ACCURACY: 0.7241 | F1 MACRO: 0.7493 | F1 MICRO: 0.7609
# in second
# EPOCH 10 | LOSS: 3.3728630542755127 | ACCURACY: 0.7248 | F1 MACRO: 0.7561 | F1 MICRO: 0.7638
# Iteration 4863: ACCURACY 0.6913 | F1 MACRO 0.7794 | F1 MICRO 0.7793
#                       precision    recall  f1-score   support
#
#           pornografi       0.93      0.91      0.92       362
#                 sara       0.67      0.70      0.68       237
#          radikalisme       0.77      0.80      0.78       235
# pencemaran_nama_baik       0.62      0.90      0.73       492
#
#            micro avg       0.72      0.85      0.78      1326
#            macro avg       0.75      0.82      0.78      1326
#         weighted avg       0.74      0.85      0.78      1326
#          samples avg       0.48      0.48      0.47      1326
#
# Nearest checkpoint: 5441
# Threshold: 46868.8515625
# Samples above threshold: 136
# Acquired samples: 200
# Sampling duration: 21.804804801940918 seconds
# New train size: 5063
# EPOCH 1 | LOSS: 4.8875250816345215 | ACCURACY: 0.6116 | F1 MACRO: 0.4588 | F1 MICRO: 0.5504
# EPOCH 2 | LOSS: 4.446020126342773 | ACCURACY: 0.6804 | F1 MACRO: 0.7139 | F1 MICRO: 0.7219
# EPOCH 3 | LOSS: 4.236321926116943 | ACCURACY: 0.6463 | F1 MACRO: 0.7413 | F1 MICRO: 0.7371
# EPOCH 4 | LOSS: 4.1283135414123535 | ACCURACY: 0.717 | F1 MACRO: 0.7489 | F1 MICRO: 0.755
# EPOCH 5 | LOSS: 3.946903705596924 | ACCURACY: 0.6797 | F1 MACRO: 0.6445 | F1 MICRO: 0.6962
# EPOCH 6 | LOSS: 3.699226140975952 | ACCURACY: 0.7286 | F1 MACRO: 0.7525 | F1 MICRO: 0.763
# EPOCH 7 | LOSS: 3.576780080795288 | ACCURACY: 0.719 | F1 MACRO: 0.7446 | F1 MICRO: 0.7582
# EPOCH 8 | LOSS: 3.5117762088775635 | ACCURACY: 0.7383 | F1 MACRO: 0.7795 | F1 MICRO: 0.7884
# EPOCH 9 | LOSS: 3.4891550540924072 | ACCURACY: 0.7119 | F1 MACRO: 0.7321 | F1 MICRO: 0.7345
# EPOCH 10 | LOSS: 3.4870190620422363 | ACCURACY: 0.7267 | F1 MACRO: 0.7774 | F1 MICRO: 0.7845
# Iteration 5063: ACCURACY 0.7383 | F1 MACRO 0.7795 | F1 MICRO 0.7884
#                       precision    recall  f1-score   support
#
#           pornografi       0.92      0.91      0.91       362
#                 sara       0.67      0.65      0.66       237
#          radikalisme       0.74      0.83      0.78       235
# pencemaran_nama_baik       0.72      0.80      0.76       492
#
#            micro avg       0.77      0.81      0.79      1326
#            macro avg       0.76      0.80      0.78      1326
#         weighted avg       0.77      0.81      0.79      1326
#          samples avg       0.46      0.46      0.45      1326
#
# Nearest checkpoint: 5441
# Threshold: 19166.927734375
# Samples above threshold: 116
# Acquired samples: 200
# Sampling duration: 21.884470224380493 seconds
# New train size: 5263
# EPOCH 1 | LOSS: 4.783881187438965 | ACCURACY: 0.6199 | F1 MACRO: 0.6216 | F1 MICRO: 0.6382
# EPOCH 2 | LOSS: 4.384963512420654 | ACCURACY: 0.6887 | F1 MACRO: 0.6758 | F1 MICRO: 0.7134
# EPOCH 3 | LOSS: 4.194375514984131 | ACCURACY: 0.692 | F1 MACRO: 0.7485 | F1 MICRO: 0.7551
# EPOCH 4 | LOSS: 3.9996602535247803 | ACCURACY: 0.6399 | F1 MACRO: 0.6607 | F1 MICRO: 0.6695
# EPOCH 5 | LOSS: 3.826531410217285 | ACCURACY: 0.7125 | F1 MACRO: 0.7541 | F1 MICRO: 0.7592
# EPOCH 6 | LOSS: 3.6066958904266357 | ACCURACY: 0.7164 | F1 MACRO: 0.758 | F1 MICRO: 0.7675
# EPOCH 7 | LOSS: 3.517895460128784 | ACCURACY: 0.7228 | F1 MACRO: 0.758 | F1 MICRO: 0.7649
# EPOCH 8 | LOSS: 3.4721453189849854 | ACCURACY: 0.7222 | F1 MACRO: 0.7404 | F1 MICRO: 0.7602
# EPOCH 9 | LOSS: 3.4660675525665283 | ACCURACY: 0.7228 | F1 MACRO: 0.7569 | F1 MICRO: 0.7646
# in second
# EPOCH 10 | LOSS: 3.382493495941162 | ACCURACY: 0.7299 | F1 MACRO: 0.7664 | F1 MICRO: 0.7728
# Iteration 5263: ACCURACY 0.7164 | F1 MACRO 0.758 | F1 MICRO 0.7675
#                       precision    recall  f1-score   support
#
#           pornografi       0.93      0.90      0.92       362
#                 sara       0.63      0.64      0.64       237
#          radikalisme       0.78      0.71      0.75       235
# pencemaran_nama_baik       0.73      0.74      0.73       492
#
#            micro avg       0.77      0.76      0.77      1326
#            macro avg       0.77      0.75      0.76      1326
#         weighted avg       0.78      0.76      0.77      1326
#          samples avg       0.45      0.44      0.44      1326
#
# Nearest checkpoint: 5441
# Threshold: 19651.62890625
# Samples above threshold: 96
# Acquired samples: 178
# Sampling duration: 22.029274702072144 seconds
# New train size: 5441
# EPOCH 1 | LOSS: 4.7557373046875 | ACCURACY: 0.6579 | F1 MACRO: 0.6529 | F1 MICRO: 0.6878
# EPOCH 2 | LOSS: 4.391690254211426 | ACCURACY: 0.6624 | F1 MACRO: 0.6837 | F1 MICRO: 0.6932
# EPOCH 3 | LOSS: 4.198214054107666 | ACCURACY: 0.7003 | F1 MACRO: 0.7373 | F1 MICRO: 0.7476
# EPOCH 4 | LOSS: 4.031929016113281 | ACCURACY: 0.7293 | F1 MACRO: 0.7638 | F1 MICRO: 0.7744
# EPOCH 5 | LOSS: 3.8852245807647705 | ACCURACY: 0.7061 | F1 MACRO: 0.7239 | F1 MICRO: 0.7476
# EPOCH 6 | LOSS: 3.6226792335510254 | ACCURACY: 0.7305 | F1 MACRO: 0.7509 | F1 MICRO: 0.7623
# EPOCH 7 | LOSS: 3.5107476711273193 | ACCURACY: 0.7119 | F1 MACRO: 0.7331 | F1 MICRO: 0.7562
# in second
# EPOCH 8 | LOSS: 3.4004156589508057 | ACCURACY: 0.726 | F1 MACRO: 0.7645 | F1 MICRO: 0.7752
# in second
# EPOCH 9 | LOSS: 3.392508029937744 | ACCURACY: 0.7267 | F1 MACRO: 0.7616 | F1 MICRO: 0.7741
# in second
# EPOCH 10 | LOSS: 3.3843235969543457 | ACCURACY: 0.7215 | F1 MACRO: 0.7597 | F1 MICRO: 0.7719
# Iteration 5441: ACCURACY 0.7293 | F1 MACRO 0.7638 | F1 MICRO 0.7744
#                       precision    recall  f1-score   support
#
#           pornografi       0.97      0.83      0.90       362
#                 sara       0.79      0.52      0.63       237
#          radikalisme       0.77      0.80      0.79       235
# pencemaran_nama_baik       0.76      0.73      0.74       492
#
#            micro avg       0.82      0.73      0.77      1326
#            macro avg       0.82      0.72      0.76      1326
#         weighted avg       0.82      0.73      0.77      1326
#          samples avg       0.44      0.42      0.42      1326
#
# Nearest checkpoint: 6218
# Threshold: 19657.515625
# Samples above threshold: 78
# Acquired samples: 200
# Sampling duration: 21.799554586410522 seconds
# New train size: 5641
# EPOCH 1 | LOSS: 4.779597759246826 | ACCURACY: 0.6392 | F1 MACRO: 0.3975 | F1 MICRO: 0.603
# EPOCH 2 | LOSS: 4.374013423919678 | ACCURACY: 0.6251 | F1 MACRO: 0.329 | F1 MICRO: 0.4642
# EPOCH 3 | LOSS: 4.206890106201172 | ACCURACY: 0.6785 | F1 MACRO: 0.7053 | F1 MICRO: 0.7435
# EPOCH 4 | LOSS: 4.052487850189209 | ACCURACY: 0.7158 | F1 MACRO: 0.7395 | F1 MICRO: 0.7488
# EPOCH 5 | LOSS: 3.8799474239349365 | ACCURACY: 0.7241 | F1 MACRO: 0.7449 | F1 MICRO: 0.7585
# EPOCH 6 | LOSS: 3.638090133666992 | ACCURACY: 0.7363 | F1 MACRO: 0.7808 | F1 MICRO: 0.7878
# EPOCH 7 | LOSS: 3.533024549484253 | ACCURACY: 0.7415 | F1 MACRO: 0.7805 | F1 MICRO: 0.7865
# EPOCH 8 | LOSS: 3.4888577461242676 | ACCURACY: 0.7299 | F1 MACRO: 0.788 | F1 MICRO: 0.792
# EPOCH 9 | LOSS: 3.478842258453369 | ACCURACY: 0.7305 | F1 MACRO: 0.7587 | F1 MICRO: 0.7672
# EPOCH 10 | LOSS: 3.4550161361694336 | ACCURACY: 0.7325 | F1 MACRO: 0.7747 | F1 MICRO: 0.7801
# Iteration 5641: ACCURACY 0.7299 | F1 MACRO 0.788 | F1 MICRO 0.792
#                       precision    recall  f1-score   support
#
#           pornografi       0.93      0.90      0.92       362
#                 sara       0.62      0.73      0.67       237
#          radikalisme       0.77      0.83      0.80       235
# pencemaran_nama_baik       0.70      0.84      0.76       492
#
#            micro avg       0.75      0.84      0.79      1326
#            macro avg       0.76      0.83      0.79      1326
#         weighted avg       0.76      0.84      0.80      1326
#          samples avg       0.46      0.47      0.46      1326
#
# Nearest checkpoint: 6218
# Threshold: 19386.076171875
# Samples above threshold: 58
# Acquired samples: 200
# Sampling duration: 22.10277485847473 seconds
# New train size: 5841
# EPOCH 1 | LOSS: 4.762261867523193 | ACCURACY: 0.6013 | F1 MACRO: 0.2712 | F1 MICRO: 0.3937
# EPOCH 2 | LOSS: 4.312228202819824 | ACCURACY: 0.7235 | F1 MACRO: 0.7581 | F1 MICRO: 0.7693
# EPOCH 3 | LOSS: 4.174025535583496 | ACCURACY: 0.7068 | F1 MACRO: 0.741 | F1 MICRO: 0.7374
# EPOCH 4 | LOSS: 4.018645763397217 | ACCURACY: 0.7248 | F1 MACRO: 0.7691 | F1 MICRO: 0.7844
# EPOCH 5 | LOSS: 3.8526182174682617 | ACCURACY: 0.6952 | F1 MACRO: 0.6716 | F1 MICRO: 0.7064
# EPOCH 6 | LOSS: 3.6370368003845215 | ACCURACY: 0.7196 | F1 MACRO: 0.7654 | F1 MICRO: 0.7734
# EPOCH 7 | LOSS: 3.5245563983917236 | ACCURACY: 0.737 | F1 MACRO: 0.7531 | F1 MICRO: 0.7734
# in second
# EPOCH 8 | LOSS: 3.391061782836914 | ACCURACY: 0.7466 | F1 MACRO: 0.7801 | F1 MICRO: 0.7874
# in second
# EPOCH 9 | LOSS: 3.3771514892578125 | ACCURACY: 0.7421 | F1 MACRO: 0.7851 | F1 MICRO: 0.7905
# in second
# EPOCH 10 | LOSS: 3.3759474754333496 | ACCURACY: 0.7402 | F1 MACRO: 0.7766 | F1 MICRO: 0.7862
# Iteration 5841: ACCURACY 0.7248 | F1 MACRO 0.7691 | F1 MICRO 0.7844
#                       precision    recall  f1-score   support
#
#           pornografi       0.93      0.91      0.92       362
#                 sara       0.76      0.50      0.61       237
#          radikalisme       0.75      0.85      0.80       235
# pencemaran_nama_baik       0.68      0.85      0.76       492
#
#            micro avg       0.77      0.80      0.78      1326
#            macro avg       0.78      0.78      0.77      1326
#         weighted avg       0.78      0.80      0.78      1326
#          samples avg       0.48      0.46      0.46      1326
#
# Nearest checkpoint: 6218
# Threshold: 19140.94140625
# Samples above threshold: 38
# Acquired samples: 200
# Sampling duration: 21.84201693534851 seconds
# New train size: 6041
# EPOCH 1 | LOSS: 4.7096171379089355 | ACCURACY: 0.6424 | F1 MACRO: 0.5251 | F1 MICRO: 0.5862
# EPOCH 2 | LOSS: 4.294366836547852 | ACCURACY: 0.6977 | F1 MACRO: 0.766 | F1 MICRO: 0.7682
# EPOCH 3 | LOSS: 4.13920783996582 | ACCURACY: 0.6913 | F1 MACRO: 0.7349 | F1 MICRO: 0.7525
# EPOCH 4 | LOSS: 3.968205690383911 | ACCURACY: 0.6868 | F1 MACRO: 0.6967 | F1 MICRO: 0.6992
# EPOCH 5 | LOSS: 3.848435163497925 | ACCURACY: 0.6855 | F1 MACRO: 0.6551 | F1 MICRO: 0.6801
# in second
# EPOCH 6 | LOSS: 3.517418146133423 | ACCURACY: 0.7338 | F1 MACRO: 0.7418 | F1 MICRO: 0.7522
# in second
# EPOCH 7 | LOSS: 3.493647813796997 | ACCURACY: 0.7312 | F1 MACRO: 0.7478 | F1 MICRO: 0.7581
# in second
# EPOCH 8 | LOSS: 3.483849048614502 | ACCURACY: 0.735 | F1 MACRO: 0.7526 | F1 MICRO: 0.7654
# in second
# EPOCH 9 | LOSS: 3.4782426357269287 | ACCURACY: 0.7293 | F1 MACRO: 0.7679 | F1 MICRO: 0.7736
# in second
# EPOCH 10 | LOSS: 3.473679780960083 | ACCURACY: 0.7389 | F1 MACRO: 0.758 | F1 MICRO: 0.7696
# Iteration 6041: ACCURACY 0.6977 | F1 MACRO 0.766 | F1 MICRO 0.7682
#                       precision    recall  f1-score   support
#
#           pornografi       0.94      0.86      0.90       362
#                 sara       0.57      0.85      0.68       237
#          radikalisme       0.81      0.68      0.74       235
# pencemaran_nama_baik       0.65      0.87      0.74       492
#
#            micro avg       0.72      0.83      0.77      1326
#            macro avg       0.74      0.81      0.77      1326
#         weighted avg       0.75      0.83      0.77      1326
#          samples avg       0.47      0.47      0.46      1326
#
# Nearest checkpoint: 6218
# Threshold: 18887.271484375
# Samples above threshold: 18
# Acquired samples: 177
# Sampling duration: 21.93707776069641 seconds
# New train size: 6218
# EPOCH 1 | LOSS: 4.71725606918335 | ACCURACY: 0.6997 | F1 MACRO: 0.7336 | F1 MICRO: 0.7429
# EPOCH 2 | LOSS: 4.284731864929199 | ACCURACY: 0.6977 | F1 MACRO: 0.6764 | F1 MICRO: 0.6962
# EPOCH 3 | LOSS: 4.120548725128174 | ACCURACY: 0.6746 | F1 MACRO: 0.6762 | F1 MICRO: 0.6885
# EPOCH 4 | LOSS: 3.9884042739868164 | ACCURACY: 0.7241 | F1 MACRO: 0.769 | F1 MICRO: 0.7753
# EPOCH 5 | LOSS: 3.874992847442627 | ACCURACY: 0.7035 | F1 MACRO: 0.775 | F1 MICRO: 0.7738
# EPOCH 6 | LOSS: 3.620277166366577 | ACCURACY: 0.7267 | F1 MACRO: 0.7648 | F1 MICRO: 0.7756
# EPOCH 7 | LOSS: 3.5158774852752686 | ACCURACY: 0.7376 | F1 MACRO: 0.748 | F1 MICRO: 0.766
# EPOCH 8 | LOSS: 3.4878005981445312 | ACCURACY: 0.7453 | F1 MACRO: 0.7807 | F1 MICRO: 0.7886
# EPOCH 9 | LOSS: 3.460786819458008 | ACCURACY: 0.7331 | F1 MACRO: 0.7619 | F1 MICRO: 0.7677
# EPOCH 10 | LOSS: 3.438852071762085 | ACCURACY: 0.7254 | F1 MACRO: 0.7739 | F1 MICRO: 0.782
# Iteration 6218: ACCURACY 0.7453 | F1 MACRO 0.7807 | F1 MICRO 0.7886
#                       precision    recall  f1-score   support
#
#           pornografi       0.96      0.91      0.94       362
#                 sara       0.66      0.61      0.64       237
#          radikalisme       0.76      0.86      0.80       235
# pencemaran_nama_baik       0.73      0.76      0.75       492
#
#            micro avg       0.79      0.79      0.79      1326
#            macro avg       0.78      0.78      0.78      1326
#         weighted avg       0.79      0.79      0.79      1326
#          samples avg       0.46      0.45      0.45      1326
#
# Total sampling time: 463.24 seconds
# Total runtime: 8274.343876361847 seconds
