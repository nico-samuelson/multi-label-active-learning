# %%
import numpy as np
import pandas as pd

# %%
num_data = {
    'netifier': 7773,
    'dat': 500,
    'hsd': 13169,
    'casa': 1080,
    'hoasa': 2854,
}

# %%
def average_results(results):
    return pd.concat(results).groupby(level=0).mean().astype(float)

# %%
def load_result(dataset, ignored_method=None):
    methods = ['lc', 'mc', 'kmeans', 'coreset', 'comal', 'besra', 'random']
    result = {}

    if ignored_method is not None:
        for method in ignored_method:
            methods.remove(method)
    
    for method in methods:
        for i in range (1, 6):
            if i == 1:
                result[method] = [pd.read_csv(f"../{dataset}/metrics/{dataset}-{method}-{i}-results.csv")]
            else:
                result[method].append(pd.read_csv(f"../{dataset}/metrics/{dataset}-{method}-{i}-results.csv"))

    for method in methods:
        result[method] = average_results(result[method])
    
    passive_result = pd.read_csv(f"../{dataset}/metrics/{dataset}-passive-results.csv")
    result['passive'] = pd.DataFrame({
        'Accuracy': [np.mean(passive_result['Accuracy']) for i in range(len(result['lc']))],
        'F1 Micro': [np.mean(passive_result['F1 Micro']) for i in range(len(result['lc']))],
        'F1 Macro': [np.mean(passive_result['F1 Macro']) for i in range(len(result['lc']))],
    })

    return result

# %%
def highlight_cells(val):
        # For non-percentage, you can set your own thresholds
    if val > 0:  # >5% better than passive
        return 'background-color:lightgreen;color:black'
    elif val < 0:  # >5% worse than passive
        return 'background-color:lightcoral;color:black'
    else:
        return 'background-color:lightyellow;color:black'
    return ''

def compare_results(result, num_data, key, checkpoint_only=False, ignored_method=None):
    results = {}
    index = []

    passive_value = result['passive'][key].values[0]

    for method in result.keys():
        if (ignored_method is not None and method in ignored_method) or method == 'passive':
            continue

        filtered = result[method][~result[method]['Data Used'].astype(int).isin([9216, 9217])]
        if checkpoint_only:
            index = []
            for i in range(len(filtered[key])):
                if round(filtered['Data Used'].iloc[i] / num_data, 2) in [0.50, 0.60, 0.70, 0.80]:
                    index.append(i)

            results['passive'] = result['passive'][key].iloc[index].values
            results[method] = 100 * (filtered[key].iloc[index].values - passive_value) / passive_value
            # results[method] = filtered[key].iloc[index].values - result['passive'][key]
            index = np.round(result['lc']['Data Used'].iloc[index].values / num_data * 100, 1)
        else:
            results['passive'] = [0 for i in range(len(filtered['Data Used']))]
            # results[method] = filtered[key].values
            results[method] = 100 * (filtered[key].values - passive_value)
            index = np.round(filtered['Data Used'].values / num_data * 100, 1)
            
    df = pd.DataFrame(results, index=index)
    return df.style.apply(lambda x: ['background-color: lightgray' if col == 'passive' 
                                    else highlight_cells(x[col]) for col in df.columns], axis=1)\
                  .format("{:+.2f}%")\
                  .format_index("{:.0f}%")
    # return df.style.highlight_max(axis=1, props='color:white; background-color:darkgreen;').highlight_min(axis=1, props='color:white; background-color:darkred;').format("{:+.2f}%").format_index("{:.0f}%")

# %% [markdown]
# # NETIFIER

# %%
result = load_result('netifier')

# %%
print("F1 Micro")
compare_results(result, num_data['netifier'], 'F1 Micro')
# Out:
# F1 Micro
# <style type="text/css">
# #T_213d2_row0_col0, #T_213d2_row1_col0, #T_213d2_row2_col0, #T_213d2_row3_col0, #T_213d2_row4_col0, #T_213d2_row5_col0, #T_213d2_row6_col0, #T_213d2_row7_col0, #T_213d2_row8_col0, #T_213d2_row9_col0, #T_213d2_row10_col0, #T_213d2_row11_col0, #T_213d2_row12_col0, #T_213d2_row13_col0, #T_213d2_row14_col0, #T_213d2_row15_col0, #T_213d2_row16_col0, #T_213d2_row17_col0, #T_213d2_row18_col0, #T_213d2_row19_col0, #T_213d2_row20_col0, #T_213d2_row21_col0 {
#   background-color: lightgray;
# }
# #T_213d2_row0_col1, #T_213d2_row0_col2, #T_213d2_row0_col3, #T_213d2_row0_col4, #T_213d2_row0_col5, #T_213d2_row0_col6, #T_213d2_row0_col7, #T_213d2_row1_col1, #T_213d2_row1_col2, #T_213d2_row1_col3, #T_213d2_row1_col4, #T_213d2_row1_col5, #T_213d2_row1_col6, #T_213d2_row1_col7, #T_213d2_row2_col1, #T_213d2_row2_col2, #T_213d2_row2_col3, #T_213d2_row2_col4, #T_213d2_row2_col5, #T_213d2_row2_col6, #T_213d2_row2_col7, #T_213d2_row3_col1, #T_213d2_row3_col2, #T_213d2_row3_col3, #T_213d2_row3_col4, #T_213d2_row3_col5, #T_213d2_row3_col6, #T_213d2_row3_col7, #T_213d2_row4_col1, #T_213d2_row4_col2, #T_213d2_row4_col3, #T_213d2_row4_col4, #T_213d2_row4_col5, #T_213d2_row4_col6, #T_213d2_row4_col7, #T_213d2_row5_col1, #T_213d2_row5_col2, #T_213d2_row5_col3, #T_213d2_row5_col4, #T_213d2_row5_col5, #T_213d2_row5_col6, #T_213d2_row5_col7, #T_213d2_row6_col1, #T_213d2_row6_col2, #T_213d2_row6_col3, #T_213d2_row6_col4, #T_213d2_row6_col5, #T_213d2_row6_col6, #T_213d2_row6_col7, #T_213d2_row7_col1, #T_213d2_row7_col2, #T_213d2_row7_col3, #T_213d2_row7_col4, #T_213d2_row7_col5, #T_213d2_row7_col6, #T_213d2_row7_col7, #T_213d2_row8_col1, #T_213d2_row8_col3, #T_213d2_row8_col4, #T_213d2_row8_col5, #T_213d2_row8_col6, #T_213d2_row8_col7, #T_213d2_row9_col1, #T_213d2_row9_col3, #T_213d2_row9_col4, #T_213d2_row9_col5, #T_213d2_row9_col6, #T_213d2_row9_col7, #T_213d2_row10_col1, #T_213d2_row10_col3, #T_213d2_row10_col4, #T_213d2_row10_col5, #T_213d2_row10_col6, #T_213d2_row10_col7, #T_213d2_row11_col1, #T_213d2_row11_col3, #T_213d2_row11_col4, #T_213d2_row11_col5, #T_213d2_row11_col6, #T_213d2_row11_col7, #T_213d2_row12_col1, #T_213d2_row12_col4, #T_213d2_row12_col5, #T_213d2_row12_col6, #T_213d2_row12_col7, #T_213d2_row13_col1, #T_213d2_row13_col3, #T_213d2_row13_col4, #T_213d2_row13_col5, #T_213d2_row13_col7, #T_213d2_row14_col1, #T_213d2_row14_col4, #T_213d2_row14_col5, #T_213d2_row14_col7, #T_213d2_row15_col1, #T_213d2_row15_col4, #T_213d2_row15_col5, #T_213d2_row15_col7, #T_213d2_row16_col1, #T_213d2_row16_col5, #T_213d2_row17_col3, #T_213d2_row17_col5, #T_213d2_row17_col7, #T_213d2_row18_col1, #T_213d2_row19_col5, #T_213d2_row20_col5, #T_213d2_row21_col5 {
#   background-color: lightcoral;
#   color: black;
# }
# #T_213d2_row8_col2, #T_213d2_row9_col2, #T_213d2_row10_col2, #T_213d2_row11_col2, #T_213d2_row12_col2, #T_213d2_row12_col3, #T_213d2_row13_col2, #T_213d2_row13_col6, #T_213d2_row14_col2, #T_213d2_row14_col3, #T_213d2_row14_col6, #T_213d2_row15_col2, #T_213d2_row15_col3, #T_213d2_row15_col6, #T_213d2_row16_col2, #T_213d2_row16_col3, #T_213d2_row16_col4, #T_213d2_row16_col6, #T_213d2_row16_col7, #T_213d2_row17_col1, #T_213d2_row17_col2, #T_213d2_row17_col4, #T_213d2_row17_col6, #T_213d2_row18_col2, #T_213d2_row18_col3, #T_213d2_row18_col4, #T_213d2_row18_col5, #T_213d2_row18_col6, #T_213d2_row18_col7, #T_213d2_row19_col1, #T_213d2_row19_col2, #T_213d2_row19_col3, #T_213d2_row19_col4, #T_213d2_row19_col6, #T_213d2_row19_col7, #T_213d2_row20_col1, #T_213d2_row20_col2, #T_213d2_row20_col3, #T_213d2_row20_col4, #T_213d2_row20_col6, #T_213d2_row20_col7, #T_213d2_row21_col1, #T_213d2_row21_col2, #T_213d2_row21_col3, #T_213d2_row21_col4, #T_213d2_row21_col6, #T_213d2_row21_col7 {
#   background-color: lightgreen;
#   color: black;
# }
# </style>
# <table id="T_213d2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_213d2_level0_col0" class="col_heading level0 col0" >passive</th>
#       <th id="T_213d2_level0_col1" class="col_heading level0 col1" >lc</th>
#       <th id="T_213d2_level0_col2" class="col_heading level0 col2" >mc</th>
#       <th id="T_213d2_level0_col3" class="col_heading level0 col3" >kmeans</th>
#       <th id="T_213d2_level0_col4" class="col_heading level0 col4" >coreset</th>
#       <th id="T_213d2_level0_col5" class="col_heading level0 col5" >comal</th>
#       <th id="T_213d2_level0_col6" class="col_heading level0 col6" >besra</th>
#       <th id="T_213d2_level0_col7" class="col_heading level0 col7" >random</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_213d2_level0_row0" class="row_heading level0 row0" >5%</th>
#       <td id="T_213d2_row0_col0" class="data row0 col0" >+0.00%</td>
#       <td id="T_213d2_row0_col1" class="data row0 col1" >-9.58%</td>
#       <td id="T_213d2_row0_col2" class="data row0 col2" >-9.58%</td>
#       <td id="T_213d2_row0_col3" class="data row0 col3" >-9.58%</td>
#       <td id="T_213d2_row0_col4" class="data row0 col4" >-9.58%</td>
#       <td id="T_213d2_row0_col5" class="data row0 col5" >-12.19%</td>
#       <td id="T_213d2_row0_col6" class="data row0 col6" >-9.96%</td>
#       <td id="T_213d2_row0_col7" class="data row0 col7" >-9.51%</td>
#     </tr>
#     <tr>
#       <th id="T_213d2_level0_row1" class="row_heading level0 row1" >12%</th>
#       <td id="T_213d2_row1_col0" class="data row1 col0" >+0.00%</td>
#       <td id="T_213d2_row1_col1" class="data row1 col1" >-7.38%</td>
#       <td id="T_213d2_row1_col2" class="data row1 col2" >-3.51%</td>
#       <td id="T_213d2_row1_col3" class="data row1 col3" >-6.35%</td>
#       <td id="T_213d2_row1_col4" class="data row1 col4" >-8.03%</td>
#       <td id="T_213d2_row1_col5" class="data row1 col5" >-6.37%</td>
#       <td id="T_213d2_row1_col6" class="data row1 col6" >-4.57%</td>
#       <td id="T_213d2_row1_col7" class="data row1 col7" >-5.48%</td>
#     </tr>
#     <tr>
#       <th id="T_213d2_level0_row2" class="row_heading level0 row2" >19%</th>
#       <td id="T_213d2_row2_col0" class="data row2 col0" >+0.00%</td>
#       <td id="T_213d2_row2_col1" class="data row2 col1" >-6.18%</td>
#       <td id="T_213d2_row2_col2" class="data row2 col2" >-2.69%</td>
#       <td id="T_213d2_row2_col3" class="data row2 col3" >-3.48%</td>
#       <td id="T_213d2_row2_col4" class="data row2 col4" >-7.22%</td>
#       <td id="T_213d2_row2_col5" class="data row2 col5" >-4.85%</td>
#       <td id="T_213d2_row2_col6" class="data row2 col6" >-3.24%</td>
#       <td id="T_213d2_row2_col7" class="data row2 col7" >-3.40%</td>
#     </tr>
#     <tr>
#       <th id="T_213d2_level0_row3" class="row_heading level0 row3" >25%</th>
#       <td id="T_213d2_row3_col0" class="data row3 col0" >+0.00%</td>
#       <td id="T_213d2_row3_col1" class="data row3 col1" >-4.69%</td>
#       <td id="T_213d2_row3_col2" class="data row3 col2" >-1.12%</td>
#       <td id="T_213d2_row3_col3" class="data row3 col3" >-3.01%</td>
#       <td id="T_213d2_row3_col4" class="data row3 col4" >-5.17%</td>
#       <td id="T_213d2_row3_col5" class="data row3 col5" >-3.51%</td>
#       <td id="T_213d2_row3_col6" class="data row3 col6" >-2.24%</td>
#       <td id="T_213d2_row3_col7" class="data row3 col7" >-2.69%</td>
#     </tr>
#     <tr>
#       <th id="T_213d2_level0_row4" class="row_heading level0 row4" >31%</th>
#       <td id="T_213d2_row4_col0" class="data row4 col0" >+0.00%</td>
#       <td id="T_213d2_row4_col1" class="data row4 col1" >-3.68%</td>
#       <td id="T_213d2_row4_col2" class="data row4 col2" >-0.54%</td>
#       <td id="T_213d2_row4_col3" class="data row4 col3" >-1.99%</td>
#       <td id="T_213d2_row4_col4" class="data row4 col4" >-3.39%</td>
#       <td id="T_213d2_row4_col5" class="data row4 col5" >-3.75%</td>
#       <td id="T_213d2_row4_col6" class="data row4 col6" >-1.79%</td>
#       <td id="T_213d2_row4_col7" class="data row4 col7" >-2.07%</td>
#     </tr>
#     <tr>
#       <th id="T_213d2_level0_row5" class="row_heading level0 row5" >36%</th>
#       <td id="T_213d2_row5_col0" class="data row5 col0" >+0.00%</td>
#       <td id="T_213d2_row5_col1" class="data row5 col1" >-2.24%</td>

# %% [markdown]
# # DOCTOR'S ANSWER TEXT

# %%
result = load_result('dat')

# %%
print("F1 Micro")
compare_results(result, num_data['dat'], 'F1 Micro')
# Out:
# F1 Micro
# <style type="text/css">
# #T_1306f_row0_col0, #T_1306f_row1_col0, #T_1306f_row2_col0, #T_1306f_row3_col0, #T_1306f_row4_col0, #T_1306f_row5_col0, #T_1306f_row6_col0, #T_1306f_row7_col0, #T_1306f_row8_col0, #T_1306f_row9_col0, #T_1306f_row10_col0, #T_1306f_row11_col0, #T_1306f_row12_col0, #T_1306f_row13_col0, #T_1306f_row14_col0, #T_1306f_row15_col0, #T_1306f_row16_col0, #T_1306f_row17_col0, #T_1306f_row18_col0, #T_1306f_row19_col0, #T_1306f_row20_col0, #T_1306f_row21_col0, #T_1306f_row22_col0, #T_1306f_row23_col0 {
#   background-color: lightgray;
# }
# #T_1306f_row0_col1, #T_1306f_row0_col2, #T_1306f_row0_col3, #T_1306f_row0_col4, #T_1306f_row0_col5, #T_1306f_row0_col6, #T_1306f_row0_col7, #T_1306f_row1_col1, #T_1306f_row1_col2, #T_1306f_row1_col3, #T_1306f_row1_col4, #T_1306f_row1_col5, #T_1306f_row1_col6, #T_1306f_row1_col7, #T_1306f_row2_col1, #T_1306f_row2_col2, #T_1306f_row2_col3, #T_1306f_row2_col4, #T_1306f_row2_col5, #T_1306f_row2_col6, #T_1306f_row2_col7, #T_1306f_row3_col1, #T_1306f_row3_col2, #T_1306f_row3_col3, #T_1306f_row3_col4, #T_1306f_row3_col5, #T_1306f_row3_col6, #T_1306f_row3_col7, #T_1306f_row4_col1, #T_1306f_row4_col2, #T_1306f_row4_col3, #T_1306f_row4_col4, #T_1306f_row4_col5, #T_1306f_row4_col6, #T_1306f_row4_col7, #T_1306f_row5_col1, #T_1306f_row5_col2, #T_1306f_row5_col3, #T_1306f_row5_col4, #T_1306f_row5_col5, #T_1306f_row5_col6, #T_1306f_row5_col7, #T_1306f_row6_col1, #T_1306f_row6_col2, #T_1306f_row6_col3, #T_1306f_row6_col4, #T_1306f_row6_col5, #T_1306f_row6_col6, #T_1306f_row6_col7, #T_1306f_row7_col1, #T_1306f_row7_col3, #T_1306f_row7_col4, #T_1306f_row7_col5, #T_1306f_row7_col6, #T_1306f_row7_col7, #T_1306f_row8_col1, #T_1306f_row8_col2, #T_1306f_row8_col4, #T_1306f_row8_col5, #T_1306f_row8_col6, #T_1306f_row8_col7, #T_1306f_row9_col1, #T_1306f_row9_col3, #T_1306f_row9_col4, #T_1306f_row9_col5, #T_1306f_row9_col6, #T_1306f_row9_col7, #T_1306f_row10_col4, #T_1306f_row10_col5, #T_1306f_row10_col6, #T_1306f_row10_col7, #T_1306f_row11_col4, #T_1306f_row11_col5, #T_1306f_row11_col6, #T_1306f_row11_col7, #T_1306f_row12_col5, #T_1306f_row12_col7, #T_1306f_row13_col3, #T_1306f_row13_col5, #T_1306f_row13_col6, #T_1306f_row13_col7, #T_1306f_row14_col5, #T_1306f_row14_col7, #T_1306f_row15_col2, #T_1306f_row15_col5, #T_1306f_row16_col5, #T_1306f_row16_col7, #T_1306f_row17_col5, #T_1306f_row18_col5, #T_1306f_row19_col5, #T_1306f_row19_col7, #T_1306f_row20_col5, #T_1306f_row21_col5, #T_1306f_row21_col7, #T_1306f_row22_col3, #T_1306f_row22_col5, #T_1306f_row22_col6, #T_1306f_row23_col1, #T_1306f_row23_col3, #T_1306f_row23_col5, #T_1306f_row23_col6 {
#   background-color: lightcoral;
#   color: black;
# }
# #T_1306f_row7_col2, #T_1306f_row8_col3, #T_1306f_row9_col2, #T_1306f_row10_col1, #T_1306f_row10_col2, #T_1306f_row10_col3, #T_1306f_row11_col1, #T_1306f_row11_col2, #T_1306f_row11_col3, #T_1306f_row12_col1, #T_1306f_row12_col2, #T_1306f_row12_col3, #T_1306f_row12_col4, #T_1306f_row12_col6, #T_1306f_row13_col1, #T_1306f_row13_col2, #T_1306f_row13_col4, #T_1306f_row14_col1, #T_1306f_row14_col2, #T_1306f_row14_col3, #T_1306f_row14_col4, #T_1306f_row14_col6, #T_1306f_row15_col1, #T_1306f_row15_col3, #T_1306f_row15_col4, #T_1306f_row15_col6, #T_1306f_row15_col7, #T_1306f_row16_col1, #T_1306f_row16_col2, #T_1306f_row16_col3, #T_1306f_row16_col4, #T_1306f_row16_col6, #T_1306f_row17_col1, #T_1306f_row17_col2, #T_1306f_row17_col3, #T_1306f_row17_col4, #T_1306f_row17_col6, #T_1306f_row17_col7, #T_1306f_row18_col1, #T_1306f_row18_col2, #T_1306f_row18_col3, #T_1306f_row18_col4, #T_1306f_row18_col6, #T_1306f_row18_col7, #T_1306f_row19_col1, #T_1306f_row19_col2, #T_1306f_row19_col3, #T_1306f_row19_col4, #T_1306f_row19_col6, #T_1306f_row20_col1, #T_1306f_row20_col2, #T_1306f_row20_col3, #T_1306f_row20_col4, #T_1306f_row20_col6, #T_1306f_row20_col7, #T_1306f_row21_col1, #T_1306f_row21_col2, #T_1306f_row21_col3, #T_1306f_row21_col4, #T_1306f_row21_col6, #T_1306f_row22_col1, #T_1306f_row22_col2, #T_1306f_row22_col4, #T_1306f_row22_col7, #T_1306f_row23_col2, #T_1306f_row23_col4, #T_1306f_row23_col7 {
#   background-color: lightgreen;
#   color: black;
# }
# </style>
# <table id="T_1306f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1306f_level0_col0" class="col_heading level0 col0" >passive</th>
#       <th id="T_1306f_level0_col1" class="col_heading level0 col1" >lc</th>
#       <th id="T_1306f_level0_col2" class="col_heading level0 col2" >mc</th>
#       <th id="T_1306f_level0_col3" class="col_heading level0 col3" >kmeans</th>
#       <th id="T_1306f_level0_col4" class="col_heading level0 col4" >coreset</th>
#       <th id="T_1306f_level0_col5" class="col_heading level0 col5" >comal</th>
#       <th id="T_1306f_level0_col6" class="col_heading level0 col6" >besra</th>
#       <th id="T_1306f_level0_col7" class="col_heading level0 col7" >random</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1306f_level0_row0" class="row_heading level0 row0" >5%</th>
#       <td id="T_1306f_row0_col0" class="data row0 col0" >+0.00%</td>
#       <td id="T_1306f_row0_col1" class="data row0 col1" >-0.65%</td>
#       <td id="T_1306f_row0_col2" class="data row0 col2" >-0.65%</td>
#       <td id="T_1306f_row0_col3" class="data row0 col3" >-0.65%</td>
#       <td id="T_1306f_row0_col4" class="data row0 col4" >-0.65%</td>
#       <td id="T_1306f_row0_col5" class="data row0 col5" >-0.68%</td>
#       <td id="T_1306f_row0_col6" class="data row0 col6" >-0.65%</td>
#       <td id="T_1306f_row0_col7" class="data row0 col7" >-0.65%</td>
#     </tr>
#     <tr>
#       <th id="T_1306f_level0_row1" class="row_heading level0 row1" >13%</th>
#       <td id="T_1306f_row1_col0" class="data row1 col0" >+0.00%</td>
#       <td id="T_1306f_row1_col1" class="data row1 col1" >-0.56%</td>
#       <td id="T_1306f_row1_col2" class="data row1 col2" >-0.65%</td>
#       <td id="T_1306f_row1_col3" class="data row1 col3" >-0.65%</td>
#       <td id="T_1306f_row1_col4" class="data row1 col4" >-0.58%</td>
#       <td id="T_1306f_row1_col5" class="data row1 col5" >-0.58%</td>
#       <td id="T_1306f_row1_col6" class="data row1 col6" >-0.62%</td>
#       <td id="T_1306f_row1_col7" class="data row1 col7" >-0.62%</td>
#     </tr>
#     <tr>
#       <th id="T_1306f_level0_row2" class="row_heading level0 row2" >19%</th>
#       <td id="T_1306f_row2_col0" class="data row2 col0" >+0.00%</td>
#       <td id="T_1306f_row2_col1" class="data row2 col1" >-0.42%</td>
#       <td id="T_1306f_row2_col2" class="data row2 col2" >-0.46%</td>
#       <td id="T_1306f_row2_col3" class="data row2 col3" >-0.39%</td>
#       <td id="T_1306f_row2_col4" class="data row2 col4" >-0.39%</td>
#       <td id="T_1306f_row2_col5" class="data row2 col5" >-0.50%</td>
#       <td id="T_1306f_row2_col6" class="data row2 col6" >-0.48%</td>
#       <td id="T_1306f_row2_col7" class="data row2 col7" >-0.58%</td>
#     </tr>
#     <tr>
#       <th id="T_1306f_level0_row3" class="row_heading level0 row3" >26%</th>
#       <td id="T_1306f_row3_col0" class="data row3 col0" >+0.00%</td>
#       <td id="T_1306f_row3_col1" class="data row3 col1" >-0.39%</td>
#       <td id="T_1306f_row3_col2" class="data row3 col2" >-0.51%</td>
#       <td id="T_1306f_row3_col3" class="data row3 col3" >-0.50%</td>
#       <td id="T_1306f_row3_col4" class="data row3 col4" >-0.30%</td>
#       <td id="T_1306f_row3_col5" class="data row3 col5" >-0.47%</td>
#       <td id="T_1306f_row3_col6" class="data row3 col6" >-0.44%</td>
#       <td id="T_1306f_row3_col7" class="data row3 col7" >-0.53%</td>
#     </tr>
#     <tr>
#       <th id="T_1306f_level0_row4" class="row_heading level0 row4" >31%</th>
#       <td id="T_1306f_row4_col0" class="data row4 col0" >+0.00%</td>
#       <td id="T_1306f_row4_col1" class="data row4 col1" >-0.37%</td>
#       <td id="T_1306f_row4_col2" class="data row4 col2" >-0.20%</td>
#       <td id="T_1306f_row4_col3" class="data row4 col3" >-0.37%</td>
#       <td id="T_1306f_row4_col4" class="data row4 col4" >-0.20%</td>
#       <td id="T_1306f_row4_col5" class="data row4 col5" >-0.34%</td>
#       <td id="T_1306f_row4_col6" class="d

# %% [markdown]
# # HATE SPEECH DETECTION

# %%
result = load_result('hsd')

# %%
print("F1 Micro")
compare_results(result, num_data['hsd'], 'F1 Micro')
# Out:
# F1 Micro
# <style type="text/css">
# #T_78f91_row0_col0, #T_78f91_row1_col0, #T_78f91_row2_col0, #T_78f91_row3_col0, #T_78f91_row4_col0, #T_78f91_row5_col0, #T_78f91_row6_col0, #T_78f91_row7_col0, #T_78f91_row8_col0, #T_78f91_row9_col0, #T_78f91_row10_col0, #T_78f91_row11_col0, #T_78f91_row12_col0, #T_78f91_row13_col0, #T_78f91_row14_col0, #T_78f91_row15_col0, #T_78f91_row16_col0, #T_78f91_row17_col0, #T_78f91_row18_col0, #T_78f91_row19_col0, #T_78f91_row20_col0, #T_78f91_row21_col0, #T_78f91_row22_col0, #T_78f91_row23_col0, #T_78f91_row24_col0, #T_78f91_row25_col0, #T_78f91_row26_col0 {
#   background-color: lightgray;
# }
# #T_78f91_row0_col1, #T_78f91_row0_col2, #T_78f91_row0_col3, #T_78f91_row0_col4, #T_78f91_row0_col5, #T_78f91_row0_col6, #T_78f91_row0_col7, #T_78f91_row1_col1, #T_78f91_row1_col2, #T_78f91_row1_col3, #T_78f91_row1_col4, #T_78f91_row1_col5, #T_78f91_row1_col6, #T_78f91_row1_col7, #T_78f91_row2_col1, #T_78f91_row2_col2, #T_78f91_row2_col3, #T_78f91_row2_col4, #T_78f91_row2_col5, #T_78f91_row2_col6, #T_78f91_row2_col7, #T_78f91_row3_col1, #T_78f91_row3_col2, #T_78f91_row3_col3, #T_78f91_row3_col4, #T_78f91_row3_col5, #T_78f91_row3_col6, #T_78f91_row3_col7, #T_78f91_row4_col1, #T_78f91_row4_col2, #T_78f91_row4_col3, #T_78f91_row4_col4, #T_78f91_row4_col5, #T_78f91_row4_col6, #T_78f91_row4_col7, #T_78f91_row5_col1, #T_78f91_row5_col2, #T_78f91_row5_col3, #T_78f91_row5_col4, #T_78f91_row5_col5, #T_78f91_row5_col6, #T_78f91_row5_col7, #T_78f91_row6_col1, #T_78f91_row6_col2, #T_78f91_row6_col3, #T_78f91_row6_col4, #T_78f91_row6_col5, #T_78f91_row6_col6, #T_78f91_row6_col7, #T_78f91_row7_col1, #T_78f91_row7_col2, #T_78f91_row7_col3, #T_78f91_row7_col4, #T_78f91_row7_col5, #T_78f91_row7_col6, #T_78f91_row7_col7, #T_78f91_row8_col1, #T_78f91_row8_col2, #T_78f91_row8_col3, #T_78f91_row8_col4, #T_78f91_row8_col5, #T_78f91_row8_col6, #T_78f91_row8_col7, #T_78f91_row9_col1, #T_78f91_row9_col2, #T_78f91_row9_col3, #T_78f91_row9_col4, #T_78f91_row9_col5, #T_78f91_row9_col6, #T_78f91_row9_col7, #T_78f91_row10_col1, #T_78f91_row10_col2, #T_78f91_row10_col3, #T_78f91_row10_col4, #T_78f91_row10_col5, #T_78f91_row10_col6, #T_78f91_row10_col7, #T_78f91_row11_col1, #T_78f91_row11_col2, #T_78f91_row11_col3, #T_78f91_row11_col4, #T_78f91_row11_col5, #T_78f91_row11_col6, #T_78f91_row11_col7, #T_78f91_row12_col1, #T_78f91_row12_col3, #T_78f91_row12_col4, #T_78f91_row12_col5, #T_78f91_row12_col6, #T_78f91_row12_col7, #T_78f91_row13_col1, #T_78f91_row13_col3, #T_78f91_row13_col4, #T_78f91_row13_col5, #T_78f91_row13_col6, #T_78f91_row13_col7, #T_78f91_row14_col1, #T_78f91_row14_col3, #T_78f91_row14_col4, #T_78f91_row14_col5, #T_78f91_row14_col6, #T_78f91_row14_col7, #T_78f91_row15_col1, #T_78f91_row15_col3, #T_78f91_row15_col4, #T_78f91_row15_col5, #T_78f91_row15_col6, #T_78f91_row15_col7, #T_78f91_row16_col1, #T_78f91_row16_col3, #T_78f91_row16_col4, #T_78f91_row16_col5, #T_78f91_row16_col6, #T_78f91_row16_col7, #T_78f91_row17_col1, #T_78f91_row17_col2, #T_78f91_row17_col4, #T_78f91_row17_col5, #T_78f91_row17_col6, #T_78f91_row17_col7, #T_78f91_row18_col1, #T_78f91_row18_col4, #T_78f91_row18_col5, #T_78f91_row18_col6, #T_78f91_row18_col7, #T_78f91_row19_col1, #T_78f91_row19_col2, #T_78f91_row19_col4, #T_78f91_row19_col5, #T_78f91_row19_col6, #T_78f91_row19_col7, #T_78f91_row20_col1, #T_78f91_row20_col4, #T_78f91_row20_col5, #T_78f91_row20_col6, #T_78f91_row20_col7, #T_78f91_row21_col1, #T_78f91_row21_col4, #T_78f91_row21_col5, #T_78f91_row21_col6, #T_78f91_row21_col7, #T_78f91_row22_col1, #T_78f91_row22_col2, #T_78f91_row22_col4, #T_78f91_row22_col5, #T_78f91_row22_col6, #T_78f91_row22_col7, #T_78f91_row23_col1, #T_78f91_row23_col4, #T_78f91_row23_col5, #T_78f91_row23_col7, #T_78f91_row24_col1, #T_78f91_row24_col4, #T_78f91_row24_col5, #T_78f91_row24_col6, #T_78f91_row24_col7, #T_78f91_row25_col1, #T_78f91_row25_col2, #T_78f91_row25_col4, #T_78f91_row25_col5, #T_78f91_row25_col6, #T_78f91_row26_col5, #T_78f91_row26_col6, #T_78f91_row26_col7 {
#   background-color: lightcoral;
#   color: black;
# }
# #T_78f91_row12_col2, #T_78f91_row13_col2, #T_78f91_row14_col2, #T_78f91_row15_col2, #T_78f91_row16_col2, #T_78f91_row17_col3, #T_78f91_row18_col2, #T_78f91_row18_col3, #T_78f91_row19_col3, #T_78f91_row20_col2, #T_78f91_row20_col3, #T_78f91_row21_col2, #T_78f91_row21_col3, #T_78f91_row22_col3, #T_78f91_row23_col2, #T_78f91_row23_col3, #T_78f91_row23_col6, #T_78f91_row24_col2, #T_78f91_row24_col3, #T_78f91_row25_col3, #T_78f91_row25_col7, #T_78f91_row26_col1, #T_78f91_row26_col2, #T_78f91_row26_col3, #T_78f91_row26_col4 {
#   background-color: lightgreen;
#   color: black;
# }
# </style>
# <table id="T_78f91">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78f91_level0_col0" class="col_heading level0 col0" >passive</th>
#       <th id="T_78f91_level0_col1" class="col_heading level0 col1" >lc</th>
#       <th id="T_78f91_level0_col2" class="col_heading level0 col2" >mc</th>
#       <th id="T_78f91_level0_col3" class="col_heading level0 col3" >kmeans</th>
#       <th id="T_78f91_level0_col4" class="col_heading level0 col4" >coreset</th>
#       <th id="T_78f91_level0_col5" class="col_heading level0 col5" >comal</th>
#       <th id="T_78f91_level0_col6" class="col_heading level0 col6" >besra</th>
#       <th id="T_78f91_level0_col7" class="col_heading level0 col7" >random</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78f91_level0_row0" class="row_heading level0 row0" >5%</th>
#       <td id="T_78f91_row0_col0" class="data row0 col0" >+0.00%</td>
#       <td id="T_78f91_row0_col1" class="data row0 col1" >-19.38%</td>
#       <td id="T_78f91_row0_col2" class="data row0 col2" >-19.38%</td>
#       <td id="T_78f91_row0_col3" class="data row0 col3" >-18.43%</td>
#       <td id="T_78f91_row0_col4" class="data row0 col4" >-19.55%</td>
#       <td id="T_78f91_row0_col5" class="data row0 col5" >-15.04%</td>
#       <td id="T_78f91_row0_col6" class="data row0 col6" >-21.52%</td>
#       <td id="T_78f91_row0_col7" class="data row0 col7" >-19.55%</td>
#     </tr>
#     <tr>
#       <th id="T_78f91_level0_row1" class="row_heading level0 row1" >12%</th>
#       <td id="T_78f91_row1_col0" class="data row1 col0" >+0.00%</td>
#       <td id="T_78f91_row1_col1" class="data row1 col1" >-17.51%</td>
#       <td id="T_78f91_row1_col2" class="data row1 col2" >-8.25%</td>
#       <td id="T_78f91_row1_col3" class="data row1 col3" >-9.87%</td>
#       <td id="T_78f91_row1_col4" class="data row1 col4" >-12.70%</td>
#       <td id="T_78f91_row1_col5" class="data row1 col5" >-8.50%</td>
#       <td id="T_78f91_row1_col6" class="data row1 col6" >-10.39%</td>
#       <td id="T_78f91_row1_col7" class="data row1 col7" >-10.71%</td>
#     </tr>
#     <tr>
#       <th id="T_78f91_level0_row2" class="row_heading level0 row2" >19%</th>
#       <td id="T_78f91_row2_col0" class="data row2 col0" >+0.00%</td>
#       <td id="T_78f91_row2_col1" class="data row2 col1" >-16.41%</td>
#       <td id="T_78f91_row2_col2" class="data row2 col2" >-5.39%</td>
#       <td id="T_78f91_row2_col3" class="data row2 col3" >-7.31%</td>
#       <td id="T_78f91_row2_col4" class="data row2 col4" >-8.71%</td>
#       <td id="T_78f91_row2_col5" class="data row2 col5" >-6.27%</td>
#       <td id="T_78f91_row2_col6" class="data row2 col6" >-7.44%</td>
#       <td id="T_78f91_row2_col7" class="data row2 col7" >-7.36%</td>
#     </tr>
#     <tr>
#       <th id="T_78f91_level0_row3" class="row_heading level0 row3" >25%</th>
#       <td id="T_78f91_row3_col0" class="data row3 col0" >+0.00%</td>
#       <td id="T_78f91_row3_col1" class="data row3 col1" >-13.47%</td>
#       <td id="T_78f91_row3_col2" class="data row3 col2" >-3.79%</td>
#       <td id="T_78f91_row3_col3" class="data row3 col3" >-4.75%</td>
#       <td id="T_78f91_row3_col4" class="data row3 col4" >-7.38%</td>
#       <td id="T_78f91_row3_col5" class="data row3 col5" >-4.73%</td>
#       <td id="T_78f91_row3_col6" class="data row3 col6" >-5.61%</td>
#       <td id="T_78f91_row3_col7" class="data row3 col7" >-5.53%</td>
#     </tr>
#     <tr>
#       <th id="T

# %% [markdown]
# # CASA

# %%
result = load_result('casa')

# %%
print("F1 Micro")
compare_results(result, num_data['casa'], 'F1 Micro')
# Out:
# F1 Micro
# <style type="text/css">
# #T_3384a_row0_col0, #T_3384a_row1_col0, #T_3384a_row2_col0, #T_3384a_row3_col0, #T_3384a_row4_col0, #T_3384a_row5_col0, #T_3384a_row6_col0, #T_3384a_row7_col0, #T_3384a_row8_col0, #T_3384a_row9_col0, #T_3384a_row10_col0, #T_3384a_row11_col0, #T_3384a_row12_col0, #T_3384a_row13_col0, #T_3384a_row14_col0, #T_3384a_row15_col0, #T_3384a_row16_col0, #T_3384a_row17_col0, #T_3384a_row18_col0, #T_3384a_row19_col0, #T_3384a_row20_col0, #T_3384a_row21_col0, #T_3384a_row22_col0, #T_3384a_row23_col0 {
#   background-color: lightgray;
# }
# #T_3384a_row0_col1, #T_3384a_row0_col2, #T_3384a_row0_col3, #T_3384a_row0_col4, #T_3384a_row0_col5, #T_3384a_row0_col6, #T_3384a_row0_col7, #T_3384a_row1_col1, #T_3384a_row1_col2, #T_3384a_row1_col3, #T_3384a_row1_col4, #T_3384a_row1_col5, #T_3384a_row1_col6, #T_3384a_row1_col7, #T_3384a_row2_col1, #T_3384a_row2_col2, #T_3384a_row2_col3, #T_3384a_row2_col4, #T_3384a_row2_col5, #T_3384a_row2_col6, #T_3384a_row2_col7, #T_3384a_row3_col1, #T_3384a_row3_col2, #T_3384a_row3_col3, #T_3384a_row3_col4, #T_3384a_row3_col5, #T_3384a_row3_col6, #T_3384a_row3_col7, #T_3384a_row4_col1, #T_3384a_row4_col2, #T_3384a_row4_col3, #T_3384a_row4_col4, #T_3384a_row4_col5, #T_3384a_row4_col6, #T_3384a_row4_col7, #T_3384a_row5_col1, #T_3384a_row5_col2, #T_3384a_row5_col3, #T_3384a_row5_col4, #T_3384a_row5_col5, #T_3384a_row5_col6, #T_3384a_row5_col7, #T_3384a_row6_col1, #T_3384a_row6_col2, #T_3384a_row6_col3, #T_3384a_row6_col4, #T_3384a_row6_col5, #T_3384a_row6_col6, #T_3384a_row6_col7, #T_3384a_row7_col1, #T_3384a_row7_col2, #T_3384a_row7_col3, #T_3384a_row7_col4, #T_3384a_row7_col5, #T_3384a_row7_col6, #T_3384a_row7_col7, #T_3384a_row8_col1, #T_3384a_row8_col2, #T_3384a_row8_col3, #T_3384a_row8_col4, #T_3384a_row8_col5, #T_3384a_row8_col6, #T_3384a_row8_col7, #T_3384a_row9_col1, #T_3384a_row9_col2, #T_3384a_row9_col3, #T_3384a_row9_col4, #T_3384a_row9_col5, #T_3384a_row9_col6, #T_3384a_row9_col7, #T_3384a_row10_col1, #T_3384a_row10_col2, #T_3384a_row10_col3, #T_3384a_row10_col4, #T_3384a_row10_col5, #T_3384a_row10_col6, #T_3384a_row10_col7, #T_3384a_row11_col1, #T_3384a_row11_col2, #T_3384a_row11_col3, #T_3384a_row11_col4, #T_3384a_row11_col5, #T_3384a_row11_col6, #T_3384a_row11_col7, #T_3384a_row12_col1, #T_3384a_row12_col2, #T_3384a_row12_col3, #T_3384a_row12_col4, #T_3384a_row12_col5, #T_3384a_row12_col6, #T_3384a_row12_col7, #T_3384a_row13_col1, #T_3384a_row13_col2, #T_3384a_row13_col3, #T_3384a_row13_col4, #T_3384a_row13_col5, #T_3384a_row13_col6, #T_3384a_row13_col7, #T_3384a_row14_col1, #T_3384a_row14_col2, #T_3384a_row14_col4, #T_3384a_row14_col5, #T_3384a_row14_col6, #T_3384a_row14_col7, #T_3384a_row15_col1, #T_3384a_row15_col2, #T_3384a_row15_col3, #T_3384a_row15_col4, #T_3384a_row15_col5, #T_3384a_row15_col6, #T_3384a_row15_col7, #T_3384a_row16_col1, #T_3384a_row16_col2, #T_3384a_row16_col4, #T_3384a_row16_col5, #T_3384a_row16_col6, #T_3384a_row16_col7, #T_3384a_row17_col1, #T_3384a_row17_col2, #T_3384a_row17_col3, #T_3384a_row17_col5, #T_3384a_row17_col7, #T_3384a_row18_col1, #T_3384a_row18_col2, #T_3384a_row18_col5, #T_3384a_row18_col6, #T_3384a_row18_col7, #T_3384a_row19_col1, #T_3384a_row19_col3, #T_3384a_row19_col5, #T_3384a_row19_col7, #T_3384a_row20_col4, #T_3384a_row20_col5, #T_3384a_row20_col7, #T_3384a_row21_col1, #T_3384a_row21_col5, #T_3384a_row21_col7, #T_3384a_row22_col1, #T_3384a_row22_col2, #T_3384a_row22_col4, #T_3384a_row22_col5, #T_3384a_row22_col7, #T_3384a_row23_col5 {
#   background-color: lightcoral;
#   color: black;
# }
# #T_3384a_row14_col3, #T_3384a_row16_col3, #T_3384a_row17_col4, #T_3384a_row17_col6, #T_3384a_row18_col3, #T_3384a_row18_col4, #T_3384a_row19_col2, #T_3384a_row19_col4, #T_3384a_row19_col6, #T_3384a_row20_col2, #T_3384a_row20_col3, #T_3384a_row20_col6, #T_3384a_row21_col2, #T_3384a_row21_col4, #T_3384a_row21_col6, #T_3384a_row22_col3, #T_3384a_row22_col6, #T_3384a_row23_col2, #T_3384a_row23_col3, #T_3384a_row23_col6, #T_3384a_row23_col7 {
#   background-color: lightgreen;
#   color: black;
# }
# #T_3384a_row20_col1, #T_3384a_row21_col3, #T_3384a_row23_col1, #T_3384a_row23_col4 {
#   background-color: lightyellow;
#   color: black;
# }
# </style>
# <table id="T_3384a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3384a_level0_col0" class="col_heading level0 col0" >passive</th>
#       <th id="T_3384a_level0_col1" class="col_heading level0 col1" >lc</th>
#       <th id="T_3384a_level0_col2" class="col_heading level0 col2" >mc</th>
#       <th id="T_3384a_level0_col3" class="col_heading level0 col3" >kmeans</th>
#       <th id="T_3384a_level0_col4" class="col_heading level0 col4" >coreset</th>
#       <th id="T_3384a_level0_col5" class="col_heading level0 col5" >comal</th>
#       <th id="T_3384a_level0_col6" class="col_heading level0 col6" >besra</th>
#       <th id="T_3384a_level0_col7" class="col_heading level0 col7" >random</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3384a_level0_row0" class="row_heading level0 row0" >5%</th>
#       <td id="T_3384a_row0_col0" class="data row0 col0" >+0.00%</td>
#       <td id="T_3384a_row0_col1" class="data row0 col1" >-16.48%</td>
#       <td id="T_3384a_row0_col2" class="data row0 col2" >-16.48%</td>
#       <td id="T_3384a_row0_col3" class="data row0 col3" >-16.48%</td>
#       <td id="T_3384a_row0_col4" class="data row0 col4" >-16.48%</td>
#       <td id="T_3384a_row0_col5" class="data row0 col5" >-18.38%</td>
#       <td id="T_3384a_row0_col6" class="data row0 col6" >-16.82%</td>
#       <td id="T_3384a_row0_col7" class="data row0 col7" >-16.48%</td>
#     </tr>
#     <tr>
#       <th id="T_3384a_level0_row1" class="row_heading level0 row1" >12%</th>
#       <td id="T_3384a_row1_col0" class="data row1 col0" >+0.00%</td>
#       <td id="T_3384a_row1_col1" class="data row1 col1" >-7.70%</td>
#       <td id="T_3384a_row1_col2" class="data row1 col2" >-8.49%</td>
#       <td id="T_3384a_row1_col3" class="data row1 col3" >-8.01%</td>
#       <td id="T_3384a_row1_col4" class="data row1 col4" >-8.01%</td>
#       <td id="T_3384a_row1_col5" class="data row1 col5" >-8.55%</td>
#       <td id="T_3384a_row1_col6" class="data row1 col6" >-7.80%</td>
#       <td id="T_3384a_row1_col7" class="data row1 col7" >-8.19%</td>
#     </tr>
#     <tr>
#       <th id="T_3384a_level0_row2" class="row_heading level0 row2" >19%</th>
#       <td id="T_3384a_row2_col0" class="data row2 col0" >+0.00%</td>
#       <td id="T_3384a_row2_col1" class="data row2 col1" >-3.64%</td>
#       <td id="T_3384a_row2_col2" class="data row2 col2" >-3.47%</td>
#       <td id="T_3384a_row2_col3" class="data row2 col3" >-4.81%</td>
#       <td id="T_3384a_row2_col4" class="data row2 col4" >-4.40%</td>
#       <td id="T_3384a_row2_col5" class="data row2 col5" >-3.84%</td>
#       <td id="T_3384a_row2_col6" class="data row2 col6" >-3.22%</td>
#       <td id="T_3384a_row2_col7" class="data row2 col7" >-3.77%</td>
#     </tr>
#     <tr>
#       <th id="T_3384a_level0_row3" class="row_heading level0 row3" >25%</th>
#       <td id="T_3384a_row3_col0" class="data row3 col0" >+0.00%</td>
#       <td id="T_3384a_row3_col1" class="data row3 col1" >-2.13%</td>
#       <td id="T_3384a_row3_col2" class="data row3 col2" >-1.93%</td>
#       <td id="T_3384a_row3_col3" class="data row3 col3" >-2.61%</td>
#       <td id="T_3384a_row3_col4" class="data row3 col4" >-2.87%</td>
#       <td id="T_3384a_row3_col5" class="data row3 col5" >-2.92%</td>
#       <td id="T_3384a_row3_col6" class="data row3 col6" >-2.07%</td>
#       <td id="T_3384a_row3_col7" class="data row3 col7" >-2.15%</td>
#     </tr>
#     <tr>
#       <th id="T_3384a_level0_row4" class="row_heading level0 row4" >31%</th>
#       <td id="T_3384a_row4_col0" class="data row4 col0" >+0.00%</td>
#       <td id="T_3384a_row4_col1" class="data row4 col1" >-1.64%</td>
#       <td id="T_3384a_row4_col2" class="data row4 col2" >-1.45%</td>
#       <td id="T_3384a_row4_col3" class="data row4 col3" >-1.60%</td>
#       <td id="T_3384a_row4_col4" class="data row4 col4" >-2.18%</td>
#       <td id="T_3384a_row4_col5" class="data row4 c

# %% [markdown]
# # HOASA

# %%
result = load_result('hoasa')

# %%
print("F1 Micro")
compare_results(result, num_data['hoasa'], 'F1 Micro')
# Out:
# F1 Micro
# <style type="text/css">
# #T_b4cce_row0_col0, #T_b4cce_row1_col0, #T_b4cce_row2_col0, #T_b4cce_row3_col0, #T_b4cce_row4_col0, #T_b4cce_row5_col0, #T_b4cce_row6_col0, #T_b4cce_row7_col0, #T_b4cce_row8_col0, #T_b4cce_row9_col0, #T_b4cce_row10_col0, #T_b4cce_row11_col0, #T_b4cce_row12_col0, #T_b4cce_row13_col0, #T_b4cce_row14_col0, #T_b4cce_row15_col0, #T_b4cce_row16_col0, #T_b4cce_row17_col0, #T_b4cce_row18_col0, #T_b4cce_row19_col0, #T_b4cce_row20_col0, #T_b4cce_row21_col0, #T_b4cce_row22_col0, #T_b4cce_row23_col0, #T_b4cce_row24_col0, #T_b4cce_row25_col0 {
#   background-color: lightgray;
# }
# #T_b4cce_row0_col1, #T_b4cce_row0_col2, #T_b4cce_row0_col3, #T_b4cce_row0_col4, #T_b4cce_row0_col5, #T_b4cce_row0_col6, #T_b4cce_row0_col7, #T_b4cce_row1_col1, #T_b4cce_row1_col2, #T_b4cce_row1_col3, #T_b4cce_row1_col4, #T_b4cce_row1_col5, #T_b4cce_row1_col6, #T_b4cce_row1_col7, #T_b4cce_row2_col1, #T_b4cce_row2_col2, #T_b4cce_row2_col3, #T_b4cce_row2_col4, #T_b4cce_row2_col5, #T_b4cce_row2_col6, #T_b4cce_row2_col7, #T_b4cce_row3_col1, #T_b4cce_row3_col2, #T_b4cce_row3_col3, #T_b4cce_row3_col4, #T_b4cce_row3_col5, #T_b4cce_row3_col6, #T_b4cce_row3_col7, #T_b4cce_row4_col1, #T_b4cce_row4_col2, #T_b4cce_row4_col3, #T_b4cce_row4_col4, #T_b4cce_row4_col5, #T_b4cce_row4_col6, #T_b4cce_row4_col7, #T_b4cce_row5_col1, #T_b4cce_row5_col2, #T_b4cce_row5_col3, #T_b4cce_row5_col4, #T_b4cce_row5_col5, #T_b4cce_row5_col6, #T_b4cce_row5_col7, #T_b4cce_row6_col1, #T_b4cce_row6_col2, #T_b4cce_row6_col3, #T_b4cce_row6_col4, #T_b4cce_row6_col5, #T_b4cce_row6_col6, #T_b4cce_row6_col7, #T_b4cce_row7_col1, #T_b4cce_row7_col2, #T_b4cce_row7_col3, #T_b4cce_row7_col4, #T_b4cce_row7_col5, #T_b4cce_row7_col6, #T_b4cce_row7_col7, #T_b4cce_row8_col1, #T_b4cce_row8_col2, #T_b4cce_row8_col3, #T_b4cce_row8_col4, #T_b4cce_row8_col5, #T_b4cce_row8_col6, #T_b4cce_row8_col7, #T_b4cce_row9_col1, #T_b4cce_row9_col2, #T_b4cce_row9_col3, #T_b4cce_row9_col4, #T_b4cce_row9_col5, #T_b4cce_row9_col6, #T_b4cce_row9_col7, #T_b4cce_row10_col1, #T_b4cce_row10_col2, #T_b4cce_row10_col3, #T_b4cce_row10_col4, #T_b4cce_row10_col5, #T_b4cce_row10_col6, #T_b4cce_row10_col7, #T_b4cce_row11_col1, #T_b4cce_row11_col2, #T_b4cce_row11_col3, #T_b4cce_row11_col4, #T_b4cce_row11_col5, #T_b4cce_row11_col6, #T_b4cce_row11_col7, #T_b4cce_row12_col1, #T_b4cce_row12_col2, #T_b4cce_row12_col3, #T_b4cce_row12_col4, #T_b4cce_row12_col5, #T_b4cce_row12_col6, #T_b4cce_row12_col7, #T_b4cce_row13_col1, #T_b4cce_row13_col2, #T_b4cce_row13_col3, #T_b4cce_row13_col4, #T_b4cce_row13_col5, #T_b4cce_row13_col6, #T_b4cce_row13_col7, #T_b4cce_row14_col1, #T_b4cce_row14_col2, #T_b4cce_row14_col3, #T_b4cce_row14_col4, #T_b4cce_row14_col5, #T_b4cce_row14_col6, #T_b4cce_row14_col7, #T_b4cce_row15_col1, #T_b4cce_row15_col2, #T_b4cce_row15_col3, #T_b4cce_row15_col4, #T_b4cce_row15_col5, #T_b4cce_row15_col6, #T_b4cce_row15_col7, #T_b4cce_row16_col1, #T_b4cce_row16_col2, #T_b4cce_row16_col3, #T_b4cce_row16_col4, #T_b4cce_row16_col5, #T_b4cce_row16_col6, #T_b4cce_row16_col7, #T_b4cce_row17_col1, #T_b4cce_row17_col2, #T_b4cce_row17_col3, #T_b4cce_row17_col4, #T_b4cce_row17_col5, #T_b4cce_row17_col6, #T_b4cce_row17_col7, #T_b4cce_row18_col1, #T_b4cce_row18_col2, #T_b4cce_row18_col3, #T_b4cce_row18_col4, #T_b4cce_row18_col5, #T_b4cce_row18_col6, #T_b4cce_row18_col7, #T_b4cce_row19_col1, #T_b4cce_row19_col2, #T_b4cce_row19_col3, #T_b4cce_row19_col4, #T_b4cce_row19_col5, #T_b4cce_row19_col6, #T_b4cce_row19_col7, #T_b4cce_row20_col1, #T_b4cce_row20_col2, #T_b4cce_row20_col3, #T_b4cce_row20_col4, #T_b4cce_row20_col5, #T_b4cce_row20_col6, #T_b4cce_row20_col7, #T_b4cce_row21_col1, #T_b4cce_row21_col2, #T_b4cce_row21_col3, #T_b4cce_row21_col4, #T_b4cce_row21_col5, #T_b4cce_row21_col6, #T_b4cce_row21_col7, #T_b4cce_row22_col1, #T_b4cce_row22_col2, #T_b4cce_row22_col3, #T_b4cce_row22_col4, #T_b4cce_row22_col5, #T_b4cce_row22_col6, #T_b4cce_row22_col7, #T_b4cce_row23_col1, #T_b4cce_row23_col2, #T_b4cce_row23_col3, #T_b4cce_row23_col4, #T_b4cce_row23_col5, #T_b4cce_row23_col6, #T_b4cce_row23_col7, #T_b4cce_row24_col1, #T_b4cce_row24_col2, #T_b4cce_row24_col3, #T_b4cce_row24_col4, #T_b4cce_row24_col5, #T_b4cce_row24_col6, #T_b4cce_row24_col7, #T_b4cce_row25_col1, #T_b4cce_row25_col2, #T_b4cce_row25_col3, #T_b4cce_row25_col4, #T_b4cce_row25_col5, #T_b4cce_row25_col6, #T_b4cce_row25_col7 {
#   background-color: lightcoral;
#   color: black;
# }
# </style>
# <table id="T_b4cce">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b4cce_level0_col0" class="col_heading level0 col0" >passive</th>
#       <th id="T_b4cce_level0_col1" class="col_heading level0 col1" >lc</th>
#       <th id="T_b4cce_level0_col2" class="col_heading level0 col2" >mc</th>
#       <th id="T_b4cce_level0_col3" class="col_heading level0 col3" >kmeans</th>
#       <th id="T_b4cce_level0_col4" class="col_heading level0 col4" >coreset</th>
#       <th id="T_b4cce_level0_col5" class="col_heading level0 col5" >comal</th>
#       <th id="T_b4cce_level0_col6" class="col_heading level0 col6" >besra</th>
#       <th id="T_b4cce_level0_col7" class="col_heading level0 col7" >random</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4cce_level0_row0" class="row_heading level0 row0" >5%</th>
#       <td id="T_b4cce_row0_col0" class="data row0 col0" >+0.00%</td>
#       <td id="T_b4cce_row0_col1" class="data row0 col1" >-12.38%</td>
#       <td id="T_b4cce_row0_col2" class="data row0 col2" >-12.50%</td>
#       <td id="T_b4cce_row0_col3" class="data row0 col3" >-12.38%</td>
#       <td id="T_b4cce_row0_col4" class="data row0 col4" >-12.38%</td>
#       <td id="T_b4cce_row0_col5" class="data row0 col5" >-10.47%</td>
#       <td id="T_b4cce_row0_col6" class="data row0 col6" >-13.06%</td>
#       <td id="T_b4cce_row0_col7" class="data row0 col7" >-12.38%</td>
#     </tr>
#     <tr>
#       <th id="T_b4cce_level0_row1" class="row_heading level0 row1" >12%</th>
#       <td id="T_b4cce_row1_col0" class="data row1 col0" >+0.00%</td>
#       <td id="T_b4cce_row1_col1" class="data row1 col1" >-4.55%</td>
#       <td id="T_b4cce_row1_col2" class="data row1 col2" >-4.77%</td>
#       <td id="T_b4cce_row1_col3" class="data row1 col3" >-4.83%</td>
#       <td id="T_b4cce_row1_col4" class="data row1 col4" >-4.50%</td>
#       <td id="T_b4cce_row1_col5" class="data row1 col5" >-4.21%</td>
#       <td id="T_b4cce_row1_col6" class="data row1 col6" >-4.96%</td>
#       <td id="T_b4cce_row1_col7" class="data row1 col7" >-4.85%</td>
#     </tr>
#     <tr>
#       <th id="T_b4cce_level0_row2" class="row_heading level0 row2" >19%</th>
#       <td id="T_b4cce_row2_col0" class="data row2 col0" >+0.00%</td>
#       <td id="T_b4cce_row2_col1" class="data row2 col1" >-2.74%</td>
#       <td id="T_b4cce_row2_col2" class="data row2 col2" >-2.42%</td>
#       <td id="T_b4cce_row2_col3" class="data row2 col3" >-2.71%</td>
#       <td id="T_b4cce_row2_col4" class="data row2 col4" >-2.65%</td>
#       <td id="T_b4cce_row2_col5" class="data row2 col5" >-2.67%</td>
#       <td id="T_b4cce_row2_col6" class="data row2 col6" >-2.94%</td>
#       <td id="T_b4cce_row2_col7" class="data row2 col7" >-2.62%</td>
#     </tr>
#     <tr>
#       <th id="T_b4cce_level0_row3" class="row_heading level0 row3" >25%</th>
#       <td id="T_b4cce_row3_col0" class="data row3 col0" >+0.00%</td>
#       <td id="T_b4cce_row3_col1" class="data row3 col1" >-1.78%</td>
#       <td id="T_b4cce_row3_col2" class="data row3 col2" >-1.58%</td>
#       <td id="T_b4cce_row3_col3" class="data row3 col3" >-1.65%</td>
#       <td id="T_b4cce_row3_col4" class="data row3 col4" >-1.93%</td>
#       <td id="T_b4cce_row3_col5" class="data row3 col5" >-2.15%</td>
#       <td id="T_b4cce_row3_col6" class="data row3 col6" >-2.14%</td>
#       <td id="T_b4cce_row3_col7" class="data row3 col7" >-1.88%</td>
#     </tr>
#     <tr>
#       <th id="T_b4cce_level0_row4" class="row_heading level0 row4" >31%</th>
#       <td id="T_b4cce_row4_col0" class="data row4 col0" >+0.00%</td>
#       <td id="T_b4cce_row4_col1" class="data row4 col1" >-1.42%</td>
#       <td id="T_b4cce_row
